# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/spark-nlp-workshop/blob/master/healthcare-nlp/01.2.Resume_MedicalNer_Model_Training.ipynb)

# %% [markdown]
# If you are using the `spark-nlp-jsl` library, please use this  [1.4.Resume_MedicalNer_Model_Training
# ](https://github.com/JohnSnowLabs/spark-nlp-workshop/blob/master/tutorials/Certification_Trainings/Healthcare/1.4.Resume_MedicalNer_Model_Training.ipynb) notebook.

# %% [markdown]
# # Resume MedicalNer Model Training
#
# Steps:
# - Train a new model for a few epochs.
# - Load the same model and train for more epochs on the same taxnonomy, and check stats.
# - Train a model already trained on a different data

# %% [markdown]
# ## Healthcare NLP for Data Scientists Course
#
# If you are not familiar with the components in this notebook, you can check [Healthcare NLP for Data Scientists Udemy Course](https://www.udemy.com/course/healthcare-nlp-for-data-scientists/) and the [MOOC Notebooks](https://github.com/JohnSnowLabs/spark-nlp-workshop/tree/master/Spark_NLP_Udemy_MOOC/Healthcare_NLP) for each components.

# %% [markdown]
# ## Colab Setup

# %%
# Install the johnsnowlabs library to access Spark-OCR and Spark-NLP for Healthcare, Finance, and Legal.
! pip install -q johnsnowlabs

# %%
from google.colab import files
print('Please Upload your John Snow Labs License using the button below')
license_keys = files.upload()

# %%
from johnsnowlabs import nlp, medical, visual

# After uploading your license run this to install all licensed Python Wheels and pre-download Jars the Spark Session JVM
nlp.settings.enforce_versions=True
nlp.install(refresh_install=True)

# %%
from johnsnowlabs import nlp, medical, visual
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# Automatically load license data and start a session with all jars user has access to
spark = nlp.start()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://c70380d4151b:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>John-Snow-Labs-Spark-Session 🚀 with Jars for: 🚀Spark-NLP==6.4.0, 💊Spark-Healthcare==6.4.0, running on ⚡ PySpark==3.4.0</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Download Clinical Word Embeddings for training

# %%
clinical_embeddings = nlp.WordEmbeddingsModel.pretrained('embeddings_clinical', "en", "clinical/models")\
    .setInputCols(["sentence", "token"])\
    .setOutputCol("embeddings")
# Out:
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]

# %% [markdown]
# ## Download Data for Training (NCBI Disease Dataset)

# %%
# !wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/NCBI_disease_official_test.conll
# !wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/NCBI_disease_official_train_dev.conll

# %%
# from sparknlp.training import CoNLL

training_data = nlp.CoNLL().readDataset(spark, 'NCBI_disease_official_train_dev.conll')

training_data.show(3)
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |                text|            document|            sentence|               token|                 pos|               label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |Identification of...|[{document, 0, 89...|[{document, 0, 89...|[{token, 0, 13, I...|[{pos, 0, 13, NN,...|[{named_entity, 0...|
# |The adenomatous p...|[{document, 0, 21...|[{document, 0, 21...|[{token, 0, 2, Th...|[{pos, 0, 2, NN, ...|[{named_entity, 0...|
# |Complex formation...|[{document, 0, 63...|[{document, 0, 63...|[{token, 0, 6, Co...|[{pos, 0, 6, NN, ...|[{named_entity, 0...|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 3 rows

# %%
test_data = nlp.CoNLL().readDataset(spark, 'NCBI_disease_official_test.conll')

test_data.show(3)
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |                text|            document|            sentence|               token|                 pos|               label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |Clustering of mis...|[{document, 0, 10...|[{document, 0, 10...|[{token, 0, 9, Cl...|[{pos, 0, 9, NN, ...|[{named_entity, 0...|
# |Ataxia - telangie...|[{document, 0, 13...|[{document, 0, 13...|[{token, 0, 5, At...|[{pos, 0, 5, NN, ...|[{named_entity, 0...|
# |The risk of cance...|[{document, 0, 15...|[{document, 0, 15...|[{token, 0, 2, Th...|[{pos, 0, 2, NN, ...|[{named_entity, 0...|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 3 rows

# %% [markdown]
# ## Split the test data into two parts:
# - We Keep the first part separate and use it for training the model further, as it will be totally unseen data from the same taxonomy.
#
# - The second part will be used to testing and evaluating

# %%
(test_data_1, test_data_2) = test_data.randomSplit([0.5, 0.5], seed = 100)

# save the test data as parquet for easy testing
clinical_embeddings.transform(test_data_1).write.parquet('test_1.parquet')

clinical_embeddings.transform(test_data_2).write.parquet('test_2.parquet')

# %% [markdown]
# ## Train a new model, pause, and resume training on the same dataset.

# %% [markdown]
# ### MedicalNerDLGraphChecker
#
# The MedicalNerDLGraphChecker processes the dataset to extract required graph parameters (tokens, labels, embedding dimensions)

# %%
nerDLGraphChecker = medical.NerDLGraphChecker()\
    .setInputCols(["sentence", "token"])\
    .setLabelColumn("label")\
    .setEmbeddingsModel(clinical_embeddings)

# %% [markdown]
# ### Train for 2 epochs

# %%
nerTagger = medical.NerApproach()\
    .setInputCols(["sentence", "token", "embeddings"])\
    .setLabelColumn("label")\
    .setOutputCol("ner")\
    .setMaxEpochs(2)\
    .setLr(0.003)\
    .setBatchSize(8)\
    .setRandomSeed(0)\
    .setVerbose(1)\
    .setEvaluationLogExtended(True) \
    .setEnableOutputLogs(True)\
    .setIncludeConfidence(True)\
    .setTestDataset('./test_2.parquet')\
    .setOutputLogsPath('./ner_logs')

ner_pipeline = nlp.Pipeline(stages=[
    clinical_embeddings,
    nerDLGraphChecker,
    nerTagger
 ])

# %%
# %%time
ner_model = ner_pipeline.fit(training_data)
# Out:
# CPU times: user 128 ms, sys: 36.5 ms, total: 164 ms
# Wall time: 3min 49s

# %%
# !ls ner_logs/MedicalNerApproach*
# Out:
# ner_logs/MedicalNerApproach_62b5bd934d4c.log

# %%
# Training Logs
! cat ner_logs/MedicalNerApproach*
# Out:
# Name of the selected graph: medical-ner-dl/blstm_10_200_128_100.pb
# Training started - total epochs: 2 - lr: 0.003 - batch size: 8 - labels: 3 - chars: 84 - training examples: 6347
#
#
# Epoch 1/2 started, lr: 0.003, dataset size: 6347
#
#
# Epoch 1/2 - 114.65s - loss: 2017.4677 - avg training loss: 2.5376952 - batches: 795
# Quality on test dataset:
# time to finish evaluation: 2.99s
# Total test loss: 102.4633	Avg test loss: 1.6010
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-Disease	 448	 45	 182	 0.9087221	 0.7111111	 0.7978629
# B-Disease	 396	 48	 135	 0.8918919	 0.7457627	 0.8123078
# tp: 844 fp: 93 fn: 317 labels: 2
# Macro-average	 prec: 0.900307, rec: 0.72843695, f1: 0.8053038
# Micro-average	 prec: 0.90074706, rec: 0.7269595, f1: 0.80457586
#
#
# Epoch 2/2 started, lr: 0.0029850747, dataset size: 6347
#
#
# Epoch 2/2 - 93.89s - loss: 802.73486 - avg training loss: 1.0097294 - batches: 795
# Quality on test dataset:
# time to finish evaluation: 2.59s
# Total test loss: 72.8574	Avg test loss: 1.1384
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-Disease	 526	 86	 104	 0.8594771	 0.83492064	 0.8470209
# B-Disease	 440	 74	 91	 0.8560311	 0.82862526	 0.84210527
# tp: 966 fp: 160 fn: 195 labels: 2
# Macro-average	 prec: 0.8577541, rec: 0.8317729, f1: 0.8445637
# Micro-average	 prec: 0.8579041, rec: 0.8320413, f1: 0.8447748

# %%
# Logs of 4 consecutive epochs to compare with 2+2 epochs on separate datasets from same taxonomy

#!cat ner_logs/MedicalNerApproach_4d3d69967c3f.log

# %% [markdown]
# ### Evaluate

# %%
#from sparknlp_jsl.eval import NerDLMetrics
import pyspark.sql.functions as F

pred_df = ner_model.stages[2].transform(clinical_embeddings.transform(test_data_2))

evaler = medical.NerDLMetrics(mode="full_chunk")

eval_result = evaler.computeMetricsFromDF(pred_df.select("label","ner"), prediction_col="ner", label_col="label", drop_o = True, case_sensitive = True).cache()

eval_result.withColumn("precision", F.round(eval_result["precision"],4))\
           .withColumn("recall", F.round(eval_result["recall"],4))\
           .withColumn("f1", F.round(eval_result["f1"],4)).show(100)

print(eval_result.selectExpr("avg(f1) as macro").show())
print (eval_result.selectExpr("sum(f1*total) as sumprod","sum(total) as sumtotal").selectExpr("sumprod/sumtotal as micro").show())
# Out:
# +-------+-----+----+-----+-----+---------+------+------+
# | entity|   tp|  fp|   fn|total|precision|recall|    f1|
# +-------+-----+----+-----+-----+---------+------+------+
# |Disease|427.0|87.0|100.0|527.0|   0.8307|0.8102|0.8204|
# +-------+-----+----+-----+-----+---------+------+------+
#
# +------------------+
# |             macro|
# +------------------+
# |0.8203650336215178|
# +------------------+
#
# None
# +------------------+
# |             micro|
# +------------------+
# |0.8203650336215178|
# +------------------+
#
# None

# %% [markdown]
# `ner_utils`: This new module is used after NER training to calculate mertic chunkbase and plot training logs.
#
# `evaluate`: if verbose, returns overall performance, as well as performance per chunk type; otherwise, simply returns overall precision, recall, f1 scores
#
# `loss_plot`: Plots the figure of loss vs epochs
#
# `get_charts` : Plots the figures of metrics ( precision, recall, f1) vs epochs
#
# ```
# from sparknlp_jsl.utils.ner_utils import get_charts, loss_plot, evaluate
#
# metrics = evaluate(preds_df['prediction'].values, preds_df['ground_truth'].values)
#
# loss_plot(f"./ner_logs/{log_file}")
#
# get_charts('./ner_logs/'+log_files[0])
# ```

# %% [markdown]
# ### Save the model to disk

# %%
ner_model.stages[2].write().overwrite().save('models/NCBI_NER_2_epoch')

# %% [markdown]
# ### Train using the saved model on unseen dataset
# #### We use unseen data from same taxonomy

# %%
nerTagger = medical.NerApproach()\
      .setInputCols(["sentence", "token", "embeddings"])\
      .setLabelColumn("label")\
      .setOutputCol("ner")\
      .setMaxEpochs(2)\
      .setLr(0.003)\
      .setBatchSize(8)\
      .setRandomSeed(0)\
      .setVerbose(1)\
      .setEvaluationLogExtended(True) \
      .setEnableOutputLogs(True)\
      .setIncludeConfidence(True)\
      .setTestDataset('/content/test_2.parquet')\
      .setOutputLogsPath('ner_logs')\
      .setPretrainedModelPath("models/NCBI_NER_2_epoch") ## load existing model

ner_pipeline = nlp.Pipeline(stages=[
      clinical_embeddings,
      nerDLGraphChecker,
      nerTagger
 ])

# %%
# remove the existing logs

! rm -r ./ner_logs

# %%
# %%time
ner_model_retrained = ner_pipeline.fit(test_data_1)
# Out:
# CPU times: user 60.4 ms, sys: 11.2 ms, total: 71.6 ms
# Wall time: 27.4 s

# %%
# !ls ner_logs/MedicalNerApproach*
# Out:
# ner_logs/MedicalNerApproach_9bcc98f13054.log

# %%
# !cat ./ner_logs/MedicalNerApproach*
# Out:
# Name of the selected graph: pretrained graph
# Training started - total epochs: 2 - lr: 0.003 - batch size: 8 - labels: 3 - chars: 84 - training examples: 438
#
#
# Epoch 1/2 started, lr: 0.003, dataset size: 438
#
#
# Epoch 1/2 - 10.00s - loss: 52.71894 - avg training loss: 0.9248937 - batches: 57
# Quality on test dataset:
# time to finish evaluation: 3.19s
# Total test loss: 67.1229	Avg test loss: 1.0488
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-Disease	 563	 96	 67	 0.85432476	 0.89365077	 0.87354535
# B-Disease	 457	 77	 74	 0.8558052	 0.8606403	 0.858216
# tp: 1020 fp: 173 fn: 141 labels: 2
# Macro-average	 prec: 0.855065, rec: 0.8771455, f1: 0.86596453
# Micro-average	 prec: 0.85498744, rec: 0.878553, f1: 0.86661
#
#
# Epoch 2/2 started, lr: 0.0029850747, dataset size: 438
#
#
# Epoch 2/2 - 6.86s - loss: 44.027653 - avg training loss: 0.772415 - batches: 57
# Quality on test dataset:
# time to finish evaluation: 2.41s
# Total test loss: 66.9565	Avg test loss: 1.0462
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-Disease	 553	 82	 77	 0.8708661	 0.87777776	 0.8743082
# B-Disease	 463	 65	 68	 0.87689394	 0.8719397	 0.87440985
# tp: 1016 fp: 147 fn: 145 labels: 2
# Macro-average	 prec: 0.87388, rec: 0.87485874, f1: 0.87436914
# Micro-average	 prec: 0.87360275, rec: 0.87510765, f1: 0.87435454

# %%
#from sparknlp_jsl.eval import NerDLMetrics
import pyspark.sql.functions as F

pred_df = ner_model_retrained.stages[2].transform(clinical_embeddings.transform(test_data_2))

evaler = medical.NerDLMetrics(mode="full_chunk")

eval_result = evaler.computeMetricsFromDF(pred_df.select("label","ner"), prediction_col="ner", label_col="label",case_sensitive = True).cache()

eval_result.withColumn("precision", F.round(eval_result["precision"],4))\
    .withColumn("recall", F.round(eval_result["recall"],4))\
    .withColumn("f1", F.round(eval_result["f1"],4)).show(100)

print(eval_result.selectExpr("avg(f1) as macro").show())
print (eval_result.selectExpr("sum(f1*total) as sumprod","sum(total) as sumtotal").selectExpr("sumprod/sumtotal as micro").show())
# Out:
# +-------+-----+----+----+-----+---------+------+------+
# | entity|   tp|  fp|  fn|total|precision|recall|    f1|
# +-------+-----+----+----+-----+---------+------+------+
# |Disease|450.0|77.0|77.0|527.0|   0.8539|0.8539|0.8539|
# +-------+-----+----+----+-----+---------+------+------+
#
# +------------------+
# |             macro|
# +------------------+
# |0.8538899430740038|
# +------------------+
#
# None
# +------------------+
# |             micro|
# +------------------+
# |0.8538899430740038|
# +------------------+
#
# None

# %% [markdown]
# ### Train a Model Choosing Best Model
#
# `useBestModel`:  This param preserves and restores the model that has achieved the best performance at the end of the training. The priority is metrics from testDataset (micro F1), metrics from validationSplit (micro F1), and if none is set it will keep track of loss during the training. <br/>
#
# `earlyStopping`: You can stop training at the point when the perforfmance on test/validation dataset starts to degrage. Two params are used in order to use this feature: <br/>
#
# - `earlyStoppingCriterion`: This is used set the minimal improvement of the test metric to terminate training. The metric monitored is the same as the metrics used in `useBestModel` (micro F1 when using test/validation set, loss otherwise). Default is 0 which means no early stopping is applied.
#
# - `earlyStoppingPatience`:  The number of epoch without improvement which will be tolerated. Default is 0, which means that early stopping will occur at the first time when performance in the current epoch is no better than in the previous epoch.

# %%
# remove the existing logs

! rm -r ./ner_logs

# %%
nerTagger = medical.NerApproach()\
      .setInputCols(["sentence", "token", "embeddings"])\
      .setLabelColumn("label")\
      .setOutputCol("ner")\
      .setMaxEpochs(20)\
      .setLr(0.003)\
      .setBatchSize(8)\
      .setRandomSeed(0)\
      .setVerbose(1)\
      .setEvaluationLogExtended(True) \
      .setEnableOutputLogs(True)\
      .setIncludeConfidence(True)\
      .setTestDataset('./test_2.parquet')\
      .setOutputLogsPath('./ner_logs')\
      .setValidationSplit(0.2)\
      .setUseBestModel(True)\
      .setEarlyStoppingCriterion(0.04)\
      .setEarlyStoppingPatience(3)


ner_pipeline = nlp.Pipeline(stages=[
      clinical_embeddings,
      nerDLGraphChecker,
      nerTagger
 ])

# %%
# %%time
ner_model = ner_pipeline.fit(training_data)
# Out:
# CPU times: user 142 ms, sys: 39.7 ms, total: 182 ms
# Wall time: 8min 42s

# %%
# !ls ner_logs/MedicalNerApproach*
# Out:
# ner_logs/MedicalNerApproach_60b9665b40be.log

# %%
# Training Logs
! cat ner_logs/MedicalNerApproach*
# Out:
# Name of the selected graph: medical-ner-dl/blstm_10_200_128_100.pb
# Training started - total epochs: 20 - lr: 0.003 - batch size: 8 - labels: 3 - chars: 84 - training examples: 5078
#
#
# Epoch 1/20 started, lr: 0.003, dataset size: 5078
#
#
# Epoch 1/20 - 79.09s - loss: 1679.1544 - avg training loss: 2.6401799 - batches: 636
# Quality on validation dataset (20.0%), validation examples = 1269
# time to finish evaluation: 6.37s
# Total validation loss: 212.8022	Avg validation loss: 1.3055
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-Disease	 1162	 146	 312	 0.8883792	 0.7883311	 0.8353702
# B-Disease	 976	 116	 274	 0.8937729	 0.7808	 0.8334756
# tp: 2138 fp: 262 fn: 586 labels: 2
# Macro-average	 prec: 0.8910761, rec: 0.78456557, f1: 0.8344357
# Micro-average	 prec: 0.8908333, rec: 0.78487515, f1: 0.83450425
# Quality on test dataset:
# time to finish evaluation: 2.28s
# Total test loss: 91.4491	Avg test loss: 1.4289
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-Disease	 488	 78	 142	 0.8621908	 0.7746032	 0.8160535
# B-Disease	 386	 68	 145	 0.85022026	 0.7269303	 0.7837563
# tp: 874 fp: 146 fn: 287 labels: 2
# Macro-average	 prec: 0.8562055, rec: 0.75076675, f1: 0.8000271
# Micro-average	 prec: 0.8568627, rec: 0.75279933, f1: 0.80146724
#
#
# Epoch 2/20 started, lr: 0.0029850747, dataset size: 5078
#
#
# Epoch 2/20 - 73.48s - loss: 691.5809 - avg training loss: 1.0873913 - batches: 636
# Quality on validation dataset (20.0%), validation examples = 1269
# time to finish evaluation: 5.39s
# Total validation loss: 144.2742	Avg validation loss: 0.8851
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-Disease	 1249	 117	 225	 0.9143485	 0.8473541	 0.87957746
# B-Disease	 1131	 153	 119	 0.88084114	 0.9048	 0.8926598
# tp: 2380 fp: 270 fn: 344 labels: 2
# Macro-average	 prec: 0.8975948, rec: 0.87607706, f1: 0.8867054
# Micro-average	 prec: 0.8981132, rec: 0.8737151, f1: 0.8857461
# Quality on test dataset:
# time to finish evaluation: 2.16s
# Total test loss: 62.0942	Avg test loss: 0.9702
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-Disease	 543	 79	 87	 0.87299037	 0.86190474	 0.86741215
# B-Disease	 465	 75	 66	 0.8611111	 0.8757062	 0.86834735
# tp: 1008 fp: 154 fn: 153 labels: 2
# Macro-average	 prec: 0.86705077, rec: 0.86880547, f1: 0.8679272
# Micro-average	 prec: 0.8674699, rec: 0.86821705, f1: 0.86784333
#
#
# Epoch 3/20 started, lr: 0.0029702971, dataset size: 5078
#
#
# Epoch 3/20 - 76.32s - loss: 521.60956 - avg training loss: 0.82014084 - batches: 636
# Quality on validation dataset (20.0%), validation examples = 1269
# time to finish evaluation: 5.88s
# Total validation loss: 140.4200	Avg validation loss: 0.8615
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-Disease	 1131	 86	 343	 0.9293344	 0.7672999	 0.84057975
# B-Disease	 1099	 119	 151	 0.90229887	 0.8792	 0.89059967
# tp: 2230 fp: 205 fn: 494 labels: 2
# Macro-average	 prec: 0.91581666, rec: 0.82324994, f1: 0.8670697
# Micro-average	 prec: 0.91581106, rec: 0.81864905, f1: 0.8645086
# Quality on test dataset:
# time to finish evaluation: 2.35s
# Total test loss: 61.9819	Avg test loss: 0.9685
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-Disease	 492	 55	 138	 0.89945155	 0.7809524	 0.83602375
# B-Disease	 452	 65	 79	 0.8742747	 0.8512241	 0.86259544
# tp: 944 fp: 120 fn: 217 labels: 2
# Macro-average	 prec: 0.8868631, rec: 0.81608826, f1: 0.850005
# Micro-average	 prec: 0.88721806, rec: 0.8130922, f1: 0.84853935
#
#
# Epoch 4/20 started, lr: 0.002955665, dataset size: 5078
#
#
# Epoch 4/20 - 76.17s - loss: 431.27222 - avg training loss: 0.67810094 - batches: 636
# Quality on validation dataset (20.0%), validation examples = 1269
# time to finish evaluation: 5.37s
# Total validation loss: 116.6307	Avg validation loss: 0.7155
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-Disease	 1320	 274	 154	 0.8281054	 0.8955224	 0.86049545
# B-Disease	 1128	 142	 122	 0.88818896	 0.9024	 0.8952381
# tp: 2448 fp: 416 fn: 276 labels: 2
# Macro-average	 prec: 0.85814714, rec: 0.8989612, f1: 0.8780802
# Micro-average	 prec: 0.8547486, rec: 0.8986784, f1: 0.8761632
# Quality on test dataset:
# time to finish evaluation: 2.54s
# Total test loss: 58.6320	Avg test loss: 0.9161
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-Disease	 575	 147	 55	 0.7963989	 0.9126984	 0.8505917
# B-Disease	 464	 78	 67	 0.8560886	 0.873823	 0.8648649
# tp: 1039 fp: 225 fn: 122 labels: 2
# Macro-average	 prec: 0.82624376, rec: 0.8932607, f1: 0.8584463
# Micro-average	 prec: 0.82199365, rec: 0.8949182, f1: 0.85690725
#
#
# Epoch 5/20 started, lr: 0.0029411765, dataset size: 5078
#
#
# Epoch 5/20 - 86.40s - loss: 391.33032 - avg training loss: 0.6152992 - batches: 636
# Quality on validation dataset (20.0%), validation examples = 1269
# time to finish evaluation: 5.44s
# Total validation loss: 120.1484	Avg validation loss: 0.7371
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-Disease	 1320	 177	 154	 0.8817635	 0.8955224	 0.88858974
# B-Disease	 1153	 156	 97	 0.88082504	 0.9224	 0.90113324
# tp: 2473 fp: 333 fn: 251 labels: 2
# Macro-average	 prec: 0.88129425, rec: 0.9089612, f1: 0.894914
# Micro-average	 prec: 0.8813257, rec: 0.9078561, f1: 0.8943942
# Quality on test dataset:
# time to finish evaluation: 2.30s
# Total test loss: 63.5061	Avg test loss: 0.9923
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-Disease	 553	 113	 77	 0.8303303	 0.87777776	 0.85339504
# B-Disease	 469	 90	 62	 0.8389982	 0.88323915	 0.86055046
# tp: 1022 fp: 203 fn: 139 labels: 2
# Macro-average	 prec: 0.8346642, rec: 0.8805084, f1: 0.85697365
# Micro-average	 prec: 0.83428574, rec: 0.8802756, f1: 0.8566639
#
#
# Epoch 6/20 started, lr: 0.0029268293, dataset size: 5078
#
#
# Epoch 6/20 - 76.27s - loss: 352.5215 - avg training loss: 0.5542791 - batches: 636
# Quality on validation dataset (20.0%), validation examples = 1269
# time to finish evaluation: 5.79s
# Total validation loss: 106.0887	Avg validation loss: 0.6509
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-Disease	 1326	 194	 148	 0.8723684	 0.89959294	 0.8857715
# B-Disease	 1161	 160	 89	 0.87887967	 0.9288	 0.90315056
# tp: 2487 fp: 354 fn: 237 labels: 2
# Macro-average	 prec: 0.87562406, rec: 0.9141965, f1: 0.89449465
# Micro-average	 prec: 0.875396, rec: 0.9129956, f1: 0.8938005
# Quality on test dataset:
# time to finish evaluation: 2.21s
# Total test loss: 66.4452	Avg test loss: 1.0382
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-Disease	 555	 107	 75	 0.8383686	 0.88095236	 0.85913306
# B-Disease	 468	 93	 63	 0.8342246	 0.88135594	 0.8571429
# tp: 1023 fp: 200 fn: 138 labels: 2
# Macro-average	 prec: 0.83629656, rec: 0.8811542, f1: 0.8581396
# Micro-average	 prec: 0.8364677, rec: 0.88113695, f1: 0.8582215
# Early stopping: test set macro F1 has not improved for more than 3 epochs

# %% [markdown]
# As you see above, training was stopped before 20th epoch since there were not improvement.

# %% [markdown]
# **Evaluate**

# %%
#from sparknlp_jsl.eval import NerDLMetrics

pred_df = ner_model.stages[2].transform(clinical_embeddings.transform(test_data_1))

evaler = medical.NerDLMetrics(mode="full_chunk")

eval_result = evaler.computeMetricsFromDF(pred_df.select("label","ner"), prediction_col="ner", label_col="label", drop_o = True, case_sensitive = True).cache()

eval_result.withColumn("precision", F.round(eval_result["precision"],4))\
    .withColumn("recall", F.round(eval_result["recall"],4))\
    .withColumn("f1", F.round(eval_result["f1"],4)).show(100)

print(eval_result.selectExpr("avg(f1) as macro").show())
print (eval_result.selectExpr("sum(f1*total) as sumprod","sum(total) as sumtotal").selectExpr("sumprod/sumtotal as micro").show())
# Out:
# +-------+-----+----+----+-----+---------+------+------+
# | entity|   tp|  fp|  fn|total|precision|recall|    f1|
# +-------+-----+----+----+-----+---------+------+------+
# |Disease|379.0|77.0|49.0|428.0|   0.8311|0.8855|0.8575|
# +-------+-----+----+----+-----+---------+------+------+
#
# +------------------+
# |             macro|
# +------------------+
# |0.8574660633484162|
# +------------------+
#
# None
# +------------------+
# |             micro|
# +------------------+
# |0.8574660633484162|
# +------------------+
#
# None

# %%
pred_df = ner_model.stages[2].transform(clinical_embeddings.transform(test_data_2))

evaler = medical.NerDLMetrics(mode="full_chunk")

eval_result = evaler.computeMetricsFromDF(pred_df.select("label","ner"), prediction_col="ner", label_col="label", drop_o = True, case_sensitive = True).cache()

eval_result.withColumn("precision", F.round(eval_result["precision"],4))\
    .withColumn("recall", F.round(eval_result["recall"],4))\
    .withColumn("f1", F.round(eval_result["f1"],4)).show(100)

print(eval_result.selectExpr("avg(f1) as macro").show())
print (eval_result.selectExpr("sum(f1*total) as sumprod","sum(total) as sumtotal").selectExpr("sumprod/sumtotal as micro").show())
# Out:
# +-------+-----+----+----+-----+---------+------+------+
# | entity|   tp|  fp|  fn|total|precision|recall|    f1|
# +-------+-----+----+----+-----+---------+------+------+
# |Disease|450.0|85.0|77.0|527.0|   0.8411|0.8539|0.8475|
# +-------+-----+----+----+-----+---------+------+------+
#
# +-----------------+
# |            macro|
# +-----------------+
# |0.847457627118644|
# +-----------------+
#
# None
# +-----------------+
# |            micro|
# +-----------------+
# |0.847457627118644|
# +-----------------+
#
# None

# %% [markdown]
# ## Now let's take a model trained on a different dataset and train on this dataset

# %%
jsl_ner = medical.NerModel.pretrained('ner_jsl','en','clinical/models')

jsl_ner.getClasses()
# Out:
# ner_jsl download started this may take some time.
# Approximate size to download 14.5 MB
# [OK!]
# ['O',
#  'B-Injury_or_Poisoning',
#  'B-Direction',
#  'B-Test',
#  'I-Route',
#  'B-Admission_Discharge',
#  'B-Death_Entity',
#  'I-Oxygen_Therapy',
#  'B-Relationship_Status',
#  'I-Drug_BrandName',
#  'B-Duration',
#  'I-Alcohol',
#  'I-Triglycerides',
#  'I-Date',
#  'B-Hyperlipidemia',
#  'B-Respiration',
#  'I-Test',
#  'B-Birth_Entity',
#  'I-VS_Finding',
#  'B-Age',
#  'I-Vaccine_Name',
#  'I-Social_History_Header',
#  'B-Labour_Delivery',
#  'I-Medical_Device',
#  'B-Family_History_Header',
#  'B-BMI',
#  'I-Fetus_NewBorn',
#  'I-BMI',
#  'B-Temperature',
#  'I-Section_Header',
#  'I-Communicable_Disease',
#  'I-ImagingFindings',
#  'I-Psychological_Condition',
#  'I-Obesity',
#  'I-Sexually_Active_or_Sexual_Orientation',
#  'I-Modifier',
#  'B-Alcohol',
#  'I-Temperature',
#  'I-Vaccine',
#  'I-Symptom',
#  'I-Pulse',
#  'B-Kidney_Disease',
#  'B-Oncological',
#  'I-EKG_Findings',
#  'B-Medical_History_Header',
#  'I-Relationship_Status',
#  'B-Cerebrovascular_Disease',
#  'I-Blood_Pressure',
#  'I-Diabetes',
#  'B-Oxygen_Therapy',
#  'B-O2_Saturation',
#  'B-Psychological_Condition',
#  'B-Heart_Disease',
#  'I-Frequency',
#  'B-Employment',
#  'B-Obesity',
#  'B-Disease_Syndrome_Disorder',
#  'I-Oncological',
#  'B-Pregnancy',
#  'I-RelativeDate',
#  'I-Procedure',
#  'B-ImagingFindings',
#  'B-Procedure',
#  'I-Labour_Delivery',
#  'B-Medical_Device',
#  'I-Family_History_Header',
#  'B-Race_Ethnicity',
#  'I-Hypertension',
#  'I-External_body_part_or_region',
#  'I-Imaging_Technique',
#  'I-Kidney_Disease',
#  'B-Section_Header',
#  'I-Medical_History_Header',
#  'I-Test_Result',
#  'I-Direction',
#  'I-Substance',
#  'B-Symptom',
#  'I-Treatment',
#  'B-Treatment',
#  'B-Substance',
#  'I-Clinical_Dept',
#  'I-Death_Entity',
#  'B-Route',
#  'B-Drug_Ingredient',
#  'I-LDL',
#  'I-Heart_Disease',
#  'I-Duration',
#  'B-Blood_Pressure',
#  'I-Respiration',
#  'B-Diet',
#  'I-Age',
#  'B-External_body_part_or_region',
#  'B-LDL',
#  'B-Vaccine_Name',
#  'B-VS_Finding',
#  'I-O2_Saturation',
#  'I-Race_Ethnicity',
#  'I-Substance_Quantity',
#  'B-Allergen',
#  'B-EKG_Findings',
#  'B-Imaging_Technique',
#  'I-Diet',
#  'I-Gender',
#  'I-Allergen',
#  'B-Triglycerides',
#  'B-RelativeTime',
#  'I-Disease_Syndrome_Disorder',
#  'B-Gender',
#  'B-Pulse',
#  'I-Injury_or_Poisoning',
#  'I-Total_Cholesterol',
#  'B-Social_History_Header',
#  'I-Cerebrovascular_Disease',
#  'B-Substance_Quantity',
#  'B-Diabetes',
#  'I-Admission_Discharge',
#  'B-Modifier',
#  'B-Internal_organ_or_component',
#  'B-Clinical_Dept',
#  'I-Internal_organ_or_component',
#  'I-Vital_Signs_Header',
#  'I-Height',
#  'I-Hyperlipidemia',
#  'I-RelativeTime',
#  'I-Smoking',
#  'I-Drug_Ingredient',
#  'B-Form',
#  'I-Employment',
#  'B-Drug_BrandName',
#  'B-Strength',
#  'I-Weight',
#  'B-RelativeDate',
#  'B-Fetus_NewBorn',
#  'B-Height',
#  'B-Test_Result',
#  'B-Time',
#  'B-Frequency',
#  'B-Sexually_Active_or_Sexual_Orientation',
#  'I-Strength',
#  'B-Weight',
#  'B-Vaccine',
#  'I-Pregnancy',
#  'I-Form',
#  'B-Vital_Signs_Header',
#  'I-Dosage',
#  'I-Time',
#  'B-Communicable_Disease',
#  'B-Dosage',
#  'B-Overweight',
#  'B-Hypertension',
#  'B-HDL',
#  'B-Total_Cholesterol',
#  'I-HDL',
#  'B-Smoking',
#  'B-Date']

# %% [markdown]
# ### Now train a model using this model as base

# %%
nerTagger = medical.NerApproach()\
      .setInputCols(["sentence", "token", "embeddings"])\
      .setLabelColumn("label")\
      .setOutputCol("ner")\
      .setMaxEpochs(2)\
      .setLr(0.003)\
      .setBatchSize(8)\
      .setRandomSeed(0)\
      .setVerbose(1)\
      .setEvaluationLogExtended(True) \
      .setEnableOutputLogs(True)\
      .setIncludeConfidence(True)\
      .setTestDataset('/content/test_2.parquet')\
      .setOutputLogsPath('ner_logs')\
      .setPretrainedModelPath("/root/cache_pretrained/ner_jsl_en_4.2.0_3.0_1666181370373")\
      .setOverrideExistingTags(True) # since the tags do not align, set this flag to true

# do hyperparameter by tuning the params above (max epoch, LR, dropout etc.) to get better results
ner_pipeline = nlp.Pipeline(stages=[
      clinical_embeddings,
      nerDLGraphChecker,
      nerTagger
 ])

# %%
# remove the existing logs

! rm -r ./ner_logs

# %%
# %%time
ner_jsl_retrained = ner_pipeline.fit(training_data)
# Out:
# CPU times: user 111 ms, sys: 29.5 ms, total: 141 ms
# Wall time: 4min 57s

# %%
# !cat ./ner_logs/MedicalNerApproach*
# Out:
# Name of the selected graph: pretrained graph
# Training started - total epochs: 2 - lr: 0.003 - batch size: 8 - labels: 3 - chars: 103 - training examples: 6347
#
#
# Epoch 1/2 started, lr: 0.003, dataset size: 6347
#
#
# Epoch 1/2 - 144.52s - loss: 1367.6096 - avg training loss: 1.7202637 - batches: 795
# Quality on test dataset:
# time to finish evaluation: 10.93s
# Total test loss: 90.0039	Avg test loss: 1.4063
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-Disease	 422	 30	 208	 0.9336283	 0.6698413	 0.780037
# B-Disease	 427	 61	 104	 0.875	 0.80414313	 0.83807653
# tp: 849 fp: 91 fn: 312 labels: 2
# Macro-average	 prec: 0.90431416, rec: 0.73699224, f1: 0.81212443
# Micro-average	 prec: 0.9031915, rec: 0.73126614, f1: 0.8081866
#
#
# Epoch 2/2 started, lr: 0.0029850747, dataset size: 6347
#
#
# Epoch 2/2 - 128.24s - loss: 664.2519 - avg training loss: 0.83553696 - batches: 795
# Quality on test dataset:
# time to finish evaluation: 9.73s
# Total test loss: 53.9078	Avg test loss: 0.8423
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-Disease	 557	 99	 73	 0.8490854	 0.88412696	 0.86625195
# B-Disease	 454	 73	 77	 0.86148006	 0.8549906	 0.858223
# tp: 1011 fp: 172 fn: 150 labels: 2
# Macro-average	 prec: 0.8552827, rec: 0.8695588, f1: 0.86236167
# Micro-average	 prec: 0.8546069, rec: 0.87080103, f1: 0.862628

# %%
#from sparknlp_jsl.eval import NerDLMetrics

pred_df = ner_jsl_retrained.stages[2].transform(clinical_embeddings.transform(test_data_2))

evaler = medical.NerDLMetrics(mode="full_chunk")

eval_result = evaler.computeMetricsFromDF(pred_df.select("label","ner"), prediction_col="ner", label_col="label", drop_o = True, case_sensitive = True).cache()

eval_result.withColumn("precision", F.round(eval_result["precision"],4))\
    .withColumn("recall", F.round(eval_result["recall"],4))\
    .withColumn("f1", F.round(eval_result["f1"],4)).show(100)

print(eval_result.selectExpr("avg(f1) as macro").show())
print (eval_result.selectExpr("sum(f1*total) as sumprod","sum(total) as sumtotal").selectExpr("sumprod/sumtotal as micro").show())
# Out:
# +-------+-----+----+----+-----+---------+------+------+
# | entity|   tp|  fp|  fn|total|precision|recall|    f1|
# +-------+-----+----+----+-----+---------+------+------+
# |Disease|442.0|85.0|85.0|527.0|   0.8387|0.8387|0.8387|
# +-------+-----+----+----+-----+---------+------+------+
#
# +------------------+
# |             macro|
# +------------------+
# |0.8387096774193549|
# +------------------+
#
# None
# +------------------+
# |             micro|
# +------------------+
# |0.8387096774193549|
# +------------------+
#
# None

# %% [markdown]
# ## Lower-Memory NER Training with `explodeSentencesForTraining` (6.4.0)
#
# Healthcare NLP **6.4.0** adds `explodeSentencesForTraining` to `MedicalNerApproach`. When enabled, multi-sentence training rows are split into one row per sentence before training. This can reduce peak memory usage and improve training efficiency on long documents.
#
# Validation splitting stays at the **document level** first; sentence rows are generated only for the training step. Default is `False`.
#
# | explodeSentencesForTraining | Approx. training time | Approx. peak RAM |
# |------------------------------|----------------------:|-----------------:|
# | `True` | ~11 minutes | ~9.3 GB |
# | `False` | ~24 minutes | ~30 GB |
#
# Benchmark on 30 documents (~30,000 characters). Actual results vary with hardware, Spark configuration, and hyperparameters.

# %%
nerTagger_explode = medical.NerApproach()\
      .setInputCols(["sentence", "token", "embeddings"])\
      .setLabelColumn("label")\
      .setOutputCol("ner")\
      .setMaxEpochs(2)\
      .setLr(0.003)\
      .setBatchSize(8)\
      .setRandomSeed(0)\
      .setVerbose(1)\
      .setValidationSplit(0.2)\
      .setEvaluationLogExtended(True) \
      .setEnableOutputLogs(True)\
      .setIncludeConfidence(True)\
      .setOutputLogsPath("./ner_logs")\
      .setExplodeSentencesForTraining(True)

explode_pipeline = nlp.Pipeline(stages=[
      clinical_embeddings,
      nerDLGraphChecker,
      nerTagger_explode,
])

# %%
# %%time
ner_explode_model = explode_pipeline.fit(training_data)
# Out:
# CPU times: user 61.4 ms, sys: 28.3 ms, total: 89.7 ms
# Wall time: 2min 52s
