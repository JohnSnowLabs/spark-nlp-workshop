# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/spark-nlp-workshop/blob/master/healthcare-nlp/04.3.Clinical_Deidentification_SparkNLP_vs_Cloud_Providers_Comparison.ipynb)

# %% [markdown]
# # Comparison of different Deidentification Libraries
# Out-of-the-box, without customization

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In this notebook we will include a comparison of the deidentification capabilities of different libraries on 100 random clinical notes taken from [n2C2 Deidentification](https://portal.dbmi.hms.harvard.edu/projects/n2c2-nlp/) dataset.
#
# We are just taking into account all the capabilities the libraries offer **without needing to do any further training, finetuning or defining in-house rules.**
#
# The tested libraries are:
# - [Spark NLP for Healthcare](https://nlp.johnsnowlabs.com/) ([clinical_deidentification](https://https://nlp.johnsnowlabs.com/2021/06/08/clinical_deidentification_glove_en.html) pipeline with Glove Embeddings)
# - [AWS Comprehend Medical "detect_phi"](https://docs.aws.amazon.com/comprehend-medical/latest/dev/textanalysis-phi.html) API call
# - [Microsoft Azure Cognitive Services "recognize_pii_entities"](https://docs.microsoft.com/en-us/rest/api/cognitiveservices-textanalytics/3.1preview4/entities-recognition-pii/entities-recognition-pii) API call. NOTE: This endpoint was not sufficient to cover all entities and we needed to add `recognize_entities` from the `Azure` client.
# - [Google Cloud Platform Data Loss Prevention](https://cloud.google.com/dlp/docs/deidentify-sensitive-data) API call. NOTE: This endpoint was not sufficient and we needed to add `analyze_entities` from `LanguageServiceClient`.

# %% [markdown]
# # IMPORTANT NOTES TO CONSIDER BEFORE MOVING FORWARD
# 1. All libraries tested here have different tags. A map of entities is provided.
# 2. All libraries have different annotations guidelines, so we have considered as value *fuzzy matches*, with similarity bigger than the 60% of the annotated by JSL chunk (For some APIs, the chunk "Children Care Clinic" is detected including the word "Clinic", for others only proper names ("Children Care"). Both may be valid, they just depend on the [annotation guidelines](https://https://www.johnsnowlabs.com/inter-annotator-agreement-charts-transfer-learning-training-without-license-custom-training-script-with-annotation-lab/)).
# 3. All libraries have **customization** capabilities, that mean you can get much better results if you use some in-house knowledge, rule-based approach or finetunning. However, the aim of this benchmark is to check **OUT OF THE BOX** capabilities without any customization.
# 4. All libraries have more labels that the ones we included here, we just got a sample of 8 representative labels (`ID, DATE, HOSPITAL, LOCATION, AGE, PATIENT, DOCTOR, PHONE`)
# 5. Only SparkNLP and AWS had a good coverage of all the tags. Azure and GCP needed a combination of the PHI endpoint + a commong NER for detecting other entities (as Locations, Names, etc)

# %% [markdown]
# # Labels available in each API
# Not all the API have the same specificity using labels. Some of them use more high-level tags (for example, `NAME` for both *Doctor* and *Patient* names, or `LOCATION` *City*, *ZIP*, even *Hospital*) but some others go low-level, so you can be able to differentiate between Doctors and Patients, what we should appreaciate.
#
# The more **specificity** - the better, because as a rule of thumb, the more specific the less accurate you usually are: detecting `NAME` is evidently *easier* than *detecting* and *asserting* if that name is a `Doctor`'s name or a `Patient`'s name.
#
# Same happens with LOCATIONS and subentities (Street, City, etc) and many other tasks.

# %% [markdown]
# Our reference is the annotated labels by _JSL in-house medical annotators_. **Their total amount is 8**.
#
# You can see the rest of API labels in the following table:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Which is the most specific library?
# The most specific library is **Spark NLP for Healthcare**, since it's the only one able to distinguish between a Patient and a Doctor Name, a Hospital and other Organizations or Addresses, etc.
#
# This does not say anything about the accuracy of those tags. At the end of the day, you can have just one tag **NAME** or **LOCATION** and be able to detect all patients vs doctors, or organizations vs hospitals.
#
# However, just imagine you want to mas or obfuscate the **Hospital** name. If you detect it as *ORGANIZATION** you may mask it as **ORG** and obfuscate it as "McDonalds". It is much better to be aware it's a Hospital and obfuscate is as **Mt. Sinai** instead.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Which has the best out-of-the-box performance?
# Here is the performance for the 8 annotated tags by in-house JSL medical annotators.
#
# NOTE1: all the API have different specificity. That means that, for Spark NLP, a Hospital will be detected as "**HOSPITAL**" but for Azure it may be an "**Organization**". We need to be **permissive** because different guidelines were applied when training those models in the different providers.
#
# ```
# {
#     'DATE': ['DATE', 'DateTime', 'DATE_OF_BIRTH'],
#     'ID': ['ID', 'MEDICALRECORD', 'SocialNumber', 'IDNUM'],
#     'AGE': ['AGE', 'Quantity'],
#     'PHONE': ['PHONE', 'PHONE_OR_FAX', 'PhoneNumber'],
#     'DOCTOR': ['DOCTOR', 'NAME', 'Person'],
#     'PATIENT': ['PATIENT', 'NAME', 'Person'],
#     'HOSPITAL': ['HOSPITAL', 'ADDRESS', 'Organization', 'Address', 'ORGANIZATION'],
#     'LOCATION': ['LOCATION', 'ADDRESS', 'Address', 'STATE', 'COUNTRY', 'STREET', 'CITY']
# }
# ```

# %% [markdown]
# The results show that, for the *100 clinical notes* of *n2c2 corpus*, the most accurate model is the one from **Spark NLP For Healthcare**, followed very closely by **AWS Comprehend Medical**.
#
# Also, **Spark NLP** is the most specific of them all.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now that we have seen the high-level picture, let's see the advantages and disadvantages of all of them

# %% [markdown]
# ## Spark NLP
# - Best accuracy
# - Best specificity: very granular entities
# - Can be augmented with Spark NLP NER models and rule-based components
# - Can run in air-gapped environments
# - License model: pay a license and use as much as you need

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## AWS Comprehend Medical
# - Very good accuracy
# - Average level of granularity
# - Big catalog of entities
# - SaSS model: pay per API call

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Azure Cognitive Services
# - Average accuracy
# - Strange behavious, for example if we don't know the country of the document, it was returning Specific SSN and Income codes from New Zeland. Setting country specific labels didn't work.
# - We needed to use also generic ner to complement LOCATION and PATIENT / DOCTOR, since the recall for Person Names and Places (including Hospitals) was very low.
# - Granular entities
# - Many entities available in the catalogue, focus on country-region specific
# - SaSS: pay per API call
# - Almost no ID detected even after adding different generic and PHI country-specific specific endpoints (we remove ID from the chart and metrics to not impact with a 0)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Google Cloud Platform: Data Loss Prevention (DLP)
# - Good accuracy for some tags
# - It requires some previous configuration, default tags were not properly detecting basic tags as names or locations
# - We needed to use also generic ner to complement LOCATION and PATIENT / DOCTOR, since the recall for Person Names and Places (including Hospitals) was very low.
# - More entities available in the catalog, focus on country-region specific
# - SaSS: pay per API call
# - Almost no ID detected even after adding different generic and PHI specific endpoints (we remove ID from the chart and metrics to not impact with a 0)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
#         SPARK NLP    AWS    AZURE      GCP
# AGE	      1	   0.96	0.93	  0.9
# DATE	     1       0.99	0.9	   0.96
# DOCTOR	   0.98    0.96	0.7	   0.6
# HOSPITAL 	0.92    0.89	0.72	  0.72
# LOCATION 	0.9     0.81	0.87      0.73
# PATIENT	  0.96    0.95	0.78      0.48
# PHONE	    1       1	   0.8       0.97
# ID	       0.93    0.93	-	  -
# ```

# %% [markdown]
# # AGGREGATED METRICS
# We removed ID from metrics for Azure and GCP to not impact with a 0 in the average F1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # LET US BEGIN !

# %% [markdown]
# # Download some clinical notes from N2C2

# %%
# !wget -q https://github.com/JohnSnowLabs/spark-nlp-workshop/raw/master/tutorials/Certification_Trainings/Healthcare/data/deid_surrogate_test_all_groundtruth_version2.xml

# %% [markdown]
# # Parsing the XML

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('deid_surrogate_test_all_groundtruth_version2.xml')
root = tree.getroot()

# %% [markdown]
# # Retrieving texts and PHI fields

# %%
import re
data = []
for r in root.findall('RECORD'):
    for t in r.findall('TEXT'):
        children = []
        for c in t:
            children.append((c.text, c.attrib['TYPE']))
        text = "".join([ t.text ] + [ ET.tostring(e).decode('utf-8') for e in t])
        unmasked_text = re.sub(r"<PHI [^>]*>", "", text)
        unmasked_text = re.sub(r"</PHI>", "", unmasked_text)
        data.append({'unmasked_text': unmasked_text, 'text': text, 'phi': children})

# %%
len(data)
# Out:
# 220

# %%
# Printing data[0], that contains the information of the first clinical note.
print(data[0]['unmasked_text'])
# Out:
# 113416550
# PRGH
# 13523357
# 630190
# 6/7/1999 12:00:00 AM
# Discharge Summary
# Signed
# DIS
# Admission Date :
# 06/07/1999
# Report Status :
# Signed
# Discharge Date :
# 06/13/1999
# HISTORY OF PRESENT ILLNESS :
# Essentially , Mr. Cornea is a 60 year old male who noted the onset of dark urine during early January .
# He underwent CT and ERCP at the Lisonatemi Faylandsburgnic, Community Hospital with a stent placement and resolution of jaundice .
# He underwent an ECHO and endoscopy at Ingree and Ot of Weamanshy Medical Center on April 28 .
# He was found to have a large , bulging , extrinsic mass in the lesser curvature of his stomach .
# Fine needle aspiration showed atypical cells , positively reactive mesothelial cells .
# Abdominal CT on April 14 , showed a 12 x 8 x 8 cm mass in the region of the left liver , and appeared to be from the lesser curvature of the stomach or left liver .
# He denied any nausea , vomiting , anorexia , or weight loss .
# He states that his color in urine or in stool is now normal .
# PAST MEDICAL HISTORY :
# He has hypertension and nephrolithiasis .
# PAST SURGICAL HISTORY :
# Status post left kidney stones x2 , and he has had a parathyroid surgery .
# ALLERGIES :
# He has no known drug allergies .
# MEDICATIONS PRIOR TO ADMISSION :
# Hydrochlorothiazide 25 mg q.d. , Clonidine 0.1 mg p.o. q.d. , baclofen 5 mg p.o. t.i.d.
# HOSPITAL COURSE :
# Basically , patient underwent a subtotal gastrectomy on the 7th of June by Dr. Kotefooksshuff .
# He had an uncomplicated postoperative course and he was transferred .
# Advanced his diet on postop day # 4 to a transitional diet .
# His PCA was discontinued on postop day # 4 , and essentially he was started on his pre-op medications on the postop day # 5 .
# PHYSICAL EXAMINATION :
# CHEST :
# Clear .
# HEART :
# Regular .
# ABDOMINAL INCISION :
# Clean , dry and intact .
# No drainage .
# VITAL SIGNS :
# He is afebrile and otherwise vital signs are stable .
# He is having good p.o. intake on present diet and he is moving his bowels .
# DISPOSITION :
# He is going to a rehabilitation facility until he is able to live independently .
# DISCHARGE MEDICATIONS :
# Same as pre-op , with the addition of Roxicet elixir .
# Dictated By :
# THAMETO DOYLE , M.D. OS43
# Attending :
# PRO R. KOTEFOOKSSHUFF , M.D. RF6 ZY525/1920
# Batch :
# 69874
# Index No. YFKAJTRZX9
# D :
# 06/13/99
# T :
# 06/13/99 KE9
# [ report_end ]

# %%
print(data[0]['phi'])
# Out:
# [('113416550', 'ID'), ('PRGH', 'HOSPITAL'), ('13523357', 'ID'), ('630190', 'ID'), ('6/7', 'DATE'), ('06/07', 'DATE'), ('06/13', 'DATE'), ('Cornea', 'PATIENT'), ('January', 'DATE'), ('Lisonatemi Faylandsburgnic, Community Hospital', 'HOSPITAL'), ('Ingree and Ot of Weamanshy Medical Center', 'HOSPITAL'), ('April 28', 'DATE'), ('April 14', 'DATE'), ('7th of June', 'DATE'), ('Kotefooksshuff', 'DOCTOR'), ('THAMETO DOYLE', 'DOCTOR'), ('OS43', 'ID'), ('PRO R. KOTEFOOKSSHUFF', 'DOCTOR'), ('RF6 ZY525/1920', 'ID'), ('69874', 'ID'), ('YFKAJTRZX9', 'ID'), ('06/13', 'DATE'), ('06/13', 'DATE'), ('KE9', 'ID')]

# %% [markdown]
# # BENCHMARK PREPARATION

# %%
import random
CLINICAL_NOTES = 100
RANDOM_SEED = 0.1

# %% [markdown]
# ## Shuffling

# %%
f_seed = lambda: RANDOM_SEED
random.shuffle(data, f_seed)
data = data[:100]
len(data)
# Out:
# <ipython-input-8-50f44fd2cd7a>:2: DeprecationWarning: The *random* parameter to shuffle() has been deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   random.shuffle(data, f_seed)
# 100

# %%
data[0]['phi']
# Out:
# [('929334185', 'ID'),
#  ('FIH', 'HOSPITAL'),
#  ('8151167', 'ID'),
#  ('53653/y9m1', 'ID'),
#  ('539442', 'ID'),
#  ('5/13', 'DATE'),
#  ('5/13', 'DATE'),
#  ('5/16', 'DATE'),
#  ('July', 'DATE'),
#  ('July', 'DATE'),
#  ('July', 'DATE'),
#  ('November', 'DATE'),
#  ('September 1', 'DATE'),
#  ('November 5', 'DATE'),
#  ('September', 'DATE'),
#  ('05', 'DATE'),
#  ('May 14', 'DATE'),
#  ('May 15', 'DATE'),
#  ('Douet', 'PATIENT'),
#  ('Wires', 'DOCTOR'),
#  ('Wires', 'DOCTOR'),
#  ('526-6508', 'PHONE'),
#  ('May 16', 'DATE'),
#  ('Wires', 'DOCTOR'),
#  ('Caslighlourdes', 'DOCTOR'),
#  ('STIE FYFE', 'DOCTOR'),
#  ('RIEMIND CASLIGHLOURDES', 'DOCTOR'),
#  ('iv / bmot', 'DOCTOR'),
#  ('5/16', 'DATE'),
#  ('05/17', 'DATE')]

# %%
import json
with open('100n2c2.json', 'w') as f:
  f.write(json.dumps(data))

# %%
# 1 text per line
with open('100n2c2_texts.json', 'w') as f:
  f.write(json.dumps([{'text': x['unmasked_text']} for x in data]))

# %% [markdown]
# # Spark NLP for Healthcare
# Let's use Spark NLP for Healthcare's Pretrained Pipeline for `clinical_deidentification`

# %%
# Install the johnsnowlabs library to access Spark-OCR and Spark-NLP for Healthcare, Finance, and Legal.
! pip install -q johnsnowlabs==5.1.0

# %%
from google.colab import files
print('Please Upload your John Snow Labs License using the button below')
license_keys = files.upload()

# %%
from johnsnowlabs import nlp, medical, visual

# After uploading your license run this to install all licensed Python Wheels and pre-download Jars the Spark Session JVM
nlp.install()

# %%
from johnsnowlabs import nlp, medical, visual
import pandas as pd
import json
import warnings
warnings.filterwarnings('ignore')

# Automatically load license data and start a session with all jars user has access to
spark = nlp.start()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://532a9de1a18c:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>John-Snow-Labs-Spark-Session 🚀 with Jars for: 🚀Spark-NLP==5.1.0, 💊Spark-Healthcare==5.1.0, running on ⚡ PySpark==3.1.2</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
deid_pipeline = nlp.PretrainedPipeline("clinical_deidentification_glove_augmented", "en", "clinical/models")
# Out:
# clinical_deidentification_glove_augmented download started this may take some time.
# Approx size to download 173 MB
# [OK!]

# %% [markdown]
# ## `annotate()` on PretrainedPipelines uses LightPipelines, what means is optimized for speed

# %%
# %%time
res = []
for d in data:
  x = deid_pipeline.annotate(d['unmasked_text'])
  res.append(x)
# Out:
# CPU times: user 1.52 s, sys: 623 ms, total: 2.15 s
# Wall time: 1min 59s

# %%
with open('sparknlp_res_xx.json', 'w') as f:
  f.write(json.dumps(res))

# %% [markdown]
# # AWS Comprehend Medical

# %%
# !pip install -q botocore boto3

# %%
ACCESS_KEY = 'ADD ME'
SECRET_KEY = 'ADD ME'

# %%
from botocore.vendored import requests
import json
import boto3
import logging
import threading
client = boto3.client(region_name='us-west-2', service_name='comprehendmedical', aws_access_key_id=ACCESS_KEY,
    aws_secret_access_key=SECRET_KEY)

def extract_entities_from_message(message):
    return client.detect_phi(Text=message)

# %%
res = []
for d in data:
  res.append(extract_entities_from_message(d['unmasked_text']))

# %%
with open('aws_res.json', 'w') as f:
  f.write(json.dumps(res))

# %% [markdown]
# # Azure Cognitive Services

# %% [markdown]
# ## Deid Model Annotations

# %%
# !pip install azure-ai-textanalytics==5.1.0

# %%
import math
key = "ADD ME"
endpoint = "https://cstest2.cognitiveservices.azure.com/"

from azure.ai.textanalytics import TextAnalyticsClient
from azure.core.credentials import AzureKeyCredential

MAX_LENGTH = 5120

# Authenticate the client using your key and endpoint
def authenticate_client():
    ta_credential = AzureKeyCredential(key)
    text_analytics_client = TextAnalyticsClient(
            endpoint=endpoint,
            credential=ta_credential)
    return text_analytics_client

client = authenticate_client()

# Example method for detecting sensitive information (PII) from text
def pii_recognition_example(client, text):
  parts = math.ceil(len(text) / MAX_LENGTH)
  parts_text = []
  for i in range(0, parts):
    part = text[MAX_LENGTH*i:MAX_LENGTH*(i+1)]
    res = client.recognize_pii_entities([part], language="en")
    parts_text.append(res)
  return parts_text

def ner(client, text):
  parts = math.ceil(len(text) / MAX_LENGTH)
  parts_text = []
  for i in range(0, parts):
    part = text[MAX_LENGTH*i:MAX_LENGTH*(i+1)]
    res = client.recognize_entities([part], language="en")
    parts_text.append(res)
  return parts_text

# %%
results = []
for d in data:
  results.append(pii_recognition_example(client, d['unmasked_text']))

# %%
results
# Out:
# [[[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=929334185, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=5/13/1994 12:00:00 AM, category=DateTime, subcategory=None, length=21, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=96, confidence_score=0.73), PiiEntity(text=5/13/94, category=DateTime, subcategory=Date, length=7, offset=142, confidence_score=0.8), PiiEntity(text=5/16/94, category=DateTime, subcategory=Date, length=7, offset=167, confidence_score=0.8), PiiEntity(text=69 year-old, category=Quantity, subcategory=Age, length=11, offset=360, confidence_score=0.8), PiiEntity(text=July of 1993, category=DateTime, subcategory=DateRange, length=12, offset=406, confidence_score=0.8), PiiEntity(text=10 minutes, category=DateTime, subcategory=Duration, length=10, offset=676, confiden]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=979440029, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=2027705, category=DateTime, subcategory=Date, length=7, offset=15, confidence_score=0.8), PiiEntity(text=06/11/2005 12:00:00 AM, category=DateTime, subcategory=None, length=22, offset=38, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=91, confidence_score=0.73), PiiEntity(text=MRN, category=Organization, subcategory=None, length=3, offset=177, confidence_score=0.5), PiiEntity(text=2027705, category=DateTime, subcategory=Date, length=7, offset=183, confidence_score=0.8), PiiEntity(text=Age, category=Quantity, subcategory=Age, length=3, offset=191, confidence_score=0.8), PiiEntity(text=47y, category=DateTime, subcategory=Duration, length=3, offset=197, confidence_score=0.8), PiiEntity(text=06/11/2005 12:08 PM, category=DateTime, subcategory=None, length=19, offset=221, confidence_score=0.8), ]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=305265793, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=10/20/1992 12:00:00 AM, category=DateTime, subcategory=None, length=22, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=91, confidence_score=0.73), PiiEntity(text=10/20/92, category=DateTime, subcategory=Date, length=8, offset=137, confidence_score=0.8), PiiEntity(text=11/6/92, category=DateTime, subcategory=Date, length=7, offset=163, confidence_score=0.8), PiiEntity(text=71 year old, category=Quantity, subcategory=Age, length=11, offset=320, confidence_score=0.8), PiiEntity(text=Recently, category=DateTime, subcategory=None, length=8, offset=752, confidence_score=0.8), PiiEntity(text=15 years ago, category=DateTime, subcategory=Date, length=12, offset=1169, confidence_score=]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=356529973, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=1/19/1993 12:00:00 AM, category=DateTime, subcategory=None, length=21, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=113, confidence_score=0.73), PiiEntity(text=1-19-93, category=DateTime, subcategory=Date, length=7, offset=159, confidence_score=0.8), PiiEntity(text=1-25-93, category=DateTime, subcategory=Date, length=7, offset=184, confidence_score=0.8), PiiEntity(text=1-19-93, category=DateTime, subcategory=Date, length=7, offset=1037, confidence_score=0.8), PiiEntity(text=52 year old, category=Quantity, subcategory=Age, length=11, offset=1195, confidence_score=0.8), PiiEntity(text=at this time, category=DateTime, subcategory=None, length=12, offset=1871, confidence_score=],
#   [RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=Bone, category=Person, subcategory=None, length=4, offset=18, confidence_score=0.63), PiiEntity(text=in two weeks, category=DateTime, subcategory=Date, length=12, offset=37, confidence_score=0.8), PiiEntity(text=ERTCA D. BONE, category=Person, subcategory=None, length=13, offset=52, confidence_score=0.97), PiiEntity(text=1-25-93, category=DateTime, subcategory=Date, length=7, offset=93, confidence_score=0.8), PiiEntity(text=01/26/93, category=DateTime, subcategory=Date, length=8, offset=106, confidence_score=0.8), PiiEntity(text=Bone, category=Person, subcategory=None, length=4, offset=136, confidence_score=0.74), PiiEntity(text=Drabelk Kote, category=Person, subcategory=None, length=12, offset=145, confidence_score=0.7), PiiEntity(text=Memorial, category=Organization, subcategory=None, length=8, offset=165, confidence_score=0.4), PiiEntity(text=Naabel Scgach, category=Person, subcategory=None, length=13, offset=200, confidence_score=0.69), PiiEntity(t]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=506243692, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=6305145
#    963632, category=PhoneNumber, subcategory=None, length=14, offset=15, confidence_score=0.8), PiiEntity(text=11/4/2000 12:00:00 AM, category=DateTime, subcategory=None, length=21, offset=37, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=84, confidence_score=0.73), PiiEntity(text=11/04/2000, category=DateTime, subcategory=Date, length=10, offset=190, confidence_score=0.8), PiiEntity(text=11/09/2000, category=DateTime, subcategory=Date, length=10, offset=218, confidence_score=0.8), PiiEntity(text=State, category=Person, subcategory=None, length=5, offset=683, confidence_score=0.93), PiiEntity(text=81-year-old, category=Quantity, subcategory=Age, length=11, offset=695, confidence_s],
#   [RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=State, category=Person, subcategory=None, length=5, offset=257, confidence_score=0.92), PiiEntity(text=the, category=Organization, subcategory=Sports, length=3, offset=452, confidence_score=0.62), PiiEntity(text=Uspend Harmemewood Medical Center Congestive, category=Organization, subcategory=None, length=44, offset=456, confidence_score=0.77), PiiEntity(text=State, category=Person, subcategory=None, length=5, offset=800, confidence_score=0.82), PiiEntity(text=State, category=Person, subcategory=None, length=5, offset=976, confidence_score=0.77), PiiEntity(text=within a week, category=DateTime, subcategory=DateRange, length=13, offset=982, confidence_score=0.8), PiiEntity(text=Nieie Naebrand Freierm, category=Person, subcategory=None, length=22, offset=1016, confidence_score=0.98), PiiEntity(text=the Dyathenslycha Medical Center, category=Organization, subcategory=None, length=32, offset=1042, confidence_score=0.79), PiiEntity(text=State, category=Perso]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=649953363, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=8723483
#    249112, category=PhoneNumber, subcategory=None, length=14, offset=15, confidence_score=0.8), PiiEntity(text=12/19/2000 12:00:00 AM, category=DateTime, subcategory=None, length=22, offset=37, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=90, confidence_score=0.73), PiiEntity(text=UPH, category=Organization, subcategory=None, length=3, offset=155, confidence_score=0.94), PiiEntity(text=JIM, category=Organization, subcategory=None, length=3, offset=161, confidence_score=0.64), PiiEntity(text=MRN, category=Organization, subcategory=None, length=3, offset=165, confidence_score=0.5), PiiEntity(text=8723483, category=PhoneNumber, subcategory=None, length=7, offset=171, confidence_scor]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=851842962, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=9/14/1993 12:00:00 AM, category=DateTime, subcategory=None, length=21, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=101, confidence_score=0.73), PiiEntity(text=9-14-93, category=DateTime, subcategory=Date, length=7, offset=147, confidence_score=0.8), PiiEntity(text=9-26-93, category=DateTime, subcategory=Date, length=7, offset=172, confidence_score=0.8), PiiEntity(text=80 year old, category=Quantity, subcategory=Age, length=11, offset=278, confidence_score=0.8), PiiEntity(text=recently, category=DateTime, subcategory=None, length=8, offset=327, confidence_score=0.8), PiiEntity(text=Nygarthxi Anoun, category=Person, subcategory=None, length=15, offset=352, confidence_score=0],
#   [RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=night, category=DateTime, subcategory=TimeRange, length=5, offset=90, confidence_score=0.8), PiiEntity(text=at this time, category=DateTime, subcategory=None, length=12, offset=142, confidence_score=0.8), PiiEntity(text=evening of 9/21/93, category=DateTime, subcategory=DateTimeRange, length=18, offset=252, confidence_score=0.8), PiiEntity(text=at this time, category=DateTime, subcategory=None, length=12, offset=633, confidence_score=0.8), PiiEntity(text=next 24 hours, category=DateTime, subcategory=DateTimeRange, length=13, offset=1363, confidence_score=0.8), PiiEntity(text=7 day, category=DateTime, subcategory=Duration, length=5, offset=1626, confidence_score=0.8), PiiEntity(text=the Kingganmonttri- Medical Center, category=Organization, subcategory=None, length=34, offset=2122, confidence_score=0.59), PiiEntity(text=one p, category=DateTime, subcategory=Time, length=5, offset=2280, confidence_score=0.8), PiiEntity(text=9/28/93, category=DateTime, su]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=442434998, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=3/13/1992 12:00:00 AM, category=DateTime, subcategory=None, length=21, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=99, confidence_score=0.73), PiiEntity(text=3-13-92, category=DateTime, subcategory=Date, length=7, offset=145, confidence_score=0.8), PiiEntity(text=3-20-93, category=DateTime, subcategory=Date, length=7, offset=170, confidence_score=0.8), PiiEntity(text=3-15-93, category=DateTime, subcategory=Date, length=7, offset=445, confidence_score=0.8), PiiEntity(text=61 year old, category=Quantity, subcategory=Age, length=11, offset=736, confidence_score=0.8), PiiEntity(text=1984, category=DateTime, subcategory=DateRange, length=4, offset=792, confidence_score=0.8), Pi]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=113416550, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=PRGH, category=Organization, subcategory=None, length=4, offset=11, confidence_score=0.78), PiiEntity(text=6/7/1999 12:00:00 AM, category=DateTime, subcategory=None, length=20, offset=32, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=78, confidence_score=0.73), PiiEntity(text=06/07/1999, category=DateTime, subcategory=Date, length=10, offset=99, confidence_score=0.8), PiiEntity(text=06/13/1999, category=DateTime, subcategory=Date, length=10, offset=150, confidence_score=0.8), PiiEntity(text=Cornea, category=Person, subcategory=None, length=6, offset=208, confidence_score=0.92), PiiEntity(text=60 year old, category=Quantity, subcategory=Age, length=11, offset=220, confidence_score=0.8), PiiEntity(text=early January, category=DateTime, subcategory=DateRange, length=13, offset=278, confidence]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=172897359, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=7/13/1998 12:00:00 AM, category=DateTime, subcategory=None, length=21, offset=36, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=85, confidence_score=0.73), PiiEntity(text=ABREUN, category=Person, subcategory=None, length=6, offset=139, confidence_score=0.75), PiiEntity(text=BRIANG N, category=Person, subcategory=None, length=8, offset=148, confidence_score=0.9), PiiEntity(text=07/13/1998, category=DateTime, subcategory=Date, length=10, offset=198, confidence_score=0.8), PiiEntity(text=09/20/1998, category=DateTime, subcategory=Date, length=10, offset=226, confidence_score=0.8), PiiEntity(text=August 17 , 1998, category=DateTime, subcategory=Date, length=16, offset=554, confidence_score],
#   [RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=next several weeks, category=DateTime, subcategory=DateRange, length=18, offset=74, confidence_score=0.8), PiiEntity(text=By August 9th, category=DateTime, subcategory=DateRange, length=13, offset=149, confidence_score=0.8), PiiEntity(text=by August 29th, category=DateTime, subcategory=DateRange, length=14, offset=245, confidence_score=0.8), PiiEntity(text=At this time, category=DateTime, subcategory=None, length=12, offset=262, confidence_score=0.8), PiiEntity(text=ten days, category=DateTime, subcategory=Duration, length=8, offset=558, confidence_score=0.8), PiiEntity(text=next several days, category=DateTime, subcategory=DateRange, length=17, offset=685, confidence_score=0.8), PiiEntity(text=September 16th , 1998, category=DateTime, subcategory=Date, length=21, offset=777, confidence_score=0.8), PiiEntity(text=Abreun, category=Person, subcategory=None, length=6, offset=894, confidence_score=0.96), PiiEntity(text=by the 22nd of July, category=DateTim],
#   [RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=fourteen days, category=DateTime, subcategory=Duration, length=13, offset=28, confidence_score=0.8), PiiEntity(text=At this time, category=DateTime, subcategory=None, length=12, offset=44, confidence_score=0.8), PiiEntity(text=several days, category=DateTime, subcategory=Duration, length=12, offset=135, confidence_score=0.8), PiiEntity(text=several weeks, category=DateTime, subcategory=Duration, length=13, offset=207, confidence_score=0.8), PiiEntity(text=August 29th, category=DateTime, subcategory=Date, length=11, offset=241, confidence_score=0.8), PiiEntity(text=Levo, category=Organization, subcategory=None, length=4, offset=330, confidence_score=0.35), PiiEntity(text=Vanc, category=Organization, subcategory=None, length=4, offset=337, confidence_score=0.39), PiiEntity(text=one week, category=DateTime, subcategory=Duration, length=8, offset=443, confidence_score=0.8), PiiEntity(text=ten day, category=DateTime, subcategory=Duration, length=7, offset=5],
#   [RecognizePiiEntitiesResult(id=0, entities=[], redacted_text=port_end ]
#    , warnings=[], statistics=None, is_error=False)]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=353101799, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=353101799, category=NZSocialWelfareNumber, subcategory=None, length=9, offset=1, confidence_score=0.65), PiiEntity(text=PRGH, category=Organization, subcategory=None, length=4, offset=11, confidence_score=0.78), PiiEntity(text=08386825, category=NZSocialWelfareNumber, subcategory=None, length=8, offset=16, confidence_score=0.65), PiiEntity(text=01/10/1999 12:00:00 AM, category=DateTime, subcategory=None, length=22, offset=32, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=86, confidence_score=0.73), PiiEntity(text=01/10/1999, category=DateTime, subcategory=Date, length=10, offset=107, confidence_score=0.8), PiiEntity(text=01/13/1999, category=DateTime, subcategory=Date, length=10, offset=158, confidence_score=0.8), PiiEntity(text=Foot, category=Person, subcategory=None, length=4, offset=404],
#   [RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=By 01/13/99, category=DateTime, subcategory=DateRange, length=11, offset=87, confidence_score=0.8), PiiEntity(text=in 24 hours, category=DateTime, subcategory=None, length=11, offset=148, confidence_score=0.8), PiiEntity(text=in five minutes, category=DateTime, subcategory=None, length=15, offset=183, confidence_score=0.8), PiiEntity(text=72 hours, category=DateTime, subcategory=Duration, length=8, offset=455, confidence_score=0.8), PiiEntity(text=8 p.m. to 8 a.m., category=DateTime, subcategory=TimeRange, length=16, offset=648, confidence_score=0.8), PiiEntity(text=5 p.m., category=DateTime, subcategory=Time, length=6, offset=770, confidence_score=0.8), PiiEntity(text=Foot, category=Person, subcategory=None, length=4, offset=1009, confidence_score=0.9), PiiEntity(text=Sawbelbcount, category=Person, subcategory=None, length=12, offset=1121, confidence_score=0.98), PiiEntity(text=TOYA NIQUE, category=Person, subcategory=None, length=10, offset=1299, con]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=997390203, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=PRGH, category=Organization, subcategory=None, length=4, offset=11, confidence_score=0.78), PiiEntity(text=06/09/2004 12:00:00 AM, category=DateTime, subcategory=None, length=22, offset=33, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=73, confidence_score=0.73), PiiEntity(text=06/09/2004, category=DateTime, subcategory=Date, length=10, offset=94, confidence_score=0.8), PiiEntity(text=06/15/2004, category=DateTime, subcategory=Date, length=10, offset=145, confidence_score=0.8), PiiEntity(text=STYFI LINKEJESC, category=Person, subcategory=None, length=15, offset=168, confidence_score=0.71), PiiEntity(text=65-year-old, category=Quantity, subcategory=Age, length=11, offset=266, confidence_score=0.8), PiiEntity(text=1997, category=DateTime, subcategory=DateRange, length=4, offset=375, confiden]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=110477301, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=6582882
#    672220, category=PhoneNumber, subcategory=None, length=14, offset=15, confidence_score=0.8), PiiEntity(text=1/10/1999 12:00:00 AM, category=DateTime, subcategory=None, length=21, offset=37, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=86, confidence_score=0.73), PiiEntity(text=GACOBECHAFF, category=Person, subcategory=None, length=11, offset=140, confidence_score=0.93), PiiEntity(text=NACHIDE N, category=Person, subcategory=None, length=9, offset=154, confidence_score=0.75), PiiEntity(text=01/10/1999, category=DateTime, subcategory=Date, length=10, offset=205, confidence_score=0.8), PiiEntity(text=01/16/1999, category=DateTime, subcategory=Date, length=10, offset=233, confiden]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=533289709, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=533289709, category=NZSocialWelfareNumber, subcategory=None, length=9, offset=1, confidence_score=0.65), PiiEntity(text=20543098
#    466847, category=PhoneNumber, subcategory=None, length=15, offset=14, confidence_score=0.8), PiiEntity(text=12/29/2002 12:00:00 AM, category=DateTime, subcategory=None, length=22, offset=30, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=73, confidence_score=0.73), PiiEntity(text=12/29/2002, category=DateTime, subcategory=Date, length=10, offset=94, confidence_score=0.8), PiiEntity(text=New Years Eve, category=DateTime, subcategory=Date, length=13, offset=138, confidence_score=0.8), PiiEntity(text=MED, category=Organization, subcategory=None, length=3, offset=240, confidence_score=0.56), PiiEntity(text=12/31/02 AT 03:00 PM, category=DateTime, subcategory=None, len]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=793183831, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=PUMC, category=Organization, subcategory=None, length=4, offset=11, confidence_score=0.72), PiiEntity(text=0442446
#    437894, category=PhoneNumber, subcategory=None, length=14, offset=16, confidence_score=0.8), PiiEntity(text=9/20/2003 12:00:00 AM, category=DateTime, subcategory=None, length=21, offset=39, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=86, confidence_score=0.73), PiiEntity(text=HEESCKIH, category=Person, subcategory=None, length=8, offset=138, confidence_score=0.49), PiiEntity(text=ORA, category=Person, subcategory=None, length=3, offset=149, confidence_score=0.55), PiiEntity(text=09/20/2003, category=DateTime, subcategory=Date, length=10, offset=196, confidence_score=0.8), PiiEntity(text=10/06/2003, category=DateTime, subcategory=Date, length=10, offset=224, confidence_score=],
#   [RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=several years, category=DateTime, subcategory=Duration, length=13, offset=256, confidence_score=0.8), PiiEntity(text=a second, category=DateTime, subcategory=Duration, length=8, offset=341, confidence_score=0.8), PiiEntity(text=November 25 , 2003, category=DateTime, subcategory=Date, length=18, offset=1118, confidence_score=0.8), PiiEntity(text=may, category=DateTime, subcategory=DateRange, length=3, offset=1205, confidence_score=0.8), PiiEntity(text=ten in the morning, category=DateTime, subcategory=Time, length=18, offset=1747, confidence_score=0.8), PiiEntity(text=ten in the evening, category=DateTime, subcategory=Time, length=18, offset=1768, confidence_score=0.8), PiiEntity(text=Senna, category=Person, subcategory=None, length=5, offset=2154, confidence_score=0.75), PiiEntity(text=four days, category=DateTime, subcategory=Duration, length=9, offset=2301, confidence_score=0.8), PiiEntity(text=four days, category=DateTime, subcategory=Duration, leng]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=192218121, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=32853200
#    913527, category=PhoneNumber, subcategory=None, length=15, offset=17, confidence_score=0.8), PiiEntity(text=12/10/2002 12:00:00 AM, category=DateTime, subcategory=None, length=22, offset=33, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=82, confidence_score=0.73), PiiEntity(text=12/10/2002, category=DateTime, subcategory=Date, length=10, offset=103, confidence_score=0.8), PiiEntity(text=12/11/2002, category=DateTime, subcategory=Date, length=10, offset=147, confidence_score=0.8), PiiEntity(text=PULEFREIERM, category=Person, subcategory=None, length=11, offset=189, confidence_score=0.42), PiiEntity(text=CAR, category=Organization, subcategory=Sports, length=3, offset=251, confidence_score=0.58), PiiEntity(text=12/11/02 AT 02:00 PM, category=DateTime, subcategory=None, length=20, of],
#   [RecognizePiiEntitiesResult(id=0, entities=[], redacted_text=M
#    ****** END OF DISCHARGE ORDERS ******
#    [ report_end ]
#    , warnings=[], statistics=None, is_error=False)]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=109277792, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=109277792, category=NZSocialWelfareNumber, subcategory=None, length=9, offset=1, confidence_score=0.65), PiiEntity(text=3477400
#    810976, category=PhoneNumber, subcategory=None, length=14, offset=15, confidence_score=0.8), PiiEntity(text=01/30/2004 12:00:00 AM, category=DateTime, subcategory=None, length=22, offset=38, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=91, confidence_score=0.73), PiiEntity(text=SHUFFSKOCKOTESKI, category=Person, subcategory=None, length=16, offset=156, confidence_score=0.88), PiiEntity(text=MRN, category=Organization, subcategory=None, length=3, offset=179, confidence_score=0.5), PiiEntity(text=3477400, category=PhoneNumber, subcategory=None, length=7, offset=185, confidence_score=0.8), PiiEntity(text=Age, category=Quantity, subcategory=Age, length=3, offset=193,]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=445912627, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=445912627, category=NZSocialWelfareNumber, subcategory=None, length=9, offset=1, confidence_score=0.65), PiiEntity(text=9201893
#    581259, category=PhoneNumber, subcategory=None, length=14, offset=15, confidence_score=0.8), PiiEntity(text=5/10/2001 12:00:00 AM, category=DateTime, subcategory=None, length=21, offset=37, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=89, confidence_score=0.73), PiiEntity(text=JESC, category=Person, subcategory=None, length=4, offset=144, confidence_score=0.45), PiiEntity(text=DIMPCRI, category=Person, subcategory=None, length=7, offset=151, confidence_score=0.8), PiiEntity(text=INEO, category=Person, subcategory=None, length=4, offset=159, confidence_score=0.43), PiiEntity(text=MRN, category=Organization, subcategory=None, length=3, offset=164, confidence_score=]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=229937784, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=12/6/1993 12:00:00 AM, category=DateTime, subcategory=None, length=21, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=90, confidence_score=0.73), PiiEntity(text=12-6-93, category=DateTime, subcategory=Date, length=7, offset=136, confidence_score=0.8), PiiEntity(text=12-9-93, category=DateTime, subcategory=Date, length=7, offset=161, confidence_score=0.8), PiiEntity(text=75 year old, category=Quantity, subcategory=Age, length=11, offset=193, confidence_score=0.8), PiiEntity(text=Iming Medical Center, category=Organization, subcategory=None, length=20, offset=233, confidence_score=0.57), PiiEntity(text=12-6-93, category=DateTime, subcategory=Date, length=7, offset=434, confiden]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=721435037, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=721435037, category=NZSocialWelfareNumber, subcategory=None, length=9, offset=1, confidence_score=0.65), PiiEntity(text=7/17/2003 12:00:00 AM, category=DateTime, subcategory=None, length=21, offset=34, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=71, confidence_score=0.73), PiiEntity(text=07/17/2003, category=DateTime, subcategory=Date, length=10, offset=92, confidence_score=0.8), PiiEntity(text=07/18/2003, category=DateTime, subcategory=Date, length=10, offset=136, confidence_score=0.8), PiiEntity(text=005-89-63-9, category=PhoneNumber, subcategory=None, length=11, offset=196, confidence_score=0.8), PiiEntity(text=5P-8, category=DateTime, subcategory=TimeRange, length=4, offset=219, confidence_score=0.8), PiiEntity(text=MED, category=Organization, subcategory=None, length=3, offset=236, ]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=647737749, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=10/1/2005 12:00:00 AM, category=DateTime, subcategory=None, length=21, offset=34, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=72, confidence_score=0.73), PiiEntity(text=10/01/2005, category=DateTime, subcategory=Date, length=10, offset=93, confidence_score=0.8), PiiEntity(text=10/02/2005, category=DateTime, subcategory=Date, length=10, offset=137, confidence_score=0.8), PiiEntity(text=10/02/05 AT 06:00 PM, category=DateTime, subcategory=None, length=20, offset=273, confidence_score=0.8), PiiEntity(text=SCARV, category=Person, subcategory=None, length=5, offset=389, confidence_score=0.94), PiiEntity(text=STAJOH NETONE, category=Person, subcategory=None, length=13, offset=397, confidence_score=0.82), PiiEntity(text=PROSCAR, category=Organization, subcategory=None, length=7, offset=485, con]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=844970557, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=844970557, category=NZSocialWelfareNumber, subcategory=None, length=9, offset=1, confidence_score=0.65), PiiEntity(text=4822461
#    736093, category=PhoneNumber, subcategory=None, length=14, offset=15, confidence_score=0.8), PiiEntity(text=11/16/2004 12:00:00 AM, category=DateTime, subcategory=None, length=22, offset=38, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=86, confidence_score=0.73), PiiEntity(text=11/16/2004, category=DateTime, subcategory=Date, length=10, offset=194, confidence_score=0.8), PiiEntity(text=11/18/2004, category=DateTime, subcategory=Date, length=10, offset=222, confidence_score=0.8), PiiEntity(text=37-year-old, category=Quantity, subcategory=Age, length=11, offset=304, confidence_score=0.8), PiiEntity(text=the week, category=DateTime, subcategory=DateRange, length=8, ]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=305265793, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=119849, category=DateTime, subcategory=Date, length=6, offset=34, confidence_score=0.8), PiiEntity(text=9/9/1993 12:00:00 AM, category=DateTime, subcategory=None, length=20, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=89, confidence_score=0.73), PiiEntity(text=9/9/93, category=DateTime, subcategory=Date, length=6, offset=135, confidence_score=0.8), PiiEntity(text=9/12/93, category=DateTime, subcategory=Date, length=7, offset=159, confidence_score=0.8), PiiEntity(text=71 year old, category=Quantity, subcategory=Age, length=11, offset=209, confidence_score=0.8), PiiEntity(text=the Istooksu Medical Center, category=Organization, subcategory=None, length=27, offset=294, confid]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=305265793, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=5/8/1993 12:00:00 AM, category=DateTime, subcategory=None, length=20, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=113, confidence_score=0.73), PiiEntity(text=5-8-93, category=DateTime, subcategory=Date, length=6, offset=159, confidence_score=0.8), PiiEntity(text=5-11-93, category=DateTime, subcategory=Date, length=7, offset=183, confidence_score=0.8), PiiEntity(text=71 year old, category=Quantity, subcategory=Age, length=11, offset=460, confidence_score=0.8), PiiEntity(text=General Surgery, category=Organization, subcategory=None, length=15, offset=663, confidence_score=0.61), PiiEntity(text=February 3 , 1992, category=DateTime, subcategory=Date, length=17, offset=880, con]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=305265793, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=09/21/1992 12:00:00 AM, category=DateTime, subcategory=None, length=22, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=124, confidence_score=0.73), PiiEntity(text=09/21/92, category=DateTime, subcategory=Date, length=8, offset=170, confidence_score=0.8), PiiEntity(text=09/24/92, category=DateTime, subcategory=Date, length=8, offset=196, confidence_score=0.8), PiiEntity(text=GYN Oncology SErvice, category=Organization, subcategory=None, length=20, offset=329, confidence_score=0.59), PiiEntity(text=1980, category=DateTime, subcategory=DateRange, length=4, offset=353, confidence_score=0.8), PiiEntity(text=Slaineaee Ganz, category=Person, subcategory=None, length=14, offset=365, ]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=305265793, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=01/06/1992 12:00:00 AM, category=DateTime, subcategory=None, length=22, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=101, confidence_score=0.73), PiiEntity(text=01-06-92, category=DateTime, subcategory=Date, length=8, offset=147, confidence_score=0.8), PiiEntity(text=1-9-92, category=DateTime, subcategory=Date, length=6, offset=173, confidence_score=0.8), PiiEntity(text=01-06-92 through 1-8-92, category=DateTime, subcategory=DateRange, length=23, offset=323, confidence_score=0.8), PiiEntity(text=71 year old, category=Quantity, subcategory=Age, length=11, offset=395, confidence_score=0.8), PiiEntity(text=the General Surgery Service, category=Organization, subcategory=None, l],
#   [RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=three day, category=DateTime, subcategory=Duration, length=9, offset=94, confidence_score=0.8), PiiEntity(text=January 8 , 1992, category=DateTime, subcategory=Date, length=16, offset=282, confidence_score=0.8), PiiEntity(text=Chabechird, category=Person, subcategory=None, length=10, offset=756, confidence_score=0.92), PiiEntity(text=RAHZACK INNELL, category=Person, subcategory=None, length=14, offset=779, confidence_score=0.98), PiiEntity(text=SLAINEAEE CHABECHIRD, category=Person, subcategory=None, length=20, offset=817, confidence_score=0.95), PiiEntity(text=01-07-92, category=DateTime, subcategory=Date, length=8, offset=865, confidence_score=0.8), PiiEntity(text=01/08/92, category=DateTime, subcategory=Date, length=8, offset=879, confidence_score=0.8), PiiEntity(text=Slaineaee Chabechird Palmda, category=Person, subcategory=None, length=27, offset=897, confidence_score=0.97)], redacted_text=e patient received a total of 480 mg of Carboplatin and a ]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=305265793, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=09/02/1992 12:00:00 AM, category=DateTime, subcategory=None, length=22, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=104, confidence_score=0.73), PiiEntity(text=09-02-92, category=DateTime, subcategory=Date, length=8, offset=150, confidence_score=0.8), PiiEntity(text=9-14-92, category=DateTime, subcategory=Date, length=7, offset=176, confidence_score=0.8), PiiEntity(text=71 year old, category=Quantity, subcategory=Age, length=11, offset=395, confidence_score=0.8), PiiEntity(text=at this time, category=DateTime, subcategory=None, length=12, offset=550, confidence_score=0.8), PiiEntity(text=the General Surgical Service, category=Organization, subcategory=None, length=28, offs],
#   [RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=1/1, category=DateTime, subcategory=Date, length=3, offset=570, confidence_score=0.8), PiiEntity(text=4/10, category=DateTime, subcategory=Date, length=4, offset=611, confidence_score=0.8), PiiEntity(text=6/6, category=DateTime, subcategory=Date, length=3, offset=646, confidence_score=0.8), PiiEntity(text=Neathe, category=Person, subcategory=None, length=6, offset=938, confidence_score=0.91), PiiEntity(text=September 11 , 1992, category=DateTime, subcategory=Date, length=19, offset=1411, confidence_score=0.8), PiiEntity(text=September 14 , 1992, category=DateTime, subcategory=Date, length=19, offset=1988, confidence_score=0.8), PiiEntity(text=Santea Gehawhi General Hospital, category=Organization, subcategory=None, length=31, offset=2616, confidence_score=0.78), PiiEntity(text=Gableslandbaltma, category=Organization, subcategory=None, length=16, offset=2668, confidence_score=0.41), PiiEntity(text=The Santea Gehawhi General Hospital, category=Organizati]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=305265793, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=5/14/1992 12:00:00 AM, category=DateTime, subcategory=None, length=21, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=90, confidence_score=0.73), PiiEntity(text=5/14/92, category=DateTime, subcategory=Date, length=7, offset=136, confidence_score=0.8), PiiEntity(text=5/19/92, category=DateTime, subcategory=Date, length=7, offset=161, confidence_score=0.8), PiiEntity(text=71 year old, category=Quantity, subcategory=Age, length=11, offset=251, confidence_score=0.8), PiiEntity(text=recently, category=DateTime, subcategory=None, length=8, offset=316, confidence_score=0.8), PiiEntity(text=5/2, category=DateTime, subcategory=Date, length=3, offset=364, confidence_score=0.8), PiiEnti]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=010760828, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=010760828, category=NZInlandRevenueNumber, subcategory=None, length=9, offset=1, confidence_score=0.75), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=3/1/1994 12:00:00 AM, category=DateTime, subcategory=None, length=20, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=89, confidence_score=0.73), PiiEntity(text=3-1-94, category=DateTime, subcategory=Date, length=6, offset=135, confidence_score=0.8), PiiEntity(text=3-14-94, category=DateTime, subcategory=Date, length=7, offset=159, confidence_score=0.8), PiiEntity(text=77 year old, category=Quantity, subcategory=Age, length=11, offset=208, confidence_score=0.8), PiiEntity(text=four weeks, category=DateTime, subcategory=Duration, length=10, offset=610, confide]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=677051476, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=1/11/1992 12:00:00 AM, category=DateTime, subcategory=None, length=21, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=90, confidence_score=0.73), PiiEntity(text=01-11-92, category=DateTime, subcategory=Date, length=8, offset=136, confidence_score=0.8), PiiEntity(text=01-22-92, category=DateTime, subcategory=Date, length=8, offset=162, confidence_score=0.8), PiiEntity(text=1/12/92, category=DateTime, subcategory=Date, length=7, offset=311, confidence_score=0.8), PiiEntity(text=Tikrhalt, category=Person, subcategory=None, length=8, offset=540, confidence_score=0.92), PiiEntity(text=86 year old, category=Quantity, subcategory=Age, length=11, offset=555, confidence_score=0.8), Pi],
#   [RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=the 11th, category=DateTime, subcategory=Date, length=8, offset=243, confidence_score=0.8), PiiEntity(text=the day, category=DateTime, subcategory=Date, length=7, offset=286, confidence_score=0.8), PiiEntity(text=Ko, category=Person, subcategory=None, length=2, offset=703, confidence_score=0.9), PiiEntity(text=one p, category=DateTime, subcategory=Time, length=5, offset=763, confidence_score=0.8), PiiEntity(text=10 days, category=DateTime, subcategory=Duration, length=7, offset=785, confidence_score=0.8), PiiEntity(text=8/27/92, category=DateTime, subcategory=Date, length=7, offset=805, confidence_score=0.8), PiiEntity(text=Visiting Nurses Association, category=Organization, subcategory=None, length=27, offset=932, confidence_score=0.95), PiiEntity(text=daily, category=DateTime, subcategory=Set, length=5, offset=992, confidence_score=0.8), PiiEntity(text=TOMEDANKELL FLOWAYLES, category=Person, subcategory=None, length=21, offset=1073, confidence_score=]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=894133108, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=02/04/1992 12:00:00 AM, category=DateTime, subcategory=None, length=22, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=91, confidence_score=0.73), PiiEntity(text=02/04/92, category=DateTime, subcategory=Date, length=8, offset=137, confidence_score=0.8), PiiEntity(text=02/15/92, category=DateTime, subcategory=Date, length=8, offset=163, confidence_score=0.8), PiiEntity(text=68 year old, category=Quantity, subcategory=Age, length=11, offset=218, confidence_score=0.8), PiiEntity(text=Cla Lip Operinlafo Hospital, category=Organization, subcategory=None, length=27, offset=312, confidence_score=0.59), PiiEntity(text=Fairm of Ijordcompmac Hospital, category=Organization, subcategory]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=013496896, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=129165, category=DateTime, subcategory=Date, length=6, offset=34, confidence_score=0.8), PiiEntity(text=02/22/1992 12:00:00 AM, category=DateTime, subcategory=None, length=22, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=105, confidence_score=0.73), PiiEntity(text=02/22/92, category=DateTime, subcategory=Date, length=8, offset=151, confidence_score=0.8), PiiEntity(text=03/08/92, category=DateTime, subcategory=Date, length=8, offset=177, confidence_score=0.8), PiiEntity(text=03/03/92, category=DateTime, subcategory=Date, length=8, offset=575, confidence_score=0.8), PiiEntity(text=Sep/24/05, category=DateTime, subcategory=Date, length=9, offset=736, confidence_score=0.8), Pii]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=405728860, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=1/3/1994 12:00:00 AM, category=DateTime, subcategory=None, length=20, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=96, confidence_score=0.73), PiiEntity(text=1-3-94, category=DateTime, subcategory=Date, length=6, offset=142, confidence_score=0.8), PiiEntity(text=1-9-94, category=DateTime, subcategory=Date, length=6, offset=166, confidence_score=0.8), PiiEntity(text=January 3 , 1994, category=DateTime, subcategory=Date, length=16, offset=405, confidence_score=0.8), PiiEntity(text=66 year old, category=Quantity, subcategory=Age, length=11, offset=710, confidence_score=0.8), PiiEntity(text=early 1992, category=DateTime, subcategory=DateRange, length=10, offset=981, confidence_]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=405728860, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=11/26/1992 12:00:00 AM, category=DateTime, subcategory=None, length=22, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=88, confidence_score=0.73), PiiEntity(text=11-26-92, category=DateTime, subcategory=Date, length=8, offset=134, confidence_score=0.8), PiiEntity(text=12-04-92, category=DateTime, subcategory=Date, length=8, offset=160, confidence_score=0.8), PiiEntity(text=11-28-92, category=DateTime, subcategory=Date, length=8, offset=335, confidence_score=0.8), PiiEntity(text=65 year old, category=Quantity, subcategory=Age, length=11, offset=518, confidence_score=0.8), PiiEntity(text=now, category=DateTime, subcategory=None, length=3, offset=588, confidence_score=0.8), PiiE]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=399210956, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=9/18/1993 12:00:00 AM, category=DateTime, subcategory=None, length=21, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=106, confidence_score=0.73), PiiEntity(text=09/18/93, category=DateTime, subcategory=Date, length=8, offset=152, confidence_score=0.8), PiiEntity(text=09/29/93, category=DateTime, subcategory=Date, length=8, offset=178, confidence_score=0.8), PiiEntity(text=09/22/93, category=DateTime, subcategory=Date, length=8, offset=464, confidence_score=0.8), PiiEntity(text=75 year old, category=Quantity, subcategory=Age, length=11, offset=509, confidence_score=0.8), PiiEntity(text=two days, category=DateTime, subcategory=Duration, length=8, offset=854, confidence_score=0],
#   [RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=09/29/93, category=DateTime, subcategory=Date, length=8, offset=184, confidence_score=0.8), PiiEntity(text=Tiffill Sapnins, category=Person, subcategory=None, length=15, offset=330, confidence_score=0.96), PiiEntity(text=Dingclearf Alllirefaith Memorial Hospital, category=Organization, subcategory=None, length=41, offset=349, confidence_score=0.8), PiiEntity(text=Dwainco Rallsversgach, category=Person, subcategory=None, length=21, offset=399, confidence_score=0.89), PiiEntity(text=the H Health Network, category=Organization, subcategory=None, length=20, offset=468, confidence_score=0.9), PiiEntity(text=q.am, category=Organization, subcategory=None, length=4, offset=648, confidence_score=0.9), PiiEntity(text=MARGNA IRON, category=Person, subcategory=None, length=11, offset=687, confidence_score=0.99), PiiEntity(text=01/09/94, category=DateTime, subcategory=Date, length=8, offset=726, confidence_score=0.8), PiiEntity(text=01/10/94, category=DateTime, sub]],
# ...
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=340169283, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=3/28/1994 12:00:00 AM, category=DateTime, subcategory=None, length=21, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=82, confidence_score=0.73), PiiEntity(text=03-28-94, category=DateTime, subcategory=Date, length=8, offset=128, confidence_score=0.8), PiiEntity(text=03-31-94, category=DateTime, subcategory=Date, length=8, offset=154, confidence_score=0.8), PiiEntity(text=56 year old, category=Quantity, subcategory=Age, length=11, offset=360, confidence_score=0.8), PiiEntity(text=three days, category=DateTime, subcategory=Duration, length=10, offset=523, confidence_score=0.8), PiiEntity(text=Fairm, category=Person, subcategory=None, length=5, offset=620, confidence_score=0.76]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=942840618, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=6/13/1994 12:00:00 AM, category=DateTime, subcategory=None, length=21, offset=35, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=86, confidence_score=0.73), PiiEntity(text=RATA GIVEN, category=Person, subcategory=None, length=10, offset=140, confidence_score=0.54), PiiEntity(text=06/13/94, category=DateTime, subcategory=Date, length=8, offset=194, confidence_score=0.8), PiiEntity(text=07/01/94, category=DateTime, subcategory=Date, length=8, offset=220, confidence_score=0.8), PiiEntity(text=6/13/94, category=DateTime, subcategory=Date, length=7, offset=416, confidence_score=0.8), PiiEntity(text=6/17/94, category=DateTime, subcategory=Date, length=7, offset=459, confidence_score=0.8), Pii],
#   [RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=6/19, category=DateTime, subcategory=Date, length=4, offset=272, confidence_score=0.8), PiiEntity(text=fall, category=DateTime, subcategory=DateRange, length=4, offset=431, confidence_score=0.8), PiiEntity(text=Given, category=Person, subcategory=None, length=5, offset=886, confidence_score=0.54), PiiEntity(text=6/22, category=DateTime, subcategory=Date, length=4, offset=961, confidence_score=0.8), PiiEntity(text=fall, category=DateTime, subcategory=DateRange, length=4, offset=1055, confidence_score=0.8), PiiEntity(text=6/24, category=DateTime, subcategory=Date, length=4, offset=1276, confidence_score=0.8), PiiEntity(text=6/26, category=DateTime, subcategory=Date, length=4, offset=1626, confidence_score=0.8), PiiEntity(text=fall, category=DateTime, subcategory=DateRange, length=4, offset=1652, confidence_score=0.8), PiiEntity(text=6/29, category=DateTime, subcategory=Date, length=4, offset=1799, confidence_score=0.8), PiiEntity(text=Given, category=Per]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=957770228, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=2/5/1994 12:00:00 AM, category=DateTime, subcategory=None, length=20, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=99, confidence_score=0.73), PiiEntity(text=2-5-94, category=DateTime, subcategory=Date, length=6, offset=145, confidence_score=0.8), PiiEntity(text=4-2-94, category=DateTime, subcategory=Date, length=6, offset=169, confidence_score=0.8), PiiEntity(text=February 6 , 1994, category=DateTime, subcategory=Date, length=17, offset=459, confidence_score=0.8), PiiEntity(text=February 10 , 1994, category=DateTime, subcategory=Date, length=18, offset=576, confidence_score=0.8), PiiEntity(text=71 year old, category=Quantity, subcategory=Age, length=11, offset=854, confide],
#   [RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=February 24 , 1994, category=DateTime, subcategory=Date, length=18, offset=414, confidence_score=0.8), PiiEntity(text=February 26 , 1994, category=DateTime, subcategory=Date, length=18, offset=514, confidence_score=0.8), PiiEntity(text=March 3 , 1994, category=DateTime, subcategory=Date, length=14, offset=716, confidence_score=0.8), PiiEntity(text=March 13 , 1994, category=DateTime, subcategory=Date, length=15, offset=1099, confidence_score=0.8), PiiEntity(text=March 14 , 1994, category=DateTime, subcategory=Date, length=15, offset=1232, confidence_score=0.8), PiiEntity(text=seven days, category=DateTime, subcategory=Duration, length=10, offset=1429, confidence_score=0.8), PiiEntity(text=March 31 , 1994, category=DateTime, subcategory=Date, length=15, offset=1606, confidence_score=0.8), PiiEntity(text=April 2 , 1994, category=DateTime, subcategory=Date, length=14, offset=1717, confidence_score=0.8), PiiEntity(text=previously, category=DateTime, subcate]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=348983165, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=4/14/1994 12:00:00 AM, category=DateTime, subcategory=None, length=21, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=115, confidence_score=0.73), PiiEntity(text=4/14/94, category=DateTime, subcategory=Date, length=7, offset=161, confidence_score=0.8), PiiEntity(text=4/20/94, category=DateTime, subcategory=Date, length=7, offset=186, confidence_score=0.8), PiiEntity(text=April 14 , 1994, category=DateTime, subcategory=Date, length=15, offset=387, confidence_score=0.8), PiiEntity(text=Le, category=Person, subcategory=None, length=2, offset=438, confidence_score=0.9), PiiEntity(text=seventy three year old, category=Quantity, subcategory=Age, length=22, offset=446, confidence_sc],
#   [RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=the Psychiatry Service, category=Organization, subcategory=None, length=22, offset=226, confidence_score=0.92), PiiEntity(text=Neurological Intensive Care Unit, category=Organization, subcategory=None, length=32, offset=608, confidence_score=0.58), PiiEntity(text=two days, category=DateTime, subcategory=Duration, length=8, offset=689, confidence_score=0.8), PiiEntity(text=the Neurology Ward, category=Organization, subcategory=None, length=18, offset=943, confidence_score=0.65), PiiEntity(text=The Psychiatry Service, category=Organization, subcategory=None, length=22, offset=1080, confidence_score=0.86), PiiEntity(text=Psychiatry, category=Organization, subcategory=None, length=10, offset=1194, confidence_score=0.47), PiiEntity(text=Black Doylestrictshore Ft. Clinics Medical Center, category=Organization, subcategory=None, length=49, offset=1486, confidence_score=0.49), PiiEntity(text=the 7th, category=DateTime, subcategory=Date, length=7, offset=1539, ]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=815556500, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=9164371
#    974151, category=PhoneNumber, subcategory=None, length=14, offset=15, confidence_score=0.8), PiiEntity(text=12/20/2002 12:00:00 AM, category=DateTime, subcategory=None, length=22, offset=37, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=85, confidence_score=0.73), PiiEntity(text=BREUNCA, category=Person, subcategory=None, length=7, offset=137, confidence_score=0.83), PiiEntity(text=AREU, category=Person, subcategory=None, length=4, offset=147, confidence_score=0.81), PiiEntity(text=12/20/2002, category=DateTime, subcategory=Date, length=10, offset=195, confidence_score=0.8), PiiEntity(text=12/26/2002, category=DateTime, subcategory=Date, length=10, offset=223, confidence_score=],
#   [RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=N KANNER, category=Person, subcategory=None, length=8, offset=0, confidence_score=0.94), PiiEntity(text=KIHDAIZ, category=Person, subcategory=None, length=7, offset=20, confidence_score=0.92)], redacted_text=******** , M.D. ILL ******* , M.D.
#    [ report_end ]
#    , warnings=[], statistics=None, is_error=False)]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=871417118, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=9/5/1994 12:00:00 AM, category=DateTime, subcategory=None, length=20, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=97, confidence_score=0.73), PiiEntity(text=9/5/94, category=DateTime, subcategory=Date, length=6, offset=143, confidence_score=0.8), PiiEntity(text=9/14/94, category=DateTime, subcategory=Date, length=7, offset=167, confidence_score=0.8), PiiEntity(text=9/6/94, category=DateTime, subcategory=Date, length=6, offset=483, confidence_score=0.8), PiiEntity(text=68 year-old, category=Quantity, subcategory=Age, length=11, offset=728, confidence_score=0.8), PiiEntity(text=one-year, category=DateTime, subcategory=Duration, length=8, offset=906, confidence_score=0.8), Pi]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=625433852, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=160996, category=DateTime, subcategory=Date, length=6, offset=34, confidence_score=0.8), PiiEntity(text=10/1/1994 12:00:00 AM, category=DateTime, subcategory=None, length=21, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=105, confidence_score=0.73), PiiEntity(text=10-01-94, category=DateTime, subcategory=Date, length=8, offset=151, confidence_score=0.8), PiiEntity(text=10-10-94, category=DateTime, subcategory=Date, length=8, offset=177, confidence_score=0.8), PiiEntity(text=10-02-94, category=DateTime, subcategory=Date, length=8, offset=436, confidence_score=0.8), PiiEntity(text=10-01-94, category=DateTime, subcategory=Date, length=8, offset=464, confidence_score=0.8), PiiEn]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=914783811, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=7478819
#    972979, category=PhoneNumber, subcategory=None, length=14, offset=15, confidence_score=0.8), PiiEntity(text=8/4/1998 12:00:00 AM, category=DateTime, subcategory=None, length=20, offset=37, confidence_score=0.8), PiiEntity(text=FALL, category=DateTime, subcategory=DateRange, length=4, offset=74, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=123, confidence_score=0.73), PiiEntity(text=012-69-91, category=PhoneNumber, subcategory=None, length=9, offset=212, confidence_score=0.8), PiiEntity(text=08/04/1998, category=DateTime, subcategory=Date, length=10, offset=239, confidence_score=0.8), PiiEntity(text=08/12/98, category=DateTime, subcategory=Date, length=8, offset=267, confidence],
#   [RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=8/5/98, category=DateTime, subcategory=Date, length=6, offset=14, confidence_score=0.8), PiiEntity(text=14 seconds, category=DateTime, subcategory=Duration, length=10, offset=789, confidence_score=0.8), PiiEntity(text=81 year old, category=Quantity, subcategory=Age, length=11, offset=911, confidence_score=0.8), PiiEntity(text=Fairm of Ijordcompmac Hospital, category=Organization, subcategory=None, length=30, offset=1005, confidence_score=0.68), PiiEntity(text=fall, category=DateTime, subcategory=DateRange, length=4, offset=1172, confidence_score=0.8), PiiEntity(text=Lyjoneshutchepawalt Cleod Exre, category=Organization, subcategory=None, length=30, offset=1231, confidence_score=0.44), PiiEntity(text=Fairm of Ijordcompmac Hospital, category=Organization, subcategory=None, length=30, offset=1505, confidence_score=0.56), PiiEntity(text=Bridges Hospital, category=Organization, subcategory=None, length=16, offset=1551, confidence_score=0.54), PiiEntity(text]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=405507617, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=2887168
#    97947758, category=PhoneNumber, subcategory=None, length=16, offset=15, confidence_score=0.8), PiiEntity(text=91688806, category=NZSocialWelfareNumber, subcategory=None, length=8, offset=32, confidence_score=0.65), PiiEntity(text=9/10/2002 12:00:00 AM, category=DateTime, subcategory=None, length=21, offset=41, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=99, confidence_score=0.73)], redacted_text=
#    *********
#    ***
#    ****************
#    ********
#    *********************
#    Face Sheet / Discharge Order
#    SIGNED
#    ***
#    [ report_end ]
#    , warnings=[], statistics=None, is_error=False)]],
#  [[RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=757750881, category=PhoneNumber, subcategory=None, length=9, offset=1, confidence_score=0.8), PiiEntity(text=FIH, category=Organization, subcategory=None, length=3, offset=11, confidence_score=0.89), PiiEntity(text=1524602, category=DateTime, subcategory=Date, length=7, offset=15, confidence_score=0.8), PiiEntity(text=10/12/1998 12:00:00 AM, category=DateTime, subcategory=None, length=22, offset=37, confidence_score=0.8), PiiEntity(text=DIS, category=Organization, subcategory=Sports, length=3, offset=87, confidence_score=0.73), PiiEntity(text=KOTE, category=Person, subcategory=None, length=4, offset=141, confidence_score=0.9), PiiEntity(text=NIE L, category=Person, subcategory=None, length=5, offset=148, confidence_score=0.91), PiiEntity(text=10/12/1998, category=DateTime, subcategory=Date, length=10, offset=195, confidence_score=0.8), PiiEntity(text=10/18/1998, category=DateTime, subcategory=Date, length=10, offset=223, confidence_score=0.8), PiiEntit],
#   [RecognizePiiEntitiesResult(id=0, entities=[PiiEntity(text=Pulmonary Service, category=Organization, subcategory=None, length=17, offset=1405, confidence_score=0.83), PiiEntity(text=14 days, category=DateTime, subcategory=Duration, length=7, offset=1578, confidence_score=0.8), PiiEntity(text=Atrovent, category=Organization, subcategory=None, length=8, offset=1607, confidence_score=0.45), PiiEntity(text=one month, category=DateTime, subcategory=Duration, length=9, offset=1663, confidence_score=0.8), PiiEntity(text=10 days, category=DateTime, subcategory=Duration, length=7, offset=2082, confidence_score=0.8), PiiEntity(text=q4, category=DateTime, subcategory=DateRange, length=2, offset=2119, confidence_score=0.8), PiiEntity(text=LENNI CAN, category=Person, subcategory=None, length=9, offset=2261, confidence_score=0.98), PiiEntity(text=08/04/1999, category=DateTime, subcategory=Date, length=10, offset=2291, confidence_score=0.8), PiiEntity(text=08/09/1999 1:46 P, category=DateTime, subcategory=None, length=17, of]]]

# %%
res = []
for doc in results:
  x = dict()
  x['redacted'] = ''
  entities = []
  flat_subdoc = [item for sublist in doc for item in sublist]
  for subdoc in flat_subdoc:
    x['redacted'] += subdoc.redacted_text
    for entity in subdoc.entities:
      y = dict()
      y['entity'] = entity.text
      y['category'] = entity.category
      y['confidence'] = entity.confidence_score
      y['offset'] = entity.offset
      y['length'] = entity.length
      entities.append(y)
  x['entities'] = entities
  res.append(x)

# %%
with open('azure_res.json', 'w') as f:
  f.write(json.dumps(res))

# %%
len(res)
# Out:
# 100

# %% [markdown]
# ## NER Model Annotations

# %%
# Getting annotations from NER model for LOCATION entities
results = []
for d in data:
  results.append(ner(client, d['unmasked_text']))

# %%
res = []
for doc in results:
  x = dict()
  # x['redacted'] = ''
  entities = []
  flat_subdoc = [item for sublist in doc for item in sublist]
  for subdoc in flat_subdoc:
    # x['redacted'] += subdoc.redacted_text
    for entity in subdoc.entities:
      y = dict()
      y['entity'] = entity.text
      y['category'] = entity.category if entity.category == 'Location' else 'NULL'
      y['confidence'] = entity.confidence_score
      y['offset'] = entity.offset
      y['length'] = entity.length
      entities.append(y)
  x['entities'] = entities
  res.append(x)

# %%
with open('azure_res_location.json', 'w') as f:
  f.write(json.dumps(res))

# %%
len(res)
# Out:
# 100

# %% [markdown]
# # GCP (Google Cloud Provider)

# %% [markdown]
# ## Deid Model Annotations

# %%
# !pip install google-cloud

# %%
import requests

# %%
import json
GCP_KEY = {
  "type": "service_account",
  "project_id": "ADD ME",
  "private_key_id": "ADD ME",
  "private_key": "ADD ME",
  "client_email": "ADD ME",
  "client_id": "ADD ME",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "ADD ME"
}
with open('./gcp_key.json', 'w') as f:
  json.dump(GCP_KEY, f)

# %%
import os
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = "/content/gcp_key.json"

# %%
# !echo $GOOGLE_APPLICATION_CREDENTIALS

# %%
# !pip install google-cloud-dlp
import google.cloud.dlp

# %%
import time

def inspect_string(
    project,
    content_string,
    info_types=[],
    custom_dictionaries=None,
    custom_regexes=None,
    min_likelihood=None,
    max_findings=None,
    include_quote=True,
):
    """Uses the Data Loss Prevention API to analyze strings for protected data.
    Args:
        project: The Google Cloud project id to use as a parent resource.
        content_string: The string to inspect.
        info_types: A list of strings representing info types to look for.
            A full list of info type categories can be fetched from the API.
        min_likelihood: A string representing the minimum likelihood threshold
            that constitutes a match. One of: 'LIKELIHOOD_UNSPECIFIED',
            'VERY_UNLIKELY', 'UNLIKELY', 'POSSIBLE', 'LIKELY', 'VERY_LIKELY'.
        max_findings: The maximum number of findings to report; 0 = no maximum.
        include_quote: Boolean for whether to display a quote of the detected
            information in the results.
    Returns:
        None; the response from the API is printed to the terminal.
    """

    # Import the client library.
    import google.cloud.dlp

    # Instantiate a client.
    dlp = google.cloud.dlp_v2.DlpServiceClient()

    # Prepare info_types by converting the list of strings into a list of
    # dictionaries (protos are also accepted).
    info_types = [{"name": info_type} for info_type in info_types]

    # Construct the configuration dictionary. Keys which are None may
    # optionally be omitted entirely.
    inspect_config = {
        "info_types": info_types,
        # "custom_info_types": custom_info_types,
        "min_likelihood": min_likelihood,
        "include_quote": include_quote,
        "limits": {"max_findings_per_request": max_findings},
    }

    # Construct the `item`.
    item = {"value": content_string}

    # Convert the project id into a full resource id.
    parent = f"projects/{project}"

    # Call the API.
    response = dlp.inspect_content(
        request={"parent": parent, "inspect_config": inspect_config, "item": item}
    )

    return response

# %%
from bs4 import BeautifulSoup

# %%
# Get Azure labels for ID
lang_page = requests.get('https://cloud.google.com/dlp/docs/infotypes-reference')
soup = BeautifulSoup(lang_page.content, 'html.parser')
codes = soup.find_all('code')
orgs = [l.get_text() for l in codes]
# id_cat = [i for i in orgs if ('ID' in i) or ('Number' in i)]
id_cat = list(set(orgs))
cleaned_list = [x for x in id_cat if (x!='GCP_CREDENTIALS')&(x!='ICD9_CODE')&(x!='DOMAIN_NAME')&(x!='TIME')&(x!='CREDIT_CARD_NUMBER')&(x!='JSON_WEB_TOKEN')&(x!='DOCUMENT_TYPE/R&D/DATABASE_BACKUP')&(x!='DOMAIN_NAME')&(x!='STORAGE_SIGNED_URL')&(x!='DOCUMENT_TYPE/LEGAL/LAW')&(x!='URL')&(x!='STORAGE_SIGNED_POLICY_DOCUMENT')&(x!='WEAK_PASSWORD_HASH')&(x!='GCP_API_KEY')&(x!='DOCUMENT_TYPE/LEGAL/COURT_ORDER')&(x!='ENCRYPTION_KEY')&(x!='ENCRYPTION_KEY')&(x!='HTTP_COOKIE')&(x!='EMAIL_ADDRESS')&(x!='DOCUMENT_TYPE/HR/RESUME')&(x!='IMEI_HARDWARE_ID')&(x!='XSRF_TOKEN')&(x!='FDA_CODE')&(x!='MEDICAL_TERM')&(x!='GENDER')&(x!='AWS_CREDENTIALS')&(x!='MAC_ADDRESS')&(x!='AZURE_AUTH_TOKEN')&(x!='DOCUMENT_TYPE/R&D/SYSTEM_LOG')&(x!='DOCUMENT_TYPE/LEGAL/PLEADING')&(x!='PASSWORD')&(x!='ICD10_CODE')&(x!='AUTH_TOKEN')&(x!='BASIC_AUTH_HEADER')&(x != 'DOCUMENT_TYPE/LEGAL/BRIEF') and (x != 'IBAN_CODE') and (x != 'ETHNIC_GROUP')and (x != 'DOCUMENT_TYPE/LEGAL/BLANK_FORM')and (x != 'DOCUMENT_TYPE/R&D/SOURCE_CODE')and (x != 'DOCUMENT_TYPE/FINANCE/SEC_FILING') and (x != 'infoTypes.list')]

# %%
gcp_anns = []

for i, d in enumerate(data):
  res = inspect_string(GCP_KEY['project_id'], d['unmasked_text'], info_types=cleaned_list)
  gcp_entities = []
  # Print out the results.
  if res.result.findings:
    for finding in res.result.findings:
      ent = {}
      try:
          ent['quote'] = finding.quote
          ent['entity'] = finding.info_type.name
          ent['start'] = finding.location.codepoint_range.start
          ent['end'] = finding.location.codepoint_range.end
          gcp_entities.append(ent)
      except AttributeError:
          pass
  gcp_anns.append({'original_text': d['unmasked_text'], 'entities': gcp_entities})
  time.sleep(20)

# %%
len(gcp_anns)
# Out:
# 100

# %%
with open('./gcp_res.json', 'w') as f:
  f.write(json.dumps(gcp_anns))

# %% [markdown]
# ## NER Model Annotations

# %%
# !pip install google-cloud-language

# %%
import json
GCP_KEY = {
  "type": "service_account",
  "project_id": "ADD ME",
  "private_key_id": "ADD ME",
  "private_key": "ADD ME",
  "client_email": "ADD ME",
  "client_id": "ADD ME",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "ADD ME"
}
with open('./gcp_key.json', 'w') as f:
  json.dump(GCP_KEY, f)

# %%
import os
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = "/content/gcp_key.json"

# %%
# !echo $GOOGLE_APPLICATION_CREDENTIALS

# %%
from google.cloud import language_v1
from google.cloud.language_v1 import enums

def gcp_ner(document):
    client = language_v1.LanguageServiceClient()
    encoding_type = enums.EncodingType.UTF8

    # Get entities from the document
    response = client.analyze_entities(document, encoding_type=encoding_type)
    return response

# %%
# GCP regular NER model
gcp_anns_ner = []

import time
for i, d in enumerate(data):
  res = gcp_ner(document = {"content": d['unmasked_text'], "type": enums.Document.Type.PLAIN_TEXT, "language": "en"})
  gcp_entities = []
  # Print out the results.
  if res.entities:
    for finding in res.entities:
      ent = {}
      try:
          ent['quote'] = finding.mentions[0].text.content
          ent['entity'] = enums.Entity.Type(finding.type).name
          ent['start'] = finding.mentions[0].text.begin_offset
          ent['end'] = int(finding.mentions[0].text.begin_offset) + len(finding.mentions[0].text.content)
          gcp_entities.append(ent)
      except AttributeError:
          pass
  gcp_anns_ner.append({'original_text': d['unmasked_text'], 'entities': gcp_entities})
  time.sleep(5)

# %%
len(gcp_anns_ner)
# Out:
# 100

# %%
with open('./gcp_res_ner.json', 'w') as f:
  f.write(json.dumps(gcp_anns_ner))

# %% [markdown]
# # BENCHMARK

# %% [markdown]
# # Load annotated data by JSL and texts

# %%
# !wget -q https://github.com/JohnSnowLabs/spark-nlp-workshop/raw/master/tutorials/Certification_Trainings/Healthcare/data/annotations.json

# %%
import json
with open('annotations.json', 'r') as f:
  annotations = json.load(f)

# %%
annotations = sorted(annotations, key=lambda x: x['id'])

# %%
import json
with open('100n2c2_texts.json', 'r') as f:
  texts = json.load(f)

# %%
annotations[0]['data']['text']
# Out:
# "\n929334185\nFIH\n8151167\n53653/y9m1\n539442\n5/13/1994 12:00:00 AM\nHYPOPHARYNGEAL CANCER .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n5/13/94\nDISCHARGE DATE :\n5/16/94\nPRINCIPAL DIAGNOSIS :\nHypopharyngeal cancer .\nPRINCIPAL PROCEDURE :\nRemoval of left neck lymph node and esophageal endoscopy and dilation .\nHISTORY AND REASON FOR ADMISSION :\nThis is a 69 year-old white male status post surgery in July of 1993 for a laryngopharyngoesophagogastrectomy with gastric reconstruction and modified right neck dissection for pharyngeal cancer .\nSince that surgery , the patient has had dysphagia off and on , solids worse than liquids .\nSometimes solids get stuck for about 10 minutes .\nAbout two months ago the patient had come to the emergency room because he couldn 't swallow for three days .\nHe required esophageal dilation .\nAlso , since July the patient has noted bilateral lymphadenopathy , especially the large submandibular , which has gotten larger .\nIt is difficult to get an exact history as to the onset of the lymphadenopathy , as the patient cannot vocalize and is intoxicated at the time of admission .\nThe lymphadenopathy is uncomfortable but not painful .\nPAST MEDICAL HISTORY :\nSignificant for radiation therapy after his surgery in July , a tracheoesophageal fistula , which was repaired , exploratory laparotomy in November , 1994 , for small bowel obstruction , hypertension , colitis , neonatal jaundice , and on September 1 , 1993 , drainage of a neck abscess .\nHe underwent closure of pharyngeal cutaneous fistula with muscle interposition on November 5 , 1994 , and a left upper lobectomy in September , 1993 , for lung cancer .\nALLERGIES :\nAspirin .\nMEDICATIONS ON ADMISSION :\nNone .\nSOCIAL HISTORY :\nNotable for heavy alcohol use and history of heavy tobacco use , although he quit two years ago .\nREVIEW OF SYSTEMS :\nNo fevers or chills , no nightsweats .\nPositive weight gain since his last admission , positive diarrhea times two weeks-soft brown stools .\nNegative bright red blood per rectum , negative coughing , negative hemoptysis , negative hematemesis , negative chest pain , positive shortness of breath with exertion .\nThe patient can walk or go up a flight of stairs without any shortness of breath , however .\nPHYSICAL EXAMINATION :\nThe patient was a pleasant , mildly intoxicated male with grossly swollen neck .\nHe was afebrile with stable vital signs .\nHead , eyes , ears , nose , throat :\nnormocephalic , atraumatic , pupils equal , regular and reactive to light and accommodation , extra ocular muscles intact .\nTongue with multiple white-yellow lesions .\nNeck grossly swollen at the midline and right angle with jaw , unable to fully swallow .\nThe lungs were clear to auscultation .\nHeart :\nregular rate and rhythm .\nThe abdomen was soft , nontender , nondistended , positive bowel sounds .\nExtremities without clubbing , cyanosis or edema .\nASSESSMENT AND PLAN :\nThis 69 year-old male status post laryngopharyngo-esophagogastrectomy for cancer in 05/93 now represents with progressive dysphagia and gross lymphadenopathy and neck mass .\nThe patient is mildly intoxicated .\nHOSPITAL COURSE :\nThe patient was given overnight hydration .\nHe was taken to the operating room on May 14 , 1994 , for a bronchoscopy and esophagoscopy , dilatation and biopsy .\nHis left neck mass was excised and preliminarily was said to be squamous cell carcinoma .\nThe patient had esophagoscopy , where a stenosis was noted which was dilated to a # 49 French catheter .\nThere were no complications .\nThe patient was taken to the floor in stable condition .\nPostoperatively , there was no crepitus and X-rays showed no mediastinal air .\nNeck biopsy site was clean .\nOn May 15 , the patient 's diet was advanced to a soft diet and then later in the day to a regular diet .\nRadiation Oncology was consulted and it was determined that Mr. Douet still had room for more palliative radiation therapy of his ne ...

# %%
texts[0]['text']
# Out:
# "\n929334185\nFIH\n8151167\n53653/y9m1\n539442\n5/13/1994 12:00:00 AM\nHYPOPHARYNGEAL CANCER .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n5/13/94\nDISCHARGE DATE :\n5/16/94\nPRINCIPAL DIAGNOSIS :\nHypopharyngeal cancer .\nPRINCIPAL PROCEDURE :\nRemoval of left neck lymph node and esophageal endoscopy and dilation .\nHISTORY AND REASON FOR ADMISSION :\nThis is a 69 year-old white male status post surgery in July of 1993 for a laryngopharyngoesophagogastrectomy with gastric reconstruction and modified right neck dissection for pharyngeal cancer .\nSince that surgery , the patient has had dysphagia off and on , solids worse than liquids .\nSometimes solids get stuck for about 10 minutes .\nAbout two months ago the patient had come to the emergency room because he couldn 't swallow for three days .\nHe required esophageal dilation .\nAlso , since July the patient has noted bilateral lymphadenopathy , especially the large submandibular , which has gotten larger .\nIt is difficult to get an exact history as to the onset of the lymphadenopathy , as the patient cannot vocalize and is intoxicated at the time of admission .\nThe lymphadenopathy is uncomfortable but not painful .\nPAST MEDICAL HISTORY :\nSignificant for radiation therapy after his surgery in July , a tracheoesophageal fistula , which was repaired , exploratory laparotomy in November , 1994 , for small bowel obstruction , hypertension , colitis , neonatal jaundice , and on September 1 , 1993 , drainage of a neck abscess .\nHe underwent closure of pharyngeal cutaneous fistula with muscle interposition on November 5 , 1994 , and a left upper lobectomy in September , 1993 , for lung cancer .\nALLERGIES :\nAspirin .\nMEDICATIONS ON ADMISSION :\nNone .\nSOCIAL HISTORY :\nNotable for heavy alcohol use and history of heavy tobacco use , although he quit two years ago .\nREVIEW OF SYSTEMS :\nNo fevers or chills , no nightsweats .\nPositive weight gain since his last admission , positive diarrhea times two weeks-soft brown stools .\nNegative bright red blood per rectum , negative coughing , negative hemoptysis , negative hematemesis , negative chest pain , positive shortness of breath with exertion .\nThe patient can walk or go up a flight of stairs without any shortness of breath , however .\nPHYSICAL EXAMINATION :\nThe patient was a pleasant , mildly intoxicated male with grossly swollen neck .\nHe was afebrile with stable vital signs .\nHead , eyes , ears , nose , throat :\nnormocephalic , atraumatic , pupils equal , regular and reactive to light and accommodation , extra ocular muscles intact .\nTongue with multiple white-yellow lesions .\nNeck grossly swollen at the midline and right angle with jaw , unable to fully swallow .\nThe lungs were clear to auscultation .\nHeart :\nregular rate and rhythm .\nThe abdomen was soft , nontender , nondistended , positive bowel sounds .\nExtremities without clubbing , cyanosis or edema .\nASSESSMENT AND PLAN :\nThis 69 year-old male status post laryngopharyngo-esophagogastrectomy for cancer in 05/93 now represents with progressive dysphagia and gross lymphadenopathy and neck mass .\nThe patient is mildly intoxicated .\nHOSPITAL COURSE :\nThe patient was given overnight hydration .\nHe was taken to the operating room on May 14 , 1994 , for a bronchoscopy and esophagoscopy , dilatation and biopsy .\nHis left neck mass was excised and preliminarily was said to be squamous cell carcinoma .\nThe patient had esophagoscopy , where a stenosis was noted which was dilated to a # 49 French catheter .\nThere were no complications .\nThe patient was taken to the floor in stable condition .\nPostoperatively , there was no crepitus and X-rays showed no mediastinal air .\nNeck biopsy site was clean .\nOn May 15 , the patient 's diet was advanced to a soft diet and then later in the day to a regular diet .\nRadiation Oncology was consulted and it was determined that Mr. Douet still had room for more palliative radiation therapy of his ne ...

# %% [markdown]
# Check that annotated texts correspond to the original texts

# %%
assert texts[0]['text'] == annotations[0]['data']['text']

# %%
assert texts[99]['text']  == annotations[99]['data']['text']

# %% [markdown]
# # Creating Annotation Named Tuple

# %%
import collections

Annotation = collections.namedtuple('Annotation', 'start end label text')

# %% [markdown]
# # Creating ground truth

# %%
ann_tuples = []
for annotation in annotations:
  for completion in annotation['completions']:
    text_ann = []
    for result in completion['result']:
      tup = Annotation(result['value']['start'], result['value']['end'], result['value']['labels'][0], result['value']['text'])
      text_ann.append(tup)
  ann_tuples.append(text_ann)

# %% [markdown]
# # Creating labels synonyms through different APIs
# Keys: Ground truth labels
# Values: Label names in different APIs

# %%
label_maps = {
    'DATE': ['DATE', 'DateTime', 'DATE_OF_BIRTH'],
    'ID': ['ID', 'MEDICALRECORD', 'IDNUM'],
    'AGE': ['AGE', 'Quantity'],
    'PHONE': ['PHONE', 'PHONE_OR_FAX', 'PhoneNumber', 'PHONE_NUMBER', 'CONTACT'],
    'DOCTOR': ['DOCTOR', 'NAME', 'Person', 'PERSON_NAME', 'PATIENT', 'USERNAME'],
    'PATIENT': ['PATIENT', 'NAME', 'Person', 'PERSON_NAME', 'DOCTOR', 'USERNAME'],
    'HOSPITAL': ['HOSPITAL', 'ADDRESS', 'Organization', 'Address', 'ORGANIZATION', 'LOCATION'],
    'LOCATION': ['LOCATION', 'ADDRESS', 'Address', 'Location', 'Organization', 'STATE', 'COUNTRY', 'STREET', 'CITY', 'HOSPITAL']}

# %%
import math
def is_same_label(api_label, label):
  api_label_mod = api_label.replace("{","")
  api_label_mod = api_label_mod.replace("}","")
  api_label_mod = api_label_mod.replace("[","")
  api_label_mod = api_label_mod.replace("]","")
  api_label_mod = api_label_mod.replace("<","")
  api_label_mod = api_label_mod.replace(">","")
  return api_label_mod in label_maps[label]

def is_sim_pos(pos1, pos2):
  # Different tokenization rules may bring to displacement. I consider a 10% of span
  diff = int(pos1) * 0.1
  return abs(pos1 - pos2) <= diff

def is_sim_text(text1, text2):
  return (text1.strip() in text2.strip()) or (text2.strip() in text1.strip()) or (Levenshtein.ratio(text1.strip(), text2.strip())>0.6)

# %% [markdown]
# # Creating Metrics
# Different libraries have different annotation guidelines, so we won't go for an exact match, but for a fuzzy match

# %%
# !pip -q install levenshtein

# %%
import Levenshtein

# TP: Exact match and label (or equivalent in the map)
# TP (fuzzy match): Partial match and exact label (or equivalent in the map)
# FP: A label annotated by the Medical Annotator was labelled as something else by the model
# FN: A label annotated by the Medical Annotator was not labelled by the model

# NOTE: We are not considering as FP a tag detected by the model and not tagged by the annotator as this is usually done,
# since the models have all many different labels not considered in the Annotator's guidelines

# Calculates TP, FP and FN for 1 document
def get_doc_metrics(ann_tuples, res_tuples, print_fn=False, print_fp=False, verbose=None):
  metrics_dict = dict()
  for key in label_maps.keys():
    metrics_dict[key] = {'tp': 0, 'fp': 0, 'fn': 0}

  if res_tuples is None:
    return metrics_dict

  for ann_tuple in ann_tuples:
    checking = False
    if verbose is not None and verbose == ann_tuple.label:
      print("- Checking " + ann_tuple.label + " - " + ann_tuple.text)
      checking = True
    found = False
    if ann_tuple.label not in label_maps:
      continue
    for res_tuple in res_tuples:
      if checking:
        print("-- towards... " + res_tuple.label + " - " + res_tuple.text + "(" + str(is_sim_pos(ann_tuple.start, res_tuple.start)) + " " + str(ann_tuple.start) + "/" + str(res_tuple.start) + "," + str(is_sim_pos(ann_tuple.end, res_tuple.end)) + " " + str(ann_tuple.end) + "/" + str(res_tuple.end) + "," + str(is_same_label(res_tuple.label, ann_tuple.label)) + "," + str(is_sim_text(ann_tuple.text, res_tuple.text)) + ")")
      # Exact match
      if ann_tuple.start == res_tuple.start and ann_tuple.end == res_tuple.end and is_same_label(res_tuple.label, ann_tuple.label) and ann_tuple.text.strip() == res_tuple.text.strip():
        metrics_dict[ann_tuple.label]['tp']+=1
        if checking:
          print ("--- Exact match!")
        found = True
        break
      # Fuzzy match
      elif (is_sim_pos(ann_tuple.start, res_tuple.start) or is_sim_pos(ann_tuple.end, res_tuple.end)) and is_same_label(res_tuple.label, ann_tuple.label) and is_sim_text(ann_tuple.text, res_tuple.text):
        metrics_dict[ann_tuple.label]['tp']+=1
        if checking:
          print ("--- Fuzzy match!")
        found = True
        break
      # False Positives
      elif (is_sim_pos(ann_tuple.start, res_tuple.start) or is_sim_pos(ann_tuple.end, res_tuple.end)) and not is_same_label(res_tuple.label, ann_tuple.label) and is_sim_text(ann_tuple.text, res_tuple.text):
        metrics_dict[ann_tuple.label]['fp']+=1
        found = True
        if checking:
          print ("--- FP!")
        if print_fp:
          print(f"False Positive. Annotated: {ann_tuple.label} --> {ann_tuple.text}\t\tExtracted: {res_tuple.label} --> {res_tuple.text}")
        break
    # Missing annotation
    if not found:
      metrics_dict[ann_tuple.label]['fn']+=1
      if checking:
        print ("--- FN!")
      if print_fn:
          print(f"False Negative in {ann_tuple.id}. Annotated: {ann_tuple.label} --> {ann_tuple.text} not found")
  return metrics_dict

# %%
# Calculates TP, FP and FN for all the documents
def get_all_doc_metrics(all_doc_ann, all_doc_res, print_fn=False, print_fp=False, verbose=None):
  if len(all_doc_ann) != len(all_doc_res):
    print("You should have the same number of annotations in ground truth and in API to evaluate")
    return None
  metrics_dict = dict()
  for key in label_maps.keys():
    metrics_dict[key] = {'tp': 0, 'fp': 0, 'fn': 0}

  for i in range(0, len(all_doc_ann)):
    res_dict = get_doc_metrics(all_doc_ann[i], all_doc_res[i], print_fn, print_fp, verbose)
    for k in metrics_dict.keys():
      for k2 in metrics_dict[key].keys():
        metrics_dict[k][k2] += res_dict[k][k2]
  return metrics_dict

# %%
# PREC, REC and F1 calculations
def get_formula_metrics(metrics_dict):
  formula_metrics_dict = dict()
  for key in metrics_dict.keys():
    prec = 0
    if metrics_dict[key]['tp']+metrics_dict[key]['fp'] != 0:
      prec = metrics_dict[key]['tp'] / (metrics_dict[key]['tp']+metrics_dict[key]['fp'])
    rec = 0
    if metrics_dict[key]['tp']+metrics_dict[key]['fn'] != 0:
      rec = metrics_dict[key]['tp'] / (metrics_dict[key]['tp']+metrics_dict[key]['fn'])
    formula_metrics_dict[key] = {
        'prec': prec,
        'rec': rec,
        'f1': (2*rec*prec) / (rec + prec) if (rec + prec) != 0 else 0}
  return formula_metrics_dict

# %% [markdown]
# # SparkNLP

# %%
import json
with open('sparknlp_res_xx.json', 'r') as f:
  sparknlp_res = json.load(f)

# %%
for i in range(0, len(sparknlp_res)):
  sparknlp_res[i]['original_text'] = texts[i]
  text = ""

# %%
import re
sparknlp_tuples = []
for n, r in enumerate(sparknlp_res):
  tuples = []
  found_chunks = []
  masks = re.findall(r"<[A-Z_]+>", "\n".join(r['masked']))
  chunks = r['ner_chunk']
  if len(masks) != len(chunks):
    sparknlp_tuples.append(None)
    continue
  for i in range(0, len(chunks)):
    mask = masks[i]
    chunk = chunks[i]
    possible_spans = [(match.start(), match.end()) for match in re.finditer(f"[\n ]{re.escape(chunk)}[\n ]", r['original_text'])]
    position = found_chunks.count(chunk)
    if position >= len(possible_spans):
      continue
    start = possible_spans[position][0]
    end = possible_spans[position][1]
    found_chunks.append(chunk)
    tuples.append(Annotation(start, end, mask, chunk))
  sparknlp_tuples.append(tuples)

# %%
sparknlp_tuples[0]
# Out:
# [Annotation(start=0, end=11, label='<MEDICALRECORD>', text='929334185'),
#  Annotation(start=10, end=15, label='<HOSPITAL>', text='FIH'),
#  Annotation(start=14, end=34, label='<MEDICALRECORD>', text='8151167\n53653/y9m1'),
#  Annotation(start=33, end=41, label='<MEDICALRECORD>', text='539442'),
#  Annotation(start=40, end=51, label='<DATE>', text='5/13/1994'),
#  Annotation(start=141, end=150, label='<DATE>', text='5/13/94'),
#  Annotation(start=166, end=175, label='<DATE>', text='5/16/94'),
#  Annotation(start=359, end=363, label='<AGE>', text='69'),
#  Annotation(start=405, end=419, label='<DATE>', text='July of 1993'),
#  Annotation(start=405, end=411, label='<DATE>', text='July'),
#  Annotation(start=845, end=851, label='<DATE>', text='July'),
#  Annotation(start=1338, end=1355, label='<DATE>', text='November , 1994'),
#  Annotation(start=1438, end=1458, label='<DATE>', text='September 1 , 1993'),
#  Annotation(start=1570, end=1589, label='<DATE>', text='November 5 , 1994'),
#  Annotation(start=1620, end=1638, label='<DATE>', text='September , 1993'),
#  Annotation(start=2918, end=2922, label='<AGE>', text='69'),
#  Annotation(start=2997, end=3004, label='<DATE>', text='05/93'),
#  Annotation(start=3223, end=3238, label='<DATE>', text='May 14 , 1994'),
#  Annotation(start=3476, end=3480, label='<AGE>', text='49'),
#  Annotation(start=3695, end=3703, label='<DATE>', text='May 15'),
#  Annotation(start=3862, end=3869, label='<PATIENT>', text='Douet'),
#  Annotation(start=3975, end=3982, label='<NAME>', text='Wires'),
#  Annotation(start=3984, end=3993, label='<DATE>', text='Tuesday'),
#  Annotation(start=4018, end=4025, label='<NAME>', text='Wires'),
#  Annotation(start=4047, end=4057, label='<PHONE>', text='526-6508'),
#  Annotation(start=4061, end=4069, label='<DATE>', text='May 16'),
#  Annotation(start=4264, end=4271, label='<NAME>', text='Wires'),
#  Annotation(start=4278, end=4294, label='<DOCTOR>', text='Caslighlourdes'),
#  Annotation(start=4295, end=4306, label='<DOCTOR>', text='STIE FYFE'),
#  Annotation(start=4328, end=4352, label='<DOCTOR>', text='RIEMIND CASLIGHLOURDES'),
#  Annotation(start=4378, end=4387, label='<DATE>', text='5/16/94'),
#  Annotation(start=4391, end=4401, label='<DATE>', text='05/17/94')]

# %%
sparknlp_dict = get_all_doc_metrics(ann_tuples, sparknlp_tuples)
sparknlp_dict
# Out:
# {'AGE': {'fn': 0, 'fp': 0, 'tp': 95},
#  'DATE': {'fn': 5, 'fp': 1, 'tp': 944},
#  'DOCTOR': {'fn': 12, 'fp': 5, 'tp': 381},
#  'HOSPITAL': {'fn': 15, 'fp': 13, 'tp': 154},
#  'ID': {'fn': 39, 'fp': 25, 'tp': 396},
#  'LOCATION': {'fn': 5, 'fp': 4, 'tp': 38},
#  'PATIENT': {'fn': 8, 'fp': 0, 'tp': 107},
#  'PHONE': {'fn': 0, 'fp': 0, 'tp': 15}}

# %%
get_formula_metrics(sparknlp_dict)
# Out:
# {'AGE': {'f1': 1.0, 'prec': 1.0, 'rec': 1.0},
#  'DATE': {'f1': 0.996832101372756,
#   'prec': 0.9989417989417989,
#   'rec': 0.9947312961011591},
#  'DOCTOR': {'f1': 0.9781771501925545,
#   'prec': 0.9870466321243523,
#   'rec': 0.9694656488549618},
#  'HOSPITAL': {'f1': 0.9166666666666667,
#   'prec': 0.9221556886227545,
#   'rec': 0.9112426035502958},
#  'ID': {'f1': 0.9252336448598132,
#   'prec': 0.9406175771971497,
#   'rec': 0.9103448275862069},
#  'LOCATION': {'f1': 0.8941176470588236,
#   'prec': 0.9047619047619048,
#   'rec': 0.8837209302325582},
#  'PATIENT': {'f1': 0.9639639639639639, 'prec': 1.0, 'rec': 0.9304347826086956},
#  'PHONE': {'f1': 1.0, 'prec': 1.0, 'rec': 1.0}}

# %% [markdown]
# # AWS Medical Comprehend

# %%
import json
with open('aws_res.json', 'r') as f:
  aws_res = json.load(f)

# %%
aws_tuples = []
for doc in aws_res:
  tuples = []
  for res in doc['Entities']:
    tuples.append(Annotation(res['BeginOffset'], res['EndOffset'], res['Type'], res['Text']))
  aws_tuples.append(tuples)

# %%
aws_tuples[0]
# Out:
# [Annotation(start=1, end=10, label='ID', text='929334185'),
#  Annotation(start=15, end=22, label='ID', text='8151167'),
#  Annotation(start=23, end=28, label='ID', text='53653'),
#  Annotation(start=34, end=40, label='ID', text='539442'),
#  Annotation(start=41, end=50, label='DATE', text='5/13/1994'),
#  Annotation(start=142, end=149, label='DATE', text='5/13/94'),
#  Annotation(start=167, end=174, label='DATE', text='5/16/94'),
#  Annotation(start=360, end=362, label='AGE', text='69'),
#  Annotation(start=406, end=418, label='DATE', text='July of 1993'),
#  Annotation(start=738, end=752, label='ADDRESS', text='emergency room'),
#  Annotation(start=1339, end=1354, label='DATE', text='November , 1994'),
#  Annotation(start=1439, end=1457, label='DATE', text='September 1 , 1993'),
#  Annotation(start=1571, end=1588, label='DATE', text='November 5 , 1994'),
#  Annotation(start=1621, end=1637, label='DATE', text='September , 1993'),
#  Annotation(start=2919, end=2921, label='AGE', text='69'),
#  Annotation(start=2998, end=3003, label='DATE', text='05/93'),
#  Annotation(start=3206, end=3220, label='ADDRESS', text='operating room'),
#  Annotation(start=3224, end=3237, label='DATE', text='May 14 , 1994'),
#  Annotation(start=3696, end=3702, label='DATE', text='May 15'),
#  Annotation(start=3799, end=3817, label='ADDRESS', text='Radiation Oncology'),
#  Annotation(start=3863, end=3868, label='NAME', text='Douet'),
#  Annotation(start=3976, end=3981, label='NAME', text='Wires'),
#  Annotation(start=4019, end=4024, label='NAME', text='Wires'),
#  Annotation(start=4048, end=4056, label='PHONE_OR_FAX', text='526-6508'),
#  Annotation(start=4062, end=4068, label='DATE', text='May 16'),
#  Annotation(start=4265, end=4270, label='NAME', text='Wires'),
#  Annotation(start=4279, end=4293, label='NAME', text='Caslighlourdes'),
#  Annotation(start=4296, end=4305, label='NAME', text='STIE FYFE'),
#  Annotation(start=4329, end=4351, label='NAME', text='RIEMIND CASLIGHLOURDES'),
#  Annotation(start=4379, end=4386, label='DATE', text='5/16/94'),
#  Annotation(start=4392, end=4400, label='DATE', text='05/17/94')]

# %%
aws_dict = get_all_doc_metrics(ann_tuples, aws_tuples)
aws_dict
# Out:
# {'AGE': {'fn': 6, 'fp': 1, 'tp': 88},
#  'DATE': {'fn': 10, 'fp': 0, 'tp': 943},
#  'DOCTOR': {'fn': 33, 'fp': 0, 'tp': 369},
#  'HOSPITAL': {'fn': 34, 'fp': 3, 'tp': 145},
#  'ID': {'fn': 29, 'fp': 34, 'tp': 402},
#  'LOCATION': {'fn': 9, 'fp': 6, 'tp': 32},
#  'PATIENT': {'fn': 11, 'fp': 0, 'tp': 104},
#  'PHONE': {'fn': 0, 'fp': 0, 'tp': 15}}

# %%
get_formula_metrics(aws_dict)
# Out:
# {'AGE': {'f1': 0.9617486338797814,
#   'prec': 0.9887640449438202,
#   'rec': 0.9361702127659575},
#  'DATE': {'f1': 0.9947257383966245, 'prec': 1.0, 'rec': 0.9895068205666316},
#  'DOCTOR': {'f1': 0.9571984435797666, 'prec': 1.0, 'rec': 0.917910447761194},
#  'HOSPITAL': {'f1': 0.8868501529051988,
#   'prec': 0.9797297297297297,
#   'rec': 0.8100558659217877},
#  'ID': {'f1': 0.9273356401384083,
#   'prec': 0.9220183486238532,
#   'rec': 0.9327146171693735},
#  'LOCATION': {'f1': 0.810126582278481,
#   'prec': 0.8421052631578947,
#   'rec': 0.7804878048780488},
#  'PATIENT': {'f1': 0.9497716894977168, 'prec': 1.0, 'rec': 0.9043478260869565},
#  'PHONE': {'f1': 1.0, 'prec': 1.0, 'rec': 1.0}}

# %% [markdown]
# # Azure Cognitive Services

# %% [markdown]
# ## Deid Model Results

# %%
import requests
from bs4 import BeautifulSoup

# %%
# Get Azure labels for ID
lang_page = requests.get('https://docs.microsoft.com/en-us/azure/cognitive-services/language-service/personally-identifiable-information/concepts/entity-categories')
soup = BeautifulSoup(lang_page.content, 'html.parser')
codes = soup.find_all('code')
orgs = [l.get_text() for l in codes]
id_cat = [i for i in orgs if ('ID' in i) or ('Number' in i)]
id_cat = id_cat[2:] #excluding phone numbers
id_cat = list(set(id_cat))

# %%
id_cats = id_cat + ['ID', 'MEDICALRECORD', 'IDNUM']

label_maps = {
    'DATE': ['DATE', 'DateTime', 'DATE_OF_BIRTH'],
    'ID': id_cats,
    'AGE': ['AGE', 'Quantity'],
    'PHONE': ['PHONE', 'PHONE_OR_FAX', 'PhoneNumber', 'PHONE_NUMBER', 'CONTACT'],
    'DOCTOR': ['DOCTOR', 'NAME', 'Person', 'PERSON_NAME', 'PATIENT', 'USERNAME'],
    'PATIENT': ['PATIENT', 'NAME', 'Person', 'PERSON_NAME', 'DOCTOR', 'USERNAME'],
    'HOSPITAL': ['HOSPITAL', 'ADDRESS', 'Organization', 'Address', 'ORGANIZATION', 'LOCATION'],
    'LOCATION': ['LOCATION', 'ADDRESS', 'Address', 'Location', 'Organization', 'STATE', 'COUNTRY', 'STREET', 'CITY', 'HOSPITAL']}

# %%
import json
with open('azure_res.json', 'r') as f:
  azure_res = json.load(f)

# %%
azure_tuples = []
for doc in azure_res:
  tuples = []
  for res in doc['entities']:
    tuples.append(Annotation(res['offset'], res['offset'] + res['length'], res['category'], res['entity']))
  azure_tuples.append(tuples)

# %%
azure_dict = get_all_doc_metrics(ann_tuples, azure_tuples)
azure_dict
# Out:
# {'AGE': {'fn': 2, 'fp': 11, 'tp': 82},
#  'DATE': {'fn': 180, 'fp': 0, 'tp': 773},
#  'DOCTOR': {'fn': 179, 'fp': 3, 'tp': 220},
#  'HOSPITAL': {'fn': 76, 'fp': 4, 'tp': 102},
#  'ID': {'fn': 266, 'fp': 197, 'tp': 2},
#  'LOCATION': {'fn': 45, 'fp': 1, 'tp': 1},
#  'PATIENT': {'fn': 37, 'fp': 4, 'tp': 74},
#  'PHONE': {'fn': 5, 'fp': 0, 'tp': 10}}

# %%
get_formula_metrics(azure_dict)
# Out:
# {'AGE': {'f1': 0.9265536723163842,
#   'prec': 0.8817204301075269,
#   'rec': 0.9761904761904762},
#  'DATE': {'f1': 0.895712630359212, 'prec': 1.0, 'rec': 0.8111227701993704},
#  'DOCTOR': {'f1': 0.707395498392283,
#   'prec': 0.9865470852017937,
#   'rec': 0.5513784461152882},
#  'HOSPITAL': {'f1': 0.7183098591549295,
#   'prec': 0.9622641509433962,
#   'rec': 0.5730337078651685},
#  'ID': {'f1': 0.008565310492505354,
#   'prec': 0.010050251256281407,
#   'rec': 0.007462686567164179},
#  'LOCATION': {'f1': 0.041666666666666664,
#   'prec': 0.5,
#   'rec': 0.021739130434782608},
#  'PATIENT': {'f1': 0.783068783068783,
#   'prec': 0.9487179487179487,
#   'rec': 0.6666666666666666},
#  'PHONE': {'f1': 0.8, 'prec': 1.0, 'rec': 0.6666666666666666}}

# %% [markdown]
# ## NER Model Results

# %%
# Adding LOCATION from NER
import json
with open('azure_res_location.json', 'r') as f:
  azure_res = json.load(f)

# %%
azure_tuples = []
for doc in azure_res:
  tuples = []
  for res in doc['entities']:
    tuples.append(Annotation(res['offset'], res['offset'] + res['length'], res['category'], res['entity']))
  azure_tuples.append(tuples)

# %%
azure_dict = get_all_doc_metrics(ann_tuples, azure_tuples)
azure_dict
# Out:
# {'AGE': {'fn': 2, 'fp': 93, 'tp': 0},
#  'DATE': {'fn': 157, 'fp': 796, 'tp': 0},
#  'DOCTOR': {'fn': 175, 'fp': 227, 'tp': 0},
#  'HOSPITAL': {'fn': 55, 'fp': 127, 'tp': 0},
#  'ID': {'fn': 20, 'fp': 445, 'tp': 0},
#  'LOCATION': {'fn': 11, 'fp': 0, 'tp': 36},
#  'PATIENT': {'fn': 20, 'fp': 95, 'tp': 0},
#  'PHONE': {'fn': 5, 'fp': 10, 'tp': 0}}

# %%
get_formula_metrics(azure_dict)
# Out:
# {'AGE': {'f1': 0, 'prec': 0.0, 'rec': 0.0},
#  'DATE': {'f1': 0, 'prec': 0.0, 'rec': 0.0},
#  'DOCTOR': {'f1': 0, 'prec': 0.0, 'rec': 0.0},
#  'HOSPITAL': {'f1': 0, 'prec': 0.0, 'rec': 0.0},
#  'ID': {'f1': 0, 'prec': 0.0, 'rec': 0.0},
#  'LOCATION': {'f1': 0.8674698795180723,
#   'prec': 1.0,
#   'rec': 0.7659574468085106},
#  'PATIENT': {'f1': 0, 'prec': 0.0, 'rec': 0.0},
#  'PHONE': {'f1': 0, 'prec': 0.0, 'rec': 0.0}}

# %% [markdown]
# # Google Cloud Provider (GCP)

# %% [markdown]
# ## Deid Model Results

# %%
from bs4 import BeautifulSoup
import requests

# %%
# Get Azure labels for ID
lang_page = requests.get('https://cloud.google.com/dlp/docs/infotypes-reference')
soup = BeautifulSoup(lang_page.content, 'html.parser')
codes = soup.find_all('code')
orgs = [l.get_text() for l in codes]
# id_cat = [i for i in orgs if ('ID' in i) or ('Number' in i)]
id_cat = list(set(orgs))
cleaned_list = [x for x in id_cat if (x!='IP_ADDRESS')&(x!='DOCUMENT_TYPE/FINANCE/REGULATORY')&(x!='DOCUMENT_TYPE/R&D/PATENT')&(x!='MAC_ADDRESS_LOCAL')&(x!='GCP_CREDENTIALS')&(x!='ICD9_CODE')&(x!='DOMAIN_NAME')&(x!='TIME')&(x!='CREDIT_CARD_NUMBER')&(x!='JSON_WEB_TOKEN')&(x!='DOCUMENT_TYPE/R&D/DATABASE_BACKUP')&(x!='DOMAIN_NAME')&(x!='STORAGE_SIGNED_URL')&(x!='DOCUMENT_TYPE/LEGAL/LAW')&(x!='URL')&(x!='STORAGE_SIGNED_POLICY_DOCUMENT')&(x!='WEAK_PASSWORD_HASH')&(x!='GCP_API_KEY')&(x!='DOCUMENT_TYPE/LEGAL/COURT_ORDER')&(x!='ENCRYPTION_KEY')&(x!='ENCRYPTION_KEY')&(x!='HTTP_COOKIE')&(x!='EMAIL_ADDRESS')&(x!='DOCUMENT_TYPE/HR/RESUME')&(x!='IMEI_HARDWARE_ID')&(x!='XSRF_TOKEN')&(x!='FDA_CODE')&(x!='MEDICAL_TERM')&(x!='GENDER')&(x!='AWS_CREDENTIALS')&(x!='MAC_ADDRESS')&(x!='AZURE_AUTH_TOKEN')&(x!='DOCUMENT_TYPE/R&D/SYSTEM_LOG')&(x!='DOCUMENT_TYPE/LEGAL/PLEADING')&(x!='PASSWORD')&(x!='ICD10_CODE')&(x!='AUTH_TOKEN')&(x!='BASIC_AUTH_HEADER')&(x != 'DOCUMENT_TYPE/LEGAL/BRIEF') and (x != 'IBAN_CODE') and (x != 'ETHNIC_GROUP')and (x != 'DOCUMENT_TYPE/LEGAL/BLANK_FORM')and (x != 'DOCUMENT_TYPE/R&D/SOURCE_CODE')and (x != 'DOCUMENT_TYPE/FINANCE/SEC_FILING') and (x != 'infoTypes.list')]

# %%
cleaned_list
# Out:
# ['JAPAN_PASSPORT',
#  'US_ADOPTION_TAXPAYER_IDENTIFICATION_NUMBER',
#  'INDIA_AADHAAR_INDIVIDUAL',
#  'US_TOLLFREE_PHONE_NUMBER',
#  'NORWAY_NI_NUMBER',
#  'SOUTH_AFRICA_ID_NUMBER',
#  'SWIFT_CODE',
#  'CANADA_OHIP',
#  'US_DEA_NUMBER',
#  'SWEDEN_PASSPORT',
#  'GERMANY_DRIVERS_LICENSE_NUMBER',
#  'NETHERLANDS_PASSPORT',
#  'PASSPORT',
#  'UK_PASSPORT',
#  'ICCID_NUMBER',
#  'FEMALE_NAME',
#  'VEHICLE_IDENTIFICATION_NUMBER',
#  'CHINA_PASSPORT',
#  'TURKEY_ID_NUMBER',
#  'PERSON_NAME',
#  'INDIA_PAN_INDIVIDUAL',
#  'PHONE_NUMBER',
#  'SPAIN_NIE_NUMBER',
#  'KOREA_RRN',
#  'CANADA_QUEBEC_HIN',
#  'MEXICO_PASSPORT',
#  'US_HEALTHCARE_NPI',
#  'CANADA_BANK_ACCOUNT',
#  'PERU_DNI_NUMBER',
#  'UK_NATIONAL_INSURANCE_NUMBER',
#  'PORTUGAL_CDC_NUMBER',
#  'AUSTRALIA_MEDICARE_NUMBER',
#  'PARAGUAY_CIC_NUMBER',
#  'BRAZIL_CPF_NUMBER',
#  'SPAIN_SOCIAL_SECURITY_NUMBER',
#  'SPAIN_DRIVERS_LICENSE_NUMBER',
#  'BELGIUM_NATIONAL_ID_CARD_NUMBER',
#  'LAST_NAME',
#  'DENMARK_CPR_NUMBER',
#  'US_DRIVERS_LICENSE_NUMBER',
#  'SWEDEN_NATIONAL_ID_NUMBER',
#  'KOREA_PASSPORT',
#  'US_BANK_ROUTING_MICR',
#  'POLAND_PESEL_NUMBER',
#  'CANADA_BC_PHN',
#  'GERMANY_TAXPAYER_IDENTIFICATION_NUMBER',
#  'STREET_ADDRESS',
#  'ORGANIZATION_NAME',
#  'ADVERTISING_ID',
#  'JAPAN_INDIVIDUAL_NUMBER',
#  'CHINA_RESIDENT_ID_NUMBER',
#  'FIRST_NAME',
#  'AUSTRALIA_PASSPORT',
#  'INDONESIA_NIK_NUMBER',
#  'CHILE_CDI_NUMBER',
#  'ISRAEL_IDENTITY_CARD_NUMBER',
#  'CANADA_PASSPORT',
#  'GENERIC_ID',
#  'US_STATE',
#  'POLAND_NATIONAL_ID_NUMBER',
#  'SINGAPORE_PASSPORT',
#  'FRANCE_TAX_IDENTIFICATION_NUMBER',
#  'FRANCE_NIR',
#  'AUSTRALIA_TAX_FILE_NUMBER',
#  'SPAIN_DNI_NUMBER',
#  'UK_DRIVERS_LICENSE_NUMBER',
#  'GERMANY_SCHUFA_ID',
#  'SINGAPORE_NATIONAL_REGISTRATION_ID_NUMBER',
#  'US_PASSPORT',
#  'CREDIT_CARD_TRACK_NUMBER',
#  'JAPAN_BANK_ACCOUNT',
#  'CANADA_DRIVERS_LICENSE_NUMBER',
#  'VENEZUELA_CDI_NUMBER',
#  'IRELAND_EIRCODE',
#  'POLAND_PASSPORT',
#  'AUSTRALIA_DRIVERS_LICENSE_NUMBER',
#  'SPAIN_CIF_NUMBER',
#  'ARGENTINA_DNI_NUMBER',
#  'US_SOCIAL_SECURITY_NUMBER',
#  'INDIA_GST_INDIVIDUAL',
#  'US_EMPLOYER_IDENTIFICATION_NUMBER',
#  'TAIWAN_PASSPORT',
#  'CANADA_SOCIAL_INSURANCE_NUMBER',
#  'HONG_KONG_ID_NUMBER',
#  'IRELAND_PASSPORT',
#  'SPAIN_PASSPORT',
#  'AGE',
#  'LOCATION',
#  'US_VEHICLE_IDENTIFICATION_NUMBER',
#  'UK_NATIONAL_HEALTH_SERVICE_NUMBER',
#  'FRANCE_CNI',
#  'AMERICAN_BANKERS_CUSIP_ID',
#  'SPAIN_NIF_NUMBER',
#  'IRELAND_PPSN',
#  'URUGUAY_CDI_NUMBER',
#  'GERMANY_IDENTITY_CARD_NUMBER',
#  'SCOTLAND_COMMUNITY_HEALTH_INDEX_NUMBER',
#  'ITALY_FISCAL_CODE',
#  'MEXICO_CURP_NUMBER',
#  'GERMANY_PASSPORT',
#  'JAPAN_DRIVERS_LICENSE_NUMBER',
#  'THAILAND_NATIONAL_ID_NUMBER',
#  'NETHERLANDS_BSN_NUMBER',
#  'UK_TAXPAYER_REFERENCE',
#  'COLOMBIA_CDC_NUMBER',
#  'IRELAND_DRIVING_LICENSE_NUMBER',
#  'US_INDIVIDUAL_TAXPAYER_IDENTIFICATION_NUMBER',
#  'MALE_NAME',
#  'US_PREPARER_TAXPAYER_IDENTIFICATION_NUMBER',
#  'FINLAND_NATIONAL_ID_NUMBER',
#  'IMSI_ID',
#  'DATE',
#  'DATE_OF_BIRTH',
#  'FRANCE_PASSPORT']

# %%
phone_cats = [i for i in cleaned_list if 'PHONE' in i]
name_cats = ['PERSON_NAME', 'FEMALE_NAME', 'MALE_NAME', 'FIRST_NAME', 'LAST_NAME']
age_cats = ['AGE']
date_cats = ['DATE_OF_BIRTH', 'DATE']
location_cats = ['STREET_ADDRESS', 'LOCATION', 'ORGANIZATION_NAME', 'ORGANIZATION']
id_cats = [i for i in cleaned_list if (i not in phone_cats)&(i not in name_cats)&(i not in location_cats)&(i not in date_cats)&(i not in age_cats)]

label_maps = {
    'DATE': date_cats,
    'ID': id_cats,
    'AGE': age_cats,
    'PHONE': phone_cats,
    'DOCTOR': name_cats,
    'PATIENT': name_cats,
    'HOSPITAL': location_cats,
    'LOCATION': location_cats}

# %%
import json
with open('gcp_res.json', 'r') as f:
  gcp_res = json.load(f)

# %%
gcp_tuples = []
for doc in gcp_res:
  tuples = []
  for res in doc['entities']:
    tuples.append(Annotation(res['start'], res['end'], res['entity'], res['quote']))
  gcp_tuples.append(tuples)

# %%
gcp_dict = get_all_doc_metrics(ann_tuples, gcp_tuples)
gcp_dict
# Out:
# {'AGE': {'fn': 6, 'fp': 10, 'tp': 79},
#  'DATE': {'fn': 69, 'fp': 0, 'tp': 884},
#  'DOCTOR': {'fn': 337, 'fp': 3, 'tp': 62},
#  'HOSPITAL': {'fn': 164, 'fp': 6, 'tp': 12},
#  'ID': {'fn': 433, 'fp': 22, 'tp': 10},
#  'LOCATION': {'fn': 29, 'fp': 17, 'tp': 1},
#  'PATIENT': {'fn': 104, 'fp': 7, 'tp': 4},
#  'PHONE': {'fn': 1, 'fp': 0, 'tp': 14}}

# %%
get_formula_metrics(gcp_dict)
# Out:
# {'AGE': {'f1': 0.9080459770114941,
#   'prec': 0.8876404494382022,
#   'rec': 0.9294117647058824},
#  'DATE': {'f1': 0.9624387588459444, 'prec': 1.0, 'rec': 0.9275970619097587},
#  'DOCTOR': {'f1': 0.2672413793103448,
#   'prec': 0.9538461538461539,
#   'rec': 0.15538847117794485},
#  'HOSPITAL': {'f1': 0.12371134020618554,
#   'prec': 0.6666666666666666,
#   'rec': 0.06818181818181818},
#  'ID': {'f1': 0.042105263157894736,
#   'prec': 0.3125,
#   'rec': 0.022573363431151242},
#  'LOCATION': {'f1': 0.04166666666666667,
#   'prec': 0.05555555555555555,
#   'rec': 0.03333333333333333},
#  'PATIENT': {'f1': 0.06722689075630252,
#   'prec': 0.36363636363636365,
#   'rec': 0.037037037037037035},
#  'PHONE': {'f1': 0.9655172413793104, 'prec': 1.0, 'rec': 0.9333333333333333}}

# %% [markdown]
# ## NER Model Results

# %%
label_maps = {
    'DATE': ['NULL'],
    'ID': ['NULL'],
    'AGE': ['NULL'],
    'PHONE': ['NULL'],
    'DOCTOR': ['PERSON'],
    'PATIENT': ['PERSON'],
    'HOSPITAL': ['LOCATION', 'ORGANIZATION'],
    'LOCATION': ['ADDRESS', 'LOCATION', 'ORGANIZATION']}

# %%
import json
with open('gcp_res_ner.json', 'r') as f:
  gcp_res_ner = json.load(f)

# %%
gcp_tuples = []
for doc in gcp_res_ner:
  tuples = []
  for res in doc['entities']:
    tuples.append(Annotation(res['start'], res['end'], res['entity'], res['quote']))
  gcp_tuples.append(tuples)

# %%
gcp_dict = get_all_doc_metrics(ann_tuples, gcp_tuples)
gcp_dict
# Out:
# {'AGE': {'fn': 0, 'fp': 95, 'tp': 0},
#  'DATE': {'fn': 6, 'fp': 947, 'tp': 0},
#  'DOCTOR': {'fn': 58, 'fp': 171, 'tp': 173},
#  'HOSPITAL': {'fn': 21, 'fp': 59, 'tp': 102},
#  'ID': {'fn': 11, 'fp': 454, 'tp': 0},
#  'LOCATION': {'fn': 3, 'fp': 17, 'tp': 27},
#  'PATIENT': {'fn': 49, 'fp': 30, 'tp': 36},
#  'PHONE': {'fn': 0, 'fp': 15, 'tp': 0}}

# %%
get_formula_metrics(gcp_dict)
# Out:
# {'AGE': {'f1': 0, 'prec': 0.0, 'rec': 0},
#  'DATE': {'f1': 0, 'prec': 0.0, 'rec': 0.0},
#  'DOCTOR': {'f1': 0.6017391304347826,
#   'prec': 0.502906976744186,
#   'rec': 0.7489177489177489},
#  'HOSPITAL': {'f1': 0.7183098591549295,
#   'prec': 0.6335403726708074,
#   'rec': 0.8292682926829268},
#  'ID': {'f1': 0, 'prec': 0.0, 'rec': 0.0},
#  'LOCATION': {'f1': 0.7297297297297297,
#   'prec': 0.6136363636363636,
#   'rec': 0.9},
#  'PATIENT': {'f1': 0.47682119205298007,
#   'prec': 0.5454545454545454,
#   'rec': 0.4235294117647059},
#  'PHONE': {'f1': 0, 'prec': 0.0, 'rec': 0}}

# %% [markdown]
# # THAT'S A WRAP!
