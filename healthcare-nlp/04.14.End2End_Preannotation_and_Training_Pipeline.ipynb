# %% [markdown]
# ![JohnSnowLabs](https://sparknlp.org/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/spark-nlp-workshop/blob/master/healthcare-nlp/04.14.End2End_Preannotation_and_Training_Pipeline.ipynb)

# %% [markdown]
# # **End2End Preannotation and Training Pipeline**

# %%
# Install the johnsnowlabs library to access Spark-OCR and Spark-NLP for Healthcare, Finance, and Legal.
! pip install -q johnsnowlabs

# %%
from google.colab import files
print('Please Upload your John Snow Labs License using the button below')
license_keys = files.upload()

# %%
from johnsnowlabs import nlp, medical

# After uploading your license run this to install all licensed Python Wheels and pre-download Jars the Spark Session JVM
nlp.settings.enforce_versions=True
nlp.install(refresh_install=True)

# %%
import os
import json
import numpy as np
import pandas as pd

spark = nlp.start()
# Out:
# 👌 Detected license file /content/6.1.1.spark_nlp_for_healthcare.json
# 👌 Launched cpu optimized session with with: 🚀Spark-NLP==6.1.3, 💊Spark-Healthcare==6.1.1, running on ⚡ PySpark==3.4.0

# %% [markdown]
# ## Loading the Pretrained Pipeline
#
# Spark NLP's pretrained pipeline, `clinical_deidentification_docwise_benchmark`, is loaded. This pipeline is designed to mask and obfuscate sensitive information in medical texts, such as names, ID numbers, contact information, locations, ages, and dates. The existing stages of the pipeline are examined to understand its structure.

# %%
deid_pipeline = nlp.PretrainedPipeline("clinical_deidentification_docwise_benchmark", "en", "clinical/models")
# Out:
# clinical_deidentification_docwise_benchmark download started this may take some time.
# Approx size to download 2.3 GB
# [OK!]

# %%
deid_pipeline.model.stages
# Out:
# [DocumentAssembler_ae0f203deedd,
#  InternalDocumentSplitter_cc36578ceda6,
#  REGEX_TOKENIZER_2e85686aea12,
#  WORD_EMBEDDINGS_MODEL_9004b1d00302,
#  MedicalNerModel_1a8637089929,
#  NER_CONVERTER_1aef7e9d2de5,
#  MedicalNerModel_d92d47622e85,
#  MedicalNerModel_32184c1db80b,
#  MedicalNerModel_ada39ac0d359,
#  NER_CONVERTER_a99db4e6a79d,
#  NER_CONVERTER_4a9436714344,
#  NER_CONVERTER_ea6433988e18,
#  PretrainedZeroShotNER_5f30ab9002f1,
#  NER_CONVERTER_c97040caf7b3,
#  MedicalNerModel_b8b167ec3114,
#  NER_CONVERTER_06db473f3215,
#  ContextualEntityRuler_11ff6711ef6b,
#  ChunkMergeModel_95d6827691bb,
#  CONTEXTUAL-PARSER_bf2a6abaf5fa,
#  CONTEXTUAL-PARSER_ff6bad379d91,
#  CONTEXTUAL-PARSER_89341cae7221,
#  CONTEXTUAL-PARSER_c6b9eded8d31,
#  CONTEXTUAL-PARSER_9480c24bd9f8,
#  CONTEXTUAL-PARSER_3886bce391c8,
#  CONTEXTUAL-PARSER_0bb3fb75cd01,
#  ENTITY_EXTRACTOR_6792f2f6e85a,
#  ENTITY_EXTRACTOR_74ace4be4f73,
#  CONTEXTUAL-PARSER_dfb32adc7555,
#  REGEX_MATCHER_5003669d6422,
#  CONTEXTUAL-PARSER_746a25662aa6,
#  CONTEXTUAL-PARSER_079220479a3d,
#  CONTEXTUAL-PARSER_f8b8f9aafb9f,
#  CONTEXTUAL-PARSER_7f824493eafc,
#  REGEX_MATCHER_26934077fe57,
#  REGEX_MATCHER_5fe3de8b5a4e,
#  MERGE_ddff59e8b14a,
#  ChunkMergeModel_50feb5f97568,
#  ContextualEntityRuler_08eeaa89c938,
#  ChunkMergeModel_5a3f1e608447,
#  LightDeIdentification_dd156106d887,
#  LightDeIdentification_acfc9a325ba4]

# %% [markdown]
# ### Sample Text

# %%
text = """
Name: John Lee
Medical Record Number (MRN): 7789201
Date of Birth / Age / Sex: 1973 / 52 / Male
Accession #: GH-556672
Social Security #: XXX-XX-1234
Address: 123 Main Street, FALL RIVER, NIAGARA FALLS, NY 14304
Specimen #: RD23-4897
Material Received: Gastric, Ileum, and Random Colon Biopsies
Material Details: 6 slides labeled 032-1902
Date Collected: 2025-05-10
Date Received: 2025-05-10
Requesting Physician: Dr. Jameson
Referring Facility: General Hospital, New York City, NY
Clinical History: None Given.
Clinical Note: Peripheral sequestration, i.e., splenomegaly or hepatomegaly, should be excluded to be sure if peripheral sequestration is not present.
CPT Code(s): 88305
Gastric, ileum, and random colon, biopsies:
No evidence of dysplasia.
The following special studies were performed at Barstow Heights Christus Southeast, NY – St Elizabeth; New York City.
Chromosome Analysis (Cytogenetics): (Addendum report to follow.)
Leukemic Immunophenotyping (Flow Cytometry):
Date Reported: 2025-05-12, 16:30
Electronically Signed Out By:
Dr. Smith
Dr. Carter, CT(ASCP)
"""

# %% [markdown]
# ## Extending the Pipeline with New Stages
#
# New and customized stages are added to enhance the capabilities of the existing pipeline.

# %%
document_assembler = nlp.DocumentAssembler()\
      .setInputCol("text")\
      .setOutputCol("document")

splitter = (
            medical.InternalDocumentSplitter()
            .setInputCols("document")
            .setOutputCol("splitter")
            .setSplitMode("recursive")
            .setSplitPatterns(["\s+"])  # Token base
            .setPatternsAreRegex(True)
            .setChunkSize(512)    # 512 Char Lenght
            .setChunkOverlap(50)
            .setEnableSentenceIncrement(True)  # Like sentenceDetector
)

tokenizer = (
    nlp.Tokenizer()
    .setInputCols("splitter")
    .setOutputCol("token")
)

# %% [markdown]
# ### Create a Custom `CPT Code` Parser
#
# Using `ContextualParserApproach`, a new parser is created to detect CPT (Current Procedural Terminology) codes within the text based on regex rules. This allows the pipeline to recognize a custom entity type not found in the standard de-identification pipeline.

# %%
cpt_rule = {
    "entity": "CPT_CODE",
    "ruleScope": "sentence",
    "regex": r"(?:CPT(?: Code\(s\)?|#|:)?\s*:?[\s#]*)?(\b88[0-9]{3}\b)",
    "matchScope": "token"
}

with open('cpt.json', 'w') as f:
    json.dump(cpt_rule, f)

cpt_parser = medical.ContextualParserApproach() \
    .setInputCols(["splitter", "token"]) \
    .setOutputCol("entity_cpt") \
    .setJsonPath("cpt.json") \
    .setCaseSensitive(False) \
    .setPrefixAndSuffixMatch(False)

cpt_parser_pipeline = nlp.Pipeline(stages=[
    document_assembler,
    splitter,
    tokenizer,
    cpt_parser
  ])

empty_data = spark.createDataFrame([[""]]).toDF("text")

cpt_parser_model = cpt_parser_pipeline.fit(empty_data)

# %%
cpt_parser_model.stages[-1].write().overwrite().save("./parsers/cpt_parser")

cpt_parser = medical.ContextualParserModel.load("parsers/cpt_parser") \
    .setInputCols(["splitter", "token"])\
    .setOutputCol("entity_cpt")

# %%
annotations = nlp.LightPipeline(cpt_parser_model).annotate(text)

annotations["entity_cpt"]
# Out:
# ['88305']

# %% [markdown]
# ###  Create a Custom `Specimen ID` Parser
#
# Similarly, another parser is created with ContextualParserApproach to extract specimen IDs from medical texts

# %%
with open('specimen.json', 'w') as f:
    json.dump({
        "entity": "IDNUM",
        "ruleScope": "sentence",
        "regex": "(?:Specimen(?:\s*(?:ID|Number|Code|#|No\.?)?:?)?\s*)?#?[A-Z]{1,5}[0-9]{2,4}-?[0-9]{3,6}",
        "contextLength": 25,
        "matchScope": "token"
    }, f)

specimen_parser = medical.ContextualParserApproach() \
    .setInputCols(["splitter", "token"]) \
    .setOutputCol("entity_specimen") \
    .setJsonPath("specimen.json") \
    .setCaseSensitive(False) \
    .setPrefixAndSuffixMatch(False)

specimen_parser_pipeline = nlp.Pipeline(stages=[
    document_assembler,
    splitter,
    tokenizer,
    specimen_parser
  ])

empty_data = spark.createDataFrame([[""]]).toDF("text")

specimen_parser_model = specimen_parser_pipeline.fit(empty_data)

# %%
specimen_parser_model.stages[-1].write().overwrite().save("./parsers/specimen_parser")

specimen_parser = medical.ContextualParserModel.load("./parsers/specimen_parser") \
    .setInputCols(["splitter", "token"])\
    .setOutputCol("entity_specimen")

# %%
annotations = nlp.LightPipeline(specimen_parser_model).annotate(text)

annotations["entity_specimen"]
# Out:
# ['RD23-4897']

# %% [markdown]
# ### IOBTagger
#
# The `IOBTagger` is added to tag the entities recognized by the Named Entity Recognition (NER) model in the IOB (Inside, Outside, Beginning) format. This format provides a standard data structure required for training the NER model.

# %%
iobTagger = medical.IOBTagger()\
  .setInputCols(["token", "ner_chunk"])\
  .setOutputCol("ner_label")

# %% [markdown]
# ### Update the Chunk Merging Strategy
#
# The inputs of the ChunkMergeModel, which is responsible for merging entities from different NER models, are updated to include the entities generated by the newly created cpt_parser and specimen_parser. This ensures that all entities found by both the pretrained models and our custom parsers are consolidated.

# %%
merger_input_cols = deid_pipeline.model.stages[35].getInputCols()
merger_input_cols
# Out:
# ['entity_icd10',
#  'entity_email',
#  'entity_ip_address',
#  'entity_age',
#  'entity_medicalrecord',
#  'entity_ssn',
#  'entity_account',
#  'entity_vin',
#  'entity_date',
#  'entity_phone',
#  'entity_phone2',
#  'entity_country',
#  'entity_state',
#  'entity_zip',
#  'entity_plate',
#  'entity_dln',
#  'entity_license']

# %%
merger_input_cols = deid_pipeline.model.stages[35].getInputCols()

chunk_merge_rulebase = deid_pipeline.model.stages[35]\
      .setInputCols(["entity_cpt", "entity_specimen"] + merger_input_cols)

# %% [markdown]
# ### Update the De-identification Blacklist

# %%
deid_pipeline.model.stages[38]
# Out:
# ChunkMergeModel_5a3f1e608447

# %%
deid_pipeline.model.stages[38] = deid_pipeline.model.stages[38]\
                                      .setBlackList(['CPT_CODE'])

# %% [markdown]
# ### Updated Stages

# %%
deid_pipeline.model.stages = (
    deid_pipeline.model.stages[:35]
    + [cpt_parser, specimen_parser, chunk_merge_rulebase]
    + deid_pipeline.model.stages[36:]
    + [iobTagger]
)

# %%
deid_pipeline.model.stages
# Out:
# [DocumentAssembler_ae0f203deedd,
#  InternalDocumentSplitter_cc36578ceda6,
#  REGEX_TOKENIZER_2e85686aea12,
#  WORD_EMBEDDINGS_MODEL_9004b1d00302,
#  MedicalNerModel_1a8637089929,
#  NER_CONVERTER_1aef7e9d2de5,
#  MedicalNerModel_d92d47622e85,
#  MedicalNerModel_32184c1db80b,
#  MedicalNerModel_ada39ac0d359,
#  NER_CONVERTER_a99db4e6a79d,
#  NER_CONVERTER_4a9436714344,
#  NER_CONVERTER_ea6433988e18,
#  PretrainedZeroShotNER_5f30ab9002f1,
#  NER_CONVERTER_c97040caf7b3,
#  MedicalNerModel_b8b167ec3114,
#  NER_CONVERTER_06db473f3215,
#  ContextualEntityRuler_11ff6711ef6b,
#  ChunkMergeModel_95d6827691bb,
#  CONTEXTUAL-PARSER_bf2a6abaf5fa,
#  CONTEXTUAL-PARSER_ff6bad379d91,
#  CONTEXTUAL-PARSER_89341cae7221,
#  CONTEXTUAL-PARSER_c6b9eded8d31,
#  CONTEXTUAL-PARSER_9480c24bd9f8,
#  CONTEXTUAL-PARSER_3886bce391c8,
#  CONTEXTUAL-PARSER_0bb3fb75cd01,
#  ENTITY_EXTRACTOR_6792f2f6e85a,
#  ENTITY_EXTRACTOR_74ace4be4f73,
#  CONTEXTUAL-PARSER_dfb32adc7555,
#  REGEX_MATCHER_5003669d6422,
#  CONTEXTUAL-PARSER_746a25662aa6,
#  CONTEXTUAL-PARSER_079220479a3d,
#  CONTEXTUAL-PARSER_f8b8f9aafb9f,
#  CONTEXTUAL-PARSER_7f824493eafc,
#  REGEX_MATCHER_26934077fe57,
#  REGEX_MATCHER_5fe3de8b5a4e,
#  CONTEXTUAL-PARSER_9f6e020bef49,
#  CONTEXTUAL-PARSER_f1b97eba775b,
#  MERGE_ddff59e8b14a,
#  ChunkMergeModel_50feb5f97568,
#  ContextualEntityRuler_08eeaa89c938,
#  ChunkMergeModel_5a3f1e608447,
#  LightDeIdentification_dd156106d887,
#  LightDeIdentification_acfc9a325ba4,
#  IOBTagger_e79d09a5ca5d]

# %% [markdown]
# ## Save and Test the Modified Pipeline

# %%
empty_result = deid_pipeline.transform(spark.createDataFrame([[""]]).toDF("text"))

deid_pipeline.model.write().overwrite().save("modified_pipeline")

# %%
# We are loading the pretrained pipeline using the `from_disk` method.

modified_pipeline = nlp.PretrainedPipeline.from_disk('modified_pipeline')

# %% [markdown]
# ### Sample Result

# %%
samples_df = spark.createDataFrame([[text]]).toDF("text")

result = modified_pipeline.transform(samples_df).cache()

# %%
from pyspark.sql import functions as F

result.select(F.explode(F.arrays_zip(result.ner_chunk.result,
                                     result.ner_chunk.begin,
                                     result.ner_chunk.end,
                                     result.ner_chunk.metadata)).alias("cols")) \
      .select(F.expr("cols['0']").alias("chunk"),
              F.expr("cols['1']").alias("begin"),
              F.expr("cols['2']").alias("end"),
              F.expr("cols['3']['entity']").alias("ner_label"),
              F.expr("cols['3']['confidence']").alias("confidence")).show(50,truncate=False)
# Out:
# +----------------------------------+-----+----+---------+----------+
# |chunk                             |begin|end |ner_label|confidence|
# +----------------------------------+-----+----+---------+----------+
# |John Lee                          |7    |14  |NAME     |0.9999188 |
# |7789201                           |45   |51  |IDNUM    |0.71      |
# |1973                              |80   |83  |DATE     |0.99705976|
# |52                                |87   |88  |AGE      |0.99993765|
# |GH-556672                         |110  |118 |IDNUM    |0.86922663|
# |XXX-XX-1234                       |139  |149 |IDNUM    |0.85107106|
# |123 Main Street                   |160  |174 |LOCATION |0.9999253 |
# |FALL RIVER                        |177  |186 |LOCATION |0.9986915 |
# |NIAGARA FALLS                     |189  |201 |LOCATION |0.9978828 |
# |NY                                |204  |205 |LOCATION |0.9999924 |
# |14304                             |207  |211 |LOCATION |0.73      |
# |RD23-4897                         |225  |233 |IDNUM    |0.50      |
# |032-1902                          |331  |338 |IDNUM    |0.87777317|
# |2025-05-10                        |356  |365 |DATE     |null      |
# |2025-05-10                        |382  |391 |DATE     |null      |
# |Jameson                           |419  |425 |NAME     |0.9986112 |
# |General Hospital                  |447  |462 |LOCATION |0.9987417 |
# |New York                          |465  |472 |LOCATION |null      |
# |NY                                |480  |481 |LOCATION |0.99999106|
# |Barstow Heights Christus Southeast|801  |834 |LOCATION |0.9990096 |
# |NY                                |837  |838 |LOCATION |0.99993145|
# |St Elizabeth                      |842  |853 |LOCATION |0.9997955 |
# |New York                          |856  |863 |LOCATION |null      |
# |2025-05-12                        |996  |1005|DATE     |null      |
# |Smith                             |1048 |1052|NAME     |0.9999714 |
# |Carter                            |1058 |1063|NAME     |0.9998995 |
# +----------------------------------+-----+----+---------+----------+

# %%
pd.set_option("display.max_colwidth", 1000)

result_df = result.selectExpr("text",
                              "mask_entity.result as masked_result",
                              "obfuscated.result as obfuscated_result").toPandas()
result_df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       text  \
# 0  \nName: John Lee\nMedical Record Number (MRN): 7789201\nDate of Birth / Age / Sex: 1973 / 52 / Male\nAccession #: GH-556672\nSocial Security #: XXX-XX-1234\nAddress: 123 Main Street, FALL RIVER, NIAGARA FALLS, NY 14304\nSpecimen #: RD23-4897\nMaterial Received: Gastric, Ileum, and Random Colon Biopsies\nMaterial Details: 6 slides labeled 032-1902\nDate Collected: 2025-05-10\nDate Received: 2025-05-10\nRequesting Physician: Dr. Jameson\nReferring Facility: General Hospital, New York City, NY\nClinical History: None Given.\nClinical Note: Peripheral sequestration, i.e., splenomegaly or hepatomegaly, should be excluded to be sure if peripheral sequestration is not present.\nCPT Code(s): 88305\nGastric, ileum, and random colon, biopsies:\nNo evidence of dysplasia.\nThe following special studies were performed at Barstow Heights Christus Southeast, NY – St Elizabeth; New York City.\nChromosome Analysis (Cytogenetics): (Addendum report to follow.)\nLeukemic Immunophenotyping (Flow Cytome...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              masked_result  \
# 0  [\nName: <NAME>\nMedical Record Number (MRN): <IDNUM>\nDate of Birth / Age / Sex: <DATE> / <AGE> / Male\nAccession #: <IDNUM>\nSocial Security #: <IDNUM>\nAddress: <LOCATION>, <LOCATION>, <LOCATION>, <LOCATION> <LOCATION>\nSpecimen #: <IDNUM>\nMaterial Received: Gastric, Ileum, and Random Colon Biopsies\nMaterial Details: 6 slides labeled <IDNUM>\nDate Collected: <DATE>\nDate Received: <DATE>\nRequesting Physician: Dr. <NAME>\nReferring Facility: <LOCATION>, <LOCATION> City, <LOCATION>\nClinical History: None Given.\nClinical Note: Peripheral sequestration, i.e., splenomegaly or hepatomegaly, should be excluded to be sure if peripheral sequestration is not present.\nCPT Code(s): 88305\nGastric, ileum, and random colon, biopsies:\nNo evidence of dysplasia.\nThe following special studies were performed at <LOCATION>, <LOCATION> – <LOCATION>; <LOCATION> City.\nChromosome Analysis (Cytogenetics): (Addendum report to follow.)\nLeukemic Immunophenotyping (Flow Cytometry):\nDate Reported:...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          obfuscated_result
# 0  [\nName: Gillie Allan\nMedical Record Number (MRN): 0074518\nDate of Birth / Age / Sex: 1974 / 44 / Male\nAccession #: PU-663305\nSocial Security #: WWW-WW-8529\nAddress: 3255 Independence Street, 302 W MCNEESE ST, 4101 NW 89TH BLVD, 16100 SOUTH FREEWAY 59 KOCH AVE\nSpecimen #: SA52-9740\nMaterial Received: Gastric, Ileum, and Random Colon Biopsies\nMaterial Details: 6 slides labeled 125-8415\nDate Collected: 2025-06-27\nDate Received: 2025-06-27\nRequesting Physician: Dr. Marchelle\nReferring Facility: 310 Ellis Street, 2000 Boise Ave City, 16100 SOUTH FREEWAY\nClinical History: None Given.\nClinical Note: Peripheral sequestration, i.e., splenomegaly or hepatomegaly, should be excluded to be sure if peripheral sequestration is not present.\nCPT Code(s): 88305\nGastric, ileum, and random colon, biopsies:\nNo evidence of dysplasia.\nThe following special studies were performed at 103 North Street, 16100 SOUTH FREEWAY – 969 Lakeland Drive; 2000 Boise Ave City.\nChromosome Analysis (C...

# %% [markdown]
# ##  Prepare Data for Custom NER Model Training

# %%
# !wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/refs/heads/master/data/ner/eng.train -O eng.train

data_conll = nlp.CoNLL(includeDocId=True,explodeSentences=True).readDataset(spark, "./eng.train")
data_conll.show(2)
# Out:
# +------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |doc_id|                text|            document|            sentence|               token|                 pos|               label|
# +------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |     X|EU rejects German...|[{document, 0, 47...|[{document, 0, 47...|[{token, 0, 1, EU...|[{pos, 0, 1, NNP,...|[{named_entity, 0...|
# |     X|     Peter Blackburn|[{document, 0, 14...|[{document, 0, 14...|[{token, 0, 4, Pe...|[{pos, 0, 4, NNP,...|[{named_entity, 0...|
# +------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 2 rows

# %%
data_conll.count()
# Out:
# 14041

# %%
input_spark_df = data_conll.select("doc_id", "text")
input_spark_df.show(2, truncate=50)
# Out:
# +------+------------------------------------------------+
# |doc_id|                                            text|
# +------+------------------------------------------------+
# |     X|EU rejects German call to boycott British lamb .|
# |     X|                                 Peter Blackburn|
# +------+------------------------------------------------+
# only showing top 2 rows

# %% [markdown]
# ### Preprocess Data with the Modified Pipeline
#
# Run the entire dataset through our modified pipeline. This generates token, sentence, and embedding annotations required for the NER training downstream.

# %%
results = modified_pipeline.transform(input_spark_df)
results.columns
# Out:
# ['doc_id',
#  'text',
#  'document',
#  'splitter',
#  'token',
#  'embeddings',
#  'ner_clinical_large',
#  'ner_chunk_clinical_large',
#  'ner_deid_generic_docwise',
#  'ner_deid_docwise_subentity',
#  'ner_deid_generic_docwise_merged_conll',
#  'ner_chunk_generic_docwise',
#  'ner_chunk_subentity_docwise',
#  'ner_chunk_merged_docwise',
#  'ner_zero_shot',
#  'ner_chunk_zero_shot_raw',
#  'ner_deid_subentity_docwise_new',
#  'ner_chunk_subentity_docwise_new_chunk',
#  'ner_chunk_zero_shot',
#  'deid_merged_ner_chunk',
#  'entity_icd10',
#  'entity_ssn',
#  'entity_account',
#  'entity_dln',
#  'entity_plate',
#  'entity_vin',
#  'entity_license',
#  'entity_country',
#  'entity_state',
#  'entity_age',
#  'entity_date',
#  'entity_phone',
#  'entity_phone2',
#  'entity_zip',
#  'entity_medicalrecord',
#  'entity_email',
#  'entity_ip_address',
#  'entity_cpt',
#  'entity_specimen',
#  'deid_merged_ner_rulebased',
#  'ner_chunk_raw',
#  'ner_chunk_processed',
#  'ner_chunk',
#  'mask_entity',
#  'obfuscated',
#  'ner_label']

# %%
result_df = results.select('doc_id','text','document','splitter',
                          'token',"embeddings", 'ner_label')

# %%
result_df.show(2, truncate=40)
# Out:
# +------+----------------------------------------+----------------------------------------+----------------------------------------+----------------------------------------+----------------------------------------+----------------------------------------+
# |doc_id|                                    text|                                document|                                splitter|                                   token|                              embeddings|                               ner_label|
# +------+----------------------------------------+----------------------------------------+----------------------------------------+----------------------------------------+----------------------------------------+----------------------------------------+
# |     X|EU rejects German call to boycott Bri...|[{document, 0, 47, EU rejects German ...|[{document, 0, 48, EU rejects German ...|[{token, 0, 1, EU, {sentence -> 0}, [...|[{word_embeddings, 0, 1, EU, {isOOV -...|[{named_entity, 0, 1, B-LOCATION, {wo...|
# |     X|                         Peter Blackburn|[{document, 0, 14, Peter Blackburn, {...|[{document, 0, 15, Peter Blackburn, {...|[{token, 0, 4, Peter, {sentence -> 0}...|[{word_embeddings, 0, 4, Peter, {isOO...|[{named_entity, 0, 4, B-NAME, {word -...|
# +------+----------------------------------------+----------------------------------------+----------------------------------------+----------------------------------------+----------------------------------------+----------------------------------------+
# only showing top 2 rows

# %% [markdown]
# ### Persist Preprocessed Data
#
# Save the annotated DataFrame to Parquet format. This is an optimization step to speed up the training process by avoiding re-computation.

# %%
# %%time

n_partitions = 48

# WRITING THE DATA
result_df.repartition(n_partitions).write.mode("overwrite").format("parquet")\
    .save(f"./data/result_df_{n_partitions}.parquet")
# Out:
# CPU times: user 124 ms, sys: 51.5 ms, total: 175 ms
# Wall time: 16min 18s

# %% [markdown]
# ## Train a Custom Medical NER Model

# %%
# READING THE DATA
n_partitions = 48
result_df = spark.read \
    .parquet(f"./data/result_df_{n_partitions}.parquet")\
    .repartition(n_partitions)

# %%
result_df.count()
# Out:
# 14041

# %%
(train_df, test_df) = result_df.randomSplit([0.8, 0.2], seed = 42)

# %%
test_df.repartition(n_partitions).write.mode("overwrite").format("parquet")\
    .save(f"./data/test_df.parquet")

# %% [markdown]
# ###  Use MedicalNerDLGraphChecker for NER
#
# The MedicalNerDLGraphChecker processes the dataset to extract required graph parameters (tokens, labels, embedding dimensions)

# %%
embeddings = (nlp.WordEmbeddingsModel.pretrained("embeddings_clinical", "en", "clinical/models")
            .setInputCols(["splitter", "token"])
            .setOutputCol("embeddings"))
# Out:
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]

# %%
nerDLGraphChecker = medical.NerDLGraphChecker()\
    .setInputCols(["splitter", "token"])\
    .setLabelColumn("ner_label")\
    .setEmbeddingsModel(embeddings)

# %% [markdown]
# ###  Configure and Run the MedicalNerApproach

# %%
nerTagger = medical.NerApproach()\
    .setInputCols(["splitter", "token", "embeddings"])\
    .setLabelColumn("ner_label")\
    .setOutputCol("ner")\
    .setMaxEpochs(30)\
    .setBatchSize(8)\
    .setRandomSeed(0)\
    .setVerbose(1)\
    .setValidationSplit(0.2)\
    .setEvaluationLogExtended(True) \
    .setEnableOutputLogs(True)\
    .setIncludeConfidence(True)\
    .setOutputLogsPath('ner_logs')\
    .setEarlyStoppingCriterion(0.01)\
    .setEarlyStoppingPatience(5)\
    .setUseBestModel(False)\
    #.setTestDataset("./data/test_df.parquet")\
    #.setEnableMemoryOptimizer(True) #>> if you have a limited memory and a large conll file, you can set this True to train batch by batch
    #.setDatasetInfo("NCBI_sample_short dataset") #You can add details regarding the dataset

ner_pipeline = nlp.Pipeline(
    stages=[
          nerDLGraphChecker,
          nerTagger
 ])

# %%
# %%time
ner_model = ner_pipeline.fit(train_df)
# Out:
# CPU times: user 322 ms, sys: 112 ms, total: 433 ms
# Wall time: 42min 28s

# %%
ner_model.stages[-1].getTrainingClassDistribution()
# Out:
# {'I-NAME': 4435, 'I-CONTACT': 175, 'I-AGE': 34, 'I-IDNUM': 59, 'B-DATE': 3550, 'I-DATE': 497, 'I-LOCATION': 3804, 'B-NAME': 5213, 'B-AGE': 572, 'B-LOCATION': 10538, 'B-IDNUM': 156, 'O': 136268, 'B-CONTACT': 312}

# %% [markdown]
# ### Save the Trained NER Model and Review Logs

# %%
ner_model.stages[-1].write().overwrite().save('models/new_NER_model')

# %%
import os
log_file= os.listdir("ner_logs")[0]

with open (f"./ner_logs/{log_file}") as f:
    print(f.read())
# Out:
# Name of the selected graph: medical-ner-dl/blstm_100_200_128_100.pb
# Training started - total epochs: 30 - lr: 0.001 - batch size: 8 - labels: 13 - chars: 84 - training examples: 11194
#
#
# Epoch 1/30 started, lr: 0.001, dataset size: 11194
#
#
# Epoch 1/30 - 74.09s - loss: 5313.576 - avg training loss: 4.761269 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 13.60s
# Total validation loss: 810.2688	Avg validation loss: 2.8232
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 782	 232	 123	 0.77120316	 0.8640884	 0.81500787
# I-CONTACT	 17	 20	 7	 0.45945945	 0.7083333	 0.55737704
# I-AGE	 0	 0	 8	 0.0	 0.0	 0.0
# I-IDNUM	 0	 0	 9	 0.0	 0.0	 0.0
# B-DATE	 617	 37	 115	 0.94342506	 0.84289616	 0.89033186
# I-DATE	 75	 18	 15	 0.8064516	 0.8333333	 0.81967217
# I-LOCATION	 368	 144	 424	 0.71875	 0.46464646	 0.5644172
# B-NAME	 892	 340	 159	 0.72402596	 0.8487155	 0.7814279
# B-AGE	 62	 30	 67	 0.67391306	 0.48062015	 0.561086
# B-LOCATION	 1697	 394	 447	 0.8115734	 0.7915112	 0.8014167
# B-IDNUM	 0	 0	 38	 0.0	 0.0	 0.0
# B-CONTACT	 6	 21	 45	 0.22222222	 0.11764706	 0.15384614
# tp: 4516 fp: 1236 fn: 1457 labels: 12
# Macro-average	 prec: 0.5109187, rec: 0.49598262, f1: 0.5033399
# Micro-average	 prec: 0.7851182, rec: 0.756069, f1: 0.7703198
#
#
# Epoch 2/30 started, lr: 9.950249E-4, dataset size: 11194
#
#
# Epoch 2/30 - 72.74s - loss: 3150.152 - avg training loss: 2.822717 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 11.89s
# Total validation loss: 649.5971	Avg validation loss: 2.2634
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 747	 118	 158	 0.8635838	 0.82541436	 0.84406775
# I-CONTACT	 20	 27	 4	 0.42553192	 0.8333333	 0.5633803
# I-AGE	 6	 15	 2	 0.2857143	 0.75	 0.41379315
# I-IDNUM	 8	 3	 1	 0.72727275	 0.8888889	 0.8
# B-DATE	 617	 34	 115	 0.9477727	 0.84289616	 0.89226323
# I-DATE	 72	 11	 18	 0.8674699	 0.8	 0.8323699
# I-LOCATION	 384	 97	 408	 0.7983368	 0.4848485	 0.6032994
# B-NAME	 870	 297	 181	 0.7455013	 0.82778305	 0.78449047
# B-AGE	 72	 23	 57	 0.75789475	 0.55813956	 0.64285713
# B-LOCATION	 1608	 253	 536	 0.8640516	 0.75	 0.8029963
# B-IDNUM	 5	 6	 33	 0.45454547	 0.13157895	 0.20408164
# B-CONTACT	 18	 36	 33	 0.33333334	 0.3529412	 0.34285715
# tp: 4427 fp: 920 fn: 1546 labels: 12
# Macro-average	 prec: 0.67258406, rec: 0.6704853, f1: 0.6715331
# Micro-average	 prec: 0.8279409, rec: 0.7411686, f1: 0.7821556
#
#
# Epoch 3/30 started, lr: 9.90099E-4, dataset size: 11194
#
#
# Epoch 3/30 - 72.43s - loss: 2600.674 - avg training loss: 2.330353 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 12.03s
# Total validation loss: 559.5906	Avg validation loss: 1.9498
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 776	 96	 129	 0.88990825	 0.8574586	 0.8733821
# I-CONTACT	 20	 22	 4	 0.47619048	 0.8333333	 0.6060606
# I-AGE	 0	 0	 8	 0.0	 0.0	 0.0
# I-IDNUM	 0	 0	 9	 0.0	 0.0	 0.0
# B-DATE	 622	 24	 110	 0.9628483	 0.8497268	 0.90275764
# I-DATE	 78	 15	 12	 0.83870965	 0.8666667	 0.85245895
# I-LOCATION	 401	 118	 391	 0.7726397	 0.50631315	 0.6117467
# B-NAME	 874	 180	 177	 0.829222	 0.831589	 0.83040386
# B-AGE	 58	 9	 71	 0.86567163	 0.4496124	 0.59183675
# B-LOCATION	 1628	 213	 516	 0.884302	 0.75932837	 0.817064
# B-IDNUM	 0	 3	 38	 0.0	 0.0	 0.0
# B-CONTACT	 21	 36	 30	 0.36842105	 0.4117647	 0.3888889
# tp: 4478 fp: 716 fn: 1495 labels: 12
# Macro-average	 prec: 0.5739928, rec: 0.53048277, f1: 0.55138075
# Micro-average	 prec: 0.86214864, rec: 0.74970704, f1: 0.8020059
#
#
# Epoch 4/30 started, lr: 9.852217E-4, dataset size: 11194
#
#
# Epoch 4/30 - 72.53s - loss: 2306.0225 - avg training loss: 2.0663283 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 12.92s
# Total validation loss: 520.5558	Avg validation loss: 1.8138
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 800	 152	 105	 0.84033614	 0.8839779	 0.86160475
# I-CONTACT	 18	 4	 6	 0.8181818	 0.75	 0.78260875
# I-AGE	 0	 0	 8	 0.0	 0.0	 0.0
# I-IDNUM	 0	 0	 9	 0.0	 0.0	 0.0
# B-DATE	 634	 28	 98	 0.95770395	 0.8661202	 0.9096126
# I-DATE	 78	 15	 12	 0.83870965	 0.8666667	 0.85245895
# I-LOCATION	 418	 110	 374	 0.7916667	 0.5277778	 0.6333334
# B-NAME	 901	 239	 150	 0.79035085	 0.85727876	 0.8224555
# B-AGE	 78	 27	 51	 0.74285716	 0.60465115	 0.6666666
# B-LOCATION	 1719	 253	 425	 0.87170386	 0.8017724	 0.835277
# B-IDNUM	 3	 3	 35	 0.5	 0.078947365	 0.13636363
# B-CONTACT	 26	 16	 25	 0.61904764	 0.50980395	 0.5591398
# tp: 4675 fp: 847 fn: 1298 labels: 12
# Macro-average	 prec: 0.64754647, rec: 0.5622497, f1: 0.60189116
# Micro-average	 prec: 0.8466135, rec: 0.78268874, f1: 0.81339705
#
#
# Epoch 5/30 started, lr: 9.803922E-4, dataset size: 11194
#
#
# Epoch 5/30 - 72.34s - loss: 2084.7458 - avg training loss: 1.8680519 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 12.03s
# Total validation loss: 522.5231	Avg validation loss: 1.8206
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 774	 87	 131	 0.8989547	 0.85524863	 0.8765572
# I-CONTACT	 20	 35	 4	 0.36363637	 0.8333333	 0.5063291
# I-AGE	 1	 2	 7	 0.33333334	 0.125	 0.18181819
# I-IDNUM	 0	 0	 9	 0.0	 0.0	 0.0
# B-DATE	 648	 50	 84	 0.9283668	 0.8852459	 0.9062937
# I-DATE	 79	 18	 11	 0.814433	 0.87777776	 0.8449198
# I-LOCATION	 429	 113	 363	 0.7915129	 0.5416667	 0.6431784
# B-NAME	 887	 174	 164	 0.8360038	 0.84395814	 0.8399622
# B-AGE	 73	 17	 56	 0.8111111	 0.56589144	 0.6666667
# B-LOCATION	 1790	 291	 354	 0.8601634	 0.83488804	 0.84733725
# B-IDNUM	 5	 2	 33	 0.71428573	 0.13157895	 0.22222224
# B-CONTACT	 27	 27	 24	 0.5	 0.5294118	 0.51428574
# tp: 4733 fp: 816 fn: 1240 labels: 12
# Macro-average	 prec: 0.6543167, rec: 0.5853334, f1: 0.6179057
# Micro-average	 prec: 0.85294646, rec: 0.7923991, f1: 0.8215587
#
#
# Epoch 6/30 started, lr: 9.756098E-4, dataset size: 11194
#
#
# Epoch 6/30 - 72.65s - loss: 1927.5942 - avg training loss: 1.727235 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 11.91s
# Total validation loss: 496.6267	Avg validation loss: 1.7304
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 751	 67	 154	 0.9180929	 0.8298343	 0.87173533
# I-CONTACT	 17	 4	 7	 0.8095238	 0.7083333	 0.7555556
# I-AGE	 7	 5	 1	 0.5833333	 0.875	 0.7
# I-IDNUM	 6	 5	 3	 0.54545456	 0.6666667	 0.6
# B-DATE	 667	 78	 65	 0.895302	 0.9112022	 0.9031821
# I-DATE	 78	 18	 12	 0.8125	 0.8666667	 0.83870965
# I-LOCATION	 445	 170	 347	 0.72357726	 0.56186867	 0.6325515
# B-NAME	 866	 173	 185	 0.83349377	 0.8239772	 0.8287082
# B-AGE	 95	 52	 34	 0.64625853	 0.7364341	 0.6884058
# B-LOCATION	 1813	 319	 331	 0.85037524	 0.8456157	 0.8479888
# B-IDNUM	 6	 7	 32	 0.46153846	 0.15789473	 0.23529413
# B-CONTACT	 24	 7	 27	 0.7741935	 0.47058824	 0.58536583
# tp: 4775 fp: 905 fn: 1198 labels: 12
# Macro-average	 prec: 0.73780364, rec: 0.7045068, f1: 0.72077084
# Micro-average	 prec: 0.84066904, rec: 0.7994308, f1: 0.81953156
#
#
# Epoch 7/30 started, lr: 9.7087387E-4, dataset size: 11194
#
#
# Epoch 7/30 - 72.42s - loss: 1776.9587 - avg training loss: 1.5922569 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 12.12s
# Total validation loss: 473.0480	Avg validation loss: 1.6483
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 791	 133	 114	 0.8560606	 0.87403315	 0.8649536
# I-CONTACT	 17	 6	 7	 0.73913044	 0.7083333	 0.7234042
# I-AGE	 7	 6	 1	 0.53846157	 0.875	 0.6666667
# I-IDNUM	 5	 3	 4	 0.625	 0.5555556	 0.5882353
# B-DATE	 650	 42	 82	 0.9393064	 0.88797814	 0.91292137
# I-DATE	 78	 5	 12	 0.939759	 0.8666667	 0.9017341
# I-LOCATION	 523	 249	 269	 0.67746115	 0.66035354	 0.6687979
# B-NAME	 905	 207	 146	 0.8138489	 0.8610847	 0.8368007
# B-AGE	 96	 36	 33	 0.72727275	 0.74418604	 0.7356322
# B-LOCATION	 1820	 307	 324	 0.85566527	 0.8488806	 0.85225946
# B-IDNUM	 9	 7	 29	 0.5625	 0.23684211	 0.33333334
# B-CONTACT	 27	 15	 24	 0.64285713	 0.5294118	 0.5806452
# tp: 4928 fp: 1016 fn: 1045 labels: 12
# Macro-average	 prec: 0.74311036, rec: 0.72069377, f1: 0.7317304
# Micro-average	 prec: 0.82907134, rec: 0.82504606, f1: 0.82705384
#
#
# Epoch 8/30 started, lr: 9.6618367E-4, dataset size: 11194
#
#
# Epoch 8/30 - 72.36s - loss: 1654.2742 - avg training loss: 1.4823245 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 12.07s
# Total validation loss: 476.8753	Avg validation loss: 1.6616
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 796	 128	 109	 0.86147183	 0.879558	 0.870421
# I-CONTACT	 18	 13	 6	 0.58064514	 0.75	 0.6545455
# I-AGE	 5	 6	 3	 0.45454547	 0.625	 0.52631575
# I-IDNUM	 5	 3	 4	 0.625	 0.5555556	 0.5882353
# B-DATE	 661	 59	 71	 0.91805553	 0.9030055	 0.91046834
# I-DATE	 79	 17	 11	 0.8229167	 0.87777776	 0.8494624
# I-LOCATION	 437	 104	 355	 0.8077634	 0.55176765	 0.65566385
# B-NAME	 911	 218	 140	 0.8069088	 0.8667935	 0.83577985
# B-AGE	 75	 17	 54	 0.8152174	 0.5813953	 0.67873305
# B-LOCATION	 1758	 228	 386	 0.8851964	 0.8199627	 0.8513317
# B-IDNUM	 9	 18	 29	 0.33333334	 0.23684211	 0.2769231
# B-CONTACT	 20	 12	 31	 0.625	 0.39215687	 0.48192772
# tp: 4774 fp: 823 fn: 1199 labels: 12
# Macro-average	 prec: 0.71133786, rec: 0.6699846, f1: 0.69004226
# Micro-average	 prec: 0.85295695, rec: 0.79926336, f1: 0.82523775
#
#
# Epoch 9/30 started, lr: 9.615385E-4, dataset size: 11194
#
#
# Epoch 9/30 - 72.60s - loss: 1561.9133 - avg training loss: 1.3995639 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 12.08s
# Total validation loss: 475.4011	Avg validation loss: 1.6564
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 754	 70	 151	 0.91504854	 0.8331492	 0.87218046
# I-CONTACT	 18	 2	 6	 0.9	 0.75	 0.81818175
# I-AGE	 7	 16	 1	 0.3043478	 0.875	 0.45161292
# I-IDNUM	 3	 3	 6	 0.5	 0.33333334	 0.4
# B-DATE	 666	 49	 66	 0.93146855	 0.90983605	 0.9205253
# I-DATE	 79	 8	 11	 0.90804595	 0.87777776	 0.8926553
# I-LOCATION	 409	 89	 383	 0.8212851	 0.51641417	 0.63410854
# B-NAME	 874	 153	 177	 0.8510224	 0.831589	 0.84119344
# B-AGE	 91	 27	 38	 0.7711864	 0.70542634	 0.7368421
# B-LOCATION	 1766	 218	 378	 0.890121	 0.82369405	 0.8556202
# B-IDNUM	 11	 11	 27	 0.5	 0.28947368	 0.36666667
# B-CONTACT	 34	 26	 17	 0.56666666	 0.6666667	 0.6126126
# tp: 4712 fp: 672 fn: 1261 labels: 12
# Macro-average	 prec: 0.738266, rec: 0.70103, f1: 0.7191663
# Micro-average	 prec: 0.8751857, rec: 0.7888833, f1: 0.8297966
#
#
# Epoch 10/30 started, lr: 9.569379E-4, dataset size: 11194
#
#
# Epoch 10/30 - 72.31s - loss: 1457.5361 - avg training loss: 1.306036 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 11.97s
# Total validation loss: 467.3960	Avg validation loss: 1.6286
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 785	 98	 120	 0.8890147	 0.8674033	 0.8780761
# I-CONTACT	 17	 2	 7	 0.8947368	 0.7083333	 0.79069763
# I-AGE	 4	 4	 4	 0.5	 0.5	 0.5
# I-IDNUM	 5	 5	 4	 0.5	 0.5555556	 0.5263158
# B-DATE	 657	 46	 75	 0.93456614	 0.897541	 0.91567945
# I-DATE	 79	 10	 11	 0.8876405	 0.87777776	 0.88268155
# I-LOCATION	 456	 117	 336	 0.79581153	 0.57575756	 0.6681318
# B-NAME	 886	 162	 165	 0.8454198	 0.8430067	 0.8442115
# B-AGE	 65	 11	 64	 0.8552632	 0.503876	 0.63414633
# B-LOCATION	 1812	 265	 332	 0.87241215	 0.8451493	 0.8585643
# B-IDNUM	 14	 19	 24	 0.42424244	 0.36842105	 0.3943662
# B-CONTACT	 32	 18	 19	 0.64	 0.627451	 0.6336633
# tp: 4812 fp: 757 fn: 1161 labels: 12
# Macro-average	 prec: 0.75325894, rec: 0.68085605, f1: 0.7152298
# Micro-average	 prec: 0.8640689, rec: 0.8056253, f1: 0.8338243
#
#
# Epoch 11/30 started, lr: 9.5238106E-4, dataset size: 11194
#
#
# Epoch 11/30 - 72.43s - loss: 1359.5898 - avg training loss: 1.2182704 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 11.94s
# Total validation loss: 483.3792	Avg validation loss: 1.6842
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 791	 148	 114	 0.84238553	 0.87403315	 0.85791755
# I-CONTACT	 18	 3	 6	 0.85714287	 0.75	 0.79999995
# I-AGE	 7	 9	 1	 0.4375	 0.875	 0.5833333
# I-IDNUM	 0	 1	 9	 0.0	 0.0	 0.0
# B-DATE	 666	 52	 66	 0.9275766	 0.90983605	 0.9186207
# I-DATE	 79	 2	 11	 0.97530866	 0.87777776	 0.9239766
# I-LOCATION	 465	 156	 327	 0.7487923	 0.5871212	 0.6581741
# B-NAME	 906	 232	 145	 0.7961336	 0.86203617	 0.82777524
# B-AGE	 99	 39	 30	 0.7173913	 0.76744187	 0.741573
# B-LOCATION	 1782	 243	 362	 0.88	 0.83115673	 0.8548812
# B-IDNUM	 7	 10	 31	 0.4117647	 0.18421052	 0.25454548
# B-CONTACT	 32	 15	 19	 0.68085104	 0.627451	 0.6530612
# tp: 4852 fp: 910 fn: 1121 labels: 12
# Macro-average	 prec: 0.6895706, rec: 0.6788387, f1: 0.68416256
# Micro-average	 prec: 0.84206873, rec: 0.81232214, f1: 0.826928
#
#
# Epoch 12/30 started, lr: 9.478674E-4, dataset size: 11194
#
#
# Epoch 12/30 - 72.18s - loss: 1276.0999 - avg training loss: 1.1434586 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 11.93s
# Total validation loss: 478.6965	Avg validation loss: 1.6679
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 765	 94	 140	 0.8905704	 0.8453039	 0.86734694
# I-CONTACT	 18	 5	 6	 0.7826087	 0.75	 0.7659574
# I-AGE	 5	 5	 3	 0.5	 0.625	 0.5555556
# I-IDNUM	 5	 7	 4	 0.41666666	 0.5555556	 0.4761905
# B-DATE	 658	 40	 74	 0.9426934	 0.8989071	 0.92027974
# I-DATE	 83	 17	 7	 0.83	 0.9222222	 0.87368417
# I-LOCATION	 476	 176	 316	 0.73006135	 0.6010101	 0.65927976
# B-NAME	 864	 143	 187	 0.857994	 0.82207423	 0.83965015
# B-AGE	 71	 6	 58	 0.9220779	 0.5503876	 0.6893204
# B-LOCATION	 1808	 248	 336	 0.8793774	 0.8432836	 0.8609524
# B-IDNUM	 9	 10	 29	 0.47368422	 0.23684211	 0.31578946
# B-CONTACT	 35	 28	 16	 0.5555556	 0.6862745	 0.6140351
# tp: 4797 fp: 779 fn: 1176 labels: 12
# Macro-average	 prec: 0.73177415, rec: 0.69473845, f1: 0.7127755
# Micro-average	 prec: 0.8602941, rec: 0.803114, f1: 0.83072126
#
#
# Epoch 13/30 started, lr: 9.433963E-4, dataset size: 11194
#
#
# Epoch 13/30 - 72.16s - loss: 1198.8289 - avg training loss: 1.0742195 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 11.97s
# Total validation loss: 483.7581	Avg validation loss: 1.6856
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 798	 136	 107	 0.8543897	 0.8817679	 0.86786294
# I-CONTACT	 19	 6	 5	 0.76	 0.7916667	 0.7755102
# I-AGE	 7	 5	 1	 0.5833333	 0.875	 0.7
# I-IDNUM	 5	 5	 4	 0.5	 0.5555556	 0.5263158
# B-DATE	 656	 46	 76	 0.9344729	 0.89617485	 0.91492325
# I-DATE	 80	 9	 10	 0.8988764	 0.8888889	 0.8938548
# I-LOCATION	 469	 129	 323	 0.78428096	 0.5921717	 0.6748202
# B-NAME	 907	 196	 144	 0.8223028	 0.86298764	 0.84215415
# B-AGE	 84	 17	 45	 0.83168316	 0.6511628	 0.7304347
# B-LOCATION	 1779	 211	 365	 0.89396983	 0.82975745	 0.86066765
# B-IDNUM	 7	 7	 31	 0.5	 0.18421052	 0.26923075
# B-CONTACT	 26	 6	 25	 0.8125	 0.50980395	 0.62650603
# tp: 4837 fp: 773 fn: 1136 labels: 12
# Macro-average	 prec: 0.7646508, rec: 0.709929, f1: 0.7362746
# Micro-average	 prec: 0.86221033, rec: 0.8098108, f1: 0.83518946
#
#
# Epoch 14/30 started, lr: 9.389671E-4, dataset size: 11194
#
#
# Epoch 14/30 - 72.44s - loss: 1150.4482 - avg training loss: 1.0308676 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 11.79s
# Total validation loss: 480.6207	Avg validation loss: 1.6746
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 786	 100	 119	 0.8871332	 0.8685083	 0.87772197
# I-CONTACT	 18	 4	 6	 0.8181818	 0.75	 0.78260875
# I-AGE	 5	 5	 3	 0.5	 0.625	 0.5555556
# I-IDNUM	 4	 12	 5	 0.25	 0.44444445	 0.32000002
# B-DATE	 653	 38	 79	 0.94500726	 0.8920765	 0.9177793
# I-DATE	 80	 6	 10	 0.9302326	 0.8888889	 0.90909094
# I-LOCATION	 474	 167	 318	 0.7394696	 0.5984849	 0.66154915
# B-NAME	 891	 165	 160	 0.84375	 0.847764	 0.8457523
# B-AGE	 92	 22	 37	 0.80701756	 0.7131783	 0.7572017
# B-LOCATION	 1788	 230	 356	 0.8860258	 0.8339552	 0.8592024
# B-IDNUM	 9	 11	 29	 0.45	 0.23684211	 0.31034485
# B-CONTACT	 33	 13	 18	 0.7173913	 0.64705884	 0.68041235
# tp: 4833 fp: 773 fn: 1140 labels: 12
# Macro-average	 prec: 0.73118407, rec: 0.6955168, f1: 0.71290463
# Micro-average	 prec: 0.86211205, rec: 0.80914116, f1: 0.83478713
#
#
# Epoch 15/30 started, lr: 9.345794E-4, dataset size: 11194
#
#
# Epoch 15/30 - 72.14s - loss: 1058.0411 - avg training loss: 0.9480655 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 11.79s
# Total validation loss: 480.8502	Avg validation loss: 1.6754
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 781	 103	 124	 0.8834842	 0.8629834	 0.8731135
# I-CONTACT	 18	 5	 6	 0.7826087	 0.75	 0.7659574
# I-AGE	 4	 4	 4	 0.5	 0.5	 0.5
# I-IDNUM	 4	 12	 5	 0.25	 0.44444445	 0.32000002
# B-DATE	 658	 38	 74	 0.9454023	 0.8989071	 0.9215687
# I-DATE	 79	 4	 11	 0.9518072	 0.87777776	 0.9132948
# I-LOCATION	 479	 163	 313	 0.7461059	 0.60479796	 0.6680614
# B-NAME	 881	 153	 170	 0.85203093	 0.83824927	 0.84508395
# B-AGE	 81	 22	 48	 0.78640777	 0.627907	 0.69827586
# B-LOCATION	 1763	 206	 381	 0.89537835	 0.8222948	 0.8572818
# B-IDNUM	 11	 19	 27	 0.36666667	 0.28947368	 0.32352942
# B-CONTACT	 26	 9	 25	 0.74285716	 0.50980395	 0.6046512
# tp: 4785 fp: 738 fn: 1188 labels: 12
# Macro-average	 prec: 0.7252291, rec: 0.6688866, f1: 0.6959193
# Micro-average	 prec: 0.866377, rec: 0.80110496, f1: 0.8324635
#
#
# Epoch 16/30 started, lr: 9.302326E-4, dataset size: 11194
#
#
# Epoch 16/30 - 72.21s - loss: 1003.9417 - avg training loss: 0.89958936 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 11.81s
# Total validation loss: 506.1074	Avg validation loss: 1.7634
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 754	 77	 151	 0.9073405	 0.8331492	 0.8686636
# I-CONTACT	 18	 3	 6	 0.85714287	 0.75	 0.79999995
# I-AGE	 5	 6	 3	 0.45454547	 0.625	 0.52631575
# I-IDNUM	 4	 12	 5	 0.25	 0.44444445	 0.32000002
# B-DATE	 662	 46	 70	 0.93502825	 0.90437156	 0.91944444
# I-DATE	 80	 2	 10	 0.9756098	 0.8888889	 0.93023264
# I-LOCATION	 519	 228	 273	 0.6947791	 0.655303	 0.67446387
# B-NAME	 883	 157	 168	 0.8490385	 0.84015226	 0.844572
# B-AGE	 82	 19	 47	 0.8118812	 0.6356589	 0.7130436
# B-LOCATION	 1817	 289	 327	 0.862773	 0.84748137	 0.8550588
# B-IDNUM	 10	 13	 28	 0.4347826	 0.2631579	 0.32786885
# B-CONTACT	 31	 10	 20	 0.75609756	 0.60784316	 0.67391306
# tp: 4865 fp: 862 fn: 1108 labels: 12
# Macro-average	 prec: 0.7324183, rec: 0.6912875, f1: 0.7112588
# Micro-average	 prec: 0.8494849, rec: 0.8144986, f1: 0.831624
#
#
# Epoch 17/30 started, lr: 9.259259E-4, dataset size: 11194
#
#
# Epoch 17/30 - 72.71s - loss: 928.61005 - avg training loss: 0.8320879 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 11.87s
# Total validation loss: 529.9523	Avg validation loss: 1.8465
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 773	 104	 132	 0.88141394	 0.8541436	 0.86756456
# I-CONTACT	 18	 4	 6	 0.8181818	 0.75	 0.78260875
# I-AGE	 3	 3	 5	 0.5	 0.375	 0.42857143
# I-IDNUM	 5	 6	 4	 0.45454547	 0.5555556	 0.5
# B-DATE	 651	 34	 81	 0.95036495	 0.8893443	 0.91884255
# I-DATE	 80	 3	 10	 0.96385545	 0.8888889	 0.9248555
# I-LOCATION	 486	 207	 306	 0.7012987	 0.6136364	 0.6545455
# B-NAME	 895	 195	 156	 0.8211009	 0.85156995	 0.8360579
# B-AGE	 76	 15	 53	 0.83516484	 0.58914727	 0.6909091
# B-LOCATION	 1783	 268	 361	 0.869332	 0.83162314	 0.85005957
# B-IDNUM	 9	 7	 29	 0.5625	 0.23684211	 0.33333334
# B-CONTACT	 38	 31	 13	 0.5507246	 0.74509805	 0.6333334
# tp: 4817 fp: 877 fn: 1156 labels: 12
# Macro-average	 prec: 0.7423735, rec: 0.6817374, f1: 0.7107646
# Micro-average	 prec: 0.8459782, rec: 0.8064624, f1: 0.82574785
#
#
# Epoch 18/30 started, lr: 9.21659E-4, dataset size: 11194
#
#
# Epoch 18/30 - 72.03s - loss: 889.5888 - avg training loss: 0.7971226 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 11.89s
# Total validation loss: 539.2037	Avg validation loss: 1.8788
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 806	 146	 99	 0.8466387	 0.8906077	 0.8680668
# I-CONTACT	 18	 3	 6	 0.85714287	 0.75	 0.79999995
# I-AGE	 4	 6	 4	 0.4	 0.5	 0.44444448
# I-IDNUM	 5	 6	 4	 0.45454547	 0.5555556	 0.5
# B-DATE	 665	 46	 67	 0.9353024	 0.90847	 0.9216909
# I-DATE	 79	 9	 11	 0.89772725	 0.87777776	 0.88764036
# I-LOCATION	 478	 140	 314	 0.7734628	 0.60353535	 0.67801416
# B-NAME	 920	 229	 131	 0.80069625	 0.8753568	 0.8363636
# B-AGE	 92	 31	 37	 0.7479675	 0.7131783	 0.7301587
# B-LOCATION	 1744	 201	 400	 0.8966581	 0.8134328	 0.8530203
# B-IDNUM	 17	 23	 21	 0.425	 0.4473684	 0.4358974
# B-CONTACT	 32	 13	 19	 0.7111111	 0.627451	 0.6666667
# tp: 4860 fp: 853 fn: 1113 labels: 12
# Macro-average	 prec: 0.72885436, rec: 0.7135611, f1: 0.7211266
# Micro-average	 prec: 0.8506914, rec: 0.81366146, f1: 0.83176446
#
#
# Epoch 19/30 started, lr: 9.174312E-4, dataset size: 11194
#
#
# Epoch 19/30 - 72.25s - loss: 819.7897 - avg training loss: 0.73457855 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 11.74s
# Total validation loss: 553.1683	Avg validation loss: 1.9274
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 805	 137	 100	 0.8545647	 0.88950276	 0.87168384
# I-CONTACT	 18	 2	 6	 0.9	 0.75	 0.81818175
# I-AGE	 7	 6	 1	 0.53846157	 0.875	 0.6666667
# I-IDNUM	 8	 20	 1	 0.2857143	 0.8888889	 0.43243244
# B-DATE	 660	 39	 72	 0.944206	 0.90163934	 0.9224318
# I-DATE	 78	 1	 12	 0.98734176	 0.8666667	 0.9230769
# I-LOCATION	 494	 174	 298	 0.73952097	 0.6237374	 0.67671233
# B-NAME	 921	 208	 130	 0.81576616	 0.87630826	 0.84495413
# B-AGE	 87	 13	 42	 0.87	 0.6744186	 0.75982535
# B-LOCATION	 1842	 306	 302	 0.8575419	 0.85914177	 0.8583411
# B-IDNUM	 18	 20	 20	 0.47368422	 0.47368422	 0.47368422
# B-CONTACT	 35	 13	 16	 0.7291667	 0.6862745	 0.7070707
# tp: 4973 fp: 939 fn: 1000 labels: 12
# Macro-average	 prec: 0.74966407, rec: 0.7804385, f1: 0.76474184
# Micro-average	 prec: 0.8411705, rec: 0.83258, f1: 0.8368532
#
#
# Epoch 20/30 started, lr: 9.1324205E-4, dataset size: 11194
#
#
# Epoch 20/30 - 72.18s - loss: 794.60266 - avg training loss: 0.71200955 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 11.96s
# Total validation loss: 560.5070	Avg validation loss: 1.9530
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 794	 112	 111	 0.87637967	 0.87734807	 0.87686366
# I-CONTACT	 18	 4	 6	 0.8181818	 0.75	 0.78260875
# I-AGE	 7	 8	 1	 0.46666667	 0.875	 0.6086956
# I-IDNUM	 4	 8	 5	 0.33333334	 0.44444445	 0.3809524
# B-DATE	 662	 43	 70	 0.9390071	 0.90437156	 0.92136395
# I-DATE	 82	 9	 8	 0.9010989	 0.9111111	 0.9060773
# I-LOCATION	 482	 182	 310	 0.72590363	 0.60858583	 0.6620879
# B-NAME	 924	 221	 127	 0.8069869	 0.8791627	 0.84153014
# B-AGE	 93	 28	 36	 0.76859504	 0.7209302	 0.74399996
# B-LOCATION	 1797	 245	 347	 0.8800196	 0.838153	 0.85857624
# B-IDNUM	 13	 14	 25	 0.4814815	 0.34210527	 0.40000004
# B-CONTACT	 33	 26	 18	 0.55932206	 0.64705884	 0.6
# tp: 4909 fp: 900 fn: 1064 labels: 12
# Macro-average	 prec: 0.71308136, rec: 0.73318917, f1: 0.7229955
# Micro-average	 prec: 0.845068, rec: 0.8218651, f1: 0.83330506
#
#
# Epoch 21/30 started, lr: 9.090909E-4, dataset size: 11194
#
#
# Epoch 21/30 - 73.02s - loss: 729.1303 - avg training loss: 0.65334255 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 11.75s
# Total validation loss: 570.9016	Avg validation loss: 1.9892
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 769	 127	 136	 0.8582589	 0.84972376	 0.85397
# I-CONTACT	 18	 4	 6	 0.8181818	 0.75	 0.78260875
# I-AGE	 7	 9	 1	 0.4375	 0.875	 0.5833333
# I-IDNUM	 4	 8	 5	 0.33333334	 0.44444445	 0.3809524
# B-DATE	 676	 57	 56	 0.9222374	 0.92349726	 0.92286694
# I-DATE	 84	 14	 6	 0.85714287	 0.93333334	 0.89361703
# I-LOCATION	 511	 223	 281	 0.6961853	 0.64520204	 0.6697248
# B-NAME	 903	 213	 148	 0.8091398	 0.8591817	 0.83341026
# B-AGE	 92	 24	 37	 0.79310346	 0.7131783	 0.75102043
# B-LOCATION	 1799	 259	 345	 0.8741497	 0.8390858	 0.8562589
# B-IDNUM	 13	 14	 25	 0.4814815	 0.34210527	 0.40000004
# B-CONTACT	 27	 8	 24	 0.7714286	 0.5294118	 0.62790704
# tp: 4903 fp: 960 fn: 1070 labels: 12
# Macro-average	 prec: 0.7210119, rec: 0.72534686, f1: 0.72317296
# Micro-average	 prec: 0.8362613, rec: 0.82086056, f1: 0.8284893
#
#
# Epoch 22/30 started, lr: 9.049774E-4, dataset size: 11194
#
#
# Epoch 22/30 - 72.37s - loss: 707.8651 - avg training loss: 0.6342877 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 11.74s
# Total validation loss: 596.7788	Avg validation loss: 2.0794
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 769	 100	 136	 0.8849252	 0.84972376	 0.8669673
# I-CONTACT	 18	 4	 6	 0.8181818	 0.75	 0.78260875
# I-AGE	 6	 6	 2	 0.5	 0.75	 0.6
# I-IDNUM	 5	 5	 4	 0.5	 0.5555556	 0.5263158
# B-DATE	 663	 41	 69	 0.9417614	 0.9057377	 0.9233983
# I-DATE	 80	 3	 10	 0.96385545	 0.8888889	 0.9248555
# I-LOCATION	 480	 157	 312	 0.7535322	 0.6060606	 0.67179847
# B-NAME	 882	 161	 169	 0.84563756	 0.83920074	 0.8424068
# B-AGE	 87	 14	 42	 0.8613861	 0.6744186	 0.7565217
# B-LOCATION	 1821	 276	 323	 0.8683834	 0.849347	 0.8587597
# B-IDNUM	 14	 13	 24	 0.5185185	 0.36842105	 0.43076923
# B-CONTACT	 27	 8	 24	 0.7714286	 0.5294118	 0.62790704
# tp: 4852 fp: 788 fn: 1121 labels: 12
# Macro-average	 prec: 0.76896745, rec: 0.71389705, f1: 0.7404097
# Micro-average	 prec: 0.8602837, rec: 0.81232214, f1: 0.8356153
#
#
# Epoch 23/30 started, lr: 9.009009E-4, dataset size: 11194
#
#
# Epoch 23/30 - 72.47s - loss: 671.4792 - avg training loss: 0.60168386 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 11.86s
# Total validation loss: 594.4822	Avg validation loss: 2.0714
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 777	 113	 128	 0.8730337	 0.85856354	 0.8657382
# I-CONTACT	 18	 7	 6	 0.72	 0.75	 0.7346939
# I-AGE	 6	 6	 2	 0.5	 0.75	 0.6
# I-IDNUM	 6	 3	 3	 0.6666667	 0.6666667	 0.6666667
# B-DATE	 663	 41	 69	 0.9417614	 0.9057377	 0.9233983
# I-DATE	 81	 8	 9	 0.9101124	 0.9	 0.9050279
# I-LOCATION	 516	 277	 276	 0.6506936	 0.6515151	 0.65110415
# B-NAME	 900	 209	 151	 0.8115419	 0.8563273	 0.8333334
# B-AGE	 78	 19	 51	 0.8041237	 0.60465115	 0.6902655
# B-LOCATION	 1823	 309	 321	 0.85506564	 0.85027987	 0.8526661
# B-IDNUM	 14	 7	 24	 0.6666667	 0.36842105	 0.4745763
# B-CONTACT	 31	 17	 20	 0.6458333	 0.60784316	 0.62626266
# tp: 4913 fp: 1016 fn: 1060 labels: 12
# Macro-average	 prec: 0.7537916, rec: 0.73083377, f1: 0.74213517
# Micro-average	 prec: 0.8286389, rec: 0.82253474, f1: 0.8255756
#
#
# Epoch 24/30 started, lr: 8.96861E-4, dataset size: 11194
#
#
# Epoch 24/30 - 73.01s - loss: 637.0078 - avg training loss: 0.57079554 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 12.02s
# Total validation loss: 633.4691	Avg validation loss: 2.2072
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 789	 106	 116	 0.88156426	 0.8718232	 0.87666667
# I-CONTACT	 18	 0	 6	 1.0	 0.75	 0.85714287
# I-AGE	 4	 8	 4	 0.33333334	 0.5	 0.4
# I-IDNUM	 0	 3	 9	 0.0	 0.0	 0.0
# B-DATE	 651	 30	 81	 0.95594716	 0.8893443	 0.9214438
# I-DATE	 83	 6	 7	 0.9325843	 0.9222222	 0.9273743
# I-LOCATION	 470	 164	 322	 0.7413249	 0.59343433	 0.6591865
# B-NAME	 907	 184	 144	 0.8313474	 0.86298764	 0.8468721
# B-AGE	 93	 31	 36	 0.75	 0.7209302	 0.7351779
# B-LOCATION	 1811	 287	 333	 0.86320305	 0.8446828	 0.8538425
# B-IDNUM	 11	 11	 27	 0.5	 0.28947368	 0.36666667
# B-CONTACT	 29	 11	 22	 0.725	 0.5686275	 0.63736266
# tp: 4866 fp: 841 fn: 1107 labels: 12
# Macro-average	 prec: 0.70952535, rec: 0.6511271, f1: 0.67907304
# Micro-average	 prec: 0.8526371, rec: 0.814666, f1: 0.8332192
#
#
# Epoch 25/30 started, lr: 8.928572E-4, dataset size: 11194
#
#
# Epoch 25/30 - 72.68s - loss: 620.70953 - avg training loss: 0.5561913 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 11.84s
# Total validation loss: 606.1949	Avg validation loss: 2.1122
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 777	 110	 128	 0.87598646	 0.85856354	 0.8671875
# I-CONTACT	 18	 2	 6	 0.9	 0.75	 0.81818175
# I-AGE	 5	 3	 3	 0.625	 0.625	 0.625
# I-IDNUM	 5	 10	 4	 0.33333334	 0.5555556	 0.41666666
# B-DATE	 668	 38	 64	 0.94617563	 0.91256833	 0.9290682
# I-DATE	 81	 16	 9	 0.83505154	 0.9	 0.8663102
# I-LOCATION	 496	 223	 296	 0.689847	 0.6262626	 0.6565188
# B-NAME	 878	 159	 173	 0.8466731	 0.83539486	 0.8409962
# B-AGE	 97	 33	 32	 0.74615383	 0.751938	 0.7490347
# B-LOCATION	 1829	 331	 315	 0.84675926	 0.85307837	 0.84990704
# B-IDNUM	 13	 14	 25	 0.4814815	 0.34210527	 0.40000004
# B-CONTACT	 31	 9	 20	 0.775	 0.60784316	 0.6813187
# tp: 4898 fp: 948 fn: 1075 labels: 12
# Macro-average	 prec: 0.7417884, rec: 0.7181925, f1: 0.72979975
# Micro-average	 prec: 0.8378378, rec: 0.8200234, f1: 0.82883495
#
#
# Epoch 26/30 started, lr: 8.8888896E-4, dataset size: 11194
#
#
# Epoch 26/30 - 73.34s - loss: 598.86615 - avg training loss: 0.5366184 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 12.02s
# Total validation loss: 669.0346	Avg validation loss: 2.3311
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 788	 109	 117	 0.87848383	 0.87071824	 0.87458384
# I-CONTACT	 18	 6	 6	 0.75	 0.75	 0.75
# I-AGE	 3	 3	 5	 0.5	 0.375	 0.42857143
# I-IDNUM	 5	 6	 4	 0.45454547	 0.5555556	 0.5
# B-DATE	 655	 34	 77	 0.95065314	 0.89480877	 0.921886
# I-DATE	 84	 8	 6	 0.9130435	 0.93333334	 0.92307687
# I-LOCATION	 473	 151	 319	 0.75801283	 0.5972222	 0.6680791
# B-NAME	 903	 196	 148	 0.82165605	 0.8591817	 0.84000003
# B-AGE	 85	 24	 44	 0.7798165	 0.65891474	 0.71428573
# B-LOCATION	 1818	 261	 326	 0.87445885	 0.8479478	 0.8609993
# B-IDNUM	 13	 13	 25	 0.5	 0.34210527	 0.40625
# B-CONTACT	 26	 14	 25	 0.65	 0.50980395	 0.5714286
# tp: 4871 fp: 825 fn: 1102 labels: 12
# Macro-average	 prec: 0.73588914, rec: 0.6828826, f1: 0.70839566
# Micro-average	 prec: 0.8551615, rec: 0.8155031, f1: 0.83486164
#
#
# Epoch 27/30 started, lr: 8.849558E-4, dataset size: 11194
#
#
# Epoch 27/30 - 72.19s - loss: 559.0887 - avg training loss: 0.50097555 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 12.05s
# Total validation loss: 646.7245	Avg validation loss: 2.2534
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 768	 78	 137	 0.9078014	 0.8486188	 0.87721306
# I-CONTACT	 18	 6	 6	 0.75	 0.75	 0.75
# I-AGE	 5	 7	 3	 0.41666666	 0.625	 0.5
# I-IDNUM	 6	 9	 3	 0.4	 0.6666667	 0.5
# B-DATE	 674	 53	 58	 0.9270977	 0.92076504	 0.9239205
# I-DATE	 80	 4	 10	 0.95238096	 0.8888889	 0.9195402
# I-LOCATION	 484	 207	 308	 0.70043415	 0.6111111	 0.65273094
# B-NAME	 901	 184	 150	 0.8304148	 0.85727876	 0.84363294
# B-AGE	 89	 24	 40	 0.7876106	 0.68992245	 0.7355371
# B-LOCATION	 1806	 287	 338	 0.86287624	 0.8423507	 0.85249
# B-IDNUM	 13	 15	 25	 0.4642857	 0.34210527	 0.3939394
# B-CONTACT	 33	 22	 18	 0.6	 0.64705884	 0.62264156
# tp: 4877 fp: 896 fn: 1096 labels: 12
# Macro-average	 prec: 0.71663076, rec: 0.72414714, f1: 0.72036934
# Micro-average	 prec: 0.84479475, rec: 0.81650764, f1: 0.8304104
#
#
# Epoch 28/30 started, lr: 8.810573E-4, dataset size: 11194
#
#
# Epoch 28/30 - 72.74s - loss: 552.04486 - avg training loss: 0.49466386 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 11.87s
# Total validation loss: 664.2622	Avg validation loss: 2.3145
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 791	 134	 114	 0.85513514	 0.87403315	 0.86448085
# I-CONTACT	 18	 3	 6	 0.85714287	 0.75	 0.79999995
# I-AGE	 4	 4	 4	 0.5	 0.5	 0.5
# I-IDNUM	 5	 8	 4	 0.3846154	 0.5555556	 0.45454547
# B-DATE	 655	 34	 77	 0.95065314	 0.89480877	 0.921886
# I-DATE	 80	 4	 10	 0.95238096	 0.8888889	 0.9195402
# I-LOCATION	 473	 159	 319	 0.74841774	 0.5972222	 0.66432583
# B-NAME	 907	 209	 144	 0.812724	 0.86298764	 0.837102
# B-AGE	 87	 23	 42	 0.7909091	 0.6744186	 0.7280335
# B-LOCATION	 1811	 283	 333	 0.86485195	 0.8446828	 0.85464835
# B-IDNUM	 11	 12	 27	 0.47826087	 0.28947368	 0.36065573
# B-CONTACT	 31	 21	 20	 0.59615386	 0.60784316	 0.60194176
# tp: 4873 fp: 894 fn: 1100 labels: 12
# Macro-average	 prec: 0.7326038, rec: 0.69499284, f1: 0.7133029
# Micro-average	 prec: 0.84498006, rec: 0.8158379, f1: 0.8301533
#
#
# Epoch 29/30 started, lr: 8.7719306E-4, dataset size: 11194
#
#
# Epoch 29/30 - 72.08s - loss: 520.0228 - avg training loss: 0.46597028 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 11.74s
# Total validation loss: 688.4561	Avg validation loss: 2.3988
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 801	 134	 104	 0.8566845	 0.8850829	 0.8706522
# I-CONTACT	 18	 4	 6	 0.8181818	 0.75	 0.78260875
# I-AGE	 5	 11	 3	 0.3125	 0.625	 0.41666666
# I-IDNUM	 0	 10	 9	 0.0	 0.0	 0.0
# B-DATE	 664	 38	 68	 0.94586897	 0.90710384	 0.92608094
# I-DATE	 84	 16	 6	 0.84	 0.93333334	 0.8842105
# I-LOCATION	 487	 195	 305	 0.7140762	 0.614899	 0.6607869
# B-NAME	 914	 206	 137	 0.81607145	 0.869648	 0.84200823
# B-AGE	 90	 28	 39	 0.7627119	 0.6976744	 0.728745
# B-LOCATION	 1835	 294	 309	 0.861907	 0.85587686	 0.85888135
# B-IDNUM	 8	 11	 30	 0.42105263	 0.21052632	 0.2807018
# B-CONTACT	 30	 20	 21	 0.6	 0.5882353	 0.59405947
# tp: 4936 fp: 967 fn: 1037 labels: 12
# Macro-average	 prec: 0.66242117, rec: 0.66144836, f1: 0.66193444
# Micro-average	 prec: 0.836185, rec: 0.8263854, f1: 0.8312563
#
#
# Epoch 30/30 started, lr: 8.733625E-4, dataset size: 11194
#
#
# Epoch 30/30 - 72.58s - loss: 488.6079 - avg training loss: 0.4378207 - batches: 1116
# Quality on validation dataset (20.0%), validation examples = 2238
# time to finish evaluation: 11.79s
# Total validation loss: 670.8219	Avg validation loss: 2.3374
# label	 tp	 fp	 fn	 prec	 rec	 f1
# I-NAME	 789	 122	 116	 0.86608124	 0.8718232	 0.86894274
# I-CONTACT	 18	 3	 6	 0.85714287	 0.75	 0.79999995
# I-AGE	 4	 8	 4	 0.33333334	 0.5	 0.4
# I-IDNUM	 4	 8	 5	 0.33333334	 0.44444445	 0.3809524
# B-DATE	 665	 36	 67	 0.9486448	 0.90847	 0.9281228
# I-DATE	 84	 13	 6	 0.8659794	 0.93333334	 0.8983958
# I-LOCATION	 493	 211	 299	 0.70028406	 0.62247473	 0.6590909
# B-NAME	 887	 162	 164	 0.8455672	 0.84395814	 0.8447619
# B-AGE	 95	 35	 34	 0.7307692	 0.7364341	 0.73359066
# B-LOCATION	 1801	 273	 343	 0.8683703	 0.84001863	 0.8539592
# B-IDNUM	 10	 10	 28	 0.5	 0.2631579	 0.3448276
# B-CONTACT	 27	 11	 24	 0.7105263	 0.5294118	 0.6067416
# tp: 4877 fp: 892 fn: 1096 labels: 12
# Macro-average	 prec: 0.713336, rec: 0.6869605, f1: 0.69989985
# Micro-average	 prec: 0.8453805, rec: 0.81650764, f1: 0.83069324

# %% [markdown]
# ## Evaluate the Newly Trained NER Model

# %%
pred_df = ner_model.stages[-1].transform(test_df).cache()

# %%
pred_df.show()
# Out:
# +------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |doc_id|                text|            document|            splitter|               token|          embeddings|           ner_label|                 ner|
# +------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |     X|" Brush Wellman h...|[{document, 0, 15...|[{document, 0, 15...|[{token, 0, 0, ",...|[{word_embeddings...|[{named_entity, 0...|[{named_entity, 0...|
# |     X|" It is almost im...|[{document, 0, 10...|[{document, 0, 10...|[{token, 0, 0, ",...|[{word_embeddings...|[{named_entity, 0...|[{named_entity, 0...|
# |     X|" It was an off-s...|[{document, 0, 10...|[{document, 0, 10...|[{token, 0, 0, ",...|[{word_embeddings...|[{named_entity, 0...|[{named_entity, 0...|
# |     X|" The two-day vis...|[{document, 0, 12...|[{document, 0, 12...|[{token, 0, 0, ",...|[{word_embeddings...|[{named_entity, 0...|[{named_entity, 0...|
# |     X|( Marseille ) , R...|[{document, 0, 63...|[{document, 0, 64...|[{token, 0, 0, (,...|[{word_embeddings...|[{named_entity, 0...|[{named_entity, 0...|
# |     X|- Barrington Rese...|[{document, 0, 13...|[{document, 0, 13...|[{token, 0, 0, -,...|[{word_embeddings...|[{named_entity, 0...|[{named_entity, 0...|
# |     X|-- Amsterdam news...|[{document, 0, 58...|[{document, 0, 59...|[{token, 0, 1, --...|[{word_embeddings...|[{named_entity, 0...|[{named_entity, 0...|
# |     X|-- Rosemary Benne...|[{document, 0, 53...|[{document, 0, 54...|[{token, 0, 1, --...|[{word_embeddings...|[{named_entity, 0...|[{named_entity, 0...|
# |     X|1860 Munich 3 1 0...|[{document, 0, 24...|[{document, 0, 25...|[{token, 0, 3, 18...|[{word_embeddings...|[{named_entity, 0...|[{named_entity, 0...|
# |     X|2 - Zhang Ning ( ...|[{document, 0, 62...|[{document, 0, 63...|[{token, 0, 0, 2,...|[{word_embeddings...|[{named_entity, 0...|[{named_entity, 0...|
# |     X|2. Samuel Matete ...|[{document, 0, 32...|[{document, 0, 33...|[{token, 0, 0, 2,...|[{word_embeddings...|[{named_entity, 0...|[{named_entity, 0...|
# |     X|3 arose on July 2...|[{document, 0, 12...|[{document, 0, 12...|[{token, 0, 0, 3,...|[{word_embeddings...|[{named_entity, 0...|[{named_entity, 0...|
# |     X|3. Michael Schuma...|[{document, 0, 49...|[{document, 0, 50...|[{token, 0, 0, 3,...|[{word_embeddings...|[{named_entity, 0...|[{named_entity, 0...|
# |     X|       4. Lacher 219|[{document, 0, 12...|[{document, 0, 13...|[{token, 0, 0, 4,...|[{word_embeddings...|[{named_entity, 0...|[{named_entity, 0...|
# |     X|8. Laurent Ottoz ...|[{document, 0, 31...|[{document, 0, 32...|[{token, 0, 0, 8,...|[{word_embeddings...|[{named_entity, 0...|[{named_entity, 0...|
# |     X|Ajax Amsterdam 1 ...|[{document, 0, 28...|[{document, 0, 29...|[{token, 0, 3, Aj...|[{word_embeddings...|[{named_entity, 0...|[{named_entity, 0...|
# |     X|Analysts hold Dut...|[{document, 0, 34...|[{document, 0, 35...|[{token, 0, 7, An...|[{word_embeddings...|[{named_entity, 0...|[{named_entity, 0...|
# |     X|  COLOMBO 1996-08-24|[{document, 0, 17...|[{document, 0, 18...|[{token, 0, 6, CO...|[{word_embeddings...|[{named_entity, 0...|[{named_entity, 0...|
# |     X|         DNEVNI AVAZ|[{document, 0, 10...|[{document, 0, 11...|[{token, 0, 5, DN...|[{word_embeddings...|[{named_entity, 0...|[{named_entity, 0...|
# |     X|        Division two|[{document, 0, 11...|[{document, 0, 12...|[{token, 0, 7, Di...|[{word_embeddings...|[{named_entity, 0...|[{named_entity, 0...|
# +------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
from pyspark.sql import functions as F

pred_token_df = pred_df.select(F.explode(F.arrays_zip(pred_df.ner_label.metadata,
                                                  pred_df.ner_label.begin,
                                                  pred_df.ner_label.end,
                                                  pred_df.ner_label.result,
                                                  pred_df.ner.result)).alias("cols")) \
          .select(F.expr("cols['0']['word']").alias("token"),
                  F.expr("cols['1']").alias("begin"),
                  F.expr("cols['2']").alias("end"),
                  F.expr("cols['3']").alias("gtruth"),
                  F.expr("cols['4']").alias("prediction"))\
          .toPandas()

pred_token_df
# Out:
#          token  begin  end  gtruth prediction
# 0            "      0    0       O          O
# 1        Brush      2    6  B-NAME          O
# 2      Wellman      8   14  I-NAME     I-NAME
# 3          has     16   18       O          O
# 4         been     20   23       O          O
# ...        ...    ...  ...     ...        ...
# 41244    games     42   46       O          O
# 41245   behind     48   53       O          O
# 41246    first     55   59       O          O
# 41247    place     61   65       O          O
# 41248        )     67   67       O          O
#
# [41249 rows x 5 columns]

# %% [markdown]
# ### Calculate Evaluation Metrics
# Use the NerDLMetrics class to compute precision, recall, and F1-score for each entity. The evaluation is shown with both `full_chunk` and `partial_chunk_per_token` modes.

# %%
evaler = medical.NerDLMetrics(mode="full_chunk")

eval_result = evaler.computeMetricsFromDF(pred_df.select("ner_label","ner"),
                                          prediction_col="ner",
                                          label_col="ner_label",
                                          drop_o = True, case_sensitive = True).cache()

eval_result.withColumn("precision", F.round(eval_result["precision"],4))\
           .withColumn("recall", F.round(eval_result["recall"],4))\
           .withColumn("f1", F.round(eval_result["f1"],4)).show(100)

print(eval_result.selectExpr("avg(f1) as macro").show())
print (eval_result.selectExpr("sum(f1*total) as sumprod","sum(total) as sumtotal").selectExpr("sumprod/sumtotal as micro").show())
# Out:
# +--------+------+-----+-----+------+---------+------+------+
# |  entity|    tp|   fp|   fn| total|precision|recall|    f1|
# +--------+------+-----+-----+------+---------+------+------+
# | CONTACT|  68.0|  7.0| 17.0|  85.0|   0.9067|   0.8|  0.85|
# |    NAME|1192.0|109.0|107.0|1299.0|   0.9162|0.9176|0.9169|
# |    DATE| 815.0| 25.0| 31.0| 846.0|   0.9702|0.9634|0.9668|
# |   IDNUM|  24.0| 11.0| 17.0|  41.0|   0.6857|0.5854|0.6316|
# |LOCATION|2452.0|181.0|212.0|2664.0|   0.9313|0.9204|0.9258|
# |     AGE| 142.0| 22.0| 15.0| 157.0|   0.8659|0.9045|0.8847|
# +--------+------+-----+-----+------+---------+------+------+
#
# +-----------------+
# |            macro|
# +-----------------+
# |0.862638263002126|
# +-----------------+
#
# None
# +-----------------+
# |            micro|
# +-----------------+
# |0.925448076564739|
# +-----------------+
#
# None

# %%
evaler = medical.NerDLMetrics(mode="partial_chunk_per_token")
eval_result_partial = evaler.computeMetricsFromDF(pred_df.select("ner_label","ner"), prediction_col="ner", label_col="ner_label", drop_o = True, case_sensitive = True).cache()

eval_result_partial.withColumn("precision", F.round(eval_result_partial["precision"],4))\
           .withColumn("recall", F.round(eval_result_partial["recall"],4))\
           .withColumn("f1", F.round(eval_result_partial["f1"],4)).sort("entity").show(100)
df_partial=eval_result_partial.toPandas()
print("partial_chunk_per_token")
print(eval_result_partial.selectExpr("avg(f1) as macro").show())
print (eval_result_partial.selectExpr("sum(f1*total) as sumprod","sum(total) as sumtotal").selectExpr("sumprod/sumtotal as micro").show())
# Out:
# +--------+------+-----+-----+------+---------+------+------+
# |  entity|    tp|   fp|   fn| total|precision|recall|    f1|
# +--------+------+-----+-----+------+---------+------+------+
# |     AGE| 150.0| 25.0| 17.0| 167.0|   0.8571|0.8982|0.8772|
# | CONTACT| 113.0|  6.0| 21.0| 134.0|   0.9496|0.8433|0.8933|
# |    DATE| 965.0| 22.0| 30.0| 995.0|   0.9777|0.9698|0.9738|
# |   IDNUM|  31.0| 17.0| 20.0|  51.0|   0.6458|0.6078|0.6263|
# |LOCATION|3466.0|221.0|252.0|3718.0|   0.9401|0.9322|0.9361|
# |    NAME|2247.0|138.0|108.0|2355.0|   0.9421|0.9541|0.9481|
# +--------+------+-----+-----+------+---------+------+------+
#
# partial_chunk_per_token
# +------------------+
# |             macro|
# +------------------+
# |0.8757876037007678|
# +------------------+
#
# None
# +------------------+
# |             micro|
# +------------------+
# |0.9407430847696318|
# +------------------+
#
# None

# %% [markdown]
# ## Create the Final Pipeline with the Custom NER Model

# %%
# We are loading the pretrained pipeline using the `from_disk` method.

modified_pipeline = nlp.PretrainedPipeline.from_disk('modified_pipeline')

# %%
modified_pipeline.model.stages
# Out:
# [DocumentAssembler_ae0f203deedd,
#  InternalDocumentSplitter_cc36578ceda6,
#  REGEX_TOKENIZER_2e85686aea12,
#  WORD_EMBEDDINGS_MODEL_9004b1d00302,
#  MedicalNerModel_1a8637089929,
#  NER_CONVERTER_1aef7e9d2de5,
#  MedicalNerModel_d92d47622e85,
#  MedicalNerModel_32184c1db80b,
#  MedicalNerModel_ada39ac0d359,
#  NER_CONVERTER_a99db4e6a79d,
#  NER_CONVERTER_4a9436714344,
#  NER_CONVERTER_ea6433988e18,
#  PretrainedZeroShotNER_5f30ab9002f1,
#  NER_CONVERTER_c97040caf7b3,
#  MedicalNerModel_b8b167ec3114,
#  NER_CONVERTER_06db473f3215,
#  ContextualEntityRuler_11ff6711ef6b,
#  ChunkMergeModel_95d6827691bb,
#  CONTEXTUAL-PARSER_bf2a6abaf5fa,
#  CONTEXTUAL-PARSER_ff6bad379d91,
#  CONTEXTUAL-PARSER_89341cae7221,
#  CONTEXTUAL-PARSER_c6b9eded8d31,
#  CONTEXTUAL-PARSER_9480c24bd9f8,
#  CONTEXTUAL-PARSER_3886bce391c8,
#  CONTEXTUAL-PARSER_0bb3fb75cd01,
#  ENTITY_EXTRACTOR_6792f2f6e85a,
#  ENTITY_EXTRACTOR_74ace4be4f73,
#  CONTEXTUAL-PARSER_dfb32adc7555,
#  REGEX_MATCHER_5003669d6422,
#  CONTEXTUAL-PARSER_746a25662aa6,
#  CONTEXTUAL-PARSER_079220479a3d,
#  CONTEXTUAL-PARSER_f8b8f9aafb9f,
#  CONTEXTUAL-PARSER_7f824493eafc,
#  REGEX_MATCHER_26934077fe57,
#  REGEX_MATCHER_5fe3de8b5a4e,
#  CONTEXTUAL-PARSER_9f6e020bef49,
#  CONTEXTUAL-PARSER_f1b97eba775b,
#  MERGE_ddff59e8b14a,
#  ChunkMergeModel_50feb5f97568,
#  ContextualEntityRuler_08eeaa89c938,
#  ChunkMergeModel_5a3f1e608447,
#  LightDeIdentification_dd156106d887,
#  LightDeIdentification_acfc9a325ba4,
#  IOBTagger_e79d09a5ca5d]

# %% [markdown]
# ### New Stages

# %%
ner_deid_new = medical.NerModel.load("models/new_NER_model")\
    .setInputCols(["splitter", "token", "embeddings"])\
    .setOutputCol("ner_deid_new")

ner_deid_new_converter = nlp.NerConverter()\
      .setInputCols(["splitter", "token", "ner_deid_new"])\
      .setOutputCol("ner_chunk_new")

ner_deid = medical.NerModel.pretrained("ner_deid_subentity_docwise", "en", "clinical/models")  \
      .setInputCols(["splitter", "token", "embeddings"]) \
      .setOutputCol("ner_deid_subentity_docwise")

ner_deid_converter = nlp.NerConverter()\
      .setInputCols(["splitter", "token", "ner_deid_subentity_docwise"])\
      .setOutputCol("ner_chunk_subentity_docwise")

chunk_merge_ner = medical.ChunkMergeModel()\
    .setInputCols("ner_chunk_new", # New Trained Model
                  "ner_chunk_subentity_docwise")\
    .setOutputCol("deid_merged_ner_chunk")\
    .setOrderingFeatures(["ChunkLength","ChunkBegin"])\
    .setMergeOverlapping(True)\
    .setResetSentenceIndices(True)
# Out:
# ner_deid_subentity_docwise download started this may take some time.
# Approximate size to download 8.9 MB
# [OK!]

# %% [markdown]
# ### **Update Stages**

# %%
modified_pipeline.model.stages = (
    modified_pipeline.model.stages[:4]
    + [ner_deid_new,
       ner_deid_new_converter,
       ner_deid,
       ner_deid_converter,
       chunk_merge_ner]
    + modified_pipeline.model.stages[18:]

)

# %%
modified_pipeline.model.stages
# Out:
# [DocumentAssembler_ae0f203deedd,
#  InternalDocumentSplitter_cc36578ceda6,
#  REGEX_TOKENIZER_2e85686aea12,
#  WORD_EMBEDDINGS_MODEL_9004b1d00302,
#  MedicalNerModel_1a8637089929,
#  NER_CONVERTER_1aef7e9d2de5,
#  MedicalNerModel_d92d47622e85,
#  MedicalNerModel_32184c1db80b,
#  MedicalNerModel_ada39ac0d359,
#  NER_CONVERTER_a99db4e6a79d,
#  NER_CONVERTER_4a9436714344,
#  NER_CONVERTER_ea6433988e18,
#  PretrainedZeroShotNER_5f30ab9002f1,
#  NER_CONVERTER_c97040caf7b3,
#  MedicalNerModel_b8b167ec3114,
#  NER_CONVERTER_06db473f3215,
#  ContextualEntityRuler_11ff6711ef6b,
#  ChunkMergeModel_95d6827691bb,
#  CONTEXTUAL-PARSER_bf2a6abaf5fa,
#  CONTEXTUAL-PARSER_ff6bad379d91,
#  CONTEXTUAL-PARSER_89341cae7221,
#  CONTEXTUAL-PARSER_c6b9eded8d31,
#  CONTEXTUAL-PARSER_9480c24bd9f8,
#  CONTEXTUAL-PARSER_3886bce391c8,
#  CONTEXTUAL-PARSER_0bb3fb75cd01,
#  ENTITY_EXTRACTOR_6792f2f6e85a,
#  ENTITY_EXTRACTOR_74ace4be4f73,
#  CONTEXTUAL-PARSER_dfb32adc7555,
#  REGEX_MATCHER_5003669d6422,
#  CONTEXTUAL-PARSER_746a25662aa6,
#  CONTEXTUAL-PARSER_079220479a3d,
#  CONTEXTUAL-PARSER_f8b8f9aafb9f,
#  CONTEXTUAL-PARSER_7f824493eafc,
#  REGEX_MATCHER_26934077fe57,
#  REGEX_MATCHER_5fe3de8b5a4e,
#  CONTEXTUAL-PARSER_9f6e020bef49,
#  CONTEXTUAL-PARSER_f1b97eba775b,
#  MERGE_ddff59e8b14a,
#  ChunkMergeModel_50feb5f97568,
#  ContextualEntityRuler_08eeaa89c938,
#  ChunkMergeModel_5a3f1e608447,
#  LightDeIdentification_dd156106d887,
#  LightDeIdentification_acfc9a325ba4,
#  IOBTagger_e79d09a5ca5d]

# %% [markdown]
# ### Reassemble and Save the Final
#
# Rebuild the pipeline's stages, replacing the original NER components with our new custom NER model and the reconfigured merger. The final pipeline is then saved.

# %%
empty_result = modified_pipeline.transform(spark.createDataFrame([[""]]).toDF("text"))

modified_pipeline.model.write().overwrite().save("new_pipeline")

# %%
new_pipeline = nlp.PretrainedPipeline.from_disk('new_pipeline')

# %% [markdown]
# ## Final Test of the New Pipeline

# %%
samples_df = spark.createDataFrame([[text]]).toDF("text")

result = new_pipeline.transform(samples_df).cache()

# %%
result.select(F.explode(F.arrays_zip(result.ner_chunk.result,
                                     result.ner_chunk.begin,
                                     result.ner_chunk.end,
                                     result.ner_chunk.metadata)).alias("cols")) \
      .select(F.expr("cols['0']").alias("chunk"),
              F.expr("cols['1']").alias("begin"),
              F.expr("cols['2']").alias("end"),
              F.expr("cols['3']['entity']").alias("ner_label"),
              F.expr("cols['3']['confidence']").alias("confidence")).show(50,truncate=False)
# Out:
# +----------------------------------+-----+----+---------+----------+
# |chunk                             |begin|end |ner_label|confidence|
# +----------------------------------+-----+----+---------+----------+
# |John Lee                          |7    |14  |NAME     |0.9999188 |
# |7789201                           |45   |51  |IDNUM    |0.71      |
# |1973                              |80   |83  |DATE     |0.99705976|
# |52                                |87   |88  |AGE      |0.99993765|
# |GH-556672                         |110  |118 |IDNUM    |0.86922663|
# |XXX-XX-1234                       |139  |149 |IDNUM    |0.85107106|
# |123 Main Street                   |160  |174 |LOCATION |0.9999253 |
# |FALL RIVER                        |177  |186 |LOCATION |0.9986915 |
# |NIAGARA FALLS                     |189  |201 |LOCATION |0.9978828 |
# |NY                                |204  |205 |LOCATION |0.9999924 |
# |14304                             |207  |211 |LOCATION |0.73      |
# |RD23-4897                         |225  |233 |IDNUM    |0.50      |
# |032-1902                          |331  |338 |IDNUM    |0.87777317|
# |2025-05-10                        |356  |365 |DATE     |null      |
# |2025-05-10                        |382  |391 |DATE     |null      |
# |Jameson                           |419  |425 |NAME     |0.9986112 |
# |General Hospital                  |447  |462 |LOCATION |0.9987417 |
# |New York                          |465  |472 |LOCATION |null      |
# |NY                                |480  |481 |LOCATION |0.99999106|
# |Barstow Heights Christus Southeast|801  |834 |LOCATION |0.9990096 |
# |NY                                |837  |838 |LOCATION |0.99993145|
# |St Elizabeth                      |842  |853 |LOCATION |0.9997955 |
# |New York                          |856  |863 |LOCATION |null      |
# |2025-05-12                        |996  |1005|DATE     |null      |
# |Smith                             |1048 |1052|NAME     |0.9999714 |
# |Carter                            |1058 |1063|NAME     |0.9998995 |
# +----------------------------------+-----+----+---------+----------+

# %%
pd.set_option("display.max_colwidth", 1000)
result_df = result.selectExpr("text","mask_entity.result as masked_result","obfuscated.result as obfuscated_result").toPandas()
result_df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       text  \
# 0  \nName: John Lee\nMedical Record Number (MRN): 7789201\nDate of Birth / Age / Sex: 1973 / 52 / Male\nAccession #: GH-556672\nSocial Security #: XXX-XX-1234\nAddress: 123 Main Street, FALL RIVER, NIAGARA FALLS, NY 14304\nSpecimen #: RD23-4897\nMaterial Received: Gastric, Ileum, and Random Colon Biopsies\nMaterial Details: 6 slides labeled 032-1902\nDate Collected: 2025-05-10\nDate Received: 2025-05-10\nRequesting Physician: Dr. Jameson\nReferring Facility: General Hospital, New York City, NY\nClinical History: None Given.\nClinical Note: Peripheral sequestration, i.e., splenomegaly or hepatomegaly, should be excluded to be sure if peripheral sequestration is not present.\nCPT Code(s): 88305\nGastric, ileum, and random colon, biopsies:\nNo evidence of dysplasia.\nThe following special studies were performed at Barstow Heights Christus Southeast, NY – St Elizabeth; New York City.\nChromosome Analysis (Cytogenetics): (Addendum report to follow.)\nLeukemic Immunophenotyping (Flow Cytome...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              masked_result  \
# 0  [\nName: <NAME>\nMedical Record Number (MRN): <IDNUM>\nDate of Birth / Age / Sex: <DATE> / <AGE> / Male\nAccession #: <IDNUM>\nSocial Security #: <IDNUM>\nAddress: <LOCATION>, <LOCATION>, <LOCATION>, <LOCATION> <LOCATION>\nSpecimen #: <IDNUM>\nMaterial Received: Gastric, Ileum, and Random Colon Biopsies\nMaterial Details: 6 slides labeled <IDNUM>\nDate Collected: <DATE>\nDate Received: <DATE>\nRequesting Physician: Dr. <NAME>\nReferring Facility: <LOCATION>, <LOCATION> City, <LOCATION>\nClinical History: None Given.\nClinical Note: Peripheral sequestration, i.e., splenomegaly or hepatomegaly, should be excluded to be sure if peripheral sequestration is not present.\nCPT Code(s): 88305\nGastric, ileum, and random colon, biopsies:\nNo evidence of dysplasia.\nThe following special studies were performed at <LOCATION>, <LOCATION> – <LOCATION>; <LOCATION> City.\nChromosome Analysis (Cytogenetics): (Addendum report to follow.)\nLeukemic Immunophenotyping (Flow Cytometry):\nDate Reported:...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          obfuscated_result
# 0  [\nName: Gillie Allan\nMedical Record Number (MRN): 0074518\nDate of Birth / Age / Sex: 1974 / 44 / Male\nAccession #: PU-663305\nSocial Security #: WWW-WW-8529\nAddress: 3255 Independence Street, 302 W MCNEESE ST, 4101 NW 89TH BLVD, 16100 SOUTH FREEWAY 59 KOCH AVE\nSpecimen #: SA52-9740\nMaterial Received: Gastric, Ileum, and Random Colon Biopsies\nMaterial Details: 6 slides labeled 125-8415\nDate Collected: 2025-06-27\nDate Received: 2025-06-27\nRequesting Physician: Dr. Marchelle\nReferring Facility: 310 Ellis Street, 2000 Boise Ave City, 16100 SOUTH FREEWAY\nClinical History: None Given.\nClinical Note: Peripheral sequestration, i.e., splenomegaly or hepatomegaly, should be excluded to be sure if peripheral sequestration is not present.\nCPT Code(s): 88305\nGastric, ileum, and random colon, biopsies:\nNo evidence of dysplasia.\nThe following special studies were performed at 103 North Street, 16100 SOUTH FREEWAY – 969 Lakeland Drive; 2000 Boise Ave City.\nChromosome Analysis (C...
