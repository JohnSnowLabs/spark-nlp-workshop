# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/spark-nlp-workshop/blob/master/healthcare-nlp/04.1.Clinical_Multi_Language_Deidentification.ipynb)

# %% [markdown]
# # Clinical Deidentification Multi Language

# %% [markdown]
# ## Colab Setup

# %%
# Install the johnsnowlabs library to access Spark-OCR and Spark-NLP for Healthcare, Finance, and Legal.
! pip install -q johnsnowlabs

# %%
from google.colab import files
print('Please Upload your John Snow Labs License using the button below')
license_keys = files.upload()

# %%
from johnsnowlabs import nlp, medical

# After uploading your license run this to install all licensed Python Wheels and pre-download Jars the Spark Session JVM
nlp.settings.enforce_versions=True
nlp.install(refresh_install=True)

# %%
from johnsnowlabs import nlp, medical
import warnings
warnings.filterwarnings('ignore')

# Automatically load license data and start a session with all jars user has access to
spark = nlp.start()
spark
# Out:
# 👌 Detected license file /content/spark_nlp_for_healthcare_spark_ocr_10445.json
# 👌 Launched cpu optimized session with with: 🚀Spark-NLP==6.1.3, 💊Spark-Healthcare==6.1.1, running on ⚡ PySpark==3.4.0
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://34fd1f126d02:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>John-Snow-Labs-Spark-Session 🚀 with Jars for: 🚀Spark-NLP==6.1.3, 💊Spark-Healthcare==6.1.1, running on ⚡ PySpark==3.4.0</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import pyspark.sql as SQL
import pyspark.sql.types as T
import pyspark.sql.functions as F
from pyspark import keyword_only
from pyspark.sql import DataFrame
import pandas as pd

# %% [markdown]
# ## Healthcare NLP for Data Scientists Course
#
# If you are not familiar with the components in this notebook, you can check [Healthcare NLP for Data Scientists Udemy Course](https://www.udemy.com/course/healthcare-nlp-for-data-scientists/) and the [MOOC Notebooks](https://github.com/JohnSnowLabs/spark-nlp-workshop/tree/master/Spark_NLP_Udemy_MOOC/Healthcare_NLP) for each components.

# %% [markdown]
# # Deidentification Models in Different Languages

# %% [markdown]
# <center><b>Deidentification NER Models for Other Languages</b>
#
# |index|model|lang|index|model|lang|
# |-----:|:-----|----|-----:|:-----|----|
# | 1| [ner_deid_generic](https://nlp.johnsnowlabs.com/2022/01/06/ner_deid_generic_de.html)  |de| 14| [ner_deid_generic](https://nlp.johnsnowlabs.com/2022/02/11/ner_deid_generic_fr.html)  |fr|
# | 2| [ner_deid_subentity](https://nlp.johnsnowlabs.com/2022/01/06/ner_deid_subentity_de.html)  |de| 15| [ner_deid_subentity](https://nlp.johnsnowlabs.com/2022/02/14/ner_deid_subentity_fr.html)  |fr|
# | 3| [ner_deid_generic](https://nlp.johnsnowlabs.com/2022/01/18/ner_deid_generic_es.html)  |es| 16| [ner_deid_generic](https://nlp.johnsnowlabs.com/2022/03/25/ner_deid_generic_it_3_0.html)  |it|
# | 4| [ner_deid_generic_augmented](https://nlp.johnsnowlabs.com/2022/02/16/ner_deid_generic_augmented_es.html)  |es| 17| [ner_deid_subentity](https://nlp.johnsnowlabs.com/2022/03/25/ner_deid_subentity_it_2_4.html)  |it|
# | 5| [ner_deid_generic_roberta](https://nlp.johnsnowlabs.com/2022/01/17/ner_deid_generic_roberta_es.html)  |es| 18| [ner_deid_generic](https://nlp.johnsnowlabs.com/2022/04/13/ner_deid_generic_pt_3_0.html)  |pt|
# | 6| [ner_deid_generic_roberta_augmented](https://nlp.johnsnowlabs.com/2022/02/16/ner_deid_generic_roberta_augmented_es.html)  |es| 19| [ner_deid_subentity](https://nlp.johnsnowlabs.com/2022/04/13/ner_deid_subentity_pt_3_0.html)  |pt|
# | 7| [ner_deid_subentity](https://nlp.johnsnowlabs.com/2022/01/18/ner_deid_subentity_es.html)  |es| 20| [ner_deid_subentity](https://nlp.johnsnowlabs.com/2022/06/27/ner_deid_subentity_ro_3_0.html)  |ro|
# | 8| [ner_deid_subentity_augmented](https://nlp.johnsnowlabs.com/2022/02/16/ner_deid_subentity_augmented_es.html)  |es| 21| [ner_deid_subentity_bert](https://nlp.johnsnowlabs.com/2022/06/27/ner_deid_subentity_bert_ro_3_0.html)  |ro|
# | 9| [ner_deid_subentity_roberta](https://nlp.johnsnowlabs.com/2022/01/17/ner_deid_subentity_roberta_es.html)  |es| 22| [ner_deid_generic](https://nlp.johnsnowlabs.com/models)  |ro|
# | 10| [ner_deid_subentity_roberta_augmented](https://nlp.johnsnowlabs.com/2022/02/16/ner_deid_subentity_roberta_augmented_es.html)  |es| 23| [ner_deid_generic_bert](https://nlp.johnsnowlabs.com/models)  |ro|
# | 11| [ner_deid_subentity](https://nlp.johnsnowlabs.com/2023/05/31/ner_deid_subentity_ar.html)  |ar| 24| [ner_deid_generic](https://nlp.johnsnowlabs.com/2023/05/30/ner_deid_generic_ar.html)  |ar|
#  12|[ner_deid_subentity_arabert](https://nlp.johnsnowlabs.com/2023/09/16/ner_deid_subentity_arabert_ar.html)   |ar| 25|[ner_deid_generic_arabert](https://nlp.johnsnowlabs.com/2023/09/16/ner_deid_generic_arabert_ar.html)   |ar|
#  13| [ner_deid_subentity_camelbert](https://nlp.johnsnowlabs.com/2023/09/22/ner_deid_subentity_camelbert_ar.html) |ar| 26| [ner_deid_generic_camelbert](https://nlp.johnsnowlabs.com/2023/09/16/ner_deid_generic_camelbert_ar.html) |ar|

# %% [markdown]
# # DE-IDENTIFICATION FOR GERMAN

# %% [markdown]
# ## German Deidentification NER Models

# %% [markdown]
# |index|model|lang|index|model|lang|
# |-----:|:-----|----|-----:|:-----|----|
# | 1| [ner_deid_generic](https://nlp.johnsnowlabs.com/2022/01/06/ner_deid_generic_de.html)  |de| 2| [ner_deid_subentity](https://nlp.johnsnowlabs.com/2022/01/06/ner_deid_subentity_de.html)  |de|

# %% [markdown]
# Creating pipeline

# %%
# Annotator that transforms a text column from dataframe into an Annotation ready for NLP
documentAssembler = nlp.DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")

sentencerDL = nlp.SentenceDetectorDLModel.pretrained("sentence_detector_dl", "xx") \
    .setInputCols(["document"])\
    .setOutputCol("sentence")

# Tokenizer splits words in a relevant format for NLP
tokenizer = nlp.Tokenizer()\
    .setInputCols(["sentence"])\
    .setOutputCol("token")

word_embeddings_de = nlp.WordEmbeddingsModel.pretrained("w2v_cc_300d","de","clinical/models")\
    .setInputCols(["document","token"])\
	  .setOutputCol("embeddings")
# Out:
# sentence_detector_dl download started this may take some time.
# Approximate size to download 514.9 KB
# [OK!]
# w2v_cc_300d download started this may take some time.
# Approximate size to download 1.2 GB
# [OK!]

# %% [markdown]
# ### NER Deid Generic
#
# **`ner_deid_generic`** extracts:
# - Name
# - Profession
# - Age
# - Date
# - Contact (Telephone numbers, FAX numbers, Email addresses)
# - Location (Address, City, Postal code, Hospital Name, Employment information)
# - Id (Social Security numbers, Medical record numbers, Internet protocol addresses)

# %%
ner_generic_de = medical.NerModel.pretrained("ner_deid_generic", "de", "clinical/models")\
    .setInputCols(["sentence","token","embeddings"])\
    .setOutputCol("ner_deid_generic")

ner_converter_generic = medical.NerConverterInternal()\
    .setInputCols(["sentence","token","ner_deid_generic"])\
    .setOutputCol("ner_chunk_generic")
# Out:
# ner_deid_generic download started this may take some time.
# Approximate size to download 14.3 MB
# [OK!]

# %%
ner_generic_de.getClasses()
# Out:
# ['O',
#  'I-LOCATION',
#  'B-DATE',
#  'I-NAME',
#  'B-LOCATION',
#  'I-DATE',
#  'B-ID',
#  'B-AGE',
#  'B-CONTACT',
#  'B-PROFESSION',
#  'B-NAME']

# %% [markdown]
# ### NER Deid Subentity
#
# **`ner_deid_subentity`** extracts:
#
# - Patient
# - Doctor
# - Hospital
# - Date
# - Organization
# - City
# - Street
# - User Name
# - Profession
# - Phone
# - Country
# - Age

# %%
ner_subentity_de = medical.NerModel.pretrained("ner_deid_subentity", "de", "clinical/models")\
    .setInputCols(["sentence","token","embeddings"])\
    .setOutputCol("ner_deid_subentity")

ner_converter_subentity = medical.NerConverterInternal()\
    .setInputCols(["sentence", "token", "ner_deid_subentity"])\
    .setOutputCol("ner_chunk_subentity")
# Out:
# ner_deid_subentity download started this may take some time.
# Approximate size to download 14.3 MB
# [OK!]

# %%
ner_subentity_de.getClasses()
# Out:
# ['O',
#  'B-ORGANIZATION',
#  'I-DOCTOR',
#  'B-DOCTOR',
#  'B-USERNAME',
#  'I-CITY',
#  'I-DATE',
#  'B-COUNTRY',
#  'B-PROFESSION',
#  'I-STREET',
#  'I-PATIENT',
#  'B-PHONE',
#  'B-CITY',
#  'B-HOSPITAL',
#  'B-DATE',
#  'B-STREET',
#  'B-PATIENT',
#  'I-ORGANIZATION',
#  'I-HOSPITAL',
#  'B-AGE',
#  'I-COUNTRY']

# %% [markdown]
# ### Pipeline

# %%
nlpPipeline_de = nlp.Pipeline(
    stages=[
        documentAssembler,
        sentencerDL,
        tokenizer,
        word_embeddings_de,
        ner_generic_de,
        ner_converter_generic,
        ner_subentity_de,
        ner_converter_subentity,
])

empty_data = spark.createDataFrame([[""]]).toDF("text")
model_de = nlpPipeline_de.fit(empty_data)

# %%
text_de = """Michael Berger wird am Morgen des 12 Dezember 2018 ins St. Elisabeth-Krankenhaus in Bad Kissingen eingeliefert. Herr Berger ist 76 Jahre alt und hat zu viel Wasser in den Beinen."""

text_df_de = spark.createDataFrame([[text_de]]).toDF("text")
result_de = model_de.transform(text_df_de)

# %% [markdown]
# Results for `ner_deid_subentity`

# %%
result_de.select(F.explode(F.arrays_zip(result_de.ner_chunk_subentity.result,
                                        result_de.ner_chunk_subentity.metadata)).alias("cols")) \
         .select(F.expr("cols['0']").alias("chunk"),
                 F.expr("cols['1']['entity']").alias("ner_label")).show(truncate=False)
# Out:
# +--------------------------------------+---------+
# |chunk                                 |ner_label|
# +--------------------------------------+---------+
# |Michael Berger                        |PATIENT  |
# |12 Dezember 2018                      |DATE     |
# |Elisabeth-Krankenhaus in Bad Kissingen|HOSPITAL |
# |Berger                                |PATIENT  |
# |76                                    |AGE      |
# +--------------------------------------+---------+

# %% [markdown]
# Results for `ner_deid_generic`

# %%
result_de.select(F.explode(F.arrays_zip(result_de.ner_chunk_generic.result,
                                        result_de.ner_chunk_generic.metadata)).alias("cols")) \
         .select(F.expr("cols['0']").alias("chunk"),
                 F.expr("cols['1']['entity']").alias("ner_label")).show(truncate=False)
# Out:
# +-------------------------+---------+
# |chunk                    |ner_label|
# +-------------------------+---------+
# |Michael Berger           |NAME     |
# |12 Dezember 2018         |DATE     |
# |St. Elisabeth-Krankenhaus|LOCATION |
# |Bad Kissingen            |LOCATION |
# |Berger                   |NAME     |
# |76                       |AGE      |
# +-------------------------+---------+

# %% [markdown]
# ## DeIdentification

# %% [markdown]
# ### Obfuscation mode

# %%
# Downloading custom faker entity list.
! wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/obfuscate.txt

# %%
deid_masked_entity = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"])\
    .setOutputCol("masked_with_entity")\
    .setMode("mask")\
    .setMaskingPolicy("entity_labels")\

deid_masked_char = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"])\
    .setOutputCol("masked_with_chars")\
    .setMode("mask")\
    .setMaskingPolicy("same_length_chars")\

deid_masked_fixed_char = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"])\
    .setOutputCol("masked_fixed_length_chars")\
    .setMode("mask")\
    .setMaskingPolicy("fixed_length_chars")\
    .setFixedMaskLength(4)\

deid_obfuscated = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"]) \
    .setOutputCol("obfuscated") \
    .setMode("obfuscate")\
    .setObfuscateDate(True)\
    .setObfuscateRefFile('obfuscate.txt')\
    .setObfuscateRefSource("file")

# %%
nlpPipeline_de = nlp.Pipeline(
    stages=[
        documentAssembler,
        sentencerDL,
        tokenizer,
        word_embeddings_de,
        ner_subentity_de,
        ner_converter_subentity,
        deid_masked_entity,
        deid_masked_char,
        deid_masked_fixed_char,
        deid_obfuscated
])

empty_data = spark.createDataFrame([[""]]).toDF("text")
model_de = nlpPipeline_de.fit(empty_data)

# %%
deid_lp_de = nlp.LightPipeline(model_de)

# %%
text = """Michael Berger wird am Morgen des 12 Dezember 2018 ins St. Elisabeth-Krankenhaus in Bad Kissingen eingeliefert. Herr Berger ist 76 Jahre alt und hat zu viel Wasser in den Beinen."""

# %%
import pandas as pd
pd.set_option("display.max_colwidth", 100)

result_lp_de = deid_lp_de.annotate(text)

df_de = pd.DataFrame(list(zip(result_lp_de["masked_with_entity"],
                              result_lp_de["masked_with_chars"],
                              result_lp_de["masked_fixed_length_chars"],
                              result_lp_de["obfuscated"])),
                 columns= ["Masked", "Masked with Chars", "Masked with Fixed Chars", "Obfuscated"])

df_de
# Out:
#                                                                      Masked  \
# 0      <PATIENT> wird am Morgen des <DATE> ins St. <HOSPITAL> eingeliefert.
# 1  Herr <PATIENT> ist <AGE> Jahre alt und hat zu viel Wasser in den Beinen.
#
#                                                                                      Masked with Chars  \
# 0  [************] wird am Morgen des [**************] ins St. [************************************...
# 1                                   Herr [****] ist ** Jahre alt und hat zu viel Wasser in den Beinen.
#
#                                               Masked with Fixed Chars  \
# 0             **** wird am Morgen des **** ins St. **** eingeliefert.
# 1  Herr **** ist **** Jahre alt und hat zu viel Wasser in den Beinen.
#
#                                                                                             Obfuscated
# 0  Gotthold Christoph wird am Morgen des 04 Dezember 2018 ins St. Vivantes Humboldt-klinikum Berlin...
# 1                                     Herr Drub ist 66 Jahre alt und hat zu viel Wasser in den Beinen.

# %% [markdown]
# ### Faker mode

# %%
deid_obfuscated_faker = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"]) \
    .setOutputCol("obfuscated") \
    .setMode("obfuscate")\
    .setLanguage('de')\
    .setObfuscateDate(True)\
    .setObfuscateRefSource('faker')

# %%
nlpPipeline_de = nlp.Pipeline(
    stages=[
        documentAssembler,
        sentencerDL,
        tokenizer,
        word_embeddings_de,
        ner_subentity_de,
        ner_converter_subentity,
        deid_masked_entity,
        deid_masked_char,
        deid_masked_fixed_char,
        deid_obfuscated_faker
])

empty_data = spark.createDataFrame([[""]]).toDF("text")
model_de = nlpPipeline_de.fit(empty_data)

# %%
deid_lp_de = nlp.LightPipeline(model_de)

# %%
text = """Michael Berger wird am Morgen des 12 Dezember 2018 ins St. Elisabeth-Krankenhaus in Bad Kissingen eingeliefert. Herr Berger ist 76 Jahre alt und hat zu viel Wasser in den Beinen."""

# %%
pd.set_option("display.max_colwidth", 100)

result_de = deid_lp_de.annotate(text)

df_de = pd.DataFrame(list(zip(result_de["masked_with_entity"],
                              result_de["masked_with_chars"],
                              result_de["masked_fixed_length_chars"],
                              result_de["obfuscated"])),
                 columns= ["Masked", "Masked with Chars", "Masked with Fixed Chars", "Obfuscated"])

df_de
# Out:
#                                                                      Masked  \
# 0      <PATIENT> wird am Morgen des <DATE> ins St. <HOSPITAL> eingeliefert.
# 1  Herr <PATIENT> ist <AGE> Jahre alt und hat zu viel Wasser in den Beinen.
#
#                                                                                      Masked with Chars  \
# 0  [************] wird am Morgen des [**************] ins St. [************************************...
# 1                                   Herr [****] ist ** Jahre alt und hat zu viel Wasser in den Beinen.
#
#                                               Masked with Fixed Chars  \
# 0             **** wird am Morgen des **** ins St. **** eingeliefert.
# 1  Herr **** ist **** Jahre alt und hat zu viel Wasser in den Beinen.
#
#                                                                                         Obfuscated
# 0  Weller Finger wird am Morgen des 15 Dezember 2018 ins St. St. Raphael Krankenhaus eingeliefert.
# 1                               Herr Finger ist 79 Jahre alt und hat zu viel Wasser in den Beinen.

# %% [markdown]
# ## Pretrained German Deidentification Pipeline
#
# - We developed a clinical deidentification pretrained pipeline that can be used to deidentify PHI information from German medical texts. The PHI information will be masked and obfuscated in the resulting text.
# - The pipeline can mask and obfuscate:
#     - Patient
#     - Doctor
#     - Hospital
#     - Date
#     - Organization
#     - City
#     - Street
#     - Country
#     - User name
#     - Profession
#     - Phone
#     - Age
#     - Contact
#     - ID
#     - Phone
#     - Zip
#     - Account
#     - SSN
#     - Driver's License Number
#     - Plate Number

# %%
deid_pipeline_de = nlp.PretrainedPipeline("clinical_deidentification", "de", "clinical/models")
# Out:
# clinical_deidentification download started this may take some time.
# Approx size to download 1.2 GB
# [OK!]

# %%
pd.set_option("display.max_colwidth", 100)

text = """Zusammenfassung : Michael Berger wird am Morgen des 12 Dezember 2018 ins St.Elisabeth Krankenhaus in Bad Kissingen eingeliefert.
Herr Michael Berger ist 76 Jahre alt und hat zu viel Wasser in den Beinen.

Persönliche Daten :
ID-Nummer: T0110053F
Platte A-BC124
Kontonummer: DE89370400440532013000
SSN : 13110587M565
Lizenznummer: B072RRE2I55
Adresse : St.Johann-Straße 13 19300"""

result_de = deid_pipeline_de.annotate(text)

df_de = pd.DataFrame(list(zip(result_de["sentence"],
                              result_de["masked"],
                              result_de["masked_with_chars"],
                              result_de["masked_fixed_length_chars"],
                              result_de["obfuscated"])),
                 columns= ["Sentence", "Masked", "Masked with Chars", "Masked with Fixed Chars", "Obfuscated"])

df_de
# Out:
#                                                                                               Sentence  \
# 0  Zusammenfassung : Michael Berger wird am Morgen des 12 Dezember 2018 ins St.Elisabeth Krankenhau...
# 1                           Herr Michael Berger ist 76 Jahre alt und hat zu viel Wasser in den Beinen.
# 2                                                            Persönliche Daten :\nID-Nummer: T0110053F
# 3                                                                                       Platte A-BC124
# 4                                              Kontonummer: DE89370400440532013000\nSSN : 13110587M565
# 5                                                                            Lizenznummer: B072RRE2I55
# 6                                                                  Adresse : St.Johann-Straße 13 19300
#
#                                                                                Masked  \
# 0  Zusammenfassung : <PATIENT> wird am Morgen des <DATE> ins <HOSPITAL> eingeliefert.
# 1            Herr <PATIENT> ist <AGE> Jahre alt und hat zu viel Wasser in den Beinen.
# 2                                                Persönliche Daten :\nID-Nummer: <ID>
# 3                                                                      Platte <PLATE>
# 4                                                 Kontonummer: <ACCOUNT>\nSSN : <SSN>
# 5                                                                 Lizenznummer: <DLN>
# 6                                                            Adresse : <STREET> <ZIP>
#
#                                                                                      Masked with Chars  \
# 0  Zusammenfassung : [************] wird am Morgen des [**************] ins [**********************...
# 1                           Herr [************] ist ** Jahre alt und hat zu viel Wasser in den Beinen.
# 2                                                            Persönliche Daten :\nID-Nummer: [*******]
# 3                                                                                       Platte [*****]
# 4                                              Kontonummer: [********************]\nSSN : [**********]
# 5                                                                            Lizenznummer: [*********]
# 6                                                                  Adresse : [*****************] [***]
#
#                                                  Masked with Fixed Chars  \
# 0  Zusammenfassung : **** wird am Morgen des **** ins **** eingeliefert.
# 1     Herr **** ist **** Jahre alt und hat zu viel Wasser in den Beinen.
# 2                                   Persönliche Daten :\nID-Nummer: ****
# 3                                                            Platte ****
# 4                                          Kontonummer: ****\nSSN : ****
# 5                                                     Lizenznummer: ****
# 6                                                    Adresse : **** ****
#
#                                                                                             Obfuscated
# 0  Zusammenfassung : Saban Steffen wird am Morgen des 12 Dezember 2018 ins Klinik St. Hedwig eingel...
# 1                            Herr Saban Steffen ist 75 Jahre alt und hat zu viel Wasser in den Beinen.
# 2                                                            Persönliche Daten :\nID-Nummer: W9009942Q
# 3                                                                                       Platte Z-SL013
# 4                                                        Kontonummer: 192837465738\nSSN : 02009476T454
# 5                                                                            Lizenznummer: S961KKX1V44
# 6                                                                       Adresse : Kösterring 4/1 08299

# %% [markdown]
# # DE-IDENTIFICATION FOR SPANISH

# %% [markdown]
# ##   Spanish Deidentification NER Models
# We have eight different models you can use:
# * `ner_deid_generic`, detects 7 entities, uses SciWiki 300d embeddings.
# * `ner_deid_generic_roberta`, same as previous, but uses Roberta Clinical Embeddings.
# * `ner_deid_generic_augmented`, detects 8 entities (now includes 'SEX' entity), uses SciWiki 300d embeddings and has been trained with more data
# * `ner_deid_generic_roberta_augmented`, same as previous, but uses Roberta Clinical Embeddings.
# * `ner_deid_subentity`, detects 13 entities, uses SciWiki 300d embeddings.
# * `ner_deid_subentity_roberta`, same as previous, but uses Roberta Clinical Embeddings.
# * `ner_deid_subentity_augmented`, detects 17 entities, uses SciWiki 300d embeddings and has been trained with more data.
# * `ner_deid_subentity_roberta_augmented`, same as previous, but uses Roberta Clinical Embeddings.
#
# Since `augmented` models improve their results compared to the non augmented ones, we are going to show case them in this notebook

# %% [markdown]
# |index|model|lang|index|model|lang|
# |-----:|:-----|----|-----:|:-----|----|
# | 1| [ner_deid_generic](https://nlp.johnsnowlabs.com/2022/01/18/ner_deid_generic_es.html)  |es| 5| [ner_deid_subentity](https://nlp.johnsnowlabs.com/2022/01/18/ner_deid_subentity_es.html)  |es|
# | 2| [ner_deid_generic_augmented](https://nlp.johnsnowlabs.com/2022/02/16/ner_deid_generic_augmented_es.html)  |es| 6| [ner_deid_subentity_augmented](https://nlp.johnsnowlabs.com/2022/02/16/ner_deid_subentity_augmented_es.html)  |es|
# | 3| [ner_deid_generic_roberta](https://nlp.johnsnowlabs.com/2022/01/17/ner_deid_generic_roberta_es.html)  |es| 7| [ner_deid_subentity_roberta](https://nlp.johnsnowlabs.com/2022/01/17/ner_deid_subentity_roberta_es.html)  |es|
# | 4| [ner_deid_generic_roberta_augmented](https://nlp.johnsnowlabs.com/2022/02/16/ner_deid_generic_roberta_augmented_es.html)  |es| 8| [ner_deid_subentity_roberta_augmented](https://nlp.johnsnowlabs.com/2022/02/16/ner_deid_subentity_roberta_augmented_es.html)  |es|

# %% [markdown]
# Creating pipeline for Sciwiki 300d-based augmented model

# %%
# Annotator that transforms a text column from dataframe into an Annotation ready for NLP
documentAssembler = nlp.DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")

sentencerDL = nlp.SentenceDetectorDLModel.pretrained("sentence_detector_dl", "xx") \
    .setInputCols(["document"])\
    .setOutputCol("sentence")

# Tokenizer splits words in a relevant format for NLP
tokenizer = nlp.Tokenizer()\
    .setInputCols(["sentence"])\
    .setOutputCol("token")

word_embeddings_es = nlp.WordEmbeddingsModel.pretrained("embeddings_sciwiki_300d","es","clinical/models")\
    .setInputCols(["document","token"])\
	  .setOutputCol("embeddings")
# Out:
# sentence_detector_dl download started this may take some time.
# Approximate size to download 514.9 KB
# [OK!]
# embeddings_sciwiki_300d download started this may take some time.
# Approximate size to download 253.3 MB
# [OK!]

# %% [markdown]
# ###   NER Deid Generic (Augmented)
#
# **`ner_deid_generic_augmented`** extracts:
# - Name
# - Profession
# - Age
# - Date
# - Contact (Telephone numbers, FAX numbers, Email addresses)
# - Location (Address, City, Postal code, Hospital Name, Employment information)
# - Id (Social Security numbers, Medical record numbers, Internet protocol addresses)
# - Sex

# %%
ner_generic_es = medical.NerModel.pretrained("ner_deid_generic_augmented", "es", "clinical/models")\
    .setInputCols(["sentence","token","embeddings"])\
    .setOutputCol("ner_deid_generic")

ner_converter_generic = medical.NerConverterInternal()\
    .setInputCols(["sentence","token","ner_deid_generic"])\
    .setOutputCol("ner_chunk_generic")
# Out:
# ner_deid_generic_augmented download started this may take some time.
# Approximate size to download 14.3 MB
# [OK!]

# %%
ner_generic_es.getClasses()
# Out:
# ['O',
#  'I-LOCATION',
#  'B-ORGANIZATION',
#  'I-CONTACT',
#  'I-PROFESSION',
#  'I-NAME',
#  'I-DATE',
#  'B-ID',
#  'B-PROFESSION',
#  'B-CONTACT',
#  'I-ID',
#  'B-NAME',
#  'B-DATE',
#  'B-LOCATION',
#  'B-SEX',
#  'I-ORGANIZATION',
#  'B-AGE',
#  'I-SEX']

# %% [markdown]
# ###   NER Deid Subentity
#
# **`ner_deid_subentity`** extracts:
#
# - Patient
# - Doctor
# - Hospital
# - Date
# - Organization
# - City
# - Street
# - User Name
# - Profession
# - Phone
# - Country
# - Age
# - Sex
# - Email
# - ZIP
# - ID
# - Medical Record

# %%
ner_subentity_es = medical.NerModel.pretrained("ner_deid_subentity_augmented", "es", "clinical/models")\
    .setInputCols(["sentence","token","embeddings"])\
    .setOutputCol("ner_deid_subentity")

ner_converter_subentity = medical.NerConverterInternal()\
    .setInputCols(["sentence", "token", "ner_deid_subentity"])\
    .setOutputCol("ner_chunk_subentity")
# Out:
# ner_deid_subentity_augmented download started this may take some time.
# Approximate size to download 14.3 MB
# [OK!]

# %%
ner_subentity_es.getClasses()
# Out:
# ['O',
#  'B-MEDICALRECORD',
#  'B-ORGANIZATION',
#  'I-PROFESSION',
#  'B-DOCTOR',
#  'B-USERNAME',
#  'B-PROFESSION',
#  'I-ID',
#  'B-CITY',
#  'B-DATE',
#  'B-PATIENT',
#  'B-SEX',
#  'I-SEX',
#  'I-DOCTOR',
#  'I-CITY',
#  'I-DATE',
#  'B-COUNTRY',
#  'B-ID',
#  'B-ZIP',
#  'I-STREET',
#  'I-PATIENT',
#  'B-PHONE',
#  'I-PHONE',
#  'B-HOSPITAL',
#  'B-EMAIL',
#  'B-STREET',
#  'I-ORGANIZATION',
#  'B-AGE',
#  'I-HOSPITAL',
#  'I-COUNTRY']

# %% [markdown]
# ###   Pipeline

# %%
nlpPipeline_es = nlp.Pipeline(
    stages=[
        documentAssembler,
        sentencerDL,
        tokenizer,
        word_embeddings_es,
        ner_generic_es,
        ner_converter_generic,
        ner_subentity_es,
        ner_converter_subentity,
])

empty_data = spark.createDataFrame([[""]]).toDF("text")
model_es = nlpPipeline_es.fit(empty_data)

# %%
text = "Antonio Miguel Martínez, un varón de 35 años de edad, de profesión auxiliar de enfermería y nacido en Cadiz, España. Aún no estaba vacunado, se infectó con Covid-19 el dia 14/03/2022 y tuvo que ir al Hospital. Fue tratado con anticuerpos monoclonales en la Clinica San Carlos."

text_df = spark.createDataFrame([[text]]).toDF("text")
result_es = model_es.transform(text_df)

# %% [markdown]
# Results for `ner_deid_subentity`

# %%
result_es.select(F.explode(F.arrays_zip(result_es.ner_chunk_subentity.result,
                                        result_es.ner_chunk_subentity.metadata)).alias("cols")) \
         .select(F.expr("cols['0']").alias("chunk"),
                 F.expr("cols['1']['entity']").alias("ner_label")).show(truncate=False)
# Out:
# +-----------------------+----------+
# |chunk                  |ner_label |
# +-----------------------+----------+
# |Antonio Miguel Martínez|PATIENT   |
# |un varón               |SEX       |
# |35                     |AGE       |
# |auxiliar de enfermería |PROFESSION|
# |Cadiz                  |CITY      |
# |España                 |COUNTRY   |
# |14/03/2022             |DATE      |
# |Clinica San Carlos     |HOSPITAL  |
# +-----------------------+----------+

# %% [markdown]
# Results for `ner_deid_generic`

# %%
result_es.select(F.explode(F.arrays_zip(result_es.ner_chunk_generic.result,
                                        result_es.ner_chunk_generic.metadata)).alias("cols")) \
         .select(F.expr("cols['0']").alias("chunk"),
                 F.expr("cols['1']['entity']").alias("ner_label")).show(truncate=False)
# Out:
# +-----------------------+----------+
# |chunk                  |ner_label |
# +-----------------------+----------+
# |Antonio Miguel Martínez|NAME      |
# |un varón               |SEX       |
# |35                     |AGE       |
# |auxiliar de enfermería |PROFESSION|
# |Cadiz                  |LOCATION  |
# |España                 |LOCATION  |
# |14/03/2022             |DATE      |
# |Clinica San Carlos     |LOCATION  |
# +-----------------------+----------+

# %% [markdown]
# ## DeIdentification

# %% [markdown]
# ### Obfuscation mode

# %%
# Downloading faker entity list.
! wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/obfuscate_es.txt

# %%
deid_masked_entity = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"])\
    .setOutputCol("masked_with_entity")\
    .setMode("mask")\
    .setMaskingPolicy("entity_labels")

deid_masked_char = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"])\
    .setOutputCol("masked_with_chars")\
    .setMode("mask")\
    .setMaskingPolicy("same_length_chars")

deid_masked_fixed_char = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"])\
    .setOutputCol("masked_fixed_length_chars")\
    .setMode("mask")\
    .setMaskingPolicy("fixed_length_chars")\
    .setFixedMaskLength(4)

deid_obfuscated = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"]) \
    .setOutputCol("obfuscated") \
    .setMode("obfuscate")\
    .setObfuscateDate(True)\
    .setObfuscateRefFile('obfuscate_es.txt')\
    .setObfuscateRefSource("file")

# %%
nlpPipeline_es = nlp.Pipeline(stages=[
      documentAssembler,
      sentencerDL,
      tokenizer,
      word_embeddings_es,
      ner_subentity_es,
      ner_converter_subentity,
      deid_masked_entity,
      deid_masked_char,
      deid_masked_fixed_char,
      deid_obfuscated
      ])

empty_data = spark.createDataFrame([[""]]).toDF("text")
model_es = nlpPipeline_es.fit(empty_data)

# %%
deid_lp_es = nlp.LightPipeline(model_es)

# %%
text = "Antonio Miguel Martínez, un varón de 35 años de edad, de profesión auxiliar de enfermería y nacido en Cadiz, España. Aún no estaba vacunado, se infectó con Covid-19 el dia 14/03/2022 y tuvo que ir al Hospital. Fue tratado con anticuerpos monoclonales en la Clinica San Carlos."

# %%
pd.set_option("display.max_colwidth", 100)

result_es = deid_lp_es.annotate(text)

df_es = pd.DataFrame(list(zip(result_es["masked_with_entity"],
                              result_es["masked_with_chars"],
                              result_es["masked_fixed_length_chars"],
                              result_es["obfuscated"])),
                  columns= ["Masked", "Masked with Chars", "Masked with Fixed Chars", "Obfuscated"])

df_es
# Out:
#                                                                                                 Masked  \
# 0     <PATIENT>, <SEX> de <AGE> años de edad, de profesión <PROFESSION> y nacido en <CITY>, <COUNTRY>.
# 1  Aún no estaba vacunado, se infectó con Covid-19 el dia <DATE> y tuvo que ir al Hospital. Fue tra...
#
#                                                                                      Masked with Chars  \
# 0  [*********************], [******] de ** años de edad, de profesión [********************] y naci...
# 1  Aún no estaba vacunado, se infectó con Covid-19 el dia [********] y tuvo que ir al Hospital. Fue...
#
#                                                                                Masked with Fixed Chars  \
# 0                           ****, **** de **** años de edad, de profesión **** y nacido en ****, ****.
# 1  Aún no estaba vacunado, se infectó con Covid-19 el dia **** y tuvo que ir al Hospital. Fue trata...
#
#                                                                                             Obfuscated
# 0    María Miguélez Sanz, hombre de 34 años de edad, de profesión conserje y nacido en Madrid, España.
# 1  Aún no estaba vacunado, se infectó con Covid-19 el dia 07/05/2022 y tuvo que ir al Hospital. Fue...

# %% [markdown]
# ### Faker Mode

# %%
deid_obfuscated_faker = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"]) \
    .setOutputCol("obfuscated") \
    .setMode("obfuscate")\
    .setLanguage('es')\
    .setObfuscateDate(True)\
    .setObfuscateRefSource('faker')

# %%
nlpPipeline_es = nlp.Pipeline(
    stages=[
        documentAssembler,
        sentencerDL,
        tokenizer,
        word_embeddings_es,
        ner_subentity_es,
        ner_converter_subentity,
        deid_masked_entity,
        deid_masked_char,
        deid_masked_fixed_char,
        deid_obfuscated_faker
])

empty_data = spark.createDataFrame([[""]]).toDF("text")
model_es = nlpPipeline_es.fit(empty_data)

# %%
deid_lp_es = nlp.LightPipeline(model_es)

# %%
text = "Antonio Miguel Martínez, un varón de 35 años de edad, de profesión auxiliar de enfermería y nacido en Cadiz, España. Aún no estaba vacunado, se infectó con Covid-19 el dia 14/03/2022 y tuvo que ir al Hospital. Fue tratado con anticuerpos monoclonales en la Clinica San Carlos."

# %%
pd.set_option("display.max_colwidth", 100)

result_es = deid_lp_es.annotate(text)

df_es = pd.DataFrame(list(zip(result_es["masked_with_entity"],
                              result_es["masked_with_chars"],
                              result_es["masked_fixed_length_chars"],
                              result_es["obfuscated"])),
                  columns= ["Masked", "Masked with Chars", "Masked with Fixed Chars", "Obfuscated"])

df_es
# Out:
#                                                                                                 Masked  \
# 0     <PATIENT>, <SEX> de <AGE> años de edad, de profesión <PROFESSION> y nacido en <CITY>, <COUNTRY>.
# 1  Aún no estaba vacunado, se infectó con Covid-19 el dia <DATE> y tuvo que ir al Hospital. Fue tra...
#
#                                                                                      Masked with Chars  \
# 0  [*********************], [******] de ** años de edad, de profesión [********************] y naci...
# 1  Aún no estaba vacunado, se infectó con Covid-19 el dia [********] y tuvo que ir al Hospital. Fue...
#
#                                                                                Masked with Fixed Chars  \
# 0                           ****, **** de **** años de edad, de profesión **** y nacido en ****, ****.
# 1  Aún no estaba vacunado, se infectó con Covid-19 el dia **** y tuvo que ir al Hospital. Fue trata...
#
#                                                                                             Obfuscated
# 0  Nicusor Mamady Guevara, m de 27 años de edad, de profesión desarrollador de blockchain y nacido ...
# 1  Aún no estaba vacunado, se infectó con Covid-19 el dia 15/03/2022 y tuvo que ir al Hospital. Fue...

# %% [markdown]
# ## Pretrained Spanish Deidentification Pipeline
#
# - We developed a clinical deidentification pretrained pipeline that can be used to deidentify PHI information from German medical texts. The PHI information will be masked and obfuscated in the resulting text.
# - The pipeline can mask and obfuscate:
#     - Patient
#     - Doctor
#     - Hospital
#     - Date
#     - Organization
#     - City
#     - Street
#     - Country
#     - User name
#     - Profession
#     - Phone
#     - Age
#     - Contact
#     - ID
#     - Phone
#     - ZIP
#     - Account
#     - SSN
#     - Driver's License Number
#     - Plate Number
#     - Sex

# %% [markdown]
# |index|model|index|model|
# |-----:|:-----|-----:|:-----|
# | 1| [clinical_deidentification_augmented]()| 2| [clinical_deidentification]()|

# %%
deid_pipeline_es = nlp.PretrainedPipeline("clinical_deidentification_augmented", "es", "clinical/models")
# Out:
# clinical_deidentification_augmented download started this may take some time.
# Approx size to download 268.3 MB
# [OK!]

# %%
text = """Datos del paciente.
Nombre:  Ernesto.
Apellidos: Rivera Bueno.
NHC: 368503.
NASS: 26 63514095.
Domicilio:  Calle Miguel Benitez 90.
Localidad/ Provincia: Madrid.
CP: 28016.
Datos asistenciales.
Fecha de nacimiento: 03/03/1946.
País: España.
Edad: 70 años Sexo: H.
Fecha de Ingreso: 12/12/2016.
Médico:  Ignacio Navarro Cuéllar NºCol: 28 28 70973.
Informe clínico del paciente: Paciente de 70 años de edad, minero jubilado, sin alergias medicamentosas conocidas, que presenta como antecedentes personales: accidente laboral antiguo con fracturas vertebrales y costales; intervenido de enfermedad de Dupuytren en mano derecha y by-pass iliofemoral izquierdo; Diabetes Mellitus tipo II, hipercolesterolemia e hiperuricemia; enolismo activo, fumador de 20 cigarrillos / día.
Es derivado desde Atención Primaria por presentar hematuria macroscópica postmiccional en una ocasión y microhematuria persistente posteriormente, con micciones normales.
En la exploración física presenta un buen estado general, con abdomen y genitales normales; tacto rectal compatible con adenoma de próstata grado I/IV.
En la analítica de orina destaca la existencia de 4 hematíes/ campo y 0-5 leucocitos/campo; resto de sedimento normal.
Hemograma normal; en la bioquímica destaca una glucemia de 169 mg/dl y triglicéridos de 456 mg/dl; función hepática y renal normal. PSA de 1.16 ng/ml.
Las citologías de orina son repetidamente sospechosas de malignidad.
En la placa simple de abdomen se valoran cambios degenerativos en columna lumbar y calcificaciones vasculares en ambos hipocondrios y en pelvis.
La ecografía urológica pone de manifiesto la existencia de quistes corticales simples en riñón derecho, vejiga sin alteraciones con buena capacidad y próstata con un peso de 30 g.
En la UIV se observa normofuncionalismo renal bilateral, calcificaciones sobre silueta renal derecha y uréteres arrosariados con imágenes de adición en el tercio superior de ambos uréteres, en relación a pseudodiverticulosis ureteral. El cistograma demuestra una vejiga con buena capacidad, pero paredes trabeculadas en relación a vejiga de esfuerzo. La TC abdominal es normal.
La cistoscopia descubre la existencia de pequeñas tumoraciones vesicales, realizándose resección transuretral con el resultado anatomopatológico de carcinoma urotelial superficial de vejiga.
Remitido por: Ignacio Navarro Cuéllar c/ del Abedul 5-7, 2º dcha 28036 Madrid, España E-mail: nnavcu@hotmail.com.
"""

result_es = deid_pipeline_es.annotate(text)
print("\n".join(result_es['masked_with_chars']))
print("\n")
print("\n".join(result_es['masked']))
print("\n")
print("\n".join(result_es['masked_fixed_length_chars']))
print("\n")
print("\n".join(result_es['obfuscated']))
# Out:
# Datos [**********].
# Nombre:  [*****].
# Apellidos: [**********].
# NHC: [****].
# NASS: [*********].
# Domicilio:  [*********************].
# Localidad/ Provincia: [****].
# CP: [***].
# Datos asistenciales.
# Fecha de nacimiento: [********].
# País: [****].
# Edad: ** años Sexo: *.
# Fecha de Ingreso: [********].
# Médico:  [*********************] NºCol: [*********].
# Informe clínico [**********]: [******] ** ** años de edad, minero jubilado, sin alergias medicamentosas conocidas, que presenta como antecedentes personales: accidente laboral antiguo con fracturas vertebrales y costales; intervenido de enfermedad de Dupuytren en mano derecha y by-pass iliofemoral izquierdo;
# Diabetes Mellitus tipo II, hipercolesterolemia e hiperuricemia; enolismo activo, fumador de 20 cigarrillos / día.
# Es derivado desde Atención Primaria por presentar hematuria macroscópica postmiccional en una ocasión y microhematuria persistente posteriormente, con micciones normales.
# En la exploración física presenta un buen estado general, con abdomen y genitales normales; tacto rectal compatible con adenoma de próstata grado I/IV.
# En la analítica de orina destaca la existencia de 4 hematíes/ campo y 0-5 leucocitos/campo; resto de sedimento normal.
# Hemograma normal; en la bioquímica destaca una glucemia de 169 mg/dl y triglicéridos de 456 mg/dl; función hepática y renal normal. PSA de 1.16 ng/ml.
# Las citologías de orina son repetidamente sospechosas de malignidad.
# En la placa simple de abdomen se valoran cambios degenerativos en columna lumbar y calcificaciones vasculares en ambos hipocondrios y en pelvis.
# La ecografía urológica pone de manifiesto la existencia de quistes corticales simples en riñón derecho, vejiga sin alteraciones con buena capacidad y próstata con un peso de 30 g.
# En la UIV se observa normofuncionalismo renal bilateral, calcificaciones sobre silueta renal derecha y uréteres arrosariados con imágenes de adición en el tercio superior de ambos uréteres, en relación a pseudodiverticulosis ureteral. El cistograma demuestra una vejiga con buena capacidad, pero paredes trabeculadas en relación a vejiga de esfuerzo.
# La TC abdominal es normal.
# La cistoscopia descubre la existencia de pequeñas tumoraciones vesicales, realizándose resección transuretral con el resultado anatomopatológico de carcinoma urotelial superficial de vejiga.
# Remitido por: [*********************] [***************], [*****] [***] [****], [****] E-mail: [****************].
#
#
# Datos <SEX>.
# Nombre:  <PATIENT>.
# Apellidos: <PATIENT>.
# NHC: <SSN>.
# NASS: <ID>.
# Domicilio:  <STREET>.
# Localidad/ Provincia: <CITY>.
# CP: <ZIP>.
# Datos asistenciales.
# Fecha de nacimiento: <DATE>.
# País: <COUNTRY>.
# Edad: <AGE> años Sexo: <SEX>.
# Fecha de Ingreso: <DATE>.
# Médico:  <DOCTOR> NºCol: <ID>.
# Informe clínico <SEX>: <SSN> <SSN> <AGE> años de edad, minero jubilado, sin alergias medicamentosas conocidas, que presenta como antecedentes personales: accidente laboral antiguo con fracturas vertebrales y costales; intervenido de enfermedad de Dupuytren en mano derecha y by-pass iliofemoral izquierdo;
# Diabetes Mellitus tipo II, hipercolesterolemia e hiperuricemia; enolismo activo, fumador de 20 cigarrillos / día.
# Es derivado desde Atención Primaria por presentar hematuria macroscópica postmiccional en una ocasión y microhematuria persistente posteriormente, con micciones normales.
# En la exploración física presenta un buen estado general, con abdomen y genitales normales; tacto rectal compatible con adenoma de próstata grado I/IV.
# En la analítica de orina destaca la existencia de 4 hematíes/ campo y 0-5 leucocitos/campo; resto de sedimento normal.
# Hemograma normal; en la bioquímica destaca una glucemia de 169 mg/dl y triglicéridos de 456 mg/dl; función hepática y renal normal. PSA de 1.16 ng/ml.
# Las citologías de orina son repetidamente sospechosas de malignidad.
# En la placa simple de abdomen se valoran cambios degenerativos en columna lumbar y calcificaciones vasculares en ambos hipocondrios y en pelvis.
# La ecografía urológica pone de manifiesto la existencia de quistes corticales simples en riñón derecho, vejiga sin alteraciones con buena capacidad y próstata con un peso de 30 g.
# En la UIV se observa normofuncionalismo renal bilateral, calcificaciones sobre silueta renal derecha y uréteres arrosariados con imágenes de adición en el tercio superior de ambos uréteres, en relación a pseudodiverticulosis ureteral. El cistograma demuestra una vejiga con buena capacidad, pero paredes trabeculadas en relación a vejiga de esfuerzo.
# La TC abdominal es normal.
# La cistoscopia descubre la existencia de pequeñas tumoraciones vesicales, realizándose resección transuretral con el resultado anatomopatológico de carcinoma urotelial superficial de vejiga.
# Remitido por: <DOCTOR> <STREET>, <STREET> <ZIP> <CITY>, <COUNTRY> E-mail: <EMAIL>.
#
#
# Datos ****.
# Nombre:  ****.
# Apellidos: ****.
# NHC: ****.
# NASS: ****.
# Domicilio:  ****.
# Localidad/ Provincia: ****.
# CP: ****.
# Datos asistenciales.
# Fecha de nacimiento: ****.
# País: ****.
# Edad: **** años Sexo: ****.
# Fecha de Ingreso: ****.
# Médico:  **** NºCol: ****.
# Informe clínico ****: **** **** **** años de edad, minero jubilado, sin alergias medicamentosas conocidas, que presenta como antecedentes personales: accidente laboral antiguo con fracturas vertebrales y costales; intervenido de enfermedad de Dupuytren en mano derecha y by-pass iliofemoral izquierdo;
# Diabetes Mellitus tipo II, hipercolesterolemia e hiperuricemia; enolismo activo, fumador de 20 cigarrillos / día.
# Es derivado desde Atención Primaria por presentar hematuria macroscópica postmiccional en una ocasión y microhematuria persistente posteriormente, con micciones normales.
# En la exploración física presenta un buen estado general, con abdomen y genitales normales; tacto rectal compatible con adenoma de próstata grado I/IV.
# En la analítica de orina destaca la existencia de 4 hematíes/ campo y 0-5 leucocitos/campo; resto de sedimento normal.
# Hemograma normal; en la bioquímica destaca una glucemia de 169 mg/dl y triglicéridos de 456 mg/dl; función hepática y renal normal. PSA de 1.16 ng/ml.
# Las citologías de orina son repetidamente sospechosas de malignidad.
# En la placa simple de abdomen se valoran cambios degenerativos en columna lumbar y calcificaciones vasculares en ambos hipocondrios y en pelvis.
# La ecografía urológica pone de manifiesto la existencia de quistes corticales simples en riñón derecho, vejiga sin alteraciones con buena capacidad y próstata con un peso de 30 g.
# En la UIV se observa normofuncionalismo renal bilateral, calcificaciones sobre silueta renal derecha y uréteres arrosariados con imágenes de adición en el tercio superior de ambos uréteres, en relación a pseudodiverticulosis ureteral. El cistograma demuestra una vejiga con buena capacidad, pero paredes trabeculadas en relación a vejiga de esfuerzo.
# La TC abdominal es normal.
# La cistoscopia descubre la existencia de pequeñas tumoraciones vesicales, realizándose resección transuretral con el resultado anatomopatológico de carcinoma urotelial superficial de vejiga.
# Remitido por: **** ****, **** **** ****, **** E-mail: ****.
#
#
# Datos mujer.
# Nombre:  María Miguélez Sanz.
# Apellidos: María Miguélez Sanz.
# NHC: 631496.
# NASS: 73 36485904.
# Domicilio:  Avda. De América, 100.
# Localidad/ Provincia: Zaragoza.
# CP: 71983.
# Datos asistenciales.
# Fecha de nacimiento: 03/03/1946.
# País: España.
# Edad: 73 años Sexo: HOMBRE.
# Fecha de Ingreso: 12/12/2016.
# Médico:  José Ignacio Reverte Miguélez NºCol: 71 71 29026.
# Informe clínico mujer: Kjxnlwml el 73 años de edad, minero jubilado, sin alergias medicamentosas conocidas, que presenta como antecedentes personales: accidente laboral antiguo con fracturas vertebrales y costales; intervenido de enfermedad de Dupuytren en mano derecha y by-pass iliofemoral izquierdo;
# Diabetes Mellitus tipo II, hipercolesterolemia e hiperuricemia; enolismo activo, fumador de 20 cigarrillos / día.
# Es derivado desde Atención Primaria por presentar hematuria macroscópica postmiccional en una ocasión y microhematuria persistente posteriormente, con micciones normales.
# En la exploración física presenta un buen estado general, con abdomen y genitales normales; tacto rectal compatible con adenoma de próstata grado I/IV.
# En la analítica de orina destaca la existencia de 4 hematíes/ campo y 0-5 leucocitos/campo; resto de sedimento normal.
# Hemograma normal; en la bioquímica destaca una glucemia de 169 mg/dl y triglicéridos de 456 mg/dl; función hepática y renal normal. PSA de 1.16 ng/ml.
# Las citologías de orina son repetidamente sospechosas de malignidad.
# En la placa simple de abdomen se valoran cambios degenerativos en columna lumbar y calcificaciones vasculares en ambos hipocondrios y en pelvis.
# La ecografía urológica pone de manifiesto la existencia de quistes corticales simples en riñón derecho, vejiga sin alteraciones con buena capacidad y próstata con un peso de 30 g.
# En la UIV se observa normofuncionalismo renal bilateral, calcificaciones sobre silueta renal derecha y uréteres arrosariados con imágenes de adición en el tercio superior de ambos uréteres, en relación a pseudodiverticulosis ureteral. El cistograma demuestra una vejiga con buena capacidad, pero paredes trabeculadas en relación a vejiga de esfuerzo.
# La TC abdominal es normal.
# La cistoscopia descubre la existencia de pequeñas tumoraciones vesicales, realizándose resección transuretral con el resultado anatomopatológico de carcinoma urotelial superficial de vejiga.
# Remitido por: José Ignacio Reverte Miguélez Calle Ramón Y Cajal S/n, c/ gran via, 2 71963 Zaragoza, España E-mail: henrywatson@world.com.

# %% [markdown]
# # DE-IDENTIFICATION FOR FRENCH

# %% [markdown]
# ## French Deidentification NER Models
# We have two different models you can use:
# * `ner_deid_generic`, detects 7 entities
# * `ner_deid_subentity`, detects 15 entities

# %% [markdown]
# |index|model|lang|index|model|lang|
# |-----:|:-----|----|-----:|:-----|----|
# | 1| [ner_deid_generic](https://nlp.johnsnowlabs.com/2022/02/11/ner_deid_generic_fr.html)  |fr| 2| [ner_deid_subentity](https://nlp.johnsnowlabs.com/2022/02/14/ner_deid_subentity_fr.html)  |fr|

# %% [markdown]
# Creating pipeline

# %%
documentAssembler = nlp.DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")

sentencerDL = nlp.SentenceDetectorDLModel.pretrained("sentence_detector_dl", "xx") \
    .setInputCols(["document"])\
    .setOutputCol("sentence")

tokenizer = nlp.Tokenizer()\
    .setInputCols(["sentence"])\
    .setOutputCol("token")

word_embeddings_fr = nlp.WordEmbeddingsModel.pretrained("w2v_cc_300d", "fr")\
    .setInputCols(["document","token"])\
  	.setOutputCol("embeddings")
# Out:
# sentence_detector_dl download started this may take some time.
# Approximate size to download 514.9 KB
# [OK!]
# w2v_cc_300d download started this may take some time.
# Approximate size to download 1.2 GB
# [OK!]

# %% [markdown]
# ### NER Deid Generic
#
# **`ner_deid_generic`** extracts:
# - Name
# - Profession
# - Age
# - Date
# - Contact (Telephone numbers, Email addresses)
# - Location (Address, City, Postal code, Hospital Name, Organization)
# - ID (Social Security numbers, Medical record numbers)

# %%
ner_generic_fr = medical.NerModel.pretrained("ner_deid_generic", "fr", "clinical/models")\
    .setInputCols(["sentence","token","embeddings"])\
    .setOutputCol("ner_deid_generic")

ner_converter_generic = medical.NerConverterInternal()\
    .setInputCols(["sentence","token","ner_deid_generic"])\
    .setOutputCol("ner_chunk_generic")
# Out:
# ner_deid_generic download started this may take some time.
# Approximate size to download 14.3 MB
# [OK!]

# %%
ner_generic_fr.getClasses()
# Out:
# ['O',
#  'I-LOCATION',
#  'I-CONTACT',
#  'I-PROFESSION',
#  'I-NAME',
#  'I-DATE',
#  'B-ID',
#  'B-PROFESSION',
#  'B-CONTACT',
#  'I-ID',
#  'B-NAME',
#  'B-DATE',
#  'B-LOCATION',
#  'B-AGE',
#  'I-AGE']

# %% [markdown]
# ### NER Deid Subentity
#
# **`ner_deid_subentity`** extracts:
#
# - Patient
# - Doctor
# - Hospital
# - Date
# - Organization
# - City
# - Street
# - Username
# - Profession
# - Phone
# - Country
# - Age
# - E-mail
# - ZIP
# - Medical Record

# %%
ner_subentity_fr = medical.NerModel.pretrained("ner_deid_subentity", "fr", "clinical/models")\
    .setInputCols(["sentence","token","embeddings"])\
    .setOutputCol("ner_deid_subentity")

ner_converter_subentity = medical.NerConverterInternal()\
    .setInputCols(["sentence", "token", "ner_deid_subentity"])\
    .setOutputCol("ner_chunk_subentity")
# Out:
# ner_deid_subentity download started this may take some time.
# Approximate size to download 14.3 MB
# [OK!]

# %%
ner_subentity_fr.getClasses()
# Out:
# ['O',
#  'B-MEDICALRECORD',
#  'B-ORGANIZATION',
#  'I-PROFESSION',
#  'B-DOCTOR',
#  'B-USERNAME',
#  'B-PROFESSION',
#  'B-CITY',
#  'B-DATE',
#  'I-MEDICALRECORD',
#  'B-E-MAIL',
#  'B-PATIENT',
#  'I-DOCTOR',
#  'I-CITY',
#  'I-DATE',
#  'B-COUNTRY',
#  'B-ZIP',
#  'I-STREET',
#  'I-PATIENT',
#  'B-PHONE',
#  'I-PHONE',
#  'B-HOSPITAL',
#  'B-STREET',
#  'I-ORGANIZATION',
#  'I-HOSPITAL',
#  'B-AGE',
#  'I-AGE',
#  'I-COUNTRY']

# %% [markdown]
# ### Pipeline

# %%
nlpPipeline_fr = nlp.Pipeline(stages=[
      documentAssembler,
      sentencerDL,
      tokenizer,
      word_embeddings_fr,
      ner_generic_fr,
      ner_converter_generic,
      ner_subentity_fr,
      ner_converter_subentity,
      ])

empty_data = spark.createDataFrame([[""]]).toDF("text")
model_fr = nlpPipeline_fr.fit(empty_data)

# %%
text = "J'ai vu en consultation Michel Martinez (49 ans), jardinier, adressé au Centre Hospitalier De Plaisir pour un diabète mal contrôlé avec des symptômes datant de Mars 2015."

text_df = spark.createDataFrame([[text]]).toDF("text")
result_fr = model_fr.transform(text_df)

# %% [markdown]
# Results for `ner_deid_generic`

# %%
result_fr.select(F.explode(F.arrays_zip(result_fr.ner_chunk_generic.result,
                                        result_fr.ner_chunk_generic.metadata)).alias("cols")) \
         .select(F.expr("cols['0']").alias("chunk"),
                 F.expr("cols['1']['entity']").alias("ner_label")).show(truncate=False)
# Out:
# +-----------------------------+----------+
# |chunk                        |ner_label |
# +-----------------------------+----------+
# |Michel Martinez              |NAME      |
# |49 ans                       |AGE       |
# |jardinier                    |PROFESSION|
# |Centre Hospitalier De Plaisir|LOCATION  |
# |Mars 2015                    |DATE      |
# +-----------------------------+----------+

# %% [markdown]
# Results for `ner_deid_subentity`

# %%
result_fr.select(F.explode(F.arrays_zip(result_fr.ner_chunk_subentity.result,
                                        result_fr.ner_chunk_subentity.metadata)).alias("cols")) \
         .select(F.expr("cols['0']").alias("chunk"),
                 F.expr("cols['1']['entity']").alias("ner_label")).show(truncate=False)
# Out:
# +-----------------------------+----------+
# |chunk                        |ner_label |
# +-----------------------------+----------+
# |Michel Martinez              |PATIENT   |
# |49 ans                       |AGE       |
# |jardinier                    |PROFESSION|
# |Centre Hospitalier De Plaisir|HOSPITAL  |
# |Mars 2015                    |DATE      |
# +-----------------------------+----------+

# %% [markdown]
# ## DeIdentification

# %% [markdown]
# ### Obfuscation mode

# %%
# Downloading faker entity list.
! wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/obfuscate_fr.txt

# %%
deid_masked_entity = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"])\
    .setOutputCol("masked_with_entity")\
    .setMode("mask")\
    .setMaskingPolicy("entity_labels")

deid_masked_char = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"])\
    .setOutputCol("masked_with_chars")\
    .setMode("mask")\
    .setMaskingPolicy("same_length_chars")

deid_masked_fixed_char = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"])\
    .setOutputCol("masked_fixed_length_chars")\
    .setMode("mask")\
    .setMaskingPolicy("fixed_length_chars")\
    .setFixedMaskLength(4)

deid_obfuscated = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"]) \
    .setOutputCol("obfuscated") \
    .setMode("obfuscate")\
    .setObfuscateDate(True)\
    .setObfuscateRefFile('obfuscate_fr.txt')\
    .setObfuscateRefSource("file")

# %%
nlpPipeline_fr = nlp.Pipeline(stages=[
      documentAssembler,
      sentencerDL,
      tokenizer,
      word_embeddings_fr,
      ner_subentity_fr,
      ner_converter_subentity,
      deid_masked_entity,
      deid_masked_char,
      deid_masked_fixed_char,
      deid_obfuscated
      ])

empty_data = spark.createDataFrame([[""]]).toDF("text")
model_fr = nlpPipeline_fr.fit(empty_data)

# %%
deid_lp_fr = nlp.LightPipeline(model_fr)

# %%
text = "J'ai vu en consultation Michel Martinez (49 ans), jardinier, adressé au Centre Hospitalier De Plaisir pour un diabète mal contrôlé avec des symptômes datant de Mars 2015."

# %%
pd.set_option("display.max_colwidth", 200)

result_fr = deid_lp_fr.annotate(text)

df_fr = pd.DataFrame(list(zip(result_fr["masked_with_entity"],
                              result_fr["masked_with_chars"],
                              result_fr["masked_fixed_length_chars"],
                              result_fr["obfuscated"])),
                 columns= ["Masked_with_entity", "Masked with Chars", "Masked with Fixed Chars", "Obfuscated"])

df_fr
# Out:
#                                                                                                                                  Masked_with_entity  \
# 0  J'ai vu en consultation <PATIENT> (<AGE>), <PROFESSION>, adressé au <HOSPITAL> pour un diabète mal contrôlé avec des symptômes datant de <DATE>.
#
#                                                                                                                                                             Masked with Chars  \
# 0  J'ai vu en consultation [*************] ([****]), [*******], adressé au [***************************] pour un diabète mal contrôlé avec des symptômes datant de [*******].
#
#                                                                                                       Masked with Fixed Chars  \
# 0  J'ai vu en consultation **** (****), ****, adressé au **** pour un diabète mal contrôlé avec des symptômes datant de ****.
#
#                                                                                                                                                                                  Obfuscated
# 0  J'ai vu en consultation Mme Victor Lecoq (56 ans), cartographe, adressé au Centre Hospitalier Du Sud Seine-et-marne pour un diabète mal contrôlé avec des symptômes datant de Mars 1115.

# %% [markdown]
# ### Faker mode

# %%
deid_obfuscated_faker = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"]) \
    .setOutputCol("obfuscated") \
    .setMode("obfuscate")\
    .setLanguage('fr')\
    .setObfuscateDate(True)\
    .setObfuscateRefSource('faker')

# %%
nlpPipeline_fr = nlp.Pipeline(stages=[
      documentAssembler,
      sentencerDL,
      tokenizer,
      word_embeddings_fr,
      ner_subentity_fr,
      ner_converter_subentity,
      deid_masked_entity,
      deid_masked_char,
      deid_masked_fixed_char,
      deid_obfuscated_faker
      ])

empty_data = spark.createDataFrame([[""]]).toDF("text")
model_fr = nlpPipeline_fr.fit(empty_data)

# %%
deid_lp_fr = nlp.LightPipeline(model_fr)

# %%
text = "J'ai vu en consultation Michel Martinez (49 ans), jardinier, adressé au Centre Hospitalier De Plaisir pour un diabète mal contrôlé avec des symptômes datant de Mars 2015."

# %%
pd.set_option("display.max_colwidth", 200)

result_fr = deid_lp_fr.annotate(text)

df_fr = pd.DataFrame(list(zip(result_fr["masked_with_entity"],
                              result_fr["masked_with_chars"],
                              result_fr["masked_fixed_length_chars"],
                              result_fr["obfuscated"])),
                 columns= ["Masked_with_entity", "Masked with Chars", "Masked with Fixed Chars", "Obfuscated"])

df_fr
# Out:
#                                                                                                                                  Masked_with_entity  \
# 0  J'ai vu en consultation <PATIENT> (<AGE>), <PROFESSION>, adressé au <HOSPITAL> pour un diabète mal contrôlé avec des symptômes datant de <DATE>.
#
#                                                                                                                                                             Masked with Chars  \
# 0  J'ai vu en consultation [*************] ([****]), [*******], adressé au [***************************] pour un diabète mal contrôlé avec des symptômes datant de [*******].
#
#                                                                                                       Masked with Fixed Chars  \
# 0  J'ai vu en consultation **** (****), ****, adressé au **** pour un diabète mal contrôlé avec des symptômes datant de ****.
#
#                                                                                                                                                                                                 Obfuscated
# 0  J'ai vu en consultation Anakoni Biason (52 ans), éducateur de la protection judiciaire de la jeunesse (pjj), adressé au Centre Hospitalier Isarien - Etablissement Public De Sante Mentale De L'oise...

# %% [markdown]
# ## Pretrained French Deidentification Pipeline
#
# - We developed a clinical deidentification pretrained pipeline that can be used to deidentify PHI information from French medical texts. The PHI information will be masked and obfuscated in the resulting text.
# - The pipeline can mask and obfuscate:
#     - Patient
#     - Doctor
#     - Hospital
#     - Date
#     - Organization
#     - Sex
#     - City
#     - Street
#     - Country
#     - ZIP
#     - Username
#     - Profession
#     - Phone
#     - Email
#     - Age
#     - ID number
#     - Medical record number
#     - Account number
#     - SSN
#     - Plate Number
#     - IP address
#     - URL

# %%
deid_pipeline_fr = nlp.PretrainedPipeline("clinical_deidentification", "fr", "clinical/models")
# Out:
# clinical_deidentification download started this may take some time.
# Approx size to download 1.2 GB
# [OK!]

# %%
text = """COMPTE-RENDU D'HOSPITALISATION
PRENOM : Jean
NOM : Dubois
NUMÉRO DE SÉCURITÉ SOCIALE : 1780160471058
ADRESSE : 18 Avenue Matabiau
VILLE : Grenoble
CODE POSTAL : 38000
DATE DE NAISSANCE : 03/03/1946
Âge : 70 ans
Sexe : H
COURRIEL : jdubois@hotmail.fr
DATE D'ADMISSION : 12/12/2016
MÉDÉCIN : Dr Michel Renaud
RAPPORT CLINIQUE : 70 ans, retraité, sans allergie médicamenteuse connue, qui présente comme antécédents : ancien accident du travail avec fractures vertébrales et des côtes ; opéré de la maladie de Dupuytren à la main droite et d'un pontage ilio-fémoral gauche ; diabète de type II, hypercholestérolémie et hyperuricémie ; alcoolisme actif, fume 20 cigarettes / jour.
Il nous a été adressé car il présentait une hématurie macroscopique postmictionnelle à une occasion et une microhématurie persistante par la suite, avec une miction normale.
L'examen physique a montré un bon état général, avec un abdomen et des organes génitaux normaux ; le toucher rectal était compatible avec un adénome de la prostate de grade I/IV.
L'analyse d'urine a montré 4 globules rouges/champ et 0-5 leucocytes/champ ; le reste du sédiment était normal.
Hémogramme normal ; la biochimie a montré une glycémie de 169 mg/dl et des triglycérides de 456 mg/dl ; les fonctions hépatiques et rénales étaient normales. PSA de 1,16 ng/ml.
ADDRESSÉ À : Dre Marie Breton - Centre Hospitalier de Bellevue Service D'Endocrinologie et de Nutrition - Rue Paulin Bussières, 38000 Grenoble
COURRIEL : mariebreton@chb.fr
"""

# %%
pd.set_option("display.max_colwidth", 100)

result_fr = deid_pipeline_fr.annotate(text)

df_fr = pd.DataFrame(list(zip(result_fr["sentence"],
                              result_fr["masked"],
                              result_fr["masked_with_chars"],
                              result_fr["masked_fixed_length_chars"],
                              result_fr["obfuscated"])),
                 columns= ["Sentence", "Masked", "Masked with Chars", "Masked with Fixed Chars", "Obfuscated"])

df_fr
# Out:
#                                                                                                Sentence  \
# 0                                                                        COMPTE-RENDU D'HOSPITALISATION
# 1                                                                                         PRENOM : Jean
# 2                                                                                          NOM : Dubois
# 3                                                            NUMÉRO DE SÉCURITÉ SOCIALE : 1780160471058
# 4                                                                          ADRESSE : 18 Avenue Matabiau
# 5                                                                                      VILLE : Grenoble
# 6                                                                                   CODE POSTAL : 38000
# 7                                                                        DATE DE NAISSANCE : 03/03/1946
# 8                                                                                          Âge : 70 ans
# 9                                Sexe : H\nCOURRIEL : jdubois@hotmail.fr\nDATE D'ADMISSION : 12/12/2016
# 10                                                                           MÉDÉCIN : Dr Michel Renaud
# 11  RAPPORT CLINIQUE : 70 ans, retraité, sans allergie médicamenteuse connue, qui présente comme ant...
# 12  Il nous a été adressé car il présentait une hématurie macroscopique postmictionnelle à une occas...
# 13  L'examen physique a montré un bon état général, avec un abdomen et des organes génitaux normaux ...
# 14  L'analyse d'urine a montré 4 globules rouges/champ et 0-5 leucocytes/champ ; le reste du sédimen...
# 15                                                                                   PSA de 1,16 ng/ml.
# 16  ADDRESSÉ À : Dre Marie Breton - Centre Hospitalier de Bellevue Service D'Endocrinologie et de Nu...
# 17                                                                      COURRIEL : mariebreton@chb.fr\n
#
#                                                                                                  Masked  \
# 0                                                                        COMPTE-RENDU D'HOSPITALISATION
# 1                                                                                    PRENOM : <PATIENT>
# 2                                                                                       NOM : <PATIENT>
# 3                                                                    NUMÉRO DE SÉCURITÉ SOCIALE : <SSN>
# 4                                                                                    ADRESSE : <STREET>
# 5                                                                                        VILLE : <CITY>
# 6                                                                                   CODE POSTAL : <ZIP>
# 7                                                                            DATE DE NAISSANCE : <DATE>
# 8                                                                                           Âge : <AGE>
# 9                                          Sexe : <SEX>\nCOURRIEL : <E-MAIL>\nDATE D'ADMISSION : <DATE>
# 10                                                                                   MÉDÉCIN : <DOCTOR>
# 11  RAPPORT CLINIQUE : <AGE>ans, retraité, sans allergie médicamenteuse connue, qui présente comme a...
# 12  <SEX> nous a été adressé car <SEX> présentait une hématurie macroscopique postmictionnelle à une...
# 13  L'examen physique a montré un bon état général, avec un abdomen et des organes génitaux normaux ...
# 14  L'analyse d'urine a montré 4 globules rouges/champ et 0-5 leucocytes/champ ; le reste du sédimen...
# 15                                                                                   PSA de 1,16 ng/ml.
# 16  ADDRESSÉ À : <DOCTOR> - <HOSPITAL> Service D'Endocrinologie et de Nutrition - <STREET>, <ZIP><CITY>
# 17                                                                                COURRIEL : <E-MAIL>\n
#
#                                                                                       Masked with Chars  \
# 0                                                                        COMPTE-RENDU D'HOSPITALISATION
# 1                                                                                         PRENOM : [**]
# 2                                                                                          NOM : [****]
# 3                                                            NUMÉRO DE SÉCURITÉ SOCIALE : [***********]
# 4                                                                          ADRESSE : [****************]
# 5                                                                                      VILLE : [******]
# 6                                                                                   CODE POSTAL : [***]
# 7                                                                        DATE DE NAISSANCE : [********]
# 8                                                                                          Âge : [****]
# 9                                Sexe : *\nCOURRIEL : [****************]\nDATE D'ADMISSION : [********]
# 10                                                                           MÉDÉCIN : [**************]
# 11  RAPPORT CLINIQUE : **ans, retraité, sans allergie médicamenteuse connue, qui présente comme anté...
# 12  ** nous a été adressé car ** présentait une hématurie macroscopique postmictionnelle à une occas...
# 13  L'examen physique a montré un bon état général, avec un abdomen et des organes génitaux normaux ...
# 14  L'analyse d'urine a montré 4 globules rouges/champ et 0-5 leucocytes/champ ; le reste du sédimen...
# 15                                                                                   PSA de 1,16 ng/ml.
# 16  ADDRESSÉ À : [**************] - [****************************] Service D'Endocrinologie et de Nu...
# 17                                                                      COURRIEL : [****************]\n
#
#                                                                                 Masked with Fixed Chars  \
# 0                                                                        COMPTE-RENDU D'HOSPITALISATION
# 1                                                                                         PRENOM : ****
# 2                                                                                            NOM : ****
# 3                                                                     NUMÉRO DE SÉCURITÉ SOCIALE : ****
# 4                                                                                        ADRESSE : ****
# 5                                                                                          VILLE : ****
# 6                                                                                    CODE POSTAL : ****
# 7                                                                              DATE DE NAISSANCE : ****
# 8                                                                                            Âge : ****
# 9                                                 Sexe : ****\nCOURRIEL : ****\nDATE D'ADMISSION : ****
# 10                                                                                       MÉDÉCIN : ****
# 11  RAPPORT CLINIQUE : ****ans, retraité, sans allergie médicamenteuse connue, qui présente comme an...
# 12  **** nous a été adressé car **** présentait une hématurie macroscopique postmictionnelle à une o...
# 13  L'examen physique a montré un bon état général, avec un abdomen et des organes génitaux normaux ...
# 14  L'analyse d'urine a montré 4 globules rouges/champ et 0-5 leucocytes/champ ; le reste du sédimen...
# 15                                                                                   PSA de 1,16 ng/ml.
# 16                   ADDRESSÉ À : **** - **** Service D'Endocrinologie et de Nutrition - ****, ********
# 17                                                                                    COURRIEL : ****\n
#
#                                                                                              Obfuscated
# 0                                                                        COMPTE-RENDU D'HOSPITALISATION
# 1                                                             PRENOM : Mme Jérôme François De La Dufour
# 2                                                                                  NOM : Mme Marie Lamy
# 3                                                            NUMÉRO DE SÉCURITÉ SOCIALE : 0431051740163
# 4                                                                         ADRESSE : Boulevard De Vallet
# 5                                                                                 VILLE : Sainte Martin
# 6                                                                                   CODE POSTAL : 83111
# 7                                                                        DATE DE NAISSANCE : 03/03/1946
# 8                                                                                          Âge : 75 ans
# 9                     Sexe : FEMME\nCOURRIEL : georgeslemonnier@live.com\nDATE D'ADMISSION : 12/12/2016
# 10                                                                                MÉDÉCIN : Dr. Sauvage
# 11  RAPPORT CLINIQUE : 75ans, retraité, sans allergie médicamenteuse connue, qui présente comme anté...
# 12  Homme nous a été adressé car homme présentait une hématurie macroscopique postmictionnelle à une...
# 13  L'examen physique a montré un bon état général, avec un abdomen et des organes génitaux normaux ...
# 14  L'analyse d'urine a montré 4 globules rouges/champ et 0-5 leucocytes/champ ; le reste du sédimen...
# 15                                                                                   PSA de 1,16 ng/ml.
# 16  ADDRESSÉ À : Dre. Martinez - Centre Hospitalier D'orthez Service D'Endocrinologie et de Nutritio...
# 17                                                              COURRIEL : massecatherine@bouygtel.fr\n

# %% [markdown]
# # DE-IDENTIFICATION FOR ITALIAN

# %% [markdown]
# ## Italian NER Deidentification Models
# We have two different models you can use:
# * `ner_deid_generic`, detects 8 entities
# * `ner_deid_subentity`, detects 19 entities

# %% [markdown]
# |index|model|lang|index|model|lang|
# |-----:|:-----|----|-----:|:-----|----|
# | 1| [ner_deid_generic](https://nlp.johnsnowlabs.com/2022/03/25/ner_deid_generic_it_3_0.html)  |it| 2| [ner_deid_subentity](https://nlp.johnsnowlabs.com/2022/03/25/ner_deid_subentity_it_2_4.html)  |it|

# %% [markdown]
# Creating pipeline

# %%
documentAssembler = nlp.DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")

sentencerDL = nlp.SentenceDetectorDLModel.pretrained("sentence_detector_dl", "xx") \
    .setInputCols(["document"])\
    .setOutputCol("sentence")

tokenizer = nlp.Tokenizer()\
    .setInputCols(["sentence"])\
    .setOutputCol("token")

word_embeddings_it = nlp.WordEmbeddingsModel.pretrained("w2v_cc_300d", "it")\
    .setInputCols(["document","token"])\
	  .setOutputCol("embeddings")
# Out:
# sentence_detector_dl download started this may take some time.
# Approximate size to download 514.9 KB
# [OK!]
# w2v_cc_300d download started this may take some time.
# Approximate size to download 1.2 GB
# [OK!]

# %% [markdown]
# ###  NER Deid Generic
#
# **`ner_deid_generic`** extracts:
# - Name
# - Profession
# - Age
# - Date
# - Contact (Telephone numbers, Email addresses)
# - Location (Address, City, Postal code, Hospital Name, Organization)
# - ID (Social Security numbers, Medical record numbers)
# - Sex

# %%
ner_generic_it = medical.NerModel.pretrained("ner_deid_generic", "it", "clinical/models")\
    .setInputCols(["sentence","token","embeddings"])\
    .setOutputCol("ner_deid_generic")

ner_converter_generic = medical.NerConverterInternal()\
    .setInputCols(["sentence","token","ner_deid_generic"])\
    .setOutputCol("ner_chunk_generic")
# Out:
# ner_deid_generic download started this may take some time.
# Approximate size to download 14.3 MB
# [OK!]

# %%
ner_generic_it.getClasses()
# Out:
# ['O',
#  'I-LOCATION',
#  'I-CONTACT',
#  'I-PROFESSION',
#  'I-NAME',
#  'I-DATE',
#  'B-ID',
#  'B-CONTACT',
#  'B-PROFESSION',
#  'I-ID',
#  'B-NAME',
#  'B-DATE',
#  'B-LOCATION',
#  'B-SEX',
#  'I-SEX',
#  'B-AGE']

# %% [markdown]
# ### NER Deid Subentity
#
# **`ner_deid_subentity`** extracts:
#
# - Patient
# - Doctor
# - Hospital
# - Date
# - Organization
# - City
# - Street
# - Username
# - Profession
# - Phone
# - Country
# - Age
# - Sex
# - Email
# - ZIP
# - Medical Record Number
# - Social Security Number
# - ID Number
# - URL

# %%
ner_subentity_it = medical.NerModel.pretrained("ner_deid_subentity", "it", "clinical/models")\
    .setInputCols(["sentence","token","embeddings"])\
    .setOutputCol("ner_deid_subentity")

ner_converter_subentity = medical.NerConverterInternal()\
    .setInputCols(["sentence", "token", "ner_deid_subentity"])\
    .setOutputCol("ner_chunk_subentity")
# Out:
# ner_deid_subentity download started this may take some time.
# Approximate size to download 14.3 MB
# [OK!]

# %%
ner_subentity_it.getClasses()
# Out:
# ['O',
#  'B-MEDICALRECORD',
#  'B-ORGANIZATION',
#  'I-PROFESSION',
#  'B-DOCTOR',
#  'B-USERNAME',
#  'B-PROFESSION',
#  'B-URL',
#  'I-URL',
#  'B-CITY',
#  'B-DATE',
#  'I-MEDICALRECORD',
#  'B-SEX',
#  'B-PATIENT',
#  'I-SEX',
#  'I-DOCTOR',
#  'I-CITY',
#  'B-SSN',
#  'I-DATE',
#  'I-SSN',
#  'B-COUNTRY',
#  'B-ZIP',
#  'I-STREET',
#  'I-PATIENT',
#  'B-PHONE',
#  'I-PHONE',
#  'B-HOSPITAL',
#  'B-EMAIL',
#  'B-IDNUM',
#  'B-STREET',
#  'I-IDNUM',
#  'I-ORGANIZATION',
#  'I-HOSPITAL',
#  'B-AGE',
#  'I-COUNTRY']

# %% [markdown]
# ###  Pipeline

# %%
nlpPipeline_it = nlp.Pipeline(
    stages=[
        documentAssembler,
        sentencerDL,
        tokenizer,
        word_embeddings_it,
        ner_generic_it,
        ner_converter_generic,
        ner_subentity_it,
        ner_converter_subentity,
])

empty_data = spark.createDataFrame([[""]]).toDF("text")
model_it = nlpPipeline_it.fit(empty_data)

# %%
text = "Ho visto Gastone Montanariello (49 anni), virologo, riferito all' Ospedale San Camillo per diabete mal controllato con sintomi risalenti a marzo 2015."

text_df = spark.createDataFrame([[text]]).toDF("text")
result_it = model_it.transform(text_df)

# %% [markdown]
# Results for `ner_deid_generic`

# %%
result_it.select(F.explode(F.arrays_zip(result_it.ner_chunk_generic.result,
                                        result_it.ner_chunk_generic.metadata)).alias("cols")) \
         .select(F.expr("cols['0']").alias("chunk"),
                 F.expr("cols['1']['entity']").alias("ner_label")).show(truncate=False)
# Out:
# +---------------------+----------+
# |chunk                |ner_label |
# +---------------------+----------+
# |Gastone Montanariello|NAME      |
# |49                   |AGE       |
# |virologo             |PROFESSION|
# |Ospedale San Camillo |LOCATION  |
# |marzo 2015           |DATE      |
# +---------------------+----------+

# %% [markdown]
# Results for `ner_deid_subentity`

# %%
result_it.select(F.explode(F.arrays_zip(result_it.ner_chunk_subentity.result,
                                        result_it.ner_chunk_subentity.metadata)).alias("cols")) \
         .select(F.expr("cols['0']").alias("chunk"),
                 F.expr("cols['1']['entity']").alias("ner_label")).show(truncate=False)
# Out:
# +---------------------+----------+
# |chunk                |ner_label |
# +---------------------+----------+
# |Gastone Montanariello|PATIENT   |
# |49                   |AGE       |
# |virologo             |PROFESSION|
# |Ospedale San Camillo |HOSPITAL  |
# |marzo 2015           |DATE      |
# +---------------------+----------+

# %% [markdown]
# ## DeIdentification

# %% [markdown]
# ### Obfuscation mode

# %%
# Downloading faker entity list.
! wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/obfuscate_it.txt

# %%
deid_masked_entity = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"])\
    .setOutputCol("masked_with_entity")\
    .setMode("mask")\
    .setMaskingPolicy("entity_labels")

deid_masked_char = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"])\
    .setOutputCol("masked_with_chars")\
    .setMode("mask")\
    .setMaskingPolicy("same_length_chars")

deid_masked_fixed_char = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"])\
    .setOutputCol("masked_fixed_length_chars")\
    .setMode("mask")\
    .setMaskingPolicy("fixed_length_chars")\
    .setFixedMaskLength(4)

deid_obfuscated = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"]) \
    .setOutputCol("obfuscated") \
    .setMode("obfuscate")\
    .setObfuscateDate(True)\
    .setObfuscateRefFile('obfuscate_it.txt')\
    .setObfuscateRefSource("file")

# %%
nlpPipeline_it = nlp.Pipeline(
    stages=[
        documentAssembler,
        sentencerDL,
        tokenizer,
        word_embeddings_it,
        ner_subentity_it,
        ner_converter_subentity,
        deid_masked_entity,
        deid_masked_char,
        deid_masked_fixed_char,
        deid_obfuscated
])

empty_data = spark.createDataFrame([[""]]).toDF("text")
model_it = nlpPipeline_it.fit(empty_data)

# %%
deid_lp_it = nlp.LightPipeline(model_it)

# %%
text = "Ho visto Gastone Montanariello (49 anni), virologo, riferito all' Ospedale San Camillo per diabete mal controllato con sintomi risalenti a marzo 2015."

# %%
pd.set_option("display.max_colwidth", 200)

result_it = deid_lp_it.annotate(text)

df_it = pd.DataFrame(list(zip(result_it["masked_with_entity"],
                              result_it["masked_with_chars"],
                              result_it["masked_fixed_length_chars"],
                              result_it["obfuscated"])),
                 columns= ["Masked_with_entity", "Masked with Chars", "Masked with Fixed Chars", "Obfuscated"])

df_it
# Out:
#                                                                                                                     Masked_with_entity  \
# 0  Ho visto <PATIENT> (<AGE> anni), <PROFESSION>, riferito all' <HOSPITAL> per diabete mal controllato con sintomi risalenti a <DATE>.
#
#                                                                                                                                         Masked with Chars  \
# 0  Ho visto [*******************] (** anni), [******], riferito all' [******************] per diabete mal controllato con sintomi risalenti a [********].
#
#                                                                                          Masked with Fixed Chars  \
# 0  Ho visto **** (**** anni), ****, riferito all' **** per diabete mal controllato con sintomi risalenti a ****.
#
#                                                                                                                                   Obfuscated
# 0  Ho visto Mario Nonis (42 anni), gemmologo, riferito all' Azienda Usl Fg-1 per diabete mal controllato con sintomi risalenti a marzo 1815.

# %% [markdown]
# ### Faker mode

# %%
deid_obfuscated = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"]) \
    .setOutputCol("obfuscated") \
    .setMode("obfuscate")\
    .setLanguage('it')\
    .setObfuscateDate(True)\
    .setObfuscateRefSource('faker')

# %%
nlpPipeline_it = nlp.Pipeline(
    stages=[
        documentAssembler,
        sentencerDL,
        tokenizer,
        word_embeddings_it,
        ner_subentity_it,
        ner_converter_subentity,
        deid_masked_entity,
        deid_masked_char,
        deid_masked_fixed_char,
        deid_obfuscated
])

empty_data = spark.createDataFrame([[""]]).toDF("text")
model_it = nlpPipeline_it.fit(empty_data)

# %%
deid_lp_it = nlp.LightPipeline(model_it)

# %%
text = "Ho visto Gastone Montanariello (49 anni), virologo, riferito all' Ospedale San Camillo per diabete mal controllato con sintomi risalenti a marzo 2015."

# %%
pd.set_option("display.max_colwidth", 200)

result_it = deid_lp_it.annotate(text)

df_it = pd.DataFrame(list(zip(result_it["masked_with_entity"],
                              result_it["masked_with_chars"],
                              result_it["masked_fixed_length_chars"],
                              result_it["obfuscated"])),
                 columns= ["Masked_with_entity", "Masked with Chars", "Masked with Fixed Chars", "Obfuscated"])

df_it
# Out:
#                                                                                                                     Masked_with_entity  \
# 0  Ho visto <PATIENT> (<AGE> anni), <PROFESSION>, riferito all' <HOSPITAL> per diabete mal controllato con sintomi risalenti a <DATE>.
#
#                                                                                                                                         Masked with Chars  \
# 0  Ho visto [*******************] (** anni), [******], riferito all' [******************] per diabete mal controllato con sintomi risalenti a [********].
#
#                                                                                          Masked with Fixed Chars  \
# 0  Ho visto **** (**** anni), ****, riferito all' **** per diabete mal controllato con sintomi risalenti a ****.
#
#                                                                                                                                                               Obfuscated
# 0  Ho visto Jacqulyne Carne (42 anni), hospital doctor, riferito all' Las Vegas - Amg Specialty Hospital per diabete mal controllato con sintomi risalenti a marzo 0115.

# %% [markdown]
# ## Pretrained Italian Deidentification Pipeline
#
# - We developed a clinical deidentification pretrained pipeline that can be used to deidentify PHI information from Italian medical texts. The PHI information will be masked and obfuscated in the resulting text.
# - The pipeline can mask and obfuscate:
#     - Patient
#     - Doctor
#     - Hospital
#     - Date
#     - Organization
#     - Sex
#     - City
#     - Street
#     - Country
#     - ZIP
#     - Username
#     - Profession
#     - Phone
#     - Email
#     - Age
#     - ID number
#     - Medical record number
#     - Account number
#     - SSN
#     - Plate Number
#     - IP address
#     - URL

# %%
deid_pipeline_it = nlp.PretrainedPipeline("clinical_deidentification", "it", "clinical/models")
# Out:
# clinical_deidentification download started this may take some time.
# Approx size to download 1.2 GB
# [OK!]

# %%
text = """RAPPORTO DI RICOVERO
NOME: Lodovico Fibonacci
CODICE FISCALE: MVANSK92F09W408A
INDIRIZZO: Viale Burcardo 7
CITTÀ : Napoli
CODICE POSTALE: 80139
DATA DI NASCITA: 03/03/1946
ETÀ: 70 anni
SESSO: M
EMAIL: lpizzo@tim.it
DATA DI AMMISSIONE: 12/12/2016
DOTTORE: Eva Viviani
RAPPORTO CLINICO: 70 anni, pensionato, senza allergie farmacologiche note, che presenta la seguente storia: ex incidente sul lavoro con fratture vertebrali e costali; operato per la malattia di Dupuytren alla mano destra e un bypass ileo-femorale sinistro; diabete di tipo II, ipercolesterolemia e iperuricemia; alcolismo attivo, fuma 20 sigarette/giorno.
È stato indirizzato a noi perché ha presentato un'ematuria macroscopica post-evacuazione in un'occasione e una microematuria persistente in seguito, con un'evacuazione normale.
L'esame fisico ha mostrato buone condizioni generali, con addome e genitali normali; l'esame digitale rettale era coerente con un adenoma prostatico di grado I/IV.
L'analisi delle urine ha mostrato 4 globuli rossi/campo e 0-5 leucociti/campo; il resto del sedimento era normale.
L'emocromo è normale; la biochimica ha mostrato una glicemia di 169 mg/dl e trigliceridi 456 mg/dl; la funzione epatica e renale sono normali. PSA di 1,16 ng/ml.

INDIRIZZATO A: Dott. Bruno Ferrabosco - ASL Napoli 1 Centro, Dipartimento di Endocrinologia e Nutrizione - Stretto Scamarcio 320, 80138 Napoli
EMAIL: bferrabosco@poste.it
"""

# %%
pd.set_option("display.max_colwidth", None)

result_it = deid_pipeline_it.annotate(text)

df_it = pd.DataFrame(list(zip(result_it["sentence"],
                              result_it["masked"],
                              result_it["masked_with_chars"],
                              result_it["masked_fixed_length_chars"],
                              result_it["obfuscated"])),
                 columns= ["Sentence", "Masked", "Masked with Chars", "Masked with Fixed Chars", "Obfuscated"])

df_it
# Out:
#                                                                                                                                                                                                                                                                                                                                                                Sentence  \
# 0                                                                                                                                                                                                                                                                                                                                                  RAPPORTO DI RICOVERO
# 1                                                                                                                                                                                                                                                                                                                                              NOME: Lodovico Fibonacci
# 2                                                                                                                                                                                                                                                                                                                                      CODICE FISCALE: MVANSK92F09W408A
# 3                                                                                                                                                                                                                                                                                                                           INDIRIZZO: Viale Burcardo 7\nCITTÀ : Napoli
# 4                                                                                                                                                                                                                                                                                                      CODICE POSTALE: 80139\nDATA DI NASCITA: 03/03/1946\nETÀ: 70 anni
# 5                                                                                                                                                                                                                                                                                                        SESSO: M\nEMAIL: lpizzo@tim.it\nDATA DI AMMISSIONE: 12/12/2016
# 6                                                                                                                                                                                                                                                                                                                                                  DOTTORE: Eva Viviani
# 7   RAPPORTO CLINICO: 70 anni, pensionato, senza allergie farmacologiche note, che presenta la seguente storia: ex incidente sul lavoro con fratture vertebrali e costali; operato per la malattia di Dupuytren alla mano destra e un bypass ileo-femorale sinistro; diabete di tipo II, ipercolesterolemia e iperuricemia; alcolismo attivo, fuma 20 sigarette/giorno.
# 8                                                                                                                                                                                      È stato indirizzato a noi perché ha presentato un'ematuria macroscopica post-evacuazione in un'occasione e una microematuria persistente in seguito, con un'evacuazione normale.
# 9                                                                                                                                                                                                   L'esame fisico ha mostrato buone condizioni generali, con addome e genitali normali; l'esame digitale rettale era coerente con un adenoma prostatico di grado I/IV.
# 10                                                                                                                                                                                                                                                   L'analisi delle urine ha mostrato 4 globuli rossi/campo e 0-5 leucociti/campo; il resto del sedimento era normale.
# 11                                                                                                                                                                                                                       L'emocromo è normale; la biochimica ha mostrato una glicemia di 169 mg/dl e trigliceridi 456 mg/dl; la funzione epatica e renale sono normali.
# 12                                                                                                                                                                                                                                                                                                                                                   PSA di 1,16 ng/ml.
# 13                                                                                                                                                                                                                                                                                                                                                 INDIRIZZATO A: Dott.
# 14                                                                                                                                                                                                                                            Bruno Ferrabosco - ASL Napoli 1 Centro, Dipartimento di Endocrinologia e Nutrizione - Stretto Scamarcio 320, 80138 Napoli
# 15                                                                                                                                                                                                                                                                                                                                        EMAIL: bferrabosco@poste.it\n
#
#                                                                                                                                                                                                                                                                                                                                                                    Masked  \
# 0                                                                                                                                                                                                                                                                                                                                                    RAPPORTO DI RICOVERO
# 1                                                                                                                                                                                                                                                                                                                                                         NOME: <PATIENT>
# 2                                                                                                                                                                                                                                                                                                                                                   CODICE FISCALE: <SSN>
# 3                                                                                                                                                                                                                                                                                                                                     INDIRIZZO: <STREET>\nCITTÀ : <CITY>
# 4                                                                                                                                                                                                                                                                                                            CODICE POSTALE: <ZIP>DATA DI NASCITA: <DATE>\nETÀ: <AGE>anni
# 5                                                                                                                                                                                                                                                                                                               SESSO: <SEX>\nEMAIL: <E-MAIL>\nDATA DI AMMISSIONE: <DATE>
# 6                                                                                                                                                                                                                                                                                                                                                       DOTTORE: <DOCTOR>
# 7   RAPPORTO CLINICO: <AGE>anni, pensionato, senza allergie farmacologiche note, che presenta la seguente storia: ex incidente sul lavoro con fratture vertebrali e costali; operato per la malattia di Dupuytren alla mano destra e un bypass ileo-femorale sinistro; diabete di tipo II, ipercolesterolemia e iperuricemia; alcolismo attivo, fuma 20 sigarette/giorno.
# 8                                                                                                                                                                                        È stato indirizzato a noi perché ha presentato un'ematuria macroscopica post-evacuazione in un'occasione e una microematuria persistente in seguito, con un'evacuazione normale.
# 9                                                                                                                                                                                                     L'esame fisico ha mostrato buone condizioni generali, con addome e genitali normali; l'esame digitale rettale era coerente con un adenoma prostatico di grado I/IV.
# 10                                                                                                                                                                                                                                                     L'analisi delle urine ha mostrato 4 globuli rossi/campo e 0-5 leucociti/campo; il resto del sedimento era normale.
# 11                                                                                                                                                                                                                         L'emocromo è normale; la biochimica ha mostrato una glicemia di 169 mg/dl e trigliceridi 456 mg/dl; la funzione epatica e renale sono normali.
# 12                                                                                                                                                                                                                                                                                                                                                     PSA di 1,16 ng/ml.
# 13                                                                                                                                                                                                                                                                                                                                                   INDIRIZZATO A: Dott.
# 14                                                                                                                                                                                                                                                                            <DOCTOR> - <HOSPITAL>, Dipartimento di Endocrinologia e Nutrizione - <STREET>, <ZIP> <CITY>
# 15                                                                                                                                                                                                                                                                                                                                                      EMAIL: <E-MAIL>\n
#
#                                                                                                                                                                                                                                                                                                                                                      Masked with Chars  \
# 0                                                                                                                                                                                                                                                                                                                                                 RAPPORTO DI RICOVERO
# 1                                                                                                                                                                                                                                                                                                                                             NOME: [****************]
# 2                                                                                                                                                                                                                                                                                                                                     CODICE FISCALE: [**************]
# 3                                                                                                                                                                                                                                                                                                                          INDIRIZZO: [**************]\nCITTÀ : [****]
# 4                                                                                                                                                                                                                                                                                                        CODICE POSTALE: [***]DATA DI NASCITA: [********]\nETÀ: **anni
# 5                                                                                                                                                                                                                                                                                                       SESSO: *\nEMAIL: [***********]\nDATA DI AMMISSIONE: [********]
# 6                                                                                                                                                                                                                                                                                                                                                 DOTTORE: [*********]
# 7   RAPPORTO CLINICO: **anni, pensionato, senza allergie farmacologiche note, che presenta la seguente storia: ex incidente sul lavoro con fratture vertebrali e costali; operato per la malattia di Dupuytren alla mano destra e un bypass ileo-femorale sinistro; diabete di tipo II, ipercolesterolemia e iperuricemia; alcolismo attivo, fuma 20 sigarette/giorno.
# 8                                                                                                                                                                                     È stato indirizzato a noi perché ha presentato un'ematuria macroscopica post-evacuazione in un'occasione e una microematuria persistente in seguito, con un'evacuazione normale.
# 9                                                                                                                                                                                                  L'esame fisico ha mostrato buone condizioni generali, con addome e genitali normali; l'esame digitale rettale era coerente con un adenoma prostatico di grado I/IV.
# 10                                                                                                                                                                                                                                                  L'analisi delle urine ha mostrato 4 globuli rossi/campo e 0-5 leucociti/campo; il resto del sedimento era normale.
# 11                                                                                                                                                                                                                      L'emocromo è normale; la biochimica ha mostrato una glicemia di 169 mg/dl e trigliceridi 456 mg/dl; la funzione epatica e renale sono normali.
# 12                                                                                                                                                                                                                                                                                                                                                  PSA di 1,16 ng/ml.
# 13                                                                                                                                                                                                                                                                                                                                                INDIRIZZATO A: Dott.
# 14                                                                                                                                                                                                                                           [**************] - [*****************], Dipartimento di Endocrinologia e Nutrizione - [*******************], [***] [****]
# 15                                                                                                                                                                                                                                                                                                                                       EMAIL: [******************]\n
#
#                                                                                                                                                                                                                                                                                                                                                  Masked with Fixed Chars  \
# 0                                                                                                                                                                                                                                                                                                                                                   RAPPORTO DI RICOVERO
# 1                                                                                                                                                                                                                                                                                                                                                             NOME: ****
# 2                                                                                                                                                                                                                                                                                                                                                   CODICE FISCALE: ****
# 3                                                                                                                                                                                                                                                                                                                                          INDIRIZZO: ****\nCITTÀ : ****
# 4                                                                                                                                                                                                                                                                                                               CODICE POSTALE: ****DATA DI NASCITA: ****\nETÀ: ****anni
# 5                                                                                                                                                                                                                                                                                                                     SESSO: ****\nEMAIL: ****\nDATA DI AMMISSIONE: ****
# 6                                                                                                                                                                                                                                                                                                                                                          DOTTORE: ****
# 7   RAPPORTO CLINICO: ****anni, pensionato, senza allergie farmacologiche note, che presenta la seguente storia: ex incidente sul lavoro con fratture vertebrali e costali; operato per la malattia di Dupuytren alla mano destra e un bypass ileo-femorale sinistro; diabete di tipo II, ipercolesterolemia e iperuricemia; alcolismo attivo, fuma 20 sigarette/giorno.
# 8                                                                                                                                                                                       È stato indirizzato a noi perché ha presentato un'ematuria macroscopica post-evacuazione in un'occasione e una microematuria persistente in seguito, con un'evacuazione normale.
# 9                                                                                                                                                                                                    L'esame fisico ha mostrato buone condizioni generali, con addome e genitali normali; l'esame digitale rettale era coerente con un adenoma prostatico di grado I/IV.
# 10                                                                                                                                                                                                                                                    L'analisi delle urine ha mostrato 4 globuli rossi/campo e 0-5 leucociti/campo; il resto del sedimento era normale.
# 11                                                                                                                                                                                                                        L'emocromo è normale; la biochimica ha mostrato una glicemia di 169 mg/dl e trigliceridi 456 mg/dl; la funzione epatica e renale sono normali.
# 12                                                                                                                                                                                                                                                                                                                                                    PSA di 1,16 ng/ml.
# 13                                                                                                                                                                                                                                                                                                                                                  INDIRIZZATO A: Dott.
# 14                                                                                                                                                                                                                                                                                            **** - ****, Dipartimento di Endocrinologia e Nutrizione - ****, **** ****
# 15                                                                                                                                                                                                                                                                                                                                                         EMAIL: ****\n
#
#                                                                                                                                                                                                                                                                                                                                                             Obfuscated
# 0                                                                                                                                                                                                                                                                                                                                                 RAPPORTO DI RICOVERO
# 1                                                                                                                                                                                                                                                                                                                                                      NOME: Cherubini
# 2                                                                                                                                                                                                                                                                                                                                     CODICE FISCALE: BEXKDJ25Q32N731X
# 3                                                                                                                                                                                                                                                                                                       INDIRIZZO: Canale Adamo 11 Piano 7\nCITTÀ : Lodovico Salentino
# 4                                                                                                                                                                                                                                                                                                        CODICE POSTALE: 13462DATA DI NASCITA: 03/03/1946\nETÀ: 79anni
# 5                                                                                                                                                                                                                                                                                               SESSO: U\nEMAIL: henrywatson@world.com\nDATA DI AMMISSIONE: 12/12/2016
# 6                                                                                                                                                                                                                                                                                                                                                   DOTTORE: Schiavone
# 7   RAPPORTO CLINICO: 79anni, pensionato, senza allergie farmacologiche note, che presenta la seguente storia: ex incidente sul lavoro con fratture vertebrali e costali; operato per la malattia di Dupuytren alla mano destra e un bypass ileo-femorale sinistro; diabete di tipo II, ipercolesterolemia e iperuricemia; alcolismo attivo, fuma 20 sigarette/giorno.
# 8                                                                                                                                                                                     È stato indirizzato a noi perché ha presentato un'ematuria macroscopica post-evacuazione in un'occasione e una microematuria persistente in seguito, con un'evacuazione normale.
# 9                                                                                                                                                                                                  L'esame fisico ha mostrato buone condizioni generali, con addome e genitali normali; l'esame digitale rettale era coerente con un adenoma prostatico di grado I/IV.
# 10                                                                                                                                                                                                                                                  L'analisi delle urine ha mostrato 4 globuli rossi/campo e 0-5 leucociti/campo; il resto del sedimento era normale.
# 11                                                                                                                                                                                                                      L'emocromo è normale; la biochimica ha mostrato una glicemia di 169 mg/dl e trigliceridi 456 mg/dl; la funzione epatica e renale sono normali.
# 12                                                                                                                                                                                                                                                                                                                                                  PSA di 1,16 ng/ml.
# 13                                                                                                                                                                                                                                                                                                                                                INDIRIZZATO A: Dott.
# 14                                                                                                                                                                                                                     Annamaria Taliani - Asl 7 Di Carbonia Azienda U.s.l. N. 7, Dipartimento di Endocrinologia e Nutrizione - Via Gaito 89, 13461 Lodovico Salentino
# 15                                                                                                                                                                                                                                                                                                                                            EMAIL: murat.g@jsl.com\n

# %% [markdown]
# # DE-IDENTIFICATION FOR PORTUGUESE

# %% [markdown]
# ## Potuguese NER Deidentification Models
# We have two different models you can use:
# * `ner_deid_generic`, detects 8 entities
# * `ner_deid_subentity`, detects 19 entities

# %% [markdown]
# |index|model|lang|index|model|lang|
# |-----:|:-----|----|-----:|:-----|----|
# | 1| [ner_deid_generic](https://nlp.johnsnowlabs.com/2022/04/13/ner_deid_generic_pt_3_0.html)  |pt| 2| [ner_deid_subentity](https://nlp.johnsnowlabs.com/2022/04/13/ner_deid_subentity_pt_3_0.html)  |pt|

# %% [markdown]
# Creating pipeline

# %%
documentAssembler = nlp.DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")

sentencerDL = nlp.SentenceDetectorDLModel.pretrained("sentence_detector_dl", "xx") \
    .setInputCols(["document"])\
    .setOutputCol("sentence")

tokenizer = nlp.Tokenizer()\
    .setInputCols(["sentence"])\
    .setOutputCol("token")

word_embeddings_pt = nlp.WordEmbeddingsModel.pretrained("w2v_cc_300d", "pt")\
    .setInputCols(["document","token"])\
	  .setOutputCol("embeddings")
# Out:
# sentence_detector_dl download started this may take some time.
# Approximate size to download 514.9 KB
# [OK!]
# w2v_cc_300d download started this may take some time.
# Approximate size to download 1.1 GB
# [OK!]

# %% [markdown]
# ### NER Deid Generic
#
# **`ner_deid_generic`** extracts:
# - Name
# - Profession
# - Age
# - Date
# - Contact (Telephone numbers, Email addresses)
# - Location (Address, City, Postal code, Hospital Name, Organization)
# - ID (Social Security numbers, Medical record numbers)
# - Sex

# %%
ner_generic_pt = medical.NerModel.pretrained("ner_deid_generic", "pt", "clinical/models")\
    .setInputCols(["sentence","token","embeddings"])\
    .setOutputCol("ner_deid_generic")

ner_converter_generic = medical.NerConverterInternal()\
    .setInputCols(["sentence","token","ner_deid_generic"])\
    .setOutputCol("ner_chunk_generic")
# Out:
# ner_deid_generic download started this may take some time.
# Approximate size to download 14.3 MB
# [OK!]

# %%
ner_generic_pt.getClasses()
# Out:
# ['O',
#  'I-LOCATION',
#  'I-CONTACT',
#  'I-PROFESSION',
#  'I-NAME',
#  'I-DATE',
#  'B-ID',
#  'B-PROFESSION',
#  'B-CONTACT',
#  'I-ID',
#  'B-NAME',
#  'B-DATE',
#  'B-LOCATION',
#  'B-SEX',
#  'I-SEX',
#  'B-AGE']

# %% [markdown]
# ### NER Deid Subentity
#
# **`ner_deid_subentity`** extracts:
#
# `PATIENT`, `HOSPITAL`, `DATE`, `ORGANIZATION`, `CITY`, `ID`, `STREET`, `SEX`, `EMAIL`, `ZIP`, `PROFESSION`, `PHONE`, `COUNTRY`, `DOCTOR`, `AGE`

# %%
ner_subentity_pt = medical.NerModel.pretrained("ner_deid_subentity", "pt", "clinical/models")\
    .setInputCols(["sentence","token","embeddings"])\
    .setOutputCol("ner_deid_subentity")

ner_converter_subentity = medical.NerConverterInternal()\
    .setInputCols(["sentence", "token", "ner_deid_subentity"])\
    .setOutputCol("ner_chunk_subentity")
# Out:
# ner_deid_subentity download started this may take some time.
# Approximate size to download 14.3 MB
# [OK!]

# %%
ner_subentity_pt.getClasses()
# Out:
# ['O',
#  'B-ORGANIZATION',
#  'I-PROFESSION',
#  'B-DOCTOR',
#  'B-PROFESSION',
#  'I-ID',
#  'B-CITY',
#  'B-DATE',
#  'B-PATIENT',
#  'B-SEX',
#  'I-SEX',
#  'I-DOCTOR',
#  'I-CITY',
#  'I-DATE',
#  'B-COUNTRY',
#  'B-ID',
#  'B-ZIP',
#  'I-STREET',
#  'I-PATIENT',
#  'B-PHONE',
#  'I-PHONE',
#  'B-HOSPITAL',
#  'B-EMAIL',
#  'B-STREET',
#  'I-ORGANIZATION',
#  'I-HOSPITAL',
#  'B-AGE',
#  'I-COUNTRY']

# %% [markdown]
# ### Pipeline

# %%
nlpPipeline_pt = nlp.Pipeline(
    stages=[
        documentAssembler,
        sentencerDL,
        tokenizer,
        word_embeddings_pt,
        ner_generic_pt,
        ner_converter_generic,
        ner_subentity_pt,
        ner_converter_subentity,
])

empty_data = spark.createDataFrame([[""]]).toDF("text")
model_pt = nlpPipeline_pt.fit(empty_data)

# %%
text = """Detalhes do paciente.
Nome do paciente:  Pedro Gonçalves
NHC: 2569870.
Endereço: Rua Das Flores 23.
Código Postal: 21754-987.
Dados de cuidados.
Data de nascimento: 10/10/1963.
Idade: 53 anos
Data de admissão: 17/06/2016.
Doutora: Maria Santos"""

text_df = spark.createDataFrame([[text]]).toDF("text")
result_pt = model_pt.transform(text_df)

# %% [markdown]
# Results for `ner_deid_generic`

# %%
result_pt.select(F.explode(F.arrays_zip(result_pt.ner_chunk_generic.result,
                                        result_pt.ner_chunk_generic.metadata)).alias("cols")) \
         .select(F.expr("cols['0']").alias("chunk"),
                 F.expr("cols['1']['entity']").alias("ner_label")).show(truncate=False)
# Out:
# +-----------------+---------+
# |chunk            |ner_label|
# +-----------------+---------+
# |Pedro Gonçalves  |NAME     |
# |2569870          |ID       |
# |Rua Das Flores 23|LOCATION |
# |21754-987        |LOCATION |
# |10/10/1963       |DATE     |
# |53               |AGE      |
# |17/06/2016       |DATE     |
# |Maria Santos     |NAME     |
# +-----------------+---------+

# %% [markdown]
# Results for `ner_deid_subentity`

# %%
result_pt.select(F.explode(F.arrays_zip(result_pt.ner_chunk_subentity.result,
                                        result_pt.ner_chunk_subentity.metadata)).alias("cols")) \
         .select(F.expr("cols['0']").alias("chunk"),
                 F.expr("cols['1']['entity']").alias("ner_label")).show(truncate=False)
# Out:
# +-----------------+---------+
# |chunk            |ner_label|
# +-----------------+---------+
# |Pedro Gonçalves  |PATIENT  |
# |2569870          |ID       |
# |Rua Das Flores 23|STREET   |
# |21754-987        |ZIP      |
# |10/10/1963       |DATE     |
# |53               |AGE      |
# |17/06/2016       |DATE     |
# |Maria Santos     |DOCTOR   |
# +-----------------+---------+

# %% [markdown]
# ## DeIdentification

# %% [markdown]
# ### Obfuscation mode

# %%
# Downloading faker entity list.
! wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/obfuscate_pt.txt

# %%
deid_masked_entity = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"])\
    .setOutputCol("masked_with_entity")\
    .setMode("mask")\
    .setMaskingPolicy("entity_labels")

deid_masked_char = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"])\
    .setOutputCol("masked_with_chars")\
    .setMode("mask")\
    .setMaskingPolicy("same_length_chars")

deid_masked_fixed_char = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"])\
    .setOutputCol("masked_fixed_length_chars")\
    .setMode("mask")\
    .setMaskingPolicy("fixed_length_chars")\
    .setFixedMaskLength(4)

deid_obfuscated = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"]) \
    .setOutputCol("obfuscated") \
    .setMode("obfuscate")\
    .setObfuscateDate(True)\
    .setObfuscateRefFile('obfuscate_pt.txt')\
    .setObfuscateRefSource("file")

# %%
nlpPipeline_pt = nlp.Pipeline(
    stages=[
      documentAssembler,
      sentencerDL,
      tokenizer,
      word_embeddings_pt,
      ner_subentity_pt,
      ner_converter_subentity,
      deid_masked_entity,
      deid_masked_char,
      deid_masked_fixed_char,
      deid_obfuscated
])

empty_data = spark.createDataFrame([[""]]).toDF("text")
model_pt = nlpPipeline_pt.fit(empty_data)

# %%
deid_lp_pt = nlp.LightPipeline(model_pt)

# %%
text = """Detalhes do paciente.
Nome do paciente: Antonio Gonçalves
NHC: 2569870.
Endereço: Rua Das Flores 23.
Código Postal: 21754-987.
Dados de cuidados.
Data de nascimento: 10/10/1963.
Idade: 23 anos
Data de admissão: 17/06/2016.
Doutora: Maria Santos"""

# %%
pd.set_option("display.max_colwidth", 200)

result_pt = deid_lp_pt.annotate(text)

df_pt = pd.DataFrame(list(zip(result_pt["sentence"],
                              result_pt["masked_with_entity"],
                              result_pt["masked_with_chars"],
                              result_pt["masked_fixed_length_chars"],
                              result_pt["obfuscated"])),
                 columns= ["Sentence", "Masked_with_entity", "Masked with Chars", "Masked with Fixed Chars", "Obfuscated"])

df_pt
# Out:
#                                                   Sentence  \
# 0                                    Detalhes do paciente.
# 1                      Nome do paciente: Antonio Gonçalves
# 2                                            NHC: 2569870.
# 3  Endereço: Rua Das Flores 23.\nCódigo Postal: 21754-987.
# 4                                       Dados de cuidados.
# 5                          Data de nascimento: 10/10/1963.
# 6                                           Idade: 23 anos
# 7                            Data de admissão: 17/06/2016.
# 8                                  \nDoutora: Maria Santos
#
#                            Masked_with_entity  \
# 0                       Detalhes do paciente.
# 1                 Nome do paciente: <PATIENT>
# 2                                  NHC: <ID>.
# 3  Endereço: <STREET>.\nCódigo Postal: <ZIP>.
# 4                          Dados de cuidados.
# 5                 Data de nascimento: <DATE>.
# 6                           Idade: <AGE> anos
# 7                   Data de admissão: <DATE>.
# 8                         \nDoutora: <DOCTOR>
#
#                                          Masked with Chars  \
# 0                                    Detalhes do paciente.
# 1                      Nome do paciente: [***************]
# 2                                            NHC: [*****].
# 3  Endereço: [***************].\nCódigo Postal: [*******].
# 4                                       Dados de cuidados.
# 5                          Data de nascimento: [********].
# 6                                           Idade: ** anos
# 7                            Data de admissão: [********].
# 8                                  \nDoutora: [**********]
#
#                  Masked with Fixed Chars  \
# 0                  Detalhes do paciente.
# 1                 Nome do paciente: ****
# 2                             NHC: ****.
# 3  Endereço: ****.\nCódigo Postal: ****.
# 4                     Dados de cuidados.
# 5              Data de nascimento: ****.
# 6                       Idade: **** anos
# 7                Data de admissão: ****.
# 8                        \nDoutora: ****
#
#                                                             Obfuscated
# 0                                                Detalhes do paciente.
# 1                                         Nome do paciente: Nascimento
# 2                                                        NHC: 5218907.
# 3  Endereço: Av Da Quinta Do Guarda-mor, 9.\nCódigo Postal: 56023-890.
# 4                                                   Dados de cuidados.
# 5                                      Data de nascimento: 19/11/1963.
# 6                                                       Idade: 26 anos
# 7                                        Data de admissão: 27/07/2016.
# 8                                                 \nDoutora: Sebastião

# %% [markdown]
# ### Faker mode

# %%
deid_obfuscated_faker = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"]) \
    .setOutputCol("obfuscated") \
    .setMode("obfuscate")\
    .setLanguage('pt')\
    .setObfuscateDate(True)\
    .setObfuscateRefSource('faker')

# %%
nlpPipeline_pt = nlp.Pipeline(
    stages=[
        documentAssembler,
        sentencerDL,
        tokenizer,
        word_embeddings_pt,
        ner_subentity_pt,
        ner_converter_subentity,
        deid_masked_entity,
        deid_masked_char,
        deid_masked_fixed_char,
        deid_obfuscated_faker
])

empty_data = spark.createDataFrame([[""]]).toDF("text")
model_pt = nlpPipeline_pt.fit(empty_data)

# %%
deid_lp_pt = nlp.LightPipeline(model_pt)

# %%
pd.set_option("display.max_colwidth", 200)

result_pt = deid_lp_pt.annotate(text)

df_pt = pd.DataFrame(list(zip(result_pt["sentence"],
                              result_pt["masked_with_entity"],
                              result_pt["masked_with_chars"],
                              result_pt["masked_fixed_length_chars"],
                              result_pt["obfuscated"])),
                 columns= ["Sentence", "Masked_with_entity", "Masked with Chars", "Masked with Fixed Chars", "Obfuscated"])

df_pt
# Out:
#                                                   Sentence  \
# 0                                    Detalhes do paciente.
# 1                      Nome do paciente: Antonio Gonçalves
# 2                                            NHC: 2569870.
# 3  Endereço: Rua Das Flores 23.\nCódigo Postal: 21754-987.
# 4                                       Dados de cuidados.
# 5                          Data de nascimento: 10/10/1963.
# 6                                           Idade: 23 anos
# 7                            Data de admissão: 17/06/2016.
# 8                                  \nDoutora: Maria Santos
#
#                            Masked_with_entity  \
# 0                       Detalhes do paciente.
# 1                 Nome do paciente: <PATIENT>
# 2                                  NHC: <ID>.
# 3  Endereço: <STREET>.\nCódigo Postal: <ZIP>.
# 4                          Dados de cuidados.
# 5                 Data de nascimento: <DATE>.
# 6                           Idade: <AGE> anos
# 7                   Data de admissão: <DATE>.
# 8                         \nDoutora: <DOCTOR>
#
#                                          Masked with Chars  \
# 0                                    Detalhes do paciente.
# 1                      Nome do paciente: [***************]
# 2                                            NHC: [*****].
# 3  Endereço: [***************].\nCódigo Postal: [*******].
# 4                                       Dados de cuidados.
# 5                          Data de nascimento: [********].
# 6                                           Idade: ** anos
# 7                            Data de admissão: [********].
# 8                                  \nDoutora: [**********]
#
#                  Masked with Fixed Chars  \
# 0                  Detalhes do paciente.
# 1                 Nome do paciente: ****
# 2                             NHC: ****.
# 3  Endereço: ****.\nCódigo Postal: ****.
# 4                     Dados de cuidados.
# 5              Data de nascimento: ****.
# 6                       Idade: **** anos
# 7                Data de admissão: ****.
# 8                        \nDoutora: ****
#
#                                                         Obfuscated
# 0                                            Detalhes do paciente.
# 1                                  Nome do paciente: Larwance Brow
# 2                                                    NHC: 9652341.
# 3  Endereço: 425 Jack Martin Boulevard.\nCódigo Postal: 90467-234.
# 4                                               Dados de cuidados.
# 5                                  Data de nascimento: 24/10/1963.
# 6                                                   Idade: 22 anos
# 7                                    Data de admissão: 01/07/2016.
# 8                                        \nDoutora: Graeme Patella

# %% [markdown]
# ## Pretrained Portuguese Deidentification Pipeline
#
# - We developed a clinical deidentification pretrained pipeline that can be used to deidentify PHI information from Italian medical texts. The PHI information will be masked and obfuscated in the resulting text.
# - The pipeline can mask and obfuscate:
#     - Patient
#     - Doctor
#     - Hospital
#     - Date
#     - Organization
#     - Sex
#     - City
#     - Street
#     - Country
#     - ZIP
#     - Username
#     - Profession
#     - Phone
#     - Email
#     - Age
#     - ID number
#     - Medical record number
#     - Account number
#     - SSN
#     - Plate Number
#     - IP address
#     - URL

# %%
deid_pipeline_pt = nlp.PretrainedPipeline("clinical_deidentification", "pt", "clinical/models")
# Out:
# clinical_deidentification download started this may take some time.
# Approx size to download 1.2 GB
# [OK!]

# %%
text = """RELAÇÃO HOSPITALAR
NOME: Pedro Gonçalves
NHC: MVANSK92F09W408A
ENDEREÇO: Rua Burcardo 7
CÓDIGO POSTAL: 80139
DATA DE NASCIMENTO: 03/03/1946
IDADE: 70 anos
SEXO: Homens
E-MAIL: pgon21@tim.pt
DATA DE ADMISSÃO: 12/12/2016
DOUTORA: Eva Andrade
RELATO CLÍNICO: 70 anos, aposentado, sem alergia a medicamentos conhecida, com a seguinte história: ex-acidente de trabalho com fratura de vértebras e costelas; operado de doença de Dupuytren na mão direita e ponte ílio-femoral esquerda; diabetes tipo II, hipercolesterolemia e hiperuricemia; alcoolismo ativo, fuma 20 cigarros/dia.
Ele foi encaminhado a nós por apresentar hematúria macroscópica pós-evacuação em uma ocasião e microhematúria persistente posteriormente, com evacuação normal.
O exame físico mostrou bom estado geral, com abdome e genitais normais; o toque retal foi compatível com adenoma de próstata grau I/IV.
A urinálise mostrou 4 hemácias/campo e 0-5 leucócitos/campo; o resto do sedimento era normal.
O hemograma é normal; a bioquímica mostrou uma glicemia de 169 mg/dl e triglicerídeos 456 mg/dl; função hepática e renal são normais. PSA de 1,16 ng/ml.

DIRIGIDA A: Dr. Eva Andrade - Centro Hospitalar do Medio Ave - Avenida Dos Aliados, 56
E-MAIL: evandrade@poste.pt
"""

# %%
import pandas as pd

pd.set_option("display.max_colwidth", None)

result_pt = deid_pipeline_pt.annotate(text)

df_pt = pd.DataFrame(list(zip(result_pt["sentence"],
                              result_pt["masked"],
                              result_pt["masked_with_chars"],
                              result_pt["masked_fixed_length_chars"],
                              result_pt["obfuscated"])),
                 columns= ["Sentence", "Masked", "Masked with Chars", "Masked with Fixed Chars", "Obfuscated"])

df_pt
# Out:
#                                                                                                                                                                                                                                                                                                                                         Sentence  \
# 0                                                                                                                                                                                                                                                                                                      RELAÇÃO HOSPITALAR\nNOME: Pedro Gonçalves
# 1                                                                                                                                                                                                                                                                                                                          NHC: MVANSK92F09W408A
# 2                                                                                                                                                                                                                                                                                                                       ENDEREÇO: Rua Burcardo 7
# 3                                                                                                                                                                                                                                                                                           CÓDIGO POSTAL: 80139\nDATA DE NASCIMENTO: 03/03/1946
# 4                                                                                                                                                                                                                                                                                                                                 IDADE: 70 anos
# 5                                                                                                                                                                                                                                                                                                                                   SEXO: Homens
# 6                                                                                                                                                                                                                                                                                            E-MAIL: pgon21@tim.pt\nDATA DE ADMISSÃO: 12/12/2016
# 7                                                                                                                                                                                                                                                                                                                           DOUTORA: Eva Andrade
# 8   RELATO CLÍNICO: 70 anos, aposentado, sem alergia a medicamentos conhecida, com a seguinte história: ex-acidente de trabalho com fratura de vértebras e costelas; operado de doença de Dupuytren na mão direita e ponte ílio-femoral esquerda; diabetes tipo II, hipercolesterolemia e hiperuricemia; alcoolismo ativo, fuma 20 cigarros/dia.
# 9                                       Ele foi encaminhado a nós por apresentar hematúria macroscópica pós-evacuação em uma ocasião e microhematúria persistente posteriormente, com evacuação normal.\nO exame físico mostrou bom estado geral, com abdome e genitais normais; o toque retal foi compatível com adenoma de próstata grau I/IV.
# 10                                                                                                          A urinálise mostrou 4 hemácias/campo e 0-5 leucócitos/campo; o resto do sedimento era normal.\nO hemograma é normal; a bioquímica mostrou uma glicemia de 169 mg/dl e triglicerídeos 456 mg/dl; função hepática e renal são normais.
# 11                                                                                                                                                                                                                                                                                                                            PSA de 1,16 ng/ml.
# 12                                                                                                                                                                                                                                                        DIRIGIDA A: Dr. Eva Andrade - Centro Hospitalar do Medio Ave - Avenida Dos Aliados, 56
# 13                                                                                                                                                                                                                                                                                                                  E-MAIL: evandrade@poste.pt\n
#
#                                                                                                                                                                                                                                                                                                                                              Masked  \
# 0                                                                                                                                                                                                                                                                                                                RELAÇÃO HOSPITALAR\nNOME: <DOCTOR>
# 1                                                                                                                                                                                                                                                                                                                                         NHC: <ID>
# 2                                                                                                                                                                                                                                                                                                                                ENDEREÇO: <STREET>
# 3                                                                                                                                                                                                                                                                                                  CÓDIGO POSTAL: <ZIP>\nDATA DE NASCIMENTO: <DATE>
# 4                                                                                                                                                                                                                                                                                                                                 IDADE: <AGE> anos
# 5                                                                                                                                                                                                                                                                                                                                       SEXO: <SEX>
# 6                                                                                                                                                                                                                                                                                                         E-MAIL: <EMAIL>\nDATA DE ADMISSÃO: <DATE>
# 7                                                                                                                                                                                                                                                                                                                                 DOUTORA: <DOCTOR>
# 8   RELATO CLÍNICO: <AGE> anos, aposentado, sem alergia a medicamentos conhecida, com a seguinte história: ex-acidente de trabalho com fratura de vértebras e costelas; operado de doença de Dupuytren na mão direita e ponte ílio-femoral esquerda; diabetes tipo II, hipercolesterolemia e hiperuricemia; alcoolismo ativo, fuma 20 cigarros/dia.
# 9                                          Ele foi encaminhado a nós por apresentar hematúria macroscópica pós-evacuação em uma ocasião e microhematúria persistente posteriormente, com evacuação normal.\nO exame físico mostrou bom estado geral, com abdome e genitais normais; o toque retal foi compatível com adenoma de próstata grau I/IV.
# 10                                                                                                             A urinálise mostrou 4 hemácias/campo e 0-5 leucócitos/campo; o resto do sedimento era normal.\nO hemograma é normal; a bioquímica mostrou uma glicemia de 169 mg/dl e triglicerídeos 456 mg/dl; função hepática e renal são normais.
# 11                                                                                                                                                                                                                                                                                                                               PSA de 1,16 ng/ml.
# 12                                                                                                                                                                                                                                                                                      DIRIGIDA A: Dr. <DOCTOR> - Centro <HOSPITAL> - <STREET>, 56
# 13                                                                                                                                                                                                                                                                                                                                E-MAIL: <EMAIL>\n
#
#                                                                                                                                                                                                                                                                                                                                Masked with Chars  \
# 0                                                                                                                                                                                                                                                                                                      RELAÇÃO HOSPITALAR\nNOME: [*************]
# 1                                                                                                                                                                                                                                                                                                                          NHC: [**************]
# 2                                                                                                                                                                                                                                                                                                                       ENDEREÇO: [************]
# 3                                                                                                                                                                                                                                                                                           CÓDIGO POSTAL: [***]\nDATA DE NASCIMENTO: [********]
# 4                                                                                                                                                                                                                                                                                                                                 IDADE: ** anos
# 5                                                                                                                                                                                                                                                                                                                                   SEXO: [****]
# 6                                                                                                                                                                                                                                                                                            E-MAIL: [***********]\nDATA DE ADMISSÃO: [********]
# 7                                                                                                                                                                                                                                                                                                                           DOUTORA: [*********]
# 8   RELATO CLÍNICO: ** anos, aposentado, sem alergia a medicamentos conhecida, com a seguinte história: ex-acidente de trabalho com fratura de vértebras e costelas; operado de doença de Dupuytren na mão direita e ponte ílio-femoral esquerda; diabetes tipo II, hipercolesterolemia e hiperuricemia; alcoolismo ativo, fuma 20 cigarros/dia.
# 9                                       Ele foi encaminhado a nós por apresentar hematúria macroscópica pós-evacuação em uma ocasião e microhematúria persistente posteriormente, com evacuação normal.\nO exame físico mostrou bom estado geral, com abdome e genitais normais; o toque retal foi compatível com adenoma de próstata grau I/IV.
# 10                                                                                                          A urinálise mostrou 4 hemácias/campo e 0-5 leucócitos/campo; o resto do sedimento era normal.\nO hemograma é normal; a bioquímica mostrou uma glicemia de 169 mg/dl e triglicerídeos 456 mg/dl; função hepática e renal são normais.
# 11                                                                                                                                                                                                                                                                                                                            PSA de 1,16 ng/ml.
# 12                                                                                                                                                                                                                                                        DIRIGIDA A: Dr. [*********] - Centro [*********************] - [*****************], 56
# 13                                                                                                                                                                                                                                                                                                                  E-MAIL: [****************]\n
#
#                                                                                                                                                                                                                                                                                                                            Masked with Fixed Chars  \
# 0                                                                                                                                                                                                                                                                                                                   RELAÇÃO HOSPITALAR\nNOME: ****
# 1                                                                                                                                                                                                                                                                                                                                        NHC: ****
# 2                                                                                                                                                                                                                                                                                                                                   ENDEREÇO: ****
# 3                                                                                                                                                                                                                                                                                                    CÓDIGO POSTAL: ****\nDATA DE NASCIMENTO: ****
# 4                                                                                                                                                                                                                                                                                                                                 IDADE: **** anos
# 5                                                                                                                                                                                                                                                                                                                                       SEXO: ****
# 6                                                                                                                                                                                                                                                                                                             E-MAIL: ****\nDATA DE ADMISSÃO: ****
# 7                                                                                                                                                                                                                                                                                                                                    DOUTORA: ****
# 8   RELATO CLÍNICO: **** anos, aposentado, sem alergia a medicamentos conhecida, com a seguinte história: ex-acidente de trabalho com fratura de vértebras e costelas; operado de doença de Dupuytren na mão direita e ponte ílio-femoral esquerda; diabetes tipo II, hipercolesterolemia e hiperuricemia; alcoolismo ativo, fuma 20 cigarros/dia.
# 9                                         Ele foi encaminhado a nós por apresentar hematúria macroscópica pós-evacuação em uma ocasião e microhematúria persistente posteriormente, com evacuação normal.\nO exame físico mostrou bom estado geral, com abdome e genitais normais; o toque retal foi compatível com adenoma de próstata grau I/IV.
# 10                                                                                                            A urinálise mostrou 4 hemácias/campo e 0-5 leucócitos/campo; o resto do sedimento era normal.\nO hemograma é normal; a bioquímica mostrou uma glicemia de 169 mg/dl e triglicerídeos 456 mg/dl; função hepática e renal são normais.
# 11                                                                                                                                                                                                                                                                                                                              PSA de 1,16 ng/ml.
# 12                                                                                                                                                                                                                                                                                                   DIRIGIDA A: Dr. **** - Centro **** - ****, 56
# 13                                                                                                                                                                                                                                                                                                                                  E-MAIL: ****\n
#
#                                                                                                                                                                                                                                                                                                                                       Obfuscated
# 0                                                                                                                                                                                                                                                                                                         RELAÇÃO HOSPITALAR\nNOME: Vasco Soares
# 1                                                                                                                                                                                                                                                                                                                          NHC: VONAZL67M36T139N
# 2                                                                                                                                                                                                                                                                                                                      ENDEREÇO: Rua Augusta, 19
# 3                                                                                                                                                                                                                                                                                           CÓDIGO POSTAL: 93046\nDATA DE NASCIMENTO: 03/03/1946
# 4                                                                                                                                                                                                                                                                                                                                 IDADE: 77 anos
# 5                                                                                                                                                                                                                                                                                                                                   SEXO: Mulher
# 6                                                                                                                                                                                                                                                                                         E-MAIL: richard@yahoo.pt\nDATA DE ADMISSÃO: 12/12/2016
# 7                                                                                                                                                                                                                                                                                                                          DOUTORA: Eva Coutinho
# 8   RELATO CLÍNICO: 77 anos, aposentado, sem alergia a medicamentos conhecida, com a seguinte história: ex-acidente de trabalho com fratura de vértebras e costelas; operado de doença de Dupuytren na mão direita e ponte ílio-femoral esquerda; diabetes tipo II, hipercolesterolemia e hiperuricemia; alcoolismo ativo, fuma 20 cigarros/dia.
# 9                                       Ele foi encaminhado a nós por apresentar hematúria macroscópica pós-evacuação em uma ocasião e microhematúria persistente posteriormente, com evacuação normal.\nO exame físico mostrou bom estado geral, com abdome e genitais normais; o toque retal foi compatível com adenoma de próstata grau I/IV.
# 10                                                                                                          A urinálise mostrou 4 hemácias/campo e 0-5 leucócitos/campo; o resto do sedimento era normal.\nO hemograma é normal; a bioquímica mostrou uma glicemia de 169 mg/dl e triglicerídeos 456 mg/dl; função hepática e renal são normais.
# 11                                                                                                                                                                                                                                                                                                                            PSA de 1,16 ng/ml.
# 12                                                                                                                                                                                                                                DIRIGIDA A: Dr. Eva Coutinho - Centro Centro Hospitalar Universitario Do Algarve - Rua De Santa María, 100, 56
# 13                                                                                                                                                                                                                                                                                                               E-MAIL: maria.prado@jacob.com\n

# %% [markdown]
# # DE-IDENTIFICATION FOR ROMANIAN

# %% [markdown]
# ## Romanian NER Deidentification Models
# We have two different models you can use:
# * `ner_deid_subentity`, detects 17 entities
# * `ner_deid_subentity_bert`, detects 17 entities

# %% [markdown]
# |index|model|lang|index|model|lang|
# |-----:|:-----|----|-----:|:-----|----|
# | 1| [ner_deid_subentity](https://nlp.johnsnowlabs.com/2022/06/27/ner_deid_subentity_ro_3_0.html)  |ro| 3| [ner_deid_generic](https://nlp.johnsnowlabs.com/models)  |ro|
# | 2| [ner_deid_subentity_bert](https://nlp.johnsnowlabs.com/2022/06/27/ner_deid_subentity_bert_ro_3_0.html)  |ro| 4| [ner_deid_generic_bert](https://nlp.johnsnowlabs.com/models)  |ro|

# %% [markdown]
# Creating pipeline

# %%
documentAssembler = nlp.DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")

sentencerDL = nlp.SentenceDetectorDLModel.pretrained("sentence_detector_dl", "xx") \
    .setInputCols(["document"])\
    .setOutputCol("sentence")

tokenizer = nlp.Tokenizer()\
    .setInputCols(["sentence"])\
    .setOutputCol("token")

word_embeddings_ro = nlp.WordEmbeddingsModel.pretrained("w2v_cc_300d", "ro")\
    .setInputCols(["sentence","token"])\
	  .setOutputCol("word_embeddings")
# Out:
# sentence_detector_dl download started this may take some time.
# Approximate size to download 514.9 KB
# [OK!]
# w2v_cc_300d download started this may take some time.
# Approximate size to download 1.1 GB
# [OK!]

# %% [markdown]
# ### NER Deid Generic
#
# **`ner_deid_generic`** extracts:
# - Name
# - Profession
# - Age
# - Date
# - Contact (Telephone numbers, Email addresses)
# - Location (Address, City, Postal code, Hospital Name, Organization)
# - ID (Social Security numbers, Medical record numbers)

# %%
ner_generic_ro = medical.NerModel.pretrained("ner_deid_generic", "ro", "clinical/models")\
    .setInputCols(["sentence","token","word_embeddings"])\
    .setOutputCol("ner_deid_generic")

ner_converter_generic = medical.NerConverterInternal()\
    .setInputCols(["sentence","token","ner_deid_generic"])\
    .setOutputCol("ner_chunk_generic")
# Out:
# ner_deid_generic download started this may take some time.
# Approximate size to download 14.3 MB
# [OK!]

# %%
ner_generic_ro.getClasses()
# Out:
# ['O',
#  'I-LOCATION',
#  'I-CONTACT',
#  'I-PROFESSION',
#  'I-NAME',
#  'I-DATE',
#  'B-ID',
#  'B-CONTACT',
#  'B-PROFESSION',
#  'B-NAME',
#  'B-DATE',
#  'B-LOCATION',
#  'B-AGE',
#  'I-AGE']

# %% [markdown]
# ### NER Deid Subentity
#
# **`ner_deid_subentity`** extracts:
#
# `PATIENT`, `HOSPITAL`, `DATE`, `ORGANIZATION`, `CITY`, `STREET`, `EMAIL`, `ZIP`, `PROFESSION`, `PHONE`, `COUNTRY`, `DOCTOR`, `AGE`, `FAX`, `IDNUM`, `LOCATION-OTHER`, `MEDICALRECORD`,

# %%
ner_subentity_ro = medical.NerModel.pretrained("ner_deid_subentity", "ro", "clinical/models")\
    .setInputCols(["sentence","token","word_embeddings"])\
    .setOutputCol("ner_deid_subentity")

ner_converter_subentity = medical.NerConverterInternal()\
    .setInputCols(["sentence","token","ner_deid_subentity"])\
    .setOutputCol("ner_chunk_subentity")
# Out:
# ner_deid_subentity download started this may take some time.
# Approximate size to download 14.4 MB
# [OK!]

# %%
ner_subentity_ro.getClasses()
# Out:
# ['O',
#  'B-MEDICALRECORD',
#  'B-ORGANIZATION',
#  'I-PROFESSION',
#  'B-DOCTOR',
#  'B-PROFESSION',
#  'I-LOCATION-OTHER',
#  'B-CITY',
#  'B-DATE',
#  'B-LOCATION-OTHER',
#  'B-PATIENT',
#  'I-DOCTOR',
#  'I-CITY',
#  'I-DATE',
#  'B-COUNTRY',
#  'B-ZIP',
#  'I-STREET',
#  'I-PATIENT',
#  'B-PHONE',
#  'I-PHONE',
#  'B-HOSPITAL',
#  'B-EMAIL',
#  'B-IDNUM',
#  'B-STREET',
#  'B-FAX',
#  'I-ORGANIZATION',
#  'I-HOSPITAL',
#  'B-AGE',
#  'I-FAX',
#  'I-AGE',
#  'I-COUNTRY']

# %% [markdown]
# ### Pipeline

# %%
nlpPipeline_ro = nlp.Pipeline(
    stages=[
        documentAssembler,
        sentencerDL,
        tokenizer,
        word_embeddings_ro,
        ner_generic_ro,
        ner_converter_generic,
        ner_subentity_ro,
        ner_converter_subentity,
])

empty_data = spark.createDataFrame([[""]]).toDF("text")
model_ro = nlpPipeline_ro.fit(empty_data)

# %%
text = """
Spitalul Pentru Ochi de Deal, Drumul Oprea Nr. 972 Vaslui, 737405 România
Tel: +40(235)413773
Data setului de analize: 25 May 2022
Nume si Prenume : BUREAN MARIA, Varsta: 77
Medic : Agota Evelyn Timar
C.N.P : 2450502264401"""

text_df = spark.createDataFrame([[text]]).toDF("text")
result_ro = model_ro.transform(text_df)

# %% [markdown]
# Results for `ner_deid_generic`

# %%
result_ro.select(F.explode(F.arrays_zip(result_ro.ner_chunk_generic.result,
                                        result_ro.ner_chunk_generic.metadata)).alias("cols")) \
         .select(F.expr("cols['0']").alias("chunk"),
                 F.expr("cols['1']['entity']").alias("ner_label")).show(truncate=False)
# Out:
# +----------------------------+---------+
# |chunk                       |ner_label|
# +----------------------------+---------+
# |Spitalul Pentru Ochi de Deal|LOCATION |
# |Drumul Oprea Nr. 972        |LOCATION |
# |Vaslui                      |LOCATION |
# |737405 România              |LOCATION |
# |+40(235)413773              |CONTACT  |
# |25 May 2022                 |DATE     |
# |BUREAN MARIA                |NAME     |
# |77                          |AGE      |
# |Agota Evelyn Timar          |NAME     |
# |2450502264401               |ID       |
# +----------------------------+---------+

# %% [markdown]
# Results for `ner_deid_subentity`

# %%
result_ro.select(F.explode(F.arrays_zip(result_ro.ner_chunk_subentity.result,
                                        result_ro.ner_chunk_subentity.metadata)).alias("cols")) \
         .select(F.expr("cols['0']").alias("chunk"),
                 F.expr("cols['1']['entity']").alias("ner_label")).show(truncate=False)
# Out:
# +----------------------------+---------+
# |chunk                       |ner_label|
# +----------------------------+---------+
# |Spitalul Pentru Ochi de Deal|HOSPITAL |
# |Drumul Oprea Nr. 972        |STREET   |
# |Vaslui                      |CITY     |
# |737405                      |ZIP      |
# |+40(235)413773              |PHONE    |
# |25 May 2022                 |DATE     |
# |BUREAN MARIA                |PATIENT  |
# |77                          |AGE      |
# |Agota Evelyn Timar          |DOCTOR   |
# |2450502264401               |IDNUM    |
# +----------------------------+---------+

# %% [markdown]
# ## DeIdentification

# %% [markdown]
# ### Obfuscation mode

# %%
# Downloading faker entity list.
! wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/obfuscate_ro.txt

# %%
deid_masked_entity = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"])\
    .setOutputCol("masked_with_entity")\
    .setMode("mask")\
    .setMaskingPolicy("entity_labels")

deid_masked_char = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"])\
    .setOutputCol("masked_with_chars")\
    .setMode("mask")\
    .setMaskingPolicy("same_length_chars")

deid_masked_fixed_char = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"])\
    .setOutputCol("masked_fixed_length_chars")\
    .setMode("mask")\
    .setMaskingPolicy("fixed_length_chars")\
    .setFixedMaskLength(4)

deid_obfuscated = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"]) \
    .setOutputCol("obfuscated") \
    .setMode("obfuscate")\
    .setObfuscateDate(True)\
    .setObfuscateRefFile('obfuscate_ro.txt')\
    .setObfuscateRefSource("file")

# %%
nlpPipeline_ro = nlp.Pipeline(
    stages=[
        documentAssembler,
        sentencerDL,
        tokenizer,
        word_embeddings_ro,
        ner_subentity_ro,
        ner_converter_subentity,
        deid_masked_entity,
        deid_masked_char,
        deid_masked_fixed_char,
        deid_obfuscated
])

empty_data = spark.createDataFrame([[""]]).toDF("text")
model_ro = nlpPipeline_ro.fit(empty_data)

# %%
deid_lp_ro = nlp.LightPipeline(model_ro)

# %%
text = """
Spitalul Pentru Ochi de Deal, Drumul Oprea Nr. 972 Vaslui, 737405 România
Tel: +40(235)413773
Data setului de analize: 25 May 2022
Nume si Prenume : BUREAN MARIA, Varsta: 77
Medic : Agota Evelyn Timar
C.N.P : 2450502264401"""

# %%
pd.set_option("display.max_colwidth", 200)

result_ro = deid_lp_ro.annotate(text)

df_ro = pd.DataFrame(list(zip(result_ro["sentence"],
                              result_ro["masked_with_entity"],
                              result_ro["masked_with_chars"],
                              result_ro["masked_fixed_length_chars"],
                              result_ro["obfuscated"])),
                 columns= ["Sentence", "Masked_with_entity", "Masked with Chars", "Masked with Fixed Chars", "Obfuscated"])

df_ro
# Out:
#                                                                     Sentence  \
# 0  Spitalul Pentru Ochi de Deal, Drumul Oprea Nr. 972 Vaslui, 737405 România
# 1                                                        Tel: +40(235)413773
# 2                                       Data setului de analize: 25 May 2022
# 3     Nume si Prenume : BUREAN MARIA, Varsta: 77\nMedic : Agota Evelyn Timar
# 4                                                      C.N.P : 2450502264401
#
#                                              Masked_with_entity  \
# 0                    <HOSPITAL>, <STREET> <CITY>, <ZIP> România
# 1                                                  Tel: <PHONE>
# 2                               Data setului de analize: <DATE>
# 3  Nume si Prenume : <PATIENT>, Varsta: <AGE>\nMedic : <DOCTOR>
# 4                                               C.N.P : <IDNUM>
#
#                                                            Masked with Chars  \
# 0  [**************************], [******************] [****], [****] România
# 1                                                        Tel: [************]
# 2                                       Data setului de analize: [*********]
# 3     Nume si Prenume : [**********], Varsta: **\nMedic : [****************]
# 4                                                      C.N.P : [***********]
#
#                               Masked with Fixed Chars  \
# 0                       ****, **** ****, **** România
# 1                                           Tel: ****
# 2                       Data setului de analize: ****
# 3  Nume si Prenume : ****, Varsta: ****\nMedic : ****
# 4                                        C.N.P : ****
#
#                                                                                             Obfuscated
# 0  Institutul De Boli Cardiovasculare Prof. Dr. G. I. M. Georgescu, Aleea Aanei Sacele, 202316 România
# 1                                                                                  Tel: +31(706)340220
# 2                                                                Data setului de analize: 18 June 2022
# 3                            Nume si Prenume : DRAGOMIR EMILIA, Varsta: 75\nMedic : Iurie Caius Stoica
# 4                                                                                C.N.P : 7361617793314

# %% [markdown]
# ### Faker mode

# %%
deid_obfuscated_faker = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"]) \
    .setOutputCol("obfuscated") \
    .setMode("obfuscate")\
    .setLanguage('ro')\
    .setObfuscateDate(True)\
    .setIgnoreRegex(True)\
    .setObfuscateRefSource('faker')

# %%
nlpPipeline_ro = nlp.Pipeline(
    stages=[
        documentAssembler,
        sentencerDL,
        tokenizer,
        word_embeddings_ro,
        ner_subentity_ro,
        ner_converter_subentity,
        deid_masked_entity,
        deid_masked_char,
        deid_masked_fixed_char,
        deid_obfuscated_faker
])

empty_data = spark.createDataFrame([[""]]).toDF("text")
model_ro = nlpPipeline_ro.fit(empty_data)

# %%
deid_lp_ro = nlp.LightPipeline(model_ro)

# %%
pd.set_option("display.max_colwidth", 200)

result_ro = deid_lp_ro.annotate(text)

df_ro = pd.DataFrame(list(zip(result_ro["sentence"],
                              result_ro["masked_with_entity"],
                              result_ro["masked_with_chars"],
                              result_ro["masked_fixed_length_chars"],
                              result_ro["obfuscated"])),
                 columns= ["Sentence", "Masked_with_entity", "Masked with Chars", "Masked with Fixed Chars", "Obfuscated"])

df_ro
# Out:
#                                                                     Sentence  \
# 0  Spitalul Pentru Ochi de Deal, Drumul Oprea Nr. 972 Vaslui, 737405 România
# 1                                                        Tel: +40(235)413773
# 2                                       Data setului de analize: 25 May 2022
# 3     Nume si Prenume : BUREAN MARIA, Varsta: 77\nMedic : Agota Evelyn Timar
# 4                                                      C.N.P : 2450502264401
#
#                                              Masked_with_entity  \
# 0                    <HOSPITAL>, <STREET> <CITY>, <ZIP> România
# 1                                                  Tel: <PHONE>
# 2                               Data setului de analize: <DATE>
# 3  Nume si Prenume : <PATIENT>, Varsta: <AGE>\nMedic : <DOCTOR>
# 4                                               C.N.P : <IDNUM>
#
#                                                            Masked with Chars  \
# 0  [**************************], [******************] [****], [****] România
# 1                                                        Tel: [************]
# 2                                       Data setului de analize: [*********]
# 3     Nume si Prenume : [**********], Varsta: **\nMedic : [****************]
# 4                                                      C.N.P : [***********]
#
#                               Masked with Fixed Chars  \
# 0                       ****, **** ****, **** România
# 1                                           Tel: ****
# 2                       Data setului de analize: ****
# 3  Nume si Prenume : ****, Varsta: ****\nMedic : ****
# 4                                        C.N.P : ****
#
#                                                                   Obfuscated
# 0    Câmpulung Muscel Municipal Hospital, Pitei Negrești-oaș, 606938 România
# 1                                                        Tel: +93(108)920660
# 2                                       Data setului de analize: 06 May 2022
# 3  Nume si Prenume : CODIȚÃ BĂRNUȚIU, Varsta: 63\nMedic : Adela Nathan Filip
# 4                                                      C.N.P : 1983831179932

# %% [markdown]
# ## Pretrained Romanian Deidentification Pipeline
#
# - We developed a clinical deidentification pretrained pipeline that can be used to deidentify PHI information from Romanian medical texts. The PHI information will be masked and obfuscated in the resulting text.
# - The pipeline can mask and obfuscate:
#   - AGE,
#   - CITY,
#   - COUNTRY,
#   - DATE,
#   - DOCTOR,
#   - EMAIL,
#   - FAX,
#   - HOSPITAL,
#   - IDNUM,
#   - LOCATION-OTHER,
#   - MEDICALRECORD,
#   - ORGANIZATION,
#   - PATIENT,
#   - PHONE,
#   - PROFESSION,
#   - STREET,
#   - ZIP,
#   - ACCOUNT,
#   - LICENSE,
#   - PLATE

# %%
deid_pipeline_ro = nlp.PretrainedPipeline("clinical_deidentification", "ro", "clinical/models")
# Out:
# clinical_deidentification download started this may take some time.
# Approx size to download 1.1 GB
# [OK!]

# %%
text = """Medic : Dr. Agota EVELYN, C.N.P : 2450502264401, Data setului de analize: 25 May 2022
Varsta : 77, Nume si Prenume : BUREAN MARIA
Tel: +40(235)413773, E-mail : hale@gmail.com,
Licență : B004256985M, Înmatriculare : CD205113, Cont : FXHZ7170951927104999,
Spitalul Pentru Ochi de Deal Drumul Oprea Nr. 972 Vaslui, 737405 """

# %% [markdown]
# The results can also be inspected vertically by creating a Pandas dataframe as such:

# %%
pd.set_option("display.max_colwidth", None)

result_ro = deid_pipeline_ro.annotate(text)

df_ro = pd.DataFrame(list(zip(result_ro["sentence"],
                              result_ro["masked"],
                              result_ro["masked_with_chars"],
                              result_ro["masked_fixed_length_chars"],
                              result_ro["obfuscated"])),
                 columns= ["Sentence", "Masked", "Masked with Chars", "Masked with Fixed Chars", "Obfuscated"])

df_ro
# Out:
#                                                                                                                                                                                          Sentence  \
# 0                                                                                                           Medic : Dr. Agota EVELYN, C.N.P : 2450502264401, Data setului de analize: 25 May 2022
# 1                                                                                                                                                     Varsta : 77, Nume si Prenume : BUREAN MARIA
# 2  Tel: +40(235)413773, E-mail : hale@gmail.com,\nLicență : B004256985M, Înmatriculare : CD205113, Cont : FXHZ7170951927104999,\nSpitalul Pentru Ochi de Deal Drumul Oprea Nr. 972 Vaslui, 737405
#
#                                                                                                                                 Masked  \
# 0                                                               Medic : Dr. <DOCTOR>, C.N.P : <IDNUM>, Data setului de analize: <DATE>
# 1                                                                                          Varsta : <AGE>, Nume si Prenume : <PATIENT>
# 2  Tel: <PHONE>, E-mail : <EMAIL>,\nLicență : <LICENSE>, Înmatriculare : <PLATE>, Cont : <ACCOUNT>,\n<HOSPITAL> <STREET> <CITY>, <ZIP>
#
#                                                                                                                                                                                 Masked with Chars  \
# 0                                                                                                           Medic : Dr. [**********], C.N.P : [***********], Data setului de analize: [*********]
# 1                                                                                                                                                     Varsta : **, Nume si Prenume : [**********]
# 2  Tel: [************], E-mail : [************],\nLicență : [*********], Înmatriculare : [******], Cont : [******************],\n[**************************] [******************] [****], [****]
#
#                                                                                Masked with Fixed Chars  \
# 0                                        Medic : Dr. ****, C.N.P : ****, Data setului de analize: ****
# 1                                                                Varsta : ****, Nume si Prenume : ****
# 2  Tel: ****, E-mail : ****,\nLicență : ****, Înmatriculare : ****, Cont : ****,\n**** **** ****, ****
#
#                                                                                                                                                                                                                                                 Obfuscated
# 0                                                                                                                                                                            Medic : Dr. R.t., C.N.P : 1527271195574, Data setului de analize: 25 May 2022
# 1                                                                                                                                                                                                              Varsta : 68, Nume si Prenume : DRAGAN MIHAI
# 2  Tel: +57(182)548668, E-mail : tudorsmaranda@kappa.ro,\nLicență : C775129032F, Înmatriculare : HM172448, Cont : KHHO5029180812813651,\nCentrul Medical De Evaluare Si Recuperare Pentru Copii Si Tineri Cristian Serban Buzias Aleea Voinea Aiud, 686572

# %% [markdown]
# # DE-IDENTIFICATION FOR ARABIC

# %% [markdown]
# ## Arabic NER Deidentification Models
# We have two different models you can use:
# * `ner_deid_generic`, detects 8 entities
# * `ner_deid_subentity`, detects 17 entities
# * `ner_deid_subentity_arabert` detects 17 entities
# * `ner_deid_generic_arabert`,  detects 8 entities
# * `ner_deid_subentity_camelbert` , detects 17 entities
# * `ner_deid_generic_camelbert`,  detects 8 entities

# %% [markdown]
# |index|model|lang|index|model|lang|
# |-----:|:-----|----|-----:|:-----|----|
# | 1| [ner_deid_subentity](https://nlp.johnsnowlabs.com/2023/05/31/ner_deid_subentity_ar.html)  |ar| 2| [ner_deid_generic](https://nlp.johnsnowlabs.com/2023/05/30/ner_deid_generic_ar.html)  |ar|
# 3|[ner_deid_subentity_arabert](https://nlp.johnsnowlabs.com/2023/09/16/ner_deid_subentity_arabert_ar.html)   |ar| 4|[ner_deid_generic_arabert](https://nlp.johnsnowlabs.com/2023/09/16/ner_deid_generic_arabert_ar.html)   |ar|
#  5| [ner_deid_subentity_camelbert](https://nlp.johnsnowlabs.com/2023/09/22/ner_deid_subentity_camelbert_ar.html) |ar| 6| [ner_deid_generic_camelbert](https://nlp.johnsnowlabs.com/2023/09/16/ner_deid_generic_camelbert_ar.html) |ar|

# %%
# Annotator that transforms a text column from dataframe into an Annotation ready for NLP
documentAssembler = nlp.DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")

sentencerDL = nlp.SentenceDetectorDLModel.pretrained("sentence_detector_dl", "xx") \
    .setInputCols(["document"])\
    .setOutputCol("sentence")

# Tokenizer splits words in a relevant format for NLP
tokenizer = nlp.Tokenizer()\
    .setInputCols(["sentence"])\
    .setOutputCol("token")

word_embeddings_ar = nlp.WordEmbeddingsModel.pretrained("arabic_w2v_cc_300d","ar")\
    .setInputCols(["document","token"])\
	  .setOutputCol("embeddings")
# Out:
# sentence_detector_dl download started this may take some time.
# Approximate size to download 514.9 KB
# [OK!]
# arabic_w2v_cc_300d download started this may take some time.
# Approximate size to download 1.1 GB
# [OK!]

# %% [markdown]
# ### NER Deid Generic
#
# **`ner_deid_generic`** extracts:
# - Name
# - Profession
# - Age
# - Date
# - Contact (Telephone numbers, FAX numbers, Email addresses)
# - Location (Address, City, Postal code, Hospital Name, Employment information)
# - Id (Social Security numbers, Medical record numbers, Internet protocol addresses)

# %%
ner_generic_ar = medical.NerModel.pretrained("ner_deid_generic", "ar", "clinical/models")\
    .setInputCols(["sentence","token","embeddings"])\
    .setOutputCol("ner_deid_generic")

ner_converter_generic = medical.NerConverterInternal()\
    .setInputCols(["sentence","token","ner_deid_generic"])\
    .setOutputCol("ner_chunk_generic")
# Out:
# ner_deid_generic download started this may take some time.
# Approximate size to download 14.3 MB
# [OK!]

# %%
ner_generic_ar.getClasses()
# Out:
# ['O',
#  'I-LOCATION',
#  'I-PROFESSION',
#  'I-NAME',
#  'I-DATE',
#  'B-ID',
#  'B-PROFESSION',
#  'B-CONTACT',
#  'B-NAME',
#  'B-DATE',
#  'B-LOCATION',
#  'B-SEX',
#  'I-SEX',
#  'B-AGE',
#  'I-AGE']

# %% [markdown]
# ### NER Deid Subentity
#
# **`ner_deid_subentity`** extracts:
#
# - Patient
# - Doctor
# - Hospital
# - Date
# - Organization
# - City
# - Street
# - User Name
# - Profession
# - Phone
# - Country
# - Age

# %%
ner_subentity_ar = medical.NerModel.pretrained("ner_deid_subentity", "ar", "clinical/models")\
    .setInputCols(["sentence","token","embeddings"])\
    .setOutputCol("ner_deid_subentity")

ner_converter_subentity = medical.NerConverterInternal()\
    .setInputCols(["sentence", "token", "ner_deid_subentity"])\
    .setOutputCol("ner_chunk_subentity")
# Out:
# ner_deid_subentity download started this may take some time.
# Approximate size to download 14.3 MB
# [OK!]

# %%
ner_generic_ar.getClasses()
# Out:
# ['O',
#  'I-LOCATION',
#  'I-PROFESSION',
#  'I-NAME',
#  'I-DATE',
#  'B-ID',
#  'B-PROFESSION',
#  'B-CONTACT',
#  'B-NAME',
#  'B-DATE',
#  'B-LOCATION',
#  'B-SEX',
#  'I-SEX',
#  'B-AGE',
#  'I-AGE']

# %% [markdown]
# ### Pipeline

# %%
nlpPipeline_ar = nlp.Pipeline(
    stages=[
        documentAssembler,
        sentencerDL,
        tokenizer,
        word_embeddings_ar,
        ner_generic_ar,
        ner_converter_generic,
        ner_subentity_ar,
        ner_converter_subentity,
])

empty_data = spark.createDataFrame([[""]]).toDF("text")
model_ar = nlpPipeline_ar.fit(empty_data)

# %%
text_ar = """ملاحظات سريرية - مريض السكري. التاريخ: 11 مايو 1999. اسم المريض: فاطمة علي. العنوان: شارع الحرية، مبنى رقم 456، حي السلام، القاهرة. الرمز البريدي: 67890. البلد: مصر. اسم المستشفى: مستشفى الشفاء. اسم الطبيب: د. محمد صلاح. تفاصيل الحالة: المريضة فاطمة علي، البالغة من العمر 42 عامًا، مصابة بمرض السكري من النوع 2. تشكو من زيادة في العطش والجوع المفرط والتبول المتكرر. تم تشخيصها بمرض السكري بعد فحص شامل وفحوصات مخبرية. الخطة: تم وصف دواء فموي لخفض مستوى السكر في الدم. يجب على المريضة مراجعة الطبيب بانتظام وإجراء اختبارات السكر في الدم بانتظام. يتعين على المريضة اتباع نظام غذائي صحي ومتوازن، يشمل الحد من استهلاك السكريات والنشويات. يجب مراقبة ضغط الدم والكولسترول أيضًا ومراعاة التعليمات الطبية المتعلقة بتلك الحالات. تعليم المريضة بشأن أعراض الارتفاع أو الانخفاض الحاد في مستوى السكر في الدم وكيفية التعامل معها."""

text_df_ar = spark.createDataFrame([[text_ar]]).toDF("text")
result_ar = model_ar.transform(text_df_ar)

# %% [markdown]
# Results for `ner_deid_subentity`

# %%
result_ar.select(F.explode(F.arrays_zip(result_ar.ner_chunk_subentity.result,
                                        result_ar.ner_chunk_subentity.metadata)).alias("cols")) \
         .select(F.expr("cols['0']").alias("chunk"),
                 F.expr("cols['1']['entity']").alias("ner_label")).show(truncate=False)
# Out:
# +------------+---------+
# |chunk       |ner_label|
# +------------+---------+
# |11 مايو 1999|DATE     |
# |فاطمة علي   |DOCTOR   |
# |456،        |ZIP      |
# |القاهرة     |CITY     |
# |67890       |ZIP      |
# |مصر         |COUNTRY  |
# |محمد صلاح   |DOCTOR   |
# |42          |AGE      |
# +------------+---------+

# %% [markdown]
# Results for `ner_deid_generic`

# %%
result_ar.select(F.explode(F.arrays_zip(result_ar.ner_chunk_generic.result,
                                        result_ar.ner_chunk_generic.metadata)).alias("cols")) \
         .select(F.expr("cols['0']").alias("chunk"),
                 F.expr("cols['1']['entity']").alias("ner_label")).show(truncate=False)
# Out:
# +------------+---------+
# |chunk       |ner_label|
# +------------+---------+
# |11 مايو 1999|DATE     |
# |فاطمة علي   |NAME     |
# |شارع الحرية،|LOCATION |
# |القاهرة     |LOCATION |
# |67890       |LOCATION |
# |مصر         |LOCATION |
# |محمد صلاح   |NAME     |
# +------------+---------+

# %% [markdown]
# ## DeIdentification

# %% [markdown]
# ### Obfuscation mode

# %%
# Downloading faker entity list.
! wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/obfuscate_ar.txt

# %%
deid_masked_entity = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"])\
    .setOutputCol("masked_with_entity")\
    .setMode("mask")\
    .setLanguage('ar')\
    .setMaskingPolicy("entity_labels")

deid_masked_char = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"])\
    .setOutputCol("masked_with_chars")\
    .setMode("mask")\
    .setLanguage('ar')\
    .setMaskingPolicy("same_length_chars")

deid_masked_fixed_char = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"])\
    .setOutputCol("masked_fixed_length_chars")\
    .setMode("mask")\
    .setLanguage('ar')\
    .setMaskingPolicy("fixed_length_chars")\
    .setFixedMaskLength(4)

deid_obfuscated = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"]) \
    .setOutputCol("obfuscated") \
    .setMode("obfuscate")\
    .setLanguage('ar')\
    .setObfuscateDate(True)\
    .setObfuscateRefFile('obfuscate_ar.txt')\
    .setObfuscateRefSource("file")

# %%
nlpPipeline_ar = nlp.Pipeline(
    stages=[
        documentAssembler,
        sentencerDL,
        tokenizer,
        word_embeddings_ar,
        ner_subentity_ar,
        ner_converter_subentity,
        deid_masked_entity,
        deid_masked_char,
        deid_masked_fixed_char,
        deid_obfuscated
])

empty_data = spark.createDataFrame([[""]]).toDF("text")
model_ar = nlpPipeline_ar.fit(empty_data)

# %%
deid_lp_ar = nlp.LightPipeline(model_ar)

# %%
text = """
الملاحظات السريرية - مريض السكري
التاريخ: 11 مايو 1999
اسم المريض: فاطمة علي
العنوان: شارع الحرية ، حي السلام ، القاهرة
دولة: مصر
اسم المستشفى: مستشفى الشفاء
اسم الطبيب: د.محمد صلاح
"""

# %%
pd.set_option("display.max_colwidth", 200)

result_ar = deid_lp_ar.annotate(text)

df_ar = pd.DataFrame(list(zip(result_ar["sentence"],
                              result_ar["masked_with_entity"],
                              result_ar["masked_with_chars"],
                              result_ar["masked_fixed_length_chars"],
                              result_ar["obfuscated"])),
                 columns= ["Sentence", "Masked_with_entity", "Masked with Chars", "Masked with Fixed Chars", "Obfuscated"])

df_ar
# Out:
#                                      Sentence  \
# 0            الملاحظات السريرية - مريض السكري
# 1                       التاريخ: 11 مايو 1999
# 2                       اسم المريض: فاطمة علي
# 3  العنوان: شارع الحرية ، حي السلام ، القاهرة
# 4                                   دولة: مصر
# 5                 اسم المستشفى: مستشفى الشفاء
# 6                     اسم الطبيب: د.محمد صلاح
#
#                                 Masked_with_entity  \
# 0                 الملاحظات السريرية - مريض السكري
# 1                                 التاريخ: [تاريخ]
# 2                              اسم المريض: [دكتور]
# 3  العنوان: شارع الحرية ، حي [المدينة] ، [المدينة]
# 4                                 [البلد]: [البلد]
# 5                      اسم المستشفى: مستشفى الشفاء
# 6                              اسم الطبيب: [دكتور]
#
#                             Masked with Chars  \
# 0            الملاحظات السريرية - مريض السكري
# 1                       التاريخ: [٭٭٭٭٭٭٭٭٭٭]
# 2                       اسم المريض: [٭٭٭٭٭٭٭]
# 3  العنوان: شارع الحرية ، حي [٭٭٭٭] ، [٭٭٭٭٭]
# 4                                   [٭٭]: [٭]
# 5                 اسم المستشفى: مستشفى الشفاء
# 6                     اسم الطبيب: [٭٭٭٭٭٭٭٭٭]
#
#                  Masked with Fixed Chars  \
# 0       الملاحظات السريرية - مريض السكري
# 1                          التاريخ: ٭٭٭٭
# 2                       اسم المريض: ٭٭٭٭
# 3  العنوان: شارع الحرية ، حي ٭٭٭٭ ، ٭٭٭٭
# 4                             ٭٭٭٭: ٭٭٭٭
# 5            اسم المستشفى: مستشفى الشفاء
# 6                       اسم الطبيب: ٭٭٭٭
#
#                                       Obfuscated
# 0               الملاحظات السريرية - مريض السكري
# 1                          التاريخ: 21 مايو 1999
# 2                               اسم المريض: آمال
# 3  العنوان: شارع الحرية ، حي أبو النمرس ، أريانة
# 4                                      دولة: مصر
# 5                    اسم المستشفى: مستشفى الشفاء
# 6                                اسم الطبيب: أمل

# %% [markdown]
# ### Faker mode

# %%
deid_obfuscated_faker = medical.DeIdentification()\
    .setInputCols(["sentence", "token", "ner_chunk_subentity"]) \
    .setOutputCol("obfuscated") \
    .setMode("obfuscate")\
    .setLanguage('ar')\
    .setObfuscateDate(True)\
    .setObfuscateRefSource('faker')

# %%
nlpPipeline_ar = nlp.Pipeline(stages=[
      documentAssembler,
      sentencerDL,
      tokenizer,
      word_embeddings_ar,
      ner_subentity_ar,
      ner_converter_subentity,
      deid_masked_entity,
      deid_masked_char,
      deid_masked_fixed_char,
      deid_obfuscated_faker
      ])

empty_data = spark.createDataFrame([[""]]).toDF("text")
model_ar = nlpPipeline_ar.fit(empty_data)

# %%
deid_lp_ar = nlp.LightPipeline(model_ar)

# %%
pd.set_option("display.max_colwidth", 200)

result_ar = deid_lp_ar.annotate(text)

df_ar = pd.DataFrame(list(zip(result_ar["sentence"],
                              result_ar["masked_with_entity"],
                              result_ar["masked_with_chars"],
                              result_ar["masked_fixed_length_chars"],
                              result_ar["obfuscated"])),
                 columns= ["Sentence", "Masked_with_entity", "Masked with Chars", "Masked with Fixed Chars", "Obfuscated"])

df_ar
# Out:
#                                      Sentence  \
# 0            الملاحظات السريرية - مريض السكري
# 1                       التاريخ: 11 مايو 1999
# 2                       اسم المريض: فاطمة علي
# 3  العنوان: شارع الحرية ، حي السلام ، القاهرة
# 4                                   دولة: مصر
# 5                 اسم المستشفى: مستشفى الشفاء
# 6                     اسم الطبيب: د.محمد صلاح
#
#                                 Masked_with_entity  \
# 0                 الملاحظات السريرية - مريض السكري
# 1                                 التاريخ: [تاريخ]
# 2                              اسم المريض: [دكتور]
# 3  العنوان: شارع الحرية ، حي [المدينة] ، [المدينة]
# 4                                 [البلد]: [البلد]
# 5                      اسم المستشفى: مستشفى الشفاء
# 6                              اسم الطبيب: [دكتور]
#
#                             Masked with Chars  \
# 0            الملاحظات السريرية - مريض السكري
# 1                       التاريخ: [٭٭٭٭٭٭٭٭٭٭]
# 2                       اسم المريض: [٭٭٭٭٭٭٭]
# 3  العنوان: شارع الحرية ، حي [٭٭٭٭] ، [٭٭٭٭٭]
# 4                                   [٭٭]: [٭]
# 5                 اسم المستشفى: مستشفى الشفاء
# 6                     اسم الطبيب: [٭٭٭٭٭٭٭٭٭]
#
#                  Masked with Fixed Chars  \
# 0       الملاحظات السريرية - مريض السكري
# 1                          التاريخ: ٭٭٭٭
# 2                       اسم المريض: ٭٭٭٭
# 3  العنوان: شارع الحرية ، حي ٭٭٭٭ ، ٭٭٭٭
# 4                             ٭٭٭٭: ٭٭٭٭
# 5            اسم المستشفى: مستشفى الشفاء
# 6                       اسم الطبيب: ٭٭٭٭
#
#                                          Obfuscated
# 0                  الملاحظات السريرية - مريض السكري
# 1                            التاريخ: 11 يونيو 1999
# 2                             اسم المريض: ملاك وصال
# 3  العنوان: شارع الحرية ، حي قفصة الشمالية ، المروج
# 4                                         دولة: مصر
# 5                       اسم المستشفى: مستشفى الشفاء
# 6                            اسم الطبيب: زياد فريدة

# %% [markdown]
# ## Pretrained Arabic Deidentification Pipeline
#
# - We developed a clinical deidentification pretrained pipeline that can be used to deidentify PHI information from Arabic medical texts. The PHI information will be masked and obfuscated in the resulting text.
# - The pipeline can mask and obfuscate:
#   - CONTACT,
#   - NAME,
#   - DATE,
#   - ID,
#   - LOCATION,
#   - AGE,
#   - PATIENT,
#   - HOSPITAL,
#   - ORGANIZATION,
#   - CITY,
#   - STREET,
#   - USERNAME,
#   - SEX,
#   - IDNUM,
#   - EMAIL,
#   - ZIP,
#   - MEDICALRECORD,
#   - PROFESSION,
#   - PHONE,
#   - COUNTRY,
#   - DOCTOR,
#   - SSN,
#   - ACCOUNT,
#   - LICENSE,
#   - DLN,
#   - VIN

# %%
deid_pipeline_ar = nlp.PretrainedPipeline("clinical_deidentification", "ar", "clinical/models")
# Out:
# clinical_deidentification download started this may take some time.
# Approx size to download 1.2 GB
# [OK!]

# %%
text = """
ملاحظات سريرية - مريض الربو:
التاريخ: 30 مايو 2023
اسم المريضة: ليلى حسن
تم تسجيل المريض في النظام باستخدام رقم الضمان الاجتماعي 123456789012.
العنوان: شارع المعرفة، مبنى رقم 789، حي الأمانة، جدة
الرمز البريدي: 54321
البلد: المملكة العربية السعودية
اسم المستشفى: مستشفى النور
اسم الطبيب: د. أميرة أحمد
"""

# %% [markdown]
# The results can also be inspected vertically by creating a Pandas dataframe as such:

# %%
pd.set_option("display.max_colwidth", None)

result_ar = deid_pipeline_ar.annotate(text)

df_ar = pd.DataFrame(list(zip(result_ar["sentence"],
                              result_ar["masked_with_entity"],
                              result_ar["masked_with_chars"],
                              result_ar["masked_fixed_length_chars"],
                              result_ar["obfuscated"])),
                 columns= ["Sentence", "masked_with_entity", "Masked with Chars", "Masked with Fixed Chars", "Obfuscated"])

df_ar
# Out:
#                                                                 Sentence  \
# 0                    ملاحظات سريرية - مريض الربو:\nالتاريخ: 30 مايو 2023
# 1                                                  اسم المريضة: ليلى حسن
# 2  تم تسجيل المريض في النظام باستخدام رقم الضمان الاجتماعي 123456789012.
# 3                   العنوان: شارع المعرفة، مبنى رقم 789، حي الأمانة، جدة
# 4                                                   الرمز البريدي: 54321
# 5                                        البلد: المملكة العربية السعودية
# 6                                             اسم المستشفى: مستشفى النور
# 7                                              اسم الطبيب: د. أميرة أحمد
#
#                                                     masked_with_entity  \
# 0               ملاحظات سريرية - مريض الربو:\nالتاريخ: [تاريخ] [تاريخ]
# 1                                                اسم المريضة: [المريض]
# 2      تم تسجيل المريض في النظام باستخدام رقم الضمان الاجتماعي [هاتف].
# 3  العنوان: شارع المعرفة، مبنى رقم [الرمز البريدي] [المدينة] [المدينة]
# 4                                       الرمز البريدي: [الرمز البريدي]
# 5                                             البلد: [المدينة] [البلد]
# 6                                               اسم المستشفى: [الموقع]
# 7                                               اسم الطبيب: د. [دكتور]
#
#                                                        Masked with Chars  \
# 0                    ملاحظات سريرية - مريض الربو:\nالتاريخ: [٭٭٭٭٭] [٭٭]
# 1                                                  اسم المريضة: [٭٭٭٭٭٭]
# 2  تم تسجيل المريض في النظام باستخدام رقم الضمان الاجتماعي [٭٭٭٭٭٭٭٭٭٭].
# 3                   العنوان: شارع المعرفة، مبنى رقم [٭٭] [٭٭٭٭٭٭٭٭٭] [٭]
# 4                                                   الرمز البريدي: [٭٭٭]
# 5                                        البلد: [٭٭٭٭٭٭٭٭٭٭٭٭٭] [٭٭٭٭٭٭]
# 6                                             اسم المستشفى: [٭٭٭٭٭٭٭٭٭٭]
# 7                                              اسم الطبيب: د. [٭٭٭٭٭٭٭٭]
#
#                                          Masked with Fixed Chars  \
# 0               ملاحظات سريرية - مريض الربو:\nالتاريخ: ٭٭٭٭ ٭٭٭٭
# 1                                              اسم المريضة: ٭٭٭٭
# 2  تم تسجيل المريض في النظام باستخدام رقم الضمان الاجتماعي ٭٭٭٭.
# 3                 العنوان: شارع المعرفة، مبنى رقم ٭٭٭٭ ٭٭٭٭ ٭٭٭٭
# 4                                            الرمز البريدي: ٭٭٭٭
# 5                                               البلد: ٭٭٭٭ ٭٭٭٭
# 6                                             اسم المستشفى: ٭٭٭٭
# 7                                            اسم الطبيب: د. ٭٭٭٭
#
#                                                               Obfuscated
# 0                   ملاحظات سريرية - مريض الربو:\nالتاريخ: 30 يونيو 2024
# 1                                                 اسم المريضة: نوح شقيري
# 2  تم تسجيل المريض في النظام باستخدام رقم الضمان الاجتماعي 036925814703.
# 3                 العنوان: شارع المعرفة، مبنى رقم 814، كلميم سانت كاترين
# 4                                                   الرمز البريدي: 29630
# 5                                          البلد: زغوان الغربية السعودية
# 6                                             اسم المستشفى: شارع المدارس
# 7                                               اسم الطبيب: د. علاء مدحت
