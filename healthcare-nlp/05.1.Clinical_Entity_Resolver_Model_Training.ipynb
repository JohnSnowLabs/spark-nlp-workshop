# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)

# %% [markdown]
#  [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/spark-nlp-workshop/blob/master/healthcare-nlp/05.1.Clinical_Entity_Resolver_Model_Training.ipynb)

# %% [markdown]
# If you are using the `spark-nlp-jsl` library, please use this  [13.Snomed_Entity_Resolver_Model_Training
# ](https://github.com/JohnSnowLabs/spark-nlp-workshop/blob/master/tutorials/Certification_Trainings/Healthcare/13.Snomed_Entity_Resolver_Model_Training.ipynb) notebook.

# %% [markdown]
# # Clinical Entity Resolver Model Training

# %%
# Install the johnsnowlabs library to access Spark-OCR and Spark-NLP for Healthcare, Finance, and Legal.
! pip install -q johnsnowlabs

# %%
from google.colab import files
print('Please Upload your John Snow Labs License using the button below')
license_keys = files.upload()

# %%
from johnsnowlabs import nlp, medical, visual

# After uploading your license run this to install all licensed Python Wheels and pre-download Jars the Spark Session JVM
nlp.settings.enforce_versions=True
nlp.install(refresh_install=True)

# %%
from johnsnowlabs import nlp, medical, visual
import pandas as pd

# Automatically load license data and start a session with all jars user has access to
spark = nlp.start()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://2e499257bf7e:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>John-Snow-Labs-Spark-Session 🚀 with Jars for: 🚀Spark-NLP==6.4.0, 💊Spark-Healthcare==6.4.0, running on ⚡ PySpark==3.4.0</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Healthcare NLP for Data Scientists Course
#
# If you are not familiar with the components in this notebook, you can check [Healthcare NLP for Data Scientists Udemy Course](https://www.udemy.com/course/healthcare-nlp-for-data-scientists/) and the [MOOC Notebooks](https://github.com/JohnSnowLabs/spark-nlp-workshop/tree/master/Spark_NLP_Udemy_MOOC/Healthcare_NLP) for each components.

# %% [markdown]
# ## Load datasets

# %%
# !wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/AskAPatient.fold-0.test.txt
# !wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/AskAPatient.fold-0.train.txt
# !wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/AskAPatient.fold-0.validation.txt

# %%
import pandas as pd

cols = ["conceptId","ground_truth","concept_name"]

aap_tr = pd.read_csv("AskAPatient.fold-0.train.txt",sep="\t",encoding="ISO-8859-1",header=None)
aap_tr.columns = cols
aap_tr["conceptId"] = aap_tr.conceptId.apply(str)

aap_ts = pd.read_csv("AskAPatient.fold-0.test.txt",sep="\t",header=None)
aap_ts.columns = cols
aap_ts["conceptId"] = aap_ts.conceptId.apply(str)

aap_vl = pd.read_csv("AskAPatient.fold-0.validation.txt",sep="\t",header=None)
aap_vl.columns = cols
aap_vl["conceptId"] = aap_vl.conceptId.apply(str)

# %%
aap_tr.head()
# Out:
#           conceptId             ground_truth             concept_name
# 0         108367008     Dislocation of joint     Dislocation of joint
# 1  3384011000036100                Arthrotec                Arthrotec
# 2         166717003  Serum creatinine raised  Serum creatinine raised
# 3  3877011000036101                  Lipitor                  Lipitor
# 4         402234004              Foot eczema              Foot eczema

# %%
aap_train_sdf = spark.createDataFrame(aap_tr)
aap_test_sdf = spark.createDataFrame(aap_ts)
aap_val_sdf = spark.createDataFrame(aap_vl)

# %% [markdown]
# # Sentence Entity Resolver (sBioBert sentence embeddings)

# %%
aap_train_sdf.show()
# Out:
# +----------------+--------------------+--------------------+
# |       conceptId|        ground_truth|        concept_name|
# +----------------+--------------------+--------------------+
# |       108367008|Dislocation of joint|Dislocation of joint|
# |3384011000036100|           Arthrotec|           Arthrotec|
# |       166717003|Serum creatinine ...|Serum creatinine ...|
# |3877011000036101|             Lipitor|             Lipitor|
# |       402234004|         Foot eczema|         Foot eczema|
# |       404640003|           Dizziness|           Dizziness|
# |       271681002|        Stomach ache|        Stomach ache|
# |        76948002|         Severe pain|         Severe pain|
# |        36031001|        Burning feet|        Burning feet|
# |        76948002|         Severe pain|         Severe pain|
# |        42399005|       Renal failure|       Renal failure|
# |       288227007|Myalgia/myositis ...|Myalgia/myositis ...|
# |       419723007|       Mentally dull|       Mentally dull|
# |       248490000|    Bloating symptom|    Bloating symptom|
# |        22253000|                Pain|                Pain|
# |       162076009|Excessive upper g...|Excessive upper g...|
# |       247592009|Poor short-term m...|Poor short-term m...|
# |        62507009|    Pins and needles|    Pins and needles|
# |3877011000036101|             Lipitor|             Lipitor|
# |        62507009|    Pins and needles|    Pins and needles|
# +----------------+--------------------+--------------------+
# only showing top 20 rows

# %%
aap_train_sdf.printSchema()
# Out:
# root
#  |-- conceptId: string (nullable = true)
#  |-- ground_truth: string (nullable = true)
#  |-- concept_name: string (nullable = true)

# %% [markdown]
# ## Get Embeddings

# %% [markdown]
# Now we will get the sentence embeddings of `concept_name` column.

# %%
documentAssembler = nlp.DocumentAssembler()\
    .setInputCol("concept_name")\
    .setOutputCol("sentence")

bert_embeddings = nlp.BertSentenceEmbeddings.pretrained("sbiobert_base_cased_mli", "en", "clinical/models")\
    .setInputCols(["sentence"])\
    .setOutputCol("bert_embeddings")
    # .setCaseSensitive(False)

embeddings_pipeline = nlp.Pipeline(stages = [
    documentAssembler,
    bert_embeddings])

embeddings_model = embeddings_pipeline.fit(aap_train_sdf)
snomed_data = embeddings_model.transform(aap_train_sdf)
# Out:
# sbiobert_base_cased_mli download started this may take some time.
# Approximate size to download 384.3 MB
# [OK!]

# %%
snomed_data.show()
# Out:
# +----------------+--------------------+--------------------+--------------------+--------------------+
# |       conceptId|        ground_truth|        concept_name|            sentence|     bert_embeddings|
# +----------------+--------------------+--------------------+--------------------+--------------------+
# |       108367008|Dislocation of joint|Dislocation of joint|[{document, 0, 19...|[{sentence_embedd...|
# |3384011000036100|           Arthrotec|           Arthrotec|[{document, 0, 8,...|[{sentence_embedd...|
# |       166717003|Serum creatinine ...|Serum creatinine ...|[{document, 0, 22...|[{sentence_embedd...|
# |3877011000036101|             Lipitor|             Lipitor|[{document, 0, 6,...|[{sentence_embedd...|
# |       402234004|         Foot eczema|         Foot eczema|[{document, 0, 10...|[{sentence_embedd...|
# |       404640003|           Dizziness|           Dizziness|[{document, 0, 8,...|[{sentence_embedd...|
# |       271681002|        Stomach ache|        Stomach ache|[{document, 0, 11...|[{sentence_embedd...|
# |        76948002|         Severe pain|         Severe pain|[{document, 0, 10...|[{sentence_embedd...|
# |        36031001|        Burning feet|        Burning feet|[{document, 0, 11...|[{sentence_embedd...|
# |        76948002|         Severe pain|         Severe pain|[{document, 0, 10...|[{sentence_embedd...|
# |        42399005|       Renal failure|       Renal failure|[{document, 0, 12...|[{sentence_embedd...|
# |       288227007|Myalgia/myositis ...|Myalgia/myositis ...|[{document, 0, 27...|[{sentence_embedd...|
# |       419723007|       Mentally dull|       Mentally dull|[{document, 0, 12...|[{sentence_embedd...|
# |       248490000|    Bloating symptom|    Bloating symptom|[{document, 0, 15...|[{sentence_embedd...|
# |        22253000|                Pain|                Pain|[{document, 0, 3,...|[{sentence_embedd...|
# |       162076009|Excessive upper g...|Excessive upper g...|[{document, 0, 35...|[{sentence_embedd...|
# |       247592009|Poor short-term m...|Poor short-term m...|[{document, 0, 21...|[{sentence_embedd...|
# |        62507009|    Pins and needles|    Pins and needles|[{document, 0, 15...|[{sentence_embedd...|
# |3877011000036101|             Lipitor|             Lipitor|[{document, 0, 6,...|[{sentence_embedd...|
# |        62507009|    Pins and needles|    Pins and needles|[{document, 0, 15...|[{sentence_embedd...|
# +----------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# We have `bert_embeddings` column in our training dataframe that we will use as input while training the model.

# %% [markdown]
# # Train SNOMED Model

# %%
bertExtractor = medical.SentenceEntityResolverApproach()\
  .setNeighbours(25)\
  .setThreshold(1000)\
  .setInputCols("bert_embeddings")\
  .setNormalizedCol("concept_name")\
  .setLabelCol("conceptId")\
  .setOutputCol('snomed_code')\
  .setDistanceFunction("EUCLIDIAN")\
  .setCaseSensitive(False)
  #.setDatasetInfo("AskAPatient_sample_short dataset") #You can add details regarding the dataset

# %time snomed_model = bertExtractor.fit(snomed_data)
# Out:
# CPU times: user 59.3 ms, sys: 21.4 ms, total: 80.7 ms
# Wall time: 5min 21s

# %%
# save if you will need that later
snomed_model.write().overwrite().save("biobertresolve_snomed_askapatient")

# %% [markdown]
# ## Test Model

# %%
prediction_Model = nlp.PipelineModel(stages=[embeddings_model, snomed_model])

aap_test_pred= prediction_Model.transform(aap_test_sdf).cache()
aap_val_pred= prediction_Model.transform(aap_val_sdf).cache()

# %%
aap_test_pred.selectExpr("conceptId","concept_name","ground_truth","snomed_code[0].result","snomed_code[0].metadata.resolved_text","snomed_code[0].metadata.all_k_resolutions").show(truncate=50)
# Out:
# +----------------+--------------------------------+------------------------------------+---------------------+--------------------------------------+--------------------------------------------------+
# |       conceptId|                    concept_name|                        ground_truth|snomed_code[0].result|snomed_code[0].metadata[resolved_text]|        snomed_code[0].metadata[all_k_resolutions]|
# +----------------+--------------------------------+------------------------------------+---------------------+--------------------------------------+--------------------------------------------------+
# |       108367008|                     dislocating|                Dislocation of joint|            387603000|                           balance off|balance off:::Impaired mobility:::Reduced mobil...|
# |3384011000036100|                       Arthrotec|                           Arthrotec|     3384011000036100|                             Arthrotec|                                         Arthrotec|
# |       166717003|               elevated creatine|             Serum creatinine raised|            166717003|                   elevated Creatinine|elevated Creatinine:::Increased creatine kinase...|
# |3877011000036101|                         Lipitor|                             Lipitor|     3877011000036101|                               Lipitor|                                           Lipitor|
# |       402234004|                  Eczema on feet|                         Foot eczema|            402234004|                           Foot eczema|Foot eczema:::Eczema:::Eczema on hands:::foot s...|
# |       404640003|                           dizzy|                           Dizziness|            404640003|                                 dizzy|dizzy:::sleepy:::trembling:::so tired:::sorenes...|
# |       271681002|   pain in the pit of my stomach|                        Stomach ache|             21522001|                    pain in my stomach|pain in my stomach:::pain in my stomach:::gas p...|
# |        76948002|extreme muscle pain in shoulders|                         Severe pain|             76948002|       Severe muscle pain in shoulders|Severe muscle pain in shoulders:::muscle pain i...|
# |        36031001|                    Burning feet|                        Burning feet|             36031001|                          Burning feet|Burning feet:::burning sensations in legs:::bur...|
# |        76948002|             imence pain in legs|                         Severe pain|             10601006|                          pain in legs|                pain in legs:::muscle pain in legs|
# |        42399005|              kidney malfunction|                       Renal failure|             90708001|                       kidney problems|kidney problems:::kidney damage:::kidney failur...|
# |       288227007|        muscle pain in my biceps|        Myalgia/myositis - upper arm|             68962001|   debilitating muscle pain in my arms|debilitating muscle pain in my arms:::muscle pa...|
# |       419723007|                       brain fog|                       Mentally dull|            419723007|                             brain fog|brain fog:::Memory fog:::head hurt:::Extreme we...|
# |       248490000|                        bloating|                    Bloating symptom|            248490000|                              bloating|                                          bloating|
# |        22253000|                            pain|                                Pain|             22253000|                                  pain|                                              pain|
# |       162076009|                             gas|Excessive upper gastrointestinal gas|            162076009|                                   gas|                                               gas|
# |       247592009|          Short term memory loss|              Poor short-term memory|            247592009|                short term memory loss|    short term memory loss:::Transient memory loss|
# |        62507009|             tingling in my feet|                    Pins and needles|             62507009|                      tingling in feet|tingling in feet:::sensations of tingling in my...|
# |3877011000036101|                         LIPITOR|                             Lipitor|     3877011000036101|                               LIPITOR|                                   LIPITOR:::LIPEX|
# |        62507009|   tingling on left side of face|                    Pins and needles|            309557009|         Numbness on left side of face|Numbness on left side of face:::numbness on lef...|
# +----------------+--------------------------------+------------------------------------+---------------------+--------------------------------------+--------------------------------------------------+
# only showing top 20 rows

# %%
aap_val_pred.selectExpr("conceptId","concept_name","ground_truth","snomed_code[0].result","snomed_code[0].metadata.resolved_text","snomed_code[0].metadata.all_k_resolutions").show(truncate=50)
# Out:
# +----------------+------------------------------+---------------------+---------------------+--------------------------------------+--------------------------------------------------+
# |       conceptId|                  concept_name|         ground_truth|snomed_code[0].result|snomed_code[0].metadata[resolved_text]|        snomed_code[0].metadata[all_k_resolutions]|
# +----------------+------------------------------+---------------------+---------------------+--------------------------------------+--------------------------------------------------+
# |       267032009|persisten feeling of tiredness|   Tired all the time|             84229001|                     extreme tiredness|extreme tiredness:::feeling tired a lot:::feeli...|
# |        22298006|                  HEART ATTACK|Myocardial infarction|             22298006|                          HEART ATTACH|HEART ATTACH:::HEADACHES:::LIGHT HEADED:::HAIR ...|
# |3877011000036101|                       LIPITOR|              Lipitor|     3877011000036101|                               LIPITOR|                                   LIPITOR:::LIPEX|
# |       415690000|                       sweated|             Sweating|            415690000|                              Sweating|                               Sweating:::Swelling|
# |       248491001|              swelling at knee|         Swollen knee|            299322007|                Swelling of knee joint|Swelling of knee joint:::swelling of the legs::...|
# |       248490000|                      bloating|     Bloating symptom|            248490000|                              bloating|                                          bloating|
# |       162059005|                 stomach upset|        Upset stomach|            162059005|                         stomach upset|stomach upset:::gastric upsets:::stomach troubl...|
# |3877011000036101|                       Lipitor|              Lipitor|     3877011000036101|                               Lipitor|                                           Lipitor|
# |        62507009|                      tingling|     Pins and needles|             62507009|                              tingling|                         tingling:::hands tingling|
# |       238131007|                   over weight|           Overweight|            238131007|                           over weight|over weight:::gaining excess weight:::fatiqued:...|
# |        73595000|                        stress|               Stress|             73595000|                                stress|                                 stress:::so tired|
# |3877011000036101|                       lipitor|              Lipitor|     3877011000036101|                               lipitor|                                           lipitor|
# |3877011000036101|                       Lipitor|              Lipitor|     3877011000036101|                               Lipitor|                                           Lipitor|
# |        22253000|                          hurt|                 Pain|             22253000|                              It hurts|It hurts:::feel bad:::confusion:::feel dreadful...|
# |        73211009|                      diabetes|    Diabetes mellitus|             73211009|                              diabetes|                         diabetes:::type2 diabetes|
# |        10601006|                     sore legs|   Pain in lower limb|             10601006|                             sore legs|sore legs:::sore arms:::sore feet:::sore knees:...|
# |        75694006|       acute pancreatic attack|         Pancreatitis|             75694006|                          Pancreatitis|Pancreatitis:::Peritonitis:::abdominal hematoma...|
# |        51197009|     SEVERE abdominal cramping|       Stomach cramps|              9991008|                    abdominal cramping|abdominal cramping:::gassy abdominal cramping::...|
# |         3723001|                     arthrites|            Arthritis|              3723001|                            arthristis|                            arthristis:::arthrotec|
# |       271767006|        skin began to come off|      Peeling of skin|            278040002|          hair has started falling out|hair has started falling out:::vision became bl...|
# +----------------+------------------------------+---------------------+---------------------+--------------------------------------+--------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# # Train Model with Auxilary Informations
#
# We can add auxilary information to our model. In here we will add an aux column with the ground truths of the codes. So the model will return the ground truths of all codes that the model will return in `all_k_aux_labels` in metadata.

# %%
bertExtractor_aux = medical.SentenceEntityResolverApproach()\
  .setNeighbours(25)\
  .setThreshold(1000)\
  .setInputCols("bert_embeddings")\
  .setNormalizedCol("concept_name")\
  .setLabelCol("conceptId")\
  .setOutputCol('snomed_code')\
  .setDistanceFunction("EUCLIDIAN")\
  .setCaseSensitive(False)\
  .setUseAuxLabel(True)\
  .setAuxLabelCol("ground_truth")

# %time snomed_aux_model = bertExtractor_aux.fit(snomed_data)
# Out:
# CPU times: user 94.6 ms, sys: 37.5 ms, total: 132 ms
# Wall time: 10min 23s

# %%
# save if you will need that later
snomed_aux_model.write().overwrite().save("biobertresolve_snomed_askapatient_aux")

# %% [markdown]
# ## Test Aux Model
#
# Please check the `all_k_aux_labels` column in metadata.

# %%
aux_prediction_Model = nlp.PipelineModel(stages=[embeddings_model, snomed_aux_model])

aap_test_pred_aux= aux_prediction_Model.transform(aap_test_sdf).cache()
aap_val_pred_aux= aux_prediction_Model.transform(aap_val_sdf).cache()

# %%
aap_test_pred_aux.selectExpr("conceptId","concept_name","ground_truth","snomed_code[0].result","snomed_code[0].metadata.resolved_text","snomed_code[0].metadata.all_k_resolutions", "snomed_code[0].metadata.all_k_aux_labels").show(truncate=50)
# Out:
# +----------------+--------------------------------+------------------------------------+---------------------+--------------------------------------+--------------------------------------------------+--------------------------------------------------+
# |       conceptId|                    concept_name|                        ground_truth|snomed_code[0].result|snomed_code[0].metadata[resolved_text]|        snomed_code[0].metadata[all_k_resolutions]|         snomed_code[0].metadata[all_k_aux_labels]|
# +----------------+--------------------------------+------------------------------------+---------------------+--------------------------------------+--------------------------------------------------+--------------------------------------------------+
# |       108367008|                     dislocating|                Dislocation of joint|            387603000|                           balance off|balance off:::Impaired mobility:::Reduced mobil...|Impairment of balance:::Impaired mobility:::Red...|
# |3384011000036100|                       Arthrotec|                           Arthrotec|     3384011000036100|                             Arthrotec|                                         Arthrotec|                                         Arthrotec|
# |       166717003|               elevated creatine|             Serum creatinine raised|            166717003|                   elevated Creatinine|elevated Creatinine:::Increased creatine kinase...|Serum creatinine raised:::Increased creatine ki...|
# |3877011000036101|                         Lipitor|                             Lipitor|     3877011000036101|                               Lipitor|                                           Lipitor|                                           Lipitor|
# |       402234004|                  Eczema on feet|                         Foot eczema|            402234004|                           Foot eczema|Foot eczema:::Eczema:::Eczema on hands:::foot s...|Foot eczema:::Eczema:::Hand eczema:::Peeling of...|
# |       404640003|                           dizzy|                           Dizziness|            404640003|                                 dizzy|dizzy:::sleepy:::trembling:::so tired:::sorenes...|Dizziness:::Drowsy:::Trembles:::Tired:::Pain:::...|
# |       271681002|   pain in the pit of my stomach|                        Stomach ache|             21522001|                    pain in my stomach|pain in my stomach:::pain in my stomach:::gas p...|Abdominal pain:::Stomach ache:::Flatulence, eru...|
# |        76948002|extreme muscle pain in shoulders|                         Severe pain|             76948002|       Severe muscle pain in shoulders|Severe muscle pain in shoulders:::muscle pain i...|Severe pain:::Myalgia/myositis - shoulder:::Mya...|
# |        36031001|                    Burning feet|                        Burning feet|             36031001|                          Burning feet|Burning feet:::burning sensations in legs:::bur...|   Burning feet:::Burning sensation:::Burning pain|
# |        76948002|             imence pain in legs|                         Severe pain|             10601006|                          pain in legs|                pain in legs:::muscle pain in legs| Pain in lower limb:::Myalgia/myositis - lower leg|
# |        42399005|              kidney malfunction|                       Renal failure|             90708001|                       kidney problems|kidney problems:::kidney damage:::kidney failur...|Kidney disease:::Renal injury:::Renal failure::...|
# |       288227007|        muscle pain in my biceps|        Myalgia/myositis - upper arm|             68962001|   debilitating muscle pain in my arms|debilitating muscle pain in my arms:::muscle pa...|Myalgia:::Myalgia/myositis - shoulder:::Severe ...|
# |       419723007|                       brain fog|                       Mentally dull|            419723007|                             brain fog|brain fog:::Memory fog:::head hurt:::Extreme we...|Mentally dull:::Memory impairment:::Headache:::...|
# |       248490000|                        bloating|                    Bloating symptom|            248490000|                              bloating|                                          bloating|                                  Bloating symptom|
# |        22253000|                            pain|                                Pain|             22253000|                                  pain|                                              pain|                                              Pain|
# |       162076009|                             gas|Excessive upper gastrointestinal gas|            162076009|                                   gas|                                               gas|              Excessive upper gastrointestinal gas|
# |       247592009|          Short term memory loss|              Poor short-term memory|            247592009|                short term memory loss|    short term memory loss:::Transient memory loss|    Poor short-term memory:::Transient memory loss|
# |        62507009|             tingling in my feet|                    Pins and needles|             62507009|                      tingling in feet|tingling in feet:::sensations of tingling in my...|Pins and needles:::Paraesthesia of foot:::Parae...|
# |3877011000036101|                         LIPITOR|                             Lipitor|     3877011000036101|                               LIPITOR|                                   LIPITOR:::LIPEX|                                   Lipitor:::Lipex|
# |        62507009|   tingling on left side of face|                    Pins and needles|            309557009|         Numbness on left side of face|Numbness on left side of face:::numbness on lef...|Numbness of face:::Numbness:::Numbness of upper...|
# +----------------+--------------------------------+------------------------------------+---------------------+--------------------------------------+--------------------------------------------------+--------------------------------------------------+
# only showing top 20 rows

# %%
aap_val_pred_aux.selectExpr("conceptId","concept_name","ground_truth","snomed_code[0].result","snomed_code[0].metadata.resolved_text","snomed_code[0].metadata.all_k_resolutions", "snomed_code[0].metadata.all_k_aux_labels").show(truncate=50)
# Out:
# +----------------+------------------------------+---------------------+---------------------+--------------------------------------+--------------------------------------------------+--------------------------------------------------+
# |       conceptId|                  concept_name|         ground_truth|snomed_code[0].result|snomed_code[0].metadata[resolved_text]|        snomed_code[0].metadata[all_k_resolutions]|         snomed_code[0].metadata[all_k_aux_labels]|
# +----------------+------------------------------+---------------------+---------------------+--------------------------------------+--------------------------------------------------+--------------------------------------------------+
# |       267032009|persisten feeling of tiredness|   Tired all the time|             84229001|                     extreme tiredness|extreme tiredness:::feeling tired a lot:::feeli...|Fatigue:::Tired all the time:::Feeling tired:::...|
# |        22298006|                  HEART ATTACK|Myocardial infarction|             22298006|                          HEART ATTACH|HEART ATTACH:::HEADACHES:::LIGHT HEADED:::HAIR ...|Myocardial infarction:::Headache:::Lightheadedn...|
# |3877011000036101|                       LIPITOR|              Lipitor|     3877011000036101|                               LIPITOR|                                   LIPITOR:::LIPEX|                                   Lipitor:::Lipex|
# |       415690000|                       sweated|             Sweating|            415690000|                              Sweating|                               Sweating:::Swelling|                               Sweating:::Swelling|
# |       248491001|              swelling at knee|         Swollen knee|            299322007|                Swelling of knee joint|Swelling of knee joint:::swelling of the legs::...|Swelling of knee joint:::Swollen legs:::Ankle o...|
# |       248490000|                      bloating|     Bloating symptom|            248490000|                              bloating|                                          bloating|                                  Bloating symptom|
# |       162059005|                 stomach upset|        Upset stomach|            162059005|                         stomach upset|stomach upset:::gastric upsets:::stomach troubl...|Upset stomach:::Excessive upper gastrointestina...|
# |3877011000036101|                       Lipitor|              Lipitor|     3877011000036101|                               Lipitor|                                           Lipitor|                                           Lipitor|
# |        62507009|                      tingling|     Pins and needles|             62507009|                              tingling|                         tingling:::hands tingling|           Pins and needles:::Paraesthesia of hand|
# |       238131007|                   over weight|           Overweight|            238131007|                           over weight|over weight:::gaining excess weight:::fatiqued:...|Overweight:::Weight gain:::Fatigue:::Sensation ...|
# |        73595000|                        stress|               Stress|             73595000|                                stress|                                 stress:::so tired|                                    Stress:::Tired|
# |3877011000036101|                       lipitor|              Lipitor|     3877011000036101|                               lipitor|                                           lipitor|                                           Lipitor|
# |3877011000036101|                       Lipitor|              Lipitor|     3877011000036101|                               Lipitor|                                           Lipitor|                                           Lipitor|
# |        22253000|                          hurt|                 Pain|             22253000|                              It hurts|It hurts:::feel bad:::confusion:::feel dreadful...|Pain:::Feeling bad:::Confusion:::Malaise:::Delu...|
# |        73211009|                      diabetes|    Diabetes mellitus|             73211009|                              diabetes|                         diabetes:::type2 diabetes|      Diabetes mellitus:::Type 2 diabetes mellitus|
# |        10601006|                     sore legs|   Pain in lower limb|             10601006|                             sore legs|sore legs:::sore arms:::sore feet:::sore knees:...|Pain in lower limb:::Pain in upper limb:::Foot ...|
# |        75694006|       acute pancreatic attack|         Pancreatitis|             75694006|                          Pancreatitis|Pancreatitis:::Peritonitis:::abdominal hematoma...|Pancreatitis:::Peritonitis:::Intra-abdominal ha...|
# |        51197009|     SEVERE abdominal cramping|       Stomach cramps|              9991008|                    abdominal cramping|abdominal cramping:::gassy abdominal cramping::...|Abdominal colic:::Excessive upper gastrointesti...|
# |         3723001|                     arthrites|            Arthritis|              3723001|                            arthristis|                            arthristis:::arthrotec|                             Arthritis:::Arthrotec|
# |       271767006|        skin began to come off|      Peeling of skin|            278040002|          hair has started falling out|hair has started falling out:::vision became bl...|Loss of hair:::Blurring of visual image:::Tingl...|
# +----------------+------------------------------+---------------------+---------------------+--------------------------------------+--------------------------------------------------+--------------------------------------------------+
# only showing top 20 rows
