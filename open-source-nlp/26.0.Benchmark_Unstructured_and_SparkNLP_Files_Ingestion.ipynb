# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/spark-nlp-workshop/blob/master/open-source-nlp/26.0.Benchmark_Unstructured_and_SparkNLP_Files_Ingestion.ipynb)

# %% [markdown]
# ## Load Mixed Files & Extract Text with Unstructured.io

# %%
import os
import requests
import subprocess

# Directory to store the files
output_dir = "all_files"
os.makedirs(output_dir, exist_ok=True)

# GitHub repo info
owner = "JohnSnowLabs"
repo = "spark-nlp"
path = "src/test/resources/reader"

# Fetch the file tree recursively
url = f"https://api.github.com/repos/{owner}/{repo}/contents/{path}?ref=master"
headers = {"Accept": "application/vnd.github.v3+json"}
response = requests.get(url, headers=headers)
files = response.json()

# Helper function to recursively fetch files
def download_files(file_list, base_path):
    for item in file_list:
        if item["type"] == "file":
            raw_url = item["download_url"]
            file_name = os.path.join(output_dir, os.path.basename(raw_url))
            print(f"Downloading {file_name} ...")
            subprocess.run(["wget", "-q", raw_url, "-O", file_name])
        elif item["type"] == "dir":
            nested_url = item["url"]
            nested_files = requests.get(nested_url, headers=headers).json()
            download_files(nested_files, base_path)

# Start recursive download
download_files(files, path)

print("\n✅ All files downloaded successfully into:", output_dir)
# Out:
# Downloading all_files/semicolon-delimited.csv ...
# Downloading all_files/stanley-cups-utf-16.csv ...
# Downloading all_files/stanley-cups.csv ...
# Downloading all_files/contains-pictures.docx ...
# Downloading all_files/doc-img-table.docx ...
# Downloading all_files/doc-with-2images.docx ...
# Downloading all_files/fake_table.docx ...
# Downloading all_files/hierarchy_test.docx ...
# Downloading all_files/page-breaks.docx ...
# Downloading all_files/email-test-image.eml ...
# Downloading all_files/email-test-image.msg ...
# Downloading all_files/email-text-attachments.eml ...
# Downloading all_files/test-several-attachments.eml ...
# Downloading all_files/example-10k.html ...
# Downloading all_files/example-bold-strong.html ...
# Downloading all_files/example-caption-th.html ...
# Downloading all_files/example-div.html ...
# Downloading all_files/example-image-paragraph.html ...
# Downloading all_files/example-images.html ...
# Downloading all_files/example-mix-tags.html ...
# Downloading all_files/fake-html.html ...
# Downloading all_files/simple-book.html ...
# Downloading all_files/table-image.html ...
# Downloading all_files/title-test.html ...
# Downloading all_files/SwitzerlandAlps.jpg ...
# Downloading all_files/README.md ...
# Downloading all_files/example-images.md ...
# Downloading all_files/simple-book.md ...
# Downloading all_files/simple-table.md ...
# Downloading all_files/simple.md ...
# Downloading all_files/umlauts-non-utf8.md ...
# Downloading all_files/umlauts-utf8.md ...
# Downloading all_files/contains-pictures.docx ...
# Downloading all_files/example-images.html ...
# Downloading all_files/example-images.md ...
# Downloading all_files/corrupted.pdf ...
# Downloading all_files/hierarchy_test.pdf ...
# Downloading all_files/image_3_pages.pdf ...
# Downloading all_files/ligatures_text.pdf ...
# Downloading all_files/pdf-title.pdf ...
# Downloading all_files/pdf-with-2images.pdf ...
# Downloading all_files/text_3_pages.pdf ...
# Downloading all_files/unsorted_text.pdf ...
# Downloading all_files/fake-power-point-table.pptx ...
# Downloading all_files/fake-power-point.pptx ...
# Downloading all_files/power-point-images.pptx ...
# Downloading all_files/speaker-notes.pptx ...
# Downloading all_files/long-text.txt ...
# Downloading all_files/max-line-count-test.txt ...
# Downloading all_files/short-line-test.txt ...
# Downloading all_files/simple-text.txt ...
# Downloading all_files/test-paragraph.txt ...
# Downloading all_files/threshold-test.txt ...
# Downloading all_files/title-length-test.txt ...
# Downloading all_files/contains-pictures.docx ...
# Downloading all_files/corrupted.pdf ...
# Downloading all_files/example-images.html ...
# Downloading all_files/pdf-with-2images.pdf ...
# Downloading all_files/stanley-cups.csv ...
# Downloading all_files/2023-half-year-analyses-by-segment.xlsx ...
# Downloading all_files/excel-images.xlsx ...
# Downloading all_files/page-break-example.xlsx ...
# Downloading all_files/simple-example-2tables.xlsx ...
# Downloading all_files/vodafone.xlsx ...
# Downloading all_files/xlsx-subtable-cases.xlsx ...
# Downloading all_files/multi-level.xml ...
# Downloading all_files/test.xml ...
#
# ✅ All files downloaded successfully into: all_files

# %% [markdown]
# 🧩 1️⃣ Install dependencies

# %%
# Install Unstructured and supporting dependencies
# !pip install "unstructured[all-docs]" pillow python-magic
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Collecting python-magic
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting unstructured[all-docs]
#   Downloading unstructured-0.18.26-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.12/dist-packages (from unstructured[all-docs]) (3.4.4)
# Collecting filetype (from unstructured[all-docs])
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from unstructured[all-docs]) (6.0.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from unstructured[all-docs]) (3.9.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from unstructured[all-docs]) (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from unstructured[all-docs]) (4.13.5)
# Collecting emoji (from unstructured[all-docs])
#   Downloading emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting dataclasses-json (from unstructured[all-docs])
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting python-iso639 (from unstructured[all-docs])
#   Downloading python_iso639-2025.11.16-py3-none-any.whl.metadata (15 kB)
# Collecting langdetect (from unstructured[all-docs])
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 15.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from unstructured[all-docs]) (2.0.2)
# Collecting rapidfuzz (from unstructured[all-docs])
#   Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Collecting backoff (from unstructured[all-docs])
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from unstructured[all-docs]) (4.15.0)
# Collecting unstructured-client (from unstructured[all-docs])
#   Downloading unstructured_client-0.42.6-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from unstructured[all-docs]) (2.0.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from unstructured[all-docs]) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from unstructured[all-docs]) (5.9.5)
# Collecting python-oxmsg (from unstructured[all-docs])
#   Downloading python_oxmsg-0.0.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.12/dist-packages (from unstructured[all-docs]) (1.1)
# Collecting pi_heif (from unstructured[all-docs])
#   Downloading pi_heif-1.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.12/dist-packages (from unstructured[all-docs]) (2.0.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (from unstructured[all-docs]) (3.1.5)
# Collecting python-pptx>=1.0.1 (from unstructured[all-docs])
#   Downloading python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: markdown in /usr/local/lib/python3.12/dist-packages (from unstructured[all-docs]) (3.10)
# Collecting pdf2image (from unstructured[all-docs])
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting msoffcrypto-tool (from unstructured[all-docs])
#   Downloading msoffcrypto_tool-5.4.2-py3-none-any.whl.metadata (10 kB)
# Collecting pypandoc (from unstructured[all-docs])
#   Downloading pypandoc-1.16.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from unstructured[all-docs]) (2.2.2)
# Collecting python-docx>=1.1.2 (from unstructured[all-docs])
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting pikepdf (from unstructured[all-docs])
#   Downloading pikepdf-10.1.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.3 kB)
# Collecting unstructured-inference>=1.1.1 (from unstructured[all-docs])
#   Downloading unstructured_inference-1.1.4-py3-none-any.whl.metadata (5.5 kB)
# Collecting unstructured.pytesseract>=0.3.12 (from unstructured[all-docs])
#   Downloading unstructured.pytesseract-0.3.15-py3-none-any.whl.metadata (11 kB)
# Collecting effdet (from unstructured[all-docs])
#   Downloading effdet-0.4.1-py3-none-any.whl.metadata (33 kB)
# Collecting onnxruntime>=1.19.0 (from unstructured[all-docs])
#   Downloading onnxruntime-1.23.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Collecting google-cloud-vision (from unstructured[all-docs])
#   Downloading google_cloud_vision-3.11.0-py3-none-any.whl.metadata (9.8 kB)
# Collecting pypdf (from unstructured[all-docs])
#   Downloading pypdf-6.5.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from unstructured[all-docs]) (3.6.1)
# Collecting onnx>=1.17.0 (from unstructured[all-docs])
#   Downloading onnx-1.20.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Collecting pdfminer.six (from unstructured[all-docs])
#   Downloading pdfminer_six-20251230-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.17.0->unstructured[all-docs]) (5.29.5)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.17.0->unstructured[all-docs]) (0.5.4)
# Collecting coloredlogs (from onnxruntime>=1.19.0->unstructured[all-docs])
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.19.0->unstructured[all-docs]) (25.9.23)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.19.0->unstructured[all-docs]) (25.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.19.0->unstructured[all-docs]) (1.14.0)
# Collecting XlsxWriter>=0.5.7 (from python-pptx>=1.0.1->unstructured[all-docs])
#   Downloading xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.12/dist-packages (from unstructured-inference>=1.1.1->unstructured[all-docs]) (0.0.20)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from unstructured-inference>=1.1.1->unstructured[all-docs]) (0.36.0)
# Requirement already satisfied: opencv-python>=4.12 in /usr/local/lib/python3.12/dist-packages (from unstructured-inference>=1.1.1->unstructured[all-docs]) (4.12.0.88)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from unstructured-inference>=1.1.1->unstructured[all-docs]) (3.10.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from unstructured-inference>=1.1.1->unstructured[all-docs]) (2.9.0+cpu)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from unstructured-inference>=1.1.1->unstructured[all-docs]) (1.0.22)
# Requirement already satisfied: transformers>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from unstructured-inference>=1.1.1->unstructured[all-docs]) (4.57.3)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from unstructured-inference>=1.1.1->unstructured[all-docs]) (1.12.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from unstructured-inference>=1.1.1->unstructured[all-docs]) (1.16.3)
# Collecting pypdfium2 (from unstructured-inference>=1.1.1->unstructured[all-docs])
#   Downloading pypdfium2-5.3.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->unstructured[all-docs]) (2.8)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->unstructured[all-docs])
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->unstructured[all-docs])
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from effdet->unstructured[all-docs]) (0.24.0+cpu)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from effdet->unstructured[all-docs]) (2.0.10)
# Requirement already satisfied: omegaconf>=2.0 in /usr/local/lib/python3.12/dist-packages (from effdet->unstructured[all-docs]) (2.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (2.28.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-vision->unstructured[all-docs]) (2.43.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-vision->unstructured[all-docs]) (1.76.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-vision->unstructured[all-docs]) (1.26.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.12/dist-packages (from html5lib->unstructured[all-docs]) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from html5lib->unstructured[all-docs]) (0.5.1)
# Requirement already satisfied: cryptography>=39.0 in /usr/local/lib/python3.12/dist-packages (from msoffcrypto-tool->unstructured[all-docs]) (43.0.3)
# Collecting olefile>=0.46 (from msoffcrypto-tool->unstructured[all-docs])
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk->unstructured[all-docs]) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk->unstructured[all-docs]) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk->unstructured[all-docs]) (2025.11.3)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl->unstructured[all-docs]) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->unstructured[all-docs]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->unstructured[all-docs]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->unstructured[all-docs]) (2025.3)
# Collecting Deprecated (from pikepdf->unstructured[all-docs])
#   Downloading deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->unstructured[all-docs]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->unstructured[all-docs]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->unstructured[all-docs]) (2025.11.12)
# Requirement already satisfied: aiofiles>=24.1.0 in /usr/local/lib/python3.12/dist-packages (from unstructured-client->unstructured[all-docs]) (24.1.0)
# Requirement already satisfied: httpcore>=1.0.9 in /usr/local/lib/python3.12/dist-packages (from unstructured-client->unstructured[all-docs]) (1.0.9)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.12/dist-packages (from unstructured-client->unstructured[all-docs]) (0.28.1)
# Requirement already satisfied: pydantic>=2.11.2 in /usr/local/lib/python3.12/dist-packages (from unstructured-client->unstructured[all-docs]) (2.12.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from unstructured-client->unstructured[all-docs]) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=39.0->msoffcrypto-tool->unstructured[all-docs]) (2.0.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (1.72.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (1.71.2)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (4.9.1)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore>=1.0.9->unstructured-client->unstructured[all-docs]) (0.16.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->unstructured-client->unstructured[all-docs]) (4.12.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf>=2.0->effdet->unstructured[all-docs]) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from omegaconf>=2.0->effdet->unstructured[all-docs]) (6.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.2->unstructured-client->unstructured[all-docs]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.2->unstructured-client->unstructured[all-docs]) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.2->unstructured-client->unstructured[all-docs]) (0.4.2)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm->unstructured-inference>=1.1.1->unstructured[all-docs]) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->unstructured-inference>=1.1.1->unstructured[all-docs]) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->unstructured-inference>=1.1.1->unstructured[all-docs]) (75.2.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->unstructured-inference>=1.1.1->unstructured[all-docs]) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->unstructured-inference>=1.1.1->unstructured[all-docs]) (2025.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime>=1.19.0->unstructured[all-docs]) (1.3.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.25.1->unstructured-inference>=1.1.1->unstructured[all-docs]) (0.22.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->unstructured-inference>=1.1.1->unstructured[all-docs]) (1.2.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured[all-docs])
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.19.0->unstructured[all-docs])
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->unstructured-inference>=1.1.1->unstructured[all-docs]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->unstructured-inference>=1.1.1->unstructured[all-docs]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->unstructured-inference>=1.1.1->unstructured[all-docs]) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->unstructured-inference>=1.1.1->unstructured[all-docs]) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->unstructured-inference>=1.1.1->unstructured[all-docs]) (3.2.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=39.0->msoffcrypto-tool->unstructured[all-docs]) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (0.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->unstructured-inference>=1.1.1->unstructured[all-docs]) (3.0.3)
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading onnx-1.20.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (18.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 87.5 MB/s eta 0:00:00
# Downloading onnxruntime-1.23.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 83.9 MB/s eta 0:00:00
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 13.3 MB/s eta 0:00:00
# Downloading python_pptx-1.0.2-py3-none-any.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 24.5 MB/s eta 0:00:00
# Downloading unstructured_inference-1.1.4-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 kB 2.4 MB/s eta 0:00:00
# Downloading unstructured.pytesseract-0.3.15-py3-none-any.whl (14 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading effdet-0.4.1-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 5.9 MB/s eta 0:00:00
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 28.3 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_cloud_vision-3.11.0-py3-none-any.whl (529 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.1/529.1 kB 26.0 MB/s eta 0:00:00
# Downloading msoffcrypto_tool-5.4.2-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.7/48.7 kB 2.6 MB/s eta 0:00:00
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Downloading pdfminer_six-20251230-py3-none-any.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 95.5 MB/s eta 0:00:00
# Downloading pi_heif-1.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 51.8 MB/s eta 0:00:00
# Downloading pikepdf-10.1.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 72.3 MB/s eta 0:00:00
# Downloading pypandoc-1.16.2-py3-none-any.whl (19 kB)
# Downloading pypdf-6.5.0-py3-none-any.whl (329 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.6/329.6 kB 16.3 MB/s eta 0:00:00
# Downloading python_iso639-2025.11.16-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.8/167.8 kB 9.4 MB/s eta 0:00:00
# Downloading python_oxmsg-0.0.2-py3-none-any.whl (31 kB)
# Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 71.0 MB/s eta 0:00:00
# Downloading unstructured-0.18.26-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 53.4 MB/s eta 0:00:00
# Downloading unstructured_client-0.42.6-py3-none-any.whl (219 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.6/219.6 kB 10.1 MB/s eta 0:00:00
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 2.2 MB/s eta 0:00:00
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 5.1 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 9.1 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.2 MB/s eta 0:00:00
# Downloading deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Downloading pypdfium2-5.3.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 69.5 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 4.7 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993223 sha256=3fe3840e1e703a55f43114a35c6508a1277a9c05cde8f46934e672f5e477af1b
#   Stored in directory: /root/.cache/pip/wheels/c1/67/88/e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# Installing collected packages: filetype, XlsxWriter, unstructured.pytesseract, rapidfuzz, python-magic, python-iso639, python-docx, pypdfium2, pypdf, pypandoc, pi_heif, pdf2image, olefile, mypy-extensions, marshmallow, langdetect, humanfriendly, emoji, Deprecated, backoff, typing-inspect, python-pptx, python-oxmsg, pikepdf, onnx, coloredlogs, unstructured-client, pdfminer.six, onnxruntime, msoffcrypto-tool, dataclasses-json, unstructured, unstructured-inference, google-cloud-vision, effdet
# Successfully installed Deprecated-1.3.1 XlsxWriter-3.2.9 backoff-2.2.1 coloredlogs-15.0.1 dataclasses-json-0.6.7 effdet-0.4.1 emoji-2.15.0 filetype-1.2.0 google-cloud-vision-3.11.0 humanfriendly-10.0 langdetect-1.0.9 marshmallow-3.26.2 msoffcrypto-tool-5.4.2 mypy-extensions-1.1.0 olefile-0.47 onnx-1.20.0 onnxruntime-1.23.2 pdf2image-1.17.0 pdfminer.six-20251230 pi_heif-1.1.1 pikepdf-10.1.0 pypandoc-1.16.2 pypdf-6.5.0 pypdfium2-5.3.0 python-docx-1.2.0 python-iso639-2025.11.16 python-magic-0.4.27 python-oxmsg-0.0.2 python-pptx-1.0.2 rapidfuzz-3.14.3 typing-inspect-0.9.0 unstructured-0.18.26 unstructured-client-0.42.6 unstructured-inference-1.1.4 unstructured.pytesseract-0.3.15

# %% [markdown]
# 📁 2️⃣ Set up configuration

# %%
from pathlib import Path

# Directory containing your documents
INPUT_DIR = Path("/content/all_files")   # 🔹 Change to your folder path
# Output file where all extracted text will be saved
OUTPUT_FILE = Path("/content/output_all_text.txt")

# %% [markdown]
# ⚙️ 3️⃣ Import modules and helper functions

# %%
import time
from unstructured.partition.auto import partition

def extract_text_from_file(filepath: Path) -> str:
    """
    Use Unstructured.io to partition the file and return full extracted text.
    """
    try:
        elements = partition(filename=str(filepath))
    except Exception as e:
        print(f"⚠️ Failed to read {filepath.name}: {e}")
        return ""

    text_content = []
    for element in elements:
        try:
            txt = getattr(element, "text", None)
            if txt:
                text_content.append(txt)
        except Exception:
            continue

    return "\n".join(text_content)

# %% [markdown]
# 🧾 Stage 1: Load file list

# %%
t0 = time.perf_counter()

files = [
    f for f in INPUT_DIR.rglob("*")
    if f.is_file()
]

t1 = time.perf_counter()
timings = {"list_files": t1 - t0}

print(f"📄 Found {len(files)} supported files in {INPUT_DIR}")
# Out:
# 📄 Found 59 supported files in /content/all_files

# %% [markdown]
# 🧠 Stage 2: Extract text

# %%
extract_start = time.perf_counter()
all_text = []

for idx, file_path in enumerate(files, start=1):
    file_t0 = time.perf_counter()

    text = extract_text_from_file(file_path)
    all_text.append(f"====== {file_path.name} ======\n{text}\n")

    file_t1 = time.perf_counter()
    print(f"✔ [{idx}/{len(files)}] {file_path.name} processed in {file_t1 - file_t0:.2f}s")

extract_end = time.perf_counter()
timings["extract_text"] = extract_end - extract_start
# Out:
# ✔ [1/59] excel-images.xlsx processed in 12.24s
# ✔ [2/59] speaker-notes.pptx processed in 0.36s
# ✔ [3/59] doc-with-2images.docx processed in 0.07s
# Warning: No languages specified, defaulting to English.
# ✔ [4/59] hierarchy_test.pdf processed in 9.02s
# ✔ [5/59] simple.md processed in 0.74s
# ✔ [6/59] short-line-test.txt processed in 0.01s
# ✔ [7/59] title-length-test.txt processed in 0.01s
# Warning: No languages specified, defaulting to English.
# ⚠️ Failed to read corrupted.pdf: Unable to get page count. Is poppler installed and in PATH?
# ✔ [8/59] corrupted.pdf processed in 0.07s
# ✔ [9/59] stanley-cups.csv processed in 0.01s
# ✔ [10/59] fake-power-point.pptx processed in 0.02s
# ✔ [11/59] 2023-half-year-analyses-by-segment.xlsx processed in 0.19s
# Warning: No languages specified, defaulting to English.
# yolox_l0.05.onnx:   0%|          | 0.00/217M [00:00<?, ?B/s]
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# preprocessor_config.json:   0%|          | 0.00/274 [00:00<?, ?B/s]
# The `max_size` parameter is deprecated and will be removed in v4.26. Please specify in `size['longest_edge'] instead`.
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/115M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/46.8M [00:00<?, ?B/s]
# ✔ [12/59] email-test-image.msg processed in 36.50s
# ✔ [13/59] example-mix-tags.html processed in 0.02s
# ✔ [14/59] README.md processed in 0.03s
# ⚠️ Failed to read stanley-cups-utf-16.csv: 'utf-8' codec can't decode byte 0xfe in position 0: invalid start byte
# ✔ [15/59] stanley-cups-utf-16.csv processed in 0.00s
# ✔ [16/59] email-text-attachments.eml processed in 0.03s
# ✔ [17/59] umlauts-non-utf8.md processed in 0.11s
# ✔ [18/59] simple-book.md processed in 0.02s
# Warning: No languages specified, defaulting to English.
# ✔ [19/59] SwitzerlandAlps.jpg processed in 6.34s
# ✔ [20/59] fake-power-point-table.pptx processed in 0.03s
# ✔ [21/59] title-test.html processed in 0.01s
# ✔ [22/59] example-bold-strong.html processed in 0.02s
# ✔ [23/59] example-div.html processed in 0.02s
# ✔ [24/59] xlsx-subtable-cases.xlsx processed in 0.07s
# Warning: No languages specified, defaulting to English.
# ✔ [25/59] pdf-title.pdf processed in 0.04s
# Warning: No languages specified, defaulting to English.
# ⚠️ Failed to read test-several-attachments.eml: Unable to get page count. Is poppler installed and in PATH?
# ✔ [26/59] test-several-attachments.eml processed in 0.14s
# ✔ [27/59] test-paragraph.txt processed in 0.01s
# ✔ [28/59] example-images.html processed in 0.01s
# ✔ [29/59] fake_table.docx processed in 0.02s
# ✔ [30/59] example-image-paragraph.html processed in 0.02s
# ✔ [31/59] power-point-images.pptx processed in 0.02s
# ✔ [32/59] simple-text.txt processed in 0.02s
# Warning: No languages specified, defaulting to English.
# ⚠️ Failed to read image_3_pages.pdf: Unable to get page count. Is poppler installed and in PATH?
# ✔ [33/59] image_3_pages.pdf processed in 0.01s
# ✔ [34/59] page-breaks.docx processed in 0.05s
# ✔ [35/59] simple-table.md processed in 0.02s
# ✔ [36/59] contains-pictures.docx processed in 0.04s
# Warning: No languages specified, defaulting to English.
# ✔ [37/59] text_3_pages.pdf processed in 0.02s
# ✔ [38/59] multi-level.xml processed in 0.01s
# ✔ [39/59] simple-book.html processed in 0.03s
# ✔ [40/59] semicolon-delimited.csv processed in 0.07s
# ✔ [41/59] example-images.md processed in 0.02s
# ✔ [42/59] page-break-example.xlsx processed in 0.04s
# ✔ [43/59] hierarchy_test.docx processed in 0.08s
# ✔ [44/59] example-caption-th.html processed in 0.03s
# ✔ [45/59] fake-html.html processed in 0.01s
# ✔ [46/59] table-image.html processed in 0.01s
# ✔ [47/59] long-text.txt processed in 0.02s
# ✔ [48/59] max-line-count-test.txt processed in 0.01s
# ✔ [49/59] example-10k.html processed in 0.45s
# ✔ [50/59] vodafone.xlsx processed in 0.07s
# Warning: No languages specified, defaulting to English.
# ✔ [51/59] unsorted_text.pdf processed in 0.03s
# Warning: No languages specified, defaulting to English.
# ✔ [52/59] email-test-image.eml processed in 6.40s
# ✔ [53/59] test.xml processed in 0.00s
# ✔ [54/59] threshold-test.txt processed in 0.01s
# ✔ [55/59] simple-example-2tables.xlsx processed in 0.02s
# ✔ [56/59] umlauts-utf8.md processed in 0.02s
# Warning: No languages specified, defaulting to English.
# ✔ [57/59] pdf-with-2images.pdf processed in 0.02s
# ✔ [58/59] doc-img-table.docx processed in 0.02s
# Warning: No languages specified, defaulting to English.
# ✔ [59/59] ligatures_text.pdf processed in 0.02s

# %% [markdown]
# 💾 Stage 3: Save all extracted text

# %%
save_start = time.perf_counter()

OUTPUT_FILE.write_text("\n\n".join(all_text), encoding="utf-8")

save_end = time.perf_counter()
timings["save_output"] = save_end - save_start

print(f"✅ All text saved to: {OUTPUT_FILE}")
# Out:
# ✅ All text saved to: /content/output_all_text.txt

# %% [markdown]
# 📊 Stage 4: Timing Summary + Text Sample

# %%
print("\n✨ Extraction complete!")
print("🕒 Time summary:")
for stage, dt in timings.items():
    print(f" - {stage}: {dt:.3f} seconds")

sample_len = 500
joined = "\n\n".join(all_text)
print("\n📘 Text Sample (first 500 chars):")
print(joined[:sample_len])
if len(joined) > sample_len:
    print("...")
# Out:
# ✨ Extraction complete!
# 🕒 Time summary:
#  - list_files: 0.003 seconds
#  - extract_text: 73.732 seconds
#  - save_output: 0.001 seconds
#
# 📘 Text Sample (first 500 chars):
# ====== excel-images.xlsx ======
# Country City Switzerland Neuchatel Ecuador Quito Spain Madrid USA Miami
#
#
# ====== speaker-notes.pptx ======
# Adding a Bullet Slide
# Find the bullet slide layout
# Use _TextFrame.text for first bullet
# Use _TextFrame.add_paragraph() for subsequent bullets
# Here is a lot of text!
# Here is some text in a text box!
#
#
# ====== doc-with-2images.docx ======
# This is a document with images
# First page with an image
# Second page with another image
#
#
# ====== hierarchy_test.pdf ======
# Cha
# ...

# %% [markdown]
# ## Load Mixed Files & Extract Text with SparkNLP

# %% [markdown]
# 📦 1️⃣ Install Spark NLP and Start Spark

# %%
# Install Spark NLP and PySpark
# !pip install -q --force-reinstall pyspark==3.5.7
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.4/317.4 MB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 kB 12.4 MB/s eta 0:00:00
#   Building wheel for pyspark (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dataproc-spark-connect 1.0.1 requires pyspark[connect]~=4.0.0, but you have pyspark 3.5.7 which is incompatible.

# %%
# !pip install spark-nlp==6.3.0
# Out:
# Collecting spark-nlp==6.3.0
#   Downloading spark_nlp-6.3.0-py2.py3-none-any.whl.metadata (19 kB)
# Downloading spark_nlp-6.3.0-py2.py3-none-any.whl (744 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 745.0/745.0 kB 8.7 MB/s eta 0:00:00
# Installing collected packages: spark-nlp
# Successfully installed spark-nlp-6.3.0

# %%
import sparknlp
from pyspark.sql import SparkSession

# Start Spark Session
spark = sparknlp.start()

print("🚀 Spark NLP version:", sparknlp.version())
# Out:
# 🚀 Spark NLP version: 6.3.0

# %%
print("Spark version:", spark.version)
print("Scala Version:", spark.sparkContext._jvm.scala.util.Properties.versionString())
print("Java Version:", spark.sparkContext._jvm.java.lang.System.getProperty("java.version"))
# Out:
# Spark version: 3.5.7
# Scala Version: version 2.12.18
# Java Version: 17.0.17

# %% [markdown]
# 📁 2️⃣ Define Input/Output Paths

# %%
from pathlib import Path

# Directory with mixed docs
INPUT_DIR = "/content/all_files"
# Parquet output
OUTPUT_PARQUET = "/content/sparknlp_output.parquet"

# %% [markdown]
# 🧾 Stage 1: Load files

# %%
import time
from sparknlp.reader.reader_assembler import ReaderAssembler
from pyspark.ml import Pipeline

t0 = time.perf_counter()

reader_assembler = ReaderAssembler() \
    .setContentPath(INPUT_DIR) \
    .setOutputCol("document")

t1 = time.perf_counter()

# %% [markdown]
# 🧠 Stage 2: Extract text

# %%
pipeline = Pipeline(stages=[reader_assembler])

t2 = time.perf_counter()

# %%
empty_df = spark.createDataFrame([], "string").toDF("text")
model = pipeline.fit(empty_df)
df_spark_nlp = model.transform(empty_df)

t3 = time.perf_counter()

# %% [markdown]
# 💾 Stage 3: Save all extracted text

# %%
df_spark_nlp.select("document_text.result").write.mode("overwrite").parquet(OUTPUT_PARQUET)
t4 = time.perf_counter()

# %% [markdown]
# 📊 Stage 4: Timing Summary + Text Sample

# %%
# ─────────────── Timing Report ───────────────── #
print("\n🕒 Spark NLP Processing Timings")
print(f" - setContentPath:        {t1 - t0:.3f} sec")
print(f" - Pipeline creation:     {t2 - t1:.3f} sec")
print(f" - Fit + Transform:       {t3 - t2:.3f} sec")
print(f" - Save to Parquet:       {t4 - t3:.3f} sec")
print(f" - Total:                 {t4 - t0:.3f} sec")
# Out:
# 🕒 Spark NLP Processing Timings
#  - setContentPath:        3.135 sec
#  - Pipeline creation:     0.008 sec
#  - Fit + Transform:       13.836 sec
#  - Save to Parquet:       17.387 sec
#  - Total:                 34.366 sec

# %%
# Load the saved Parquet file into a new DataFrame
df_loaded = spark.read.parquet(OUTPUT_PARQUET)

print(f"✅ Loaded {df_loaded.count()} records from Parquet.")
# Out:
# ✅ Loaded 59 records from Parquet.

# %%
# Show the first 10 rows (truncated to 200 characters for readability)
df_loaded.show(10, truncate=200)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                                                                                                                                                  result|
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[Sample Title Text\nThis is an example paragraph. Below you'll see the first table containing sample data.\nHere is some additional text between the tables. You can add any information or context y...|
# |                                                                                                [This SHOULD be a title\nThis is a normal paragraph.\nThis MIGHT be a title\nAnother regular paragraph.]|
# |                                                                                                                                 [This should be detected as a title\nThis is also a title using strong]|
# |                                                                                                       [This Text Is Consider Title\nThe text here is consider as narrative text, so it's content data.]|
# |                                                                                                                                                                                           [Test Images]|
# |                                                                                                                                                                                           [Test Images]|
# |[Simple Book\nIndex\nChapter 1: Beginnings\nChapter 2: Middle Path\nChapter 3: Finishing Touch\nChapter 1: Beginnings\nEvery project starts with a simple idea and a clear intention. In this chapter...|
# |                                                                                                                                                                                                      []|
# |[My First Heading\nMy Second Heading\nMy first paragraph. lorem ipsum dolor set amet. if the cow comes home under the sun how do you fault the cow for it's worn hooves?\nA test list\nWith sub-bulle...|
# |                                                                                                                                                  [Test Images\nA base64 image after the table is below]|
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows
