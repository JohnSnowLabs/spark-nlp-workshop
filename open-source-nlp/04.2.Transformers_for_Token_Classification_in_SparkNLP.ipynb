# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/spark-nlp-workshop/blob/master/open-source-nlp/04.2.Transformers_for_Token_Classification_in_SparkNLP.ipynb)

# %% [markdown]
# # Transformers for Token Classification in Spark NLP

# %% [markdown]
# **BertForTokenClassification** can load Bert Models with a token classification head on top (a linear layer on top of the hidden-states output) e.g. for Named-Entity-Recognition (NER) tasks.
#
# Pretrained models can be loaded with `pretrained()` of the companion object. The default model is `"bert_base_token_classifier_conll03"`, if no name is provided. <br/><br/>
#
#
# ### **Here are Bert Based Token Classification models available in Spark NLP**
# <br/>
#
# | Title                                                                                                                        | Name                                          | Language   |
# |:-----------------------------------------------------------------------------------------------------------------------------|:----------------------------------------------|:-----------|
# | BERT Token Classification - NER CoNLL (bert_base_token_classifier_conll03)                                                   | bert_base_token_classifier_conll03            | en         |
# | BERT Token Classification - NER OntoNotes (bert_base_token_classifier_ontonote)                                              | bert_base_token_classifier_ontonote           | en         |
# | BERT Token Classification Large - NER CoNLL (bert_large_token_classifier_conll03)                                            | bert_large_token_classifier_conll03           | en         |
# | BERT Token Classification Large - NER OntoNotes (bert_large_token_classifier_ontonote)                                       | bert_large_token_classifier_ontonote          | en         |
# | BERT Token Classification - ParsBERT for Persian Language Understanding (bert_token_classifier_parsbert_armanner)            | bert_token_classifier_parsbert_armanner       | fa         |
# | BERT Token Classification - ParsBERT for Persian Language Understanding (bert_token_classifier_parsbert_ner)                 | bert_token_classifier_parsbert_ner            | fa         |
# | BERT Token Classification - ParsBERT for Persian Language Understanding (bert_token_classifier_parsbert_peymaner)            | bert_token_classifier_parsbert_peymaner       | fa         |
# | BERT Token Classification - BETO Spanish Language Understanding (bert_token_classifier_spanish_ner)                          | bert_token_classifier_spanish_ner             | es         |
# | BERT Token Classification - Swedish Language Understanding (bert_token_classifier_swedish_ner)                               | bert_token_classifier_swedish_ner             | sv         |
# | BERT Token Classification - Turkish Language Understanding (bert_token_classifier_turkish_ner)                               | bert_token_classifier_turkish_ner             | tr         |
# | DistilBERT Token Classification - NER CoNLL (distilbert_base_token_classifier_conll03)                                       | distilbert_base_token_classifier_conll03      | en         |
# | DistilBERT Token Classification - NER OntoNotes (distilbert_base_token_classifier_ontonotes)                                 | distilbert_base_token_classifier_ontonotes    | en         |
# | DistilBERT Token Classification - DistilbertNER for Persian Language Understanding (distilbert_token_classifier_persian_ner) | distilbert_token_classifier_persian_ner       | fa         |
# | BERT Token Classification -  Few-NERD (bert_base_token_classifier_few_nerd)                                                  | bert_base_token_classifier_few_nerd           | en         |
# | DistilBERT Token Classification -  Few-NERD (distilbert_base_token_classifier_few_nerd)                                      | distilbert_base_token_classifier_few_nerd     | en         |
# | Named Entity Recognition for Japanese (BertForTokenClassification)                                                           | bert_token_classifier_ner_ud_gsd              | ja         |
# | Detect PHI for Deidentification (BertForTokenClassifier)                                                                     | bert_token_classifier_ner_deid                | en         |
# | Detect Clinical Entities (BertForTokenClassifier)                                                                            | bert_token_classifier_ner_jsl                 | en         |
# | Detect Drug Chemicals (BertForTokenClassifier)                                                                               | bert_token_classifier_ner_drugs               | en         |
# | Detect Clinical Entities (Slim version, BertForTokenClassifier)                                                              | bert_token_classifier_ner_jsl_slim            | en         |
# | ALBERT Token Classification Base - NER CoNLL (albert_base_token_classifier_conll03)                                          | albert_base_token_classifier_conll03          | en         |
# | ALBERT Token Classification Large - NER CoNLL (albert_large_token_classifier_conll03)                                        | albert_large_token_classifier_conll03         | en         |
# | ALBERT Token Classification XLarge - NER CoNLL (albert_xlarge_token_classifier_conll03)                                      | albert_xlarge_token_classifier_conll03        | en         |
# | DistilRoBERTa Token Classification - NER OntoNotes (distilroberta_base_token_classifier_ontonotes)                           | distilroberta_base_token_classifier_ontonotes | en         |
# | RoBERTa Token Classification Base - NER CoNLL (roberta_base_token_classifier_conll03)                                        | roberta_base_token_classifier_conll03         | en         |
# | RoBERTa Token Classification Base - NER OntoNotes (roberta_base_token_classifier_ontonotes)                                  | roberta_base_token_classifier_ontonotes       | en         |
# | RoBERTa Token Classification Large - NER CoNLL (roberta_large_token_classifier_conll03)                                      | roberta_large_token_classifier_conll03        | en         |
# | RoBERTa Token Classification Large - NER OntoNotes (roberta_large_token_classifier_ontonotes)                                | roberta_large_token_classifier_ontonotes      | en         |
# | RoBERTa Token Classification For Persian (roberta_token_classifier_zwnj_base_ner)                                            | roberta_token_classifier_zwnj_base_ner        | fa         |
# | XLM-RoBERTa Token Classification Base - NER XTREME (xlm_roberta_token_classifier_ner_40_lang)                                | xlm_roberta_token_classifier_ner_40_lang      | xx         |
# | XLNet Token Classification Base - NER CoNLL (xlnet_base_token_classifier_conll03)                                            | xlnet_base_token_classifier_conll03           | en         |
# | XLNet Token Classification Large - NER CoNLL (xlnet_large_token_classifier_conll03)                                          | xlnet_large_token_classifier_conll03          | en         |
# | Detect Adverse Drug Events (BertForTokenClassification)                                                                      | bert_token_classifier_ner_ade                 | en         |
# | Detect Anatomical Regions (BertForTokenClassification)                                                                       | bert_token_classifier_ner_anatomy             | en         |
# | Detect Bacterial Species (BertForTokenClassification)                                                                        | bert_token_classifier_ner_bacteria            | en         |
# | XLM-RoBERTa Token Classification Base - NER CoNLL (xlm_roberta_base_token_classifier_conll03)                                | xlm_roberta_base_token_classifier_conll03     | en         |
# | XLM-RoBERTa Token Classification Base - NER OntoNotes (xlm_roberta_base_token_classifier_ontonotes)                          | xlm_roberta_base_token_classifier_ontonotes   | en         |
# | Longformer Token Classification Base - NER CoNLL (longformer_base_token_classifier_conll03)                                  | longformer_base_token_classifier_conll03      | en         |
# | Longformer Token Classification Base - NER CoNLL (longformer_large_token_classifier_conll03)                                 | longformer_large_token_classifier_conll03     | en         |
# | Detect Chemicals in Medical text (BertForTokenClassification)                                                                | bert_token_classifier_ner_chemicals           | en         |
# | Detect Chemical Compounds and Genes (BertForTokenClassifier)                                                                 | bert_token_classifier_ner_chemprot            | en         |
# | Detect Cancer Genetics (BertForTokenClassification)                                                                          | bert_token_classifier_ner_bionlp              | en         |
# | Detect Cellular/Molecular Biology Entities (BertForTokenClassification)                                                      | bert_token_classifier_ner_cellular            | en         |
# | Detect concepts in drug development trials (BertForTokenClassification)                                                      | bert_token_classifier_drug_development_trials | en         |
# | Detect Cancer Genetics (BertForTokenClassification)                                                                          | bert_token_classifier_ner_bionlp              | en         |
# | Detect Adverse Drug Events (BertForTokenClassification)                                                                      | bert_token_classifier_ner_ade                 | en         |
# | Detect Anatomical Regions (MedicalBertForTokenClassifier)                                                                    | bert_token_classifier_ner_anatomy             | en         |
# | Detect Cellular/Molecular Biology Entities (BertForTokenClassification)                                                      | bert_token_classifier_ner_cellular            | en         |
# | Detect Chemicals in Medical text (BertForTokenClassification)                                                                | bert_token_classifier_ner_chemicals           | en         |
# | Detect Chemical Compounds and Genes (BertForTokenClassifier)                                                                 | bert_token_classifier_ner_chemprot            | en         |
# | Detect PHI for Deidentification (BertForTokenClassifier)                                                                     | bert_token_classifier_ner_deid                | en         |
# | Detect Drug Chemicals (BertForTokenClassifier)                                                                               | bert_token_classifier_ner_drugs               | en         |
# | Detect Clinical Entities (BertForTokenClassifier)                                                                            | bert_token_classifier_ner_jsl                 | en         |
# | Detect Clinical Entities (Slim version, BertForTokenClassifier)                                                              | bert_token_classifier_ner_jsl_slim            | en         |
# | Detect Bacterial Species (BertForTokenClassification)                                                                        | bert_token_classifier_ner_bacteria            | en         |

# %% [markdown]
# You can also import any models trained with the transformers library into Spark NLP for greater inference speed & scalability. Access our tutorials to do so in [this discussion thread](https://github.com/JohnSnowLabs/spark-nlp/discussions/5669). You will find notebooks like [this one](https://github.com/JohnSnowLabs/spark-nlp/blob/74b8f230bc1547ee1b1152fbd19c111e8610f13c/examples/python/transformers/HuggingFace%20in%20Spark%20NLP%20-%20BertForTokenClassification.ipynb) to import BertForTokenClassification models. The process is very straightforward and can be done in a few lines of code. Once you've downloaded the model and extracted its contents as described in the notebooks, it's as simple as running the following snippet:

# %% [markdown]
# ```
# tokenClassifier = BertForTokenClassification.loadSavedModel(
#      '{}/saved_model/1'.format(MODEL_NAME), spark)\
#  .setInputCols(["document",'token'])\
#  .setOutputCol("ner")\
#  .setCaseSensitive(True)\
#  .setMaxSentenceLength(128)
#
# tokenClassifier.write().overwrite().save("./{}_spark_nlp".format(MODEL_NAME))
# ```

# %% [markdown]
# ## Colab Setup

# %%
# !wget -q http://setup.johnsnowlabs.com/colab.sh -O - | bash

# %%
import sparknlp

from sparknlp.base import *
from sparknlp.annotator import *
from pyspark.ml import Pipeline,PipelineModel
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
import pandas as pd

spark = sparknlp.start()

print("Spark NLP version", sparknlp.version())
print("Apache Spark version:", spark.version)

spark
# Out:
# Spark NLP version 6.2.0
# Apache Spark version: 3.5.1
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://a08017834a51:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark NLP</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## BertForTokenClassification Pipeline

# %% [markdown]
# Now, let's create a Spark NLP Pipeline with `bert_base_token_classifier_conll03` model and check the results. <br/>

# %%
document_assembler = DocumentAssembler() \
    .setInputCol('text') \
    .setOutputCol('document')

tokenizer = Tokenizer() \
    .setInputCols(['document']) \
    .setOutputCol('token')

tokenClassifier = BertForTokenClassification \
    .pretrained('bert_base_token_classifier_conll03', 'en') \
    .setInputCols(['token', 'document']) \
    .setOutputCol('ner') \
    .setCaseSensitive(True) \
    .setMaxSentenceLength(512)

# since output column is IOB/IOB2 style, NerConverter can extract entities
ner_converter = NerConverter() \
    .setInputCols(['document', 'token', 'ner']) \
    .setOutputCol('entities')

pipeline = Pipeline(
    stages=[
        document_assembler,
        tokenizer,
        tokenClassifier,
        ner_converter
])

example = spark.createDataFrame([['My name is John Parker! I live in New York and I am a member of the New York Road Runners.']]).toDF("text")
model = pipeline.fit(example)
result= model.transform(example)
# Out:
# bert_base_token_classifier_conll03 download started this may take some time.
# Approximate size to download 385.4 MB
# [OK!]

# %%
model.stages
# Out:
# [DocumentAssembler_3c72149d6ad3,
#  REGEX_TOKENIZER_b58826e7149d,
#  BERT_FOR_TOKEN_CLASSIFICATION_675a6a750b89,
#  NerConverter_9ca1674549b0]

# %% [markdown]
# We can check the classes of `bert_base_token_classifier_conll03` model by using `getClasses()` function

# %%
tokenClassifier.getClasses()
# Out:
# ['B-LOC', 'I-ORG', 'I-MISC', 'I-LOC', 'I-PER', 'B-MISC', 'B-ORG', 'O', 'B-PER']

# %%
result.columns
# Out:
# ['text', 'document', 'token', 'ner', 'entities']

# %%
result.printSchema()
# Out:
# root
#  |-- text: string (nullable = true)
#  |-- document: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- annotatorType: string (nullable = true)
#  |    |    |-- begin: integer (nullable = false)
#  |    |    |-- end: integer (nullable = false)
#  |    |    |-- result: string (nullable = true)
#  |    |    |-- metadata: map (nullable = true)
#  |    |    |    |-- key: string
#  |    |    |    |-- value: string (valueContainsNull = true)
#  |    |    |-- embeddings: array (nullable = true)
#  |    |    |    |-- element: float (containsNull = false)
#  |-- token: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- annotatorType: string (nullable = true)
#  |    |    |-- begin: integer (nullable = false)
#  |    |    |-- end: integer (nullable = false)
#  |    |    |-- result: string (nullable = true)
#  |    |    |-- metadata: map (nullable = true)
#  |    |    |    |-- key: string
#  |    |    |    |-- value: string (valueContainsNull = true)
#  |    |    |-- embeddings: array (nullable = true)
#  |    |    |    |-- element: float (containsNull = false)
#  |-- ner: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- annotatorType: string (nullable = true)
#  |    |    |-- begin: integer (nullable = false)
#  |    |    |-- end: integer (nullable = false)
#  |    |    |-- result: string (nullable = true)
#  |    |    |-- metadata: map (nullable = true)
#  |    |    |    |-- key: string
#  |    |    |    |-- value: string (valueContainsNull = true)
#  |    |    |-- embeddings: array (nullable = true)
#  |    |    |    |-- element: float (containsNull = false)
#  |-- entities: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- annotatorType: string (nullable = true)
#  |    |    |-- begin: integer (nullable = false)
#  |    |    |-- end: integer (nullable = false)
#  |    |    |-- result: string (nullable = true)
#  |    |    |-- metadata: map (nullable = true)
#  |    |    |    |-- key: string
#  |    |    |    |-- value: string (valueContainsNull = true)
#  |    |    |-- embeddings: array (nullable = true)
#  |    |    |    |-- element: float (containsNull = false)

# %% [markdown]
# Checking the ner labels of each token

# %%
result_df = result.select(F.explode(F.arrays_zip(result.token.result,
                                                 result.ner.result)).alias("cols"))\
                  .select(F.expr("cols['0']").alias("token"),
                          F.expr("cols['1']").alias("ner_label"))

result_df.show(50, truncate=100)
# Out:
# +-------+---------+
# |  token|ner_label|
# +-------+---------+
# |     My|        O|
# |   name|        O|
# |     is|        O|
# |   John|    B-PER|
# | Parker|    I-PER|
# |      !|        O|
# |      I|        O|
# |   live|        O|
# |     in|        O|
# |    New|    B-LOC|
# |   York|    I-LOC|
# |    and|        O|
# |      I|        O|
# |     am|        O|
# |      a|        O|
# | member|        O|
# |     of|        O|
# |    the|        O|
# |    New|    B-ORG|
# |   York|    I-ORG|
# |   Road|    I-ORG|
# |Runners|    I-ORG|
# |      .|        O|
# +-------+---------+

# %% [markdown]
# Inspecting the chunks

# %%
result_df_1= result.select(F.explode(F.arrays_zip(result.entities.result,
                                                  result.entities.begin,
                                                  result.entities.end,
                                                  result.entities.metadata)).alias("col"))\
                   .select(F.expr("col['0']").alias("entities"),
                            F.expr("col['1']").alias("begin"),
                            F.expr("col['2']").alias("end"),
                            F.expr("col['3']['entity']").alias("ner_label"))

result_df_1.show(50, truncate=False)
# Out:
# +---------------------+-----+---+---------+
# |entities             |begin|end|ner_label|
# +---------------------+-----+---+---------+
# |John Parker          |11   |21 |PER      |
# |New York             |34   |41 |LOC      |
# |New York Road Runners|68   |88 |ORG      |
# +---------------------+-----+---+---------+

# %% [markdown]
# ##  BertForTokenClassification By Using LightPipeline

# %% [markdown]
# Now,  we will use the `bert_large_token_classifier_ontonote` model with LightPipeline and fullAnnotate it with sample data.

# %%
document_assembler = DocumentAssembler() \
    .setInputCol('text') \
    .setOutputCol('document')

tokenizer = Tokenizer() \
    .setInputCols(['document']) \
    .setOutputCol('token')

tokenClassifier = BertForTokenClassification \
    .pretrained('bert_large_token_classifier_ontonote', 'en') \
    .setInputCols(['token', 'document']) \
    .setOutputCol('ner') \
    .setCaseSensitive(True) \
    .setMaxSentenceLength(512)

# since output column is IOB/IOB2 style, NerConverter can extract entities
ner_converter = NerConverter() \
    .setInputCols(['document', 'token', 'ner']) \
    .setOutputCol('entities')

pipeline = Pipeline(
    stages=[
        document_assembler,
        tokenizer,
        tokenClassifier,
        ner_converter
])

empty_df = spark.createDataFrame([['']]).toDF("text")
model = pipeline.fit(example)
# Out:
# bert_large_token_classifier_ontonote download started this may take some time.
# Approximate size to download 1.2 GB
# [OK!]

# %%
light_model= LightPipeline(model)
light_result= light_model.fullAnnotate("Steven Rothery is the original guitarist and the longest continuous member of the British rock band Marillion.")[0]

# %%
light_result
# Out:
# {'document': [Annotation(document, 0, 109, Steven Rothery is the original guitarist and the longest continuous member of the British rock band Marillion., {}, [])],
#  'token': [Annotation(token, 0, 5, Steven, {'sentence': '0'}, []),
#   Annotation(token, 7, 13, Rothery, {'sentence': '0'}, []),
#   Annotation(token, 15, 16, is, {'sentence': '0'}, []),
#   Annotation(token, 18, 20, the, {'sentence': '0'}, []),
#   Annotation(token, 22, 29, original, {'sentence': '0'}, []),
#   Annotation(token, 31, 39, guitarist, {'sentence': '0'}, []),
#   Annotation(token, 41, 43, and, {'sentence': '0'}, []),
#   Annotation(token, 45, 47, the, {'sentence': '0'}, []),
#   Annotation(token, 49, 55, longest, {'sentence': '0'}, []),
#   Annotation(token, 57, 66, continuous, {'sentence': '0'}, []),
#   Annotation(token, 68, 73, member, {'sentence': '0'}, []),
#   Annotation(token, 75, 76, of, {'sentence': '0'}, []),
#   Annotation(token, 78, 80, the, {'sentence': '0'}, []),
#   Annotation(token, 82, 88, British, {'sentence': '0'}, []),
#   Annotation(token, 90, 93, rock, {'sentence': '0'}, []),
#   Annotation(token, 95, 98, band, {'sentence': '0'}, []),
#   Annotation(token, 100, 108, Marillion, {'sentence': '0'}, []),
#   Annotation(token, 109, 109, ., {'sentence': '0'}, [])],
#  'ner': [Annotation(named_entity, 0, 5, B-PERSON, {'I-TIME': '6.1151095E-6', 'B-PERSON': '0.99626774', 'B-GPE': '1.4145728E-4', 'B-LAW': '3.8991775E-6', 'B-NORP': '7.933833E-6', 'B-LOC': '4.8394018E-6', 'I-ORG': '7.028693E-6', 'I-QUANTITY': '6.0757934E-6', 'B-DATE': '1.3328474E-5', 'B-PRODUCT': '6.693481E-6', 'B-FAC': '3.3222973E-6', 'I-DATE': '9.561656E-6', 'I-WORK_OF_ART': '7.5560447E-6', 'B-TIME': '8.392697E-6', 'B-QUANTITY': '1.9475995E-6', 'I-PERCENT': '1.6473581E-6', 'I-LAW': '3.5765759E-6', 'I-GPE': '7.099687E-6', 'I-NORP': '1.6927808E-6', 'I-ORDINAL': '7.2051733E-7', 'I-EVENT': '2.5540241E-6', 'I-LOC': '2.452749E-6', 'B-EVENT': '1.8551714E-6', 'I-FAC': '3.809145E-6', 'B-ORDINAL': '3.6989925E-6', 'B-LANGUAGE': '3.4697189E-6', 'B-MONEY': '1.3152049E-6', 'B-PERCENT': '3.3578328E-6', 'I-LANGUAGE': '6.9534684E-7', 'B-ORG': '2.346658E-5', 'I-MONEY': '4.328781E-6', 'I-PRODUCT': '3.2988482E-6', 'word': 'Steven', 'O': '0.0033311422', 'B-WORK_OF_ART': '1.2767629E-5', 'I-CARDINAL': '1.3950191E-6', 'sentence': '0', 'I-PERSON': '7.72544E-5', 'B-CARDINAL': '1.2494112E-5'}, []),
#   Annotation(named_entity, 7, 13, I-PERSON, {'I-TIME': '1.424027E-5', 'B-PERSON': '4.103248E-4', 'B-GPE': '2.3291497E-5', 'B-LAW': '2.1709166E-6', 'B-NORP': '1.3806134E-5', 'B-LOC': '9.734777E-6', 'I-ORG': '4.734241E-5', 'I-QUANTITY': '1.2247509E-5', 'B-DATE': '2.9426654E-5', 'B-PRODUCT': '2.9593863E-5', 'B-FAC': '7.1879786E-6', 'I-DATE': '2.9977851E-5', 'I-WORK_OF_ART': '2.660501E-5', 'B-TIME': '1.3115954E-5', 'B-QUANTITY': '6.9066773E-6', 'I-PERCENT': '7.0828773E-6', 'I-LAW': '6.942642E-6', 'I-GPE': '3.1855397E-4', 'I-NORP': '1.0157981E-5', 'I-ORDINAL': '3.0856418E-6', 'I-EVENT': '4.2831016E-6', 'I-LOC': '1.6996042E-5', 'B-EVENT': '3.910154E-6', 'I-FAC': '2.4908011E-5', 'B-ORDINAL': '1.30092985E-5', 'B-LANGUAGE': '1.4290207E-5', 'B-MONEY': '7.3237456E-6', 'B-PERCENT': '7.989429E-6', 'I-LANGUAGE': '3.4063078E-6', 'B-ORG': '1.0138179E-5', 'I-MONEY': '6.0185935E-6', 'I-PRODUCT': '1.111118E-5', 'word': 'Rothery', 'O': '0.0018733718', 'B-WORK_OF_ART': '9.871203E-6', 'I-CARDINAL': '8.122974E-6', 'sentence': '0', 'I-PERSON': '0.9969444', 'B-CARDINAL': '1.9044637E-5'}, []),
#   Annotation(named_entity, 15, 16, O, {'I-TIME': '3.86558E-7', 'B-PERSON': '6.6300436E-7', 'B-GPE': '7.925201E-7', 'B-LAW': '4.221998E-8', 'B-NORP': '5.994304E-7', 'B-LOC': '2.754835E-7', 'I-ORG': '9.4467293E-7', 'I-QUANTITY': '2.4990823E-7', 'B-DATE': '7.7304094E-7', 'B-PRODUCT': '1.5317185E-7', 'B-FAC': '8.660252E-8', 'I-DATE': '7.028276E-7', 'I-WORK_OF_ART': '3.131517E-7', 'B-TIME': '2.8454812E-7', 'B-QUANTITY': '2.1128642E-7', 'I-PERCENT': '1.5794495E-7', 'I-LAW': '2.3141018E-7', 'I-GPE': '4.1680767E-7', 'I-NORP': '2.4702118E-7', 'I-ORDINAL': '1.5439587E-8', 'I-EVENT': '8.880259E-8', 'I-LOC': '3.1517916E-7', 'B-EVENT': '7.4982424E-8', 'I-FAC': '2.479032E-7', 'B-ORDINAL': '5.43908E-7', 'B-LANGUAGE': '2.0738013E-7', 'B-MONEY': '1.0794629E-7', 'B-PERCENT': '8.6701434E-8', 'I-LANGUAGE': '3.035085E-8', 'B-ORG': '5.728579E-7', 'I-MONEY': '2.1215658E-7', 'I-PRODUCT': '2.451803E-7', 'word': 'is', 'O': '0.9999866', 'B-WORK_OF_ART': '2.3540869E-7', 'I-CARDINAL': '5.2121794E-7', 'sentence': '0', 'I-PERSON': '1.0965246E-6', 'B-CARDINAL': '1.2842792E-6'}, []),
#   Annotation(named_entity, 18, 20, O, {'I-TIME': '2.4348685E-7', 'B-PERSON': '7.133418E-7', 'B-GPE': '7.287976E-7', 'B-LAW': '5.4052503E-8', 'B-NORP': '7.287358E-7', 'B-LOC': '3.285901E-7', 'I-ORG': '6.7114115E-7', 'I-QUANTITY': '1.4615945E-7', 'B-DATE': '5.5362585E-7', 'B-PRODUCT': '1.4275204E-7', 'B-FAC': '1.3795854E-7', 'I-DATE': '3.167474E-7', 'I-WORK_OF_ART': '3.1734672E-7', 'B-TIME': '2.8970013E-7', 'B-QUANTITY': '1.8148775E-7', 'I-PERCENT': '9.76584E-8', 'I-LAW': '1.4687089E-7', 'I-GPE': '2.3016113E-7', 'I-NORP': '1.634335E-7', 'I-ORDINAL': '1.0861936E-8', 'I-EVENT': '6.035448E-8', 'I-LOC': '1.7601114E-7', 'B-EVENT': '8.1976516E-8', 'I-FAC': '1.8828676E-7', 'B-ORDINAL': '3.868193E-7', 'B-LANGUAGE': '2.0906302E-7', 'B-MONEY': '1.5569363E-7', 'B-PERCENT': '6.86033E-8', 'I-LANGUAGE': '2.795139E-8', 'B-ORG': '7.025224E-7', 'I-MONEY': '1.6076146E-7', 'I-PRODUCT': '1.4630417E-7', 'word': 'the', 'O': '0.99998903', 'B-WORK_OF_ART': '3.0794925E-7', 'I-CARDINAL': '3.8008227E-7', 'sentence': '0', 'I-PERSON': '6.8696437E-7', 'B-CARDINAL': '1.020985E-6'}, []),
#   Annotation(named_entity, 22, 29, O, {'I-TIME': '2.5100638E-7', 'B-PERSON': '6.866432E-7', 'B-GPE': '8.604855E-7', 'B-LAW': '5.879263E-8', 'B-NORP': '1.2914896E-6', 'B-LOC': '3.208236E-7', 'I-ORG': '6.8484013E-7', 'I-QUANTITY': '2.0690516E-7', 'B-DATE': '4.0764087E-7', 'B-PRODUCT': '1.4175099E-7', 'B-FAC': '1.405734E-7', 'I-DATE': '3.9316424E-7', 'I-WORK_OF_ART': '3.6910325E-7', 'B-TIME': '2.2995704E-7', 'B-QUANTITY': '2.1450803E-7', 'I-PERCENT': '1.07629766E-7', 'I-LAW': '1.6286337E-7', 'I-GPE': '2.2095855E-7', 'I-NORP': '2.1551374E-7', 'I-ORDINAL': '1.38429925E-8', 'I-EVENT': '7.154849E-8', 'I-LOC': '2.2492786E-7', 'B-EVENT': '6.1492884E-8', 'I-FAC': '2.1919317E-7', 'B-ORDINAL': '7.40048E-7', 'B-LANGUAGE': '2.6857998E-7', 'B-MONEY': '1.4224813E-7', 'B-PERCENT': '7.156625E-8', 'I-LANGUAGE': '3.8660374E-8', 'B-ORG': '6.874445E-7', 'I-MONEY': '2.1183392E-7', 'I-PRODUCT': '1.44054E-7', 'word': 'original', 'O': '0.9999876', 'B-WORK_OF_ART': '3.02816E-7', 'I-CARDINAL': '5.2331336E-7', 'sentence': '0', 'I-PERSON': '5.671826E-7', 'B-CARDINAL': '1.1732989E-6'}, []),
#   Annotation(named_entity, 31, 39, O, {'I-TIME': '3.4984862E-7', 'B-PERSON': '3.816698E-6', 'B-GPE': '1.2944042E-6', 'B-LAW': '9.656976E-8', 'B-NORP': '1.9287095E-6', 'B-LOC': '4.7125553E-7', 'I-ORG': '6.7371735E-7', 'I-QUANTITY': '3.0121407E-7', 'B-DATE': '7.4836447E-7', 'B-PRODUCT': '2.1018134E-7', 'B-FAC': '1.5027935E-7', 'I-DATE': '6.925555E-7', 'I-WORK_OF_ART': '5.235124E-7', 'B-TIME': '5.2949076E-7', 'B-QUANTITY': '3.1332567E-7', 'I-PERCENT': '1.6266898E-7', 'I-LAW': '2.0179672E-7', 'I-GPE': '2.9059416E-7', 'I-NORP': '2.0849679E-7', 'I-ORDINAL': '2.011456E-8', 'I-EVENT': '1.1304626E-7', 'I-LOC': '2.4137537E-7', 'B-EVENT': '9.94773E-8', 'I-FAC': '2.7406287E-7', 'B-ORDINAL': '1.1287544E-6', 'B-LANGUAGE': '3.4140433E-7', 'B-MONEY': '2.0582853E-7', 'B-PERCENT': '1.2621904E-7', 'I-LANGUAGE': '5.008558E-8', 'B-ORG': '1.0977388E-6', 'I-MONEY': '2.8653864E-7', 'I-PRODUCT': '1.484486E-7', 'word': 'guitarist', 'O': '0.9999756', 'B-WORK_OF_ART': '4.5802992E-7', 'I-CARDINAL': '8.827049E-7', 'sentence': '0', 'I-PERSON': '1.4571565E-6', 'B-CARDINAL': '4.5018974E-6'}, []),
#   Annotation(named_entity, 41, 43, O, {'I-TIME': '3.0524745E-7', 'B-PERSON': '3.163639E-7', 'B-GPE': '4.70283E-7', 'B-LAW': '3.694539E-8', 'B-NORP': '4.525522E-7', 'B-LOC': '2.0998587E-7', 'I-ORG': '7.8954935E-7', 'I-QUANTITY': '2.1958391E-7', 'B-DATE': '4.0365163E-7', 'B-PRODUCT': '1.044062E-7', 'B-FAC': '9.174519E-8', 'I-DATE': '5.0778965E-7', 'I-WORK_OF_ART': '3.476018E-7', 'B-TIME': '2.6602257E-7', 'B-QUANTITY': '1.6369322E-7', 'I-PERCENT': '1.3021564E-7', 'I-LAW': '1.7884663E-7', 'I-GPE': '2.6235762E-7', 'I-NORP': '1.77111E-7', 'I-ORDINAL': '1.17383285E-8', 'I-EVENT': '7.403513E-8', 'I-LOC': '2.1914252E-7', 'B-EVENT': '5.5667996E-8', 'I-FAC': '2.4401677E-7', 'B-ORDINAL': '4.1297548E-7', 'B-LANGUAGE': '1.9004021E-7', 'B-MONEY': '1.1742105E-7', 'B-PERCENT': '6.338308E-8', 'I-LANGUAGE': '3.0263884E-8', 'B-ORG': '3.5136395E-7', 'I-MONEY': '1.8880702E-7', 'I-PRODUCT': '1.7161761E-7', 'word': 'and', 'O': '0.9999901', 'B-WORK_OF_ART': '1.8862941E-7', 'I-CARDINAL': '6.0852426E-7', 'sentence': '0', 'I-PERSON': '6.0003447E-7', 'B-CARDINAL': '9.566439E-7'}, []),
#   Annotation(named_entity, 45, 47, O, {'I-TIME': '2.8474827E-7', 'B-PERSON': '3.5432743E-7', 'B-GPE': '5.5795834E-7', 'B-LAW': '5.1527056E-8', 'B-NORP': '6.0163103E-7', 'B-LOC': '2.579843E-7', 'I-ORG': '5.862525E-7', 'I-QUANTITY': '1.8784665E-7', 'B-DATE': '5.7290134E-7', 'B-PRODUCT': '1.1919932E-7', 'B-FAC': '1.07666445E-7', 'I-DATE': '3.89496E-7', 'I-WORK_OF_ART': '3.026032E-7', 'B-TIME': '3.0503253E-7', 'B-QUANTITY': '2.2696949E-7', 'I-PERCENT': '1.1160008E-7', 'I-LAW': '1.612599E-7', 'I-GPE': '2.386264E-7', 'I-NORP': '1.7043551E-7', 'I-ORDINAL': '1.1755584E-8', 'I-EVENT': '6.483445E-8', 'I-LOC': '1.8698832E-7', 'B-EVENT': '6.865429E-8', 'I-FAC': '2.0538924E-7', 'B-ORDINAL': '4.576463E-7', 'B-LANGUAGE': '2.1570497E-7', 'B-MONEY': '1.4063949E-7', 'B-PERCENT': '7.230116E-8', 'I-LANGUAGE': '3.4243726E-8', 'B-ORG': '4.1746287E-7', 'I-MONEY': '1.6414458E-7', 'I-PRODUCT': '1.500411E-7', 'word': 'the', 'O': '0.99998987', 'B-WORK_OF_ART': '2.4347867E-7', 'I-CARDINAL': '4.2219185E-7', 'sentence': '0', 'I-PERSON': '5.359807E-7', 'B-CARDINAL': '1.1482133E-6'}, []),
#   Annotation(named_entity, 49, 55, O, {'I-TIME': '2.8749378E-7', 'B-PERSON': '3.924699E-7', 'B-GPE': '5.829022E-7', 'B-LAW': '5.051623E-8', 'B-NORP': '8.268727E-7', 'B-LOC': '2.46604E-7', 'I-ORG': '5.411242E-7', 'I-QUANTITY': '2.0865664E-7', 'B-DATE': '4.7395213E-7', 'B-PRODUCT': '1.4354768E-7', 'B-FAC': '9.93796E-8', 'I-DATE': '6.1636496E-7', 'I-WORK_OF_ART': '2.802674E-7', 'B-TIME': '2.1724847E-7', 'B-QUANTITY': '1.9384805E-7', 'I-PERCENT': '1.1470209E-7', 'I-LAW': '1.8392501E-7', 'I-GPE': '2.4502864E-7', 'I-NORP': '1.9744978E-7', 'I-ORDINAL': '1.6311551E-8', 'I-EVENT': '7.060316E-8', 'I-LOC': '2.6364958E-7', 'B-EVENT': '6.2910686E-8', 'I-FAC': '2.2552096E-7', 'B-ORDINAL': '6.437925E-7', 'B-LANGUAGE': '2.1591052E-7', 'B-MONEY': '1.060963E-7', 'B-PERCENT': '8.357659E-8', 'I-LANGUAGE': '3.696856E-8', 'B-ORG': '4.4694187E-7', 'I-MONEY': '1.7052596E-7', 'I-PRODUCT': '1.4327674E-7', 'word': 'longest', 'O': '0.99998915', 'B-WORK_OF_ART': '2.4463927E-7', 'I-CARDINAL': '5.8094093E-7', 'sentence': '0', 'I-PERSON': '4.719427E-7', 'B-CARDINAL': '1.1837498E-6'}, []),
#   Annotation(named_entity, 57, 66, O, {'I-TIME': '2.5847544E-7', 'B-PERSON': '5.4313136E-7', 'B-GPE': '8.628242E-7', 'B-LAW': '6.1866466E-8', 'B-NORP': '1.3904247E-6', 'B-LOC': '3.4494582E-7', 'I-ORG': '5.6062567E-7', 'I-QUANTITY': '2.2005256E-7', 'B-DATE': '4.998681E-7', 'B-PRODUCT': '1.3334072E-7', 'B-FAC': '1.0381815E-7', 'I-DATE': '5.131989E-7', 'I-WORK_OF_ART': '2.8196942E-7', 'B-TIME': '1.812651E-7', 'B-QUANTITY': '2.0724265E-7', 'I-PERCENT': '1.1213415E-7', 'I-LAW': '1.7778397E-7', 'I-GPE': '2.2130773E-7', 'I-NORP': '2.1182899E-7', 'I-ORDINAL': '1.272319E-8', 'I-EVENT': '6.851549E-8', 'I-LOC': '1.9803092E-7', 'B-EVENT': '6.844553E-8', 'I-FAC': '1.9618547E-7', 'B-ORDINAL': '4.187846E-7', 'B-LANGUAGE': '2.4040534E-7', 'B-MONEY': '1.1560642E-7', 'B-PERCENT': '6.876786E-8', 'I-LANGUAGE': '3.748445E-8', 'B-ORG': '6.8316746E-7', 'I-MONEY': '1.8013755E-7', 'I-PRODUCT': '1.2787719E-7', 'word': 'continuous', 'O': '0.9999886', 'B-WORK_OF_ART': '2.9034916E-7', 'I-CARDINAL': '5.215772E-7', 'sentence': '0', 'I-PERSON': '4.1704425E-7', 'B-CARDINAL': '8.5142347E-7'}, []),
#   Annotation(named_entity, 68, 73, O, {'I-TIME': '3.318877E-7', 'B-PERSON': '7.128178E-7', 'B-GPE': '9.816886E-7', 'B-LAW': '6.199939E-8', 'B-NORP': '8.9437793E-7', 'B-LOC': '3.9483535E-7', 'I-ORG': '6.945246E-7', 'I-QUANTITY': '2.4650853E-7', 'B-DATE': '4.3795632E-7', 'B-PRODUCT': '1.2699817E-7', 'B-FAC': '1.2063178E-7', 'I-DATE': '4.3742676E-7', 'I-WORK_OF_ART': '3.1618436E-7', 'B-TIME': '2.3826341E-7', 'B-QUANTITY': '2.3552018E-7', 'I-PERCENT': '1.16960926E-7', 'I-LAW': '1.8271693E-7', 'I-GPE': '2.6424263E-7', 'I-NORP': '1.7661327E-7', 'I-ORDINAL': '1.4452917E-8', 'I-EVENT': '7.5440134E-8', 'I-LOC': '2.2924415E-7', 'B-EVENT': '6.182368E-8', 'I-FAC': '2.0973592E-7', 'B-ORDINAL': '5.114601E-7', 'B-LANGUAGE': '1.9716306E-7', 'B-MONEY': '1.2914319E-7', 'B-PERCENT': '8.468153E-8', 'I-LANGUAGE': '3.4440713E-8', 'B-ORG': '6.9654993E-7', 'I-MONEY': '1.9234416E-7', 'I-PRODUCT': '1.6248494E-7', 'word': 'member', 'O': '0.9999876', 'B-WORK_OF_ART': '2.8646636E-7', 'I-CARDINAL': '5.4486935E-7', 'sentence': '0', 'I-PERSON': '7.5696187E-7', 'B-CARDINAL': '1.2374003E-6'}, []),
#   Annotation(named_entity, 75, 76, O, {'I-TIME': '3.312181E-7', 'B-PERSON': '6.7985724E-7', 'B-GPE': '8.787888E-7', 'B-LAW': '6.6997025E-8', 'B-NORP': '8.160627E-7', 'B-LOC': '2.931927E-7', 'I-ORG': '1.6659598E-6', 'I-QUANTITY': '2.1699364E-7', 'B-DATE': '4.81422E-7', 'B-PRODUCT': '1.2819103E-7', 'B-FAC': '1.0664426E-7', 'I-DATE': '4.839175E-7', 'I-WORK_OF_ART': '4.7593093E-7', 'B-TIME': '2.8096002E-7', 'B-QUANTITY': '2.0669687E-7', 'I-PERCENT': '1.1879876E-7', 'I-LAW': '2.7258977E-7', 'I-GPE': '3.4713523E-7', 'I-NORP': '2.0278709E-7', 'I-ORDINAL': '1.2075723E-8', 'I-EVENT': '8.565495E-8', 'I-LOC': '2.6000288E-7', 'B-EVENT': '6.8901656E-8', 'I-FAC': '2.0633114E-7', 'B-ORDINAL': '3.53934E-7', 'B-LANGUAGE': '2.2440847E-7', 'B-MONEY': '1.3560738E-7', 'B-PERCENT': '7.82686E-8', 'I-LANGUAGE': '3.2886177E-8', 'B-ORG': '1.0927795E-6', 'I-MONEY': '2.1053326E-7', 'I-PRODUCT': '2.0844476E-7', 'word': 'of', 'O': '0.9999864', 'B-WORK_OF_ART': '2.8734718E-7', 'I-CARDINAL': '4.577298E-7', 'sentence': '0', 'I-PERSON': '1.0019489E-6', 'B-CARDINAL': '8.384346E-7'}, []),
#   Annotation(named_entity, 78, 80, O, {'I-TIME': '3.696093E-7', 'B-PERSON': '1.6163801E-6', 'B-GPE': '2.465877E-6', 'B-LAW': '1.5926081E-7', 'B-NORP': '2.6216824E-6', 'B-LOC': '6.920797E-7', 'I-ORG': '2.10677E-6', 'I-QUANTITY': '2.3134972E-7', 'B-DATE': '1.4277114E-6', 'B-PRODUCT': '3.0647973E-7', 'B-FAC': '2.5162626E-7', 'I-DATE': '4.0044148E-7', 'I-WORK_OF_ART': '6.549004E-7', 'B-TIME': '4.0672828E-7', 'B-QUANTITY': '2.802003E-7', 'I-PERCENT': '1.1915455E-7', 'I-LAW': '3.6300798E-7', 'I-GPE': '5.0643393E-7', 'I-NORP': '3.2464231E-7', 'I-ORDINAL': '1.5046377E-8', 'I-EVENT': '9.271294E-8', 'I-LOC': '2.7784532E-7', 'B-EVENT': '1.5293244E-7', 'I-FAC': '2.745745E-7', 'B-ORDINAL': '3.0539107E-7', 'B-LANGUAGE': '4.976153E-7', 'B-MONEY': '2.1697923E-7', 'B-PERCENT': '7.291126E-8', 'I-LANGUAGE': '4.6601066E-8', 'B-ORG': '2.8586353E-6', 'I-MONEY': '3.258154E-7', 'I-PRODUCT': '2.5653273E-7', 'word': 'the', 'O': '0.9999754', 'B-WORK_OF_ART': '5.869629E-7', 'I-CARDINAL': '4.5595857E-7', 'sentence': '0', 'I-PERSON': '1.7173708E-6', 'B-CARDINAL': '1.1622814E-6'}, []),
#   Annotation(named_entity, 82, 88, B-NORP, {'I-TIME': '5.4569705E-6', 'B-PERSON': '3.908793E-5', 'B-GPE': '4.4001464E-4', 'B-LAW': '4.057693E-6', 'B-NORP': '0.9969838', 'B-LOC': '3.4287295E-5', 'I-ORG': '1.10148185E-5', 'I-QUANTITY': '7.739908E-6', 'B-DATE': '1.2456092E-4', 'B-PRODUCT': '4.883015E-6', 'B-FAC': '2.0886516E-6', 'I-DATE': '4.9284117E-6', 'I-WORK_OF_ART': '1.2599795E-5', 'B-TIME': '6.1083956E-6', 'B-QUANTITY': '9.714403E-6', 'I-PERCENT': '4.0984232E-6', 'I-LAW': '5.71346E-6', 'I-GPE': '5.005003E-6', 'I-NORP': '3.92847E-5', 'I-ORDINAL': '1.1051741E-6', 'I-EVENT': '8.970189E-6', 'I-LOC': '6.140539E-6', 'B-EVENT': '1.0014333E-5', 'I-FAC': '3.50484E-6', 'B-ORDINAL': '3.2109842E-6', 'B-LANGUAGE': '6.432285E-5', 'B-MONEY': '5.7850816E-6', 'B-PERCENT': '3.7218274E-6', 'I-LANGUAGE': '4.563335E-6', 'B-ORG': '1.9561112E-5', 'I-MONEY': '1.1016988E-5', 'I-PRODUCT': '2.3243056E-6', 'word': 'British', 'O': '0.0020796887', 'B-WORK_OF_ART': '6.4216547E-6', 'I-CARDINAL': '6.244285E-6', 'sentence': '0', 'I-PERSON': '6.884402E-6', 'B-CARDINAL': '1.2067353E-5'}, []),
#   Annotation(named_entity, 90, 93, O, {'I-TIME': '2.6698578E-7', 'B-PERSON': '8.214968E-7', 'B-GPE': '1.2402369E-6', 'B-LAW': '6.230438E-8', 'B-NORP': '1.3332815E-6', 'B-LOC': '4.0598687E-7', 'I-ORG': '2.616434E-6', 'I-QUANTITY': '2.1346808E-7', 'B-DATE': '4.668437E-7', 'B-PRODUCT': '2.0992064E-7', 'B-FAC': '1.3046332E-7', 'I-DATE': '5.7873E-7', 'I-WORK_OF_ART': '6.7477936E-7', 'B-TIME': '1.9377121E-7', 'B-QUANTITY': '2.3035103E-7', 'I-PERCENT': '1.0234338E-7', 'I-LAW': '2.6961E-7', 'I-GPE': '6.23795E-7', 'I-NORP': '4.0283103E-7', 'I-ORDINAL': '1.6615633E-8', 'I-EVENT': '1.742692E-7', 'I-LOC': '5.4351534E-7', 'B-EVENT': '7.4210334E-8', 'I-FAC': '3.616071E-7', 'B-ORDINAL': '5.152944E-7', 'B-LANGUAGE': '3.3661286E-7', 'B-MONEY': '1.1653953E-7', 'B-PERCENT': '6.361462E-8', 'I-LANGUAGE': '5.2787684E-8', 'B-ORG': '1.2649833E-6', 'I-MONEY': '2.3248934E-7', 'I-PRODUCT': '2.9019324E-7', 'word': 'rock', 'O': '0.999982', 'B-WORK_OF_ART': '3.4984507E-7', 'I-CARDINAL': '6.0517067E-7', 'sentence': '0', 'I-PERSON': '1.1657156E-6', 'B-CARDINAL': '9.893287E-7'}, []),
#   Annotation(named_entity, 95, 98, O, {'I-TIME': '3.4231206E-7', 'B-PERSON': '1.3964628E-6', 'B-GPE': '1.1438818E-6', 'B-LAW': '7.4656896E-8', 'B-NORP': '1.2169779E-6', 'B-LOC': '3.2726706E-7', 'I-ORG': '3.4046982E-6', 'I-QUANTITY': '2.0294263E-7', 'B-DATE': '9.0857225E-7', 'B-PRODUCT': '1.9780506E-7', 'B-FAC': '1.2396464E-7', 'I-DATE': '9.49527E-7', 'I-WORK_OF_ART': '6.0952357E-7', 'B-TIME': '2.656319E-7', 'B-QUANTITY': '2.3475269E-7', 'I-PERCENT': '1.00304575E-7', 'I-LAW': '4.0896265E-7', 'I-GPE': '4.562455E-7', 'I-NORP': '3.067296E-7', 'I-ORDINAL': '1.5810564E-8', 'I-EVENT': '1.4395576E-7', 'I-LOC': '3.5826227E-7', 'B-EVENT': '7.98957E-8', 'I-FAC': '2.4710062E-7', 'B-ORDINAL': '7.0542825E-7', 'B-LANGUAGE': '2.6955706E-7', 'B-MONEY': '1.592207E-7', 'B-PERCENT': '6.266957E-8', 'I-LANGUAGE': '3.8821266E-8', 'B-ORG': '2.8824074E-6', 'I-MONEY': '2.3338029E-7', 'I-PRODUCT': '2.4068126E-7', 'word': 'band', 'O': '0.99997836', 'B-WORK_OF_ART': '4.669348E-7', 'I-CARDINAL': '4.7134478E-7', 'sentence': '0', 'I-PERSON': '1.0722329E-6', 'B-CARDINAL': '1.5274167E-6'}, []),
#   Annotation(named_entity, 100, 108, B-ORG, {'I-TIME': '1.1090555E-5', 'B-PERSON': '0.005681531', 'B-GPE': '5.518865E-4', 'B-LAW': '5.1079598E-5', 'B-NORP': '5.993886E-4', 'B-LOC': '5.2824296E-5', 'I-ORG': '5.906859E-4', 'I-QUANTITY': '2.1935146E-5', 'B-DATE': '1.0696911E-4', 'B-PRODUCT': '2.6321498E-4', 'B-FAC': '9.635565E-5', 'I-DATE': '3.9159728E-5', 'I-WORK_OF_ART': '4.992765E-5', 'B-TIME': '1.4301094E-5', 'B-QUANTITY': '1.5173151E-5', 'I-PERCENT': '1.216582E-5', 'I-LAW': '1.663871E-5', 'I-GPE': '2.5833178E-5', 'I-NORP': '1.6172073E-5', 'I-ORDINAL': '7.2403495E-6', 'I-EVENT': '1.0339268E-5', 'I-LOC': '1.072161E-5', 'B-EVENT': '5.2946543E-5', 'I-FAC': '1.7330827E-5', 'B-ORDINAL': '9.8863E-6', 'B-LANGUAGE': '1.7610344E-5', 'B-MONEY': '1.3744348E-5', 'B-PERCENT': '1.3018798E-5', 'I-LANGUAGE': '3.5729697E-6', 'B-ORG': '0.98973817', 'I-MONEY': '1.9022005E-5', 'I-PRODUCT': '1.9146499E-5', 'word': 'Marillion', 'O': '9.7279635E-4', 'B-WORK_OF_ART': '7.634969E-4', 'I-CARDINAL': '9.754504E-6', 'sentence': '0', 'I-PERSON': '5.3895194E-5', 'B-CARDINAL': '5.09801E-5'}, []),
#   Annotation(named_entity, 109, 109, O, {'I-TIME': '3.1646584E-7', 'B-PERSON': '1.2672284E-6', 'B-GPE': '6.736634E-7', 'B-LAW': '1.2240933E-7', 'B-NORP': '9.401408E-7', 'B-LOC': '4.741611E-7', 'I-ORG': '6.9024844E-7', 'I-QUANTITY': '3.6712441E-7', 'B-DATE': '1.0233404E-6', 'B-PRODUCT': '2.1415869E-7', 'B-FAC': '1.9316263E-7', 'I-DATE': '1.2537054E-6', 'I-WORK_OF_ART': '3.472445E-7', 'B-TIME': '5.365475E-7', 'B-QUANTITY': '2.6323286E-7', 'I-PERCENT': '1.3643537E-7', 'I-LAW': '3.015167E-7', 'I-GPE': '2.5580982E-7', 'I-NORP': '2.633398E-7', 'I-ORDINAL': '1.8539993E-8', 'I-EVENT': '9.84235E-8', 'I-LOC': '2.7149164E-7', 'B-EVENT': '1.7153234E-7', 'I-FAC': '2.3432113E-7', 'B-ORDINAL': '9.4840027E-7', 'B-LANGUAGE': '1.7673956E-7', 'B-MONEY': '2.774753E-7', 'B-PERCENT': '1.1067189E-7', 'I-LANGUAGE': '3.9499266E-8', 'B-ORG': '3.568773E-6', 'I-MONEY': '2.130604E-7', 'I-PRODUCT': '1.9235216E-7', 'word': '.', 'O': '0.99997807', 'B-WORK_OF_ART': '1.0761365E-6', 'I-CARDINAL': '9.0237404E-7', 'sentence': '0', 'I-PERSON': '1.1469942E-6', 'B-CARDINAL': '2.8341803E-6'}, [])],
#  'entities': [Annotation(chunk, 0, 13, Steven Rothery, {'entity': 'PERSON', 'sentence': '0', 'chunk': '0', 'confidence': '0.9966061'}, []),
#   Annotation(chunk, 82, 88, British, {'entity': 'NORP', 'sentence': '0', 'chunk': '1', 'confidence': '0.9969838'}, []),
#   Annotation(chunk, 100, 108, Marillion, {'entity': 'ORG', 'sentence': '0', 'chunk': '2', 'confidence': '0.98973817'}, [])]}

# %% [markdown]
# Let's check the classes that `bert_large_token_classifier_ontonote` model can predict

# %%
tokenClassifier.getClasses()
# Out:
# ['I-TIME',
#  'B-PERSON',
#  'B-GPE',
#  'B-LAW',
#  'B-NORP',
#  'B-LOC',
#  'I-ORG',
#  'I-QUANTITY',
#  'B-DATE',
#  'B-PRODUCT',
#  'B-FAC',
#  'I-DATE',
#  'I-WORK_OF_ART',
#  'B-TIME',
#  'B-QUANTITY',
#  'I-PERCENT',
#  'I-LAW',
#  'I-GPE',
#  'I-NORP',
#  'I-ORDINAL',
#  'I-EVENT',
#  'I-LOC',
#  'B-EVENT',
#  'I-FAC',
#  'B-ORDINAL',
#  'B-LANGUAGE',
#  'B-MONEY',
#  'B-PERCENT',
#  'I-LANGUAGE',
#  'B-ORG',
#  'I-MONEY',
#  'I-PRODUCT',
#  'O',
#  'B-WORK_OF_ART',
#  'I-CARDINAL',
#  'I-PERSON',
#  'B-CARDINAL']

# %%
light_result.keys()
# Out:
# dict_keys(['document', 'token', 'ner', 'entities'])

# %% [markdown]
# Checking the ner labels of each token

# %%
tokens= []
ner_labels= []

for i, k in list(zip(light_result["token"], light_result["ner"])):
  tokens.append(i.result)
  ner_labels.append(k.result)

result_df= pd.DataFrame({"tokens": tokens, "ner_labels": ner_labels})
result_df.head(20)
# Out:
#         tokens ner_labels
# 0       Steven   B-PERSON
# 1      Rothery   I-PERSON
# 2           is          O
# 3          the          O
# 4     original          O
# 5    guitarist          O
# 6          and          O
# 7          the          O
# 8      longest          O
# 9   continuous          O
# 10      member          O
# 11          of          O
# 12         the          O
# 13     British     B-NORP
# 14        rock          O
# 15        band          O
# 16   Marillion      B-ORG
# 17           .          O

# %% [markdown]
# Let's check the chunk results

# %%
chunks= []
begin= []
end= []
ner_label= []

for i in light_result["entities"]:
  chunks.append(i.result)
  begin.append(i.begin)
  end.append(i.end)
  ner_label.append(i.metadata["entity"])

result_df= pd.DataFrame({"chunks": chunks, "begin": begin, "end": end, "ner_label": ner_label})
result_df.head(20)
# Out:
#            chunks  begin  end ner_label
# 0  Steven Rothery      0   13    PERSON
# 1         British     82   88      NORP
# 2       Marillion    100  108       ORG

# %% [markdown]
# ## RoBertaForTokenClassification  Pipeline

# %% [markdown]
# Now, let's create a Spark NLP Pipeline with `roberta_base_token_classifier_ontonotes` model and check the results. <br/>

# %%
document_assembler = DocumentAssembler() \
  .setInputCol('text') \
  .setOutputCol('document')

tokenizer = Tokenizer() \
  .setInputCols(['document']) \
  .setOutputCol('token')

tokenClassifier = RoBertaForTokenClassification.pretrained('roberta_base_token_classifier_ontonotes', 'en') \
  .setInputCols(['token', 'document']) \
  .setOutputCol('ner') \
  .setCaseSensitive(True) \
  .setMaxSentenceLength(512)

# since output column is IOB/IOB2 style, NerConverter can extract entities
ner_converter = NerConverter() \
  .setInputCols(['document', 'token', 'ner']) \
  .setOutputCol('entities')

pipeline = Pipeline(
    stages=[
      document_assembler,
      tokenizer,
      tokenClassifier,
      ner_converter
])

example = spark.createDataFrame([['My name is John!']]).toDF("text")
result = pipeline.fit(example).transform(example)
# Out:
# roberta_base_token_classifier_ontonotes download started this may take some time.
# Approximate size to download 434.7 MB
# [OK!]

# %%
tokenClassifier.getClasses()
# Out:
# ['I-TIME',
#  'B-PERSON',
#  'B-GPE',
#  'B-LAW',
#  'B-NORP',
#  'B-LOC',
#  'I-ORG',
#  'I-QUANTITY',
#  'B-DATE',
#  'B-PRODUCT',
#  'B-FAC',
#  'I-DATE',
#  'I-WORK_OF_ART',
#  'B-TIME',
#  'B-QUANTITY',
#  'I-PERCENT',
#  'I-LAW',
#  'I-GPE',
#  'I-NORP',
#  'I-ORDINAL',
#  'I-EVENT',
#  'I-LOC',
#  'B-EVENT',
#  'I-FAC',
#  'B-ORDINAL',
#  'B-LANGUAGE',
#  'B-MONEY',
#  'B-PERCENT',
#  'I-LANGUAGE',
#  'B-ORG',
#  'I-MONEY',
#  'I-PRODUCT',
#  'O',
#  'B-WORK_OF_ART',
#  'I-CARDINAL',
#  'I-PERSON',
#  'B-CARDINAL']

# %%
result.columns
# Out:
# ['text', 'document', 'token', 'ner', 'entities']

# %%
result_df = result.select(F.explode(F.arrays_zip(result.token.result,
                                                 result.ner.result)).alias("cols"))\
                  .select(F.expr("cols['0']").alias("token"),
                          F.expr("cols['1']").alias("ner_label"))

result_df.show(50, truncate=100)
# Out:
# +-----+---------+
# |token|ner_label|
# +-----+---------+
# |   My|        O|
# | name|        O|
# |   is|        O|
# | John| B-PERSON|
# |    !|        O|
# +-----+---------+

# %%
result_df_1= result.select(F.explode(F.arrays_zip(result.entities.result,
                                                  result.entities.begin,
                                                  result.entities.end,
                                                  result.entities.metadata)).alias("col"))\
                   .select(F.expr("col['0']").alias("entities"),
                            F.expr("col['1']").alias("begin"),
                            F.expr("col['2']").alias("end"),
                            F.expr("col['3']['entity']").alias("ner_label"))

result_df_1.show(50, truncate=False)
# Out:
# +--------+-----+---+---------+
# |entities|begin|end|ner_label|
# +--------+-----+---+---------+
# |John    |11   |14 |PERSON   |
# +--------+-----+---+---------+
