# %% [markdown]
# ##De-identification in Spark OCR

# %% [markdown]
# ####0 Import libs

# %%
import os
import matplotlib.pyplot as plt
from pyspark.ml import Pipeline, PipelineModel

import sparknlp
import sparknlp_jsl
from sparknlp.base import *
from sparknlp.util import *
from sparknlp.annotator import *
from sparknlp_jsl.base import *
from sparknlp_jsl.annotator import *
from sparknlp.pretrained import ResourceDownloader

import sparkocr
from sparkocr.transformers import *
from sparkocr.utils import *
from sparkocr.enums import *

sparkocr.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">15:24:15, INFO Received command c on object id p0
# 15:24:15, INFO Received command c on object id p0
# 15:24:15, INFO Received command c on object id p0
# 15:24:15, INFO Received command c on object id p0
# 15:24:15, INFO Received command c on object id p0
# 15:24:15, INFO Received command c on object id p0
# 15:24:15, INFO Received command c on object id p0
# 15:24:15, INFO Received command c on object id p0
# 15:24:15, INFO Received command c on object id p0
# 15:24:15, INFO Received command c on object id p0
# Spark version: 3.1.2
# Spark NLP version: 5.1.0
# Spark NLP for Healthcare version: 5.1.0
# Spark OCR version: 5.0.0
#
# 15:24:15, INFO Received command c on object id p0
# 15:24:15, INFO Received command c on object id p0
# 15:24:15, INFO Received command c on object id p0
# 15:24:15, INFO Received command c on object id p0
# 15:24:15, INFO Received command c on object id p0
# </div>

# %% [markdown]
# ###1 Define Spark NLP de-identification pipeline

# %%
def deidentification_nlp_pipeline(input_column, prefix = ""):
    document_assembler = DocumentAssembler() \
        .setInputCol(input_column) \
        .setOutputCol(prefix + "document")

    # Sentence Detector annotator, processes various sentences per line
    sentence_detector = SentenceDetector() \
        .setInputCols([prefix + "document"]) \
        .setOutputCol(prefix + "sentence")

    tokenizer = Tokenizer() \
        .setInputCols([prefix + "sentence"]) \
        .setOutputCol(prefix + "token")

    # Clinical word embeddings
    word_embeddings = WordEmbeddingsModel.pretrained("embeddings_clinical", "en", "clinical/models") \
        .setInputCols([prefix + "sentence", prefix + "token"]) \
        .setOutputCol(prefix + "embeddings")
    # NER model trained on i2b2 (sampled from MIMIC) dataset
    clinical_ner = MedicalNerModel.pretrained("ner_deid_large", "en", "clinical/models") \
        .setInputCols([prefix + "sentence", prefix + "token", prefix + "embeddings"]) \
        .setOutputCol(prefix + "ner")

    custom_ner_converter = NerConverter() \
        .setInputCols([prefix + "sentence", prefix + "token", prefix + "ner"]) \
        .setOutputCol(prefix + "ner_chunk") \
        .setWhiteList(['NAME', 'AGE', 'CONTACT', 'LOCATION', 'PROFESSION', 'PERSON', 'DATE'])

    nlp_pipeline = Pipeline(stages=[
            document_assembler,
            sentence_detector,
            tokenizer,
            word_embeddings,
            clinical_ner,
            custom_ner_converter
        ])
    empty_data = spark.createDataFrame([[""]]).toDF(input_column)
    nlp_model = nlp_pipeline.fit(empty_data)
    return nlp_model
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">15:24:15, INFO Received command c on object id p0
# 15:24:15, INFO Received command c on object id p0
# 15:24:15, INFO Received command c on object id p0
# 15:24:15, INFO Received command c on object id p0
# </div>

# %% [markdown]
# ###2 Define Spark OCR pipeline

# %%
# Read Pdf as image
pdf_to_image = PdfToImage()\
  .setInputCol("content")\
  .setOutputCol("image_raw")\
  .setResolution(400)

# Extract text from image
ocr = ImageToText() \
    .setInputCol("image_raw") \
    .setOutputCol("text") \
    .setIgnoreResolution(False) \
    .setPageIteratorLevel(PageIteratorLevel.SYMBOL) \
    .setPageSegMode(PageSegmentationMode.SPARSE_TEXT) \
    .setWithSpaces(True) \
    .setConfidenceThreshold(70)

# Found coordinates of sensitive data
position_finder = PositionFinder() \
    .setInputCols("ner_chunk") \
    .setOutputCol("coordinates") \
    .setPageMatrixCol("positions") \
    .setPadding(1)

# Draw filled rectangle for hide sensitive data
drawRegions = ImageDrawRegions()  \
    .setInputCol("image_raw")  \
    .setInputRegionsCol("coordinates")  \
    .setOutputCol("image_with_regions")  \
    .setFilledRect(True) \
    .setRectColor(Color.black)
    
# OCR pipeline
deid_pipeline = PipelineModel(stages=[
    pdf_to_image,
    ocr,
    deidentification_nlp_pipeline(input_column="text"),
    position_finder,
    drawRegions
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [ | ]15:30:21, INFO Received command c on object id p0
# 15:30:21, INFO Received command c on object id p0
# 15:30:21, INFO Received command c on object id p0
# 15:30:21, INFO Received command c on object id p0
# 15:30:21, INFO Received command c on object id p0
# 15:30:21, INFO Received command c on object id p0
# 15:30:21, INFO Received command c on object id p0
# 15:30:21, INFO Received command c on object id p0
# 15:30:21, INFO Received command c on object id p0
# 15:30:21, INFO Received command c on object id p0
# 15:30:21, INFO Received command c on object id p0
# 15:30:21, INFO Received command c on object id p0
# 15:30:21, INFO Received command c on object id p0
# 15:30:21, INFO Received command c on object id p0
# 15:30:21, INFO Received command c on object id p0
# 15:30:21, INFO Received command c on object id p0
# 15:30:21, INFO Received command c on object id p0
# 15:30:21, INFO Received command c on object id p0
# 15:30:21, INFO Received command c on object id p0
# 15:30:21, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:22, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# [OK!]
# ner_deid_large download started this may take some time.
# [ | ]15:30:23, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# 15:30:23, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:24, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# 15:30:25, INFO Received command c on object id p0
# [OK!]
# 15:30:25, INFO Received command c on object id p0
# 15:30:26, INFO Received command c on object id p0
# 15:30:26, INFO Received command c on object id p0
# 15:30:26, INFO Received command c on object id p0
# 15:30:26, INFO Received command c on object id p0
# 15:30:26, INFO Received command c on object id p0
# 15:30:26, INFO Received command c on object id p0
# </div>

# %% [markdown]
# ###3 Prepare documents

# %%
# %sh
OCR_DIR=/dbfs/tmp/deid_ocr3
if [ ! -d "$OCR_DIR" ]; then
    mkdir $OCR_DIR
    cd $OCR_DIR
    for i in {0..3}
    do
      wget https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/ocr/MT_0$i.pdf
    done
fi
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">15:30:26, INFO Received command c on object id p0
# 15:30:26, INFO Received command c on object id p0
# 15:30:26, INFO Received command c on object id p0
# 15:30:26, INFO Received command c on object id p0
# </div>

# %%
display(dbutils.fs.ls("dbfs:/tmp/deid_ocr3/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/tmp/deid_ocr3/MT_00.pdf</td><td>MT_00.pdf</td><td>528022</td></tr><tr><td>dbfs:/tmp/deid_ocr3/MT_01.pdf</td><td>MT_01.pdf</td><td>165397</td></tr><tr><td>dbfs:/tmp/deid_ocr3/MT_02.pdf</td><td>MT_02.pdf</td><td>309334</td></tr><tr><td>dbfs:/tmp/deid_ocr3/MT_03.pdf</td><td>MT_03.pdf</td><td>248334</td></tr></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">15:30:26, INFO Received command c on object id p0
# 15:30:26, INFO Received command c on object id p0
# 15:30:26, INFO Received command c on object id p0
# 15:30:26, INFO Received command c on object id p0
# 15:30:26, INFO Received command c on object id p0
# 15:30:26, INFO Received command c on object id p0
# 15:30:26, INFO Received command c on object id p0
# 15:30:26, INFO Received command c on object id p0
# 15:30:26, INFO Received command c on object id p0
# 15:30:26, INFO Received command c on object id p0
# 15:30:26, INFO Received command c on object id p0
# 15:30:26, INFO Received command c on object id p0
# </div>

# %%
file_path='dbfs:/tmp/deid_ocr3/*.pdf'
pdfs = spark.read.format("binaryFile").load(file_path)
pdfs.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">15:30:27, INFO Received command c on object id p0
# 15:30:27, INFO Received command c on object id p0
# 15:30:27, INFO Received command c on object id p0
# 15:30:27, INFO Received command c on object id p0
# 15:30:27, INFO Received command c on object id p0
# 15:30:27, INFO Received command c on object id p0
# 15:30:27, INFO Received command c on object id p0
# 15:30:27, INFO Received command c on object id p0
# 15:30:27, INFO Received command c on object id p0
# 15:30:27, INFO Received command c on object id p0
# 15:30:27, INFO Received command c on object id p0
# 15:30:27, INFO Received command c on object id p0
# 15:30:27, INFO Received command c on object id p0
# 15:30:27, INFO Received command c on object id p0
# 15:30:27, INFO Received command c on object id p0
# 15:30:27, INFO Received command c on object id p0
# 15:30:27, INFO Received command c on object id p0
# 15:30:27, INFO Received command c on object id p0
# 15:30:27, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:28, INFO Received command c on object id p0
# 15:30:29, INFO Received command c on object id p0
# +--------------------+-------------------+------+--------------------+
#                 path|   modificationTime|length|             content|
# +--------------------+-------------------+------+--------------------+
# dbfs:/tmp/deid_oc...|2022-05-23 16:39:22|528022|[25 50 44 46 2D 3...|
# dbfs:/tmp/deid_oc...|2022-05-23 16:39:22|309334|[25 50 44 46 2D 3...|
# dbfs:/tmp/deid_oc...|2022-05-23 16:39:23|248334|[25 50 44 46 2D 3...|
# dbfs:/tmp/deid_oc...|2022-05-23 16:39:22|165397|[25 50 44 46 2D 3...|
# +--------------------+-------------------+------+--------------------+
#
# 15:30:29, INFO Received command c on object id p0
# 15:30:29, INFO Received command c on object id p0
# 15:30:29, INFO Received command c on object id p0
# 15:30:29, INFO Received command c on object id p0
# 15:30:29, INFO Received command c on object id p0
# </div>

# %%
from sparkocr.databricks import display_images
display_images(PdfToImage().transform(pdfs).limit(2))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:30, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:31, INFO Received command c on object id p0
# 15:30:32, INFO Received command c on object id p0
# 15:30:32, INFO Received command c on object id p0
# 15:30:32, INFO Received command c on object id p0
# 15:30:32, INFO Received command c on object id p0
# 15:30:32, INFO Received command c on object id p0
# 15:30:32, INFO Received command c on object id p0
# 15:30:32, INFO Received command c on object id p0
# 15:30:32, INFO Received command c on object id p0
# 15:30:32, INFO Received command c on object id p0
# 15:30:32, INFO Received command c on object id p0
# 15:30:32, INFO Received command c on object id p0
# 15:30:32, INFO Received command c on object id p0
# 15:30:32, INFO Received command c on object id p0
# 15:30:32, INFO Received command c on object id p0
# </div>
# <ul style='list-style-type:none; padding-inline-start: 0px;'>
#             <li style='padding: 20px; background-color: rgba(0,0,0,.03);'>
#               <ul style='padding-inline-start: 0px;list-style-type:none;'>
#                 <li><b>Origin:</b> dbfs:/tmp/deid_ocr3/MT_00.pdf</li>
#                 <li><b>Resolution:</b> 300 dpi</li>
#                 <li><b>Width:</b> 2250 px</li>
#                 <li><b>Height:</b> 3249 px</li>
#                 <li><b>Mode:</b> Greyscale</li>
#                 <li><b>Number of channels:</b> 1</li>
#                </ul>
#             </li>
#             <li style='padding: 10px; background-color: rgba(0,0,0,.01);'>
#               <img src ='/files/tmp/79cc2a08-524a-11ee-971e-00163e85aab4.png' width='800'>
#             </li>
#             <li style='padding: 20px; background-color: rgba(0,0,0,.03);'>
#               <ul style='padding-inline-start: 0px;list-style-type:none;'>
#                 <li><b>Origin:</b> dbfs:/tmp/deid_ocr3/MT_00.pdf</li>
#                 <li><b>Resolution:</b> 300 dpi</li>
#                 <li><b>Width:</b> 2250 px</li>
#                 <li><b>Height:</b> 3249 px</li>
#                 <li><b>Mode:</b> Greyscale</li>
#                 <li><b>Number of channels:</b> 1</li>
#                </ul>
#             </li>
#             <li style='padding: 10px; background-color: rgba(0,0,0,.01);'>
#               <img src ='/files/tmp/79f7f200-524a-11ee-971e-00163e85aab4.png' width='800'>
#             </li></ul>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">15:30:32, INFO Received command c on object id p0
# 15:30:32, INFO Received command c on object id p0
# 15:30:32, INFO Received command c on object id p0
# 15:30:32, INFO Received command c on object id p0
# 15:30:32, INFO Received command c on object id p0
# </div>

# %% [markdown]
# ###4 Run pipeline

# %%
deid_results = deid_pipeline.transform(pdfs).cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">15:30:33, INFO Received command c on object id p0
# 15:30:33, INFO Received command c on object id p0
# 15:30:33, INFO Received command c on object id p0
# 15:30:33, INFO Received command c on object id p0
# 15:30:33, INFO Received command c on object id p0
# 15:30:33, INFO Received command c on object id p0
# 15:30:33, INFO Received command c on object id p0
# 15:30:33, INFO Received command c on object id p0
# 15:30:33, INFO Received command c on object id p0
# 15:30:33, INFO Received command c on object id p0
# 15:30:33, INFO Received command c on object id p0
# 15:30:33, INFO Received command c on object id p0
# </div>

# %% [markdown]
# #### Display Ner chunks

# %%
display(deid_results.select("ner_chunk").limit(2))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ner_chunk</th></tr></thead><tbody><tr><td>List(List(chunk, 120, 129, 2093-01-13, Map(entity -> DATE, sentence -> 0, chunk -> 0, confidence -> 1.0), List()), List(chunk, 133, 142, David Hale, Map(entity -> NAME, sentence -> 0, chunk -> 1, confidence -> 0.9675), List()), List(chunk, 158, 174, Hendrickson , Ora, Map(entity -> NAME, sentence -> 0, chunk -> 2, confidence -> 0.9865667), List()), List(chunk, 557, 571, August 24, 2007, Map(entity -> DATE, sentence -> 5, chunk -> 3, confidence -> 0.978075), List()), List(chunk, 656, 670, August 20, 2007, Map(entity -> DATE, sentence -> 6, chunk -> 4, confidence -> 0.991175), List()), List(chunk, 694, 708, August 31, 2007, Map(entity -> DATE, sentence -> 7, chunk -> 5, confidence -> 0.920425), List()), List(chunk, 998, 1005, May 2006, Map(entity -> DATE, sentence -> 10, chunk -> 6, confidence -> 0.98235), List()))</td></tr><tr><td>List(List(chunk, 208, 221, US Post Office, Map(entity -> LOCATION, sentence -> 3, chunk -> 0, confidence -> 0.5585334), List()), List(chunk, 347, 370, Tuesday, August 14, 2007, Map(entity -> DATE, sentence -> 8, chunk -> 1, confidence -> 0.94046664), List()), List(chunk, 1450, 1455, Monday, Map(entity -> DATE, sentence -> 32, chunk -> 2, confidence -> 0.9998), List()), List(chunk, 1637, 1646, March
# 2005, Map(entity -> DATE, sentence -> 35, chunk -> 3, confidence -> 0.97965), List()), List(chunk, 1941, 1941, Y, Map(entity -> NAME, sentence -> 36, chunk -> 4, confidence -> 0.851), List()), List(chunk, 2055, 2064, March 2006, Map(entity -> DATE, sentence -> 36, chunk -> 5, confidence -> 0.97545), List()))</td></tr></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">15:30:33, INFO Received command c on object id p0
# 15:30:33, INFO Received command c on object id p0
# 15:30:33, INFO Received command c on object id p0
# 15:30:33, INFO Received command c on object id p0
# </div>

# %% [markdown]
# ####Display coordinates of text which need to hide

# %%
display(deid_results.select('coordinates').limit(2))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>coordinates</th></tr></thead><tbody><tr><td>List(List(0, 0, 694.0, 1018.0, 267.7, 31.6, 0.0, 0, 0.0), List(1, 0, 1012.0, 1015.2, 292.6, 37.6, 0.0, 0, 0.0), List(2, 0, 546.0, 1163.7646, 460.58826, 33.17647, 0.0, 0, 0.0), List(3, 0, 494.0, 2070.7334, 421.33334, 37.666668, 0.0, 0, 0.0), List(4, 0, 494.0, 2214.7334, 427.73334, 37.2, 0.0, 0, 0.0), List(5, 0, 494.0, 2284.7334, 422.4, 37.733334, 0.0, 0, 0.0), List(6, 0, 1669.0, 2600.0, 285.75, 38.0, 0.0, 0, 0.0))</td></tr><tr><td>List(List(0, 1, 1190.0, 916.1429, 417.85715, 36.857143, 0.0, 0, 0.0), List(1, 1, 1329.0, 1161.9584, 645.8334, 35.916668, 0.0, 0, 0.0), List(2, 1, 2263.0, 2860.5, 229.83333, 39.333332, 0.0, 0, 0.0), List(4, 1, 942.0, 3285.0, 54.0, 38.0, 0.0, 0, 0.0), List(5, 1, 1505.0, 3360.3, 357.5, 37.6, 0.0, 0, 0.0))</td></tr></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">15:30:51, INFO Received command c on object id p0
# 15:30:51, INFO Received command c on object id p0
# 15:30:51, INFO Received command c on object id p0
# 15:30:51, INFO Received command c on object id p0
# </div>

# %% [markdown]
# ###4 Display original and de-identified results

# %%
r = deid_results.select("image_raw", "image_with_regions").collect()[0]
img_orig = r.image_raw
img_deid = r.image_with_regions

img_pil_orig = to_pil_image(img_orig, img_orig.mode)
img_pil_deid = to_pil_image(img_deid, img_deid.mode)

plt.figure(figsize=(24,16))
plt.subplot(1, 2, 1)
plt.imshow(img_pil_orig, cmap='gray')
plt.title('original')
plt.subplot(1, 2, 2)
plt.imshow(img_pil_deid, cmap='gray')
plt.title("de-id'd")
plt.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">15:30:52, INFO Received command c on object id p0
# 15:30:52, INFO Received command c on object id p0
# 15:30:52, INFO Received command c on object id p0
# 15:30:52, INFO Received command c on object id p0
# 15:30:52, INFO Received command c on object id p0
# 15:30:52, INFO Received command c on object id p0
# 15:30:52, INFO Received command c on object id p0
# 15:30:52, INFO Received command c on object id p0
# 15:30:52, INFO Received command c on object id p0
# 15:30:52, INFO Received command c on object id p0
# 15:30:52, INFO Received command c on object id p0
# 15:30:52, INFO Received command c on object id p0
# 15:30:52, INFO Received command c on object id p0
# 15:30:52, INFO Received command c on object id p0
# 15:30:52, INFO Received command c on object id p0
# 15:30:52, INFO Received command c on object id p0
# 15:30:52, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:53, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:54, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:55, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:56, INFO Received command c on object id p0
# 15:30:57, INFO Received command c on object id p0
# 15:30:57, INFO Received command c on object id p0
# 15:30:57, INFO Received command c on object id p0
# 15:30:57, INFO Received command c on object id p0
# 15:30:57, INFO Received command c on object id p0
# 15:30:57, INFO Received command c on object id p0
# 15:30:57, INFO Received command c on object id p0
# 15:30:57, INFO Received command c on object id p0
# 15:30:57, INFO Received command c on object id p0
# 15:30:57, INFO Received command c on object id p0
# 15:30:57, INFO Received command c on object id p0
# 15:30:57, INFO Received command c on object id p0
# 15:30:57, INFO Received command c on object id p0
# 15:30:57, INFO Received command c on object id p0
# 15:30:57, INFO Received command c on object id p0
# 15:30:57, INFO Received command c on object id p0
# 15:30:57, INFO Received command c on object id p0
# 15:30:57, INFO Received command c on object id p0
# 15:30:57, INFO Received command c on object id p0
# 15:30:57, INFO Received command c on object id p0
# 15:30:57, INFO Received command c on object id p0
# 15:30:58, INFO Received command c on object id p0
# 15:30:58, INFO Received command c on object id p0
# 15:30:58, INFO Received command c on object id p0
# 15:30:58, INFO Received command c on object id p0
# 15:30:58, INFO Received command c on object id p0
# 15:30:58, INFO Received command c on object id p0
# 15:30:58, INFO Received command c on object id p0
# 15:30:58, INFO Received command c on object id p0
# 15:30:58, INFO Received command c on object id p0
# 15:30:58, INFO Received command c on object id p0
# 15:30:58, INFO Received command c on object id p0
# 15:30:58, INFO Received command c on object id p0
# 15:30:58, INFO Receive
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">15:31:11, INFO Received command c on object id p0
# 15:31:11, INFO Received command c on object id p0
# 15:31:11, INFO Received command c on object id p0
# 15:31:11, INFO Received command c on object id p0
# 15:31:11, INFO Received command c on object id p0
# </div>
