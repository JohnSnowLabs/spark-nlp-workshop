# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/nlu/blob/master/examples/colab/ocr/table_extraction.ipynb)
#
# # Table extraction for PDFs, PPTs and Docx files
# In this notebook we will extract tables in text format from 3 different PDF files using OCR for `PDFs`, `PPTs` and `DOCX` files.
#
#
# | NLU Spell            | Transformer Class                                                                       |
# |----------------------|-----------------------------------------------------------------------------------------|
# | nlu.load(`pdf2table`) | [PdfToTextTable](https://nlp.johnsnowlabs.com/docs/en/ocr_pipeline_components#pdftotexttable) |
# | nlu.load(`ppt2table`) | [PptToTextTable](https://nlp.johnsnowlabs.com/docs/en/ocr_pipeline_components#ppttotexttable)     |
# | nlu.load(`doc2table`) | [DocToTextTable](https://nlp.johnsnowlabs.com/docs/en/ocr_pipeline_components#doctotexttable)     |
#
#
# When your nlu pipeline contains a `ocr spell` the predict method will accept the following inputs :
#
# - a `string` pointing to a folder or to a file
# - a `list`, `numpy array` or `Pandas Series` containing paths pointing to folders or files
# - a `Pandas Dataframe` or `Spark Dataframe` containing a column named `path` which has one path entry per row pointing to folders or files
#
# For every path in the input passed to the `predict()` method, nlu will distinguish between two cases:
# 1. If the path points to a `file`, nlu will apply OCR transformers to it, if the file type is applicable with the currently loaded OCR pipeline.
# 2. If the path points to a `folder`, nlu will recuirsively search for files in the folder and subfolders which have file types wich are applicable with the loaded OCR pipeline.
#
# NLU checks the file endings to determine wether the OCR models can be applied or not, i.e. `.pdf`, `.doc`, `.ppt` etc..
# If your files lack these endings, NLU will not process them.

# %%
# %%capture
# !wget https://setup.johnsnowlabs.com/nlu/colab.sh -O - | bash
import nlu

# %% [markdown]
# ## Authorize your environment for OCR
# You need a Spark OCR license for using OCR spells, which is available for [free here](https://www.johnsnowlabs.com/spark-nlp-try-free/)
#
# Either upload the json credentials file to the `/content` folder of google colab or manually pass the credentials to `nlu.auth`.
# For more details on how to authorize your environment, check out the [OCR documentaton page](https://nlu.johnsnowlabs.com/docs/en/nlu_for_ocr#authorize-via-providing-string-parameters)

# %%
import nlu
import json, os
from google.colab import files

if 'spark_jsl.json' not in os.listdir():
  license_keys = files.upload()
  os.rename(list(license_keys.keys())[0], 'spark_jsl.json')

# this will automatically install the OCR library and NLP Healthcare library when credentials are provided
nlu.auth('spark_jsl.json')

# %% [markdown]
# ## Download some `PDF` files we can apply OCR on

# %%
! wget https://github.com/JohnSnowLabs/nlu/raw/4.0.0/tests/datasets/ocr/pdf/tables.pdf
! wget https://github.com/JohnSnowLabs/nlu/raw/4.0.0/tests/datasets/ocr/pdf/insurance.pdf

# %% [markdown]
# ## Create helper function to print talbes easily

# %%
def print_tables(results):
  for i, df in enumerate(results):
    print(f"Table {i+1}:")
    print(df)
    print("\n")

# %% [markdown]
# ## Use the load the `pdf2table` spell
# At first step we will run the spell on simple `pdf` file then we will run this on more complex `pdf` that contains multiple tables

# %%
results = nlu.load('pdf2table').predict('/content/tables.pdf')
print_tables(results)
# Out:
# Table 1:
#      mpg cyl   disp   hp  drat     wt   qsec vs am gear
# 1   21.0   6  160.0  110  3.90  2.620  16.46  0  1    4
# 2   21.0   6  160.0  110  3.90  2.875  17.02  0  1    4
# 3   22.8   4  108.0   93  3.85  2.320  18.61  1  1    4
# 4   21.4   6  258.0  110  3.08  3.215  19.44  1  0    3
# 5   18.7   8  360.0  175  3.15  3.440  17.02  0  0    3
# 6   18.1   6  225.0  105  2.76  3.460  20.22  1  0    3
# 7   14.3   8  360.0  245  3.21  3.570  15.84  0  0    3
# 8   24.4   4  146.7   62  3.69  3.190  20.00  1  0    4
# 9   22.8   4  140.8   95  3.92  3.150  22.90  1  0    4
# 10  19.2   6  167.6  123  3.92  3.440  18.30  1  0    4
# 11  17.8   6  167.6  123  3.92  3.440  18.90  1  0    4
# 12  16.4   8  275.8  180  3.07  4.070  17.40  0  0    3
# 13  17.3   8  275.8  180  3.07  3.730  17.60  0  0    3
# 14  15.2   8  275.8  180  3.07  3.780  18.00  0  0    3
# 15  10.4   8  472.0  205  2.93  5.250  17.98  0  0    3
# 16  10.4   8  460.0  215  3.00  5.424  17.82  0  0    3
# 17  14.7   8  440.0  230  3.23  5.345  17.42  0  0    3
# 18  32.4   4   78.7   66  4.08  2.200  19.47  1  1    4
# 19  30.4   4   75.7   52  4.93  1.615  18.52  1  1    4
# 20  33.9   4   71.1   65  4.22  1.835  19.90  1  1    4
# 21  21.5   4  120.1   97  3.70  2.465  20.01  1  0    3
# 22  15.5   8  318.0  150  2.76  3.520  16.87  0  0    3
# 23  15.2   8  304.0  150  3.15  3.435  17.30  0  0    3
# 24  13.3   8  350.0  245  3.73  3.840  15.41  0  0    3
# 25  19.2   8  400.0  175  3.08  3.845  17.05  0  0    3
# 26  27.3   4   79.0   66  4.08  1.935  18.90  1  1    4
# 27  26.0   4  120.3   91  4.43  2.140  16.70  0  1    5
# 28  30.4   4   95.1  113  3.77  1.513  16.90  1  1    5
# 29  15.8   8  351.0  264  4.22  3.170  14.50  0  1    5
# 30  19.7   6  145.0  175  3.62  2.770  15.50  0  1    5
# 31  15.0   8  301.0  335  3.54  3.570  14.60  0  1    5
#
#
# Table 2:
#    Sepal.Length Sepal.Width Petal.Length   Petal.Width      Species
# 1                       5.1          3.5           1.4   0.2 setosa
# 2                       4.9          3.0           1.4   0.2 setosa
# 3                       4.7          3.2           1.3   0.2 setosa
# 4                       4.6          3.1           1.5   0.2 setosa
# 5                       5.0          3.6           1.4   0.2 setosa
# 6                       5.4          3.9           1.7   0.4 setosa
# 7              Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 8                   145 6.7          3.3           5.7          2.5  virginica
# 9                   146 6.7          3.0           5.2          2.3  virginica
# 10                  147 6.3          2.5           5.0          1.9  virginica
# 11                  148 6.5          3.0           5.2          2.0  virginica
# 12                  149 6.2          3.4           5.4          2.3  virginica
# 13                  150 5.9          3.0           5.1          1.8  virginica
# 14                                     2
#
#
# Table 3:
#    supp
# 1    VC
# 2    VC
# 3    VC
# 4    VC
# 5    VC
# 6    VC
# 7    VC
# 8    VC
# 9    VC
# 10   VC
# 11   VC
# 12   VC
# 13   VC
# 14   VC

# %%
# You get an array of pandas Dataframes returned, You can easily view them

# %%
results[0]
# Out:
#      mpg cyl   disp   hp  drat     wt   qsec vs am gear
# 1   21.0   6  160.0  110  3.90  2.620  16.46  0  1    4
# 2   21.0   6  160.0  110  3.90  2.875  17.02  0  1    4
# 3   22.8   4  108.0   93  3.85  2.320  18.61  1  1    4
# 4   21.4   6  258.0  110  3.08  3.215  19.44  1  0    3
# 5   18.7   8  360.0  175  3.15  3.440  17.02  0  0    3
# 6   18.1   6  225.0  105  2.76  3.460  20.22  1  0    3
# 7   14.3   8  360.0  245  3.21  3.570  15.84  0  0    3
# 8   24.4   4  146.7   62  3.69  3.190  20.00  1  0    4
# 9   22.8   4  140.8   95  3.92  3.150  22.90  1  0    4
# 10  19.2   6  167.6  123  3.92  3.440  18.30  1  0    4
# 11  17.8   6  167.6  123  3.92  3.440  18.90  1  0    4
# 12  16.4   8  275.8  180  3.07  4.070  17.40  0  0    3
# 13  17.3   8  275.8  180  3.07  3.730  17.60  0  0    3
# 14  15.2   8  275.8  180  3.07  3.780  18.00  0  0    3
# 15  10.4   8  472.0  205  2.93  5.250  17.98  0  0    3
# 16  10.4   8  460.0  215  3.00  5.424  17.82  0  0    3
# 17  14.7   8  440.0  230  3.23  5.345  17.42  0  0    3
# 18  32.4   4   78.7   66  4.08  2.200  19.47  1  1    4
# 19  30.4   4   75.7   52  4.93  1.615  18.52  1  1    4
# 20  33.9   4   71.1   65  4.22  1.835  19.90  1  1    4
# 21  21.5   4  120.1   97  3.70  2.465  20.01  1  0    3
# 22  15.5   8  318.0  150  2.76  3.520  16.87  0  0    3
# 23  15.2   8  304.0  150  3.15  3.435  17.30  0  0    3
# 24  13.3   8  350.0  245  3.73  3.840  15.41  0  0    3
# 25  19.2   8  400.0  175  3.08  3.845  17.05  0  0    3
# 26  27.3   4   79.0   66  4.08  1.935  18.90  1  1    4
# 27  26.0   4  120.3   91  4.43  2.140  16.70  0  1    5
# 28  30.4   4   95.1  113  3.77  1.513  16.90  1  1    5
# 29  15.8   8  351.0  264  4.22  3.170  14.50  0  1    5
# 30  19.7   6  145.0  175  3.62  2.770  15.50  0  1    5
# 31  15.0   8  301.0  335  3.54  3.570  14.60  0  1    5

# %%
results[1]
# Out:
#    Sepal.Length Sepal.Width Petal.Length   Petal.Width      Species
# 1                       5.1          3.5           1.4   0.2 setosa
# 2                       4.9          3.0           1.4   0.2 setosa
# 3                       4.7          3.2           1.3   0.2 setosa
# 4                       4.6          3.1           1.5   0.2 setosa
# 5                       5.0          3.6           1.4   0.2 setosa
# 6                       5.4          3.9           1.7   0.4 setosa
# 7              Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 8                   145 6.7          3.3           5.7          2.5  virginica
# 9                   146 6.7          3.0           5.2          2.3  virginica
# 10                  147 6.3          2.5           5.0          1.9  virginica
# 11                  148 6.5          3.0           5.2          2.0  virginica
# 12                  149 6.2          3.4           5.4          2.3  virginica
# 13                  150 5.9          3.0           5.1          1.8  virginica
# 14                                     2

# %%
results[2]
# Out:
#    supp
# 1    VC
# 2    VC
# 3    VC
# 4    VC
# 5    VC
# 6    VC
# 7    VC
# 8    VC
# 9    VC
# 10   VC
# 11   VC
# 12   VC
# 13   VC
# 14   VC

# %% [markdown]
# ## Run the `pdf2table` spell on more complex pdf file
# Here we have a real pdf file with 8 tables. Lets run `pdf2table` spell on it!

# %%
results = nlu.load('pdf2table').predict('/content/insurance.pdf')
print_tables(results)
# Out:
# Table 1:
#   0_ Volume/\rModel #                                 Title of Model  \
# 1             III-360            Consumer Credit Insurance Model Act
# 2             III-365  Credit Personal Property Insurance Model\rAct
# 3             III-370    Consumer Credit Insurance Model\rRegulation
# 4             III-375            Creditor-Placed Insurance Model Act
#
#                                          Description  \
# 1  This model act helps promote the public welfar...
# 2  This model act 1) Promotes the public welfare ...
# 3  This model regulation helps protect the intere...
# 4  This model act creates a legal framework withi...
#
#   Related Charts: State Laws on Insurance Topics 5_
# 1
# 2
# 3      PC-50 - Terrorism and War Risks Exclusion
# 4
#
#
# Table 2:
#   0_  III-385  \
# 1     III-390
# 2     III-395
#
#   Model Regulation to Define Standards and\rCommissioner’s Authority for Companies\rDeemed to be in Hazardous Financial\rCondition  \
# 1                          Model Law on Examinations
# 2  Participation in the NAIC Insurance\rRegulator...
#
#   This model regulation sets forth standards for identifying insurers found to be in such\rcondition as to render the continuance of their business hazardous to the public or to\rholders of their policies or certificates of insurance.  \
# 1  This model law helps provide an effective, eff...
# 2  This model act sets forth the requirements for...
#
#                                                   4_ 5_
# 1  CF-40 - Financial Examinations Standards for I...
# 2
#
#
# Table 3:
#   0_  III-430         Health Maintenance Organization Model\rAct  \
# 1     III-432  Model Regulation to Implement Rules\rRegarding...
#
#   This model act provides for a system of regulation for health maintenance organizations\rthat is fair and efficient, and promotes the continued solvency of health maintenance\rorganizations.  \
# 1  This model regulation implements the NAIC Heal...
#
#   HM-10 - Departmental Regulation of HMOs\rHM-20 - Open Enrollment Periods for HMOs\rHM-30 - HMO Net Worth and Deposit Requirements  \
# 1  HM-10 - Departmental Regulation of HMOs\rHM-20...
#
#   5_
# 1
#
#
# Table 4:
#   0_ Volume/\rModel #                                     Title of Model  \
# 1             III-440   Insurance Holding Company System\rRegulatory Act
# 2             III-450  Insurance Holding Company System Model\rRegula...
#
#                                          Description  \
# 1  This model act includes requirements pertainin...
# 2  This model regulation sets forth rules and pro...
#
#   Related Charts: State Laws on Insurance Topics 5_
# 1
# 2
#
#
# Table 5:
#   0_  III-460  \
# 1     III-480
# 2     III-490
# 3     III-500
#
#   An Act Concerning Insider Trading of\rDomestic Stock Insurance Company Equity\rSecurities  \
# 1  Regulations Adopted Pursuant to an Act\rConcer...
# 2  Regulation Regarding Proxies, Consents\rand Au...
# 3  Stockholders Information Supplement\rSchedule SIS
#
#   This model act includes provisions concerning the unfair use of information, sales of\requity security, exceptions, definitions and forfeiture. Its corresponding model regulation\ris MDL-480.  \
# 1  This model regulation contains definitions and...
# 2  Thismodelregulationprovidesproxyrequirements,f...
# 3  This model contains general instructions, info...
#
#   4_ 5_
# 1
# 2
# 3
#
#
# Table 6:
#   0_  III-505  \
# 1     III-510
# 2     III-520
#
#   Risk Management and Own Risk and\rSolvency Assessment (ORSA) Model Act  \
# 1  Criminal Sanctions for Failure to Report\rImpa...
# 2  Life and Health Insurance Guaranty\rAssociatio...
#
#   Thismodelactestablishestherequirementsformaintainingariskmanagement\rframework and completing an Own Risk and Solvency Assessment (ORSA). It addresses\rexemptions, confidentiality and sanctions.  \
# 1  This model outlines the criminal sanctions and...
# 2  This model act protects against failure in the...
#
#                                                   4_ 5_
# 1
# 2  IN-10 - Life and Health Guaranty Fund Laws\rIN...
#
#
# Table 7:
#   0_ Volume/\rModel #                                     Title of Model  \
# 1             III-540  Property and Casualty Insurance Guaranty\rAsso...
# 2             III-555                     Insurer Receivership Model Act
# 3             III-558               Administrative Supervision Model Act
#
#                                          Description  \
# 1  This model act provides a mechanism for the pa...
# 2  This model act helps protect the interests of ...
# 3  This model act outlines the parameters under w...
#
#       Related Charts: State Laws on Insurance Topics 5_
# 1  IN-30 - Property and Casualty Guaranty Fund La...
# 2
# 3
#
#
# Table 8:
#   0_  IV-565  \
# 1     IV-568
# 2     IV-570
# 3     IV-575
# 4     IV-580
#
#   Group Life Insurance Definition and Group\rLife Insurance Standard Provisions Model\rAct  \
# 1          Military Sales Practices Model Regulation
# 2  Advertisements of Life Insurance and\rAnnuitie...
# 3  Life and Health Insurance Policy Language\rSim...
# 4         Life Insurance Disclosure Model Regulation
#
#   This model act sets forth group life insurance standard provisions. It defines group life\rinsurance and contains provisions relating to limits of group life insurance, notice of\rcompensation, dependent coverage, standard provisions, and a supplementary provision\rrelating to conversion privileges.  \
# 1  The purpose of this model regulation is to set...
# 2  This model regulation sets forth minimum stand...
# 3  This model act establishes minimum standards f...
# 4  This model regulation requires insurers to pro...
#
#                                                   4_ 5_
# 1          PC-50 - Terrorism and War Risks Exclusion
# 2       LI-30 - Life Insurance Disclosure Provisions
# 3  LI-20 - Form Filing Requirements Life Insuranc...
# 4  LI-30 - Life Insurance Disclosure Provisions\r...

# %% [markdown]
# ## Table extraction examples with alternativy input types

# %% [markdown]
# ### Predict on array of paths

# %%
pdf_paths = ['/content/tables.pdf','/content/insurance.pdf',]
results = nlu.load('pdf2table' ).predict(pdf_paths)
print_tables(results)
# Out:
# Table 1:
#   0_ Volume/\rModel #                                 Title of Model  \
# 1             III-360            Consumer Credit Insurance Model Act
# 2             III-365  Credit Personal Property Insurance Model\rAct
# 3             III-370    Consumer Credit Insurance Model\rRegulation
# 4             III-375            Creditor-Placed Insurance Model Act
#
#                                          Description  \
# 1  This model act helps promote the public welfar...
# 2  This model act 1) Promotes the public welfare ...
# 3  This model regulation helps protect the intere...
# 4  This model act creates a legal framework withi...
#
#   Related Charts: State Laws on Insurance Topics 5_
# 1
# 2
# 3      PC-50 - Terrorism and War Risks Exclusion
# 4
#
#
# Table 2:
#   0_  III-385  \
# 1     III-390
# 2     III-395
#
#   Model Regulation to Define Standards and\rCommissioner’s Authority for Companies\rDeemed to be in Hazardous Financial\rCondition  \
# 1                          Model Law on Examinations
# 2  Participation in the NAIC Insurance\rRegulator...
#
#   This model regulation sets forth standards for identifying insurers found to be in such\rcondition as to render the continuance of their business hazardous to the public or to\rholders of their policies or certificates of insurance.  \
# 1  This model law helps provide an effective, eff...
# 2  This model act sets forth the requirements for...
#
#                                                   4_ 5_
# 1  CF-40 - Financial Examinations Standards for I...
# 2
#
#
# Table 3:
#   0_  III-430         Health Maintenance Organization Model\rAct  \
# 1     III-432  Model Regulation to Implement Rules\rRegarding...
#
#   This model act provides for a system of regulation for health maintenance organizations\rthat is fair and efficient, and promotes the continued solvency of health maintenance\rorganizations.  \
# 1  This model regulation implements the NAIC Heal...
#
#   HM-10 - Departmental Regulation of HMOs\rHM-20 - Open Enrollment Periods for HMOs\rHM-30 - HMO Net Worth and Deposit Requirements  \
# 1  HM-10 - Departmental Regulation of HMOs\rHM-20...
#
#   5_
# 1
#
#
# Table 4:
#   0_ Volume/\rModel #                                     Title of Model  \
# 1             III-440   Insurance Holding Company System\rRegulatory Act
# 2             III-450  Insurance Holding Company System Model\rRegula...
#
#                                          Description  \
# 1  This model act includes requirements pertainin...
# 2  This model regulation sets forth rules and pro...
#
#   Related Charts: State Laws on Insurance Topics 5_
# 1
# 2
#
#
# Table 5:
#   0_  III-460  \
# 1     III-480
# 2     III-490
# 3     III-500
#
#   An Act Concerning Insider Trading of\rDomestic Stock Insurance Company Equity\rSecurities  \
# 1  Regulations Adopted Pursuant to an Act\rConcer...
# 2  Regulation Regarding Proxies, Consents\rand Au...
# 3  Stockholders Information Supplement\rSchedule SIS
#
#   This model act includes provisions concerning the unfair use of information, sales of\requity security, exceptions, definitions and forfeiture. Its corresponding model regulation\ris MDL-480.  \
# 1  This model regulation contains definitions and...
# 2  Thismodelregulationprovidesproxyrequirements,f...
# 3  This model contains general instructions, info...
#
#   4_ 5_
# 1
# 2
# 3
#
#
# Table 6:
#   0_  III-505  \
# 1     III-510
# 2     III-520
#
#   Risk Management and Own Risk and\rSolvency Assessment (ORSA) Model Act  \
# 1  Criminal Sanctions for Failure to Report\rImpa...
# 2  Life and Health Insurance Guaranty\rAssociatio...
#
#   Thismodelactestablishestherequirementsformaintainingariskmanagement\rframework and completing an Own Risk and Solvency Assessment (ORSA). It addresses\rexemptions, confidentiality and sanctions.  \
# 1  This model outlines the criminal sanctions and...
# 2  This model act protects against failure in the...
#
#                                                   4_ 5_
# 1
# 2  IN-10 - Life and Health Guaranty Fund Laws\rIN...
#
#
# Table 7:
#   0_ Volume/\rModel #                                     Title of Model  \
# 1             III-540  Property and Casualty Insurance Guaranty\rAsso...
# 2             III-555                     Insurer Receivership Model Act
# 3             III-558               Administrative Supervision Model Act
#
#                                          Description  \
# 1  This model act provides a mechanism for the pa...
# 2  This model act helps protect the interests of ...
# 3  This model act outlines the parameters under w...
#
#       Related Charts: State Laws on Insurance Topics 5_
# 1  IN-30 - Property and Casualty Guaranty Fund La...
# 2
# 3
#
#
# Table 8:
#   0_  IV-565  \
# 1     IV-568
# 2     IV-570
# 3     IV-575
# 4     IV-580
#
#   Group Life Insurance Definition and Group\rLife Insurance Standard Provisions Model\rAct  \
# 1          Military Sales Practices Model Regulation
# 2  Advertisements of Life Insurance and\rAnnuitie...
# 3  Life and Health Insurance Policy Language\rSim...
# 4         Life Insurance Disclosure Model Regulation
#
#   This model act sets forth group life insurance standard provisions. It defines group life\rinsurance and contains provisions relating to limits of group life insurance, notice of\rcompensation, dependent coverage, standard provisions, and a supplementary provision\rrelating to conversion privileges.  \
# 1  The purpose of this model regulation is to set...
# 2  This model regulation sets forth minimum stand...
# 3  This model act establishes minimum standards f...
# 4  This model regulation requires insurers to pro...
#
#                                                   4_ 5_
# 1          PC-50 - Terrorism and War Risks Exclusion
# 2       LI-30 - Life Insurance Disclosure Provisions
# 3  LI-20 - Form Filing Requirements Life Insuranc...
# 4  LI-30 - Life Insurance Disclosure Provisions\r...
#
#
# Table 9:
#      mpg cyl   disp   hp  drat     wt   qsec vs am gear
# 1   21.0   6  160.0  110  3.90  2.620  16.46  0  1    4
# 2   21.0   6  160.0  110  3.90  2.875  17.02  0  1    4
# 3   22.8   4  108.0   93  3.85  2.320  18.61  1  1    4
# 4   21.4   6  258.0  110  3.08  3.215  19.44  1  0    3
# 5   18.7   8  360.0  175  3.15  3.440  17.02  0  0    3
# 6   18.1   6  225.0  105  2.76  3.460  20.22  1  0    3
# 7   14.3   8  360.0  245  3.21  3.570  15.84  0  0    3
# 8   24.4   4  146.7   62  3.69  3.190  20.00  1  0    4
# 9   22.8   4  140.8   95  3.92  3.150  22.90  1  0    4
# 10  19.2   6  167.6  123  3.92  3.440  18.30  1  0    4
# 11  17.8   6  167.6  123  3.92  3.440  18.90  1  0    4
# 12  16.4   8  275.8  180  3.07  4.070  17.40  0  0    3
# 13  17.3   8  275.8  180  3.07  3.730  17.60  0  0    3
# 14  15.2   8  275.8  180  3.07  3.780  18.00  0  0    3
# 15  10.4   8  472.0  205  2.93  5.250  17.98  0  0    3
# 16  10.4   8  460.0  215  3.00  5.424  17.82  0  0    3
# 17  14.7   8  440.0  230  3.23  5.345  17.42  0  0    3
# 18  32.4   4   78.7   66  4.08  2.200  19.47  1  1    4
# 19  30.4   4   75.7   52  4.93  1.615  18.52  1  1    4
# 20  33.9   4   71.1   65  4.22  1.835  19.90  1  1    4
# 21  21.5   4  120.1   97  3.70  2.465  20.01  1  0    3
# 22  15.5   8  318.0  150  2.76  3.520  16.87  0  0    3
# 23  15.2   8  304.0  150  3.15  3.435  17.30  0  0    3
# 24  13.3   8  350.0  245  3.73  3.840  15.41  0  0    3
# 25  19.2   8  400.0  175  3.08  3.845  17.05  0  0    3
# 26  27.3   4   79.0   66  4.08  1.935  18.90  1  1    4
# 27  26.0   4  120.3   91  4.43  2.140  16.70  0  1    5
# 28  30.4   4   95.1  113  3.77  1.513  16.90  1  1    5
# 29  15.8   8  351.0  264  4.22  3.170  14.50  0  1    5
# 30  19.7   6  145.0  175  3.62  2.770  15.50  0  1    5
# 31  15.0   8  301.0  335  3.54  3.570  14.60  0  1    5
#
#
# Table 10:
#    Sepal.Length Sepal.Width Petal.Length   Petal.Width      Species
# 1                       5.1          3.5           1.4   0.2 setosa
# 2                       4.9          3.0           1.4   0.2 setosa
# 3                       4.7          3.2           1.3   0.2 setosa
# 4                       4.6          3.1           1.5   0.2 setosa
# 5                       5.0          3.6           1.4   0.2 setosa
# 6                       5.4          3.9           1.7   0.4 setosa
# 7              Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 8                   145 6.7          3.3           5.7          2.5  virginica
# 9                   146 6.7          3.0           5.2          2.3  virginica
# 10                  147 6.3          2.5           5.0          1.9  virginica
# 11                  148 6.5          3.0           5.2          2.0  virginica
# 12                  149 6.2          3.4           5.4          2.3  virginica
# 13                  150 5.9          3.0           5.1          1.8  virginica
# 14                                     2
#
#
# Table 11:
#    supp
# 1    VC
# 2    VC
# 3    VC
# 4    VC
# 5    VC
# 6    VC
# 7    VC
# 8    VC
# 9    VC
# 10   VC
# 11   VC
# 12   VC
# 13   VC
# 14   VC

# %% [markdown]
# ### Predict on dataframe containing a `path` column

# %%
# create a dataframe with paths
import pandas as pd 

pdf_paths = ['/content/tables.pdf','/content/insurance.pdf',]
df = pd.DataFrame({'path':pdf_paths})
df
# Out:
#                      path
# 0     /content/tables.pdf
# 1  /content/insurance.pdf

# %%
# Process dataframe with paths
results = nlu.load('pdf2table').predict(df)
print_tables(results)
# Out:
# Table 1:
#   0_ Volume/\rModel #                                 Title of Model  \
# 1             III-360            Consumer Credit Insurance Model Act
# 2             III-365  Credit Personal Property Insurance Model\rAct
# 3             III-370    Consumer Credit Insurance Model\rRegulation
# 4             III-375            Creditor-Placed Insurance Model Act
#
#                                          Description  \
# 1  This model act helps promote the public welfar...
# 2  This model act 1) Promotes the public welfare ...
# 3  This model regulation helps protect the intere...
# 4  This model act creates a legal framework withi...
#
#   Related Charts: State Laws on Insurance Topics 5_
# 1
# 2
# 3      PC-50 - Terrorism and War Risks Exclusion
# 4
#
#
# Table 2:
#   0_  III-385  \
# 1     III-390
# 2     III-395
#
#   Model Regulation to Define Standards and\rCommissioner’s Authority for Companies\rDeemed to be in Hazardous Financial\rCondition  \
# 1                          Model Law on Examinations
# 2  Participation in the NAIC Insurance\rRegulator...
#
#   This model regulation sets forth standards for identifying insurers found to be in such\rcondition as to render the continuance of their business hazardous to the public or to\rholders of their policies or certificates of insurance.  \
# 1  This model law helps provide an effective, eff...
# 2  This model act sets forth the requirements for...
#
#                                                   4_ 5_
# 1  CF-40 - Financial Examinations Standards for I...
# 2
#
#
# Table 3:
#   0_  III-430         Health Maintenance Organization Model\rAct  \
# 1     III-432  Model Regulation to Implement Rules\rRegarding...
#
#   This model act provides for a system of regulation for health maintenance organizations\rthat is fair and efficient, and promotes the continued solvency of health maintenance\rorganizations.  \
# 1  This model regulation implements the NAIC Heal...
#
#   HM-10 - Departmental Regulation of HMOs\rHM-20 - Open Enrollment Periods for HMOs\rHM-30 - HMO Net Worth and Deposit Requirements  \
# 1  HM-10 - Departmental Regulation of HMOs\rHM-20...
#
#   5_
# 1
#
#
# Table 4:
#   0_ Volume/\rModel #                                     Title of Model  \
# 1             III-440   Insurance Holding Company System\rRegulatory Act
# 2             III-450  Insurance Holding Company System Model\rRegula...
#
#                                          Description  \
# 1  This model act includes requirements pertainin...
# 2  This model regulation sets forth rules and pro...
#
#   Related Charts: State Laws on Insurance Topics 5_
# 1
# 2
#
#
# Table 5:
#   0_  III-460  \
# 1     III-480
# 2     III-490
# 3     III-500
#
#   An Act Concerning Insider Trading of\rDomestic Stock Insurance Company Equity\rSecurities  \
# 1  Regulations Adopted Pursuant to an Act\rConcer...
# 2  Regulation Regarding Proxies, Consents\rand Au...
# 3  Stockholders Information Supplement\rSchedule SIS
#
#   This model act includes provisions concerning the unfair use of information, sales of\requity security, exceptions, definitions and forfeiture. Its corresponding model regulation\ris MDL-480.  \
# 1  This model regulation contains definitions and...
# 2  Thismodelregulationprovidesproxyrequirements,f...
# 3  This model contains general instructions, info...
#
#   4_ 5_
# 1
# 2
# 3
#
#
# Table 6:
#   0_  III-505  \
# 1     III-510
# 2     III-520
#
#   Risk Management and Own Risk and\rSolvency Assessment (ORSA) Model Act  \
# 1  Criminal Sanctions for Failure to Report\rImpa...
# 2  Life and Health Insurance Guaranty\rAssociatio...
#
#   Thismodelactestablishestherequirementsformaintainingariskmanagement\rframework and completing an Own Risk and Solvency Assessment (ORSA). It addresses\rexemptions, confidentiality and sanctions.  \
# 1  This model outlines the criminal sanctions and...
# 2  This model act protects against failure in the...
#
#                                                   4_ 5_
# 1
# 2  IN-10 - Life and Health Guaranty Fund Laws\rIN...
#
#
# Table 7:
#   0_ Volume/\rModel #                                     Title of Model  \
# 1             III-540  Property and Casualty Insurance Guaranty\rAsso...
# 2             III-555                     Insurer Receivership Model Act
# 3             III-558               Administrative Supervision Model Act
#
#                                          Description  \
# 1  This model act provides a mechanism for the pa...
# 2  This model act helps protect the interests of ...
# 3  This model act outlines the parameters under w...
#
#       Related Charts: State Laws on Insurance Topics 5_
# 1  IN-30 - Property and Casualty Guaranty Fund La...
# 2
# 3
#
#
# Table 8:
#   0_  IV-565  \
# 1     IV-568
# 2     IV-570
# 3     IV-575
# 4     IV-580
#
#   Group Life Insurance Definition and Group\rLife Insurance Standard Provisions Model\rAct  \
# 1          Military Sales Practices Model Regulation
# 2  Advertisements of Life Insurance and\rAnnuitie...
# 3  Life and Health Insurance Policy Language\rSim...
# 4         Life Insurance Disclosure Model Regulation
#
#   This model act sets forth group life insurance standard provisions. It defines group life\rinsurance and contains provisions relating to limits of group life insurance, notice of\rcompensation, dependent coverage, standard provisions, and a supplementary provision\rrelating to conversion privileges.  \
# 1  The purpose of this model regulation is to set...
# 2  This model regulation sets forth minimum stand...
# 3  This model act establishes minimum standards f...
# 4  This model regulation requires insurers to pro...
#
#                                                   4_ 5_
# 1          PC-50 - Terrorism and War Risks Exclusion
# 2       LI-30 - Life Insurance Disclosure Provisions
# 3  LI-20 - Form Filing Requirements Life Insuranc...
# 4  LI-30 - Life Insurance Disclosure Provisions\r...
#
#
# Table 9:
#      mpg cyl   disp   hp  drat     wt   qsec vs am gear
# 1   21.0   6  160.0  110  3.90  2.620  16.46  0  1    4
# 2   21.0   6  160.0  110  3.90  2.875  17.02  0  1    4
# 3   22.8   4  108.0   93  3.85  2.320  18.61  1  1    4
# 4   21.4   6  258.0  110  3.08  3.215  19.44  1  0    3
# 5   18.7   8  360.0  175  3.15  3.440  17.02  0  0    3
# 6   18.1   6  225.0  105  2.76  3.460  20.22  1  0    3
# 7   14.3   8  360.0  245  3.21  3.570  15.84  0  0    3
# 8   24.4   4  146.7   62  3.69  3.190  20.00  1  0    4
# 9   22.8   4  140.8   95  3.92  3.150  22.90  1  0    4
# 10  19.2   6  167.6  123  3.92  3.440  18.30  1  0    4
# 11  17.8   6  167.6  123  3.92  3.440  18.90  1  0    4
# 12  16.4   8  275.8  180  3.07  4.070  17.40  0  0    3
# 13  17.3   8  275.8  180  3.07  3.730  17.60  0  0    3
# 14  15.2   8  275.8  180  3.07  3.780  18.00  0  0    3
# 15  10.4   8  472.0  205  2.93  5.250  17.98  0  0    3
# 16  10.4   8  460.0  215  3.00  5.424  17.82  0  0    3
# 17  14.7   8  440.0  230  3.23  5.345  17.42  0  0    3
# 18  32.4   4   78.7   66  4.08  2.200  19.47  1  1    4
# 19  30.4   4   75.7   52  4.93  1.615  18.52  1  1    4
# 20  33.9   4   71.1   65  4.22  1.835  19.90  1  1    4
# 21  21.5   4  120.1   97  3.70  2.465  20.01  1  0    3
# 22  15.5   8  318.0  150  2.76  3.520  16.87  0  0    3
# 23  15.2   8  304.0  150  3.15  3.435  17.30  0  0    3
# 24  13.3   8  350.0  245  3.73  3.840  15.41  0  0    3
# 25  19.2   8  400.0  175  3.08  3.845  17.05  0  0    3
# 26  27.3   4   79.0   66  4.08  1.935  18.90  1  1    4
# 27  26.0   4  120.3   91  4.43  2.140  16.70  0  1    5
# 28  30.4   4   95.1  113  3.77  1.513  16.90  1  1    5
# 29  15.8   8  351.0  264  4.22  3.170  14.50  0  1    5
# 30  19.7   6  145.0  175  3.62  2.770  15.50  0  1    5
# 31  15.0   8  301.0  335  3.54  3.570  14.60  0  1    5
#
#
# Table 10:
#    Sepal.Length Sepal.Width Petal.Length   Petal.Width      Species
# 1                       5.1          3.5           1.4   0.2 setosa
# 2                       4.9          3.0           1.4   0.2 setosa
# 3                       4.7          3.2           1.3   0.2 setosa
# 4                       4.6          3.1           1.5   0.2 setosa
# 5                       5.0          3.6           1.4   0.2 setosa
# 6                       5.4          3.9           1.7   0.4 setosa
# 7              Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 8                   145 6.7          3.3           5.7          2.5  virginica
# 9                   146 6.7          3.0           5.2          2.3  virginica
# 10                  147 6.3          2.5           5.0          1.9  virginica
# 11                  148 6.5          3.0           5.2          2.0  virginica
# 12                  149 6.2          3.4           5.4          2.3  virginica
# 13                  150 5.9          3.0           5.1          1.8  virginica
# 14                                     2
#
#
# Table 11:
#    supp
# 1    VC
# 2    VC
# 3    VC
# 4    VC
# 5    VC
# 6    VC
# 7    VC
# 8    VC
# 9    VC
# 10   VC
# 11   VC
# 12   VC
# 13   VC
# 14   VC

# %% [markdown]
# ### Pass a directory which contains PDF files.
# NLU will recursively search the folder for files which have `.pdf`  suffix in their name and apply the OCR model to it

# %%
results = nlu.load('pdf2table' ).predict("/content")
print_tables(results)
# Out:
# Table 1:
#   0_ Volume/\rModel #                                 Title of Model  \
# 1             III-360            Consumer Credit Insurance Model Act
# 2             III-365  Credit Personal Property Insurance Model\rAct
# 3             III-370    Consumer Credit Insurance Model\rRegulation
# 4             III-375            Creditor-Placed Insurance Model Act
#
#                                          Description  \
# 1  This model act helps promote the public welfar...
# 2  This model act 1) Promotes the public welfare ...
# 3  This model regulation helps protect the intere...
# 4  This model act creates a legal framework withi...
#
#   Related Charts: State Laws on Insurance Topics 5_
# 1
# 2
# 3      PC-50 - Terrorism and War Risks Exclusion
# 4
#
#
# Table 2:
#   0_  III-385  \
# 1     III-390
# 2     III-395
#
#   Model Regulation to Define Standards and\rCommissioner’s Authority for Companies\rDeemed to be in Hazardous Financial\rCondition  \
# 1                          Model Law on Examinations
# 2  Participation in the NAIC Insurance\rRegulator...
#
#   This model regulation sets forth standards for identifying insurers found to be in such\rcondition as to render the continuance of their business hazardous to the public or to\rholders of their policies or certificates of insurance.  \
# 1  This model law helps provide an effective, eff...
# 2  This model act sets forth the requirements for...
#
#                                                   4_ 5_
# 1  CF-40 - Financial Examinations Standards for I...
# 2
#
#
# Table 3:
#   0_  III-430         Health Maintenance Organization Model\rAct  \
# 1     III-432  Model Regulation to Implement Rules\rRegarding...
#
#   This model act provides for a system of regulation for health maintenance organizations\rthat is fair and efficient, and promotes the continued solvency of health maintenance\rorganizations.  \
# 1  This model regulation implements the NAIC Heal...
#
#   HM-10 - Departmental Regulation of HMOs\rHM-20 - Open Enrollment Periods for HMOs\rHM-30 - HMO Net Worth and Deposit Requirements  \
# 1  HM-10 - Departmental Regulation of HMOs\rHM-20...
#
#   5_
# 1
#
#
# Table 4:
#   0_ Volume/\rModel #                                     Title of Model  \
# 1             III-440   Insurance Holding Company System\rRegulatory Act
# 2             III-450  Insurance Holding Company System Model\rRegula...
#
#                                          Description  \
# 1  This model act includes requirements pertainin...
# 2  This model regulation sets forth rules and pro...
#
#   Related Charts: State Laws on Insurance Topics 5_
# 1
# 2
#
#
# Table 5:
#   0_  III-460  \
# 1     III-480
# 2     III-490
# 3     III-500
#
#   An Act Concerning Insider Trading of\rDomestic Stock Insurance Company Equity\rSecurities  \
# 1  Regulations Adopted Pursuant to an Act\rConcer...
# 2  Regulation Regarding Proxies, Consents\rand Au...
# 3  Stockholders Information Supplement\rSchedule SIS
#
#   This model act includes provisions concerning the unfair use of information, sales of\requity security, exceptions, definitions and forfeiture. Its corresponding model regulation\ris MDL-480.  \
# 1  This model regulation contains definitions and...
# 2  Thismodelregulationprovidesproxyrequirements,f...
# 3  This model contains general instructions, info...
#
#   4_ 5_
# 1
# 2
# 3
#
#
# Table 6:
#   0_  III-505  \
# 1     III-510
# 2     III-520
#
#   Risk Management and Own Risk and\rSolvency Assessment (ORSA) Model Act  \
# 1  Criminal Sanctions for Failure to Report\rImpa...
# 2  Life and Health Insurance Guaranty\rAssociatio...
#
#   Thismodelactestablishestherequirementsformaintainingariskmanagement\rframework and completing an Own Risk and Solvency Assessment (ORSA). It addresses\rexemptions, confidentiality and sanctions.  \
# 1  This model outlines the criminal sanctions and...
# 2  This model act protects against failure in the...
#
#                                                   4_ 5_
# 1
# 2  IN-10 - Life and Health Guaranty Fund Laws\rIN...
#
#
# Table 7:
#   0_ Volume/\rModel #                                     Title of Model  \
# 1             III-540  Property and Casualty Insurance Guaranty\rAsso...
# 2             III-555                     Insurer Receivership Model Act
# 3             III-558               Administrative Supervision Model Act
#
#                                          Description  \
# 1  This model act provides a mechanism for the pa...
# 2  This model act helps protect the interests of ...
# 3  This model act outlines the parameters under w...
#
#       Related Charts: State Laws on Insurance Topics 5_
# 1  IN-30 - Property and Casualty Guaranty Fund La...
# 2
# 3
#
#
# Table 8:
#   0_  IV-565  \
# 1     IV-568
# 2     IV-570
# 3     IV-575
# 4     IV-580
#
#   Group Life Insurance Definition and Group\rLife Insurance Standard Provisions Model\rAct  \
# 1          Military Sales Practices Model Regulation
# 2  Advertisements of Life Insurance and\rAnnuitie...
# 3  Life and Health Insurance Policy Language\rSim...
# 4         Life Insurance Disclosure Model Regulation
#
#   This model act sets forth group life insurance standard provisions. It defines group life\rinsurance and contains provisions relating to limits of group life insurance, notice of\rcompensation, dependent coverage, standard provisions, and a supplementary provision\rrelating to conversion privileges.  \
# 1  The purpose of this model regulation is to set...
# 2  This model regulation sets forth minimum stand...
# 3  This model act establishes minimum standards f...
# 4  This model regulation requires insurers to pro...
#
#                                                   4_ 5_
# 1          PC-50 - Terrorism and War Risks Exclusion
# 2       LI-30 - Life Insurance Disclosure Provisions
# 3  LI-20 - Form Filing Requirements Life Insuranc...
# 4  LI-30 - Life Insurance Disclosure Provisions\r...
#
#
# Table 9:
#      mpg cyl   disp   hp  drat     wt   qsec vs am gear
# 1   21.0   6  160.0  110  3.90  2.620  16.46  0  1    4
# 2   21.0   6  160.0  110  3.90  2.875  17.02  0  1    4
# 3   22.8   4  108.0   93  3.85  2.320  18.61  1  1    4
# 4   21.4   6  258.0  110  3.08  3.215  19.44  1  0    3
# 5   18.7   8  360.0  175  3.15  3.440  17.02  0  0    3
# 6   18.1   6  225.0  105  2.76  3.460  20.22  1  0    3
# 7   14.3   8  360.0  245  3.21  3.570  15.84  0  0    3
# 8   24.4   4  146.7   62  3.69  3.190  20.00  1  0    4
# 9   22.8   4  140.8   95  3.92  3.150  22.90  1  0    4
# 10  19.2   6  167.6  123  3.92  3.440  18.30  1  0    4
# 11  17.8   6  167.6  123  3.92  3.440  18.90  1  0    4
# 12  16.4   8  275.8  180  3.07  4.070  17.40  0  0    3
# 13  17.3   8  275.8  180  3.07  3.730  17.60  0  0    3
# 14  15.2   8  275.8  180  3.07  3.780  18.00  0  0    3
# 15  10.4   8  472.0  205  2.93  5.250  17.98  0  0    3
# 16  10.4   8  460.0  215  3.00  5.424  17.82  0  0    3
# 17  14.7   8  440.0  230  3.23  5.345  17.42  0  0    3
# 18  32.4   4   78.7   66  4.08  2.200  19.47  1  1    4
# 19  30.4   4   75.7   52  4.93  1.615  18.52  1  1    4
# 20  33.9   4   71.1   65  4.22  1.835  19.90  1  1    4
# 21  21.5   4  120.1   97  3.70  2.465  20.01  1  0    3
# 22  15.5   8  318.0  150  2.76  3.520  16.87  0  0    3
# 23  15.2   8  304.0  150  3.15  3.435  17.30  0  0    3
# 24  13.3   8  350.0  245  3.73  3.840  15.41  0  0    3
# 25  19.2   8  400.0  175  3.08  3.845  17.05  0  0    3
# 26  27.3   4   79.0   66  4.08  1.935  18.90  1  1    4
# 27  26.0   4  120.3   91  4.43  2.140  16.70  0  1    5
# 28  30.4   4   95.1  113  3.77  1.513  16.90  1  1    5
# 29  15.8   8  351.0  264  4.22  3.170  14.50  0  1    5
# 30  19.7   6  145.0  175  3.62  2.770  15.50  0  1    5
# 31  15.0   8  301.0  335  3.54  3.570  14.60  0  1    5
#
#
# Table 10:
#    Sepal.Length Sepal.Width Petal.Length   Petal.Width      Species
# 1                       5.1          3.5           1.4   0.2 setosa
# 2                       4.9          3.0           1.4   0.2 setosa
# 3                       4.7          3.2           1.3   0.2 setosa
# 4                       4.6          3.1           1.5   0.2 setosa
# 5                       5.0          3.6           1.4   0.2 setosa
# 6                       5.4          3.9           1.7   0.4 setosa
# 7              Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 8                   145 6.7          3.3           5.7          2.5  virginica
# 9                   146 6.7          3.0           5.2          2.3  virginica
# 10                  147 6.3          2.5           5.0          1.9  virginica
# 11                  148 6.5          3.0           5.2          2.0  virginica
# 12                  149 6.2          3.4           5.4          2.3  virginica
# 13                  150 5.9          3.0           5.1          1.8  virginica
# 14                                     2
#
#
# Table 11:
#    supp
# 1    VC
# 2    VC
# 3    VC
# 4    VC
# 5    VC
# 6    VC
# 7    VC
# 8    VC
# 9    VC
# 10   VC
# 11   VC
# 12   VC
# 13   VC
# 14   VC

# %% [markdown]
# ## Use `ppt2table` spell

# %% [markdown]
# ### lets download the test `ppt` file first.

# %%
# !wget https://github.com/JohnSnowLabs/nlu/raw/4.0.0/tests/datasets/ocr/ppt/tables.ppt

# %% [markdown]
# ### Load and make prediction on *the* test file

# %%
results = nlu.load('ppt2table').predict("/content/tables.ppt")
print_tables(results)
# Out:
# Table 1:
#                           mpg cyl   disp   hp  drat     wt   qsec vs am gear  \
# 1             Mazda RX4  21.0   6  160.0  110  3.90  2.620  16.46  0  1    4
# 2         Mazda RX4 Wag  21.0   6  160.0  110  3.90  2.875  17.02  0  1    4
# 3            Datsun 710  22.8   4  108.0   93  3.85  2.320  18.61  1  1    4
# 4        Hornet 4 Drive  21.4   6  258.0  110  3.08  3.215  19.44  1  0    3
# 5     Hornet Sportabout  18.7   8  360.0  175  3.15  3.440  17.02  0  0    3
# 6               Valiant  18.1   6  225.0  105  2.76  3.460  20.22  1  0    3
# 7            Duster 360  14.3   8  360.0  245  3.21  3.570  15.84  0  0    3
# 8             Merc 240D  24.4   4  146.7   62  3.69  3.190  20.00  1  0    4
# 9              Merc 230  22.8   4  140.8   95  3.92  3.150  22.90  1  0    4
# 10             Merc 280  19.2   6  167.6  123  3.92  3.440  18.30  1  0    4
# 11            Merc 280C  17.8   6  167.6  123  3.92  3.440  18.90  1  0    4
# 12           Merc 450SE  16.4   8  275.8  180  3.07  4.070  17.40  0  0    3
# 13           Merc 450SL  17.3   8  275.8  180  3.07  3.730  17.60  0  0    3
# 14          Merc 450SLC  15.2   8  275.8  180  3.07  3.780  18.00  0  0    3
# 15   Cadillac Fleetwood  10.4   8  472.0  205  2.93  5.250  17.98  0  0    3
# 16  Lincoln Continental  10.4   8  460.0  215  3.00  5.424  17.82  0  0    3
# 17    Chrysler Imperial  14.7   8  440.0  230  3.23  5.345  17.42  0  0    3
# 18             Fiat 128  32.4   4   78.7   66  4.08  2.200  19.47  1  1    4
# 19          Honda Civic  30.4   4   75.7   52  4.93  1.615  18.52  1  1    4
# 20       Toyota Corolla  33.9   4   71.1   65  4.22  1.835  19.90  1  1    4
# 21        Toyota Corona  21.5   4  120.1   97  3.70  2.465  20.01  1  0    3
# 22     Dodge Challenger  15.5   8  318.0  150  2.76  3.520  16.87  0  0    3
# 23          AMC Javelin  15.2   8  304.0  150  3.15  3.435  17.30  0  0    3
# 24           Camaro Z28  13.3   8  350.0  245  3.73  3.840  15.41  0  0    3
# 25     Pontiac Firebird  19.2   8  400.0  175  3.08  3.845  17.05  0  0    3
# 26            Fiat X1-9  27.3   4   79.0   66  4.08  1.935  18.90  1  1    4
# 27        Porsche 914-2  26.0   4  120.3   91  4.43  2.140  16.70  0  1    5
# 28         Lotus Europa  30.4   4   95.1  113  3.77  1.513  16.90  1  1    5
# 29       Ford Pantera L  15.8   8  351.0  264  4.22  3.170  14.50  0  1    5
# 30         Ferrari Dino  19.7   6  145.0  175  3.62  2.770  15.50  0  1    5
# 31        Maserati Bora  15.0   8  301.0  335  3.54  3.570  14.60  0  1    5
# 32           Volvo 142E  21.4   4  121.0  109  4.11  2.780  18.60  1  1    4
#
#    carb
# 1     4
# 2     4
# 3     1
# 4     1
# 5     2
# 6     1
# 7     4
# 8     2
# 9     2
# 10    4
# 11    4
# 12    3
# 13    3
# 14    3
# 15    4
# 16    4
# 17    4
# 18    1
# 19    2
# 20    1
# 21    1
# 22    2
# 23    2
# 24    4
# 25    2
# 26    1
# 27    2
# 28    2
# 29    4
# 30    6
# 31    8
# 32    2
#
#
# Table 2:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1          5.1         3.5          1.4         0.2  setosa
# 2          4.9         3.0          1.4         0.2  setosa
# 3          4.7         3.2          1.3         0.2  setosa
# 4          4.6         3.1          1.5         0.2  setosa
# 5          5.0         3.6          1.4         0.2  setosa
# 6          5.4         3.9          1.7         0.4  setosa
#
#
# Table 3:
#        Sepal.Length Sepal.Width Petal.Length Petal.Width    Species
# 1  145          6.7         3.3          5.7         2.5  virginica
# 2  146          6.7         3.0          5.2         2.3  virginica
# 3  147          6.3         2.5          5.0         1.9  virginica
# 4  148          6.5         3.0          5.2         2.0  virginica
# 5  149          6.2         3.4          5.4         2.3  virginica
# 6  150          5.9         3.0          5.1         1.8  virginica
#
#
# Table 4:
#      len supp dose
# 1    4.2   VC  0.5
# 2   11.5   VC  0.5
# 3    7.3   VC  0.5
# 4    5.8   VC  0.5
# 5    6.4   VC  0.5
# 6   10.0   VC  0.5
# 7   11.2   VC  0.5
# 8   11.2   VC  0.5
# 9    5.2   VC  0.5
# 10   7.0   VC  0.5
# 11  16.5   VC  1.0
# 12  16.5   VC  1.0
# 13  15.2   VC  1.0
# 14  17.3   VC  1.0
# 15  22.5   VC  1.0

# %% [markdown]
# ## Use `doc2table` spell

# %% [markdown]
# ### lets download the test `DOC/DOCX` file first.

# %%
# !wget https://github.com/JohnSnowLabs/nlu/raw/4.0.0/tests/datasets/ocr/docx_with_table/doc2.docx

# %% [markdown]
# ### Load and make prediction on *the* test file

# %%
results = nlu.load('doc2table').predict("/content/doc2.docx")
print_tables(results)
# Out:
# Table 1:
#    Screen Reader Responses Share
# 1           JAWS       853   49%
# 2           NVDA       238   14%
# 3    Window-Eyes       214   12%
# 4  System Access       181   10%
# 5      VoiceOver       159    9%
#
#
# Table 2:
#                    May 2012  September 2010
# 1  Screen Reader  Responses           Share
# 2           JAWS        853             49%
# 3           NVDA        238             14%
# 4    Window-Eyes        214             12%
# 5  System Access        181             10%
# 6      VoiceOver        159              9%
