# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/nlu/blob/master/examples/colab/healthcare/relation_extraction/overview_relation.ipynb)

# %% [markdown]
# # Extract **relationships** between **named entities**
# With the *Named Entity Recognizer** models provided by NLU you can extract various named entities from you dataset, like `disease` and `medicine` names, `treatments` , `tests` , `patient names` etc..
#
# Between these `entities` there can exist some relation.
# For example, the sentence :
# "`Timmys` had a `headache` , it was treated with `paracetamol` by `Dr Sami` "   ,
#
# it has the named entities `Dr Sami` , `Timmy` , `headache` , `paracetamol`   and these entities have some relation between them.
#
# - The entity `Timmy` is related to `headache` ,  with a `has` relationship
# - The entity `headache` is related to `paracetamol` with a `is treated with` relation ship
#
#
# The **Relation Extractor** models classifies for each pair for entities, wether some kind of relationship exists between them.
#
# All the models avaiable are :
#
# | Language | nlu.load() reference                                         | Spark NLP Model reference          |
# | -------- | ------------------------------------------------------------ | ------------------------------------------------------------ |
# | English  | [assert](https://nlp.johnsnowlabs.com/2021/01/26/assertion_dl_en.html) | [assertion_dl](https://nlp.johnsnowlabs.com/2021/01/26/assertion_dl_en.html)                   |
# | English  | [assert.biobert](https://nlp.johnsnowlabs.com/2021/01/26/assertion_dl_biobert_en.html) | [assertion_dl_biobert](https://nlp.johnsnowlabs.com/2021/01/26/assertion_dl_biobert_en.html)                   |
# | English  | [assert.healthcare](https://nlp.johnsnowlabs.com/2020/09/23/assertion_dl_healthcare_en.html) | [assertion_dl_healthcare](https://nlp.johnsnowlabs.com/2020/09/23/assertion_dl_healthcare_en.html)                   |
# | English  | [assert.large](https://nlp.johnsnowlabs.com/2020/05/21/assertion_dl_large_en.html) | [assertion_dl_large](https://nlp.johnsnowlabs.com/2020/05/21/assertion_dl_large_en.html)                   |

# %%
# %%capture
# # Install NLU
# !wget https://setup.johnsnowlabs.com/nlu/colab.sh | bash
# # Upload add your spark_nlp_fo"r_healthcare.json

import nlu

# %% [markdown]
# #### [Relation extraction between body parts and direction entities (ReDL).](https://nlp.johnsnowlabs.com/2021/02/04/redl_bodypart_direction_biobert_en.html)

# %%
import nlu

nlu.load('en.med_ner.jsl.wip.clinical.greedy en.relation').predict('MRI demonstrated infarction in the upper brain stem , left cerebellum and  right basil ganglia"', output_level='relation')
# Out:
# jsl_ner_wip_greedy_clinical download started this may take some time.
# Approximate size to download 14.5 MB
# [OK!]
# redl_bodypart_direction_biobert download started this may take some time.
# Approximate size to download 383.4 MB
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
#                                             document  \
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
#
#                                         entities_jsl  \
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
#
#                                   entities_jsl_class  \
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
#
#                              entities_jsl_confidence relation_relation  \
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 1
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 1
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 1
#
#   relation_relation_confidence relation_relation_entity1  \
# 0                   0.81420505                       MRI
# 0                   0.95338297                       MRI
# 0                    0.8658007                       MRI
# 0                   0.97774374                       MRI
# 0                    0.9228966                       MRI
# 0                   0.98015594                       MRI
# 0                   0.82684225                       MRI
# 0                   0.98498225                infarction
# 0                    0.9372272                infarction
# 0                    0.9718382                infarction
# 0                    0.9774138                infarction
# 0                     0.980984                infarction
# 0                    0.9743712                infarction
# 0                   0.99970907                     upper
# 0                     0.986822                     upper
# 0                     0.993254                     upper
# 0                    0.9934169                     upper
# 0                   0.99134225                     upper
# 0                    0.7077815                brain stem
# 0                   0.92520595                brain stem
# 0                    0.8609171                brain stem
# 0                   0.74085635                brain stem
# 0                     0.999744                      left
# 0                     0.993982                      left
# 0                   0.98263156                      left
# 0                    0.9837263                cerebellum
# 0                    0.9782834                cerebellum
# 0                    0.9988759                     right
#
#   relation_relation_entity1_class relation_relation_entity2  \
# 0                            Test                infarction
# 0                            Test                     upper
# 0                            Test                brain stem
# 0                            Test                      left
# 0                            Test                cerebellum
# 0                            Test                     right
# 0                            Test             basil ganglia
# 0       Disease_Syndrome_Disorder                     upper
# 0       Disease_Syndrome_Disorder                brain stem
# 0       Disease_Syndrome_Disorder                      left
# 0       Disease_Syndrome_Disorder                cerebellum
# 0       Disease_Syndrome_Disorder                     right
# 0       Disease_Syndrome_Disorder             basil ganglia
# 0                       Direction                brain stem
# 0                       Direction                      left
# 0                       Direction                cerebellum
# 0                       Direction                     right
# 0                       Direction             basil ganglia
# 0     Internal_organ_or_component                      left
# 0     Internal_organ_or_component                cerebellum
# 0     Internal_organ_or_component                     right
# 0     Internal_organ_or_component             basil ganglia
# 0                       Direction                cerebellum
# 0                       Direction                     right
# 0                       Direction             basil ganglia
# 0     Internal_organ_or_component                     right
# 0     Internal_organ_or_component             basil ganglia
# 0                       Direction             basil ganglia
#
#   relation_relation_entity2_class  \
# 0       Disease_Syndrome_Disorder
# 0                       Direction
# 0     Internal_organ_or_component
# 0                       Direction
# 0     Internal_organ_or_component
# 0                       Direction
# 0     Internal_organ_or_component
# 0                       Direction
# 0     Internal_organ_or_component
# 0                       Direction
# 0     Internal_organ_or_component
# 0                       Direction
# 0     Internal_organ_or_component
# 0     Internal_organ_or_component
# 0                       Direction
# 0     Internal_organ_or_component
# 0                       Direction
# 0     Internal_organ_or_component
# 0                       Direction
# 0     Internal_organ_or_component
# 0                       Direction
# 0     Internal_organ_or_component
# 0     Internal_organ_or_component
# 0                       Direction
# 0     Internal_organ_or_component
# 0                       Direction
# 0     Internal_organ_or_component
# 0     Internal_organ_or_component
#
#                                 word_embedding_glove
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...

# %% [markdown]
# #### [Relation extraction between body parts and problem entities (ReDL)](https://nlp.johnsnowlabs.com/2021/02/04/redl_bodypart_problem_biobert_en.html)

# %%
nlu.load('en.med_ner.jsl.wip.clinical.greedy en.relation.bodypart.problem').predict("No neurologic deficits other than some numbness in his left hand.", output_level='relation')
# Out:
# jsl_ner_wip_greedy_clinical download started this may take some time.
# Approximate size to download 14.5 MB
# [OK!]
# redl_bodypart_problem_biobert download started this may take some time.
# Approximate size to download 383.4 MB
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
#                                             document  \
# 0  No neurologic deficits other than some numbnes...
# 0  No neurologic deficits other than some numbnes...
# 0  No neurologic deficits other than some numbnes...
# 0  No neurologic deficits other than some numbnes...
# 0  No neurologic deficits other than some numbnes...
# 0  No neurologic deficits other than some numbnes...
# 0  No neurologic deficits other than some numbnes...
# 0  No neurologic deficits other than some numbnes...
# 0  No neurologic deficits other than some numbnes...
# 0  No neurologic deficits other than some numbnes...
#
#                                        entities_jsl  \
# 0  [neurologic deficits, numbness, his, left, hand]
# 0  [neurologic deficits, numbness, his, left, hand]
# 0  [neurologic deficits, numbness, his, left, hand]
# 0  [neurologic deficits, numbness, his, left, hand]
# 0  [neurologic deficits, numbness, his, left, hand]
# 0  [neurologic deficits, numbness, his, left, hand]
# 0  [neurologic deficits, numbness, his, left, hand]
# 0  [neurologic deficits, numbness, his, left, hand]
# 0  [neurologic deficits, numbness, his, left, hand]
# 0  [neurologic deficits, numbness, his, left, hand]
#
#                                   entities_jsl_class  \
# 0  [Symptom, Symptom, Gender, Direction, External...
# 0  [Symptom, Symptom, Gender, Direction, External...
# 0  [Symptom, Symptom, Gender, Direction, External...
# 0  [Symptom, Symptom, Gender, Direction, External...
# 0  [Symptom, Symptom, Gender, Direction, External...
# 0  [Symptom, Symptom, Gender, Direction, External...
# 0  [Symptom, Symptom, Gender, Direction, External...
# 0  [Symptom, Symptom, Gender, Direction, External...
# 0  [Symptom, Symptom, Gender, Direction, External...
# 0  [Symptom, Symptom, Gender, Direction, External...
#
#                    entities_jsl_confidence relation_relation  \
# 0  [0.624, 0.1138, 0.3734, 0.6826, 0.2737]                 0
# 0  [0.624, 0.1138, 0.3734, 0.6826, 0.2737]                 1
# 0  [0.624, 0.1138, 0.3734, 0.6826, 0.2737]                 1
# 0  [0.624, 0.1138, 0.3734, 0.6826, 0.2737]                 0
# 0  [0.624, 0.1138, 0.3734, 0.6826, 0.2737]                 1
# 0  [0.624, 0.1138, 0.3734, 0.6826, 0.2737]                 1
# 0  [0.624, 0.1138, 0.3734, 0.6826, 0.2737]                 1
# 0  [0.624, 0.1138, 0.3734, 0.6826, 0.2737]                 1
# 0  [0.624, 0.1138, 0.3734, 0.6826, 0.2737]                 1
# 0  [0.624, 0.1138, 0.3734, 0.6826, 0.2737]                 1
#
#   relation_relation_confidence relation_relation_entity1  \
# 0                   0.88142926       neurologic deficits
# 0                    0.7320456       neurologic deficits
# 0                   0.55514485       neurologic deficits
# 0                    0.6616252       neurologic deficits
# 0                   0.99960154                  numbness
# 0                    0.9994462                  numbness
# 0                   0.99947935                  numbness
# 0                    0.9983039                       his
# 0                    0.9985129                       his
# 0                    0.9991504                      left
#
#   relation_relation_entity1_class relation_relation_entity2  \
# 0                         Symptom                  numbness
# 0                         Symptom                       his
# 0                         Symptom                      left
# 0                         Symptom                      hand
# 0                         Symptom                       his
# 0                         Symptom                      left
# 0                         Symptom                      hand
# 0                          Gender                      left
# 0                          Gender                      hand
# 0                       Direction                      hand
#
#   relation_relation_entity2_class  \
# 0                         Symptom
# 0                          Gender
# 0                       Direction
# 0    External_body_part_or_region
# 0                          Gender
# 0                       Direction
# 0    External_body_part_or_region
# 0                       Direction
# 0    External_body_part_or_region
# 0    External_body_part_or_region
#
#                                 word_embedding_glove
# 0  [[-0.31757616996765137, -0.1074424758553505, 0...
# 0  [[-0.31757616996765137, -0.1074424758553505, 0...
# 0  [[-0.31757616996765137, -0.1074424758553505, 0...
# 0  [[-0.31757616996765137, -0.1074424758553505, 0...
# 0  [[-0.31757616996765137, -0.1074424758553505, 0...
# 0  [[-0.31757616996765137, -0.1074424758553505, 0...
# 0  [[-0.31757616996765137, -0.1074424758553505, 0...
# 0  [[-0.31757616996765137, -0.1074424758553505, 0...
# 0  [[-0.31757616996765137, -0.1074424758553505, 0...
# 0  [[-0.31757616996765137, -0.1074424758553505, 0...

# %% [markdown]
# #### [Relation extraction between body parts and procedures](https://nlp.johnsnowlabs.com/2021/02/04/redl_bodypart_procedure_test_biobert_en.html)

# %%
nlu.load('en.med_ner.jsl.wip.clinical.greedy en.relation.bodypart.procedure').predict("TECHNIQUE IN DETAIL: After informed consent was obtained from the patient and his mother, the chest was scanned with portable ultrasound.", output_level='relation')
# Out:
# jsl_ner_wip_greedy_clinical download started this may take some time.
# Approximate size to download 14.5 MB
# [OK!]
# redl_bodypart_procedure_test_biobert download started this may take some time.
# Approximate size to download 383.4 MB
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
#                                             document  \
# 0  TECHNIQUE IN DETAIL: After informed consent wa...
# 0  TECHNIQUE IN DETAIL: After informed consent wa...
# 0  TECHNIQUE IN DETAIL: After informed consent wa...
# 0  TECHNIQUE IN DETAIL: After informed consent wa...
# 0  TECHNIQUE IN DETAIL: After informed consent wa...
# 0  TECHNIQUE IN DETAIL: After informed consent wa...
#
#                                         entities_jsl  \
# 0  [TECHNIQUE IN DETAIL:, his mother, chest, port...
# 0  [TECHNIQUE IN DETAIL:, his mother, chest, port...
# 0  [TECHNIQUE IN DETAIL:, his mother, chest, port...
# 0  [TECHNIQUE IN DETAIL:, his mother, chest, port...
# 0  [TECHNIQUE IN DETAIL:, his mother, chest, port...
# 0  [TECHNIQUE IN DETAIL:, his mother, chest, port...
#
#                                   entities_jsl_class  \
# 0  [Section_Header, Gender, External_body_part_or...
# 0  [Section_Header, Gender, External_body_part_or...
# 0  [Section_Header, Gender, External_body_part_or...
# 0  [Section_Header, Gender, External_body_part_or...
# 0  [Section_Header, Gender, External_body_part_or...
# 0  [Section_Header, Gender, External_body_part_or...
#
#               entities_jsl_confidence relation_relation  \
# 0  [0.37425, 0.82855, 0.433, 0.67095]                 1
# 0  [0.37425, 0.82855, 0.433, 0.67095]                 1
# 0  [0.37425, 0.82855, 0.433, 0.67095]                 1
# 0  [0.37425, 0.82855, 0.433, 0.67095]                 1
# 0  [0.37425, 0.82855, 0.433, 0.67095]                 1
# 0  [0.37425, 0.82855, 0.433, 0.67095]                 1
#
#   relation_relation_confidence relation_relation_entity1  \
# 0                   0.98273385      TECHNIQUE IN DETAIL:
# 0                    0.9998604      TECHNIQUE IN DETAIL:
# 0                   0.99478143      TECHNIQUE IN DETAIL:
# 0                      0.99841                his mother
# 0                    0.9867143                his mother
# 0                    0.9991165                     chest
#
#   relation_relation_entity1_class relation_relation_entity2  \
# 0                  Section_Header                his mother
# 0                  Section_Header                     chest
# 0                  Section_Header       portable ultrasound
# 0                          Gender                     chest
# 0                          Gender       portable ultrasound
# 0    External_body_part_or_region       portable ultrasound
#
#   relation_relation_entity2_class  \
# 0                          Gender
# 0    External_body_part_or_region
# 0                            Test
# 0    External_body_part_or_region
# 0                            Test
# 0                            Test
#
#                                 word_embedding_glove
# 0  [[0.278702974319458, 0.49658653140068054, -0.1...
# 0  [[0.278702974319458, 0.49658653140068054, -0.1...
# 0  [[0.278702974319458, 0.49658653140068054, -0.1...
# 0  [[0.278702974319458, 0.49658653140068054, -0.1...
# 0  [[0.278702974319458, 0.49658653140068054, -0.1...
# 0  [[0.278702974319458, 0.49658653140068054, -0.1...

# %% [markdown]
# #### [Extract relations between chemicals and proteins (ReDL)](https://nlp.johnsnowlabs.com/2021/02/04/redl_chemprot_biobert_en.html)

# %%
nlu.load('en.med_ner.chemprot.clinical en.relation.chemprot').predict("""In this study, we examined the effects of mitiglinide on various cloned K(ATP) channels
     (Kir6.2/SUR1, Kir6.2/SUR2A, and Kir6.2/SUR2B) reconstituted in COS-1 cells, and compared them to another meglitinide-related compound, nateglinide. Patch-clamp analysis using
     inside-out recording configuration showed that mitiglinide inhibits the Kir6.2/SUR1 channel currents in a dose-dependent manner (IC50 value, 100 nM) but does not significantly
     inhibit either Kir6.2/SUR2A or Kir6.2/SUR2B channel currents even at high doses (more than 10 microM). Nateglinide inhibits Kir6.2/SUR1 and Kir6.2/SUR2B channels at 100 nM,
     and inhibits Kir6.2/SUR2A channels at high concentrations (1 microM). Binding experiments on mitiglinide, nateglinide, and repaglinide to SUR1 expressed in COS-1 cells 
     revealed that they inhibit the binding of [3H]glibenclamide to SUR1 (IC50 values: mitiglinide, 280 nM; nateglinide, 8 microM; repaglinide, 1.6 microM), suggesting that
     they all share a glibenclamide binding site. The insulin responses to glucose, mitiglinide, tolbutamide, and glibenclamide in MIN6 cells after chronic mitiglinide, nateglinide,
     or repaglinide treatment were comparable to those after chronic tolbutamide and glibenclamide treatment. These results indicate that, similar to the sulfonylureas, mitiglinide 
     is highly specific to the Kir6.2/SUR1 complex, i.e., the pancreatic beta-cell K(ATP) channel, 
     and suggest that mitiglinide may be a clinically useful anti-diabetic drug.""", output_level='relation')
# Out:
# ner_chemprot_clinical download started this may take some time.
# Approximate size to download 15.3 MB
# [OK!]
# redl_chemprot_biobert download started this may take some time.
# Approximate size to download 383.4 MB
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
#                                              document  \
# 0   In this study, we examined the effects of miti...
# 0   In this study, we examined the effects of miti...
# 0   In this study, we examined the effects of miti...
# 0   In this study, we examined the effects of miti...
# 0   In this study, we examined the effects of miti...
# ..                                                ...
# 0   In this study, we examined the effects of miti...
# 0   In this study, we examined the effects of miti...
# 0   In this study, we examined the effects of miti...
# 0   In this study, we examined the effects of miti...
# 0   In this study, we examined the effects of miti...
#
#                                     entities_chemprot  \
# 0   [mitiglinide, channels, nateglinide, mitiglini...
# 0   [mitiglinide, channels, nateglinide, mitiglini...
# 0   [mitiglinide, channels, nateglinide, mitiglini...
# 0   [mitiglinide, channels, nateglinide, mitiglini...
# 0   [mitiglinide, channels, nateglinide, mitiglini...
# ..                                                ...
# 0   [mitiglinide, channels, nateglinide, mitiglini...
# 0   [mitiglinide, channels, nateglinide, mitiglini...
# 0   [mitiglinide, channels, nateglinide, mitiglini...
# 0   [mitiglinide, channels, nateglinide, mitiglini...
# 0   [mitiglinide, channels, nateglinide, mitiglini...
#
#                               entities_chemprot_class  \
# 0   [CHEMICAL, GENE-N, CHEMICAL, CHEMICAL, CHEMICA...
# 0   [CHEMICAL, GENE-N, CHEMICAL, CHEMICAL, CHEMICA...
# 0   [CHEMICAL, GENE-N, CHEMICAL, CHEMICAL, CHEMICA...
# 0   [CHEMICAL, GENE-N, CHEMICAL, CHEMICAL, CHEMICA...
# 0   [CHEMICAL, GENE-N, CHEMICAL, CHEMICAL, CHEMICA...
# ..                                                ...
# 0   [CHEMICAL, GENE-N, CHEMICAL, CHEMICAL, CHEMICA...
# 0   [CHEMICAL, GENE-N, CHEMICAL, CHEMICAL, CHEMICA...
# 0   [CHEMICAL, GENE-N, CHEMICAL, CHEMICAL, CHEMICA...
# 0   [CHEMICAL, GENE-N, CHEMICAL, CHEMICAL, CHEMICA...
# 0   [CHEMICAL, GENE-N, CHEMICAL, CHEMICAL, CHEMICA...
#
#                          entities_chemprot_confidence relation_relation  \
# 0   [1.0, 1.0, 1.0, 1.0, 0.9999, 1.0, 1.0, 0.9998,...             CPR:2
# 0   [1.0, 1.0, 1.0, 1.0, 0.9999, 1.0, 1.0, 0.9998,...             CPR:2
# 0   [1.0, 1.0, 1.0, 1.0, 0.9999, 1.0, 1.0, 0.9998,...             CPR:4
# 0   [1.0, 1.0, 1.0, 1.0, 0.9999, 1.0, 1.0, 0.9998,...             CPR:2
# 0   [1.0, 1.0, 1.0, 1.0, 0.9999, 1.0, 1.0, 0.9998,...             CPR:2
# ..                                                ...               ...
# 0   [1.0, 1.0, 1.0, 1.0, 0.9999, 1.0, 1.0, 0.9998,...             CPR:4
# 0   [1.0, 1.0, 1.0, 1.0, 0.9999, 1.0, 1.0, 0.9998,...             CPR:4
# 0   [1.0, 1.0, 1.0, 1.0, 0.9999, 1.0, 1.0, 0.9998,...             CPR:2
# 0   [1.0, 1.0, 1.0, 1.0, 0.9999, 1.0, 1.0, 0.9998,...             CPR:4
# 0   [1.0, 1.0, 1.0, 1.0, 0.9999, 1.0, 1.0, 0.9998,...             CPR:2
#
#    relation_relation_confidence relation_relation_entity1  \
# 0                     0.9944285               mitiglinide
# 0                    0.97920156               mitiglinide
# 0                     0.7447406               mitiglinide
# 0                    0.99507207               mitiglinide
# 0                     0.9898095               mitiglinide
# ..                          ...                       ...
# 0                    0.78318495             sulfonylureas
# 0                    0.72365254             sulfonylureas
# 0                     0.6978523               mitiglinide
# 0                     0.6686603               mitiglinide
# 0                     0.8149319                   channel
#
#    relation_relation_entity1_class relation_relation_entity2  \
# 0                         CHEMICAL                  channels
# 0                         CHEMICAL               nateglinide
# 0                         CHEMICAL               mitiglinide
# 0                         CHEMICAL               Nateglinide
# 0                         CHEMICAL               mitiglinide
# ..                             ...                       ...
# 0                         CHEMICAL                   channel
# 0                         CHEMICAL               mitiglinide
# 0                         CHEMICAL                   channel
# 0                         CHEMICAL               mitiglinide
# 0                           GENE-N               mitiglinide
#
#    relation_relation_entity2_class  \
# 0                           GENE-N
# 0                         CHEMICAL
# 0                         CHEMICAL
# 0                         CHEMICAL
# 0                         CHEMICAL
# ..                             ...
# 0                           GENE-N
# 0                         CHEMICAL
# 0                           GENE-N
# 0                         CHEMICAL
# 0                         CHEMICAL
#
#                                  word_embedding_glove
# 0   [[-0.03855392336845398, -0.6488023400306702, -...
# 0   [[-0.03855392336845398, -0.6488023400306702, -...
# 0   [[-0.03855392336845398, -0.6488023400306702, -...
# 0   [[-0.03855392336845398, -0.6488023400306702, -...
# 0   [[-0.03855392336845398, -0.6488023400306702, -...
# ..                                                ...
# 0   [[-0.03855392336845398, -0.6488023400306702, -...
# 0   [[-0.03855392336845398, -0.6488023400306702, -...
# 0   [[-0.03855392336845398, -0.6488023400306702, -...
# 0   [[-0.03855392336845398, -0.6488023400306702, -...
# 0   [[-0.03855392336845398, -0.6488023400306702, -...
#
# [390 rows x 11 columns]

# %% [markdown]
# #### [Extract relations between problem, treatment and test entities (ReDL)](https://nlp.johnsnowlabs.com/2021/02/04/redl_clinical_biobert_en.html)

# %%
nlu.load('en.med_ner.clinical en.relation.clinical').predict("""A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation 
and subsequent type two diabetes mellitus ( T2DM ), one prior episode of HTG-induced pancreatitis three years prior to presentation,  associated with an acute hepatitis , and obesity with a body mass 
index ( BMI ) of 33.5 kg/m2 , presented with a one-week history of polyuria , polydipsia , poor appetite , and vomiting .
""", output_level='relation')
# Out:
# ner_clinical download started this may take some time.
# Approximate size to download 13.9 MB
# [OK!]
# redl_clinical_biobert download started this may take some time.
# Approximate size to download 383.4 MB
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
#                                              document  \
# 0   A 28-year-old female with a history of gestati...
# 0   A 28-year-old female with a history of gestati...
# 0   A 28-year-old female with a history of gestati...
# 0   A 28-year-old female with a history of gestati...
# 0   A 28-year-old female with a history of gestati...
# ..                                                ...
# 0   A 28-year-old female with a history of gestati...
# 0   A 28-year-old female with a history of gestati...
# 0   A 28-year-old female with a history of gestati...
# 0   A 28-year-old female with a history of gestati...
# 0   A 28-year-old female with a history of gestati...
#
#                                     entities_clinical  \
# 0   [gestational diabetes mellitus, subsequent typ...
# 0   [gestational diabetes mellitus, subsequent typ...
# 0   [gestational diabetes mellitus, subsequent typ...
# 0   [gestational diabetes mellitus, subsequent typ...
# 0   [gestational diabetes mellitus, subsequent typ...
# ..                                                ...
# 0   [gestational diabetes mellitus, subsequent typ...
# 0   [gestational diabetes mellitus, subsequent typ...
# 0   [gestational diabetes mellitus, subsequent typ...
# 0   [gestational diabetes mellitus, subsequent typ...
# 0   [gestational diabetes mellitus, subsequent typ...
#
#                               entities_clinical_class  \
# 0   [PROBLEM, PROBLEM, PROBLEM, PROBLEM, PROBLEM, ...
# 0   [PROBLEM, PROBLEM, PROBLEM, PROBLEM, PROBLEM, ...
# 0   [PROBLEM, PROBLEM, PROBLEM, PROBLEM, PROBLEM, ...
# 0   [PROBLEM, PROBLEM, PROBLEM, PROBLEM, PROBLEM, ...
# 0   [PROBLEM, PROBLEM, PROBLEM, PROBLEM, PROBLEM, ...
# ..                                                ...
# 0   [PROBLEM, PROBLEM, PROBLEM, PROBLEM, PROBLEM, ...
# 0   [PROBLEM, PROBLEM, PROBLEM, PROBLEM, PROBLEM, ...
# 0   [PROBLEM, PROBLEM, PROBLEM, PROBLEM, PROBLEM, ...
# 0   [PROBLEM, PROBLEM, PROBLEM, PROBLEM, PROBLEM, ...
# 0   [PROBLEM, PROBLEM, PROBLEM, PROBLEM, PROBLEM, ...
#
#                          entities_clinical_confidence relation_relation  \
# 0   [0.8904333, 0.78448, 0.9992, 0.99745, 0.981733...                 O
# 0   [0.8904333, 0.78448, 0.9992, 0.99745, 0.981733...               PIP
# 0   [0.8904333, 0.78448, 0.9992, 0.99745, 0.981733...               PIP
# 0   [0.8904333, 0.78448, 0.9992, 0.99745, 0.981733...               PIP
# 0   [0.8904333, 0.78448, 0.9992, 0.99745, 0.981733...               PIP
# ..                                                ...               ...
# 0   [0.8904333, 0.78448, 0.9992, 0.99745, 0.981733...                 O
# 0   [0.8904333, 0.78448, 0.9992, 0.99745, 0.981733...                 O
# 0   [0.8904333, 0.78448, 0.9992, 0.99745, 0.981733...                 O
# 0   [0.8904333, 0.78448, 0.9992, 0.99745, 0.981733...                 O
# 0   [0.8904333, 0.78448, 0.9992, 0.99745, 0.981733...                 O
#
#    relation_relation_confidence      relation_relation_entity1  \
# 0                     0.6946002  gestational diabetes mellitus
# 0                     0.7937271  gestational diabetes mellitus
# 0                      0.595535  gestational diabetes mellitus
# 0                    0.75506943  gestational diabetes mellitus
# 0                     0.6516741  gestational diabetes mellitus
# ..                          ...                            ...
# 0                     0.9422905                       polyuria
# 0                     0.9724138                       polyuria
# 0                     0.9820661                     polydipsia
# 0                     0.9853564                     polydipsia
# 0                    0.98181975                  poor appetite
#
#    relation_relation_entity1_class              relation_relation_entity2  \
# 0                          PROBLEM  subsequent type two diabetes mellitus
# 0                          PROBLEM                                   T2DM
# 0                          PROBLEM               HTG-induced pancreatitis
# 0                          PROBLEM                     an acute hepatitis
# 0                          PROBLEM                                obesity
# ..                             ...                                    ...
# 0                          PROBLEM                          poor appetite
# 0                          PROBLEM                               vomiting
# 0                          PROBLEM                          poor appetite
# 0                          PROBLEM                               vomiting
# 0                          PROBLEM                               vomiting
#
#    relation_relation_entity2_class  \
# 0                          PROBLEM
# 0                          PROBLEM
# 0                          PROBLEM
# 0                          PROBLEM
# 0                          PROBLEM
# ..                             ...
# 0                          PROBLEM
# 0                          PROBLEM
# 0                          PROBLEM
# 0                          PROBLEM
# 0                          PROBLEM
#
#                                  word_embedding_glove
# 0   [[0.040217556059360504, 0.4003961980342865, 0....
# 0   [[0.040217556059360504, 0.4003961980342865, 0....
# 0   [[0.040217556059360504, 0.4003961980342865, 0....
# 0   [[0.040217556059360504, 0.4003961980342865, 0....
# 0   [[0.040217556059360504, 0.4003961980342865, 0....
# ..                                                ...
# 0   [[0.040217556059360504, 0.4003961980342865, 0....
# 0   [[0.040217556059360504, 0.4003961980342865, 0....
# 0   [[0.040217556059360504, 0.4003961980342865, 0....
# 0   [[0.040217556059360504, 0.4003961980342865, 0....
# 0   [[0.040217556059360504, 0.4003961980342865, 0....
#
# [61 rows x 11 columns]

# %% [markdown]
# #### [Extract temporal relations among clinical events (ReDL)](https://nlp.johnsnowlabs.com/2021/02/04/redl_temporal_events_biobert_en.html)

# %%
nlu.load('en.med_ner.events_clinical en.relation.temporal_events').predict("She is diagnosed with cancer in 1991. Then she was admitted to Mayo Clinic in May 2000 and discharged in October 2001", output_level='relation')
# Out:
# ner_events_clinical download started this may take some time.
# Approximate size to download 13.8 MB
# [OK!]
# redl_temporal_events_biobert download started this may take some time.
# Approximate size to download 383.4 MB
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
#                                             document  \
# 0  She is diagnosed with cancer in 1991. Then she...
# 0  She is diagnosed with cancer in 1991. Then she...
# 0  She is diagnosed with cancer in 1991. Then she...
# 0  She is diagnosed with cancer in 1991. Then she...
# 0  She is diagnosed with cancer in 1991. Then she...
# 0  She is diagnosed with cancer in 1991. Then she...
# 0  She is diagnosed with cancer in 1991. Then she...
# 0  She is diagnosed with cancer in 1991. Then she...
# 0  She is diagnosed with cancer in 1991. Then she...
# 0  She is diagnosed with cancer in 1991. Then she...
# 0  She is diagnosed with cancer in 1991. Then she...
# 0  She is diagnosed with cancer in 1991. Then she...
# 0  She is diagnosed with cancer in 1991. Then she...
# 0  She is diagnosed with cancer in 1991. Then she...
# 0  She is diagnosed with cancer in 1991. Then she...
# 0  She is diagnosed with cancer in 1991. Then she...
# 0  She is diagnosed with cancer in 1991. Then she...
# 0  She is diagnosed with cancer in 1991. Then she...
#
#                             entities_events_clinical  \
# 0  [diagnosed, cancer, 1991, admitted, Mayo Clini...
# 0  [diagnosed, cancer, 1991, admitted, Mayo Clini...
# 0  [diagnosed, cancer, 1991, admitted, Mayo Clini...
# 0  [diagnosed, cancer, 1991, admitted, Mayo Clini...
# 0  [diagnosed, cancer, 1991, admitted, Mayo Clini...
# 0  [diagnosed, cancer, 1991, admitted, Mayo Clini...
# 0  [diagnosed, cancer, 1991, admitted, Mayo Clini...
# 0  [diagnosed, cancer, 1991, admitted, Mayo Clini...
# 0  [diagnosed, cancer, 1991, admitted, Mayo Clini...
# 0  [diagnosed, cancer, 1991, admitted, Mayo Clini...
# 0  [diagnosed, cancer, 1991, admitted, Mayo Clini...
# 0  [diagnosed, cancer, 1991, admitted, Mayo Clini...
# 0  [diagnosed, cancer, 1991, admitted, Mayo Clini...
# 0  [diagnosed, cancer, 1991, admitted, Mayo Clini...
# 0  [diagnosed, cancer, 1991, admitted, Mayo Clini...
# 0  [diagnosed, cancer, 1991, admitted, Mayo Clini...
# 0  [diagnosed, cancer, 1991, admitted, Mayo Clini...
# 0  [diagnosed, cancer, 1991, admitted, Mayo Clini...
#
#                       entities_events_clinical_class  \
# 0  [OCCURRENCE, PROBLEM, DATE, OCCURRENCE, CLINIC...
# 0  [OCCURRENCE, PROBLEM, DATE, OCCURRENCE, CLINIC...
# 0  [OCCURRENCE, PROBLEM, DATE, OCCURRENCE, CLINIC...
# 0  [OCCURRENCE, PROBLEM, DATE, OCCURRENCE, CLINIC...
# 0  [OCCURRENCE, PROBLEM, DATE, OCCURRENCE, CLINIC...
# 0  [OCCURRENCE, PROBLEM, DATE, OCCURRENCE, CLINIC...
# 0  [OCCURRENCE, PROBLEM, DATE, OCCURRENCE, CLINIC...
# 0  [OCCURRENCE, PROBLEM, DATE, OCCURRENCE, CLINIC...
# 0  [OCCURRENCE, PROBLEM, DATE, OCCURRENCE, CLINIC...
# 0  [OCCURRENCE, PROBLEM, DATE, OCCURRENCE, CLINIC...
# 0  [OCCURRENCE, PROBLEM, DATE, OCCURRENCE, CLINIC...
# 0  [OCCURRENCE, PROBLEM, DATE, OCCURRENCE, CLINIC...
# 0  [OCCURRENCE, PROBLEM, DATE, OCCURRENCE, CLINIC...
# 0  [OCCURRENCE, PROBLEM, DATE, OCCURRENCE, CLINIC...
# 0  [OCCURRENCE, PROBLEM, DATE, OCCURRENCE, CLINIC...
# 0  [OCCURRENCE, PROBLEM, DATE, OCCURRENCE, CLINIC...
# 0  [OCCURRENCE, PROBLEM, DATE, OCCURRENCE, CLINIC...
# 0  [OCCURRENCE, PROBLEM, DATE, OCCURRENCE, CLINIC...
#
#                  entities_events_clinical_confidence relation_relation  \
# 0  [0.8962, 0.9419, 0.7578, 0.9965, 0.81165004, 0...            BEFORE
# 0  [0.8962, 0.9419, 0.7578, 0.9965, 0.81165004, 0...            BEFORE
# 0  [0.8962, 0.9419, 0.7578, 0.9965, 0.81165004, 0...            BEFORE
# 0  [0.8962, 0.9419, 0.7578, 0.9965, 0.81165004, 0...           OVERLAP
# 0  [0.8962, 0.9419, 0.7578, 0.9965, 0.81165004, 0...            BEFORE
# 0  [0.8962, 0.9419, 0.7578, 0.9965, 0.81165004, 0...           OVERLAP
# 0  [0.8962, 0.9419, 0.7578, 0.9965, 0.81165004, 0...           OVERLAP
# 0  [0.8962, 0.9419, 0.7578, 0.9965, 0.81165004, 0...            BEFORE
# 0  [0.8962, 0.9419, 0.7578, 0.9965, 0.81165004, 0...           OVERLAP
# 0  [0.8962, 0.9419, 0.7578, 0.9965, 0.81165004, 0...           OVERLAP
# 0  [0.8962, 0.9419, 0.7578, 0.9965, 0.81165004, 0...           OVERLAP
# 0  [0.8962, 0.9419, 0.7578, 0.9965, 0.81165004, 0...           OVERLAP
# 0  [0.8962, 0.9419, 0.7578, 0.9965, 0.81165004, 0...            BEFORE
# 0  [0.8962, 0.9419, 0.7578, 0.9965, 0.81165004, 0...           OVERLAP
# 0  [0.8962, 0.9419, 0.7578, 0.9965, 0.81165004, 0...            BEFORE
# 0  [0.8962, 0.9419, 0.7578, 0.9965, 0.81165004, 0...           OVERLAP
# 0  [0.8962, 0.9419, 0.7578, 0.9965, 0.81165004, 0...           OVERLAP
# 0  [0.8962, 0.9419, 0.7578, 0.9965, 0.81165004, 0...           OVERLAP
#
#   relation_relation_confidence relation_relation_entity1  \
# 0                    0.5220578                 diagnosed
# 0                    0.5257622                 diagnosed
# 0                    0.7286371                 diagnosed
# 0                   0.68805766                    cancer
# 0                     0.503832                    cancer
# 0                    0.5337672                    cancer
# 0                    0.6538015                    cancer
# 0                    0.6306291                    cancer
# 0                    0.6419974                      1991
# 0                    0.7710563                      1991
# 0                    0.6345041                      1991
# 0                   0.66277844                  admitted
# 0                   0.57481164                  admitted
# 0                   0.78253996               Mayo Clinic
# 0                    0.5491552               Mayo Clinic
# 0                   0.67014843               Mayo Clinic
# 0                   0.70321065                  May 2000
# 0                    0.5360404                discharged
#
#   relation_relation_entity1_class relation_relation_entity2  \
# 0                      OCCURRENCE                    cancer
# 0                      OCCURRENCE                  admitted
# 0                      OCCURRENCE                discharged
# 0                         PROBLEM                      1991
# 0                         PROBLEM                  admitted
# 0                         PROBLEM               Mayo Clinic
# 0                         PROBLEM                  May 2000
# 0                         PROBLEM                discharged
# 0                            DATE               Mayo Clinic
# 0                            DATE                  May 2000
# 0                            DATE              October 2001
# 0                      OCCURRENCE                  May 2000
# 0                      OCCURRENCE                discharged
# 0                   CLINICAL_DEPT                  May 2000
# 0                   CLINICAL_DEPT                discharged
# 0                   CLINICAL_DEPT              October 2001
# 0                            DATE              October 2001
# 0                      OCCURRENCE              October 2001
#
#   relation_relation_entity2_class  \
# 0                         PROBLEM
# 0                      OCCURRENCE
# 0                      OCCURRENCE
# 0                            DATE
# 0                      OCCURRENCE
# 0                   CLINICAL_DEPT
# 0                            DATE
# 0                      OCCURRENCE
# 0                   CLINICAL_DEPT
# 0                            DATE
# 0                            DATE
# 0                            DATE
# 0                      OCCURRENCE
# 0                            DATE
# 0                      OCCURRENCE
# 0                            DATE
# 0                            DATE
# 0                            DATE
#
#                                 word_embedding_glove
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...

# %% [markdown]
# #### [Extract relations between phenotypic abnormalities and diseases (ReDL)](https://nlp.johnsnowlabs.com/2021/02/04/redl_human_phenotype_gene_biobert_en.html)

# %%
import nlu 
nlu.load('en.med_ner.human_phenotype.gene_clinical en.relation.humen_phenotype_gene').predict("She has a retinal degeneration, hearing loss and renal failure, short stature, \
Mutations in the SH3PXD2B gene coding for the Tks4 protein are responsible for the autosomal recessive.", output_level='relation')
# Out:
# ner_human_phenotype_gene_clinical download started this may take some time.
# Approximate size to download 14 MB
# [OK!]
# redl_human_phenotype_gene_biobert download started this may take some time.
# Approximate size to download 383.4 MB
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
#                                             document  \
# 0  She has a retinal degeneration, hearing loss a...
# 0  She has a retinal degeneration, hearing loss a...
# 0  She has a retinal degeneration, hearing loss a...
# 0  She has a retinal degeneration, hearing loss a...
# 0  She has a retinal degeneration, hearing loss a...
# 0  She has a retinal degeneration, hearing loss a...
# 0  She has a retinal degeneration, hearing loss a...
# 0  She has a retinal degeneration, hearing loss a...
# 0  She has a retinal degeneration, hearing loss a...
# 0  She has a retinal degeneration, hearing loss a...
# 0  She has a retinal degeneration, hearing loss a...
# 0  She has a retinal degeneration, hearing loss a...
# 0  She has a retinal degeneration, hearing loss a...
# 0  She has a retinal degeneration, hearing loss a...
# 0  She has a retinal degeneration, hearing loss a...
#
#                             entities_human_phenotype  \
# 0  [retinal degeneration, hearing loss, renal fai...
# 0  [retinal degeneration, hearing loss, renal fai...
# 0  [retinal degeneration, hearing loss, renal fai...
# 0  [retinal degeneration, hearing loss, renal fai...
# 0  [retinal degeneration, hearing loss, renal fai...
# 0  [retinal degeneration, hearing loss, renal fai...
# 0  [retinal degeneration, hearing loss, renal fai...
# 0  [retinal degeneration, hearing loss, renal fai...
# 0  [retinal degeneration, hearing loss, renal fai...
# 0  [retinal degeneration, hearing loss, renal fai...
# 0  [retinal degeneration, hearing loss, renal fai...
# 0  [retinal degeneration, hearing loss, renal fai...
# 0  [retinal degeneration, hearing loss, renal fai...
# 0  [retinal degeneration, hearing loss, renal fai...
# 0  [retinal degeneration, hearing loss, renal fai...
#
#   entities_human_phenotype_class  \
# 0     [HP, HP, HP, HP, GENE, HP]
# 0     [HP, HP, HP, HP, GENE, HP]
# 0     [HP, HP, HP, HP, GENE, HP]
# 0     [HP, HP, HP, HP, GENE, HP]
# 0     [HP, HP, HP, HP, GENE, HP]
# 0     [HP, HP, HP, HP, GENE, HP]
# 0     [HP, HP, HP, HP, GENE, HP]
# 0     [HP, HP, HP, HP, GENE, HP]
# 0     [HP, HP, HP, HP, GENE, HP]
# 0     [HP, HP, HP, HP, GENE, HP]
# 0     [HP, HP, HP, HP, GENE, HP]
# 0     [HP, HP, HP, HP, GENE, HP]
# 0     [HP, HP, HP, HP, GENE, HP]
# 0     [HP, HP, HP, HP, GENE, HP]
# 0     [HP, HP, HP, HP, GENE, HP]
#
#                  entities_human_phenotype_confidence relation_relation  \
# 0  [0.75415003, 0.89845, 0.83535004, 0.98755, 1.0...                 0
# 0  [0.75415003, 0.89845, 0.83535004, 0.98755, 1.0...                 0
# 0  [0.75415003, 0.89845, 0.83535004, 0.98755, 1.0...                 0
# 0  [0.75415003, 0.89845, 0.83535004, 0.98755, 1.0...                 1
# 0  [0.75415003, 0.89845, 0.83535004, 0.98755, 1.0...                 1
# 0  [0.75415003, 0.89845, 0.83535004, 0.98755, 1.0...                 0
# 0  [0.75415003, 0.89845, 0.83535004, 0.98755, 1.0...                 0
# 0  [0.75415003, 0.89845, 0.83535004, 0.98755, 1.0...                 1
# 0  [0.75415003, 0.89845, 0.83535004, 0.98755, 1.0...                 1
# 0  [0.75415003, 0.89845, 0.83535004, 0.98755, 1.0...                 0
# 0  [0.75415003, 0.89845, 0.83535004, 0.98755, 1.0...                 1
# 0  [0.75415003, 0.89845, 0.83535004, 0.98755, 1.0...                 1
# 0  [0.75415003, 0.89845, 0.83535004, 0.98755, 1.0...                 1
# 0  [0.75415003, 0.89845, 0.83535004, 0.98755, 1.0...                 1
# 0  [0.75415003, 0.89845, 0.83535004, 0.98755, 1.0...                 1
#
#   relation_relation_confidence relation_relation_entity1  \
# 0                    0.9052638      retinal degeneration
# 0                   0.96042186      retinal degeneration
# 0                    0.9282169      retinal degeneration
# 0                   0.53137904      retinal degeneration
# 0                    0.5809548      retinal degeneration
# 0                   0.96309054              hearing loss
# 0                    0.7941067              hearing loss
# 0                   0.78562695              hearing loss
# 0                    0.9091281              hearing loss
# 0                    0.8859341             renal failure
# 0                    0.5636836             renal failure
# 0                    0.8232073             renal failure
# 0                   0.78578025             short stature
# 0                    0.8902422             short stature
# 0                   0.95104796                  SH3PXD2B
#
#   relation_relation_entity1_class relation_relation_entity2  \
# 0                              HP              hearing loss
# 0                              HP             renal failure
# 0                              HP             short stature
# 0                              HP                  SH3PXD2B
# 0                              HP       autosomal recessive
# 0                              HP             renal failure
# 0                              HP             short stature
# 0                              HP                  SH3PXD2B
# 0                              HP       autosomal recessive
# 0                              HP             short stature
# 0                              HP                  SH3PXD2B
# 0                              HP       autosomal recessive
# 0                              HP                  SH3PXD2B
# 0                              HP       autosomal recessive
# 0                            GENE       autosomal recessive
#
#   relation_relation_entity2_class  \
# 0                              HP
# 0                              HP
# 0                              HP
# 0                            GENE
# 0                              HP
# 0                              HP
# 0                              HP
# 0                            GENE
# 0                              HP
# 0                              HP
# 0                            GENE
# 0                              HP
# 0                            GENE
# 0                              HP
# 0                              HP
#
#                                 word_embedding_glove
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...
# 0  [[-0.21964989602565765, -0.2844458520412445, -...

# %% [markdown]
# #### [Extract relations between effects of using multiple drugs (ReDL)](https://nlp.johnsnowlabs.com/2021/02/04/redl_drug_drug_interaction_biobert_en.html)

# %%
nlu.load('en.med_ner.posology en.relation.drug_drug_interaction').predict("""When carbamazepine is withdrawn from the combination therapy, aripiprazole dose should then be reduced. \
If additional adrenergic drugs are to be administered by any route, \
they should be used with caution because the pharmacologically predictable sympathetic effects of Metformin may be potentiated""", output_level='relation')
# Out:
# ner_posology download started this may take some time.
# Approximate size to download 13.8 MB
# [OK!]
# redl_drug_drug_interaction_biobert download started this may take some time.
# Approximate size to download 383.4 MB
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
#                                             document  \
# 0  When carbamazepine is withdrawn from the combi...
# 0  When carbamazepine is withdrawn from the combi...
# 0  When carbamazepine is withdrawn from the combi...
# 0  When carbamazepine is withdrawn from the combi...
# 0  When carbamazepine is withdrawn from the combi...
# 0  When carbamazepine is withdrawn from the combi...
#
#                                    entities_posology  \
# 0  [carbamazepine, aripiprazole, adrenergic drugs...
# 0  [carbamazepine, aripiprazole, adrenergic drugs...
# 0  [carbamazepine, aripiprazole, adrenergic drugs...
# 0  [carbamazepine, aripiprazole, adrenergic drugs...
# 0  [carbamazepine, aripiprazole, adrenergic drugs...
# 0  [carbamazepine, aripiprazole, adrenergic drugs...
#
#     entities_posology_class       entities_posology_confidence  \
# 0  [DRUG, DRUG, DRUG, DRUG]  [0.9973, 0.9456, 0.73355, 0.9998]
# 0  [DRUG, DRUG, DRUG, DRUG]  [0.9973, 0.9456, 0.73355, 0.9998]
# 0  [DRUG, DRUG, DRUG, DRUG]  [0.9973, 0.9456, 0.73355, 0.9998]
# 0  [DRUG, DRUG, DRUG, DRUG]  [0.9973, 0.9456, 0.73355, 0.9998]
# 0  [DRUG, DRUG, DRUG, DRUG]  [0.9973, 0.9456, 0.73355, 0.9998]
# 0  [DRUG, DRUG, DRUG, DRUG]  [0.9973, 0.9456, 0.73355, 0.9998]
#
#   relation_relation relation_relation_confidence relation_relation_entity1  \
# 0         DDI-false                    0.9113702             carbamazepine
# 0         DDI-false                    0.8676392             carbamazepine
# 0         DDI-false                    0.7183167             carbamazepine
# 0         DDI-false                     0.919468              aripiprazole
# 0        DDI-effect                   0.67719287              aripiprazole
# 0        DDI-effect                   0.76084733          adrenergic drugs
#
#   relation_relation_entity1_class relation_relation_entity2  \
# 0                            DRUG              aripiprazole
# 0                            DRUG          adrenergic drugs
# 0                            DRUG                 Metformin
# 0                            DRUG          adrenergic drugs
# 0                            DRUG                 Metformin
# 0                            DRUG                 Metformin
#
#   relation_relation_entity2_class  \
# 0                            DRUG
# 0                            DRUG
# 0                            DRUG
# 0                            DRUG
# 0                            DRUG
# 0                            DRUG
#
#                                 word_embedding_glove
# 0  [[-0.06080734729766846, -0.2955009639263153, -...
# 0  [[-0.06080734729766846, -0.2955009639263153, -...
# 0  [[-0.06080734729766846, -0.2955009639263153, -...
# 0  [[-0.06080734729766846, -0.2955009639263153, -...
# 0  [[-0.06080734729766846, -0.2955009639263153, -...
# 0  [[-0.06080734729766846, -0.2955009639263153, -...

# %%
df = nlu.load('en.med_ner.jsl.wip.clinical.greedy en.relation').predict('MRI demonstrated infarction in the upper brain stem , left cerebellum and  right basil ganglia"', output_level='relation') 
df
# Out:
# jsl_ner_wip_greedy_clinical download started this may take some time.
# Approximate size to download 14.5 MB
# [OK!]
# redl_bodypart_direction_biobert download started this may take some time.
# Approximate size to download 383.4 MB
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
#                                             document  \
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
# 0  MRI demonstrated infarction in the upper brain...
#
#                                         entities_jsl  \
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
# 0  [MRI, infarction, upper, brain stem, left, cer...
#
#                                   entities_jsl_class  \
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
# 0  [Test, Disease_Syndrome_Disorder, Direction, I...
#
#                              entities_jsl_confidence relation_relation  \
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 1
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 1
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 0
# 0  [0.9991, 0.4823, 0.3457, 0.35735, 0.1791, 0.84...                 1
#
#   relation_relation_confidence relation_relation_entity1  \
# 0                   0.85597134                       MRI
# 0                    0.9804575                       MRI
# 0                    0.8249747                       MRI
# 0                    0.9636165                       MRI
# 0                    0.9405368                       MRI
# 0                    0.9595499                       MRI
# 0                   0.95838296                       MRI
# 0                   0.98808306                infarction
# 0                    0.6006562                infarction
# 0                   0.98814803                infarction
# 0                   0.97544575                infarction
# 0                    0.9879937                infarction
# 0                     0.967108                infarction
# 0                     0.999723                     upper
# 0                    0.9878605                     upper
# 0                   0.98925984                     upper
# 0                   0.99197376                     upper
# 0                    0.9906499                     upper
# 0                    0.8471937                brain stem
# 0                    0.9499055                brain stem
# 0                   0.94872344                brain stem
# 0                   0.80231595                brain stem
# 0                   0.99922395                      left
# 0                   0.98997074                      left
# 0                    0.9803618                      left
# 0                   0.98347455                cerebellum
# 0                    0.9885316                cerebellum
# 0                    0.9994967                     right
#
#   relation_relation_entity1_class relation_relation_entity2  \
# 0                            Test                infarction
# 0                            Test                     upper
# 0                            Test                brain stem
# 0                            Test                      left
# 0                            Test                cerebellum
# 0                            Test                     right
# 0                            Test             basil ganglia
# 0       Disease_Syndrome_Disorder                     upper
# 0       Disease_Syndrome_Disorder                brain stem
# 0       Disease_Syndrome_Disorder                      left
# 0       Disease_Syndrome_Disorder                cerebellum
# 0       Disease_Syndrome_Disorder                     right
# 0       Disease_Syndrome_Disorder             basil ganglia
# 0                       Direction                brain stem
# 0                       Direction                      left
# 0                       Direction                cerebellum
# 0                       Direction                     right
# 0                       Direction             basil ganglia
# 0     Internal_organ_or_component                      left
# 0     Internal_organ_or_component                cerebellum
# 0     Internal_organ_or_component                     right
# 0     Internal_organ_or_component             basil ganglia
# 0                       Direction                cerebellum
# 0                       Direction                     right
# 0                       Direction             basil ganglia
# 0     Internal_organ_or_component                     right
# 0     Internal_organ_or_component             basil ganglia
# 0                       Direction             basil ganglia
#
#   relation_relation_entity2_class  \
# 0       Disease_Syndrome_Disorder
# 0                       Direction
# 0     Internal_organ_or_component
# 0                       Direction
# 0     Internal_organ_or_component
# 0                       Direction
# 0     Internal_organ_or_component
# 0                       Direction
# 0     Internal_organ_or_component
# 0                       Direction
# 0     Internal_organ_or_component
# 0                       Direction
# 0     Internal_organ_or_component
# 0     Internal_organ_or_component
# 0                       Direction
# 0     Internal_organ_or_component
# 0                       Direction
# 0     Internal_organ_or_component
# 0                       Direction
# 0     Internal_organ_or_component
# 0                       Direction
# 0     Internal_organ_or_component
# 0     Internal_organ_or_component
# 0                       Direction
# 0     Internal_organ_or_component
# 0                       Direction
# 0     Internal_organ_or_component
# 0     Internal_organ_or_component
#
#                                 word_embedding_glove
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
# 0  [[0.30669355392456055, -0.18632292747497559, 0...
