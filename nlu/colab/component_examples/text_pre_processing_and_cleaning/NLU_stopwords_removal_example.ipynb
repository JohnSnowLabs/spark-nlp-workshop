# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/nlu/blob/master/examples/colab/component_examples/text_pre_processing_and_cleaning/NLU_stopwords_removal_example.ipynb)
#
# # Stopwords removal with NLU
#
# Stopwords refer to the most common words in a language.
#
# I. e.  'the, is, at, which,on' are stopwords which will be removed.
#
#
# # 1. Install Java and NLU

# %%
# !wget https://setup.johnsnowlabs.com/nlu/colab.sh -O - | bash
  

import nlu
# Out:
# --2021-05-01 23:22:51--  https://raw.githubusercontent.com/JohnSnowLabs/nlu/master/scripts/colab_setup.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1671 (1.6K) [text/plain]
# Saving to: ‘STDOUT’
#
# -                   100%[===================>]   1.63K  --.-KB/s    in 0s
#
# 2021-05-01 23:22:52 (33.4 MB/s) - written to stdout [1671/1671]
#
# Installing  NLU 3.0.0 with  PySpark 3.0.2 and Spark NLP 3.0.1 for Google Colab ...
#      |████████████████████████████████| 204.8MB 76kB/s
#      |████████████████████████████████| 153kB 43.2MB/s
#      |████████████████████████████████| 204kB 17.9MB/s
#      |████████████████████████████████| 204kB 43.4MB/s
# ...

# %% [markdown]
# ## 2. Load Model and remove stopwords from sample string

# %%
import nlu
pipe = nlu.load('stopwords')
pipe.predict('He was suprised by the diversity of NLU')
# Out:
# stopwords_en download started this may take some time.
# Approximate size to download 2.9 KB
# [OK!]
# sentence_detector_dl download started this may take some time.
# Approximate size to download 354.6 KB
# [OK!]
#                                   document  ...               stopword_less
# 0  He was suprised by the diversity of NLU  ...  [suprised, diversity, NLU]
#
# [1 rows x 4 columns]

# %% [markdown]
# # 4. Checkout the stopword models NLU has to offer for other languages than English!

# %%
nlu.print_all_model_kinds_for_action('stopwords')
# Out:
# For language <en> NLU provides the following Models :
# nlu.load('en.stopwords') returns Spark NLP model stopwords_en
# For language <fr> NLU provides the following Models :
# nlu.load('fr.stopwords') returns Spark NLP model stopwords_fr
# For language <de> NLU provides the following Models :
# nlu.load('de.stopwords') returns Spark NLP model stopwords_de
# For language <it> NLU provides the following Models :
# nlu.load('it.stopwords') returns Spark NLP model stopwords_it
# For language <pl> NLU provides the following Models :
# nlu.load('pl.stopwords') returns Spark NLP model stopwords_pl
# For language <pt> NLU provides the following Models :
# nlu.load('pt.stopwords') returns Spark NLP model stopwords_pt
# For language <ru> NLU provides the following Models :
# nlu.load('ru.stopwords') returns Spark NLP model stopwords_ru
# For language <af> NLU provides the following Models :
# nlu.load('af.stopwords') returns Spark NLP model stopwords_af
# ...

# %% [markdown]
# ## 4.1 Let's try German stopword removal!

# %%
nlu.load('stopwords').predict("Er war von der Vielfältigkeit des NLU Packets begeistert",output_level='token')
# Out:
# stopwords_en download started this may take some time.
# Approximate size to download 2.9 KB
# [OK!]
# sentence_detector_dl download started this may take some time.
# Approximate size to download 354.6 KB
# [OK!]
#             token                                      stopword_less
# 0              Er  [Er, war, von, der, Vielfältigkeit, des, NLU, ...
# 0             war  [Er, war, von, der, Vielfältigkeit, des, NLU, ...
# 0             von  [Er, war, von, der, Vielfältigkeit, des, NLU, ...
# 0             der  [Er, war, von, der, Vielfältigkeit, des, NLU, ...
# 0  Vielfältigkeit  [Er, war, von, der, Vielfältigkeit, des, NLU, ...
# 0             des  [Er, war, von, der, Vielfältigkeit, des, NLU, ...
# 0             NLU  [Er, war, von, der, Vielfältigkeit, des, NLU, ...
# 0         Packets  [Er, war, von, der, Vielfältigkeit, des, NLU, ...
# 0      begeistert  [Er, war, von, der, Vielfältigkeit, des, NLU, ...
