# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/nlu/blob/master/examples/collab/Text_Pre_Processing_and_Cleaning/NLU_Spellchecking_example.ipynb)
#
# # Detect sentences with NLU
#
# Detecting sentences is a common problen when working with text data.
# The NLU Sentence Detector will find the beginning and end of each sentence for every row in your dataset.
#
#
# ## 1. Install NLU and Java 8

# %%
import os
! apt-get update -qq > /dev/null   
# Install java
! apt-get install -y openjdk-8-jdk-headless -qq > /dev/null
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["PATH"] = os.environ["JAVA_HOME"] + "/bin:" + os.environ["PATH"]
! pip install nlu==1.0.2rc1  > /dev/null

# %% [markdown]
# # 2. Load the Sentence Detector and predict the sentences

# %%
import nlu
sentence_pipe = nlu.load('sentence_detector')
sentence_pipe.predict('NLU can detect things. Like beginning and endings of sentences. It can also do much more!', output_level ='sentence')
# Out:
# <class 'AttributeError'>
# type object 'NluError' has no attribute '__set_missing_model_attributes__'
# Something went wrong during loading and fitting the pipe. Check the other prints for more information and also verbose mode. Did you use a correct model reference?
# The NLU components could not be properly created. Please check previous print messages and Verbose mode for further info

# %% [markdown]
# # 3.  Lets configure our pipeline.
#
# By calling pipe.print_info() we can can see all configurable parameters for every component in this NLU pipeline.
# We can simply copy paste the outputs of print_info() and configure our pipe.

# %%
sentence_pipe.print_info()
# Out:
# Sorry something went wrong when building the pipeline. Please check verbose mode and your NLU reference.

# %% [markdown]
# # 3.1 Lets configure our Sentence Detector to only accept sentences of length minimum 5

# %%
sentence_pipe = nlu.load('sentence_detector')
sentence_pipe['sentence_detector'].setMinLength(5)
sentence_pipe.predict('NLU can detect things. Like beginning and endings of sentences. It can also do much more!', output_level ='sentence')
# Out:
# <class 'AttributeError'>
# type object 'NluError' has no attribute '__set_missing_model_attributes__'
# Something went wrong during loading and fitting the pipe. Check the other prints for more information and also verbose mode. Did you use a correct model reference?
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-04c5c36af40e> in <module>()
#       1 sentence_pipe = nlu.load('sentence_detector')
# ----> 2 sentence_pipe['sentence_detector'].setMinLength(5)
#       3 sentence_pipe.predict('NLU can detect things. Like beginning and endings of sentences. It can also do much more!', output_level ='sentence')
#
# TypeError: 'NluError' object is not subscriptable
