# %% [markdown]
# ### Colab Setup

# %%
! pip install -q johnsnowlabs

# %%
from johnsnowlabs import *

# After uploading your license run this to install all licensed Python Wheels and pre-download Jars the Spark Session JVM
nlp.install(refresh_install=True, force_browser = True)

# %%
import pandas as pd
from pyspark.sql.functions import *
from pyspark.ml import PipelineModel
from pyspark.sql import functions as F
import warnings
warnings.filterwarnings('ignore')

# Automatically load licenste data and start a session with all jars user has access to
spark = nlp.start()

# %% [markdown]
# # Analysis
# During this process of analysis, we will continue with `cf_industries_pages`` dataframe
#
# In this case, we don't know which page contains what information. We can use `FinanceBertForSequenceClassification` models to do Text Classification, in this case, at `Page` level.
#
# To check the Responsibility Reports page, we have specific models called `"finclf_augmented_esg"` and `"finclf_esg"`
#
# Let's import dataset and create generic classification pipeline

# %%
# !wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/finance-nlp/data/solution_accelerator_esg_and_rr/cf_industries_pages.parquet.zip
# Out:
# --2023-03-27 14:44:53--  https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/finance-nlp/data/solution_accelerator_esg_and_rr/cf_industries_pages.parquet.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 141300 (138K) [application/zip]
# Saving to: ‘cf_industries_pages.parquet.zip’
#
# cf_industries_pages 100%[===================>] 137.99K  --.-KB/s    in 0.004s
#
# 2023-03-27 14:44:53 (36.5 MB/s) - ‘cf_industries_pages.parquet.zip’ saved [141300/141300]

# %%
# !unzip cf_industries_pages.parquet.zip -d cf_industries_pages.parquet

# %%
def generic_clf_pipeline(model_name):
  document_assembler = nlp.DocumentAssembler() \
    .setInputCol('text') \
    .setOutputCol('document')

  tokenizer = nlp.Tokenizer() \
    .setInputCols(['document']) \
    .setOutputCol('token')

  sequenceClassifier = finance.BertForSequenceClassification.pretrained(model_name, "en", "finance/models")\
    .setInputCols(["document",'token'])\
    .setOutputCol("class")

  pipeline = nlp.Pipeline(stages=[
      document_assembler, 
      tokenizer,
      sequenceClassifier
  ])

  empty_data = spark.createDataFrame([[""]]).toDF("text")

  model = pipeline.fit(empty_data)

  return model

# %%
data = spark.read.parquet("./cf_industries_pages.parquet")

data.show()
# Out:
# +--------+--------------------+
# |page_num|                text|
# +--------+--------------------+
# |       1|CF Industries
# 202...|
# |       2|A Message from Ou...|
# |       3|OUR BUSINESS AND ...|
# |       4|ACCOUNTABILITY AN...|
# |       5|This report detai...|
# |       6|At CF Industries,...|
# |       7|AMMONIA’S ROLE IN...|
# |       8|(1) Other segment...|
# |       9|“We operate advan...|
# |      10|DIMENSIONS & KEY ...|
# |      11|1. Energy, Emissi...|
# |      12|Our four distinct...|
# |      13|Key Issues
#
# 1) ...|
# |      14|14) Product Desig...|
# |      15|Our intensive wor...|
# |      16|ESG Goals
# ENERGY,...|
# |      17|We are excited ab...|
# |      18| ▶ Supplier Scree...|
# |      19|Energy,
# Emission...|
# |      20|CF Industries bel...|
# +--------+--------------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import *
# We remove repeating text from all pages
data = data.withColumn('text', regexp_replace('text', 'Message from CEO About this Report About the Company Energy, Emissions & Climate ChangeOur Workplace & Communities Food Security & Product Stewardship Ethics & Governance Coalitions, Partnerships & Policy EngagementApproach to ESG & SustainabilityReporting & Data', ''))

data = data.withColumn('text', regexp_replace('text', '\n', ' '))

data = data.withColumn('text', regexp_replace('text', '▶', '\n▶'))

data.show(truncate = 200)
# Out:
# +--------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |page_num|                                                                                                                                                                                                    text|
# +--------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |       1|                                                                                                                                     CF Industries 2021  ESG Report 1CF INDUSTRIES  |  2021 ESG REPORT  |
# |       2|A Message from Our CEO To our Stakeholders: CF Industries made substantial progress in 2021  across the environmental, social, and governance  (ESG) dimensions that we believe are critical to  the ...|
# |       3|OUR BUSINESS AND STRATEGY At our core, CF Industries is a producer of ammonia.  For decades, we have used the Haber-Bosch process  to fix atmospheric nitrogen with hydrogen from  natural gas to pro...|
# |       4|ACCOUNTABILITY AND TRANSPARENCY Our strategy of accelerating the world’s transition  to clean energy is linked to a comprehensive set of  ESG goals. These commitments include a dramatic  reduction ...|
# |       5|This report details CF Industries’ progress and opportunities within key environmental, social,  and governance areas from January 1, 2021, to December 31, 2021. It covers the operations under  Com...|
# |       6|At CF Industries, our mission is to provide clean energy to feed and fuel  the world sustainably. With our employees focused on safe and reliable  operations, environmental stewardship, and discipl...|
# |       7|AMMONIA’S ROLE IN SOCIETY  CF Industries is a leading global manufacturer of  hydrogen and nitrogen products for clean energy,  fertilizer, emissions abatement, and other industrial  applications. ...|
# |       8|(1) Other segment products include DEF, urea liquor, nitric acid, aqua ammonia, and NPKs.  2021 2020 2019 Sales Volume (tons) Net Sales Sales Volume (tons) Net Sales Sales Volume (tons) Net Sales P...|
# |       9|“We operate advantaged, efficient,  and flexible manufacturing  complexes in the United States,  Canada, and the United Kingdom,  with our North American facilities  supported by an extensive stora...|
# |      10|DIMENSIONS & KEY ISSUES  As a result of the Company’s materiality assessment, CF Industries  has identified four distinct environmental, social, and governance  dimensions that are critical to the ...|
# |      11|1. Energy, Emissions & Climate Change (E)  CF Industries has established ambitious goals  related to decarbonizing the ammonia production  process. Our ability to achieve these goals will have  a m...|
# |      12|Our four distinct ESG dimensions are the result  of learnings from direct engagement with our  shareholders and other key stakeholders. CF  Industries believes in fostering open dialogue with  all ...|
# |      13|Key Issues    1) GHG Emissions are defined and calculated  according to methodologies consistent with the  Greenhouse Gas Protocol (GHGP). The Company  discloses Scope 1, Scope 2, and Scope 3 emiss...|
# |      14|14) Product Design for Use-Phase Efficiency centers  on the ability of end products to improve energy  efficiency, eliminate, or lower greenhouse gas  emissions, reduce raw materials consumption, i...|
# |      15|Our intensive work to identify four ESG dimensions  and 16 key issues that align with the UN SDGs  ultimately allowed us to develop a comprehensive  set of ESG goals for the Company in 2020. We use...|
# |      16|ESG Goals ENERGY, EMISSIONS & CLIMATE CHANGE
# ▶ During 2021, develop and prioritize a list of viable  GHG reduction capital projects
# ▶ Reduce total CO2 equivalent emissions by 25% per  ton of pr...|
# |      17|We are excited about our initial progress on our 2020  goals and continue to believe we can spur positive  change for our stakeholders.  We believe we are on track to meet our goal to reduce  our n...|
# |      18|
# ▶ Supplier Screening: During 2021, CF Industries bol- stered its supplier screening efforts by requesting  that the top 50% of our suppliers share information  about their ESG practices and appro...|
# |      19|Energy,  Emissions  & Climate  Change  KEY ISSUES
# ▶ GHG Emissions
# ▶ Energy Management
# ▶ Air Quality
# ▶ Climate Change
# ▶ Water Management UN SDGS Importance to CF Industries Ensure availabi...|
# |      20|CF Industries believes that it is critical to continue to  account for the risks and opportunities stemming  from climate change to ensure that our business, our  planet, and the communities where ...|
# +--------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# ## Using Text Classification to find Relevant Parts of the Document: `Environment`, `Social`, `Governance`
# To check the Responsibility Reports pages, we have a specific model called `"finclf_esg"` and `"finclf_augmented_esg"`
#
# Firstly, we use our `finclf_esg` classfication model to classify pages into three categories: `Environmental`, `Social`, `Governance`.

# %%
model_name = "finclf_esg"
result = generic_clf_pipeline(model_name).transform(data)
# Out:
# finclf_esg download started this may take some time.
# [OK!]

# %%
result = result.select("page_num", "text", "class.result")

# %%
result.show(20, truncate = 80)
# Out:
# +--------+--------------------------------------------------------------------------------+---------------+
# |page_num|                                                                            text|         result|
# +--------+--------------------------------------------------------------------------------+---------------+
# |       1|             CF Industries 2021  ESG Report 1CF INDUSTRIES  |  2021 ESG REPORT  |   [Governance]|
# |       2|A Message from Our CEO To our Stakeholders: CF Industries made substantial pr...|[Environmental]|
# |       3|OUR BUSINESS AND STRATEGY At our core, CF Industries is a producer of ammonia...|[Environmental]|
# |       4|ACCOUNTABILITY AND TRANSPARENCY Our strategy of accelerating the world’s tran...|[Environmental]|
# |       5|This report details CF Industries’ progress and opportunities within key envi...|[Environmental]|
# |       6|At CF Industries, our mission is to provide clean energy to feed and fuel  th...|[Environmental]|
# |       7|AMMONIA’S ROLE IN SOCIETY  CF Industries is a leading global manufacturer of ...|[Environmental]|
# |       8|(1) Other segment products include DEF, urea liquor, nitric acid, aqua ammoni...|[Environmental]|
# |       9|“We operate advantaged, efficient,  and flexible manufacturing  complexes in ...|[Environmental]|
# |      10|DIMENSIONS & KEY ISSUES  As a result of the Company’s materiality assessment,...|[Environmental]|
# |      11|1. Energy, Emissions & Climate Change (E)  CF Industries has established ambi...|[Environmental]|
# |      12|Our four distinct ESG dimensions are the result  of learnings from direct eng...|[Environmental]|
# |      13|Key Issues    1) GHG Emissions are defined and calculated  according to metho...|[Environmental]|
# |      14|14) Product Design for Use-Phase Efficiency centers  on the ability of end pr...|[Environmental]|
# |      15|Our intensive work to identify four ESG dimensions  and 16 key issues that al...|   [Governance]|
# |      16|ESG Goals ENERGY, EMISSIONS & CLIMATE CHANGE
# ▶ During 2021, develop and pri...|[Environmental]|
# |      17|We are excited about our initial progress on our 2020  goals and continue to ...|[Environmental]|
# |      18|
# ▶ Supplier Screening: During 2021, CF Industries bol- stered its supplier s...|       [Social]|
# |      19|Energy,  Emissions  & Climate  Change  KEY ISSUES
# ▶ GHG Emissions
# ▶ Energ...|[Environmental]|
# |      20|CF Industries believes that it is critical to continue to  account for the ri...|[Environmental]|
# +--------+--------------------------------------------------------------------------------+---------------+
# only showing top 20 rows

# %%
result.write.mode("overwrite").parquet("finclf_esg_result.parquet")

# %% [markdown]
# ## Using Text Classification to find Relevant Parts of the Document: ESG Text Classification
# Secondly, we will use `finclf_augmented_esg` model. This model classifes the Responsibility and ESG reports pages into 26 categories:
#
# `Business_Ethics`, `Data_Security`, `Access_And_Affordability`, `Business_Model_Resilience`, `Competitive_Behavior`, `Critical_Incident_Risk_Management`, `Customer_Welfare`, `Director_Removal`, `Employee_Engagement_Inclusion_And_Diversity`, `Employee_Health_And_Safety`, `Human_Rights_And_Community_Relations`, `Labor_Practices`, `Management_Of_Legal_And_Regulatory_Framework`, `Physical_Impacts_Of_Climate_Change`, `Product_Quality_And_Safety`, `Product_Design_And_Lifecycle_Management`, `Selling_Practices_And_Product_Labeling`, `Supply_Chain_Management`, `Systemic_Risk_Management`, `Waste_And_Hazardous_Materials_Management`, `Water_And_Wastewater_Management`, `Air_Quality`, `Customer_Privacy`, `Ecological_Impacts`, `Energy_Management`, `GHG_Emissions`

# %%
model_name = "finclf_augmented_esg"
result_esg = generic_clf_pipeline(model_name).transform(data)
# Out:
# finclf_augmented_esg download started this may take some time.
# [OK!]

# %%
result_esg.show()
# Out:
# +--------+--------------------+--------------------+--------------------+--------------------+
# |page_num|                text|            document|               token|               class|
# +--------+--------------------+--------------------+--------------------+--------------------+
# |       1|CF Industries 202...|[{document, 0, 66...|[{token, 0, 1, CF...|[{category, 0, 66...|
# |       2|A Message from Ou...|[{document, 0, 32...|[{token, 0, 0, A,...|[{category, 0, 32...|
# |       3|OUR BUSINESS AND ...|[{document, 0, 43...|[{token, 0, 2, OU...|[{category, 0, 43...|
# |       4|ACCOUNTABILITY AN...|[{document, 0, 51...|[{token, 0, 13, A...|[{category, 0, 51...|
# |       5|This report detai...|[{document, 0, 14...|[{token, 0, 3, Th...|[{category, 0, 14...|
# |       6|At CF Industries,...|[{document, 0, 11...|[{token, 0, 1, At...|[{category, 0, 11...|
# |       7|AMMONIA’S ROLE IN...|[{document, 0, 34...|[{token, 0, 8, AM...|[{category, 0, 34...|
# |       8|(1) Other segment...|[{document, 0, 27...|[{token, 0, 0, (,...|[{category, 0, 27...|
# |       9|“We operate advan...|[{document, 0, 58...|[{token, 0, 2, “W...|[{category, 0, 58...|
# |      10|DIMENSIONS & KEY ...|[{document, 0, 86...|[{token, 0, 9, DI...|[{category, 0, 86...|
# |      11|1. Energy, Emissi...|[{document, 0, 41...|[{token, 0, 0, 1,...|[{category, 0, 41...|
# |      12|Our four distinct...|[{document, 0, 37...|[{token, 0, 2, Ou...|[{category, 0, 37...|
# |      13|Key Issues    1) ...|[{document, 0, 49...|[{token, 0, 2, Ke...|[{category, 0, 49...|
# |      14|14) Product Desig...|[{document, 0, 30...|[{token, 0, 1, 14...|[{category, 0, 30...|
# |      15|Our intensive wor...|[{document, 0, 16...|[{token, 0, 2, Ou...|[{category, 0, 16...|
# |      16|ESG Goals ENERGY,...|[{document, 0, 36...|[{token, 0, 2, ES...|[{category, 0, 36...|
# |      17|We are excited ab...|[{document, 0, 53...|[{token, 0, 1, We...|[{category, 0, 53...|
# |      18|
# ▶ Supplier Scre...|[{document, 0, 28...|[{token, 2, 2, ▶,...|[{category, 0, 28...|
# |      19|Energy,  Emission...|[{document, 0, 36...|[{token, 0, 5, En...|[{category, 0, 36...|
# |      20|CF Industries bel...|[{document, 0, 24...|[{token, 0, 1, CF...|[{category, 0, 24...|
# +--------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
result_esg = result_esg.select("page_num", "text", "class.result")

# %%
result_esg.show(truncate = 80)
# Out:
# +--------+--------------------------------------------------------------------------------+----------------------------------------------+
# |page_num|                                                                            text|                                        result|
# +--------+--------------------------------------------------------------------------------+----------------------------------------------+
# |       1|             CF Industries 2021  ESG Report 1CF INDUSTRIES  |  2021 ESG REPORT  |[Management_Of_Legal_And_Regulatory_Framework]|
# |       2|A Message from Our CEO To our Stakeholders: CF Industries made substantial pr...|    [Waste_And_Hazardous_Materials_Management]|
# |       3|OUR BUSINESS AND STRATEGY At our core, CF Industries is a producer of ammonia...|    [Waste_And_Hazardous_Materials_Management]|
# |       4|ACCOUNTABILITY AND TRANSPARENCY Our strategy of accelerating the world’s tran...|                               [GHG_Emissions]|
# |       5|This report details CF Industries’ progress and opportunities within key envi...|[Management_Of_Legal_And_Regulatory_Framework]|
# |       6|At CF Industries, our mission is to provide clean energy to feed and fuel  th...|                           [Energy_Management]|
# |       7|AMMONIA’S ROLE IN SOCIETY  CF Industries is a leading global manufacturer of ...|    [Waste_And_Hazardous_Materials_Management]|
# |       8|(1) Other segment products include DEF, urea liquor, nitric acid, aqua ammoni...|    [Waste_And_Hazardous_Materials_Management]|
# |       9|“We operate advantaged, efficient,  and flexible manufacturing  complexes in ...|                           [Energy_Management]|
# |      10|DIMENSIONS & KEY ISSUES  As a result of the Company’s materiality assessment,...|                   [Business_Model_Resilience]|
# |      11|1. Energy, Emissions & Climate Change (E)  CF Industries has established ambi...|    [Waste_And_Hazardous_Materials_Management]|
# |      12|Our four distinct ESG dimensions are the result  of learnings from direct eng...|    [Waste_And_Hazardous_Materials_Management]|
# |      13|Key Issues    1) GHG Emissions are defined and calculated  according to metho...|                                 [Air_Quality]|
# |      14|14) Product Design for Use-Phase Efficiency centers  on the ability of end pr...|     [Product_Design_And_Lifecycle_Management]|
# |      15|Our intensive work to identify four ESG dimensions  and 16 key issues that al...|                        [Competitive_Behavior]|
# |      16|ESG Goals ENERGY, EMISSIONS & CLIMATE CHANGE
# ▶ During 2021, develop and pri...|             [Water_And_Wastewater_Management]|
# |      17|We are excited about our initial progress on our 2020  goals and continue to ...|             [Water_And_Wastewater_Management]|
# |      18|
# ▶ Supplier Screening: During 2021, CF Industries bol- stered its supplier s...|                     [Supply_Chain_Management]|
# |      19|Energy,  Emissions  & Climate  Change  KEY ISSUES
# ▶ GHG Emissions
# ▶ Energ...|             [Water_And_Wastewater_Management]|
# |      20|CF Industries believes that it is critical to continue to  account for the ri...|                                 [Air_Quality]|
# +--------+--------------------------------------------------------------------------------+----------------------------------------------+
# only showing top 20 rows

# %%
result_esg.write.mode("overwrite").parquet("finclf_augmented_esg_result.parquet")

# %% [markdown]
# # Continue you analysis
# Make sure you understand the contents of a Responsibilty Reports and what information can be extracted. In the following notebooks we are going to extract all of that information using Finance NLP

# %% [markdown]
# # You are ready to proceed to the 03 Named Entity Recognition notebook!

# %% [markdown]
# In next and the following notebooks you will use Finance NLP to extract information, more specifically:
# - `NER`: To extract up to 20 quantifiable entities, including KPI, from the Responsibility and ESG Reports of companies.;
# - `Table Extract` to get table from RR reports.
# - `Table Understanding`: to understand the tables using Financial Question-Answering model.
