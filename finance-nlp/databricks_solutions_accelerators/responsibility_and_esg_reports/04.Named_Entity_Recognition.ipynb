# %% [markdown]
# # Entity Extraction
# We read back our results of classification models. As you know in the previous step, we classified RR document pages with two clause models. `"finclf_esg"` model classifies the Responsibility and ESG reports pages into three categories: `Environmental`, `Social`, `Governance`. The `"finclf_augmented_esg"` model classifes the reports pages into 26 categories
#
# Now, we will apply our `finner_responsibility_reports` NER model to extract up to 20 quantifiable entities, including KPI, from the Responsibility and ESG reports pages.

# %% [markdown]
# ### Colab Setup

# %%
! pip install -q johnsnowlabs

# %%
from johnsnowlabs import *

# After uploading your license run this to install all licensed Python Wheels and pre-download Jars the Spark Session JVM
nlp.install(refresh_install=True, force_browser = True)

# %%
from johnsnowlabs import *

from pyspark.ml import PipelineModel
from pyspark.sql import functions as F

import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# Automatically load licenste data and start a session with all jars user has access to
spark = nlp.start()
# Out:
# 👌 Launched cpu optimized session with with: 🚀Spark-NLP==4.3.2, 💊Spark-Healthcare==4.3.2, running on ⚡ PySpark==3.1.2

# %% [markdown]
# ## Import the result of ESG models

# %%
# !wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/finance-nlp/data/solution_accelerator_esg_and_rr/finclf_esg_result.parquet.zip

# !wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/finance-nlp/data/solution_accelerator_esg_and_rr/finclf_augmented_esg_result.parquet.zip

# %%
# !unzip finclf_esg_result.parquet.zip -d finclf_esg_result.parquet

# !unzip finclf_augmented_esg_result.parquet.zip -d finclf_augmented_esg_result.parquet

# %% [markdown]
# # Let's start

# %%
data = spark.read.parquet("./finclf_augmented_esg_result.parquet")

data.show(truncate = 50)
# Out:
# +--------+--------------------------------------------------+----------------------------------------------+
# |page_num|                                              text|                                        result|
# +--------+--------------------------------------------------+----------------------------------------------+
# |       1|CF Industries 2021  ESG Report 1CF INDUSTRIES  ...|[Management_Of_Legal_And_Regulatory_Framework]|
# |       2|A Message from Our CEO To our Stakeholders: CF ...|    [Waste_And_Hazardous_Materials_Management]|
# |       3|OUR BUSINESS AND STRATEGY At our core, CF Indus...|    [Waste_And_Hazardous_Materials_Management]|
# |       4|ACCOUNTABILITY AND TRANSPARENCY Our strategy of...|                               [GHG_Emissions]|
# |       5|This report details CF Industries’ progress and...|[Management_Of_Legal_And_Regulatory_Framework]|
# |       6|At CF Industries, our mission is to provide cle...|                           [Energy_Management]|
# |       7|AMMONIA’S ROLE IN SOCIETY  CF Industries is a l...|    [Waste_And_Hazardous_Materials_Management]|
# |       8|(1) Other segment products include DEF, urea li...|    [Waste_And_Hazardous_Materials_Management]|
# |       9|“We operate advantaged, efficient,  and flexibl...|                           [Energy_Management]|
# |      10|DIMENSIONS & KEY ISSUES  As a result of the Com...|                   [Business_Model_Resilience]|
# |      11|1. Energy, Emissions & Climate Change (E)  CF I...|    [Waste_And_Hazardous_Materials_Management]|
# |      12|Our four distinct ESG dimensions are the result...|    [Waste_And_Hazardous_Materials_Management]|
# |      13|Key Issues    1) GHG Emissions are defined and ...|                                 [Air_Quality]|
# |      14|14) Product Design for Use-Phase Efficiency cen...|     [Product_Design_And_Lifecycle_Management]|
# |      15|Our intensive work to identify four ESG dimensi...|                        [Competitive_Behavior]|
# |      16|ESG Goals ENERGY, EMISSIONS & CLIMATE CHANGE
# ...|             [Water_And_Wastewater_Management]|
# |      17|We are excited about our initial progress on ou...|             [Water_And_Wastewater_Management]|
# |      18|
# ▶ Supplier Screening: During 2021, CF Industr...|                     [Supply_Chain_Management]|
# |      19|Energy,  Emissions  & Climate  Change  KEY ISSU...|             [Water_And_Wastewater_Management]|
# |      20|CF Industries believes that it is critical to c...|                                 [Air_Quality]|
# +--------+--------------------------------------------------+----------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# ## NER: Named Entity Recognition on Responsibility Reports Pages
# This is `finner_responsibility_reports`model pipeline.

# %%
document_assembler = nlp.DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")\

sentence_detector = nlp.SentenceDetector()\
    .setInputCols(["document"])\
    .setOutputCol("sentence")\

tokenizer = nlp.Tokenizer() \
    .setInputCols(["sentence"]) \
    .setOutputCol("token")\
    .setContextChars(['.', ',', ';', ':', '!', '?', '*', '(', ')', '-', '"', "'", "’", '%', '&', '>', '”', '“','▶'])

ner_model = finance.BertForTokenClassification.pretrained("finner_responsibility_reports", "en", "finance/models")\
    .setInputCols(["sentence", "token"])\
    .setOutputCol("ner")\
    .setCaseSensitive(True)\
    .setMaxSentenceLength(512)

ner_converter = nlp.NerConverter()\
    .setInputCols(["sentence", "token", "ner"])\
    .setOutputCol("ner_chunk")

pipeline =  nlp.Pipeline(stages=[
    document_assembler,
    sentence_detector,
    tokenizer,
    ner_model,
    ner_converter
])

empty_data = spark.createDataFrame([[""]]).toDF("text")

ner_model = pipeline.fit(empty_data)
# Out:
# finner_responsibility_reports download started this may take some time.
# [OK!]

# %% [markdown]
# Let's choose **page 16** as an example and continue with it. Its category is `Water_And_Wastewater_Management`

# %%
sample_data = data.filter(data.page_num == 16)

result = ner_model.transform(sample_data)

# %%
result.select(F.explode(F.arrays_zip(result.ner_chunk.result, result.ner_chunk.metadata)).alias("cols")) \
      .select(F.expr("cols['0']").alias("chunk"),
              F.expr("cols['1']['entity']").alias("ner_label"),
              F.expr("cols['1']['confidence']").alias("confidence")).show(100, truncate=False)
# Out:
# +------------------------------------+---------------------+----------+
# |chunk                               |ner_label            |confidence|
# +------------------------------------+---------------------+----------+
# |During 2021                         |DATE_PERIOD          |0.9993252 |
# |GHG                                 |ENVIRONMENTAL_KPI    |0.99813557|
# |CO2 equivalent                      |ENVIRONMENTAL_KPI    |0.915977  |
# |emissions                           |ENVIRONMENTAL_KPI    |0.9913143 |
# |25%                                 |PERCENTAGE           |0.9989867 |
# |per  ton of product                 |RELATIVE_METRIC      |0.9983778 |
# |by 2030                             |DATE_PERIOD          |0.9992966 |
# |2015                                |DATE_PERIOD          |0.9833939 |
# |Scope 3 emissions                   |ENVIRONMENTAL_KPI    |0.99981374|
# |10%                                 |PERCENTAGE           |0.9991741 |
# |by 2030                             |DATE_PERIOD          |0.9998578 |
# |2021                                |DATE_PERIOD          |0.9967447 |
# |carbon emissions                    |ENVIRONMENTAL_KPI    |0.9996411 |
# |by 2050                             |DATE_PERIOD          |0.99984074|
# |Sustainability  Accounting Standards|ESG_ROLE             |0.95444137|
# |During 2021                         |DATE_PERIOD          |0.99882543|
# |water                               |ENVIRONMENTAL_KPI    |0.99645597|
# |95%                                 |PERCENTAGE           |0.9994601 |
# |safety                              |SOCIAL_KPI           |0.97005814|
# |employees                           |PROFESSIONAL_GROUP   |0.99295723|
# |manufacturing                       |ENVIRONMENTAL_KPI    |0.99693507|
# |distribution                        |ENVIRONMENTAL_KPI    |0.98252344|
# |80%)                                |PERCENTAGE           |0.99958074|
# |inspections                         |SOCIAL_KPI           |0.9683696 |
# |90 days                             |DATE_PERIOD          |0.7210693 |
# |females                             |TARGET_GROUP         |0.9991558 |
# |persons of  color                   |TARGET_GROUP         |0.987771  |
# |leadership                          |PROFESSIONAL_GROUP   |0.9974948 |
# |director                            |PROFESSIONAL_GROUP   |0.99828684|
# |30%                                 |PERCENTAGE           |0.9995135 |
# |by end of 2025                      |DATE_PERIOD          |0.91376716|
# |38%                                 |PERCENTAGE           |0.99938196|
# |12/31/2021
# ▶                      |DATE_PERIOD          |0.6721128 |
# |underrepresented                    |TARGET_GROUP         |0.99596345|
# |employee                            |PROFESSIONAL_GROUP   |0.9963559 |
# |by end of 2021                      |DATE_PERIOD          |0.8844385 |
# |minority                            |TARGET_GROUP         |0.9915173 |
# |female                              |TARGET_GROUP         |0.9997305 |
# |communities                         |TARGET_GROUP         |0.8695828 |
# |responders                          |SOCIAL_KPI           |0.47922084|
# |communities                         |TARGET_GROUP         |0.91017306|
# |program                             |SOCIAL_KPI           |0.8564682 |
# |end of 2021                         |DATE_PERIOD          |0.9133491 |
# |paid                                |SOCIAL_KPI           |0.75892806|
# |time                                |SOCIAL_KPI           |0.9919767 |
# |off                                 |SOCIAL_KPI           |0.6518558 |
# |employees                           |PROFESSIONAL_GROUP   |0.9995098 |
# |volunteer                           |SOCIAL_KPI           |0.62805897|
# |communities                         |TARGET_GROUP         |0.95455205|
# |25%                                 |PERCENTAGE           |0.9993981 |
# |employee                            |PROFESSIONAL_GROUP   |0.9997265 |
# |participation                       |SOCIAL_KPI           |0.8617201 |
# |program                             |SOCIAL_KPI           |0.9967832 |
# |by the end of 2025                  |DATE_PERIOD          |0.9774887 |
# |90,000                              |AMOUNT               |0.99255675|
# |farmers                             |PROFESSIONAL_GROUP   |0.8815971 |
# |program                             |SOCIAL_KPI           |0.9993999 |
# |by  2023                            |DATE_PERIOD          |0.9996816 |
# |achieve                             |SOCIAL_ACTION        |0.6066138 |
# |60 million                          |AMOUNT               |0.99974704|
# |acres                               |ENVIRONMENTAL_UNIT   |0.99192595|
# |farmland                            |ENVIRONMENTAL_KPI    |0.9973602 |
# |by 2030                             |DATE_PERIOD          |0.9997989 |
# |certification                       |SOCIAL_KPI           |0.97630185|
# |certification                       |SOCIAL_KPI           |0.7526611 |
# |100%                                |PERCENTAGE           |0.9996413 |
# |manufacturing sites                 |ENVIRONMENTAL_KPI    |0.996472  |
# |by  2030                            |DATE_PERIOD          |0.99977237|
# |suppliers                           |TARGET_GROUP_BUSINESS|0.7568911 |
# |providers                           |PROFESSIONAL_GROUP   |0.98288554|
# |annually                            |RELATIVE_METRIC      |0.50600874|
# |50%                                 |PERCENTAGE           |0.9994685 |
# |procurement                         |ECONOMIC_KPI         |0.9975585 |
# |expenditures                        |ECONOMIC_KPI         |0.9812137 |
# |Annually                            |RELATIVE_METRIC      |0.9698139 |
# |100%                                |PERCENTAGE           |0.9996816 |
# |employees                           |PROFESSIONAL_GROUP   |0.9998083 |
# |trained                             |SOCIAL_ACTION        |0.99810964|
# |certify                             |SOCIAL_ACTION        |0.9971897 |
# |compliance                          |SOCIAL_KPI           |0.9965113 |
# |Annually                            |RELATIVE_METRIC      |0.97036487|
# |100%                                |PERCENTAGE           |0.99966496|
# |employees                           |PROFESSIONAL_GROUP   |0.99982435|
# |trained                             |SOCIAL_ACTION        |0.9982557 |
# |certify                             |SOCIAL_ACTION        |0.9957993 |
# |compliance                          |SOCIAL_KPI           |0.99407333|
# |Annually                            |RELATIVE_METRIC      |0.9480801 |
# |100%                                |PERCENTAGE           |0.99955165|
# |employees                           |PROFESSIONAL_GROUP   |0.9998196 |
# |trained                             |SOCIAL_ACTION        |0.99896634|
# |Annually                            |RELATIVE_METRIC      |0.95608956|
# |100%                                |PERCENTAGE           |0.9995911 |
# |employees                           |PROFESSIONAL_GROUP   |0.99980783|
# |trained                             |SOCIAL_ACTION        |0.99854666|
# |certify                             |SOCIAL_ACTION        |0.9823533 |
# |emission                            |ENVIRONMENTAL_KPI    |0.8636276 |
# |projects                            |SOCIAL_KPI           |0.7688228 |
# +------------------------------------+---------------------+----------+

# %%
res = result.collect()[0]

# %% [markdown]
# ### Visualize Results

# %%
ner_vis = nlp.viz.NerVisualizer()

visualiser = nlp.viz.NerVisualizer()

visualiser.display(res, label_col='ner_chunk', document_col='document')
# Out:
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">ESG Goals ENERGY, EMISSIONS & CLIMATE CHANGE  <br>▶ </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #993335"><span class="spark-nlp-display-entity-name">During 2021 </span><span class="spark-nlp-display-entity-type">DATE_PERIOD</span></span><span class="spark-nlp-display-others" style="background-color: white">, develop and prioritize a list of viable  </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #A4250E"><span class="spark-nlp-display-entity-name">GHG </span><span class="spark-nlp-display-entity-type">ENVIRONMENTAL_KPI</span></span><span class="spark-nlp-display-others" style="background-color: white"> reduction capital projects  <br>▶ Reduce total </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #A4250E"><span class="spark-nlp-display-entity-name">CO2 equivalent </span><span class="spark-nlp-display-entity-type">ENVIRONMENTAL_KPI</span></span><span class="spark-nlp-display-others" style="background-color: white"> </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #A4250E"><span class="spark-nlp-display-entity-name">emissions </span><span class="spark-nlp-display-entity-type">ENVIRONMENTAL_KPI</span></span><span class="spark-nlp-display-others" style="background-color: white"> by </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #809C23"><span class="spark-nlp-display-entity-name">25% </span><span class="spark-nlp-display-entity-type">PERCENTAGE</span></span><span class="spark-nlp-display-others" style="background-color: white"> </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #7F71BC"><span class="spark-nlp-display-entity-name">per  ton of product </span><span class="spark-nlp-display-entity-type">RELATIVE_METRIC</span></span><span class="spark-nlp-display-others" style="background-color: white"> </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #993335"><span class="spark-nlp-display-entity-name">by 2030 </span><span class="spark-nlp-display-entity-type">DATE_PERIOD</span></span><span class="spark-nlp-display-others" style="background-color: white"> (</span><span class="spark-nlp-display-entity-wrapper" style="background-color: #993335"><span class="spark-nlp-display-entity-name">2015 </span><span class="spark-nlp-display-entity-type">DATE_PERIOD</span></span><span class="spark-nlp-display-others" style="background-color: white"> baseline year)  <br>▶ Reduce </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #A4250E"><span class="spark-nlp-display-entity-name">Scope 3 emissions </span><span class="spark-nlp-display-entity-type">ENVIRONMENTAL_KPI</span></span><span class="spark-nlp-display-others" style="background-color: white"> by </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #809C23"><span class="spark-nlp-display-entity-name">10% </span><span class="spark-nlp-display-entity-type">PERCENTAGE</span></span><span class="spark-nlp-display-others" style="background-color: white"> </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #993335"><span class="spark-nlp-display-entity-name">by 2030 </span><span class="spark-nlp-display-entity-type">DATE_PERIOD</span></span><span class="spark-nlp-display-others" style="background-color: white"> (new  goal established in </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #993335"><span class="spark-nlp-display-entity-name">2021 </span><span class="spark-nlp-display-entity-type">DATE_PERIOD</span></span><span class="spark-nlp-display-others" style="background-color: white">)  <br>▶ Achieve net-zero </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #A4250E"><span class="spark-nlp-display-entity-name">carbon emissions </span><span class="spark-nlp-display-entity-type">E ...

# %% [markdown]
# ## Let's extract entities from result of finclf_esg model

# %%
data = spark.read.parquet("./finclf_esg_result.parquet")

data.show(30)
# Out:
# +--------+--------------------+---------------+
# |page_num|                text|         result|
# +--------+--------------------+---------------+
# |       1|CF Industries 202...|   [Governance]|
# |       2|A Message from Ou...|[Environmental]|
# |       3|OUR BUSINESS AND ...|[Environmental]|
# |       4|ACCOUNTABILITY AN...|[Environmental]|
# |       5|This report detai...|[Environmental]|
# |       6|At CF Industries,...|[Environmental]|
# |       7|AMMONIA’S ROLE IN...|[Environmental]|
# |       8|(1) Other segment...|[Environmental]|
# |       9|“We operate advan...|[Environmental]|
# |      10|DIMENSIONS & KEY ...|[Environmental]|
# |      11|1. Energy, Emissi...|[Environmental]|
# |      12|Our four distinct...|[Environmental]|
# |      13|Key Issues    1) ...|[Environmental]|
# |      14|14) Product Desig...|[Environmental]|
# |      15|Our intensive wor...|   [Governance]|
# |      16|ESG Goals ENERGY,...|[Environmental]|
# |      17|We are excited ab...|[Environmental]|
# |      18|
# ▶ Supplier Scre...|       [Social]|
# |      19|Energy,  Emission...|[Environmental]|
# |      20|CF Industries bel...|[Environmental]|
# |      21|GHG Emissions, En...|[Environmental]|
# |      22|+ -O O O O O H2H2...|[Environmental]|
# |      23|
# ▶ CF Industries...|[Environmental]|
# |      24|Air Quality, & En...|[Environmental]|
# |      25|Water Management ...|[Environmental]|
# |      26|Aqueduct Water Ri...|   [Governance]|
# |      27|IMPROVING WATER Q...|[Environmental]|
# |      28|Our  Workplaces  ...|       [Social]|
# |      29|UN SDGS Importanc...|[Environmental]|
# |      30|Workforce Health ...|       [Social]|
# +--------+--------------------+---------------+
# only showing top 30 rows

# %% [markdown]
# ### We get the page that includes `Social` information
# We get page 34 as an example

# %%
from pyspark.sql.functions import *

sample_data = data.filter(data.page_num == 34)

result = ner_model.transform(sample_data)

# %%
sample_data.show(truncate = 50)
# Out:
# +--------+--------------------------------------------------+--------+
# |page_num|                                              text|  result|
# +--------+--------------------------------------------------+--------+
# |      34|Two of our ESG goals are related to ID&E. The  ...|[Social]|
# +--------+--------------------------------------------------+--------+

# %%
result.select(F.explode(F.arrays_zip(result.ner_chunk.result, result.ner_chunk.metadata)).alias("cols")) \
      .select(F.expr("cols['0']").alias("chunk"),
              F.expr("cols['1']['entity']").alias("ner_label"),
              F.expr("cols['1']['confidence']").alias("confidence")).show(100, truncate=False)
# Out:
# +----------------+------------------+----------+
# |chunk           |ner_label         |confidence|
# +----------------+------------------+----------+
# |females         |TARGET_GROUP      |0.9997331 |
# |persons of color|TARGET_GROUP      |0.99637717|
# |leadership      |PROFESSIONAL_GROUP|0.99970853|
# |director        |PROFESSIONAL_GROUP|0.99915284|
# |30%             |PERCENTAGE        |0.9992818 |
# |by 2025         |DATE_PERIOD       |0.99955726|
# |underrepresented|TARGET_GROUP      |0.99945337|
# |employee        |PROFESSIONAL_GROUP|0.9996691 |
# |end of  2021    |DATE_PERIOD       |0.98864007|
# |hiring          |SOCIAL_KPI        |0.6323411 |
# |promotion       |SOCIAL_KPI        |0.547257  |
# |minority        |TARGET_GROUP      |0.99972713|
# |female          |TARGET_GROUP      |0.99984014|
# |December 2021   |DATE_PERIOD       |0.99864554|
# |38%             |PERCENTAGE        |0.99958694|
# |leadership      |PROFESSIONAL_GROUP|0.9997405 |
# |director        |PROFESSIONAL_GROUP|0.9992318 |
# |females         |TARGET_GROUP      |0.9997533 |
# |persons of color|TARGET_GROUP      |0.99821687|
# |2025            |DATE_PERIOD       |0.99706066|
# |coming years    |DATE_PERIOD       |0.7766551 |
# |March 2021      |DATE_PERIOD       |0.9704058 |
# |joined          |SOCIAL_ACTION     |0.72748744|
# |80+             |AMOUNT            |0.9997154 |
# |companies       |COUNTABLE_ITEM    |0.5279813 |
# |committing      |SOCIAL_ACTION     |0.9651312 |
# |sponsored       |SOCIAL_ACTION     |0.79608727|
# |underrepresented|TARGET_GROUP      |0.9990647 |
# |employee        |PROFESSIONAL_GROUP|0.9995012 |
# |2021            |DATE_PERIOD       |0.99622   |
# |college         |TARGET_GROUP      |0.80093056|
# |45%             |PERCENTAGE        |0.99938303|
# |workforce       |PROFESSIONAL_GROUP|0.99939513|
# |pay             |ECONOMIC_KPI      |0.93176275|
# |$127,000        |AMOUNT            |0.9986964 |
# |per year        |RELATIVE_METRIC   |0.9992348 |
# |operator        |PROFESSIONAL_GROUP|0.99770164|
# |three           |AMOUNT            |0.99723005|
# |2022            |DATE_PERIOD       |0.99764436|
# |24/7            |AMOUNT            |0.98703486|
# |employees       |PROFESSIONAL_GROUP|0.9976626 |
# |violations      |SOCIAL_KPI        |0.98335886|
# |concerns        |SOCIAL_KPI        |0.8518843 |
# +----------------+------------------+----------+

# %%
res = result.collect()[0]

# %% [markdown]
# ### Visualize Results

# %%
ner_vis = nlp.viz.NerVisualizer()

visualiser = nlp.viz.NerVisualizer()

visualiser.display(res, label_col='ner_chunk', document_col='document')
# Out:
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">Two of our ESG goals are related to ID&E. The  first is to increase representation of </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #635D39"><span class="spark-nlp-display-entity-name">females </span><span class="spark-nlp-display-entity-type">TARGET_GROUP</span></span><span class="spark-nlp-display-others" style="background-color: white"> and  </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #635D39"><span class="spark-nlp-display-entity-name">persons of color </span><span class="spark-nlp-display-entity-type">TARGET_GROUP</span></span><span class="spark-nlp-display-others" style="background-color: white"> in senior </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #144B51"><span class="spark-nlp-display-entity-name">leadership </span><span class="spark-nlp-display-entity-type">PROFESSIONAL_GROUP</span></span><span class="spark-nlp-display-others" style="background-color: white"> roles (</span><span class="spark-nlp-display-entity-wrapper" style="background-color: #144B51"><span class="spark-nlp-display-entity-name">director </span><span class="spark-nlp-display-entity-type">PROFESSIONAL_GROUP</span></span><span class="spark-nlp-display-others" style="background-color: white">  level and above) to </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #7541BA"><span class="spark-nlp-display-entity-name">30% </span><span class="spark-nlp-display-entity-type">PERCENTAGE</span></span><span class="spark-nlp-display-others" style="background-color: white"> </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #7F8A41"><span class="spark-nlp-display-entity-name">by 2025 </span><span class="spark-nlp-display-entity-type">DATE_PERIOD</span></span><span class="spark-nlp-display-others" style="background-color: white">. The second is to  implement a program to create additional pathways  to long-term professional growth for traditionally  </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #635D39"><span class="spark-nlp-display-entity-name">underrepresented </span><span class="spark-nlp-display-entity-type">TARGET_GROUP</span></span><span class="spark-nlp-display-others" style="background-color: white"> </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #144B51"><span class="spark-nlp-display-entity-name">employee </span><span class="spark-nlp-display-entity-type">PROFESSIONAL_GROUP</span></span><span class="spark-nlp-display-others" style="background-color: white"> groups by the </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #7F8A41"><span class="spark-nlp-display-entity-name">end of  2021 </span><span class="spark-nlp-display-entity-type">DATE_PERIOD</span></span><span class="spark-nlp-display-others" style="background-color: white">, in order to increase the </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #82C0C6"><span class="spark-nlp-display-entity-name">hiring </span><span class="spark-nlp-display-entity-type">SOCIAL_KPI</span></span><span class="spark-nlp-display-others" style="background-color: white"> and </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #82C0C6"><span class="spark-nlp-display-entity-name">promotion </span><span class="spark-nlp-display-entity-type">SOCIAL_KPI</span></span><span class="spark-nlp-display-others" style="background-color: white"> of  </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #635D39"><span class="spark-nlp-display-entity-name">minority </span><span class="spark-nlp-display-entity-type">TARGET_GROUP</span></span><span class="spark-nlp-display-others" style="background-color: white"> and </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #635D39"><span class="spark-nlp-display-en ...

# %% [markdown]
# # Now you can proceed to 05 Extract and Understand Table!
