# %% [markdown]
# # ICD-O Entity Resolution - version 2.4.6
#
# ## Example for ICD-O Entity Resolution Pipeline
# A common NLP problem in medical applications is to identify clinical entities with the snomed codes and also cancer specific entities with their ICD10CM codes and their ICDO histology behaviour.
#
# In this example we will use Spark-NLP to identify and resolve these entities using three ontologies: SNOMED, ICD10CM and ICD-O.
#
# Some cancer related clinical notes (taken from https://www.cancernetwork.com/case-studies):
# https://www.cancernetwork.com/case-studies/large-scrotal-mass-multifocal-intra-abdominal-retroperitoneal-and-pelvic-metastases
# https://oncology.medicinematters.com/lymphoma/chronic-lymphocytic-leukemia/case-study-small-b-cell-lymphocytic-lymphoma-and-chronic-lymphoc/12133054
# https://oncology.medicinematters.com/lymphoma/epidemiology/central-nervous-system-lymphoma/12124056
# https://oncology.medicinematters.com/lymphoma/case-study-cutaneous-t-cell-lymphoma/12129416
#
# Note 0: Desmoplastic small round cell tumor
# <div style="border:2px solid #747474; background-color: #e3e3e3; margin: 5px; padding: 10px">
# A 35-year-old African-American man was referred to our urology clinic by his primary care physician for consultation about a large left scrotal mass. The patient reported a 3-month history of left scrotal swelling that had progressively increased in size and was associated with mild left scrotal pain. He also had complaints of mild constipation, with hard stools every other day. He denied any urinary complaints. On physical examination, a hard paratesticular mass could be palpated in the left hemiscrotum extending into the left groin, separate from the left testicle, and measuring approximately 10 × 7 cm in size. A hard, lower abdominal mass in the suprapubic region could also be palpated in the midline. The patient was admitted urgently to the hospital for further evaluation with cross-sectional imaging and blood work.
#
# Laboratory results, including results of a complete blood cell count with differential, liver function tests, coagulation panel, and basic chemistry panel, were unremarkable except for a serum creatinine level of 2.6 mg/dL. Typical markers for a testicular germ cell tumor were within normal limits: the beta–human chorionic gonadotropin level was less than 1 mIU/mL and the alpha fetoprotein level was less than 2.8 ng/mL. A CT scan of the chest, abdomen, and pelvis with intravenous contrast was obtained, and it showed large multifocal intra-abdominal, retroperitoneal, and pelvic masses (Figure 1). On cross-sectional imaging, a 7.8-cm para-aortic mass was visualized compressing the proximal portion of the left ureter, creating moderate left hydroureteronephrosis. Additionally, three separate pelvic masses were present in the retrovesical space, each measuring approximately 5 to 10 cm at their largest diameter; these displaced the bladder anteriorly and the rectum posteriorly.
#
# The patient underwent ultrasound-guided needle biopsy of one of the pelvic masses on hospital day 3 for definitive diagnosis. Microscopic examination of the tissue by our pathologist revealed cellular islands with oval to elongated, irregular, and hyperchromatic nuclei; scant cytoplasm; and invading fibrous tissue—as well as three mitoses per high-powered field (Figure 2). Immunohistochemical staining demonstrated strong positivity for cytokeratin AE1/AE3, vimentin, and desmin. Further mutational analysis of the cells detected the presence of an EWS-WT1 fusion transcript consistent with a diagnosis of desmoplastic small round cell tumor.
# </div>
#
# Note 1: SLL and CLL
# <div style="border:2px solid #747474; background-color: #e3e3e3; margin: 5px; padding: 10px">
# A 72-year-old man with a history of diabetes mellitus, hypertension, and hypercholesterolemia self-palpated a left submandibular lump in 2012. Complete blood count (CBC) in his internist’s office showed solitary leukocytosis (white count 22) with predominant lymphocytes for which he was referred to a hematologist. Peripheral blood flow cytometry on 04/11/12 confirmed chronic lymphocytic leukemia (CLL)/small lymphocytic lymphoma (SLL): abnormal cell population comprising 63% of CD45 positive leukocytes, co-expressing CD5 and CD23 in CD19-positive B cells. CD38 was negative but other prognostic markers were not assessed at that time. The patient was observed regularly for the next 3 years and his white count trend was as follows: 22.8 (4/2012) --> 28.5 (07/2012) --> 32.2 (12/2012) --> 36.5 (02/2013) --> 42 (09/2013) --> 44.9 (01/2014) --> 75.8 (2/2015). His other counts stayed normal until early 2015 when he also developed anemia (hemoglobin [HGB] 10.9) although platelets remained normal at 215. He had been noticing enlargement of his cervical, submandibular, supraclavicular, and axillary lymphadenopathy for several months since 2014 and a positron emission tomography (PET)/computed tomography (CT) scan done in 12/2014 had shown extensive diffuse lymphadenopathy within the neck, chest, abdomen, and pelvis. Maximum standardized uptake value (SUV max) was similar to low baseline activity within the vasculature of the neck and chest. In the abdomen and pelvis, however, there was mild to moderately hypermetabolic adenopathy measuring up to SUV of 4. The largest right neck nodes measured up to 2.3 x 3 cm and left neck nodes measured up to 2.3 x 1.5 cm. His right axillary lymphadenopathy measured up to 5.5 x 2.6 cm and on the left measured up to 4.8 x 3.4 cm. Lymph nodes on the right abdomen and pelvis measured up to 6.7 cm and seemed to have some mass effect with compression on the urinary bladder without symptoms. He underwent a bone marrow biopsy on 02/03/15, which revealed hypercellular marrow (60%) with involvement by CLL (30%); flow cytometry showed CD38 and ZAP-70 positivity; fluorescence in situ hybridization (FISH) analysis showed 13q deletion/monosomy 13; IgVH was unmutated; karyotype was 46XY.
# </div>
#
# Note 2: CNS lymphoma
# <div style="border:2px solid #747474; background-color: #e3e3e3; margin: 5px; padding: 10px">
# A 56-year-old woman began to experience vertigo, headaches, and frequent falls. A computed tomography (CT) scan of the brain revealed the presence of a 1.6 x 1.6 x 2.1 cm mass involving the fourth ventricle (Figure 14.1). A gadolinium-enhanced magnetic resonance imaging (MRI) scan confirmed the presence of the mass, and a stereotactic biopsy was performed that demonstrated a primary central nervous system lymphoma (PCNSL) with a diffuse large B-cell histology. Complete blood count (CBC), lactate dehydrogenase (LDH), and beta-2-microglobulin were normal. Systemic staging with a positron emission tomography (PET)/CT scan and bone marrow biopsy showed no evidence of lymphomatous involvement outside the CNS. An eye exam and lumbar puncture showed no evidence of either ocular or leptomeningeal involvement.
# </div>
#
# Note 3: Cutaneous T-cell lymphoma
# <div style="border:2px solid #747474; background-color: #e3e3e3; margin: 5px; padding: 10px">
# An 83-year-old female presented with a progressing pruritic cutaneous rash that started 8 years ago. On clinical exam there were numerous coalescing, infiltrated, scaly, and partially crusted erythematous plaques distributed over her trunk and extremities and a large fungating ulcerated nodule on her right thigh covering 75% of her total body surface area (Figure 10.1). Lymphoma associated alopecia and a left axillary lymphadenopathy were also noted. For the past 3–4 months she reported fatigue, severe pruritus, night sweats, 20 pounds of weight loss, and loss of appetite.
# </div>

# %%
import sys, os, time, pandas as pd

from sparknlp.base import *
from sparknlp.annotator import *
from sparknlp_jsl.annotator import *
import pyspark.sql.functions as F
from pyspark.sql.types import StructType, StructField, StringType

pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_rows', 500)

# %%
import sparknlp_jsl
sparknlp_jsl.version()
# Out:
# '2.4.7'

# %%
spark = sparknlp_jsl.start("####")

# %% [markdown]
# ## Let's create a dataset with all four case studies

# %%
notes = []
notes.append("""A 35-year-old African-American man was referred to our urology clinic by his primary care physician for consultation about a large left scrotal mass. The patient reported a 3-month history of left scrotal swelling that had progressively increased in size and was associated with mild left scrotal pain. He also had complaints of mild constipation, with hard stools every other day. He denied any urinary complaints. On physical examination, a hard paratesticular mass could be palpated in the left hemiscrotum extending into the left groin, separate from the left testicle, and measuring approximately 10 × 7 cm in size. A hard, lower abdominal mass in the suprapubic region could also be palpated in the midline. The patient was admitted urgently to the hospital for further evaluation with cross-sectional imaging and blood work.
Laboratory results, including results of a complete blood cell count with differential, liver function tests, coagulation panel, and basic chemistry panel, were unremarkable except for a serum creatinine level of 2.6 mg/dL. Typical markers for a testicular germ cell tumor were within normal limits: the beta–human chorionic gonadotropin level was less than 1 mIU/mL and the alpha fetoprotein level was less than 2.8 ng/mL. A CT scan of the chest, abdomen, and pelvis with intravenous contrast was obtained, and it showed large multifocal intra-abdominal, retroperitoneal, and pelvic masses (Figure 1). On cross-sectional imaging, a 7.8-cm para-aortic mass was visualized compressing the proximal portion of the left ureter, creating moderate left hydroureteronephrosis. Additionally, three separate pelvic masses were present in the retrovesical space, each measuring approximately 5 to 10 cm at their largest diameter; these displaced the bladder anteriorly and the rectum posteriorly.
The patient underwent ultrasound-guided needle biopsy of one of the pelvic masses on hospital day 3 for definitive diagnosis. Microscopic examination of the tissue by our pathologist revealed cellular islands with oval to elongated, irregular, and hyperchromatic nuclei; scant cytoplasm; and invading fibrous tissue—as well as three mitoses per high-powered field (Figure 2). Immunohistochemical staining demonstrated strong positivity for cytokeratin AE1/AE3, vimentin, and desmin. Further mutational analysis of the cells detected the presence of an EWS-WT1 fusion transcript consistent with a diagnosis of desmoplastic small round cell tumor.""")
notes.append("""A 72-year-old man with a history of diabetes mellitus, hypertension, and hypercholesterolemia self-palpated a left submandibular lump in 2012. Complete blood count (CBC) in his internist’s office showed solitary leukocytosis (white count 22) with predominant lymphocytes for which he was referred to a hematologist. Peripheral blood flow cytometry on 04/11/12 confirmed chronic lymphocytic leukemia (CLL)/small lymphocytic lymphoma (SLL): abnormal cell population comprising 63% of CD45 positive leukocytes, co-expressing CD5 and CD23 in CD19-positive B cells. CD38 was negative but other prognostic markers were not assessed at that time. The patient was observed regularly for the next 3 years and his white count trend was as follows: 22.8 (4/2012) --> 28.5 (07/2012) --> 32.2 (12/2012) --> 36.5 (02/2013) --> 42 (09/2013) --> 44.9 (01/2014) --> 75.8 (2/2015). His other counts stayed normal until early 2015 when he also developed anemia (hemoglobin [HGB] 10.9) although platelets remained normal at 215. He had been noticing enlargement of his cervical, submandibular, supraclavicular, and axillary lymphadenopathy for several months since 2014 and a positron emission tomography (PET)/computed tomography (CT) scan done in 12/2014 had shown extensive diffuse lymphadenopathy within the neck, chest, abdomen, and pelvis. Maximum standardized uptake value (SUV max) was similar to low baseline activity within the vasculature of the neck and chest. In the abdomen and pelvis, however, there was mild to moderately hypermetabolic adenopathy measuring up to SUV of 4. The largest right neck nodes measured up to 2.3 x 3 cm and left neck nodes measured up to 2.3 x 1.5 cm. His right axillary lymphadenopathy measured up to 5.5 x 2.6 cm and on the left measured up to 4.8 x 3.4 cm. Lymph nodes on the right abdomen and pelvis measured up to 6.7 cm and seemed to have some mass effect with compression on the urinary bladder without symptoms. He underwent a bone marrow biopsy on 02/03/15, which revealed hypercellular marrow (60%) with involvement by CLL (30%); flow cytometry showed CD38 and ZAP-70 positivity; fluorescence in situ hybridization (FISH) analysis showed 13q deletion/monosomy 13; IgVH was unmutated; karyotype was 46XY.""")
notes.append("A 56-year-old woman began to experience vertigo, headaches, and frequent falls. A computed tomography (CT) scan of the brain revealed the presence of a 1.6 x 1.6 x 2.1 cm mass involving the fourth ventricle (Figure 14.1). A gadolinium-enhanced magnetic resonance imaging (MRI) scan confirmed the presence of the mass, and a stereotactic biopsy was performed that demonstrated a primary central nervous system lymphoma (PCNSL) with a diffuse large B-cell histology. Complete blood count (CBC), lactate dehydrogenase (LDH), and beta-2-microglobulin were normal. Systemic staging with a positron emission tomography (PET)/CT scan and bone marrow biopsy showed no evidence of lymphomatous involvement outside the CNS. An eye exam and lumbar puncture showed no evidence of either ocular or leptomeningeal involvement.") 
notes.append("An 83-year-old female presented with a progressing pruritic cutaneous rash that started 8 years ago. On clinical exam there were numerous coalescing, infiltrated, scaly, and partially crusted erythematous plaques distributed over her trunk and extremities and a large fungating ulcerated nodule on her right thigh covering 75% of her total body surface area (Figure 10.1). Lymphoma associated alopecia and a left axillary lymphadenopathy were also noted. For the past 3–4 months she reported fatigue, severe pruritus, night sweats, 20 pounds of weight loss, and loss of appetite.")

# Notes column names

docid_col         = "doc_id"
note_col          = "description"

data = spark.createDataFrame([(i,n.lower(),) for i,n in enumerate(notes)], 
                             StructType([StructField(docid_col, StringType()),
                                         StructField(note_col, StringType())]))

# %% [markdown]
# ## And let's build a SparkNLP pipeline with the following stages:
# - DocumentAssembler: Entry annotator for our pipelines; it creates the data structure for the Annotation Framework
# - SentenceDetector: Annotator to pragmatically separate complete sentences inside each document
# - Tokenizer: Annotator to separate sentences in tokens (generally words)
# - WordEmbeddings: Vectorization of word tokens, in this case using word embeddings trained from PubMed, ICD10 and other clinical resources.
# - ChunkEmbeddings: Aggregates the WordEmbeddings for each NER Chunk
# - Clinical NER + NerConverter: This annotators return Chunks related to generic clinical entities
# - BioNLP NER + NerConverter: This annotators return Chunks related to Cancer and Genetics diseases
# - SNOMED ChunkEntityResolver: Annotator that performs search for the KNNs, in this case trained from SNOMED CT Ontology.
# - ICD10CM Neoplasms ChunkEntityResolver: Annotator that performs search for the KNNs, in this case trained from ICD10CM codes from C000-D499 and R590-R599.
# - ICDO ChunkEntityResolver: Annotator that performs search for the KNNs, in this case trained from ICDO Histology Behavior.

# %%
#Language and Model Repository

models_language   = "en"
models_repository = "clinical/models"

# %%
# Embeddings Pretrained Model Name

embeddings_name   = "embeddings_clinical"

# Preparation and embeddings column names

doc_col           = "document"
sent_col          = "sentence"
token_col         = "token"
embeddings_col    = "embeddings"

# Usual preparation Annotators and Embeddings

docAssembler = DocumentAssembler().setInputCol(note_col).setOutputCol(doc_col)
sentenceDetector = SentenceDetector().setInputCols(doc_col).setOutputCol(sent_col)
tokenizer_chars = [",","\/"," ",".","|","@","#","%","&","\\$","\\[","\\]","\\(","\\)","\\-",";"]
tokenizer = Tokenizer().setSplitChars(tokenizer_chars)\
    .setInputCols(sent_col).setOutputCol(token_col)
embeddings = WordEmbeddingsModel.pretrained(embeddings_name, models_language, models_repository)\
    .setInputCols(sent_col, token_col)\
    .setOutputCol(embeddings_col)
# Out:
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]

# %%
# NER Pretrained Model Names

clinical_ner_name = "ner_clinical"
cancer_ner_name   = "ner_bionlp"

# NER Column Names

ner_clinical_col  = "ner_clinical"
ner_bio_col       = "ner_bio"

# Annotators responsible for the Cancer Genetics Entity Recognition task

clinicalNer = NerDLModel.pretrained(clinical_ner_name, models_language, models_repository)\
    .setInputCols(sent_col, token_col, embeddings_col)\
    .setOutputCol(ner_clinical_col)

bioNer = NerDLModel.pretrained(cancer_ner_name, models_language, models_repository)\
    .setInputCols(sent_col, token_col, embeddings_col)\
    .setOutputCol(ner_bio_col)
# Out:
# ner_clinical download started this may take some time.
# Approximate size to download 13.8 MB
# [OK!]
# ner_bionlp download started this may take some time.
# Approximate size to download 13.9 MB
# [OK!]

# %%
# Chunk column names

chunk_clinical_col = "chunk_clinical"
chunk_cancer_col   = "chunk_cancer"

#Converter annotators transform IOB tags into full chunks (sequence set of tokens) tagged with `entity` metadata

clinicalConverter = NerConverter().setInputCols(sent_col, token_col, ner_clinical_col)\
    .setOutputCol(chunk_clinical_col)
cancerConverter = NerConverter().setInputCols(sent_col, token_col, ner_bio_col)\
    .setOutputCol(chunk_cancer_col).setWhiteList(['Cancer']) # We whitelist just `Cancer` entities

# %%
# ChunkEmbeddings column names

chunk_embs_clinical_col = "chunk_embs_clinical"
chunk_embs_cancer_col   = "chunk_embs_cancer"

#ChunkEmbeddings annotators aggregate embeddings for each token in the chunk

clinicalChunkEmbeddings = ChunkEmbeddings()\
  .setInputCols(chunk_clinical_col, embeddings_col)\
  .setOutputCol(chunk_embs_clinical_col)
cancerChunkEmbeddings = ChunkEmbeddings()\
  .setInputCols(chunk_cancer_col, embeddings_col)\
  .setOutputCol(chunk_embs_cancer_col)

# %%
# ChunkTokenizer column names

chunk_token_clinical_col = "chunk_token_clinical"
chunk_token_cancer_col   = "chunk_token_cancer"

# ChunkTokenizer provides extra flexibility at the time of tokenizing a given chunk

clinicalChunkTokenizer = ChunkTokenizer().setSplitChars(tokenizer_chars)\
    .setInputCols(chunk_clinical_col).setOutputCol(chunk_token_clinical_col)
cancerChunkTokenizer = ChunkTokenizer().setSplitChars(tokenizer_chars)\
    .setInputCols(chunk_cancer_col).setOutputCol(chunk_token_cancer_col)

# %%
# Entity Resolution Pretrained Model Names

snomed_model_name           = "ensembleresolve_snomed_clinical"
icd10cm_model_name   = "chunkresolve_icd10cm_neoplasms_clinical"
icd_model_name              = "chunkresolve_icdo_clinical"

# Entity Resolution column Names

snomed_clinical_col  = "snomed_resolution"
icd10cm_col   = "icd10cm_resolution"
icdo_col      = "icdo_resolution" 

snomedResolver = EnsembleEntityResolverModel()\
    .pretrained(snomed_model_name, models_language, models_repository)\
    .setEnableJaccard(False).setEnableLevenshtein(True).setEnableJaroWinkler(True)\
    .setNeighbours(200).setAlternatives(10).setDistanceWeights([3,3,0,0,4,2])\
    .setExtramassPenalty(2.5).setPoolingStrategy("MAX").setConfidenceFunction("INVERSE")\
    .setInputCols(chunk_token_clinical_col, chunk_embs_clinical_col)\
    .setOutputCol(snomed_clinical_col)\
    
icd10cmResolver = ChunkEntityResolverModel\
    .pretrained(icd10cm_model_name, models_language, models_repository)\
    .setEnableLevenshtein(True)\
    .setNeighbours(200).setAlternatives(5).setDistanceWeights([1,4,1,0,0,3])\
    .setExtramassPenalty(2.5).setPoolingStrategy("MAX").setConfidenceFunction("INVERSE")\
    .setInputCols(chunk_token_cancer_col, chunk_embs_cancer_col)\
    .setOutputCol(icd10cm_col)

icdoResolver = ChunkEntityResolverModel\
    .pretrained(icd_model_name, models_language, models_repository)\
    .setEnableLevenshtein(True)\
    .setNeighbours(200).setAlternatives(5).setDistanceWeights([4,4,2,0,8,8])\
    .setExtramassPenalty(3).setPoolingStrategy("MAX").setConfidenceFunction("INVERSE")\
    .setInputCols(chunk_token_cancer_col, chunk_embs_cancer_col)\
    .setOutputCol(icdo_col)
# Out:
# ensembleresolve_snomed_clinical download started this may take some time.
# Approximate size to download 592.9 MB
# [OK!]
# chunkresolve_icd10cm_neoplasms_clinical download started this may take some time.
# Approximate size to download 20.4 MB
# [OK!]
# chunkresolve_icdo_clinical download started this may take some time.
# Approximate size to download 8.2 MB
# [OK!]

# %%
pipelineFull = Pipeline().setStages([
    docAssembler, 
    sentenceDetector, 
    tokenizer, 
    embeddings, 
    clinicalNer,
    bioNer,
    clinicalConverter,
    cancerConverter,
    clinicalChunkEmbeddings, 
    cancerChunkEmbeddings, 
    clinicalChunkTokenizer,
    cancerChunkTokenizer,
    snomedResolver,
    icd10cmResolver,
    icdoResolver
])

# %%
pipelineModelFull = pipelineFull.fit(data)

# %%
output = pipelineModelFull.transform(data).cache()

# %% [markdown]
# ## The last part of our pipeline are the **ChunkEntityResolvers**:
#
# ### EntityResolver:
# Trained on an augmented ICDO Dataset from JSL Data Market it provides histology codes resolution for the matched expressions. Other than providing the code in the "result" field it provides more metadata about the matching process:
#
# - all_k_results -> Sorted ResolverLabels in the top `alternatives` that match the distance `threshold`
# - all_k_resolutions -> Respective ResolverNormalized strings
# - all_k_confidences -> Respective normalized probabilities based in inverse distance valuesprobability
# - all_k_distances -> Respective distance values after aggregation
# - all_k_wmd_distances -> Respective WMD distance values (added if allDistancesMetadata==True)
# - all_k_tfidf_distances -> Respective TFIDF Cosine distance values (added if allDistancesMetadata==True)
# - all_k_jaccard_distances -> Respective Jaccard distance values (added if allDistancesMetadata==True)
# - all_k_sorensen_distances -> Respective SorensenDice distance values (added if allDistancesMetadata==True)
# - all_k_jaro_distances -> Respective JaroWinkler distance values (added if allDistancesMetadata==True)
# - all_k_levenshtein_distances -> Respective Levenshtein distance values (added if allDistancesMetadata==True)
# - target_text -> The actual searched string
# - resolved_text -> The top ResolverNormalized string
# - confidence -> Top probability
# - distance -> Top distance value
# - sentence -> Sentence index
# - chunk -> Chunk Index
# - token -> Token index

# %%
def quick_metadata_analysis(df, doc_field, chunk_field, code_fields):
    code_res_meta = ", ".join([f"{cf}.metadata" for cf in code_fields])
    expression = f"explode(arrays_zip({chunk_field}.begin, {chunk_field}.end, {chunk_field}.result, {chunk_field}.metadata, "+code_res_meta+")) as a"
    top_n_rest = [(f"float(a['{i+4}'].confidence) as {(cf.split('_')[0])}_conf",
                    f"arrays_zip(split(a['{i+4}'].all_k_results,':::'),split(a['{i+4}'].all_k_resolutions,':::')) as {cf.split('_')[0]+'_opts'}")
                    for i, cf in enumerate(code_fields)]
    top_n_rest_args = []
    for tr in top_n_rest:
        for t in tr:
            top_n_rest_args.append(t)
    return df.selectExpr(doc_field, expression) \
        .orderBy(docid_col, F.expr("a['0']"), F.expr("a['1']"))\
        .selectExpr(f"concat_ws('::',{doc_field},a['0'],a['1']) as coords", "a['2'] as chunk","a['3'].entity as entity", *top_n_rest_args)

# %%
snomed_analysis = \
quick_metadata_analysis(output, docid_col, chunk_clinical_col,[snomed_clinical_col]).toPandas()

# %%
cancer_analysis = \
quick_metadata_analysis(output, docid_col, chunk_cancer_col,[icd10cm_col, icdo_col]).toPandas()

# %%
snomed_analysis
# Out:
#             coords  \
# 0      0::123::147
# 1      0::192::212
# 2      0::223::253
# 3      0::279::300
# 4      0::329::345
# 5      0::353::363
# 6      0::396::413
# 7      0::419::438
# 8      0::441::466
# 9      0::621::673
# 10     0::768::785
# 11     0::808::814
# 12     0::820::829
# 13     0::873::899
# 14     0::906::939
# 15     0::942::958
# 16     0::965::985
# 17   0::1017::1040
# 18   0::1056::1070
# 19   0::1076::1103
# 20   0::1132::1174
# 21   0::1203::1229
# 22   0::1256::1324
# 23   0::1354::1402
# 24   0::1409::1427
# 25   0::1454::1460
# 26   0::1463::1487
# 27   0::1566::1600
# 28   0::1603::1644
# 29   0::1753::1790
# 30   0::1860::1872
# 31   0::1888::1900
# 32   0::1946::1982
# 33   0::2012::2027
# 34   0::2068::2088
# 35   0::2091::2105
# 36   0::2112::2137
# 37   0::2196::2223
# 38   0::2238::2254
# 39   0::2260::2288
# 40   0::2295::2300
# 41   0::2303::2342
# 42   0::2369::2396
# 43   0::2429::2463
# 44       1::36::66
# 45      1::73::132
# 46     1::143::162
# 47     1::203::236
# 48     1::247::269
# 49     1::316::346
# 50     1::370::397
# 51     1::411::430
# 52     1::439::462
# 53     1::496::524
# 54     1::530::558
# 55     1::583::606
# 56     1::700::714
# 57     1::864::879
# 58     1::935::950
# 59     1::975::983
# 60   1::1030::1088
# 61   1::1095::1118
# 62   1::1154::1183
# 63   1::1200::1209
# 64   1::1216::1219
# 65   1::1247::1323
# 66   1::1326::1367
# 67   1::1499::1542
# 68   1::1674::1707
# 69   1::1782::1824
# 70   1::1867::1882
# 71   1::1889::1922
# 72   1::1932::1939
# 73   1::1955::1974
# 74   1::2004::2023
# 75   1::2051::2053
# 76   1::2062::2075
# 77   1::2084::2087
# 78   1::2100::2109
# 79   1::2112::2145
# 80   1::2154::2161
# 81   1::2170::2172
# 82   1::2216::2224
# 83       2::40::57
# 84       2::64::77
# 85      2::80::100
# 86     2::107::123
# 87     2::150::211
# 88     2::222::269
# 89     2::277::280
# 90     2::308::315
# 91     2::322::342
# 92     2::376::416
# 93     2::431::462
# 94     2::465::484
# 95     2::493::513
# 96     2::560::575
# 97     2::582::611
# 98     2::622::625
# 99     2::631::648
# 100    2::672::711
# 101    2::714::724
# 102    2::730::744
# 103    2::768::810
# 104      3::37::73
# 105    3::104::116
# 106    3::129::167
# 107    3::174::211
# 108    3::260::312
# 109    3::330::362
# 110    3::373::380
# 111    3::393::400
# 112    3::406::436
# 113    3::492::515
# 114    3::524::529
# 115    3::545::555
# 116    3::562::577
#
#                                                                              chunk  \
# 0                                                        a large left scrotal mass
# 1                                                            left scrotal swelling
# 2                                                  progressively increased in size
# 3                                                           mild left scrotal pain
# 4                                                                mild constipation
# 5                                                                      hard stools
# 6                                                               urinary complaints
# 7                                                             physical examination
# 8                                                       a hard paratesticular mass
# 9                            a hard, lower abdominal mass in the suprapubic region
# 10                                                              further evaluation
# 11                                                                         imaging
# 12                                                                      blood work
# 13                                                     a complete blood cell count
# 14                                              differential, liver function tests
# 15                                                               coagulation panel
# 16                                                           basic chemistry panel
# 17                                                        a serum creatinine level
# 18                                                                 typical markers
# 19                                                    a testicular germ cell tumor
# 20                                     the beta–human chorionic gonadotropin level
# 21                                                     the alpha fetoprotein level
# 22           a ct scan of the chest, abdomen, and pelvis with intravenous contrast
# 23                               large multifocal intra-abdominal, retroperitoneal
# 24                                                             pelvic masses (figu
# 25                                                                         imaging
# 26                                                       a 7.8-cm para-aortic mass
# 27                                             moderate left hydroureteronephrosis
# 28                                      additionally, three separate pelvic masses
# 29                                          these displaced the bladder anteriorly
# 30                                                                   needle biopsy
# 31                                                                   pelvic masses
# 32                                           microscopic examination of the tissue
# 33                                                                cellular islands
# 34                                                           hyperchromatic nuclei
# 35                                                                 scant cytoplasm
# 36                                                      invading fibrous tissue—as
# 37                                                    immunohistochemical staining
# 38                                                               strong positivity
# 39                                                   cytokeratin ae1/ae3, vimentin
# 40                                                                          desmin
# 41                                        further mutational analysis of the cells
# 42                                                    an ews-wt1 fusion transcript
# 43                                             desmoplastic small round cell tumor
# 44                                                 diabetes mellitus, hypertension
# 45                    hypercholesterolemia self-palpated a left submandibular lump
# 46                                                            complete blood count
# 47                                              solitary leukocytosis (white count
# 48                                                         predominant lymphocytes
# 49                                                 peripheral blood flow cytometry
# 50                                                    chronic lymphocytic leukemia
# 51                                                            lymphocytic lymphoma
# 52                                                        abnormal cell population
# 53                                                   leukocytes, co-expressing cd5
# 54                                                   cd23 in cd19-positive b cells
# 55                                                        other prognostic markers
# 56                                                                 his white count
# 57                                                                his other counts
# 58                                                                anemia (hemoglob
# 59                                                                       platelets
# 60                     enlargement of his cervical, submandibular, supraclavicular
# 61                                                        axillary lymphadenopathy
# 62                                                  a positron emission tomography
# 63                                                                      tomography
# 64                                                                            scan
# 65   extensive diffuse lymphadenopathy within the neck, chest, abdomen, and pelvis
# 66                                      maximum standardized uptake value (suv max
# 67                                    mild to moderately hypermetabolic adenopathy
# 68                                              his right axillary lymphadenopathy
# 69                                     lymph nodes on the right abdomen and pelvis
# 70                                                                some mass effect
# 71                                              compression on the urinary bladder
# 72                                                                        symptoms
# 73                                                            a bone marrow biopsy
# 74                                                            hypercellular marrow
# 75                                                                             cll
# 76                                                                  flow cytometry
# 77                                                                            cd38
# 78                                                                      positivity
# 79                                              fluorescence in situ hybridization
# 80                                                                        analysis
# 81                                                                             13q
# 82                                                                       karyotype
# 83                                                              vertigo, headaches
# 84                                                                  frequent falls
# 85                                                           a computed tomography
# 86                                                               scan of the brain
# 87                  a 1.6 x 1.6 x 2.1 cm mass involving the fourth ventricle (figu
# 88                                a gadolinium-enhanced magnetic resonance imaging
# 89                                                                            scan
# 90                                                                        the mass
# 91                                                           a stereotactic biopsy
# 92                                       a primary central nervous system lymphoma
# 93                                                a diffuse large b-cell histology
# 94                                                            complete blood count
# 95                                                           lactate dehydrogenase
# 96                                                                systemic staging
# 97                                                  a positron emission tomography
# 98                                                                            scan
# 99                                                              bone marrow biopsy
# 100                                       lymphomatous involvement outside the cns
# 101                                                                    an eye exam
# 102                                                                lumbar puncture
# 103                                    either ocular or leptomeningeal involvement
# 104                                          a progressing pruritic cutaneous rash
# 105                                                                  clinical exam
# 106                                        numerous coalescing, infiltrated, scaly
# 107                                         partially crusted erythematous plaques
# 108                          a large fungating ulcerated nodule on her right thigh
# 109                                              her total body surface area (figu
# 110                                                                       lymphoma
# 111                                                                       alopecia
# 112                                                a left axillary lymphadenopathy
# 113                                                       fatigue, severe pruritus
# 114                                                                         sweats
# 115                                                                    weight loss
# 116                                                               loss of appetite
#
#       entity  snomed_conf  \
# 0    PROBLEM       0.2148
# 1    PROBLEM       0.6447
# 2    PROBLEM       1.0000
# 3    PROBLEM       0.8921
# 4    PROBLEM       0.9955
# 5    PROBLEM       1.0000
# 6    PROBLEM       0.5742
# 7       TEST       1.0000
# 8    PROBLEM       1.0000
# 9    PROBLEM       0.7964
# 10      TEST       1.0000
# 11      TEST       1.0000
# 12      TEST       0.9949
# 13      TEST       0.6899
# 14      TEST       1.0000
# 15      TEST       1.0000
# 16      TEST       1.0000
# 17      TEST       0.9877
# 18      TEST       0.6726
# 19   PROBLEM       0.9990
# 20      TEST       0.9901
# 21      TEST       0.9999
# 22      TEST       0.7441
# 23   PROBLEM       0.9727
# 24   PROBLEM       1.0000
# 25      TEST       1.0000
# 26   PROBLEM       1.0000
# 27   PROBLEM       0.9995
# 28   PROBLEM       1.0000
# 29   PROBLEM       1.0000
# 30      TEST       1.0000
# 31   PROBLEM       0.9353
# 32      TEST       0.7927
# 33   PROBLEM       1.0000
# 34   PROBLEM       0.6018
# 35   PROBLEM       0.9999
# 36   PROBLEM       1.0000
# 37      TEST       0.4233
# 38   PROBLEM       0.1105
# 39      TEST       0.9809
# 40      TEST       1.0000
# 41      TEST       1.0000
# 42   PROBLEM       0.5859
# 43   PROBLEM       1.0000
# 44   PROBLEM       0.9995
# 45   PROBLEM       0.9938
# 46      TEST       1.0000
# 47   PROBLEM       0.9994
# 48   PROBLEM       1.0000
# 49      TEST       0.7135
# 50   PROBLEM       0.4722
# 51   PROBLEM       1.0000
# 52   PROBLEM       0.9942
# 53      TEST       0.6836
# 54      TEST       1.0000
# 55      TEST       0.9903
# 56      TEST       0.7411
# 57      TEST       1.0000
# 58   PROBLEM       1.0000
# 59      TEST       1.0000
# 60   PROBLEM       0.9994
# 61   PROBLEM       1.0000
# 62      TEST       1.0000
# 63      TEST       0.3333
# 64      TEST       0.1000
# 65   PROBLEM       1.0000
# 66      TEST       0.9305
# 67   PROBLEM       0.9999
# 68   PROBLEM       0.9962
# 69   PROBLEM       1.0000
# 70   PROBLEM       0.9990
# 71   PROBLEM       0.9999
# 72   PROBLEM       0.1000
# 73      TEST       1.0000
# 74   PROBLEM       1.0000
# 75      TEST       0.2005
# 76      TEST       1.0000
# 77   PROBLEM       0.3414
# 78   PROBLEM       0.4387
# 79      TEST       1.0000
# 80      TEST       0.1000
# 81      TEST       0.6249
# 82      TEST       1.0000
# 83   PROBLEM       0.8690
# 84   PROBLEM       1.0000
# 85      TEST       0.9332
# 86      TEST       1.0000
# 87   PROBLEM       0.5938
# 88      TEST       0.9894
# 89      TEST       0.1000
# 90   PROBLEM       1.0000
# 91      TEST       1.0000
# 92   PROBLEM       1.0000
# 93   PROBLEM       1.0000
# 94      TEST       1.0000
# 95      TEST       0.2000
# 96      TEST       1.0000
# 97      TEST       1.0000
# 98      TEST       0.1000
# 99      TEST       1.0000
# 100  PROBLEM       1.0000
# 101     TEST       0.9947
# 102     TEST       1.0000
# 103  PROBLEM       0.9881
# 104  PROBLEM       1.0000
# 105     TEST       1.0000
# 106  PROBLEM       0.9909
# 107  PROBLEM       1.0000
# 108  PROBLEM       1.0000
# 109  PROBLEM       1.0000
# 110  PROBLEM       0.9568
# 111  PROBLEM       0.8236
# 112  PROBLEM       0.6610
# 113  PROBLEM       0.6904
# 114  PROBLEM       1.0000
# 115  PROBLEM       1.0000
# 116  PROBLEM       0.9981
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              snomed_opts
# 0                 [(10682271000119109, Mass of skin of left hand), (10692461000119101, Mass of skin of left thumb), (10682191000119102, Mass of skin of left foot), (10682231000119106, Mass of skin of left forearm), (15634751000119101, Mass of left ovary), (12240181000119103, Mass in left breast), (15748121000119108, Mass of joint of left foot), (13340001000004107, Mass of right submandibular region), (15744721000119103, Mass of joint of left hand), (15746361000119101, Mass of structure of left eye)]
# 1                                                                                                                   [(271687003, Swelling of scrotum), (762916009, Swelling of left foot), (15952141000119106, Left parotid gland swelling), (442648006, Swelling of left tonsil), (12242351000119109, Swelling of left arm), (438457000, Swelling of testicle), (441974004, Swelling of buttock), (341401000119104, Left conjunctival edema), (60728008, Swelling of abdomen), (15629941000119104, Left inguinal pain)]
# 2    [(771339005, Hyperzincaemia and hypercalprotectinaemia), (51978008, Head lag in the newborn (disorder)), (762459007, Disorder due to and following breast reduction), (81543006, Abnormal hard tissue formation in pulp (disorder)), (772791006, Age-related loss of skeletal muscle mass), (191290006, Hemorrhagic disorder due to increase in anti-8a), (191291005, Hemorrhagic disorder due to increase in anti-9a), (315252002, Changing shape of pigmented skin lesion (disorder)), (52139007, Volume exces...
# 3                                                                                                                         [(16675301000119100, Pain of left testicle), (316821000119105, Pain of left thigh), (15629941000119104, Left inguinal pain), (287047008, Pain in left leg), (722829006, Acute scrotal pain), (301368006, Left hypochondrial pain), (1076811000119109, Pain of left heel), (285387005, Left sided abdominal pain), (316751000119107, Pain in left foot), (316851000119102, Pain of left wrist)]
# 4                                                                                                                                                  [(111360009, Intractable constipation), (197118003, Functional constipation), (370218001, Mild asthma), (430097009, Spastic constipation), (331987008, Mild dietary indigestion), (409587002, Severe diarrhea), (426979002, Mild persistent asthma), (397543001, Mild visual impairment), (308853007, Mild stomach dysplasia), (427679007, Mild intermittent asthma)]
# 5                                                                                                                                                                                                                                         [(75295004, Hard stools), (398032003, Loose stools), (35064005, Black stools), (64412006, Red stools), (167609007, Green stools), (300328001, Liver hard), (27731006, Soft stool), (449181000124106, Seedy stool), (449201000124107, Creamy stool), (267058009, Stool floats)]
# 6                                                                                                                                                                 [(264832001, Urinary eosinophils), (5277004, Urinary casts), (38276004, Multiple complaints), (106102002, Abnormal urinary product), (7766007, Nebulous urine), (102850002, Urinary reducing substance), (703453009, Complaining of wooziness), (267022002, General symptom), (102840003, Urinary cast, erythrocyte), (102837003, Urinary cast, waxy)]
# 7                                                                             [(5880005, Physical examination), (410184003, Physical examination management), (438547004, Postoperative physical examination), (103740001, Periodic physical examination), (363003006, Cardiovascular physical examination), (410182004, Physical examination assessment), (116302003, Physical examination maneuver), (81375008, Physical assessment), (27032005, Rhinolaryngologic examination), (84728005, Neurological examination)]
# 8                                                                                                      [(6370001000004104, Mass of hard palate), (300848003, Observation of a mass), (102031000119109, Paratesticular mass (disorder)), (444905003, Mass of soft tissue), (69559004, Mass of retroperitoneal structure), (237047009, Tubo-ovarian mass), (74285003, Mass of pelvic structure), (440299000, Mass of thoracic structure), (15636651000119101, Mass in both breasts), (126806005, Neoplasm of hard palate)]
# 9    [(163293006, On examination - abdominal mass-very hard), (163307004, On examination - abdominal mass - lower border defined), (274745006, Localised swelling, mass and lump, lower limb), (312355005, On examination - left lower abdominal mass), (457321000124103, Mass in nipple region of right breast), (438512007, Abdominal rigidity of periumbilical region (finding)), (448772000, Mass of abdominal cavity structure (finding)), (201489002, Arthropathy in Behcet syndrome of the pelvic region and t...
# 10                                               [(182770003, Preanaesthesia evaluation), (165171009, Initial psychiatric evaluation), (225343006, Assessment of needs), (43038000, Cardiovascular examination and evaluation), (200619008, Comprehensive interview and evaluation), (203421005, Limited interview and evaluation), (363109007, Evaluation of test results), (453971000124106, Evaluation of pharmacogenetic result), (713132000, Assessment of drug use), (225378006, Ongoing assessment of behaviour)]
# 11                                                                                                                                                                                                                    [(363679005, Imaging), (372083001, Spleen imaging), (371575001, Tomographic imaging), (58920005, Carotid imaging), (274415007, Lymphatics imaging), (41747008, Bone imaging), (413815006, Chest imaging), (371576000, Video imaging), (258174001, Imaging guidance), (372079001, Adrenal imaging)]
# 12                                                                                                                                                                                                                    [(737376008, Uncongenial work), (224363007, In work), (160895006, Stopped work), (224467009, Demoted at work), (73438004, Out of work), (224464002, Redeployed at work), (224366004, In sheltered work), (224375002, In regular work), (224367008, On work experience), (160926000, Fit for work)]
# 13                                                                    [(117355001, Blood cell count, manual), (117356000, Blood cell count, automated), (26604007, Complete blood count), (43789009, Complete blood count without differential), (88308000, Blood cell count (procedure)), (767002, White blood cell count - observation), (165511009, Differential white blood cell count procedure), (104101007, Prolymphocyte count, blood), (103759004, Metamyelocyte count, blood), (104121008, Cell count, urine)]
# 14                                                                                           [(26958001, Liver function test), (23426006, Lung function tests), (270954007, Differential renal function), (736164009, Monitoring of liver function), (167197004, Digestive function tests), (167191003, Gastric function tests), (426345008, Complex lung function test), (252184007, Combined pituitary function test), (386550008, Radioisotope function study of liver), (167209002, Chem. metabolic function tests)]
# 15                                                                                                                                                      [(3116009, Blood coagulation panel), (16254007, Lipid panel), (29711001, Coagulation panel for thrombosis), (88291001, Obstetric panel), (54610007, Kidney panel), (35650009, Thyroid panel), (112922009, Coagulation of uterus), (252278002, Coagulation pathway screening), (395216006, Advanced coagulation studies), (86236002, Coagulation inhibitor test)]
# 40                                                                                                                                                                                                                     [(259987000, Cytokeratin), (48184006, Tropomyosin), (46583003, Actin), (405833006, Schwannomin), (710237002, Trihexosylceramide), (387280008, Hyaluronoglucosaminidase), (304270003, Cerebrosidase), (58652008, Glycoasparaginase), (69662009, Alpha actinin), (444056009, Cytokeratin antibody)]
# 41   [(201924001, Kashin-Bek disease of the hand), (287161001, Effects of the elements (disorder)), (414022008, Disorder of cellular component of blood), (84984002, Adjustment reaction with predominant disturbance of conduct), (201925000, Kashin-Bek disease of the pelvic region and thigh), (414023003, Disorder of cellular component of blood in newborn), (473262008, Second degree burn of multiple sites of neck), (211787009, Second degree burn of multiple sites of trunk), (92749008, Carcinoma in si...
# 42                                                             [(9730000, Fusion of ischiofemoral joint), (52998000, Fusion of pantalar joint), (443456009, Expression of comedone), (239546004, Spinal fusion in situ), (32359009, Chandler operation for hip fusion), (178805003, Reduction of spondylolisthesis and fusion), (55705006, Fixation of spine with fusion), (87193006, Fusion-stabilization and immobilization), (46379002, Intercarpal fusion (procedure)), (359895004, Radiocarpal fusion (procedure))]
# 43                                   [(128735004, Desmoplastic small round cell tumor), (82267002, Malignant tumor, small cell type), (13238004, Granular cell tumor, malignant), (64575004, Malignant lymphoma, small cell), (77870005, Interstitial cell tumor, malignant), (128778009, Malignant tenosynovial giant cell tumor), (18861007, Granulosa cell tumor, malignant), (128907008, Steroid cell tumor, malignant), (128643000, Somatostatin cell tumor, malignant), (9001003, Chondromatous giant cell tumor)]
# 44                                                           [(73211009, Diabetes mellitus), (8801005, Secondary diabetes mellitus), (49817004, Neonatal diabetes mellitus), (445260006, Posttransplant diabetes mellitus), (11687002, Gestational diabetes mellitus), (530558861000132104, Atypical diabetes mellitus), (783722008, Myopathy and diabetes mellitus), (10754881000119104, Diabetes mellitus in childbirth), (420422005, Ketoacidosis in diabetes mellitus), (703136005, Diabetes mellitus in remission)]
# 45   [(190774002, Hyperlipidemia, group A), (16675391000119106, Ultrasonography of left kidney abnormal), (16675351000119101, Ultrasonography of right kidney abnormal), (406016007, Left ovary not present in specimen), (406015006, Right ovary not present in specimen), (164873001, Electrocardiographic left ventricle hypertrophy (finding)), (302071006, Finding of sensation of thyroid gland), (164877000, Electrocardiographic right ventricular hypertrophy (finding)), (15634311000119103, Mammographic m...
# 46                                                                                                                   [(26604007, Complete blood count), (43789009, Complete blood count without differential), (88308000, Blood cell count), (104101007, Prolymphocyte count, blood), (104100008, Promyelocyte count, blood), (104103005, Myeloblast count, blood), (103759004, Metamyelocyte count, blood), (104099000, Myelocyte count, blood), (104102000, Blast count, blood), (391558003, Total white blood count)]
# 47                                                                         [(165513007, Differential white count abnormal), (165509000, White cell count abnormal), (165507003, White cell count normal), (165512002, Differential white cell count normal), (365632008, Finding of platelet count), (365601007, Finding of eosinophil count), (165408006, Full blood count abnormal), (165407001, Full blood count borderline), (234513007, Post-splenectomy leukocytosis), (63583004, Solitary aggregation (finding))]
# 48   [(93545005, Hodgkin paragranuloma of spleen), (118605002, Hodgkin lymphoma, nodular lymphocyte predominance), (363265005, Predominant humoral immune deficiency (disorder)), (363088000, Disorder involving basophils and mast cells), (449173006, Diffuse non-Hodgkin's lymphoma of tonsil), (448465000, Diffuse non-Hodgkin's lymphoma of testis), (277551008, Splenic lymphoma with villous lymphocytes (disorder)), (722955006, Chronic lymphoproliferative disorder of natural killer cells), (234534000, A...
# 49                                                                                              [(80810009, Regional blood flow study), (165090004, Arterial blood flow test), (14768001, Peripheral blood film examination), (64444005, Flow cytometry), (302779002, Blood flow tests), (165091000, Limb blood flow test), (44927006, Measurement of coronary blood flow), (104153004, Reticulocyte count, flow cytometry), (85817005, Flow cytometry, ploidy analysis), (12065009, Monitoring of coronary blood flow)]
# 50                                                     [(92812005, Chronic leukemia), (430338009, Smouldering chronic lymphocytic leukaemia), (92814006, Chronic lymphoid leukemia), (188745007, Chronic monocytic leukemia), (277549009, Chronic lymphocytic prolymphocytic leukemia syndrome), (21983002, Chronic lymphocytic thyroiditis), (91857003, Acute lymphoid leukemia), (277601005, Acute monocytoid leukemia), (278453007, Acute biphenotypic leukemia), (122951000119108, Lymphocytic leukemia in relapse)]
# 51                                                                                                                                                             [(302841002, Lymphocytic lymphoma), (404143002, Crosti's lymphoma), (765136002, Berti lymphoma), (307623001, Plasmacytic lymphoma), (109976000, Lymphoepithelioid lymphoma), (118617000, Burkitt lymphoma), (109962001, Nonfollicular lymphoma), (724648008, Plasmablastic lymphoma), (109965004, Lymphoblastic lymphoma), (269476000, Nodular lymphoma)]
# 52                                                                                                                                                           [(39266006, Abnormal cell), (125391008, Abnormal cell size), (116023004, Abnormal cell structure), (89615005, Abnormal blood cell), (12222001, Abnormal red blood cell), (24827003, Abnormal white blood cell), (726587004, Pelger Huet cell), (68425008, Abnormal megakaryocyte (cell)), (127565009, Abnormal macrophage (cell)), (45614000, Sézary cell)]
# 53                                                                                                                               [(770542008, Isochromosomy Yq), (25954009, Laryngismus paralyticus), (783016009, Infundibulo panhypophysitis), (783158009, Infundibulo neurohypophysitis), (18900005, Periporitis staphylogenes), (95505003, Micropunctum lacrimale), (784346006, Navajo neurohepatopathy), (449169008, Subchorial intervillitis), (431501000124109, Sialodochitis fibrinosa), (57337005, Steatopygia)]
# 54   [(126250003, Deglycerolised red blood cells, human), (787740006, Human protein C only product), (776183008, Hepatitis B surface antigen only product), (776887006, Neomycin and polymyxin B and pramocaine only product), (780237007, Polymyxin B only product in vaginal dose form), (780233006, Polymyxin B only product in cutaneous dose form), (780234000, Polymyxin B only product in ocular dose form), (778319001, Amphotericin B only product in cutaneous dose form), (780235004, Polymyxin B only pro...
# 55                                                                                                           [(246111003, Prognostic score (attribute)), (246515000, Use of skin marker), (246110002, Marker status (attribute)), (58091002, Independent of (attribute)), (72589006, With staging (attribute)), (263502005, Clinical course (attribute)), (263493007, Clinical status (attribute)), (246231009, Staging system (attribute)), (260835007, Staging type (attribute)), (278156009, ABO status (attribute))]
# 56                                                                                                                          [(391558003, Total white blood count), (767002, White blood cell count), (26604007, Complete blood count), (165550008, Myelocyte count procedure), (165552000, Myeloblast count procedure), (88308000, Blood cell count), (165511009, Differential white blood cell count), (165549008, Promyelocyte count procedure), (165551007, Metamyelocyte count), (270925001, Percentage cell count)]
# 57                                                                                                                                           [(104101007, Prolymphocyte count, blood), (103759004, Metamyelocyte count, blood), (104099000, Myelocyte count, blood), (250437009, Count of human cells), (104103005, Myeloblast count, blood), (104100008, Promyelocyte count, blood), (104102000, Blast count, blood), (104121008, Cell count, urine), (116713002, Cell count, semen), (414278000, FMC7 absolute count)]
# 58                                                                                                                                                                                                  [(271737000, Anemia), (83414005, Macrocytic anemia), (53165003, Megaloblastic anemia), (234349007, Microcytic anemia), (41841004, Sideroachrestic anemia), (80875006, Achylic anemia), (11503009, Relative anemia), (462166006, Fetal anemia), (59106005, Hypoproliferative anemia), (66612000, Nutritional anemia)]
# 59                                                                                                                                                                                                                               [(16378004, Platelets), (446569001, Microthrombus), (70310009, Schistocyte), (63599005, Acanthocyte), (19394005, Prolymphocyte), (52300009, Polychromasia), (25624002, Dysplastic platelet), (44687006, Giant platelet), (117294002, Platelet clumps), (250317006, Platelet satellite)]
# 60   [(405291003, Supraclavicular cervical sympathectomy (procedure)), (173490007, Excision of lesion of submandibular gland), (229410002, Accessory mobilisation of the cervical spine), (112718009, Excision of first AND cervical rib), (53103008, Excision of cervical lymph nodes group), (739129004, Total excision of right submandibular gland), (739128007, Total excision of left submandibular gland), (16339003, Incision of supraclavicular fossa with drainage), (739126006, Excision of right cervical...
# ...
# 86                                                                              [(41440006, Radioisotope scan of brain), (303781007, Contrast radiography of brain), (441986001, Imaging of brain), (39704007, Exploration of brain), (52808008, Removal of neuropacemaker of brain), (234915008, Marsupialisation of lesion of brain), (230886007, Exploration of ventricle of brain), (807005, Excision of tissue of brain), (62446008, Destruction of tissue of brain), (241471000, Ultrasound scan of native liver)]
# 87   [(10680231000119105, Mass of skin of left lower leg (finding)), (10682791000119101, Mass of skin of right lower leg (finding)), (10682751000119106, Mass of skin of right lower limb (finding)), (10680071000119103, Mass of subcutaneous tissue of right hand (finding)), (10682391000119100, Mass of subcutaneous tissue of left foot (finding)), (10682871000119105, Mass of subcutaneous tissue of right foot (finding)), (10679871000119109, Mass of subcutaneous tissue of left forearm (finding)), (10692...
# 88   [(113091000, Magnetic resonance imaging), (241663008, Vascular magnetic resonance imaging), (711304008, Magnetic resonance imaging proctography), (258177008, Magnetic resonance imaging guidance), (446186001, Forensic magnetic resonance imaging), (241631002, Magnetic resonance imaging pelvimetry), (713206003, Magnetic resonance imaging myelography), (419194002, Magnetic resonance imaging venography), (419275004, Magnetic resonance imaging urography), (241628003, Magnetic resonance imaging of ...
# 89                                                                                                                                                                                                                                  [(169229007, Booking scan), (16310003, Ultrasound scan), (105378004, Thallium scan), (41440006, Cerebral scan), (41747008, Bone scan), (241332004, Milk scan), (241354002, Kidney scan), (86924002, Gallium scan), (373205008, Isotope scan), (241450005, Midliner ultrasound scan)]
# 90                                                                                                                                                                                                  [(14160001000004107, Vallecular mass), (248521008, Mass of finger), (300523009, Mass of prepuce), (309531006, Mass of knee), (309530007, Mass of hilum), (28140001000004102, Mass of neurohypophysis), (309540005, Mass of shin), (441975003, Mass of tongue), (432525007, Mass of head), (297960002, Mass of skin)]
# 91                                                     [(171491002, Stereotactic biopsy of brain), (89311007, Jejunoscopy and biopsy), (445982009, Oesophagogastroduodenoscopy and biopsy), (59046001, Laryngotracheobronchoscopy with biopsy), (26058004, Thoracoscopy with biopsy), (274362004, Surgical biopsy of prostate), (184598004, Needle biopsy of brain), (236258004, Needle biopsy of prostate), (54899006, Stereotactic excisional biopsy of intracranial lesion), (214084009, Excisional biopsy of skull)]
# 92   [(307649006, Primary central nervous system lymphoma), (448254007, Non-Hodgkin's lymphoma of central nervous system), (733926004, Ganglioneuroblastoma of central nervous system), (147121000119104, Ependymoma of central nervous system), (449221001, Diffuse non-Hodgkin's lymphoma of central nervous system), (448995000, Follicular non-Hodgkin's lymphoma of central nervous system), (734099007, Neuroblastoma of central nervous system), (10706006, Tuberculosis of central nervous system), (14713100...
# 93   [(14742008, Structure of large intestine), (64575004, Malignant lymphoma, small cell diffuse), (125276008, Diffuse angiectasis (morphologic abnormality)), (399560003, Diffuse embryoma (morphologic abnormality)), (76319000, Diffuse necrosis (morphologic abnormality)), (397381007, Diffuse astrocytoma (morphologic abnormality)), (56229006, Diffuse infarct (morphologic abnormality)), (125569002, Diffuse fibromatosis (morphologic abnormality)), (125316002, Diffuse ulceration (morphologic abnormal...
# 94                                                                                                                   [(26604007, Complete blood count), (43789009, Complete blood count without differential), (88308000, Blood cell count), (104101007, Prolymphocyte count, blood), (104100008, Promyelocyte count, blood), (104103005, Myeloblast count, blood), (103759004, Metamyelocyte count, blood), (104099000, Myelocyte count, blood), (104102000, Blast count, blood), (391558003, Total white blood count)]
# 95                                                                                    [(63028001, Indolelactate dehydrogenase), (129941009, Isopiperitenol dehydrogenase), (7670009, Aminobutyraldehyde dehydrogenase), (55443005, Hydroxycyclohexanecarboxylate dehydrogenase), (58163007, Lactate dehydrogenase isoenzyme), (74997008, Glucose dehydrogenase), (130161001, Tauropine dehydrogenase), (6107003, Asparagusate dehydrogenase), (130154000, Pretyrosine dehydrogenase), (4239003, Glycerol dehydrogenase)]
# 96      [(706904009, TNM colon tumour staging), (258259005, is (tumor staging)), (254375000, Cotswolds Hodgkin disease tumor staging system), (258304009, Multisystem involvement (tumor staging)), (258284008, Stannards retinoblastoma stages (tumor staging)), (258232002, Cancer staging (tumor staging)), (254292007, Tumor staging (tumor staging)), (417957003, Uveal metastasis (tumor staging)), (261985008, No metastases (tumor staging)), (254370005, St Jude malignant histiocytosis tumor staging system)]
# 97   [(82918005, Positron emission tomography), (764666002, Positron emission tomography of brain), (416323006, Positron emission tomography breast study), (241439007, Positron emission tomography heart study), (450436003, Positron emission tomography with computed tomography), (16545811000119100, Positron emission tomography myocardial metabolism study), (105371005, Single photon emission computerized tomography), (241440009, Positron emission tomography myocardial glucose metabolism study), (43...
# 115                                                                                                                                                                   [(89362005, Weight loss), (359649009, Weight loss diet), (161832001, Progressive weight loss), (309257005, Excessive weight loss), (426977000, Recent weight loss), (416528001, Intentional weight loss), (448765001, Unintentional weight loss), (267024001, Abnormal weight loss), (422868009, Unexplained weight loss), (8943002, Weight gain)]
# 116                                                                                                                                                                      [(79890006, Loss of appetite), (405788002, Psychogenic loss of appetite), (289161009, Observation of appetite), (277521002, Loss of motivation), (247796005, Loss of pleasure), (282299006, Loss of balance), (45991007, Loss of emotion), (419045004, Loss of consciousness), (276306002, Loss of initiative), (162327005, Loss of judgement)]

# %%
cancer_analysis
# Out:
#           coords                                chunk  entity  icd10cm_conf  \
# 0    0::448::461                       paratesticular  Cancer        1.0000
# 1  0::1078::1103           testicular germ cell tumor  Cancer        1.0000
# 2  0::1632::1644                        pelvic masses  Cancer        0.4190
# 3  0::2429::2463  desmoplastic small round cell tumor  Cancer        0.2120
# 4    1::370::397         chronic lymphocytic leukemia  Cancer        1.0000
# 5    1::411::430                 lymphocytic lymphoma  Cancer        1.0000
# 6    2::386::416      central nervous system lymphoma  Cancer        0.4149
# 7    3::373::380                             lymphoma  Cancer        0.5000
# 8    3::408::436        left axillary lymphadenopathy  Cancer        0.7554
#
#                                                                                                                                                                                                                                                                                                                                                                icd10cm_opts  \
# 0  [(C6290, Malignant neoplasm of unspecified testis, unspecified whether descended or undescended), (D481, Neoplasm of uncertain behavior of connective and other soft tissue), (D480, Neoplasm of uncertain behavior of bone and articular cartilage), (C480, Malignant neoplasm of retroperitoneum), (C493, Malignant neoplasm of connective and soft tissue of thorax)]
# 1                                                                                [(C6290, Malignant neoplasm of unspecified testis, unspecified whether descended or undescended), (C801, Malignant (primary) neoplasm, unspecified), (C561, Malignant neoplasm of right ovary), (C562, Malignant neoplasm of left ovary), (C569, Malignant neoplasm of unspecified ovary)]
# 2                      [(C763, Malignant neoplasm of pelvis), (D3616, Benign neoplasm of peripheral nerves and autonomic nervous system of pelvis), (D3615, Benign neoplasm of peripheral nerves and autonomic nervous system of abdomen), (C481, Malignant neoplasm of specified parts of peritoneum), (C495, Malignant neoplasm of connective and soft tissue of pelvis)]
# 3                                                            [(C784, Secondary malignant neoplasm of small intestine), (C8307, Small cell B-cell lymphoma, spleen), (C801, Malignant (primary) neoplasm, unspecified), (C3491, Malignant neoplasm of unspecified part of right bronchus or lung), (C3492, Malignant neoplasm of unspecified part of left bronchus or lung)]
# 4                  [(C9110, Chronic lymphocytic leukemia of B-cell type not having achieved remission), (C9210, Chronic myeloid leukemia, BCR/ABL-positive, not having achieved remission), (C9310, Chronic myelomonocytic leukemia not having achieved remission), (C9102, Acute lymphoblastic leukemia, in relapse), (C9101, Acute lymphoblastic leukemia, in remission)]
# 5                                                                   [(C8350, Lymphoblastic (diffuse) lymphoma, unspecified site), (C8300, Small cell B-cell lymphoma, unspecified site), (C880, Waldenstrom macroglobulinemia), (C8143, Lymphocyte-rich Hodgkin lymphoma, intra-abdominal lymph nodes), (C8146, Lymphocyte-rich Hodgkin lymphoma, intrapelvic lymph nodes)]
# 6                         [(C8589, Other specified types of non-Hodgkin lymphoma, extranodal and solid organ sites), (C8380, Other non-follicular lymphoma, unspecified site), (C8387, Other non-follicular lymphoma, spleen), (C729, Malignant neoplasm of central nervous system, unspecified), (C8389, Other non-follicular lymphoma, extranodal and solid organ sites)]
# 7                                                 [(C8590, Non-Hodgkin lymphoma, unspecified, unspecified site), (C862, Enteropathy-type (intestinal) T-cell lymphoma), (C8580, Other specified types of non-Hodgkin lymphoma, unspecified site), (C8290, Follicular lymphoma, unspecified, unspecified site), (C8350, Lymphoblastic (diffuse) lymphoma, unspecified site)]
# 8          [(R590, Localized enlarged lymph nodes), (C50622, Malignant neoplasm of axillary tail of left male breast), (C8594, Non-Hodgkin lymphoma, unspecified, lymph nodes of axilla and upper limb), (C8514, Unspecified B-cell lymphoma, lymph nodes of axilla and upper limb), (C84A4, Cutaneous T-cell lymphoma, unspecified, lymph nodes of axilla and upper limb)]
#
#    icdo_conf  \
# 0     0.4685
# 1     0.4306
# 2     0.3418
# 3     1.0000
# 4     0.3443
# 5     0.2147
# 6     0.3507
# 7     0.5000
# 8     0.3171
#
#                                                                                                                                                                                                                                 icdo_opts
# 0                     [(9540/3, Malignant peripheral nerve sheath tumor), (9502/3, Teratoid medulloepithelioma), (9150/1, Hemangiopericytoma, NOS), (8815/3, Solitary fibrous tumor, malignant), (9150/3, Hemangiopericytoma, malignant)]
# 1                       [(9085/3, Mixed germ cell tumor), (9065/3, Germ cell tumor, nonseminomatous), (8621/3, Granulosa cell-theca cell tumor, mal.), (8650/3, Leydig cell tumor, malignant), (8620/3, Granulosa cell tumor, malignant)]
# 2                                                                     [(8312/3, Renal cell carcinoma), (8000/0, Neoplasm, benign), (9350/1, Craniopharyngioma), (9130/0, Hemangioendothelioma, benign), (8815/0, Solitary fibrous tumor)]
# 3  [(8806/3, Desmoplastic small round cell tumor), (8002/3, Malignant tumor, small cell type), (8003/3, Malignant tumor, giant cell type), (8005/3, Malignant tumor, clear cell type), (9252/3, Malignant tenosynovial giant cell tumor)]
# 4   [(9805/3, Acute biphenotypic leukemia), (9729/3, Precursor T-cell lymphoblastic lymphoma), (9946/3, Juvenile myelomonocytic leukemia), (9963/3, Chronic neutrophilic leukemia), (9835/3, Precursor cell lymphoblastic leukemia, NOS)]
# 5                               [(9764/3, Immunoproliferative small intestinal disease), (9673/3, Mantle cell lymphoma), (9761/3, Waldenstrom macroglobulinemia), (9701/3, Sezary syndrome), (9651/3, Hodgkin lymphoma, lymphocyte-rich)]
# 6                                       [(9501/3, Medulloepithelioma, NOS), (9350/1, Craniopharyngioma), (9475/3, Medulloblastoma, WNT-activated), (9477/3, Medulloblastoma, non-WNT/non-SHH), (9591/3, Malignant lymphoma, non-Hodgkin)]
# 7                             [(9591/3, Malignant lymphoma, non-Hodgkin), (9673/3, Mantle cell lymphoma), (9651/3, Hodgkin lymphoma, lymphocyte-rich), (9701/3, Sezary syndrome), (9764/3, Immunoproliferative small intestinal disease)]
# 8                                         [(8312/3, Renal cell carcinoma), (9705/3, Angioimmunoblastic T-cell lymphoma), (8000/0, Neoplasm, benign), (8000/3, Neoplasm, malignant), (9831/3, T-cell large granular lymphocytic leukemia)]
