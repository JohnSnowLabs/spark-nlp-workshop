# %% [markdown]
# # SNOMED-ICD-O Entity Resolution - version 2.4.6
#
# ## Example for ICD-O Entity Resolution Pipeline
# A common NLP problem in medical applications is to identify clinical entities with the snomed codes and also cancer specific entities with their ICD10CM codes and their ICDO histology behaviour.
#
# In this example we will use Spark-NLP to identify and resolve these entities using three ontologies: SNOMED, ICD10CM and ICD-O.
#
# Some cancer related clinical notes (taken from https://www.cancernetwork.com/case-studies):
# https://www.cancernetwork.com/case-studies/large-scrotal-mass-multifocal-intra-abdominal-retroperitoneal-and-pelvic-metastases
# https://oncology.medicinematters.com/lymphoma/chronic-lymphocytic-leukemia/case-study-small-b-cell-lymphocytic-lymphoma-and-chronic-lymphoc/12133054
# https://oncology.medicinematters.com/lymphoma/epidemiology/central-nervous-system-lymphoma/12124056
# https://oncology.medicinematters.com/lymphoma/case-study-cutaneous-t-cell-lymphoma/12129416
#
# Note 0: Desmoplastic small round cell tumor
# <div style="border:2px solid #747474; background-color: #e3e3e3; margin: 5px; padding: 10px">
# A 35-year-old African-American man was referred to our urology clinic by his primary care physician for consultation about a large left scrotal mass. The patient reported a 3-month history of left scrotal swelling that had progressively increased in size and was associated with mild left scrotal pain. He also had complaints of mild constipation, with hard stools every other day. He denied any urinary complaints. On physical examination, a hard paratesticular mass could be palpated in the left hemiscrotum extending into the left groin, separate from the left testicle, and measuring approximately 10 × 7 cm in size. A hard, lower abdominal mass in the suprapubic region could also be palpated in the midline. The patient was admitted urgently to the hospital for further evaluation with cross-sectional imaging and blood work.
#
# Laboratory results, including results of a complete blood cell count with differential, liver function tests, coagulation panel, and basic chemistry panel, were unremarkable except for a serum creatinine level of 2.6 mg/dL. Typical markers for a testicular germ cell tumor were within normal limits: the beta–human chorionic gonadotropin level was less than 1 mIU/mL and the alpha fetoprotein level was less than 2.8 ng/mL. A CT scan of the chest, abdomen, and pelvis with intravenous contrast was obtained, and it showed large multifocal intra-abdominal, retroperitoneal, and pelvic masses (Figure 1). On cross-sectional imaging, a 7.8-cm para-aortic mass was visualized compressing the proximal portion of the left ureter, creating moderate left hydroureteronephrosis. Additionally, three separate pelvic masses were present in the retrovesical space, each measuring approximately 5 to 10 cm at their largest diameter; these displaced the bladder anteriorly and the rectum posteriorly.
#
# The patient underwent ultrasound-guided needle biopsy of one of the pelvic masses on hospital day 3 for definitive diagnosis. Microscopic examination of the tissue by our pathologist revealed cellular islands with oval to elongated, irregular, and hyperchromatic nuclei; scant cytoplasm; and invading fibrous tissue—as well as three mitoses per high-powered field (Figure 2). Immunohistochemical staining demonstrated strong positivity for cytokeratin AE1/AE3, vimentin, and desmin. Further mutational analysis of the cells detected the presence of an EWS-WT1 fusion transcript consistent with a diagnosis of desmoplastic small round cell tumor.
# </div>
#
# Note 1: SLL and CLL
# <div style="border:2px solid #747474; background-color: #e3e3e3; margin: 5px; padding: 10px">
# A 72-year-old man with a history of diabetes mellitus, hypertension, and hypercholesterolemia self-palpated a left submandibular lump in 2012. Complete blood count (CBC) in his internist’s office showed solitary leukocytosis (white count 22) with predominant lymphocytes for which he was referred to a hematologist. Peripheral blood flow cytometry on 04/11/12 confirmed chronic lymphocytic leukemia (CLL)/small lymphocytic lymphoma (SLL): abnormal cell population comprising 63% of CD45 positive leukocytes, co-expressing CD5 and CD23 in CD19-positive B cells. CD38 was negative but other prognostic markers were not assessed at that time. The patient was observed regularly for the next 3 years and his white count trend was as follows: 22.8 (4/2012) --> 28.5 (07/2012) --> 32.2 (12/2012) --> 36.5 (02/2013) --> 42 (09/2013) --> 44.9 (01/2014) --> 75.8 (2/2015). His other counts stayed normal until early 2015 when he also developed anemia (hemoglobin [HGB] 10.9) although platelets remained normal at 215. He had been noticing enlargement of his cervical, submandibular, supraclavicular, and axillary lymphadenopathy for several months since 2014 and a positron emission tomography (PET)/computed tomography (CT) scan done in 12/2014 had shown extensive diffuse lymphadenopathy within the neck, chest, abdomen, and pelvis. Maximum standardized uptake value (SUV max) was similar to low baseline activity within the vasculature of the neck and chest. In the abdomen and pelvis, however, there was mild to moderately hypermetabolic adenopathy measuring up to SUV of 4. The largest right neck nodes measured up to 2.3 x 3 cm and left neck nodes measured up to 2.3 x 1.5 cm. His right axillary lymphadenopathy measured up to 5.5 x 2.6 cm and on the left measured up to 4.8 x 3.4 cm. Lymph nodes on the right abdomen and pelvis measured up to 6.7 cm and seemed to have some mass effect with compression on the urinary bladder without symptoms. He underwent a bone marrow biopsy on 02/03/15, which revealed hypercellular marrow (60%) with involvement by CLL (30%); flow cytometry showed CD38 and ZAP-70 positivity; fluorescence in situ hybridization (FISH) analysis showed 13q deletion/monosomy 13; IgVH was unmutated; karyotype was 46XY.
# </div>
#
# Note 2: CNS lymphoma
# <div style="border:2px solid #747474; background-color: #e3e3e3; margin: 5px; padding: 10px">
# A 56-year-old woman began to experience vertigo, headaches, and frequent falls. A computed tomography (CT) scan of the brain revealed the presence of a 1.6 x 1.6 x 2.1 cm mass involving the fourth ventricle (Figure 14.1). A gadolinium-enhanced magnetic resonance imaging (MRI) scan confirmed the presence of the mass, and a stereotactic biopsy was performed that demonstrated a primary central nervous system lymphoma (PCNSL) with a diffuse large B-cell histology. Complete blood count (CBC), lactate dehydrogenase (LDH), and beta-2-microglobulin were normal. Systemic staging with a positron emission tomography (PET)/CT scan and bone marrow biopsy showed no evidence of lymphomatous involvement outside the CNS. An eye exam and lumbar puncture showed no evidence of either ocular or leptomeningeal involvement.
# </div>
#
# Note 3: Cutaneous T-cell lymphoma
# <div style="border:2px solid #747474; background-color: #e3e3e3; margin: 5px; padding: 10px">
# An 83-year-old female presented with a progressing pruritic cutaneous rash that started 8 years ago. On clinical exam there were numerous coalescing, infiltrated, scaly, and partially crusted erythematous plaques distributed over her trunk and extremities and a large fungating ulcerated nodule on her right thigh covering 75% of her total body surface area (Figure 10.1). Lymphoma associated alopecia and a left axillary lymphadenopathy were also noted. For the past 3–4 months she reported fatigue, severe pruritus, night sweats, 20 pounds of weight loss, and loss of appetite.
# </div>

# %%
import sys, os, time, pandas as pd

from sparknlp.base import *
from sparknlp.annotator import *
from sparknlp_jsl.annotator import *
import pyspark.sql.functions as F
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType

pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_rows', 500)

# %%
import sparknlp_jsl
sparknlp_jsl.version()
# Out:
# '2.4.6'

# %%
spark = sparknlp_jsl.start("####")

# %% [markdown]
# ## Let's create a dataset with all four case studies

# %%
notes = []
notes.append("""A 35-year-old African-American man was referred to our urology clinic by his primary care physician for consultation about a large left scrotal mass. The patient reported a 3-month history of left scrotal swelling that had progressively increased in size and was associated with mild left scrotal pain. He also had complaints of mild constipation, with hard stools every other day. He denied any urinary complaints. On physical examination, a hard paratesticular mass could be palpated in the left hemiscrotum extending into the left groin, separate from the left testicle, and measuring approximately 10 × 7 cm in size. A hard, lower abdominal mass in the suprapubic region could also be palpated in the midline. The patient was admitted urgently to the hospital for further evaluation with cross-sectional imaging and blood work.
Laboratory results, including results of a complete blood cell count with differential, liver function tests, coagulation panel, and basic chemistry panel, were unremarkable except for a serum creatinine level of 2.6 mg/dL. Typical markers for a testicular germ cell tumor were within normal limits: the beta–human chorionic gonadotropin level was less than 1 mIU/mL and the alpha fetoprotein level was less than 2.8 ng/mL. A CT scan of the chest, abdomen, and pelvis with intravenous contrast was obtained, and it showed large multifocal intra-abdominal, retroperitoneal, and pelvic masses (Figure 1). On cross-sectional imaging, a 7.8-cm para-aortic mass was visualized compressing the proximal portion of the left ureter, creating moderate left hydroureteronephrosis. Additionally, three separate pelvic masses were present in the retrovesical space, each measuring approximately 5 to 10 cm at their largest diameter; these displaced the bladder anteriorly and the rectum posteriorly.
The patient underwent ultrasound-guided needle biopsy of one of the pelvic masses on hospital day 3 for definitive diagnosis. Microscopic examination of the tissue by our pathologist revealed cellular islands with oval to elongated, irregular, and hyperchromatic nuclei; scant cytoplasm; and invading fibrous tissue—as well as three mitoses per high-powered field (Figure 2). Immunohistochemical staining demonstrated strong positivity for cytokeratin AE1/AE3, vimentin, and desmin. Further mutational analysis of the cells detected the presence of an EWS-WT1 fusion transcript consistent with a diagnosis of desmoplastic small round cell tumor.""")
notes.append("""A 72-year-old man with a history of diabetes mellitus, hypertension, and hypercholesterolemia self-palpated a left submandibular lump in 2012. Complete blood count (CBC) in his internist’s office showed solitary leukocytosis (white count 22) with predominant lymphocytes for which he was referred to a hematologist. Peripheral blood flow cytometry on 04/11/12 confirmed chronic lymphocytic leukemia (CLL)/small lymphocytic lymphoma (SLL): abnormal cell population comprising 63% of CD45 positive leukocytes, co-expressing CD5 and CD23 in CD19-positive B cells. CD38 was negative but other prognostic markers were not assessed at that time. The patient was observed regularly for the next 3 years and his white count trend was as follows: 22.8 (4/2012) --> 28.5 (07/2012) --> 32.2 (12/2012) --> 36.5 (02/2013) --> 42 (09/2013) --> 44.9 (01/2014) --> 75.8 (2/2015). His other counts stayed normal until early 2015 when he also developed anemia (hemoglobin [HGB] 10.9) although platelets remained normal at 215. He had been noticing enlargement of his cervical, submandibular, supraclavicular, and axillary lymphadenopathy for several months since 2014 and a positron emission tomography (PET)/computed tomography (CT) scan done in 12/2014 had shown extensive diffuse lymphadenopathy within the neck, chest, abdomen, and pelvis. Maximum standardized uptake value (SUV max) was similar to low baseline activity within the vasculature of the neck and chest. In the abdomen and pelvis, however, there was mild to moderately hypermetabolic adenopathy measuring up to SUV of 4. The largest right neck nodes measured up to 2.3 x 3 cm and left neck nodes measured up to 2.3 x 1.5 cm. His right axillary lymphadenopathy measured up to 5.5 x 2.6 cm and on the left measured up to 4.8 x 3.4 cm. Lymph nodes on the right abdomen and pelvis measured up to 6.7 cm and seemed to have some mass effect with compression on the urinary bladder without symptoms. He underwent a bone marrow biopsy on 02/03/15, which revealed hypercellular marrow (60%) with involvement by CLL (30%); flow cytometry showed CD38 and ZAP-70 positivity; fluorescence in situ hybridization (FISH) analysis showed 13q deletion/monosomy 13; IgVH was unmutated; karyotype was 46XY.""")
notes.append("A 56-year-old woman began to experience vertigo, headaches, and frequent falls. A computed tomography (CT) scan of the brain revealed the presence of a 1.6 x 1.6 x 2.1 cm mass involving the fourth ventricle (Figure 14.1). A gadolinium-enhanced magnetic resonance imaging (MRI) scan confirmed the presence of the mass, and a stereotactic biopsy was performed that demonstrated a primary central nervous system lymphoma (PCNSL) with a diffuse large B-cell histology. Complete blood count (CBC), lactate dehydrogenase (LDH), and beta-2-microglobulin were normal. Systemic staging with a positron emission tomography (PET)/CT scan and bone marrow biopsy showed no evidence of lymphomatous involvement outside the CNS. An eye exam and lumbar puncture showed no evidence of either ocular or leptomeningeal involvement.") 
notes.append("An 83-year-old female presented with a progressing pruritic cutaneous rash that started 8 years ago. On clinical exam there were numerous coalescing, infiltrated, scaly, and partially crusted erythematous plaques distributed over her trunk and extremities and a large fungating ulcerated nodule on her right thigh covering 75% of her total body surface area (Figure 10.1). Lymphoma associated alopecia and a left axillary lymphadenopathy were also noted. For the past 3–4 months she reported fatigue, severe pruritus, night sweats, 20 pounds of weight loss, and loss of appetite.")

# Notes column names

docid_col         = "doc_id"
note_col          = "description"

data = spark.createDataFrame([(i,n.lower(),) for i,n in enumerate(notes)], 
                             StructType([StructField(docid_col, StringType()),
                                         StructField(note_col, StringType())]))

# %% [markdown]
# ## And let's build a SparkNLP pipeline with the following stages:
# - DocumentAssembler: Entry annotator for our pipelines; it creates the data structure for the Annotation Framework
# - SentenceDetector: Annotator to pragmatically separate complete sentences inside each document
# - Tokenizer: Annotator to separate sentences in tokens (generally words)
# - WordEmbeddings: Vectorization of word tokens, in this case using word embeddings trained from PubMed, ICD10 and other clinical resources.
# - ChunkEmbeddings: Aggregates the WordEmbeddings for each NER Chunk
# - Clinical NER + NerConverter: This annotators return Chunks related to generic clinical entities
# - BioNLP NER + NerConverter: This annotators return Chunks related to Cancer and Genetics diseases
# - SNOMED ChunkEntityResolver: Annotator that performs search for the KNNs, in this case trained from SNOMED CT Ontology.
# - ICD10CM Neoplasms ChunkEntityResolver: Annotator that performs search for the KNNs, in this case trained from ICD10CM codes from C000-D499 and R590-R599.
# - ICDO ChunkEntityResolver: Annotator that performs search for the KNNs, in this case trained from ICDO Histology Behavior.

# %%
#Language and Model Repository

models_language   = "en"
models_repository = "clinical/models"

# %%
# Embeddings Pretrained Model Name

embeddings_name   = "embeddings_clinical"

# Preparation and embeddings column names

doc_col           = "document"
sent_col          = "sentence"
token_col         = "token"
embeddings_col    = "embeddings"

# Usual preparation Annotators and Embeddings

docAssembler = DocumentAssembler().setInputCol(note_col).setOutputCol(doc_col)
sentenceDetector = SentenceDetector().setInputCols(doc_col).setOutputCol(sent_col)
tokenizer_chars = [",","\/"," ",".","|","@","#","%","&","\\$","\\[","\\]","\\(","\\)","\\-",";"]
tokenizer = Tokenizer().setSplitChars(tokenizer_chars)\
    .setInputCols(sent_col).setOutputCol(token_col)
embeddings = WordEmbeddingsModel.pretrained(embeddings_name, models_language, models_repository)\
    .setInputCols(sent_col, token_col)\
    .setOutputCol(embeddings_col)
# Out:
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]

# %%
# NER Pretrained Model Names

clinical_ner_name = "ner_clinical"
cancer_ner_name   = "ner_bionlp"

# NER Column Names

ner_clinical_col  = "ner_clinical"
ner_bio_col       = "ner_bio"

# Annotators responsible for the Cancer Genetics Entity Recognition task

clinicalNer = NerDLModel.pretrained(clinical_ner_name, models_language, models_repository)\
    .setInputCols(sent_col, token_col, embeddings_col)\
    .setOutputCol(ner_clinical_col)

bioNer = NerDLModel.pretrained(cancer_ner_name, models_language, models_repository)\
    .setInputCols(sent_col, token_col, embeddings_col)\
    .setOutputCol(ner_bio_col)
# Out:
# ner_clinical download started this may take some time.
# Approximate size to download 13.8 MB
# [OK!]
# ner_bionlp download started this may take some time.
# Approximate size to download 13.9 MB
# [OK!]

# %%
# Chunk column names

chunk_clinical_col = "chunk_clinical"
chunk_cancer_col   = "chunk_cancer"

#Converter annotators transform IOB tags into full chunks (sequence set of tokens) tagged with `entity` metadata

clinicalConverter = NerConverter().setInputCols(sent_col, token_col, ner_clinical_col)\
    .setOutputCol(chunk_clinical_col)
cancerConverter = NerConverter().setInputCols(sent_col, token_col, ner_bio_col)\
    .setOutputCol(chunk_cancer_col).setWhiteList(['Cancer']) # We whitelist just `Cancer` entities

# %%
# ChunkEmbeddings column names

chunk_embs_clinical_col = "chunk_embs_clinical"
chunk_embs_cancer_col   = "chunk_embs_cancer"

#ChunkEmbeddings annotators aggregate embeddings for each token in the chunk

clinicalChunkEmbeddings = ChunkEmbeddings()\
  .setInputCols(chunk_clinical_col, embeddings_col)\
  .setOutputCol(chunk_embs_clinical_col)
cancerChunkEmbeddings = ChunkEmbeddings()\
  .setInputCols(chunk_cancer_col, embeddings_col)\
  .setOutputCol(chunk_embs_cancer_col)

# %%
# ChunkTokenizer column names

chunk_token_clinical_col = "chunk_token_clinical"
chunk_token_cancer_col   = "chunk_token_cancer"

# ChunkTokenizer provides extra flexibility at the time of tokenizing a given chunk

clinicalChunkTokenizer = ChunkTokenizer().setSplitChars(tokenizer_chars)\
    .setInputCols(chunk_clinical_col).setOutputCol(chunk_token_clinical_col)
cancerChunkTokenizer = ChunkTokenizer().setSplitChars(tokenizer_chars)\
    .setInputCols(chunk_cancer_col).setOutputCol(chunk_token_cancer_col)

# %%
# Entity Resolution Pretrained Model Names

snomed_model_name           = "ensembleresolve_snomed_clinical"
icd10cm_model_name   = "chunkresolve_icd10cm_neoplasms_clinical"
icd_model_name              = "chunkresolve_icdo_clinical"

# Entity Resolution column Names

snomed_clinical_col  = "snomed_resolution"
icd10cm_col   = "icd10cm_resolution"
icdo_col      = "icdo_resolution" 

snomedResolver = EnsembleEntityResolverModel()\
    .pretrained(snomed_model_name, models_language, models_repository)\
    .setEnableJaccard(False).setEnableLevenshtein(True).setEnableJaroWinkler(True)\
    .setNeighbours(200).setAlternatives(10).setDistanceWeights([3,3,0,0,4,2])\
    .setExtramassPenalty(2.5)\
    .setInputCols(chunk_token_clinical_col, chunk_embs_clinical_col)\
    .setOutputCol(snomed_clinical_col)\
    
icd10cmResolver = ChunkEntityResolverModel\
    .pretrained(icd10cm_model_name, models_language, models_repository)\
    .setEnableLevenshtein(True)\
    .setNeighbours(200).setAlternatives(5).setDistanceWeights([1,4,1,0,0,3])\
    .setExtramassPenalty(2.5)\
    .setInputCols(chunk_token_cancer_col, chunk_embs_cancer_col)\
    .setOutputCol(icd10cm_col)

icdoResolver = ChunkEntityResolverModel\
    .pretrained(icd_model_name, models_language, models_repository)\
    .setEnableLevenshtein(True)\
    .setNeighbours(200).setAlternatives(5).setDistanceWeights([4,4,2,0,8,8])\
    .setExtramassPenalty(3)\
    .setInputCols(chunk_token_cancer_col, chunk_embs_cancer_col)\
    .setOutputCol(icdo_col)
# Out:
# ensembleresolve_snomed_clinical download started this may take some time.
# Approximate size to download 592.9 MB
# [OK!]
# chunkresolve_icd10cm_neoplasms_clinical download started this may take some time.
# Approximate size to download 20.4 MB
# [OK!]
# chunkresolve_icdo_clinical download started this may take some time.
# Approximate size to download 8.2 MB
# [OK!]

# %%
pipelineFull = Pipeline().setStages([
    docAssembler, 
    sentenceDetector, 
    tokenizer, 
    embeddings, 
    clinicalNer,
    bioNer,
    clinicalConverter,
    cancerConverter,
    clinicalChunkEmbeddings, 
    cancerChunkEmbeddings, 
    clinicalChunkTokenizer,
    cancerChunkTokenizer,
    snomedResolver,
    icd10cmResolver,
    icdoResolver
])

# %%
pipelineModelFull = pipelineFull.fit(data)

# %%
output = pipelineModelFull.transform(data).cache()

# %% [markdown]
# ## The last part of our pipeline are the **ChunkEntityResolvers**:
#
# ### EntityResolver:
# Trained on an augmented ICDO Dataset from JSL Data Market it provides histology codes resolution for the matched expressions. Other than providing the code in the "result" field it provides more metadata about the matching process:
#
# - all_k_results -> Sorted ResolverLabels in the top `alternatives` that match the distance `threshold`
# - all_k_resolutions -> Respective ResolverNormalized strings
# - all_k_confidences -> Respective normalized probabilities based in inverse distance valuesprobability
# - all_k_distances -> Respective distance values after aggregation
# - target_text -> The actual searched string
# - resolved_text -> The top ResolverNormalized string
# - confidence -> Top probability
# - distance -> Top distance value
# - sentence -> Sentence index
# - chunk -> Chunk Index
# - token -> Token index

# %%
def quick_metadata_analysis(df, doc_field, chunk_field, code_fields):
    code_res_meta = ", ".join([f"{cf}.metadata" for cf in code_fields])
    expression = f"explode(arrays_zip({chunk_field}.begin, {chunk_field}.end, {chunk_field}.result, {chunk_field}.metadata, "+code_res_meta+")) as a"
    top_n_rest = [(f"float(a['{i+4}'].confidence) as {(cf.split('_')[0])}_conf",
                    f"arrays_zip(split(a['{i+4}'].all_k_results,':::'),split(a['{i+4}'].all_k_resolutions,':::')) as {cf.split('_')[0]+'_opts'}")
                    for i, cf in enumerate(code_fields)]
    top_n_rest_args = []
    for tr in top_n_rest:
        for t in tr:
            top_n_rest_args.append(t)
    return df.selectExpr(doc_field, expression) \
        .orderBy(docid_col, F.expr("a['0']"), F.expr("a['1']"))\
        .selectExpr(f"concat_ws('::',{doc_field},a['0'],a['1']) as coords", "a['2'] as chunk","a['3'].entity as entity", *top_n_rest_args)

# %%
snomed_analysis = \
quick_metadata_analysis(output, docid_col, chunk_clinical_col,[snomed_clinical_col]).toPandas()

# %%
cancer_analysis = \
quick_metadata_analysis(output, docid_col, chunk_cancer_col,[icd10cm_col, icdo_col]).toPandas()

# %%
snomed_analysis
# Out:
#             coords  \
# 0      0::123::147
# 1      0::192::212
# 2      0::223::253
# 3      0::279::300
# 4      0::329::345
# 5      0::353::363
# 6      0::396::413
# 7      0::419::438
# 8      0::441::466
# 9      0::621::673
# 10     0::768::785
# 11     0::808::814
# 12     0::820::829
# 13     0::873::899
# 14     0::906::939
# 15     0::942::958
# 16     0::965::985
# 17   0::1017::1040
# 18   0::1056::1070
# 19   0::1076::1103
# 20   0::1132::1174
# 21   0::1203::1229
# 22   0::1256::1324
# 23   0::1354::1402
# 24   0::1409::1427
# 25   0::1454::1460
# 26   0::1463::1487
# 27   0::1566::1600
# 28   0::1603::1644
# 29   0::1753::1790
# 30   0::1860::1872
# 31   0::1888::1900
# 32   0::1946::1982
# 33   0::2012::2027
# 34   0::2068::2088
# 35   0::2091::2105
# 36   0::2112::2137
# 37   0::2196::2223
# 38   0::2238::2254
# 39   0::2260::2288
# 40   0::2295::2300
# 41   0::2303::2342
# 42   0::2369::2396
# 43   0::2429::2463
# 44       1::36::66
# 45      1::73::132
# 46     1::143::162
# 47     1::203::236
# 48     1::247::269
# 49     1::316::346
# 50     1::370::397
# 51     1::411::430
# 52     1::439::462
# 53     1::496::524
# 54     1::530::558
# 55     1::583::606
# 56     1::700::714
# 57     1::864::879
# 58     1::935::950
# 59     1::975::983
# 60   1::1030::1088
# 61   1::1095::1118
# 62   1::1154::1183
# 63   1::1200::1209
# 64   1::1216::1219
# 65   1::1247::1323
# 66   1::1326::1367
# 67   1::1499::1542
# 68   1::1674::1707
# 69   1::1782::1824
# 70   1::1867::1882
# 71   1::1889::1922
# 72   1::1932::1939
# 73   1::1955::1974
# 74   1::2004::2023
# 75   1::2051::2053
# 76   1::2062::2075
# 77   1::2084::2087
# 78   1::2100::2109
# 79   1::2112::2145
# 80   1::2154::2161
# 81   1::2170::2172
# 82   1::2216::2224
# 83       2::40::57
# 84       2::64::77
# 85      2::80::100
# 86     2::107::123
# 87     2::150::211
# 88     2::222::269
# 89     2::277::280
# 90     2::308::315
# 91     2::322::342
# 92     2::376::416
# 93     2::431::462
# 94     2::465::484
# 95     2::493::513
# 96     2::560::575
# 97     2::582::611
# 98     2::622::625
# 99     2::631::648
# 100    2::672::711
# 101    2::714::724
# 102    2::730::744
# 103    2::768::810
# 104      3::37::73
# 105    3::104::116
# 106    3::129::167
# 107    3::174::211
# 108    3::260::312
# 109    3::330::362
# 110    3::373::380
# 111    3::393::400
# 112    3::406::436
# 113    3::492::515
# 114    3::524::529
# 115    3::545::555
# 116    3::562::577
#
#                                                                              chunk  \
# 0                                                        a large left scrotal mass
# 1                                                            left scrotal swelling
# 2                                                  progressively increased in size
# 3                                                           mild left scrotal pain
# 4                                                                mild constipation
# 5                                                                      hard stools
# 6                                                               urinary complaints
# 7                                                             physical examination
# 8                                                       a hard paratesticular mass
# 9                            a hard, lower abdominal mass in the suprapubic region
# 10                                                              further evaluation
# 11                                                                         imaging
# 12                                                                      blood work
# 13                                                     a complete blood cell count
# 14                                              differential, liver function tests
# 15                                                               coagulation panel
# 16                                                           basic chemistry panel
# 17                                                        a serum creatinine level
# 18                                                                 typical markers
# 19                                                    a testicular germ cell tumor
# 20                                     the beta–human chorionic gonadotropin level
# 21                                                     the alpha fetoprotein level
# 22           a ct scan of the chest, abdomen, and pelvis with intravenous contrast
# 23                               large multifocal intra-abdominal, retroperitoneal
# 24                                                             pelvic masses (figu
# 25                                                                         imaging
# 26                                                       a 7.8-cm para-aortic mass
# 27                                             moderate left hydroureteronephrosis
# 28                                      additionally, three separate pelvic masses
# 29                                          these displaced the bladder anteriorly
# 30                                                                   needle biopsy
# 31                                                                   pelvic masses
# 32                                           microscopic examination of the tissue
# 33                                                                cellular islands
# 34                                                           hyperchromatic nuclei
# 35                                                                 scant cytoplasm
# 36                                                      invading fibrous tissue—as
# 37                                                    immunohistochemical staining
# 38                                                               strong positivity
# 39                                                   cytokeratin ae1/ae3, vimentin
# 40                                                                          desmin
# 41                                        further mutational analysis of the cells
# 42                                                    an ews-wt1 fusion transcript
# 43                                             desmoplastic small round cell tumor
# 44                                                 diabetes mellitus, hypertension
# 45                    hypercholesterolemia self-palpated a left submandibular lump
# 46                                                            complete blood count
# 47                                              solitary leukocytosis (white count
# 48                                                         predominant lymphocytes
# 49                                                 peripheral blood flow cytometry
# 50                                                    chronic lymphocytic leukemia
# 51                                                            lymphocytic lymphoma
# 52                                                        abnormal cell population
# 53                                                   leukocytes, co-expressing cd5
# 54                                                   cd23 in cd19-positive b cells
# 55                                                        other prognostic markers
# 56                                                                 his white count
# 57                                                                his other counts
# 58                                                                anemia (hemoglob
# 59                                                                       platelets
# 60                     enlargement of his cervical, submandibular, supraclavicular
# 61                                                        axillary lymphadenopathy
# 62                                                  a positron emission tomography
# 63                                                                      tomography
# 64                                                                            scan
# 65   extensive diffuse lymphadenopathy within the neck, chest, abdomen, and pelvis
# 66                                      maximum standardized uptake value (suv max
# 67                                    mild to moderately hypermetabolic adenopathy
# 68                                              his right axillary lymphadenopathy
# 69                                     lymph nodes on the right abdomen and pelvis
# 70                                                                some mass effect
# 71                                              compression on the urinary bladder
# 72                                                                        symptoms
# 73                                                            a bone marrow biopsy
# 74                                                            hypercellular marrow
# 75                                                                             cll
# 76                                                                  flow cytometry
# 77                                                                            cd38
# 78                                                                      positivity
# 79                                              fluorescence in situ hybridization
# 80                                                                        analysis
# 81                                                                             13q
# 82                                                                       karyotype
# 83                                                              vertigo, headaches
# 84                                                                  frequent falls
# 85                                                           a computed tomography
# 86                                                               scan of the brain
# 87                  a 1.6 x 1.6 x 2.1 cm mass involving the fourth ventricle (figu
# 88                                a gadolinium-enhanced magnetic resonance imaging
# 89                                                                            scan
# 90                                                                        the mass
# 91                                                           a stereotactic biopsy
# 92                                       a primary central nervous system lymphoma
# 93                                                a diffuse large b-cell histology
# 94                                                            complete blood count
# 95                                                           lactate dehydrogenase
# 96                                                                systemic staging
# 97                                                  a positron emission tomography
# 98                                                                            scan
# 99                                                              bone marrow biopsy
# 100                                       lymphomatous involvement outside the cns
# 101                                                                    an eye exam
# 102                                                                lumbar puncture
# 103                                    either ocular or leptomeningeal involvement
# 104                                          a progressing pruritic cutaneous rash
# 105                                                                  clinical exam
# 106                                        numerous coalescing, infiltrated, scaly
# 107                                         partially crusted erythematous plaques
# 108                          a large fungating ulcerated nodule on her right thigh
# 109                                              her total body surface area (figu
# 110                                                                       lymphoma
# 111                                                                       alopecia
# 112                                                a left axillary lymphadenopathy
# 113                                                       fatigue, severe pruritus
# 114                                                                         sweats
# 115                                                                    weight loss
# 116                                                               loss of appetite
#
#       entity  snomed_conf  \
# 0    PROBLEM       0.1074
# 1    PROBLEM       0.1175
# 2    PROBLEM       0.1318
# 3    PROBLEM       0.1184
# 4    PROBLEM       0.1177
# 5    PROBLEM       1.0000
# 6    PROBLEM       0.1347
# 7       TEST       1.0000
# 8    PROBLEM       0.1354
# 9    PROBLEM       0.1070
# 10      TEST       0.1707
# 11      TEST       1.0000
# 12      TEST       0.1320
# 13      TEST       0.1210
# 14      TEST       0.1227
# 15      TEST       0.1953
# 16      TEST       0.1272
# 17      TEST       0.1404
# 18      TEST       0.1185
# 19   PROBLEM       0.1130
# 20      TEST       0.1604
# 21      TEST       0.1336
# 22      TEST       0.1062
# 23   PROBLEM       0.1024
# 24   PROBLEM       0.1455
# 25      TEST       1.0000
# 26   PROBLEM       0.1164
# 27   PROBLEM       0.1072
# 28   PROBLEM       0.1150
# 29   PROBLEM       0.1043
# 30      TEST       1.0000
# 31   PROBLEM       0.1076
# 32      TEST       0.1105
# 33   PROBLEM       0.1361
# 34   PROBLEM       0.1141
# 35   PROBLEM       0.1430
# 36   PROBLEM       0.1192
# 37      TEST       0.1150
# 38   PROBLEM       0.1018
# 39      TEST       0.1547
# 40      TEST       0.1110
# 41      TEST       0.1112
# 42   PROBLEM       0.1076
# 43   PROBLEM       1.0000
# 44   PROBLEM       0.1561
# 45   PROBLEM       0.1078
# 46      TEST       1.0000
# 47   PROBLEM       0.1186
# 48   PROBLEM       0.1254
# 49      TEST       0.1096
# 50   PROBLEM       0.1444
# 51   PROBLEM       1.0000
# 52   PROBLEM       0.1439
# 53      TEST       0.1135
# 54      TEST       0.1113
# 55      TEST       0.1207
# 56      TEST       0.1250
# 57      TEST       0.1058
# 58   PROBLEM       0.3674
# 59      TEST       1.0000
# 60   PROBLEM       0.1078
# 61   PROBLEM       1.0000
# 62      TEST       0.2284
# 63      TEST       0.1440
# 64      TEST       0.1059
# 65   PROBLEM       0.1223
# 66      TEST       0.1142
# 67   PROBLEM       0.1161
# 68   PROBLEM       0.1142
# 69   PROBLEM       0.1131
# 70   PROBLEM       0.1147
# 71   PROBLEM       0.1077
# 72   PROBLEM       0.1134
# 73      TEST       0.2294
# 74   PROBLEM       0.1281
# 75      TEST       0.1037
# 76      TEST       1.0000
# 77   PROBLEM       0.1036
# 78   PROBLEM       0.1345
# 79      TEST       1.0000
# 80      TEST       0.1037
# 81      TEST       0.1109
# 82      TEST       1.0000
# 83   PROBLEM       0.1039
# 84   PROBLEM       0.1482
# 85      TEST       0.1121
# 86      TEST       0.1451
# 87   PROBLEM       0.1017
# 88      TEST       0.1585
# 89      TEST       0.1059
# 90   PROBLEM       0.1081
# 91      TEST       0.1596
# 92   PROBLEM       0.3104
# 93   PROBLEM       0.1116
# 94      TEST       1.0000
# 95      TEST       0.1496
# 96      TEST       0.1436
# 97      TEST       0.2284
# 98      TEST       0.1059
# 99      TEST       1.0000
# 100  PROBLEM       0.1349
# 101     TEST       0.1082
# 102     TEST       1.0000
# 103  PROBLEM       0.1050
# 104  PROBLEM       0.1260
# 105     TEST       0.1518
# 106  PROBLEM       0.1102
# 107  PROBLEM       0.1557
# 108  PROBLEM       0.1056
# 109  PROBLEM       0.1462
# 110  PROBLEM       1.0000
# 111  PROBLEM       1.0000
# 112  PROBLEM       0.1206
# 113  PROBLEM       0.1033
# 114  PROBLEM       1.0000
# 115  PROBLEM       1.0000
# 116  PROBLEM       1.0000
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              snomed_opts
# 0                       [(15634671000119101, Mass of left adrenal gland), (12240181000119103, Mass in left breast), (15634751000119101, Mass of left ovary), (10682231000119106, Mass of skin of left forearm), (10692461000119101, Mass of skin of left thumb), (15748081000119106, Mass of joint of left shoulder), (10682191000119102, Mass of skin of left foot), (10682271000119109, Mass of skin of left hand), (15636691000119106, Mass of right adrenal gland), (15748121000119108, Mass of joint of left foot)]
# 1                                                                                                     [(15952141000119106, Left parotid gland swelling), (442648006, Swelling of left tonsil), (762916009, Swelling of left foot), (12242351000119109, Swelling of left arm), (271687003, Swelling of scrotum), (442778006, Bilateral tonsillar swelling), (438457000, Swelling of testicle), (16675301000119100, Left testicular pain), (274743004, Groin swelling), (15952181000119101, Right parotid gland swelling)]
# 2    [(771339005, Hyperzincaemia and hypercalprotectinaemia), (51978008, Head lag in the newborn (disorder)), (762459007, Disorder due to and following breast reduction), (81543006, Abnormal hard tissue formation in pulp (disorder)), (691471000119109, Ischemia co-occurrent and due to increased oxygen demand), (691471000119109, Ischaemia co-occurrent and due to increased oxygen demand), (191290006, Hemorrhagic disorder due to increase in anti-8a), (191290006, Haemorrhagic disorder due to increase ...
# 3                                                                                                                                          [(722829006, Acute scrotal pain), (20502007, Scrotal pain), (16675301000119100, Left testicular pain), (15629941000119104, Left inguinal pain), (16675301000119100, Pain of left testicle), (316821000119105, Pain of left thigh), (162049009, Left flank pain), (301368006, Left hypochondrial pain), (285387005, Left sided abdominal pain), (287047008, Pain in left leg)]
# 4                                                                                                                                     [(111360009, Intractable constipation), (197118003, Functional constipation), (430097009, Spastic constipation), (191973007, Psychogenic constipation), (432994008, Neurogenic constipation), (370218001, Mild asthma), (331987008, Mild dietary indigestion), (386805003, Mild cognitive impairment), (386805003, Mild cognitive disorder), (197118003, Constipation-functional)]
# 5                                                                                                                                                                                                                                                           [(75295004, Hard stools), (75295004, Hard stool), (75295004, Hard feces), (75295004, Hard faeces), (35064005, Dark stools), (64412006, Red stools), (35064005, Black stools), (398032003, Loose stools), (167609007, Green stools), (70396004, Grey stools)]
# 6                                                                                                                                                                         [(38276004, Multiple complaints), (5277004, Urinary casts), (264832001, Urinary eosinophils), (102846009, Urinary sediment), (102850002, Urinary reducing substance), (106102002, Abnormal urinary product), (102847000, Amorphous urinary sediment), (7766007, Nebulous urine), (40434009, Dyspeptic urine), (102837003, Urinary cast, waxy)]
# 7                                                                     [(5880005, Physical examination), (5880005, Physical examination procedure), (410182004, Physical examination assessment), (410184003, Physical examination management), (116302003, Physical examination maneuver), (116302003, Physical examination manoeuvre), (410182004, Assess physical examination), (410184003, Manage physical examination), (103740001, Periodic physical examination), (438547004, Postoperative physical examination)]
# 8                                                                                                                           [(102031000119109, Paratesticular mass), (6370001000004104, Mass of hard palate), (102031000119109, Paratesticular mass (disorder)), (300848003, Observation of a mass), (444905003, Mass of soft tissue), (69559004, Mass of retroperitoneal structure), (444905003, Soft tissue mass), (237047009, Tubo-ovarian mass), (87860000, Mass of testicle), (126806005, Neoplasm of hard palate)]
# 9    [(163293006, On examination - abdominal mass-very hard), (163307004, On examination - abdominal mass - lower border defined), (28640001000004103, Mass of left lower quadrant of abdominal wall), (39261000119104, Left lower quadrant abdominal swelling, mass, or lump), (312355005, On examination - left lower abdominal mass (finding)), (448772000, Mass of abdominal cavity structure (finding)), (312355005, On examination - left lower abdominal mass), (163293006, On examination - abdominal mass-ve...
# 10                                 [(182770003, Preanaesthesia evaluation), (165171009, Initial psychiatric evaluation), (203421005, Limited interview and evaluation), (14736009, Patient evaluation and management), (43038000, Cardiovascular examination and evaluation), (200619008, Comprehensive interview and evaluation), (363109007, Evaluation of test results), (453971000124106, Evaluation of pharmacogenetic result), (225343006, Assessment of needs), (31958005, Developmental testing and assessment)]
# 11                                                                                                                                                                                                                        [(363679005, Imaging), (258174001, Imaging guidance), (41747008, Bone imaging), (363679005, Clinical imaging), (39500001, Thyroid imaging), (58920005, Carotid imaging), (413815006, Chest imaging), (371576000, Video imaging), (64432007, Myocardial imaging), (372079001, Adrenal imaging)]
# 12                                                                                                                                                                                                          [(224363007, In work), (737376008, Uncongenial work), (160895006, Stopped work), (73438004, Out of work), (224467009, Demoted at work), (224464002, Redeployed at work), (224366004, In sheltered work), (224375002, In regular work), (737376008, Uncongenial work environment), (160926000, Fit for work)]
# 13                                                                                               [(26604007, Complete blood count), (88308000, Blood cell count), (391558003, Total white blood cell count), (767002, White blood cell count), (14089001, Red blood cell count), (117355001, Blood cell count, manual), (117356000, Blood cell count, automated), (43789009, Complete blood count without differential), (26604007, Complete blood count (procedure)), (165511009, Differential white blood cell count)]
# 14                                                                                                            [(26958001, Liver function test), (270954007, Differential renal function), (23426006, Lung function tests), (167197004, Digestive function tests), (736164009, Monitoring of liver function), (167191003, Gastric function tests), (164961002, Physiological function tests), (167178004, Chemical function tests), (268382008, Circulatory function tests), (167209002, Chem. metabolic function tests)]
# 15                                                                                                                                                                      [(3116009, Blood coagulation panel), (29711001, Coagulation panel for thrombosis), (16254007, Lipid panel), (29711001, Thrombosis panel), (88291001, Obstetric panel), (35650009, Thyroid panel), (54610007, Kidney panel), (112922009, Coagulation of uterus), (252278002, Coagulation pathway screening), (3116009, Blood coagulation screen)]
# 16                                                                                                               [(275711006, Serum chemistry test), (28040002, General health panel), (84355003, Antibody panel measurement), (43782000, Diagnostic panel or profile), (166312007, Blood chemistry (procedure)), (269937005, Sample virology general), (252275004, Hematology - general), (252275004, Haematology - general), (103766003, Evocative or suppression testing panel), (16254007, Lipid panel (procedure))]
# 17                                                                     [(313822004, Corrected serum creatinine level), (271243004, Serum vitamin A level), (313936008, Plasma creatinine level), (313817004, Corrected plasma creatinine level), (113075003, Creatinine measurement, serum), (270976003, Serum A1 antitrypsin level), (391535001, Serum immunoglobulin A2 level), (391334001, Serum immunoglobulin A1 level), (391452000, Serum desmethyldothiepin level), (412863004, Dialysis fluid creatinine level)]
# 18                                                                                              [(259428003, Lipidoses marker), (767280006, Metabolic marker), (259381005, Glycogenoses marker), (388376002, Hexahydrophtalic anhydrid specific IgE), (388382004, Methyltetrahydrophtalic anhydrid specific IgE), (388372000, Alkalase specific IgE), (388381006, Maxatase anhydrid specific IgE), (259672007, Biochemical tumor marker), (259672007, Biochemical tumour marker), (388426000, Ampicilloyl specific IgE)]
# 19                                                                [(713577007, Germ cell tumor of testis), (237059008, Germ cell tumor of ovary), (277508009, Pineal germ cell tumor), (713577007, Germ cell tumour of testis), (713646001, Malignant germ cell tumor of testis), (773283006, Cervical malignant germ cell tumor), (277456001, Suprasellar germ cell tumor), (107691000119101, Nonseminomatous germ cell tumor of testis), (237059008, Germ cell tumour of ovary), (277508009, Pineal germ cell tumour)]
# 20   [(67900009, Human chorionic gonadotropin level), (167376008, Urine chorionic gonadotropin level), (67900009, Human chorionic gonadotrophin level), (250658009, Free beta human chorionic gonadotropin level), (394721004, Total beta human chorionic gonadotropin level), (167376008, Urine chorionic gonadotrophin level), (67900009, Human chorionic gonadotropin measurement), (250658009, Free beta human chorionic gonadotrophin level), (394721004, Total beta human chorionic gonadotrophin level), (3865...
# 21                                            [(391290009, Fluid sample alpha fetoprotein level), (391516001, Maternal serum alpha fetoprotein level), (104404005, Serum alpha-fetoprotein), (391516001, Maternal serum alpha-fetoprotein level), (169188005, Alpha-fetoprotein radioimmunoassay), (268468007, Alpha-fetoprotein blood test), (413484007, Alpha carotene level), (412968009, Urine alpha-aminoadipate level), (80152001, Alpha-1-Fetoprotein measurement), (412949006, Plasma alpha-aminoadipate level)]
# 22   [(726552004, CT of thorax, abdomen and pelvis with oral contrast), (764729002, CT of abdomen and pelvis with oral and IV (intravenous) contrast), (16462121000119108, CT angiography of thorax, abdomen and pelvis with contrast), (764729002, Computed tomography of abdomen and pelvis with oral and intravenous contrast), (16462121000119108, CT angiogram of thorax, abdomen and pelvis with contrast), (764731006, Computed tomography of thorax, abdomen and pelvis with oral and intravenous contrast), ...
# 23                                                                                 [(78197004, Comedocarcinoma, noninfiltrating), (108350001, Abdomen, excluding retroperitoneal region), (421419001, Lipoblastoma, diffuse), (91394001, Structure of retroperitoneal lymph node), (420777000, Lipoblastoma, circumscribed), (53880006, Haemangiopericytoma, benign), (63373002, Lymphangioendothelioma, malignant), (31131002, Vipoma, malignant), (83802009, Androblastoma, benign), (72889001, Mesonephroma, benign)]
# 24                                                                                  [(16293003, Pelvic osteoclasis), (178026004, Biopsy of pelvic mass), (28160007, Pelvic lymphangiography, bilateral), (55853002, Pelvic exenteration, female), (14563007, Endoscopy of pelvic cavity), (61392008, Reconstruction of pelvic floor), (88914000, Radiography of pelvic bones), (24848001, Pelvic echography (procedure)), (58259007, Radiography of pelvic soft tissue), (419553002, Ultrasound scan of pelvic vessels)]
# 25                                                                                                                                                                                                                        [(363679005, Imaging), (258174001, Imaging guidance), (41747008, Bone imaging), (363679005, Clinical imaging), (39500001, Thyroid imaging), (58920005, Carotid imaging), (413815006, Chest imaging), (371576000, Video imaging), (64432007, Myocardial imaging), (372079001, Adrenal imaging)]
# 26                                                                                                                                                                                                           [(14160001000004107, Vallecular mass), (300848003, Observation of a mass), (297960002, Mass of skin), (16550001000004104, Mass of ankle), (309526009, Mass of hand), (442098006, Mass of foot), (441683007, Mass of wrist), (299704007, Mass of face), (442026004, Mass of toe), (441766009, Mass of nose)]
# 27                                                                                     [(981000124106, Moderate left ventricular systolic dysfunction), (1088481000119106, Chronic left tympanitis), (1088481000119106, Chronic left myringitis), (15639051000119100, Left dacryostenosis), (443768001, Left kidney absent), (253637002, Hemitruncus to left), (253637002, Left hemitruncus), (762913001, Left renal hypoplasia), (338461000119109, Left pseudopapilloedema), (338461000119109, Left pseudopapilledema)]
# 28   [(720016003, Nonallopathic lesion of pelvic region), (210229000, Injury of multiple pelvic organs), (74285003, Mass of pelvic structure), (733380004, Multiple open wounds of pelvic region), (249733009, Large pelvic bone (finding)), (267952008, Arthralgia of the pelvic region and thigh), (74285003, Mass of pelvic structure (finding)), (94992009, Neoplasm of uncertain behavior of pelvic peritoneum), (203271005, Tuberculosis of the pelvic and thigh bones), (94992009, Neoplasm of uncertain behav...
# 29                                                                                                                         [(9887002, Concave-casqued hornbill), (39735001, Three-wattled bellbird), (421971000, Three-toed amphiuma), (132633000, Treeing Tennessee Brindle dog), (72126007, Tropical two-wing flyingfish), (132472008, Austrian Smooth-Haired Bracke dog), (424997007, Three-toed woodpecker), (59330002, Large pin-tailed sandgrouse), (34162002, Two-toed amphiuma), (421872006, Two-toed amphiuma)]
# 30                                                                                                                                                       [(129249002, Needle biopsy), (72771008, Needle bone biopsy), (48635004, Fine needle biopsy), (9911007, Core needle biopsy), (274314005, Percutaneous needle biopsy), (396901009, Transthoracic needle biopsy), (72771008, Needle biopsy of bone), (274319000, Needle biopsy of lung), (184598004, Needle biopsy of brain), (303588003, Needle biopsy of liver)]
# 31                                                                                                                                                                                    [(16293003, Pelvic osteoclasis), (35025007, Pelvic examination), (113100006, Pelvic lymphangiogram), (24848001, Pelvic echography), (241256002, Pelvic venogram), (419259002, Pelvic venogram), (71599004, Pelvic pneumography), (30763005, Pelvic osteoplasty), (241255003, Pelvic angiography), (52224004, Pelvic evisceration)]
# 32   [(609298005, Microscopic examination of blood specimen), (127800008, Microscopic examination of urine specimen), (608945008, Microscopic examination of vomitus specimen), (608945008, Microscopic examination of vomit specimen), (608857000, Microscopic examination of specimen from perirenal tissue), (608861006, Microscopic examination of specimen from perivesical tissue), (608859002, Microscopic examination of specimen from periureteral tissue), (609013007, Microscopic examination of retroperi...
# 33                                          [(422252006, Rhode Island), (224659006, Terraced bungalow), (441608000, Republic of the Marshall Islands), (223992005, Falkland islands (geographic location)), (223738004, Laccadive islands (geographic location)), (223533006, Comoros islands (geographic location)), (224008006, Island of North America), (223627009, Solomon islands (geographic location)), (223845007, Balearic islands (geographic location)), (223737009, Andaman islands (geographic location))]
# 34                                                                                                                         [(305750000, Seen by stomatherapist), (305630008, Seen by hypnotherapist), (171338009, Special examination arranged), (305631007, Seen by osteopath), (184085002, Patient moved in area), (169508004, Pregnant, sheath failure), (413328008, Transfer out of area), (184165003, Registered in deprived area), (184084003, Registration ghost - dead), (305741002, Seen by Marie Curie nurse)]
# 35                                                                                                                                               [(62035001, Cytoplasm), (127563002, Scant hemorrhage), (43228000, Spore cytoplasm), (127563002, Scant haemorrhage), (52875007, Cytoplasm, prokaryotic), (125421003, Cytoplasmic hyalinisation), (50492002, Hyposegmented nucleus), (15967006, Hypersegmented nucleus), (46813004, Mitochondrial aggregation within cytoplasm), (50492002, Hyposegmentation of nucleus)]
# 36                                                                                                         [(1335005, Fibrous cavernositis), (392544003, Fibrous downgrowth), (392544003, Fibrous ingrowth), (416416006, Retrocorneal fibrous membrane), (254736006, Cutaneous fibrous tissue tumor), (254736006, Cutaneous fibrous tissue tumour), (402870005, Reactive fibrous tissue proliferation), (10623005, Fibrous dysplasia of bone), (76098004, Fibrous dysplasia of jaw), (195469007, Fibrous polyp of anus)]
# 37                                                                                              [(247438007, Staining of skin), (234978004, Staining of tooth), (196317007, Posteruptive teeth staining), (234978004, Staining of teeth), (231915009, Corneal blood staining), (281005004, Corneal epithelial staining finding), (234983007, Intrinsic staining of tooth), (281005004, Corneal epithelial staining observations), (234979007, Extrinsic staining of tooth), (392612009, Fluorescein staining of cornea)]
# 38                                                                                                                 [(22454009, Tody motmot), (430760009, Micromonospora inositola), (114006005, Thermoactinomyces putidus), (90265001, Thermoactinomyces dichotomicus), (430591000, Micromonospora auratinigra), (443669001, Micromonospora narathiwatensis), (441212000, Thioploca ingrica), (430645001, Micromonospora endolithica), (5311000146105, Micromonospora peucetia), (718807003, Micromonospora tulbaghiae)]
# 39                                                                                                                                                                                          [(444056009, Cytokeratin antibody), (259987000, Cytokeratin), (709132000, Cytokeratin 19), (259615002, Cytokeratin 20), (102665003, Keratin protein), (259987000, Cytokeratin (substance)), (117208008, Antibody to cytokeratin filaments), (726534004, Actin IgG), (121044001, Actin antigen), (75956008, Haematein stain)]
# 40                                                                                                                                                                                                                        [(46583003, Actin), (259987000, Cytokeratin), (405833006, Schwannomin), (48184006, Tropomyosin), (304270003, Cerebrosidase), (710237002, Trihexosylceramide), (58652008, Glycoasparaginase), (387280008, Hyaluronoglucosaminidase), (83475004, Desmin (substance)), (69662009, Alpha actinin)]
# 41   [(201924001, Kashin-Beck disease of the hand), (201924001, Kashin-Bek disease of the hand), (201834006, Localized, primary osteoarthritis of the hand), (201834006, Localised, primary osteoarthritis of the hand), (287161001, Effects of the elements (disorder)), (414022008, Disorder of cellular component of blood), (84984002, Adjustment reaction with predominant disturbance of conduct), (201925000, Kashin-Beck disease of the pelvic region and thigh), (201925000, Kashin-Bek disease of the pelvi...
# 42                                                                                            [(52998000, Fusion of pantalar joint), (448397004, Fusion of scaphotrapeziotrapezoid joint), (59323008, Spinal fusion with graft), (9730000, Fusion of ischiofemoral joint), (239546004, Spinal fusion in situ), (30266003, Exploration of spinal fusion), (178806002, Fusion spondylolisthesis in situ), (443456009, Expression of comedone), (288056002, Bone fusion (procedure)), (178804004, Back fusion (procedure))]
# 43   [(128735004, Desmoplastic small round cell tumor), (128735004, Desmoplastic small round cell tumour), (128735004, Desmoplastic small round cell tumor (morphologic abnormality)), (82267002, Malignant tumor, small cell type), (82267002, Malignant tumor - small cell type), (82267002, Malignant tumour, small cell type), (82267002, Malignant tumour - small cell type), (9001003, Chondromatous giant cell tumor), (128778009, Malignant tenosynovial giant cell tumor), (64575004, Malignant lymphoma, sm...
# 44                                                                            [(73211009, Diabetes mellitus), (8801005, Secondary diabetes mellitus), (49817004, Neonatal diabetes mellitus), (703136005, Diabetes mellitus in remission), (44054006, Diabetes mellitus type 2), (46635009, Diabetes mellitus type 1), (530558861000132104, Atypical diabetes mellitus), (10754881000119104, Diabetes mellitus in childbirth), (445260006, Posttransplant diabetes mellitus), (11687002, Gestational diabetes mellitus)]
# 45   [(16675391000119106, Ultrasonography of left kidney abnormal), (190774002, Hyperlipidemia, group A), (15634311000119103, Mammographic mass of left breast), (12266201000119107, Mammographic calcification of left breast), (399706008, Left ovary uninvolved by tumour), (399706008, Left ovary uninvolved by tumor), (406016007, Left ovary not present in specimen), (16675351000119101, Ultrasonography of right kidney abnormal), (15634271000119103, Mammographic mass of right breast), (164874007, Elect...
# 46                                                                                                      [(26604007, Complete blood count), (43789009, Complete blood count without differential), (26604007, Complete blood count (procedure)), (88308000, Blood cell count), (391558003, Total white blood count), (104100008, Promyelocyte count, blood), (104099000, Myelocyte count, blood), (104103005, Myeloblast count, blood), (104101007, Prolymphocyte count, blood), (103759004, Metamyelocyte count, blood)]
# 47                                                                              [(165513007, Differential white count abnormal), (165509000, White cell count abnormal), (165507003, White cell count normal), (165507003, White blood cell count normal), (165512002, Differential white cell count normal), (165509000, White blood cell count abnormal), (365601007, Finding of eosinophil count), (365625004, Red blood cell count), (365632008, Finding of platelet count), (762656009, Abnormal blood cell count)]
# 48   [(277551008, Splenic lymphoma with villous lymphocytes), (93545005, Hodgkin paragranuloma of spleen), (236512004, Leukaemic infiltrate of kidney), (236512004, Leukemic infiltrate of kidney), (267543009, Functional disorders of polymorphonuclear neutrophils), (363265005, Predominant humoral immune deficiency (disorder)), (118605002, Hodgkin lymphoma, nodular lymphocyte predominance), (363088000, Disorder involving basophils and mast cells), (440525003, Primary small cell neoplasm of thymus), ...
# 49                                                                                           [(165090004, Arterial blood flow test), (14768001, Peripheral blood film examination), (14768001, Peripheral blood smear interpretation), (80810009, Regional blood flow study), (64444005, Flow cytometry), (165091000, Limb blood flow test), (302779002, Blood flow tests), (104153004, Reticulocyte count, flow cytometry), (64444005, Flow cytometry (procedure)), (418576007, Peripheral blood stem cell collection)]
# 50                    [(430338009, Smoldering chronic lymphocytic leukemia), (92814006, Chronic lymphoid leukemia), (92812005, Chronic leukemia), (188745007, Chronic monocytic leukemia), (430338009, Smouldering chronic lymphocytic leukaemia), (277549009, Chronic lymphocytic prolymphocytic leukemia syndrome), (21983002, Chronic lymphocytic thyroiditis), (92814006, Chronic lymphoid leukaemia), (188745007, Chronic monocytic leukaemia), (277549009, Chronic lymphocytic prolymphocytic leukaemia syndrome)]
# 51                                                                                                                                                [(302841002, Lymphocytic lymphoma), (302841002, Small lymphocytic lymphoma), (302841002, Lymphocytic lymphosarcoma), (765136002, Berti lymphoma), (404143002, Crosti's lymphoma), (307623001, Plasmacytic lymphoma), (109965004, Lymphoblastic lymphoma), (109976000, Lymphoepithelioid lymphoma), (118617000, Burkitt lymphoma), (724648008, Plasmablastic lymphoma)]
# 52                                                                                                                                          [(39266006, Abnormal cell), (116023004, Abnormal cell structure), (125391008, Abnormal cell size), (89615005, Abnormal blood cell), (107677004, Abnormal hematopoietic cell), (107677004, Abnormal haematopoietic cell), (397019006, Abnormal red blood cell), (12222001, Abnormal red blood cell), (24827003, Abnormal white blood cell), (39266006, Abnormal cell (cell))]
# 53                                                                                                                              [(25954009, Laryngismus paralyticus), (770542008, Isochromosomy Yq), (783158009, Infundibulo neurohypophysitis), (783016009, Infundibulo panhypophysitis), (18900005, Periporitis staphylogenes), (95505003, Micropunctum lacrimale), (449169008, Subchorial intervillitis), (784346006, Navajo neurohepatopathy), (431501000124109, Sialodochitis fibrinosa), (237101004, Leukorrhoea)]
# 54   [(126250003, Deglycerolised red blood cells, human), (776183008, Hepatitis B surface antigen only product), (787740006, Human protein C only product), (126256009, Red blood cells, human, irradiated), (780233006, Polymyxin B only product in cutaneous dose form), (256378001, Red cells - irradiated (product)), (126251004, Leukocyte reduced red blood cells, human), (256385002, Red cells - filtered (product)), (256388000, Red cells - washed (product)), (126251004, Leucocyte reduced red blood cell...
# 55                                                                    [(246111003, Prognostic score (attribute)), (277655009, Additional staging descriptors), (246515000, Use of skin marker), (246110002, Marker status), (313136007, Serum tumour marker status), (313136007, Serum tumor marker status), (703870008, Laterality indicator reference set), (246110002, Marker status (attribute)), (900000000000530003, ALTERNATIVE association reference set), (900000000000521006, Association type reference set)]
# 56                                                                                                                   [(391558003, Total white blood count), (767002, White blood cell count), (391558003, Total white blood cell count), (165511009, Differential white blood cell count), (26604007, Complete blood count), (165551007, Metamyelocyte count procedure), (88308000, Blood cell count), (271039009, Percentage metamyelocyte count), (70025000, White operation), (165550008, Myelocyte count procedure)]
# 57                                                                                                                                      [(104101007, Prolymphocyte count, blood), (103759004, Metamyelocyte count, blood), (104099000, Myelocyte count, blood), (250437009, Count of human cells), (104103005, Myeloblast count, blood), (414278000, FMC7 absolute count), (104100008, Promyelocyte count, blood), (104102000, Blast count, blood), (391309001, Percentage FMC 7 count), (104121008, Cell count, urine)]
# 58                                                                                                                                                                                                       [(271737000, Anemia), (53165003, Megaloblastic anemia), (462166006, Fetal anemia), (300980002, Normocytic anemia), (80875006, Achylic anemia), (234350007, Neonatal anemia), (44452003, Hypochromic anemia), (387702001, Perinatal anemia), (41841004, Sideroachrestic anemia), (66612000, Nutritional anemia)]
# 59                                                                                                                                                                                                                                                 [(16378004, Platelets), (16378004, Platelet), (44687006, Megathrombocyte), (63599005, Acanthocyte), (16378004, Thrombocyte), (70310009, Schistocyte), (446569001, Microthrombus), (19394005, Prolymphocyte), (52300009, Polychromasia), (117294002, Platelet clumps)]
# 60   [(405291003, Supraclavicular cervical sympathectomy (procedure)), (173490007, Excision of lesion of submandibular gland), (739129004, Total excision of right submandibular gland), (739128007, Total excision of left submandibular gland), (16339003, Incision of supraclavicular fossa with drainage), (741724000, Excision of right submandibular gland), (741722001, Excision of left submandibular gland), (112718009, Excision of first AND cervical rib), (53103008, Excision of cervical lymph nodes gr...
# ...
# 86                                                                                            [(41440006, Radioisotope scan of brain), (441986001, Imaging of brain), (303781007, Contrast radiography of brain), (39704007, Exploration of brain), (39704007, Exploration of brain tissue), (807005, Excision of tissue of brain), (62446008, Destruction of tissue of brain), (234915008, Marsupialisation of lesion of brain), (32012009, Radioisotope scan of head), (230886007, Exploration of ventricle of brain)]
# 87   [(10682791000119101, Mass of skin of right lower leg (finding)), (10680231000119105, Mass of skin of left lower leg (finding)), (10682751000119106, Mass of skin of right lower limb (finding)), (10680071000119103, Mass of subcutaneous tissue of right hand (finding)), (10680031000119101, Mass of subcutaneous tissue of right forearm (finding)), (10682391000119100, Mass of subcutaneous tissue of left foot (finding)), (10682871000119105, Mass of subcutaneous tissue of right foot (finding)), (1069...
# 88    [(113091000, Magnetic resonance imaging), (241663008, Vascular magnetic resonance imaging), (258177008, Magnetic resonance imaging guidance), (446186001, Forensic magnetic resonance imaging), (784794007, Multiparametric magnetic resonance imaging), (241638008, Magnetic resonance imaging of hand), (241601008, Magnetic resonance imaging of head), (711304008, Magnetic resonance imaging proctography), (425559005, Magnetic resonance imaging of bone), (447239004, Magnetic resonance imaging of limb)]
# 89                                                                                                                                                                                                                                 [(41747008, Bone scan), (16310003, Ultrasound scan), (41440006, Cerebral scan), (241354002, Kidney scan), (241354002, Renal scan), (373205008, Isotope scan), (86924002, Gallium scan), (105378004, Thallium scan), (169229007, Booking scan), (241450005, Midliner ultrasound scan)]
# 90                                                                                                                                                                                                                    [(14160001000004107, Vallecular mass), (297960002, Mass of skin), (309526009, Mass of hand), (442098006, Mass of foot), (16550001000004104, Mass of ankle), (441683007, Mass of wrist), (299704007, Mass of face), (442026004, Mass of toe), (441766009, Mass of nose), (309531006, Mass of knee)]
# 91                                                         [(171491002, Stereotactic biopsy of brain), (89311007, Jejunoscopy and biopsy), (26058004, Thoracoscopy with biopsy), (26058004, Thoracoscopy and biopsy), (59046001, Laryngotracheobronchoscopy with biopsy), (445982009, Oesophagogastroduodenoscopy and biopsy), (54899006, Stereotactic excisional biopsy of intracranial lesion), (274362004, Surgical biopsy of prostate), (184598004, Needle biopsy of brain), (236258004, Needle biopsy of prostate)]
# 92   [(307649006, Primary central nervous system lymphoma), (448254007, Non-Hodgkin's lymphoma of central nervous system), (448254007, Non-Hodgkin lymphoma of central nervous system), (147121000119104, Ependymoma of central nervous system), (734099007, Neuroblastoma of central nervous system), (10706006, Tuberculosis of central nervous system), (733926004, Ganglioneuroblastoma of central nervous system), (448995000, Follicular non-Hodgkin's lymphoma of central nervous system), (449221001, Diffuse...
# 93   [(14742008, Structure of large intestine), (24505004, Carcinoma, diffuse type), (24505004, Adenocarcinoma, diffuse type), (421419001, Lipoblastoma, diffuse), (125276008, Diffuse angiectasis (morphologic abnormality)), (64575004, Malignant lymphoma, small cell diffuse), (125543008, Diffuse metaplasia (morphologic abnormality)), (399560003, Diffuse embryoma (morphologic abnormality)), (125282006, Diffuse lymphangiectasis (morphologic abnormality)), (76319000, Diffuse necrosis (morphologic abno...
# 94                                                                                                      [(26604007, Complete blood count), (43789009, Complete blood count without differential), (26604007, Complete blood count (procedure)), (88308000, Blood cell count), (391558003, Total white blood count), (104100008, Promyelocyte count, blood), (104099000, Myelocyte count, blood), (104103005, Myeloblast count, blood), (104101007, Prolymphocyte count, blood), (103759004, Metamyelocyte count, blood)]
# 95                                                                                                               [(58163007, Lactate dehydrogenase isoenzyme), (63028001, Indolelactate dehydrogenase), (25745004, Dehydrogluconate dehydrogenase), (74997008, Glucose dehydrogenase), (5813001, Malate dehydrogenase), (129941009, Isopiperitenol dehydrogenase), (7670009, Aminobutyraldehyde dehydrogenase), (130821000, Lactate aldolase), (75284005, Glutamate dehydrogenase), (70012008, L-lactate dehydrogenase)]
# 96                                                                                                       [(254292007, Tumor staging), (254292007, Tumour staging), (254291000, Staging and scales), (106252000, Lymphoma staging descriptors), (706904009, TNM colon tumor staging), (706904009, TNM colon tumour staging), (385359000, Modified Dukes staging system), (258271004, Specific tumor staging descriptor), (258271004, Specific tumour staging descriptor), (254376004, Testicular tumour staging systems)]
# 97   [(82918005, Positron emission tomography), (764666002, Positron emission tomography of brain), (241439007, Positron emission tomography heart study), (416323006, Positron emission tomography breast study), (82918005, Positron emission tomography (procedure)), (450436003, Positron emission tomography with computed tomography), (16545811000119100, Positron emission tomography myocardial metabolism study), (105371005, Single photon emission computerized tomography), (105371005, Single photon em...
# 98                                                                                                                                                                                                                                 [(41747008, Bone scan), (16310003, Ultrasound scan), (41440006, Cerebral scan), (241354002, Kidney scan), (241354002, Renal scan), (373205008, Isotope scan), (86924002, Gallium scan), (105378004, Thallium scan), (169229007, Booking scan), (241450005, Midliner ultrasound scan)]
# 99                                                                                                                                                        [(234326005, Bone marrow biopsy), (49401003, Bone marrow aspiration), (167907006, Bone marrow examination), (119966007, Bone marrow excision), (119965006, Bone marrow incision), (234328006, Bone marrow trephine), (372085008, Bone marrow imaging), (234326005, Bone marrow sampling), (30438009, Bone marrow harvest), (43007001, Bone marrow operations)]
# 100  [(445925008, Lymphomatous infiltration (morphologic abnormality)), (189958005, Lymphomatous tumor, benign (morphologic abnormality)), (405952001, Parameningeal structure in the context of malignancy), (77744003, Basal lamina, inclusion in central location), (267091000, Structure of solitary lymphoid nodule of small intestine), (110459008, Malignant lymphoma, metastatic (morphologic abnormality)), (129109004, Structure of retroperitoneal region, excluding major organs), (41919003, Juvenile ca...
# 101                                                                                                                                                        [(25434003, Limited eye examination), (36228007, Examination of eye), (36228007, Eye examination), (78831002, Comprehensive eye examination), (722161008, Diabetic retinal eye exam), (397533004, Driver eye examination), (9624009, Tenectomy of eye), (21685006, Stereophotography of eye), (363115007, Exploration of eye), (373353005, Operation on eye)]
# 102                                                                                                                                                                               [(277762005, Lumbar puncture), (265232001, Diagnostic lumbar puncture), (25084003, Therapeutic lumbar puncture), (277762005, Spinal puncture), (261501006, Cervical puncture), (19062008, Cranial puncture), (273989008, Cranial puncture), (48633006, Lumbar discogram), (229318008, Lumbar traction), (57931004, Arterial puncture)]
# 103  [(303295006, Choroidal and/or retinal structures), (115237006, Osseous AND/OR chondromatous neoplasm), (312742006, Vitreous and/or retinal structures), (305089002, Conjunctival and/or corneal structures), (81016008, Intra-ocular part of optic nerve), (310787001, Lung and/or mediastinal structures), (128731008, Meningeal melanomatosis (morphologic abnormality)), (120612006, Ocular adnexal part (body structure)), (85009001, Structure of choroid of both eyes), (726420002, Meningeal melanoma (mo...
# 104                                                                  [(64144002, Pruritic rash (disorder)), (162415008, Complaining of a rash), (391000161103, Rash of periwound skin), (402953001, Pinta, generalised cutaneous phase), (402953001, Pinta, generalized cutaneous phase), (135888007, On examination - erythematous rash), (304386008, On examination - itchy rash), (284078000, Purpuric rash (disorder)), (238991008, Seborrhoeic eczema-like rash), (402748000, Pseudolymphomatous rash due to drug)]
# 105                                                                                                                                            [(5880005, Clinical examination), (386053000, Clinical evaluation), (363679005, Clinical imaging), (169283005, Clinical photography), (84100007, Clinical interview), (110465008, Clinical trial), (386053000, Clinical investigation), (164772003, Clinical examination larynx), (410183009, Clinical examination education), (164771005, Clinical examination pharynx)]
# 106                                                     [(271761007, Scaly skin (finding)), (275887009, Scaly scalp (finding)), (403466004, Micaceous and keratotic balanitis), (238760005, Symmetrical lividities of soles), (204919003, Erythematous plaques of pinta), (445394005, Dusky discolouration of skin), (445394005, Dusky discoloration of skin), (715963002, Atrichia with papular lesions), (123695006, Inflammatory hyperkeratotic dermatosis, rupial), (267637004, Corneal pigmentations and deposits)]
# 107                                                               [(204919003, Erythematous plaques of pinta), (204919003, Erythematous pinta plaque), (123701000, Crusted eczematous dermatitis), (235071003, Acute erythematous candidosis), (238946004, Reticular erythematous mucinosis), (135888007, On examination - erythematous rash), (235071003, Oral erythematous candidiasis), (123701000, Crusted eczema (disorder)), (277225007, Crusted nasal mucosa), (413224007, Erythematous duodenopathy (disorder))]
# 108  [(285688008, Difficulty weight-bearing on right leg (finding)), (285688008, Difficulty weight-bearing on right leg), (285685006, Does weight-bear on right leg), (285694000, Difficulty weight-bearing on left leg (finding)), (285685006, Weight-bears on right leg), (427359005, Solitary nodule of lung (finding)), (285694000, Difficulty weight-bearing on left leg), (285692001, Does weight-bear on left leg), (274746007, Localised swelling, mass and lump, multiple sites), (285692001, Weight-bears o...
# 109                                                                            [(91035006, Total body surface), (128178001, Body surface area), (727497004, Entire body surface area), (128178001, Body surface area (body structure)), (127947003, Structure of body surface region), (727497004, Entire body surface area (body structure)), (264104007, Diaper area (body structure)), (123957003, Percent of body surface), (730325007, Entire surface of body of sternum), (22201000087104, Affected area of body)]
# 110                                                                                                                                                                                 [(118600007, Lymphoma), (765136002, Berti lymphoma), (404143002, Crosti's lymphoma), (302841002, Lymphocytic lymphoma), (109965004, Lymphoblastic lymphoma), (118599009, Lymphoma, Hodgkins), (118600007, Malignant lymphoma), (109976000, Lymphoepithelioid lymphoma), (269476000, Nodular lymphoma), (420788006, Ocular lymphoma)]
# 111                                                                                                                                                                                                   [(56317004, Alopecia), (201137002, Alopecia localis), (238923001, Lipoedematous alopecia), (68225006, Alopecia areata), (201135005, Alopecia senilis), (19754005, Alopecia totalis), (403334008, Brush alopecia), (201136006, Alopecia febrilis), (27382006, Alopecia mucinosa), (111024006, Alopecia marginalis)]
# 112                                [(127191002, Central axillary lymphadenopathy), (127190001, Lateral axillary lymphadenopathy), (127193004, Pectoral axillary lymphadenopathy), (127192009, Apical axillary lymphadenopathy), (127123009, Left gastric lymphadenopathy), (127189005, Axillary lymphadenopathy (disorder)), (16005111000119102, Left axillary neuropathy), (164150006, On examination - axillary lymphadenopathy), (127151000, Left colic lymphadenopathy), (10631911000119108, Left axillary abscess)]
# 113                                                                                                                                                          [(276444007, Generalised pruritus), (109252001, Brachioradial summer pruritus), (52702003, Chronic fatigue syndrome), (238695001, Aquagenic pruritus), (279333002, Pruritus of skin), (276444007, Generalized pruritus), (69069001, Pruritus of penis), (279333002, Pruritus - disorder), (402178001, Brachioradial pruritus), (65645005, Pruritus scroti)]
# 114                                                                                                                                                                                                                                                                  [(415690000, Sweats), (224962007, Hot sweats), (161858001, Sweats normally), (42984000, Night sweats), (52613005, Diaphoresis), (16001004, Earache), (271811009, Flushes), (60728008, Meteorism), (70784009, Meningismus), (20154006, Pneumaturia)]
# 115                                                                                                                                                     [(89362005, Weight loss), (359649009, Weight loss diet), (267024001, Abnormal weight loss), (426977000, Recent weight loss), (309257005, Excessive weight loss), (161832001, Progressive weight loss), (416528001, Intentional weight loss), (448765001, Involuntary weight loss), (422868009, Unexplained weight loss), (448765001, Unintentional weight loss)]
# 116                                                                                                                                                                                  [(79890006, Loss of appetite), (405788002, Psychogenic loss of appetite), (289161009, Finding of appetite), (289161009, Observation of appetite), (282299006, Loss of balance), (247796005, Loss of pleasure), (277521002, Loss of motivation), (45991007, Loss of emotion), (11542009, Loss of affect), (44564008, Loss of voice)]

# %%
cancer_analysis
# Out:
#           coords                                chunk  entity  icd10cm_conf  \
# 0    0::448::461                       paratesticular  Cancer        1.0000
# 1  0::1078::1103           testicular germ cell tumor  Cancer        1.0000
# 2  0::1632::1644                        pelvic masses  Cancer        0.2407
# 3  0::2429::2463  desmoplastic small round cell tumor  Cancer        0.2029
# 4    1::370::397         chronic lymphocytic leukemia  Cancer        1.0000
# 5    1::411::430                 lymphocytic lymphoma  Cancer        1.0000
# 6    2::386::416      central nervous system lymphoma  Cancer        0.3170
# 7    3::373::380                             lymphoma  Cancer        0.3333
# 8    3::408::436        left axillary lymphadenopathy  Cancer        0.3534
#
#                                                                                                                                                                                                                                                                                                                                                                                                  icd10cm_opts  \
# 0                       [(C6290, Malignant neoplasm of unspecified testis, unspecified whether descended or undescended), (D481, Neoplasm of uncertain behavior of connective and other soft tissue), (D480, Neoplasm of uncertain behavior of bone and articular cartilage), (C480, Malignant neoplasm of retroperitoneum), (C490, Malignant neoplasm of connective and soft tissue of head, face and neck)]
# 1   [(C6290, Malignant neoplasm of unspecified testis, unspecified whether descended or undescended), (C801, Malignant (primary) neoplasm, unspecified), (C6290, Malignant neoplasm of unspecified testis, unspecified whether descended or undescended), (C6290, Malignant neoplasm of unspecified testis, unspecified whether descended or undescended), (C801, Malignant (primary) neoplasm, unspecified)]
# 2                                                                                                                                            [(C763, Malignant neoplasm of pelvis), (C763, Malignant neoplasm of pelvis), (D168, Benign neoplasm of pelvic bones, sacrum and coccyx), (D168, Benign neoplasm of pelvic bones, sacrum and coccyx), (D168, Benign neoplasm of pelvic bones, sacrum and coccyx)]
# 3                                                                        [(C3490, Malignant neoplasm of unspecified part of unspecified bronchus or lung), (C801, Malignant (primary) neoplasm, unspecified), (C179, Malignant neoplasm of small intestine, unspecified), (C784, Secondary malignant neoplasm of small intestine), (C3491, Malignant neoplasm of unspecified part of right bronchus or lung)]
# 4  [(C9110, Chronic lymphocytic leukemia of B-cell type not having achieved remission), (C9510, Chronic leukemia of unspecified cell type not having achieved remission), (C9210, Chronic myeloid leukemia, BCR/ABL-positive, not having achieved remission), (C9310, Chronic myelomonocytic leukemia not having achieved remission), (C9310, Chronic myelomonocytic leukemia not having achieved remission)]
# 5                                                                                                                      [(C8350, Lymphoblastic (diffuse) lymphoma, unspecified site), (C8300, Small cell B-cell lymphoma, unspecified site), (C8300, Small cell B-cell lymphoma, unspecified site), (C880, Waldenstrom macroglobulinemia), (C8146, Lymphocyte-rich Hodgkin lymphoma, intrapelvic lymph nodes)]
# 6                                                                  [(C8380, Other non-follicular lymphoma, unspecified site), (C8589, Other specified types of non-Hodgkin lymphoma, extranodal and solid organ sites), (C8387, Other non-follicular lymphoma, spleen), (C729, Malignant neoplasm of central nervous system, unspecified), (C729, Malignant neoplasm of central nervous system, unspecified)]
# 7                                                                                                      [(C862, Enteropathy-type (intestinal) T-cell lymphoma), (C8590, Non-Hodgkin lymphoma, unspecified, unspecified site), (C862, Enteropathy-type (intestinal) T-cell lymphoma), (C8290, Follicular lymphoma, unspecified, unspecified site), (C8290, Follicular lymphoma, unspecified, unspecified site)]
# 8                                                                                           [(R590, Localized enlarged lymph nodes), (R590, Localized enlarged lymph nodes), (C50622, Malignant neoplasm of axillary tail of left male breast), (C8514, Unspecified B-cell lymphoma, lymph nodes of axilla and upper limb), (C8594, Non-Hodgkin lymphoma, unspecified, lymph nodes of axilla and upper limb)]
#
#    icdo_conf  \
# 0     0.2512
# 1     0.2616
# 2     0.2448
# 3     0.5000
# 4     0.2257
# 5     0.2197
# 6     0.2415
# 7     0.2000
# 8     0.2280
#
#                                                                                                                                                                                                                                              icdo_opts
# 0                   [(9540/3, Malignant peripheral nerve sheath tumor), (9540/3, Malignant peripheral nerve sheath tumor), (9502/3, Teratoid medulloepithelioma), (9063/3, Spermatocytic seminoma), (9540/3, Malignant peripheral nerve sheath tumor)]
# 1                                    [(9085/3, Mixed germ cell tumor), (9065/3, Germ cell tumor, nonseminomatous), (9065/3, Germ cell tumor, nonseminomatous), (9065/3, Germ cell tumor, nonseminomatous), (9065/3, Germ cell tumor, nonseminomatous)]
# 2                                                                      [(8312/3, Renal cell carcinoma), (9350/1, Craniopharyngioma), (8000/0, Neoplasm, benign), (9351/1, Adamantinomatous craniopharyngioma), (9130/0, Hemangioendothelioma, benign)]
# 3          [(8806/3, Desmoplastic small round cell tumor), (8806/3, Desmoplastic small round cell tumor), (8806/3, Desmoplastic small round cell tumor), (8806/3, Desmoplastic small round cell tumor), (8806/3, Desmoplastic small round cell tumor)]
# 4  [(9729/3, Precursor T-cell lymphoblastic lymphoma), (9729/3, Precursor T-cell lymphoblastic lymphoma), (9805/3, Acute biphenotypic leukemia), (9729/3, Precursor T-cell lymphoblastic lymphoma), (9729/3, Precursor T-cell lymphoblastic lymphoma)]
# 5                                                                            [(9673/3, Mantle cell lymphoma), (9673/3, Mantle cell lymphoma), (9673/3, Mantle cell lymphoma), (9673/3, Mantle cell lymphoma), (9761/3, Waldenstrom macroglobulinemia)]
# 6                                                            [(9501/3, Medulloepithelioma, NOS), (9501/3, Medulloepithelioma, NOS), (9475/3, Medulloblastoma, WNT-activated), (9477/3, Medulloblastoma, non-WNT/non-SHH), (9350/1, Craniopharyngioma)]
# 7                                         [(9673/3, Mantle cell lymphoma), (9591/3, Malignant lymphoma, non-Hodgkin), (9591/3, Malignant lymphoma, non-Hodgkin), (9591/3, Malignant lymphoma, non-Hodgkin), (9591/3, Malignant lymphoma, non-Hodgkin)]
# 8                                           [(9705/3, Angioimmunoblastic T-cell lymphoma), (8312/3, Renal cell carcinoma), (9705/3, Angioimmunoblastic T-cell lymphoma), (8312/3, Renal cell carcinoma), (9705/3, Angioimmunoblastic T-cell lymphoma)]
