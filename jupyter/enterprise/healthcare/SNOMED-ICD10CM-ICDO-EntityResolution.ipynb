# %% [markdown]
# # ICD-O Entity Resolution - version 2.4.6
#
# ## Example for ICD-O Entity Resolution Pipeline
# A common NLP problem in medical applications is to identify clinical entities with the snomed codes and also cancer specific entities with their ICD10CM codes and their ICDO histology behaviour.
#
# In this example we will use Spark-NLP to identify and resolve these entities using three ontologies: SNOMED, ICD10CM and ICD-O.
#
# Some cancer related clinical notes (taken from https://www.cancernetwork.com/case-studies):
# https://www.cancernetwork.com/case-studies/large-scrotal-mass-multifocal-intra-abdominal-retroperitoneal-and-pelvic-metastases
# https://oncology.medicinematters.com/lymphoma/chronic-lymphocytic-leukemia/case-study-small-b-cell-lymphocytic-lymphoma-and-chronic-lymphoc/12133054
# https://oncology.medicinematters.com/lymphoma/epidemiology/central-nervous-system-lymphoma/12124056
# https://oncology.medicinematters.com/lymphoma/case-study-cutaneous-t-cell-lymphoma/12129416
#
# Note 0: Desmoplastic small round cell tumor
# <div style="border:2px solid #747474; background-color: #e3e3e3; margin: 5px; padding: 10px">
# A 35-year-old African-American man was referred to our urology clinic by his primary care physician for consultation about a large left scrotal mass. The patient reported a 3-month history of left scrotal swelling that had progressively increased in size and was associated with mild left scrotal pain. He also had complaints of mild constipation, with hard stools every other day. He denied any urinary complaints. On physical examination, a hard paratesticular mass could be palpated in the left hemiscrotum extending into the left groin, separate from the left testicle, and measuring approximately 10 × 7 cm in size. A hard, lower abdominal mass in the suprapubic region could also be palpated in the midline. The patient was admitted urgently to the hospital for further evaluation with cross-sectional imaging and blood work.
#
# Laboratory results, including results of a complete blood cell count with differential, liver function tests, coagulation panel, and basic chemistry panel, were unremarkable except for a serum creatinine level of 2.6 mg/dL. Typical markers for a testicular germ cell tumor were within normal limits: the beta–human chorionic gonadotropin level was less than 1 mIU/mL and the alpha fetoprotein level was less than 2.8 ng/mL. A CT scan of the chest, abdomen, and pelvis with intravenous contrast was obtained, and it showed large multifocal intra-abdominal, retroperitoneal, and pelvic masses (Figure 1). On cross-sectional imaging, a 7.8-cm para-aortic mass was visualized compressing the proximal portion of the left ureter, creating moderate left hydroureteronephrosis. Additionally, three separate pelvic masses were present in the retrovesical space, each measuring approximately 5 to 10 cm at their largest diameter; these displaced the bladder anteriorly and the rectum posteriorly.
#
# The patient underwent ultrasound-guided needle biopsy of one of the pelvic masses on hospital day 3 for definitive diagnosis. Microscopic examination of the tissue by our pathologist revealed cellular islands with oval to elongated, irregular, and hyperchromatic nuclei; scant cytoplasm; and invading fibrous tissue—as well as three mitoses per high-powered field (Figure 2). Immunohistochemical staining demonstrated strong positivity for cytokeratin AE1/AE3, vimentin, and desmin. Further mutational analysis of the cells detected the presence of an EWS-WT1 fusion transcript consistent with a diagnosis of desmoplastic small round cell tumor.
# </div>
#
# Note 1: SLL and CLL
# <div style="border:2px solid #747474; background-color: #e3e3e3; margin: 5px; padding: 10px">
# A 72-year-old man with a history of diabetes mellitus, hypertension, and hypercholesterolemia self-palpated a left submandibular lump in 2012. Complete blood count (CBC) in his internist’s office showed solitary leukocytosis (white count 22) with predominant lymphocytes for which he was referred to a hematologist. Peripheral blood flow cytometry on 04/11/12 confirmed chronic lymphocytic leukemia (CLL)/small lymphocytic lymphoma (SLL): abnormal cell population comprising 63% of CD45 positive leukocytes, co-expressing CD5 and CD23 in CD19-positive B cells. CD38 was negative but other prognostic markers were not assessed at that time. The patient was observed regularly for the next 3 years and his white count trend was as follows: 22.8 (4/2012) --> 28.5 (07/2012) --> 32.2 (12/2012) --> 36.5 (02/2013) --> 42 (09/2013) --> 44.9 (01/2014) --> 75.8 (2/2015). His other counts stayed normal until early 2015 when he also developed anemia (hemoglobin [HGB] 10.9) although platelets remained normal at 215. He had been noticing enlargement of his cervical, submandibular, supraclavicular, and axillary lymphadenopathy for several months since 2014 and a positron emission tomography (PET)/computed tomography (CT) scan done in 12/2014 had shown extensive diffuse lymphadenopathy within the neck, chest, abdomen, and pelvis. Maximum standardized uptake value (SUV max) was similar to low baseline activity within the vasculature of the neck and chest. In the abdomen and pelvis, however, there was mild to moderately hypermetabolic adenopathy measuring up to SUV of 4. The largest right neck nodes measured up to 2.3 x 3 cm and left neck nodes measured up to 2.3 x 1.5 cm. His right axillary lymphadenopathy measured up to 5.5 x 2.6 cm and on the left measured up to 4.8 x 3.4 cm. Lymph nodes on the right abdomen and pelvis measured up to 6.7 cm and seemed to have some mass effect with compression on the urinary bladder without symptoms. He underwent a bone marrow biopsy on 02/03/15, which revealed hypercellular marrow (60%) with involvement by CLL (30%); flow cytometry showed CD38 and ZAP-70 positivity; fluorescence in situ hybridization (FISH) analysis showed 13q deletion/monosomy 13; IgVH was unmutated; karyotype was 46XY.
# </div>
#
# Note 2: CNS lymphoma: https://www.icd10data.com/ICD10CM/Codes/C00-D49/C81-C96/C85-/C85.89
# <div style="border:2px solid #747474; background-color: #e3e3e3; margin: 5px; padding: 10px">
# A 56-year-old woman began to experience vertigo, headaches, and frequent falls. A computed tomography (CT) scan of the brain revealed the presence of a 1.6 x 1.6 x 2.1 cm mass involving the fourth ventricle (Figure 14.1). A gadolinium-enhanced magnetic resonance imaging (MRI) scan confirmed the presence of the mass, and a stereotactic biopsy was performed that demonstrated a primary central nervous system lymphoma (PCNSL) with a diffuse large B-cell histology. Complete blood count (CBC), lactate dehydrogenase (LDH), and beta-2-microglobulin were normal. Systemic staging with a positron emission tomography (PET)/CT scan and bone marrow biopsy showed no evidence of lymphomatous involvement outside the CNS. An eye exam and lumbar puncture showed no evidence of either ocular or leptomeningeal involvement.
# </div>
#
# Note 3: Cutaneous T-cell lymphoma
# <div style="border:2px solid #747474; background-color: #e3e3e3; margin: 5px; padding: 10px">
# An 83-year-old female presented with a progressing pruritic cutaneous rash that started 8 years ago. On clinical exam there were numerous coalescing, infiltrated, scaly, and partially crusted erythematous plaques distributed over her trunk and extremities and a large fungating ulcerated nodule on her right thigh covering 75% of her total body surface area (Figure 10.1). Lymphoma associated alopecia and a left axillary lymphadenopathy were also noted. For the past 3–4 months she reported fatigue, severe pruritus, night sweats, 20 pounds of weight loss, and loss of appetite.
# </div>

# %%
import sys, os, time, pandas as pd

sys.path.append("/home/fernandrez/JSL/repos/spark-nlp/python")
sys.path.append("/home/fernandrez/JSL/repos/spark-nlp-internal/python")

from sparknlp.base import *
from sparknlp.annotator import *
from sparknlp_jsl.annotator import *
import pyspark.sql.functions as F
from pyspark.sql.types import StructType, StructField, StringType

pd.set_option('display.max_colwidth', 250)
pd.set_option('display.max_rows', 500)

# %%
import sparknlp_jsl
sparknlp_jsl.version()
# Out:
# '2.4.7'

# %%
spark = sparknlp_jsl.start("####")

# %% [markdown]
# ## Let's create a dataset with all four case studies

# %%
notes = []
notes.append("""A 35-year-old African-American man was referred to our urology clinic by his primary care physician for consultation about a large left scrotal mass. The patient reported a 3-month history of left scrotal swelling that had progressively increased in size and was associated with mild left scrotal pain. He also had complaints of mild constipation, with hard stools every other day. He denied any urinary complaints. On physical examination, a hard paratesticular mass could be palpated in the left hemiscrotum extending into the left groin, separate from the left testicle, and measuring approximately 10 × 7 cm in size. A hard, lower abdominal mass in the suprapubic region could also be palpated in the midline. The patient was admitted urgently to the hospital for further evaluation with cross-sectional imaging and blood work.
Laboratory results, including results of a complete blood cell count with differential, liver function tests, coagulation panel, and basic chemistry panel, were unremarkable except for a serum creatinine level of 2.6 mg/dL. Typical markers for a testicular germ cell tumor were within normal limits: the beta–human chorionic gonadotropin level was less than 1 mIU/mL and the alpha fetoprotein level was less than 2.8 ng/mL. A CT scan of the chest, abdomen, and pelvis with intravenous contrast was obtained, and it showed large multifocal intra-abdominal, retroperitoneal, and pelvic masses (Figure 1). On cross-sectional imaging, a 7.8-cm para-aortic mass was visualized compressing the proximal portion of the left ureter, creating moderate left hydroureteronephrosis. Additionally, three separate pelvic masses were present in the retrovesical space, each measuring approximately 5 to 10 cm at their largest diameter; these displaced the bladder anteriorly and the rectum posteriorly.
The patient underwent ultrasound-guided needle biopsy of one of the pelvic masses on hospital day 3 for definitive diagnosis. Microscopic examination of the tissue by our pathologist revealed cellular islands with oval to elongated, irregular, and hyperchromatic nuclei; scant cytoplasm; and invading fibrous tissue—as well as three mitoses per high-powered field (Figure 2). Immunohistochemical staining demonstrated strong positivity for cytokeratin AE1/AE3, vimentin, and desmin. Further mutational analysis of the cells detected the presence of an EWS-WT1 fusion transcript consistent with a diagnosis of desmoplastic small round cell tumor.""")
notes.append("""A 72-year-old man with a history of diabetes mellitus, hypertension, and hypercholesterolemia self-palpated a left submandibular lump in 2012. Complete blood count (CBC) in his internist’s office showed solitary leukocytosis (white count 22) with predominant lymphocytes for which he was referred to a hematologist. Peripheral blood flow cytometry on 04/11/12 confirmed chronic lymphocytic leukemia (CLL)/small lymphocytic lymphoma (SLL): abnormal cell population comprising 63% of CD45 positive leukocytes, co-expressing CD5 and CD23 in CD19-positive B cells. CD38 was negative but other prognostic markers were not assessed at that time. The patient was observed regularly for the next 3 years and his white count trend was as follows: 22.8 (4/2012) --> 28.5 (07/2012) --> 32.2 (12/2012) --> 36.5 (02/2013) --> 42 (09/2013) --> 44.9 (01/2014) --> 75.8 (2/2015). His other counts stayed normal until early 2015 when he also developed anemia (hemoglobin [HGB] 10.9) although platelets remained normal at 215. He had been noticing enlargement of his cervical, submandibular, supraclavicular, and axillary lymphadenopathy for several months since 2014 and a positron emission tomography (PET)/computed tomography (CT) scan done in 12/2014 had shown extensive diffuse lymphadenopathy within the neck, chest, abdomen, and pelvis. Maximum standardized uptake value (SUV max) was similar to low baseline activity within the vasculature of the neck and chest. In the abdomen and pelvis, however, there was mild to moderately hypermetabolic adenopathy measuring up to SUV of 4. The largest right neck nodes measured up to 2.3 x 3 cm and left neck nodes measured up to 2.3 x 1.5 cm. His right axillary lymphadenopathy measured up to 5.5 x 2.6 cm and on the left measured up to 4.8 x 3.4 cm. Lymph nodes on the right abdomen and pelvis measured up to 6.7 cm and seemed to have some mass effect with compression on the urinary bladder without symptoms. He underwent a bone marrow biopsy on 02/03/15, which revealed hypercellular marrow (60%) with involvement by CLL (30%); flow cytometry showed CD38 and ZAP-70 positivity; fluorescence in situ hybridization (FISH) analysis showed 13q deletion/monosomy 13; IgVH was unmutated; karyotype was 46XY.""")
notes.append("A 56-year-old woman began to experience vertigo, headaches, and frequent falls. A computed tomography (CT) scan of the brain revealed the presence of a 1.6 x 1.6 x 2.1 cm mass involving the fourth ventricle (Figure 14.1). A gadolinium-enhanced magnetic resonance imaging (MRI) scan confirmed the presence of the mass, and a stereotactic biopsy was performed that demonstrated a primary central nervous system lymphoma (PCNSL) with a diffuse large B-cell histology. Complete blood count (CBC), lactate dehydrogenase (LDH), and beta-2-microglobulin were normal. Systemic staging with a positron emission tomography (PET)/CT scan and bone marrow biopsy showed no evidence of lymphomatous involvement outside the CNS. An eye exam and lumbar puncture showed no evidence of either ocular or leptomeningeal involvement.") 
notes.append("An 83-year-old female presented with a progressing pruritic cutaneous rash that started 8 years ago. On clinical exam there were numerous coalescing, infiltrated, scaly, and partially crusted erythematous plaques distributed over her trunk and extremities and a large fungating ulcerated nodule on her right thigh covering 75% of her total body surface area (Figure 10.1). Lymphoma associated alopecia and a left axillary lymphadenopathy were also noted. For the past 3–4 months she reported fatigue, severe pruritus, night sweats, 20 pounds of weight loss, and loss of appetite.")

# Notes column names

docid_col         = "doc_id"
note_col          = "description"

data = spark.createDataFrame([(i,n.lower(),) for i,n in enumerate(notes)], 
                             StructType([StructField(docid_col, StringType()),
                                         StructField(note_col, StringType())]))

# %% [markdown]
# ## And let's build a SparkNLP pipeline with the following stages:
# - DocumentAssembler: Entry annotator for our pipelines; it creates the data structure for the Annotation Framework
# - SentenceDetector: Annotator to pragmatically separate complete sentences inside each document
# - Tokenizer: Annotator to separate sentences in tokens (generally words)
# - WordEmbeddings: Vectorization of word tokens, in this case using word embeddings trained from PubMed, ICD10 and other clinical resources.
# - ChunkEmbeddings: Aggregates the WordEmbeddings for each NER Chunk
# - Clinical NER + NerConverter: This annotators return Chunks related to generic clinical entities
# - BioNLP NER + NerConverter: This annotators return Chunks related to Cancer and Genetics diseases
# - ChunkEntityResolver: Annotator that performs search for the KNNs, in this case trained from ICDO Histology Behavior.

# %%
#Language and Model Repository

models_language   = "en"
models_repository = "clinical/models"

# %%
# Embeddings Pretrained Model Name

embeddings_name   = "embeddings_clinical"

# Preparation and embeddings column names

doc_col           = "document"
sent_col          = "sentence"
token_col         = "token"
embeddings_col    = "embeddings"

# Usual preparation Annotators and Embeddings

docAssembler = DocumentAssembler().setInputCol(note_col).setOutputCol(doc_col)
sentenceDetector = SentenceDetector().setInputCols(doc_col).setOutputCol(sent_col)
tokenizer_chars = [",","\/"," ",".","|","@","#","%","&","\\$","\\[","\\]","\\(","\\)","\\-",";"]
tokenizer = Tokenizer().setSplitChars(tokenizer_chars)\
    .setInputCols(sent_col).setOutputCol(token_col)
embeddings = WordEmbeddingsModel.pretrained(embeddings_name, models_language, models_repository)\
    .setInputCols(sent_col, token_col)\
    .setOutputCol(embeddings_col)
# Out:
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]

# %%
# NER Pretrained Model Names

clinical_ner_name = "ner_clinical"
cancer_ner_name   = "ner_bionlp"

# NER Column Names

ner_clinical_col  = "ner_clinical"
ner_bio_col       = "ner_bio"

# Annotators responsible for the Cancer Genetics Entity Recognition task

clinicalNer = NerDLModel.pretrained(clinical_ner_name, models_language, models_repository)\
    .setInputCols(sent_col, token_col, embeddings_col)\
    .setOutputCol(ner_clinical_col)

bioNer = NerDLModel.pretrained(cancer_ner_name, models_language, models_repository)\
    .setInputCols(sent_col, token_col, embeddings_col)\
    .setOutputCol(ner_bio_col)
# Out:
# ner_clinical download started this may take some time.
# Approximate size to download 13.8 MB
# [OK!]
# ner_bionlp download started this may take some time.
# Approximate size to download 13.9 MB
# [OK!]

# %%
# Chunk column names

chunk_clinical_col = "chunk_clinical"
chunk_cancer_col   = "chunk_cancer"

#Converter annotators transform IOB tags into full chunks (sequence set of tokens) tagged with `entity` metadata

clinicalConverter = NerConverter().setInputCols(sent_col, token_col, ner_clinical_col)\
    .setOutputCol(chunk_clinical_col)
cancerConverter = NerConverter().setInputCols(sent_col, token_col, ner_bio_col)\
    .setOutputCol(chunk_cancer_col).setWhiteList(['Cancer']) # We whitelist just `Cancer` entities

# %%
# ChunkEmbeddings column names

chunk_embs_clinical_col = "chunk_embs_clinical"
chunk_embs_cancer_col   = "chunk_embs_cancer"

#ChunkEmbeddings annotators aggregate embeddings for each token in the chunk

clinicalChunkEmbeddings = ChunkEmbeddings()\
  .setInputCols(chunk_clinical_col, embeddings_col)\
  .setOutputCol(chunk_embs_clinical_col)
cancerChunkEmbeddings = ChunkEmbeddings()\
  .setInputCols(chunk_cancer_col, embeddings_col)\
  .setOutputCol(chunk_embs_cancer_col)

# %%
# ChunkTokenizer column names

chunk_token_clinical_col = "chunk_token_clinical"
chunk_token_cancer_col   = "chunk_token_cancer"

# ChunkTokenizer provides extra flexibility at the time of tokenizing a given chunk

clinicalChunkTokenizer = ChunkTokenizer().setSplitChars(tokenizer_chars)\
    .setInputCols(chunk_clinical_col).setOutputCol(chunk_token_clinical_col)
cancerChunkTokenizer = ChunkTokenizer().setSplitChars(tokenizer_chars)\
    .setInputCols(chunk_cancer_col).setOutputCol(chunk_token_cancer_col)

# %%
# Entity Resolution Pretrained Model Names

snomed_model_name           = "ensembleresolve_snomed_clinical"
icd10cm_model_name   = "chunkresolve_icd10cm_neoplasms_clinical"
icd_model_name              = "chunkresolve_icdo_clinical"

# Entity Resolution column Names

snomed_token_col,snomed_chunk_col,snomed_embs_col = chunk_token_clinical_col,chunk_clinical_col,chunk_embs_clinical_col
#snomed_token_col,snomed_chunk_col,snomed_embs_col = chunk_token_bio_col,chunk_bio_col,chunk_embs_bio_col

snomed_clinical_col  = "snomed_resolution"
icd10cm_col   = "icd10cm_resolution"
icdo_col      = "icdo_resolution" 

snomedResolver = EnsembleEntityResolverModel()\
    .pretrained(snomed_model_name, models_language, models_repository)\
    .setEnableLevenshtein(True)\
    .setNeighbours(200).setAlternatives(5).setDistanceWeights([1,3,2,0,0,4])\
    .setExtramassPenalty(1).setPoolingStrategy("MAX")\
    .setInputCols(snomed_token_col, snomed_embs_col)\
    .setOutputCol(snomed_clinical_col)\
    
icd10cmResolver = ChunkEntityResolverModel\
    .pretrained(icd10cm_model_name, models_language, models_repository)\
    .setEnableLevenshtein(True)\
    .setNeighbours(200).setAlternatives(5).setDistanceWeights([1,3,2,0,0,4])\
    .setExtramassPenalty(1).setPoolingStrategy("MAX")\
    .setInputCols(chunk_token_cancer_col, chunk_embs_cancer_col)\
    .setOutputCol(icd10cm_col)

icdoResolver = ChunkEntityResolverModel\
    .pretrained(icd_model_name, models_language, models_repository)\
    .setEnableLevenshtein(True)\
    .setNeighbours(200).setAlternatives(5).setDistanceWeights([1,3,2,0,0,4])\
    .setExtramassPenalty(1).setPoolingStrategy("MAX")\
    .setInputCols(chunk_token_cancer_col, chunk_embs_cancer_col)\
    .setOutputCol(icdo_col)
# Out:
# ensembleresolve_snomed_clinical download started this may take some time.
# Approximate size to download 592.9 MB
# [OK!]
# chunkresolve_icd10cm_neoplasms_clinical download started this may take some time.
# Approximate size to download 15.4 MB
# [OK!]
# chunkresolve_icdo_clinical download started this may take some time.
# Approximate size to download 8.2 MB
# [OK!]

# %%
pipelineFull = Pipeline().setStages([
    docAssembler, 
    sentenceDetector, 
    tokenizer, 
    embeddings, 
    clinicalNer,
    bioNer,
    clinicalConverter,
    cancerConverter,
    clinicalChunkEmbeddings, 
    cancerChunkEmbeddings, 
    clinicalChunkTokenizer,
    cancerChunkTokenizer,
    snomedResolver,
    icd10cmResolver,
    icdoResolver
])

# %%
pipelineModelFull = pipelineFull.fit(data)

# %%
output = pipelineModelFull.transform(data).cache()

# %% [markdown]
# ## The key parts of our model are the **WordEmbeddings and ChunkEntityResolver**:
#
# ### WordEmebeddings:
# Word2Vec model trained on semantically augmented datasets using information from curated Datasets in JSL Data Market.
#
# ### EntityResolver:
# Trained on an augmented ICDO Dataset from JSL Data Market it provides histology codes resolution for the matched expressions. Other than providing the code in the "result" field it provides more metadata about the matching process:
#
# - all_k_results -> Sorted ResolverLabels in the top `alternatives` that match the distance `threshold`
# - all_k_resolutions -> Respective ResolverNormalized strings
# - all_k_distances -> Respective distance values after aggregation
# - all_k_wmd_distances -> Respective WMD distance values (added if allDistancesMetadata==True)
# - all_k_tfidf_distances -> Respective TFIDF Cosine distance values (added if allDistancesMetadata==True)
# - all_k_jaccard_distances -> Respective Jaccard distance values (added if allDistancesMetadata==True)
# - all_k_sorensen_distances -> Respective SorensenDice distance values (added if allDistancesMetadata==True)
# - all_k_jaro_distances -> Respective JaroWinkler distance values (added if allDistancesMetadata==True)
# - all_k_levenshtein_distances -> Respective Levenshtein distance values (added if allDistancesMetadata==True)
# - all_k_confidences -> Respective normalized probabilities based in inverse distance valuesprobability (added if allDistancesMetadata==True)
# - target_text -> The actual searched string
# - resolved_text -> The top ResolverNormalized string
# - confidence -> Top probability
# - distance -> Top distance value
# - sentence -> Sentence index
# - chunk -> Chunk Index
# - token -> Token index

# %%
def quick_metadata_analysis(df, doc_field, chunk_field, code_fields):
    code_res_meta = ", ".join([f"{cf}.result, {cf}.metadata" for cf in code_fields])
    expression = f"explode(arrays_zip({chunk_field}.begin, {chunk_field}.end, {chunk_field}.result, {chunk_field}.metadata, "+code_res_meta+")) as a"
    top_n_rest = [(f"a['{2*i+4}'] as {(cf.split('_')[0])}",
                   f"float(a['{2*i+5}'].distance) as {(cf.split('_')[0])}_dst",
                   f"a['{2*i+5}'].confidence as {(cf.split('_')[0])}_conf",
                    f"split(a['{2*i+5}'].all_k_resolutions,':::') as {cf.split('_')[0]+'_opts'}")
                    for i, cf in enumerate(code_fields)]
    top_n_rest_args = []
    for tr in top_n_rest:
        for t in tr:
            top_n_rest_args.append(t)
    return df.selectExpr(doc_field, expression) \
        .orderBy(docid_col, F.expr("a['0']"), F.expr("a['1']"))\
        .selectExpr(f"concat_ws('::',{doc_field},a['0'],a['1']) as coords", "a['2'] as chunk","a['3'].entity as entity", *top_n_rest_args)

# %%
snomed_analysis = \
quick_metadata_analysis(output, docid_col, snomed_chunk_col,[snomed_clinical_col]).toPandas()

# %%
cancer_analysis = \
quick_metadata_analysis(output, docid_col, chunk_cancer_col,[icd10cm_col, icdo_col]).toPandas()

# %%
snomed_analysis[snomed_analysis.snomed_dst<3]
# Out:
#             coords  \
# 0      0::123::147
# 1      0::192::212
# 3      0::279::300
# 4      0::329::345
# 5      0::353::363
# 6      0::396::413
# 7      0::419::438
# 8      0::441::466
# 9      0::621::673
# 10     0::768::785
# 11     0::808::814
# 12     0::820::829
# 13     0::873::899
# 14     0::906::939
# 15     0::942::958
# 17   0::1017::1040
# 19   0::1076::1103
# 20   0::1132::1174
# 21   0::1203::1229
# 22   0::1256::1324
# 24   0::1409::1427
# 25   0::1454::1460
# 26   0::1463::1487
# 27   0::1566::1600
# 28   0::1603::1644
# 30   0::1860::1872
# 31   0::1888::1900
# 32   0::1946::1982
# 35   0::2091::2105
# 36   0::2112::2137
# 37   0::2196::2223
# 39   0::2260::2288
# 43   0::2429::2463
# 44       1::36::66
# 46     1::143::162
# 49     1::316::346
# 50     1::370::397
# 51     1::411::430
# 52     1::439::462
# 53     1::496::524
# 56     1::700::714
# 58     1::935::950
# 59     1::975::983
# 60   1::1030::1088
# 61   1::1095::1118
# 62   1::1154::1183
# 63   1::1200::1209
# 64   1::1216::1219
# 65   1::1247::1323
# 66   1::1326::1367
# 68   1::1674::1707
# 69   1::1782::1824
# 70   1::1867::1882
# 71   1::1889::1922
# 72   1::1932::1939
# 73   1::1955::1974
# 74   1::2004::2023
# 76   1::2062::2075
# 79   1::2112::2145
# 80   1::2154::2161
# 82   1::2216::2224
# 84       2::64::77
# 85      2::80::100
# 86     2::107::123
# 88     2::222::269
# 89     2::277::280
# 90     2::308::315
# 91     2::322::342
# 92     2::376::416
# 93     2::431::462
# 94     2::465::484
# 95     2::493::513
# 96     2::560::575
# 97     2::582::611
# 98     2::622::625
# 99     2::631::648
# 101    2::714::724
# 102    2::730::744
# 104      3::37::73
# 105    3::104::116
# 107    3::174::211
# 109    3::330::362
# 110    3::373::380
# 111    3::393::400
# 112    3::406::436
# 113    3::492::515
# 114    3::524::529
# 115    3::545::555
# 116    3::562::577
#
#                                                                              chunk  \
# 0                                                        a large left scrotal mass
# 1                                                            left scrotal swelling
# 3                                                           mild left scrotal pain
# 4                                                                mild constipation
# 5                                                                      hard stools
# 6                                                               urinary complaints
# 7                                                             physical examination
# 8                                                       a hard paratesticular mass
# 9                            a hard, lower abdominal mass in the suprapubic region
# 10                                                              further evaluation
# 11                                                                         imaging
# 12                                                                      blood work
# 13                                                     a complete blood cell count
# 14                                              differential, liver function tests
# 15                                                               coagulation panel
# 17                                                        a serum creatinine level
# 19                                                    a testicular germ cell tumor
# 20                                     the beta–human chorionic gonadotropin level
# 21                                                     the alpha fetoprotein level
# 22           a ct scan of the chest, abdomen, and pelvis with intravenous contrast
# 24                                                             pelvic masses (figu
# 25                                                                         imaging
# 26                                                       a 7.8-cm para-aortic mass
# 27                                             moderate left hydroureteronephrosis
# 28                                      additionally, three separate pelvic masses
# 30                                                                   needle biopsy
# 31                                                                   pelvic masses
# 32                                           microscopic examination of the tissue
# 35                                                                 scant cytoplasm
# 36                                                      invading fibrous tissue—as
# 37                                                    immunohistochemical staining
# 39                                                   cytokeratin ae1/ae3, vimentin
# 43                                             desmoplastic small round cell tumor
# 44                                                 diabetes mellitus, hypertension
# 46                                                            complete blood count
# 49                                                 peripheral blood flow cytometry
# 50                                                    chronic lymphocytic leukemia
# 51                                                            lymphocytic lymphoma
# 52                                                        abnormal cell population
# 53                                                   leukocytes, co-expressing cd5
# 56                                                                 his white count
# 58                                                                anemia (hemoglob
# 59                                                                       platelets
# 60                     enlargement of his cervical, submandibular, supraclavicular
# 61                                                        axillary lymphadenopathy
# 62                                                  a positron emission tomography
# 63                                                                      tomography
# 64                                                                            scan
# 65   extensive diffuse lymphadenopathy within the neck, chest, abdomen, and pelvis
# 66                                      maximum standardized uptake value (suv max
# 68                                              his right axillary lymphadenopathy
# 69                                     lymph nodes on the right abdomen and pelvis
# 70                                                                some mass effect
# 71                                              compression on the urinary bladder
# 72                                                                        symptoms
# 73                                                            a bone marrow biopsy
# 74                                                            hypercellular marrow
# 76                                                                  flow cytometry
# 79                                              fluorescence in situ hybridization
# 80                                                                        analysis
# 82                                                                       karyotype
# 84                                                                  frequent falls
# 85                                                           a computed tomography
# 86                                                               scan of the brain
# 88                                a gadolinium-enhanced magnetic resonance imaging
# 89                                                                            scan
# 90                                                                        the mass
# 91                                                           a stereotactic biopsy
# 92                                       a primary central nervous system lymphoma
# 93                                                a diffuse large b-cell histology
# 94                                                            complete blood count
# 95                                                           lactate dehydrogenase
# 96                                                                systemic staging
# 97                                                  a positron emission tomography
# 98                                                                            scan
# 99                                                              bone marrow biopsy
# 101                                                                    an eye exam
# 102                                                                lumbar puncture
# 104                                          a progressing pruritic cutaneous rash
# 105                                                                  clinical exam
# 107                                         partially crusted erythematous plaques
# 109                                              her total body surface area (figu
# 110                                                                       lymphoma
# 111                                                                       alopecia
# 112                                                a left axillary lymphadenopathy
# 113                                                       fatigue, severe pruritus
# 114                                                                         sweats
# 115                                                                    weight loss
# 116                                                               loss of appetite
#
#       entity             snomed  snomed_dst snomed_conf  \
# 0    PROBLEM  12240181000119103      2.5600      0.4150
# 1    PROBLEM  15952141000119106      1.9707      0.7348
# 3    PROBLEM          722829006      1.7024      0.6669
# 4    PROBLEM          111360009      2.2277      0.3581
# 5    PROBLEM           75295004      0.0000      0.9785
# 6    PROBLEM          264832001      2.6279      0.3346
# 7       TEST            5880005      0.0000      0.5778
# 8    PROBLEM    102031000119109      2.5000      0.5384
# 9    PROBLEM          163293006      2.5434      0.4674
# 10      TEST          165171009      2.3180      0.4525
# 11      TEST          363679005      0.0000      0.8721
# 12      TEST          224363007      2.1267      0.6204
# 13      TEST           26604007      1.0370      0.9243
# 14      TEST          270954007      1.5520      0.4005
# 15      TEST            3116009      1.0435      0.9049
# 17      TEST          313822004      1.1250      0.4185
# 19   PROBLEM          277508009      1.6246      0.6254
# 20      TEST           67900009      1.0000      0.3097
# 21      TEST          391290009      1.2347      0.5292
# 22      TEST          726552004      1.4048      0.2839
# 24   PROBLEM           16293003      2.2264      0.7414
# 25      TEST          363679005      0.0000      0.8721
# 26   PROBLEM  14160001000004107      2.4000      0.6904
# 27   PROBLEM       981000124106      2.2609      0.8359
# 28   PROBLEM          720016003      2.9799      0.7044
# 30      TEST          129249002      0.0000      0.5074
# 31   PROBLEM           16293003      2.2264      0.2901
# 32      TEST          608857000      1.5439      0.2530
# 35   PROBLEM           62035001      1.6000      0.9913
# 36   PROBLEM          402870005      2.2737      0.5418
# 37      TEST          196317007      2.8684      0.7307
# 39      TEST          259987000      1.8000      0.9221
# 43   PROBLEM          128735004      0.0000      0.9874
# 44   PROBLEM           73211009      1.7333      0.3034
# 46      TEST           26604007      0.0000      0.9395
# 49      TEST           64444005      2.1935      0.3598
# 50   PROBLEM          277473004      1.0000      0.3562
# 51   PROBLEM          302841002      0.0000      0.9633
# 52   PROBLEM          125391008      1.5072      0.4229
# 53      TEST           93131008      2.5714      0.3125
# 56      TEST          391558003      1.9808      0.6282
# 58   PROBLEM           47100003      2.2857      0.4163
# 59      TEST           16378004      0.0000      1.0000
# 60   PROBLEM          284369001      2.6847      0.4810
# 61   PROBLEM          127189005      0.0000      0.4029
# 62      TEST           82918005      0.5000      0.6009
# 63      TEST           46377000      1.7778      0.5153
# 64      TEST           41747008      2.2222      0.4095
# 65   PROBLEM          269151006      2.3243      0.7296
# 66      TEST          397876009      2.6341      0.3816
# 68   PROBLEM          127189005      1.1765      0.6428
# 69   PROBLEM          782166005      2.4186      0.4029
# 70   PROBLEM          415777001      2.7692      0.4881
# 71   PROBLEM          397732007      1.7853      0.3739
# 72   PROBLEM          249306007      1.5385      0.2894
# 73      TEST          234326005      0.5000      0.8103
# 74   PROBLEM          446409001      2.0724      0.9962
# 76      TEST           64444005      0.0000      0.9804
# 79      TEST          426329006      0.0000      0.8673
# 80      TEST           33353001      1.5385      0.2328
# 82      TEST          734840008      0.0000      0.9922
# 84   PROBLEM          279992002      2.0848      0.8335
# 85      TEST          241571002      1.4152      0.2325
# 86      TEST             807005      2.0089      0.3228
# 88      TEST          113091000      0.5536      0.4045
# 89      TEST           41747008      2.2222      0.4095
# 90   PROBLEM  14160001000004107      2.4000      0.8213
# 91      TEST          171491002      1.5714      0.9691
# 92   PROBLEM          307649006      0.3333      0.9484
# 93   PROBLEM           40935003      2.6742      0.7934
# 94      TEST           26604007      0.0000      0.9395
# 95      TEST           67568008      1.0000      0.2944
# 96      TEST          706904009      2.8389      0.9814
# 97      TEST           82918005      0.5000      0.6009
# 98      TEST           41747008      2.2222      0.4095
# 99      TEST          234326005      0.0000      0.7156
# 101     TEST           25434003      2.4348      0.6288
# 102     TEST          277762005      0.0000      0.8748
# 104  PROBLEM          162415008      2.8108      0.5059
# 105     TEST            5880005      1.5306      0.5858
# 107  PROBLEM          204919003      2.8421      0.8592
# 109  PROBLEM           91035006      1.7500      0.7888
# 110  PROBLEM          118600007      0.0000      0.9066
# 111  PROBLEM           56317004      0.0000      0.8927
# 112  PROBLEM          127191002      1.6958      0.3135
# 113  PROBLEM          276444007      2.4264      0.4239
# 114  PROBLEM          415690000      0.0000      0.9101
# 115  PROBLEM           89362005      0.0000      0.7306
# 116  PROBLEM           79890006      0.0000      0.8414
#
#                                                                                                                                                                                                                                                    snomed_opts
# 0                                                                                                        [Mass in left breast, Mass of scrotum, Mass of left ovary, On examination - left lower abdominal mass, Mass of left lower quadrant of abdominal wall]
# 1                                                                                                                                               [Left parotid gland swelling, Groin swelling, Right parotid gland swelling, Calabar swelling, Pelvic swelling]
# 3                                                                                                                                                [Acute scrotal pain, Left inguinal pain, Left flank pain, Left sided abdominal pain, Left hypochondrial pain]
# 4                                                                                                                                             [Intractable constipation, Mild dietary indigestion, Functional constipation, Mild asthma, Spastic constipation]
# 5                                                                                                                                                                                          [Hard stools, Loose stools, Black stools, Red stools, Green stools]
# 6                                                                                                                                              [Urinary eosinophils, Urinary casts, Multiple complaints, Abnormal urinary product, Urinary reducing substance]
# 7                                                                                                         [Physical examination, Periodic physical examination, Physical examination maneuver, Physical examination, limited, Physical examination management]
# 8                                                                                                                                                    [Paratesticular mass (disorder), Observation of a mass, Mass of testicle, Mass of sacrum, Mass of axilla]
# 9                                [On examination - abdominal mass-very hard, Nonallopathic lesion of abdominal region, On examination - abdominal mass - lower border defined, Mass of abdominal cavity structure (finding), Mass of abdominal wall (finding)]
# 10                                                                            [Initial psychiatric evaluation, Preanaesthesia evaluation, Cardiovascular examination and evaluation, Comprehensive interview and evaluation, Limited interview and evaluation]
# 11                                                                                                                                                                                       [Imaging, Bone imaging, Chest imaging, Video imaging, Spleen imaging]
# 12                                                                                                                                                                                     [In work, Stopped work, Uncongenial work, Demoted at work, Out of work]
# 13                                                            [Complete blood count, Complete blood count without differential, Total white blood cell count (procedure), Differential white blood cell count procedure, White blood cell count - observation]
# 14                                                                                                                                   [Differential renal function, Liver function test, Digestive function tests, Gastric function tests, Lung function tests]
# 15                                                                                                                                                     [Blood coagulation panel, Coagulation panel for thrombosis, Lipid panel, Obstetric panel, Kidney panel]
# 17                                                                                                                  [Corrected serum creatinine level, Plasma creatinine level, Serum vitamin A level, Corrected plasma creatinine level, Serum albumin level]
# 19                                                                        [Pineal germ cell tumour, Cervical malignant germ cell tumor, Suprasellar germ cell tumor (disorder), Nonseminomatous germ cell tumor of testis, Malignant germ cell tumor of ovary]
# 20                                  [Human chorionic gonadotropin level, Urine chorionic gonadotropin level, Total beta human chorionic gonadotropin level, Free beta human chorionic gonadotropin level, Plasma free beta human chorionic gonadotropin level]
# 21                                                                                               [Fluid sample alpha fetoprotein level, Maternal serum alpha-fetoprotein level, Serum alpha-fetoprotein, Alpha carotene level, Urine alpha-aminoadipate level]
# 22   [CT of thorax, abdomen and pelvis with oral contrast, Computed tomography of thorax, abdomen and pelvis with oral and intravenous contrast, CT of abdomen and pelvis with oral contrast, Computed tomography of abdomen and pelvis with oral and intra...
# 24                                                                                             [Pelvic osteoclasis, Pelvic exenteration, female, Pelvic lymphangiography, bilateral, Operation on pelvic region of trunk, Procedure on pelvic region of trunk]
# 25                                                                                                                                                                                       [Imaging, Bone imaging, Chest imaging, Video imaging, Spleen imaging]
# 26                                                                                                                                                                 [Vallecular mass, Tubo-ovarian mass, Observation of a mass, Mass of testis, Mass in breast]
# 27                                                                                                 [Moderate left ventricular systolic dysfunction, Left dacryostenosis, Chronic left tympanitis, Left hemitruncus, Congenital left vesicoureterorenal reflux]
# 28                                                             [Nonallopathic lesion of pelvic region, Tuberculosis of the pelvic and thigh bones, Arthralgia of the pelvic region and thigh, Large pelvic bone (finding), Mass of pelvic structure (finding)]
# 30                                                                                                                                                          [Needle biopsy, Needle bone biopsy, Fine needle biopsy, Core needle biopsy, Needle biopsy of lung]
# 31                                                                                                                                                        [Pelvic osteoclasis, Pelvic lymphangiogram, Pelvic pneumography, Pelvic echography, Pelvic venogram]
# 32   [Microscopic examination of specimen from perirenal tissue, Microscopic examination of blood specimen, Microscopic examination of specimen from perivesical tissue, Microscopic examination of specimen from skin, Microscopic examination of specimen...
# 35                                                                                                                                [Cytoplasm, Scant hemorrhage, Mitochondrial aggregation within cytoplasm, Cytoplasm, prokaryotic, Cytoplasmic hyalinisation]
# 36                                                      [Reactive fibrous tissue proliferation, Angiomatoid fibrous histiocytoma of skin, Malignant fibrous histiocytoma of skin, Solitary fibrous tumor of pleura, Inflammatory fibrous hyperplasia of mouth]
# 37                                                                                                                        [Posteruptive teeth staining, Staining of skin, Corneal blood staining, Posteruptive staining of tooth, Intrinsic staining of tooth]
# 39                                                                                                                                                      [Cytokeratin, Cytokeratin antibody, Cytokeratin 19, Antibody to cytokeratin filaments, Cytokeratin 20]
# 43                                                                                                                              [Desmoplastic small round cell tumor, Chondromatous giant cell tumor, Clear cell tumor, Granular cell tumor, Giant cell tumor]
# 44                                                                                                                    [Diabetes mellitus, Diabetes mellitus in childbirth, Diabetes mellitus in remission, Diabetes mellitus type 2, Diabetes mellitus type 1]
# 46                                                                                                                 [Complete blood count, Total white blood count, Complete blood count without differential, Blood cell count, Platelet count, blood, manual]
# 49                                                                                                                                 [Flow cytometry, Blood flow tests, Regional blood flow study, Arterial blood flow test, Reticulocyte count, flow cytometry]
# 50                                                                              [B-cell chronic lymphocytic leukemia, T-cell chronic lymphocytic leukemia, Chronic lymphoid leukemia, B-cell chronic lymphocytic leukemia variant, Chronic monocytic leukemia]
# 51                                                                                                                                          [Lymphocytic lymphoma, Lymphoblastic lymphoma, Burkitt lymphoma, Plasmacytic lymphoma, Lymphoepithelioid lymphoma]
# 52                                                                                                                                                  [Abnormal cell size, Abnormal cell structure, Abnormal cell, Abnormal red blood cell, Abnormal blood cell]
# 53                                                                                                                                                                           [Leptocephaly, Leukorrhoea, Pneumopyopericardium, Tenonitis, Pseudochromhidrosis]
# 56                                                                                                                                 [Total white blood count, White blood cell count, Differential white blood cell count, Metamyelocyte count, Organism count]
# 58                                                                                                                                       [Anemia of prematurity, Anemia, Anemia of diabetes, Anemia related to kwashiorkor, Anemia following fetal blood loss]
# 59                                                                                                                                                                                         [Platelets, Microthrombus, Schistocyte, Acanthocyte, Prolymphocyte]
# 60                                                 [Examination of submandibular gland, Exploration of supraclavicular fossa, Supraclavicular cervical sympathectomy (procedure), Excision of right submandibular gland, Excision of left submandibular gland]
# 61                                                                                          [Axillary lymphadenopathy, Apical axillary lymphadenopathy, Lateral axillary lymphadenopathy, Central axillary lymphadenopathy, Pectoral axillary lymphadenopathy]
# 62                                           [Positron emission tomography, Positron emission tomography of brain, Positron emission tomography heart study, Positron emission tomography breast study, Positron emission tomography with computed tomography]
# 63                                                                                                                                         [Cardiac tomography, Tomography - chest, Diagnostic tomography, Computerized tomography, Computed tomography ovary]
# 64                                                                                                                                                                                             [Bone scan, Milk scan, Kidney scan, Booking scan, Gallium scan]
# 65                  [Internal injury of chest, abdomen and pelvis, Lymphadenopathy of head AND/OR neck, Head and neck lymphadenopathy (disorder), Injury of blood vessels of abdomen AND/OR pelvis, Injury of multiple blood vessels of abdomen AND/OR pelvis]
# 66                                                                    [Max 5 (qualifier value), Max (qualifier value), Maximum intercuspation technique (qualifier value), Standardized technique (qualifier value), Thallium uptake method (qualifier value)]
# 68                                                                                          [Axillary lymphadenopathy, Lateral axillary lymphadenopathy, Central axillary lymphadenopathy, Pectoral axillary lymphadenopathy, Apical axillary lymphadenopathy]
# 69                                            [Enostosis of right pelvis, Injury of blood vessels of abdomen AND/OR pelvis, Internal injury of chest, abdomen and pelvis, Injury of multiple blood vessels of abdomen AND/OR pelvis, Enostosis of left pelvis]
# 70                                                                                                                           [Unit of mass concentration, Entitic mass (property), Mass rate (property), Mass ratio (property), Mass concentration (property)]
# 71                                                                                        [Neurogenic dysfunction of the urinary bladder, Tumor of urinary bladder, Mass of urinary bladder, Fibrosis of urinary bladder, Neoplasm of apex of urinary bladder]
# 72                                                                                                                                                                             [Nose symptoms, Anal symptoms, Tooth symptoms, Mouth symptoms, Visual symptoms]
# 73                                                                                                                                       [Bone marrow biopsy, Non-surgical bone marrow biopsy, Bone marrow culture, Bone marrow imaging, Bone marrow excision]
# 74                                                                                                                     [Normocellular bone marrow, Bone marrow suppression, Bone marrow megaloblastic, Bone marrow erythropoiesis, Bone marrow megakaryocytes]
# 76                                                                                                      [Flow cytometry, Flow cytometric crossmatch, Flow cytometry, ploidy analysis, Reticulocyte count, flow cytometry, Flow cytometry, cell cycle analysis]
# 79   [Fluorescence in situ hybridization, Computer assisted fluorescence in situ hybridization, Breakpoint analysis of deoxyribonucleic acid using fluorescence in situ hybridization, Human epidermal growth factor receptor 2 gene detection by fluoresce...
# 80                                                                                                                                                                                 [Food analysis, Work analysis, Ego analysis, Game analysis, Image analysis]
# 82                                                                                                                                                                              [Karyotype, Karyotype morphology, Hypodiploidy, Tetraploidy, Karyotype 46, XY]
# 84                                                                                                                                      [Recurrent falls, Observation of falls, Falls infrequently, Falls caused by medication, Finding of frequency of falls]
# 85                                                                                                            [Computed tomography of hip, Computed tomography of head, Computed tomography of hand, Computed tomography of knee, Computed tomography of neck]
# 86                                                                                                                    [Excision of tissue of brain, Destruction of tissue of brain, Imaging of brain, Exploration of ventricle of brain, Exploration of brain]
# 88                                                                                [Magnetic resonance imaging, Magnetic resonance imaging of hip, Vascular magnetic resonance imaging, Magnetic resonance imaging of hand, Magnetic resonance imaging of limb]
# 89                                                                                                                                                                                             [Bone scan, Milk scan, Kidney scan, Booking scan, Gallium scan]
# 90                                                                                                                                  [Vallecular mass, Subcutaneous mass of head, Pulsatile mass of abdomen, Mass in both breasts, Mass of both adrenal glands]
# 91                                                               [Stereotactic biopsy of brain, Jejunoscopy and biopsy, Stereotactic excisional biopsy of intracranial lesion, Oesophagogastroduodenoscopy and biopsy, Laryngotracheobronchoscopy with biopsy]
# 92                                                   [Primary central nervous system lymphoma, Ependymoma of central nervous system, Tuberculosis of central nervous system, Neuroblastoma of central nervous system, Cysticercosis of central nervous system]
# 93                                                     [Diffuse meningiomatosis, Structure of large intestine, Diffuse angiectasis (morphologic abnormality), Malignant lymphoma, large cell, noncleaved, diffuse, Diffuse embryoma (morphologic abnormality)]
# 94                                                                                                                 [Complete blood count, Total white blood count, Complete blood count without differential, Blood cell count, Platelet count, blood, manual]
# 95                                                                                                         [D-lactate dehydrogenase, L-lactate dehydrogenase, LDH - lactate dehydrogenase, Lactate dehydrogenase isoenzyme, Lactate dehydrogenase isoenzyme 1]
# 96                                                                    [TNM colon tumour staging, is (tumor staging), Cotswolds Hodgkin disease tumor staging system, Multisystem involvement (tumor staging), Stannards retinoblastoma stages (tumor staging)]
# 97                                           [Positron emission tomography, Positron emission tomography of brain, Positron emission tomography heart study, Positron emission tomography breast study, Positron emission tomography with computed tomography]
# 98                                                                                                                                                                                             [Bone scan, Milk scan, Kidney scan, Booking scan, Gallium scan]
# 99                                                                                                                                                 [Bone marrow biopsy, Bone marrow trephine, Bone marrow excision, Bone marrow harvest, Bone marrow incision]
# 101                                                                                                 [Limited eye examination, Comprehensive eye examination, Diabetic retinal eye exam (procedure), Examination of eye under anesthetic, Massaging of the eye]
# 102                                                                                                                                            [Lumbar puncture, Diagnostic lumbar puncture, Therapeutic lumbar puncture, Cervical puncture, Lumbar discogram]
# 104                                                                                                                                              [Complaining of a rash, Multimorphic rash, Pruritic rash (disorder), Rash of periwound skin, Premycotic rash]
# 105                                                                                                                                         [Clinical examination, Clinical evaluation, Clinical photography, Clinical examination larynx, Clinical interview]
# 107                                                                                                              [Erythematous plaques of pinta, Erythematous duodenopathy, Acute erythematous candidosis, On examination - erythematous rash, Crusted eczema]
# 109                                                                               [Total body surface, Entire body surface area (body structure), Structure of body surface region, Diaper area (body structure), Entire body surface region (body structure)]
# 110                                                                                                                                                                            [Lymphoma, Berti lymphoma, Ocular lymphoma, Nodular lymphoma, Burkitt lymphoma]
# 111                                                                                                                                                                            [Alopecia, Brush alopecia, Alopecia areata, Alopecia localis, Diffuse alopecia]
# 112                                                                                              [Central axillary lymphadenopathy, Lateral axillary lymphadenopathy, Apical axillary lymphadenopathy, Left gastric lymphadenopathy, Left axillary neuropathy]
# 113                                                                                                         [Generalised pruritus, Brachioradial pruritus, Severe diarrhea, Brachioradial summer pruritus, Severe systemic illness respiratory muscle fatigue]
# 114                                                                                                                                                                                           [Sweats, Hot sweats, Night sweats, Sweats normally, Diaphoresis]
# 115                                                                                                                                                                     [Weight loss, Weight loss diet, Recent weight loss, Abnormal weight loss, Weight gain]
# 116                                                                                                                                                 [Loss of appetite, Psychogenic loss of appetite, Observation of appetite, Loss of balance, Loss of memory]

# %%
cancer_analysis[cancer_analysis.icd10cm_dst<3]
# Out:
#           coords                                chunk  entity icd10cm  \
# 1  0::1078::1103           testicular germ cell tumor  Cancer   C6290
# 2  0::1632::1644                        pelvic masses  Cancer    C763
# 3  0::2429::2463  desmoplastic small round cell tumor  Cancer    D489
# 4    1::370::397         chronic lymphocytic leukemia  Cancer   C9210
# 5    1::411::430                 lymphocytic lymphoma  Cancer   C8300
# 6    2::386::416      central nervous system lymphoma  Cancer   C8589
# 7    3::373::380                             lymphoma  Cancer   C8590
#
#    icd10cm_dst icd10cm_conf  \
# 1       1.5040       0.6792
# 2       2.7200       1.0000
# 3       2.4000       0.7772
# 4       1.3616       0.3933
# 5       1.5758       0.8882
# 6       0.8205       0.4599
# 7       0.0000       0.9606
#
#                                                                                                                                                                                                                                                 icd10cm_opts  \
# 1      [Malignant neoplasm of unspecified testis, unspecified whether descended or undescended, Malignant (primary) neoplasm, unspecified, Malignant neoplasm of left ovary, Neoplasm of uncertain behavior, unspecified, Malignant neoplasm of right ovary]
# 2  [Malignant neoplasm of pelvis, Malignant neoplasm of specified parts of peritoneum, Benign neoplasm of peripheral nerves and autonomic nervous system of pelvis, Benign neoplasm of peripheral nerves and autonomic nervous system of abdomen, Maligna...
# 3  [Neoplasm of uncertain behavior, unspecified, Secondary malignant neoplasm of small intestine, Diffuse large B-cell lymphoma, lymph nodes of axilla and upper limb, Neoplasm of uncertain behavior of unspecified testis, Malignant (primary) neoplasm...
# 4  [Chronic myeloid leukemia, BCR/ABL-positive, not having achieved remission, Chronic myelomonocytic leukemia not having achieved remission, Chronic leukemia of unspecified cell type not having achieved remission, Chronic lymphocytic leukemia of B-...
# 5  [Small cell B-cell lymphoma, unspecified site, Waldenstrom macroglobulinemia, Non-Hodgkin lymphoma, unspecified, unspecified site, Small cell B-cell lymphoma, extranodal and solid organ sites, Lymphocyte depleted Hodgkin lymphoma, lymph nodes of ...
# 6  [Other specified types of non-Hodgkin lymphoma, extranodal and solid organ sites, Other non-follicular lymphoma, unspecified site, Malignant neoplasm of central nervous system, unspecified, Other non-follicular lymphoma, lymph nodes of head, face...
# 7  [Non-Hodgkin lymphoma, unspecified, unspecified site, Non-Hodgkin lymphoma, unspecified, extranodal and solid organ sites, Lymphocyte depleted Hodgkin lymphoma, intra-abdominal lymph nodes, Follicular lymphoma, unspecified, unspecified site, Hodg...
#
#      icdo  icdo_dst icdo_conf  \
# 1  9085/3    1.3846    0.9652
# 2  8312/3    4.1178    0.9888
# 3  8806/3    0.0000    0.9949
# 4  9946/3    1.3895    0.4412
# 5  9673/3    1.1429    0.5380
# 6  9501/3    1.4222    0.5049
# 7  9591/3    0.0000    0.4914
#
#                                                                                                                                                                         icdo_opts
# 1                  [Mixed germ cell tumor, Squamous cell carcinoma, HPV-positive, Squamous cell carcinoma, HPV-negative, Germ cell tumor, nonseminomatous, Clear cell tumor, NOS]
# 2                                                                                       [Renal cell carcinoma, Polyembryoma, Neoplasm, benign, Craniopharyngioma, Ganglioneuroma]
# 3                        [Desmoplastic small round cell tumor, Small cell sarcoma, Malignant tumor, giant cell type, Malignant tenosynovial giant cell tumor, Oat cell carcinoma]
# 4  [Juvenile myelomonocytic leukemia, Chronic lymphocytic leukemia/small lymphocytic lymphoma, Burkitt cell leukemia, Chronic myeloid leukemia, NOS, Acute biphenotypic leukemia]
# 5                                      [Mantle cell lymphoma, Follicular lymphoma, NOS, Follicular lymphoma, grade 2, Follicular lymphoma, grade 3, Follicular lymphoma, grade 1]
# 6                  [Medulloepithelioma, NOS, Craniopharyngioma, Medulloblastoma, WNT-activated, Medulloblastoma, non-WNT/non-SHH, Medulloblastoma, SHH-activated and TP53-mutant]
# 7                                  [Malignant lymphoma, non-Hodgkin, Mantle cell lymphoma, Hydroa vacciniforme-like lymphoma, Hodgkin lymphoma, lymphocyte-rich, Sezary syndrome]
