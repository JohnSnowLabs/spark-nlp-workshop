# %% [markdown]
# # ICD-O Entity Resolution - version 2.4.6

# %%
import sys, os, time, pandas as pd

sys.path.append("/home/fernandrez/JSL/repos/spark-nlp/python")
sys.path.append("/home/fernandrez/JSL/repos/spark-nlp-internal/python")

from sparknlp.base import *
from sparknlp.annotator import *
from sparknlp.training import *
from sparknlp_jsl.annotator import *
import pyspark.sql.functions as F
from pyspark.sql.types import StructType, StructField, StringType

pd.set_option('display.max_colwidth', 250)
pd.set_option('display.max_rows', 500)

# %%
import sparknlp_jsl
sparknlp_jsl.version()
# Out:
# '2.4.7'

# %%
spark = sparknlp_jsl.start("####")

# %% [markdown]
# ## Let's create a dataset with all some case studies

# %%
data = CoNLL().readDataset(spark, "/home/fernandrez/JSL/repos/spark-nlp-training/src/main/resources/ner-posology-data/i2b2_med7.conll")

# %%
data = data\
.withColumn("text_feed", F.expr("regexp_replace(lower(text),'([0-9])',' $1 ')"))\
.withColumn("length", F.expr("length(text)"))\
.withColumn("doc_id", F.monotonically_increasing_id())\
.orderBy("length", ascending=False).limit(20)
# Out:
#   File "<ipython-input-23-2fed4cd01ccb>", line 4
#     .withColumn("doc_id", F.monotonically_increasing_id())\.limit(20)
#                                                                      ^
# SyntaxError: unexpected character after line continuation character

# %%
from IPython.core.display import display, HTML

html_output=""
for i, d in enumerate(data.select("text").collect()):
    html_output += f'Note {i}:'
    html_output +='<div style="border:2px solid #747474; background-color: #e3e3e3; margin: 5px; padding: 10px">'
    html_output += d[0]
    html_output += '</div><br/>'

display(HTML(html_output))
# Out:
# Note 0<div style="border:2px solid #747474; background-color: #e3e3e3; margin: 5px; padding: 10px">Pentamidine 300 mg IV q . 36 hours , Pentamidine nasal wash 60 mg per 6 ml of sterile water q.d . , voriconazole 200 mg p.o . b.i.d . , acyclovir 400 mg p.o . b.i.d . , cyclosporine 50 mg p.o . b.i.d . , prednisone 60 mg p.o . q.d . , GCSF 480 mcg IV q.d . , Epogen 40,000 units subcu q . week , Protonix 40 mg q.d . , Simethicone 80 mg p.o . q . 8 , nitroglycerin paste 1 &quot ; q . 4 h . p.r.n . , flunisolide nasal inhaler , 2 puffs q . 8 , OxyCodone 10-15 mg p.o . q . 6 p.r.n . , Sudafed 30 mg q . 6 p.o . p.r.n . , Fluconazole 2% cream b.i.d . to erythematous skin lesions , Ditropan 5 mg p.o . b.i.d . , Tylenol 650 mg p.o . q . 4 h . p.r.n . , Ambien 5-10 mg p.o . q . h.s . p.r.n . , Neurontin 100 mg q . a.m . , 200 mg q . p.m . , Aquaphor cream b.i.d . p.r.n . , Lotrimin 1% cream b.i.d . to feet , Dulcolax 5-10 mg p.o . q.d . p.r.n . , Phoslo 667 mg p.o . t.i.d . , Peridex 0.12% , 15 ml p.o . b.i.d . mouthwash , Benadryl 25-50 mg q . 4-6 h . p.r.n . pruritus , Sarna cream q.d . p.r.n . pruritus , Nystatin 5 ml p.o . q.i.d . swish and !</div><br/>Note 1<div style="border:2px solid #747474; background-color: #e3e3e3; margin: 5px; padding: 10px">Albuterol nebulizers 2.5 mg q.4h . and Atrovent nebulizers 0.5 mg q.4h . , please alternate albuterol and Atrovent ; Rocaltrol 0.25 mcg per NG tube q.d .; calcium carbonate 1250 mg per NG tube q.i.d .; vitamin B12 1000 mcg IM q . month , next dose is due Nov 18 ; diltiazem 60 mg per NG tube t.i.d .; ferrous sulfate 300 mg per NG t.i.d .; Haldol 5 mg IV q.h.s .; hydralazine 10 mg IV q.6h . p.r.n . hypertension ; lisinopril 10 mg per NG tube q.d .; Ativan 1 mg per NG tube q.h.s .; Lopressor 25 mg per NG tube t.i.d .; Zantac 150 mg per NG tube b.i.d .; multivitamin 10 ml per NG tube q.d .; Macrodantin 100 mg per NG tube q.i.d . x 10 days beginning on 11/3/00 .</div><br/>Note 2<div style="border:2px solid #747474; background-color: #e3e3e3; margin: 5px; padding: 10px">Tylenol 650 mg p.o . q . 4-6h p.r.n . headache or pain ; acyclovir 400 mg p.o . t.i.d .; acyclovir topical t.i.d . to be applied to lesion on corner of mouth ; Peridex 15 ml p.o . b.i.d .; Mycelex 1 troche p.o . t.i.d .; g-csf 404 mcg subcu q.d .; folic acid 1 mg p.o . q.d .; lorazepam 1-2 mg p.o . q . 4-6h p.r.n . nausea and vomiting ; Miracle Cream topical q.d . p.r.n . perianal irritation ; Eucerin Cream topical b.i.d .; Zantac 150 mg p.o . b.i.d .; Restoril 15-30 mg p.o . q . h.s . p.r.n . insomnia ; multivitamin 1 tablet p.o . q.d .; viscous lidocaine 15 ml p.o . q . 3h can be applied to corner of mouth or lips p.r.n . pain control .</div><br/>Note 3<div style="border:2px solid #747474; background-color: #e3e3e3; margin: 5px; padding: 10px">The patient &apos;s incisions sternal and right leg were clean and healing well , normal sinus rhythm at 70-80 , with blood pressure 98-110/60 and patient was doing well , recovering , ambulating , tolerating regular diet and last hematocrit prior to discharge was 39% with a BUN and creatinine of 15 and 1.0 , prothrombin time level of 13.8 , chest X-ray prior to discharge showed small bilateral effusions with mild cardiomegaly and subsegmental atelectasis bibasilar and electrocardiogram showed normal sinus rhythm with left atrial enlargement and no acute ischemic changes on electrocardiogram .</div><br/>Note 4<div style="border:2px solid #747474; background-color: #e3e3e3; margin: 5px; padding: 10px">This is an 82 - year-old male with a history of prior tobacco use , hypertension , chronic renal insufficiency , COPD , gastritis , and TIA who initially presented to Braintree with a non-ST elevation MI and Guaiac positive stools , transferred to St . Margaret's Center for Women & Infants for cardiac catheterization with PTCA to mid LAD lesion complicated by hypotension and bradycardia requiring Atropine , IV fluids and transient dopamine possibly secondary to vagal reaction , subsequently t ...

# %%
# Notes column names

docid_col         = "doc_id"
note_col          = "text_feed"

# %% [markdown]
# ## And let's build a SparkNLP pipeline with the following stages:
# - DocumentAssembler: Entry annotator for our pipelines; it creates the data structure for the Annotation Framework
# - SentenceDetector: Annotator to pragmatically separate complete sentences inside each document
# - Tokenizer: Annotator to separate sentences in tokens (generally words)
# - StopWordsCleaner: Annotator to remove words defined as StopWords in SparkML
# - WordEmbeddings: Vectorization of word tokens, in this case using word embeddings trained from PubMed, ICD10 and other clinical resources.
# - ChunkEmbeddings: Aggregates the WordEmbeddings for each NER Chunk
# - BioNLP NER + NerConverter: This annotators return Chunks related to Cancer and Genetics diseases
# - ChunkEntityResolver: Annotator that performs search for the KNNs, in this case trained from ICDO Histology Behavior.

# %%
#Language and Model Repository

models_language   = "en"
models_repository = "clinical/models"

# %%
# Embeddings Pretrained Model Name

embeddings_name   = "embeddings_clinical"

# Preparation and embeddings column names

doc_col           = "document"
sent_col          = "sentence"
token_col         = "token"
embeddings_col    = "embeddings"

# Usual preparation Annotators and Embeddings

docAssembler = DocumentAssembler().setInputCol(note_col).setOutputCol(doc_col)
sentenceDetector = SentenceDetector().setInputCols(doc_col).setOutputCol(sent_col)
tokenizer_chars = [",","\/"," ",".","|","@","#","%","&","\\$","\\[","\\]","\\(","\\)","\\-",";"]
tokenizer = Tokenizer().setSplitChars(tokenizer_chars)\
    .setInputCols(sent_col).setOutputCol(token_col)
embeddings = WordEmbeddingsModel.pretrained(embeddings_name, models_language, models_repository)\
    .setInputCols(sent_col, token_col)\
    .setOutputCol(embeddings_col)
# Out:
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]

# %%
# NER Pretrained Model Names

jsl_ner_name  = "ner_jsl"
drug_ner_name = "ner_drugs"

# NER Column Names

ner_jsl_col  = "ner_jsl"
ner_drug_col = "ner_drug"

# Annotators responsible for the Cancer Genetics Entity Recognition task

jslNer = NerDLModel.pretrained(jsl_ner_name, models_language, models_repository)\
    .setInputCols(sent_col, token_col, embeddings_col)\
    .setOutputCol(ner_jsl_col)

drugNer = NerDLModel.pretrained(drug_ner_name, models_language, models_repository)\
    .setInputCols(sent_col, token_col, embeddings_col)\
    .setOutputCol(ner_drug_col)
# Out:
# ner_jsl download started this may take some time.
# Approximate size to download 14 MB
# [OK!]
# ner_drugs download started this may take some time.
# Approximate size to download 13.8 MB
# [OK!]

# %%
# Chunk column names

chunk_jsl_col  = "chunk_jsl"
chunk_drug_col = "chunk_drug"

#Converter annotators transform IOB tags into full chunks (sequence set of tokens) tagged with `entity` metadata

jslConverter = NerConverter().setInputCols(sent_col, token_col, ner_jsl_col)\
    .setOutputCol(chunk_jsl_col).setWhiteList(["Diagnosis"])
drugConverter = NerConverter().setInputCols(sent_col, token_col, ner_drug_col)\
    .setOutputCol(chunk_drug_col)

# %%
# ChunkEmbeddings column names

chunk_embs_jsl_col  = "chunk_embs_jsl"
chunk_embs_drug_col = "chunk_embs_drug"

#ChunkEmbeddings annotators aggregate embeddings for each token in the chunk

jslChunkEmbeddings = ChunkEmbeddings()\
  .setInputCols(chunk_jsl_col, embeddings_col)\
  .setOutputCol(chunk_embs_jsl_col)
drugChunkEmbeddings = ChunkEmbeddings()\
  .setInputCols(chunk_drug_col, embeddings_col)\
  .setOutputCol(chunk_embs_drug_col)

# %%
# ChunkTokenizer column names

chunk_token_jsl_col  = "chunk_token_jsl"
chunk_token_drug_col = "chunk_token_drug"

# ChunkTokenizer provides extra flexibility at the time of tokenizing a given chunk

jslChunkTokenizer = ChunkTokenizer().setSplitChars(tokenizer_chars)\
    .setInputCols(chunk_jsl_col).setOutputCol(chunk_token_jsl_col)
drugChunkTokenizer = ChunkTokenizer().setSplitChars(tokenizer_chars)\
    .setInputCols(chunk_drug_col).setOutputCol(chunk_token_drug_col)

# %%
# Entity Resolution Pretrained Model Names

icd10cm_model_name = "chunkresolve_icd10cm_clinical"
rxnorm_model_name  = "ensembleresolve_rxnorm_clinical"

# Entity Resolution column Names

icd10cm_col = "icd10cm_resolution"
rxnorm_col  = "rxnorm_resolution"
    
icd10cmResolver = ChunkEntityResolverModel\
    .pretrained(icd10cm_model_name, models_language, models_repository)\
    .setEnableLevenshtein(True)\
    .setNeighbours(200).setAlternatives(5).setDistanceWeights([1,3,2,0,0,1])\
    .setExtramassPenalty(3).setPoolingStrategy("MAX")\
    .setInputCols(chunk_token_jsl_col, chunk_embs_jsl_col)\
    .setOutputCol(icd10cm_col)

rxnormResolver = EnsembleEntityResolverModel()\
    .pretrained(rxnorm_model_name, models_language, models_repository)\
    .setEnableLevenshtein(True)\
    .setNeighbours(200).setAlternatives(5).setDistanceWeights([1,3,2,0,0,1])\
    .setExtramassPenalty(3).setPoolingStrategy("MAX")\
    .setInputCols(chunk_token_drug_col, chunk_embs_drug_col)\
    .setOutputCol(rxnorm_col)\
# Out:
# chunkresolve_icd10cm_clinical download started this may take some time.
# Approximate size to download 166.3 MB
# [OK!]
# ensembleresolve_rxnorm_clinical download started this may take some time.
# Approximate size to download 783.3 MB
# [OK!]

# %%
pipelineFull = Pipeline().setStages([
    docAssembler, 
    sentenceDetector, 
    tokenizer, 
    embeddings, 
    jslNer,
    drugNer,
    jslConverter,
    drugConverter,
    jslChunkEmbeddings, 
    drugChunkEmbeddings,
    jslChunkTokenizer,
    drugChunkTokenizer,
    icd10cmResolver,
    rxnormResolver
])

# %%
pipelineModelFull = pipelineFull.fit(data)

# %%
output = pipelineModelFull.transform(data).cache()

# %% [markdown]
# ## The key parts of our pipeline are the **WordEmbeddings, NerDLModel and ChunkEntityResolver**:
#
# ### WordEmebeddings:
# Word2Vec model trained on semantically augmented datasets using information from curated Datasets in JSL Data Market.
#
# ### EntityResolver:
# Trained on an augmented ICDO Dataset from JSL Data Market it provides histology codes resolution for the matched expressions. Other than providing the code in the "result" field it provides more metadata about the matching process:
#
# - all_k_results -> Sorted ResolverLabels in the top `alternatives` that match the distance `threshold`
# - all_k_resolutions -> Respective ResolverNormalized strings
# - all_k_distances -> Respective distance values after aggregation
# - all_k_wmd_distances -> Respective WMD distance values (added if allDistancesMetadata==True)
# - all_k_tfidf_distances -> Respective TFIDF Cosine distance values (added if allDistancesMetadata==True)
# - all_k_jaccard_distances -> Respective Jaccard distance values (added if allDistancesMetadata==True)
# - all_k_sorensen_distances -> Respective SorensenDice distance values (added if allDistancesMetadata==True)
# - all_k_jaro_distances -> Respective JaroWinkler distance values (added if allDistancesMetadata==True)
# - all_k_levenshtein_distances -> Respective Levenshtein distance values (added if allDistancesMetadata==True)
# - all_k_confidences -> Respective normalized probabilities based in inverse distance valuesprobability (added if allDistancesMetadata==True)
# - target_text -> The actual searched string
# - resolved_text -> The top ResolverNormalized string
# - confidence -> Top probability
# - distance -> Top distance value
# - sentence -> Sentence index
# - chunk -> Chunk Index
# - token -> Token index

# %%
def quick_metadata_analysis(df, doc_field, chunk_field, code_fields, dist_thres=1):
    code_res_meta = ", ".join([f"{cf}.result, {cf}.metadata" for cf in code_fields])
    expression = f"explode(arrays_zip({chunk_field}.begin, {chunk_field}.end, {chunk_field}.result, {chunk_field}.metadata, "+code_res_meta+")) as a"
    top_n_rest = [(f"a['{2*i+4}'] as {(cf.split('_')[0])}",
                   f"float(a['{2*i+5}'].distance) as {(cf.split('_')[0])}_dst",
                   f"a['{2*i+5}'].confidence as {(cf.split('_')[0])}_conf",
                    f"split(a['{2*i+5}'].all_k_resolutions,':::') as {cf.split('_')[0]+'_opts'}")
                    for i, cf in enumerate(code_fields)]
    top_n_rest_args = []
    for tr in top_n_rest:
        for t in tr:
            top_n_rest_args.append(t)
    return df.selectExpr(doc_field, expression) \
        .orderBy(docid_col, F.expr("a['0']"), F.expr("a['1']"))\
        .selectExpr(f"concat_ws('::',{doc_field},a['0'],a['1']) as coords", "a['2'] as chunk","a['3'].entity as entity", *top_n_rest_args)

# %%
icd10cm_analysis = \
quick_metadata_analysis(output, docid_col, chunk_jsl_col,[icd10cm_col], 1).toPandas()

# %%
rxnorm_analysis = \
quick_metadata_analysis(output, docid_col, chunk_drug_col,[rxnorm_col], 1).toPandas()

# %%
icd10cm_analysis[icd10cm_analysis.rxnorm_dst<0.75]
# Out:
#           coords                                     chunk     entity icd10cm  \
# 0    1::460::471                              hypertension  Diagnosis    P292
# 1    2::551::558                                  insomnia  Diagnosis   G4709
# 2      4::72::85                            hypertension ,  Diagnosis    I973
# 3    4::117::120                                      copd  Diagnosis   R0902
# 4    4::124::132                                 gastritis  Diagnosis   K3183
# 5      6::51::90  restrictive and obstructive lung disease  Diagnosis    J449
# 6    6::263::288                fixed inferolateral defect  Diagnosis    Q214
# 7    6::292::311                      systolic dysfunction  Diagnosis    N522
# 8    6::468::482                           aortic stenosis  Diagnosis    Q253
# 9    7::122::144                   coronary artery disease  Diagnosis   I2541
# 10     8::24::47                  skin and sinus infection  Diagnosis    J329
# 11    9::84::102                       dilated left atrium  Diagnosis    Q242
# 12   9::156::185            region lv systolic dysfunction  Diagnosis  H832X2
# 13   9::467::487                     pericardial effusions  Diagnosis    I318
# 14  10::227::248                    acanthamoeba infection  Diagnosis   B6010
# 15  10::347::361                           cmv infection ,  Diagnosis    B009
# 16  10::471::482                              hyponatremia  Diagnosis    E871
# 17    13::69::96              left ventricular hypertrophy  Diagnosis    I509
# 18  13::151::178              right ventricular dilatation  Diagnosis  I50810
# 19  13::442::463                    pulmonary hypertension  Diagnosis    I270
# 20    17::70::89                      myelogenous leukemia  Diagnosis   C9221
# 21    18::46::58                             breast cancer  Diagnosis   C7981
# 22  18::136::147                              hypertension  Diagnosis    P292
# 23  18::151::164                            hyperlipidemia  Diagnosis   E7849
# 24  18::177::200                  urinary tract infections  Diagnosis    P393
# 25  18::431::433                                       flu  Diagnosis    A202
# 26    19::62::84                   coronary artery disease  Diagnosis   I2541
# 27  19::207::215                                 cirrhosis  Diagnosis   K7460
# 28  19::241::259                       portal hypertension  Diagnosis    K766
# 29  19::280::307              upper gastrointestinal bleed  Diagnosis    K922
# 30  19::410::422                             renal failure  Diagnosis    N186
# 31  19::428::449                    pulmonary hypertension  Diagnosis    I270
#
#     icd10cm_dst icd10cm_conf  \
# 0        0.7822       0.2415
# 1        0.6428       0.2355
# 2        0.6970       0.2259
# 3        1.3677       0.3386
# 4        1.3750       0.2392
# 5        0.6463       0.3183
# 6        0.9813       0.2379
# 7        0.8949       0.2883
# 8        0.0000       0.3179
# 9        0.6244       0.3227
# 10       0.6885       0.2352
# 11       0.6653       0.3403
# 12       1.1453       0.2426
# 13       1.0625       0.3522
# 14       0.3620       0.3099
# 15       0.9080       0.2112
# 16       0.6123       0.4572
# 17       0.7681       0.2681
# 18       0.8183       0.2639
# 19       0.5050       0.2619
# 20       0.7122       0.2593
# 21       0.4392       0.2830
# 22       0.7822       0.2415
# 23       0.6230       0.3430
# 24       0.6674       0.2168
# 25       1.4270       0.2338
# 26       0.6244       0.3227
# 27       0.6570       0.3502
# 28       0.1053       0.3349
# 29       0.9056       0.2672
# 30       0.0000       0.2903
# 31       0.5050       0.2619
#
#                                                                                                                                                                                                                                                  icd10cm_opts
# 0                                                                                                                   [Neonatal hypertension, Postprocedural hypertension, Portal hypertension, Renovascular hypertension, Secondary hypertension, unspecified]
# 1                                                                                                                                                   [Other insomnia, Primary insomnia, Adjustment insomnia, Paradoxical insomnia, Psychophysiologic insomnia]
# 2                                                                                                                          [Postprocedural hypertension, Neonatal hypertension, Portal hypertension, Renovascular hypertension, Other secondary hypertension]
# 3                                                                                                                           [Hypoxemia, Respiratory arrest, Chronic adenoiditis, Thromboangiitis obliterans [Buerger's disease], Postprocedural hypertension]
# 4                                                                                                                                                                        [Achlorhydria, Celiac disease, Trichuriasis, Opisthorchiasis, Calicivirus enteritis]
# 5                                                                                            [Chronic obstructive pulmonary disease, unspecified, Suberosis, Interstitial pulmonary disease, unspecified, Farmer's lung, Desquamative interstitial pneumonia]
# 6                                                                                                 [Aortopulmonary septal defect, Cardiac septal defect, acquired, Congenital diaphragmatic hernia, Atrioventricular septal defect, Ventricular septal defect]
# 7                                                                                   [Drug-induced erectile dysfunction, Male erectile disorder, Other testicular dysfunction, Corporo-venous occlusive erectile dysfunction, Outlet dysfunction constipation]
# 8                                                                                                                [Supravalvular aortic stenosis, Atherosclerosis of aorta, Congenital stenosis of aortic valve, Rheumatic aortic stenosis, Williams syndrome]
# 9                                                                                            [Coronary artery aneurysm, Chronic total occlusion of coronary artery, Coronary angioplasty status, Coronary artery dissection, Atherosclerosis of renal artery]
# 10                                                                                                                                  [Chronic sinusitis, unspecified, Cellulitis, unspecified, Neonatal skin infection, Preauricular sinus and cyst, Pyoderma]
# 11                                                                                                                                     [Cor triatriatum, Cardiomyopathy, unspecified, Dilated cardiomyopathy, Sciatica, left side, Periarthritis, left wrist]
# 12                                                  [Labyrinthine dysfunction, left ear, Labyrinthine dysfunction, right ear, Corporo-venous occlusive erectile dysfunction, Outlet dysfunction constipation, Spinal stenosis, occipito-atlanto-axial region]
# 13                                                                                                         [Other specified diseases of pericardium, Chylous effusion, Pleural effusion, not elsewhere classified, Malignant neoplasm of pleura, Atelectasis]
# 14                                                                                                                                                                 [Acanthamebiasis, unspecified, Anisakiasis, Gnathostomiasis, Paragonimiasis, Enterobiasis]
# 15                                                                                                             [Herpesviral infection, unspecified, Papovavirus infection, unspecified, Yatapoxvirus infection, unspecified, Gnathostomiasis, Pneumocystosis]
# 16                                                                                                                                                                 [Hypo-osmolality and hyponatremia, Hypokalemia, Hypovolemia, Hypocalcemia, Hypomagnesemia]
# 17                                                                                               [Heart failure, unspecified, Right heart failure, unspecified, Ventricular septal defect, Hypertrophy of bone, left humerus, Hypertrophy of bone, left hand]
# 18                                                                                                  [Right heart failure, unspecified, Heart failure, unspecified, Coronary artery aneurysm, Ventricular septal defect, Ventricular premature depolarization]
# 19                                                                                    [Primary pulmonary hypertension, Other secondary pulmonary hypertension, Secondary pulmonary arterial hypertension, Postprocedural hypertension, Neonatal hypertension]
# 20  [Atypical chronic myeloid leukemia, BCR/ABL-negative, in remission, Chronic myeloid leukemia, BCR/ABL-positive, in relapse, Myeloid leukemia, unspecified in relapse, Acute myeloblastic leukemia, in remission, Acute myeloblastic leukemia, in relapse]
# 21                                                                                            [Secondary malignant neoplasm of breast, Malignant neoplasm of prostate, Liver cell carcinoma, Malignant neoplasm of vagina, Malignant neoplasm of endometrium]
# 22                                                                                                                  [Neonatal hypertension, Postprocedural hypertension, Portal hypertension, Renovascular hypertension, Secondary hypertension, unspecified]
# 23                                                                                                                                      [Other hyperlipidemia, Hyperlipidemia, unspecified, Lesch-Nyhan syndrome, Mixed hyperlipidemia, Drug-induced obesity]
# 24                                           [Neonatal urinary tract infection, Disorder of urinary system, unspecified, Urinary tract infection, site not specified, Urinary tract infection following delivery, unspecified, Urinary calculus, unspecified]
# 25                                                                                                                                                                     [Pneumonic plague, Epidemic myalgia, Cough, O'nyong-nyong fever, Salmonella enteritis]
# 26                                                                                           [Coronary artery aneurysm, Chronic total occlusion of coronary artery, Coronary angioplasty status, Coronary artery dissection, Atherosclerosis of renal artery]
# 27                                                                                                               [Unspecified cirrhosis of liver, Hepatic fibrosis, Pulmonary fibrosis, unspecified, Hemochromatosis, unspecified, Primary biliary cirrhosis]
# 28                                                                                                                               [Portal hypertension, Portal vein thrombosis, Postprocedural hypertension, Neonatal hypertension, Renovascular hypertension]
# 29                                                                                          [Gastrointestinal hemorrhage, unspecified, Duodenitis without bleeding, Flatulence, Esophageal varices with bleeding, Other neonatal gastrointestinal hemorrhage]
# 30                                                                                                                     [End stage renal disease, Congenital renal failure, Acute kidney failure, unspecified, Heart-lung transplant failure, Lowe's syndrome]
# 31                                                                                    [Primary pulmonary hypertension, Other secondary pulmonary hypertension, Secondary pulmonary arterial hypertension, Postprocedural hypertension, Neonatal hypertension]

# %%
rxnorm_analysis[rxnorm_analysis.rxnorm_dst<0.75]
# Out:
#            coords                             chunk    entity   rxnorm  \
# 0        0::0::10                       pentamidine  DrugChem     7994
# 1       0::47::57                       pentamidine  DrugChem     7994
# 2     0::116::127                      voriconazole  DrugChem   121243
# 3     0::158::166                         acyclovir  DrugChem      281
# 4     0::197::208                      cyclosporine  DrugChem     3008
# 5     0::236::245                        prednisone  DrugChem     8640
# 6     0::375::385                       simethicone  DrugChem     9796
# 7     0::413::425                     nitroglycerin  DrugChem     4917
# 8     0::467::477                       flunisolide  DrugChem    25120
# 9     0::515::523                         oxycodone  DrugChem     7804
# 10    0::608::618                       fluconazole  DrugChem     4450
# 12    0::702::708                           tylenol  DrugChem   202433
# 14    0::798::806                         neurontin  DrugChem   196498
# 15    0::891::901                       lotrimin  1  DrugChem   220204
# 18  0::1068::1085                benadryl  2  5 - 5  DrugChem  1433678
# 19  0::1166::1173                          nystatin  DrugChem   312061
# 20        1::0::8                         albuterol  DrugChem      435
# 21      1::45::52                          atrovent  DrugChem   151390
# 22    1::104::112                         albuterol  DrugChem      435
# 23    1::118::125                          atrovent  DrugChem   151390
# 24    1::129::137                         rocaltrol  DrugChem   152323
# 25    1::173::189                 calcium carbonate  DrugChem     1897
# 26    1::228::236                         vitamin b  DrugChem    11251
# 27    1::306::314                         diltiazem  DrugChem     3443
# 28    1::347::361                   ferrous sulfate  DrugChem    24947
# 29    1::392::397                            haldol  DrugChem   151839
# 30    1::418::428                       hydralazine  DrugChem     5470
# 31    1::475::484                        lisinopril  DrugChem    29046
# 32    1::591::596                            zantac  DrugChem   152523
# 33    1::674::684                       macrodantin  DrugChem   203054
# 34        2::0::6                           tylenol  DrugChem   202433
# 35      2::67::75                         acyclovir  DrugChem      281
# 36    2::105::113                         acyclovir  DrugChem      281
# 37    2::276::285                        folic acid  DrugChem     4511
# 38    2::307::315                         lorazepam  DrugChem     6470
# 39    2::435::441                           eucerin  DrugChem    59478
# 40    2::466::477                      zantac  1  5  DrugChem   220992
# 42    2::607::615                         lidocaine  DrugChem     6387
# 43    3::310::319                        creatinine  DrugChem     2913
# 44    4::404::411                          atropine  DrugChem     1223
# 45    4::439::446                          dopamine  DrugChem     3628
# 47      7::89::99                       cholesterol  DrugChem     2438
# 48   10::401::410                        creatinine  DrugChem     2913
# 49       11::0::6                           tylenol  DrugChem   202433
# 51   11::125::137                     nortriptyline  DrugChem     7531
# 52   11::165::175                       simvastatin  DrugChem    36567
# 53   11::203::211                         metamucil  DrugChem     6802
# 54   11::248::256                         neurontin  DrugChem   196498
# 56   11::333::364  lisinopril / hydrochlorothiazide  DrugChem   214618
# 57   11::397::410                    hydrocortisone  DrugChem     5492
# 58       12::0::6                           aspirin  DrugChem     1191
# 59     12::26::34                         albuterol  DrugChem      435
# 60     12::93::99                           heparin  DrugChem   235473
# 62   12::204::214                       simvastatin  DrugChem    36567
# 63   12::280::291                      zantac  1  5  DrugChem   220992
# 64   12::307::314                          nystatin  DrugChem   312061
# 65   12::355::364                        lisinopril  DrugChem    29046
# 66   12::384::391                          mestinon  DrugChem   203001
# 68   12::476::485                        prednisone  DrugChem     8640
# 70   14::278::286                         adenosine  DrugChem      296
# 71       15::0::5                            sodium  DrugChem  1551667
# 72     15::19::27                         potassium  DrugChem     8588
# 73     15::39::46                          chloride  DrugChem  1940993
# 74     15::60::71                      bicarbonates  DrugChem     1527
# 75    15::99::108                        creatinine  DrugChem     2913
# 76   15::120::126                           glucose  DrugChem     4850
# 77     16::22::33                      tetracycline  DrugChem    10395
# 78     16::63::73                       cyclosporin  DrugChem     3008
# 79   16::103::112                        prednisone  DrugChem     8640
# 80   16::137::146                        bactrim ds  DrugChem   346206
# 81   16::167::175                         diltiazem  DrugChem     3443
# 82   16::202::211                        mycostatin  DrugChem   202719
# 83   16::253::257                             lasix  DrugChem   202991
# 84   16::350::355                            imuran  DrugChem   202559
# 86   17::211::221                        -thioguani  DrugChem    10485
# 87   18::107::115                         tamoxifen  DrugChem    10324
#
#     rxnorm_dst rxnorm_conf  \
# 0       0.0000      0.3457
# 1       0.0000      0.3457
# 2       0.0000      0.3846
# 3       0.0000      0.3513
# 4       0.0000      0.3246
# 5       0.0000      0.2489
# 6       0.0000      0.3288
# 7       0.0000      0.4393
# 8       0.0000      0.2991
# 9       0.0000      0.3823
# 10      0.0000      0.3966
# 12      0.0000      0.2318
# 14      0.0000      0.3702
# 15      0.6871      0.2008
# 18      0.6413      0.2121
# 19      0.3131      0.5121
# 20      0.0000      0.3258
# 21      0.0000      0.2885
# 22      0.0000      0.3258
# 23      0.0000      0.2885
# 24      0.0000      0.3526
# 25      0.0000      0.2400
# 26      0.0000      0.2232
# 27      0.0000      0.3070
# 28      0.0000      0.2316
# 29      0.0000      0.3886
# 30      0.0000      0.3306
# 31      0.0000      0.4409
# 32      0.0000      0.2744
# 33      0.0000      0.3426
# 34      0.0000      0.2318
# 35      0.0000      0.3513
# 36      0.0000      0.3513
# 37      0.0000      0.2439
# 38      0.0000      0.3187
# 39      0.0000      0.3735
# 40      0.2543      0.2799
# 42      0.0000      0.2396
# 43      0.0000      0.4820
# 44      0.0000      0.2774
# 45      0.0000      0.3775
# 47      0.0000      0.3050
# 48      0.0000      0.4820
# 49      0.0000      0.2318
# 51      0.0000      0.4095
# 52      0.0000      0.3721
# 53      0.0000      0.3518
# 54      0.0000      0.3702
# 56      0.4234      0.2913
# 57      0.0000      0.2401
# 58      0.0000      0.2461
# 59      0.0000      0.3258
# 60      0.0000      0.2595
# 62      0.0000      0.3721
# 63      0.2543      0.2799
# 64      0.3131      0.5121
# 65      0.0000      0.4409
# 66      0.0000      0.3919
# 68      0.0000      0.2489
# 70      0.0000      0.3201
# 71      0.0000      0.2313
# 72      0.0000      0.2179
# 73      0.4704      0.2012
# 74      0.0000      0.5546
# 75      0.0000      0.4820
# 76      0.0000      0.2576
# 77      0.0000      0.3338
# 78      0.0000      0.5422
# 79      0.0000      0.2489
# 80      0.0000      0.2833
# 81      0.0000      0.3070
# 82      0.0000      0.3502
# 83      0.0000      0.4539
# 84      0.0000      0.4603
# 86      0.7273      0.2357
# 87      0.0000      0.2786
#
#                                                                                                                     rxnorm_opts
# 0                      [Pentamidine, Pentamidine diisothionate, Pentamidine Isethionate, Pentamidine only product, Propamidine]
# 1                      [Pentamidine, Pentamidine diisothionate, Pentamidine Isethionate, Pentamidine only product, Propamidine]
# 2                                                  [Voriconazole, Voriconazole Powder, Posaconazole, Itraconazole, Fluconazole]
# 3                                                    [Acyclovir, Acyclovir Powder, Acyclovir Sodium, Ganciclovir, valaciclovir]
# 4                               [Cyclosporine, Cyclosporine Powder, cycloSPORINE ophthalmic, CycloSPORINE Modified, Tacrolimus]
# 5                                  [Prednisone, PREDNISONE PWDR, Prednisone Intensol, Prednisone acetate, PredniSONE Anhydrous]
# 6                       [Simethicone, Simethicone Powder, Simethicone Solution, simethicone emulsion, Simethicone only product]
# 7                                           [Nitroglycerin, Nitroglycerin ER, Caffeine / Nitroglycerin, Isosorbide, Nicorandil]
# 8                      [Flunisolide, Flunisolide Anhydrous, flunisolide nasal, Flunisolide Micronized, flunisolide hemihydrate]
# 9                                          [Oxycodone, oxycodone HCl, oxycodone pectinate, Oxycodone only product, Hydrocodone]
# 10                                                  [Fluconazole, Fluconazole Powder, Voriconazole, Itraconazole, Posaconazole]
# 12                                 [Tylenol, Children's Tylenol, Infant's Tylenol, Tylenol GoTabs, Children's Tylenol Meltaway]
# 14                                                                     [Neurontin, Oxycontin, Cogentin, Tenormin, Notriptyline]
# 15                                                           [Tempra 1, Canesten 1, Prena1, Lidoject 1, Tricarboxylporphyrin 1]
# 18                                                                   [Etrafon 2-25, DDP-225, LAURETH-25, ABT-925, ceteareth-25]
# 19            [NYSTATIN PWDR, Nystatin only product, nystatin, combinations, Hydrocortisone / Nystatin, Nystatin-Triamcinolone]
# 20                              [Albuterol, Albuterol Powder, Albuterol Sulfate, Albuterol Ipratropium, Albuterol only product]
# 21                                                       [Atrovent, Atrovent Autohaler, Atrovent Aerocap, Antrafenine, Nitrong]
# 22                              [Albuterol, Albuterol Powder, Albuterol Sulfate, Albuterol Ipratropium, Albuterol only product]
# 23                                                       [Atrovent, Atrovent Autohaler, Atrovent Aerocap, Antrafenine, Nitrong]
# 24                                                               [Rocaltrol, Bolasterone, Oxychloroquine, Polycosanol, Dotarem]
# 25    [Calcium carbonate, CALCIUM CARBONATE PWDR, Calcium Carbonate Light, precipitated calcium carbonate, Magnesium carbonate]
# 26                                                                  [Vitamin B, Vitamin B1, Vitamin B2, VITAMIN B3, VITAMIN B5]
# 27                            [Diltiazem, DILTIAZEM HCL, Diltiazem maleate, Diltiazem Malate, Diltiazem Hydrochloride Novaplus]
# 28       [Ferrous sulfate, Ferrous Sulfate Powder, Ferrous Sulfate Solution, Ferrous Sulfate Crystal, Ferrous Ammonium Sulfate]
# 29                                                                         [Haldol, Stadol, Maprotilin, Fendilin, Methyldopate]
# 30                          [Hydralazine, hydralazine HCl, Hydralazine Plus, HydrALAZINE Hydrochloride Novaplus, Dihydralazine]
# 31                                                                     [Lisinopril, Enalapril, Fosinopril, Ramipril, Quinapril]
# 32                                                                [Zantac, Zantac GELdose, Zantac EFFERdose, Zarontin, Mylanta]
# 33                                                                         [Macrodantin, Zarontin, Memantin, Robaxin, Trobicin]
# 34                                 [Tylenol, Children's Tylenol, Infant's Tylenol, Tylenol GoTabs, Children's Tylenol Meltaway]
# 35                                                   [Acyclovir, Acyclovir Powder, Acyclovir Sodium, Ganciclovir, valaciclovir]
# 36                                                   [Acyclovir, Acyclovir Powder, Acyclovir Sodium, Ganciclovir, valaciclovir]
# 37                        [Folic acid, Cantassium folic acid, Folic Acid Powder, Folic acid analogues, Folic acid only product]
# 38                                                    [Lorazepam, LORazepam Novaplus, Lorazepam Powder, Diazepam, Lormetazepam]
# 39                                                                       [Eucerin, Telbermin, Embeline, Iferanserin, Peldesine]
# 40                                                         [Zantac 150, polyquaternium 15, Glutose 15, Clinisol 15, Aldoril 15]
# 42                                           [Lidocaine, LIDOCAINE PWDR, Absorbine Lidocaine, Satohap Lidocaine, lidocaine HCl]
# 43                                                             [CREATININE, Creatinine Powder, Arabinitol, Urea Nailstik, Urea]
# 44                                             [Atropine, Isopto Atropine, Atropine Powder, Atropine Care, atropine ophthalmic]
# 45                            [Dopamine, dopamine HCl, Dopamine agonists, Dopamine only product, Dopamine Hydrochloride Powder]
# 47                                     [Cholesterol, cholesterol sulfate, cholesterol oleate, HDL cholesterol, LDL cholesterol]
# 48                                                             [CREATININE, Creatinine Powder, Arabinitol, Urea Nailstik, Urea]
# 49                                 [Tylenol, Children's Tylenol, Infant's Tylenol, Tylenol GoTabs, Children's Tylenol Meltaway]
# 51                                                 [Nortriptyline, nortriptyline HCl, Amitriptyline, Protriptyline, Sertraline]
# 52                                                    [Simvastatin, Simvastatin Powder, Atorvastatin, Pravastatin, Fluvastatin]
# 53                                                                     [Metamucil, Epanutin, dimethylcurine, Ezetimib, LIPOMUL]
# 54                                                                     [Neurontin, Oxycontin, Cogentin, Tenormin, Notriptyline]
# 56  [Hydrochlorothiazide-Lisinopril, Lisinopril, Hydrochlorothiazide, Enalapril-Hydrochlorothiazide, lisinopril and amlodipine]
# 57             [Hydrocortisone, HYDROCORTISONE PWDR, hydrocortisone probutate, Gadaderm Hydrocortisone, hydrocortisone acetate]
# 58                                                     [Aspirin, ASPIRIN PWDR, Litecoat Aspirin, Norwich Aspirin, Aspirin Free]
# 59                              [Albuterol, Albuterol Powder, Albuterol Sulfate, Albuterol Ipratropium, Albuterol only product]
# 60                                                          [HEPARIN, Heparin, Heparin Sodium, heparin sodium, heparin calcium]
# 62                                                    [Simvastatin, Simvastatin Powder, Atorvastatin, Pravastatin, Fluvastatin]
# 63                                                         [Zantac 150, polyquaternium 15, Glutose 15, Clinisol 15, Aldoril 15]
# 64            [NYSTATIN PWDR, Nystatin only product, nystatin, combinations, Hydrocortisone / Nystatin, Nystatin-Triamcinolone]
# 65                                                                     [Lisinopril, Enalapril, Fosinopril, Ramipril, Quinapril]
# 66                                                                          [Mestinon, Metacin, Vesprin, Meclastine, Methixene]
# 68                                 [Prednisone, PREDNISONE PWDR, Prednisone Intensol, Prednisone acetate, PredniSONE Anhydrous]
# 70                 [Adenosine, Adenosine Powder, Adenosine Monophosphate, Adenosine triphosphate, ADENOSINE MONOPHOSPHATE PWDR]
# 71                                                        [SODIUM, Sodium, SODIUM DIBUNATE, inotersen sodium, patisiran sodium]
# 72                                               [Potassium, POTASSIUM, POTASSIUM, troclosene potassium, POTASSIUM SULFOOLEATE]
# 73         [Isavuconazonium chloride, STEARALKONIUM CHLORIDE, Behentrimonium chloride, cethexonium chloride, Quelicin Chloride]
# 74                                                    [BICARBONATES, BICARBONATE, kalium jodatum, Kalium, Ammonium bicarbonate]
# 75                                                             [CREATININE, Creatinine Powder, Arabinitol, Urea Nailstik, Urea]
# 76                                                   [Glucose, ReliOn Glucose, Enfamil Glucose, Glucose powder, GLUCOSE LIQUID]
# 77                         [Tetracycline, tetracycline HCl, TETRACYCLINE TRIHYDRATE, Tetracycline antibiotics, Oxytetracycline]
# 78                                                              [Cyclosporin, Voclosporin, Tacrolimus, Neoral, Deoxyspergualin]
# 79                                 [Prednisone, PREDNISONE PWDR, Prednisone Intensol, Prednisone acetate, PredniSONE Anhydrous]
# 80                                                               [Bactrim DS, Tolectin DS, Nicorette DS, Urin DS, Limbitrol DS]
# 81                            [Diltiazem, DILTIAZEM HCL, Diltiazem maleate, Diltiazem Malate, Diltiazem Hydrochloride Novaplus]
# 82                                              [Mycostatin, Mycostatin Topical, Mycostatin Pastilles, Nystatine, Meclocycline]
# 83                                                                         [Lasix, Furosemid, Apressin, Mercaptomerin, delagil]
# 84                                                                       [Imuran, Leukeran, Meticorten, Natulan, Methisoprinol]
# 86                                         [Thioguanine, Thioguanine Tabloid, Thioguanine Anhydrous, Treosulfan, Prothionamide]
# 87                                              [Tamoxifen, GenRx Tamoxifen, Tamoxifen Citrate, PMS Tamoxifen, Tamoxifen Hexal]
