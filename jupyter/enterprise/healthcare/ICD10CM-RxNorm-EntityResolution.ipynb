# %% [markdown]
# # ICD-O Entity Resolution - version 2.4.6

# %%
import sys, os, time, pandas as pd

from sparknlp.base import *
from sparknlp.annotator import *
from sparknlp.training import *
from sparknlp_jsl.annotator import *
import pyspark.sql.functions as F
from pyspark.sql.types import StructType, StructField, StringType

pd.set_option('display.max_colwidth', 250)
pd.set_option('display.max_rows', 500)

# %%
import sparknlp_jsl
sparknlp_jsl.version()
# Out:
# '2.4.7'

# %%
spark = sparknlp_jsl.start("####")

# %% [markdown]
# ## Let's create a dataset with all some case studies

# %%
data = CoNLL().readDataset(spark, "/home/fernandrez/JSL/repos/spark-nlp-training/src/main/resources/ner-posology-data/i2b2_med7.conll")

# %%
data = data\
.withColumn("text_feed", F.expr("regexp_replace(lower(text),'([0-9])',' $1 ')"))\
.withColumn("length", F.expr("length(text)"))\
.withColumn("doc_id", F.monotonically_increasing_id())\
.orderBy("length", ascending=False).limit(20)

# %%
from IPython.core.display import display, HTML

html_output=""
for i, d in enumerate(data.select("text").collect()):
    html_output += f'Note {i}:'
    html_output +='<div style="border:2px solid #747474; background-color: #e3e3e3; margin: 5px; padding: 10px">'
    html_output += d[0]
    html_output += '</div><br/>'

display(HTML(html_output))
# Out:
# Note 0:<div style="border:2px solid #747474; background-color: #e3e3e3; margin: 5px; padding: 10px">Pentamidine 300 mg IV q . 36 hours , Pentamidine nasal wash 60 mg per 6 ml of sterile water q.d . , voriconazole 200 mg p.o . b.i.d . , acyclovir 400 mg p.o . b.i.d . , cyclosporine 50 mg p.o . b.i.d . , prednisone 60 mg p.o . q.d . , GCSF 480 mcg IV q.d . , Epogen 40,000 units subcu q . week , Protonix 40 mg q.d . , Simethicone 80 mg p.o . q . 8 , nitroglycerin paste 1 &quot ; q . 4 h . p.r.n . , flunisolide nasal inhaler , 2 puffs q . 8 , OxyCodone 10-15 mg p.o . q . 6 p.r.n . , Sudafed 30 mg q . 6 p.o . p.r.n . , Fluconazole 2% cream b.i.d . to erythematous skin lesions , Ditropan 5 mg p.o . b.i.d . , Tylenol 650 mg p.o . q . 4 h . p.r.n . , Ambien 5-10 mg p.o . q . h.s . p.r.n . , Neurontin 100 mg q . a.m . , 200 mg q . p.m . , Aquaphor cream b.i.d . p.r.n . , Lotrimin 1% cream b.i.d . to feet , Dulcolax 5-10 mg p.o . q.d . p.r.n . , Phoslo 667 mg p.o . t.i.d . , Peridex 0.12% , 15 ml p.o . b.i.d . mouthwash , Benadryl 25-50 mg q . 4-6 h . p.r.n . pruritus , Sarna cream q.d . p.r.n . pruritus , Nystatin 5 ml p.o . q.i.d . swish and !</div><br/>Note 1:<div style="border:2px solid #747474; background-color: #e3e3e3; margin: 5px; padding: 10px">Albuterol nebulizers 2.5 mg q.4h . and Atrovent nebulizers 0.5 mg q.4h . , please alternate albuterol and Atrovent ; Rocaltrol 0.25 mcg per NG tube q.d .; calcium carbonate 1250 mg per NG tube q.i.d .; vitamin B12 1000 mcg IM q . month , next dose is due Nov 18 ; diltiazem 60 mg per NG tube t.i.d .; ferrous sulfate 300 mg per NG t.i.d .; Haldol 5 mg IV q.h.s .; hydralazine 10 mg IV q.6h . p.r.n . hypertension ; lisinopril 10 mg per NG tube q.d .; Ativan 1 mg per NG tube q.h.s .; Lopressor 25 mg per NG tube t.i.d .; Zantac 150 mg per NG tube b.i.d .; multivitamin 10 ml per NG tube q.d .; Macrodantin 100 mg per NG tube q.i.d . x 10 days beginning on 11/3/00 .</div><br/>Note 2:<div style="border:2px solid #747474; background-color: #e3e3e3; margin: 5px; padding: 10px">Tylenol 650 mg p.o . q . 4-6h p.r.n . headache or pain ; acyclovir 400 mg p.o . t.i.d .; acyclovir topical t.i.d . to be applied to lesion on corner of mouth ; Peridex 15 ml p.o . b.i.d .; Mycelex 1 troche p.o . t.i.d .; g-csf 404 mcg subcu q.d .; folic acid 1 mg p.o . q.d .; lorazepam 1-2 mg p.o . q . 4-6h p.r.n . nausea and vomiting ; Miracle Cream topical q.d . p.r.n . perianal irritation ; Eucerin Cream topical b.i.d .; Zantac 150 mg p.o . b.i.d .; Restoril 15-30 mg p.o . q . h.s . p.r.n . insomnia ; multivitamin 1 tablet p.o . q.d .; viscous lidocaine 15 ml p.o . q . 3h can be applied to corner of mouth or lips p.r.n . pain control .</div><br/>Note 3:<div style="border:2px solid #747474; background-color: #e3e3e3; margin: 5px; padding: 10px">The patient &apos;s incisions sternal and right leg were clean and healing well , normal sinus rhythm at 70-80 , with blood pressure 98-110/60 and patient was doing well , recovering , ambulating , tolerating regular diet and last hematocrit prior to discharge was 39% with a BUN and creatinine of 15 and 1.0 , prothrombin time level of 13.8 , chest X-ray prior to discharge showed small bilateral effusions with mild cardiomegaly and subsegmental atelectasis bibasilar and electrocardiogram showed normal sinus rhythm with left atrial enlargement and no acute ischemic changes on electrocardiogram .</div><br/>Note 4:<div style="border:2px solid #747474; background-color: #e3e3e3; margin: 5px; padding: 10px">This is an 82 - year-old male with a history of prior tobacco use , hypertension , chronic renal insufficiency , COPD , gastritis , and TIA who initially presented to Braintree with a non-ST elevation MI and Guaiac positive stools , transferred to St . Margaret's Center for Women & Infants for cardiac catheterization with PTCA to mid LAD lesion complicated by hypotension and bradycardia requiring Atropine , IV fluids and transient dopamine possibly secondary to vagal reaction , subsequen ...

# %%
# Notes column names

docid_col         = "doc_id"
note_col          = "text_feed"

# %% [markdown]
# ## And let's build a SparkNLP pipeline with the following stages:
# - DocumentAssembler: Entry annotator for our pipelines; it creates the data structure for the Annotation Framework
# - SentenceDetector: Annotator to pragmatically separate complete sentences inside each document
# - Tokenizer: Annotator to separate sentences in tokens (generally words)
# - StopWordsCleaner: Annotator to remove words defined as StopWords in SparkML
# - WordEmbeddings: Vectorization of word tokens, in this case using word embeddings trained from PubMed, ICD10 and other clinical resources.
# - ChunkEmbeddings: Aggregates the WordEmbeddings for each NER Chunk
# - BioNLP NER + NerConverter: This annotators return Chunks related to Cancer and Genetics diseases
# - ChunkEntityResolver: Annotator that performs search for the KNNs, in this case trained from ICDO Histology Behavior.

# %%
#Language and Model Repository

models_language   = "en"
models_repository = "clinical/models"

# %%
# Embeddings Pretrained Model Name

embeddings_name   = "embeddings_clinical"

# Preparation and embeddings column names

doc_col           = "document"
sent_col          = "sentence"
token_col         = "token"
embeddings_col    = "embeddings"

# Usual preparation Annotators and Embeddings

docAssembler = DocumentAssembler().setInputCol(note_col).setOutputCol(doc_col)
sentenceDetector = SentenceDetector().setInputCols(doc_col).setOutputCol(sent_col)
tokenizer_chars = [",","\/"," ",".","|","@","#","%","&","\\$","\\[","\\]","\\(","\\)","\\-",";"]
tokenizer = Tokenizer().setSplitChars(tokenizer_chars)\
    .setInputCols(sent_col).setOutputCol(token_col)
embeddings = WordEmbeddingsModel.pretrained(embeddings_name, models_language, models_repository)\
    .setInputCols(sent_col, token_col)\
    .setOutputCol(embeddings_col)
# Out:
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]

# %%
# NER Pretrained Model Names

jsl_ner_name  = "ner_jsl"
drug_ner_name = "ner_drugs"

# NER Column Names

ner_jsl_col  = "ner_jsl"
ner_drug_col = "ner_drug"

# Annotators responsible for the Cancer Genetics Entity Recognition task

jslNer = NerDLModel.pretrained(jsl_ner_name, models_language, models_repository)\
    .setInputCols(sent_col, token_col, embeddings_col)\
    .setOutputCol(ner_jsl_col)

drugNer = NerDLModel.pretrained(drug_ner_name, models_language, models_repository)\
    .setInputCols(sent_col, token_col, embeddings_col)\
    .setOutputCol(ner_drug_col)
# Out:
# ner_jsl download started this may take some time.
# Approximate size to download 14 MB
# [OK!]
# ner_drugs download started this may take some time.
# Approximate size to download 13.8 MB
# [OK!]

# %%
# Chunk column names

chunk_jsl_col  = "chunk_jsl"
chunk_drug_col = "chunk_drug"

#Converter annotators transform IOB tags into full chunks (sequence set of tokens) tagged with `entity` metadata

jslConverter = NerConverter().setInputCols(sent_col, token_col, ner_jsl_col)\
    .setOutputCol(chunk_jsl_col).setWhiteList(["Diagnosis"])
drugConverter = NerConverter().setInputCols(sent_col, token_col, ner_drug_col)\
    .setOutputCol(chunk_drug_col)

# %%
# ChunkEmbeddings column names

chunk_embs_jsl_col  = "chunk_embs_jsl"
chunk_embs_drug_col = "chunk_embs_drug"

#ChunkEmbeddings annotators aggregate embeddings for each token in the chunk

jslChunkEmbeddings = ChunkEmbeddings()\
  .setInputCols(chunk_jsl_col, embeddings_col)\
  .setOutputCol(chunk_embs_jsl_col)
drugChunkEmbeddings = ChunkEmbeddings()\
  .setInputCols(chunk_drug_col, embeddings_col)\
  .setOutputCol(chunk_embs_drug_col)

# %%
# ChunkTokenizer column names

chunk_token_jsl_col  = "chunk_token_jsl"
chunk_token_drug_col = "chunk_token_drug"

# ChunkTokenizer provides extra flexibility at the time of tokenizing a given chunk

jslChunkTokenizer = ChunkTokenizer().setSplitChars(tokenizer_chars)\
    .setInputCols(chunk_jsl_col).setOutputCol(chunk_token_jsl_col)
drugChunkTokenizer = ChunkTokenizer().setSplitChars(tokenizer_chars)\
    .setInputCols(chunk_drug_col).setOutputCol(chunk_token_drug_col)

# %%
# Entity Resolution Pretrained Model Names

icd10cm_model_name = "chunkresolve_icd10cm_clinical"
icd10cm_model_name = "ensembleresolve_icd10cm_clinical"
rxnorm_model_name  = "ensembleresolve_rxnorm_clinical"

# Entity Resolution column Names

icd10cm_col = "icd10cm_resolution"
rxnorm_col  = "rxnorm_resolution"

#ChunkEntityResolverModel.pretrained(icd10cm_model_name, models_language, models_repository)\
icd10cmResolver = \
    EnsembleEntityResolverModel.pretrained(icd10cm_model_name, models_language, models_repository)\
    .setEnableLevenshtein(True)\
    .setNeighbours(200).setAlternatives(5).setDistanceWeights([1,3,2,0,0,1])\
    .setExtramassPenalty(3).setPoolingStrategy("MAX")\
    .setInputCols(chunk_token_jsl_col, chunk_embs_jsl_col)\
    .setOutputCol(icd10cm_col)

rxnormResolver = EnsembleEntityResolverModel()\
    .pretrained(rxnorm_model_name, models_language, models_repository)\
    .setEnableLevenshtein(True)\
    .setNeighbours(200).setAlternatives(5).setDistanceWeights([1,3,2,0,0,1])\
    .setExtramassPenalty(3).setPoolingStrategy("MAX")\
    .setInputCols(chunk_token_drug_col, chunk_embs_drug_col)\
    .setOutputCol(rxnorm_col)\
# Out:
# ensembleresolve_icd10cm_clinical download started this may take some time.
# Approximate size to download 345 MB
# [OK!]
# ensembleresolve_rxnorm_clinical download started this may take some time.
# Approximate size to download 783.3 MB
# [OK!]

# %%
pipelineFull = Pipeline().setStages([
    docAssembler, 
    sentenceDetector, 
    tokenizer, 
    embeddings, 
    jslNer,
    drugNer,
    jslConverter,
    drugConverter,
    jslChunkEmbeddings, 
    drugChunkEmbeddings,
    jslChunkTokenizer,
    drugChunkTokenizer,
    rxnormResolver
])

# %%
# Persisiting temporarily to keep DAG size and resource usage low (Ensmeble Resolvers are Resource Intensive)
pipelineModelFull = pipelineFull.fit(data)
output = pipelineModelFull.transform(data)
output.write.mode("overwrite").save("temp")
output = spark.read.load("temp")

# %%
output = icd10cmResolver.transform(output).cache()

# %% [markdown]
# ## The last part of our pipeline are the **ChunkEntityResolvers**:
#
# ### EntityResolver:
# Trained on an augmented ICDO Dataset from JSL Data Market it provides histology codes resolution for the matched expressions. Other than providing the code in the "result" field it provides more metadata about the matching process:
#
# - all_k_results -> Sorted ResolverLabels in the top `alternatives` that match the distance `threshold`
# - all_k_resolutions -> Respective ResolverNormalized strings
# - all_k_confidences -> Respective normalized probabilities based in inverse distance valuesprobability
# - all_k_distances -> Respective distance values after aggregation
# - all_k_wmd_distances -> Respective WMD distance values (added if allDistancesMetadata==True)
# - all_k_tfidf_distances -> Respective TFIDF Cosine distance values (added if allDistancesMetadata==True)
# - all_k_jaccard_distances -> Respective Jaccard distance values (added if allDistancesMetadata==True)
# - all_k_sorensen_distances -> Respective SorensenDice distance values (added if allDistancesMetadata==True)
# - all_k_jaro_distances -> Respective JaroWinkler distance values (added if allDistancesMetadata==True)
# - all_k_levenshtein_distances -> Respective Levenshtein distance values (added if allDistancesMetadata==True)
# - target_text -> The actual searched string
# - resolved_text -> The top ResolverNormalized string
# - confidence -> Top probability
# - distance -> Top distance value
# - sentence -> Sentence index
# - chunk -> Chunk Index
# - token -> Token index

# %%
def quick_metadata_analysis(df, doc_field, chunk_field, code_fields):
    code_res_meta = ", ".join([f"{cf}.metadata" for cf in code_fields])
    expression = f"explode(arrays_zip({chunk_field}.begin, {chunk_field}.end, {chunk_field}.result, {chunk_field}.metadata, "+code_res_meta+")) as a"
    top_n_rest = [(f"float(a['{i+4}'].confidence) as {(cf.split('_')[0])}_conf",
                    f"arrays_zip(split(a['{i+4}'].all_k_results,':::'),split(a['{i+4}'].all_k_resolutions,':::')) as {cf.split('_')[0]+'_opts'}")
                    for i, cf in enumerate(code_fields)]
    top_n_rest_args = []
    for tr in top_n_rest:
        for t in tr:
            top_n_rest_args.append(t)
    return df.selectExpr(doc_field, expression) \
        .orderBy(docid_col, F.expr("a['0']"), F.expr("a['1']"))\
        .selectExpr(f"concat_ws('::',{doc_field},a['0'],a['1']) as coords", "a['2'] as chunk","a['3'].entity as entity", *top_n_rest_args)

# %%
icd10cm_analysis = \
quick_metadata_analysis(output, docid_col, chunk_jsl_col,[icd10cm_col]).toPandas()

# %%
rxnorm_analysis = \
quick_metadata_analysis(output, docid_col, chunk_drug_col,[rxnorm_col]).toPandas()

# %%
icd10cm_analysis[icd10cm_analysis.icd10cm_conf>0.5]
# Out:
#                    coords                         chunk     entity  \
# 0          1419::122::144       coronary artery disease  Diagnosis
# 1     17179871651::72::85                hypertension ,  Diagnosis
# 3   17179871651::124::132                     gastritis  Diagnosis
# 4    17179871866::84::102           dilated left atrium  Diagnosis
# 6   17179871866::467::487         pericardial effusions  Diagnosis
# 7     25769803781::46::58                 breast cancer  Diagnosis
# 9   25769803781::151::164                hyperlipidemia  Diagnosis
# 10  25769803781::177::200      urinary tract infections  Diagnosis
# 12    25769804562::70::89          myelogenous leukemia  Diagnosis
# 13  34359739832::551::558                      insomnia  Diagnosis
# 14  60129544572::227::248        acanthamoeba infection  Diagnosis
# 15  60129544572::347::361               cmv infection ,  Diagnosis
# 16  60129544572::471::482                  hyponatremia  Diagnosis
# 17    60129544592::24::47      skin and sinus infection  Diagnosis
# 18    68719478548::62::84       coronary artery disease  Diagnosis
# 19  68719478548::207::215                     cirrhosis  Diagnosis
# 20  68719478548::241::259           portal hypertension  Diagnosis
# 21  68719478548::280::307  upper gastrointestinal bleed  Diagnosis
# 22  68719478548::410::422                 renal failure  Diagnosis
# 23  68719478548::428::449        pulmonary hypertension  Diagnosis
# 24    68719478549::69::96  left ventricular hypertrophy  Diagnosis
# 25  68719478549::151::178  right ventricular dilatation  Diagnosis
# 26  68719478549::442::463        pulmonary hypertension  Diagnosis
# 28  68719479050::263::288    fixed inferolateral defect  Diagnosis
# 29  68719479050::292::311          systolic dysfunction  Diagnosis
# 30  68719479050::468::482               aortic stenosis  Diagnosis
#
#     icd10cm_conf  \
# 0         0.9835
# 1         0.9663
# 3         0.9995
# 4         0.9961
# 6         0.7889
# 7         0.9871
# 9         0.9998
# 10        0.5388
# 12        0.5312
# 13        0.9999
# 14        0.9933
# 15        0.9876
# 16        0.9996
# 17        0.9729
# 18        0.9835
# 19        0.9998
# 20        0.8403
# 21        1.0000
# 22        1.0000
# 23        0.9177
# 24        0.9611
# 25        0.8235
# 26        0.9177
# 28        0.9880
# 29        0.9999
# 30        0.7248
#
#                                                                                                                                                                                                                                                  icd10cm_opts
# 0   [(I2510, Atherosclerotic heart disease of native coronary artery without angina pectoris), (I739, Peripheral vascular disease, unspecified), (I2542, Coronary artery dissection), (I2541, Coronary artery aneurysm), (I2582, Chronic total occlusion o...
# 1                                      [(I701, Atherosclerosis of renal artery), (I270, Primary pulmonary hypertension), (I2720, Pulmonary hypertension, unspecified), (I158, Other secondary hypertension), (I2729, Other secondary pulmonary hypertension)]
# 3                [(K2970, Gastritis, unspecified, without bleeding), (K2900, Acute gastritis without bleeding), (K2920, Alcoholic gastritis without bleeding), (K2960, Other gastritis without bleeding), (K5281, Eosinophilic gastritis or gastroenteritis)]
# 4                                                         [(Q242, Cor triatriatum), (Q173, Other misshapen ear), (Q105, Congenital stenosis and stricture of lacrimal duct), (Q201, Double outlet right ventricle), (Q226, Hypoplastic right heart syndrome)]
# 6           [(I313, Pericardial effusion (noninflammatory)), (I314, Cardiac tamponade), (I318, Other specified diseases of pericardium), (I898, Other specified noninfective disorders of lymphatic vessels and lymph nodes), (I301, Infective pericarditis)]
# 7   [(C50919, Malignant neoplasm of unspecified site of unspecified female breast), (C61, Malignant neoplasm of prostate), (C23, Malignant neoplasm of gallbladder), (C569, Malignant neoplasm of unspecified ovary), (C541, Malignant neoplasm of endomet...
# 9                                                                                  [(E785, Hyperlipidemia, unspecified), (E7849, Other hyperlipidemia), (E781, Pure hyperglyceridemia), (E7801, Familial hypercholesterolemia), (E782, Mixed hyperlipidemia)]
# 10                 [(N390, Urinary tract infection, site not specified), (N139, Obstructive and reflux uropathy, unspecified), (N320, Bladder-neck obstruction), (N209, Urinary calculus, unspecified), (N219, Calculus of lower urinary tract, unspecified)]
# 12  [(C9500, Acute leukemia of unspecified cell type not having achieved remission), (C9510, Chronic leukemia of unspecified cell type not having achieved remission), (C92Z0, Other myeloid leukemia not having achieved remission), (C9210, Chronic myel...
# 13                                                                                            [(G4700, Insomnia, unspecified), (G4709, Other insomnia), (G4719, Other hypersomnia), (G4710, Hypersomnia, unspecified), (G4453, Primary thunderclap headache)]
# 14  [(B6010, Acanthamebiasis, unspecified), (A499, Bacterial infection, unspecified), (A039, Shigellosis, unspecified), (A029, Salmonella infection, unspecified), (B965, Pseudomonas (aeruginosa) (mallei) (pseudomallei) as the cause of diseases classi...
# 15                                                                                  [(B259, Cytomegaloviral disease, unspecified), (B340, Adenovirus infection, unspecified), (B749, Filariasis, unspecified), (B59, Pneumocystosis), (B710, Hymenolepiasis)]
# 16                                                                                                 [(E871, Hypo-osmolality and hyponatremia), (E876, Hypokalemia), (E870, Hyperosmolality and hypernatremia), (E875, Hyperkalemia), (E8341, Hypermagnesemia)]
# 17  [(L089, Local infection of the skin and subcutaneous tissue, unspecified), (L03011, Cellulitis of right finger), (L03012, Cellulitis of left finger), (L0390, Cellulitis, unspecified), (L989, Disorder of the skin and subcutaneous tissue, unspecifi...
# 18  [(I2510, Atherosclerotic heart disease of native coronary artery without angina pectoris), (I739, Peripheral vascular disease, unspecified), (I2542, Coronary artery dissection), (I2541, Coronary artery aneurysm), (I2582, Chronic total occlusion o...
# 19                                                          [(K740, Hepatic fibrosis), (K745, Biliary cirrhosis, unspecified), (K7030, Alcoholic cirrhosis of liver without ascites), (K744, Secondary biliary cirrhosis), (K7469, Other cirrhosis of liver)]
# 20                                                                              [(K766, Portal hypertension), (K751, Phlebitis of portal vein), (K3189, Other diseases of stomach and duodenum), (K740, Hepatic fibrosis), (K7469, Other cirrhosis of liver)]
# 21                    [(K922, Gastrointestinal hemorrhage, unspecified), (K2971, Gastritis, unspecified, with bleeding), (K912, Postsurgical malabsorption, not elsewhere classified), (K2211, Ulcer of esophagus with bleeding), (K567, Ileus, unspecified)]
# 22  [(I159, Secondary hypertension, unspecified), (I50814, Right heart failure due to left heart failure), (I509, Heart failure, unspecified), (I120, Hypertensive chronic kidney disease with stage 5 chronic kidney disease or end stage renal disease),...
# 23                                       [(I270, Primary pulmonary hypertension), (I701, Atherosclerosis of renal artery), (I288, Other diseases of pulmonary vessels), (I973, Postprocedural hypertension), (I2729, Other secondary pulmonary hypertension)]
# 24                                                                        [(I517, Cardiomegaly), (I253, Aneurysm of heart), (I519, Heart disease, unspecified), (I513, Intracardiac thrombosis, not elsewhere classified), (I4901, Ventricular fibrillation)]
# 25                                                                           [(I517, Cardiomegaly), (I253, Aneurysm of heart), (I519, Heart disease, unspecified), (I513, Intracardiac thrombosis, not elsewhere classified), (I428, Other cardiomyopathies)]
# 26                                       [(I270, Primary pulmonary hypertension), (I701, Atherosclerosis of renal artery), (I288, Other diseases of pulmonary vessels), (I973, Postprocedural hypertension), (I2729, Other secondary pulmonary hypertension)]
# 28  [(I2783, Eisenmenger's syndrome), (I510, Cardiac septal defect, acquired), (I459, Conduction disorder, unspecified), (I232, Ventricular septal defect as current complication following acute myocardial infarction), (I231, Atrial septal defect as c...
# 29  [(I519, Heart disease, unspecified), (I5020, Unspecified systolic (congestive) heart failure), (I5030, Unspecified diastolic (congestive) heart failure), (I5040, Unspecified combined systolic (congestive) and diastolic (congestive) heart failure)...
# 30                                              [(I060, Rheumatic aortic stenosis), (I771, Stricture of artery), (I77819, Aortic ectasia, unspecified site), (I719, Aortic aneurysm of unspecified site, without rupture), (I050, Rheumatic mitral stenosis)]

# %%
rxnorm_analysis[rxnorm_analysis.rxnorm_conf>0.5]
# Out:
#                      coords                             chunk    entity  \
# 0              1419::89::99                       cholesterol  DrugChem
# 1     17179871651::404::411                          atropine  DrugChem
# 2     17179871651::439::446                          dopamine  DrugChem
# 3     25769803781::107::115                         tamoxifen  DrugChem
# 4     25769803877::278::286                         adenosine  DrugChem
# 7         34359739832::0::6                           tylenol  DrugChem
# 8       34359739832::67::75                         acyclovir  DrugChem
# 9     34359739832::105::113                         acyclovir  DrugChem
# 10    34359739832::276::285                        folic acid  DrugChem
# 11    34359739832::307::315                         lorazepam  DrugChem
# 12    34359739832::435::441                           eucerin  DrugChem
# 13    34359739832::466::477                      zantac  1  5  DrugChem
# 15    34359739832::607::615                         lidocaine  DrugChem
# 16      34359740128::30::40                       quinn  8  2  DrugChem
# 17        34359740235::0::6                           aspirin  DrugChem
# 18      34359740235::26::34                         albuterol  DrugChem
# 20    34359740235::137::151                   synthroid  2  0  DrugChem
# 21    34359740235::204::214                       simvastatin  DrugChem
# 22    34359740235::280::291                      zantac  1  5  DrugChem
# 23    34359740235::307::314                          nystatin  DrugChem
# 24    34359740235::355::364                        lisinopril  DrugChem
# 25    34359740235::384::391                          mestinon  DrugChem
# 27    34359740235::476::485                        prednisone  DrugChem
# 29    60129544572::401::410                        creatinine  DrugChem
# 30       60129544655::0::10                       pentamidine  DrugChem
# 31      60129544655::47::57                       pentamidine  DrugChem
# 32    60129544655::116::127                      voriconazole  DrugChem
# 33    60129544655::158::166                         acyclovir  DrugChem
# 34    60129544655::197::208                      cyclosporine  DrugChem
# 35    60129544655::236::245                        prednisone  DrugChem
# 36    60129544655::375::385                       simethicone  DrugChem
# 37    60129544655::413::425                     nitroglycerin  DrugChem
# 38    60129544655::467::477                       flunisolide  DrugChem
# 39    60129544655::515::523                         oxycodone  DrugChem
# 40    60129544655::608::618                       fluconazole  DrugChem
# 42    60129544655::702::708                           tylenol  DrugChem
# 44    60129544655::798::806                         neurontin  DrugChem
# 49  60129544655::1166::1173                          nystatin  DrugChem
# 50    77309411777::310::319                        creatinine  DrugChem
# 51        94489280866::0::8                         albuterol  DrugChem
# 52      94489280866::45::52                          atrovent  DrugChem
# 53    94489280866::104::112                         albuterol  DrugChem
# 54    94489280866::118::125                          atrovent  DrugChem
# 55    94489280866::129::137                         rocaltrol  DrugChem
# 56    94489280866::173::189                 calcium carbonate  DrugChem
# 57    94489280866::228::236                         vitamin b  DrugChem
# 58    94489280866::306::314                         diltiazem  DrugChem
# 59    94489280866::347::361                   ferrous sulfate  DrugChem
# 60    94489280866::392::397                            haldol  DrugChem
# 61    94489280866::418::428                       hydralazine  DrugChem
# 62    94489280866::475::484                        lisinopril  DrugChem
# 63    94489280866::591::596                            zantac  DrugChem
# 64    94489280866::674::684                       macrodantin  DrugChem
# 65      94489282573::22::33                      tetracycline  DrugChem
# 66      94489282573::63::73                       cyclosporin  DrugChem
# 67    94489282573::103::112                        prednisone  DrugChem
# 68    94489282573::137::146                        bactrim ds  DrugChem
# 69    94489282573::167::175                         diltiazem  DrugChem
# 70    94489282573::202::211                        mycostatin  DrugChem
# 71    94489282573::253::257                             lasix  DrugChem
# 72    94489282573::350::355                            imuran  DrugChem
# 73        94489282654::0::6                           tylenol  DrugChem
# 75    94489282654::125::137                     nortriptyline  DrugChem
# 76    94489282654::165::175                       simvastatin  DrugChem
# 77    94489282654::203::211                         metamucil  DrugChem
# 78    94489282654::248::256                         neurontin  DrugChem
# 80    94489282654::333::364  lisinopril / hydrochlorothiazide  DrugChem
# 81    94489282654::397::410                    hydrocortisone  DrugChem
# 85      94489283102::60::71                      bicarbonates  DrugChem
# 86     94489283102::99::108                        creatinine  DrugChem
# 87    94489283102::120::126                           glucose  DrugChem
#
#     rxnorm_conf  \
# 0        0.9995
# 1        0.8091
# 2        0.9996
# 3        0.7936
# 4        0.9995
# 7        0.5824
# 8        0.9995
# 9        0.9995
# 10       0.7348
# 11       0.7309
# 12       0.9995
# 13       0.9769
# 15       0.6198
# 16       0.5047
# 17       0.6711
# 18       0.9995
# 20       0.5257
# 21       0.9995
# 22       0.9769
# 23       0.9998
# 24       0.9995
# 25       0.9995
# 27       0.5965
# 29       0.9999
# 30       0.8076
# 31       0.8076
# 32       0.9995
# 33       0.9995
# 34       0.9995
# 35       0.5965
# 36       0.9995
# 37       0.9996
# 38       0.9995
# 39       0.9995
# 40       0.9995
# 42       0.5824
# 44       0.9995
# 49       0.9998
# 50       0.9999
# 51       0.9995
# 52       0.5949
# 53       0.9995
# 54       0.5949
# 55       0.9995
# 56       0.5385
# 57       0.6834
# 58       0.9995
# 59       0.7034
# 60       0.9995
# 61       0.9995
# 62       0.9995
# 63       0.6023
# 64       0.9995
# 65       0.9995
# 66       0.9997
# 67       0.5965
# 68       0.8872
# 69       0.9995
# 70       0.9995
# 71       0.9995
# 72       0.9995
# 73       0.5824
# 75       0.9995
# 76       0.9995
# 77       0.9995
# 78       0.9995
# 80       0.9328
# 81       0.6562
# 85       0.9996
# 86       0.9999
# 87       0.7946
#
#                                                                                                                                                                                                                                                 rxnorm_opts
# 0                                                                                                                    [(2438, Cholesterol), (1366924, cholesterol sulfate), (10808, TRIGLYCERIDES), (6433, VLDL cholesterol), (1368200, cholesterol oleate)]
# 1                                                                                                                                      [(1223, Atropine), (92995, Isopto Atropine), (7971, pempidine), (153971, Atropine sulphate), (26839, Hexamethonium)]
# 2                                                                                                                                      [(3628, Dopamine), (62342, Dopamine agonists), (82010, dopamine HCl), (7512, Norepinephrine), (2146, Catecholamine)]
# 3                                                                                                                                       [(10324, Tamoxifen), (606421, GenRx Tamoxifen), (40137, Tamoxifen Citrate), (72143, Keoxifene), (72965, Letrozole)]
# 4                                                                                                     [(296, Adenosine), (318, Adenosine triphosphate), (359140, Adenosine Powder), (655027, ADENOSINE MONOPHOSPHATE PWDR), (309, Adenosine Monophosphate)]
# 7                                                                                                          [(202433, Tylenol), (1192485, Children's Tylenol), (353059, Infant's Tylenol), (692659, Tylenol GoTabs), (1192491, Children's Tylenol Meltaway)]
# 8                                                                                                                                                  [(281, Acyclovir), (10803, Trifluridine), (73645, valaciclovir), (33562, Foscarnet), (83171, Cidofovir)]
# 9                                                                                                                                                  [(281, Acyclovir), (10803, Trifluridine), (73645, valaciclovir), (33562, Foscarnet), (83171, Cidofovir)]
# 10                                                                                                               [(4511, Folic acid), (225860, Cantassium folic acid), (237787, Folic Acid Powder), (1431568, Folic acid analogues), (1151, Ascorbic acid)]
# 11                                                                                                                                     [(6470, Lorazepam), (672652, LORazepam Novaplus), (74667, Zaleplon), (381029, Diazepam RecTube), (10767, Triazolam)]
# 12                                                                                                                                         [(59478, Eucerin), (9100, Racemethionine), (2407, Chloroquinaldol), (33682, Picloxydine), (42463, Pravastatine)]
# 13                                                                                                                                    [(220992, Zantac 150), (1313178, PPG-15), (1302325, polyquaternium 15), (352656, Formule 115 DM), (1110075, PRM-151)]
# 15                                                                                                                         [(6387, Lidocaine), (1947765, LIDOCAINE PWDR), (1863550, Absorbine Lidocaine), (2103313, Satohap Lidocaine), (4171, Etidocaine)]
# 16                                                                                              [(1998906, lotilaner 225 MG), (1485525, doconexent 265 MG), (2044427, fosnetupitant 235 MG), (450555, PHENICARBAZIDE 243 MG), (446190, Lymecycline 226 MG)]
# 17                                                                                                                                [(1191, Aspirin), (238143, ASPIRIN PWDR), (215443, Litecoat Aspirin), (218783, Norwich Aspirin), (215568, Bayer Aspirin)]
# 18                                                                                                                            [(435, Albuterol), (10368, Terbutaline), (7688, Metaproterenol), (240460, Albuterol Powder), (214199, Albuterol Ipratropium)]
# 20  [(574318, Guaifenesin 1200 MG [Liquidbid 1200]), (564813, Colistin 1500000 UNT [Colomycin]), (1719783, Aldesleukin 22000000 UNT [Proleukin]), (574314, Activated Charcoal 25000 MG [Charcoaid 2000]), (575574, Guaifenesin 1200 MG [Guiadrine G-1200])]
# 21                                                                                                                                                [(36567, Simvastatin), (83367, Atorvastatin), (8699, Probucol), (42463, Pravastatin), (6472, Lovastatin)]
# 22                                                                                                                                    [(220992, Zantac 150), (1313178, PPG-15), (1302325, polyquaternium 15), (352656, Formule 115 DM), (1110075, PRM-151)]
# 23                                                                                                                                    [(312061, NYSTATIN PWDR), (4450, Fluconazol), (2121944, Conazol Miconazole), (6932, Miconazole), (26422, Haloprogin)]
# 24                                                                                                                                                  [(29046, Lisinopril), (35296, Ramipril), (35208, Quinapril), (17767, Amlodipine), (54552, Perindopril)]
# 25                                                                                                                                  [(203001, Mestinon), (180806, butalamine), (2400, Chlorprophenpyridamine), (2346, Chlorbutin), (4497, Fluprednisolone)]
# 27                                                                                                             [(8640, Prednisone), (312619, PREDNISONE PWDR), (582600, Prednisone Intensol), (34376, prednisolone tebutate), (235485, Prednisone acetate)]
# 29                                                                                                                                    [(2913, CREATININE), (829331, Creatinine Powder), (18225, Arabinitol), (60653, Ectyl urea), (352580, Dermaflex Urea)]
# 30                                                                                                                 [(7994, Pentamidine), (91073, Pentamidine diisothionate), (7995, Pentamidine Isethionate), (20883, chlorproguanil), (152209, Pentostam)]
# 31                                                                                                                 [(7994, Pentamidine), (91073, Pentamidine diisothionate), (7995, Pentamidine Isethionate), (20883, chlorproguanil), (152209, Pentostam)]
# 32                                                                                                                                       [(121243, Voriconazole), (28031, Itraconazole), (4450, Fluconazole), (341018, Anidulafungin), (4451, Flucytosine)]
# 33                                                                                                                                                 [(281, Acyclovir), (10803, Trifluridine), (73645, valaciclovir), (33562, Foscarnet), (83171, Cidofovir)]
# 34                                                                                                         [(3008, Cyclosporine), (2059454, Cyclosporine Powder), (1256, Azathioprine), (647973, cycloSPORINE ophthalmic), (236077, CycloSPORINE Modified)]
# 35                                                                                                             [(8640, Prednisone), (312619, PREDNISONE PWDR), (582600, Prednisone Intensol), (34376, prednisolone tebutate), (235485, Prednisone acetate)]
# 36                                                                                                                      [(9796, Simethicone), (317608, simethicone emulsion), (1323181, Simethicone Solution), (1948209, Acotiamide), (21125, Cinitapride)]
# 37                                                                                                               [(4917, Nitroglycerin), (285072, Nitroglycerin ER), (6057, Isosorbide), (31748, Nicorandil), (1431118, methylpropylpropanediol dinitrate)]
# 38                                                                                                                               [(25120, Flunisolide), (41126, Fluticasone), (606910, Flunisolide Micronized), (274964, Ciclesonide), (19831, Budesonide)]
# 39                                                                                                                          [(7804, Oxycodone), (82063, oxycodone HCl), (221107, HYDROCODONE POLISTIREX), (476889, oxycodone pectinate), (10689, Tramadol)]
# 40                                                                                                                               [(4450, Fluconazole), (2121944, Conazol Miconazole), (1720882, Isavuconazole), (37806, Terconazole), (6135, Ketoconazole)]
# 42                                                                                                         [(202433, Tylenol), (1192485, Children's Tylenol), (353059, Infant's Tylenol), (692659, Tylenol GoTabs), (1192491, Children's Tylenol Meltaway)]
# 44                                                                                                                                                         [(196498, Neurontin), (6760, Meprobamat), (203799, Nardil), (114228, Paxil), (10510, tiotixene)]
# 49                                                                                                                                    [(312061, NYSTATIN PWDR), (4450, Fluconazol), (2121944, Conazol Miconazole), (6932, Miconazole), (26422, Haloprogin)]
# 50                                                                                                                                    [(2913, CREATININE), (829331, Creatinine Powder), (18225, Arabinitol), (60653, Ectyl urea), (352580, Dermaflex Urea)]
# 51                                                                                                                            [(435, Albuterol), (10368, Terbutaline), (7688, Metaproterenol), (240460, Albuterol Powder), (214199, Albuterol Ipratropium)]
# 52                                                                                                                                [(151390, Atrovent), (379767, Atrovent Autohaler), (379769, Atrovent Aerocap), (202473, Diazemuls), (32675, Oxybutynine)]
# 53                                                                                                                            [(435, Albuterol), (10368, Terbutaline), (7688, Metaproterenol), (240460, Albuterol Powder), (214199, Albuterol Ipratropium)]
# 54                                                                                                                                [(151390, Atrovent), (379767, Atrovent Autohaler), (379769, Atrovent Aerocap), (202473, Diazemuls), (32675, Oxybutynine)]
# 55                                                                                                                        [(152323, Rocaltrol), (19207, Lapachone), (1858416, Afterbite Xtra), (2002796, levocloperastine fendizoate), (152606, DaunoXome)]
# 56                                                                                [(1897, Calcium carbonate), (2059337, CALCIUM CARBONATE PWDR), (29155, Magnesium carbonate), (349908, precipitated calcium carbonate), (605116, Calcium Carbonate Light)]
# 57                                                                                                                                                  [(11251, Vitamin B), (1551642, VITAMIN C), (1151, Vitamin C), (1551673, VITAMIN E), (11256, Vitamin E)]
# 58                                                                                                                                            [(3443, Diltiazem), (33910, Isradipine), (81999, Diltiazem Malate), (7417, Nifedipine), (39879, Barnidipine)]
# 59                                                                                        [(24947, Ferrous sulfate), (237507, Ferrous Sulfate Granule), (1144988, Ferrous Sulfate Cream), (405078, Ferrous Sulfate ER), (1135373, Ferrous Sulfate Crystal)]
# 60                                                                                                                                                  [(151839, Haldol), (202473, Diazemuls), (6011, Isocarboxazide), (784911, Solabegron), (136560, Nimbex)]
# 61                                                                                                                                 [(5470, Hydralazine), (82027, hydralazine HCl), (3409, Dihydralazine), (217597, Hydralazine Plus), (49608, endralazine)]
# 62                                                                                                                                                  [(29046, Lisinopril), (35296, Ramipril), (35208, Quinapril), (17767, Amlodipine), (54552, Perindopril)]
# 63                                                                                                                                  [(152523, Zantac), (220997, Zantac GELdose), (220996, Zantac EFFERdose), (19207, Lapachone), (1858416, Afterbite Xtra)]
# 64                                                                                                                               [(203054, Macrodantin), (19207, Lapachone), (2002796, levocloperastine fendizoate), (180817, visnadine), (24474, valamin)]
# 65                                                                                                           [(10395, Tetracycline), (142446, tetracycline HCl), (236873, TETRACYCLINE TRIHYDRATE), (708232, Tetracycline antibiotics), (6398, Lincomycin)]
# 66                                                                                                                                                  [(3008, Cyclosporin), (42316, Tacrolimus), (202817, Neoral), (52799, Mizoribine), (1256, Azathioprine)]
# 67                                                                                                             [(8640, Prednisone), (312619, PREDNISONE PWDR), (582600, Prednisone Intensol), (34376, prednisolone tebutate), (235485, Prednisone acetate)]
# 68                                                                                                                                           [(346206, Bactrim DS), (218732, Nicorette DS), (1376967, Palgic-DS), (606093, Urso DS), (220336, Tolectin DS)]
# 69                                                                                                                                            [(3443, Diltiazem), (33910, Isradipine), (81999, Diltiazem Malate), (7417, Nifedipine), (39879, Barnidipine)]
# 70                                                                                                                                            [(202719, Mycostatin), (4550, Phosphonomycin), (9991, Spiramycine), (2623, Clotrimazol), (57047, terizidone)]
# 71                                                                                                                                           [(202991, Lasix), (5487, Dihydrochlorothiazide), (227555, Methergin), (18952, Benziodarone), (20863, delagil)]
# 72                                                                                                                                               [(202559, Imuran), (2346, Chlorbutin), (18952, Benziodarone), (20863, delagil), (19084, Benzylthiouracil)]
# 73                                                                                                         [(202433, Tylenol), (1192485, Children's Tylenol), (353059, Infant's Tylenol), (692659, Tylenol GoTabs), (1192491, Children's Tylenol Meltaway)]
# 75                                                                                                                                               [(7531, Nortriptyline), (10737, Trazodone), (2597, Clomipramine), (36437, Sertraline), (5691, Imipramine)]
# 76                                                                                                                                                [(36567, Simvastatin), (83367, Atorvastatin), (8699, Probucol), (42463, Pravastatin), (6472, Lovastatin)]
# 77                                                                                                                              [(6802, Metamucil), (19207, Lapachone), (2002796, levocloperastine fendizoate), (152439, Trancopal), (1330241, Crenezumab)]
# 78                                                                                                                                                         [(196498, Neurontin), (6760, Meprobamat), (203799, Nardil), (114228, Paxil), (10510, tiotixene)]
# 80                                         [(214618, Hydrochlorothiazide-Lisinopril), (214536, Enalapril-Hydrochlorothiazide), (818284, Hydrochlorothiazide / Ramipril), (214357, Captopril-Hydrochlorothiazide), (261415, Fosinopril-Hydrochlorothiazide)]
# 81                                                                                        [(5492, Hydrocortisone), (238756, HYDROCORTISONE PWDR), (27196, hydrocortisone probutate), (1438748, Gadaderm Hydrocortisone), (21648, Hydrocortisone phosphate)]
# 85                                                                                                                                     [(1527, BICARBONATES), (975127, BICARBONATE), (8588, Kalium), (8597, kalium jodatum), (17774, Ammonium bicarbonate)]
# 86                                                                                                                                    [(2913, CREATININE), (829331, Creatinine Powder), (18225, Arabinitol), (60653, Ectyl urea), (352580, Dermaflex Urea)]
# 87                                                                                                           [(4850, Glucose), (1423388, ReliOn Glucose), (1086383, Enfamil Glucose), (1364777, TRUEplus Glucose Shot), (636128, Publix Glucose Raspberry)]
