# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/spark-nlp-workshop/blob/master/tutorials/Certification_Trainings/Healthcare/11.2.Pretrained_NER_Profiling_Pipelines.ipynb)

# %%
import os

jsl_secret = os.getenv('SECRET')

import sparknlp
sparknlp_version = sparknlp.version()
import sparknlp_jsl
jsl_version = sparknlp_jsl.version()

print (jsl_secret)

# %%
import json
import os
from pyspark.ml import Pipeline,PipelineModel
from pyspark.sql import SparkSession

from sparknlp.annotator import *
from sparknlp_jsl.annotator import *
from sparknlp.base import *
import sparknlp_jsl
import sparknlp

params = {"spark.driver.memory":"16G",
"spark.kryoserializer.buffer.max":"2000M",
"spark.driver.maxResultSize":"2000M"}

spark = sparknlp_jsl.start(jsl_secret,params=params)

print ("Spark NLP Version :", sparknlp.version())
print ("Spark NLP_JSL Version :", sparknlp_jsl.version())
# Out:
# Spark NLP Version : 3.2.3
# Spark NLP_JSL Version : 3.2.3

# %% [markdown]
# # Clinical NER Model Profiling Pretrained Pipeline
#
# This pipeline can be used to explore all the available pretrained NER models at once. When you run this pipeline over your text, you will end up with the predictions coming out of each pretrained clinical NER model trained with `embeddings_clinical`.
#
# |Clinical NER Model List|
# |-|
# |ner_ade_clinical|
# |ner_posology_greedy|
# |ner_risk_factors|
# |jsl_ner_wip_clinical|
# |ner_human_phenotype_gene_clinical|
# |jsl_ner_wip_greedy_clinical|
# |ner_cellular|
# |ner_cancer_genetics|
# |jsl_ner_wip_modifier_clinical|
# |ner_drugs_greedy|
# |ner_deid_sd_large|
# |ner_diseases|
# |nerdl_tumour_demo|
# |ner_deid_subentity_augmented|
# |ner_jsl_enriched|
# |ner_genetic_variants|
# |ner_bionlp|
# |ner_measurements_clinical|
# |ner_diseases_large|
# |ner_radiology|
# |ner_deid_augmented|
# |ner_anatomy|
# |ner_chemprot_clinical|
# |ner_posology_experimental|
# |ner_drugs|
# |ner_deid_sd|
# |ner_posology_large|
# |ner_deid_large|
# |ner_posology|
# |ner_deidentify_dl|
# |ner_deid_enriched|
# |ner_bacterial_species|
# |ner_drugs_large|
# |ner_clinical_large|
# |jsl_rd_ner_wip_greedy_clinical|
# |ner_medmentions_coarse|
# |ner_radiology_wip_clinical|
# |ner_clinical|
# |ner_chemicals|
# |ner_deid_synthetic|
# |ner_events_clinical|
# |ner_posology_small|
# |ner_anatomy_coarse|
# |ner_human_phenotype_go_clinical|
# |ner_jsl_slim|
# |ner_jsl|
# |ner_jsl_greedy|
# |ner_events_admission_clinical|
#
# You can check [Models Hub](https://nlp.johnsnowlabs.com/models) page for more information about all these models and more.

# %%
from sparknlp.pretrained import PretrainedPipeline

clinical_profiling_pipeline = PretrainedPipeline("ner_profiling_clinical", "en", "clinical/models")
# Out:
# ner_profiling_clinical download started this may take some time.
# Approx size to download 2.2 GB
# [OK!]

# %%
text = '''A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus ( T2DM ), one prior episode of HTG-induced pancreatitis three years prior to presentation , associated with an acute hepatitis , and obesity with a body mass index ( BMI ) of 33.5 kg/m2 , presented with a one-week history of polyuria , polydipsia , poor appetite , and vomiting .'''

# %%
clinical_result = clinical_profiling_pipeline.annotate(text)
clinical_result.keys()
# Out:
# dict_keys(['ner_ade_clinical_chunks', 'ner_posology_greedy_chunks', 'ner_risk_factors_chunks', 'jsl_ner_wip_clinical_chunks', 'ner_human_phenotype_gene_clinical_chunks', 'jsl_ner_wip_greedy_clinical_chunks', 'ner_cellular_chunks', 'ner_cancer_genetics_chunks', 'jsl_ner_wip_modifier_clinical_chunks', 'ner_drugs_greedy_chunks', 'ner_deid_sd_large_chunks', 'ner_diseases_chunks', 'nerdl_tumour_demo_chunks', 'ner_deid_subentity_augmented_chunks', 'ner_jsl_enriched_chunks', 'ner_genetic_variants_chunks', 'ner_bionlp_chunks', 'ner_measurements_clinical_chunks', 'ner_diseases_large_chunks', 'ner_radiology_chunks', 'ner_deid_augmented_chunks', 'ner_anatomy_chunks', 'ner_chemprot_clinical_chunks', 'ner_posology_experimental_chunks', 'ner_drugs_chunks', 'ner_deid_sd_chunks', 'ner_posology_large_chunks', 'ner_deid_large_chunks', 'ner_posology_chunks', 'ner_deidentify_dl_chunks', 'ner_deid_enriched_chunks', 'ner_bacterial_species_chunks', 'ner_drugs_large_chunks', 'ner_clinical_large_chunks', 'token', 'jsl_rd_ner_wip_greedy_clinical_chunks', 'ner_medmentions_coarse_chunks', 'ner_radiology_wip_clinical_chunks', 'ner_clinical_chunks', 'ner_chemicals_chunks', 'ner_deid_synthetic_chunks', 'ner_events_clinical_chunks', 'ner_posology_small_chunks', 'ner_anatomy_coarse_chunks', 'ner_human_phenotype_go_clinical_chunks', 'ner_jsl_slim_chunks', 'ner_jsl_chunks', 'ner_jsl_greedy_chunks', 'sentence', 'ner_events_admission_clinical_chunks'])

# %%
print("Clinical Text: \n", text, "\n \nResults:\n")

for i in clinical_result.keys():
  print("{} : ".format(i), clinical_result[i])
# Out:
# Clinical Text:
#
# At this time, chest tube placement for drainage of the fluid occurred and thoracoscopy with fluid biopsies, which were performed, which revealed epithelioid malignant mesothelioma.
# The patient was then stained with a PET CT, which showed extensive uptake in the chest, bilateral pleural pericardial effusions, and lymphadenopathy.
# She also had acidic fluid, pectoral and intramammary lymph nodes and uptake in L4 with SUV of 4. This was consistent with stage III disease. Her repeat echocardiogram showed an ejection fraction of 45% to 49%.
# She was transferred to Oncology service and started on chemotherapy on September 1, 2007 with cisplatin 75 mg/centimeter squared equaling 109 mg IV piggyback over 2 hours on September 1, 2007
#
#
# Results:
#
# ner_ade_clinical_chunks :  ['chest tube placement', 'drainage of the fluid', 'chemotherapy', 'cisplatin', 'IV piggyback']
# ner_posology_greedy_chunks :  ['chemotherapy', 'cisplatin 75 mg/centimeter', '109 mg IV piggyback', 'over 2 hours']
# ner_risk_factors_chunks :  ['September', '2007', 'September', '2007']
# jsl_ner_wip_clinical_chunks :  ['chest tube placement', 'drainage of the fluid', 'thoracoscopy', 'fluid biopsies', 'epithelioid malignant mesothelioma', 'PET CT', 'extensive', 'uptake', 'chest', 'bilateral', 'pleural pericardial effusions', 'lymphadenopathy', 'She', 'acidic fluid', 'pectoral', 'intramammary lymph nodes', 'L4', 'SUV', '4', 'stage III disease', 'Her', 'echocardiogram', 'ejection fraction', '45%', '49%', 'She', 'Oncology service', 'chemotherapy', 'September 1, 2007', 'cisplatin', '75 mg/centimeter', '109 mg', 'IV', 'over 2 hours', 'September 1, 2007']
# ner_human_phenotype_gene_clinical_chunks :  ['chest tube placement', 'malignant mesothelioma', 'bilateral', 'pleural pericardial effusions', 'mg']
# jsl_ner_wip_greedy_clinical_chunks :  ['chest tube placement', 'thoracoscopy', 'fluid biopsies', 'epithelioid malignant mesothelioma', 'PET CT', 'extensive uptake in the chest', 'bilateral', 'pleural pericardial effusions', 'lymphadenopathy', 'She', 'acidic fluid', 'pectoral', 'intramammary lymph nodes', 'L4', 'SUV', '4', 'stage III disease', 'Her', 'echocardiogram', 'ejection fraction', '45% to 49%', 'She', 'Oncology service', 'chemotherapy on September 1, 2007 with cisplatin 75', '109 mg', 'IV', 'over 2 hours', 'September 1, 2007']
# ner_cellular_chunks :  []
# ner_cancer_genetics_chunks :  []
# jsl_ner_wip_modifier_clinical_chunks :  ['chest tube placement', 'thoracoscopy', 'fluid biopsies', 'epithelioid malignant mesothelioma', 'PET CT', 'extensive uptake in the chest', 'bilateral', 'pleural pericardial effusions', 'lymphadenopathy', 'She', 'acidic fluid', 'pectoral', 'intramammary lymph nodes', 'L4', 'SUV', '4', 'stage III disease', 'Her', 'echocardiogram', 'ejection fraction', '45% to 49%', 'She', 'Oncology service', 'chemotherapy on September 1, 2007 with cisplatin 75', '109 mg', 'IV', 'over 2 hours', 'September 1, 2007']
# ner_drugs_greedy_chunks :  ['chemotherapy', 'cisplatin 75 mg/centimeter squared']
# ner_deid_sd_large_chunks :  ['September 1, 2007', 'September 1, 2007']
# ner_diseases_chunks :  ['the fluid', 'epithelioid malignant mesothelioma', 'extensive uptake in the chest', 'bilateral pleural pericardial effusions', 'lymphadenopathy', 'acidic fluid', 'stage III disease']
# nerdl_tumour_demo_chunks :  []
# ner_deid_subentity_augmented_chunks :  ['September 1, 2007', 'September 1, 2007']
# ner_jsl_enriched_chunks :  ['thoracoscopy', 'fluid biopsies', 'epithelioid', 'malignant', 'mesothelioma', 'PET CT', 'pleural pericardial effusions', 'lymphadenopathy', 'She', 'stage III disease', 'Her', 'echocardiogram', 'She', 'chemotherapy', 'cisplatin', '75 mg/centimeter squared equaling 109 mg', 'IV piggyback', 'over 2 hours']
# ner_genetic_variants_chunks :  []
# ner_bionlp_chunks :  ['chest tube', 'epithelioid malignant mesothelioma', 'patient', 'chest', 'pleural pericardial', 'She', 'pectoral', 'intramammary lymph nodes', 'L4', 'She', 'cisplatin']
# ner_measurements_clinical_chunks :  ['45% to 49%', '109', 'mg']
# ner_diseases_large_chunks :  ['epithelioid malignant mesothelioma', 'chest, bilateral pleural pericardial effusions', 'lymphadenopathy']
# ner_radiology_chunks :  ['chest tube placement', 'drainage of the fluid', 'thoracoscopy', 'fluid biopsies', 'epithelioid malignant mesothelioma', 'PET CT', 'extensive uptake', 'chest', 'bilateral pleural pericardial', 'effusions', 'lymphadenopathy', 'acidic fluid', 'pectoral', 'intramammary lymph nodes', 'uptake', 'L4', 'SUV', 'stage III disease', 'echocardiogram', 'ejection fraction', '45%', '49%', '75', 'mg/centimeter', '109', 'mg']
# ner_deid_augmented_chunks :  ['September 1, 2007', 'September 1, 2007']
# ner_anatomy_chunks :  ['fluid', 'fluid biopsies', 'mesothelioma', 'pleural pericardial effusions', 'fluid', 'pectoral', 'lymph nodes']
# ner_chemprot_clinical_chunks :  ['CT', 'cisplatin']
# ner_posology_experimental_chunks :  ['chemotherapy', 'cisplatin', '75 mg/centimeter squared equaling', '109 mg', 'IV']
# ner_drugs_chunks :  ['cisplatin']
# ner_deid_sd_chunks :  ['September 1, 2007', 'September 1, 2007']
# ner_posology_large_chunks :  ['chemotherapy', 'cisplatin', '75 mg/centimeter squared', '109 mg', 'IV', 'piggyback', 'over 2 hours']
# ner_deid_large_chunks :  ['September 1, 2007', 'September 1, 2007']
# ner_posology_chunks :  ['chemotherapy', 'cisplatin', '75 mg/centimeter', '109 mg', 'IV', 'piggyback', 'over 2 hours']
# ner_deidentify_dl_chunks :  ['September 1, 2007', 'September 1, 2007']
# ner_deid_enriched_chunks :  ['September 1, 2007', 'September 1, 2007']
# ner_bacterial_species_chunks :  []
# ner_drugs_large_chunks :  ['chemotherapy', 'cisplatin 75 mg/centimeter squared equaling 109 mg IV']
# ner_clinical_large_chunks :  ['chest tube placement', 'drainage of the fluid', 'thoracoscopy', 'fluid biopsies', 'epithelioid malignant mesothelioma', 'a PET CT', 'extensive uptake in the chest', 'bilateral pleural pericardial effusions', 'lymphadenopathy', 'acidic fluid', 'pectoral and intramammary lymph nodes', 'uptake in L4', 'SUV', 'stage III disease', 'Her repeat echocardiogram', 'an ejection fraction', 'chemotherapy', 'cisplatin', 'IV piggyback']
# token :  ['At', 'this', 'time', ',', 'chest', 'tube', 'placement', 'for', 'drainage', 'of', 'the', 'fluid', 'occurred', 'and', 'thoracoscopy', 'with', 'fluid', 'biopsies', ',', 'which', 'were', 'performed', ',', 'which', 'revealed', 'epithelioid', 'malignant', 'mesothelioma', '.', 'The', 'patient', 'was', 'then', 'stained', 'with', 'a', 'PET', 'CT', ',', 'which', 'showed', 'extensive', 'uptake', 'in', 'the', 'chest', ',', 'bilateral', 'pleural', 'pericardial', 'effusions', ',', 'and', 'lymphadenopathy', '.', 'She', 'also', 'had', 'acidic', 'fluid', ',', 'pectoral', 'and', 'intramammary', 'lymph', 'nodes', 'and', 'uptake', 'in', 'L4', 'with', 'SUV', 'of', '4', '.', 'This', 'was', 'consistent', 'with', 'stage', 'III', 'disease', '.', 'Her', 'repeat', 'echocardiogram', 'showed', 'an', 'ejection', 'fraction', 'of', '45%', 'to', '49%', '.', 'She', 'was', 'transferred', 'to', 'Oncology', 'service', 'and', 'started', 'on', 'chemotherapy', 'on', 'September', '1', ',', '2007', 'with', 'cisplatin', '75', 'mg/centimeter', 'squared', 'equaling', '109', 'mg', 'IV', 'piggyback', 'over', '2', 'hours', 'on', 'September', '1', ',', '2007']
# jsl_rd_ner_wip_greedy_clinical_chunks :  ['chest tube placement', 'drainage of the fluid', 'thoracoscopy', 'fluid biopsies', 'epithelioid malignant mesothelioma', 'PET CT', 'extensive uptake', 'chest', 'bilateral', 'pleural pericardial effusions', 'lymphadenopathy', 'She', 'acidic fluid', 'pectoral', 'intramammary lymph nodes', 'L4', 'SUV', '4', 'stage III disease', 'Her', 'echocardiogram', 'ejection fraction', '45% to 49%', 'She', 'Oncology service', 'chemotherapy', 'September 1, 2007', 'cisplatin 75', '109 mg', 'IV piggyback', 'over 2 hours', 'September 1, 2007']
# ner_medmentions_coarse_chunks :  ['chest tube placement', 'drainage', 'fluid', 'thoracoscopy', 'fluid biopsies', 'epithelioid malignant mesothelioma', 'PET CT', 'chest', 'bilateral pleural pericardial effusions', 'lymphadenopathy', 'acidic fluid', 'pectoral', 'intramammary lymph nodes', 'uptake', 'L4', 'SUV', 'stage III disease', 'repeat echocardiogram', 'ejection fraction', 'Oncology service', 'chemotherapy', 'cisplatin']
# ner_radiology_wip_clinical_chunks :  ['chest tube placement', 'drainage of the fluid', 'thoracoscopy', 'fluid biopsies', 'malignant mesothelioma', 'PET CT', 'extensive uptake', 'chest', 'bilateral', 'pleural pericardial', 'effusions', 'lymphadenopathy', 'acidic fluid', 'pectoral', 'intramammary lymph nodes', 'uptake', 'L4', 'SUV', '4', 'stage III disease', 'echocardiogram', 'ejection fraction of 45% to 49%', '75', 'mg/centimeter', '109', 'mg']
# ner_clinical_chunks :  ['chest tube placement', 'drainage of the fluid', 'thoracoscopy', 'fluid biopsies', 'epithelioid malignant mesothelioma', 'a PET CT', 'extensive uptake in the chest', 'bilateral pleural pericardial effusions', 'lymphadenopathy', 'acidic fluid', 'pectoral and intramammary lymph nodes', 'uptake in L4', 'SUV', 'stage III disease', 'Her repeat echocardiogram', 'an ejection fraction', 'chemotherapy', 'cisplatin', 'IV piggyback']
# ner_chemicals_chunks :  ['cisplatin']
# ner_deid_synthetic_chunks :  ['September 1, 2007', 'September 1, 2007']
# ner_events_clinical_chunks :  ['this time', 'chest tube placement', 'drainage', 'the fluid', 'thoracoscopy', 'fluid biopsies', 'revealed', 'epithelioid malignant mesothelioma', 'stained', 'a PET CT', 'showed', 'extensive uptake in the chest', 'bilateral pleural pericardial effusions', 'lymphadenopathy', 'acidic fluid, pectoral and intramammary lymph nodes', 'uptake in L4', 'SUV', 'stage III disease', 'Her repeat echocardiogram', 'showed', 'an ejection fraction', 'transferred', 'Oncology service', 'chemotherapy', 'September 1, 2007', 'cisplatin', 'IV piggyback', '2 hours', 'September 1, 2007']
# ner_posology_small_chunks :  ['chemotherapy', 'cisplatin', '75', '109 mg', 'IV', 'piggyback', 'over 2 hours']
# ner_anatomy_coarse_chunks :  ['chest tube', 'fluid', 'fluid biopsies', 'epithelioid malignant mesothelioma', 'chest', 'bilateral pleural pericardial effusions', 'fluid', 'pectoral', 'intramammary lymph nodes']
# ner_human_phenotype_go_clinical_chunks :  ['chest tube placement', 'mesothelioma', 'bilateral', 'lymphadenopathy']
# ner_jsl_slim_chunks :  ['chest tube placement', 'drainage of the fluid', 'thoracoscopy', 'fluid biopsies', 'epithelioid malignant mesothelioma', 'PET CT', 'extensive uptake in the chest', 'pleural pericardial effusions', 'lymphadenopathy', 'She', 'acidic fluid', 'pectoral', 'intramammary lymph nodes', 'L4', 'stage III disease', 'Her', 'echocardiogram', 'ejection fraction', '45% to 49%', 'She', 'Oncology service', 'chemotherapy on September 1, 2007 with cisplatin 75', 'September 1, 2007']
# ner_jsl_chunks :  ['chest tube placement', 'drainage of the fluid', 'thoracoscopy', 'fluid biopsies', 'epithelioid malignant mesothelioma', 'PET CT', 'extensive', 'uptake', 'chest', 'bilateral', 'pleural pericardial effusions', 'lymphadenopathy', 'She', 'acidic fluid', 'pectoral', 'intramammary lymph nodes', 'L4', 'SUV', '4', 'stage III disease', 'Her', 'echocardiogram', 'ejection fraction', '45%', '49%', 'She', 'Oncology service', 'chemotherapy', 'September 1, 2007', 'cisplatin', '75 mg/centimeter', '109 mg', 'IV', 'over 2 hours', 'September 1, 2007']
# ner_jsl_greedy_chunks :  ['chest tube placement', 'thoracoscopy', 'fluid biopsies', 'epithelioid malignant mesothelioma', 'PET CT', 'extensive uptake in the chest', 'bilateral', 'pleural pericardial effusions', 'lymphadenopathy', 'She', 'acidic fluid', 'pectoral', 'intramammary lymph nodes', 'L4', 'SUV', '4', 'stage III disease', 'Her', 'echocardiogram', 'ejection fraction', '45% to 49%', 'She', 'Oncology service', 'chemotherapy on September 1, 2007 with cisplatin 75', '109 mg', 'IV', 'over 2 hours', 'September 1, 2007']
# sentence :  ['At this time, chest tube placement for drainage of the fluid occurred and thoracoscopy with fluid biopsies, which were performed, which revealed epithelioid malignant mesothelioma.', 'The patient was then stained with a PET CT, which showed extensive uptake in the chest, bilateral pleural pericardial effusions, and lymphadenopathy.', 'She also had acidic fluid, pectoral and intramammary lymph nodes and uptake in L4 with SUV of 4.', 'This was consistent with stage III disease.', 'Her repeat echocardiogram showed an ejection fraction of 45% to 49%.', 'She was transferred to Oncology service and started on chemotherapy on September 1, 2007 with cisplatin 75 mg/centimeter squared equaling 109 mg IV piggyback over 2 hours on September 1, 2007']
# ner_events_admission_clinical_chunks :  ['chest tube placement', 'drainage of the fluid', 'thoracoscopy', 'fluid biopsies', 'revealed', 'epithelioid malignant mesothelioma', 'stained', 'a PET CT', 'showed', 'extensive uptake in the chest', 'bilateral pleural pericardial effusions', 'lymphadenopathy', 'acidic fluid, pectoral and intramammary lymph nodes', 'uptake in L4', 'SUV', 'stage III disease', 'Her repeat echocardiogram', 'showed', 'an ejection fraction', 'transferred', 'Oncology service', 'chemotherapy', 'September 1, 2007', 'cisplatin', 'over 2 hours', 'September 1, 2007']

# %%
import pandas as pd


def get_results(light_result):

  for i in light_result.keys():
    
    model_name = "_".join(i.split("_")[:-1])

    if (i == 'sentence') | (i == 'token'):
      
      continue
    
    elif len(light_result[i]) == 0:
      
      print("\n", "*"*20, model_name, "Model Results", "*"*20)
      print("No Result For This Model")

    
    else:

      sentences = []
      begins = []
      ends = []
      chunks = []
      entities = []
      confidences = []

      for n in (light_result[i]):

        sentences.append(n.metadata['sentence'])
        begins.append(n.begin)
        ends.append(n.end) 
        chunks.append(n.result)
        entities.append(n.metadata['entity'])
        confidences.append(n.metadata['confidence'])

        
      df = pd.DataFrame({'sentence':sentences, 'begin': begins, 'end': ends, 'chunks': chunks, 'entity': entities, 'confidence': confidences})
      
      print("\n \n", "*"*20, model_name, "Model Results", "*"*20)
      display(df)

# %%
text2 = """
At this time, chest tube placement for drainage of the fluid occurred and thoracoscopy with fluid biopsies, which were performed, which revealed epithelioid malignant mesothelioma. 
The patient was then stained with a PET CT, which showed extensive uptake in the chest, bilateral pleural pericardial effusions, and lymphadenopathy. 
She also had acidic fluid, pectoral and intramammary lymph nodes and uptake in L4 with SUV of 4. This was consistent with stage III disease. Her repeat echocardiogram showed an ejection fraction of 45% to 49%. 
She was transferred to Oncology service and started on chemotherapy on September 1, 2007 with cisplatin 75 mg/centimeter squared equaling 109 mg IV piggyback over 2 hours on September 1, 2007
"""

# %%
clinical_full_result = clinical_profiling_pipeline.fullAnnotate(text2)[0]

# %%
clinical_full_result['ner_jsl_chunks']
# Out:
# [Annotation(chunk, 15, 34, chest tube placement, {'entity': 'Procedure', 'sentence': '0', 'chunk': '0', 'confidence': '0.46089998'}),
#  Annotation(chunk, 40, 60, drainage of the fluid, {'entity': 'Procedure', 'sentence': '0', 'chunk': '1', 'confidence': '0.40230003'}),
#  Annotation(chunk, 75, 86, thoracoscopy, {'entity': 'Procedure', 'sentence': '0', 'chunk': '2', 'confidence': '0.9927'}),
#  Annotation(chunk, 93, 106, fluid biopsies, {'entity': 'Procedure', 'sentence': '0', 'chunk': '3', 'confidence': '0.80535'}),
#  Annotation(chunk, 146, 179, epithelioid malignant mesothelioma, {'entity': 'Oncological', 'sentence': '0', 'chunk': '4', 'confidence': '0.934'}),
#  Annotation(chunk, 219, 224, PET CT, {'entity': 'Test', 'sentence': '1', 'chunk': '5', 'confidence': '0.946'}),
#  Annotation(chunk, 240, 248, extensive, {'entity': 'Modifier', 'sentence': '1', 'chunk': '6', 'confidence': '0.8028'}),
#  Annotation(chunk, 250, 255, uptake, {'entity': 'ImagingFindings', 'sentence': '1', 'chunk': '7', 'confidence': '0.5804'}),
#  Annotation(chunk, 264, 268, chest, {'entity': 'External_body_part_or_region', 'sentence': '1', 'chunk': '8', 'confidence': '0.7954'}),
#  Annotation(chunk, 271, 279, bilateral, {'entity': 'Direction', 'sentence': '1', 'chunk': '9', 'confidence': '0.5107'}),
#  Annotation(chunk, 281, 309, pleural pericardial effusions, {'entity': 'Disease_Syndrome_Disorder', 'sentence': '1', 'chunk': '10', 'confidence': '0.37933335'}),
#  Annotation(chunk, 316, 330, lymphadenopathy, {'entity': 'Symptom', 'sentence': '1', 'chunk': '11', 'confidence': '0.9799'}),
#  Annotation(chunk, 334, 336, She, {'entity': 'Gender', 'sentence': '2', 'chunk': '12', 'confidence': '0.9999'}),
#  Annotation(chunk, 347, 358, acidic fluid, {'entity': 'Symptom', 'sentence': '2', 'chunk': '13', 'confidence': '0.2116'}),
#  Annotation(chunk, 361, 368, pectoral, {'entity': 'Internal_organ_or_component', 'sentence': '2', 'chunk': '14', 'confidence': '0.6198'}),
#  Annotation(chunk, 374, 397, intramammary lymph nodes, {'entity': 'Internal_organ_or_component', 'sentence': '2', 'chunk': '15', 'confidence': '0.49179998'}),
#  Annotation(chunk, 413, 414, L4, {'entity': 'Internal_organ_or_component', 'sentence': '2', 'chunk': '16', 'confidence': '0.8673'}),
#  Annotation(chunk, 421, 423, SUV, {'entity': 'Test', 'sentence': '2', 'chunk': '17', 'confidence': '0.9899'}),
#  Annotation(chunk, 428, 428, 4, {'entity': 'Test_Result', 'sentence': '2', 'chunk': '18', 'confidence': '0.779'}),
#  Annotation(chunk, 456, 472, stage III disease, {'entity': 'Heart_Disease', 'sentence': '3', 'chunk': '19', 'confidence': '0.3536333'}),
#  Annotation(chunk, 475, 477, Her, {'entity': 'Gender', 'sentence': '4', 'chunk': '20', 'confidence': '0.9999'}),
#  Annotation(chunk, 486, 499, echocardiogram, {'entity': 'Test', 'sentence': '4', 'chunk': '21', 'confidence': '0.983'}),
#  Annotation(chunk, 511, 527, ejection fraction, {'entity': 'Test', 'sentence': '4', 'chunk': '22', 'confidence': '0.78894997'}),
#  Annotation(chunk, 532, 534, 45%, {'entity': 'Test_Result', 'sentence': '4', 'chunk': '23', 'confidence': '0.9082'}),
#  Annotation(chunk, 539, 541, 49%, {'entity': 'Test_Result', 'sentence': '4', 'chunk': '24', 'confidence': '0.7783'}),
#  Annotation(chunk, 545, 547, She, {'entity': 'Gender', 'sentence': '5', 'chunk': '25', 'confidence': '0.9999'}),
#  Annotation(chunk, 568, 583, Oncology service, {'entity': 'Clinical_Dept', 'sentence': '5', 'chunk': '26', 'confidence': '0.8259'}),
#  Annotation(chunk, 600, 611, chemotherapy, {'entity': 'Treatment', 'sentence': '5', 'chunk': '27', 'confidence': '0.9995'}),
#  Annotation(chunk, 616, 632, September 1, 2007, {'entity': 'Date', 'sentence': '5', 'chunk': '28', 'confidence': '0.57875'}),
#  Annotation(chunk, 639, 647, cisplatin, {'entity': 'Drug_Ingredient', 'sentence': '5', 'chunk': '29', 'confidence': '0.9282'}),
#  Annotation(chunk, 649, 664, 75 mg/centimeter, {'entity': 'Strength', 'sentence': '5', 'chunk': '30', 'confidence': '0.5732'}),
#  Annotation(chunk, 683, 688, 109 mg, {'entity': 'Strength', 'sentence': '5', 'chunk': '31', 'confidence': '0.7955'}),
#  Annotation(chunk, 690, 691, IV, {'entity': 'Route', 'sentence': '5', 'chunk': '32', 'confidence': '0.9924'}),
#  Annotation(chunk, 703, 714, over 2 hours, {'entity': 'Duration', 'sentence': '5', 'chunk': '33', 'confidence': '0.2995'}),
#  Annotation(chunk, 719, 735, September 1, 2007, {'entity': 'Date', 'sentence': '5', 'chunk': '34', 'confidence': '0.5768'})]

# %%
print("Clinical Text:\n", text2)
# Out:
# Clinical Text:
#
# At this time, chest tube placement for drainage of the fluid occurred and thoracoscopy with fluid biopsies, which were performed, which revealed epithelioid malignant mesothelioma.
# The patient was then stained with a PET CT, which showed extensive uptake in the chest, bilateral pleural pericardial effusions, and lymphadenopathy.
# She also had acidic fluid, pectoral and intramammary lymph nodes and uptake in L4 with SUV of 4. This was consistent with stage III disease. Her repeat echocardiogram showed an ejection fraction of 45% to 49%.
# She was transferred to Oncology service and started on chemotherapy on September 1, 2007 with cisplatin 75 mg/centimeter squared equaling 109 mg IV piggyback over 2 hours on September 1, 2007

# %%
get_results(clinical_full_result)
# Out:
#
#  ******************** ner_ade_clinical Model Results ********************
#   sentence  begin  end                 chunks entity  confidence
# 0        0     15   34   chest tube placement   DRUG      0.9326
# 1        0     40   60  drainage of the fluid   DRUG  0.66934997
# 2        5    600  611           chemotherapy   DRUG      0.9953
# 3        5    639  647              cisplatin   DRUG      0.9877
# 4        5    690  701           IV piggyback   DRUG      0.6635
#
#  ******************** ner_posology_greedy Model Results ********************
#   sentence  begin  end                      chunks    entity  confidence
# 0        5    600  611                chemotherapy      DRUG      0.9972
# 1        5    639  664  cisplatin 75 mg/centimeter      DRUG   0.6113667
# 2        5    683  701         109 mg IV piggyback      DRUG  0.55439997
# 3        5    703  714                over 2 hours  DURATION   0.5100667
#
#  ******************** ner_risk_factors Model Results ********************
#   sentence  begin  end     chunks entity confidence
# 0        5    616  624  September    PHI     0.9968
# 1        5    629  632       2007    PHI     0.9999
# 2        5    719  727  September    PHI     0.9816
# 3        5    732  735       2007    PHI     0.9999
#
#  ******************** jsl_ner_wip_clinical Model Results ********************
#    sentence  begin  ...                        entity  confidence
# 0         0     15  ...                     Procedure  0.46089998
# 1         0     40  ...                     Procedure  0.40230003
# 2         0     75  ...                     Procedure      0.9927
# 3         0     93  ...                     Procedure     0.80535
# 4         0    146  ...                   Oncological       0.934
# 5         1    219  ...                          Test       0.946
# 6         1    240  ...                      Modifier      0.8028
# 7         1    250  ...               ImagingFindings      0.5804
# 8         1    264  ...  External_body_part_or_region      0.7954
# 9         1    271  ...                     Direction      0.5107
# 10        1    281  ...     Disease_Syndrome_Disorder  0.37933335
# 11        1    316  ...                       Symptom      0.9799
# 12        2    334  ...                        Gender      0.9999
# 13        2    347  ...                       Symptom      0.2116
# 14        2    361  ...   Internal_organ_or_component      0.6198
# 15        2    374  ...   Internal_organ_or_component  0.49179998
# 16        2    413  ...   Internal_organ_or_component      0.8673
# 17        2    421  ...                          Test      0.9899
# 18        2    428  ...                   Test_Result       0.779
# 19        3    456  ...                 Heart_Disease   0.3536333
# 20        4    475  ...                        Gender      0.9999
# 21        4    486  ...                          Test       0.983
# 22        4    511  ...                          Test  0.78894997
# 23        4    532  ...                   Test_Result      0.9082
# 24        4    539  ...                   Test_Result      0.7783
# 25        5    545  ...                        Gender      0.9999
# 26        5    568  ...                 Clinical_Dept      0.8259
# 27        5    600  ...                     Treatment      0.9995
# 28        5    616  ...                          Date     0.57875
# 29        5    639  ...               Drug_Ingredient      0.9282
# 30        5    649  ...                      Strength      0.5732
# 31        5    683  ...                      Strength      0.7955
# 32        5    690  ...                         Route      0.9924
# 33        5    703  ...                      Duration      0.2995
# 34        5    719  ...                          Date      0.5768
#
# [35 rows x 6 columns]
#
#  ******************** ner_human_phenotype_gene_clinical Model Results ********************
#   sentence  begin  end                         chunks entity  confidence
# 0        0     15   34           chest tube placement     HP   0.9459999
# 1        0    158  179         malignant mesothelioma     HP  0.83739996
# 2        1    271  279                      bilateral     HP      0.9917
# 3        1    281  309  pleural pericardial effusions     HP   0.7528667
# 4        5    687  688                             mg   GENE      0.6901
#
#  ******************** jsl_ner_wip_greedy_clinical Model Results ********************
#    sentence  begin  ...                       entity  confidence
# 0         0     15  ...                    Procedure  0.38986668
# 1         0     75  ...                    Procedure      0.9627
# 2         0     93  ...                    Procedure      0.6287
# 3         0    146  ...                  Oncological  0.77963334
# 4         1    219  ...                         Test  0.61195004
# 5         1    240  ...                      Symptom     0.42046
# 6         1    271  ...                    Direction      0.4811
# 7         1    281  ...    Disease_Syndrome_Disorder  0.35029998
# 8         1    316  ...                      Symptom      0.9886
# 9         2    334  ...                       Gender      0.9986
# 10        2    347  ...                      Symptom  0.24340001
# 11        2    361  ...  Internal_organ_or_component      0.7872
# 12        2    374  ...  Internal_organ_or_component      0.3719
# 13        2    413  ...  Internal_organ_or_component      0.6547
# 14        2    421  ...                         Test        0.77
# 15        2    428  ...                  Test_Result      0.4117
# 16        3    456  ...    Disease_Syndrome_Disorder  0.18936668
# 17        4    475  ...                       Gender      0.9993
# 18        4    486  ...                         Test      0.9492
# 19        4    511  ...                         Test      0.7333
# 20        4    532  ...                  Test_Result      0.5097
# 21        5    545  ...                       Gender      0.9996
# 22        5    568  ...                Clinical_Dept      0.7143
# 23        5    600  ...                         Drug   0.4660778
# 24        5    683  ...                     Strength  0.85074997
# 25        5    690  ...                        Route      0.9845
# 26        5    703  ...                     Duration  0.45116666
# 27        5    719  ...                         Date    0.546875
#
# [28 rows x 6 columns]
#  ******************** ner_cellular Model Results ********************
# No Result For This Model
#
#  ******************** ner_cancer_genetics Model Results ********************
# No Result For This Model
#
#
#  ******************** jsl_ner_wip_modifier_clinical Model Results ********************
#    sentence  begin  ...                       entity  confidence
# 0         0     15  ...                    Procedure  0.38986668
# 1         0     75  ...                    Procedure      0.9627
# 2         0     93  ...                    Procedure      0.6287
# 3         0    146  ...                  Oncological  0.77963334
# 4         1    219  ...                         Test  0.61195004
# 5         1    240  ...                      Symptom     0.42046
# 6         1    271  ...                    Direction      0.4811
# 7         1    281  ...    Disease_Syndrome_Disorder  0.35029998
# 8         1    316  ...                      Symptom      0.9886
# 9         2    334  ...                       Gender      0.9986
# 10        2    347  ...                      Symptom  0.24340001
# 11        2    361  ...  Internal_organ_or_component      0.7872
# 12        2    374  ...  Internal_organ_or_component      0.3719
# 13        2    413  ...  Internal_organ_or_component      0.6547
# 14        2    421  ...                         Test        0.77
# 15        2    428  ...                  Test_Result      0.4117
# 16        3    456  ...    Disease_Syndrome_Disorder  0.18936668
# 17        4    475  ...                       Gender      0.9993
# 18        4    486  ...                         Test      0.9492
# 19        4    511  ...                         Test      0.7333
# 20        4    532  ...                  Test_Result      0.5097
# 21        5    545  ...                       Gender      0.9996
# 22        5    568  ...                Clinical_Dept      0.7143
# 23        5    600  ...                         Drug   0.4660778
# 24        5    683  ...                     Strength  0.85074997
# 25        5    690  ...                        Route      0.9845
# 26        5    703  ...                     Duration  0.45116666
# 27        5    719  ...                         Date    0.546875
#
# [28 rows x 6 columns]
#
#  ******************** ner_drugs_greedy Model Results ********************
#   sentence  begin  end                              chunks entity confidence
# 0        5    600  611                        chemotherapy   DRUG     0.9915
# 1        5    639  672  cisplatin 75 mg/centimeter squared   DRUG   0.736475
#
#  ******************** ner_deid_sd_large Model Results ********************
#   sentence  begin  end             chunks entity confidence
# 0        5    616  632  September 1, 2007   DATE   0.992875
# 1        5    719  735  September 1, 2007   DATE     0.9836
#
#  ******************** ner_diseases Model Results ********************
#   sentence  begin  ...   entity  confidence
# 0        0     52  ...  Disease     0.76675
# 1        0    146  ...  Disease      0.9227
# 2        1    240  ...  Disease  0.80366004
# 3        1    271  ...  Disease  0.96672505
# 4        1    316  ...  Disease      0.9999
# 5        2    347  ...  Disease  0.94850004
# 6        3    456  ...  Disease   0.9553333
#
# [7 rows x 6 columns]
#  ******************** nerdl_tumour_demo Model Results ********************
# No Result For This Model
#
#
#  ******************** ner_deid_subentity_augmented Model Results ********************
#   sentence  begin  end             chunks entity  confidence
# 0        5    616  632  September 1, 2007   DATE  0.99487495
# 1        5    719  735  September 1, 2007   DATE      0.9971
#
#  ******************** ner_jsl_enriched Model Results ********************
#    sentence  begin  ...          entity  confidence
# 0         0     75  ...  Procedure_Name      0.6788
# 1         0     93  ...  Procedure_Name      0.4374
# 2         0    146  ...        Modifier      0.8205
# 3         0    158  ...        Modifier      0.4504
# 4         0    168  ...       Diagnosis      0.4025
# 5         1    219  ...            Name     0.73455
# 6         1    281  ...       Diagnosis   0.3698667
# 7         1    316  ...    Symptom_Name      0.4932
# 8         2    334  ...          Gender      0.9127
# 9         3    456  ...       Diagnosis      0.4519
# 10        4    475  ...          Gender      0.8515
# 11        4    486  ...            Name      0.9569
# 12        5    545  ...          Gender      0.9212
# 13        5    600  ...       Drug_Name      0.4972
# 14        5    639  ...       Drug_Name      0.9529
# 15        5    649  ...          Dosage  0.43346667
# 16        5    690  ...           Route     0.57515
# 17        5    703  ...       Frequency  0.56259996
#
# [18 rows x 6 columns]
#  ******************** ner_genetic_variants Model Results ********************
# No Result For This Model
#
#
#  ******************** ner_bionlp Model Results ********************
#    sentence  begin  ...                  entity  confidence
# 0         0     15  ...                  Tissue      0.7381
# 1         0    146  ...                  Cancer  0.99289995
# 2         1    187  ...                Organism         1.0
# 3         1    264  ...    Organism_subdivision      0.7252
# 4         1    281  ...  Multi-tissue_structure     0.95265
# 5         2    334  ...                Organism      0.9652
# 6         2    361  ...  Multi-tissue_structure      0.7478
# 7         2    374  ...  Multi-tissue_structure  0.99906665
# 8         2    413  ...    Organism_subdivision      0.8929
# 9         5    545  ...                Organism      0.9757
# 10        5    639  ...         Simple_chemical         1.0
#
# [11 rows x 6 columns]
#
#  ******************** ner_measurements_clinical Model Results ********************
#   sentence  begin  end      chunks        entity  confidence
# 0        4    532  541  45% to 49%  Measurements  0.93483335
# 1        5    683  685         109  Measurements      0.9978
# 2        5    687  688          mg         Units      0.9897
#
#  ******************** ner_diseases_large Model Results ********************
#   sentence  begin  ...   entity  confidence
# 0        0    146  ...  Disease   0.6461667
# 1        1    264  ...  Disease  0.75486666
# 2        1    316  ...  Disease      0.9945
#
# [3 rows x 6 columns]
#
#  ******************** ner_radiology Model Results ********************
#    sentence  begin  ...                     entity  confidence
# 0         0     15  ...                  Procedure  0.51626664
# 1         0     40  ...                  Procedure    0.596475
# 2         0     75  ...                  Procedure      0.9119
# 3         0     93  ...                  Procedure      0.8919
# 4         0    146  ...  Disease_Syndrome_Disorder   0.6127333
# 5         1    219  ...                ImagingTest     0.84875
# 6         1    240  ...            ImagingFindings  0.74584997
# 7         1    264  ...                   BodyPart      0.7238
# 8         1    271  ...                   BodyPart  0.57813334
# 9         1    301  ...            ImagingFindings      0.9505
# 10        1    316  ...            ImagingFindings      0.9589
# 11        2    347  ...                    Symptom  0.46240002
# 12        2    361  ...                   BodyPart      0.8985
# 13        2    374  ...                   BodyPart  0.46686664
# 14        2    403  ...              OtherFindings      0.3704
# 15        2    413  ...                   BodyPart      0.7656
# 16        2    421  ...                       Test      0.9806
# 17        3    456  ...  Disease_Syndrome_Disorder  0.71883327
# 18        4    486  ...                ImagingTest      0.8499
# 19        4    511  ...              OtherFindings  0.65744996
# 20        4    532  ...               Measurements      0.7109
# 21        4    539  ...               Measurements      0.5052
# 22        5    649  ...               Measurements      0.9718
# 23        5    652  ...                      Units      0.9255
# 24        5    683  ...               Measurements      0.7244
# 25        5    687  ...                      Units      0.9886
#
# [26 rows x 6 columns]
#
#  ******************** ner_deid_augmented Model Results ********************
#   sentence  begin  end             chunks entity  confidence
# 0        5    616  632  September 1, 2007   DATE     0.73095
# 1        5    719  735  September 1, 2007   DATE  0.78297496
#
#  ******************** ner_anatomy Model Results ********************
#   sentence  begin  ...                  entity  confidence
# 0        0     56  ...      Organism_substance      0.9908
# 1        0     93  ...      Organism_substance  0.75049996
# 2        0    168  ...  Pathological_formation      0.9592
# 3        1    281  ...  Multi-tissue_structure   0.7043667
# 4        2    354  ...      Organism_substance      0.8905
# 5        2    361  ...                   Organ      0.9682
# 6        2    387  ...  Multi-tissue_structure     0.65225
#
# [7 rows x 6 columns]
#
#  ******************** ner_chemprot_clinical Model Results ********************
#   sentence  begin  end     chunks    entity confidence
# 0        1    223  224         CT  CHEMICAL     0.6036
# 1        5    639  647  cisplatin  CHEMICAL     0.9951
#
#  ******************** ner_posology_experimental Model Results ********************
#   sentence  begin  end                             chunks    entity confidence
# 0        5    600  611                       chemotherapy      Drug     0.9987
# 1        5    639  647                          cisplatin      Drug     0.9995
# 2        5    649  681  75 mg/centimeter squared equaling  Strength   0.708475
# 3        5    683  688                             109 mg  Strength     0.7835
# 4        5    690  691                                 IV     Route     0.9985
#
#  ******************** ner_drugs Model Results ********************
#   sentence  begin  end     chunks    entity confidence
# 0        5    639  647  cisplatin  DrugChem     0.9409
#
#  ******************** ner_deid_sd Model Results ********************
#   sentence  begin  end             chunks entity  confidence
# 0        5    616  632  September 1, 2007   DATE    0.846875
# 1        5    719  735  September 1, 2007   DATE  0.80730003
#
#  ******************** ner_posology_large Model Results ********************
#   sentence  begin  end                    chunks    entity  confidence
# 0        5    600  611              chemotherapy      DRUG      0.9748
# 1        5    639  647                 cisplatin      DRUG      0.9923
# 2        5    649  672  75 mg/centimeter squared  STRENGTH   0.6071333
# 3        5    683  688                    109 mg  STRENGTH      0.5665
# 4        5    690  691                        IV     ROUTE      0.9997
# 5        5    693  701                 piggyback      DRUG      0.8181
# 6        5    703  714              over 2 hours  DURATION  0.64023334
#
#  ******************** ner_deid_large Model Results ********************
#   sentence  begin  end             chunks entity  confidence
# 0        5    616  632  September 1, 2007   DATE  0.99442506
# 1        5    719  735  September 1, 2007   DATE    0.981325
#
#  ******************** ner_posology Model Results ********************
#   sentence  begin  end            chunks    entity  confidence
# 0        5    600  611      chemotherapy      DRUG      0.9983
# 1        5    639  647         cisplatin      DRUG      0.9226
# 2        5    649  664  75 mg/centimeter  STRENGTH  0.76170003
# 3        5    683  688            109 mg  STRENGTH     0.58815
# 4        5    690  691                IV     ROUTE      0.9992
# 5        5    693  701         piggyback      DRUG      0.5382
# 6        5    703  714      over 2 hours  DURATION      0.6929
#
#  ******************** ner_deidentify_dl Model Results ********************
#   sentence  begin  end             chunks entity  confidence
# 0        5    616  632  September 1, 2007   DATE    0.975175
# 1        5    719  735  September 1, 2007   DATE  0.90697503
#
#  ******************** ner_deid_enriched Model Results ********************
#   sentence  begin  end             chunks entity  confidence
# 0        5    616  632  September 1, 2007   DATE  0.89425004
# 1        5    719  735  September 1, 2007   DATE  0.98062503
#  ******************** ner_bacterial_species Model Results ********************
# No Result For This Model
#
#
#  ******************** ner_drugs_large Model Results ********************
#   sentence  begin  ...  entity  confidence
# 0        5    600  ...    DRUG      0.9989
# 1        5    639  ...    DRUG  0.78898746
#
# [2 rows x 6 columns]
#
#  ******************** ner_clinical_large Model Results ********************
#    sentence  begin  ...     entity  confidence
# 0         0     15  ...  TREATMENT   0.9526333
# 1         0     40  ...    PROBLEM      0.7372
# 2         0     75  ...  TREATMENT      0.6497
# 3         0     93  ...       TEST      0.7528
# 4         0    146  ...    PROBLEM  0.97339994
# 5         1    217  ...       TEST  0.94320005
# 6         1    240  ...    PROBLEM  0.90375996
# 7         1    271  ...    PROBLEM     0.96755
# 8         1    316  ...    PROBLEM      0.9956
# 9         2    347  ...    PROBLEM  0.96854997
# 10        2    361  ...    PROBLEM       0.748
# 11        2    403  ...    PROBLEM   0.8012333
# 12        2    421  ...       TEST      0.9959
# 13        3    456  ...    PROBLEM   0.8552334
# 14        4    475  ...       TEST   0.8606667
# 15        4    508  ...       TEST      0.7115
# 16        5    600  ...  TREATMENT      0.9994
# 17        5    639  ...  TREATMENT      0.9996
# 18        5    690  ...  TREATMENT     0.72965
#
# [19 rows x 6 columns]
#
#  ******************** jsl_rd_ner_wip_greedy_clinical Model Results ********************
#    sentence  begin  ...                     entity  confidence
# 0         0     15  ...                  Procedure   0.3780667
# 1         0     40  ...                    Symptom    0.220275
# 2         0     75  ...                  Procedure      0.9868
# 3         0     93  ...                  Procedure      0.6185
# 4         0    146  ...                Oncological       0.863
# 5         1    219  ...                ImagingTest     0.87745
# 6         1    240  ...            ImagingFindings      0.5199
# 7         1    264  ...                   BodyPart      0.6398
# 8         1    271  ...                  Direction      0.9666
# 9         1    281  ...  Disease_Syndrome_Disorder  0.30393335
# 10        1    316  ...                    Symptom      0.9352
# 11        2    334  ...                     Gender      0.9996
# 12        2    347  ...                    Symptom  0.13010001
# 13        2    361  ...                   BodyPart       0.852
# 14        2    374  ...                   BodyPart  0.42610002
# 15        2    413  ...                   BodyPart      0.7413
# 16        2    421  ...                       Test      0.9597
# 17        2    428  ...                Test_Result      0.7571
# 18        3    456  ...  Disease_Syndrome_Disorder  0.25123334
# 19        4    475  ...                     Gender      0.9993
# 20        4    486  ...                ImagingTest      0.8135
# 21        4    511  ...                       Test  0.57554996
# 22        4    532  ...                Test_Result  0.55973333
# 23        5    545  ...                     Gender      0.9994
# 24        5    568  ...              Clinical_Dept     0.83315
# 25        5    600  ...                  Treatment      0.9994
# 26        5    616  ...                       Date    0.536425
# 27        5    639  ...                       Drug      0.3294
# 28        5    683  ...                   Strength      0.5406
# 29        5    690  ...                      Route      0.5315
# 30        5    703  ...                  Frequency  0.28546667
# 31        5    719  ...                       Date     0.47405
#
# [32 rows x 6 columns]
#
#  ******************** ner_medmentions_coarse Model Results ********************
#    sentence  begin  ...                                entity  confidence
# 0         0     15  ...   Therapeutic_or_Preventive_Procedure  0.36516666
# 1         0     40  ...   Therapeutic_or_Preventive_Procedure      0.4727
# 2         0     56  ...                        Body_Substance      0.7212
# 3         0     75  ...                  Diagnostic_Procedure      0.9583
# 4         0     93  ...                  Diagnostic_Procedure      0.8891
# 5         0    146  ...                    Neoplastic_Process   0.6380667
# 6         1    219  ...                  Diagnostic_Procedure      0.7052
# 7         1    264  ...               Body_Location_or_Region      0.3164
# 8         1    271  ...                   Disease_or_Syndrome  0.60230005
# 9         1    316  ...                   Disease_or_Syndrome      0.9749
# 10        2    347  ...                              Chemical      0.4011
# 11        2    361  ...  Body_Part,_Organ,_or_Organ_Component      0.3486
# 12        2    374  ...  Body_Part,_Organ,_or_Organ_Component  0.55473334
# 13        2    403  ...                     Biologic_Function      0.9737
# 14        2    413  ...  Body_Part,_Organ,_or_Organ_Component      0.7707
# 15        2    421  ...                  Quantitative_Concept      0.9767
# 16        3    456  ...                   Disease_or_Syndrome  0.34710002
# 17        4    479  ...                  Diagnostic_Procedure      0.5894
# 18        4    511  ...                    Clinical_Attribute     0.48065
# 19        5    568  ...                          Organization      0.6135
# 20        5    600  ...   Therapeutic_or_Preventive_Procedure      0.9682
# 21        5    639  ...               Pharmacologic_Substance      0.6573
#
# [22 rows x 6 columns]
#
#  ******************** ner_radiology_wip_clinical Model Results ********************
#    sentence  begin  ...                     entity  confidence
# 0         0     15  ...                  Procedure  0.49003336
# 1         0     40  ...                  Procedure      0.6985
# 2         0     75  ...                  Procedure       0.724
# 3         0     93  ...                  Procedure     0.86725
# 4         0    158  ...  Disease_Syndrome_Disorder     0.73555
# 5         1    219  ...                ImagingTest     0.76355
# 6         1    240  ...            ImagingFindings     0.67755
# 7         1    264  ...                   BodyPart      0.9731
# 8         1    271  ...                  Direction      0.9242
# 9         1    281  ...                   BodyPart     0.55285
# 10        1    301  ...            ImagingFindings      0.8569
# 11        1    316  ...            ImagingFindings      0.9438
# 12        2    347  ...                    Symptom     0.57955
# 13        2    361  ...                   BodyPart      0.9582
# 14        2    374  ...                   BodyPart   0.3478333
# 15        2    403  ...            ImagingFindings      0.3102
# 16        2    413  ...                   BodyPart      0.8154
# 17        2    421  ...                       Test      0.6648
# 18        2    428  ...               Measurements      0.5026
# 19        3    456  ...  Disease_Syndrome_Disorder   0.6250333
# 20        4    486  ...                ImagingTest      0.7168
# 21        4    511  ...              OtherFindings   0.6937833
# 22        5    649  ...               Measurements      0.9931
# 23        5    652  ...                      Units      0.3847
# 24        5    683  ...               Measurements      0.5697
# 25        5    687  ...                      Units       0.991
#
# [26 rows x 6 columns]
#
#  ******************** ner_clinical Model Results ********************
#    sentence  begin  ...     entity  confidence
# 0         0     15  ...  TREATMENT   0.9526333
# 1         0     40  ...    PROBLEM      0.7372
# 2         0     75  ...  TREATMENT      0.6497
# 3         0     93  ...       TEST      0.7528
# 4         0    146  ...    PROBLEM  0.97339994
# 5         1    217  ...       TEST  0.94320005
# 6         1    240  ...    PROBLEM  0.90375996
# 7         1    271  ...    PROBLEM     0.96755
# 8         1    316  ...    PROBLEM      0.9956
# 9         2    347  ...    PROBLEM  0.96854997
# 10        2    361  ...    PROBLEM       0.748
# 11        2    403  ...    PROBLEM   0.8012333
# 12        2    421  ...       TEST      0.9959
# 13        3    456  ...    PROBLEM   0.8552334
# 14        4    475  ...       TEST   0.8606667
# 15        4    508  ...       TEST      0.7115
# 16        5    600  ...  TREATMENT      0.9994
# 17        5    639  ...  TREATMENT      0.9996
# 18        5    690  ...  TREATMENT     0.72965
#
# [19 rows x 6 columns]
#
#  ******************** ner_chemicals Model Results ********************
#   sentence  begin  end     chunks entity confidence
# 0        5    639  647  cisplatin   CHEM     0.9993
#
#  ******************** ner_deid_synthetic Model Results ********************
#   sentence  begin  end             chunks entity  confidence
# 0        5    616  632  September 1, 2007   DATE  0.84255004
# 1        5    719  735  September 1, 2007   DATE  0.90424997
#
#  ******************** ner_events_clinical Model Results ********************
#    sentence  begin  ...         entity  confidence
# 0         0      4  ...           DATE       0.749
# 1         0     15  ...      TREATMENT   0.9272334
# 2         0     40  ...      TREATMENT      0.8659
# 3         0     52  ...        PROBLEM      0.4505
# 4         0     75  ...           TEST       0.999
# 5         0     93  ...           TEST     0.81295
# 6         0    137  ...     EVIDENTIAL      0.9098
# 7         0    146  ...        PROBLEM  0.88753337
# 8         1    204  ...           TEST      0.4576
# 9         1    217  ...           TEST      0.8901
# 10        1    233  ...     EVIDENTIAL      0.9928
# 11        1    240  ...        PROBLEM   0.8134801
# 12        1    271  ...        PROBLEM  0.77522504
# 13        1    316  ...        PROBLEM      0.9938
# 14        2    347  ...        PROBLEM    0.670775
# 15        2    403  ...        PROBLEM   0.7688667
# 16        2    421  ...           TEST      0.9687
# 17        3    456  ...        PROBLEM  0.77113336
# 18        4    475  ...           TEST       0.762
# 19        4    501  ...     EVIDENTIAL      0.8502
# 20        4    508  ...           TEST      0.6353
# 21        5    553  ...     OCCURRENCE      0.9978
# 22        5    568  ...  CLINICAL_DEPT      0.8858
# 23        5    600  ...      TREATMENT      0.9988
# 24        5    616  ...           DATE  0.82707494
# 25        5    639  ...      TREATMENT      0.9992
# 26        5    690  ...      TREATMENT     0.81755
# 27        5    708  ...       DURATION      0.7003
# 28        5    719  ...           DATE  0.59790003
#
# [29 rows x 6 columns]
#
#  ******************** ner_posology_small Model Results ********************
#   sentence  begin  end        chunks    entity confidence
# 0        5    600  611  chemotherapy      DRUG     0.9956
# 1        5    639  647     cisplatin      DRUG     0.9981
# 2        5    649  650            75  STRENGTH        1.0
# 3        5    683  688        109 mg  STRENGTH    0.86925
# 4        5    690  691            IV     ROUTE     0.9975
# 5        5    693  701     piggyback      FORM     0.9257
# 6        5    703  714  over 2 hours  DURATION  0.6864333
#
#  ******************** ner_anatomy_coarse Model Results ********************
#   sentence  begin  ...   entity confidence
# 0        0     15  ...  Anatomy     0.9935
# 1        0     56  ...  Anatomy     0.6578
# 2        0     93  ...  Anatomy    0.90225
# 3        0    146  ...  Anatomy     0.9373
# 4        1    264  ...  Anatomy     0.9934
# 5        1    271  ...  Anatomy   0.879475
# 6        2    354  ...  Anatomy     0.8928
# 7        2    361  ...  Anatomy     0.9971
# 8        2    374  ...  Anatomy  0.9921667
#
# [9 rows x 6 columns]
#
#  ******************** ner_human_phenotype_go_clinical Model Results ********************
#   sentence  begin  end                chunks entity  confidence
# 0        0     15   34  chest tube placement     GO  0.78533334
# 1        0    168  179          mesothelioma     HP      0.9402
# 2        1    271  279             bilateral     HP      0.9886
# 3        1    316  330       lymphadenopathy     HP      0.9511
#
#  ******************** ner_jsl_slim Model Results ********************
#    sentence  begin  ...                     entity  confidence
# 0         0     15  ...                  Procedure   0.6034333
# 1         0     40  ...                  Procedure      0.3985
# 2         0     75  ...                  Procedure      0.9869
# 3         0     93  ...                  Procedure     0.74905
# 4         0    146  ...                Oncological  0.73946667
# 5         1    219  ...                       Test      0.5567
# 6         1    240  ...                    Symptom  0.44191998
# 7         1    281  ...  Disease_Syndrome_Disorder  0.46723333
# 8         1    316  ...                    Symptom      0.9701
# 9         2    334  ...               Demographics      0.9986
# 10        2    347  ...                    Symptom     0.30525
# 11        2    361  ...                  Body_Part       0.979
# 12        2    374  ...                  Body_Part   0.5018334
# 13        2    413  ...                  Body_Part      0.8264
# 14        3    456  ...  Disease_Syndrome_Disorder  0.31986666
# 15        4    475  ...               Demographics      0.9996
# 16        4    486  ...                       Test      0.9299
# 17        4    511  ...                       Test     0.78625
# 18        4    532  ...                Test_Result  0.72013336
# 19        5    545  ...               Demographics      0.9993
# 20        5    568  ...              Clinical_Dept       0.737
# 21        5    600  ...                       Drug   0.6103889
# 22        5    719  ...                  Date_Time     0.65085
#
# [23 rows x 6 columns]
#
#  ******************** ner_jsl Model Results ********************
#    sentence  begin  ...                        entity  confidence
# 0         0     15  ...                     Procedure  0.46089998
# 1         0     40  ...                     Procedure  0.40230003
# 2         0     75  ...                     Procedure      0.9927
# 3         0     93  ...                     Procedure     0.80535
# 4         0    146  ...                   Oncological       0.934
# 5         1    219  ...                          Test       0.946
# 6         1    240  ...                      Modifier      0.8028
# 7         1    250  ...               ImagingFindings      0.5804
# 8         1    264  ...  External_body_part_or_region      0.7954
# 9         1    271  ...                     Direction      0.5107
# 10        1    281  ...     Disease_Syndrome_Disorder  0.37933335
# 11        1    316  ...                       Symptom      0.9799
# 12        2    334  ...                        Gender      0.9999
# 13        2    347  ...                       Symptom      0.2116
# 14        2    361  ...   Internal_organ_or_component      0.6198
# 15        2    374  ...   Internal_organ_or_component  0.49179998
# 16        2    413  ...   Internal_organ_or_component      0.8673
# 17        2    421  ...                          Test      0.9899
# 18        2    428  ...                   Test_Result       0.779
# 19        3    456  ...                 Heart_Disease   0.3536333
# 20        4    475  ...                        Gender      0.9999
# 21        4    486  ...                          Test       0.983
# 22        4    511  ...                          Test  0.78894997
# 23        4    532  ...                   Test_Result      0.9082
# 24        4    539  ...                   Test_Result      0.7783
# 25        5    545  ...                        Gender      0.9999
# 26        5    568  ...                 Clinical_Dept      0.8259
# 27        5    600  ...                     Treatment      0.9995
# 28        5    616  ...                          Date     0.57875
# 29        5    639  ...               Drug_Ingredient      0.9282
# 30        5    649  ...                      Strength      0.5732
# 31        5    683  ...                      Strength      0.7955
# 32        5    690  ...                         Route      0.9924
# 33        5    703  ...                      Duration      0.2995
# 34        5    719  ...                          Date      0.5768
#
# [35 rows x 6 columns]
#
#  ******************** ner_jsl_greedy Model Results ********************
#    sentence  begin  ...                       entity  confidence
# 0         0     15  ...                    Procedure  0.38986668
# 1         0     75  ...                    Procedure      0.9627
# 2         0     93  ...                    Procedure      0.6287
# 3         0    146  ...                  Oncological  0.77963334
# 4         1    219  ...                         Test  0.61195004
# 5         1    240  ...                      Symptom     0.42046
# 6         1    271  ...                    Direction      0.4811
# 7         1    281  ...    Disease_Syndrome_Disorder  0.35029998
# 8         1    316  ...                      Symptom      0.9886
# 9         2    334  ...                       Gender      0.9986
# 10        2    347  ...                      Symptom  0.24340001
# 11        2    361  ...  Internal_organ_or_component      0.7872
# 12        2    374  ...  Internal_organ_or_component      0.3719
# 13        2    413  ...  Internal_organ_or_component      0.6547
# 14        2    421  ...                         Test        0.77
# 15        2    428  ...                  Test_Result      0.4117
# 16        3    456  ...    Disease_Syndrome_Disorder  0.18936668
# 17        4    475  ...                       Gender      0.9993
# 18        4    486  ...                         Test      0.9492
# 19        4    511  ...                         Test      0.7333
# 20        4    532  ...                  Test_Result      0.5097
# 21        5    545  ...                       Gender      0.9996
# 22        5    568  ...                Clinical_Dept      0.7143
# 23        5    600  ...                         Drug   0.4660778
# 24        5    683  ...                     Strength  0.85074997
# 25        5    690  ...                        Route      0.9845
# 26        5    703  ...                     Duration  0.45116666
# 27        5    719  ...                         Date    0.546875
#
# [28 rows x 6 columns]
#
#  ******************** ner_events_admission_clinical Model Results ********************
#    sentence  begin  ...         entity  confidence
# 0         0     15  ...      TREATMENT   0.8781667
# 1         0     40  ...      TREATMENT      0.4451
# 2         0     75  ...           TEST      0.9948
# 3         0     93  ...           TEST  0.84274995
# 4         0    137  ...     EVIDENTIAL      0.5703
# 5         0    146  ...        PROBLEM  0.87450004
# 6         1    204  ...        PROBLEM      0.3036
# 7         1    217  ...           TEST  0.74953336
# 8         1    233  ...     EVIDENTIAL      0.9502
# 9         1    240  ...        PROBLEM     0.73456
# 10        1    271  ...        PROBLEM    0.845675
# 11        1    316  ...        PROBLEM      0.9673
# 12        2    347  ...        PROBLEM  0.60776246
# 13        2    403  ...        PROBLEM   0.5861667
# 14        2    421  ...           TEST      0.9866
# 15        3    456  ...        PROBLEM      0.8269
# 16        4    475  ...           TEST   0.6921666
# 17        4    501  ...     EVIDENTIAL      0.9871
# 18        4    508  ...     OCCURRENCE  0.40440002
# 19        5    553  ...     OCCURRENCE      0.9965
# 20        5    568  ...  CLINICAL_DEPT      0.7772
# 21        5    600  ...      TREATMENT       0.994
# 22        5    616  ...           DATE    0.925325
# 23        5    639  ...      TREATMENT      0.9982
# 24        5    703  ...      FREQUENCY  0.72436666
# 25        5    719  ...           DATE     0.74775
#
# [26 rows x 6 columns]

# %% [markdown]
# # BioBert NER Model Profiling Pretrained Pipeline
#
# This pipeline can be used to explore all the available pretrained NER models at once. When you run this pipeline over your text, you will end up with the predictions coming out of each pretrained clinical NER model trained with `biobert_pubmed_base_cased`.
#
# |BioBert NER Model List|
# |-|
# |ner_cellular_biobert|
# |ner_diseases_biobert|
# |ner_events_biobert|
# |ner_bionlp_biobert|
# |ner_jsl_greedy_biobert|
# |ner_jsl_biobert|
# |ner_anatomy_biobert|
# |ner_jsl_enriched_biobert|
# |ner_human_phenotype_go_biobert|
# |ner_deid_biobert|
# |ner_deid_enriched_biobert|
# |ner_clinical_biobert|
# |ner_anatomy_coarse_biobert|
# |ner_human_phenotype_gene_biobert|
# |ner_posology_large_biobert|
# |jsl_rd_ner_wip_greedy_biobert|
# |ner_posology_biobert|
# |jsl_ner_wip_greedy_biobert|
# |ner_chemprot_biobert|
# |ner_ade_biobert|
# |ner_risk_factors_biobert|
#
# You can check [Models Hub](https://nlp.johnsnowlabs.com/models) page for more information about all these models and more.

# %%
"|\n|".join(['ner_cellular_biobert_chunks', 'ner_diseases_biobert_chunks', 'ner_events_biobert_chunks', 'ner_bionlp_biobert_chunks', 'ner_jsl_greedy_biobert_chunks', 'ner_jsl_biobert_chunks', 'ner_anatomy_biobert_chunks', 'ner_jsl_enriched_biobert_chunks', 'ner_human_phenotype_go_biobert_chunks', 'ner_deid_biobert_chunks', 'ner_deid_enriched_biobert_chunks', 'token', 'ner_clinical_biobert_chunks', 'ner_anatomy_coarse_biobert_chunks', 'ner_human_phenotype_gene_biobert_chunks', 'ner_posology_large_biobert_chunks', 'jsl_rd_ner_wip_greedy_biobert_chunks', 'ner_posology_biobert_chunks', 'jsl_ner_wip_greedy_biobert_chunks', 'ner_chemprot_biobert_chunks', 'ner_ade_biobert_chunks', 'ner_risk_factors_biobert_chunks'])
# Out:
# 'ner_cellular_biobert_chunks|\n|ner_diseases_biobert_chunks|\n|ner_events_biobert_chunks|\n|ner_bionlp_biobert_chunks|\n|ner_jsl_greedy_biobert_chunks|\n|ner_jsl_biobert_chunks|\n|ner_anatomy_biobert_chunks|\n|ner_jsl_enriched_biobert_chunks|\n|ner_human_phenotype_go_biobert_chunks|\n|ner_deid_biobert_chunks|\n|ner_deid_enriched_biobert_chunks|\n|token|\n|ner_clinical_biobert_chunks|\n|ner_anatomy_coarse_biobert_chunks|\n|ner_human_phenotype_gene_biobert_chunks|\n|ner_posology_large_biobert_chunks|\n|jsl_rd_ner_wip_greedy_biobert_chunks|\n|ner_posology_biobert_chunks|\n|jsl_ner_wip_greedy_biobert_chunks|\n|ner_chemprot_biobert_chunks|\n|ner_ade_biobert_chunks|\n|ner_risk_factors_biobert_chunks'

# %%
from sparknlp.pretrained import PretrainedPipeline

biobert_profiling_pipeline = PretrainedPipeline("ner_profiling_biobert", "en", "clinical/models")
# Out:
# ner_profiling_biobert download started this may take some time.
# Approx size to download 714.6 MB
# [OK!]

# %%
bio_result = biobert_profiling_pipeline.annotate(text)
bio_result.keys()
# Out:
# dict_keys(['ner_cellular_biobert_chunks', 'ner_diseases_biobert_chunks', 'ner_events_biobert_chunks', 'ner_bionlp_biobert_chunks', 'ner_jsl_greedy_biobert_chunks', 'ner_jsl_biobert_chunks', 'ner_anatomy_biobert_chunks', 'ner_jsl_enriched_biobert_chunks', 'ner_human_phenotype_go_biobert_chunks', 'ner_deid_biobert_chunks', 'ner_deid_enriched_biobert_chunks', 'token', 'ner_clinical_biobert_chunks', 'ner_anatomy_coarse_biobert_chunks', 'ner_human_phenotype_gene_biobert_chunks', 'ner_posology_large_biobert_chunks', 'jsl_rd_ner_wip_greedy_biobert_chunks', 'ner_posology_biobert_chunks', 'jsl_ner_wip_greedy_biobert_chunks', 'ner_chemprot_biobert_chunks', 'ner_ade_biobert_chunks', 'ner_risk_factors_biobert_chunks', 'sentence'])

# %%
print("Clinical Text: \n", text, "\n \nResults:\n")

for i in bio_result.keys():
  print("{} : ".format(i), bio_result[i])
# Out:
# Clinical Text:
#
# At this time, chest tube placement for drainage of the fluid occurred and thoracoscopy with fluid biopsies, which were performed, which revealed epithelioid malignant mesothelioma.
# The patient was then stained with a PET CT, which showed extensive uptake in the chest, bilateral pleural pericardial effusions, and lymphadenopathy.
# She also had acidic fluid, pectoral and intramammary lymph nodes and uptake in L4 with SUV of 4. This was consistent with stage III disease. Her repeat echocardiogram showed an ejection fraction of 45% to 49%.
# She was transferred to Oncology service and started on chemotherapy on September 1, 2007 with cisplatin 75 mg/centimeter squared equaling 109 mg IV piggyback over 2 hours on September 1, 2007
#
#
# Results:
#
# ner_cellular_biobert_chunks :  []
# ner_diseases_biobert_chunks :  ['epithelioid malignant mesothelioma', 'pleural pericardial effusions', 'lymphadenopathy', 'stage III disease']
# ner_events_biobert_chunks :  ['chest tube placement', 'drainage', 'the fluid', 'thoracoscopy', 'fluid biopsies', 'revealed', 'epithelioid malignant mesothelioma', 'a PET CT', 'showed', 'extensive uptake in the chest', 'bilateral pleural pericardial effusions', 'lymphadenopathy', 'acidic fluid, pectoral and intramammary lymph nodes', 'uptake in L4', 'SUV', 'stage III disease', 'Her repeat echocardiogram', 'showed', 'an ejection fraction', 'transferred', 'Oncology service', 'chemotherapy', 'September 1, 2007', 'cisplatin', '2 hours', 'September 1, 2007']
# ner_bionlp_biobert_chunks :  ['chest tube', 'fluid', 'epithelioid malignant mesothelioma', 'patient', 'chest', 'pericardial effusions', 'acidic fluid', 'pectoral', 'intramammary lymph nodes', 'L4', 'cisplatin']
# ner_jsl_greedy_biobert_chunks :  ['chest tube placement', 'fluid', 'thoracoscopy', 'fluid biopsies', 'epithelioid malignant mesothelioma', 'PET CT', 'extensive uptake', 'chest', 'bilateral', 'pleural pericardial effusions', 'lymphadenopathy', 'She', 'acidic fluid', 'pectoral', 'intramammary lymph nodes', 'L4', 'SUV', 'stage III disease', 'Her', 'echocardiogram', 'ejection fraction', '45% to 49%', 'She', 'Oncology service', 'chemotherapy on September 1, 2007 with cisplatin 75 mg/centimeter', '109 mg IV piggyback', 'over 2 hours', 'September 1, 2007']
# ner_jsl_biobert_chunks :  ['chest tube placement', 'drainage of the fluid', 'thoracoscopy', 'fluid biopsies', 'epithelioid malignant mesothelioma', 'PET CT', 'extensive uptake', 'chest', 'bilateral', 'pleural pericardial effusions', 'lymphadenopathy', 'She', 'acidic fluid', 'pectoral', 'intramammary lymph nodes', 'uptake in L4', 'SUV', '4', 'stage III', 'disease', 'Her', 'echocardiogram', 'ejection fraction', '45% to 49%', 'She', 'Oncology service', 'chemotherapy', 'September 1, 2007', 'cisplatin', '75 mg/centimeter', '109 mg', 'IV piggyback', 'over 2 hours', 'September 1, 2007']
# ner_anatomy_biobert_chunks :  ['fluid', 'fluid', 'chest', 'pleural pericardial effusions', 'fluid', 'lymph nodes']
# ner_jsl_enriched_biobert_chunks :  ['thoracoscopy', 'fluid biopsies', 'epithelioid malignant mesothelioma', 'PET CT', 'lymphadenopathy', 'She', 'Her', 'echocardiogram', 'She', 'chemotherapy', 'cisplatin']
# ner_human_phenotype_go_biobert_chunks :  ['bilateral']
# ner_deid_biobert_chunks :  ['September 1, 2007', 'September 1, 2007']
# ner_deid_enriched_biobert_chunks :  ['September 1, 2007', 'September 1, 2007']
# token :  ['At', 'this', 'time', ',', 'chest', 'tube', 'placement', 'for', 'drainage', 'of', 'the', 'fluid', 'occurred', 'and', 'thoracoscopy', 'with', 'fluid', 'biopsies', ',', 'which', 'were', 'performed', ',', 'which', 'revealed', 'epithelioid', 'malignant', 'mesothelioma', '.', 'The', 'patient', 'was', 'then', 'stained', 'with', 'a', 'PET', 'CT', ',', 'which', 'showed', 'extensive', 'uptake', 'in', 'the', 'chest', ',', 'bilateral', 'pleural', 'pericardial', 'effusions', ',', 'and', 'lymphadenopathy', '.', 'She', 'also', 'had', 'acidic', 'fluid', ',', 'pectoral', 'and', 'intramammary', 'lymph', 'nodes', 'and', 'uptake', 'in', 'L4', 'with', 'SUV', 'of', '4', '.', 'This', 'was', 'consistent', 'with', 'stage', 'III', 'disease', '.', 'Her', 'repeat', 'echocardiogram', 'showed', 'an', 'ejection', 'fraction', 'of', '45%', 'to', '49%', '.', 'She', 'was', 'transferred', 'to', 'Oncology', 'service', 'and', 'started', 'on', 'chemotherapy', 'on', 'September', '1', ',', '2007', 'with', 'cisplatin', '75', 'mg/centimeter', 'squared', 'equaling', '109', 'mg', 'IV', 'piggyback', 'over', '2', 'hours', 'on', 'September', '1', ',', '2007']
# ner_clinical_biobert_chunks :  ['chest tube placement', 'drainage', 'the fluid', 'thoracoscopy', 'fluid biopsies', 'epithelioid malignant mesothelioma', 'a PET CT', 'extensive uptake in the chest', 'bilateral pleural pericardial effusions', 'lymphadenopathy', 'acidic fluid', 'pectoral and intramammary lymph nodes', 'uptake in L4', 'SUV', 'stage III disease', 'Her repeat echocardiogram', 'an ejection fraction', 'chemotherapy', 'cisplatin']
# ner_anatomy_coarse_biobert_chunks :  ['chest tube', 'fluid', 'fluid', 'epithelioid malignant mesothelioma', 'chest', 'bilateral pleural pericardial effusions', 'acidic fluid', 'pectoral', 'intramammary lymph nodes', 'L4']
# ner_human_phenotype_gene_biobert_chunks :  ['chest tube', 'bilateral', 'pleural pericardial effusions']
# ner_posology_large_biobert_chunks :  ['chemotherapy', 'cisplatin', '75 mg/centimeter', '109 mg', 'IV']
# jsl_rd_ner_wip_greedy_biobert_chunks :  ['chest', 'tube placement', 'drainage', 'fluid', 'thoracoscopy', 'fluid biopsies', 'epithelioid malignant mesothelioma', 'PET CT', 'extensive uptake', 'chest', 'bilateral', 'pleural pericardial', 'effusions', 'lymphadenopathy', 'acidic fluid', 'pectoral', 'intramammary lymph nodes', 'uptake', 'L4', 'SUV', 'stage III disease', 'echocardiogram', 'ejection fraction', '45%', '49%', '75', 'mg/centimeter', '109', 'mg']
# ner_posology_biobert_chunks :  ['chemotherapy', 'cisplatin', '75 mg/centimeter', '109 mg', 'IV', 'piggyback']
# jsl_ner_wip_greedy_biobert_chunks :  ['chest tube placement', 'fluid', 'thoracoscopy', 'fluid biopsies', 'epithelioid malignant mesothelioma', 'PET CT', 'extensive uptake', 'chest', 'bilateral', 'pleural pericardial effusions', 'lymphadenopathy', 'She', 'acidic fluid', 'pectoral', 'intramammary lymph nodes', 'L4', 'SUV', 'stage III disease', 'Her', 'echocardiogram', 'ejection fraction', '45% to 49%', 'She', 'Oncology service', 'chemotherapy on September 1, 2007 with cisplatin 75 mg/centimeter', '109 mg IV piggyback', 'over 2 hours', 'September 1, 2007']
# ner_chemprot_biobert_chunks :  ['cisplatin']
# ner_ade_biobert_chunks :  ['chest tube placement', 'drainage of the fluid', 'thoracoscopy', 'extensive uptake in the chest', 'bilateral pleural pericardial effusions', 'acidic fluid', 'stage', 'chemotherapy', 'cisplatin', 'piggyback']
# ner_risk_factors_biobert_chunks :  ['September', 'September', '2007']
# sentence :  ['At this time, chest tube placement for drainage of the fluid occurred and thoracoscopy with fluid biopsies, which were performed, which revealed epithelioid malignant mesothelioma.', 'The patient was then stained with a PET CT, which showed extensive uptake in the chest, bilateral pleural pericardial effusions, and lymphadenopathy.', 'She also had acidic fluid, pectoral and intramammary lymph nodes and uptake in L4 with SUV of 4.', 'This was consistent with stage III disease.', 'Her repeat echocardiogram showed an ejection fraction of 45% to 49%.', 'She was transferred to Oncology service and started on chemotherapy on September 1, 2007 with cisplatin 75 mg/centimeter squared equaling 109 mg IV piggyback over 2 hours on September 1, 2007']

# %%
bio_full_result = biobert_profiling_pipeline.fullAnnotate(text2)[0]

# %%
bio_full_result['ner_jsl_biobert_chunks']
# Out:
# [Annotation(chunk, 15, 34, chest tube placement, {'entity': 'Procedure', 'sentence': '0', 'chunk': '0', 'confidence': '0.5898667'}),
#  Annotation(chunk, 40, 60, drainage of the fluid, {'entity': 'Symptom', 'sentence': '0', 'chunk': '1', 'confidence': '0.28855002'}),
#  Annotation(chunk, 75, 86, thoracoscopy, {'entity': 'Procedure', 'sentence': '0', 'chunk': '2', 'confidence': '0.9924'}),
#  Annotation(chunk, 93, 106, fluid biopsies, {'entity': 'Procedure', 'sentence': '0', 'chunk': '3', 'confidence': '0.76275'}),
#  Annotation(chunk, 146, 179, epithelioid malignant mesothelioma, {'entity': 'Oncological', 'sentence': '0', 'chunk': '4', 'confidence': '0.53603333'}),
#  Annotation(chunk, 219, 224, PET CT, {'entity': 'Test', 'sentence': '1', 'chunk': '5', 'confidence': '0.71395004'}),
#  Annotation(chunk, 240, 255, extensive uptake, {'entity': 'ImagingFindings', 'sentence': '1', 'chunk': '6', 'confidence': '0.5604'}),
#  Annotation(chunk, 264, 268, chest, {'entity': 'External_body_part_or_region', 'sentence': '1', 'chunk': '7', 'confidence': '0.7058'}),
#  Annotation(chunk, 271, 279, bilateral, {'entity': 'Direction', 'sentence': '1', 'chunk': '8', 'confidence': '0.9832'}),
#  Annotation(chunk, 281, 309, pleural pericardial effusions, {'entity': 'Disease_Syndrome_Disorder', 'sentence': '1', 'chunk': '9', 'confidence': '0.26483333'}),
#  Annotation(chunk, 316, 330, lymphadenopathy, {'entity': 'Symptom', 'sentence': '1', 'chunk': '10', 'confidence': '0.9024'}),
#  Annotation(chunk, 334, 336, She, {'entity': 'Gender', 'sentence': '2', 'chunk': '11', 'confidence': '0.9999'}),
#  Annotation(chunk, 347, 358, acidic fluid, {'entity': 'Symptom', 'sentence': '2', 'chunk': '12', 'confidence': '0.325'}),
#  Annotation(chunk, 361, 368, pectoral, {'entity': 'Internal_organ_or_component', 'sentence': '2', 'chunk': '13', 'confidence': '0.7713'}),
#  Annotation(chunk, 374, 397, intramammary lymph nodes, {'entity': 'Internal_organ_or_component', 'sentence': '2', 'chunk': '14', 'confidence': '0.23506665'}),
#  Annotation(chunk, 403, 414, uptake in L4, {'entity': 'ImagingFindings', 'sentence': '2', 'chunk': '15', 'confidence': '0.6043'}),
#  Annotation(chunk, 421, 423, SUV, {'entity': 'Test', 'sentence': '2', 'chunk': '16', 'confidence': '0.95'}),
#  Annotation(chunk, 428, 428, 4, {'entity': 'Test_Result', 'sentence': '2', 'chunk': '17', 'confidence': '0.5174'}),
#  Annotation(chunk, 456, 464, stage III, {'entity': 'Modifier', 'sentence': '3', 'chunk': '18', 'confidence': '0.4131'}),
#  Annotation(chunk, 466, 472, disease, {'entity': 'Oncological', 'sentence': '3', 'chunk': '19', 'confidence': '0.2835'}),
#  Annotation(chunk, 475, 477, Her, {'entity': 'Gender', 'sentence': '4', 'chunk': '20', 'confidence': '1.0'}),
#  Annotation(chunk, 486, 499, echocardiogram, {'entity': 'Test', 'sentence': '4', 'chunk': '21', 'confidence': '0.9883'}),
#  Annotation(chunk, 511, 527, ejection fraction, {'entity': 'Test', 'sentence': '4', 'chunk': '22', 'confidence': '0.82905'}),
#  Annotation(chunk, 532, 541, 45% to 49%, {'entity': 'Test_Result', 'sentence': '4', 'chunk': '23', 'confidence': '0.4547'}),
#  Annotation(chunk, 545, 547, She, {'entity': 'Gender', 'sentence': '5', 'chunk': '24', 'confidence': '1.0'}),
#  Annotation(chunk, 568, 583, Oncology service, {'entity': 'Clinical_Dept', 'sentence': '5', 'chunk': '25', 'confidence': '0.99284995'}),
#  Annotation(chunk, 600, 611, chemotherapy, {'entity': 'Treatment', 'sentence': '5', 'chunk': '26', 'confidence': '0.9986'}),
#  Annotation(chunk, 616, 632, September 1, 2007, {'entity': 'Date', 'sentence': '5', 'chunk': '27', 'confidence': '0.965975'}),
#  Annotation(chunk, 639, 647, cisplatin, {'entity': 'Drug_Ingredient', 'sentence': '5', 'chunk': '28', 'confidence': '0.9809'}),
#  Annotation(chunk, 649, 664, 75 mg/centimeter, {'entity': 'Strength', 'sentence': '5', 'chunk': '29', 'confidence': '0.39270002'}),
#  Annotation(chunk, 683, 688, 109 mg, {'entity': 'Strength', 'sentence': '5', 'chunk': '30', 'confidence': '0.77709997'}),
#  Annotation(chunk, 690, 701, IV piggyback, {'entity': 'Route', 'sentence': '5', 'chunk': '31', 'confidence': '0.72214997'}),
#  Annotation(chunk, 703, 714, over 2 hours, {'entity': 'Frequency', 'sentence': '5', 'chunk': '32', 'confidence': '0.34986666'}),
#  Annotation(chunk, 719, 735, September 1, 2007, {'entity': 'Date', 'sentence': '5', 'chunk': '33', 'confidence': '0.93887496'})]

# %%
print("Clinical Text:\n", text2)
# Out:
# Clinical Text:
#
# At this time, chest tube placement for drainage of the fluid occurred and thoracoscopy with fluid biopsies, which were performed, which revealed epithelioid malignant mesothelioma.
# The patient was then stained with a PET CT, which showed extensive uptake in the chest, bilateral pleural pericardial effusions, and lymphadenopathy.
# She also had acidic fluid, pectoral and intramammary lymph nodes and uptake in L4 with SUV of 4. This was consistent with stage III disease. Her repeat echocardiogram showed an ejection fraction of 45% to 49%.
# She was transferred to Oncology service and started on chemotherapy on September 1, 2007 with cisplatin 75 mg/centimeter squared equaling 109 mg IV piggyback over 2 hours on September 1, 2007

# %%
get_results(bio_full_result)
# Out:
#
#  ******************** ner_cellular_biobert Model Results ********************
# No Result For This Model
#
#
#  ******************** ner_diseases_biobert Model Results ********************
#   sentence  begin  end                              chunks   entity  confidence
# 0        0    146  179  epithelioid malignant mesothelioma  Disease  0.95236665
# 1        1    281  309       pleural pericardial effusions  Disease   0.8773667
# 2        1    316  330                     lymphadenopathy  Disease      0.9807
# 3        3    456  472                   stage III disease  Disease   0.8513667
#
#  ******************** ner_events_biobert Model Results ********************
#    sentence  begin  ...         entity  confidence
# 0         0     15  ...      TREATMENT  0.82250005
# 1         0     40  ...      TREATMENT      0.9375
# 2         0     52  ...        PROBLEM     0.92555
# 3         0     75  ...           TEST      0.6154
# 4         0     93  ...           TEST     0.88645
# 5         0    137  ...     EVIDENTIAL      0.9861
# 6         0    146  ...        PROBLEM  0.93763334
# 7         1    217  ...           TEST  0.94936675
# 8         1    233  ...     EVIDENTIAL      0.9169
# 9         1    240  ...        PROBLEM     0.82536
# 10        1    271  ...        PROBLEM    0.876475
# 11        1    316  ...        PROBLEM      0.8454
# 12        2    347  ...        PROBLEM  0.73123753
# 13        2    403  ...        PROBLEM      0.7737
# 14        2    421  ...           TEST      0.9839
# 15        3    456  ...        PROBLEM  0.76570004
# 16        4    475  ...           TEST  0.92633337
# 17        4    501  ...     EVIDENTIAL      0.9836
# 18        4    508  ...           TEST  0.63166666
# 19        5    553  ...     OCCURRENCE      0.9887
# 20        5    568  ...  CLINICAL_DEPT     0.88925
# 21        5    600  ...      TREATMENT      0.9914
# 22        5    616  ...           DATE    0.814475
# 23        5    639  ...      TREATMENT      0.9957
# 24        5    708  ...       DURATION     0.63945
# 25        5    719  ...           DATE  0.67277503
#
# [26 rows x 6 columns]
#
#  ******************** ner_bionlp_biobert Model Results ********************
#    sentence  begin  ...                  entity confidence
# 0         0     15  ...  Multi-tissue_structure    0.63195
# 1         0     56  ...      Organism_substance     0.9947
# 2         0    146  ...                  Cancer  0.9557667
# 3         1    187  ...                Organism        1.0
# 4         1    264  ...    Organism_subdivision     0.8881
# 5         1    289  ...  Multi-tissue_structure    0.72915
# 6         2    347  ...      Organism_substance     0.7724
# 7         2    361  ...  Multi-tissue_structure     0.9817
# 8         2    374  ...  Multi-tissue_structure     0.9721
# 9         2    413  ...  Multi-tissue_structure     0.9519
# 10        5    639  ...         Simple_chemical        1.0
#
# [11 rows x 6 columns]
#
#  ******************** ner_jsl_greedy_biobert Model Results ********************
#    sentence  begin  ...                        entity  confidence
# 0         0     15  ...                     Procedure  0.43430004
# 1         0     56  ...                       Symptom      0.4547
# 2         0     75  ...                     Procedure      0.9943
# 3         0     93  ...                     Procedure      0.6034
# 4         0    146  ...                   Oncological   0.7372667
# 5         1    219  ...                          Test      0.8478
# 6         1    240  ...               ImagingFindings      0.5046
# 7         1    264  ...  External_body_part_or_region      0.6914
# 8         1    271  ...                     Direction      0.5708
# 9         1    281  ...     Disease_Syndrome_Disorder       0.249
# 10        1    316  ...                       Symptom      0.8689
# 11        2    334  ...                        Gender      0.9998
# 12        2    347  ...                       Symptom      0.2492
# 13        2    361  ...  External_body_part_or_region      0.5236
# 14        2    374  ...   Internal_organ_or_component  0.37393332
# 15        2    413  ...   Internal_organ_or_component      0.7177
# 16        2    421  ...                          Test      0.8601
# 17        3    456  ...                   Oncological  0.19683333
# 18        4    475  ...                        Gender      0.9996
# 19        4    486  ...                          Test      0.9874
# 20        4    511  ...                          Test      0.8779
# 21        4    532  ...                   Test_Result  0.62729996
# 22        5    545  ...                        Gender      0.9996
# 23        5    568  ...                 Clinical_Dept  0.90384996
# 24        5    600  ...                          Drug     0.53597
# 25        5    683  ...                          Drug    0.531375
# 26        5    703  ...                      Duration  0.50083333
# 27        5    719  ...                          Date    0.513325
#
# [28 rows x 6 columns]
#
#  ******************** ner_jsl_biobert Model Results ********************
#    sentence  begin  ...                        entity  confidence
# 0         0     15  ...                     Procedure   0.5898667
# 1         0     40  ...                       Symptom  0.28855002
# 2         0     75  ...                     Procedure      0.9924
# 3         0     93  ...                     Procedure     0.76275
# 4         0    146  ...                   Oncological  0.53603333
# 5         1    219  ...                          Test  0.71395004
# 6         1    240  ...               ImagingFindings      0.5604
# 7         1    264  ...  External_body_part_or_region      0.7058
# 8         1    271  ...                     Direction      0.9832
# 9         1    281  ...     Disease_Syndrome_Disorder  0.26483333
# 10        1    316  ...                       Symptom      0.9024
# 11        2    334  ...                        Gender      0.9999
# 12        2    347  ...                       Symptom       0.325
# 13        2    361  ...   Internal_organ_or_component      0.7713
# 14        2    374  ...   Internal_organ_or_component  0.23506665
# 15        2    403  ...               ImagingFindings      0.6043
# 16        2    421  ...                          Test        0.95
# 17        2    428  ...                   Test_Result      0.5174
# 18        3    456  ...                      Modifier      0.4131
# 19        3    466  ...                   Oncological      0.2835
# 20        4    475  ...                        Gender         1.0
# 21        4    486  ...                          Test      0.9883
# 22        4    511  ...                          Test     0.82905
# 23        4    532  ...                   Test_Result      0.4547
# 24        5    545  ...                        Gender         1.0
# 25        5    568  ...                 Clinical_Dept  0.99284995
# 26        5    600  ...                     Treatment      0.9986
# 27        5    616  ...                          Date    0.965975
# 28        5    639  ...               Drug_Ingredient      0.9809
# 29        5    649  ...                      Strength  0.39270002
# 30        5    683  ...                      Strength  0.77709997
# 31        5    690  ...                         Route  0.72214997
# 32        5    703  ...                     Frequency  0.34986666
# 33        5    719  ...                          Date  0.93887496
#
# [34 rows x 6 columns]
#
#  ******************** ner_anatomy_biobert Model Results ********************
#   sentence  begin  ...                  entity confidence
# 0        0     56  ...      Organism_substance     0.9964
# 1        0     93  ...      Organism_substance      0.965
# 2        1    264  ...    Organism_subdivision     0.9811
# 3        1    281  ...  Multi-tissue_structure     0.6669
# 4        2    354  ...      Organism_substance     0.9242
# 5        2    387  ...  Pathological_formation    0.89185
#
# [6 rows x 6 columns]
#
#  ******************** ner_jsl_enriched_biobert Model Results ********************
#    sentence  begin  ...          entity  confidence
# 0         0     75  ...  Procedure_Name      0.9168
# 1         0     93  ...  Procedure_Name  0.63594997
# 2         0    146  ...       Diagnosis  0.37353334
# 3         1    219  ...            Name      0.7194
# 4         1    316  ...    Symptom_Name      0.5233
# 5         2    334  ...          Gender       0.857
# 6         4    475  ...          Gender      0.8197
# 7         4    486  ...            Name      0.9748
# 8         5    545  ...          Gender      0.8454
# 9         5    600  ...       Drug_Name      0.6239
# 10        5    639  ...       Drug_Name       0.977
#
# [11 rows x 6 columns]
#
#  ******************** ner_human_phenotype_go_biobert Model Results ********************
#   sentence  begin  end     chunks entity confidence
# 0        1    271  279  bilateral     HP     0.9994
#
#  ******************** ner_deid_biobert Model Results ********************
#   sentence  begin  end             chunks entity  confidence
# 0        5    616  632  September 1, 2007   DATE    0.918525
# 1        5    719  735  September 1, 2007   DATE  0.78264993
#
#  ******************** ner_deid_enriched_biobert Model Results ********************
#   sentence  begin  end             chunks entity  confidence
# 0        5    616  632  September 1, 2007   DATE  0.85272497
# 1        5    719  735  September 1, 2007   DATE     0.80125
#
#  ******************** ner_clinical_biobert Model Results ********************
#    sentence  begin  ...     entity  confidence
# 0         0     15  ...  TREATMENT  0.83743334
# 1         0     40  ...  TREATMENT      0.9278
# 2         0     52  ...    PROBLEM  0.73440003
# 3         0     75  ...       TEST      0.7644
# 4         0     93  ...       TEST      0.7454
# 5         0    146  ...    PROBLEM   0.9554667
# 6         1    217  ...       TEST      0.9867
# 7         1    240  ...    PROBLEM      0.7874
# 8         1    271  ...    PROBLEM    0.726475
# 9         1    316  ...    PROBLEM      0.9856
# 10        2    347  ...    PROBLEM       0.686
# 11        2    361  ...    PROBLEM     0.68846
# 12        2    403  ...    PROBLEM  0.72023326
# 13        2    421  ...       TEST      0.9567
# 14        3    456  ...    PROBLEM  0.78283334
# 15        4    475  ...       TEST  0.89046663
# 16        4    508  ...       TEST  0.70666665
# 17        5    600  ...  TREATMENT      0.9666
# 18        5    639  ...  TREATMENT      0.9939
#
# [19 rows x 6 columns]
#
#  ******************** ner_anatomy_coarse_biobert Model Results ********************
#   sentence  begin  ...   entity confidence
# 0        0     15  ...  Anatomy    0.97695
# 1        0     56  ...  Anatomy     0.9538
# 2        0     93  ...  Anatomy     0.7474
# 3        0    146  ...  Anatomy  0.9614666
# 4        1    264  ...  Anatomy     0.9686
# 5        1    271  ...  Anatomy   0.784075
# 6        2    347  ...  Anatomy    0.64615
# 7        2    361  ...  Anatomy     0.9955
# 8        2    374  ...  Anatomy  0.9804333
# 9        2    413  ...  Anatomy     0.9677
#
# [10 rows x 6 columns]
#
#  ******************** ner_human_phenotype_gene_biobert Model Results ********************
#   sentence  begin  end                         chunks entity confidence
# 0        0     15   24                     chest tube     HP     0.9135
# 1        1    271  279                      bilateral     HP     0.9859
# 2        1    281  309  pleural pericardial effusions     HP  0.9592333
#
#  ******************** ner_posology_large_biobert Model Results ********************
#   sentence  begin  end            chunks    entity confidence
# 0        5    600  611      chemotherapy      DRUG        1.0
# 1        5    639  647         cisplatin      DRUG        1.0
# 2        5    649  664  75 mg/centimeter  STRENGTH     0.8503
# 3        5    683  688            109 mg  STRENGTH    0.90645
# 4        5    690  691                IV     ROUTE     0.9999
#
#  ******************** jsl_rd_ner_wip_greedy_biobert Model Results ********************
#    sentence  begin  ...                     entity  confidence
# 0         0     15  ...                   BodyPart      0.7313
# 1         0     21  ...                  Procedure     0.63555
# 2         0     40  ...                  Procedure      0.5822
# 3         0     56  ...            ImagingFindings      0.4293
# 4         0     75  ...                  Procedure      0.9873
# 5         0     93  ...                  Procedure      0.5108
# 6         0    146  ...  Disease_Syndrome_Disorder  0.50823337
# 7         1    219  ...                ImagingTest     0.85085
# 8         1    240  ...            ImagingFindings  0.38160002
# 9         1    264  ...                   BodyPart      0.9469
# 10        1    271  ...                  Direction      0.8119
# 11        1    281  ...                   BodyPart     0.56675
# 12        1    301  ...            ImagingFindings      0.8505
# 13        1    316  ...            ImagingFindings      0.7923
# 14        2    347  ...                    Symptom     0.34085
# 15        2    361  ...                   BodyPart      0.9509
# 16        2    374  ...                   BodyPart      0.6314
# 17        2    403  ...            ImagingFindings      0.7065
# 18        2    413  ...                   BodyPart      0.9876
# 19        2    421  ...                    Symptom      0.8034
# 20        3    456  ...  Disease_Syndrome_Disorder   0.7056667
# 21        4    486  ...                ImagingTest      0.6999
# 22        4    511  ...              OtherFindings  0.65540004
# 23        4    532  ...               Measurements      0.9959
# 24        4    539  ...               Measurements      0.9925
# 25        5    649  ...               Measurements      0.9994
# 26        5    652  ...                      Units      0.9592
# 27        5    683  ...               Measurements      0.9504
# 28        5    687  ...                      Units      0.9992
#
# [29 rows x 6 columns]
#
#  ******************** ner_posology_biobert Model Results ********************
#   sentence  begin  end            chunks     entity confidence
# 0        5    600  611      chemotherapy       DRUG     0.9995
# 1        5    639  647         cisplatin       DRUG        1.0
# 2        5    649  664  75 mg/centimeter   STRENGTH     0.7199
# 3        5    683  688            109 mg   STRENGTH       0.81
# 4        5    690  691                IV      ROUTE        1.0
# 5        5    693  701         piggyback  FREQUENCY     0.9044
#
#  ******************** jsl_ner_wip_greedy_biobert Model Results ********************
#    sentence  begin  ...                        entity  confidence
# 0         0     15  ...                     Procedure  0.43430004
# 1         0     56  ...                       Symptom      0.4547
# 2         0     75  ...                     Procedure      0.9943
# 3         0     93  ...                     Procedure      0.6034
# 4         0    146  ...                   Oncological   0.7372667
# 5         1    219  ...                          Test      0.8478
# 6         1    240  ...               ImagingFindings      0.5046
# 7         1    264  ...  External_body_part_or_region      0.6914
# 8         1    271  ...                     Direction      0.5708
# 9         1    281  ...     Disease_Syndrome_Disorder       0.249
# 10        1    316  ...                       Symptom      0.8689
# 11        2    334  ...                        Gender      0.9998
# 12        2    347  ...                       Symptom      0.2492
# 13        2    361  ...  External_body_part_or_region      0.5236
# 14        2    374  ...   Internal_organ_or_component  0.37393332
# 15        2    413  ...   Internal_organ_or_component      0.7177
# 16        2    421  ...                          Test      0.8601
# 17        3    456  ...                   Oncological  0.19683333
# 18        4    475  ...                        Gender      0.9996
# 19        4    486  ...                          Test      0.9874
# 20        4    511  ...                          Test      0.8779
# 21        4    532  ...                   Test_Result  0.62729996
# 22        5    545  ...                        Gender      0.9996
# 23        5    568  ...                 Clinical_Dept  0.90384996
# 24        5    600  ...                          Drug     0.53597
# 25        5    683  ...                          Drug    0.531375
# 26        5    703  ...                      Duration  0.50083333
# 27        5    719  ...                          Date    0.513325
#
# [28 rows x 6 columns]
#
#  ******************** ner_chemprot_biobert Model Results ********************
#   sentence  begin  end     chunks    entity confidence
# 0        5    639  647  cisplatin  CHEMICAL     0.9939
#
#  ******************** ner_ade_biobert Model Results ********************
#   sentence  begin  ...  entity  confidence
# 0        0     15  ...    DRUG   0.9891667
# 1        0     40  ...    DRUG  0.77637494
# 2        0     75  ...    DRUG      0.9375
# 3        1    240  ...     ADE     0.90334
# 4        1    271  ...     ADE     0.73015
# 5        2    347  ...     ADE      0.6747
# 6        3    456  ...    DRUG      0.9395
# 7        5    600  ...    DRUG      0.9912
# 8        5    639  ...    DRUG       0.992
# 9        5    693  ...    DRUG      0.8437
#
# [10 rows x 6 columns]
#
#  ******************** ner_risk_factors_biobert Model Results ********************
#   sentence  begin  end     chunks entity confidence
# 0        5    616  624  September    PHI     0.9707
# 1        5    719  727  September    PHI     0.9858
# 2        5    732  735       2007    PHI     0.9828
