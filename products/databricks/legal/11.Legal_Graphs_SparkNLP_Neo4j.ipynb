# %% [markdown]
# #SparkNLP_Neo4j.ipynb

# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)

# %%
from johnsnowlabs import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import pandas as pd
import warnings
import glob
import pickle
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import os
import sys
import time
import json
import neo4j
import functools 
import graphistry
import numpy as np
from tqdm import tqdm
from scipy import spatial
from neo4j import GraphDatabase
from neo4j import GraphDatabase, Driver

print('neo4j', neo4j.__version__)
print('graphistry', graphistry.__version__)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">neo4j 5.1.0
# graphistry 0.28.3
# </div>

# %% [markdown]
# ###Establishing a connection with Neo4j Sandbox and pygraphistry

# %%
class Neo4jConnection:
    
    def __init__(self, uri, user, pwd):
        
        self.__uri = uri
        self.__user = user
        self.__pwd = pwd
        self.__driver = None
        
        try:
            self.__driver = GraphDatabase.driver(self.__uri, auth=(self.__user, self.__pwd))
        except Exception as e:
            print("Failed to create the driver:", e)
        
    def close(self):
        
        if self.__driver is not None:
            self.__driver.close()
        
    def query(self, query, parameters=None, db=None):
        
        assert self.__driver is not None, "Driver not initialized!"
        session = None
        response = None
        
        try: 
            session = self.__driver.session(database=db) if db is not None else self.__driver.session() 
            response = list(session.run(query, parameters))
        except Exception as e:
            print("Query failed:", e)
        finally: 
            if session is not None:
                session.close()
        return response
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import neo4j
from neo4j import GraphDatabase
from neo4j import GraphDatabase, Driver
uri = 'bolt://44.194.255.107:7687'
pwd = 'friend-semiconductors-switches'
user= 'neo4j'

conn = Neo4jConnection(uri=uri, user=user , pwd=pwd)

NEO4J = {
    'uri': "bolt://44.194.255.107:7687", 
    'auth': ("neo4j", "friend-semiconductors-switches")
}
# create an account in graphistry and use the username and password here.
graphistry.register(api=3,bolt=NEO4J,username=[username], password=[password])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #Available graphs in ChunkMappers

# %%
sec_results = [
    """Fig Publishing, Inc.""",
    """AWA Group LP""",
    """DatChat, Inc.""",
    """iConsumer Corp."""]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
documentAssembler = nlp.DocumentAssembler()\
        .setInputCol("text")\
        .setOutputCol("document")

chunkAssembler = nlp.Doc2Chunk() \
    .setInputCols("document") \
    .setOutputCol("chunk") \
    .setIsArray(False)
#to change
CM = legal.ChunkMapperModel()\
      .pretrained("legmapper_edgar_companyname", "en", "legal/models")\
      .setInputCols(["chunk"])\
      .setOutputCol("mappings")

cm_pipeline = Pipeline(stages=[documentAssembler, chunkAssembler, CM])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">legmapper_edgar_companyname download started this may take some time.
# [OK!]
# </div>

# %%
text = [""]
test_data = spark.createDataFrame([text]).toDF("text")
fit_cm_pipeline = cm_pipeline.fit(test_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from collections import defaultdict
dicti = defaultdict(list)

for i in sec_results:
    kk = fit_cm_pipeline.transform(spark.createDataFrame([[i]]).toDF("text"))
    cm_res = []
    cm_res.append(kk.collect())
    for r in cm_res:
        json_dict = dict()
        json_dict['mappings'] = []
        for n in r[0]['mappings']:
            json_dict['mappings'].append([str(n.annotatorType), n.begin, n.end, str(n.result), {k:v for k,v in n.metadata.items()}])
    for i in json_dict['mappings']:
        dicti[i[4]['relation']].append(i[3])
    #     print(i[3],'--->',i[4]['relation'])  
    # print('-------------------------------')

df = pd.DataFrame(dicti)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>sic</th>
#       <th>sic_code</th>
#       <th>irs_number</th>
#       <th>fiscal_year_end</th>
#       <th>state_location</th>
#       <th>state_incorporation</th>
#       <th>business_street</th>
#       <th>business_city</th>
#       <th>business_state</th>
#       <th>business_zip</th>
#       <th>business_phone</th>
#       <th>former_name</th>
#       <th>former_name_date</th>
#       <th>date</th>
#       <th>company_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Fig Publishing, Inc.</td>
#       <td>SERVICES-PREPACKAGED SOFTWARE [7372]</td>
#       <td>7372</td>
#       <td>475336565</td>
#       <td>931</td>
#       <td>CA</td>
#       <td>DE</td>
#       <td>599 THIRD STREET</td>
#       <td>SAN FRANCISCO</td>
#       <td>CA</td>
#       <td>94107</td>
#       <td>(415) 689-5789</td>
#       <td></td>
#       <td></td>
#       <td>2017-01-23</td>
#       <td>1658966</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>AWA Group LP</td>
#       <td>INVESTMENT ADVICE [6282]</td>
#       <td>6282</td>
#       <td>371785232</td>
#       <td>630</td>
#       <td>NC</td>
#       <td>DE</td>
#       <td>116 SOUTH FRANKLIN STREET</td>
#       <td>ROCKY MOUNT</td>
#       <td>NC</td>
#       <td>27804</td>
#       <td>952-446-6678</td>
#       <td></td>
#       <td></td>
#       <td>2017-01-23</td>
#       <td>1645148</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>DatChat, Inc.</td>
#       <td>TELEGRAPH &amp; OTHER MESSAGE COMMUNICATIONS [4822]</td>
#       <td>4822</td>
#       <td>472502264</td>
#       <td>1231</td>
#       <td>NJ</td>
#       <td>NV</td>
#       <td>65 CHURCH STREET</td>
#       <td>NEW BRUNSWICK</td>
#       <td>NJ</td>
#       <td>08901</td>
#       <td>7323544768</td>
#       <td>Dat Chat, Inc</td>
#       <td>20150722</td>
#       <td>2017-01-12</td>
#       <td>1648960</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>iConsumer Corp.</td>
#       <td>SERVICES-PERSONAL SERVICES [7200]</td>
#       <td>7200</td>
#       <td>274286597</td>
#       <td>1231</td>
#       <td>FL</td>
#       <td>DE</td>
#       <td>19821 NW 2ND AVE SUITE 351</td>
#       <td>MIAMI GARDENS</td>
#       <td>FL</td>
#       <td>33169</td>
#       <td>8003726095</td>
#       <td></td>
#       <td></td>
#       <td>2017-01-18</td>
#       <td>1652350</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ###Generate csv for Neo4j

# %%
df.to_csv('graphs.csv',index=False)

# %% [markdown]
# To use the CSV in Neo4j there are a couple of ways mentioned [here](https://neo4j.com/developer/kb/import-csv-locations/). I have used the one where we upload it to google sheets and then publish it to web and then use the link that is generated in here.
#
# ![6.png](/files/FINLEG/6.png)

# %% [markdown]
# ###Visualization using Neo4j and graphistry

# %%
query = '''
    // create an array of maps, using the keys() function
    LOAD CSV WITH HEADERS FROM 'https://docs.google.com/spreadsheets/d/e/2PACX-1vSSFwFkyFQgMwb_WyW8LYC0mN-7tFgt3jsiO3uq6D1atKG05w8gxSxQUytqpl1BUTbOs3ErjdO1eeWY/pub?gid=419410490&single=true&output=csv' as row
    with row.name AS company,
        [key IN keys(row) WHERE key<>'name' | {relType:key,location:row[key]}] as relTypeLocs

    WHERE row.name = 'DatChat, Inc.'

    unwind relTypeLocs AS relTypeLoc



    merge (l:locations {name:COALESCE(relTypeLoc.location,'Unknown')})



    merge (t:tokens {name:company})



    WITH l,t,



        relTypeLoc.relType AS relType



    // use apoc to create the rels



    CALL apoc.create.relationship(t,relType,{}, l) YIELD rel



    RETURN *
    '''
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
result = conn.query(query)

result
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: [&lt;Record l=&lt;Node element_id=&#39;0&#39; labels=frozenset({&#39;locations&#39;}) properties={&#39;name&#39;: &#39;1648960&#39;}&gt; rel=&lt;Relationship element_id=&#39;0&#39; nodes=(&lt;Node element_id=&#39;1&#39; labels=frozenset({&#39;tokens&#39;}) properties={&#39;name&#39;: &#39;DatChat, Inc.&#39;}&gt;, &lt;Node element_id=&#39;0&#39; labels=frozenset({&#39;locations&#39;}) properties={&#39;name&#39;: &#39;1648960&#39;}&gt;) type=&#39;company_id&#39; properties={}&gt; relType=&#39;company_id&#39; t=&lt;Node element_id=&#39;1&#39; labels=frozenset({&#39;tokens&#39;}) properties={&#39;name&#39;: &#39;DatChat, Inc.&#39;}&gt;&gt;,
#  &lt;Record l=&lt;Node element_id=&#39;2&#39; labels=frozenset({&#39;locations&#39;}) properties={&#39;name&#39;: &#39;NJ&#39;}&gt; rel=&lt;Relationship element_id=&#39;1&#39; nodes=(&lt;Node element_id=&#39;1&#39; labels=frozenset({&#39;tokens&#39;}) properties={&#39;name&#39;: &#39;DatChat, Inc.&#39;}&gt;, &lt;Node element_id=&#39;2&#39; labels=frozenset({&#39;locations&#39;}) properties={&#39;name&#39;: &#39;NJ&#39;}&gt;) type=&#39;state_location&#39; properties={}&gt; relType=&#39;state_location&#39; t=&lt;Node element_id=&#39;1&#39; labels=frozenset({&#39;tokens&#39;}) properties={&#39;name&#39;: &#39;DatChat, Inc.&#39;}&gt;&gt;,
#  &lt;Record l=&lt;Node element_id=&#39;3&#39; labels=frozenset({&#39;locations&#39;}) properties={&#39;name&#39;: &#39;472502264&#39;}&gt; rel=&lt;Relationship element_id=&#39;2&#39; nodes=(&lt;Node element_id=&#39;1&#39; labels=frozenset({&#39;tokens&#39;}) properties={&#39;name&#39;: &#39;DatChat, Inc.&#39;}&gt;, &lt;Node element_id=&#39;3&#39; labels=frozenset({&#39;locations&#39;}) properties={&#39;name&#39;: &#39;472502264&#39;}&gt;) type=&#39;irs_number&#39; properties={}&gt; relType=&#39;irs_number&#39; t=&lt;Node element_id=&#39;1&#39; labels=frozenset({&#39;tokens&#39;}) properties={&#39;name&#39;: &#39;DatChat, Inc.&#39;}&gt;&gt;,
#  &lt;Record l=&lt;Node element_id=&#39;4&#39; labels=frozenset({&#39;locations&#39;}) properties={&#39;name&#39;: &#39;NEW BRUNSWICK&#39;}&gt; rel=&lt;Relationship element_id=&#39;3&#39; nodes=(&lt;Node element_id=&#39;1&#39; labels=frozenset({&#39;tokens&#39;}) properties={&#39;name&#39;: &#39;DatChat, Inc.&#39;}&gt;, &lt;Node element_id=&#39;4&#39; labels=frozenset({&#39;locations&#39;}) properties={&#39;name&#39;: &#39;NEW BRUNSWICK&#39;}&gt;) type=&#39;business_city&#39; properties={}&gt; relType=&#39;business_city&#39; t=&lt;Node element_id=&#39;1&#39; labels=frozenset({&#39;tokens&#39;}) properties={&#39;name&#39;: &#39;DatChat, Inc.&#39;}&gt;&gt;,
#  &lt;Record l=&lt;Node element_id=&#39;5&#39; labels=frozenset({&#39;locations&#39;}) properties={&#39;name&#39;: &#39;2017-01-12&#39;}&gt; rel=&lt;Relationship element_id=&#39;4&#39; nodes=(&lt;Node element_id=&#39;1&#39; labels=frozenset({&#39;tokens&#39;}) properties={&#39;name&#39;: &#39;DatChat, Inc.&#39;}&gt;, &lt;Node element_id=&#39;5&#39; labels=frozenset({&#39;locations&#39;}) properties={&#39;name&#39;: &#39;2017-01-12&#39;}&gt;) type=&#39;date&#39; properties={}&gt; relType=&#39;date&#39; t=&lt;Node element_id=&#39;1&#39; labels=frozenset({&#39;tokens&#39;}) properties={&#39;name&#39;: &#39;DatChat, Inc.&#39;}&gt;&gt;,
#  &lt;Record l=&lt;Node element_id=&#39;6&#39; labels=frozenset({&#39;locations&#39;}) properties={&#39;name&#39;: &#39;Dat Chat, Inc&#39;}&gt; rel=&lt;Relationship element_id=&#39;5&#39; nodes=(&lt;Node element_id=&#39;1&#39; labels=frozenset({&#39;tokens&#39;}) properties={&#39;name&#39;: &#39;DatChat, Inc.&#39;}&gt;, &lt;Node element_id=&#39;6&#39; labels=frozenset({&#39;locations&#39;}) properties={&#39;name&#39;: &#39;Dat Chat, Inc&#39;}&gt;) type=&#39;former_name&#39; properties={}&gt; relType=&#39;former_name&#39; t=&lt;Node element_id=&#39;1&#39; labels=frozenset({&#39;tokens&#39;}) properties={&#39;name&#39;: &#39;DatChat, Inc.&#39;}&gt;&gt;,
#  &lt;Record l=&lt;Node element_id=&#39;7&#39; labels=frozenset({&#39;locations&#39;}) properties={&#39;name&#39;: &#39;20150722&#39;}&gt; rel=&lt;Relationship element_id=&#39;6&#39; nodes=(&lt;Node element_id=&#39;1&#39; labels=frozenset({&#39;tokens&#39;}) properties={&#39;name&#39;: &#39;DatChat, Inc.&#39;}&gt;, &lt;Node element_id=&#39;7&#39; labels=frozenset({&#39;locations&#39;}) properties={&#39;name&#39;: &#39;20150722&#39;}&gt;) type=&#39;former_name_date&#39; properties={}&gt; relType=&#39;former_name_date&#39; t=&lt;Node element_id=&#39;1&#39; labels=frozenset({&#39;tokens&#39;}) properties={&#39;name&#39;: &#39;DatChat, Inc.&#39;}&gt;&gt;,
#  &lt;Record l=&lt;Node element_id=&#39;2&#39; labels=frozenset({&#39;locations&#39;}) properties={&#39;name&#39;: &#39;NJ&#39;}&gt; rel=&lt;Relationship element_id=&#39;7&#39; nodes=(&lt;Node element_id=&#39;1&#39; labels=frozenset({&#39;tokens&#39;}) properties={&#39;name&#39;: &#39;DatChat, Inc.&#39;}&gt;, &lt;Node element_id=&#39;2&#39; labels=frozenset({&#39;locations&#39;}) properties={&#39;name&#39;: &#39;NJ&#39;}&gt;) type=&#39;business_state&#39; properties={}&gt; relType=&#39;business_state&#39; t=&lt;Node element_id=&#39;1&#39; labels=frozenset({&#39;tokens&#39;}) properties={&#39;name&#39;: &#39;DatChat, Inc.&#39;}&gt;&gt;,
#  &lt;Record l=&lt;Node element_id=&#39;8&#39; labels=frozenset({&#39;locations&#39;}) properties={&#39;name&#39;: &#39;1231&#39;}&gt; rel=&lt;Relationship element_id=&#39;8&#39; nodes=(&lt;Node element_id=&#39;1&#39; labels=frozenset({&#39;tokens&#39;}) properties={&#39;name&#39;: &#39;DatChat, Inc.&#39;}&gt;, &lt;Node element_id=&#39;8&#39; labels=frozenset({&#39;locations&#39;}) properties={&#39;name&#39;: &#39;1231&#39;}&gt;) type=&#39;fiscal_year_end&#39; properties={}&gt; relType=&#39;fiscal_year_end&#39; t=&lt;Node element_id=&#39;1&#39; labels=frozenset({&#39;tokens&#39;}) properties={&#39;name&#39;: &#39;DatChat, Inc.&#39;}&gt;&gt;,
#  &lt;Record l=&lt;Node element_id=&#39;9&#39; labels=frozenset({&#39;locations&#39;}) properties={&#39;name&#39;: &#39;65 CHURCH STREET&#39;}&gt; rel=&lt;Relationship element_id=&#39;9&#39; nodes=(&lt;Node element_id=&#39;1&#39; labels=frozenset({&#39;tokens&#39;}) properties={&#39;name&#39;: &#39;DatChat, Inc.&#39;}&gt;, &lt;Node element_id=&#39;9&#39; labels=frozenset({&#39;locations&#39;}) properties={&#39;name&#39;: &#39;65 CHURCH STREET&#39;}&gt;) type=&#39;business_street&#39; properties={}&gt; relType=&#39;business_street&#39; t=&lt;Node element_id=&#39;1&#39; labels=frozenset({&#39;tokens&#39;}) properties={&#39;name&#39;: &#39;DatChat, Inc.&#39;}&gt;&gt;,
#  &lt;Record l=&lt;Node element_id=&#39;10&#39; labels=frozenset({&#39;locations&#39;}) properties={&#39;name&#39;: &#39;4822&#39;}&gt; rel=&lt;Relationship element_id=&#39;10&#39; nodes=(&lt;Node element_id=&#39;1&#39; labels=frozenset({&#39;tokens&#39;}) properties={&#39;name&#39;: &#39;DatChat, Inc.&#39;}&gt;, &lt;Node element_id=&#39;10&#39; labels=frozenset({&#39;locations&#39;}) properties={&#39;name&#39;: &#39;4822&#39;}&gt;) type=&#39;sic_code&#39; properties={}&gt; relType=&#39;sic_code&#39; t=&lt;Node element_id=&#39;1&#39; labels=frozenset({&#39;tokens&#39;}) properties={&#39;name&#39;: &#39;DatChat, Inc.&#39;}&gt;&gt;,
#  &lt;Record l=&lt;Node element_id=&#39;11&#39; labels=frozenset({&#39;locations&#39;}) properties={&#39;name&#39;: &#39;TELEGRAPH &amp; OTHER MESSAGE COMMUNICATIONS [4822]&#39;}&gt; rel=&lt;Relationship element_id=&#39;11&#39; nodes=(&lt;Node element_id=&#39;1&#39; labels=frozenset({&#39;tokens&#39;}) properties={&#39;name&#39;: &#39;DatChat, Inc.&#39;}&gt;, &lt;Node element_id=&#39;11&#39; labels=frozenset({&#39;locations&#39;}) properties={&#39;name&#39;: &#39;TELEGRAPH &amp; OTHER MESSAGE COMMUN

# %%
g = graphistry.cypher(query)
print(g._edges.columns)
# g.plot()

g.plot()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Index([&#39;_bolt_relationship_id&#39;, &#39;type&#39;, &#39;_bolt_start_node_id_key&#39;,
#        &#39;_bolt_end_node_id_key&#39;],
#       dtype=&#39;object&#39;)
# Out[20]: </div>
#             <iframe id="7222825a-aac2-4caa-a7ef-9b4fb8d4a7ea" src="https://hub.graphistry.com/graph/graph.html?dataset=cef47d516b48475fbf1492c2a7b66f3a&type=arrow&viztoken=097aa4a1-2088-4216-89d5-aba755f62896&usertag=cce73edc-pygraphistry-0.28.3&splashAfter=1665990946&info=true"
#                     allowfullscreen="true" webkitallowfullscreen="true" mozallowfullscreen="true"
#                     oallowfullscreen="true" msallowfullscreen="true"
#                     style="width:100%; height:500px; border: 1px solid #DDD; overflow: hidden"
#
#             >
#             </iframe>
#
#             <script>
#                 try {
#                   $("#7222825a-aac2-4caa-a7ef-9b4fb8d4a7ea").bind('mousewheel', function(e) { e.preventDefault(); });
#                 } catch (e) { console.error('exn catching scroll', e); }
#             </script>

# %% [markdown]
# ![8.png](/files/FINLEG/8.png)

# %% [markdown]
# #Graphs with NER and Relation Extraction

# %%
documentAssembler = nlp.DocumentAssembler()\
  .setInputCol("text")\
  .setOutputCol("document")

"""sentenceDetector = SentenceDetectorDLModel.pretrained("sentence_detector_dl","xx")\
        .setInputCols(["document"])\
        .setOutputCol("sentence")"""

tokenizer = nlp.Tokenizer()\
  .setInputCols("document")\
  .setOutputCol("token")

embeddings = nlp.RoBertaEmbeddings.pretrained("roberta_embeddings_legal_roberta_base", "en") \
        .setInputCols("document", "token") \
        .setOutputCol("embeddings")\
        .setMaxSentenceLength(512)

ner_model = legal.NerModel.pretrained('legner_contract_doc_parties', 'en', 'legal/models')\
        .setInputCols(["document", "token", "embeddings"])\
        .setOutputCol("ner")

ner_converter = nlp.NerConverter()\
        .setInputCols(["document","token","ner"])\
        .setOutputCol("ner_chunk")

"""
ONLY NEEDED IF YOU WANT TO FILTER RELATION PAIRS OR SYNTACTIC DISTANCE
pos_tagger = PerceptronModel()\
    .pretrained("pos_clinical", "en", "clinical/models") \
    .setInputCols(["document", "tokens"])\
    .setOutputCol("pos_tags")

dependency_parser = DependencyParserModel() \
    .pretrained("dependency_conllu", "en") \
    .setInputCols(["document", "pos_tags", "tokens"]) \
    .setOutputCol("dependencies")

# Set a filter on pairs of named entities which will be treated as relation candidates
re_filter = RENerChunksFilter()\
    .setInputCols(["ner_chunks", "dependencies"])\
    .setOutputCol("re_ner_chunks")\
#    .setMaxSyntacticDistance(7)\
#    .setRelationPairs(['PARTY-ALIAS', 'DOC-PARTY', 'DOC-EFFDATE'])
"""
reDL = legal.RelationExtractionDLModel.pretrained('legre_contract_doc_parties', 'en', 'legal/models')\
    .setPredictionThreshold(0.5)\
    .setInputCols(["ner_chunk", "document"])\
    .setOutputCol("relations")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">roberta_embeddings_legal_roberta_base download started this may take some time.
# Approximate size to download 447.2 MB
# [OK!]
# legner_contract_doc_parties download started this may take some time.
# [OK!]
# legre_contract_doc_parties download started this may take some time.
# [OK!]
# </div>

# %%
pipeline = Pipeline(stages=[
    documentAssembler,
    tokenizer,
    embeddings,
    ner_model,
    ner_converter,
    reDL
])
"""sentenceDetector,
pos_tagger,
    dependency_parser,
    re_filter,
"""
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[22]: &#39;sentenceDetector,\npos_tagger,\n    dependency_parser,\n    re_filter,\n&#39;</div>

# %%
text='''
This INTELLECTUAL PROPERTY AGREEMENT (this "Agreement"), dated as of December 31, 2018 (the "Effective Date") is entered into by and between Armstrong Flooring, Inc., a Delaware corporation ("Seller") and AFI Licensing LLC, a Delaware limited liability company ("Licensing" and together with Seller, "Arizona") and AHF Holding, Inc. (formerly known as Tarzan HoldCo, Inc.), a Delaware corporation ("Buyer") and Armstrong Hardwood Flooring Company, a Tennessee corporation (the "Company" and together with Buyer the "Buyer Entities") (each of Arizona on the one hand and the Buyer Entities on the other hand, a "Party" and collectively, the "Parties").
'''

data = spark.createDataFrame([[text]]).toDF("text")
model = pipeline.fit(data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lmodel = LightPipeline(model)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import pandas as pd

def get_relations_df (results, col='relations'):
  rel_pairs=[]
  for rel in results[0][col]:
      rel_pairs.append((
          rel.result, 
          rel.metadata['entity1'], 
          rel.metadata['entity1_begin'],
          rel.metadata['entity1_end'],
          rel.metadata['chunk1'], 
          rel.metadata['entity2'],
          rel.metadata['entity2_begin'],
          rel.metadata['entity2_end'],
          rel.metadata['chunk2'], 
          rel.metadata['confidence']
      ))

  rel_df = pd.DataFrame(rel_pairs, columns=['relation','entity1','entity1_begin','entity1_end','chunk1','entity2','entity2_begin','entity2_end','chunk2', 'confidence'])

  return rel_df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
results = lmodel.fullAnnotate(text)
rel_df = get_relations_df (results)
rel_df = rel_df[rel_df['relation']!='no_rel']
print(rel_df.to_string(index=False))
print()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">            relation entity1 entity1_begin entity1_end                              chunk1 entity2 entity2_begin entity2_end                  chunk2 confidence
#             dated_as     DOC             6          36     INTELLECTUAL PROPERTY AGREEMENT EFFDATE            70          86       December 31, 2018 0.98433626
#            signed_by     DOC             6          36     INTELLECTUAL PROPERTY AGREEMENT   PARTY           142         164 Armstrong Flooring, Inc 0.60404813
#            has_alias   PARTY           142         164             Armstrong Flooring, Inc   ALIAS           193         198                  Seller 0.96357507
#            has_alias   PARTY           206         222                   AFI Licensing LLC   ALIAS           264         272               Licensing  0.9546678
#            has_alias   PARTY           316         331                    AHF Holding, Inc   ALIAS           612         616                   Party  0.5387175
#            has_alias   PARTY           316         331                    AHF Holding, Inc   ALIAS           642         648                 Parties  0.5387175
# has_collective_alias   ALIAS           400         404                               Buyer   ALIAS           612         616                   Party  0.5539445
# has_collective_alias   ALIAS           400         404                               Buyer   ALIAS           642         648                 Parties  0.5539445
#            has_alias   PARTY           412         446 Armstrong Hardwood Flooring Company   ALIAS           479         485                 Company 0.92106056
#            has_alias   PARTY           412         446 Armstrong Hardwood Flooring Company   ALIAS           612         616                   Party 0.58123946
#            has_alias   PARTY           412         446 Armstrong Hardwood Flooring Company   ALIAS           642         648                 Parties 0.58123946
# has_collective_alias   ALIAS           506         510                               Buyer   ALIAS           517         530          Buyer Entities 0.63492435
# has_collective_alias   ALIAS           506         510                               Buyer   ALIAS           612         616                   Party  0.6483803
# has_collective_alias   ALIAS           506         510                               Buyer   ALIAS           642         648                 Parties  0.6483803
# has_collective_alias   ALIAS           517         530                      Buyer Entities   ALIAS           612         616                   Party  0.6970743
# has_collective_alias   ALIAS           517         530                      Buyer Entities   ALIAS           642         648                 Parties  0.6970743
#
# </div>

# %% [markdown]
# ###Visualization using Neo4j and graphistry

# %%
def update_data(query, rows, batch_size = 10000):
    # Function to handle the updating the Neo4j database in batch mode.
    # Especially for large datasets.
    total = 0
    batch = 0
    start = time.time()
    result = None

    while batch * batch_size < len(rows):

        res = conn.query(query, parameters={'rows': rows[batch*batch_size:(batch+1)*batch_size].to_dict('records')})
        total += res[0]['total']
        batch += 1
        result = {"total":total, "batches":batch, "time":time.time()-start}
        print(result)

    return result
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def add_ners_rels(rows, batch_size=10000):
    # Adds NER nodes to the Neo4j graph as a batch job.
    query = '''
    //chunk1 NERs
    UNWIND $rows as row
    MERGE(n1:NER{name:row.chunk1}) ON CREATE SET n1.type=row.entity1

    //chunk2 NERs
    MERGE(n2:NER{name:row.chunk2}) ON CREATE SET n2.type=row.entity2

    //connect NERs
    WITH row, n1, n2
    MERGE (n1)-[:LINKS{relation:row.relation}]->(n2)
    RETURN count(*) as total  
    '''

    return update_data(query, rows, batch_size)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
add_ners_rels(rel_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#39;total&#39;: 16, &#39;batches&#39;: 1, &#39;time&#39;: 1.9607667922973633}
# Out[58]: {&#39;total&#39;: 16, &#39;batches&#39;: 1, &#39;time&#39;: 1.9607667922973633}</div>

# %% [markdown]
# ![9.png](/files/FINLEG/9.png)

# %%
rel_df.to_csv('/dbfs/relations.csv',index=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import pandas as pd
matches_df = pd.read_csv('/dbfs/relations.csv')
matches_df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[60]: Index([&#39;relation&#39;, &#39;entity1&#39;, &#39;entity1_begin&#39;, &#39;entity1_end&#39;, &#39;chunk1&#39;,
#        &#39;entity2&#39;, &#39;entity2_begin&#39;, &#39;entity2_end&#39;, &#39;chunk2&#39;, &#39;confidence&#39;],
#       dtype=&#39;object&#39;)</div>

# %%
(graphistry
  .edges(matches_df, 'chunk1',
        'chunk2')
  .nodes(matches_df, 'relation','entity1','entity2')
).plot()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[61]: </div>
#             <iframe id="3289d725-ac98-43de-aa4a-c63a9d0334a1" src="https://hub.graphistry.com/graph/graph.html?dataset=959188417ace4b2e9b64f1f340fc1d50&type=arrow&viztoken=6d283662-738e-4033-ba02-7853c32c79ac&usertag=cce73edc-pygraphistry-0.28.3&splashAfter=1665992163&info=true"
#                     allowfullscreen="true" webkitallowfullscreen="true" mozallowfullscreen="true"
#                     oallowfullscreen="true" msallowfullscreen="true"
#                     style="width:100%; height:500px; border: 1px solid #DDD; overflow: hidden"
#
#             >
#             </iframe>
#
#             <script>
#                 try {
#                   $("#3289d725-ac98-43de-aa4a-c63a9d0334a1").bind('mousewheel', function(e) { e.preventDefault(); });
#                 } catch (e) { console.error('exn catching scroll', e); }
#             </script>
