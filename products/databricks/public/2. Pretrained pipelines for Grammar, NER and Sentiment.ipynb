# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)

# %% [markdown]
# # 2. Pretrained pipelines for Grammar, NER and Sentiment

# %%
import sparknlp

print("Spark NLP version", sparknlp.version())

print("Apache Spark version:", spark.version)

spark
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Spark NLP version 4.2.4
# Apache Spark version: 3.1.2
# Out[1]: </div>
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=7956323724731612#setting/sparkui/0616-152819-zhyjt0vc/driver-6106925149926492024">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://10.139.64.4:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Using Pretrained Pipelines

# %% [markdown]
# https://github.com/JohnSnowLabs/spark-nlp-models
#
# https://nlp.johnsnowlabs.com/models

# %%
from sparknlp.pretrained import ResourceDownloader
ResourceDownloader.showPublicPipelines(lang="en")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------------------------------------------------------------------------------------------------+------+---------+
#  Pipeline                                                                                                    | lang | version |
# +-------------------------------------------------------------------------------------------------------------+------+---------+
#  dependency_parse                                                                                            |  en  | 2.0.2   |
#  check_spelling                                                                                              |  en  | 2.1.0   |
#  match_datetime                                                                                              |  en  | 2.1.0   |
#  match_pattern                                                                                               |  en  | 2.1.0   |
#  clean_pattern                                                                                               |  en  | 2.1.0   |
#  clean_stop                                                                                                  |  en  | 2.1.0   |
#  match_phrases                                                                                               |  en  | 2.1.0   |
#  movies_sentiment_analysis                                                                                   |  en  | 2.1.0   |
#  explain_document_ml                                                                                         |  en  | 2.1.0   |
#  clean_slang                                                                                                 |  en  | 2.1.0   |
#  analyze_sentiment                                                                                           |  en  | 2.1.0   |
#  explain_document_dl                                                                                         |  en  | 2.1.0   |
#  explain_document_dl_fast                                                                                    |  en  | 2.1.0   |
#  recognize_entities_dl                                                                                       |  en  | 2.1.0   |
#  recognize_entities_bert                                                                                     |  en  | 2.1.0   |
#  explain_document_dl_noncontrib                                                                              |  en  | 2.1.0   |
#  explain_document_dl_fast_noncontrib                                                                         |  en  | 2.1.0   |
#  recognize_entities_dl_noncontrib                                                                            |  en  | 2.1.0   |
#  recognize_entities_bert_noncontrib                                                                          |  en  | 2.1.0   |
#  analyze_sentiment                                                                                           |  en  | 2.1.0   |
#  movies_sentiment_analysis                                                                                   |  en  | 2.1.0   |
#  explain_document_ml                                                                                         |  en  | 2.1.0   |
#  analyze_sentiment                                                                                           |  en  | 2.1.0   |
#  dependency_parse                                                                                            |  en  | 2.1.0   |
#  onto_recognize_entities_sm                                                                                  |  en  | 2.1.0   |
#  onto_recognize_entities_lg                                                                                  |  en  | 2.1.0   |
#  match_chunks                                                                                                |  en  | 2.1.0   |
#  explain_document_dl_noncontrib                                                                              |  en  | 2.1.0   |
#  explain_document_dl                                                                                         |  en  | 2.1.0   |
#  match_chunks                                                                                                |  en  | 2.1.0   |
#  match_chunks                                                                                                |  en  | 2.2.0   |
#  onto_recognize_entities_lg                                                                                  |  en  | 2.4.0   |
#  onto_recognize_entities_sm                                                                                  |  en  | 2.4.0   |
#  check_spelling                                                                                              |  en  | 2.4.0   |
#  match_datetime                                                                                              |  en  | 2.4.0   |
#  clean_pattern                                                                                               |  en  | 2.4.0   |
#  match_chunks                                                                                                |  en  | 2.4.0   |
#  recognize_entities_dl                                                                                       |  en  | 2.4.0   |
#  explain_document_ml                                                                                         |  en  | 2.4.0   |
#  dependency_parse                                                                                            |  en  | 2.4.0   |
#  clean_stop                                                                                                  |  en  | 2.4.0   |
#  explain_document_dl                                                                                         |  en  | 2.4.0   |
#  match_phrases                                                                                               |  en  | 2.4.0   |
#  clean_slang                                                                                                 |  en  | 2.4.0   |
#  analyze_sentiment                                                                                           |  en  | 2.4.0   |
#  match_pattern                                                                                               |  en  | 2.4.0   |
#  match_datetime                                                                                              |  en  | 2.4.0   |
#  explain_document_dl                                                                                         |  en  | 2.4.3   |
#  recognize_entities_dl                                                                                       |  en  | 2.4.3   |
#  recognize_entities_bert                                                                                     |  en  | 2.4.3   |
#  text_cleaning                                                                                               |  en  | 2.4.4   |
#  clean_stop                                                                                                  |  en  | 2.4.4   |
#  analyze_sentimentdl_use_imdb                                                                                |  en  | 2.5.0   |
#  analyze_sentimentdl_glove_imdb                                                                              |  en  | 2.5.0   |
#  check_spelling_dl                                                                                           |  en  | 2.5.0   |
#  analyze_sentimentdl_use_imdb                                                                                |  en  | 2.5.0   |
#  analyze_sentimentdl_use_twitter                                                                             |  en  |

# %%
from sparknlp.pretrained import PretrainedPipeline
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
testDoc = '''Peter is a very good persn.
My life in Russia is very intersting.
John and Peter are brthers. However they don't support each other that much.
Lucas Nogal Dunbercker is no longer happy. He has a good car though.
Europe is very culture rich. There are huge churches! and big houses!
'''
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
testDoc
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: &#34;Peter is a very good persn.\nMy life in Russia is very intersting.\nJohn and Peter are brthers. However they don&#39;t support each other that much.\nLucas Nogal Dunbercker is no longer happy. He has a good car though.\nEurope is very culture rich. There are huge churches! and big houses!\n&#34;</div>

# %% [markdown]
# ### Explain Document DL

# %% [markdown]
# **Stages**
# - DocumentAssembler
# - SentenceDetector
# - Tokenizer
# - NER (NER with GloVe 100D embeddings, CoNLL2003 dataset)
# - Lemmatizer
# - Stemmer
# - Part of Speech
# - SpellChecker (Norvig)

# %%
pipeline_dl = PretrainedPipeline('explain_document_dl', lang='en')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">explain_document_dl download started this may take some time.
# Approx size to download 169.4 MB
# [OK!]
# </div>

# %%
pipeline_dl.model.stages
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: [document_7939d5bf1083,
#  SENTENCE_05265b07c745,
#  REGEX_TOKENIZER_c5c312143f63,
#  SPELL_e4ea67180337,
#  LEMMATIZER_c62ad8f355f9,
#  STEMMER_ba49f7631065,
#  POS_d01c734956fe,
#  WORD_EMBEDDINGS_MODEL_48cffc8b9a76,
#  NerDLModel_d4424c9af5f4,
#  NER_CONVERTER_a81db9af2d23]</div>

# %%
pipeline_dl.model.stages[-2].getStorageRef()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: &#39;glove_100d&#39;</div>

# %%
pipeline_dl.model.stages[-2].getClasses()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: [&#39;O&#39;, &#39;B-ORG&#39;, &#39;B-LOC&#39;, &#39;B-PER&#39;, &#39;I-PER&#39;, &#39;I-ORG&#39;, &#39;B-MISC&#39;, &#39;I-LOC&#39;, &#39;I-MISC&#39;]</div>

# %%
result = pipeline_dl.annotate(testDoc)

result.keys()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: dict_keys([&#39;entities&#39;, &#39;stem&#39;, &#39;checked&#39;, &#39;lemma&#39;, &#39;document&#39;, &#39;pos&#39;, &#39;token&#39;, &#39;ner&#39;, &#39;embeddings&#39;, &#39;sentence&#39;])</div>

# %%
result['entities']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: [&#39;Peter&#39;, &#39;Russia&#39;, &#39;John&#39;, &#39;Peter&#39;, &#39;Lucas Nogal Dunbercker&#39;, &#39;Europe&#39;]</div>

# %%
import pandas as pd

df = pd.DataFrame({'token':result['token'], 'ner_label':result['ner'],
                      'spell_corrected':result['checked'], 'POS':result['pos'],
                      'lemmas':result['lemma'], 'stems':result['stem']})

df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>token</th>
#       <th>ner_label</th>
#       <th>spell_corrected</th>
#       <th>POS</th>
#       <th>lemmas</th>
#       <th>stems</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Peter</td>
#       <td>B-PER</td>
#       <td>Peter</td>
#       <td>NNP</td>
#       <td>Peter</td>
#       <td>peter</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>is</td>
#       <td>O</td>
#       <td>is</td>
#       <td>VBZ</td>
#       <td>be</td>
#       <td>i</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>a</td>
#       <td>O</td>
#       <td>a</td>
#       <td>DT</td>
#       <td>a</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>very</td>
#       <td>O</td>
#       <td>very</td>
#       <td>RB</td>
#       <td>very</td>
#       <td>veri</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>good</td>
#       <td>O</td>
#       <td>good</td>
#       <td>JJ</td>
#       <td>good</td>
#       <td>good</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>persn</td>
#       <td>O</td>
#       <td>person</td>
#       <td>NN</td>
#       <td>person</td>
#       <td>person</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>.</td>
#       <td>O</td>
#       <td>.</td>
#       <td>.</td>
#       <td>.</td>
#       <td>.</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>My</td>
#       <td>O</td>
#       <td>My</td>
#       <td>PRP$</td>
#       <td>My</td>
#       <td>my</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>life</td>
#       <td>O</td>
#       <td>life</td>
#       <td>NN</td>
#       <td>life</td>
#       <td>life</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>in</td>
#       <td>O</td>
#       <td>in</td>
#       <td>IN</td>
#       <td>in</td>
#       <td>in</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Russia</td>
#       <td>B-LOC</td>
#       <td>Russia</td>
#       <td>NNP</td>
#       <td>Russia</td>
#       <td>russia</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>is</td>
#       <td>O</td>
#       <td>is</td>
#       <td>VBZ</td>
#       <td>be</td>
#       <td>i</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>very</td>
#       <td>O</td>
#       <td>very</td>
#       <td>RB</td>
#       <td>very</td>
#       <td>veri</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>intersting</td>
#       <td>O</td>
#       <td>interesting</td>
#       <td>VBG</td>
#       <td>interest</td>
#       <td>interest</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>.</td>
#       <td>O</td>
#       <td>.</td>
#       <td>.</td>
#       <td>.</td>
#       <td>.</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>John</td>
#       <td>B-PER</td>
#       <td>John</td>
#       <td>NNP</td>
#       <td>John</td>
#       <td>john</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>and</td>
#       <td>O</td>
#       <td>and</td>
#       <td>CC</td>
#       <td>and</td>
#       <td>and</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Peter</td>
#       <td>B-PER</td>
#       <td>Peter</td>
#       <td>NNP</td>
#       <td>Peter</td>
#       <td>peter</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>are</td>
#       <td>O</td>
#       <td>are</td>
#       <td>VBP</td>
#       <td>be</td>
#       <td>ar</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>brthers</td>
#       <td>O</td>
#       <td>brothers</td>
#       <td>NNS</td>
#       <td>brother</td>
#       <td>brother</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>.</td>
#       <td>O</td>
#       <td>.</td>
#       <td>.</td>
#       <td>.</td>
#       <td>.</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>However</td>
#       <td>O</td>
#       <td>However</td>
#       <td>RB</td>
#       <td>However</td>
#       <td>howev</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>they</td>
#       <td>O</td>
#       <td>they</td>
#       <td>PRP</td>
#       <td>they</td>
#       <td>thei</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>don't</td>
#       <td>O</td>
#       <td>don't</td>
#       <td>VBP</td>
#       <td>don't</td>
#       <td>don't</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>support</td>
#       <td>O</td>
#       <td>support</td>
#       <td>VB</td>
#       <td>support</td>
#       <td>support</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>each</td>
#       <td>O</td>
#       <td>each</td>
#       <td>DT</td>
#       <td>each</td>
#       <td>each</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>other</td>
#       <td>O</td>
#       <td>other</td>
#       <td>JJ</td>
#       <td>other</td>
#       <td>other</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>that</td>
#       <td>O</td>
#       <td>that</td>
#       <td>IN</td>
#       <td>that</td>
#       <td>that</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>much</td>
#       <td>O</td>
#       <td>much</td>
#       <td>JJ</td>
#       <td>much</td>
#       <td>much</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>.</td>
#       <td>O</td>
#       <td>.</td>
#       <td>.</td>
#       <td>.</td>
#       <td>.</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>Lucas</td>
#       <td>B-ORG</td>
#       <td>Lucas</td>
#       <td>NNP</td>
#       <td>Lucas</td>
#       <td>luca</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>Nogal</td>
#       <td>I-ORG</td>
#       <td>Nogal</td>
#       <td>NNP</td>
#       <td>Nogal</td>
#       <td>nogal</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>Dunbercker</td>
#       <td>I-ORG</td>
#       <td>Dunbercker</td>
#       <td>NNP</td>
#       <td>Dunbercker</td>
#       <td>dunberck</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>is</td>
#       <td>O</td>
#       <td>is</td>
#       <td>VBZ</td>
#       <td>be</td>
#       <td>i</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>no</td>
#       <td>O</td>
#       <td>no</td>
#       <td>DT</td>
#       <td>no</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>longer</td>
#       <td>O</td>
#       <td>longer</td>
#       <td>RB</td>
#       <td>long</td>
#       <td>longer</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>happy</td>
#       <td>O</td>
#       <td>happy</td>
#       <td>JJ</td>
#       <td>happy</td>
#       <td>happi</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>.</td>
#       <td>O</td>
#       <td>.</td>
#       <td>.</td>
#       <td>.</td>
#       <td>.</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>He</td>
#       <td>O</td>
#       <td>He</td>
#       <td>PRP</td>
#       <td>He</td>
#       <td>he</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>has</td>
#       <td>O</td>
#       <td>has</td>
#       <td>VBZ</td>
#       <td>have</td>
#       <td>ha</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>a</td>
#       <td>O</td>
#       <td>a</td>
#       <td>DT</td>
#       <td>a</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>good</td>
#       <td>O</td>
#       <td>good</td>
#       <td>JJ</td>
#       <td>good</td>
#       <td>good</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>car</td>
#       <td>O</td>
#       <td>car</td>
#       <td>NN</td>
#       <td>car</td>
#       <td>car</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>though</td>
#       <td>O</td>
#       <td>though</td>
#       <td>IN</td>
#       <td>though</td>
#       <td>though</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>.</td>
#       <td>O</td>
#       <td>.</td>
#       <td>.</td>
#       <td>.</td>
#       <td>.</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>Europe</td>
#       <td>B-LOC</td>
#       <td>Europe</td>
#       <td>NNP</td>
#       <td>Europe</td>
#       <td>europ</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>is</td>
#       <td>O</td>
#       <td>is</td>
#       <td>VBZ</td>
#       <td>be</td>
#       <td>i</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>very</td>
#       <td>O</td>
#       <td>very</td>
#       <td>RB</td>
#       <td>very</td>
#       <td>veri</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>culture</td>
#       <td>O</td>
#       <td>culture</td>
#       <td>RB</td>
#       <td>culture</td>
#       <td>cultur</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>rich

# %% [markdown]
# ### Recognize Entities DL

# %%
recognize_entities = PretrainedPipeline('recognize_entities_dl', lang='en')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">recognize_entities_dl download started this may take some time.
# Approx size to download 160.1 MB
# [OK!]
# </div>

# %%
testDoc = '''
Peter is a very good persn.
My life in Russia is very intersting.
John and Peter are brthers. However they don't support each other that much.
Lucas Nogal Dunbercker is no longer happy. He has a good car though.
Europe is very culture rich. There are huge churches! and big houses!
'''

result = recognize_entities.annotate(testDoc)

list(zip(result['token'], result['ner']))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: [(&#39;Peter&#39;, &#39;B-PER&#39;),
#  (&#39;is&#39;, &#39;O&#39;),
#  (&#39;a&#39;, &#39;O&#39;),
#  (&#39;very&#39;, &#39;O&#39;),
#  (&#39;good&#39;, &#39;O&#39;),
#  (&#39;persn&#39;, &#39;O&#39;),
#  (&#39;.&#39;, &#39;O&#39;),
#  (&#39;My&#39;, &#39;O&#39;),
#  (&#39;life&#39;, &#39;O&#39;),
#  (&#39;in&#39;, &#39;O&#39;),
#  (&#39;Russia&#39;, &#39;B-LOC&#39;),
#  (&#39;is&#39;, &#39;O&#39;),
#  (&#39;very&#39;, &#39;O&#39;),
#  (&#39;intersting&#39;, &#39;O&#39;),
#  (&#39;.&#39;, &#39;O&#39;),
#  (&#39;John&#39;, &#39;B-PER&#39;),
#  (&#39;and&#39;, &#39;O&#39;),
#  (&#39;Peter&#39;, &#39;B-PER&#39;),
#  (&#39;are&#39;, &#39;O&#39;),
#  (&#39;brthers&#39;, &#39;O&#39;),
#  (&#39;.&#39;, &#39;O&#39;),
#  (&#39;However&#39;, &#39;O&#39;),
#  (&#39;they&#39;, &#39;O&#39;),
#  (&#34;don&#39;t&#34;, &#39;O&#39;),
#  (&#39;support&#39;, &#39;O&#39;),
#  (&#39;each&#39;, &#39;O&#39;),
#  (&#39;other&#39;, &#39;O&#39;),
#  (&#39;that&#39;, &#39;O&#39;),
#  (&#39;much&#39;, &#39;O&#39;),
#  (&#39;.&#39;, &#39;O&#39;),
#  (&#39;Lucas&#39;, &#39;B-ORG&#39;),
#  (&#39;Nogal&#39;, &#39;I-ORG&#39;),
#  (&#39;Dunbercker&#39;, &#39;I-ORG&#39;),
#  (&#39;is&#39;, &#39;O&#39;),
#  (&#39;no&#39;, &#39;O&#39;),
#  (&#39;longer&#39;, &#39;O&#39;),
#  (&#39;happy&#39;, &#39;O&#39;),
#  (&#39;.&#39;, &#39;O&#39;),
#  (&#39;He&#39;, &#39;O&#39;),
#  (&#39;has&#39;, &#39;O&#39;),
#  (&#39;a&#39;, &#39;O&#39;),
#  (&#39;good&#39;, &#39;O&#39;),
#  (&#39;car&#39;, &#39;O&#39;),
#  (&#39;though&#39;, &#39;O&#39;),
#  (&#39;.&#39;, &#39;O&#39;),
#  (&#39;Europe&#39;, &#39;B-LOC&#39;),
#  (&#39;is&#39;, &#39;O&#39;),
#  (&#39;very&#39;, &#39;O&#39;),
#  (&#39;culture&#39;, &#39;O&#39;),
#  (&#39;rich&#39;, &#39;O&#39;),
#  (&#39;.&#39;, &#39;O&#39;),
#  (&#39;There&#39;, &#39;O&#39;),
#  (&#39;are&#39;, &#39;O&#39;),
#  (&#39;huge&#39;, &#39;O&#39;),
#  (&#39;churches&#39;, &#39;O&#39;),
#  (&#39;!&#39;, &#39;O&#39;),
#  (&#39;and&#39;, &#39;O&#39;),
#  (&#39;big&#39;, &#39;O&#39;),
#  (&#39;houses&#39;, &#39;O&#39;),
#  (&#39;!&#39;, &#39;O&#39;)]</div>

# %% [markdown]
# ### Clean Stop Words

# %%
clean_stop = PretrainedPipeline('clean_stop', lang='en')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">clean_stop download started this may take some time.
# Approx size to download 22.8 KB
# [OK!]
# </div>

# %%
result = clean_stop.annotate(testDoc)
result.keys()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: dict_keys([&#39;document&#39;, &#39;sentence&#39;, &#39;token&#39;, &#39;cleanTokens&#39;])</div>

# %%
' '.join(result['cleanTokens'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: &#34;Peter good persn . life Russia intersting . John Peter brthers . don&#39;t support . Lucas Nogal Dunbercker longer happy . good car . Europe culture rich . huge churches ! big houses !&#34;</div>

# %% [markdown]
# ### Spell Checker
#
# (Norvig Algo)
#
# ref: https://norvig.com/spell-correct.html

# %%
spell_checker = PretrainedPipeline('check_spelling', lang='en')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">check_spelling download started this may take some time.
# Approx size to download 913.5 KB
# [OK!]
# </div>

# %%
testDoc = '''
Peter is a very good persn.
My life in Russia is very intersting.
John and Peter are brthers. However they don't support each other that much.
Lucas Nogal Dunbercker is no longer happy. He has a good car though.
Europe is very culture rich. There are huge churches! and big houses!
'''

result = spell_checker.annotate(testDoc)

result.keys()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: dict_keys([&#39;document&#39;, &#39;sentence&#39;, &#39;token&#39;, &#39;checked&#39;])</div>

# %%
list(zip(result['token'], result['checked']))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: [(&#39;Peter&#39;, &#39;Peter&#39;),
#  (&#39;is&#39;, &#39;is&#39;),
#  (&#39;a&#39;, &#39;a&#39;),
#  (&#39;very&#39;, &#39;very&#39;),
#  (&#39;good&#39;, &#39;good&#39;),
#  (&#39;persn&#39;, &#39;person&#39;),
#  (&#39;.&#39;, &#39;.&#39;),
#  (&#39;My&#39;, &#39;My&#39;),
#  (&#39;life&#39;, &#39;life&#39;),
#  (&#39;in&#39;, &#39;in&#39;),
#  (&#39;Russia&#39;, &#39;Russia&#39;),
#  (&#39;is&#39;, &#39;is&#39;),
#  (&#39;very&#39;, &#39;very&#39;),
#  (&#39;intersting&#39;, &#39;interesting&#39;),
#  (&#39;.&#39;, &#39;.&#39;),
#  (&#39;John&#39;, &#39;John&#39;),
#  (&#39;and&#39;, &#39;and&#39;),
#  (&#39;Peter&#39;, &#39;Peter&#39;),
#  (&#39;are&#39;, &#39;are&#39;),
#  (&#39;brthers&#39;, &#39;brothers&#39;),
#  (&#39;.&#39;, &#39;.&#39;),
#  (&#39;However&#39;, &#39;However&#39;),
#  (&#39;they&#39;, &#39;they&#39;),
#  (&#34;don&#39;t&#34;, &#34;don&#39;t&#34;),
#  (&#39;support&#39;, &#39;support&#39;),
#  (&#39;each&#39;, &#39;each&#39;),
#  (&#39;other&#39;, &#39;other&#39;),
#  (&#39;that&#39;, &#39;that&#39;),
#  (&#39;much&#39;, &#39;much&#39;),
#  (&#39;.&#39;, &#39;.&#39;),
#  (&#39;Lucas&#39;, &#39;Lucas&#39;),
#  (&#39;Nogal&#39;, &#39;Nogal&#39;),
#  (&#39;Dunbercker&#39;, &#39;Dunbercker&#39;),
#  (&#39;is&#39;, &#39;is&#39;),
#  (&#39;no&#39;, &#39;no&#39;),
#  (&#39;longer&#39;, &#39;longer&#39;),
#  (&#39;happy&#39;, &#39;happy&#39;),
#  (&#39;.&#39;, &#39;.&#39;),
#  (&#39;He&#39;, &#39;He&#39;),
#  (&#39;has&#39;, &#39;has&#39;),
#  (&#39;a&#39;, &#39;a&#39;),
#  (&#39;good&#39;, &#39;good&#39;),
#  (&#39;car&#39;, &#39;car&#39;),
#  (&#39;though&#39;, &#39;though&#39;),
#  (&#39;.&#39;, &#39;.&#39;),
#  (&#39;Europe&#39;, &#39;Europe&#39;),
#  (&#39;is&#39;, &#39;is&#39;),
#  (&#39;very&#39;, &#39;very&#39;),
#  (&#39;culture&#39;, &#39;culture&#39;),
#  (&#39;rich&#39;, &#39;rich&#39;),
#  (&#39;.&#39;, &#39;.&#39;),
#  (&#39;There&#39;, &#39;There&#39;),
#  (&#39;are&#39;, &#39;are&#39;),
#  (&#39;huge&#39;, &#39;huge&#39;),
#  (&#39;churches&#39;, &#39;churches&#39;),
#  (&#39;!&#39;, &#39;!&#39;),
#  (&#39;and&#39;, &#39;and&#39;),
#  (&#39;big&#39;, &#39;big&#39;),
#  (&#39;houses&#39;, &#39;houses&#39;),
#  (&#39;!&#39;, &#39;!&#39;)]</div>

# %% [markdown]
# ### Parsing a list of texts

# %%
testDoc_list = ['French author who helped pioner the science-fiction genre.',
'Verne wrate about space, air, and underwater travel before navigable aircrast',
'Practical submarines were invented, and before any means of space travel had been devised.']

testDoc_list
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: [&#39;French author who helped pioner the science-fiction genre.&#39;,
#  &#39;Verne wrate about space, air, and underwater travel before navigable aircrast&#39;,
#  &#39;Practical submarines were invented, and before any means of space travel had been devised.&#39;]</div>

# %%
pipeline_dl = PretrainedPipeline('explain_document_dl', lang='en')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">explain_document_dl download started this may take some time.
# Approx size to download 169.4 MB
# [OK!]
# </div>

# %%
result_list = pipeline_dl.annotate(testDoc_list)

len(result_list)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[23]: 3</div>

# %%
result_list[0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: {&#39;entities&#39;: [&#39;French&#39;],
#  &#39;stem&#39;: [&#39;french&#39;,
#   &#39;author&#39;,
#   &#39;who&#39;,
#   &#39;help&#39;,
#   &#39;pioneer&#39;,
#   &#39;the&#39;,
#   &#39;sciencefict&#39;,
#   &#39;genr&#39;,
#   &#39;.&#39;],
#  &#39;checked&#39;: [&#39;French&#39;,
#   &#39;author&#39;,
#   &#39;who&#39;,
#   &#39;helped&#39;,
#   &#39;pioneer&#39;,
#   &#39;the&#39;,
#   &#39;sciencefiction&#39;,
#   &#39;genre&#39;,
#   &#39;.&#39;],
#  &#39;lemma&#39;: [&#39;French&#39;,
#   &#39;author&#39;,
#   &#39;who&#39;,
#   &#39;help&#39;,
#   &#39;pioneer&#39;,
#   &#39;the&#39;,
#   &#39;sciencefiction&#39;,
#   &#39;genre&#39;,
#   &#39;.&#39;],
#  &#39;document&#39;: [&#39;French author who helped pioner the science-fiction genre.&#39;],
#  &#39;pos&#39;: [&#39;JJ&#39;, &#39;NN&#39;, &#39;WP&#39;, &#39;VBD&#39;, &#39;NN&#39;, &#39;DT&#39;, &#39;NN&#39;, &#39;NN&#39;, &#39;.&#39;],
#  &#39;token&#39;: [&#39;French&#39;,
#   &#39;author&#39;,
#   &#39;who&#39;,
#   &#39;helped&#39;,
#   &#39;pioner&#39;,
#   &#39;the&#39;,
#   &#39;science-fiction&#39;,
#   &#39;genre&#39;,
#   &#39;.&#39;],
#  &#39;ner&#39;: [&#39;B-MISC&#39;, &#39;O&#39;, &#39;O&#39;, &#39;O&#39;, &#39;O&#39;, &#39;O&#39;, &#39;O&#39;, &#39;O&#39;, &#39;O&#39;],
#  &#39;embeddings&#39;: [&#39;French&#39;,
#   &#39;author&#39;,
#   &#39;who&#39;,
#   &#39;helped&#39;,
#   &#39;pioner&#39;,
#   &#39;the&#39;,
#   &#39;science-fiction&#39;,
#   &#39;genre&#39;,
#   &#39;.&#39;],
#  &#39;sentence&#39;: [&#39;French author who helped pioner the science-fiction genre.&#39;]}</div>

# %% [markdown]
# ### Using fullAnnotate to get more details

# %% [markdown]
# ```
# annotatorType: String,
# begin: Int,
# end: Int,
# result: String, (this is what annotate returns)
# metadata: Map[String, String],
# embeddings: Array[Float]
# ```

# %%
text = 'Peter Parker is a nice guy and lives in New York'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# pipeline_dl >> explain_document_dl

detailed_result = pipeline_dl.fullAnnotate(text)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
detailed_result
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[27]: [{&#39;entities&#39;: [Annotation(chunk, 0, 11, Peter Parker, {&#39;entity&#39;: &#39;PER&#39;, &#39;sentence&#39;: &#39;0&#39;, &#39;chunk&#39;: &#39;0&#39;}),
#    Annotation(chunk, 40, 47, New York, {&#39;entity&#39;: &#39;LOC&#39;, &#39;sentence&#39;: &#39;0&#39;, &#39;chunk&#39;: &#39;1&#39;})],
#   &#39;stem&#39;: [Annotation(token, 0, 4, peter, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 6, 11, parker, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 13, 14, i, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 16, 16, a, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 18, 21, nice, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 23, 25, gui, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 27, 29, and, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 31, 35, live, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 37, 38, in, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 40, 42, new, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 44, 47, york, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;})],
#   &#39;checked&#39;: [Annotation(token, 0, 4, Peter, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 6, 11, Parker, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 13, 14, is, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 16, 16, a, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 18, 21, nice, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 23, 25, guy, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 27, 29, and, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 31, 35, lives, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 37, 38, in, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 40, 42, New, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 44, 47, York, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;})],
#   &#39;lemma&#39;: [Annotation(token, 0, 4, Peter, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 6, 11, Parker, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 13, 14, be, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 16, 16, a, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 18, 21, nice, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 23, 25, guy, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 27, 29, and, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 31, 35, life, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 37, 38, in, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 40, 42, New, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 44, 47, York, {&#39;confidence&#39;: &#39;1.0&#39;, &#39;sentence&#39;: &#39;0&#39;})],
#   &#39;document&#39;: [Annotation(document, 0, 47, Peter Parker is a nice guy and lives in New York, {})],
#   &#39;pos&#39;: [Annotation(pos, 0, 4, NNP, {&#39;word&#39;: &#39;Peter&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(pos, 6, 11, NNP, {&#39;word&#39;: &#39;Parker&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(pos, 13, 14, VBZ, {&#39;word&#39;: &#39;is&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(pos, 16, 16, DT, {&#39;word&#39;: &#39;a&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(pos, 18, 21, JJ, {&#39;word&#39;: &#39;nice&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(pos, 23, 25, NN, {&#39;word&#39;: &#39;guy&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(pos, 27, 29, CC, {&#39;word&#39;: &#39;and&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(pos, 31, 35, NNS, {&#39;word&#39;: &#39;lives&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(pos, 37, 38, IN, {&#39;word&#39;: &#39;in&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(pos, 40, 42, NNP, {&#39;word&#39;: &#39;New&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(pos, 44, 47, NNP, {&#39;word&#39;: &#39;York&#39;, &#39;sentence&#39;: &#39;0&#39;})],
#   &#39;token&#39;: [Annotation(token, 0, 4, Peter, {&#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 6, 11, Parker, {&#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 13, 14, is, {&#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 16, 16, a, {&#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 18, 21, nice, {&#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 23, 25, guy, {&#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 27, 29, and, {&#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 31, 35, lives, {&#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 37, 38, in, {&#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 40, 42, New, {&#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(token, 44, 47, York, {&#39;sentence&#39;: &#39;0&#39;})],
#   &#39;ner&#39;: [Annotation(named_entity, 0, 4, B-PER, {&#39;word&#39;: &#39;Peter&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(named_entity, 6, 11, I-PER, {&#39;word&#39;: &#39;Parker&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(named_entity, 13, 14, O, {&#39;word&#39;: &#39;is&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(named_entity, 16, 16, O, {&#39;word&#39;: &#39;a&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(named_entity, 18, 21, O, {&#39;word&#39;: &#39;nice&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(named_entity, 23, 25, O, {&#39;word&#39;: &#39;guy&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(named_entity, 27, 29, O, {&#39;word&#39;: &#39;and&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(named_entity, 31, 35, O, {&#39;word&#39;: &#39;lives&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(named_entity, 37, 38, O, {&#39;word&#39;: &#39;in&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(named_entity, 40, 42, B-LOC, {&#39;word&#39;: &#39;New&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(named_entity, 44, 47, I-LOC, {&#39;word&#39;: &#39;York&#39;, &#39;sentence&#39;: &#39;0&#39;})],
#   &#39;embeddings&#39;: [Annotation(word_embeddings, 0, 4, Peter, {&#39;isOOV&#39;: &#39;false&#39;, &#39;pieceId&#39;: &#39;-1&#39;, &#39;isWordStart&#39;: &#39;true&#39;, &#39;token&#39;: &#39;Peter&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(word_embeddings, 6, 11, Parker, {&#39;isOOV&#39;: &#39;false&#39;, &#39;pieceId&#39;: &#39;-1&#39;, &#39;isWordStart&#39;: &#39;true&#39;, &#39;token&#39;: &#39;Parker&#39;, &#39;sentence&#39;: &#39;0&#39;}),
#    Annotation(word_embeddings, 13, 14, is, {&#39;isOOV&#39;: &#39;false&#39;, &#39;pieceId&#39;: &#39;-1&#39;,

# %%
detailed_result[0]['entities']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[28]: [Annotation(chunk, 0, 11, Peter Parker, {&#39;entity&#39;: &#39;PER&#39;, &#39;sentence&#39;: &#39;0&#39;, &#39;chunk&#39;: &#39;0&#39;}),
#  Annotation(chunk, 40, 47, New York, {&#39;entity&#39;: &#39;LOC&#39;, &#39;sentence&#39;: &#39;0&#39;, &#39;chunk&#39;: &#39;1&#39;})]</div>

# %%
detailed_result[0]['entities'][0].result
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[29]: &#39;Peter Parker&#39;</div>

# %%
import pandas as pd

chunks=[]
entities=[]
for n in detailed_result[0]['entities']:
        
  chunks.append(n.result)
  entities.append(n.metadata['entity']) 
    
df = pd.DataFrame({'chunks':chunks, 'entities':entities})
df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[30]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>chunks</th>
#       <th>entities</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Peter Parker</td>
#       <td>PER</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>New York</td>
#       <td>LOC</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
tuples = []

for x,y,z in zip(detailed_result[0]["token"], detailed_result[0]["pos"], detailed_result[0]["ner"]):

  tuples.append((int(x.metadata['sentence']), x.result, x.begin, x.end, y.result, z.result))

df = pd.DataFrame(tuples, columns=['sent_id','token','start','end','pos', 'ner'])

df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[31]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sent_id</th>
#       <th>token</th>
#       <th>start</th>
#       <th>end</th>
#       <th>pos</th>
#       <th>ner</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>Peter</td>
#       <td>0</td>
#       <td>4</td>
#       <td>NNP</td>
#       <td>B-PER</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>Parker</td>
#       <td>6</td>
#       <td>11</td>
#       <td>NNP</td>
#       <td>I-PER</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>is</td>
#       <td>13</td>
#       <td>14</td>
#       <td>VBZ</td>
#       <td>O</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#       <td>a</td>
#       <td>16</td>
#       <td>16</td>
#       <td>DT</td>
#       <td>O</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0</td>
#       <td>nice</td>
#       <td>18</td>
#       <td>21</td>
#       <td>JJ</td>
#       <td>O</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0</td>
#       <td>guy</td>
#       <td>23</td>
#       <td>25</td>
#       <td>NN</td>
#       <td>O</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0</td>
#       <td>and</td>
#       <td>27</td>
#       <td>29</td>
#       <td>CC</td>
#       <td>O</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0</td>
#       <td>lives</td>
#       <td>31</td>
#       <td>35</td>
#       <td>NNS</td>
#       <td>O</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0</td>
#       <td>in</td>
#       <td>37</td>
#       <td>38</td>
#       <td>IN</td>
#       <td>O</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0</td>
#       <td>New</td>
#       <td>40</td>
#       <td>42</td>
#       <td>NNP</td>
#       <td>B-LOC</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>0</td>
#       <td>York</td>
#       <td>44</td>
#       <td>47</td>
#       <td>NNP</td>
#       <td>I-LOC</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Sentiment Analysis

# %% [markdown]
# #### Vivek algo
#
# paper: `Fast and accurate sentiment classification using an enhanced Naive Bayes model`
#
# https://arxiv.org/abs/1305.6143
#
# code `https://github.com/vivekn/sentiment`

# %%
sentiment = PretrainedPipeline('analyze_sentiment', lang='en')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">analyze_sentiment download started this may take some time.
# Approx size to download 4.9 MB
# [OK!]
# </div>

# %%
result = sentiment.annotate("The movie I watched today was not a good one")

result['sentiment']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[33]: [&#39;negative&#39;]</div>

# %% [markdown]
# #### DL version (trained on imdb)

# %% [markdown]
# `analyze_sentimentdl_use_imdb`: A pre-trained pipeline to classify IMDB reviews in neg and pos classes using tfhub_use embeddings.
#
# `analyze_sentimentdl_glove_imdb`: A pre-trained pipeline to classify IMDB reviews in neg and pos classes using glove_100d embeddings.

# %%
sentiment_imdb_glove = PretrainedPipeline('analyze_sentimentdl_glove_imdb', lang='en')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">analyze_sentimentdl_glove_imdb download started this may take some time.
# Approx size to download 155.3 MB
# [OK!]
# </div>

# %%
comment = '''
It's a very scary film but what impressed me was how true the film sticks to the original's tricks; it isn't filled with loud in-your-face jump scares, in fact, a lot of what makes this film scary is the slick cinematography and intricate shadow play. The use of lighting and creation of atmosphere is what makes this film so tense, which is why it's perfectly suited for those who like Horror movies but without the obnoxious gore.
'''
result = sentiment_imdb_glove.annotate(comment)

result['sentiment']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[35]: [&#39;pos&#39;]</div>

# %%
sentiment_imdb_glove.fullAnnotate(comment)[0]['sentiment']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[36]: [Annotation(category, 0, 433, pos, {&#39;sentence&#39;: &#39;0&#39;, &#39;pos&#39;: &#39;0.98675287&#39;, &#39;neg&#39;: &#39;0.013247096&#39;})]</div>

# %% [markdown]
# #### DL version (trained on twitter dataset)

# %%
sentiment_twitter = PretrainedPipeline('analyze_sentimentdl_use_twitter', lang='en')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">analyze_sentimentdl_use_twitter download started this may take some time.
# Approx size to download 935.1 MB
# [OK!]
# </div>

# %%
result = sentiment_twitter.annotate("The movie I watched today was a good one.")

result['sentiment']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[38]: [&#39;positive&#39;]</div>

# %%
sentiment_twitter.fullAnnotate("The movie I watched today was a good one.")[0]['sentiment']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[39]: [Annotation(category, 0, 40, positive, {&#39;sentence&#39;: &#39;0&#39;, &#39;positive&#39;: &#39;1.0&#39;, &#39;negative&#39;: &#39;0.0&#39;})]</div>

# %% [markdown]
# End of Notebook #
