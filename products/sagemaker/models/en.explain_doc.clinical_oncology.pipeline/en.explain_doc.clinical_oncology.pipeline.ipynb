# %% [markdown]
# ## 1. Subscribe to the model package

# %% [markdown]
# To subscribe to the model package:
# 1. Open the model package listing page <font color='red'> For Seller to update:[Title_of_your_product](Provide link to your marketplace listing of your product).</font>
# 1. On the AWS Marketplace listing, click on the **Continue to subscribe** button.
# 1. On the **Subscribe to this software** page, review and click on **"Accept Offer"** if you and your organization agrees with EULA, pricing, and support terms.
# 1. Once you click on **Continue to configuration button** and then choose a **region**, you will see a **Product Arn** displayed. This is the model package ARN that you need to specify while creating a deployable model using Boto3. Copy the ARN corresponding to your region and specify the same in the following cell.

# %% [markdown]
# ## Pipeline to Detect Oncology Entities, Assign Assertion Status and Find Relations
#
#
# - **Model**: `en.explain_doc.clinical_oncology.pipeline`
# - **Model Description**: This specialized oncology pipeline extracts oncological entities, assign assertion status to the extracted entities and establish relations between the extracted entities from the clinical documents.

# %%
model_package_arn = "<Customer to specify Model package ARN corresponding to their AWS region>"

# %%
import base64
import json
import uuid
from sagemaker import ModelPackage
import sagemaker as sage
from sagemaker import get_execution_role
import boto3
from IPython.display import Image, display
from PIL import Image as ImageEdit
import numpy as np
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
sagemaker_session = sage.Session()
s3_bucket = sagemaker_session.default_bucket()
region = sagemaker_session.boto_region_name
account_id = boto3.client("sts").get_caller_identity().get("Account")
role = get_execution_role()

sagemaker = boto3.client("sagemaker")
s3_client = sagemaker_session.boto_session.client("s3")
ecr = boto3.client("ecr")
sm_runtime = boto3.client("sagemaker-runtime")

# %% [markdown]
# ## 2. Create an endpoint and perform real-time inference

# %% [markdown]
# If you want to understand how real-time inference with Amazon SageMaker works, see [Documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/how-it-works-hosting.html).

# %%
model_name = "en-explain-doc-clinical-oncology-pipeline"

real_time_inference_instance_type = "ml.m4.xlarge"
batch_transform_inference_instance_type = "ml.m4.xlarge"

# %% [markdown]
# ### A. Create an endpoint

# %%
# create a deployable model from the model package.
model = ModelPackage(
    role=role, model_package_arn=model_package_arn, sagemaker_session=sagemaker_session
)

# Deploy the model
predictor = model.deploy(1, real_time_inference_instance_type, endpoint_name=model_name)
# Out:
# ---------!

# %% [markdown]
# Once endpoint has been created, you would be able to perform real-time inference.

# %%
import json
import pandas as pd
import os
import boto3

# Set display options
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

def process_data_and_invoke_realtime_endpoint(data, content_type, accept):

    content_type_to_format = {'application/json': 'json', 'application/jsonlines': 'jsonl'}
    input_format = content_type_to_format.get(content_type)
    if content_type not in content_type_to_format.keys() or accept not in content_type_to_format.keys():
        raise ValueError("Invalid content_type or accept. It should be either 'application/json' or 'application/jsonlines'.")

    i = 1
    input_dir = f'inputs/real-time/{input_format}'
    output_dir = f'outputs/real-time/{input_format}'
    s3_input_dir = f"{model_name}/validation-input/real-time/{input_format}"
    s3_output_dir = f"{model_name}/validation-output/real-time/{input_format}"

    input_file_name = f'{input_dir}/input{i}.{input_format}'
    output_file_name = f'{output_dir}/{os.path.basename(input_file_name)}.out'

    while os.path.exists(input_file_name) or os.path.exists(output_file_name):
        i += 1
        input_file_name = f'{input_dir}/input{i}.{input_format}'
        output_file_name = f'{output_dir}/{os.path.basename(input_file_name)}.out'

    os.makedirs(os.path.dirname(input_file_name), exist_ok=True)
    os.makedirs(os.path.dirname(output_file_name), exist_ok=True)

    input_data = json.dumps(data) if content_type == 'application/json' else data

    # Write input data to file
    with open(input_file_name, 'w') as f:
        f.write(input_data)

    # Upload input data to S3
    s3_client.put_object(Bucket=s3_bucket, Key=f"{s3_input_dir}/{os.path.basename(input_file_name)}", Body=bytes(input_data.encode('UTF-8')))

    # Invoke the SageMaker endpoint
    response = sm_runtime.invoke_endpoint(
        EndpointName=model_name,
        ContentType=content_type,
        Accept=accept,
        Body=input_data,
    )

    # Read response data
    response_data = json.loads(response["Body"].read().decode("utf-8")) if accept == 'application/json' else response['Body'].read().decode('utf-8')

    # Save response data to file
    with open(output_file_name, 'w') as f_out:
        if accept == 'application/json':
            json.dump(response_data, f_out, indent=4)
        else:
            for item in response_data.split('\n'):
                f_out.write(item + '\n')

    # Upload response data to S3
    output_s3_key = f"{s3_output_dir}/{os.path.basename(output_file_name)}"
    if accept == 'application/json':
        s3_client.put_object(Bucket=s3_bucket, Key=output_s3_key, Body=json.dumps(response_data).encode('UTF-8'))
    else:
        s3_client.put_object(Bucket=s3_bucket, Key=output_s3_key, Body=response_data)

    return response_data

# %% [markdown]
# ### Initial Setup

# %%
docs = [
        """She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.""",

        """Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images."""
]

sample_text = """The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases."""

# %% [markdown]
# ### JSON

# %% [markdown]
# #### Example 1

# %% [markdown]
#   **Input format**:
#
#
# ```json
# {
#     "text": "Single text document"
# }
# ```

# %%
input_json_data = {"text": sample_text}

data =  process_data_and_invoke_realtime_endpoint(input_json_data, content_type="application/json" , accept="application/json" )
ner_df = pd.DataFrame(data["ner_predictions"])
assertion_df = pd.DataFrame(data["assertion_predictions"])
relation_df = pd.DataFrame(data["relation_predictions"])

# %%
ner_df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     document  \
# 0   The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 1   The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 2   The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 3   The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 4   The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 5   The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 6   The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 7   The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 8   The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 9   The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 10  The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 11  The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 12  The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 13  The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 14  The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 15  The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 16  The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 17  The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 18  The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 19  The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 20  The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 21  The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 22  The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
#
#                                   ner_chunk  begin  end             ner_label  \
# 0                       computed tomography     24   42          Imaging_Test
# 1                                        CT     45   46          Imaging_Test
# 2                                   abdomen     61   67  Site_Other_Body_Part
# 3                                    pelvis     73   78  Site_Other_Body_Part
# 4                                   ovarian    104  110  Site_Other_Body_Part
# 5                                      mass    112  115         Tumor_Finding
# 6                                 Pap smear    120  128        Pathology_Test
# 7                           one month later    140  154         Relative_Date
# 8                  atypical glandular cells    173  196      Pathology_Result
# 9                            adenocarcinoma    213  226             Cancer_Dx
# 10                      pathologic specimen    233  251        Pathology_Test
# 11                                extension    260  268              Invasion
# 12                                    tumor    277  281         Tumor_Finding
# 13                          fallopian tubes    298  312  Site_Other_Body_Part
# 14                                 appendix    315  322  Site_Other_Body_Part
# 15                                  omentum    325  331  Site_Other_Body_Part
# 16                                 enlarged    349  356   Lymph_Node_Modifier
# 17                              lymph nodes    358  368       Site_Lymph_Node
# 18                                    tumor    409  413         Tumor_Finding
# 19                               stage IIIC    419  428               Staging
# 20  papillary serous ovarian adenocarcinoma    430  468           Oncological
# 21                         Two months later    471  486         Relative_Date
# 22                          lung metastases    520  534           Oncological
#
#    ner_confidence
# 0          0.9575
# 1          0.9565
# 2          0.9446
# 3          0.6514
# 4          0.7915
# 5          0.9557
# 6         0.96725
# 7       0.8786667
# 8       0.7270667
# 9          0.9992
# 10        0.76105
# 11         0.9241
# 12         0.9077
# 13         0.9492
# 14         0.9971
# 15         0.9937
# 16         0.9882
# 17        0.80105
# 18         0.9851
# 19        0.99035
# 20        0.60825
# 21      0.9206333
# 22     0.96220005

# %%
assertion_df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     document  \
# 0   The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 1   The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 2   The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 3   The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 4   The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 5   The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 6   The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 7   The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 8   The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 9   The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 10  The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 11  The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 12  The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
#
#                                   ner_chunk  begin  end            ner_label  \
# 0                       computed tomography     24   42         Imaging_Test
# 1                                        CT     45   46         Imaging_Test
# 2                                      mass    112  115        Tumor_Finding
# 3                                 Pap smear    120  128       Pathology_Test
# 4                  atypical glandular cells    173  196     Pathology_Result
# 5                            adenocarcinoma    213  226            Cancer_Dx
# 6                       pathologic specimen    233  251       Pathology_Test
# 7                                 extension    260  268             Invasion
# 8                                     tumor    277  281        Tumor_Finding
# 9                                  enlarged    349  356  Lymph_Node_Modifier
# 10                                    tumor    409  413        Tumor_Finding
# 11  papillary serous ovarian adenocarcinoma    430  468          Oncological
# 12                          lung metastases    520  534          Oncological
#
#    assertion assertion_confidence
# 0       Past               0.9998
# 1       Past               0.9997
# 2    Present               0.9995
# 3       Past               0.9988
# 4    Present                0.957
# 5   Possible               0.9251
# 6       Past               0.9993
# 7    Present               0.9978
# 8    Present               0.9992
# 9    Present               0.9787
# 10   Present               0.9994
# 11   Present               0.9962
# 12   Present               0.9975

# %%
relation_df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    document  \
# 0  The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 1  The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 2  The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 3  The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 4  The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 5  The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 6  The Patient underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
#
#   ner_chunk1 ner_chunk1_begin ner_chunk1_end            ner_label1  \
# 0    abdomen               61             67  Site_Other_Body_Part
# 1     pelvis               73             78  Site_Other_Body_Part
# 2    ovarian              104            110  Site_Other_Body_Part
# 3  Pap smear              120            128        Pathology_Test
# 4      tumor              277            281         Tumor_Finding
# 5      tumor              277            281         Tumor_Finding
# 6      tumor              277            281         Tumor_Finding
#
#         ner_chunk2 ner_chunk2_begin ner_chunk2_end            ner_label2  \
# 0             mass              112            115         Tumor_Finding
# 1             mass              112            115         Tumor_Finding
# 2             mass              112            115         Tumor_Finding
# 3   adenocarcinoma              213            226             Cancer_Dx
# 4  fallopian tubes              298            312  Site_Other_Body_Part
# 5         appendix              315            322  Site_Other_Body_Part
# 6          omentum              325            331  Site_Other_Body_Part
#
#          relation relation_confidence
# 0               O           0.9439166
# 1               O           0.9611397
# 2  is_location_of            0.922661
# 3   is_finding_of          0.52542114
# 4  is_location_of           0.9026299
# 5  is_location_of           0.6649267
# 6               O          0.80328876

# %% [markdown]
# #### Example 2

# %% [markdown]
#   **Input format**:
#
#
# ```json
# {
#     "text": [
#         "Text document 1",
#         "Text document 2",
#         ...
#     ]
# }
# ```

# %%
input_json_data = {"text": docs}

data =  process_data_and_invoke_realtime_endpoint(input_json_data, content_type="application/json" , accept="application/json" )
ner_df = pd.DataFrame(data["ner_predictions"])
assertion_df = pd.DataFrame(data["assertion_predictions"])
relation_df = pd.DataFrame(data["relation_predictions"])

# %%
ner_df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             document  \
# 0   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 1   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 2   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 3   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 4   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 5   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 6   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 7   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 8   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 9   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 10  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 11  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 12  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 13  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 14  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 15  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 16  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 17  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 18  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 19  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 20  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 21  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 22  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 23  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 24                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 25                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 26                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 27                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 28                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 29                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 30                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 31                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 32                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 33                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 34                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 35                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 36                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
#
#                                   ner_chunk  begin  end             ner_label  \
# 0                                       She      0    2                Gender
# 1                       computed tomography     16   34          Imaging_Test
# 2                                        CT     37   38          Imaging_Test
# 3                                   abdomen     53   59  Site_Other_Body_Part
# 4                                    pelvis     65   70  Site_Other_Body_Part
# 5                                   ovarian     96  102  Site_Other_Body_Part
# 6                                      mass    104  107         Tumor_Finding
# 7                                 Pap smear    112  120        Pathology_Test
# 8                           one month later    132  146         Relative_Date
# 9                  atypical glandular cells    165  188      Pathology_Result
# 10                           adenocarcinoma    205  218             Cancer_Dx
# 11                      pathologic specimen    225  243        Pathology_Test
# 12                                extension    252  260              Invasion
# 13                                    tumor    269  273         Tumor_Finding
# 14                          fallopian tubes    290  304  Site_Other_Body_Part
# 15                                 appendix    307  314  Site_Other_Body_Part
# 16                                  omentum    317  323  Site_Other_Body_Part
# 17                                 enlarged    341  348   Lymph_Node_Modifier
# 18                              lymph nodes    350  360       Site_Lymph_Node
# 19                                    tumor    401  405         Tumor_Finding
# 20                               stage IIIC    411  420               Staging
# 21  papillary serous ovarian adenocarcinoma    422  460           Oncological
# 22                         Two months later    463  478         Relative_Date
# 23                          lung metastases    512  526           Oncological
# 24                Chest computed tomography      0   24          Imaging_Test
# 25                                       CT     27   28          Imaging_Test
# 26                                pulmonary     38   46             Site_Lung
# 27                                  lesions     48   54         Tumor_Finding
# 28                                posterior     59   67             Direction
# 29                                    right     80   84             Direction
# 30                               upper lobe     86   95             Site_Lung
# 31                   peripheral lung cancer    102  123             Cancer_Dx
# 32                     pulmonary metastases    139  158           Oncological
# 33     metastases of the thoracic vertebrae    170  205           Oncological
# 34                                  sternum    208  214             Site_Bone
# 35                                     ribs    221  224             Site_Bone
# 36                                CT images    274  282          Imaging_Test
#
#    ner_confidence
# 0             1.0
# 1         0.93485
# 2          0.9724
# 3          0.9363
# 4          0.5375
# 5          0.7866
# 6          0.9573
# 7         0.96725
# 8       0.8786667
# 9       0.7270667
# 10         0.9992
# 11        0.76105
# 12         0.9241
# 13         0.9077
# 14         0.9492
# 15         0.9971
# 16         0.9937
# 17         0.9882
# 18        0.80105
# 19         0.9851
# 20        0.99035
# 21        0.60825
# 22      0.9206333
# 23     0.96220005
# 24     0.94563335
# 25         0.9701
# 26         0.9976
# 27         0.9101
# 28         0.9531
# 29         0.9989
# 30     0.78859997
# 31     0.60636663
# 32         0.7248
# 33        0.55206
# 34         0.9935
# 35          0.999
# 36     0.90505004

# %%
assertion_df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             document  \
# 0   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 1   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 2   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 3   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 4   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 5   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 6   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 7   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 8   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 9   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 10  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 11  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 12  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 13  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 14                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 15                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 16                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 17                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 18                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 19                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 20                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
#
#                                   ner_chunk  begin  end            ner_label  \
# 0                                       She      0    2               Gender
# 1                       computed tomography     16   34         Imaging_Test
# 2                                        CT     37   38         Imaging_Test
# 3                                      mass    104  107        Tumor_Finding
# 4                                 Pap smear    112  120       Pathology_Test
# 5                  atypical glandular cells    165  188     Pathology_Result
# 6                            adenocarcinoma    205  218            Cancer_Dx
# 7                       pathologic specimen    225  243       Pathology_Test
# 8                                 extension    252  260             Invasion
# 9                                     tumor    269  273        Tumor_Finding
# 10                                 enlarged    341  348  Lymph_Node_Modifier
# 11                                    tumor    401  405        Tumor_Finding
# 12  papillary serous ovarian adenocarcinoma    422  460          Oncological
# 13                          lung metastases    512  526          Oncological
# 14                Chest computed tomography      0   24         Imaging_Test
# 15                                       CT     27   28         Imaging_Test
# 16                                  lesions     48   54        Tumor_Finding
# 17                   peripheral lung cancer    102  123            Cancer_Dx
# 18                     pulmonary metastases    139  158          Oncological
# 19     metastases of the thoracic vertebrae    170  205          Oncological
# 20                                CT images    274  282         Imaging_Test
#
#    assertion assertion_confidence
# 0    Present               0.9992
# 1       Past               0.9997
# 2       Past               0.7904
# 3    Present               0.9996
# 4       Past               0.9988
# 5    Present                0.957
# 6   Possible               0.9251
# 7       Past               0.9993
# 8    Present               0.9978
# 9    Present               0.9992
# 10   Present               0.9787
# 11   Present               0.9994
# 12   Present               0.9962
# 13   Present               0.9975
# 14      Past               0.9993
# 15      Past               0.9997
# 16   Present               0.9969
# 17   Present               0.9845
# 18   Present               0.9301
# 19   Present               0.8446
# 20      Past               0.9976

# %%
relation_df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            document  \
# 0  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 1  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 2  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 3  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 4  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 5  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 6  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 7                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 8                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
#
#   ner_chunk1 ner_chunk1_begin ner_chunk1_end            ner_label1  \
# 0    abdomen               53             59  Site_Other_Body_Part
# 1     pelvis               65             70  Site_Other_Body_Part
# 2    ovarian               96            102  Site_Other_Body_Part
# 3  Pap smear              112            120        Pathology_Test
# 4      tumor              269            273         Tumor_Finding
# 5      tumor              269            273         Tumor_Finding
# 6      tumor              269            273         Tumor_Finding
# 7  pulmonary               38             46             Site_Lung
# 8    lesions               48             54         Tumor_Finding
#
#         ner_chunk2 ner_chunk2_begin ner_chunk2_end            ner_label2  \
# 0             mass              104            107         Tumor_Finding
# 1             mass              104            107         Tumor_Finding
# 2             mass              104            107         Tumor_Finding
# 3   adenocarcinoma              205            218             Cancer_Dx
# 4  fallopian tubes              290            304  Site_Other_Body_Part
# 5         appendix              307            314  Site_Other_Body_Part
# 6          omentum              317            323  Site_Other_Body_Part
# 7          lesions               48             54         Tumor_Finding
# 8       upper lobe               86             95             Site_Lung
#
#          relation relation_confidence
# 0               O           0.9437938
# 1               O           0.9618621
# 2  is_location_of            0.921906
# 3   is_finding_of          0.52542114
# 4  is_location_of           0.9026299
# 5  is_location_of           0.6649267
# 6               O          0.80328876
# 7  is_location_of          0.93497586
# 8  is_location_of           0.9341804

# %% [markdown]
# ### JSON Lines

# %% [markdown]
#   **Input format**:
#
# ```json
# {"text": "Text document 1"}
# {"text": "Text document 2"}
# ```

# %%
import json

def create_jsonl(records):
    json_records = []

    for text in records:
        record = {
            "text": text
        }
        json_records.append(record)

    json_lines = '\n'.join(json.dumps(record) for record in json_records)

    return json_lines

input_jsonl_data = create_jsonl(docs)

# %% [markdown]
# #### Example 1

# %%
data = process_data_and_invoke_realtime_endpoint(input_jsonl_data, content_type="application/jsonlines" , accept="application/jsonlines" )
print(data)
# Out:
# {"ner_predictions": [{"ner_chunk": "She", "begin": 0, "end": 2, "ner_label": "Gender", "ner_confidence": "1.0"}, {"ner_chunk": "computed tomography", "begin": 16, "end": 34, "ner_label": "Imaging_Test", "ner_confidence": "0.93485"}, {"ner_chunk": "CT", "begin": 37, "end": 38, "ner_label": "Imaging_Test", "ner_confidence": "0.9724"}, {"ner_chunk": "abdomen", "begin": 53, "end": 59, "ner_label": "Site_Other_Body_Part", "ner_confidence": "0.9363"}, {"ner_chunk": "pelvis", "begin": 65, "end": 70, "ner_label": "Site_Other_Body_Part", "ner_confidence": "0.5375"}, {"ner_chunk": "ovarian", "begin": 96, "end": 102, "ner_label": "Site_Other_Body_Part", "ner_confidence": "0.7866"}, {"ner_chunk": "mass", "begin": 104, "end": 107, "ner_label": "Tumor_Finding", "ner_confidence": "0.9573"}, {"ner_chunk": "Pap smear", "begin": 112, "end": 120, "ner_label": "Pathology_Test", "ner_confidence": "0.96725"}, {"ner_chunk": "one month later", "begin": 132, "end": 146, "ner_label": "Relative_Date", "ner_confidence": "0.8786667"}, {"ner_chunk": "atypical glandular cells", "begin": 165, "end": 188, "ner_label": "Pathology_Result", "ner_confidence": "0.7270667"}, {"ner_chunk": "adenocarcinoma", "begin": 205, "end": 218, "ner_label": "Cancer_Dx", "ner_confidence": "0.9992"}, {"ner_chunk": "pathologic specimen", "begin": 225, "end": 243, "ner_label": "Pathology_Test", "ner_confidence": "0.76105"}, {"ner_chunk": "extension", "begin": 252, "end": 260, "ner_label": "Invasion", "ner_confidence": "0.9241"}, {"ner_chunk": "tumor", "begin": 269, "end": 273, "ner_label": "Tumor_Finding", "ner_confidence": "0.9077"}, {"ner_chunk": "fallopian tubes", "begin": 290, "end": 304, "ner_label": "Site_Other_Body_Part", "ner_confidence": "0.9492"}, {"ner_chunk": "appendix", "begin": 307, "end": 314, "ner_label": "Site_Other_Body_Part", "ner_confidence": "0.9971"}, {"ner_chunk": "omentum", "begin": 317, "end": 323, "ner_label": "Site_Other_Body_Part", "ner_confidence": "0.9937"}, {"ner_chunk": "enlarged", "begin": 341, "end": 348, "ner_label": "Lymph_Node_Modifier", "ner_confidence": "0.9882"}, {"ner_chunk": "lymph nodes", "begin": 350, "end": 360, "ner_label": "Site_Lymph_Node", "ner_confidence": "0.80105"}, {"ner_chunk": "tumor", "begin": 401, "end": 405, "ner_label": "Tumor_Finding", "ner_confidence": "0.9851"}, {"ner_chunk": "stage IIIC", "begin": 411, "end": 420, "ner_label": "Staging", "ner_confidence": "0.99035"}, {"ner_chunk": "papillary serous ovarian adenocarcinoma", "begin": 422, "end": 460, "ner_label": "Oncological", "ner_confidence": "0.60825"}, {"ner_chunk": "Two months later", "begin": 463, "end": 478, "ner_label": "Relative_Date", "ner_confidence": "0.9206333"}, {"ner_chunk": "lung metastases", "begin": 512, "end": 526, "ner_label": "Oncological", "ner_confidence": "0.96220005"}], "assertion_predictions": [{"ner_chunk": "She", "begin": 0, "end": 2, "ner_label": "Gender", "assertion": "Present", "assertion_confidence": "0.9992"}, {"ner_chunk": "computed tomography", "begin": 16, "end": 34, "ner_label": "Imaging_Test", "assertion": "Past", "assertion_confidence": "0.9997"}, {"ner_chunk": "CT", "begin": 37, "end": 38, "ner_label": "Imaging_Test", "assertion": "Past", "assertion_confidence": "0.7904"}, {"ner_chunk": "mass", "begin": 104, "end": 107, "ner_label": "Tumor_Finding", "assertion": "Present", "assertion_confidence": "0.9996"}, {"ner_chunk": "Pap smear", "begin": 112, "end": 120, "ner_label": "Pathology_Test", "assertion": "Past", "assertion_confidence": "0.9988"}, {"ner_chunk": "atypical glandular cells", "begin": 165, "end": 188, "ner_label": "Pathology_Result", "assertion": "Present", "assertion_confidence": "0.957"}, {"ner_chunk": "adenocarcinoma", "begin": 205, "end": 218, "ner_label": "Cancer_Dx", "assertion": "Possible", "assertion_confidence": "0.9251"}, {"ner_chunk": "pathologic specimen", "begin": 225, "end": 243, "ner_label": "Pathology_Test", "assertion": "Past", "assertion_confidence": "0.9993"}, {"ner_chunk": "extension", "begin": 252, "e ...
# {"ner_predictions": [{"ner_chunk": "Chest computed tomography", "begin": 0, "end": 24, "ner_label": "Imaging_Test", "ner_confidence": "0.94563335"}, {"ner_chunk": "CT", "begin": 27, "end": 28, "ner_label": "Imaging_Test", "ner_confidence": "0.9701"}, {"ner_chunk": "pulmonary", "begin": 38, "end": 46, "ner_label": "Site_Lung", "ner_confidence": "0.9976"}, {"ner_chunk": "lesions", "begin": 48, "end": 54, "ner_label": "Tumor_Finding", "ner_confidence": "0.9101"}, {"ner_chunk": "posterior", "begin": 59, "end": 67, "ner_label": "Direction", "ner_confidence": "0.9531"}, {"ner_chunk": "right", "begin": 80, "end": 84, "ner_label": "Direction", "ner_confidence": "0.9989"}, {"ner_chunk": "upper lobe", "begin": 86, "end": 95, "ner_label": "Site_Lung", "ner_confidence": "0.78859997"}, {"ner_chunk": "peripheral lung cancer", "begin": 102, "end": 123, "ner_label": "Cancer_Dx", "ner_confidence": "0.60636663"}, {"ner_chunk": "pulmonary metastases", "begin": 139, "end": 158, "ner_label": "Oncological", "ner_confidence": "0.7248"}, {"ner_chunk": "metastases of the thoracic vertebrae", "begin": 170, "end": 205, "ner_label": "Oncological", "ner_confidence": "0.55206"}, {"ner_chunk": "sternum", "begin": 208, "end": 214, "ner_label": "Site_Bone", "ner_confidence": "0.9935"}, {"ner_chunk": "ribs", "begin": 221, "end": 224, "ner_label": "Site_Bone", "ner_confidence": "0.999"}, {"ner_chunk": "CT images", "begin": 274, "end": 282, "ner_label": "Imaging_Test", "ner_confidence": "0.90505004"}], "assertion_predictions": [{"ner_chunk": "Chest computed tomography", "begin": 0, "end": 24, "ner_label": "Imaging_Test", "assertion": "Past", "assertion_confidence": "0.9993"}, {"ner_chunk": "CT", "begin": 27, "end": 28, "ner_label": "Imaging_Test", "assertion": "Past", "assertion_confidence": "0.9997"}, {"ner_chunk": "lesions", "begin": 48, "end": 54, "ner_label": "Tumor_Finding", "assertion": "Present", "assertion_confidence": "0.9969"}, {"ner_chunk": "peripheral lung cancer", "begin": 102, "end": 123, "ner_label": "Cancer_Dx", "assertion": "Present", "assertion_confidence": "0.9845"}, {"ner_chunk": "pulmonary metastases", "begin": 139, "end": 158, "ner_label": "Oncological", "assertion": "Present", "assertion_confidence": "0.9301"}, {"ner_chunk": "metastases of the thoracic vertebrae", "begin": 170, "end": 205, "ner_label": "Oncological", "assertion": "Present", "assertion_confidence": "0.8446"}, {"ner_chunk": "CT images", "begin": 274, "end": 282, "ner_label": "Imaging_Test", "assertion": "Past", "assertion_confidence": "0.9976"}], "relation_predictions": [{"ner_chunk1": "pulmonary", "ner_chunk1_begin": "38", "ner_chunk1_end": "46", "ner_label1": "Site_Lung", "ner_chunk2": "lesions", "ner_chunk2_begin": "48", "ner_chunk2_end": "54", "ner_label2": "Tumor_Finding", "relation": "is_location_of", "relation_confidence": "0.93497586"}, {"ner_chunk1": "lesions", "ner_chunk1_begin": "48", "ner_chunk1_end": "54", "ner_label1": "Tumor_Finding", "ner_chunk2": "upper lobe", "ner_chunk2_begin": "86", "ner_chunk2_end": "95", "ner_label2": "Site_Lung", "relation": "is_location_of", "relation_confidence": "0.9341804"}]}

# %% [markdown]
# ### C. Delete the endpoint

# %% [markdown]
# Now that you have successfully performed a real-time inference, you do not need the endpoint any more. You can terminate the endpoint to avoid being charged.

# %%
model.sagemaker_session.delete_endpoint(model_name)
model.sagemaker_session.delete_endpoint_config(model_name)

# %% [markdown]
# ## 3. Batch inference

# %%
import json
import os

input_dir = 'inputs/batch'
json_input_dir = f"{input_dir}/json"
jsonl_input_dir = f"{input_dir}/jsonl"

output_dir = 'outputs/batch'
json_output_dir = f"{output_dir}/json"
jsonl_output_dir = f"{output_dir}/jsonl"

os.makedirs(json_input_dir, exist_ok=True)
os.makedirs(jsonl_input_dir, exist_ok=True)
os.makedirs(json_output_dir, exist_ok=True)
os.makedirs(jsonl_output_dir, exist_ok=True)

validation_json_file_name = "input.json"

validation_jsonl_file_name = "input.jsonl"

validation_input_json_path = f"s3://{s3_bucket}/{model_name}/validation-input/batch/json/"
validation_output_json_path = f"s3://{s3_bucket}/{model_name}/validation-output/batch/json/"

validation_input_jsonl_path = f"s3://{s3_bucket}/{model_name}/validation-input/batch/jsonl/"
validation_output_jsonl_path = f"s3://{s3_bucket}/{model_name}/validation-output/batch/jsonl/"

def write_and_upload_to_s3(input_data, file_name):
    file_format = os.path.splitext(file_name)[1].lower()
    if file_format == ".json":
        input_data = json.dumps(input_data)

    with open(file_name, "w") as f:
        f.write(input_data)

    s3_client.put_object(
        Bucket=s3_bucket,
        Key=f"{model_name}/validation-input/batch/{file_format[1:]}/{os.path.basename(file_name)}",
        Body=(bytes(input_data.encode("UTF-8"))),
    )

# %%
input_jsonl_data = create_jsonl(docs)
input_json_data = {"text": docs}

write_and_upload_to_s3(input_json_data, f"{json_input_dir}/{validation_json_file_name}")

write_and_upload_to_s3(input_jsonl_data, f"{jsonl_input_dir}/{validation_jsonl_file_name}")

# %% [markdown]
# ### JSON

# %%
# Initialize a SageMaker Transformer object for making predictions
transformer = model.transformer(
    instance_count=1,
    instance_type=batch_transform_inference_instance_type,
    accept="application/json",
    output_path=validation_output_json_path
)

transformer.transform(validation_input_json_path, content_type="application/json")
transformer.wait()

# %%
from urllib.parse import urlparse

def process_s3_json_output_and_save(validation_file_name):

    output_file_path = f"{json_output_dir}/{validation_file_name}.out"
    parsed_url = urlparse(transformer.output_path)
    file_key = f"{parsed_url.path[1:]}{validation_file_name}.out"
    response = s3_client.get_object(Bucket=s3_bucket, Key=file_key)

    data = json.loads(response["Body"].read().decode("utf-8"))
    # Define a dictionary with DataFrame objects and their names
    data_frames = {
        "NER Predictions DataFrame": pd.DataFrame(data['ner_predictions']),
        "Assertion Predictions DataFrame": pd.DataFrame(data['assertion_predictions']),
        "Relation Predictions DataFrame": pd.DataFrame(data['relation_predictions'])
    }

    # Display and save each DataFrame
    for name, df in data_frames.items():
        print(name + ":")
        display(df)
    # Save the data to the output file
    with open(output_file_path, 'w') as f_out:
        json.dump(data, f_out, indent=4)

# %%
process_s3_json_output_and_save(validation_json_file_name)
# Out:
# NER Predictions DataFrame:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             document  \
# 0   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 1   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 2   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 3   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 4   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 5   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 6   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 7   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 8   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 9   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 10  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 11  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 12  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 13  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 14  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 15  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 16  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 17  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 18  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 19  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 20  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 21  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 22  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 23  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 24                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 25                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 26                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 27                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 28                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 29                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 30                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 31                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 32                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 33                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 34                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 35                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 36                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
#
#                                   ner_chunk  begin  end             ner_label  \
# 0                                       She      0    2                Gender
# 1                       computed tomography     16   34          Imaging_Test
# 2                                        CT     37   38          Imaging_Test
# 3                                   abdomen     53   59  Site_Other_Body_Part
# 4                                    pelvis     65   70  Site_Other_Body_Part
# 5                                   ovarian     96  102  Site_Other_Body_Part
# 6                                      mass    104  107         Tumor_Finding
# 7                                 Pap smear    112  120        Pathology_Test
# 8                           one month later    132  146         Relative_Date
# 9                  atypical glandular cells    165  188      Pathology_Result
# 10                           adenocarcinoma    205  218             Cancer_Dx
# 11                      pathologic specimen    225  243        Pathology_Test
# 12                                extension    252  260              Invasion
# 13                                    tumor    269  273         Tumor_Finding
# 14                          fallopian tubes    290  304  Site_Other_Body_Part
# 15                                 appendix    307  314  Site_Other_Body_Part
# 16                                  omentum    317  323  Site_Other_Body_Part
# 17                                 enlarged    341  348   Lymph_Node_Modifier
# 18                              lymph nodes    350  360       Site_Lymph_Node
# 19                                    tumor    401  405         Tumor_Finding
# 20                               stage IIIC    411  420               Staging
# 21  papillary serous ovarian adenocarcinoma    422  460           Oncological
# 22                         Two months later    463  478         Relative_Date
# 23                          lung metastases    512  526           Oncological
# 24                Chest computed tomography      0   24          Imaging_Test
# 25                                       CT     27   28          Imaging_Test
# 26                                pulmonary     38   46             Site_Lung
# 27                                  lesions     48   54         Tumor_Finding
# 28                                posterior     59   67             Direction
# 29                                    right     80   84             Direction
# 30                               upper lobe     86   95             Site_Lung
# 31                   peripheral lung cancer    102  123             Cancer_Dx
# 32                     pulmonary metastases    139  158           Oncological
# 33     metastases of the thoracic vertebrae    170  205           Oncological
# 34                                  sternum    208  214             Site_Bone
# 35                                     ribs    221  224             Site_Bone
# 36                                CT images    274  282          Imaging_Test
#
#    ner_confidence
# 0             1.0
# 1         0.93485
# 2          0.9724
# 3          0.9363
# 4          0.5375
# 5          0.7866
# 6          0.9573
# 7         0.96725
# 8       0.8786667
# 9       0.7270667
# 10         0.9992
# 11        0.76105
# 12         0.9241
# 13         0.9077
# 14         0.9492
# 15         0.9971
# 16         0.9937
# 17         0.9882
# 18        0.80105
# 19         0.9851
# 20        0.99035
# 21        0.60825
# 22      0.9206333
# 23     0.96220005
# 24     0.94563335
# 25         0.9701
# 26         0.9976
# 27         0.9101
# 28         0.9531
# 29         0.9989
# 30     0.78859997
# 31     0.60636663
# 32         0.7248
# 33        0.55206
# 34         0.9935
# 35          0.999
# 36     0.90505004
# Assertion Predictions DataFrame:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             document  \
# 0   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 1   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 2   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 3   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 4   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 5   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 6   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 7   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 8   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 9   She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 10  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 11  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 12  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 13  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 14                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 15                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 16                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 17                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 18                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 19                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 20                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
#
#                                   ner_chunk  begin  end            ner_label  \
# 0                                       She      0    2               Gender
# 1                       computed tomography     16   34         Imaging_Test
# 2                                        CT     37   38         Imaging_Test
# 3                                      mass    104  107        Tumor_Finding
# 4                                 Pap smear    112  120       Pathology_Test
# 5                  atypical glandular cells    165  188     Pathology_Result
# 6                            adenocarcinoma    205  218            Cancer_Dx
# 7                       pathologic specimen    225  243       Pathology_Test
# 8                                 extension    252  260             Invasion
# 9                                     tumor    269  273        Tumor_Finding
# 10                                 enlarged    341  348  Lymph_Node_Modifier
# 11                                    tumor    401  405        Tumor_Finding
# 12  papillary serous ovarian adenocarcinoma    422  460          Oncological
# 13                          lung metastases    512  526          Oncological
# 14                Chest computed tomography      0   24         Imaging_Test
# 15                                       CT     27   28         Imaging_Test
# 16                                  lesions     48   54        Tumor_Finding
# 17                   peripheral lung cancer    102  123            Cancer_Dx
# 18                     pulmonary metastases    139  158          Oncological
# 19     metastases of the thoracic vertebrae    170  205          Oncological
# 20                                CT images    274  282         Imaging_Test
#
#    assertion assertion_confidence
# 0    Present               0.9992
# 1       Past               0.9997
# 2       Past               0.7904
# 3    Present               0.9996
# 4       Past               0.9988
# 5    Present                0.957
# 6   Possible               0.9251
# 7       Past               0.9993
# 8    Present               0.9978
# 9    Present               0.9992
# 10   Present               0.9787
# 11   Present               0.9994
# 12   Present               0.9962
# 13   Present               0.9975
# 14      Past               0.9993
# 15      Past               0.9997
# 16   Present               0.9969
# 17   Present               0.9845
# 18   Present               0.9301
# 19   Present               0.8446
# 20      Past               0.9976
# Relation Predictions DataFrame:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            document  \
# 0  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 1  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 2  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 3  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 4  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 5  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 6  She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.
# 7                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
# 8                                                                                                                                                                                                                                                      Chest computed tomography (CT) showed pulmonary lesions in posterior segment of right upper lobe, and peripheral lung cancer with multiple pulmonary metastases. Multiple metastases of the thoracic vertebrae, sternum, and ribs were considered, which were similar to previous CT images.
#
#   ner_chunk1 ner_chunk1_begin ner_chunk1_end            ner_label1  \
# 0    abdomen               53             59  Site_Other_Body_Part
# 1     pelvis               65             70  Site_Other_Body_Part
# 2    ovarian               96            102  Site_Other_Body_Part
# 3  Pap smear              112            120        Pathology_Test
# 4      tumor              269            273         Tumor_Finding
# 5      tumor              269            273         Tumor_Finding
# 6      tumor              269            273         Tumor_Finding
# 7  pulmonary               38             46             Site_Lung
# 8    lesions               48             54         Tumor_Finding
#
#         ner_chunk2 ner_chunk2_begin ner_chunk2_end            ner_label2  \
# 0             mass              104            107         Tumor_Finding
# 1             mass              104            107         Tumor_Finding
# 2             mass              104            107         Tumor_Finding
# 3   adenocarcinoma              205            218             Cancer_Dx
# 4  fallopian tubes              290            304  Site_Other_Body_Part
# 5         appendix              307            314  Site_Other_Body_Part
# 6          omentum              317            323  Site_Other_Body_Part
# 7          lesions               48             54         Tumor_Finding
# 8       upper lobe               86             95             Site_Lung
#
#          relation relation_confidence
# 0               O           0.9437938
# 1               O           0.9618621
# 2  is_location_of            0.921906
# 3   is_finding_of          0.52542114
# 4  is_location_of           0.9026299
# 5  is_location_of           0.6649267
# 6               O          0.80328876
# 7  is_location_of          0.93497586
# 8  is_location_of           0.9341804

# %% [markdown]
# ### JSON Lines

# %%
transformer = model.transformer(
    instance_count=1,
    instance_type=batch_transform_inference_instance_type,
    accept="application/jsonlines",
    output_path=validation_output_jsonl_path
)
transformer.transform(validation_input_jsonl_path, content_type="application/jsonlines")
transformer.wait()

# %%
from urllib.parse import urlparse

def process_s3_jsonlines_output_and_save(validation_file_name):

    output_file_path = f"{jsonl_output_dir}/{validation_file_name}.out"
    parsed_url = urlparse(transformer.output_path)
    file_key = f"{parsed_url.path[1:]}{validation_file_name}.out"
    response = s3_client.get_object(Bucket=s3_bucket, Key=file_key)

    data = response["Body"].read().decode("utf-8")
    print(data)

    # Save the data to the output file
    with open(output_file_path, 'w') as f_out:
        for item in data.split('\n'):
            f_out.write(item + '\n')

# %%
process_s3_jsonlines_output_and_save(validation_jsonl_file_name)
# Out:
# {"ner_predictions": [{"ner_chunk": "She", "begin": 0, "end": 2, "ner_label": "Gender", "ner_confidence": "1.0"}, {"ner_chunk": "computed tomography", "begin": 16, "end": 34, "ner_label": "Imaging_Test", "ner_confidence": "0.93485"}, {"ner_chunk": "CT", "begin": 37, "end": 38, "ner_label": "Imaging_Test", "ner_confidence": "0.9724"}, {"ner_chunk": "abdomen", "begin": 53, "end": 59, "ner_label": "Site_Other_Body_Part", "ner_confidence": "0.9363"}, {"ner_chunk": "pelvis", "begin": 65, "end": 70, "ner_label": "Site_Other_Body_Part", "ner_confidence": "0.5375"}, {"ner_chunk": "ovarian", "begin": 96, "end": 102, "ner_label": "Site_Other_Body_Part", "ner_confidence": "0.7866"}, {"ner_chunk": "mass", "begin": 104, "end": 107, "ner_label": "Tumor_Finding", "ner_confidence": "0.9573"}, {"ner_chunk": "Pap smear", "begin": 112, "end": 120, "ner_label": "Pathology_Test", "ner_confidence": "0.96725"}, {"ner_chunk": "one month later", "begin": 132, "end": 146, "ner_label": "Relative_Date", "ner_confidence": "0.8786667"}, {"ner_chunk": "atypical glandular cells", "begin": 165, "end": 188, "ner_label": "Pathology_Result", "ner_confidence": "0.7270667"}, {"ner_chunk": "adenocarcinoma", "begin": 205, "end": 218, "ner_label": "Cancer_Dx", "ner_confidence": "0.9992"}, {"ner_chunk": "pathologic specimen", "begin": 225, "end": 243, "ner_label": "Pathology_Test", "ner_confidence": "0.76105"}, {"ner_chunk": "extension", "begin": 252, "end": 260, "ner_label": "Invasion", "ner_confidence": "0.9241"}, {"ner_chunk": "tumor", "begin": 269, "end": 273, "ner_label": "Tumor_Finding", "ner_confidence": "0.9077"}, {"ner_chunk": "fallopian tubes", "begin": 290, "end": 304, "ner_label": "Site_Other_Body_Part", "ner_confidence": "0.9492"}, {"ner_chunk": "appendix", "begin": 307, "end": 314, "ner_label": "Site_Other_Body_Part", "ner_confidence": "0.9971"}, {"ner_chunk": "omentum", "begin": 317, "end": 323, "ner_label": "Site_Other_Body_Part", "ner_confidence": "0.9937"}, {"ner_chunk": "enlarged", "begin": 341, "end": 348, "ner_label": "Lymph_Node_Modifier", "ner_confidence": "0.9882"}, {"ner_chunk": "lymph nodes", "begin": 350, "end": 360, "ner_label": "Site_Lymph_Node", "ner_confidence": "0.80105"}, {"ner_chunk": "tumor", "begin": 401, "end": 405, "ner_label": "Tumor_Finding", "ner_confidence": "0.9851"}, {"ner_chunk": "stage IIIC", "begin": 411, "end": 420, "ner_label": "Staging", "ner_confidence": "0.99035"}, {"ner_chunk": "papillary serous ovarian adenocarcinoma", "begin": 422, "end": 460, "ner_label": "Oncological", "ner_confidence": "0.60825"}, {"ner_chunk": "Two months later", "begin": 463, "end": 478, "ner_label": "Relative_Date", "ner_confidence": "0.9206333"}, {"ner_chunk": "lung metastases", "begin": 512, "end": 526, "ner_label": "Oncological", "ner_confidence": "0.96220005"}], "assertion_predictions": [{"ner_chunk": "She", "begin": 0, "end": 2, "ner_label": "Gender", "assertion": "Present", "assertion_confidence": "0.9992"}, {"ner_chunk": "computed tomography", "begin": 16, "end": 34, "ner_label": "Imaging_Test", "assertion": "Past", "assertion_confidence": "0.9997"}, {"ner_chunk": "CT", "begin": 37, "end": 38, "ner_label": "Imaging_Test", "assertion": "Past", "assertion_confidence": "0.7904"}, {"ner_chunk": "mass", "begin": 104, "end": 107, "ner_label": "Tumor_Finding", "assertion": "Present", "assertion_confidence": "0.9996"}, {"ner_chunk": "Pap smear", "begin": 112, "end": 120, "ner_label": "Pathology_Test", "assertion": "Past", "assertion_confidence": "0.9988"}, {"ner_chunk": "atypical glandular cells", "begin": 165, "end": 188, "ner_label": "Pathology_Result", "assertion": "Present", "assertion_confidence": "0.957"}, {"ner_chunk": "adenocarcinoma", "begin": 205, "end": 218, "ner_label": "Cancer_Dx", "assertion": "Possible", "assertion_confidence": "0.9251"}, {"ner_chunk": "pathologic specimen", "begin": 225, "end": 243, "ner_label": "Pathology_Test", "assertion": "Past", "assertion_confidence": "0.9993"}, {"ner_chunk": "extension", "begin": 252, "e ...
# {"ner_predictions": [{"ner_chunk": "Chest computed tomography", "begin": 0, "end": 24, "ner_label": "Imaging_Test", "ner_confidence": "0.94563335"}, {"ner_chunk": "CT", "begin": 27, "end": 28, "ner_label": "Imaging_Test", "ner_confidence": "0.9701"}, {"ner_chunk": "pulmonary", "begin": 38, "end": 46, "ner_label": "Site_Lung", "ner_confidence": "0.9976"}, {"ner_chunk": "lesions", "begin": 48, "end": 54, "ner_label": "Tumor_Finding", "ner_confidence": "0.9101"}, {"ner_chunk": "posterior", "begin": 59, "end": 67, "ner_label": "Direction", "ner_confidence": "0.9531"}, {"ner_chunk": "right", "begin": 80, "end": 84, "ner_label": "Direction", "ner_confidence": "0.9989"}, {"ner_chunk": "upper lobe", "begin": 86, "end": 95, "ner_label": "Site_Lung", "ner_confidence": "0.78859997"}, {"ner_chunk": "peripheral lung cancer", "begin": 102, "end": 123, "ner_label": "Cancer_Dx", "ner_confidence": "0.60636663"}, {"ner_chunk": "pulmonary metastases", "begin": 139, "end": 158, "ner_label": "Oncological", "ner_confidence": "0.7248"}, {"ner_chunk": "metastases of the thoracic vertebrae", "begin": 170, "end": 205, "ner_label": "Oncological", "ner_confidence": "0.55206"}, {"ner_chunk": "sternum", "begin": 208, "end": 214, "ner_label": "Site_Bone", "ner_confidence": "0.9935"}, {"ner_chunk": "ribs", "begin": 221, "end": 224, "ner_label": "Site_Bone", "ner_confidence": "0.999"}, {"ner_chunk": "CT images", "begin": 274, "end": 282, "ner_label": "Imaging_Test", "ner_confidence": "0.90505004"}], "assertion_predictions": [{"ner_chunk": "Chest computed tomography", "begin": 0, "end": 24, "ner_label": "Imaging_Test", "assertion": "Past", "assertion_confidence": "0.9993"}, {"ner_chunk": "CT", "begin": 27, "end": 28, "ner_label": "Imaging_Test", "assertion": "Past", "assertion_confidence": "0.9997"}, {"ner_chunk": "lesions", "begin": 48, "end": 54, "ner_label": "Tumor_Finding", "assertion": "Present", "assertion_confidence": "0.9969"}, {"ner_chunk": "peripheral lung cancer", "begin": 102, "end": 123, "ner_label": "Cancer_Dx", "assertion": "Present", "assertion_confidence": "0.9845"}, {"ner_chunk": "pulmonary metastases", "begin": 139, "end": 158, "ner_label": "Oncological", "assertion": "Present", "assertion_confidence": "0.9301"}, {"ner_chunk": "metastases of the thoracic vertebrae", "begin": 170, "end": 205, "ner_label": "Oncological", "assertion": "Present", "assertion_confidence": "0.8446"}, {"ner_chunk": "CT images", "begin": 274, "end": 282, "ner_label": "Imaging_Test", "assertion": "Past", "assertion_confidence": "0.9976"}], "relation_predictions": [{"ner_chunk1": "pulmonary", "ner_chunk1_begin": "38", "ner_chunk1_end": "46", "ner_label1": "Site_Lung", "ner_chunk2": "lesions", "ner_chunk2_begin": "48", "ner_chunk2_end": "54", "ner_label2": "Tumor_Finding", "relation": "is_location_of", "relation_confidence": "0.93497586"}, {"ner_chunk1": "lesions", "ner_chunk1_begin": "48", "ner_chunk1_end": "54", "ner_label1": "Tumor_Finding", "ner_chunk2": "upper lobe", "ner_chunk2_begin": "86", "ner_chunk2_end": "95", "ner_label2": "Site_Lung", "relation": "is_location_of", "relation_confidence": "0.9341804"}]}

# %%
model.delete_model()
# Out:
# INFO:sagemaker:Deleting model with name: en-explain-doc-clinical-oncology-pipeli-2024-05-09-20-36-44-339

# %% [markdown]
# ### Unsubscribe to the listing (optional)

# %% [markdown]
# If you would like to unsubscribe to the model package, follow these steps. Before you cancel the subscription, ensure that you do not have any [deployable model](https://console.aws.amazon.com/sagemaker/home#/models) created from the model package or using the algorithm. Note - You can find this information by looking at the container name associated with the model.
#
# **Steps to unsubscribe to product from AWS Marketplace**:
# 1. Navigate to __Machine Learning__ tab on [__Your Software subscriptions page__](https://aws.amazon.com/marketplace/ai/library?productType=ml&ref_=mlmp_gitdemo_indust)
# 2. Locate the listing that you want to cancel the subscription for, and then choose __Cancel Subscription__  to cancel the subscription.
