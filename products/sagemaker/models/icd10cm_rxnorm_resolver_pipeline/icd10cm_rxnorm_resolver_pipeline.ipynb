# %% [markdown]
# ## 1. Subscribe to the model package

# %% [markdown]
# To subscribe to the model package:
# 1. Open the model package listing page <font color='red'> For Seller to update:[Title_of_your_product](Provide link to your marketplace listing of your product).</font>
# 1. On the AWS Marketplace listing, click on the **Continue to subscribe** button.
# 1. On the **Subscribe to this software** page, review and click on **"Accept Offer"** if you and your organization agrees with EULA, pricing, and support terms.
# 1. Once you click on **Continue to configuration button** and then choose a **region**, you will see a **Product Arn** displayed. This is the model package ARN that you need to specify while creating a deployable model using Boto3. Copy the ARN corresponding to your region and specify the same in the following cell.

# %% [markdown]
# ## Pipeline for ICD-10-CM and RxNorm Sentence Entity Resolver
#
# - **Model**: `icd10cm_rxnorm_resolver_pipeline`
# - **Model Description**: This pipeline can extract clinical conditions and medication entities, map the clinical conditions to their respective ICD-10-CM codes, and medication entities to RxNorm codes using `sbiobert_base_cased_mli` Sentence Bert Embeddings.

# %%
model_package_arn = "<Customer to specify Model package ARN corresponding to their AWS region>"

# %%
import base64
import json
import uuid
from sagemaker import ModelPackage
import sagemaker as sage
from sagemaker import get_execution_role
import boto3
from IPython.display import Image, display
from PIL import Image as ImageEdit
import numpy as np
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
sagemaker_session = sage.Session()
s3_bucket = sagemaker_session.default_bucket()
region = sagemaker_session.boto_region_name
account_id = boto3.client("sts").get_caller_identity().get("Account")
role = get_execution_role()

sagemaker = boto3.client("sagemaker")
s3_client = sagemaker_session.boto_session.client("s3")
ecr = boto3.client("ecr")
sm_runtime = boto3.client("sagemaker-runtime")

# %% [markdown]
# ## 2. Create an endpoint and perform real-time inference

# %% [markdown]
# If you want to understand how real-time inference with Amazon SageMaker works, see [Documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/how-it-works-hosting.html).

# %%
model_name = "icd10cm-rxnorm-resolver-pipeline"

real_time_inference_instance_type = "ml.m4.xlarge"
batch_transform_inference_instance_type = "ml.m4.xlarge"

# %% [markdown]
# ### A. Create an endpoint

# %%
# create a deployable model from the model package.
model = ModelPackage(
    role=role, model_package_arn=model_package_arn, sagemaker_session=sagemaker_session
)

# Deploy the model
predictor = model.deploy(1, real_time_inference_instance_type, endpoint_name=model_name)
# Out:
# ------------!

# %% [markdown]
# Once endpoint has been created, you would be able to perform real-time inference.

# %%
import json
import pandas as pd
import os
import boto3

# Set display options
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

def process_data_and_invoke_realtime_endpoint(data, content_type, accept):

    content_type_to_format = {'application/json': 'json', 'application/jsonlines': 'jsonl'}
    input_format = content_type_to_format.get(content_type)
    if content_type not in content_type_to_format.keys() or accept not in content_type_to_format.keys():
        raise ValueError("Invalid content_type or accept. It should be either 'application/json' or 'application/jsonlines'.")

    i = 1
    input_dir = f'inputs/real-time/{input_format}'
    output_dir = f'outputs/real-time/{input_format}'
    s3_input_dir = f"{model_name}/validation-input/real-time/{input_format}"
    s3_output_dir = f"{model_name}/validation-output/real-time/{input_format}"

    input_file_name = f'{input_dir}/input{i}.{input_format}'
    output_file_name = f'{output_dir}/{os.path.basename(input_file_name)}.out'

    while os.path.exists(input_file_name) or os.path.exists(output_file_name):
        i += 1
        input_file_name = f'{input_dir}/input{i}.{input_format}'
        output_file_name = f'{output_dir}/{os.path.basename(input_file_name)}.out'

    os.makedirs(os.path.dirname(input_file_name), exist_ok=True)
    os.makedirs(os.path.dirname(output_file_name), exist_ok=True)

    input_data = json.dumps(data) if content_type == 'application/json' else data

    # Write input data to file
    with open(input_file_name, 'w') as f:
        f.write(input_data)

    # Upload input data to S3
    s3_client.put_object(Bucket=s3_bucket, Key=f"{s3_input_dir}/{os.path.basename(input_file_name)}", Body=bytes(input_data.encode('UTF-8')))

    # Invoke the SageMaker endpoint
    response = sm_runtime.invoke_endpoint(
        EndpointName=model_name,
        ContentType=content_type,
        Accept=accept,
        Body=input_data,
    )

    # Read response data
    response_data = json.loads(response["Body"].read().decode("utf-8")) if accept == 'application/json' else response['Body'].read().decode('utf-8')

    # Save response data to file
    with open(output_file_name, 'w') as f_out:
        if accept == 'application/json':
            json.dump(response_data, f_out, indent=4)
        else:
            for item in response_data.split('\n'):
                f_out.write(item + '\n')

    # Upload response data to S3
    output_s3_key = f"{s3_output_dir}/{os.path.basename(output_file_name)}"
    if accept == 'application/json':
        s3_client.put_object(Bucket=s3_bucket, Key=output_s3_key, Body=json.dumps(response_data).encode('UTF-8'))
    else:
        s3_client.put_object(Bucket=s3_bucket, Key=output_s3_key, Body=response_data)

    return response_data

# %% [markdown]
# ### Initial Setup

# %%
docs = [
    """This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.""",
    "A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.",
]

sample_text = """The patient is a 41-year-old Vietnamese female with a cough that started last week.
She has had right upper quadrant pain radiating to her back starting yesterday.
She has a history of infective pericarditis and gestational diabetes mellitus in May 2006.
MEDICATIONS
1. Coumadin 1 mg daily. Last INR was on Tuesday, August 14, 2007, and her INR was 2.3.
2. Amiodarone 100 mg p.o. daily."""

# %% [markdown]
# ### JSON

# %% [markdown]
# #### Example 1

# %% [markdown]
#   **Input format**:
#
#
# ```json
# {
#     "text": "Single text document"
# }
# ```

# %%
input_json_data = {"text": sample_text}

data =  process_data_and_invoke_realtime_endpoint(input_json_data, content_type="application/json" , accept="application/json" )

# %%
pd.DataFrame(data["rxnorm_predictions"])
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                   document  \
# 0  The patient is a 41-year-old Vietnamese female with a cough that started last week.\nShe has had right upper quadrant pain radiating to her back starting yesterday.\nShe has a history of infective pericarditis and gestational diabetes mellitus in May 2006.\nMEDICATIONS\n1. Coumadin 1 mg daily. Last INR was on Tuesday, August 14, 2007, and her INR was 2.3.\n2. Amiodarone 100 mg p.o. daily.
# 1  The patient is a 41-year-old Vietnamese female with a cough that started last week.\nShe has had right upper quadrant pain radiating to her back starting yesterday.\nShe has a history of infective pericarditis and gestational diabetes mellitus in May 2006.\nMEDICATIONS\n1. Coumadin 1 mg daily. Last INR was on Tuesday, August 14, 2007, and her INR was 2.3.\n2. Amiodarone 100 mg p.o. daily.
#
#     ner_chunk  begin  end ner_label ner_confidence rxnorm_code  \
# 0    Coumadin    270  277      DRUG         0.9961      202421
# 1  Amiodarone    357  366      DRUG         0.9731         703
#
#          rxnorm_resolution rxnorm_confidence
# 0      coumadin [coumadin]            0.9903
# 1  amiodarone [amiodarone]            0.4986

# %%
pd.DataFrame(data["icd10cm_predictions"])
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                   document  \
# 0  The patient is a 41-year-old Vietnamese female with a cough that started last week.\nShe has had right upper quadrant pain radiating to her back starting yesterday.\nShe has a history of infective pericarditis and gestational diabetes mellitus in May 2006.\nMEDICATIONS\n1. Coumadin 1 mg daily. Last INR was on Tuesday, August 14, 2007, and her INR was 2.3.\n2. Amiodarone 100 mg p.o. daily.
# 1  The patient is a 41-year-old Vietnamese female with a cough that started last week.\nShe has had right upper quadrant pain radiating to her back starting yesterday.\nShe has a history of infective pericarditis and gestational diabetes mellitus in May 2006.\nMEDICATIONS\n1. Coumadin 1 mg daily. Last INR was on Tuesday, August 14, 2007, and her INR was 2.3.\n2. Amiodarone 100 mg p.o. daily.
# 2  The patient is a 41-year-old Vietnamese female with a cough that started last week.\nShe has had right upper quadrant pain radiating to her back starting yesterday.\nShe has a history of infective pericarditis and gestational diabetes mellitus in May 2006.\nMEDICATIONS\n1. Coumadin 1 mg daily. Last INR was on Tuesday, August 14, 2007, and her INR was 2.3.\n2. Amiodarone 100 mg p.o. daily.
# 3  The patient is a 41-year-old Vietnamese female with a cough that started last week.\nShe has had right upper quadrant pain radiating to her back starting yesterday.\nShe has a history of infective pericarditis and gestational diabetes mellitus in May 2006.\nMEDICATIONS\n1. Coumadin 1 mg daily. Last INR was on Tuesday, August 14, 2007, and her INR was 2.3.\n2. Amiodarone 100 mg p.o. daily.
#
#                        ner_chunk  begin  end ner_label ner_confidence  \
# 0                        a cough     52   58   PROBLEM         0.9635
# 1      right upper quadrant pain     96  120   PROBLEM     0.84590006
# 2         infective pericarditis    185  206   PROBLEM     0.95519996
# 3  gestational diabetes mellitus    212  240   PROBLEM     0.95213336
#
#   icd10cm_code                                             icd10cm_resolution  \
# 0          R05                                                  cough [cough]
# 1       R10.11          right upper quadrant pain [right upper quadrant pain]
# 2        I30.1                infective pericarditis [infective pericarditis]
# 3        O24.4  gestational diabetes mellitus [gestational diabetes mellitus]
#
#   icd10cm_confidence
# 0             0.7676
# 1             0.9623
# 2             0.9862
# 3             0.9838

# %% [markdown]
# #### Example 2

# %% [markdown]
#   **Input format**:
#
#
# ```json
# {
#     "text": [
#         "Text document 1",
#         "Text document 2",
#         ...
#     ]
# }
# ```

# %%
input_json_data = {"text": docs}

data =  process_data_and_invoke_realtime_endpoint(input_json_data, content_type="application/json" , accept="application/json" )

# %%
pd.DataFrame(data["rxnorm_predictions"])
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       document  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 3  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 4  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 5  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
#
#        ner_chunk  begin  end ner_label ner_confidence rxnorm_code  \
# 0       atropine    436  443      DRUG         0.9999     1666780
# 1         fluids    449  454      DRUG         0.9995       90230
# 2       dopamine    461  468      DRUG         0.9976     1743862
# 3    amoxicillin    411  421      DRUG         0.9999      370576
# 4  dapagliflozin    474  486      DRUG         0.9983     1488568
# 5  Serum acetone    965  977      DRUG         0.7603      377016
#
#              rxnorm_resolution rxnorm_confidence
# 0           atropine Injection            0.4969
# 1              liquid [liquid]            0.4616
# 2           dopamine Injection            0.4995
# 3  amoxicillin Oral Suspension            0.4813
# 4    dapagliflozin Oral Tablet            0.4880
# 5     acetone Topical Solution            0.1149

# %%
pd.DataFrame(data["icd10cm_predictions"])
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        document  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 10  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 11  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 12  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 13  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 14  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 15  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 16  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 17  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 18  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 19  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 20  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 21  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 22  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 23  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 24  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 25  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 26  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
#
#                                                                ner_chunk  \
# 0                                                           hypertension
# 1                                            chronic renal insufficiency
# 2                                                                   COPD
# 3                                                              gastritis
# 4                                                                    TIA
# 5                                         a nonspecific ST-T abnormality
# 6   occlusion of the mid left anterior descending coronary artery lesion
# 7                                                            hypotension
# 8                                                            bradycardia
# 9                                                       a vagal reaction
# 10                                         gestational diabetes mellitus
# 11                                 subsequent type two diabetes mellitus
# 12                                                    an acute hepatitis
# 13                                                               obesity
# 14                                                     a body mass index
# 15                                                              polyuria
# 16                                                            polydipsia
# 17                                                         poor appetite
# 18                                                              vomiting
# 19                                         a respiratory tract infection
# 20                                                       dry oral mucosa
# 21                                                            tenderness
# 22                                                              guarding
# 23                                                            hemolyzing
# 24                                                   significant lipemia
# 25                                                    starvation ketosis
# 26                                                      poor oral intake
#
#     begin   end ner_label ner_confidence icd10cm_code  \
# 0      65    76   PROBLEM         0.9984          I15
# 1      79   105   PROBLEM      0.9780667        N18.6
# 2     108   111   PROBLEM         0.9999        W17.0
# 3     114   122   PROBLEM         0.9993        K29.0
# 4     129   131   PROBLEM         0.9998       H53.55
# 5     175   204   PROBLEM     0.95210004       H50.40
# 6     300   367   PROBLEM     0.83212996       I21.02
# 7     395   405   PROBLEM         0.9837          I95
# 8     411   421   PROBLEM          0.997        R00.1
# 9     493   508   PROBLEM         0.8416        I87.1
# 10     39    67   PROBLEM         0.9255        O24.4
# 11    117   153   PROBLEM     0.77357996          E11
# 12    172   189   PROBLEM      0.9745667          B15
# 13    196   202   PROBLEM         0.9973          E66
# 14    209   225   PROBLEM       0.845925          Z68
# 15    285   292   PROBLEM         0.9897          R35
# 16    295   304   PROBLEM         0.9931        R63.1
# 17    307   319   PROBLEM          0.998       R45.81
# 18    326   333   PROBLEM         0.9934        R11.1
# 19    427   455   PROBLEM     0.91305006          T17
# 20    589   603   PROBLEM         0.7224        R68.2
# 21    666   675   PROBLEM         0.9997       R45.86
# 22    680   687   PROBLEM         0.9992       R45.82
# 23   1030  1039   PROBLEM         0.8774          D74
# 24   1048  1066   PROBLEM     0.94519997       E78.41
# 25   1108  1125   PROBLEM        0.98645          E41
# 26   1144  1159   PROBLEM      0.8695667        Z59.4
#
#                                                                                                                                           icd10cm_resolution  \
# 0                                                                                                            secondary hypertension [secondary hypertension]
# 1                                                                                                          end stage renal disease [end stage renal disease]
# 2                                                                                                                            fall into well [fall into well]
# 3                                                                                                                          acute gastritis [acute gastritis]
# 4                                                                                                                                  tritanomaly [tritanomaly]
# 5                                                                                                        unspecified heterotropia [unspecified heterotropia]
# 6   stemi involving left anterior descending coronary artery [st elevation (stemi) myocardial infarction involving left anterior descending coronary artery]
# 7                                                                                                                                  hypotension [hypotension]
# 8                                                                                                        bradycardia, unspecified [bradycardia, unspecified]
# 9                                                                                                                  compression of vein [compression of vein]
# 10                                                                                             gestational diabetes mellitus [gestational diabetes mellitus]
# 11                                                                                                       type 2 diabetes mellitus [type 2 diabetes mellitus]
# 12                                                                                                                     acute hepatitis a [acute hepatitis a]
# 13                                                                                                           overweight and obesity [overweight and obesity]
# 14                                                                                                             body mass index [bmi] [body mass index [bmi]]
# 15                                                                                                                                       polyuria [polyuria]
# 16                                                                                                                                   polydipsia [polydipsia]
# 17                                                                                                                         low self-esteem [low self-esteem]
# 18                                                                                                                                       vomiting [vomiting]
# 19                                                                                     foreign body in respiratory tract [foreign body in respiratory tract]
# 20                                                                                                           dry mouth, unspecified [dry mouth, unspecified]
# 21                                                                                                                   emotional lability [emotional lability]
# 22                                                                                                                                         worries [worries]
# 23                                                                                                                     methemoglobinemia [methemoglobinemia]
# 24                                                                                                         elevated lipoprotein(a) [elevated lipoprotein(a)]
# 25                                                                                                               nutritional marasmus [nutritional marasmus]
# 26                                                                                                             lack of adequate food [lack of adequate food]
#
#    icd10cm_confidence
# 0              0.4849
# 1              0.1417
# 2              0.2428
# 3              0.4076
# 4              0.2499
# 5              0.1191
# 6              0.2677
# 7              0.9785
# 8              0.3964
# 9              0.1132
# 10             0.9838
# 11             0.3189
# 12             0.7783
# 13             0.7115
# 14             0.5329
# 15             0.9976
# 16             0.9996
# 17             0.1324
# 18             0.9951
# 19             0.4154
# 20             0.8509
# 21             0.2149
# 22             0.1193
# 23             0.1060
# 24             0.1453
# 25             0.1225
# 26             0.2086

# %% [markdown]
# ### JSON Lines

# %%
import json

def create_jsonl(records):
    json_records = []

    for text in records:
        record = {
            "text": text
        }
        json_records.append(record)

    json_lines = '\n'.join(json.dumps(record) for record in json_records)

    return json_lines

input_jsonl_data = create_jsonl(docs)

# %% [markdown]
# #### Example 1

# %% [markdown]
#   **Input format**:
#
# ```json
# {"text": "Text document 1"}
# {"text": "Text document 2"}
# ```

# %%
data = process_data_and_invoke_realtime_endpoint(input_jsonl_data, content_type="application/jsonlines" , accept="application/jsonlines" )
print(data)
# Out:
# {"rxnorm_predictions": [{"ner_chunk": "atropine", "begin": 436, "end": 443, "ner_label": "DRUG", "ner_confidence": "0.9999", "rxnorm_code": "1666780", "rxnorm_resolution": "atropine Injection", "rxnorm_confidence": "0.4969"}, {"ner_chunk": "fluids", "begin": 449, "end": 454, "ner_label": "DRUG", "ner_confidence": "0.9995", "rxnorm_code": "90230", "rxnorm_resolution": "liquid [liquid]", "rxnorm_confidence": "0.4616"}, {"ner_chunk": "dopamine", "begin": 461, "end": 468, "ner_label": "DRUG", "ner_confidence": "0.9976", "rxnorm_code": "1743862", "rxnorm_resolution": "dopamine Injection", "rxnorm_confidence": "0.4995"}], "icd10cm_predictions": [{"ner_chunk": "hypertension", "begin": 65, "end": 76, "ner_label": "PROBLEM", "ner_confidence": "0.9984", "icd10cm_code": "I15", "icd10cm_resolution": "secondary hypertension [secondary hypertension]", "icd10cm_confidence": "0.4849"}, {"ner_chunk": "chronic renal insufficiency", "begin": 79, "end": 105, "ner_label": "PROBLEM", "ner_confidence": "0.9780667", "icd10cm_code": "N18.6", "icd10cm_resolution": "end stage renal disease [end stage renal disease]", "icd10cm_confidence": "0.1417"}, {"ner_chunk": "COPD", "begin": 108, "end": 111, "ner_label": "PROBLEM", "ner_confidence": "0.9999", "icd10cm_code": "W17.0", "icd10cm_resolution": "fall into well [fall into well]", "icd10cm_confidence": "0.2428"}, {"ner_chunk": "gastritis", "begin": 114, "end": 122, "ner_label": "PROBLEM", "ner_confidence": "0.9993", "icd10cm_code": "K29.0", "icd10cm_resolution": "acute gastritis [acute gastritis]", "icd10cm_confidence": "0.4076"}, {"ner_chunk": "TIA", "begin": 129, "end": 131, "ner_label": "PROBLEM", "ner_confidence": "0.9998", "icd10cm_code": "H53.55", "icd10cm_resolution": "tritanomaly [tritanomaly]", "icd10cm_confidence": "0.2499"}, {"ner_chunk": "a nonspecific ST-T abnormality", "begin": 175, "end": 204, "ner_label": "PROBLEM", "ner_confidence": "0.95210004", "icd10cm_code": "H50.40", "icd10cm_resolution": "unspecified heterotropia [unspecified heterotropia]", "icd10cm_confidence": "0.1191"}, {"ner_chunk": "occlusion of the mid left anterior descending coronary artery lesion", "begin": 300, "end": 367, "ner_label": "PROBLEM", "ner_confidence": "0.83212996", "icd10cm_code": "I21.02", "icd10cm_resolution": "stemi involving left anterior descending coronary artery [st elevation (stemi) myocardial infarction involving left anterior descending coronary artery]", "icd10cm_confidence": "0.2677"}, {"ner_chunk": "hypotension", "begin": 395, "end": 405, "ner_label": "PROBLEM", "ner_confidence": "0.9837", "icd10cm_code": "I95", "icd10cm_resolution": "hypotension [hypotension]", "icd10cm_confidence": "0.9785"}, {"ner_chunk": "bradycardia", "begin": 411, "end": 421, "ner_label": "PROBLEM", "ner_confidence": "0.997", "icd10cm_code": "R00.1", "icd10cm_resolution": "bradycardia, unspecified [bradycardia, unspecified]", "icd10cm_confidence": "0.3964"}, {"ner_chunk": "a vagal reaction", "begin": 493, "end": 508, "ner_label": "PROBLEM", "ner_confidence": "0.8416", "icd10cm_code": "I87.1", "icd10cm_resolution": "compression of vein [compression of vein]", "icd10cm_confidence": "0.1132"}]}
# {"rxnorm_predictions": [{"ner_chunk": "amoxicillin", "begin": 411, "end": 421, "ner_label": "DRUG", "ner_confidence": "0.9999", "rxnorm_code": "370576", "rxnorm_resolution": "amoxicillin Oral Suspension", "rxnorm_confidence": "0.4813"}, {"ner_chunk": "dapagliflozin", "begin": 474, "end": 486, "ner_label": "DRUG", "ner_confidence": "0.9983", "rxnorm_code": "1488568", "rxnorm_resolution": "dapagliflozin Oral Tablet", "rxnorm_confidence": "0.4880"}, {"ner_chunk": "Serum acetone", "begin": 965, "end": 977, "ner_label": "DRUG", "ner_confidence": "0.7603", "rxnorm_code": "377016", "rxnorm_resolution": "acetone Topical Solution", "rxnorm_confidence": "0.1149"}], "icd10cm_predictions": [{"ner_chunk": "gestational diabetes mellitus", "begin": 39, "end": 67, "ner_label": "PROBLEM", "ner_confidence": "0.9255", "icd10cm_code": "O24.4", "icd10cm_resolution": "gestational diabetes mellitus [gestational diabetes mellitus]", "icd10cm_confidence": "0.9838"}, {"ner_chunk": "subsequent type two diabetes mellitus", "begin": 117, "end": 153, "ner_label": "PROBLEM", "ner_confidence": "0.77357996", "icd10cm_code": "E11", "icd10cm_resolution": "type 2 diabetes mellitus [type 2 diabetes mellitus]", "icd10cm_confidence": "0.3189"}, {"ner_chunk": "an acute hepatitis", "begin": 172, "end": 189, "ner_label": "PROBLEM", "ner_confidence": "0.9745667", "icd10cm_code": "B15", "icd10cm_resolution": "acute hepatitis a [acute hepatitis a]", "icd10cm_confidence": "0.7783"}, {"ner_chunk": "obesity", "begin": 196, "end": 202, "ner_label": "PROBLEM", "ner_confidence": "0.9973", "icd10cm_code": "E66", "icd10cm_resolution": "overweight and obesity [overweight and obesity]", "icd10cm_confidence": "0.7115"}, {"ner_chunk": "a body mass index", "begin": 209, "end": 225, "ner_label": "PROBLEM", "ner_confidence": "0.845925", "icd10cm_code": "Z68", "icd10cm_resolution": "body mass index [bmi] [body mass index [bmi]]", "icd10cm_confidence": "0.5329"}, {"ner_chunk": "polyuria", "begin": 285, "end": 292, "ner_label": "PROBLEM", "ner_confidence": "0.9897", "icd10cm_code": "R35", "icd10cm_resolution": "polyuria [polyuria]", "icd10cm_confidence": "0.9976"}, {"ner_chunk": "polydipsia", "begin": 295, "end": 304, "ner_label": "PROBLEM", "ner_confidence": "0.9931", "icd10cm_code": "R63.1", "icd10cm_resolution": "polydipsia [polydipsia]", "icd10cm_confidence": "0.9996"}, {"ner_chunk": "poor appetite", "begin": 307, "end": 319, "ner_label": "PROBLEM", "ner_confidence": "0.998", "icd10cm_code": "R45.81", "icd10cm_resolution": "low self-esteem [low self-esteem]", "icd10cm_confidence": "0.1324"}, {"ner_chunk": "vomiting", "begin": 326, "end": 333, "ner_label": "PROBLEM", "ner_confidence": "0.9934", "icd10cm_code": "R11.1", "icd10cm_resolution": "vomiting [vomiting]", "icd10cm_confidence": "0.9951"}, {"ner_chunk": "a respiratory tract infection", "begin": 427, "end": 455, "ner_label": "PROBLEM", "ner_confidence": "0.91305006", "icd10cm_code": "T17", "icd10cm_resolution": "foreign body in respiratory tract [foreign body in respiratory tract]", "icd10cm_confidence": "0.4154"}, {"ner_chunk": "dry oral mucosa", "begin": 589, "end": 603, "ner_label": "PROBLEM", "ner_confidence": "0.7224", "icd10cm_code": "R68.2", "icd10cm_resolution": "dry mouth, unspecified [dry mouth, unspecified]", "icd10cm_confidence": "0.8509"}, {"ner_chunk": "tenderness", "begin": 666, "end": 675, "ner_label": "PROBLEM", "ner_confidence": "0.9997", "icd10cm_code": "R45.86", "icd10cm_resolution": "emotional lability [emotional lability]", "icd10cm_confidence": "0.2149"}, {"ner_chunk": "guarding", "begin": 680, "end": 687, "ner_label": "PROBLEM", "ner_confidence": "0.9992", "icd10cm_code": "R45.82", "icd10cm_resolution": "worries [worries]", "icd10cm_confidence": "0.1193"}, {"ner_chunk": "hemolyzing", "begin": 1030, "end": 1039, "ner_label": "PROBLEM", "ner_confidence": "0.8774", "icd10cm_code": "D74", "icd10cm_resolution": "methemoglobinemia [methemoglobinemia]", "icd10cm_confidence": "0.1060"}, {"ner_chunk": "significant l ...

# %% [markdown]
# ### C. Delete the endpoint

# %% [markdown]
# Now that you have successfully performed a real-time inference, you do not need the endpoint any more. You can terminate the endpoint to avoid being charged.

# %%
model.sagemaker_session.delete_endpoint(model_name)
model.sagemaker_session.delete_endpoint_config(model_name)

# %% [markdown]
# ## 3. Batch inference

# %%
import json
import os

input_dir = 'inputs/batch'
json_input_dir = f"{input_dir}/json"
jsonl_input_dir = f"{input_dir}/jsonl"

output_dir = 'outputs/batch'
json_output_dir = f"{output_dir}/json"
jsonl_output_dir = f"{output_dir}/jsonl"

os.makedirs(json_input_dir, exist_ok=True)
os.makedirs(jsonl_input_dir, exist_ok=True)
os.makedirs(json_output_dir, exist_ok=True)
os.makedirs(jsonl_output_dir, exist_ok=True)

validation_json_file_name = "input.json"

validation_jsonl_file_name = "input.jsonl"

validation_input_json_path = f"s3://{s3_bucket}/{model_name}/validation-input/batch/json/"
validation_output_json_path = f"s3://{s3_bucket}/{model_name}/validation-output/batch/json/"

validation_input_jsonl_path = f"s3://{s3_bucket}/{model_name}/validation-input/batch/jsonl/"
validation_output_jsonl_path = f"s3://{s3_bucket}/{model_name}/validation-output/batch/jsonl/"

def write_and_upload_to_s3(input_data, file_name):
    file_format = os.path.splitext(file_name)[1].lower()
    if file_format == ".json":
        input_data = json.dumps(input_data)

    with open(file_name, "w") as f:
        f.write(input_data)

    s3_client.put_object(
        Bucket=s3_bucket,
        Key=f"{model_name}/validation-input/batch/{file_format[1:]}/{os.path.basename(file_name)}",
        Body=(bytes(input_data.encode("UTF-8"))),
    )

# %%
input_jsonl_data = create_jsonl(docs)
input_json_data = {"text": docs}

write_and_upload_to_s3(input_json_data, f"{json_input_dir}/{validation_json_file_name}")

write_and_upload_to_s3(input_jsonl_data, f"{jsonl_input_dir}/{validation_jsonl_file_name}")

# %% [markdown]
# ### JSON

# %%
# Initialize a SageMaker Transformer object for making predictions
transformer = model.transformer(
    instance_count=1,
    instance_type=batch_transform_inference_instance_type,
    accept="application/json",
    output_path=validation_output_json_path
)

transformer.transform(validation_input_json_path, content_type="application/json")
transformer.wait()

# %%
from urllib.parse import urlparse

def process_s3_json_output_and_save(validation_file_name):

    output_file_path = f"{json_output_dir}/{validation_file_name}.out"
    parsed_url = urlparse(transformer.output_path)
    file_key = f"{parsed_url.path[1:]}{validation_file_name}.out"
    response = s3_client.get_object(Bucket=s3_bucket, Key=file_key)

    data = json.loads(response["Body"].read().decode("utf-8"))
    data_frames = {
        "RXNORM RESULT": pd.DataFrame(data['rxnorm_predictions']),
        "ICD-10-CM RESULT": pd.DataFrame(data['icd10cm_predictions']),
    }

    # Display and save each DataFrame
    for name, df in data_frames.items():
        print(name + ":")
        display(df)

    # Save the data to the output file
    with open(output_file_path, 'w') as f_out:
        json.dump(data, f_out, indent=4)

# %%
process_s3_json_output_and_save(validation_json_file_name)
# Out:
# RXNORM RESULT:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       document  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 3  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 4  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 5  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
#
#        ner_chunk  begin  end ner_label ner_confidence rxnorm_code  \
# 0       atropine    436  443      DRUG         0.9999     1666780
# 1         fluids    449  454      DRUG         0.9995       90230
# 2       dopamine    461  468      DRUG         0.9976     1743862
# 3    amoxicillin    411  421      DRUG         0.9999      370576
# 4  dapagliflozin    474  486      DRUG         0.9983     1488568
# 5  Serum acetone    965  977      DRUG         0.7603      377016
#
#              rxnorm_resolution rxnorm_confidence
# 0           atropine Injection            0.4969
# 1              liquid [liquid]            0.4616
# 2           dopamine Injection            0.4995
# 3  amoxicillin Oral Suspension            0.4813
# 4    dapagliflozin Oral Tablet            0.4880
# 5     acetone Topical Solution            0.1149
# ICD-10-CM RESULT:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        document  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 10  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 11  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 12  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 13  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 14  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 15  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 16  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 17  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 18  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 19  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 20  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 21  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 22  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 23  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 24  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 25  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
# 26  A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus, associated with an acute hepatitis, and obesity with a body mass index (BMI) of 33.5 kg/m2, presented with a one-week history of polyuria, polydipsia, poor appetite, and vomiting. Two weeks prior to presentation, she was treated with a five-day course of amoxicillin for a respiratory tract infection. She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa; significantly, her abdominal examination was benign with no tenderness or guarding. Pertinent laboratory findings on admission were: serum glucose 111 mg/dl, bicarbonate 18 mmol/l, anion gap 20, creatinine 0.4 mg/dL, triglycerides 508 mg/dL, total cholesterol 122 mg/dL, glycated hemoglobin (HbA1c) 10%, and venous pH 7.27. Serum lipase was normal at 43 U/L. Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia. The patient was initially admitted for starvation ketosis, as she reported poor oral intake for three days prior to admission.
#
#                                                                ner_chunk  \
# 0                                                           hypertension
# 1                                            chronic renal insufficiency
# 2                                                                   COPD
# 3                                                              gastritis
# 4                                                                    TIA
# 5                                         a nonspecific ST-T abnormality
# 6   occlusion of the mid left anterior descending coronary artery lesion
# 7                                                            hypotension
# 8                                                            bradycardia
# 9                                                       a vagal reaction
# 10                                         gestational diabetes mellitus
# 11                                 subsequent type two diabetes mellitus
# 12                                                    an acute hepatitis
# 13                                                               obesity
# 14                                                     a body mass index
# 15                                                              polyuria
# 16                                                            polydipsia
# 17                                                         poor appetite
# 18                                                              vomiting
# 19                                         a respiratory tract infection
# 20                                                       dry oral mucosa
# 21                                                            tenderness
# 22                                                              guarding
# 23                                                            hemolyzing
# 24                                                   significant lipemia
# 25                                                    starvation ketosis
# 26                                                      poor oral intake
#
#     begin   end ner_label ner_confidence icd10cm_code  \
# 0      65    76   PROBLEM         0.9984          I15
# 1      79   105   PROBLEM      0.9780667        N18.6
# 2     108   111   PROBLEM         0.9999        W17.0
# 3     114   122   PROBLEM         0.9993        K29.0
# 4     129   131   PROBLEM         0.9998       H53.55
# 5     175   204   PROBLEM     0.95210004       H50.40
# 6     300   367   PROBLEM     0.83212996       I21.02
# 7     395   405   PROBLEM         0.9837          I95
# 8     411   421   PROBLEM          0.997        R00.1
# 9     493   508   PROBLEM         0.8416        I87.1
# 10     39    67   PROBLEM         0.9255        O24.4
# 11    117   153   PROBLEM     0.77357996          E11
# 12    172   189   PROBLEM      0.9745667          B15
# 13    196   202   PROBLEM         0.9973          E66
# 14    209   225   PROBLEM       0.845925          Z68
# 15    285   292   PROBLEM         0.9897          R35
# 16    295   304   PROBLEM         0.9931        R63.1
# 17    307   319   PROBLEM          0.998       R45.81
# 18    326   333   PROBLEM         0.9934        R11.1
# 19    427   455   PROBLEM     0.91305006          T17
# 20    589   603   PROBLEM         0.7224        R68.2
# 21    666   675   PROBLEM         0.9997       R45.86
# 22    680   687   PROBLEM         0.9992       R45.82
# 23   1030  1039   PROBLEM         0.8774          D74
# 24   1048  1066   PROBLEM     0.94519997       E78.41
# 25   1108  1125   PROBLEM        0.98645          E41
# 26   1144  1159   PROBLEM      0.8695667        Z59.4
#
#                                                                                                                                           icd10cm_resolution  \
# 0                                                                                                            secondary hypertension [secondary hypertension]
# 1                                                                                                          end stage renal disease [end stage renal disease]
# 2                                                                                                                            fall into well [fall into well]
# 3                                                                                                                          acute gastritis [acute gastritis]
# 4                                                                                                                                  tritanomaly [tritanomaly]
# 5                                                                                                        unspecified heterotropia [unspecified heterotropia]
# 6   stemi involving left anterior descending coronary artery [st elevation (stemi) myocardial infarction involving left anterior descending coronary artery]
# 7                                                                                                                                  hypotension [hypotension]
# 8                                                                                                        bradycardia, unspecified [bradycardia, unspecified]
# 9                                                                                                                  compression of vein [compression of vein]
# 10                                                                                             gestational diabetes mellitus [gestational diabetes mellitus]
# 11                                                                                                       type 2 diabetes mellitus [type 2 diabetes mellitus]
# 12                                                                                                                     acute hepatitis a [acute hepatitis a]
# 13                                                                                                           overweight and obesity [overweight and obesity]
# 14                                                                                                             body mass index [bmi] [body mass index [bmi]]
# 15                                                                                                                                       polyuria [polyuria]
# 16                                                                                                                                   polydipsia [polydipsia]
# 17                                                                                                                         low self-esteem [low self-esteem]
# 18                                                                                                                                       vomiting [vomiting]
# 19                                                                                     foreign body in respiratory tract [foreign body in respiratory tract]
# 20                                                                                                           dry mouth, unspecified [dry mouth, unspecified]
# 21                                                                                                                   emotional lability [emotional lability]
# 22                                                                                                                                         worries [worries]
# 23                                                                                                                     methemoglobinemia [methemoglobinemia]
# 24                                                                                                         elevated lipoprotein(a) [elevated lipoprotein(a)]
# 25                                                                                                               nutritional marasmus [nutritional marasmus]
# 26                                                                                                             lack of adequate food [lack of adequate food]
#
#    icd10cm_confidence
# 0              0.4849
# 1              0.1417
# 2              0.2428
# 3              0.4076
# 4              0.2499
# 5              0.1191
# 6              0.2677
# 7              0.9785
# 8              0.3964
# 9              0.1132
# 10             0.9838
# 11             0.3189
# 12             0.7783
# 13             0.7115
# 14             0.5329
# 15             0.9976
# 16             0.9996
# 17             0.1324
# 18             0.9951
# 19             0.4154
# 20             0.8509
# 21             0.2149
# 22             0.1193
# 23             0.1060
# 24             0.1453
# 25             0.1225
# 26             0.2086

# %% [markdown]
# ### JSON Lines

# %%
transformer = model.transformer(
    instance_count=1,
    instance_type=batch_transform_inference_instance_type,
    accept="application/jsonlines",
    output_path=validation_output_jsonl_path
)
transformer.transform(validation_input_jsonl_path, content_type="application/jsonlines")
transformer.wait()

# %%
from urllib.parse import urlparse

def process_s3_jsonlines_output_and_save(validation_file_name):

    output_file_path = f"{jsonl_output_dir}/{validation_file_name}.out"
    parsed_url = urlparse(transformer.output_path)
    file_key = f"{parsed_url.path[1:]}{validation_file_name}.out"
    response = s3_client.get_object(Bucket=s3_bucket, Key=file_key)

    data = response["Body"].read().decode("utf-8")
    print(data)

    # Save the data to the output file
    with open(output_file_path, 'w') as f_out:
        for item in data.split('\n'):
            f_out.write(item + '\n')

# %%
process_s3_jsonlines_output_and_save(validation_jsonl_file_name)
# Out:
# {"rxnorm_predictions": [{"ner_chunk": "atropine", "begin": 436, "end": 443, "ner_label": "DRUG", "ner_confidence": "0.9999", "rxnorm_code": "1666780", "rxnorm_resolution": "atropine Injection", "rxnorm_confidence": "0.4969"}, {"ner_chunk": "fluids", "begin": 449, "end": 454, "ner_label": "DRUG", "ner_confidence": "0.9995", "rxnorm_code": "90230", "rxnorm_resolution": "liquid [liquid]", "rxnorm_confidence": "0.4616"}, {"ner_chunk": "dopamine", "begin": 461, "end": 468, "ner_label": "DRUG", "ner_confidence": "0.9976", "rxnorm_code": "1743862", "rxnorm_resolution": "dopamine Injection", "rxnorm_confidence": "0.4995"}], "icd10cm_predictions": [{"ner_chunk": "hypertension", "begin": 65, "end": 76, "ner_label": "PROBLEM", "ner_confidence": "0.9984", "icd10cm_code": "I15", "icd10cm_resolution": "secondary hypertension [secondary hypertension]", "icd10cm_confidence": "0.4849"}, {"ner_chunk": "chronic renal insufficiency", "begin": 79, "end": 105, "ner_label": "PROBLEM", "ner_confidence": "0.9780667", "icd10cm_code": "N18.6", "icd10cm_resolution": "end stage renal disease [end stage renal disease]", "icd10cm_confidence": "0.1417"}, {"ner_chunk": "COPD", "begin": 108, "end": 111, "ner_label": "PROBLEM", "ner_confidence": "0.9999", "icd10cm_code": "W17.0", "icd10cm_resolution": "fall into well [fall into well]", "icd10cm_confidence": "0.2428"}, {"ner_chunk": "gastritis", "begin": 114, "end": 122, "ner_label": "PROBLEM", "ner_confidence": "0.9993", "icd10cm_code": "K29.0", "icd10cm_resolution": "acute gastritis [acute gastritis]", "icd10cm_confidence": "0.4076"}, {"ner_chunk": "TIA", "begin": 129, "end": 131, "ner_label": "PROBLEM", "ner_confidence": "0.9998", "icd10cm_code": "H53.55", "icd10cm_resolution": "tritanomaly [tritanomaly]", "icd10cm_confidence": "0.2499"}, {"ner_chunk": "a nonspecific ST-T abnormality", "begin": 175, "end": 204, "ner_label": "PROBLEM", "ner_confidence": "0.95210004", "icd10cm_code": "H50.40", "icd10cm_resolution": "unspecified heterotropia [unspecified heterotropia]", "icd10cm_confidence": "0.1191"}, {"ner_chunk": "occlusion of the mid left anterior descending coronary artery lesion", "begin": 300, "end": 367, "ner_label": "PROBLEM", "ner_confidence": "0.83212996", "icd10cm_code": "I21.02", "icd10cm_resolution": "stemi involving left anterior descending coronary artery [st elevation (stemi) myocardial infarction involving left anterior descending coronary artery]", "icd10cm_confidence": "0.2677"}, {"ner_chunk": "hypotension", "begin": 395, "end": 405, "ner_label": "PROBLEM", "ner_confidence": "0.9837", "icd10cm_code": "I95", "icd10cm_resolution": "hypotension [hypotension]", "icd10cm_confidence": "0.9785"}, {"ner_chunk": "bradycardia", "begin": 411, "end": 421, "ner_label": "PROBLEM", "ner_confidence": "0.997", "icd10cm_code": "R00.1", "icd10cm_resolution": "bradycardia, unspecified [bradycardia, unspecified]", "icd10cm_confidence": "0.3964"}, {"ner_chunk": "a vagal reaction", "begin": 493, "end": 508, "ner_label": "PROBLEM", "ner_confidence": "0.8416", "icd10cm_code": "I87.1", "icd10cm_resolution": "compression of vein [compression of vein]", "icd10cm_confidence": "0.1132"}]}
# {"rxnorm_predictions": [{"ner_chunk": "amoxicillin", "begin": 411, "end": 421, "ner_label": "DRUG", "ner_confidence": "0.9999", "rxnorm_code": "370576", "rxnorm_resolution": "amoxicillin Oral Suspension", "rxnorm_confidence": "0.4813"}, {"ner_chunk": "dapagliflozin", "begin": 474, "end": 486, "ner_label": "DRUG", "ner_confidence": "0.9983", "rxnorm_code": "1488568", "rxnorm_resolution": "dapagliflozin Oral Tablet", "rxnorm_confidence": "0.4880"}, {"ner_chunk": "Serum acetone", "begin": 965, "end": 977, "ner_label": "DRUG", "ner_confidence": "0.7603", "rxnorm_code": "377016", "rxnorm_resolution": "acetone Topical Solution", "rxnorm_confidence": "0.1149"}], "icd10cm_predictions": [{"ner_chunk": "gestational diabetes mellitus", "begin": 39, "end": 67, "ner_label": "PROBLEM", "ner_confidence": "0.9255", "icd10cm_code": "O24.4", "icd10cm_resolution": "gestational diabetes mellitus [gestational diabetes mellitus]", "icd10cm_confidence": "0.9838"}, {"ner_chunk": "subsequent type two diabetes mellitus", "begin": 117, "end": 153, "ner_label": "PROBLEM", "ner_confidence": "0.77357996", "icd10cm_code": "E11", "icd10cm_resolution": "type 2 diabetes mellitus [type 2 diabetes mellitus]", "icd10cm_confidence": "0.3189"}, {"ner_chunk": "an acute hepatitis", "begin": 172, "end": 189, "ner_label": "PROBLEM", "ner_confidence": "0.9745667", "icd10cm_code": "B15", "icd10cm_resolution": "acute hepatitis a [acute hepatitis a]", "icd10cm_confidence": "0.7783"}, {"ner_chunk": "obesity", "begin": 196, "end": 202, "ner_label": "PROBLEM", "ner_confidence": "0.9973", "icd10cm_code": "E66", "icd10cm_resolution": "overweight and obesity [overweight and obesity]", "icd10cm_confidence": "0.7115"}, {"ner_chunk": "a body mass index", "begin": 209, "end": 225, "ner_label": "PROBLEM", "ner_confidence": "0.845925", "icd10cm_code": "Z68", "icd10cm_resolution": "body mass index [bmi] [body mass index [bmi]]", "icd10cm_confidence": "0.5329"}, {"ner_chunk": "polyuria", "begin": 285, "end": 292, "ner_label": "PROBLEM", "ner_confidence": "0.9897", "icd10cm_code": "R35", "icd10cm_resolution": "polyuria [polyuria]", "icd10cm_confidence": "0.9976"}, {"ner_chunk": "polydipsia", "begin": 295, "end": 304, "ner_label": "PROBLEM", "ner_confidence": "0.9931", "icd10cm_code": "R63.1", "icd10cm_resolution": "polydipsia [polydipsia]", "icd10cm_confidence": "0.9996"}, {"ner_chunk": "poor appetite", "begin": 307, "end": 319, "ner_label": "PROBLEM", "ner_confidence": "0.998", "icd10cm_code": "R45.81", "icd10cm_resolution": "low self-esteem [low self-esteem]", "icd10cm_confidence": "0.1324"}, {"ner_chunk": "vomiting", "begin": 326, "end": 333, "ner_label": "PROBLEM", "ner_confidence": "0.9934", "icd10cm_code": "R11.1", "icd10cm_resolution": "vomiting [vomiting]", "icd10cm_confidence": "0.9951"}, {"ner_chunk": "a respiratory tract infection", "begin": 427, "end": 455, "ner_label": "PROBLEM", "ner_confidence": "0.91305006", "icd10cm_code": "T17", "icd10cm_resolution": "foreign body in respiratory tract [foreign body in respiratory tract]", "icd10cm_confidence": "0.4154"}, {"ner_chunk": "dry oral mucosa", "begin": 589, "end": 603, "ner_label": "PROBLEM", "ner_confidence": "0.7224", "icd10cm_code": "R68.2", "icd10cm_resolution": "dry mouth, unspecified [dry mouth, unspecified]", "icd10cm_confidence": "0.8509"}, {"ner_chunk": "tenderness", "begin": 666, "end": 675, "ner_label": "PROBLEM", "ner_confidence": "0.9997", "icd10cm_code": "R45.86", "icd10cm_resolution": "emotional lability [emotional lability]", "icd10cm_confidence": "0.2149"}, {"ner_chunk": "guarding", "begin": 680, "end": 687, "ner_label": "PROBLEM", "ner_confidence": "0.9992", "icd10cm_code": "R45.82", "icd10cm_resolution": "worries [worries]", "icd10cm_confidence": "0.1193"}, {"ner_chunk": "hemolyzing", "begin": 1030, "end": 1039, "ner_label": "PROBLEM", "ner_confidence": "0.8774", "icd10cm_code": "D74", "icd10cm_resolution": "methemoglobinemia [methemoglobinemia]", "icd10cm_confidence": "0.1060"}, {"ner_chunk": "significant l ...

# %%
model.delete_model()
# Out:
# INFO:sagemaker:Deleting model with name: icd10cm-rxnorm-resolver-pipeline-2024-06-06-21-13-30-596

# %% [markdown]
# ### Unsubscribe to the listing (optional)

# %% [markdown]
# If you would like to unsubscribe to the model package, follow these steps. Before you cancel the subscription, ensure that you do not have any [deployable model](https://console.aws.amazon.com/sagemaker/home#/models) created from the model package or using the algorithm. Note - You can find this information by looking at the container name associated with the model.
#
# **Steps to unsubscribe to product from AWS Marketplace**:
# 1. Navigate to __Machine Learning__ tab on [__Your Software subscriptions page__](https://aws.amazon.com/marketplace/ai/library?productType=ml&ref_=mlmp_gitdemo_indust)
# 2. Locate the listing that you want to cancel the subscription for, and then choose __Cancel Subscription__  to cancel the subscription.
