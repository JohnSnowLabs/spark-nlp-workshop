# %% [markdown]
# ## 1. Subscribe to the model package

# %% [markdown]
# To subscribe to the model package:
# 1. Open the model package listing page: [Extract entities from public health data](https://aws.amazon.com/marketplace/pp/prodview-ajcem2e7qhq3u).
# 1. On the AWS Marketplace listing, click on the **Continue to subscribe** button.
# 1. On the **Subscribe to this software** page, review and click on **"Accept Offer"** if you and your organization agrees with EULA, pricing, and support terms.
# 1. Once you click on **Continue to configuration button** and then choose a **region**, you will see a **Product Arn** displayed. This is the model package ARN that you need to specify while creating a deployable model using Boto3. Copy the ARN corresponding to your region and specify the same in the following cell.

# %% [markdown]
# ### Explain Clinical Document - Public Health
#
# - **Model**: [explain_clinical_doc_public_health_en](https://nlp.johnsnowlabs.com/2024/03/19/explain_clinical_doc_public_health_en.html)
# - **Model Description**: This pipeline is designed to extract all healthcare-related entities, assign assertion status to the extracted entities, and establish relations between the extracted entities from the clinical documents.

# %%
model_package_arn = "<Customer to specify Model package ARN corresponding to their AWS region>"

# %%
import json
import os
import boto3
import pandas as pd
import sagemaker as sage
from sagemaker import ModelPackage
from sagemaker import get_execution_role
from IPython.display import display
from urllib.parse import urlparse

# %%
sagemaker_session = sage.Session()
s3_bucket = sagemaker_session.default_bucket()
region = sagemaker_session.boto_region_name
account_id = boto3.client("sts").get_caller_identity().get("Account")
role = get_execution_role()

sagemaker = boto3.client("sagemaker")
s3_client = sagemaker_session.boto_session.client("s3")
ecr = boto3.client("ecr")
sm_runtime = boto3.client("sagemaker-runtime")

# Set display options
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
model_name = "explain-clinical-doc-public-health-en"

real_time_inference_instance_type = "ml.m4.xlarge"
batch_transform_inference_instance_type = "ml.m4.2xlarge"

# %% [markdown]
# ## 2. Create a deployable model from the model package.

# %%
model = ModelPackage(
    role=role, 
    model_package_arn=model_package_arn,
    sagemaker_session=sagemaker_session,
)

# %% [markdown]
# ### Input Format
#
# To use the model, you need to provide input in one of the following supported formats:
#
# #### JSON Format
#
# Provide input as JSON. We support two variations within this format:
#
# 1. **Array of Text Documents**:
#    Use an array containing multiple text documents. Each element represents a separate text document.
#
#    ```json
#    {
#        "text": [
#            "Text document 1",
#            "Text document 2",
#            ...
#        ]
#    }
#
#     ```
#
# 2. **Single Text Document**:
#    Provide a single text document as a string.
#
#
#    ```json
#     {
#         "text": "Single text document"
#     }
#    ```
#
# #### JSON Lines (JSONL) Format
#
# Provide input in JSON Lines format, where each line is a JSON object representing a text document.
#
# ```
# {"text": "Text document 1"}
# {"text": "Text document 2"}
# ```

# %% [markdown]
# ## 3. Create an endpoint and perform real-time inference

# %% [markdown]
# If you want to understand how real-time inference with Amazon SageMaker works, see [Documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/how-it-works-hosting.html).

# %% [markdown]
# ### A. Deploy the SageMaker model to an endpoint

# %%
predictor = model.deploy(
    initial_instance_count=1,
    instance_type=real_time_inference_instance_type, 
    endpoint_name=model_name,
)

# %% [markdown]
# Once endpoint has been created, you would be able to perform real-time inference.

# %%
def invoke_realtime_endpoint(record, content_type="application/json", accept="application/json"):
    response = sm_runtime.invoke_endpoint(
        EndpointName=model_name,
        ContentType=content_type,
        Accept=accept,
        Body=json.dumps(record) if content_type == "application/json" else record,
    )

    response_body = response["Body"].read().decode("utf-8")

    if accept == "application/json":
        return json.loads(response_body)
    elif accept == "application/jsonlines":
        return response_body
    else:
        raise ValueError(f"Unsupported accept type: {accept}")

# %% [markdown]
# ### Initial Setup

# %%
docs = [
    '''The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.''',
    '''The patient is a 38-year-old male with a history of hypertension, generalized anxiety disorder, major depressive disorder, childhood trauma, smoking, alcohol, cocaine, and marijuana use, presenting with increased anxiety, restlessness, irritability, muscle tension, poor concentration, poor sleep, and decreased appetite over the past 2 months; currently on sertraline 100 mg daily, propranolol 20 mg twice daily, and lisinopril 20 mg daily, and denies suicidal ideation.'''
]


sample_text = """Social History: Patient is a 38 year old Chinese man, construction worker, often exposed to dust, fumes. He is a former smoker, having quit it 10 years ago after smoking a pack a day for 15 years. He occasionally consumes alcohol on weekends . He reports struggles with maintaining a healthy diet due to time constraints and limited access to fresh foods in his neighborhood. Obesity: BMI 32; struggles with weight management. 
Public Health Related Factors: John's occupation as a construction worker exposes him to various occupational hazards, including dust, which may contribute to his respiratory symptoms. While John quit smoking a decade ago, his previous smoking habit puts him at an increased risk for respiratory.
Socioeconomic Factors: John's socioeconomic status, characterized by his occupation as a construction worker and residing in an area with limited access to healthy foods, may impact his ability to maintain a healthy lifestyle and access healthcare services. By addressing John's medical concerns within the context of his occupational and social history, we can provide comprehensive care that not only treats his current symptoms but also promotes his long-term health and well-being. 
Medications: Lisinopril (ACE inhibitor) for hypertension."""

# %% [markdown]
# ### JSON

# %%
input_json_data = {"text": sample_text}
data = invoke_realtime_endpoint(input_json_data, content_type="application/json", accept="application/json")

ner_df = pd.DataFrame(data[0]["ner_predictions"])
assertion_df = pd.DataFrame(data[0]["assertion_predictions"])
relation_df = pd.DataFrame(data[0]["relation_predictions"])

# %%
ner_df
# Out:
#                      ner_chunk  begin   end                  ner_label  \
# 0                      Chinese     41    47             Race_Ethnicity
# 1          construction worker     54    72                 Employment
# 2                       smoker    120   125                    Smoking
# 3                      smoking    162   168                    Smoking
# 4                       a pack    170   175         Substance_Quantity
# 5                      alcohol    222   228                    Alcohol
# 6                 healthy diet    284   295                       Diet
# 7                  fresh foods    343   353            Food_Insecurity
# 8                      Obesity    376   382                    Obesity
# 9                       BMI 32    385   390                        BMI
# 10         construction worker    482   500                 Employment
# 11                     smoking    629   635                    Smoking
# 12                     smoking    664   670                    Smoking
# 13         construction worker    814   832                 Employment
# 14               healthy foods    881   893            Food_Insecurity
# 15  access healthcare services    955   980             Access_To_Care
# 16          comprehensive care   1095  1112             Access_To_Care
# 17                  well-being   1199  1208            Quality_Of_Life
# 18                  Lisinopril   1225  1234                       Drug
# 19               ACE inhibitor   1237  1249                       Drug
# 20                hypertension   1256  1267  Disease_Syndrome_Disorder
#
#    ner_confidence
# 0          0.9627
# 1      0.82774997
# 2          0.9809
# 3           0.994
# 4         0.77585
# 5          0.9693
# 6          0.5705
# 7          0.4106
# 8          0.9118
# 9      0.91419995
# 10         0.8154
# 11         0.9841
# 12         0.9758
# 13     0.77470005
# 14        0.58655
# 15         0.4998
# 16         0.5189
# 17         0.9908
# 18         0.8634
# 19        0.65005
# 20         0.9998

# %%
assertion_df
# Out:
#                      ner_chunk  begin   end                  ner_label  \
# 0          construction worker     54    72                 Employment
# 1                       smoker    120   125                    Smoking
# 2                      smoking    162   168                    Smoking
# 3                      alcohol    222   228                    Alcohol
# 4                 healthy diet    284   295                       Diet
# 5                  fresh foods    343   353            Food_Insecurity
# 6                      Obesity    376   382                    Obesity
# 7                       BMI 32    385   390                    Obesity
# 8          construction worker    482   500                 Employment
# 9                      smoking    629   635                    Smoking
# 10                     smoking    664   670                    Smoking
# 11         construction worker    814   832                 Employment
# 12               healthy foods    881   893            Food_Insecurity
# 13  access healthcare services    955   980             Access_To_Care
# 14          comprehensive care   1095  1112             Access_To_Care
# 15                  well-being   1199  1208            Quality_Of_Life
# 16                hypertension   1256  1267  Disease_Syndrome_Disorder
#
#                  assertion assertion_confidence
# 0          Present_Or_Past               0.5074
# 1          Present_Or_Past               0.5439
# 2          Present_Or_Past               0.5067
# 3   Hypothetical_Or_Absent               0.5323
# 4   Hypothetical_Or_Absent               0.6241
# 5          Present_Or_Past               0.5075
# 6   Hypothetical_Or_Absent               0.5245
# 7          Present_Or_Past               0.6096
# 8          Present_Or_Past               0.5835
# 9          Present_Or_Past               0.5389
# 10         Present_Or_Past               0.5004
# 11         Present_Or_Past               0.6962
# 12         Present_Or_Past               0.5413
# 13  Hypothetical_Or_Absent               0.8683
# 14         Present_Or_Past               0.5939
# 15         Present_Or_Past               0.4943
# 16  Hypothetical_Or_Absent               0.6363

# %%
relation_df
# Out:
#       ner_chunk1 ner_chunk1_begin ner_chunk1_end ner_label1    ner_chunk2  \
# 0         smoker              120            125    Smoking        a pack
# 1        smoking              162            168    Smoking        a pack
# 2        Obesity              376            382    Obesity        BMI 32
# 3     Lisinopril             1225           1234       Drug  hypertension
# 4  ACE inhibitor             1237           1249       Drug  hypertension
#
#   ner_chunk2_begin ner_chunk2_end                 ner_label2  \
# 0              170            175         Substance_Quantity
# 1              170            175         Substance_Quantity
# 2              385            390                        BMI
# 3             1256           1267  Disease_Syndrome_Disorder
# 4             1256           1267  Disease_Syndrome_Disorder
#
#                         relations relation_confidence
# 0      Smoking-Substance_Quantity                 1.0
# 1      Smoking-Substance_Quantity                 1.0
# 2                     Obesity-BMI                 1.0
# 3  Drug-Disease_Syndrome_Disorder                 1.0
# 4  Drug-Disease_Syndrome_Disorder                 1.0

# %% [markdown]
# ### JSON Lines

# %%
def create_jsonl(records):
    if isinstance(records, str):
        records = [records]
    json_records = [{"text": text} for text in records]
    json_lines = "\n".join(json.dumps(record) for record in json_records)
    return json_lines

# %%
input_jsonl_data = create_jsonl(sample_text)
data = invoke_realtime_endpoint(input_jsonl_data, content_type="application/jsonlines" , accept="application/jsonlines" )
print(data)
# Out:
# {"ner_predictions": [{"ner_chunk": "Chinese", "begin": 41, "end": 47, "ner_label": "Race_Ethnicity", "ner_confidence": "0.9627"}, {"ner_chunk": "construction worker", "begin": 54, "end": 72, "ner_label": "Employment", "ner_confidence": "0.82774997"}, {"ner_chunk": "smoker", "begin": 120, "end": 125, "ner_label": "Smoking", "ner_confidence": "0.9809"}, {"ner_chunk": "smoking", "begin": 162, "end": 168, "ner_label": "Smoking", "ner_confidence": "0.994"}, {"ner_chunk": "a pack", "begin": 170, "end": 175, "ner_label": "Substance_Quantity", "ner_confidence": "0.77585"}, {"ner_chunk": "alcohol", "begin": 222, "end": 228, "ner_label": "Alcohol", "ner_confidence": "0.9693"}, {"ner_chunk": "healthy diet", "begin": 284, "end": 295, "ner_label": "Diet", "ner_confidence": "0.5705"}, {"ner_chunk": "fresh foods", "begin": 343, "end": 353, "ner_label": "Food_Insecurity", "ner_confidence": "0.4106"}, {"ner_chunk": "Obesity", "begin": 376, "end": 382, "ner_label": "Obesity", "ner_confidence": "0.9118"}, {"ner_chunk": "BMI 32", "begin": 385, "end": 390, "ner_label": "BMI", "ner_confidence": "0.91419995"}, {"ner_chunk": "construction worker", "begin": 482, "end": 500, "ner_label": "Employment", "ner_confidence": "0.8154"}, {"ner_chunk": "smoking", "begin": 629, "end": 635, "ner_label": "Smoking", "ner_confidence": "0.9841"}, {"ner_chunk": "smoking", "begin": 664, "end": 670, "ner_label": "Smoking", "ner_confidence": "0.9758"}, {"ner_chunk": "construction worker", "begin": 814, "end": 832, "ner_label": "Employment", "ner_confidence": "0.77470005"}, {"ner_chunk": "healthy foods", "begin": 881, "end": 893, "ner_label": "Food_Insecurity", "ner_confidence": "0.58655"}, {"ner_chunk": "access healthcare services", "begin": 955, "end": 980, "ner_label": "Access_To_Care", "ner_confidence": "0.4998"}, {"ner_chunk": "comprehensive care", "begin": 1095, "end": 1112, "ner_label": "Access_To_Care", "ner_confidence": "0.5189"}, {"ner_chunk": "well-being", "begin": 1199, "end": 1208, "ner_label": "Quality_Of_Life", "ner_confidence": "0.9908"}, {"ner_chunk": "Lisinopril", "begin": 1225, "end": 1234, "ner_label": "Drug", "ner_confidence": "0.8634"}, {"ner_chunk": "ACE inhibitor", "begin": 1237, "end": 1249, "ner_label": "Drug", "ner_confidence": "0.65005"}, {"ner_chunk": "hypertension", "begin": 1256, "end": 1267, "ner_label": "Disease_Syndrome_Disorder", "ner_confidence": "0.9998"}], "assertion_predictions": [{"ner_chunk": "construction worker", "begin": 54, "end": 72, "ner_label": "Employment", "assertion": "Present_Or_Past", "assertion_confidence": "0.5074"}, {"ner_chunk": "smoker", "begin": 120, "end": 125, "ner_label": "Smoking", "assertion": "Present_Or_Past", "assertion_confidence": "0.5439"}, {"ner_chunk": "smoking", "begin": 162, "end": 168, "ner_label": "Smoking", "assertion": "Present_Or_Past", "assertion_confidence": "0.5067"}, {"ner_chunk": "alcohol", "begin": 222, "end": 228, "ner_label": "Alcohol", "assertion": "Hypothetical_Or_Absent", "assertion_confidence": "0.5323"}, {"ner_chunk": "healthy diet", "begin": 284, "end": 295, "ner_label": "Diet", "assertion": "Hypothetical_Or_Absent", "assertion_confidence": "0.6241"}, {"ner_chunk": "fresh foods", "begin": 343, "end": 353, "ner_label": "Food_Insecurity", "assertion": "Present_Or_Past", "assertion_confidence": "0.5075"}, {"ner_chunk": "Obesity", "begin": 376, "end": 382, "ner_label": "Obesity", "assertion": "Hypothetical_Or_Absent", "assertion_confidence": "0.5245"}, {"ner_chunk": "BMI 32", "begin": 385, "end": 390, "ner_label": "Obesity", "assertion": "Present_Or_Past", "assertion_confidence": "0.6096"}, {"ner_chunk": "construction worker", "begin": 482, "end": 500, "ner_label": "Employment", "assertion": "Present_Or_Past", "assertion_confidence": "0.5835"}, {"ner_chunk": "smoking", "begin": 629, "end": 635, "ner_label": "Smoking", "assertion": "Present_Or_Past", "assertion_confidence": "0.5389"}, {"ner_chunk": "smoking", "begin": 664, "end": 670, "ner_label": "Smoking", "assertion": "Present_Or_Pa ...

# %% [markdown]
# ### B. Delete the endpoint

# %% [markdown]
# Now that you have successfully performed a real-time inference, you do not need the endpoint any more. You can terminate the endpoint to avoid being charged.

# %%
model.sagemaker_session.delete_endpoint(model_name)
model.sagemaker_session.delete_endpoint_config(model_name)

# %% [markdown]
# ## 4. Batch inference

# %%
validation_json_file_name = "input.json"
validation_jsonl_file_name = "input.jsonl"

validation_input_json_path = f"s3://{s3_bucket}/{model_name}/validation-input/json/"
validation_output_json_path = f"s3://{s3_bucket}/{model_name}/validation-output/json/"

validation_input_jsonl_path = f"s3://{s3_bucket}/{model_name}/validation-input/jsonl/"
validation_output_jsonl_path = f"s3://{s3_bucket}/{model_name}/validation-output/jsonl/"

def upload_to_s3(input_data, file_name):
    file_format = os.path.splitext(file_name)[1].lower()
    s3_client.put_object(
        Bucket=s3_bucket,
        Key=f"{model_name}/validation-input/{file_format[1:]}/{file_name}",
        Body=input_data.encode("UTF-8"),
    )

# %%
# Create JSON and JSON Lines data
input_jsonl_data = create_jsonl(docs)
input_json_data = json.dumps({"text": docs})

# Upload JSON and JSON Lines data to S3
upload_to_s3(input_json_data, validation_json_file_name)
upload_to_s3(input_jsonl_data, validation_jsonl_file_name)

# %% [markdown]
# ### JSON

# %%
transformer = model.transformer(
    instance_count=1,
    instance_type=batch_transform_inference_instance_type,
    accept="application/json",
    output_path=validation_output_json_path
)

transformer.transform(validation_input_json_path, content_type="application/json")
transformer.wait()

# %%
def retrieve_json_output_from_s3(validation_file_name):
    parsed_url = urlparse(transformer.output_path)
    file_key = f"{parsed_url.path[1:]}{validation_file_name}.out"
    response = s3_client.get_object(Bucket=s3_bucket, Key=file_key)

    data = json.loads(response["Body"].read().decode("utf-8"))
    display(data)

# %%
retrieve_json_output_from_s3(validation_json_file_name)
# Out:
# [{'ner_predictions': [{'ner_chunk': 'insulin',
#     'begin': 59,
#     'end': 65,
#     'ner_label': 'Drug',
#     'ner_confidence': '0.9764'},
#    {'ner_chunk': 'diabetes',
#     'begin': 77,
#     'end': 84,
#     'ner_label': 'Disease_Syndrome_Disorder',
#     'ner_confidence': '0.6342'},
#    {'ner_chunk': 'type 2',
#     'begin': 87,
#     'end': 92,
#     'ner_label': 'Disease_Syndrome_Disorder',
#     'ner_confidence': '0.96895003'},
#    {'ner_chunk': 'Bactrim',
#     'begin': 120,
#     'end': 126,
#     'ner_label': 'Drug',
#     'ner_confidence': '0.999'},
#    {'ner_chunk': 'UTI',
#     'begin': 144,
#     'end': 146,
#     'ner_label': 'Disease_Syndrome_Disorder',
#     'ner_confidence': '0.9903'},
#    {'ner_chunk': 'Fragmin',
#     'begin': 183,
#     'end': 189,
#     'ner_label': 'Drug',
#     'ner_confidence': '0.9984'},
#    {'ner_chunk': 'Lantus',
#     'begin': 229,
#     'end': 234,
#     'ner_label': 'Drug',
#     'ner_confidence': '0.9969'}],
#   'assertion_predictions': [{'ner_chunk': 'insulin dependent diabetes',
#     'begin': 59,
#     'end': 84,
#     'ner_label': 'Disease_Syndrome_Disorder',
#     'assertion': 'Hypothetical_Or_Absent',
#     'assertion_confidence': '0.5407'},
#    {'ner_chunk': 'type 2',
#     'begin': 87,
#     'end': 92,
#     'ner_label': 'Disease_Syndrome_Disorder',
#     'assertion': 'Hypothetical_Or_Absent',
#     'assertion_confidence': '0.7708'},
#    {'ner_chunk': 'UTI',
#     'begin': 144,
#     'end': 146,
#     'ner_label': 'Disease_Syndrome_Disorder',
#     'assertion': 'Hypothetical_Or_Absent',
#     'assertion_confidence': '0.6465'}],
#   'relation_predictions': [{'ner_chunk1': 'insulin',
#     'ner_chunk1_begin': '59',
#     'ner_chunk1_end': '65',
#     'ner_label1': 'Drug',
#     'ner_chunk2': 'diabetes',
#     'ner_chunk2_begin': '77',
#     'ner_chunk2_end': '84',
#     'ner_label2': 'Disease_Syndrome_Disorder',
#     'relations': 'Drug-Disease_Syndrome_Disorder',
#     'relation_confidence': '1.0'},
#    {'ner_chunk1': 'insulin',
#     'ner_chunk1_begin': '59',
#     'ner_chunk1_end': '65',
#     'ner_label1': 'Drug',
#     'ner_chunk2': 'type 2',
#     'ner_chunk2_begin': '87',
#     'ner_chunk2_end': '92',
#     'ner_label2': 'Disease_Syndrome_Disorder',
#     'relations': 'Drug-Disease_Syndrome_Disorder',
#     'relation_confidence': '1.0'},
#    {'ner_chunk1': 'Bactrim',
#     'ner_chunk1_begin': '120',
#     'ner_chunk1_end': '126',
#     'ner_label1': 'Drug',
#     'ner_chunk2': 'UTI',
#     'ner_chunk2_begin': '144',
#     'ner_chunk2_end': '146',
#     'ner_label2': 'Disease_Syndrome_Disorder',
#     'relations': 'Drug-Disease_Syndrome_Disorder',
#     'relation_confidence': '1.0'}]},
#  {'ner_predictions': [{'ner_chunk': 'hypertension',
#     'begin': 52,
#     'end': 63,
#     'ner_label': 'Disease_Syndrome_Disorder',
#     'ner_confidence': '0.9997'},
#    {'ner_chunk': 'generalized anxiety disorder',
#     'begin': 66,
#     'end': 93,
#     'ner_label': 'Mental_Health',
#     'ner_confidence': '0.4836'},
#    {'ner_chunk': 'major depressive disorder',
#     'begin': 96,
#     'end': 120,
#     'ner_label': 'Psychological_Condition',
#     'ner_confidence': '0.8868666'},
#    {'ner_chunk': 'childhood trauma',
#     'begin': 123,
#     'end': 138,
#     'ner_label': 'Disease_Syndrome_Disorder',
#     'ner_confidence': '0.57405'},
#    {'ner_chunk': 'smoking',
#     'begin': 141,
#     'end': 147,
#     'ner_label': 'Smoking',
#     'ner_confidence': '0.9887'},
#    {'ner_chunk': 'alcohol',
#     'begin': 150,
#     'end': 156,
#     'ner_label': 'Alcohol',
#     'ner_confidence': '0.9946'},
#    {'ner_chunk': 'cocaine',
#     'begin': 159,
#     'end': 165,
#     'ner_label': 'Drug',
#     'ner_confidence': '0.8971'},
#    {'ner_chunk': 'marijuana',
#     'begin': 172,
#     'end': 180,
#     'ner_label': 'Substance',
#     'ner_confidence': '0.995'},
#    {'ner_chunk': 'anxiety',
#     'begin': 213,
#     'end': 219,
#     'ner_label': 'Psychological_Condition',
#     'ner_confidence': '0.9704'},
#    {'ner_chunk': 'restlessness',
#     'begin': 222,
#     'end': 233,
#     'ner_label': 'Mental_Health',
#     'ner_confidence': '0.8826'},
#    {'ner_chunk': 'poor sleep',
#     'begin': 286,
#     'end': 295,
#     'ner_label': 'Mental_Health',
#     'ner_confidence': '0.4207'},
#    {'ner_chunk': 'sertraline',
#     'begin': 358,
#     'end': 367,
#     'ner_label': 'Drug',
#     'ner_confidence': '0.9969'},
#    {'ner_chunk': 'propranolol',
#     'begin': 383,
#     'end': 393,
#     'ner_label': 'Drug',
#     'ner_confidence': '0.9986'},
#    {'ner_chunk': 'lisinopril',
#     'begin': 418,
#     'end': 427,
#     'ner_label': 'Drug',
#     'ner_confidence': '0.9996'},
#    {'ner_chunk': 'suicidal ideation',
#     'begin': 453,
#     'end': 469,
#     'ner_label': 'Mental_Health',
#     'ner_confidence': '0.7844'}],
#   'assertion_predictions': [{'ner_chunk': 'hypertension',
#     'begin': 52,
#     'end': 63,
#     'ner_label': 'Disease_Syndrome_Disorder',
#     'assertion': 'Present_Or_Past',
#     'assertion_confidence': '0.8814'},
#    {'ner_chunk': 'generalized anxiety disorder',
#     'begin': 66,
#     'end': 93,
#     'ner_label': 'Mental_Health',
#     'assertion': 'Present_Or_Past',
#     'assertion_confidence': '0.9048'},
#    {'ner_chunk': 'major depressive disorder',
#     'begin': 96,
#     'end': 120,
#     'ner_label': 'Psychological_Condition',
#     'assertion': 'Present_Or_Past',
#     'assertion_confidence': '0.9006'},
#    {'ner_chunk': 'childhood trauma',
#     'begin': 123,
#     'end': 138,
#     'ner_label': 'Disease_Syndrome_Disorder',
#     'assertion': 'Present_Or_Past',
#     'assertion_confidence': '0.8195'},
#    {'ner_chunk': 'smoking',
#     'begin': 141,
#     'end': 147,
#     'ner_label': 'Smoking',
#     'assertion': 'Present_Or_Past',
#     'assertion_confidence': '0.88'},
#    {'ner_chunk': 'alcohol',
#     'begin': 150,
#     'end': 156,
#     'ner_label': 'Alcohol',
#     'assertion': 'Present_Or_Past',
#     'assertion_confidence': '0.8799'},
#    {'ner_chunk': 'cocaine',
#     'begin': 159,
#     'end': 165,
#     'ner_label': 'Substance',
#     'assertion': 'Present_Or_Past',
#     'assertion_confidence': '0.8798'},
#    {'ner_chunk': 'marijuana use',
#     'begin': 172,
#     'end': 184,
#     'ner_label': 'Substance',
#     'assertion': 'Present_Or_Past',
#     'assertion_confidence': '0.883'},
#    {'ner_chunk': 'anxiety',
#     'begin': 213,
#     'end': 219,
#     'ner_label': 'Psychological_Condition',
#     'assertion': 'Present_Or_Past',
#     'assertion_confidence': '0.8795'},
#    {'ner_chunk': 'restlessness',
#     'begin': 222,
#     'end': 233,
#     'ner_label': 'Mental_Health',
#     'assertion': 'Present_Or_Past',
#     'assertion_confidence': '0.8794'},
#    {'ner_chunk': 'poor sleep',
#     'begin': 286,
#     'end': 295,
#     'ner_label': 'Mental_Health',
#     'assertion': 'Present_Or_Past',
#     'assertion_confidence': '0.8788'},
#    {'ner_chunk': 'suicidal ideation',
#     'begin': 453,
#     'end': 469,
#     'ner_label': 'Mental_Health',
#     'assertion': 'Hypothetical_Or_Absent',
#     'assertion_confidence': '0.6815'}],
#   'relation_predictions': [{'ner_chunk1': 'hypertension',
#     'ner_chunk1_begin': '52',
#     'ner_chunk1_end': '63',
#     'ner_label1': 'Disease_Syndrome_Disorder',
#     'ner_chunk2': 'sertraline',
#     'ner_chunk2_begin': '358',
#     'ner_chunk2_end': '367',
#     'ner_label2': 'Drug',
#     'relations': 'Disease_Syndrome_Disorder-Drug',
#     'relation_confidence': '1.0'},
#    {'ner_chunk1': 'generalized anxiety disorder',
#     'ner_chunk1_begin': '66',
#     'ner_chunk1_end': '93',
#     'ner_label1': 'Mental_Health',
#     'ner_chunk2': 'sertraline',
#     'ner_chunk2_begin': '358',
#     'ner_chunk2_end': '367',
#     'ner_label2': 'Drug',
#     'relations': 'Mental_Health-Drug',
#     'relation_confidence': '1.0'},
#    {'ner_chunk1': 'childhood trauma',
#     'ner_chunk1_begin': '123',
#     'ner_chunk1_end': '138',
#     'ner_label1': 'Disease_Syndrome_Disorder',
#     'ner_chunk2': 'cocaine',
#     'ner_chunk2_begin': '159',
#     'ner_chunk2_end': '165',
#     'ner_label2': 'Drug',
#     'relations': 'Disease_Syndrome_Disorder-Drug',
#     'relation_confidence': '1.0'},
#    {'ner_chunk1': 'anxiety',
#     'ner_chunk1_begin': '213',
#     'ner_chunk1_end': '219',
#     'ner_label1': 'Psychological_Condition',
#     'ner_chunk2': 'sertraline',
#     'ner_chunk2_begin': '358',
#     'ner_chunk2_end': '367',
#     'ner_label2': 'Drug',
#     'relations': 'Psychological_Condition-Drug',
#     'relation_confidence': '1.0'},
#    {'ner_chunk1': 'restlessness',
#     'ner_chunk1_begin': '222',
#     'ner_chunk1_end': '233',
#     'ner_label1': 'Mental_Health',
#     'ner_chunk2': 'sertraline',
#     'ner_chunk2_begin': '358',
#     'ner_chunk2_end': '367',
#     'ner_label2': 'Drug',
#     'relations': 'Mental_Health-Drug',
#     'relation_confidence': '1.0'},
#    {'ner_chunk1': 'lisinopril',
#     'ner_chunk1_begin': '418',
#     'ner_chunk1_end': '427',
#     'ner_label1': 'Drug',
#     'ner_chunk2': 'suicidal ideation',
#     'ner_chunk2_begin': '453',
#     'ner_chunk2_end': '469',
#     'ner_label2': 'Mental_Health',
#     'relations': 'Drug-Mental_Health',
#     'relation_confidence': '1.0'}]}]

# %% [markdown]
# ### JSON Lines

# %%
transformer = model.transformer(
    instance_count=1,
    instance_type=batch_transform_inference_instance_type,
    accept="application/jsonlines",
    output_path=validation_output_jsonl_path
)
transformer.transform(validation_input_jsonl_path, content_type="application/jsonlines")
transformer.wait()

# %%
def retrieve_jsonlines_output_from_s3(validation_file_name):

    parsed_url = urlparse(transformer.output_path)
    file_key = f"{parsed_url.path[1:]}{validation_file_name}.out"
    response = s3_client.get_object(Bucket=s3_bucket, Key=file_key)

    data = response["Body"].read().decode("utf-8")
    print(data)

# %%
retrieve_jsonlines_output_from_s3(validation_jsonl_file_name)
# Out:
# {"ner_predictions": [{"ner_chunk": "insulin", "begin": 59, "end": 65, "ner_label": "Drug", "ner_confidence": "0.9764"}, {"ner_chunk": "diabetes", "begin": 77, "end": 84, "ner_label": "Disease_Syndrome_Disorder", "ner_confidence": "0.6342"}, {"ner_chunk": "type 2", "begin": 87, "end": 92, "ner_label": "Disease_Syndrome_Disorder", "ner_confidence": "0.96895003"}, {"ner_chunk": "Bactrim", "begin": 120, "end": 126, "ner_label": "Drug", "ner_confidence": "0.999"}, {"ner_chunk": "UTI", "begin": 144, "end": 146, "ner_label": "Disease_Syndrome_Disorder", "ner_confidence": "0.9903"}, {"ner_chunk": "Fragmin", "begin": 183, "end": 189, "ner_label": "Drug", "ner_confidence": "0.9984"}, {"ner_chunk": "Lantus", "begin": 229, "end": 234, "ner_label": "Drug", "ner_confidence": "0.9969"}], "assertion_predictions": [{"ner_chunk": "insulin dependent diabetes", "begin": 59, "end": 84, "ner_label": "Disease_Syndrome_Disorder", "assertion": "Hypothetical_Or_Absent", "assertion_confidence": "0.5407"}, {"ner_chunk": "type 2", "begin": 87, "end": 92, "ner_label": "Disease_Syndrome_Disorder", "assertion": "Hypothetical_Or_Absent", "assertion_confidence": "0.7708"}, {"ner_chunk": "UTI", "begin": 144, "end": 146, "ner_label": "Disease_Syndrome_Disorder", "assertion": "Hypothetical_Or_Absent", "assertion_confidence": "0.6465"}], "relation_predictions": [{"ner_chunk1": "insulin", "ner_chunk1_begin": "59", "ner_chunk1_end": "65", "ner_label1": "Drug", "ner_chunk2": "diabetes", "ner_chunk2_begin": "77", "ner_chunk2_end": "84", "ner_label2": "Disease_Syndrome_Disorder", "relations": "Drug-Disease_Syndrome_Disorder", "relation_confidence": "1.0"}, {"ner_chunk1": "insulin", "ner_chunk1_begin": "59", "ner_chunk1_end": "65", "ner_label1": "Drug", "ner_chunk2": "type 2", "ner_chunk2_begin": "87", "ner_chunk2_end": "92", "ner_label2": "Disease_Syndrome_Disorder", "relations": "Drug-Disease_Syndrome_Disorder", "relation_confidence": "1.0"}, {"ner_chunk1": "Bactrim", "ner_chunk1_begin": "120", "ner_chunk1_end": "126", "ner_label1": "Drug", "ner_chunk2": "UTI", "ner_chunk2_begin": "144", "ner_chunk2_end": "146", "ner_label2": "Disease_Syndrome_Disorder", "relations": "Drug-Disease_Syndrome_Disorder", "relation_confidence": "1.0"}]}
# {"ner_predictions": [{"ner_chunk": "hypertension", "begin": 52, "end": 63, "ner_label": "Disease_Syndrome_Disorder", "ner_confidence": "0.9997"}, {"ner_chunk": "generalized anxiety disorder", "begin": 66, "end": 93, "ner_label": "Mental_Health", "ner_confidence": "0.4836"}, {"ner_chunk": "major depressive disorder", "begin": 96, "end": 120, "ner_label": "Psychological_Condition", "ner_confidence": "0.8868666"}, {"ner_chunk": "childhood trauma", "begin": 123, "end": 138, "ner_label": "Disease_Syndrome_Disorder", "ner_confidence": "0.57405"}, {"ner_chunk": "smoking", "begin": 141, "end": 147, "ner_label": "Smoking", "ner_confidence": "0.9887"}, {"ner_chunk": "alcohol", "begin": 150, "end": 156, "ner_label": "Alcohol", "ner_confidence": "0.9946"}, {"ner_chunk": "cocaine", "begin": 159, "end": 165, "ner_label": "Drug", "ner_confidence": "0.8971"}, {"ner_chunk": "marijuana", "begin": 172, "end": 180, "ner_label": "Substance", "ner_confidence": "0.995"}, {"ner_chunk": "anxiety", "begin": 213, "end": 219, "ner_label": "Psychological_Condition", "ner_confidence": "0.9704"}, {"ner_chunk": "restlessness", "begin": 222, "end": 233, "ner_label": "Mental_Health", "ner_confidence": "0.8826"}, {"ner_chunk": "poor sleep", "begin": 286, "end": 295, "ner_label": "Mental_Health", "ner_confidence": "0.4207"}, {"ner_chunk": "sertraline", "begin": 358, "end": 367, "ner_label": "Drug", "ner_confidence": "0.9969"}, {"ner_chunk": "propranolol", "begin": 383, "end": 393, "ner_label": "Drug", "ner_confidence": "0.9986"}, {"ner_chunk": "lisinopril", "begin": 418, "end": 427, "ner_label": "Drug", "ner_confidence": "0.9996"}, {"ner_chunk": "suicidal ideation", "begin": 453, "end": 469, "ner_label": "Mental_Health", "ner_confidence": "0.7844"}], "assertion_predictions": [{"ner_chunk": "hypertension", "begin": 52, "end": 63, "ner_label": "Disease_Syndrome_Disorder", "assertion": "Present_Or_Past", "assertion_confidence": "0.8814"}, {"ner_chunk": "generalized anxiety disorder", "begin": 66, "end": 93, "ner_label": "Mental_Health", "assertion": "Present_Or_Past", "assertion_confidence": "0.9048"}, {"ner_chunk": "major depressive disorder", "begin": 96, "end": 120, "ner_label": "Psychological_Condition", "assertion": "Present_Or_Past", "assertion_confidence": "0.9006"}, {"ner_chunk": "childhood trauma", "begin": 123, "end": 138, "ner_label": "Disease_Syndrome_Disorder", "assertion": "Present_Or_Past", "assertion_confidence": "0.8195"}, {"ner_chunk": "smoking", "begin": 141, "end": 147, "ner_label": "Smoking", "assertion": "Present_Or_Past", "assertion_confidence": "0.88"}, {"ner_chunk": "alcohol", "begin": 150, "end": 156, "ner_label": "Alcohol", "assertion": "Present_Or_Past", "assertion_confidence": "0.8799"}, {"ner_chunk": "cocaine", "begin": 159, "end": 165, "ner_label": "Substance", "assertion": "Present_Or_Past", "assertion_confidence": "0.8798"}, {"ner_chunk": "marijuana use", "begin": 172, "end": 184, "ner_label": "Substance", "assertion": "Present_Or_Past", "assertion_confidence": "0.883"}, {"ner_chunk": "anxiety", "begin": 213, "end": 219, "ner_label": "Psychological_Condition", "assertion": "Present_Or_Past", "assertion_confidence": "0.8795"}, {"ner_chunk": "restlessness", "begin": 222, "end": 233, "ner_label": "Mental_Health", "assertion": "Present_Or_Past", "assertion_confidence": "0.8794"}, {"ner_chunk": "poor sleep", "begin": 286, "end": 295, "ner_label": "Mental_Health", "assertion": "Present_Or_Past", "assertion_confidence": "0.8788"}, {"ner_chunk": "suicidal ideation", "begin": 453, "end": 469, "ner_label": "Mental_Health", "assertion": "Hypothetical_Or_Absent", "assertion_confidence": "0.6815"}], "relation_predictions": [{"ner_chunk1": "hypertension", "ner_chunk1_begin": "52", "ner_chunk1_end": "63", "ner_label1": "Disease_Syndrome_Disorder", "ner_chunk2": "sertraline", "ner_chunk2_begin": "358", "ner_chunk2_end": "367", "ner_label2": "Drug", "relations": "Disease_Syndrome_Disorder-Drug", "relation_confidence": "1.0"}, {"ner_chunk1": "general ...

# %%
model.delete_model()

# %% [markdown]
# ### Unsubscribe to the listing (optional)

# %% [markdown]
# If you would like to unsubscribe to the model package, follow these steps. Before you cancel the subscription, ensure that you do not have any [deployable model](https://console.aws.amazon.com/sagemaker/home#/models) created from the model package or using the algorithm. Note - You can find this information by looking at the container name associated with the model.
#
# **Steps to unsubscribe to product from AWS Marketplace**:
# 1. Navigate to __Machine Learning__ tab on [__Your Software subscriptions page__](https://aws.amazon.com/marketplace/ai/library?productType=ml&ref_=mlmp_gitdemo_indust)
# 2. Locate the listing that you want to cancel the subscription for, and then choose __Cancel Subscription__  to cancel the subscription.
