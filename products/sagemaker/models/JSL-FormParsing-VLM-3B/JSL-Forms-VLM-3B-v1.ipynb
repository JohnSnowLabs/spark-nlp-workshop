# %% [markdown]
# ## 1. Subscribe to the model package

# %% [markdown]
# To subscribe to the model package:
# 1. Open the model package listing page [JSL Forms - 3B ]()
# 1. On the AWS Marketplace listing, click on the **Continue to subscribe** button.
# 1. On the **Subscribe to this software** page, review and click on **"Accept Offer"** if you and your organization agrees with EULA, pricing, and support terms.
# 1. Once you click on **Continue to configuration button** and then choose a **region**, you will see a **Product Arn** displayed. This is the model package ARN that you need to specify while creating a deployable model using Boto3. Copy the ARN corresponding to your region and specify the same in the following cell.

# %% [markdown]
# **Model**: `JSL-Forms-VLM-3B-v1`
# **Model Description**: Medical LLM built for advanced clinical reasoning, complex medical case analysis, and deep comprehension of biomedical literature. Optimized for summarization, clinical question answering, and retrieval-augmented generation (RAG), it delivers high-accuracy responses in critical healthcare applications where depth and precision are essential.

# %%
model_package_arn = "<Customer to specify Model package ARN corresponding to their AWS region>"

# %%
import os
import io
import base64
import json
import uuid
import requests
from sagemaker import ModelPackage
import sagemaker as sage
from sagemaker import get_execution_role
import boto3
from IPython.display import Image, display
from PIL import Image as ImageEdit
import numpy as np
import pandas as pd
from IPython.display import Image

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

sagemaker_session = sage.Session()
s3_bucket = sagemaker_session.default_bucket()
region = sagemaker_session.boto_region_name
account_id = boto3.client("sts").get_caller_identity().get("Account")
role = get_execution_role()

sagemaker = boto3.client("sagemaker")
s3_client = sagemaker_session.boto_session.client("s3")
ecr = boto3.client("ecr")
sm_runtime = boto3.client("sagemaker-runtime")

# %%
model_name = "JSL-Forms-VLM-3B-v1"

real_time_inference_instance_type = "ml.g4dn.12xlarge"
batch_transform_inference_instance_type = "ml.g4dn.12xlarge"

# %% [markdown]
# ## 2. Create a deployable model from the model package.

# %%
model = ModelPackage(
    role=role, 
    model_package_arn=model_package_arn, 
    sagemaker_session=sagemaker_session, 
)

# %%
import base64

def encode_file_to_base64(file_path: str) -> str:
    """
    Reads a file from disk and returns its base64-encoded string.

    Args:
        file_path (str): Path to the file on disk.

    Returns:
        str: Base64-encoded string of the file contents.
    """
    with open(file_path, "rb") as file:
        encoded_bytes = base64.b64encode(file.read())
        return encoded_bytes.decode("utf-8")

# %% [markdown]
# ## Model Configuration Documentation
#
# ### Default Configuration
# The container comes with the following default configurations:
#
# | Parameter                  | Default Value | Description                                                                   |
# |----------------------------|---------------|-------------------------------------------------------------------------------|
# | **`dtype`**                | `float16`     | Data type for model weights and activations                                   |
# | **`max_model_len`**        | `16,192`      | Maximum length for input and output combined (`input + output ≤ max_model_len`) |
# | **`tensor_parallel_size`** | Auto          | Automatically set to the number of available GPUs                            |
# | **`host`**                 | `0.0.0.0`     | Host name                                                                     |
# | **`port`**                 | `8080`        | Port number                                                                   |
#
# ### Hardcoded Settings
# The following settings are hardcoded in the container and cannot be changed:
#
# | Parameter       | Value           | Description                           |
# |-----------------|-----------------|---------------------------------------|
# | **`model`**     | `/opt/ml/model` | Model path where SageMaker mounts the model |
#
# ### Configurable Environment Variables
# You can customize vLLM by setting environment variables when creating the model.
#
# **Any parameter from the [vLLM documentation](https://docs.vllm.ai/en/latest/serving/openai_compatible_server.html#vllm-serve) can be set using the corresponding environment variable with the `SM_VLLM_` prefix.**
#
# The container converts environment variables to vllm engine arguments.
#
# ---
#
# ## Input Format
#
# ### Chat Completion
#
# #### Example Payload
#
# ##### Online Image Example
#
# ```json
# {
#     "model": "/opt/ml/model",
#     "messages": [
#         {
#             "role": "user",
#             "content": [
#                 {
#                     "type": "image_url",
#                     "url": "https://raw.githubusercontent.com/JohnSnowLabs/visual-nlp-workshop/7f5eec01dd96897dccb064d1e42a4ef2e90083a0/jupyter/data/funsd/83823750.png"
#                 }
#             ]
#         }
#     ]
# }
# ```
#
# For additional parameters:
# - [ChatCompletionRequest](https://github.com/vllm-project/vllm/blob/v0.7.3/vllm/entrypoints/openai/protocol.py#L212)
# - [OpenAI's Chat API](https://platform.openai.com/docs/api-reference/chat/create)
#
# ---
#
#
# ##### Offline Image Example (Base64)
# ```json
# {
#     "model": "/opt/ml/model",
#     "messages": [
#         {"role": "system", "content": "You are a helpful medical assistant."},
#         {
#             "role": "user",
#             "content": [
#                 {
#                  "type": "image_url",
#                  "image_url": "data:image/jpeg;base64,..."
#                 }
#             ]
#         }
#     ]
# }
# ```
#
# Reference:
# - [vLLM Vision Language Models Documentation](https://docs.vllm.ai/en/v0.6.2/models/vlm.html)
#
# ---
#
# ### Important Notes:
# - **Model Path Requirement:** Always set `"model": "/opt/ml/model"` (SageMaker's fixed model location)

# %% [markdown]
# ## 3. Create an SageMaker Endpoint

# %% [markdown]
# If you want to understand how real-time inference with Amazon SageMaker works, see [Documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/how-it-works-hosting.html).

# %%
predictor = model.deploy(
    initial_instance_count=1,
    instance_type=real_time_inference_instance_type, 
    endpoint_name=model_name,
    model_data_download_timeout=3600
)
# Out:
# --------!

# %% [markdown]
# ### 3.1 Real-time inference via Amazon SageMaker Endpoint

# %% [markdown]
# #### Initial setup

# %%
# !wget --no-check-certificate https://raw.githubusercontent.com/JohnSnowLabs/visual-nlp-workshop/7f5eec01dd96897dccb064d1e42a4ef2e90083a0/jupyter/data/funsd/82254765.png

# %%
image_url = "https://raw.githubusercontent.com/JohnSnowLabs/visual-nlp-workshop/7f5eec01dd96897dccb064d1e42a4ef2e90083a0/jupyter/data/funsd/83823750.png"

# %%
def invoke_realtime_endpoint(record):

    response = sm_runtime.invoke_endpoint(
        EndpointName=model_name,
        ContentType="application/json",
        Accept="application/json",
        Body=json.dumps(record),
    )

    return json.load(response["Body"])

# %% [markdown]
# #### Chat Completion

# %% [markdown]
# #### Offline

# %%
# Show image from file path
Image(filename='./82254765.png')

# %%
input_data = {
    "model": "/opt/ml/model",
    "messages": [
        {
            "role": "user",
            "content": [
                {
                    "type": "image_url",
                    "url": f"data:image/jpeg;base64,{encode_file_to_base64('./82254765.png')}",
                }
            ],
        },
    ],
}

result = invoke_realtime_endpoint(input_data)
output_content = result["output"]
print(output_content)
# Out:
# [{"text":"TO:","label":"question","children":[{"text":"K A SPARROW","label":"answer"}]},{"text":"DATE TO NYO:","label":"question","children":[{"text":"1/ 24/ 97","label":"answer"}]},{"text":"FROM:","label":"question","children":[{"text":"S. Reindel","label":"answer"}]},{"text":"DIV. NAME / NO:","label":"question","children":[{"text":"Nassau / 107","label":"answer"}]},{"text":"1997 SPECIAL EVENT REQUEST FORM","label":"other"},{"text":"NAME OF EVENT:","label":"question","children":[{"text":"H. Levinson Tradeshow","label":"answer"}]},{"text":"*DATE OF EVENT:","label":"question","children":[{"text":"3/ 18/ 97","label":"answer"}]},{"text":"SAMPLES / ITEMS REQUIRED:","label":"question","children":[{"text":"SAMPLE 10'S (400 PACKS PER CASE)","label":"answer"}]},{"text":"# CASES","label":"other"},{"text":"NEWPORT K.S.","label":"question","children":[{"text":"2","label":"answer"}]},{"text":"KENT III K.S.","label":"question","children":[{"text":"KENT GL LTS K.S.","label":"answer"}]},{"text":"NEWPORT 100'S","label":"question","children":[{"text":"KENT III 100","label":"answer"}]},{"text":"NEWPORT LTS. K.S.","label":"question","children":[{"text":"1","label":"answer"}]},{"text":"KENT GL 100","label":"question","children":[{"text":"KENT GL LTS K.S.","label":"answer"}]},{"text":"TRUE K.S.","label":"question","children":[{"text":"1","label":"answer"}]},{"text":"NEWPORT LTS. 100","label":"question","children":[{"text":"1","label":"answer"}]},{"text":"KENT K.S.","label":"question","children":[{"text":"1","label":"answer"}]},{"text":"KENT 100","label":"question","children":[{"text":"1","label":"answer"}]},{"text":"ITEMS","label":"other"},{"text":"QUANTITY REQUIRED","label":"other"},{"text":"BASEBALL CAP","label":"question","children":[{"text":"1500","label":"answer"}]},{"text":"WATER BOTTLES","label":"question","children":[{"text":"500","label":"answer"}]},{"text":"SHIP TO:","label":"other"},{"text":"CUSTOMER SHIPPING NUMBER","label":"question","children":[{"text":"198- 1160006","label":"answer"}]},{"text":"NYO ONLY:","label":"question","children":[{"text":"2/ 6/ 97","label":"answer"}]},{"text":"NYO ONLY:","label":"other","children":[{"text":"DATE FORWARDED TO PROMOTION SERVICES:","label":"question","children":[{"text":"2/ 6/ 97","label":"answer"}]}]},{"text":"82254765","label":"other"},{"text":"* PLEASE ALLOW 6 WEEKS FOR PROCESSING OF YOUR REQUEST.","label":"other"},{"text":"REQFORM","label":"other"},{"text":"01/ 17/ 97","label":"other"}]

# %% [markdown]
# #### Online

# %%
response = requests.get(image_url)
response.raise_for_status()
img = ImageEdit.open(io.BytesIO(response.content))
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=754x1000>

# %%
input_data = {
    "model": "/opt/ml/model",
    "messages": [
        {"role": "user", "content": [{"type": "image_url", "url": image_url}]}
    ],
}

result = invoke_realtime_endpoint(input_data)
output_content = result["output"]
print(output_content)
# Out:
# [{"text":"5578 DPW 30-59","label":"other"},{"text":"001","label":"other"},{"text":"DAVIS POLK & WARDWELL","label":"header"},{"text":"Fax Transmialt","label":"other"},{"text":"450 Lexington Avenue New York, NY 10017 212-450-4000","label":"other"},{"text":"To","label":"question","children":[{"text":"Robert H. Shaw, Esq.","label":"answer"}]},{"text":"Date","label":"question","children":[{"text":"November 11, 1997","label":"answer"}]},{"text":"Company","label":"question","children":[{"text":"Lorillard Tobacco Company","label":"answer"}]},{"text":"Fax Number","label":"question","children":[{"text":"910-335-7777","label":"answer"}]},{"text":"Voice Number","label":"question","children":[{"text":"910-335-7720","label":"answer"}]},{"text":"Sender","label":"question","children":[{"text":"Charles Duggan","label":"answer"}]},{"text":"Number of Pages (this page included)","label":"question","children":[{"text":"2","label":"answer"}]},{"text":"Sender Voice Number","label":"question","children":[{"text":"212-450-4785","label":"answer"}]},{"text":"Main Fax Operator Voice Number","label":"question","children":[{"text":"17560-188","label":"answer"}]},{"text":"Sender Fax Number","label":"question","children":[{"text":"212-450-5578","label":"answer"}]},{"text":"Reference","label":"question","children":[{"text":"17560-188","label":"answer"}]},{"text":"Message:","label":"question","children":[{"text":"","label":"answer"}]},{"text":"8582758","label":"other"}]

# %% [markdown]
# Now that you have successfully performed a real-time inference, you do not need the endpoint any more. You can terminate the endpoint to avoid being charged.

# %%
model.sagemaker_session.delete_endpoint(model_name)
model.sagemaker_session.delete_endpoint_config(model_name)

# %% [markdown]
# ## 4. Batch inference

# %%
validation_json_file_name1 = "input1.json"

validation_input_json_path = f"s3://{s3_bucket}/{model_name}/validation-input/"
validation_output_json_path = f"s3://{s3_bucket}/{model_name}/validation-output/"


def write_and_upload_to_s3(input_data, file_name):
    s3_client.put_object(
        Bucket=s3_bucket,
        Key=f"{model_name}/validation-input/{file_name}",
        Body=(bytes(input_data.encode("UTF-8"))),
    )

# %%
input_json_data1 = json.dumps(
    {
        "model": "/opt/ml/model",
        "messages": [
            {
                "role": "user",
                "content": [
                    {
                        "type": "image_url",
                        "url": f"data:image/jpeg;base64,{encode_file_to_base64('./82254765.png')}",
                    }
                ],
            },
        ],
    }
)

write_and_upload_to_s3(input_json_data1, f"{validation_json_file_name1}")

# %%
transformer = model.transformer(
    instance_count=1,
    instance_type=batch_transform_inference_instance_type,
    accept="application/json",
    output_path=validation_output_json_path,
)
transformer.transform(validation_input_json_path, content_type="application/json")
transformer.wait()

# %%
from urllib.parse import urlparse

def retrieve_json_output_from_s3(validation_file_name):

    parsed_url = urlparse(transformer.output_path)
    file_key = f"{parsed_url.path[1:]}{validation_file_name}.out"
    response = s3_client.get_object(Bucket=s3_bucket, Key=file_key)
    result = json.loads(response["Body"].read().decode("utf-8"))
    print(result)

# %%
retrieve_json_output_from_s3(validation_json_file_name1)
# Out:
# {'id': 'chatcmpl-28195d892da8476984fedc18d7fe196b', 'created': 1758533409, 'model': '/opt/ml/model', 'object': 'chat.completion', 'output': '[{"text":"DATE TO NYO:","label":"question","children":[{"text":"1/24/97","label":"answer"}]},{"text":"TO:","label":"question","children":[{"text":"K A SPARROW","label":"answer"}]},{"text":"FROM:","label":"question","children":[{"text":"S. Reindel","label":"answer"}]},{"text":"DIV. NAME / NO:","label":"question","children":[{"text":"Nassau / 107","label":"answer"}]},{"text":"1997 SPECIAL EVENT REQUEST FORM","label":"header"},{"text":"NAME OF EVENT:","label":"question","children":[{"text":"H. Levinson Tradeshow","label":"answer"}]},{"text":"*DATE OF EVENT:","label":"question","children":[{"text":"3/18/97","label":"answer"}]},{"text":"SAMPLES / ITEMS REQUIRED:","label":"question","children":[{"text":"SAMPLE 10\'S (400 PACKS PER CASE)","label":"answer"}]},{"text":"# CASES","label":"header","children":[{"text":"NEWPORT K.S.","label":"question","children":[{"text":"2","label":"answer"}]},{"text":"KENT III K.S.","label":"question","children":[{"text":"1","label":"answer"}]},{"text":"KENT GL LTS K.S.","label":"question","children":[{"text":"1","label":"answer"}]},{"text":"NEWPORT 100\'S","label":"question","children":[{"text":"1","label":"answer"}]},{"text":"KENT III 100","label":"question","children":[{"text":"1","label":"answer"}]},{"text":"KENT GL 100","label":"question","children":[{"text":"1","label":"answer"}]},{"text":"NEWPORT LTS. K.S.","label":"question","children":[{"text":"1","label":"answer"}]},{"text":"TRUE K.S.","label":"question","children":[{"text":"1","label":"answer"}]},{"text":"NEWPORT LTS. 100","label":"question","children":[{"text":"1","label":"answer"}]},{"text":"KENT K.S.","label":"question","children":[{"text":"1","label":"answer"}]},{"text":"KENT 100","label":"question","children":[{"text":"1","label":"answer"}]}]},{"text":"ITEMS","label":"header","children":[{"text":"BASEBALL CAP","label":"question","children":[{"text":"1500","label":"answer"}]},{"text":"WATER BOTTLES","label":"question","children":[{"text":"500","label":"answer"}]}]},{"text":"QUANTITY REQUIRED","label":"header"},{"text":"SHIP TO:","label":"header","children":[{"text":"CUSTOMER SHIPPING NUMBER","label":"question","children":[{"text":"198-1160006","label":"answer"}]}]},{"text":"NYO ONLY:","label":"header","children":[{"text":"DATE FORWARDED TO PROMOTION SERVICES:","label":"question","children":[{"text":"2/6/97","label":"answer"}]}]},{"text":"82254765","label":"other"},{"text":"REQFORM","label":"other"},{"text":"01/17/97","label":"other"}]'}

# %% [markdown]
# Congratulations! You just verified that the batch transform job is working as expected. Since the model is not required, you can delete it. Note that you are deleting the deployable model. Not the model package.

# %%
model.delete_model()
# Out:
# INFO:sagemaker:Deleting model with name: JSL-Forms-VLM-3B-v1-2-2025-09-22-09-23-29-619

# %% [markdown]
# ### Unsubscribe to the listing (optional)

# %% [markdown]
# If you would like to unsubscribe to the model package, follow these steps. Before you cancel the subscription, ensure that you do not have any [deployable model](https://console.aws.amazon.com/sagemaker/home#/models) created from the model package or using the algorithm. Note - You can find this information by looking at the container name associated with the model.
#
# **Steps to unsubscribe to product from AWS Marketplace**:
# 1. Navigate to __Machine Learning__ tab on [__Your Software subscriptions page__](https://aws.amazon.com/marketplace/ai/library?productType=ml&ref_=mlmp_gitdemo_indust)
# 2. Locate the listing that you want to cancel the subscription for, and then choose __Cancel Subscription__  to cancel the subscription.
