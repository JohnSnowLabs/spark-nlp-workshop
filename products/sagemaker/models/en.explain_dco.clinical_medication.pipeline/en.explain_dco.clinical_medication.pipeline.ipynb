# %% [markdown]
# ## 1. Subscribe to the model package

# %% [markdown]
# To subscribe to the model package:
# 1. Open the model package listing page <font color='red'> For Seller to update:[Title_of_your_product](Provide link to your marketplace listing of your product).</font>
# 1. On the AWS Marketplace listing, click on the **Continue to subscribe** button.
# 1. On the **Subscribe to this software** page, review and click on **"Accept Offer"** if you and your organization agrees with EULA, pricing, and support terms.
# 1. Once you click on **Continue to configuration button** and then choose a **region**, you will see a **Product Arn** displayed. This is the model package ARN that you need to specify while creating a deployable model using Boto3. Copy the ARN corresponding to your region and specify the same in the following cell.

# %% [markdown]
# ## Pipeline to Detect Medication Entities, Assign Assertion Status and Find Relations
#
# Overview:
#
# Medication entity detection, assertion status assignment, and relation extraction are crucial for analyzing medical texts. These processes can be incredibly useful to healthcare professionals, researchers, and medical NLP practitioners, enabling the extraction of valuable insights from clinical literature, electronic health records, and patient notes.
#
#
# - **Model**: `en.explain_dco.clinical_medication.pipeline`
# - **Model Description**: A pipeline for detecting posology entities with the `ner_posology_large` NER model, assigning their assertion status with `assertion_jsl` model, and extracting relations between posology-related terminology with `posology_re` relation extraction model.

# %%
model_package_arn = "<Customer to specify Model package ARN corresponding to their AWS region>"

# %%
import base64
import json
import uuid
from sagemaker import ModelPackage
import sagemaker as sage
from sagemaker import get_execution_role
import boto3
from IPython.display import Image, display
from PIL import Image as ImageEdit
import numpy as np
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
sagemaker_session = sage.Session()
s3_bucket = sagemaker_session.default_bucket()
region = sagemaker_session.boto_region_name
account_id = boto3.client("sts").get_caller_identity().get("Account")
role = get_execution_role()

sagemaker = boto3.client("sagemaker")
s3_client = sagemaker_session.boto_session.client("s3")
ecr = boto3.client("ecr")
sm_runtime = boto3.client("sagemaker-runtime")

# %% [markdown]
# ## 2. Create an endpoint and perform real-time inference

# %% [markdown]
# If you want to understand how real-time inference with Amazon SageMaker works, see [Documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/how-it-works-hosting.html).

# %%
model_name = "en-explain-dco-clinical-medication-pipeline"

content_type = "application/json"

real_time_inference_instance_type = "ml.m4.xlarge"
batch_transform_inference_instance_type = "ml.m4.xlarge"

# %% [markdown]
# ### A. Create an endpoint

# %%
# create a deployable model from the model package.
model = ModelPackage(
    role=role, model_package_arn=model_package_arn, sagemaker_session=sagemaker_session
)

# Deploy the model
predictor = model.deploy(1, real_time_inference_instance_type, endpoint_name=model_name)
# Out:
# --------!

# %% [markdown]
# Once endpoint has been created, you would be able to perform real-time inference.

# %% [markdown]
# ### B. Perform real-time inference

# %%
import json
import pandas as pd
import os
import boto3


# Set display options
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)


def process_data_and_invoke_realtime_endpoint(data_dicts):
    for data_dict in data_dicts:
        json_input_data = json.dumps(data_dict)    
        i = 1
        input_file_name = f'inputs/real-time/input{i}.json'
        output_file_name = f'outputs/real-time/out{i}.out'

        while os.path.exists(input_file_name) or os.path.exists(output_file_name):
            i += 1
            input_file_name = f'inputs/real-time/input{i}.json'
            output_file_name = f'outputs/real-time/out{i}.out'

        os.makedirs(os.path.dirname(input_file_name), exist_ok=True)
        os.makedirs(os.path.dirname(output_file_name), exist_ok=True)

        with open(input_file_name, 'w') as f:
            f.write(json_input_data)

        s3_client.put_object(Bucket=s3_bucket, Key=f"{model_name}/validation-input-json/real-time/{os.path.basename(input_file_name)}", Body=bytes(json_input_data.encode('UTF-8')))

        response = sm_runtime.invoke_endpoint(
            EndpointName=model_name,
            ContentType=content_type,
            Accept="application/json",
            Body=json_input_data,
        )

        # Process response
        response_data = json.loads(response["Body"].read().decode("utf-8"))

        df_ner = pd.DataFrame(response_data['ner_predictions'])
        df_assertion = pd.DataFrame(response_data['assertion_predictions'])
        df_relation = pd.DataFrame(response_data['relation_predictions'])

        display(df_ner, df_assertion, df_relation)

        # Save response data to file
        with open(output_file_name, 'w') as f_out:
            json.dump(response_data, f_out, indent=4)

# %% [markdown]
# ### Initial setup

# %%
docs = [
    '''The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.''',
    '''The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.'''
]


sample_text = '''The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.'''

# %% [markdown]
# #### Example 1

# %% [markdown]
#   **Input format**:
#
#
# ```json
# {
#     "text": "Single text document"
# }
# ```

# %%
data_dicts = [
    {
        "text": sample_text
    }
]

process_data_and_invoke_realtime_endpoint(data_dicts)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                               document  \
# 0   The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.
# 1   The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.
# 2   The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.
# 3   The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.
# 4   The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.
# 5   The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.
# 6   The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.
# 7   The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.
# 8   The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.
# 9   The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.
# 10  The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.
# 11  The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.
#
#         ner_chunk  begin  end  ner_label  confidence
# 0         Aspirin    267  273       DRUG      0.9816
# 1   81 milligrams    275  287   STRENGTH  0.81974995
# 2            QDay    289  292  FREQUENCY      0.9916
# 3         insulin    295  301       DRUG      0.9998
# 4        50 units    303  310     DOSAGE      0.8536
# 5          in a.m    312  317  FREQUENCY  0.66085005
# 6            HCTZ    320  323       DRUG      0.9948
# 7           50 mg    325  329   STRENGTH       0.948
# 8            QDay    331  334  FREQUENCY      0.9985
# 9   Nitroglycerin    337  349       DRUG      0.9994
# 10          1/150    351  355   STRENGTH      0.8967
# 11   sublingually    357  368      ROUTE      0.9816
#                                                                                                                                                                                                                                                                                                                                                                              document  \
# 0  The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.
# 1  The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.
# 2  The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.
# 3  The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.
#
#        ner_chunk  begin  end ner_label ner_confidence assertion
# 0        Aspirin    267  273      DRUG         0.9816   Planned
# 1        insulin    295  301      DRUG         0.9998   Planned
# 2           HCTZ    320  323      DRUG         0.9948   Planned
# 3  Nitroglycerin    337  349      DRUG         0.9994      Past
#                                                                                                                                                                                                                                                                                                                                                                              document  \
# 0  The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.
# 1  The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.
# 2  The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.
# 3  The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.
# 4  The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.
# 5  The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.
# 6  The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.
# 7  The patient is a 40-year-old white male who presents with a chief complaint of 'chest pain'. The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that chest pain started yesterday evening. He has been advised Aspirin 81 milligrams QDay. insulin 50 units in a.m. HCTZ 50 mg QDay. Nitroglycerin 1/150 sublingually.
#
#       ner_chunk1 ner_chunk1_begin ner_chunk1_end ner_label1  \
# 0        Aspirin              267            273       DRUG
# 1        Aspirin              267            273       DRUG
# 2        insulin              295            301       DRUG
# 3        insulin              295            301       DRUG
# 4           HCTZ              320            323       DRUG
# 5           HCTZ              320            323       DRUG
# 6  Nitroglycerin              337            349       DRUG
# 7  Nitroglycerin              337            349       DRUG
#
#   ner_chunk1_confidence     ner_chunk2 ner_chunk2_begin ner_chunk2_end  \
# 0                0.9816  81 milligrams              275            287
# 1                0.9816           QDay              289            292
# 2                0.9998       50 units              303            310
# 3                0.9998         in a.m              312            317
# 4                0.9948          50 mg              325            329
# 5                0.9948           QDay              331            334
# 6                0.9994          1/150              351            355
# 7                0.9994   sublingually              357            368
#
#   ner_label2 ner_chunk2_confidence        relation  relation_begin  \
# 0   STRENGTH            0.81974995   DRUG-STRENGTH             267
# 1  FREQUENCY                0.9916  DRUG-FREQUENCY             267
# 2     DOSAGE                0.8536     DRUG-DOSAGE             295
# 3  FREQUENCY            0.66085005  DRUG-FREQUENCY             295
# 4   STRENGTH                 0.948   DRUG-STRENGTH             320
# 5  FREQUENCY                0.9985  DRUG-FREQUENCY             320
# 6   STRENGTH                0.8967   DRUG-STRENGTH             337
# 7      ROUTE                0.9816      DRUG-ROUTE             337
#
#    relation_end relation_confidence
# 0           287                 1.0
# 1           292                 1.0
# 2           310                 1.0
# 3           317                 1.0
# 4           329                 1.0
# 5           334                 1.0
# 6           355                 1.0
# 7           368                 1.0

# %% [markdown]
# #### Example 2

# %% [markdown]
#   **Input format**:
#
#
# ```json
# {
#     "text": [
#         "Text document 1",
#         "Text document 2",
#         ...
#     ]
# }
# ```

# %%
data_dicts = [
    {
        "text": docs
    }
]

process_data_and_invoke_realtime_endpoint(data_dicts)
# Out:
#                                                                                                                                                                                                                                                                                                    document  \
# 0                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 1                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 2                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 3                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 4                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 5                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 6                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 7                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 8                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 9                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 10                          The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 11  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 12  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 13  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 14  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 15  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 16  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 17  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 18  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 19  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 20  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 21  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 22  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 23  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 24  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 25  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 26  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 27  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
#
#               ner_chunk  begin  end  ner_label  confidence
# 0               insulin     59   65       DRUG      0.9379
# 1               Bactrim    120  126       DRUG      0.9994
# 2           for 14 days    128  138   DURATION  0.79349995
# 3            5000 units    169  178     DOSAGE  0.80009997
# 4               Fragmin    183  189       DRUG      0.9996
# 5        subcutaneously    192  205      ROUTE      0.9994
# 6                 daily    207  211  FREQUENCY      0.9991
# 7                Lantus    229  234       DRUG      0.9986
# 8              40 units    236  243     DOSAGE      0.8326
# 9        subcutaneously    245  258      ROUTE      0.9969
# 10           at bedtime    260  269  FREQUENCY      0.8706
# 11                    1     27   27     DOSAGE      0.9994
# 12              capsule     29   35       FORM      0.9961
# 13                Advil     40   44       DRUG      0.9982
# 14                10 mg     46   50   STRENGTH  0.95175004
# 15           for 5 days     52   61   DURATION  0.76189995
# 16  magnesium hydroxide     67   85       DRUG      0.9819
# 17           suspension     97  106       FORM      0.9984
# 18                   PO    108  109      ROUTE      0.9997
# 19             40 units    179  186     DOSAGE     0.80795
# 20     insulin glargine    191  206       DRUG  0.97574997
# 21             at night    208  215  FREQUENCY  0.82850003
# 22             12 units    218  225     DOSAGE  0.84134996
# 23       insulin lispro    230  243       DRUG  0.83105004
# 24           with meals    245  254  FREQUENCY     0.92195
# 25            metformin    261  269       DRUG      0.9876
# 26              1000 mg    271  277   STRENGTH     0.84965
# 27      two times a day    279  293  FREQUENCY      0.6622
#                                                                                                                                                                                                                                                                                                   document  \
# 0                          The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 1                          The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 2                          The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 3                          The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 4  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 5  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 6  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 7  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 8  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
#
#              ner_chunk  begin  end ner_label ner_confidence assertion
# 0              insulin     59   65      DRUG         0.9379    Family
# 1              Bactrim    120  126      DRUG         0.9994      Past
# 2              Fragmin    183  189      DRUG         0.9996   Planned
# 3               Lantus    229  234      DRUG         0.9986      Past
# 4                Advil     40   44      DRUG         0.9982   Planned
# 5  magnesium hydroxide     67   85      DRUG         0.9819   Planned
# 6     insulin glargine    191  206      DRUG     0.97574997      Past
# 7       insulin lispro    230  243      DRUG     0.83105004   Planned
# 8            metformin    261  269      DRUG         0.9876   Planned
#                                                                                                                                                                                                                                                                                                    document  \
# 0                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 1                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 2                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 3                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 4                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 5                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 6                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 7   The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 8   The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 9   The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 10  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 11  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 12  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 13  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 14  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 15  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 16  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 17  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 18  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 19  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 20  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 21  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 22  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 23  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 24  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 25  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 26  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 27  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 28  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
#
#              ner_chunk1 ner_chunk1_begin ner_chunk1_end ner_label1  \
# 0               Bactrim              120            126       DRUG
# 1            5000 units              169            178     DOSAGE
# 2               Fragmin              183            189       DRUG
# 3               Fragmin              183            189       DRUG
# 4                Lantus              229            234       DRUG
# 5                Lantus              229            234       DRUG
# 6                Lantus              229            234       DRUG
# 7                     1               27             27     DOSAGE
# 8                     1               27             27     DOSAGE
# 9               capsule               29             35       FORM
# 10              capsule               29             35       FORM
# 11                Advil               40             44       DRUG
# 12                Advil               40             44       DRUG
# 13                Advil               40             44       DRUG
# 14                Advil               40             44       DRUG
# 15                10 mg               46             50   STRENGTH
# 16           for 5 days               52             61   DURATION
# 17  magnesium hydroxide               67             85       DRUG
# 18  magnesium hydroxide               67             85       DRUG
# 19             40 units              179            186     DOSAGE
# 20             40 units              179            186     DOSAGE
# 21     insulin glargine              191            206       DRUG
# 22     insulin glargine              191            206       DRUG
# 23     insulin glargine              191            206       DRUG
# 24             at night              208            215  FREQUENCY
# 25             12 units              218            225     DOSAGE
# 26       insulin lispro              230            243       DRUG
# 27            metformin              261            269       DRUG
# 28            metformin              261            269       DRUG
#
#    ner_chunk1_confidence           ner_chunk2 ner_chunk2_begin ner_chunk2_end  \
# 0                 0.9994          for 14 days              128            138
# 1             0.80009997              Fragmin              183            189
# 2                 0.9996       subcutaneously              192            205
# 3                 0.9996                daily              207            211
# 4                 0.9986             40 units              236            243
# 5                 0.9986       subcutaneously              245            258
# 6                 0.9986           at bedtime              260            269
# 7                 0.9994                Advil               40             44
# 8                 0.9994  magnesium hydroxide               67             85
# 9                 0.9961                Advil               40             44
# 10                0.9961  magnesium hydroxide               67             85
# 11                0.9982                10 mg               46             50
# 12                0.9982           for 5 days               52             61
# 13                0.9982           suspension               97            106
# 14                0.9982                   PO              108            109
# 15            0.95175004  magnesium hydroxide               67             85
# 16            0.76189995  magnesium hydroxide               67             85
# 17                0.9819           suspension               97            106
# 18                0.9819                   PO              108            109
# 19               0.80795     insulin glargine              191            206
# 20               0.80795       insulin lispro              230            243
# 21            0.97574997             at night              208            215
# 22            0.97574997             12 units              218            225
# 23            0.97574997           with meals              245            254
# 24            0.82850003       insulin lispro              230            243
# 25            0.84134996       insulin lispro              230            243
# 26            0.83105004           with meals              245            254
# 27                0.9876              1000 mg              271            277
# 28                0.9876      two times a day              279            293
#
#    ner_label2 ner_chunk2_confidence        relation  relation_begin  \
# 0    DURATION            0.79349995   DRUG-DURATION             120
# 1        DRUG                0.9996     DOSAGE-DRUG             169
# 2       ROUTE                0.9994      DRUG-ROUTE             183
# 3   FREQUENCY                0.9991  DRUG-FREQUENCY             183
# 4      DOSAGE                0.8326     DRUG-DOSAGE             229
# 5       ROUTE                0.9969      DRUG-ROUTE             229
# 6   FREQUENCY                0.8706  DRUG-FREQUENCY             229
# 7        DRUG                0.9982     DOSAGE-DRUG              27
# 8        DRUG                0.9819     DOSAGE-DRUG              27
# 9        DRUG                0.9982       FORM-DRUG              29
# 10       DRUG                0.9819       FORM-DRUG              29
# 11   STRENGTH            0.95175004   DRUG-STRENGTH              40
# 12   DURATION            0.76189995   DRUG-DURATION              40
# 13       FORM                0.9984       DRUG-FORM              40
# 14      ROUTE                0.9997      DRUG-ROUTE              40
# 15       DRUG                0.9819   STRENGTH-DRUG              46
# 16       DRUG                0.9819   DURATION-DRUG              52
# 17       FORM                0.9984       DRUG-FORM              67
# 18      ROUTE                0.9997      DRUG-ROUTE              67
# 19       DRUG            0.97574997     DOSAGE-DRUG             179
# 20       DRUG            0.83105004     DOSAGE-DRUG             179
# 21  FREQUENCY            0.82850003  DRUG-FREQUENCY             191
# 22     DOSAGE            0.84134996     DRUG-DOSAGE             191
# 23  FREQUENCY               0.92195  DRUG-FREQUENCY             191
# 24       DRUG            0.83105004  FREQUENCY-DRUG             208
# 25       DRUG            0.83105004     DOSAGE-DRUG             218
# 26  FREQUENCY               0.92195  DRUG-FREQUENCY             230
# 27   STRENGTH               0.84965   DRUG-STRENGTH             261
# 28  FREQUENCY                0.6622  DRUG-FREQUENCY             261
#
#     relation_end relation_confidence
# 0            138                 1.0
# 1            189                 1.0
# 2            205                 1.0
# 3            211                 1.0
# 4            243                 1.0
# 5            258                 1.0
# 6            269                 1.0
# 7             44                 1.0
# 8             85                 1.0
# 9             44                 1.0
# 10            85                 1.0
# 11            50                 1.0
# 12            61                 1.0
# 13           106                 1.0
# 14           109                 1.0
# 15            85                 1.0
# 16            85                 1.0
# 17           106                 1.0
# 18           109                 1.0
# 19           206                 1.0
# 20           243                 1.0
# 21           215                 1.0
# 22           225                 1.0
# 23           254                 1.0
# 24           243                 1.0
# 25           243                 1.0
# 26           254                 1.0
# 27           277                 1.0
# 28           293                 1.0

# %% [markdown]
# ### C. Delete the endpoint

# %% [markdown]
# Now that you have successfully performed a real-time inference, you do not need the endpoint any more. You can terminate the endpoint to avoid being charged.

# %%
model.sagemaker_session.delete_endpoint(model_name)
model.sagemaker_session.delete_endpoint_config(model_name)

# %% [markdown]
# ## 3. Batch inference

# %%
import os

validation_file_name = "input.json"

validation_input_path = f"s3://{s3_bucket}/{model_name}/validation-input-json/batch"
validation_output_path = f"s3://{s3_bucket}/{model_name}/validation-output-json/batch"

input_dir = 'inputs/batch'
output_dir = 'outputs/batch'

os.makedirs(input_dir, exist_ok=True)
os.makedirs(output_dir, exist_ok=True)

# %%
import json

def write_and_upload_to_s3(json_input_data, file_name):

    json_data = json.dumps(json_input_data)

    with open(file_name, "w") as f:
        f.write(json_data)

    s3_client.put_object(
        Bucket=s3_bucket,
        Key=f"{model_name}/validation-input-json/batch/{os.path.basename(file_name)}",
        Body=(bytes(json_data.encode("UTF-8"))),
    )

# %%
# Define input JSON data for each validation file
input_json_data = {"text": docs}

write_and_upload_to_s3(input_json_data, f"{input_dir}/{validation_file_name}")

# %%
# Initialize a SageMaker Transformer object for making predictions
transformer = model.transformer(
    instance_count=1,
    instance_type=batch_transform_inference_instance_type,
    accept="application/json",
)
transformer.transform(validation_input_path, content_type=content_type)
transformer.wait()

# %%
from urllib.parse import urlparse

def process_s3_output_and_save(validation_file_name, output_file_name):

    output_file_path = f"{output_dir}/{output_file_name}"
    parsed_url = urlparse(transformer.output_path)
    file_key = f"{parsed_url.path[1:]}/{validation_file_name}.out"
    response = s3_client.get_object(Bucket=s3_bucket, Key=file_key)

    data = json.loads(response["Body"].read().decode("utf-8"))
    df_ner = pd.DataFrame(data['ner_predictions'])
    df_assertion = pd.DataFrame(data['assertion_predictions'])
    df_relation = pd.DataFrame(data['relation_predictions'])
    display(df_ner, df_assertion, df_relation)

    # Save the data to the output file
    with open(output_file_path, 'w') as f_out:
        json.dump(data, f_out, indent=4)

# %%
process_s3_output_and_save(validation_file_name, "out.out")
# Out:
#                                                                                                                                                                                                                                                                                                    document  \
# 0                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 1                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 2                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 3                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 4                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 5                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 6                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 7                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 8                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 9                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 10                          The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 11  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 12  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 13  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 14  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 15  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 16  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 17  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 18  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 19  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 20  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 21  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 22  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 23  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 24  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 25  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 26  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 27  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
#
#               ner_chunk  begin  end  ner_label  confidence
# 0               insulin     59   65       DRUG      0.9379
# 1               Bactrim    120  126       DRUG      0.9994
# 2           for 14 days    128  138   DURATION  0.79349995
# 3            5000 units    169  178     DOSAGE  0.80009997
# 4               Fragmin    183  189       DRUG      0.9996
# 5        subcutaneously    192  205      ROUTE      0.9994
# 6                 daily    207  211  FREQUENCY      0.9991
# 7                Lantus    229  234       DRUG      0.9986
# 8              40 units    236  243     DOSAGE      0.8326
# 9        subcutaneously    245  258      ROUTE      0.9969
# 10           at bedtime    260  269  FREQUENCY      0.8706
# 11                    1     27   27     DOSAGE      0.9994
# 12              capsule     29   35       FORM      0.9961
# 13                Advil     40   44       DRUG      0.9982
# 14                10 mg     46   50   STRENGTH  0.95175004
# 15           for 5 days     52   61   DURATION  0.76189995
# 16  magnesium hydroxide     67   85       DRUG      0.9819
# 17           suspension     97  106       FORM      0.9984
# 18                   PO    108  109      ROUTE      0.9997
# 19             40 units    179  186     DOSAGE     0.80795
# 20     insulin glargine    191  206       DRUG  0.97574997
# 21             at night    208  215  FREQUENCY  0.82850003
# 22             12 units    218  225     DOSAGE  0.84134996
# 23       insulin lispro    230  243       DRUG  0.83105004
# 24           with meals    245  254  FREQUENCY     0.92195
# 25            metformin    261  269       DRUG      0.9876
# 26              1000 mg    271  277   STRENGTH     0.84965
# 27      two times a day    279  293  FREQUENCY      0.6622
#                                                                                                                                                                                                                                                                                                   document  \
# 0                          The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 1                          The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 2                          The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 3                          The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 4  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 5  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 6  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 7  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 8  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
#
#              ner_chunk  begin  end ner_label ner_confidence assertion
# 0              insulin     59   65      DRUG         0.9379    Family
# 1              Bactrim    120  126      DRUG         0.9994      Past
# 2              Fragmin    183  189      DRUG         0.9996   Planned
# 3               Lantus    229  234      DRUG         0.9986      Past
# 4                Advil     40   44      DRUG         0.9982   Planned
# 5  magnesium hydroxide     67   85      DRUG         0.9819   Planned
# 6     insulin glargine    191  206      DRUG     0.97574997      Past
# 7       insulin lispro    230  243      DRUG     0.83105004   Planned
# 8            metformin    261  269      DRUG         0.9876   Planned
#                                                                                                                                                                                                                                                                                                    document  \
# 0                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 1                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 2                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 3                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 4                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 5                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 6                           The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2. She received a course of Bactrim for 14 days for UTI.  She was prescribed 5000 units of Fragmin  subcutaneously daily, and along with Lantus 40 units subcutaneously at bedtime.
# 7   The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 8   The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 9   The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 10  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 11  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 12  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 13  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 14  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 15  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 16  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 17  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 18  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 19  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 20  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 21  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 22  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 23  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 24  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 25  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 26  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 27  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
# 28  The patient was prescribed 1 capsule of Advil 10 mg for 5 days and magnesium hydroxide 100mg/1ml suspension PO. He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night, 12 units of insulin lispro with meals, and metformin 1000 mg two times a day.
#
#              ner_chunk1 ner_chunk1_begin ner_chunk1_end ner_label1  \
# 0               Bactrim              120            126       DRUG
# 1            5000 units              169            178     DOSAGE
# 2               Fragmin              183            189       DRUG
# 3               Fragmin              183            189       DRUG
# 4                Lantus              229            234       DRUG
# 5                Lantus              229            234       DRUG
# 6                Lantus              229            234       DRUG
# 7                     1               27             27     DOSAGE
# 8                     1               27             27     DOSAGE
# 9               capsule               29             35       FORM
# 10              capsule               29             35       FORM
# 11                Advil               40             44       DRUG
# 12                Advil               40             44       DRUG
# 13                Advil               40             44       DRUG
# 14                Advil               40             44       DRUG
# 15                10 mg               46             50   STRENGTH
# 16           for 5 days               52             61   DURATION
# 17  magnesium hydroxide               67             85       DRUG
# 18  magnesium hydroxide               67             85       DRUG
# 19             40 units              179            186     DOSAGE
# 20             40 units              179            186     DOSAGE
# 21     insulin glargine              191            206       DRUG
# 22     insulin glargine              191            206       DRUG
# 23     insulin glargine              191            206       DRUG
# 24             at night              208            215  FREQUENCY
# 25             12 units              218            225     DOSAGE
# 26       insulin lispro              230            243       DRUG
# 27            metformin              261            269       DRUG
# 28            metformin              261            269       DRUG
#
#    ner_chunk1_confidence           ner_chunk2 ner_chunk2_begin ner_chunk2_end  \
# 0                 0.9994          for 14 days              128            138
# 1             0.80009997              Fragmin              183            189
# 2                 0.9996       subcutaneously              192            205
# 3                 0.9996                daily              207            211
# 4                 0.9986             40 units              236            243
# 5                 0.9986       subcutaneously              245            258
# 6                 0.9986           at bedtime              260            269
# 7                 0.9994                Advil               40             44
# 8                 0.9994  magnesium hydroxide               67             85
# 9                 0.9961                Advil               40             44
# 10                0.9961  magnesium hydroxide               67             85
# 11                0.9982                10 mg               46             50
# 12                0.9982           for 5 days               52             61
# 13                0.9982           suspension               97            106
# 14                0.9982                   PO              108            109
# 15            0.95175004  magnesium hydroxide               67             85
# 16            0.76189995  magnesium hydroxide               67             85
# 17                0.9819           suspension               97            106
# 18                0.9819                   PO              108            109
# 19               0.80795     insulin glargine              191            206
# 20               0.80795       insulin lispro              230            243
# 21            0.97574997             at night              208            215
# 22            0.97574997             12 units              218            225
# 23            0.97574997           with meals              245            254
# 24            0.82850003       insulin lispro              230            243
# 25            0.84134996       insulin lispro              230            243
# 26            0.83105004           with meals              245            254
# 27                0.9876              1000 mg              271            277
# 28                0.9876      two times a day              279            293
#
#    ner_label2 ner_chunk2_confidence        relation  relation_begin  \
# 0    DURATION            0.79349995   DRUG-DURATION             120
# 1        DRUG                0.9996     DOSAGE-DRUG             169
# 2       ROUTE                0.9994      DRUG-ROUTE             183
# 3   FREQUENCY                0.9991  DRUG-FREQUENCY             183
# 4      DOSAGE                0.8326     DRUG-DOSAGE             229
# 5       ROUTE                0.9969      DRUG-ROUTE             229
# 6   FREQUENCY                0.8706  DRUG-FREQUENCY             229
# 7        DRUG                0.9982     DOSAGE-DRUG              27
# 8        DRUG                0.9819     DOSAGE-DRUG              27
# 9        DRUG                0.9982       FORM-DRUG              29
# 10       DRUG                0.9819       FORM-DRUG              29
# 11   STRENGTH            0.95175004   DRUG-STRENGTH              40
# 12   DURATION            0.76189995   DRUG-DURATION              40
# 13       FORM                0.9984       DRUG-FORM              40
# 14      ROUTE                0.9997      DRUG-ROUTE              40
# 15       DRUG                0.9819   STRENGTH-DRUG              46
# 16       DRUG                0.9819   DURATION-DRUG              52
# 17       FORM                0.9984       DRUG-FORM              67
# 18      ROUTE                0.9997      DRUG-ROUTE              67
# 19       DRUG            0.97574997     DOSAGE-DRUG             179
# 20       DRUG            0.83105004     DOSAGE-DRUG             179
# 21  FREQUENCY            0.82850003  DRUG-FREQUENCY             191
# 22     DOSAGE            0.84134996     DRUG-DOSAGE             191
# 23  FREQUENCY               0.92195  DRUG-FREQUENCY             191
# 24       DRUG            0.83105004  FREQUENCY-DRUG             208
# 25       DRUG            0.83105004     DOSAGE-DRUG             218
# 26  FREQUENCY               0.92195  DRUG-FREQUENCY             230
# 27   STRENGTH               0.84965   DRUG-STRENGTH             261
# 28  FREQUENCY                0.6622  DRUG-FREQUENCY             261
#
#     relation_end relation_confidence
# 0            138                 1.0
# 1            189                 1.0
# 2            205                 1.0
# 3            211                 1.0
# 4            243                 1.0
# 5            258                 1.0
# 6            269                 1.0
# 7             44                 1.0
# 8             85                 1.0
# 9             44                 1.0
# 10            85                 1.0
# 11            50                 1.0
# 12            61                 1.0
# 13           106                 1.0
# 14           109                 1.0
# 15            85                 1.0
# 16            85                 1.0
# 17           106                 1.0
# 18           109                 1.0
# 19           206                 1.0
# 20           243                 1.0
# 21           215                 1.0
# 22           225                 1.0
# 23           254                 1.0
# 24           243                 1.0
# 25           243                 1.0
# 26           254                 1.0
# 27           277                 1.0
# 28           293                 1.0

# %%
model.delete_model()
# Out:
# INFO:sagemaker:Deleting model with name: en-explain-dco-clinical-medication-pipe-2024-03-26-19-57-27-373

# %% [markdown]
# ### Unsubscribe to the listing (optional)

# %% [markdown]
# If you would like to unsubscribe to the model package, follow these steps. Before you cancel the subscription, ensure that you do not have any [deployable model](https://console.aws.amazon.com/sagemaker/home#/models) created from the model package or using the algorithm. Note - You can find this information by looking at the container name associated with the model.
#
# **Steps to unsubscribe to product from AWS Marketplace**:
# 1. Navigate to __Machine Learning__ tab on [__Your Software subscriptions page__](https://aws.amazon.com/marketplace/ai/library?productType=ml&ref_=mlmp_gitdemo_indust)
# 2. Locate the listing that you want to cancel the subscription for, and then choose __Cancel Subscription__  to cancel the subscription.
