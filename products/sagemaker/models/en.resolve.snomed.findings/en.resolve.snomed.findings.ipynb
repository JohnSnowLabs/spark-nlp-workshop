# %% [markdown]
# ## 1. Subscribe to the model package

# %% [markdown]
# To subscribe to the model package:
# 1. Open the model package listing page <font color='red'> For Seller to update:[Title_of_your_product](Provide link to your marketplace listing of your product).</font>
# 1. On the AWS Marketplace listing, click on the **Continue to subscribe** button.
# 1. On the **Subscribe to this software** page, review and click on **"Accept Offer"** if you and your organization agrees with EULA, pricing, and support terms.
# 1. Once you click on **Continue to configuration button** and then choose a **region**, you will see a **Product Arn** displayed. This is the model package ARN that you need to specify while creating a deployable model using Boto3. Copy the ARN corresponding to your region and specify the same in the following cell.

# %% [markdown]
# ## Resolve Clinical Health Information using the SNOMED taxonomy
#
# Systematized Nomenclature of Medicine – Clinical Terms (SNOMED CT) serves as the standardized core of clinical healthcare terminology in electronic health records (EHRs), encompassing codes, terms, and synonyms for various medical aspects. Its integration enables consistent sharing of health information, streamlined data organization and analysis, and reduced interpretation errors across healthcare settings. By facilitating interoperability and precision in documentation, SNOMED CT plays a crucial role in improving patient care and enhancing efficiency within healthcare systems.
#
# - **Model**: `en.resolve.snomed.findings`
# - **Model Description**: This model is designed to map healthcare data to SNOMED codes accurately. It specializes in finding SNOMED codes associated with procedures, measurements, and tests mentioned in the text, ensuring precise and standardized medical information management.

# %%
model_package_arn = "<Customer to specify Model package ARN corresponding to their AWS region>"

# %%
import base64
import json
import uuid
from sagemaker import ModelPackage
import sagemaker as sage
from sagemaker import get_execution_role
import boto3
from IPython.display import Image, display
from PIL import Image as ImageEdit
import numpy as np
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
sagemaker_session = sage.Session()
s3_bucket = sagemaker_session.default_bucket()
region = sagemaker_session.boto_region_name
account_id = boto3.client("sts").get_caller_identity().get("Account")
role = get_execution_role()

sagemaker = boto3.client("sagemaker")
s3_client = sagemaker_session.boto_session.client("s3")
ecr = boto3.client("ecr")
sm_runtime = boto3.client("sagemaker-runtime")

# %% [markdown]
# ## 2. Create an endpoint and perform real-time inference

# %% [markdown]
# If you want to understand how real-time inference with Amazon SageMaker works, see [Documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/how-it-works-hosting.html).

# %%
model_name = "en-resolve-snomed-findings"

real_time_inference_instance_type = "ml.m4.xlarge"
batch_transform_inference_instance_type = "ml.m4.xlarge"

# %% [markdown]
# ### A. Create an endpoint

# %%
# create a deployable model from the model package.
model = ModelPackage(
    role=role, model_package_arn=model_package_arn, sagemaker_session=sagemaker_session
)

# Deploy the model
predictor = model.deploy(1, real_time_inference_instance_type, endpoint_name=model_name)
# Out:
# ---------!

# %% [markdown]
# Once endpoint has been created, you would be able to perform real-time inference.

# %%
import json
import pandas as pd
import os
import boto3

# Set display options
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

def process_data_and_invoke_realtime_endpoint(data, content_type, accept):

    content_type_to_format = {'application/json': 'json', 'application/jsonlines': 'jsonl'}
    input_format = content_type_to_format.get(content_type)
    if content_type not in content_type_to_format.keys() or accept not in content_type_to_format.keys():
        raise ValueError("Invalid content_type or accept. It should be either 'application/json' or 'application/jsonlines'.")

    i = 1
    input_dir = f'inputs/real-time/{input_format}'
    output_dir = f'outputs/real-time/{input_format}'
    s3_input_dir = f"{model_name}/validation-input/real-time/{input_format}"
    s3_output_dir = f"{model_name}/validation-output/real-time/{input_format}"

    input_file_name = f'{input_dir}/input{i}.{input_format}'
    output_file_name = f'{output_dir}/{os.path.basename(input_file_name)}.out'

    while os.path.exists(input_file_name) or os.path.exists(output_file_name):
        i += 1
        input_file_name = f'{input_dir}/input{i}.{input_format}'
        output_file_name = f'{output_dir}/{os.path.basename(input_file_name)}.out'

    os.makedirs(os.path.dirname(input_file_name), exist_ok=True)
    os.makedirs(os.path.dirname(output_file_name), exist_ok=True)

    input_data = json.dumps(data) if content_type == 'application/json' else data

    # Write input data to file
    with open(input_file_name, 'w') as f:
        f.write(input_data)

    # Upload input data to S3
    s3_client.put_object(Bucket=s3_bucket, Key=f"{s3_input_dir}/{os.path.basename(input_file_name)}", Body=bytes(input_data.encode('UTF-8')))

    # Invoke the SageMaker endpoint
    response = sm_runtime.invoke_endpoint(
        EndpointName=model_name,
        ContentType=content_type,
        Accept=accept,
        Body=input_data,
    )

    # Read response data
    response_data = json.loads(response["Body"].read().decode("utf-8")) if accept == 'application/json' else response['Body'].read().decode('utf-8')

    # Save response data to file
    with open(output_file_name, 'w') as f_out:
        if accept == 'application/json':
            json.dump(response_data, f_out, indent=4)
        else:
            for item in response_data.split('\n'):
                f_out.write(item + '\n')

    # Upload response data to S3
    output_s3_key = f"{s3_output_dir}/{os.path.basename(output_file_name)}"
    if accept == 'application/json':
        s3_client.put_object(Bucket=s3_bucket, Key=output_s3_key, Body=json.dumps(response_data).encode('UTF-8'))
    else:
        s3_client.put_object(Bucket=s3_bucket, Key=output_s3_key, Body=response_data)

    return response_data

# %% [markdown]
# ### Initial Setup

# %%
docs = [
    """The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.""",
    """Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.""",
]


sample_text = """This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU."""

# %% [markdown]
# ### JSON

# %% [markdown]
# #### Example 1

# %% [markdown]
#   **Input format**:
#
#
# ```json
# {
#     "text": "Single text document"
# }
# ```

# %%
input_json_data = {"text": sample_text}

data =  process_data_and_invoke_realtime_endpoint(input_json_data, content_type="application/json" , accept="application/json" )
pd.DataFrame(data["predictions"])
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               document  \
# 0   This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 1   This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 2   This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 3   This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 4   This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 5   This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 6   This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 7   This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 8   This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 9   This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 10  This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 11  This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 12  This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 13  This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 14  This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 15  This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 16  This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 17  This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 18  This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 19  This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 20  This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 21  This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 22  This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 23  This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 24  This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 25  This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 26  This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 27  This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
# 28  This is an 82-year-old male with a history of prior tobacco use, hypertension, chronic renal insufficiency, COPD, gastritis, and TIA. He initially presented to Braintree with a nonspecific ST-T abnormality and was transferred to St. Margaret’s Center. He underwent cardiac catheterization because of occlusion of the mid left anterior descending coronary artery lesion, which was complicated by hypotension and bradycardia. He required atropine, IV fluids, and dopamine, possibly secondary to a vagal reaction. He was subsequently transferred to the CCU for close monitoring. He was hemodynamically stable at the time of admission to the CCU.
#
#                                                                ner_chunk  \
# 0                                                            82-year-old
# 1                                                                   male
# 2                                                                tobacco
# 3                                                           hypertension
# 4                                            chronic renal insufficiency
# 5                                                                   COPD
# 6                                                              gastritis
# 7                                                                    TIA
# 8                                                                     He
# 9                                                              Braintree
# 10                                                           nonspecific
# 11                                                      ST-T abnormality
# 12                                                     Margaret’s Center
# 13                                                                    He
# 14                                               cardiac catheterization
# 15  occlusion of the mid left anterior descending coronary artery lesion
# 16                                                           hypotension
# 17                                                           bradycardia
# 18                                                                    He
# 19                                                              atropine
# 20                                                                    IV
# 21                                                                fluids
# 22                                                              dopamine
# 23                                                        vagal reaction
# 24                                                                    He
# 25                                                                   CCU
# 26                                                                    He
# 27                                                             admission
# 28                                                                   CCU
#
#     begin  end                  ner_label ner_confidence snomed_code  \
# 0      11   21                        Age         0.9995    49808004
# 1      23   26                     Gender         0.9998   231494001
# 2      52   58                    Smoking         0.9952   110483000
# 3      65   76               Hypertension         0.9999    38341003
# 4      79  105             Kidney_Disease         0.9128   709044004
# 5     108  111  Disease_Syndrome_Disorder         0.9963    13645005
# 6     114  122  Disease_Syndrome_Disorder         0.9948     4556007
# 7     129  131    Cerebrovascular_Disease         0.7999   110030002
# 8     134  135                     Gender         0.9998    47523006
# 9     160  168             Drug_BrandName         0.9944    70139002
# 10    177  187                   Modifier         0.7917   248763005
# 11    189  204               EKG_Findings        0.48555   164934002
# 12    233  249              Clinical_Dept         0.9642   305562003
# 13    252  253                     Gender         0.9999    47523006
# 14    265  287                  Procedure          0.764   250906000
# 15    300  367                    Symptom     0.50056994   840313007
# 16    395  405                 VS_Finding         0.9826    19721008
# 17    411  421                 VS_Finding         0.9969    49710005
# 18    424  425                     Gender         0.9999    47523006
# 19    436  443            Drug_Ingredient         0.9966    37567005
# 20    446  447                      Route         0.9982    42279001
# 21    449  454            Drug_Ingredient          0.947   264312008
# 22    461  468            Drug_Ingredient         0.9951    15566009
# 23    495  508                    Symptom         0.2286   398665005
# 24    511  512                     Gender         0.9997    47523006
# 25    550  552              Clinical_Dept          0.993    78359009
# 26    576  577                     Gender         0.9998    47523006
# 27    621  629        Admission_Discharge         0.9988   266938001
# 28    638  640              Clinical_Dept         0.9897    78359009
#
#                                             snomed_resolution  \
# 0                                                     old-age
# 1                                                       manic
# 2                                                 tobacco use
# 3                                                hypertension
# 4                                    chronic renal impairment
# 5                          chronic obstructive airway disease
# 6                                                   gastritis
# 7                                         cerebral concussion
# 8                                                         wee
# 9                                                      harara
# 10                                                non-arousal
# 11                       electrocardiographic t wave abnormal
# 12                                     under care of gu nurse
# 13                                                        wee
# 14                              cardiac investigative finding
# 15  occlusion of mid left anterior descending coronary artery
# 16                                          globe hypotension
# 17                                          sinus bradycardia
# 18                                                        wee
# 19                                              acenaesthesia
# 20                                                     para 4
# 21                                                     liquid
# 22                                                    dourine
# 23                                         vaso vagal episode
# 24                                                        wee
# 25                                                  cord sign
# 26                                                        wee
# 27                                           hospital patient
# 28                                                  cord sign
#
#    snomed_confidence
# 0             0.3391
# 1             0.5074
# 2             0.5057
# 3             0.5460
# 4             0.5016
# 5             0.3418
# 6             0.3778
# 7             0.3349
# 8             0.3349
# 9             0.3401
# 10            0.3348
# 11            0.3407
# 12            0.3353
# 13            0.3349
# 14            0.5012
# 15            0.5142
# 16            1.0000
# 17            0.5012
# 18            0.3349
# 19            0.3425
# 20            0.3470
# 21            0.3513
# 22            0.3391
# 23            0.3476
# 24            0.3349
# 25            0.3343
# 26            0.3349
# 27            0.3394
# 28            0.3343

# %% [markdown]
# #### Example 2

# %% [markdown]
#   **Input format**:
#
#
# ```json
# {
#     "text": [
#         "Text document 1",
#         "Text document 2",
#         ...
#     ]
# }
# ```

# %%
input_json_data = {"text": docs}

data =  process_data_and_invoke_realtime_endpoint(input_json_data, content_type="application/json" , accept="application/json" )
pd.DataFrame(data["predictions"])
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                      document  \
# 0   The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 1   The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 2   The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 3   The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 4   The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 5   The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 6   The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 7   The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 8   The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 9   The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 10  The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 11  The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 12  The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 13  The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 14  The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 15  The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 16  The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 17  The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 18  The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 19  The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 20  The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 21  The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 22               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 23               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 24               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 25               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 26               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 27               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 28               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 29               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 30               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 31               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 32               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 33               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 34               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 35               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 36               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 37               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 38               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 39               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
#
#                       ner_chunk  begin  end                  ner_label  \
# 0                   40-year-old     17   27                        Age
# 1                         white     29   33             Race_Ethnicity
# 2                          male     35   38                     Gender
# 3                    chest pain     80   89                    Symptom
# 4                      diabetic    108  115                   Diabetes
# 5       coronary artery disease    144  166              Heart_Disease
# 6                         today    190  194               RelativeDate
# 7                           his    209  211                     Gender
# 8                    chest pain    213  222                    Symptom
# 9                     yesterday    232  240               RelativeDate
# 10                      evening    242  248               RelativeTime
# 11                 intermittent    272  283                   Modifier
# 12                           He    286  287                     Gender
# 13                81 milligrams    306  318                   Strength
# 14                         QDay    320  323                  Frequency
# 15                     50 units    326  333                     Dosage
# 16                       in a.m    335  340                  Frequency
# 17                        50 mg    343  347                   Strength
# 18                        1/150    355  359                   Strength
# 19                 sublingually    361  372                      Route
# 20                          PRN    374  376                  Frequency
# 21                   chest pain    378  387                    Symptom
# 22              Two weeks prior      0   14               RelativeDate
# 23                          she     34   36                     Gender
# 24                     five-day     57   64                   Duration
# 25  respiratory tract infection     82  108  Disease_Syndrome_Disorder
# 26                          She    112  114                     Gender
# 27                         T2DM    135  138                   Diabetes
# 28                          HTG    152  154             Hyperlipidemia
# 29                          She    158  160                     Gender
# 30               for six months    174  187                   Duration
# 31        endocrinology service    246  266              Clinical_Dept
# 32                          she    272  274                     Gender
# 33                   discharged    280  289        Admission_Discharge
# 34                     40 units    294  301                     Dosage
# 35                     at night    306  313                  Frequency
# 36                     12 units    317  324                     Dosage
# 37                   with meals    329  338                  Frequency
# 38                      1000 mg    346  352                   Strength
# 39              two times a day    354  368                  Frequency
#
#    ner_confidence    snomed_code  \
# 0          0.9991      819948005
# 1          0.9982      247468003
# 2          0.9993      248153007
# 3         0.73425      285389008
# 4          0.9985       74627003
# 5       0.8562667       53741008
# 6          0.9998      165284008
# 7          0.9962      400940005
# 8          0.8706      285389008
# 9          0.9937      105494007
# 10         0.9169       43724002
# 11         0.9362      271824009
# 12         0.9997       47523006
# 13         0.8203  2401000124100
# 14         0.6752       70124003
# 15        0.93025       88284004
# 16         0.7438       27718001
# 17     0.93474996      314652000
# 18           0.98      419329009
# 19         0.8702      282961006
# 20         0.8462      240305000
# 21        0.54085      285389008
# 22     0.85400003      183621003
# 23         0.9996      248152002
# 24         0.6886      276597004
# 25     0.67156667      312117008
# 26         0.9999      248152002
# 27         0.9806       44054006
# 28         0.9201         129007
# 29         0.9999      248152002
# 30         0.7686      300042001
# 31        0.94385      183535009
# 32         0.9999      248152002
# 33         0.9999      430567009
# 34        0.83655      819948005
# 35         0.4197      713822005
# 36     0.94965005      260274009
# 37         0.5086      288886005
# 38        0.93395       23037000
# 39        0.88875      185399004
#
#                                     snomed_resolution snomed_confidence
# 0         body mass index equal to or greater than 40            0.3375
# 1                                           whitehead            0.3455
# 2                                                male            0.4158
# 3                                    upper chest pain            0.5051
# 4                               diabetic complication            0.3367
# 5                             coronary artery disease            0.5495
# 6                          memory: present time known            0.3417
# 7                                                 oed            0.3340
# 8                                    upper chest pain            0.5051
# 9                                       retired early            0.3376
# 10                                              chill            0.3361
# 11                           respiration intermittent            0.3390
# 12                                                wee            0.3349
# 13                           universal designation 81            0.5298
# 14                                      quinke's sign            0.3467
# 15        disability evaluation disability 50 percent            0.5123
# 16                                               msud            0.3374
# 17  child head circumference 50 equal to 50th centile            0.3395
# 18                                             20/150            0.3446
# 19                                             squats            0.3347
# 20                                               nait            0.3352
# 21                                   upper chest pain            0.5051
# 22                                  follow-up 2 weeks            0.3699
# 23                                             female            0.3487
# 24                                     fifth day fits            0.5215
# 25                    bacterial respiratory infection            0.5088
# 26                                             female            0.3383
# 27                           type 2 diabetes mellitus            0.5095
# 28                                       homoiothermy            0.3373
# 29                                             female            0.3383
# 30                                 follow-up 6 months            0.3618
# 31                        referred to endocrinologist            0.3367
# 32                                             female            0.3487
# 33                                    discharge ready            0.3390
# 34        body mass index equal to or greater than 40            0.3554
# 35                                  wakes up at night            0.5038
# 36                                               6/12            0.3408
# 37                                           does eat            0.3393
# 38                                 parity ten or more            0.3440
# 39                            patient comes 2 monthly            0.3364

# %% [markdown]
# ### JSON Lines

# %%
import json

def create_jsonl(records):
    json_records = []

    for text in records:
        record = {
            "text": text
        }
        json_records.append(record)

    json_lines = '\n'.join(json.dumps(record) for record in json_records)

    return json_lines

input_jsonl_data = create_jsonl(docs)

# %% [markdown]
# #### Example 1

# %% [markdown]
#   **Input format**:
#
# ```json
# {"text": "Text document 1"}
# {"text": "Text document 2"}
# ```

# %%
data = process_data_and_invoke_realtime_endpoint(input_jsonl_data, content_type="application/jsonlines" , accept="application/jsonlines" )
print(data)
# Out:
# {"predictions": [{"ner_chunk": "40-year-old", "begin": 17, "end": 27, "ner_label": "Age", "ner_confidence": "0.9991", "snomed_code": "819948005", "snomed_resolution": "body mass index equal to or greater than 40", "snomed_confidence": "0.3375"}, {"ner_chunk": "white", "begin": 29, "end": 33, "ner_label": "Race_Ethnicity", "ner_confidence": "0.9982", "snomed_code": "247468003", "snomed_resolution": "whitehead", "snomed_confidence": "0.3455"}, {"ner_chunk": "male", "begin": 35, "end": 38, "ner_label": "Gender", "ner_confidence": "0.9993", "snomed_code": "248153007", "snomed_resolution": "male", "snomed_confidence": "0.4158"}, {"ner_chunk": "chest pain", "begin": 80, "end": 89, "ner_label": "Symptom", "ner_confidence": "0.73425", "snomed_code": "285389008", "snomed_resolution": "upper chest pain", "snomed_confidence": "0.5051"}, {"ner_chunk": "diabetic", "begin": 108, "end": 115, "ner_label": "Diabetes", "ner_confidence": "0.9985", "snomed_code": "74627003", "snomed_resolution": "diabetic complication", "snomed_confidence": "0.3367"}, {"ner_chunk": "coronary artery disease", "begin": 144, "end": 166, "ner_label": "Heart_Disease", "ner_confidence": "0.8562667", "snomed_code": "53741008", "snomed_resolution": "coronary artery disease", "snomed_confidence": "0.5495"}, {"ner_chunk": "today", "begin": 190, "end": 194, "ner_label": "RelativeDate", "ner_confidence": "0.9998", "snomed_code": "165284008", "snomed_resolution": "memory: present time known", "snomed_confidence": "0.3417"}, {"ner_chunk": "his", "begin": 209, "end": 211, "ner_label": "Gender", "ner_confidence": "0.9962", "snomed_code": "400940005", "snomed_resolution": "oed", "snomed_confidence": "0.3340"}, {"ner_chunk": "chest pain", "begin": 213, "end": 222, "ner_label": "Symptom", "ner_confidence": "0.8706", "snomed_code": "285389008", "snomed_resolution": "upper chest pain", "snomed_confidence": "0.5051"}, {"ner_chunk": "yesterday", "begin": 232, "end": 240, "ner_label": "RelativeDate", "ner_confidence": "0.9937", "snomed_code": "105494007", "snomed_resolution": "retired early", "snomed_confidence": "0.3376"}, {"ner_chunk": "evening", "begin": 242, "end": 248, "ner_label": "RelativeTime", "ner_confidence": "0.9169", "snomed_code": "43724002", "snomed_resolution": "chill", "snomed_confidence": "0.3361"}, {"ner_chunk": "intermittent", "begin": 272, "end": 283, "ner_label": "Modifier", "ner_confidence": "0.9362", "snomed_code": "271824009", "snomed_resolution": "respiration intermittent", "snomed_confidence": "0.3390"}, {"ner_chunk": "He", "begin": 286, "end": 287, "ner_label": "Gender", "ner_confidence": "0.9997", "snomed_code": "47523006", "snomed_resolution": "wee", "snomed_confidence": "0.3349"}, {"ner_chunk": "81 milligrams", "begin": 306, "end": 318, "ner_label": "Strength", "ner_confidence": "0.8203", "snomed_code": "2401000124100", "snomed_resolution": "universal designation 81", "snomed_confidence": "0.5298"}, {"ner_chunk": "QDay", "begin": 320, "end": 323, "ner_label": "Frequency", "ner_confidence": "0.6752", "snomed_code": "70124003", "snomed_resolution": "quinke's sign", "snomed_confidence": "0.3467"}, {"ner_chunk": "50 units", "begin": 326, "end": 333, "ner_label": "Dosage", "ner_confidence": "0.93025", "snomed_code": "88284004", "snomed_resolution": "disability evaluation disability 50 percent", "snomed_confidence": "0.5123"}, {"ner_chunk": "in a.m", "begin": 335, "end": 340, "ner_label": "Frequency", "ner_confidence": "0.7438", "snomed_code": "27718001", "snomed_resolution": "msud", "snomed_confidence": "0.3374"}, {"ner_chunk": "50 mg", "begin": 343, "end": 347, "ner_label": "Strength", "ner_confidence": "0.93474996", "snomed_code": "314652000", "snomed_resolution": "child head circumference 50 equal to 50th centile", "snomed_confidence": "0.3395"}, {"ner_chunk": "1/150", "begin": 355, "end": 359, "ner_label": "Strength", "ner_confidence": "0.98", "snomed_code": "419329009", "snomed_resolution": "20/150", "snomed_confidence": "0.3446"}, {"ner_chunk": "sublingua ...
# {"predictions": [{"ner_chunk": "Two weeks prior", "begin": 0, "end": 14, "ner_label": "RelativeDate", "ner_confidence": "0.85400003", "snomed_code": "183621003", "snomed_resolution": "follow-up 2 weeks", "snomed_confidence": "0.3699"}, {"ner_chunk": "she", "begin": 34, "end": 36, "ner_label": "Gender", "ner_confidence": "0.9996", "snomed_code": "248152002", "snomed_resolution": "female", "snomed_confidence": "0.3487"}, {"ner_chunk": "five-day", "begin": 57, "end": 64, "ner_label": "Duration", "ner_confidence": "0.6886", "snomed_code": "276597004", "snomed_resolution": "fifth day fits", "snomed_confidence": "0.5215"}, {"ner_chunk": "respiratory tract infection", "begin": 82, "end": 108, "ner_label": "Disease_Syndrome_Disorder", "ner_confidence": "0.67156667", "snomed_code": "312117008", "snomed_resolution": "bacterial respiratory infection", "snomed_confidence": "0.5088"}, {"ner_chunk": "She", "begin": 112, "end": 114, "ner_label": "Gender", "ner_confidence": "0.9999", "snomed_code": "248152002", "snomed_resolution": "female", "snomed_confidence": "0.3383"}, {"ner_chunk": "T2DM", "begin": 135, "end": 138, "ner_label": "Diabetes", "ner_confidence": "0.9806", "snomed_code": "44054006", "snomed_resolution": "type 2 diabetes mellitus", "snomed_confidence": "0.5095"}, {"ner_chunk": "HTG", "begin": 152, "end": 154, "ner_label": "Hyperlipidemia", "ner_confidence": "0.9201", "snomed_code": "129007", "snomed_resolution": "homoiothermy", "snomed_confidence": "0.3373"}, {"ner_chunk": "She", "begin": 158, "end": 160, "ner_label": "Gender", "ner_confidence": "0.9999", "snomed_code": "248152002", "snomed_resolution": "female", "snomed_confidence": "0.3383"}, {"ner_chunk": "for six months", "begin": 174, "end": 187, "ner_label": "Duration", "ner_confidence": "0.7686", "snomed_code": "300042001", "snomed_resolution": "follow-up 6 months", "snomed_confidence": "0.3618"}, {"ner_chunk": "endocrinology service", "begin": 246, "end": 266, "ner_label": "Clinical_Dept", "ner_confidence": "0.94385", "snomed_code": "183535009", "snomed_resolution": "referred to endocrinologist", "snomed_confidence": "0.3367"}, {"ner_chunk": "she", "begin": 272, "end": 274, "ner_label": "Gender", "ner_confidence": "0.9999", "snomed_code": "248152002", "snomed_resolution": "female", "snomed_confidence": "0.3487"}, {"ner_chunk": "discharged", "begin": 280, "end": 289, "ner_label": "Admission_Discharge", "ner_confidence": "0.9999", "snomed_code": "430567009", "snomed_resolution": "discharge ready", "snomed_confidence": "0.3390"}, {"ner_chunk": "40 units", "begin": 294, "end": 301, "ner_label": "Dosage", "ner_confidence": "0.83655", "snomed_code": "819948005", "snomed_resolution": "body mass index equal to or greater than 40", "snomed_confidence": "0.3554"}, {"ner_chunk": "at night", "begin": 306, "end": 313, "ner_label": "Frequency", "ner_confidence": "0.4197", "snomed_code": "713822005", "snomed_resolution": "wakes up at night", "snomed_confidence": "0.5038"}, {"ner_chunk": "12 units", "begin": 317, "end": 324, "ner_label": "Dosage", "ner_confidence": "0.94965005", "snomed_code": "260274009", "snomed_resolution": "6/12", "snomed_confidence": "0.3408"}, {"ner_chunk": "with meals", "begin": 329, "end": 338, "ner_label": "Frequency", "ner_confidence": "0.5086", "snomed_code": "288886005", "snomed_resolution": "does eat", "snomed_confidence": "0.3393"}, {"ner_chunk": "1000 mg", "begin": 346, "end": 352, "ner_label": "Strength", "ner_confidence": "0.93395", "snomed_code": "23037000", "snomed_resolution": "parity ten or more", "snomed_confidence": "0.3440"}, {"ner_chunk": "two times a day", "begin": 354, "end": 368, "ner_label": "Frequency", "ner_confidence": "0.88875", "snomed_code": "185399004", "snomed_resolution": "patient comes 2 monthly", "snomed_confidence": "0.3364"}]}

# %% [markdown]
# ### C. Delete the endpoint

# %% [markdown]
# Now that you have successfully performed a real-time inference, you do not need the endpoint any more. You can terminate the endpoint to avoid being charged.

# %%
model.sagemaker_session.delete_endpoint(model_name)
model.sagemaker_session.delete_endpoint_config(model_name)

# %% [markdown]
# ## 3. Batch inference

# %%
import json
import os

input_dir = 'inputs/batch'
json_input_dir = f"{input_dir}/json"
jsonl_input_dir = f"{input_dir}/jsonl"

output_dir = 'outputs/batch'
json_output_dir = f"{output_dir}/json"
jsonl_output_dir = f"{output_dir}/jsonl"

os.makedirs(json_input_dir, exist_ok=True)
os.makedirs(jsonl_input_dir, exist_ok=True)
os.makedirs(json_output_dir, exist_ok=True)
os.makedirs(jsonl_output_dir, exist_ok=True)

validation_json_file_name = "input.json"

validation_jsonl_file_name = "input.jsonl"

validation_input_json_path = f"s3://{s3_bucket}/{model_name}/validation-input/batch/json/"
validation_output_json_path = f"s3://{s3_bucket}/{model_name}/validation-output/batch/json/"

validation_input_jsonl_path = f"s3://{s3_bucket}/{model_name}/validation-input/batch/jsonl/"
validation_output_jsonl_path = f"s3://{s3_bucket}/{model_name}/validation-output/batch/jsonl/"

def write_and_upload_to_s3(input_data, file_name):
    file_format = os.path.splitext(file_name)[1].lower()
    if file_format == ".json":
        input_data = json.dumps(input_data)

    with open(file_name, "w") as f:
        f.write(input_data)

    s3_client.put_object(
        Bucket=s3_bucket,
        Key=f"{model_name}/validation-input/batch/{file_format[1:]}/{os.path.basename(file_name)}",
        Body=(bytes(input_data.encode("UTF-8"))),
    )

# %%
input_jsonl_data = create_jsonl(docs)
input_json_data = {"text": docs}

write_and_upload_to_s3(input_json_data, f"{json_input_dir}/{validation_json_file_name}")

write_and_upload_to_s3(input_jsonl_data, f"{jsonl_input_dir}/{validation_jsonl_file_name}")

# %% [markdown]
# ### JSON

# %%
# Initialize a SageMaker Transformer object for making predictions
transformer = model.transformer(
    instance_count=1,
    instance_type=batch_transform_inference_instance_type,
    accept="application/json",
    output_path=validation_output_json_path
)

transformer.transform(validation_input_json_path, content_type="application/json")
transformer.wait()

# %%
from urllib.parse import urlparse

def process_s3_json_output_and_save(validation_file_name):

    output_file_path = f"{json_output_dir}/{validation_file_name}.out"
    parsed_url = urlparse(transformer.output_path)
    file_key = f"{parsed_url.path[1:]}{validation_file_name}.out"
    response = s3_client.get_object(Bucket=s3_bucket, Key=file_key)

    data = json.loads(response["Body"].read().decode("utf-8"))
    df = pd.DataFrame(data["predictions"])
    display(df)

    # Save the data to the output file
    with open(output_file_path, 'w') as f_out:
        json.dump(data, f_out, indent=4)

# %%
process_s3_json_output_and_save(validation_json_file_name)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                      document  \
# 0   The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 1   The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 2   The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 3   The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 4   The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 5   The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 6   The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 7   The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 8   The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 9   The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 10  The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 11  The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 12  The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 13  The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 14  The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 15  The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 16  The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 17  The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 18  The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 19  The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 20  The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 21  The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. He has been advised  81 milligrams QDay.  50 units in a.m.  50 mg QDay.  1/150 sublingually PRN chest pain.
# 22               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 23               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 24               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 25               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 26               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 27               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 28               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 29               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 30               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 31               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 32               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 33               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 34               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 35               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 36               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 37               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 38               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
# 39               Two weeks prior to presentation , she was treated with a five-day course of  for a respiratory tract infection . She was on  ,  , and  for T2DM and  and  for HTG . She had been on  for six months at the time of presentation .The patient was seen by the endocrinology service and she was discharged on 40 units of  at night , 12 units of  with meals , and  1000 mg two times a day.
#
#                       ner_chunk  begin  end                  ner_label  \
# 0                   40-year-old     17   27                        Age
# 1                         white     29   33             Race_Ethnicity
# 2                          male     35   38                     Gender
# 3                    chest pain     80   89                    Symptom
# 4                      diabetic    108  115                   Diabetes
# 5       coronary artery disease    144  166              Heart_Disease
# 6                         today    190  194               RelativeDate
# 7                           his    209  211                     Gender
# 8                    chest pain    213  222                    Symptom
# 9                     yesterday    232  240               RelativeDate
# 10                      evening    242  248               RelativeTime
# 11                 intermittent    272  283                   Modifier
# 12                           He    286  287                     Gender
# 13                81 milligrams    306  318                   Strength
# 14                         QDay    320  323                  Frequency
# 15                     50 units    326  333                     Dosage
# 16                       in a.m    335  340                  Frequency
# 17                        50 mg    343  347                   Strength
# 18                        1/150    355  359                   Strength
# 19                 sublingually    361  372                      Route
# 20                          PRN    374  376                  Frequency
# 21                   chest pain    378  387                    Symptom
# 22              Two weeks prior      0   14               RelativeDate
# 23                          she     34   36                     Gender
# 24                     five-day     57   64                   Duration
# 25  respiratory tract infection     82  108  Disease_Syndrome_Disorder
# 26                          She    112  114                     Gender
# 27                         T2DM    135  138                   Diabetes
# 28                          HTG    152  154             Hyperlipidemia
# 29                          She    158  160                     Gender
# 30               for six months    174  187                   Duration
# 31        endocrinology service    246  266              Clinical_Dept
# 32                          she    272  274                     Gender
# 33                   discharged    280  289        Admission_Discharge
# 34                     40 units    294  301                     Dosage
# 35                     at night    306  313                  Frequency
# 36                     12 units    317  324                     Dosage
# 37                   with meals    329  338                  Frequency
# 38                      1000 mg    346  352                   Strength
# 39              two times a day    354  368                  Frequency
#
#    ner_confidence    snomed_code  \
# 0          0.9991      819948005
# 1          0.9982      247468003
# 2          0.9993      248153007
# 3         0.73425      285389008
# 4          0.9985       74627003
# 5       0.8562667       53741008
# 6          0.9998      165284008
# 7          0.9962      400940005
# 8          0.8706      285389008
# 9          0.9937      105494007
# 10         0.9169       43724002
# 11         0.9362      271824009
# 12         0.9997       47523006
# 13         0.8203  2401000124100
# 14         0.6752       70124003
# 15        0.93025       88284004
# 16         0.7438       27718001
# 17     0.93474996      314652000
# 18           0.98      419329009
# 19         0.8702      282961006
# 20         0.8462      240305000
# 21        0.54085      285389008
# 22     0.85400003      183621003
# 23         0.9996      248152002
# 24         0.6886      276597004
# 25     0.67156667      312117008
# 26         0.9999      248152002
# 27         0.9806       44054006
# 28         0.9201         129007
# 29         0.9999      248152002
# 30         0.7686      300042001
# 31        0.94385      183535009
# 32         0.9999      248152002
# 33         0.9999      430567009
# 34        0.83655      819948005
# 35         0.4197      713822005
# 36     0.94965005      260274009
# 37         0.5086      288886005
# 38        0.93395       23037000
# 39        0.88875      185399004
#
#                                     snomed_resolution snomed_confidence
# 0         body mass index equal to or greater than 40            0.3375
# 1                                           whitehead            0.3455
# 2                                                male            0.4158
# 3                                    upper chest pain            0.5051
# 4                               diabetic complication            0.3367
# 5                             coronary artery disease            0.5495
# 6                          memory: present time known            0.3417
# 7                                                 oed            0.3340
# 8                                    upper chest pain            0.5051
# 9                                       retired early            0.3376
# 10                                              chill            0.3361
# 11                           respiration intermittent            0.3390
# 12                                                wee            0.3349
# 13                           universal designation 81            0.5298
# 14                                      quinke's sign            0.3467
# 15        disability evaluation disability 50 percent            0.5123
# 16                                               msud            0.3374
# 17  child head circumference 50 equal to 50th centile            0.3395
# 18                                             20/150            0.3446
# 19                                             squats            0.3347
# 20                                               nait            0.3352
# 21                                   upper chest pain            0.5051
# 22                                  follow-up 2 weeks            0.3699
# 23                                             female            0.3487
# 24                                     fifth day fits            0.5215
# 25                    bacterial respiratory infection            0.5088
# 26                                             female            0.3383
# 27                           type 2 diabetes mellitus            0.5095
# 28                                       homoiothermy            0.3373
# 29                                             female            0.3383
# 30                                 follow-up 6 months            0.3618
# 31                        referred to endocrinologist            0.3367
# 32                                             female            0.3487
# 33                                    discharge ready            0.3390
# 34        body mass index equal to or greater than 40            0.3554
# 35                                  wakes up at night            0.5038
# 36                                               6/12            0.3408
# 37                                           does eat            0.3393
# 38                                 parity ten or more            0.3440
# 39                            patient comes 2 monthly            0.3364

# %% [markdown]
# ### JSON Lines

# %%
transformer = model.transformer(
    instance_count=1,
    instance_type=batch_transform_inference_instance_type,
    accept="application/jsonlines",
    output_path=validation_output_jsonl_path
)
transformer.transform(validation_input_jsonl_path, content_type="application/jsonlines")
transformer.wait()

# %%
from urllib.parse import urlparse

def process_s3_jsonlines_output_and_save(validation_file_name):

    output_file_path = f"{jsonl_output_dir}/{validation_file_name}.out"
    parsed_url = urlparse(transformer.output_path)
    file_key = f"{parsed_url.path[1:]}{validation_file_name}.out"
    response = s3_client.get_object(Bucket=s3_bucket, Key=file_key)

    data = response["Body"].read().decode("utf-8")
    print(data)

    # Save the data to the output file
    with open(output_file_path, 'w') as f_out:
        for item in data.split('\n'):
            f_out.write(item + '\n')

# %%
process_s3_jsonlines_output_and_save(validation_jsonl_file_name)
# Out:
# {"predictions": [{"ner_chunk": "40-year-old", "begin": 17, "end": 27, "ner_label": "Age", "ner_confidence": "0.9991", "snomed_code": "819948005", "snomed_resolution": "body mass index equal to or greater than 40", "snomed_confidence": "0.3375"}, {"ner_chunk": "white", "begin": 29, "end": 33, "ner_label": "Race_Ethnicity", "ner_confidence": "0.9982", "snomed_code": "247468003", "snomed_resolution": "whitehead", "snomed_confidence": "0.3455"}, {"ner_chunk": "male", "begin": 35, "end": 38, "ner_label": "Gender", "ner_confidence": "0.9993", "snomed_code": "248153007", "snomed_resolution": "male", "snomed_confidence": "0.4158"}, {"ner_chunk": "chest pain", "begin": 80, "end": 89, "ner_label": "Symptom", "ner_confidence": "0.73425", "snomed_code": "285389008", "snomed_resolution": "upper chest pain", "snomed_confidence": "0.5051"}, {"ner_chunk": "diabetic", "begin": 108, "end": 115, "ner_label": "Diabetes", "ner_confidence": "0.9985", "snomed_code": "74627003", "snomed_resolution": "diabetic complication", "snomed_confidence": "0.3367"}, {"ner_chunk": "coronary artery disease", "begin": 144, "end": 166, "ner_label": "Heart_Disease", "ner_confidence": "0.8562667", "snomed_code": "53741008", "snomed_resolution": "coronary artery disease", "snomed_confidence": "0.5495"}, {"ner_chunk": "today", "begin": 190, "end": 194, "ner_label": "RelativeDate", "ner_confidence": "0.9998", "snomed_code": "165284008", "snomed_resolution": "memory: present time known", "snomed_confidence": "0.3417"}, {"ner_chunk": "his", "begin": 209, "end": 211, "ner_label": "Gender", "ner_confidence": "0.9962", "snomed_code": "400940005", "snomed_resolution": "oed", "snomed_confidence": "0.3340"}, {"ner_chunk": "chest pain", "begin": 213, "end": 222, "ner_label": "Symptom", "ner_confidence": "0.8706", "snomed_code": "285389008", "snomed_resolution": "upper chest pain", "snomed_confidence": "0.5051"}, {"ner_chunk": "yesterday", "begin": 232, "end": 240, "ner_label": "RelativeDate", "ner_confidence": "0.9937", "snomed_code": "105494007", "snomed_resolution": "retired early", "snomed_confidence": "0.3376"}, {"ner_chunk": "evening", "begin": 242, "end": 248, "ner_label": "RelativeTime", "ner_confidence": "0.9169", "snomed_code": "43724002", "snomed_resolution": "chill", "snomed_confidence": "0.3361"}, {"ner_chunk": "intermittent", "begin": 272, "end": 283, "ner_label": "Modifier", "ner_confidence": "0.9362", "snomed_code": "271824009", "snomed_resolution": "respiration intermittent", "snomed_confidence": "0.3390"}, {"ner_chunk": "He", "begin": 286, "end": 287, "ner_label": "Gender", "ner_confidence": "0.9997", "snomed_code": "47523006", "snomed_resolution": "wee", "snomed_confidence": "0.3349"}, {"ner_chunk": "81 milligrams", "begin": 306, "end": 318, "ner_label": "Strength", "ner_confidence": "0.8203", "snomed_code": "2401000124100", "snomed_resolution": "universal designation 81", "snomed_confidence": "0.5298"}, {"ner_chunk": "QDay", "begin": 320, "end": 323, "ner_label": "Frequency", "ner_confidence": "0.6752", "snomed_code": "70124003", "snomed_resolution": "quinke's sign", "snomed_confidence": "0.3467"}, {"ner_chunk": "50 units", "begin": 326, "end": 333, "ner_label": "Dosage", "ner_confidence": "0.93025", "snomed_code": "88284004", "snomed_resolution": "disability evaluation disability 50 percent", "snomed_confidence": "0.5123"}, {"ner_chunk": "in a.m", "begin": 335, "end": 340, "ner_label": "Frequency", "ner_confidence": "0.7438", "snomed_code": "27718001", "snomed_resolution": "msud", "snomed_confidence": "0.3374"}, {"ner_chunk": "50 mg", "begin": 343, "end": 347, "ner_label": "Strength", "ner_confidence": "0.93474996", "snomed_code": "314652000", "snomed_resolution": "child head circumference 50 equal to 50th centile", "snomed_confidence": "0.3395"}, {"ner_chunk": "1/150", "begin": 355, "end": 359, "ner_label": "Strength", "ner_confidence": "0.98", "snomed_code": "419329009", "snomed_resolution": "20/150", "snomed_confidence": "0.3446"}, {"ner_chunk": "sublingua ...
# {"predictions": [{"ner_chunk": "Two weeks prior", "begin": 0, "end": 14, "ner_label": "RelativeDate", "ner_confidence": "0.85400003", "snomed_code": "183621003", "snomed_resolution": "follow-up 2 weeks", "snomed_confidence": "0.3699"}, {"ner_chunk": "she", "begin": 34, "end": 36, "ner_label": "Gender", "ner_confidence": "0.9996", "snomed_code": "248152002", "snomed_resolution": "female", "snomed_confidence": "0.3487"}, {"ner_chunk": "five-day", "begin": 57, "end": 64, "ner_label": "Duration", "ner_confidence": "0.6886", "snomed_code": "276597004", "snomed_resolution": "fifth day fits", "snomed_confidence": "0.5215"}, {"ner_chunk": "respiratory tract infection", "begin": 82, "end": 108, "ner_label": "Disease_Syndrome_Disorder", "ner_confidence": "0.67156667", "snomed_code": "312117008", "snomed_resolution": "bacterial respiratory infection", "snomed_confidence": "0.5088"}, {"ner_chunk": "She", "begin": 112, "end": 114, "ner_label": "Gender", "ner_confidence": "0.9999", "snomed_code": "248152002", "snomed_resolution": "female", "snomed_confidence": "0.3383"}, {"ner_chunk": "T2DM", "begin": 135, "end": 138, "ner_label": "Diabetes", "ner_confidence": "0.9806", "snomed_code": "44054006", "snomed_resolution": "type 2 diabetes mellitus", "snomed_confidence": "0.5095"}, {"ner_chunk": "HTG", "begin": 152, "end": 154, "ner_label": "Hyperlipidemia", "ner_confidence": "0.9201", "snomed_code": "129007", "snomed_resolution": "homoiothermy", "snomed_confidence": "0.3373"}, {"ner_chunk": "She", "begin": 158, "end": 160, "ner_label": "Gender", "ner_confidence": "0.9999", "snomed_code": "248152002", "snomed_resolution": "female", "snomed_confidence": "0.3383"}, {"ner_chunk": "for six months", "begin": 174, "end": 187, "ner_label": "Duration", "ner_confidence": "0.7686", "snomed_code": "300042001", "snomed_resolution": "follow-up 6 months", "snomed_confidence": "0.3618"}, {"ner_chunk": "endocrinology service", "begin": 246, "end": 266, "ner_label": "Clinical_Dept", "ner_confidence": "0.94385", "snomed_code": "183535009", "snomed_resolution": "referred to endocrinologist", "snomed_confidence": "0.3367"}, {"ner_chunk": "she", "begin": 272, "end": 274, "ner_label": "Gender", "ner_confidence": "0.9999", "snomed_code": "248152002", "snomed_resolution": "female", "snomed_confidence": "0.3487"}, {"ner_chunk": "discharged", "begin": 280, "end": 289, "ner_label": "Admission_Discharge", "ner_confidence": "0.9999", "snomed_code": "430567009", "snomed_resolution": "discharge ready", "snomed_confidence": "0.3390"}, {"ner_chunk": "40 units", "begin": 294, "end": 301, "ner_label": "Dosage", "ner_confidence": "0.83655", "snomed_code": "819948005", "snomed_resolution": "body mass index equal to or greater than 40", "snomed_confidence": "0.3554"}, {"ner_chunk": "at night", "begin": 306, "end": 313, "ner_label": "Frequency", "ner_confidence": "0.4197", "snomed_code": "713822005", "snomed_resolution": "wakes up at night", "snomed_confidence": "0.5038"}, {"ner_chunk": "12 units", "begin": 317, "end": 324, "ner_label": "Dosage", "ner_confidence": "0.94965005", "snomed_code": "260274009", "snomed_resolution": "6/12", "snomed_confidence": "0.3408"}, {"ner_chunk": "with meals", "begin": 329, "end": 338, "ner_label": "Frequency", "ner_confidence": "0.5086", "snomed_code": "288886005", "snomed_resolution": "does eat", "snomed_confidence": "0.3393"}, {"ner_chunk": "1000 mg", "begin": 346, "end": 352, "ner_label": "Strength", "ner_confidence": "0.93395", "snomed_code": "23037000", "snomed_resolution": "parity ten or more", "snomed_confidence": "0.3440"}, {"ner_chunk": "two times a day", "begin": 354, "end": 368, "ner_label": "Frequency", "ner_confidence": "0.88875", "snomed_code": "185399004", "snomed_resolution": "patient comes 2 monthly", "snomed_confidence": "0.3364"}]}

# %%
model.delete_model()
# Out:
# INFO:sagemaker:Deleting model with name: en-resolve-snomed-findings-2024-05-02-10-12-05-696

# %% [markdown]
# ### Unsubscribe to the listing (optional)

# %% [markdown]
# If you would like to unsubscribe to the model package, follow these steps. Before you cancel the subscription, ensure that you do not have any [deployable model](https://console.aws.amazon.com/sagemaker/home#/models) created from the model package or using the algorithm. Note - You can find this information by looking at the container name associated with the model.
#
# **Steps to unsubscribe to product from AWS Marketplace**:
# 1. Navigate to __Machine Learning__ tab on [__Your Software subscriptions page__](https://aws.amazon.com/marketplace/ai/library?productType=ml&ref_=mlmp_gitdemo_indust)
# 2. Locate the listing that you want to cancel the subscription for, and then choose __Cancel Subscription__  to cancel the subscription.
