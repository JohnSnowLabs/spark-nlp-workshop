# %% [markdown]
# ## 1. Subscribe to the model package

# %% [markdown]
# To subscribe to the model package:
# 1. Open the model package listing page: [NCIT Clinical Terminology Mapper](https://aws.amazon.com/marketplace/pp/prodview-cnhtyygml2lms)
# 1. On the AWS Marketplace listing, click on the **Continue to subscribe** button.
# 1. On the **Subscribe to this software** page, review and click on **"Accept Offer"** if you and your organization agrees with EULA, pricing, and support terms.
# 1. Once you click on **Continue to configuration button** and then choose a **region**, you will see a **Product Arn** displayed. This is the model package ARN that you need to specify while creating a deployable model using Boto3. Copy the ARN corresponding to your region and specify the same in the following cell.

# %% [markdown]
# ## NCIT Clinical Terminology Mapper
#
# - **Model**: `ncit_vdb_resolver`
# - **Model Description**: This pretrained pipeline extracts oncological entities from clinical texts and maps them to their corresponding National Cancer Institute Thesaurus (NCIt) codes.

# %%
model_package_arn = "<Customer to specify Model package ARN corresponding to their AWS region>"

# %%
import json
import os
import boto3
import pandas as pd
import sagemaker as sage
from sagemaker import ModelPackage
from sagemaker import get_execution_role
from IPython.display import display
from urllib.parse import urlparse

# %%
sagemaker_session = sage.Session()
s3_bucket = sagemaker_session.default_bucket()
region = sagemaker_session.boto_region_name
account_id = boto3.client("sts").get_caller_identity().get("Account")
role = get_execution_role()

sagemaker = boto3.client("sagemaker")
s3_client = sagemaker_session.boto_session.client("s3")
ecr = boto3.client("ecr")
sm_runtime = boto3.client("sagemaker-runtime")

# Set display options
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
model_name = "ncit-vdb-resolver"

real_time_inference_instance_type = "ml.m4.xlarge"
batch_transform_inference_instance_type = "ml.m4.2xlarge"

# %% [markdown]
# ## 2. Create a deployable model from the model package.

# %%
model = ModelPackage(
    role=role, 
    model_package_arn=model_package_arn,
    sagemaker_session=sagemaker_session,
)

# %% [markdown]
# ### Input Format
#
# To use the model, you need to provide input in one of the following supported formats:
#
# #### JSON Format
#
# Provide input as JSON. We support two variations within this format:
#
# 1. **Array of Text Documents**:
#    Use an array containing multiple text documents. Each element represents a separate text document.
#
#    ```json
#    {
#        "text": [
#            "Text document 1",
#            "Text document 2",
#            ...
#        ]
#    }
#
#     ```
#
# 2. **Single Text Document**:
#    Provide a single text document as a string.
#
#
#    ```json
#     {
#         "text": "Single text document"
#     }
#    ```
#
# #### JSON Lines (JSONL) Format
#
# Provide input in JSON Lines format, where each line is a JSON object representing a text document.
#
# ```
# {"text": "Text document 1"}
# {"text": "Text document 2"}
# ```

# %% [markdown]
# ## 3. Create an endpoint and perform real-time inference

# %% [markdown]
# If you want to understand how real-time inference with Amazon SageMaker works, see [Documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/how-it-works-hosting.html).

# %% [markdown]
# ### A. Deploy the SageMaker model to an endpoint

# %%
predictor = model.deploy(
    initial_instance_count=1,
    instance_type=real_time_inference_instance_type, 
    endpoint_name=model_name,
)
# Out:
# ------------!

# %% [markdown]
# Once endpoint has been created, you would be able to perform real-time inference.

# %%
def invoke_realtime_endpoint(record, content_type="application/json", accept="application/json"):
    response = sm_runtime.invoke_endpoint(
        EndpointName=model_name,
        ContentType=content_type,
        Accept=accept,
        Body=json.dumps(record) if content_type == "application/json" else record,
    )

    response_body = response["Body"].read().decode("utf-8")

    if accept == "application/json":
        return json.loads(response_body)
    elif accept == "application/jsonlines":
        return response_body
    else:
        raise ValueError(f"Unsupported accept type: {accept}")

# %% [markdown]
# ### Initial Setup

# %%
docs = [
    '''A 65-year-old woman had a history of debulking surgery, bilateral oophorectomy with omentectomy, total hysterectomy with radical pelvic lymph nodes dissection due to ovarian carcinoma (mucinous-type carcinoma, stage Ic) 1 year ago. Patient's medical compliance was poor and failed to complete her chemotherapy (cyclophosphamide 750 mg/m2, carboplatin 300 mg/m2). Recently, she noted a palpable right breast mass, 15 cm in size which nearly occupied the whole right breast in 2 months. Core needle biopsy revealed metaplastic carcinoma.''',
    '''She underwent a computed tomography (CT) scan of the abdomen and pelvis, which showed a complex ovarian mass. A Pap smear performed one month later was positive for atypical glandular cells suspicious for adenocarcinoma. The pathologic specimen showed extension of the tumor throughout the fallopian tubes, appendix, omentum, and 5 out of 5 enlarged lymph nodes. The final pathologic diagnosis of the tumor was stage IIIC papillary serous ovarian adenocarcinoma. Two months later, the patient was diagnosed with lung metastases.'''
]

sample_text = '''There was no differentiated component characteristic of adenocarcinoma, acinar cell carcinoma or hepatoid carcinoma of the pancreas. The surgical margins were negative for neoplastic infiltration. There was no evidence of perineural invasion. No lymph node metastasis was shown.'''

# %% [markdown]
# ### JSON

# %%
input_json_data = {"text": sample_text}
response_json = invoke_realtime_endpoint(input_json_data, content_type="application/json", accept="application/json")
pd.DataFrame(response_json["predictions"][0])
# Out:
#    begin  end                  ner_chunk             ner_label ner_confidence  \
# 0     56   69             adenocarcinoma             Cancer_dx           None
# 1     72   92      acinar cell carcinoma             Cancer_dx           None
# 2     97  104                   hepatoid     Histological_Type         0.9959
# 3    106  130  carcinoma of the pancreas             Cancer_dx           None
# 4    172  194    neoplastic infiltration              Invasion     0.63014996
# 5    222  231                 perineural  Site_Other_Body_Part         0.8878
# 6    233  240                   invasion              Invasion         0.9605
# 7    246  255                 lymph node       Site_Lymph_Node        0.88265
# 8    257  266                 metastasis            Metastasis         0.9999
#
#   concept_code                  resolution     score  \
# 0        C5105   colorectal adenocarcinoma  0.903468
# 1        C3768       acinar cell carcinoma  1.000000
# 2       C66950          hepatoid carcinoma  0.840701
# 3        C3850   carcinoma of the pancreas  1.000000
# 4      C187950  tumor infiltration pattern  0.877209
# 5       C38293              perineural use  0.914298
# 6       C20625                    invasion  1.000000
# 7       C33769         thoracic lymph node  0.897823
# 8       C40557                  metastases  0.938635
#
#                                     all_codes  \
# 0         [C5105, C4349, C4349, C4349, C3512]
# 1         [C3768, C3768, C3768, C4197, C4197]
# 2    [C66950, C66950, C95465, C13308, C95747]
# 3         [C3850, C3850, C3850, C3850, C3850]
# 4  [C187950, C187950, C48607, C137710, C4194]
# 5    [C38293, C66845, C41407, C38293, C41416]
# 6   [C20625, C14159, C20625, C75004, C150571]
# 7   [C33769, C32298, C77643, C176317, C12358]
# 8       [C40557, C7511, C3577, C3577, C36263]
#
#                                                                                                                                                      all_resolutions  \
# 0                                       [colorectal adenocarcinoma, colon adenocarcinoma, adenocarcinoma of the colon, adenocarcinoma of colon, lung adenocarcinoma]
# 1                                                 [acinar cell carcinoma, acinar carcinoma, acinar cell adenocarcinoma, acinar cell neoplasms, acinar cell neoplasm]
# 2                                             [hepatoid carcinoma, hepatoid adenocarcinoma, pancreatic hepatoid carcinoma, hepatic, gastric hepatoid adenocarcinoma]
# 3                                               [carcinoma of the pancreas, carcinoma of pancreas, pancreas carcinoma, pancreatic carcinoma, cancer of the pancreas]
# 4  [tumor infiltration pattern, tumor infiltration pattern assessment, infiltrating melanoma, infiltrative tumor margin present, infiltrating ductal adenocarcinoma]
# 5                                                         [perineural use, perineural mpnst, perineural tissue, perineural route of administration, perineural cell]
# 6                                                                                               [invasion, invasive, tumor invasion, cell invasion, muscle invasion]
# 7                                                          [thoracic lymph node, cervical lymph node, aortic lymph node, colon lymph node, head and neck lymph node]
# 8                                                                          [metastases, breast metastasis, pulmonary metastasis, lung metastasis, metastatic cancer]
#
#                                                                                               all_score
# 0   [0.9034679532051086, 0.894524097442627, 0.8823219537734985, 0.8813044428825378, 0.8766085505485535]
# 1   [1.0000001192092896, 0.9744840860366821, 0.958342432975769, 0.9396045804023743, 0.9360271692276001]
# 2  [0.8407007455825806, 0.8229171633720398, 0.7699582576751709, 0.7680760622024536, 0.7676540613174438]
# 3    [1.000000238418579, 0.9960108995437622, 0.956427276134491, 0.9453885555267334, 0.9308969974517822]
# 4  [0.8772085905075073, 0.8395975828170776, 0.8199583292007446, 0.8191666603088379, 0.8172265291213989]
# 5  [0.9142981767654419, 0.8962826132774353, 0.8755375146865845, 0.8609194755554199, 0.8605987429618835]
# 6    [1.000000238418579, 0.848335862159729, 0.8024402856826782, 0.7883122563362122, 0.7553536295890808]
# 7   [0.8978233933448792, 0.8929641246795654, 0.889636754989624, 0.8832467198371887, 0.8809458017349243]
# 8    [0.9386346936225891, 0.897005021572113, 0.887118935585022, 0.8848515152931213, 0.8798297047615051]

# %% [markdown]
# ### JSON Lines

# %%
def create_jsonl(records):
    if isinstance(records, str):
        records = [records]
    json_records = [{"text": text} for text in records]
    json_lines = "\n".join(json.dumps(record) for record in json_records)
    return json_lines

# %%
input_jsonl_data = create_jsonl(sample_text)
data = invoke_realtime_endpoint(input_jsonl_data, content_type="application/jsonlines" , accept="application/jsonlines" )
print(data)
# Out:
# {"predictions": [{"begin": 56, "end": 69, "ner_chunk": "adenocarcinoma", "ner_label": "Cancer_dx", "ner_confidence": null, "concept_code": "C5105", "resolution": "colorectal adenocarcinoma", "score": 0.9034679532051086, "all_codes": ["C5105", "C4349", "C4349", "C4349", "C3512"], "all_resolutions": ["colorectal adenocarcinoma", "colon adenocarcinoma", "adenocarcinoma of the colon", "adenocarcinoma of colon", "lung adenocarcinoma"], "all_score": [0.9034679532051086, 0.894524097442627, 0.8823219537734985, 0.8813044428825378, 0.8766085505485535]}, {"begin": 72, "end": 92, "ner_chunk": "acinar cell carcinoma", "ner_label": "Cancer_dx", "ner_confidence": null, "concept_code": "C3768", "resolution": "acinar cell carcinoma", "score": 1.0000001192092896, "all_codes": ["C3768", "C3768", "C3768", "C4197", "C4197"], "all_resolutions": ["acinar cell carcinoma", "acinar carcinoma", "acinar cell adenocarcinoma", "acinar cell neoplasms", "acinar cell neoplasm"], "all_score": [1.0000001192092896, 0.9744840860366821, 0.958342432975769, 0.9396045804023743, 0.9360271692276001]}, {"begin": 97, "end": 104, "ner_chunk": "hepatoid", "ner_label": "Histological_Type", "ner_confidence": "0.9959", "concept_code": "C66950", "resolution": "hepatoid carcinoma", "score": 0.8407007455825806, "all_codes": ["C66950", "C66950", "C95465", "C13308", "C95747"], "all_resolutions": ["hepatoid carcinoma", "hepatoid adenocarcinoma", "pancreatic hepatoid carcinoma", "hepatic", "gastric hepatoid adenocarcinoma"], "all_score": [0.8407007455825806, 0.8229171633720398, 0.7699582576751709, 0.7680760622024536, 0.7676540613174438]}, {"begin": 106, "end": 130, "ner_chunk": "carcinoma of the pancreas", "ner_label": "Cancer_dx", "ner_confidence": null, "concept_code": "C3850", "resolution": "carcinoma of the pancreas", "score": 1.000000238418579, "all_codes": ["C3850", "C3850", "C3850", "C3850", "C3850"], "all_resolutions": ["carcinoma of the pancreas", "carcinoma of pancreas", "pancreas carcinoma", "pancreatic carcinoma", "cancer of the pancreas"], "all_score": [1.000000238418579, 0.9960108995437622, 0.956427276134491, 0.9453885555267334, 0.9308969974517822]}, {"begin": 172, "end": 194, "ner_chunk": "neoplastic infiltration", "ner_label": "Invasion", "ner_confidence": "0.63014996", "concept_code": "C187950", "resolution": "tumor infiltration pattern", "score": 0.8772085905075073, "all_codes": ["C187950", "C187950", "C48607", "C137710", "C4194"], "all_resolutions": ["tumor infiltration pattern", "tumor infiltration pattern assessment", "infiltrating melanoma", "infiltrative tumor margin present", "infiltrating ductal adenocarcinoma"], "all_score": [0.8772085905075073, 0.8395975828170776, 0.8199583292007446, 0.8191666603088379, 0.8172265291213989]}, {"begin": 222, "end": 231, "ner_chunk": "perineural", "ner_label": "Site_Other_Body_Part", "ner_confidence": "0.8878", "concept_code": "C38293", "resolution": "perineural use", "score": 0.9142981767654419, "all_codes": ["C38293", "C66845", "C41407", "C38293", "C41416"], "all_resolutions": ["perineural use", "perineural mpnst", "perineural tissue", "perineural route of administration", "perineural cell"], "all_score": [0.9142981767654419, 0.8962826132774353, 0.8755375146865845, 0.8609194755554199, 0.8605987429618835]}, {"begin": 233, "end": 240, "ner_chunk": "invasion", "ner_label": "Invasion", "ner_confidence": "0.9605", "concept_code": "C20625", "resolution": "invasion", "score": 1.000000238418579, "all_codes": ["C20625", "C14159", "C20625", "C75004", "C150571"], "all_resolutions": ["invasion", "invasive", "tumor invasion", "cell invasion", "muscle invasion"], "all_score": [1.000000238418579, 0.848335862159729, 0.8024402856826782, 0.7883122563362122, 0.7553536295890808]}, {"begin": 246, "end": 255, "ner_chunk": "lymph node", "ner_label": "Site_Lymph_Node", "ner_confidence": "0.88265", "concept_code": "C33769", "resolution": "thoracic lymph node", "score": 0.8978233933448792, "all_codes": ["C33769", "C32298", "C77643", "C176317", "C123 ...

# %% [markdown]
# ### B. Delete the endpoint

# %% [markdown]
# Now that you have successfully performed a real-time inference, you do not need the endpoint any more. You can terminate the endpoint to avoid being charged.

# %%
model.sagemaker_session.delete_endpoint(model_name)
model.sagemaker_session.delete_endpoint_config(model_name)

# %% [markdown]
# ## 4. Batch inference

# %%
validation_json_file_name = "input.json"
validation_jsonl_file_name = "input.jsonl"

validation_input_json_path = f"s3://{s3_bucket}/{model_name}/validation-input/json/"
validation_output_json_path = f"s3://{s3_bucket}/{model_name}/validation-output/json/"

validation_input_jsonl_path = f"s3://{s3_bucket}/{model_name}/validation-input/jsonl/"
validation_output_jsonl_path = f"s3://{s3_bucket}/{model_name}/validation-output/jsonl/"

def upload_to_s3(input_data, file_name):
    file_format = os.path.splitext(file_name)[1].lower()
    s3_client.put_object(
        Bucket=s3_bucket,
        Key=f"{model_name}/validation-input/{file_format[1:]}/{file_name}",
        Body=input_data.encode("UTF-8"),
    )

# %%
# Create JSON and JSON Lines data
input_jsonl_data = create_jsonl(docs)
input_json_data = json.dumps({"text": docs})

# Upload JSON and JSON Lines data to S3
upload_to_s3(input_json_data, validation_json_file_name)
upload_to_s3(input_jsonl_data, validation_jsonl_file_name)

# %% [markdown]
# ### JSON

# %%
transformer = model.transformer(
    instance_count=1,
    instance_type=batch_transform_inference_instance_type,
    accept="application/json",
    output_path=validation_output_json_path
)

transformer.transform(validation_input_json_path, content_type="application/json")
transformer.wait()

# %%
def retrieve_json_output_from_s3(validation_file_name):
    parsed_url = urlparse(transformer.output_path)
    file_key = f"{parsed_url.path[1:]}{validation_file_name}.out"
    response = s3_client.get_object(Bucket=s3_bucket, Key=file_key)

    data = json.loads(response["Body"].read().decode("utf-8"))
    display(data)

# %%
retrieve_json_output_from_s3(validation_json_file_name)
# Out:
# {'predictions': [[{'begin': 37,
#     'end': 53,
#     'ner_chunk': 'debulking surgery',
#     'ner_label': 'Cancer_Surgery',
#     'ner_confidence': '0.78400004',
#     'concept_code': 'C15749',
#     'resolution': 'debulking surgery',
#     'score': 0.9999998211860657,
#     'all_codes': ['C15749', 'C160865', 'C160866', 'C15749', 'C15749'],
#     'all_resolutions': ['debulking surgery',
#      'primary debulking surgery',
#      'interval debulking surgery',
#      'debulking procedure',
#      'debulking'],
#     'all_score': [0.9999998211860657,
#      0.9072895646095276,
#      0.8973025679588318,
#      0.8779721260070801,
#      0.851721465587616]},
#    {'begin': 56,
#     'end': 77,
#     'ner_chunk': 'bilateral oophorectomy',
#     'ner_label': 'Cancer_Surgery',
#     'ner_confidence': '0.83615005',
#     'concept_code': 'C51590',
#     'resolution': 'bilateral oophorectomy',
#     'score': 0.9999991655349731,
#     'all_codes': ['C51590', 'C51765', 'C51765', 'C49133', 'C51667'],
#     'all_resolutions': ['bilateral oophorectomy',
#      'bilateral salpingo-oophorectomy',
#      'bilateral salpingectomy with oophorectomy',
#      'bilateral prophylactic oophorectomy',
#      'bilateral salpingectomy'],
#     'all_score': [0.9999991655349731,
#      0.9659522771835327,
#      0.9521262049674988,
#      0.9364778399467468,
#      0.9134529829025269]},
#    {'begin': 84,
#     'end': 94,
#     'ner_chunk': 'omentectomy',
#     'ner_label': 'Cancer_Surgery',
#     'ner_confidence': '0.988',
#     'concept_code': 'C51787',
#     'resolution': 'omentectomy',
#     'score': 1.0,
#     'all_codes': ['C51787', 'C51788', 'C51787', 'C51788', 'C33209'],
#     'all_resolutions': ['omentectomy',
#      'partial omentectomy',
#      'resection of omentum',
#      'partial resection of omentum',
#      'omentum'],
#     'all_score': [1.0,
#      0.8603771924972534,
#      0.8370007276535034,
#      0.8057854771614075,
#      0.7462188005447388]},
#    {'begin': 97,
#     'end': 114,
#     'ner_chunk': 'total hysterectomy',
#     'ner_label': 'Cancer_Surgery',
#     'ner_confidence': '0.95624995',
#     'concept_code': 'C15701',
#     'resolution': 'total hysterectomy',
#     'score': 1.0,
#     'all_codes': ['C15701', 'C51695', 'C15701', 'C15701', 'C51660'],
#     'all_resolutions': ['total hysterectomy',
#      'total abdominal hysterectomy',
#      'complete hysterectomy',
#      'full hysterectomy',
#      'abdominal hysterectomy'],
#     'all_score': [1.0,
#      0.970645546913147,
#      0.8939006328582764,
#      0.8890131115913391,
#      0.8696088790893555]},
#    {'begin': 121,
#     'end': 157,
#     'ner_chunk': 'radical pelvic lymph nodes dissection',
#     'ner_label': 'Cancer_Surgery',
#     'ner_confidence': '0.80143994',
#     'concept_code': 'C51896',
#     'resolution': 'pelvic lymph node dissection',
#     'score': 0.9299925565719604,
#     'all_codes': ['C51896', 'C48936', 'C166163', 'C51896', 'C51896'],
#     'all_resolutions': ['pelvic lymph node dissection',
#      'radical lymph node dissection',
#      'bilateral pelvic lymph node dissection',
#      'pelvic lymphadenectomy',
#      'excision pelvic lymph nodes'],
#     'all_score': [0.9299925565719604,
#      0.9063621163368225,
#      0.8415289521217346,
#      0.8406316041946411,
#      0.8394026160240173]},
#    {'begin': 166,
#     'end': 182,
#     'ner_chunk': 'ovarian carcinoma',
#     'ner_label': 'Cancer_dx',
#     'ner_confidence': None,
#     'concept_code': 'C4908',
#     'resolution': 'ovarian carcinoma',
#     'score': 1.0,
#     'all_codes': ['C4908', 'C4908', 'C4908', 'C4908', 'C4984'],
#     'all_resolutions': ['ovarian carcinoma',
#      'carcinoma of ovary',
#      'ovarian cancer',
#      'carcinoma of the ovary',
#      'ovarian tumor'],
#     'all_score': [1.0,
#      0.9383364915847778,
#      0.9361096620559692,
#      0.9348263144493103,
#      0.9038485288619995]},
#    {'begin': 185,
#     'end': 207,
#     'ner_chunk': 'mucinous-type carcinoma',
#     'ner_label': 'Cancer_dx',
#     'ner_confidence': None,
#     'concept_code': 'C40203',
#     'resolution': 'cervical mucinous adenocarcinoma, intestinal-type',
#     'score': 0.8483723998069763,
#     'all_codes': ['C40203', 'C7966', 'C9131', 'C180537', 'C9131'],
#     'all_resolutions': ['cervical mucinous adenocarcinoma, intestinal-type',
#      'mucinous colon adenocarcinoma',
#      'mucinous breast carcinoma',
#      'endometrial mucinous adenocarcinoma, gastric-type',
#      'mucinous carcinoma of breast'],
#     'all_score': [0.8483723998069763,
#      0.8411674499511719,
#      0.8380377292633057,
#      0.8362902402877808,
#      0.8351631760597229]},
#    {'begin': 210,
#     'end': 217,
#     'ner_chunk': 'stage Ic',
#     'ner_label': 'Staging',
#     'ner_confidence': '0.9956',
#     'concept_code': 'C141199',
#     'resolution': 'stage ie',
#     'score': 0.8238500356674194,
#     'all_codes': ['C141199', 'C16899', 'C5222', 'C137669', 'C48717'],
#     'all_resolutions': ['stage ie',
#      'stage',
#      'ovarian cancer stage ic',
#      'stage iic',
#      'n3c stage'],
#     'all_score': [0.8238500356674194,
#      0.8226260542869568,
#      0.8223692178726196,
#      0.8138011693954468,
#      0.8135220408439636]},
#    {'begin': 297,
#     'end': 308,
#     'ner_chunk': 'chemotherapy',
#     'ner_label': 'Chemotherapy',
#     'ner_confidence': '0.9999',
#     'concept_code': 'C15632',
#     'resolution': 'chemotherapy',
#     'score': 1.0000004768371582,
#     'all_codes': ['C15632', 'C15632', 'C191', 'C15632', 'C191'],
#     'all_resolutions': ['chemotherapy',
#      'chemo',
#      'chemotherapy, combination',
#      'chemotherapy, cancer, general',
#      'combination chemotherapy'],
#     'all_score': [1.0000004768371582,
#      0.8737051486968994,
#      0.8588521480560303,
#      0.844483494758606,
#      0.8398085236549377]},
#    {'begin': 311,
#     'end': 326,
#     'ner_chunk': 'cyclophosphamide',
#     'ner_label': 'Chemotherapy',
#     'ner_confidence': '0.9997',
#     'concept_code': 'C405',
#     'resolution': 'cyclophosphamide',
#     'score': 1.0000001192092896,
#     'all_codes': ['C405', 'C405', 'C9569', 'C9569', 'C63444'],
#     'all_resolutions': ['cyclophosphamide',
#      '(-)-cyclophosphamide',
#      'cisplatin-cyclophosphamide',
#      'cyclophosphamide-cisplatin',
#      'cyclophosphamide-fludarabine'],
#     'all_score': [1.0000001192092896,
#      0.9113725423812866,
#      0.9031081795692444,
#      0.8940169811248779,
#      0.8878666162490845]},
#    {'begin': 339,
#     'end': 349,
#     'ner_chunk': 'carboplatin',
#     'ner_label': 'Chemotherapy',
#     'ner_confidence': '1.0',
#     'concept_code': 'C9532',
#     'resolution': 'carboplatin-cyclophosphamide',
#     'score': 0.898856520652771,
#     'all_codes': ['C9532', 'C9532', 'C9532', 'C11854', 'C63402'],
#     'all_resolutions': ['carboplatin-cyclophosphamide',
#      'cyclophosphamide-carboplatin',
#      'carboplatin/cyclophosphamide',
#      'bms-188797/carboplatin',
#      'carboplatin-taxol'],
#     'all_score': [0.898856520652771,
#      0.8942525386810303,
#      0.8942489624023438,
#      0.8898212909698486,
#      0.8866156339645386]},
#    {'begin': 394,
#     'end': 398,
#     'ner_chunk': 'right',
#     'ner_label': 'Direction',
#     'ner_confidence': '0.9843',
#     'concept_code': 'C160199',
#     'resolution': 'right',
#     'score': 1.0000001192092896,
#     'all_codes': ['C160199', 'C124581', 'C33483', 'C49326', 'C12383'],
#     'all_resolutions': ['right',
#      'right-sided',
#      'lung, right',
#      'right testis',
#      'colon, right'],
#     'all_score': [1.0000001192092896,
#      0.737230658531189,
#      0.7326736450195312,
#      0.7324438095092773,
#      0.7295462489128113]},
#    {'begin': 400,
#     'end': 405,
#     'ner_chunk': 'breast',
#     'ner_label': 'Site_Breast',
#     'ner_confidence': '0.9931',
#     'concept_code': 'C13020',
#     'resolution': 'breast part',
#     'score': 0.874566912651062,
#     'all_codes': ['C13020', 'C12370', 'C43595', 'C176709', 'C118809'],
#     'all_resolutions': ['breast part',
#      'breast tissue',
#      'mammary',
#      'breast finding',
#      'breast cancer'],
#     'all_score': [0.874566912651062,
#      0.8470743298530579,
#      0.8454772233963013,
#      0.8377044200897217,
#      0.8345293402671814]},
#    {'begin': 407,
#     'end': 410,
#     'ner_chunk': 'mass',
#     'ner_label': 'Tumor_Finding',
#     'ner_confidence': '0.9915',
#     'concept_code': 'C126027',
#     'resolution': 'mass',
#     'score': 1.0000007152557373,
#     'all_codes': ['C126027', 'C90335', 'C112025', 'C42579', 'C45978'],
#     'all_resolutions': ['mass',
#      'mass description',
#      'mass measurement',
#      'unit of mass',
#      'fungating mass'],
#     'all_score': [1.0000007152557373,
#      0.840757429599762,
#      0.7978991866111755,
#      0.7876405119895935,
#      0.7833571434020996]},
#    {'begin': 459,
#     'end': 463,
#     'ner_chunk': 'right',
#     'ner_label': 'Direction',
#     'ner_confidence': '0.9842',
#     'concept_code': 'C160199',
#     'resolution': 'right',
#     'score': 1.0000001192092896,
#     'all_codes': ['C160199', 'C124581', 'C33483', 'C49326', 'C12383'],
#     'all_resolutions': ['right',
#      'right-sided',
#      'lung, right',
#      'right testis',
#      'colon, right'],
#     'all_score': [1.0000001192092896,
#      0.737230658531189,
#      0.7326736450195312,
#      0.7324438095092773,
#      0.7295462489128113]},
#    {'begin': 465,
#     'end': 470,
#     'ner_chunk': 'breast',
#     'ner_label': 'Site_Breast',
#     'ner_confidence': '0.9778',
#     'concept_code': 'C13020',
#     'resolution': 'breast part',
#     'score': 0.874566912651062,
#     'all_codes': ['C13020', 'C12370', 'C43595', 'C176709', 'C118809'],
#     'all_resolutions': ['breast part',
#      'breast tissue',
#      'mammary',
#      'breast finding',
#      'breast cancer'],
#     'all_score': [0.874566912651062,
#      0.8470743298530579,
#      0.8454772233963013,
#      0.8377044200897217,
#      0.8345293402671814]},
#    {'begin': 485,
#     'end': 502,
#     'ner_chunk': 'Core needle biopsy',
#     'ner_label': 'Pathology_Test',
#     'ner_confidence': '0.7783666',
#     'concept_code': 'C15680',
#     'resolution': 'core needle biopsy',
#     'score': 1.0,
#     'all_codes': ['C15680', 'C15680', 'C15680', 'C51489', 'C15680'],
#     'all_resolutions': ['core needle biopsy',
#      'core biopsy',
#      'biopsy, core',
#      'core needle biopsy of pancreas',
#      'core needle'],
#     'all_score': [1.0,
#      0.9511011838912964,
#      0.9255685806274414,
#      0.9093362092971802,
#      0.8914773464202881]},
#    {'begin': 513,
#     'end': 533,
#     'ner_chunk': 'metaplastic carcinoma',
#     'ner_label': 'Cancer_dx',
#     'ner_confidence': None,
#     'concept_code': 'C5164',
#     'resolution': 'metaplastic breast carcinoma',
#     'score': 0.9427019357681274,
#     'all_codes': ['C5164', 'C5164', 'C5164', 'C5164', 'C165468'],
#     'all_resolutions': ['metaplastic breast carcinoma',
#      'breast metaplastic carcinoma',
#      'metaplastic carcinoma of breast',
#      'metaplastic carcinoma of the breast',
#      'skin metaplastic carcinoma'],
#     'all_score': [0.9427019357681274,
#      0.9393040537834167,
#      0.9382847547531128,
#      0.9349066019058228,
#      0.9248149394989014]}],
#   [{'begin': 16,
#     'end': 34,
#     'ner_chunk': 'computed tomography',
#     'ner_label': 'Imaging_Test',
#     'ner_confidence': '0.93485',
#     'concept_code': 'C17204',
#     'resolution': 'computed tomography',
#     'score': 1.0000003576278687,
#     'all_codes': ['C17204', 'C159883', 'C17204', 'C17204', 'C45844'],
#     'all_resolutions': ['computed tomography',
#      'urography computed tomography',
#      'computed axial tomography',
#      'ct scan',
#      'ct scanner'],
#     'all_score': [1.0000003576278687,
#      0.8956605195999146,
#      0.8955866098403931,
#      0.8854690790176392,
#      0.8733323216438293]},
#    {'begin': 37,
#     'end': 38,
#     'ner_chunk': 'CT',
#     'ner_label': 'Imaging_Test',
#     'ner_confidence': '0.9724',
#     'concept_code': 'C104954',
#     'resolution': 'ct',
#     'score': 1.0000003576278687,
#     'all_codes': ['C104954', 'C104957', 'C45844', 'C161328', 'C123577'],
#     'all_resolutions': ['ct', 'ct a', 'ct scanner', 'ct number', 'cr-ct'],
#     'all_score': [1.0000003576278687,
#      0.8701925277709961,
#      0.8519605398178101,
#      0.8456451892852783,
#      0.8418126702308655]},
#    {'begin': 53,
#     'end': 59,
#     'ner_chunk': 'abdomen',
#     'ner_label': 'Site_Other_Body_Part',
#     'ner_confidence': '0.9363',
#     'concept_code': 'C12664',
#     'resolution': 'abdomen',
#     'score': 1.0000008344650269,
#     'all_codes': ['C12664', 'C12391', 'C12664', 'C12664', 'C13025'],
#     'all_resolutions': ['abdomen',
#      'stomach',
#      'abdomen, nos',
#      'abdomen, total',
#      'stomach part'],
#     'all_score': [1.0000008344650269,
#      0.8771505951881409,
#      0.8585428595542908,
#      0.8531992435455322,
#      0.8376491665840149]},
#    {'begin': 65,
#     'end': 70,
#     'ner_chunk': 'pelvis',
#     'ner_label': 'Site_Other_Body_Part',
#     'ner_confidence': '0.5375',
#     'concept_code': 'C33287',
#     'resolution': 'bone, pelvis',
#     'score': 0.8741136789321899,
#     'all_codes': ['C33287', 'C12887', 'C105733', 'C33287', 'C23817'],
#     'all_resolutions': ['bone, pelvis',
#      'renal pelvis',
#      'whole-pelvis',
#      'pelvic bone',
#      'kidney/renal pelvis'],
#     'all_score': [0.8741136789321899,
#      0.8667565584182739,
#      0.8562899827957153,
#      0.8388118743896484,
#      0.8083593249320984]},
#    {'begin': 96,
#     'end': 102,
#     'ner_chunk': 'ovarian',
#     'ner_label': 'Site_Other_Body_Part',
#     'ner_confidence': '0.7866',
#     'concept_code': 'C12404',
#     'resolution': 'ovary',
#     'score': 0.8572745323181152,
#     'all_codes': ['C12404', 'C12404', 'C33243', 'C3882', 'C33244'],
#     'all_resolutions': ['ovary',
#      'ovaries',
#      'ovarian cortex',
#      'ovarian mass',
#      'ovarian follicle'],
#     'all_score': [0.8572745323181152,
#      0.8545776605606079,
#      0.8522234559059143,
#      0.8421778082847595,
#      0.8389604091644287]},
#    {'begin': 104,
#     'end': 107,
#     'ner_chunk': 'mass',
#     'ner_label': 'Tumor_Finding',
#     'ner_confidence': '0.9573',
#     'concept_code': 'C126027',
#     'resolution': 'mass',
#     'score': 1.0000007152557373,
#     'all_codes': ['C126027', 'C90335', 'C112025', 'C42579', 'C45978'],
#     'all_resolutions': ['mass',
#      'mass description',
#      'mass measurement',
#      'unit of mass',
#      'fungating mass'],
#     'all_score': [1.0000007152557373,
#      0.840757429599762,
#      0.7978991866111755,
#      0.7876405119895935,
#      0.7833571434020996]},
#    {'begin': 112,
#     'end': 120,
#     'ner_chunk': 'Pap smear',
#     'ner_label': 'Pathology_Test',
#     'ner_confidence': '0.96725',
#     'concept_code': 'C62670',
#     'resolution': 'cervical pap test',
#     'score': 0.8581546545028687,
#     'all_codes': ['C62670', 'C65126', 'C79903', 'C105383', 'C128984'],
#     'all_resolutions': ['cervical pap test',
#      'smear',
#      'blood smear',
#      'pap',
#      'pap stain'],
#     'all_score': [0.8581546545028687,
#      0.856905996799469,
#      0.8153881430625916,
#      0.8133909702301025,
#      0.8035245537757874]},
#    {'begin': 165,
#     'end': 188,
#     'ner_chunk': 'atypical glandular cells',
#     'ner_label': 'Pathology_Result',
#     'ner_confidence': '0.7270667',
#     'concept_code': 'C36912',
#     'resolution': 'atypical glandular cell',
#     'score': 0.992756724357605,
#     'all_codes': ['C36912', 'C36912', 'C8435', 'C8435', 'C8341'],
#     'all_resolutions': ['atypical glandular cell',
#      'atypical glandular cell, not otherwise specified',
#      'atypical glandular cells of uncertain significance',
#      'atypical glandular cells of undetermined significance',
#      'glandular cell atypia'],
#     'all_score': [0.992756724357605,
#      0.938469648361206,
#      0.9353052973747253,
#      0.9344968199729919,
#      0.9308472871780396]},
#    {'begin': 205,
#     'end': 218,
#     'ner_chunk': 'adenocarcinoma',
#     'ner_label': 'Cancer_dx',
#     'ner_confidence': None,
#     'concept_code': 'C5105',
#     'resolution': 'colorectal adenocarcinoma',
#     'score': 0.9034679532051086,
#     'all_codes': ['C5105', 'C4349', 'C4349', 'C4349', 'C3512'],
#     'all_resolutions': ['colorectal adenocarcinoma',
#      'colon adenocarcinoma',
#      'adenocarcinoma of the colon',
#      'adenocarcinoma of colon',
#      'lung adenocarcinoma'],
#     'all_score': [0.9034679532051086,
#      0.8945242166519165,
#      0.8823220133781433,
#      0.8813044428825378,
#      0.8766086101531982]},
#    {'begin': 225,
#     'end': 243,
#     'ner_chunk': 'pathologic specimen',
#     'ner_label': 'Pathology_Test',
#     'ner_confidence': '0.76105',
#     'concept_code': 'C18202',
#     'resolution': 'biopsy specimen',
#     'score': 0.9088883399963379,
#     'all_codes': ['C18202', 'C85501', 'C171436', 'C164014', 'C125006'],
#     'all_resolutions': ['biopsy specimen',
#      'smear specimen',
#      'specimen pathology indicator',
#      'solid tissue specimen',
#      'pathologic examination'],
#     'all_score': [0.9088883399963379,
#      0.8782558441162109,
#      0.8690714240074158,
#      0.8651908040046692,
#      0.8629587888717651]},
#    {'begin': 252,
#     'end': 260,
#     'ner_chunk': 'extension',
#     'ner_label': 'Invasion',
#     'ner_confidence': '0.9241',
#     'concept_code': 'C45846',
#     'resolution': 'extendable',
#     'score': 0.8294858932495117,
#     'all_codes': ['C45846', 'C120271', 'C91271', 'C182346', 'C173150'],
#     'all_resolutions': ['extendable',
#      'direct extension',
#      'dynamic extension',
#      'extension comment',
#      'extent question'],
#     'all_score': [0.8294858932495117,
#      0.8277506828308105,
#      0.8193066716194153,
#      0.8085264563560486,
#      0.7912508845329285]},
#    {'begin': 269,
#     'end': 273,
#     'ner_chunk': 'tumor',
#     'ner_label': 'Tumor_Finding',
#     'ner_confidence': '0.9077',
#     'concept_code': 'C12922',
#     'resolution': 'tumor cell',
#     'score': 0.8479248881340027,
#     'all_codes': ['C12922', 'C3677', 'C23852', 'C4063', 'C3261'],
#     'all_resolutions': ['tumor cell',
#      'tumor, benign',
#      'tumor cells',
#      'tumor of muscle',
#      'tumor, metastatic'],
#     'all_score': [0.8479248881340027,
#      0.8418221473693848,
#      0.841091513633728,
#      0.8219225406646729,
#      0.8128739595413208]},
#    {'begin': 290,
#     'end': 304,
#     'ner_chunk': 'fallopian tubes',
#     'ner_label': 'Site_Other_Body_Part',
#     'ner_confidence': '0.9492',
#     'concept_code': 'C12403',
#     'resolution': 'fallopian tubes',
#     'score': 1.0000007152557373,
#     'all_codes': ['C12403', 'C12403', 'C33475', 'C12403', 'C33475'],
#     'all_resolutions': ['fallopian tubes',
#      'fallopian tube',
#      'fallopian tube, right',
#      'fallopian tube, nos',
#      'right fallopian tube'],
#     'all_score': [1.0000007152557373,
#      0.9768484830856323,
#      0.8879475593566895,
#      0.8841596245765686,
#      0.8757270574569702]},
#    {'begin': 307,
#     'end': 314,
#     'ner_chunk': 'appendix',
#     'ner_label': 'Site_Other_Body_Part',
#     'ner_confidence': '0.9971',
#     'concept_code': 'C12380',
#     'resolution': 'appendix',
#     'score': 0.9999999403953552,
#     'all_codes': ['C12380', 'C83470', 'C35403', 'C79275', 'C79276'],
#     'all_resolutions': ['appendix',
#      'appendix tip',
#      'appendix mass',
#      'body of data: appendices',
#      'appendices: regional information'],
#     'all_score': [0.9999999403953552,
#      0.8462085127830505,
#      0.839079737663269,
#      0.8134976625442505,
#      0.787269115447998]},
#    {'begin': 317,
#     'end': 323,
#     'ner_chunk': 'omentum',
#     'ner_label': 'Site_Other_Body_Part',
#     'ner_confidence': '0.9937',
#     'concept_code': 'C33209',
#     'resolution': 'omentum',
#     'score': 1.000000238418579,
#     'all_codes': ['C33209', 'C40340', 'C32697', 'C51787', 'C32981'],
#     'all_resolutions': ['omentum',
#      'omentum egist',
#      'greater omentum',
#      'resection of omentum',
#      'lesser omentum'],
#     'all_score': [1.000000238418579,
#      0.8821714520454407,
#      0.8740319609642029,
#      0.8656542301177979,
#      0.8563467264175415]},
#    {'begin': 350,
#     'end': 360,
#     'ner_chunk': 'lymph nodes',
#     'ner_label': 'Site_Lymph_Node',
#     'ner_confidence': '0.80105',
#     'concept_code': 'C32298',
#     'resolution': 'cervical lymph nodes',
#     'score': 0.8932355642318726,
#     'all_codes': ['C32298', 'C32298', 'C35812', 'C33769', 'C33034'],
#     'all_resolutions': ['cervical lymph nodes',
#      'cervical lymph node',
#      'lymph node cancer',
#      'thoracic lymph node',
#      'lymph node tissue'],
#     'all_score': [0.8932355642318726,
#      0.8725258708000183,
#      0.872384786605835,
#      0.8712409138679504,
#      0.8702684640884399]},
#    {'begin': 401,
#     'end': 405,
#     'ner_chunk': 'tumor',
#     'ner_label': 'Tumor_Finding',
#     'ner_confidence': '0.9851',
#     'concept_code': 'C12922',
#     'resolution': 'tumor cell',
#     'score': 0.8479248881340027,
#     'all_codes': ['C12922', 'C3677', 'C23852', 'C4063', 'C3261'],
#     'all_resolutions': ['tumor cell',
#      'tumor, benign',
#      'tumor cells',
#      'tumor of muscle',
#      'tumor, metastatic'],
#     'all_score': [0.8479248881340027,
#      0.8418221473693848,
#      0.841091513633728,
#      0.8219225406646729,
#      0.8128739595413208]},
#    {'begin': 411,
#     'end': 420,
#     'ner_chunk': 'stage IIIC',
#     'ner_label': 'Staging',
#     'ner_confidence': '0.99035',
#     'concept_code': 'C137673',
#     'resolution': 'stage iiic',
#     'score': 0.9999997019767761,
#     'all_codes': ['C137673', 'C112010', 'C136479', 'C95179', 'C139544'],
#     'all_resolutions': ['stage iiic',
#      'stage iii',
#      'stage iiia',
#      'stage iiic1',
#      'stage iiic breast cancer'],
#     'all_score': [0.9999997019767761,
#      0.909517765045166,
#      0.895308792591095,
#      0.8859850168228149,
#      0.8826867341995239]},
#    {'begin': 422,
#     'end': 430,
#     'ner_chunk': 'papillary',
#     'ner_label': 'Histological_Type',
#     'ner_confidence': '0.9979',
#     'concept_code': 'C14166',
#     'resolution': 'papillary',
#     'score': 0.9999997615814209,
#     'all_codes': ['C14166', 'C35911', 'C35911', 'C36031', 'C36181'],
#     'all_resolutions': ['papillary',
#      'papillary, nos',
#      'papillary pattern',
#      'papillary tumor',
#      'micropapillary'],
#     'all_score': [0.9999997615814209,
#      0.904362678527832,
#      0.8576534986495972,
#      0.8308395147323608,
#      0.8118432760238647]},
#    {'begin': 432,
#     'end': 437,
#     'ner_chunk': 'serous',
#     'ner_label': 'Histological_Type',
#     'ner_confidence': '0.9923',
#     'concept_code': 'C14168',
#     'resolution': 'serous',
#     'score': 0.9999999403953552,
#     'all_codes': ['C14168', 'C33539', 'C13169', 'C36120', 'C13169'],
#     'all_resolutions': ['serous',
#      'gland, salivary, serous',
#      'serous membrane',
#      'serous lesion',
#      'serosa'],
#     'all_score': [0.9999999403953552,
#      0.8053863048553467,
#      0.787696361541748,
#      0.7803736329078674,
#      0.779338538646698]},
#    {'begin': 439,
#     'end': 460,
#     'ner_chunk': 'ovarian adenocarcinoma',
#     'ner_label': 'Cancer_dx',
#     'ner_confidence': None,
#     'concept_code': 'C7700',
#     'resolution': 'ovarian adenocarcinoma',
#     'score': 1.000000238418579,
#     'all_codes': ['C7700', 'C7700', 'C7700', 'C4908', 'C4908'],
#     'all_resolutions': ['ovarian adenocarcinoma',
#      'adenocarcinoma of ovary',
#      'adenocarcinoma of the ovary',
#      'ovarian carcinoma',
#      'ovarian cancer'],
#     'all_score': [1.000000238418579,
#      0.9521949887275696,
#      0.9473367929458618,
#      0.8909646272659302,
#      0.8861076831817627]},
#    {'begin': 512,
#     'end': 515,
#     'ner_chunk': 'lung',
#     'ner_label': 'Site_Lung',
#     'ner_confidence': '0.9974',
#     'concept_code': 'C12468',
#     'resolution': 'lung',
#     'score': 1.000000238418579,
#     'all_codes': ['C12468', 'C12468', 'C12468', 'C13304', 'C33024'],
#     'all_resolutions': ['lung',
#      'lungs',
#      'respiratory system, lung',
#      'pulmonary',
#      'lung tissue'],
#     'all_score': [1.000000238418579,
#      0.9088419079780579,
#      0.8706839084625244,
#      0.8676108121871948,
#      0.8640806078910828]},
#    {'begin': 517,
#     'end': 526,
#     'ner_chunk': 'metastases',
#     'ner_label': 'Metastasis',
#     'ner_confidence': '0.9999',
#     'concept_code': 'C40557',
#     'resolution': 'metastases',
#     'score': 1.0000003576278687,
#     'all_codes': ['C40557', 'C7511', 'C3577', 'C7549', 'C36263'],
#     'all_resolutions': ['metastases',
#      'breast metastases',
#      'lung metastases',
#      'renal metastases',
#      'metastatic cancer'],
#     'all_score': [1.0000003576278687,
#      0.9107767939567566,
#      0.9001948237419128,
#      0.8925586342811584,
#      0.8820887804031372]}]]}

# %% [markdown]
# ### JSON Lines

# %%
transformer = model.transformer(
    instance_count=1,
    instance_type=batch_transform_inference_instance_type,
    accept="application/jsonlines",
    output_path=validation_output_jsonl_path
)
transformer.transform(validation_input_jsonl_path, content_type="application/jsonlines")
transformer.wait()

# %%
def retrieve_jsonlines_output_from_s3(validation_file_name):

    parsed_url = urlparse(transformer.output_path)
    file_key = f"{parsed_url.path[1:]}{validation_file_name}.out"
    response = s3_client.get_object(Bucket=s3_bucket, Key=file_key)

    data = response["Body"].read().decode("utf-8")
    print(data)

# %%
retrieve_jsonlines_output_from_s3(validation_jsonl_file_name)
# Out:
# {"predictions": [{"begin": 37, "end": 53, "ner_chunk": "debulking surgery", "ner_label": "Cancer_Surgery", "ner_confidence": "0.78400004", "concept_code": "C15749", "resolution": "debulking surgery", "score": 0.9999998211860657, "all_codes": ["C15749", "C160865", "C160866", "C15749", "C15749"], "all_resolutions": ["debulking surgery", "primary debulking surgery", "interval debulking surgery", "debulking procedure", "debulking"], "all_score": [0.9999998211860657, 0.9072895646095276, 0.8973025679588318, 0.8779721260070801, 0.851721465587616]}, {"begin": 56, "end": 77, "ner_chunk": "bilateral oophorectomy", "ner_label": "Cancer_Surgery", "ner_confidence": "0.83615005", "concept_code": "C51590", "resolution": "bilateral oophorectomy", "score": 0.9999991655349731, "all_codes": ["C51590", "C51765", "C51765", "C49133", "C51667"], "all_resolutions": ["bilateral oophorectomy", "bilateral salpingo-oophorectomy", "bilateral salpingectomy with oophorectomy", "bilateral prophylactic oophorectomy", "bilateral salpingectomy"], "all_score": [0.9999991655349731, 0.9659522771835327, 0.9521262049674988, 0.9364778399467468, 0.9134529829025269]}, {"begin": 84, "end": 94, "ner_chunk": "omentectomy", "ner_label": "Cancer_Surgery", "ner_confidence": "0.988", "concept_code": "C51787", "resolution": "omentectomy", "score": 1.0, "all_codes": ["C51787", "C51788", "C51787", "C51788", "C33209"], "all_resolutions": ["omentectomy", "partial omentectomy", "resection of omentum", "partial resection of omentum", "omentum"], "all_score": [1.0, 0.8603771924972534, 0.8370007276535034, 0.8057854771614075, 0.7462188005447388]}, {"begin": 97, "end": 114, "ner_chunk": "total hysterectomy", "ner_label": "Cancer_Surgery", "ner_confidence": "0.95624995", "concept_code": "C15701", "resolution": "total hysterectomy", "score": 1.0, "all_codes": ["C15701", "C51695", "C15701", "C15701", "C51660"], "all_resolutions": ["total hysterectomy", "total abdominal hysterectomy", "complete hysterectomy", "full hysterectomy", "abdominal hysterectomy"], "all_score": [1.0, 0.970645546913147, 0.8939006328582764, 0.8890131115913391, 0.8696088790893555]}, {"begin": 121, "end": 157, "ner_chunk": "radical pelvic lymph nodes dissection", "ner_label": "Cancer_Surgery", "ner_confidence": "0.80143994", "concept_code": "C51896", "resolution": "pelvic lymph node dissection", "score": 0.9299925565719604, "all_codes": ["C51896", "C48936", "C166163", "C51896", "C51896"], "all_resolutions": ["pelvic lymph node dissection", "radical lymph node dissection", "bilateral pelvic lymph node dissection", "pelvic lymphadenectomy", "excision pelvic lymph nodes"], "all_score": [0.9299925565719604, 0.9063621163368225, 0.8415289521217346, 0.8406316041946411, 0.8394026160240173]}, {"begin": 166, "end": 182, "ner_chunk": "ovarian carcinoma", "ner_label": "Cancer_dx", "ner_confidence": null, "concept_code": "C4908", "resolution": "ovarian carcinoma", "score": 1.0, "all_codes": ["C4908", "C4908", "C4908", "C4908", "C4984"], "all_resolutions": ["ovarian carcinoma", "carcinoma of ovary", "ovarian cancer", "carcinoma of the ovary", "ovarian tumor"], "all_score": [1.0, 0.9383364915847778, 0.9361096620559692, 0.9348263144493103, 0.9038485288619995]}, {"begin": 185, "end": 207, "ner_chunk": "mucinous-type carcinoma", "ner_label": "Cancer_dx", "ner_confidence": null, "concept_code": "C40203", "resolution": "cervical mucinous adenocarcinoma, intestinal-type", "score": 0.8483723998069763, "all_codes": ["C40203", "C7966", "C9131", "C180537", "C9131"], "all_resolutions": ["cervical mucinous adenocarcinoma, intestinal-type", "mucinous colon adenocarcinoma", "mucinous breast carcinoma", "endometrial mucinous adenocarcinoma, gastric-type", "mucinous carcinoma of breast"], "all_score": [0.8483723998069763, 0.8411674499511719, 0.8380377292633057, 0.8362902402877808, 0.8351631760597229]}, {"begin": 210, "end": 217, "ner_chunk": "stage Ic", "ner_label": "Staging", "ner_confidence": "0.9956", "concept_code": "C141199", "resolution": "stag ...
# {"predictions": [{"begin": 16, "end": 34, "ner_chunk": "computed tomography", "ner_label": "Imaging_Test", "ner_confidence": "0.93485", "concept_code": "C17204", "resolution": "computed tomography", "score": 1.0000003576278687, "all_codes": ["C17204", "C159883", "C17204", "C17204", "C45844"], "all_resolutions": ["computed tomography", "urography computed tomography", "computed axial tomography", "ct scan", "ct scanner"], "all_score": [1.0000003576278687, 0.8956605195999146, 0.8955866098403931, 0.8854690790176392, 0.8733323216438293]}, {"begin": 37, "end": 38, "ner_chunk": "CT", "ner_label": "Imaging_Test", "ner_confidence": "0.9724", "concept_code": "C104954", "resolution": "ct", "score": 1.0000003576278687, "all_codes": ["C104954", "C104957", "C45844", "C161328", "C123577"], "all_resolutions": ["ct", "ct a", "ct scanner", "ct number", "cr-ct"], "all_score": [1.0000003576278687, 0.8701925277709961, 0.8519605398178101, 0.8456451892852783, 0.8418126702308655]}, {"begin": 53, "end": 59, "ner_chunk": "abdomen", "ner_label": "Site_Other_Body_Part", "ner_confidence": "0.9363", "concept_code": "C12664", "resolution": "abdomen", "score": 1.0000008344650269, "all_codes": ["C12664", "C12391", "C12664", "C12664", "C13025"], "all_resolutions": ["abdomen", "stomach", "abdomen, nos", "abdomen, total", "stomach part"], "all_score": [1.0000008344650269, 0.8771505951881409, 0.8585428595542908, 0.8531992435455322, 0.8376491665840149]}, {"begin": 65, "end": 70, "ner_chunk": "pelvis", "ner_label": "Site_Other_Body_Part", "ner_confidence": "0.5375", "concept_code": "C33287", "resolution": "bone, pelvis", "score": 0.8741136789321899, "all_codes": ["C33287", "C12887", "C105733", "C33287", "C23817"], "all_resolutions": ["bone, pelvis", "renal pelvis", "whole-pelvis", "pelvic bone", "kidney/renal pelvis"], "all_score": [0.8741136789321899, 0.8667565584182739, 0.8562899827957153, 0.8388118743896484, 0.8083593249320984]}, {"begin": 96, "end": 102, "ner_chunk": "ovarian", "ner_label": "Site_Other_Body_Part", "ner_confidence": "0.7866", "concept_code": "C12404", "resolution": "ovary", "score": 0.8572745323181152, "all_codes": ["C12404", "C12404", "C33243", "C3882", "C33244"], "all_resolutions": ["ovary", "ovaries", "ovarian cortex", "ovarian mass", "ovarian follicle"], "all_score": [0.8572745323181152, 0.8545776605606079, 0.8522234559059143, 0.8421778082847595, 0.8389604091644287]}, {"begin": 104, "end": 107, "ner_chunk": "mass", "ner_label": "Tumor_Finding", "ner_confidence": "0.9573", "concept_code": "C126027", "resolution": "mass", "score": 1.0000007152557373, "all_codes": ["C126027", "C90335", "C112025", "C42579", "C45978"], "all_resolutions": ["mass", "mass description", "mass measurement", "unit of mass", "fungating mass"], "all_score": [1.0000007152557373, 0.840757429599762, 0.7978991866111755, 0.7876405119895935, 0.7833571434020996]}, {"begin": 112, "end": 120, "ner_chunk": "Pap smear", "ner_label": "Pathology_Test", "ner_confidence": "0.96725", "concept_code": "C62670", "resolution": "cervical pap test", "score": 0.8581546545028687, "all_codes": ["C62670", "C65126", "C79903", "C105383", "C128984"], "all_resolutions": ["cervical pap test", "smear", "blood smear", "pap", "pap stain"], "all_score": [0.8581546545028687, 0.856905996799469, 0.8153881430625916, 0.8133909702301025, 0.8035245537757874]}, {"begin": 165, "end": 188, "ner_chunk": "atypical glandular cells", "ner_label": "Pathology_Result", "ner_confidence": "0.7270667", "concept_code": "C36912", "resolution": "atypical glandular cell", "score": 0.992756724357605, "all_codes": ["C36912", "C36912", "C8435", "C8435", "C8341"], "all_resolutions": ["atypical glandular cell", "atypical glandular cell, not otherwise specified", "atypical glandular cells of uncertain significance", "atypical glandular cells of undetermined significance", "glandular cell atypia"], "all_score": [0.992756724357605, 0.938469648361206, 0.9353052973747253, 0.9344968199729919, 0.9308472871780396]}, {"begin": 205, "end": 21 ...

# %%
model.delete_model()
# Out:
# INFO:sagemaker:Deleting model with name: ncit-vdb-resolver-2-2025-08-18-12-52-01-495

# %% [markdown]
# ### Unsubscribe to the listing (optional)

# %% [markdown]
# If you would like to unsubscribe to the model package, follow these steps. Before you cancel the subscription, ensure that you do not have any [deployable model](https://console.aws.amazon.com/sagemaker/home#/models) created from the model package or using the algorithm. Note - You can find this information by looking at the container name associated with the model.
#
# **Steps to unsubscribe to product from AWS Marketplace**:
# 1. Navigate to __Machine Learning__ tab on [__Your Software subscriptions page__](https://aws.amazon.com/marketplace/ai/library?productType=ml&ref_=mlmp_gitdemo_indust)
# 2. Locate the listing that you want to cancel the subscription for, and then choose __Cancel Subscription__  to cancel the subscription.
