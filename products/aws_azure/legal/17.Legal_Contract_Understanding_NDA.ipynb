# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)

# %% [markdown]
# **setup**

# %%
from johnsnowlabs import *

import json
import os

import numpy as np
import pandas as pd

spark = start_spark()

# %% [markdown]
# # 🔎 **Non-disclouse Agreement Contract Understanding**
#
#
# ✍Explanation:
#
#  A Non-Disclosure Agreement (NDA) is a legal contract designed to protect confidential information shared between parties involved in a business or professional relationship. The purpose of an NDA is to establish a legal obligation that restricts the receiving party from disclosing or using the confidential information for any purpose other than what is defined in the agreement.
#
#  The `legclf_nda_agreements` model focuses specifically on analyzing Non-Disclosure Agreements (NDAs). NDAs are legal contracts designed to protect confidential information shared between parties. A specific Legal NLP model for NDAs is trained on a potentially large corpus of NDA documents to understand the specific clauses, terms and language commonly used in these agreements.
#
# - The `legclf_nda_agreements` model is a Bert Sentence Embeddings Document Classifier used to classify if the document belongs to the class nda or not (Binary Classification).

# %% [markdown]
# ## Get sample text

# %%
# !wget https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/legal-nlp/data/nda_2.txt

# %%
import re
with open('nda_2.txt', 'r') as f:
  text = f.read()
  print(text)
# Out:
# This Non-Disclosure Agreement (“Agreement”) is made and entered into on this 2nd day of January, 2023, by and between PlusUltra Inc., a Delaware corporation having its principal offices at 111 Way White, Austin, NH 229484 (“PlusUltra”) and John Snow Labs Inc., a Delaware corporation, located at , , ,  (the “Company”).
#
# For the purpose of evaluating a possible relationship between the parties (the "Purpose"), the parties may disclose to each other in oral and written form or in other medium, certain Confidential Information, as defined below, relating to their respective pipelines, products and businesses.
#
# As a precondition to any such disclosure, each party hereby agrees to keep all such Confidential Information of the other party in strict confidence under the terms set out in this Agreement.
# For purposes of this Agreement, a party receiving Confidential Information hereunder shall be referred to as the “Receiving Party” and a party disclosing Confidential Information hereunder shall be referred to as the “Disclosing Party” and each of them shall be individually referred to as a “Party” and collectively, the “Parties.
#
# Definition of Confidential Information.
#
# For the purpose of this Agreement, “Confidential Information”  shall mean any proprietary information relating to a Disclosing Party, its business or assets or that of any of its customers, Affiliates (defined below), subcontractors or other persons that is not generally known to the public, whether of a technical, business or other nature, including but not limited to inventions, know-how, trade-secrets, methods, techniques, processes, designs, drawings, diagrams, formulae and analysis, clinical data, and any business information, including but not limited to price lists, customers lists, costs analyses, reports, surveys and market information and data), whether communicated in tangible or intangible form.
#
# Any analyses, compilations, comparisons studies or other work prepared by or for the Receiving Party containing any Confidential Information of the Disclosing Party (“Derivative Materials”), shall be also regarded as Confidential Information of the Disclosing Party hereunder.
#
# For purposes of this Agreement, “Affiliate” of a Party shall mean any person, corporation or business entity controlling, controlled by or under common control with such Party.
#
# Exclusions from Definition.
# The term Confidential Information shall not include any information that the Receiving Party shall evidence in writing that was either:
# - already known to it prior to the disclosure thereto by the Disclosing Party;
# - or before being divulged by the Receiving Party to any third party, such information:
# (i) was in the public domain through no wrongful act of the Receiving Party;
# (ii) was rightfully received by the Receiving Party from a third party without restriction on disclosure and without a breach of any confidentiality obligation running directly or indirectly to the Disclosing Party;
# or (iii) was independently developed by the Receiving Party without the use, directly or indirectly, of any of the Disclosing Party’s Confidential Information.
#
# Restrictions on Disclosure of Confidential Information.
# The Receiving Party shall neither:
# - (i) use any Confidential Information other than as necessary specifically for the Purpose, nor
# - (ii) disclose any Confidential Information, in whole or in part, to any person other than its directors, officers, employees, agents or consultants (or to directors, officers, employees, agents or consultants of one of its Affiliates), who have a bona fide need to know such Confidential Information for the Purpose, and who are under a duty of confidentiality to the Receiving Party on substantially the same basis as required of Receiving Party under this Agreement (each a “Representative”).
#
# The Receiving Party shall ensure that its Representatives will maintain the confidentiality as required by the terms of this Agreement of any Disclosing Party’s Confidential Information received by such Representatives and Receiving Party shall be absolutely responsible for any breach of such obligations by its Representatives.
#
# Standard of Protection.
#
# For the purpose hereof, the Receiving Party its Representatives shall use efforts commensurate with those that it employs for the protection of its own corresponding sensitive information, which shall in any event be no lesser a standard than the type of efforts that would be taken by a careful hi-tech business for the protection of its commercial and technical secrets.
#
# Ownership of Information.
#
# No license or right under any patent, copyright, trademark, trade-name, mask work protection right or any other intellectual property right, is either granted or implied to the Receiving Party and its Representatives by the conveying thereto of any Confidential Information by the Disclosing Party.
#
# All Confidential Information (including tangible copies, reproductions, reductions and computerized, magnetic or electronic versions thereof), shall remain at all times the property of the Disclosing Party and/or its Affiliate (as applicable), shall not be repurposed or reproduced in any way, and shall be returned to the Disclosing Party or destroyed (with written confirmation to the Disclosing Party) at the Disclosing Party's first request which may at any time be made.
#
# Any portion of Derivative Materials, whether created by the Receiving Party or its Representatives, shall become the Disclosing Party's (or its Affiliate’s, as applicable) property and shall be also returned to the Disclosing Party or destroyed (with confirmation to the Disclosing Party) promptly upon the Disclosing Party's request.
#
# Without limiting the foregoing, the Receiving Party shall not assert directly or indirectly any right, including any right of set-off or lien, with respect to Disclosing Party’s Confidential Information.
#
# Notwithstanding the foregoing, the Receiving Party and its Representatives may retain:
# - (i) one (1) copy of any of Disclosing Party’s Confidential Information as required under any recordkeeping or retention requirements required of Receiving Party or its Representatives by law, rule or regulation applicable to Receiving Party or its Representatives and
# - (ii) any computer records or files created pursuant to automatic archiving back-up procedures and the like, which cannot reasonably be deleted;
# in each case subject to the confidentiality provisions of this Agreement, which shall survive indefinitely following any termination or expiration of this Agreement.
#
# Compliance with Legal Requirements.
# If the Receiving Party or any of its Representatives shall be legally required (by formal questioning or, in the written opinion of its legal counsel, by applicable laws) to disclose any of Disclosing Party’s Confidential Information, the Receiving Party shall immediately notify the Disclosing Party of such request or requirement prior to disclosure so that the Disclosing Party may seek an appropriate protective order with the reasonable assistance of the Receiving Party, and/or waive compliance with the terms of this undertaking, at the Disclosing Party's absolute discretion, and at Disclosing Party’s sole expense.
#
# If such order or waiver is not timely obtained, only such portion of the Confidential Information as specifically required shall be disclosed, and Receiving Party will use its commercially reasonable efforts to obtain confidential treatment of the Confidential Information to be disclosed.
# Notwithstanding the foregoing, Receiving Party and its Representatives shall not be required to provide notice or seek consent to disclose any information in connection with any disclosure to any regulatory or governmental entity having jurisdiction over the Receiving Party or Representatives (as applicable), except with respect to any investigation or audit specifically targeting the Disclosing Party or the Purpose to the extent legally permissible.
#
# Term;
# Survival.
# The term of this Agreement shall expire on the earlier of
# (a) two years from the date of this Agreement or
# (b) the date on which the Parties (or their Affiliates) enter into a transaction document relating to the Purpose containing confidentiality provisions with respect to the potential transaction or
# (c) either Party gives written notice of termination of this Agreement to the other Party.
# Notwithstanding any termination of this Agreement, the confidentiality obligations of the Receiving Party shall survive any termination or expiration of this Agreement for five (5) years from the date of this Agreement, except to the extent provided for elsewhere herein.
#
# Remedies.
# Receiving Party understands that any violation of this Agreement may cause Disclosing Party immediate and irreparable harm which monetary damages may not adequately remedy.
# Therefore, upon any actual or impending violation of this Agreement, Disclosing Party may seek a restraining order or other injunction, without bond, restraining or enjoining such violation by Receiving Party, its Representatives or any entity or person acting in concert with Receiving Party.
# Receiving Party understands that such relief is additional to and does not limit the availability to Disclosing Party of any other remedy.
#
# Scope of Relations.
# Neither this Agreement nor the disclosure by the Disclosing Party or its Affiliates of Confidential Information to the Receiving Party or its receipt thereof shall constitute or imply any offer, promise or intention of either Party to enter into any agreement, joint venture or other business engagement, nor constitute any representation, warranty, assurance or guarantee by the Disclosing Party or its Affiliates, with respect to the accuracy, originality, or efficiency of the Confidential Information.
#
# No Waiver.
# No failure or delay by any Party in exercising any right, power or privilege hereunder shall operate as a waiver thereof, nor shall any single or partial exercise thereof preclude any other or further exercise thereof or the exercise of any other right, power or privilege hereunder.
#
# Applicable Law and Jurisdiction.
# This Agreement shall be governed by, construed and enforced in accordance with the laws of New York State.
# The Parties hereby irrevocably submit to the jurisdiction of the competent courts located in New York County of New York State and hereby waive any objection regarding jurisdiction or forum.
# This Agreement is only for the benefit of the Parties.
# The Parties agree that unless and until definitive documentation with respect to a transaction has been signed and delivered by the Parties or one of their respective Affiliates, neither Party or any of their respective Affiliates shall have any legal obligation of any kind whatsoever (other than confidentiality obligations under this Agreement) with respect to the Purpose by virtue of this Agreement or any other written or oral communication with respect to the Purpose or any other potential transaction.
#
# Company hereby acknowledges and confirms that it is aware and that it will advise its Representatives that the U.S. federal securities laws prohibit any person who is in possession of any material non-public information about a company that is subject to the reporting requirements of the U.S.
#
# Securities Exchange Act of 1934, as amended (the “Exchange Act”), from purchasing, selling or trading securities of such issuer-company and that PlusUltra’s parent company, PlusUltra Limited, is such a reporting company.
#
# Company acknowledges that the provisions of U.S.  promulgated under the Exchange Act requires the public announcement of previously non-public material information if that information is disclosed to anyone who has not agreed with an Exchange Act reporting issuer to maintain the confidentiality of that information.
#
# Company agrees not to take, directly or indirectly, any action that would require PlusUltra Limited to make a public announcement pursuant to the requirements of Regulation FD
#
# IN WITNESS WHEREOF, the Parties have executed and delivered this Non-Disclosure Agreement, as of the date first written above.
#
# PlusUltra 						John Snow Labs Inc.
# By:	____________________			By:	___________________
# Name:  					Name:
# Title:						Title: Legal Counsel

# %% [markdown]
# ## Document classification

# %%
document_assembler = nlp.DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")
  
embeddings = nlp.BertSentenceEmbeddings.pretrained("sent_bert_base_cased", "en")\
    .setInputCols("document")\
    .setOutputCol("sentence_embeddings")
    
doc_classifier = legal.ClassifierDLModel.pretrained("legclf_nda_agreements", "en", "legal/models")\
    .setInputCols(["sentence_embeddings"])\
    .setOutputCol("category")
    
nlpPipeline = nlp.Pipeline(stages=[
    document_assembler, 
    embeddings,
    doc_classifier])

df = spark.createDataFrame([[text]]).toDF("text")

model = nlpPipeline.fit(df)
result = model.transform(df)
# Out:
# sent_bert_base_cased download started this may take some time.
# Approximate size to download 389.1 MB
# [OK!]
# legclf_nda_agreements download started this may take some time.
# [OK!]

# %%
result.select("category.result").show(truncate=False)
# Out:
# +------+
# |result|
# +------+
# |[nda] |
# +------+

# %% [markdown]
# # 🔎 **Multilabel Classification of NDA Clauses (paragraph, medium)**
#
# ✍Explanation:
#
# This models is a version of `legmulticlf_mnda_sections_other` (sentence, medium) but expecting a bigger-than-sentence context, ideally between 2 and 4-5 sentences, or a small paragraph, to provide with more context.
#
# It should be run on sentences of the NDA clauses, and will retrieve labels for each of them. The possible clause types detected my this model in NDA / MNDA aggrements are:
#
# - Parties to the Agreement - Names of the Parties Clause
# - Identification of What Information Is Confidential - Definition of Confidential Information Clause
# - Use of Confidential Information: Permitted Use Clause and Obligations of the Recipient
# - Time Frame of the Agreement - Termination Clause
# - Return of Confidential Information Clause
# - Remedies for Breaches of Agreement - Remedies Clause
# - Non-Solicitation Clause
# - Dispute Resolution Clause
# - Exceptions Clause
# - Non-competition clause
# - Other: Nothing of the above (synonym to [])
#
# 📚 Predicted Entities
# `APPLIC_LAW`, `ASSIGNMENT`, `DEF_OF_CONF_INFO`,`DISPUTE_RESOL`, `EXCEPTIONS`, `NAMES_OF_PARTIES`, `NON_COMP`, `NON_SOLIC`, `PREAMBLE`, `REMEDIES`, `REQ_DISCL`, `RETURN_OF_CONF_INFO`, `TERMINATION`, `USE_OF_CONF_INFO`, `OTHER`

# %%
document_assembler = nlp.DocumentAssembler() \
    .setInputCol("text") \
    .setOutputCol("document")

text_splitter = legal.TextSplitter() \
    .setInputCols(["document"]) \
    .setOutputCol("sentences") \
    .setExplodeSentences(True)

embeddings = nlp.UniversalSentenceEncoder.pretrained()\
    .setInputCols("document")\
    .setOutputCol("sentence_embeddings")

paragraph_classifier = nlp.MultiClassifierDLModel.pretrained("legmulticlf_mnda_sections_paragraph_other", "en", "legal/models")\
    .setInputCols(["sentence_embeddings"])\
    .setOutputCol("class")


sentence_pipeline = nlp.Pipeline(stages=[document_assembler, 
                                         text_splitter, 
                                         embeddings, 
                                         paragraph_classifier])

prediction_pipeline = nlp.Pipeline(stages=[document_assembler, 
                                           embeddings, 
                                           paragraph_classifier])

df = spark.createDataFrame([[text]]).toDF("text")

sentence_model = sentence_pipeline.fit(df)
prediction_model = prediction_pipeline.fit(df)

sentence_lp = nlp.LightPipeline(sentence_model)
prediction_lp = nlp.LightPipeline(prediction_model)

# %% [markdown]
# ## In order to classify sections, I split by paragraph (\n\n).
# Another way is splitting by sentences and accumulation up to certain number of them (3 ideally).

# %%
import pandas as pd

# Create an empty dataframe to store the texts
class_texts_df = []

paragraphs = text.split("\n\n")

for i, s in enumerate(paragraphs):
    annotation = prediction_lp.annotate(s)
    predicted_class = annotation['class']
    class_texts_df.append((s, predicted_class))
    
# Append the text to the dataframe for the predicted class
class_texts_df = pd.DataFrame(class_texts_df, columns=['text', 'class'])

# %%
class_texts_df["text"][0]
# Out:
# 'This Non-Disclosure Agreement (“Agreement”) is made and entered into on this 2nd day of January, 2023, by and between PlusUltra Inc., a Delaware corporation having its principal offices at 111 Way White, Austin, NH 229484 (“PlusUltra”) and John Snow Labs Inc., a Delaware corporation, located at , , ,  (the “Company”).'

# %%
class_texts_df = class_texts_df.explode('class').reset_index(drop=True).fillna("OTHER")

# %%
class_texts_df
# Out:
#                                                  text                class
# 0   This Non-Disclosure Agreement (“Agreement”) is...     NAMES_OF_PARTIES
# 1   For the purpose of evaluating a possible relat...     DEF_OF_CONF_INFO
# 2   For the purpose of evaluating a possible relat...             PREAMBLE
# 3   As a precondition to any such disclosure, each...             PREAMBLE
# 4             Definition of Confidential Information.     DEF_OF_CONF_INFO
# 5   For the purpose of this Agreement, “Confidenti...     DEF_OF_CONF_INFO
# 6   Any analyses, compilations, comparisons studie...     DEF_OF_CONF_INFO
# 7   For purposes of this Agreement, “Affiliate” of...                OTHER
# 8   Exclusions from Definition.\nThe term Confiden...           EXCEPTIONS
# 9   Restrictions on Disclosure of Confidential Inf...             PREAMBLE
# 10  The Receiving Party shall ensure that its Repr...     USE_OF_CONF_INFO
# 11                            Standard of Protection.                OTHER
# 12  For the purpose hereof, the Receiving Party it...     USE_OF_CONF_INFO
# 13  For the purpose hereof, the Receiving Party it...            REQ_DISCL
# 14                          Ownership of Information.                OTHER
# 15  No license or right under any patent, copyrigh...                OTHER
# 16  All Confidential Information (including tangib...  RETURN_OF_CONF_INFO
# 17  Any portion of Derivative Materials, whether c...  RETURN_OF_CONF_INFO
# 18  Without limiting the foregoing, the Receiving ...     USE_OF_CONF_INFO
# 19  Notwithstanding the foregoing, the Receiving P...  RETURN_OF_CONF_INFO
# 20  Compliance with Legal Requirements.\nIf the Re...            REQ_DISCL
# 21  If such order or waiver is not timely obtained...            REQ_DISCL
# 22  Term;\nSurvival.\nThe term of this Agreement s...          TERMINATION
# 23  Remedies.\nReceiving Party understands that an...                OTHER
# 24  Scope of Relations.\nNeither this Agreement no...     USE_OF_CONF_INFO
# 25  No Waiver.\nNo failure or delay by any Party i...                OTHER
# 26  Applicable Law and Jurisdiction.\nThis Agreeme...           APPLIC_LAW
# 27  Applicable Law and Jurisdiction.\nThis Agreeme...            REQ_DISCL
# 28  Company hereby acknowledges and confirms that ...                OTHER
# 29  Securities Exchange Act of 1934, as amended (t...                OTHER
# 30  Company acknowledges that the provisions of U....     DEF_OF_CONF_INFO
# 31  Company acknowledges that the provisions of U....           EXCEPTIONS
# 32  Company agrees not to take, directly or indire...            REQ_DISCL
# 33  IN WITNESS WHEREOF, the Parties have executed ...     USE_OF_CONF_INFO
# 34  PlusUltra \t\t\t\t\t\tJohn Snow Labs Inc. \nBy...                OTHER

# %%
# Filter out rows with empty square brackets
class_texts_df = class_texts_df[class_texts_df['class']!='OTHER']

# Print the filtered DataFrame
class_texts_df
# Out:
#                                                  text                class
# 0   This Non-Disclosure Agreement (“Agreement”) is...     NAMES_OF_PARTIES
# 1   For the purpose of evaluating a possible relat...     DEF_OF_CONF_INFO
# 2   For the purpose of evaluating a possible relat...             PREAMBLE
# 3   As a precondition to any such disclosure, each...             PREAMBLE
# 4             Definition of Confidential Information.     DEF_OF_CONF_INFO
# 5   For the purpose of this Agreement, “Confidenti...     DEF_OF_CONF_INFO
# 6   Any analyses, compilations, comparisons studie...     DEF_OF_CONF_INFO
# 8   Exclusions from Definition.\nThe term Confiden...           EXCEPTIONS
# 9   Restrictions on Disclosure of Confidential Inf...             PREAMBLE
# 10  The Receiving Party shall ensure that its Repr...     USE_OF_CONF_INFO
# 12  For the purpose hereof, the Receiving Party it...     USE_OF_CONF_INFO
# 13  For the purpose hereof, the Receiving Party it...            REQ_DISCL
# 16  All Confidential Information (including tangib...  RETURN_OF_CONF_INFO
# 17  Any portion of Derivative Materials, whether c...  RETURN_OF_CONF_INFO
# 18  Without limiting the foregoing, the Receiving ...     USE_OF_CONF_INFO
# 19  Notwithstanding the foregoing, the Receiving P...  RETURN_OF_CONF_INFO
# 20  Compliance with Legal Requirements.\nIf the Re...            REQ_DISCL
# 21  If such order or waiver is not timely obtained...            REQ_DISCL
# 22  Term;\nSurvival.\nThe term of this Agreement s...          TERMINATION
# 24  Scope of Relations.\nNeither this Agreement no...     USE_OF_CONF_INFO
# 26  Applicable Law and Jurisdiction.\nThis Agreeme...           APPLIC_LAW
# 27  Applicable Law and Jurisdiction.\nThis Agreeme...            REQ_DISCL
# 30  Company acknowledges that the provisions of U....     DEF_OF_CONF_INFO
# 31  Company acknowledges that the provisions of U....           EXCEPTIONS
# 32  Company agrees not to take, directly or indire...            REQ_DISCL
# 33  IN WITNESS WHEREOF, the Parties have executed ...     USE_OF_CONF_INFO

# %% [markdown]
# ## 📌 **`NAMES_OF_PARTIES` CLAUSE-SPECIFIC NER**

# %% [markdown]
# ### Creating a dataframe with the texts of the `NAMES_OF_PARTIES` class

# %%
names_of_the_parties_df = class_texts_df[class_texts_df['class']=='NAMES_OF_PARTIES']
names_of_the_parties_df
# Out:
#                                                 text             class
# 0  This Non-Disclosure Agreement (“Agreement”) is...  NAMES_OF_PARTIES

# %%
names_of_the_parties_df["text"][0]
# Out:
# 'This Non-Disclosure Agreement (“Agreement”) is made and entered into on this 2nd day of January, 2023, by and between PlusUltra Inc., a Delaware corporation having its principal offices at 111 Way White, Austin, NH 229484 (“PlusUltra”) and John Snow Labs Inc., a Delaware corporation, located at , , ,  (the “Company”).'

# %% [markdown]
# ### **We use a pretrained pipeline, instead of putting all the components manually**

# %%
legal_pipeline = nlp.PretrainedPipeline("legpipe_ner_contract_doc_parties_alias_former", "en", "legal/models")
# Out:
# legpipe_ner_contract_doc_parties_alias_former download started this may take some time.
# Approx size to download 891.1 MB
# [OK!]

# %%
result = legal_pipeline.fullAnnotate(names_of_the_parties_df.loc[0, 'text'])

# %% [markdown]
# ### 🧮 **NER Visualizer**
# For saving the visualization result as html, provide save_path parameter in the display function.

# %%
from sparknlp_display import NerVisualizer

visualiser = NerVisualizer()
visualiser.display(result = result[0],label_col = 'merged_ner_chunks', document_col = 'document')
print("\n\n")
# Out:
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">This </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #B91E52"><span class="spark-nlp-display-entity-name">Non-Disclosure Agreement </span><span class="spark-nlp-display-entity-type">DOC</span></span><span class="spark-nlp-display-others" style="background-color: white"> (“Agreement”) is made and entered into on this </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #4B20A9"><span class="spark-nlp-display-entity-name">2nd day of January, 2023 </span><span class="spark-nlp-display-entity-type">EFFDATE</span></span><span class="spark-nlp-display-others" style="background-color: white">, by and between </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #4373B2"><span class="spark-nlp-display-entity-name">PlusUltra Inc </span><span class="spark-nlp-display-entity-type">PARTY</span></span><span class="spark-nlp-display-others" style="background-color: white">., a Delaware corporation having its principal offices at </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #01312E"><span class="spark-nlp-display-entity-name">111 Way White, Austin </span><span class="spark-nlp-display-entity-type">ADDRESS</span></span><span class="spark-nlp-display-others" style="background-color: white">, NH 229484 (“PlusUltra”) and </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #4373B2"><span class="spark-nlp-display-entity-name">John Snow Labs Inc </span><span class="spark-nlp-display-entity-type">PARTY</span></span><span class="spark-nlp-display-others" style="background-color: white">., a Delaware corporation, located at , , ,  (the “Company”).</span></div>

# %% [markdown]
# ## 📌 **`DEF_OF_CONF_INFO` CLAUSE-SPECIFIC NER**

# %%
def_of_conf_info_df = class_texts_df[class_texts_df['class']=='DEF_OF_CONF_INFO']
def_of_conf_info_df
# Out:
#                                                  text             class
# 1   For the purpose of evaluating a possible relat...  DEF_OF_CONF_INFO
# 4             Definition of Confidential Information.  DEF_OF_CONF_INFO
# 5   For the purpose of this Agreement, “Confidenti...  DEF_OF_CONF_INFO
# 6   Any analyses, compilations, comparisons studie...  DEF_OF_CONF_INFO
# 30  Company acknowledges that the provisions of U....  DEF_OF_CONF_INFO

# %%
def_of_conf_info_df["text"][5]
# Out:
# 'For the purpose of this Agreement, “Confidential Information”  shall mean any proprietary information relating to a Disclosing Party, its business or assets or that of any of its customers, Affiliates (defined below), subcontractors or other persons that is not generally known to the public, whether of a technical, business or other nature, including but not limited to inventions, know-how, trade-secrets, methods, techniques, processes, designs, drawings, diagrams, formulae and analysis, clinical data, and any business information, including but not limited to price lists, customers lists, costs analyses, reports, surveys and market information and data), whether communicated in tangible or intangible form.'

# %%
# nda_conf_info
document_assembler = nlp.DocumentAssembler()\
        .setInputCol("text")\
        .setOutputCol("document")

text_splitter = legal.TextSplitter() \
    .setInputCols(["document"]) \
    .setOutputCol("sentence")

tokenizer = nlp.Tokenizer()\
        .setInputCols(["sentence"])\
        .setOutputCol("token")

ner_model_conf = legal.NerModel.pretrained("legner_nda_def_conf_info", "en", "legal/models")\
        .setInputCols(["sentence", "token", "embeddings"])\
        .setOutputCol("ner_conf")

ner_converter_conf = nlp.NerConverter()\
        .setInputCols(["sentence", "token", "ner_conf"])\
        .setOutputCol("ner_chunk_conf")

nlpPipeline = nlp.Pipeline(stages=[
        document_assembler,
        text_splitter,
        tokenizer,
        embeddings,
        ner_model_conf,
        ner_converter_conf, 
        ])

def_of_conf_info_sdf = spark.createDataFrame(def_of_conf_info_df)

model = nlpPipeline.fit(def_of_conf_info_sdf)
result = model.transform(def_of_conf_info_sdf)


from pyspark.sql import functions as F

result_df = result.select(F.explode('ner_chunk_conf').alias("cols")) \
                  .select(F.expr("cols.begin").alias("begin"),
                          F.expr("cols.end").alias("end"),
                          F.expr("cols.result").alias("chunk"),
                          F.expr("cols.metadata.entity").alias("entity"))

result_df.show(50, truncate=100)
# Out:
# legner_nda_def_conf_info download started this may take some time.
# [OK!]
# +-----+---+-------------------+--------------+
# |begin|end|              chunk|        entity|
# +-----+---+-------------------+--------------+
# |  133|136|               oral|CONF_INFO_FORM|
# |  142|148|            written|CONF_INFO_FORM|
# |   27| 37|        Information|CONF_INFO_TYPE|
# |  372|381|         inventions|CONF_INFO_TYPE|
# |  384|391|           know-how|CONF_INFO_TYPE|
# |  394|406|      trade-secrets|CONF_INFO_TYPE|
# |  409|415|            methods|CONF_INFO_TYPE|
# |  418|427|         techniques|CONF_INFO_TYPE|
# |  430|438|          processes|CONF_INFO_TYPE|
# |  441|447|            designs|CONF_INFO_TYPE|
# |  450|457|           drawings|CONF_INFO_TYPE|
# |  460|467|           diagrams|CONF_INFO_TYPE|
# |  470|477|           formulae|CONF_INFO_TYPE|
# |  483|490|           analysis|CONF_INFO_TYPE|
# |  493|505|      clinical data|CONF_INFO_TYPE|
# |  567|577|        price lists|CONF_INFO_TYPE|
# |  580|594|    customers lists|CONF_INFO_TYPE|
# |  597|610|     costs analyses|CONF_INFO_TYPE|
# |  613|619|            reports|CONF_INFO_TYPE|
# |  622|628|            surveys|CONF_INFO_TYPE|
# |  657|660|               data|CONF_INFO_TYPE|
# |    4| 11|           analyses|CONF_INFO_TYPE|
# |   14| 25|       compilations|CONF_INFO_TYPE|
# |   28| 46|comparisons studies|CONF_INFO_TYPE|
# |   57| 60|               work|CONF_INFO_TYPE|
# +-----+---+-------------------+--------------+

# %% [markdown]
# ### 🧮 **NER Visualizer**
# For saving the visualization result as html, provide save_path parameter in the display function.

# %%
# Importing the necessary functions
from pyspark.sql.functions import col

result = model.transform(def_of_conf_info_sdf)

result.select(F.explode(F.arrays_zip('ner_chunk_conf.result', 'ner_chunk_conf.metadata')).alias("cols")) \
      .select(F.expr("cols['0']").alias("ner_chunk"),
              F.expr("cols['1']['entity']").alias("label")).show(300,truncate = False)

print("\n\n")

from sparknlp_display import NerVisualizer

visualiser = NerVisualizer()
for i in range(result.count()):
  visualiser.display(result = result.collect()[i] ,label_col = 'ner_chunk_conf', document_col = 'document')
  print("\n\n")
# Out:
# +-------------------+--------------+
# |ner_chunk          |label         |
# +-------------------+--------------+
# |oral               |CONF_INFO_FORM|
# |written            |CONF_INFO_FORM|
# |Information        |CONF_INFO_TYPE|
# |inventions         |CONF_INFO_TYPE|
# |know-how           |CONF_INFO_TYPE|
# |trade-secrets      |CONF_INFO_TYPE|
# |methods            |CONF_INFO_TYPE|
# |techniques         |CONF_INFO_TYPE|
# |processes          |CONF_INFO_TYPE|
# |designs            |CONF_INFO_TYPE|
# |drawings           |CONF_INFO_TYPE|
# |diagrams           |CONF_INFO_TYPE|
# |formulae           |CONF_INFO_TYPE|
# |analysis           |CONF_INFO_TYPE|
# |clinical data      |CONF_INFO_TYPE|
# |price lists        |CONF_INFO_TYPE|
# |customers lists    |CONF_INFO_TYPE|
# |costs analyses     |CONF_INFO_TYPE|
# |reports            |CONF_INFO_TYPE|
# |surveys            |CONF_INFO_TYPE|
# |data               |CONF_INFO_TYPE|
# |analyses           |CONF_INFO_TYPE|
# |compilations       |CONF_INFO_TYPE|
# |comparisons studies|CONF_INFO_TYPE|
# |work               |CONF_INFO_TYPE|
# +-------------------+--------------+
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">For the purpose of evaluating a possible relationship between the parties (the "Purpose"), the parties may disclose to each other in </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #910C09"><span class="spark-nlp-display-entity-name">oral </span><span class="spark-nlp-display-entity-type">CONF_INFO_FORM</span></span><span class="spark-nlp-display-others" style="background-color: white"> and </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #910C09"><span class="spark-nlp-display-entity-name">written </span><span class="spark-nlp-display-entity-type">CONF_INFO_FORM</span></span><span class="spark-nlp-display-others" style="background-color: white"> form or in other medium, certain Confidential Information, as defined below, relating to their respective pipelines, products and businesses.</span></div>
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">Definition of Confidential </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #A402A0"><span class="spark-nlp-display-entity-name">Information </span><span class="spark-nlp-display-entity-type">CONF_INFO_TYPE</span></span><span class="spark-nlp-display-others" style="background-color: white">.</span></div>
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">For the purpose of this Agreement, “Confidential Information”  shall mean any proprietary information relating to a Disclosing Party, its business or assets or that of any of its customers, Affiliates (defined below), subcontractors or other persons that is not generally known to the public, whether of a technical, business or other nature, including but not limited to </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #135B78"><span class="spark-nlp-display-entity-name">inventions </span><span class="spark-nlp-display-entity-type">CONF_INFO_TYPE</span></span><span class="spark-nlp-display-others" style="background-color: white">, </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #135B78"><span class="spark-nlp-display-entity-name">know-how </span><span class="spark-nlp-display-entity-type">CONF_INFO_TYPE</span></span><span class="spark-nlp-display-others" style="background-color: white">, </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #135B78"><span class="spark-nlp-display-entity-name">trade-secrets </span><span class="spark-nlp-display-entity-type">CONF_INFO_TYPE</span></span><span class="spark-nlp-display-others" style="background-color: white">, </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #135B78"><span class="spark-nlp-display-entity-name">methods </span><span class="spark-nlp-display-entity-type">CONF_INFO_TYPE</span></span><span class="spark-nlp-display-others" style="background-color: white">, </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #135B78"><span class="spark-nlp-display-entity-name">techniques </span><span class="spark-nlp-display-entity-type">CONF_INFO_TYPE</span></span><span class="spark-nlp-display-others" style="background-color: white">, </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #135B78"><span class="spark-nlp-display-entity-name">processes </span><span class="spark-nlp-display-entity-type">CONF_INFO_TYPE</span></span><span class="spark-nlp-display-others" style="background-color: white">, </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #135B78"><span class="spark-nlp-display-entity-name">designs </span><span class="spark-nlp-display-entity-type">CONF_INFO_TYPE</span></span><span class="spark-nlp-display-others" style="background-color: white">, </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #135B78"><span class="spark-nlp-display-entity-name">drawings </span><span class="spark-nlp-display-entity-type">CONF_INFO_TYPE</span></span><span class="spark-nlp-display-others" style="background-color: white">, </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #135B78"><span class="spark-nlp-display-entity-name">diagrams </span><span class="spark-nlp-display-entity-type">CONF_INFO_TYPE</span></span><span class="spark-nlp-display-others" style="background-color: white">, </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #135B78"><span class="spark-nlp-display-entity-name">formulae </span><span class="spark-nlp-display-entity-type">CONF_INFO_TYPE</span></span><span class="spark-nlp-display-others" style="background-color: white"> and </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #135B78"><span class="spark-nlp-display-entity-name">analysis </span><span class="spark-nlp-display-entity-type">CONF_INFO_TYPE</span></span><span class="spark-nlp-display-others" style="background-color: white">, </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #135B78"><span class="spark-nlp-display-entity-name">clinical data </span><span class="spark-nlp-display-entity-type">CONF_INFO_TYPE</span></span><span class="spark-nlp-display-others" style="background-color: white">, and any business informa ...
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">Any </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #46083E"><span class="spark-nlp-display-entity-name">analyses </span><span class="spark-nlp-display-entity-type">CONF_INFO_TYPE</span></span><span class="spark-nlp-display-others" style="background-color: white">, </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #46083E"><span class="spark-nlp-display-entity-name">compilations </span><span class="spark-nlp-display-entity-type">CONF_INFO_TYPE</span></span><span class="spark-nlp-display-others" style="background-color: white">, </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #46083E"><span class="spark-nlp-display-entity-name">comparisons studies </span><span class="spark-nlp-display-entity-type">CONF_INFO_TYPE</span></span><span class="spark-nlp-display-others" style="background-color: white"> or other </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #46083E"><span class="spark-nlp-display-entity-name">work </span><span class="spark-nlp-display-entity-type">CONF_INFO_TYPE</span></span><span class="spark-nlp-display-others" style="background-color: white"> prepared by or for the Receiving Party containing any Confidential Information of the Disclosing Party (“Derivative Materials”), shall be also regarded as Confidential Information of the Disclosing Party hereunder.</span></div>
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">Company acknowledges that the provisions of U.S.  promulgated under the Exchange Act requires the public announcement of previously non-public material information if that information is disclosed to anyone who has not agreed with an Exchange Act reporting issuer to maintain the confidentiality of that information.</span></div>

# %% [markdown]
# ## 📌 **`RETURN_OF_CONF_INFO` CLAUSE-SPECIFIC NER**

# %%
return_of_conf_info_df = class_texts_df[class_texts_df['class']=='RETURN_OF_CONF_INFO']
return_of_conf_info_df
# Out:
#                                                  text                class
# 16  All Confidential Information (including tangib...  RETURN_OF_CONF_INFO
# 17  Any portion of Derivative Materials, whether c...  RETURN_OF_CONF_INFO
# 19  Notwithstanding the foregoing, the Receiving P...  RETURN_OF_CONF_INFO

# %%
# nda_return_of_conf_info
ner_model_return = legal.NerModel.pretrained("legner_nda_return_of_conf_info", "en", "legal/models")\
        .setInputCols(["sentence", "token", "embeddings"])\
        .setOutputCol("ner_return")

ner_converter_return = nlp.NerConverter()\
        .setInputCols(["sentence", "token", "ner_return"])\
        .setOutputCol("ner_chunk_return")

nlpPipeline = nlp.Pipeline(stages=[
        document_assembler,
        text_splitter,
        tokenizer,
        embeddings,
        ner_model_return,
        ner_converter_return, 
        ])

return_of_conf_info_sdf = spark.createDataFrame(return_of_conf_info_df)

model = nlpPipeline.fit(return_of_conf_info_sdf)
result = model.transform(return_of_conf_info_sdf)
# Out:
# legner_nda_return_of_conf_info download started this may take some time.
# [OK!]

# %% [markdown]
# ### 🧮 **NER Visualizer**
# For saving the visualization result as html, provide save_path parameter in the display function.

# %%
# Importing the necessary functions
from pyspark.sql.functions import col

result = model.transform(return_of_conf_info_sdf)

result.select(F.explode(F.arrays_zip('ner_chunk_return.result', 'ner_chunk_return.metadata')).alias("cols")) \
      .select(F.expr("cols['0']").alias("ner_chunk"),
              F.expr("cols['1']['entity']").alias("label")).show(300,truncate = False)

print("\n\n")

from sparknlp_display import NerVisualizer

visualiser = NerVisualizer()
for i in range(result.count()):
  visualiser.display(result = result.collect()[i] ,label_col = 'ner_chunk_return', document_col = 'document')
  print("\n\n--------------")
# Out:
# +----------+----------------+
# |ner_chunk |label           |
# +----------+----------------+
# |law       |LEGAL_PURPOSE   |
# |rule      |LEGAL_PURPOSE   |
# |regulation|LEGAL_PURPOSE   |
# |archiving |ARCHIVAL_PURPOSE|
# |back-up   |ARCHIVAL_PURPOSE|
# +----------+----------------+
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">All Confidential Information (including tangible copies, reproductions, reductions and computerized, magnetic or electronic versions thereof), shall remain at all times the property of the Disclosing Party and/or its Affiliate (as applicable), shall not be repurposed or reproduced in any way, and shall be returned to the Disclosing Party or destroyed (with written confirmation to the Disclosing Party) at the Disclosing Party's first request which may at any time be made.</span></div>
# --------------
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">Any portion of Derivative Materials, whether created by the Receiving Party or its Representatives, shall become the Disclosing Party's (or its Affiliate’s, as applicable) property and shall be also returned to the Disclosing Party or destroyed (with confirmation to the Disclosing Party) promptly upon the Disclosing Party's request.</span></div>
# --------------
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">Notwithstanding the foregoing, the Receiving Party and its Representatives may retain:<br>- (i) one (1) copy of any of Disclosing Party’s Confidential Information as required under any recordkeeping or retention requirements required of Receiving Party or its Representatives by </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #9EA077"><span class="spark-nlp-display-entity-name">law </span><span class="spark-nlp-display-entity-type">LEGAL_PURPOSE</span></span><span class="spark-nlp-display-others" style="background-color: white">, </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #9EA077"><span class="spark-nlp-display-entity-name">rule </span><span class="spark-nlp-display-entity-type">LEGAL_PURPOSE</span></span><span class="spark-nlp-display-others" style="background-color: white"> or </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #9EA077"><span class="spark-nlp-display-entity-name">regulation </span><span class="spark-nlp-display-entity-type">LEGAL_PURPOSE</span></span><span class="spark-nlp-display-others" style="background-color: white"> applicable to Receiving Party or its Representatives and <br>- (ii) any computer records or files created pursuant to automatic </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #928C5E"><span class="spark-nlp-display-entity-name">archiving </span><span class="spark-nlp-display-entity-type">ARCHIVAL_PURPOSE</span></span><span class="spark-nlp-display-others" style="background-color: white"> </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #928C5E"><span class="spark-nlp-display-entity-name">back-up </span><span class="spark-nlp-display-entity-type">ARCHIVAL_PURPOSE</span></span><span class="spark-nlp-display-others" style="background-color: white"> procedures and the like, which cannot reasonably be deleted;<br>in each case subject to the confidentiality provisions of this Agreement, which shall survive indefinitely following any termination or expiration of this Agreement.</span></div>
# --------------

# %% [markdown]
# ## 📌 **`USE_OF_CONF_INFO` CLAUSE-SPECIFIC NER**

# %%
use_of_conf_info_df = class_texts_df[class_texts_df['class']=='USE_OF_CONF_INFO']
use_of_conf_info_df
# Out:
#                                                  text             class
# 10  The Receiving Party shall ensure that its Repr...  USE_OF_CONF_INFO
# 12  For the purpose hereof, the Receiving Party it...  USE_OF_CONF_INFO
# 18  Without limiting the foregoing, the Receiving ...  USE_OF_CONF_INFO
# 24  Scope of Relations.\nNeither this Agreement no...  USE_OF_CONF_INFO
# 33  IN WITNESS WHEREOF, the Parties have executed ...  USE_OF_CONF_INFO

# %%
# nda_use_of_conf_info
ner_model_use = legal.NerModel.pretrained("legner_nda_confidential_information_restricted", "en", "legal/models")\
        .setInputCols(["sentence", "token", "embeddings"])\
        .setOutputCol("ner_use")

ner_converter_use = nlp.NerConverter()\
        .setInputCols(["sentence", "token", "ner_use"])\
        .setOutputCol("ner_chunk_use")

nlpPipeline = nlp.Pipeline(stages=[
        document_assembler,
        text_splitter,
        tokenizer,
        embeddings,
        ner_model_use,
        ner_converter_use, 
        ])

use_of_conf_info_sdf = spark.createDataFrame(use_of_conf_info_df)

model = nlpPipeline.fit(use_of_conf_info_sdf)
result = model.transform(use_of_conf_info_sdf)
# Out:
# legner_nda_confidential_information_restricted download started this may take some time.
# [OK!]

# %% [markdown]
# ### 🧮 **NER Visualizer**
# For saving the visualization result as html, provide save_path parameter in the display function.

# %%
# Importing the necessary functions
from pyspark.sql.functions import col

result = model.transform(use_of_conf_info_sdf)

result.select(F.explode(F.arrays_zip('ner_chunk_use.result', 'ner_chunk_use.metadata')).alias("cols")) \
      .select(F.expr("cols['0']").alias("ner_chunk"),
              F.expr("cols['1']['entity']").alias("label")).show(300,truncate = False)

print("\n\n")

from sparknlp_display import NerVisualizer

visualiser = NerVisualizer()
for i in range(result.count()):
  visualiser.display(result = result.collect()[i] ,label_col = 'ner_chunk_use', document_col = 'document')
  print("\n\n")
# Out:
# +---------------+------------------+
# |ner_chunk      |label             |
# +---------------+------------------+
# |Receiving Party|RESTRICTED_SUBJECT|
# |Receiving Party|RESTRICTED_SUBJECT|
# |Receiving      |RESTRICTED_SUBJECT|
# |Representatives|RESTRICTED_SUBJECT|
# |Receiving Party|RESTRICTED_SUBJECT|
# |Receiving      |RESTRICTED_SUBJECT|
# +---------------+------------------+
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">The </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #6414B6"><span class="spark-nlp-display-entity-name">Receiving Party </span><span class="spark-nlp-display-entity-type">RESTRICTED_SUBJECT</span></span><span class="spark-nlp-display-others" style="background-color: white"> shall ensure that its Representatives will maintain the confidentiality as required by the terms of this Agreement of any Disclosing Party’s Confidential Information received by such Representatives and </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #6414B6"><span class="spark-nlp-display-entity-name">Receiving Party </span><span class="spark-nlp-display-entity-type">RESTRICTED_SUBJECT</span></span><span class="spark-nlp-display-others" style="background-color: white"> shall be absolutely responsible for any breach of such obligations by its Representatives.</span></div>
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">For the purpose hereof, the </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #808D26"><span class="spark-nlp-display-entity-name">Receiving </span><span class="spark-nlp-display-entity-type">RESTRICTED_SUBJECT</span></span><span class="spark-nlp-display-others" style="background-color: white"> Party its </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #808D26"><span class="spark-nlp-display-entity-name">Representatives </span><span class="spark-nlp-display-entity-type">RESTRICTED_SUBJECT</span></span><span class="spark-nlp-display-others" style="background-color: white"> shall use efforts commensurate with those that it employs for the protection of its own corresponding sensitive information, which shall in any event be no lesser a standard than the type of efforts that would be taken by a careful hi-tech business for the protection of its commercial and technical secrets.</span></div>
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">Without limiting the foregoing, the </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #60C5C2"><span class="spark-nlp-display-entity-name">Receiving Party </span><span class="spark-nlp-display-entity-type">RESTRICTED_SUBJECT</span></span><span class="spark-nlp-display-others" style="background-color: white"> shall not assert directly or indirectly any right, including any right of set-off or lien, with respect to Disclosing Party’s Confidential Information.</span></div>
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">Scope of Relations.<br>Neither this Agreement nor the disclosure by the Disclosing Party or its Affiliates of Confidential Information to the </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #8BA5C3"><span class="spark-nlp-display-entity-name">Receiving </span><span class="spark-nlp-display-entity-type">RESTRICTED_SUBJECT</span></span><span class="spark-nlp-display-others" style="background-color: white"> Party or its receipt thereof shall constitute or imply any offer, promise or intention of either Party to enter into any agreement, joint venture or other business engagement, nor constitute any representation, warranty, assurance or guarantee by the Disclosing Party or its Affiliates, with respect to the accuracy, originality, or efficiency of the Confidential Information.</span></div>
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">IN WITNESS WHEREOF, the Parties have executed and delivered this Non-Disclosure Agreement, as of the date first written above.</span></div>

# %% [markdown]
# ## 📌 **`EXCEPTIONS` CLAUSE-SPECIFIC NER**

# %%
exceptions_df = class_texts_df[class_texts_df['class']=='EXCEPTIONS']
exceptions_df
# Out:
#                                                  text       class
# 8   Exclusions from Definition.\nThe term Confiden...  EXCEPTIONS
# 31  Company acknowledges that the provisions of U....  EXCEPTIONS

# %%
# nda_exceptions
ner_model_exceptions = legal.NerModel.pretrained("legner_nda_exceptions", "en", "legal/models")\
        .setInputCols(["sentence", "token", "embeddings"])\
        .setOutputCol("ner_exceptions")

ner_converter_exceptions = nlp.NerConverter()\
        .setInputCols(["sentence", "token", "ner_exceptions"])\
        .setOutputCol("ner_chunk_exceptions")

nlpPipeline = nlp.Pipeline(stages=[
        document_assembler,
        text_splitter,
        tokenizer,
        embeddings,
        ner_model_exceptions,
        ner_converter_exceptions, 
        ])

exceptions_sdf = spark.createDataFrame(exceptions_df)

model = nlpPipeline.fit(exceptions_sdf)
result = model.transform(exceptions_sdf)
# Out:
# legner_nda_exceptions download started this may take some time.
# [OK!]

# %% [markdown]
# ### 🧮 **NER Visualizer**
# For saving the visualization result as html, provide save_path parameter in the display function.

# %%
# Importing the necessary functions
from pyspark.sql.functions import col

result = model.transform(exceptions_sdf)

result.select(F.explode(F.arrays_zip('ner_chunk_exceptions.result', 'ner_chunk_exceptions.metadata')).alias("cols")) \
      .select(F.expr("cols['0']").alias("ner_chunk"),
              F.expr("cols['1']['entity']").alias("label")).show(300,truncate = False)

print("\n\n")

from sparknlp_display import NerVisualizer

visualiser = NerVisualizer()
for i in range(result.count()):
  visualiser.display(result = result.collect()[i] ,label_col = 'ner_chunk_exceptions', document_col = 'document')
  print("\n\n")
# Out:
# +-----------------------+----------------+
# |ner_chunk              |label           |
# +-----------------------+----------------+
# |known                  |EXCLUDED_INFO   |
# |prior to               |EXCLUSION_GROUND|
# |public domain          |EXCLUDED_INFO   |
# |through no wrongful act|EXCLUSION_GROUND|
# |rightfully             |EXCLUDED_INFO   |
# |received               |EXCLUDED_INFO   |
# |without restriction    |EXCLUSION_GROUND|
# |developed              |EXCLUDED_INFO   |
# |without the use        |EXCLUSION_GROUND|
# |provisions             |EXCLUDED_INFO   |
# |promulgated            |EXCLUDED_INFO   |
# +-----------------------+----------------+
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">Exclusions from Definition.<br>The term Confidential Information shall not include any information that the Receiving Party shall evidence in writing that was either:<br>- already known to it prior to the disclosure thereto by the Disclosing Party;<br>- or before being divulged by the Receiving Party to any third party, such information:<br>(i) was in the public domain through no wrongful act of the Receiving Party;<br>(ii) was rightfully received by the Receiving Party from a third party without restriction on disclosure and without a breach of any confidentiality obligation running directly or indirectly to the Disclosing Party;<br>or (iii) was independently developed by the Receiving Party without the use, directly or indirectly, of any of the Disclosing Party’s Confidential Information.</span></div>
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">Exclusions from Definition.<br>The term Confidential Information shall not include any information that the Receiving Party shall evidence in writing that was either:<br>- already </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #5A4464"><span class="spark-nlp-display-entity-name">known </span><span class="spark-nlp-display-entity-type">EXCLUDED_INFO</span></span><span class="spark-nlp-display-others" style="background-color: white"> to it </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #983943"><span class="spark-nlp-display-entity-name">prior to </span><span class="spark-nlp-display-entity-type">EXCLUSION_GROUND</span></span><span class="spark-nlp-display-others" style="background-color: white"> the disclosure thereto by the Disclosing Party;<br>- or before being divulged by the Receiving Party to any third party, such information:<br>(i) was in the public domain through no wrongful act of the Receiving Party;<br>(ii) was rightfully received by the Receiving Party from a third party without restriction on disclosure and without a breach of any confidentiality obligation running directly or indirectly to the Disclosing Party;<br>or (iii) was independently developed by the Receiving Party without the use, directly or indirectly, of any of the Disclosing Party’s Confidential Information.</span></div>
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">Exclusions from Definition.<br>The term Confidential Information shall not include any information that the Receiving Party shall evidence in writing that was either:<br>- already known to it prior to the disclosure thereto by the Disclosing Party;<br>- or before being divulged by the Receiving Party to any third party, such information:<br>(i) was in the public domain through no wrongful act of the Receiving Party;<br>(ii) was rightfully received by the Receiving Party from a third party without restriction on disclosure and without a breach of any confidentiality obligation running directly or indirectly to the Disclosing Party;<br>or (iii) was independently developed by the Receiving Party without the use, directly or indirectly, of any of the Disclosing Party’s Confidential Information.</span></div>
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">Exclusions from Definition.<br>The term Confidential Information shall not include any information that the Receiving Party shall evidence in writing that was either:<br>- already known to it prior to the disclosure thereto by the Disclosing Party;<br>- or before being divulged by the Receiving Party to any third party, such information:<br>(i) was in the </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #A4342C"><span class="spark-nlp-display-entity-name">public domain </span><span class="spark-nlp-display-entity-type">EXCLUDED_INFO</span></span><span class="spark-nlp-display-others" style="background-color: white"> </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #76B510"><span class="spark-nlp-display-entity-name">through no wrongful act </span><span class="spark-nlp-display-entity-type">EXCLUSION_GROUND</span></span><span class="spark-nlp-display-others" style="background-color: white"> of the Receiving Party;<br>(ii) was rightfully received by the Receiving Party from a third party without restriction on disclosure and without a breach of any confidentiality obligation running directly or indirectly to the Disclosing Party;<br>or (iii) was independently developed by the Receiving Party without the use, directly or indirectly, of any of the Disclosing Party’s Confidential Information.</span></div>
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">Exclusions from Definition.<br>The term Confidential Information shall not include any information that the Receiving Party shall evidence in writing that was either:<br>- already known to it prior to the disclosure thereto by the Disclosing Party;<br>- or before being divulged by the Receiving Party to any third party, such information:<br>(i) was in the public domain through no wrongful act of the Receiving Party;<br>(ii) was </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #2EA30D"><span class="spark-nlp-display-entity-name">rightfully </span><span class="spark-nlp-display-entity-type">EXCLUDED_INFO</span></span><span class="spark-nlp-display-others" style="background-color: white"> </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #2EA30D"><span class="spark-nlp-display-entity-name">received </span><span class="spark-nlp-display-entity-type">EXCLUDED_INFO</span></span><span class="spark-nlp-display-others" style="background-color: white"> by the Receiving Party from a third party </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #79836D"><span class="spark-nlp-display-entity-name">without restriction </span><span class="spark-nlp-display-entity-type">EXCLUSION_GROUND</span></span><span class="spark-nlp-display-others" style="background-color: white"> on disclosure and without a breach of any confidentiality obligation running directly or indirectly to the Disclosing Party;<br>or (iii) was independently developed by the Receiving Party without the use, directly or indirectly, of any of the Disclosing Party’s Confidential Information.</span></div>
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">Exclusions from Definition.<br>The term Confidential Information shall not include any information that the Receiving Party shall evidence in writing that was either:<br>- already known to it prior to the disclosure thereto by the Disclosing Party;<br>- or before being divulged by the Receiving Party to any third party, such information:<br>(i) was in the public domain through no wrongful act of the Receiving Party;<br>(ii) was rightfully received by the Receiving Party from a third party without restriction on disclosure and without a breach of any confidentiality obligation running directly or indirectly to the Disclosing Party;<br>or (iii) was independently developed by the Receiving Party without the use, directly or indirectly, of any of the Disclosing Party’s Confidential Information.</span></div>
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">Exclusions from Definition.<br>The term Confidential Information shall not include any information that the Receiving Party shall evidence in writing that was either:<br>- already known to it prior to the disclosure thereto by the Disclosing Party;<br>- or before being divulged by the Receiving Party to any third party, such information:<br>(i) was in the public domain through no wrongful act of the Receiving Party;<br>(ii) was rightfully received by the Receiving Party from a third party without restriction on disclosure and without a breach of any confidentiality obligation running directly or indirectly to the Disclosing Party;<br>or (iii) was independently </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #90BF2E"><span class="spark-nlp-display-entity-name">developed </span><span class="spark-nlp-display-entity-type">EXCLUDED_INFO</span></span><span class="spark-nlp-display-others" style="background-color: white"> by the Receiving Party </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #6C01A3"><span class="spark-nlp-display-entity-name">without the use </span><span class="spark-nlp-display-entity-type">EXCLUSION_GROUND</span></span><span class="spark-nlp-display-others" style="background-color: white">, directly or indirectly, of any of the Disclosing Party’s Confidential Information.</span></div>
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">Company acknowledges that the </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #A48966"><span class="spark-nlp-display-entity-name">provisions </span><span class="spark-nlp-display-entity-type">EXCLUDED_INFO</span></span><span class="spark-nlp-display-others" style="background-color: white"> of U.S.  </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #A48966"><span class="spark-nlp-display-entity-name">promulgated </span><span class="spark-nlp-display-entity-type">EXCLUDED_INFO</span></span><span class="spark-nlp-display-others" style="background-color: white"> under the Exchange Act requires the public announcement of previously non-public material information if that information is disclosed to anyone who has not agreed with an Exchange Act reporting issuer to maintain the confidentiality of that information.</span></div>

# %% [markdown]
# ## 📌 **QUESTION ANSWERING**

# %%
import re
with open('nda_2.txt', 'r') as f:
  text = f.read().split('\n\n')[0]
  print(text)
# Out:
# This Non-Disclosure Agreement (“Agreement”) is made and entered into on this 2nd day of January, 2023, by and between PlusUltra Inc., a Delaware corporation having its principal offices at 111 Way White, Austin, NH 229484 (“PlusUltra”) and John Snow Labs Inc., a Delaware corporation, located at , , ,  (the “Company”).

# %%
documentAssembler = nlp.MultiDocumentAssembler()\
        .setInputCols(["question", "context"])\
        .setOutputCols(["document_question", "document_context"])

leg_qa = legal.QuestionAnswering.pretrained("legqa_flant5_finetuned","en","legal/models")\
    .setInputCols(["document_question", "document_context"])\
    .setCustomPrompt("question: {question} context: {context}")\
    .setMaxNewTokens(50)\
    .setOutputCol("answer")

pipeline = nlp.Pipeline().setStages([
        documentAssembler,
        leg_qa
])
# Out:
# legqa_flant5_finetuned download started this may take some time.
# [OK!]

# %%
new_text = [text]

questions = {0: ["Between whom was this agreement made?", 
                 "When did this agreement enter into effect ?",
                 "In which state is PlusUltra Inc. based?",
                 "What is the address of PlusUltra?"]}

# Create a list of dictionaries for each row in the DataFrame
data = [{"context": text, "question": question} for text, question_list in zip(new_text, questions.values()) for question in question_list]

# Create a DataFrame from the list of dictionaries
df = spark.createDataFrame(data)

# Display the resulting DataFrame
df.show(truncate=90)
# Out:
# +------------------------------------------------------------------------------------------+-------------------------------------------+
# |                                                                                   context|                                   question|
# +------------------------------------------------------------------------------------------+-------------------------------------------+
# |This Non-Disclosure Agreement (“Agreement”) is made and entered into on this 2nd day of...|      Between whom was this agreement made?|
# |This Non-Disclosure Agreement (“Agreement”) is made and entered into on this 2nd day of...|When did this agreement enter into effect ?|
# |This Non-Disclosure Agreement (“Agreement”) is made and entered into on this 2nd day of...|    In which state is PlusUltra Inc. based?|
# |This Non-Disclosure Agreement (“Agreement”) is made and entered into on this 2nd day of...|          What is the address of PlusUltra?|
# +------------------------------------------------------------------------------------------+-------------------------------------------+

# %%
result = pipeline.fit(df).transform(df)

result.select('answer.result').show(truncate=False)
# Out:
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |result                                                                                                                                                                                                 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[This agreement was made between PlusUltra Inc., a Delaware corporation having its principal offices at 111 Way White, Austin, NH 229484 and John Snow Labs Inc., a Delaware corporation, located at ,]|
# |[This agreement entered into effect on the 2nd day of January, 2023.  . . . . . . ]                                                                                                                    |
# |[PlusUltra Inc. is based in Delaware. ]                                                                                                                                                                |
# |[PlusUltra is located at 111 Way White, Austin, NH 229484. ]                                                                                                                                           |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# ## 📌 **SUMMARIZATION**

# %%
import re
with open('nda_2.txt', 'r') as f:
  text = f.read()

paragraphs = text.split('\n\n')
paragraphs[:5]
# Out:
# ['This Non-Disclosure Agreement (“Agreement”) is made and entered into on this 2nd day of January, 2023, by and between PlusUltra Inc., a Delaware corporation having its principal offices at 111 Way White, Austin, NH 229484 (“PlusUltra”) and John Snow Labs Inc., a Delaware corporation, located at , , ,  (the “Company”).',
#  'For the purpose of evaluating a possible relationship between the parties (the "Purpose"), the parties may disclose to each other in oral and written form or in other medium, certain Confidential Information, as defined below, relating to their respective pipelines, products and businesses.',
#  'As a precondition to any such disclosure, each party hereby agrees to keep all such Confidential Information of the other party in strict confidence under the terms set out in this Agreement. \nFor purposes of this Agreement, a party receiving Confidential Information hereunder shall be referred to as the “Receiving Party” and a party disclosing Confidential Information hereunder shall be referred to as the “Disclosing Party” and each of them shall be individually referred to as a “Party” and collectively, the “Parties.',
#  'Definition of Confidential Information.',
#  'For the purpose of this Agreement, “Confidential Information”  shall mean any proprietary information relating to a Disclosing Party, its business or assets or that of any of its customers, Affiliates (defined below), subcontractors or other persons that is not generally known to the public, whether of a technical, business or other nature, including but not limited to inventions, know-how, trade-secrets, methods, techniques, processes, designs, drawings, diagrams, formulae and analysis, clinical data, and any business information, including but not limited to price lists, customers lists, costs analyses, reports, surveys and market information and data), whether communicated in tangible or intangible form.']

# %%
document_assembler = nlp.DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("documents")

flant5 = legal.Summarizer().pretrained('legsum_flant5_legal_augmented','en','legal/models')\
    .setInputCols(["documents"])\
    .setOutputCol("summary")\
    .setMaxTextLength(512)\
    .setMaxNewTokens(512)

pipeline = nlp.Pipeline(stages=[document_assembler, 
                                flant5])

data = spark.createDataFrame([[1, " "]]).toDF('id', 'text')
# Out:
# legsum_flant5_legal_augmented download started this may take some time.
# [OK!]

# %%
model = pipeline.fit(data)

# %%
light_model = nlp.LightPipeline(model)
light_result = light_model.annotate(paragraphs)

# %%
light_result
# Out:
# [{'documents': ['This Non-Disclosure Agreement (“Agreement”) is made and entered into on this 2nd day of January, 2023, by and between PlusUltra Inc., a Delaware corporation having its principal offices at 111 Way White, Austin, NH 229484 (“PlusUltra”) and John Snow Labs Inc., a Delaware corporation, located at , , ,  (the “Company”).'],
#   'summary': ['This Non-Disclosure Agreement is between PlusUltra Inc. and John Snow Labs Inc., a Delaware corporation located at 111 Way White, Austin, NH 229484. It is a non-disclosure agreement between the two companies.']},
#  {'documents': ['For the purpose of evaluating a possible relationship between the parties (the "Purpose"), the parties may disclose to each other in oral and written form or in other medium, certain Confidential Information, as defined below, relating to their respective pipelines, products and businesses.'],
#   'summary': ['This legal agreement states that the parties may disclose certain confidential information to each other in oral and written form or in other medium, relating to their respective pipelines, products and businesses.']},
#  {'documents': ['As a precondition to any such disclosure, each party hereby agrees to keep all such Confidential Information of the other party in strict confidence under the terms set out in this Agreement. \nFor purposes of this Agreement, a party receiving Confidential Information hereunder shall be referred to as the “Receiving Party” and a party disclosing Confidential Information hereunder shall be referred to as the “Disclosing Party” and each of them shall be individually referred to as a “Party” and collectively, the “Parties.'],
#   'summary': ['This agreement states that each party agrees to keep all confidential information of the other party in strict confidence under the terms set out in the agreement. For purposes of the agreement, a party receiving and disclosing confidential information will be referred to as the “Receiving Party” and the disclosing party will be referred to as the “Disclosing Party”.']},
#  {'documents': ['Definition of Confidential Information.'],
#   'summary': ['This legal agreement defines the definition of confidential information.']},
#  {'documents': ['For the purpose of this Agreement, “Confidential Information”  shall mean any proprietary information relating to a Disclosing Party, its business or assets or that of any of its customers, Affiliates (defined below), subcontractors or other persons that is not generally known to the public, whether of a technical, business or other nature, including but not limited to inventions, know-how, trade-secrets, methods, techniques, processes, designs, drawings, diagrams, formulae and analysis, clinical data, and any business information, including but not limited to price lists, customers lists, costs analyses, reports, surveys and market information and data), whether communicated in tangible or intangible form.'],
#   'summary': ['This legal agreement defines "Confidential Information" as any proprietary information relating to a Disclosure Party, its business or assets, or that of any of its customers, affiliates, subcontractors, or other persons that is not generally known to the public. It also defines "Inventions, know-how, trade-secrets, methods, techniques, processes, designs, drawings, diagrams, formulae and analysis, clinical data, and any business information, including price lists, customers lists, costs analyses, reports, surveys and market information and data."']},
#  {'documents': ['Any analyses, compilations, comparisons studies or other work prepared by or for the Receiving Party containing any Confidential Information of the Disclosing Party (“Derivative Materials”), shall be also regarded as Confidential Information of the Disclosing Party hereunder.'],
#   'summary': ['This legal agreement states that any analyses, compilations, comparisons studies, or other work prepared by or for the Receiving Party containing any Confidential Information of the Disclosing Party shall be considered as Confidential Information of the Disclosing Party.']},
#  {'documents': ['For purposes of this Agreement, “Affiliate” of a Party shall mean any person, corporation or business entity controlling, controlled by or under common control with such Party.'],
#   'summary': ['This agreement defines the term "Affiliate" as any person, corporation, or business entity controlling, controlled by, or under common control with the party.']},
#  {'documents': ['Exclusions from Definition.\nThe term Confidential Information shall not include any information that the Receiving Party shall evidence in writing that was either:\n- already known to it prior to the disclosure thereto by the Disclosing Party;\n- or before being divulged by the Receiving Party to any third party, such information:\n(i) was in the public domain through no wrongful act of the Receiving Party;\n(ii) was rightfully received by the Receiving Party from a third party without restriction on disclosure and without a breach of any confidentiality obligation running directly or indirectly to the Disclosing Party;\nor (iii) was independently developed by the Receiving Party without the use, directly or indirectly, of any of the Disclosing Party’s Confidential Information.'],
#   'summary': ['This legal agreement states that the term "Confidential Information" does not include any information that the Receiving Party must evidence in writing that was already known to it prior to the disclosure by the Disclosing Party, or before being divulged by the Receiving Party to any third party. It also states that the information must be in the public domain through no wrongful act, rightfully received from a third party without restriction on disclosure and without a breach of any confidentiality obligation running directly or indirectly to the Disclosing Party, or independently developed by the Receiving Party without the use, directly or indirectly, of any of the Disclosing Party\'s Confidential Information.']},
#  {'documents': ['Restrictions on Disclosure of Confidential Information.\nThe Receiving Party shall neither:\n- (i) use any Confidential Information other than as necessary specifically for the Purpose, nor\n- (ii) disclose any Confidential Information, in whole or in part, to any person other than its directors, officers, employees, agents or consultants (or to directors, officers, employees, agents or consultants of one of its Affiliates), who have a bona fide need to know such Confidential Information for the Purpose, and who are under a duty of confidentiality to the Receiving Party on substantially the same basis as required of Receiving Party under this Agreement (each a “Representative”).'],
#   'summary': ['This legal agreement states that the Receiving Party must not use any confidential information other than as necessary specifically for the purpose, nor disclose any confidential information to any person other than its directors, officers, employees, agents or consultants who have a bona fide need to know such confidential information for the purpose.']},
#  {'documents': ['The Receiving Party shall ensure that its Representatives will maintain the confidentiality as required by the terms of this Agreement of any Disclosing Party’s Confidential Information received by such Representatives and Receiving Party shall be absolutely responsible for any breach of such obligations by its Representatives.'],
#   'summary': ["This legal agreement states that the Receiving Party must ensure that its Representatives maintain the confidentiality of any Disclosing Party's Confidential Information received by such Representatives and must be absolutely responsible for any breach of such obligations by its Representatives."]},
#  {'documents': ['Standard of Protection.'],
#   'summary': ['This legal agreement states that the standard of protection is the standard of protection for all persons and entities.']},
#  {'documents': ['For the purpose hereof, the Receiving Party its Representatives shall use efforts commensurate with those that it employs for the protection of its own corresponding sensitive information, which shall in any event be no lesser a standard than the type of efforts that would be taken by a careful hi-tech business for the protection of its commercial and technical secrets.'],
#   'summary': ["This legal agreement states that the Receiving Party's Representatives must use efforts commensurate with those that they employ for the protection of their own corresponding sensitive information, which will be no lesser a standard than the type of efforts that would be taken by a careful hi-tech business for the protection of its commercial and technical secrets."]},
#  {'documents': ['Ownership of Information.'],
#   'summary': ['This legal agreement states that the owner of information is the owner of the information.']},
#  {'documents': ['No license or right under any patent, copyright, trademark, trade-name, mask work protection right or any other intellectual property right, is either granted or implied to the Receiving Party and its Representatives by the conveying thereto of any Confidential Information by the Disclosing Party.'],
#   'summary': ['This legal agreement states that no license or right under any patent, copyright, trademark, trade-name, mask work protection right or any other intellectual property right is granted or implied to the Receiving Party and its Representatives by the conveying thereto of any Confidential Information by the Disclosing Party.']},
#  {'documents': ["All Confidential Information (including tangible copies, reproductions, reductions and computerized, magnetic or electronic versions thereof), shall remain at all times the property of the Disclosing Party and/or its Affiliate (as applicable), shall not be repurposed or reproduced in any way, and shall be returned to the Disclosing Party or destroyed (with written confirmation to the Disclosing Party) at the Disclosing Party's first request which may at any time be made."],
#   'summary': ["This legal agreement states that all confidential information must remain the property of the Disclosing Party and/or its Affiliate, and must not be repurposed or reproduced in any way, and must be returned to the Disclosing Party or destroyed at the Disclosing Party's first request."]},
#  {'documents': ["Any portion of Derivative Materials, whether created by the Receiving Party or its Representatives, shall become the Disclosing Party's (or its Affiliate’s, as applicable) property and shall be also returned to the Disclosing Party or destroyed (with confirmation to the Disclosing Party) promptly upon the Disclosing Party's request."],
#   'summary': ["This legal agreement states that any portion of derivative materials created by the Receiving Party or its Representatives will become the Disclosing Party's property and will be returned to the Disclosing Party or destroyed promptly upon the Disclosing Party's request."]},
#  {'documents': ['Without limiting the foregoing, the Receiving Party shall not assert directly or indirectly any right, including any right of set-off or lien, with respect to Disclosing Party’s Confidential Information.'],
#   'summary': ["This legal agreement states that the Receiving Party shall not assert any right, including any right of set-off or lien, with respect to the Disclosure Party's Confidential Information."]},
#  {'documents': ['Notwithstanding the foregoing, the Receiving Party and its Representatives may retain:\n- (i) one (1) copy of any of Disclosing Party’s Confidential Information as required under any recordkeeping or retention requirements required of Receiving Party or its Representatives by law, rule or regulation applicable to Receiving Party or its Representatives and \n- (ii) any computer records or files created pursuant to automatic archiving back-up procedures and the like, which cannot reasonably be deleted;\nin each case subject to the confidentiality provisions of this Agreement, which shall survive indefinitely following any termination or expiration of this Agreement.'],
#   'summary': ["This legal agreement states that the Receiving Party and its Representatives may retain one (1) copy of any of Disclosing Party's Confidential Information as required under any recordkeeping or retention requirements required of Receiving Party or its Representatives by law, rule or regulation applicable to Receiving Party or its Representatives, and any computer records or files created pursuant to automatic archiving back-up procedures and the like, which cannot reasonably be deleted. It also states that the confidentiality provisions of this Agreement shall survive indefinitely following any termination or expiration of this Agreement."]},
#  {'documents': ["Compliance with Legal Requirements.\nIf the Receiving Party or any of its Representatives shall be legally required (by formal questioning or, in the written opinion of its legal counsel, by applicable laws) to disclose any of Disclosing Party’s Confidential Information, the Receiving Party shall immediately notify the Disclosing Party of such request or requirement prior to disclosure so that the Disclosing Party may seek an appropriate protective order with the reasonable assistance of the Receiving Party, and/or waive compliance with the terms of this undertaking, at the Disclosing Party's absolute discretion, and at Disclosing Party’s sole expense."],
#   'summary': ["This legal agreement states that if the Receiving Party or any of its Representatives are legally required to disclose any of the Disclosing Party's Confidential Information, the Receiving Party must notify the Disclosing Party of such request or requirement prior to disclosure so that the Disclosing Party may seek an appropriate protective order with the reasonable assistance of the Receiving Party and/or waive compliance with the terms of this undertaking, at the Disclosing Party's absolute discretion and at Disclosing Party's sole expense."]},
#  {'documents': ['If such order or waiver is not timely obtained, only such portion of the Confidential Information as specifically required shall be disclosed, and Receiving Party will use its commercially reasonable efforts to obtain confidential treatment of the Confidential Information to be disclosed.\nNotwithstanding the foregoing, Receiving Party and its Representatives shall not be required to provide notice or seek consent to disclose any information in connection with any disclosure to any regulatory or governmental entity having jurisdiction over the Receiving Party or Representatives (as applicable), except with respect to any investigation or audit specifically targeting the Disclosing Party or the Purpose to the extent legally permissible.'],
#   'summary': ['This legal agreement states that if an order or waiver is not obtained, only a portion of the Confidential Information will be disclosed, and Receiving Party and its Representatives will use their commercially reasonable efforts to obtain confidential treatment of the Confidential Information. Receiving Party and its Representatives are not required to provide notice or seek consent to disclose any information in connection with any disclosure to any regulatory or governmental entity having jurisdiction over the Receiving Party or Representatives, except with respect to any investigation or audit specifically targeting the Disclosing Party or the Purpose to the extent legally permissible.']},
#  {'documents': ['Term;\nSurvival.\nThe term of this Agreement shall expire on the earlier of\n(a) two years from the date of this Agreement or\n(b) the date on which the Parties (or their Affiliates) enter into a transaction document relating to the Purpose containing confidentiality provisions with respect to the potential transaction or\n(c) either Party gives written notice of termination of this Agreement to the other Party.\nNotwithstanding any termination of this Agreement, the confidentiality obligations of the Receiving Party shall survive any termination or expiration of this Agreement for five (5) years from the date of this Agreement, except to the extent provided for elsewhere herein.'],
#   'summary': ['This agreement states that the term of the agreement will expire on the earlier of two years from the date of the agreement or the date on which the parties enter into a transaction document containing confidentiality provisions with respect to the potential transaction. The confidentiality obligations of the Receiving Party will survive any termination or expiration of the agreement for five (5) years from the date of the agreement, except to the extent provided for elsewhere in the agreement.']},
#  {'documents': ['Remedies.\nReceiving Party understands that any violation of this Agreement may cause Disclosing Party immediate and irreparable harm which monetary damages may not adequately remedy.\nTherefore, upon any actual or impending violation of this Agreement, Disclosing Party may seek a restraining order or other injunction, without bond, restraining or enjoining such violation by Receiving Party, its Representatives or any entity or person acting in concert with Receiving Party.\nReceiving Party understands that such relief is additional to and does not limit the availability to Disclosing Party of any other remedy.'],
#   'summary': ['This legal agreement states that Disclosing Party may seek a restraining order or other injunction against Receiving Party, without bond, restraining or enjoining such violation by Receiving Party, its Representatives or any entity or person acting in concert with Receiving Party. This relief is additional to and does not limit the availability to Disclosing Party of any other remedy.']},
#  {'documents': ['Scope of Relations.\nNeither this Agreement nor the disclosure by the Disclosing Party or its Affiliates of Confidential Information to the Receiving Party or its receipt thereof shall constitute or imply any offer, promise or intention of either Party to enter into any agreement, joint venture or other business engagement, nor constitute any representation, warranty, assurance or guarantee by the Disclosing Party or its Affiliates, with respect to the accuracy, originality, or efficiency of the Confidential Information.'],
#   'summary': ['This agreement states that the disclosure of confidential information to the receiving party does not constitute any offer, promise, or intention of either party to enter into any agreement, joint venture, or other business engagement, nor does it constitute any representation, warranty, assurance, or guarantee with respect to the accuracy, originality, or efficiency of the confidential information.']},
#  {'documents': ['No Waiver.\nNo failure or delay by any Party in exercising any right, power or privilege hereunder shall operate as a waiver thereof, nor shall any single or partial exercise thereof preclude any other or further exercise thereof or the exercise of any other right, power or privilege hereunder.'],
#   'summary': ['This legal agreement states that any failure or delay by any party in exercising any right, power or privilege shall not operate as a waiver thereof, nor shall any single or partial exercise thereof preclude any other or further exercise thereof or the exercise of any other right, power or privilege hereunder.']},
#  {'documents': ['Applicable Law and Jurisdiction.\nThis Agreement shall be governed by, construed and enforced in accordance with the laws of New York State.\nThe Parties hereby irrevocably submit to the jurisdiction of the competent courts located in New York County of New York State and hereby waive any objection regarding jurisdiction or forum.\nThis Agreement is only for the benefit of the Parties.\nThe Parties agree that unless and until definitive documentation with respect to a transaction has been signed and delivered by the Parties or one of their respective Affiliates, neither Party or any of their respective Affiliates shall have any legal obligation of any kind whatsoever (other than confidentiality obligations under this Agreement) with respect to the Purpose by virtue of this Agreement or any other written or oral communication with respect to the Purpose or any other potential transaction.'],
#   'summary': ['This agreement states that it is governed by the laws of New York State and waives any objection regarding jurisdiction or forum. It also states that unless and until definitive documentation with respect to a transaction has been signed and delivered by the parties or one of their respective affiliates, neither party or any of their respective affiliates shall have any legal obligation of any kind whatsoever with respect to the purpose by virtue of this agreement or any other written or oral communication with respect to the purpose or any other potential transaction.']},
#  {'documents': ['Company hereby acknowledges and confirms that it is aware and that it will advise its Representatives that the U.S. federal securities laws prohibit any person who is in possession of any material non-public information about a company that is subject to the reporting requirements of the U.S.'],
#   'summary': ['U.S. federal securities laws. Company acknowledges and confirms that it is aware and will advise its Representatives that the U.S. federal securities laws prohibit any person who is in possession of any material non-public information about a company that is subject to the reporting requirements of the U.S. federal securities laws.']},
#  {'documents': ['Securities Exchange Act of 1934, as amended (the “Exchange Act”), from purchasing, selling or trading securities of such issuer-company and that PlusUltra’s parent company, PlusUltra Limited, is such a reporting company.'],
#   'summary': ["This legal agreement states that the Securities Exchange Act of 1934, as amended, from purchasing, selling or trading securities of such issuer-company and that PlusUltra's parent company, PlusUltra Limited, is such a reporting company."]},
#  {'documents': ['Company acknowledges that the provisions of U.S.\u202f promulgated under the Exchange Act requires the public announcement of previously non-public material information if that information is disclosed to anyone who has not agreed with an Exchange Act reporting issuer to maintain the confidentiality of that information.'],
#   'summary': ['This legal agreement states that the provisions of the U.S. Exchange Act require the public announcement of previously non-public material information if it is disclosed to anyone who has not agreed with an Exchange Act reporting issuer to maintain the confidentiality of that information.']},
#  {'documents': ['Company agrees not to take, directly or indirectly, any action that would require PlusUltra Limited to make a public announcement pursuant to the requirements of Regulation FD'],
#   'summary': ['This legal agreement states that the company agrees not to take any action that would require PlusUltra Limited to make a public announcement pursuant to the requirements of Regulation FD.']},
#  {'documents': ['IN WITNESS WHEREOF, the Parties have executed and delivered this Non-Disclosure Agreement, as of the date first written above.'],
#   'summary': ['This non-disclosure agreement is between the parties and is signed by both parties.']},
#  {'documents': ['PlusUltra \t\t\t\t\t\tJohn Snow Labs Inc. \nBy:\t____________________\t\t\tBy:\t___________________ \nName:  \t\t\t\t\tName: \nTitle:\t\t\t\t\t\tTitle: Legal Counsel \n'],
#   'summary': ['This legal agreement is between PlusUltra John Snow Labs Inc. and its legal counsel. It states that the legal counsel is the legal counsel of the company.']}]

# %%
combined_text = '\n'.join([d['summary'][0] for d in light_result])
print(combined_text)
# Out:
# This Non-Disclosure Agreement is between PlusUltra Inc. and John Snow Labs Inc., a Delaware corporation located at 111 Way White, Austin, NH 229484. It is a non-disclosure agreement between the two companies.
# This legal agreement states that the parties may disclose certain confidential information to each other in oral and written form or in other medium, relating to their respective pipelines, products and businesses.
# This agreement states that each party agrees to keep all confidential information of the other party in strict confidence under the terms set out in the agreement. For purposes of the agreement, a party receiving and disclosing confidential information will be referred to as the “Receiving Party” and the disclosing party will be referred to as the “Disclosing Party”.
# This legal agreement defines the definition of confidential information.
# This legal agreement defines "Confidential Information" as any proprietary information relating to a Disclosure Party, its business or assets, or that of any of its customers, affiliates, subcontractors, or other persons that is not generally known to the public. It also defines "Inventions, know-how, trade-secrets, methods, techniques, processes, designs, drawings, diagrams, formulae and analysis, clinical data, and any business information, including price lists, customers lists, costs analyses, reports, surveys and market information and data."
# This legal agreement states that any analyses, compilations, comparisons studies, or other work prepared by or for the Receiving Party containing any Confidential Information of the Disclosing Party shall be considered as Confidential Information of the Disclosing Party.
# This agreement defines the term "Affiliate" as any person, corporation, or business entity controlling, controlled by, or under common control with the party.
# This legal agreement states that the term "Confidential Information" does not include any information that the Receiving Party must evidence in writing that was already known to it prior to the disclosure by the Disclosing Party, or before being divulged by the Receiving Party to any third party. It also states that the information must be in the public domain through no wrongful act, rightfully received from a third party without restriction on disclosure and without a breach of any confidentiality obligation running directly or indirectly to the Disclosing Party, or independently developed by the Receiving Party without the use, directly or indirectly, of any of the Disclosing Party's Confidential Information.
# This legal agreement states that the Receiving Party must not use any confidential information other than as necessary specifically for the purpose, nor disclose any confidential information to any person other than its directors, officers, employees, agents or consultants who have a bona fide need to know such confidential information for the purpose.
# This legal agreement states that the Receiving Party must ensure that its Representatives maintain the confidentiality of any Disclosing Party's Confidential Information received by such Representatives and must be absolutely responsible for any breach of such obligations by its Representatives.
# This legal agreement states that the standard of protection is the standard of protection for all persons and entities.
# This legal agreement states that the Receiving Party's Representatives must use efforts commensurate with those that they employ for the protection of their own corresponding sensitive information, which will be no lesser a standard than the type of efforts that would be taken by a careful hi-tech business for the protection of its commercial and technical secrets.
# This legal agreement states that the owner of information is the owner of the information.
# This legal agreement states that no license or right under any patent, copyright, trademark, trade-name, mask work protection right or any other intellectual property right is granted or implied to the Receiving Party and its Representatives by the conveying thereto of any Confidential Information by the Disclosing Party.
# This legal agreement states that all confidential information must remain the property of the Disclosing Party and/or its Affiliate, and must not be repurposed or reproduced in any way, and must be returned to the Disclosing Party or destroyed at the Disclosing Party's first request.
# This legal agreement states that any portion of derivative materials created by the Receiving Party or its Representatives will become the Disclosing Party's property and will be returned to the Disclosing Party or destroyed promptly upon the Disclosing Party's request.
# This legal agreement states that the Receiving Party shall not assert any right, including any right of set-off or lien, with respect to the Disclosure Party's Confidential Information.
# This legal agreement states that the Receiving Party and its Representatives may retain one (1) copy of any of Disclosing Party's Confidential Information as required under any recordkeeping or retention requirements required of Receiving Party or its Representatives by law, rule or regulation applicable to Receiving Party or its Representatives, and any computer records or files created pursuant to automatic archiving back-up procedures and the like, which cannot reasonably be deleted. It also states that the confidentiality provisions of this Agreement shall survive indefinitely following any termination or expiration of this Agreement.
# This legal agreement states that if the Receiving Party or any of its Representatives are legally required to disclose any of the Disclosing Party's Confidential Information, the Receiving Party must notify the Disclosing Party of such request or requirement prior to disclosure so that the Disclosing Party may seek an appropriate protective order with the reasonable assistance of the Receiving Party and/or waive compliance with the terms of this undertaking, at the Disclosing Party's absolute discretion and at Disclosing Party's sole expense.
# This legal agreement states that if an order or waiver is not obtained, only a portion of the Confidential Information will be disclosed, and Receiving Party and its Representatives will use their commercially reasonable efforts to obtain confidential treatment of the Confidential Information. Receiving Party and its Representatives are not required to provide notice or seek consent to disclose any information in connection with any disclosure to any regulatory or governmental entity having jurisdiction over the Receiving Party or Representatives, except with respect to any investigation or audit specifically targeting the Disclosing Party or the Purpose to the extent legally permissible.
# This agreement states that the term of the agreement will expire on the earlier of two years from the date of the agreement or the date on which the parties enter into a transaction document containing confidentiality provisions with respect to the potential transaction. The confidentiality obligations of the Receiving Party will survive any termination or expiration of the agreement for five (5) years from the date of the agreement, except to the extent provided for elsewhere in the agreement.
# This legal agreement states that Disclosing Party may seek a restraining order or other injunction against Receiving Party, without bond, restraining or enjoining such violation by Receiving Party, its Representatives or any entity or person acting in concert with Receiving Party. This relief is additional to and does not limit the availability to Disclosing Party of any other remedy.
# This agreement states that the disclosure of confidential information to the receiving party does not constitute any offer, promise, or intention of either party to enter into any agreement, joint venture, or other business engagement, nor does it constitute any representation, warranty, assurance, or guarantee with respect to the accuracy, originality, or efficiency of the confidential information.
# This legal agreement states that any failure or delay by any party in exercising any right, power or privilege shall not operate as a waiver thereof, nor shall any single or partial exercise thereof preclude any other or further exercise thereof or the exercise of any other right, power or privilege hereunder.
# This agreement states that it is governed by the laws of New York State and waives any objection regarding jurisdiction or forum. It also states that unless and until definitive documentation with respect to a transaction has been signed and delivered by the parties or one of their respective affiliates, neither party or any of their respective affiliates shall have any legal obligation of any kind whatsoever with respect to the purpose by virtue of this agreement or any other written or oral communication with respect to the purpose or any other potential transaction.
# U.S. federal securities laws. Company acknowledges and confirms that it is aware and will advise its Representatives that the U.S. federal securities laws prohibit any person who is in possession of any material non-public information about a company that is subject to the reporting requirements of the U.S. federal securities laws.
# This legal agreement states that the Securities Exchange Act of 1934, as amended, from purchasing, selling or trading securities of such issuer-company and that PlusUltra's parent company, PlusUltra Limited, is such a reporting company.
# This legal agreement states that the provisions of the U.S. Exchange Act require the public announcement of previously non-public material information if it is disclosed to anyone who has not agreed with an Exchange Act reporting issuer to maintain the confidentiality of that information.
# This legal agreement states that the company agrees not to take any action that would require PlusUltra Limited to make a public announcement pursuant to the requirements of Regulation FD.
# This non-disclosure agreement is between the parties and is signed by both parties.
# This legal agreement is between PlusUltra John Snow Labs Inc. and its legal counsel. It states that the legal counsel is the legal counsel of the company.

# %%
light_model = nlp.LightPipeline(model)
light_result = light_model.annotate(combined_text)

# %%
light_result['summary']
# Out:
# ["This legal agreement is between PlusUltra Inc. and John Snow Labs Inc. It states that the parties may disclose certain confidential information to each other in oral and written form or in other medium, relating to their respective pipelines, products and businesses. It also states that the Receiving Party must keep all confidential information of the other party in strict confidence under the terms set out in the agreement. The Receiving Party must not use any confidential information other than as necessary specifically for the purpose, nor disclose any confidential information to any person other than its directors, officers, employees, agents or consultants who have a bona fide need to know such confidential information for the purpose. The Receiving Party must ensure that its Representatives maintain the confidentiality of any Disclosing Party's Confidential Information received by such Representatives and must be absolutely responsible for any breach of such obligations by its Representatives. The Receiving Party must not use any confidential information other than as necessary specifically for the purpose, nor disclose any confidential information to any person other than its directors, officers, employees, agents or consultants who have a bona fide need to know such confidential information for the purpose. The Receiving Party must ensure that its Representatives maintain the confidentiality of any Disclosing Party's Confidential Information received by such Representatives and must be absolutely responsible for any breach of such obligations by its Representatives. The Receiving Party must not assert any right, including any right of set-off or lien, with respect to the Disclosure Party's Confidential Information. The Receiving Party and its Representatives may retain one (1) copy of any of Disclosing Party's Confidential Information as required under any recordkeeping or retention requirements required of Receiving Party or its Representatives by law, rule or regulation applicable to Receiving Party or its Representatives, and any computer records or files created pursuant to automatic archiving back-up procedures and the like, which cannot reasonably be deleted. The confidentiality provisions of this Agreement shall survive indefinitely following any termination or expiration of this Agreement. The Receiving Party must notify the Disclosing Party of such request or requirement prior to disclosure so that the Disclosing Party may seek an appropriate protective order with the reasonable assistance of the Receiving Party and/or waive compliance with the terms of this undertaking, at the Disclosing Party's absolute discretion and at Disclosing Party's"]
