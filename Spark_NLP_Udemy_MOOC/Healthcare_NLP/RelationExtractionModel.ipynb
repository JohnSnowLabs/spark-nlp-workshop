# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/spark-nlp-workshop/blob/master/Spark_NLP_Udemy_MOOC/Healthcare_NLP/RelationExtractionModel.ipynb)

# %% [markdown]
# # RelationExtractionModel
#
# In this notebook, we will examine the `RelationExtractionModel` annotator.
#
# This Relation Extraction annotator extracts and classifies instances of relations between named entities.

# %% [markdown]
# **📖 Learning Objectives:**
#
# 1. Understand how to extract and classify the relations between named entities by using pre-trained models.
#
# 2. Become comfortable using the different parameters of the annotator.
#
# **🔗 Helpful Links:**
#
# - Documentation [RelationExtractionModel](https://nlp.johnsnowlabs.com/docs/en/licensed_annotators#relationextraction)
#
# - For extended examples of usage, see the [Spark NLP Workshop](https://github.com/JohnSnowLabs/spark-nlp-workshop/blob/master/healthcare-nlp/03.0.Clinical_Relation_Extraction.ipynb)
#
# - Python Documentation: [RelationExtractionModel](https://nlp.johnsnowlabs.com/licensed/api/python/reference/autosummary/sparknlp_jsl/annotator/re/relation_extraction/index.html#sparknlp_jsl.annotator.re.relation_extraction.RelationExtractionModel.name)
#
# - Scala Documentation: [RelationExtractionModel](https://nlp.johnsnowlabs.com/licensed/api/com/johnsnowlabs/nlp/annotators/re/RelationExtractionModel.html)
#
# - Relation Extraction Models and Relation Pairs Table: [In this link](https://nlp.johnsnowlabs.com/docs/en/best_practices_pretrained_models#relation-extraction-models-and-relation-pairs-table), available Relation Extraction models, its labels, optimal NER model, and meaningful relation pairs are illustrated.

# %% [markdown]
# ## **📜 Background**

# %% [markdown]
# This annotator extracts and classifies instances of relations between named entities. For this, relation pairs need to be defined with `setRelationPairs`, to specify between which entities the extraction should be done.

# %% [markdown]
# ## **🎬 Colab Setup**

# %%
# Install the johnsnowlabs library to access Spark-NLP for Healthcare
! pip install -q johnsnowlabs

# %%
from google.colab import files
print('Please Upload your John Snow Labs License using the button below')
license_keys = files.upload()

# %%
from johnsnowlabs import nlp, medical

# After uploading your license run this to install all licensed Python Wheels and pre-download Jars the Spark Session JVM
nlp.install()
# Out:
# 👌 Detected license file /content/5.4.0.spark_nlp_for_healthcare.json
# 🚨 Outdated Medical Secrets in license file. Version=5.4.0.PR but should be Version=5.4.0
# 🚨 Outdated OCR Secrets in license file. Version=5.1.2 but should be Version=5.4.0
# 👷 Trying to install compatible secrets. Use nlp.settings.enforce_versions=False if you want to install outdated secrets.
# 📋 Stored John Snow Labs License in /root/.johnsnowlabs/licenses/license_number_0_for_Spark-Healthcare_Spark-OCR.json
# 👷 Setting up  John Snow Labs home in /root/.johnsnowlabs, this might take a few minutes.
# Downloading 🐍+🚀 Python Library spark_nlp-5.4.0-py2.py3-none-any.whl
# Downloading 🐍+💊 Python Library spark_nlp_jsl-5.4.0-py3-none-any.whl
# Downloading 🫘+🚀 Java Library spark-nlp-assembly-5.4.0.jar
# Downloading 🫘+💊 Java Library spark-nlp-jsl-5.4.0.jar
# 🙆 JSL Home setup in /root/.johnsnowlabs
# 👌 Detected license file /content/5.4.0.spark_nlp_for_healthcare.json
# 👷 Trying to install compatible secrets. Use nlp.settings.enforce_versions=False if you want to install outdated secrets.
# Installing /root/.johnsnowlabs/py_installs/spark_nlp_jsl-5.4.0-py3-none-any.whl to /usr/bin/python3
# Installed 1 products:
# 💊 Spark-Healthcare==5.4.0 installed! ✅ Heal the planet with NLP!

# %%
import pandas as pd

# Automatically load license data and start a session with all jars user has access to
spark = nlp.start()
# Out:
# 👌 Detected license file /content/5.4.0.spark_nlp_for_healthcare.json
# 👷 Trying to install compatible secrets. Use nlp.settings.enforce_versions=False if you want to install outdated secrets.
# 👌 Launched cpu optimized session with with: 🚀Spark-NLP==5.4.0, 💊Spark-Healthcare==5.4.0, running on ⚡ PySpark==3.4.0

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://566e5ba7fceb:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>John-Snow-Labs-Spark-Session 🚀 with Jars for: 🚀Spark-NLP==5.4.0, 💊Spark-Healthcare==5.4.0, running on ⚡ PySpark==3.4.0</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## **🖨️ Input/Output Annotation Types**
# - Input: `WORD_EMBEDDINGS, POS, CHUNK, DEPENDENCY`
# - Output: `CATEGORY`

# %% [markdown]
# ## **🔎 Parameters**

# %% [markdown]
# - `predictionThreshold` *(Float)*: Sets minimal activation of the target unit to encode a new relation instance.
#
# - `relationPairs` *(List[Str])*: List of dash-separated pairs of named entities. For example, [“Biomarker-RelativeDay”] will process all relations between entities of type “Biomarker” and “RelativeDay”.
#
# - `relationPairsCaseSensitive` *(Bool)*: Determines whether relation pairs are case sensitive.
#
# - `relationTypePerPair` *dict[str, list[str]]*: List of entity pairs per relations which limit the entities can form a relation. For example, {“CAUSE”: [“PROBLEM”, “SYMPTOM”]} which only let a “CAUSE” relation to hold between a problem (“PROBLEM) and a symptom (“SYMTOM”).
#
# - `maxSyntacticDistance` *(Int)*: Maximal syntactic distance, as threshold (Default: 0). Determine how far the “from entity” can be from the “to entity” in the text. Increasing this value will increase recall, but also increase the number of false positives.
#
# - `customLabels` *(dict[str, str])*: Custom relation labels.
#
# - `multiClass` *(Bool)*: If multiClass is set, the model will return all the labels with corresponding scores (Default: False)
#
# - `scopeWindow` *(IntArray)*: By applying the scopeWindow [X, Y], additional X tokens to the left and Y tokens to the right for feature generation, enriching contextual information essential for precise embeddings-based feature extraction.
#
# - `directionSensitive` *(Bool)*: The directionSensitive setting determines how entity relations are considered. If set to true, only relations in the form of ENTITY1-ENTITY2 are considered. If set to false, both ENTITY1-ENTITY2 and ENTITY2-ENTITY1 relations are considered. Default is ‘false’.
#
# - `filterByTokenDistance` *(Int)*: The filterByTokenDistance setting is a criterion for filtering based on the number of tokens between entities. The model only identifies relations where the entities are separated by fewer than the specified number of tokens (Default: 0).
#
# - `feature_scaling` *(str)*: setFeatureScaling() method, granting the ability to apply different feature scaling techniques such as `zscore`, `minmax` or `empty` (no scaling).

# %% [markdown]
# ### Utility Function
# Get relations in a pandas dataframe

# %%
# get relations in a pandas dataframe

def get_relations_df (results, rel_col='relations', chunk_col='ner_chunks', filter_O = True):
    rel_pairs=[]
    chunks = []

    for rel in results[0][rel_col]:
        rel_pairs.append((
            rel.metadata['sentence'],
            rel.metadata['entity1_begin'],
            rel.metadata['entity1_end'],
            rel.metadata['chunk1'],
            rel.metadata['entity1'],
            rel.metadata['entity2_begin'],
            rel.metadata['entity2_end'],
            rel.metadata['chunk2'],
            rel.metadata['entity2'],
            rel.result,
            rel.metadata['confidence'],
        ))

    for chunk in results[0][chunk_col]:
        chunks.append((
            chunk.begin,
            chunk.end,
            chunk.result,
        ))

    rel_df = pd.DataFrame(rel_pairs, columns=['sentence', 'entity1_begin', 'entity1_end', 'chunk1', 'entity1', 'entity2_begin', 'entity2_end', 'chunk2', 'entity2', 'relation', 'confidence'])

    chunks_df = pd.DataFrame(chunks, columns = [ "begin", "end", "chunk"])
    chunks_df.begin = chunks_df.begin.astype(str)
    chunks_df.end = chunks_df.end.astype(str)

    result_df = pd.merge(rel_df, chunks_df, left_on=["entity1_begin", "entity1_end", "chunk1"], right_on=["begin", "end", "chunk"])[list(rel_df.columns)]

    if filter_O:
        return result_df[result_df['relation'] != 'O'].reset_index(drop=True)
    else:
        return result_df

# %% [markdown]
# ### `setMaxSyntacticDistance`
# This parameter is used for setting the maximal syntactic distance, as threshold.

# %% [markdown]
# **Build pipeline using SparNLP pretrained models and the relation extration model**.
#
#  The precision of the RE model is controlled by "setMaxSyntacticDistance(4)", which sets the maximum syntactic distance between named entities to 4. A larger value will improve recall at the expense at lower precision. A value of 4 leads to literally perfect precision (i.e. the model doesn't produce any false positives) and reasonably good recall.

# %% [markdown]
# In our example pipeline,  we will use `posology_re` pretrained Relation Extraction model for posology.

# %%
documenter = nlp.DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")

sentencer = nlp.SentenceDetector()\
    .setInputCols(["document"])\
    .setOutputCol("sentences")

tokenizer = nlp.Tokenizer()\
    .setInputCols(["sentences"])\
    .setOutputCol("tokens")

words_embedder = nlp.WordEmbeddingsModel()\
    .pretrained("embeddings_clinical", "en", "clinical/models")\
    .setInputCols(["sentences", "tokens"])\
    .setOutputCol("embeddings")

pos_tagger = nlp.PerceptronModel()\
    .pretrained("pos_clinical", "en", "clinical/models") \
    .setInputCols(["sentences", "tokens"])\
    .setOutputCol("pos_tags")

ner_tagger = medical.NerModel()\
    .pretrained("ner_posology", "en", "clinical/models")\
    .setInputCols("sentences", "tokens", "embeddings")\
    .setOutputCol("ner_tags")

ner_chunker = medical.NerConverterInternal()\
    .setInputCols(["sentences", "tokens", "ner_tags"])\
    .setOutputCol("ner_chunks")

dependency_parser = nlp.DependencyParserModel()\
    .pretrained("dependency_conllu", "en")\
    .setInputCols(["sentences", "pos_tags", "tokens"])\
    .setOutputCol("dependencies")

reModel = medical.RelationExtractionModel()\
    .pretrained("posology_re", "en", "clinical/models")\
    .setInputCols(["embeddings", "pos_tags", "ner_chunks", "dependencies"])\
    .setOutputCol("relations")\
    .setMaxSyntacticDistance(4)\

pipeline = nlp.Pipeline(stages=[
    documenter,
    sentencer,
    tokenizer,
    words_embedder,
    pos_tagger,
    ner_tagger,
    ner_chunker,
    dependency_parser,
    reModel
])

empty_data = spark.createDataFrame([[""]]).toDF("text")

model = pipeline.fit(empty_data)
# Out:
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# pos_clinical download started this may take some time.
# Approximate size to download 1.5 MB
# [OK!]
# ner_posology download started this may take some time.
# [OK!]
# dependency_conllu download started this may take some time.
# Approximate size to download 16.7 MB
# [OK!]

# %% [markdown]
# **Create a light pipeline for annotating free text**

# %%
text = """
The patient was prescribed 1 unit of Advil for 5 days after meals. The patient was also
given 1 unit of Metformin daily.
He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night ,
12 units of insulin lispro with meals , and metformin 1000 mg two times a day.
"""

lmodel = nlp.LightPipeline(model)

results = lmodel.fullAnnotate(text)

# %%
results[0].keys()
# Out:
# dict_keys(['sentences', 'document', 'ner_chunks', 'ner_tags', 'relations', 'tokens', 'embeddings', 'pos_tags', 'dependencies'])

# %%
results[0]['ner_chunks']
# Out:
# [Annotation(chunk, 28, 33, 1 unit, {'chunk': '0', 'confidence': '0.71675', 'ner_source': 'ner_chunks', 'entity': 'DOSAGE', 'sentence': '0'}, []),
#  Annotation(chunk, 38, 42, Advil, {'chunk': '1', 'confidence': '0.9984', 'ner_source': 'ner_chunks', 'entity': 'DRUG', 'sentence': '0'}, []),
#  Annotation(chunk, 44, 53, for 5 days, {'chunk': '2', 'confidence': '0.7455', 'ner_source': 'ner_chunks', 'entity': 'DURATION', 'sentence': '0'}, []),
#  Annotation(chunk, 95, 100, 1 unit, {'chunk': '3', 'confidence': '0.72360003', 'ner_source': 'ner_chunks', 'entity': 'DOSAGE', 'sentence': '1'}, []),
#  Annotation(chunk, 105, 113, Metformin, {'chunk': '4', 'confidence': '0.9998', 'ner_source': 'ner_chunks', 'entity': 'DRUG', 'sentence': '1'}, []),
#  Annotation(chunk, 115, 119, daily, {'chunk': '5', 'confidence': '0.9997', 'ner_source': 'ner_chunks', 'entity': 'FREQUENCY', 'sentence': '1'}, []),
#  Annotation(chunk, 189, 196, 40 units, {'chunk': '6', 'confidence': '0.84085', 'ner_source': 'ner_chunks', 'entity': 'DOSAGE', 'sentence': '2'}, []),
#  Annotation(chunk, 201, 216, insulin glargine, {'chunk': '7', 'confidence': '0.87525', 'ner_source': 'ner_chunks', 'entity': 'DRUG', 'sentence': '2'}, []),
#  Annotation(chunk, 218, 225, at night, {'chunk': '8', 'confidence': '0.76839995', 'ner_source': 'ner_chunks', 'entity': 'FREQUENCY', 'sentence': '2'}, []),
#  Annotation(chunk, 229, 236, 12 units, {'chunk': '9', 'confidence': '0.88755', 'ner_source': 'ner_chunks', 'entity': 'DOSAGE', 'sentence': '2'}, []),
#  Annotation(chunk, 241, 254, insulin lispro, {'chunk': '10', 'confidence': '0.77805', 'ner_source': 'ner_chunks', 'entity': 'DRUG', 'sentence': '2'}, []),
#  Annotation(chunk, 256, 265, with meals, {'chunk': '11', 'confidence': '0.9213', 'ner_source': 'ner_chunks', 'entity': 'FREQUENCY', 'sentence': '2'}, []),
#  Annotation(chunk, 273, 281, metformin, {'chunk': '12', 'confidence': '0.9997', 'ner_source': 'ner_chunks', 'entity': 'DRUG', 'sentence': '2'}, []),
#  Annotation(chunk, 283, 289, 1000 mg, {'chunk': '13', 'confidence': '0.84535', 'ner_source': 'ner_chunks', 'entity': 'STRENGTH', 'sentence': '2'}, []),
#  Annotation(chunk, 291, 305, two times a day, {'chunk': '14', 'confidence': '0.806225', 'ner_source': 'ner_chunks', 'entity': 'FREQUENCY', 'sentence': '2'}, [])]

# %%
results[0]['relations']
# Out:
# [Annotation(category, 28, 42, DOSAGE-DRUG, {'chunk2': 'Advil', 'confidence': '1.0', 'entity2_end': '42', 'chunk1': '1 unit', 'entity1': 'DOSAGE', 'entity2_begin': '38', 'chunk2_confidence': '0.9984', 'entity1_begin': '28', 'sentence': '0', 'direction': 'both', 'entity1_end': '33', 'entity2': 'DRUG', 'chunk1_confidence': '0.71675'}, []),
#  Annotation(category, 38, 53, DRUG-DURATION, {'chunk2': 'for 5 days', 'confidence': '1.0', 'entity2_end': '53', 'chunk1': 'Advil', 'entity1': 'DRUG', 'entity2_begin': '44', 'chunk2_confidence': '0.7455', 'entity1_begin': '38', 'sentence': '0', 'direction': 'both', 'entity1_end': '42', 'entity2': 'DURATION', 'chunk1_confidence': '0.9984'}, []),
#  Annotation(category, 95, 113, DOSAGE-DRUG, {'chunk2': 'Metformin', 'confidence': '1.0', 'entity2_end': '113', 'chunk1': '1 unit', 'entity1': 'DOSAGE', 'entity2_begin': '105', 'chunk2_confidence': '0.9998', 'entity1_begin': '95', 'sentence': '1', 'direction': 'both', 'entity1_end': '100', 'entity2': 'DRUG', 'chunk1_confidence': '0.72360003'}, []),
#  Annotation(category, 105, 119, DRUG-FREQUENCY, {'chunk2': 'daily', 'confidence': '1.0', 'entity2_end': '119', 'chunk1': 'Metformin', 'entity1': 'DRUG', 'entity2_begin': '115', 'chunk2_confidence': '0.9997', 'entity1_begin': '105', 'sentence': '1', 'direction': 'both', 'entity1_end': '113', 'entity2': 'FREQUENCY', 'chunk1_confidence': '0.9998'}, []),
#  Annotation(category, 189, 216, DOSAGE-DRUG, {'chunk2': 'insulin glargine', 'confidence': '1.0', 'entity2_end': '216', 'chunk1': '40 units', 'entity1': 'DOSAGE', 'entity2_begin': '201', 'chunk2_confidence': '0.87525', 'entity1_begin': '189', 'sentence': '2', 'direction': 'both', 'entity1_end': '196', 'entity2': 'DRUG', 'chunk1_confidence': '0.84085'}, []),
#  Annotation(category, 201, 225, DRUG-FREQUENCY, {'chunk2': 'at night', 'confidence': '1.0', 'entity2_end': '225', 'chunk1': 'insulin glargine', 'entity1': 'DRUG', 'entity2_begin': '218', 'chunk2_confidence': '0.76839995', 'entity1_begin': '201', 'sentence': '2', 'direction': 'both', 'entity1_end': '216', 'entity2': 'FREQUENCY', 'chunk1_confidence': '0.87525'}, []),
#  Annotation(category, 229, 254, DOSAGE-DRUG, {'chunk2': 'insulin lispro', 'confidence': '1.0', 'entity2_end': '254', 'chunk1': '12 units', 'entity1': 'DOSAGE', 'entity2_begin': '241', 'chunk2_confidence': '0.77805', 'entity1_begin': '229', 'sentence': '2', 'direction': 'both', 'entity1_end': '236', 'entity2': 'DRUG', 'chunk1_confidence': '0.88755'}, []),
#  Annotation(category, 241, 265, DRUG-FREQUENCY, {'chunk2': 'with meals', 'confidence': '1.0', 'entity2_end': '265', 'chunk1': 'insulin lispro', 'entity1': 'DRUG', 'entity2_begin': '256', 'chunk2_confidence': '0.9213', 'entity1_begin': '241', 'sentence': '2', 'direction': 'both', 'entity1_end': '254', 'entity2': 'FREQUENCY', 'chunk1_confidence': '0.77805'}, []),
#  Annotation(category, 273, 289, DRUG-STRENGTH, {'chunk2': '1000 mg', 'confidence': '1.0', 'entity2_end': '289', 'chunk1': 'metformin', 'entity1': 'DRUG', 'entity2_begin': '283', 'chunk2_confidence': '0.84535', 'entity1_begin': '273', 'sentence': '2', 'direction': 'both', 'entity1_end': '281', 'entity2': 'STRENGTH', 'chunk1_confidence': '0.9997'}, []),
#  Annotation(category, 273, 305, DRUG-FREQUENCY, {'chunk2': 'two times a day', 'confidence': '1.0', 'entity2_end': '305', 'chunk1': 'metformin', 'entity1': 'DRUG', 'entity2_begin': '291', 'chunk2_confidence': '0.806225', 'entity1_begin': '273', 'sentence': '2', 'direction': 'both', 'entity1_end': '281', 'entity2': 'FREQUENCY', 'chunk1_confidence': '0.9997'}, [])]

# %% [markdown]
# **Show extracted relations**

# %%
for rel in results[0]["relations"]:
    print("{}({}={} - {}={})".format(
        rel.result,
        rel.metadata['entity1'],
        rel.metadata['chunk1'],
        rel.metadata['entity2'],
        rel.metadata['chunk2']
    ))
# Out:
# DOSAGE-DRUG(DOSAGE=1 unit - DRUG=Advil)
# DRUG-DURATION(DRUG=Advil - DURATION=for 5 days)
# DOSAGE-DRUG(DOSAGE=1 unit - DRUG=Metformin)
# DRUG-FREQUENCY(DRUG=Metformin - FREQUENCY=daily)
# DOSAGE-DRUG(DOSAGE=40 units - DRUG=insulin glargine)
# DRUG-FREQUENCY(DRUG=insulin glargine - FREQUENCY=at night)
# DOSAGE-DRUG(DOSAGE=12 units - DRUG=insulin lispro)
# DRUG-FREQUENCY(DRUG=insulin lispro - FREQUENCY=with meals)
# DRUG-STRENGTH(DRUG=metformin - STRENGTH=1000 mg)
# DRUG-FREQUENCY(DRUG=metformin - FREQUENCY=two times a day)

# %%
print(text, "\n")

rel_df = get_relations_df (results)
rel_df
# Out:
# The patient was prescribed 1 unit of Advil for 5 days after meals. The patient was also
# given 1 unit of Metformin daily.
# He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night ,
# 12 units of insulin lispro with meals , and metformin 1000 mg two times a day.
#   sentence entity1_begin entity1_end            chunk1 entity1 entity2_begin  \
# 0        0            28          33            1 unit  DOSAGE            38
# 1        0            38          42             Advil    DRUG            44
# 2        1            95         100            1 unit  DOSAGE           105
# 3        1           105         113         Metformin    DRUG           115
# 4        2           189         196          40 units  DOSAGE           201
# 5        2           201         216  insulin glargine    DRUG           218
# 6        2           229         236          12 units  DOSAGE           241
# 7        2           241         254    insulin lispro    DRUG           256
# 8        2           273         281         metformin    DRUG           283
# 9        2           273         281         metformin    DRUG           291
#
#   entity2_end            chunk2    entity2        relation confidence
# 0          42             Advil       DRUG     DOSAGE-DRUG        1.0
# 1          53        for 5 days   DURATION   DRUG-DURATION        1.0
# 2         113         Metformin       DRUG     DOSAGE-DRUG        1.0
# 3         119             daily  FREQUENCY  DRUG-FREQUENCY        1.0
# 4         216  insulin glargine       DRUG     DOSAGE-DRUG        1.0
# 5         225          at night  FREQUENCY  DRUG-FREQUENCY        1.0
# 6         254    insulin lispro       DRUG     DOSAGE-DRUG        1.0
# 7         265        with meals  FREQUENCY  DRUG-FREQUENCY        1.0
# 8         289           1000 mg   STRENGTH   DRUG-STRENGTH        1.0
# 9         305   two times a day  FREQUENCY  DRUG-FREQUENCY        1.0

# %% [markdown]
# **Visualization of Extracted Relations**

# %%
vis = nlp.viz.RelationExtractionVisualizer()
vis.display(results[0], 'relations', show_relations=True) # default show_relations: True
# Out:
# <svg baseProfile="full" height="575" version="1.1" width="1000" xmlns="http://www.w3.org/2000/svg" xmlns:ev="http://www.w3.org/2001/xml-events" xmlns:xlink="http://www.w3.org/1999/xlink"><defs><style type="text/css"><![CDATA[@font-face{
#     font-family: "Lucida";
#     src: url("data:application/x-font-ttf;charset=utf-8;base64,...");
# }
# ]]></style></defs><rect fill="#5C87BE" fill-opacity="0.2" height="25" rx="2" ry="2" stroke="#5C87BE" stroke-width="1" width="62.89999999999999" x="288.9" y="57" /><rect fill="#8B668B" fill-opacity="0.2" height="25" rx="2" ry="2" stroke="#8B668B" stroke-width="1" width="53.199999999999996" x="405.9" y="57" /><rect fill="#BB3127" fill-opacity="0.2" height="25" rx="2" ry="2" stroke="#BB3127" stroke-width="1" width="101.69999999999999" x="493.79999999999995" y="57" /><rect fill="#5C87BE" fill-opacity="0.2" height="25" rx="2" ry="2" stroke="#5C87BE" stroke-width="1" width="62.89999999999999" x="70.19999999999999" y="157" /><rect fill="#8B668B" fill-opacity="0.2" height="25" rx="2" ry="2" stroke="#8B668B" stroke-width="1" width="92.0" x="187.19999999999996" y="157" /><rect fill="#2F67C2" fill-opacity="0.2" height="25" rx="2" ry="2" stroke="#2F67C2" stroke-width="1" width="53.199999999999996" x="313.8999999999999" y="157" /><rect fill="#5C87BE" fill-opacity="0.2" height="25" rx="2" ry="2" stroke="#5C87BE" stroke-width="1" width="82.3" x="716.9" y="257" /><rect fill="#8B668B" fill-opacity="0.2" height="25" rx="2" ry="2" stroke="#8B668B" stroke-width="1" width="159.89999999999998" x="7" y="357" /><rect fill="#2F67C2" fill-opacity="0.2" height="25" rx="2" ry="2" stroke="#2F67C2" stroke-width="1" width="82.3" x="201.59999999999997" y="357" /><rect fill="#5C87BE" fill-opacity="0.2" height="25" rx="2" ry="2" stroke="#5C87BE" stroke-width="1" width="82.3" x="328.29999999999995" y="357" /><rect fill="#8B668B" fill-opacity="0.2" height="25" rx="2" ry="2" stroke="#8B668B" stroke-width="1" width="140.5" x="464.69999999999993" y="357" /><rect fill="#2F67C2" fill-opacity="0.2" height="25" rx="2" ry="2" stroke="#2F67C2" stroke-width="1" width="101.69999999999999" x="639.9" y="357" /><rect fill="#8B668B" fill-opacity="0.2" height="25" rx="2" ry="2" stroke="#8B668B" stroke-width="1" width="92.0" x="829.7999999999998" y="357" /><rect fill="#B04D11" fill-opacity="0.2" height="25" rx="2" ry="2" stroke="#B04D11" stroke-width="1" width="72.6" x="7" y="457" /><rect fill="#2F67C2" fill-opacity="0.2" height="25" rx="2" ry="2" stroke="#2F67C2" stroke-width="1" width="150.2" x="114.3" y="457" /><text fill="#546c74" font-family="Lucida" font-size="16" style="font-weight:100" x="10" y="75">The</text><text fill="#546c74" font-family="Lucida" font-size="16" style="font-weight:100" x="53.8" y="75">patient</text><text fill="#546c74" font-family="Lucida" font-size="16" style="font-weight:100" x="136.39999999999998" y="75">was</text><text fill="#546c74" font-family="Lucida" font-size="16" style="font-weight:100" x="180.2" y="75">prescribed</text><text fill="#546c74" font-family="Lucida" font-size="16" style="font-weight:100" x="291.9" y="75">1 unit</text><text fill="#1f77b7" font-family="Lucida" font-size="12" style="font-weight:lighter" x="300.4772727272727" y="95">DOSAGE</text><text fill="#546c74" font-family="Lucida" font-size="16" style="font-weight:100" x="374.79999999999995" y="75">of</text><text fill="#546c74" font-family="Lucida" font-size="16" style="font-weight:100" x="408.9" y="75">Advil</text><text fill="#1f77b7" font-family="Lucida" font-size="12" style="font-weight:lighter" x="419.6818181818182" y="95">DRUG</text><text fill="#546c74" font-family="Lucida" font-size="16" style="font-weight:100" x="482.09999999999997" y="75" /><text fill="#546c74" font-family="Lucida" font-size="16" style="font-weight:100" x="496.79999999999995" y="75">for 5 days</text><text fill="#1f77b7" font-family="Lucida" font-size="12" style="font-weight:lighter" x="517.7227272727273" y="95">DURATION</text><text fill="#546c74" font-family="Lucida" font-size="16" style="font-weight:100" x="618.5" y="75">after</text><text fill="#546c74" font-family="Lucida" font-size="16" style="font-weight:100" x="681.7" y="75">meals.</text><text fill="#546c74" font-family="Lucida" font-size="16" style="font-weight:100" x="754.6" y="75">The</text><text fill="#546c74" font-family="Lucida" font-size="16 ...

# %% [markdown]
# ### setDirectionSensitive

# %% [markdown]
#  The `directionSensitive` setting determines how entity relations are considered. If set to true, only relations in the form of ENTITY1-ENTITY2 are considered. If set to false, both ENTITY1-ENTITY2 and ENTITY2-ENTITY1 relations are considered.

# %%
reModel = medical.RelationExtractionModel()\
    .pretrained("posology_re", "en", "clinical/models")\
    .setInputCols(["embeddings", "pos_tags", "ner_chunks", "dependencies"])\
    .setOutputCol("relations")\
    .setMaxSyntacticDistance(4)\
    .setDirectionSensitive(True)

pipeline = nlp.Pipeline(stages=[
    documenter,
    sentencer,
    tokenizer,
    words_embedder,
    pos_tagger,
    ner_tagger,
    ner_chunker,
    dependency_parser,
    reModel
])

empty_data = spark.createDataFrame([[""]]).toDF("text")

model = pipeline.fit(empty_data)

# %%
text = """
The patient was prescribed 1 unit of Advil for 5 days after meals. The patient was also
given 1 unit of Metformin daily.
He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night ,
12 units of insulin lispro with meals , and metformin 1000 mg two times a day.
"""

lmodel = nlp.LightPipeline(model)

results = lmodel.fullAnnotate(text)

# %%
print(text, "\n")

rel_df = get_relations_df (results)
rel_df
# Out:
# The patient was prescribed 1 unit of Advil for 5 days after meals. The patient was also
# given 1 unit of Metformin daily.
# He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night ,
# 12 units of insulin lispro with meals , and metformin 1000 mg two times a day.
#   sentence entity1_begin entity1_end            chunk1 entity1 entity2_begin  \
# 0        0            38          42             Advil    DRUG            44
# 1        1           105         113         Metformin    DRUG           115
# 2        2           201         216  insulin glargine    DRUG           218
# 3        2           241         254    insulin lispro    DRUG           256
# 4        2           273         281         metformin    DRUG           283
# 5        2           273         281         metformin    DRUG           291
#
#   entity2_end           chunk2    entity2        relation confidence
# 0          53       for 5 days   DURATION   DRUG-DURATION        1.0
# 1         119            daily  FREQUENCY  DRUG-FREQUENCY        1.0
# 2         225         at night  FREQUENCY  DRUG-FREQUENCY        1.0
# 3         265       with meals  FREQUENCY  DRUG-FREQUENCY        1.0
# 4         289          1000 mg   STRENGTH   DRUG-STRENGTH        1.0
# 5         305  two times a day  FREQUENCY  DRUG-FREQUENCY        1.0

# %% [markdown]
# As shown above, setting `setDirectionSensitive` results only relations in the form of ENTITY1-ENTITY2 are considered.

# %% [markdown]
# ### `setFilterByTokenDistance`

# %% [markdown]
#  The `filterByTokenDistance` setting is a criterion for filtering based on the number of tokens between entities. The model only identifies relations where the entities are separated by fewer than the specified number of tokens.

# %%
reModel = medical.RelationExtractionModel()\
    .pretrained("posology_re", "en", "clinical/models")\
    .setInputCols(["embeddings", "pos_tags", "ner_chunks", "dependencies"])\
    .setOutputCol("relations")\
    .setMaxSyntacticDistance(4)\
    .setFilterByTokenDistance(1)

pipeline = nlp.Pipeline(stages=[
    documenter,
    sentencer,
    tokenizer,
    words_embedder,
    pos_tagger,
    ner_tagger,
    ner_chunker,
    dependency_parser,
    reModel
])

empty_data = spark.createDataFrame([[""]]).toDF("text")

model = pipeline.fit(empty_data)

# %%
text = """
The patient was prescribed 1 unit of Advil for 5 days after meals. The patient was also
given 1 unit of Metformin daily.
He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night ,
12 units of insulin lispro with meals , and metformin 1000 mg two times a day.
"""

lmodel = nlp.LightPipeline(model)

results = lmodel.fullAnnotate(text)

# %%
print(text, "\n")

rel_df = get_relations_df (results)
rel_df
# Out:
# The patient was prescribed 1 unit of Advil for 5 days after meals. The patient was also
# given 1 unit of Metformin daily.
# He was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night ,
# 12 units of insulin lispro with meals , and metformin 1000 mg two times a day.
#   sentence entity1_begin entity1_end            chunk1 entity1 entity2_begin  \
# 0        0            28          33            1 unit  DOSAGE            38
# 1        0            38          42             Advil    DRUG            44
# 2        1            95         100            1 unit  DOSAGE           105
# 3        1           105         113         Metformin    DRUG           115
# 4        2           189         196          40 units  DOSAGE           201
# 5        2           201         216  insulin glargine    DRUG           218
# 6        2           229         236          12 units  DOSAGE           241
# 7        2           241         254    insulin lispro    DRUG           256
# 8        2           273         281         metformin    DRUG           283
#
#   entity2_end            chunk2    entity2        relation confidence
# 0          42             Advil       DRUG     DOSAGE-DRUG        1.0
# 1          53        for 5 days   DURATION   DRUG-DURATION        1.0
# 2         113         Metformin       DRUG     DOSAGE-DRUG        1.0
# 3         119             daily  FREQUENCY  DRUG-FREQUENCY        1.0
# 4         216  insulin glargine       DRUG     DOSAGE-DRUG        1.0
# 5         225          at night  FREQUENCY  DRUG-FREQUENCY        1.0
# 6         254    insulin lispro       DRUG     DOSAGE-DRUG        1.0
# 7         265        with meals  FREQUENCY  DRUG-FREQUENCY        1.0
# 8         289           1000 mg   STRENGTH   DRUG-STRENGTH        1.0

# %% [markdown]
# As shown above, setting setFilterByTokenDistance displays only tokens with a distance of 1.

# %% [markdown]
# ### `setRelationPairs`
# This parameter is used for setting the list of dash-separated pairs of named entities. For example, [“Biomarker-RelativeDay”] will process all relations between entities of type “Biomarker” and “RelativeDay”.

# %% [markdown]
# Now we will first use `ner_ade_clinical` NER model and detect `DRUG` and `ADE` entities. Then we can find the relations between them by using `re_ade_clinical` Relation Extraction model. We can also use the same pipeline elements rest of them we created above.

# %%
ner_tagger = medical.NerModel.pretrained("ner_ade_clinical", "en", "clinical/models")\
    .setInputCols("sentences", "tokens", "embeddings")\
    .setOutputCol("ner_tags")

pos_tagger = nlp.PerceptronModel()\
    .pretrained("pos_clinical", "en", "clinical/models") \
    .setInputCols(["sentences", "tokens"])\
    .setOutputCol("pos_tags")

ner_chunker = medical.NerConverterInternal()\
    .setInputCols(["sentences", "tokens", "ner_tags"])\
    .setOutputCol("ner_chunks")

dependency_parser = nlp.DependencyParserModel()\
    .pretrained("dependency_conllu", "en")\
    .setInputCols(["sentences", "pos_tags", "tokens"])\
    .setOutputCol("dependencies")

reModel = medical.RelationExtractionModel()\
    .pretrained("re_ade_clinical", "en", 'clinical/models')\
    .setInputCols(["embeddings", "pos_tags", "ner_chunks", "dependencies"])\
    .setOutputCol("relations")\
    .setMaxSyntacticDistance(10)\
    .setRelationPairs(["drug-ade, ade-drug"])

ade_pipeline = nlp.Pipeline(stages=[
    documenter,
    sentencer,
    tokenizer,
    words_embedder,
    pos_tagger,
    ner_tagger,
    ner_chunker,
    dependency_parser,
    reModel
])

empty_data = spark.createDataFrame([[""]]).toDF("text")

ade_model = ade_pipeline.fit(empty_data)
# Out:
# ner_ade_clinical download started this may take some time.
# [OK!]
# pos_clinical download started this may take some time.
# Approximate size to download 1.5 MB
# [OK!]
# dependency_conllu download started this may take some time.
# Approximate size to download 16.7 MB
# [OK!]
# re_ade_clinical download started this may take some time.
# [OK!]

# %% [markdown]
# Show the classes

# %%
reModel.getClasses()
# Out:
# ['0', '1']

# %% [markdown]
# We will create a LightPipeline for annotation.

# %%
ade_lmodel = nlp.LightPipeline(ade_model)

# %%
text = "I experienced fatigue, muscle cramps, anxiety, agression and sadness after taking Lipitor but no more adverse after passing Zocor."

ade_results = ade_lmodel.fullAnnotate(text)

# %%
ade_results[0].keys()
# Out:
# dict_keys(['sentences', 'document', 'ner_chunks', 'ner_tags', 'relations', 'tokens', 'embeddings', 'pos_tags', 'dependencies'])

# %%
for rel in ade_results[0]["relations"]:
    print("{}({}={} - {}={})".format(
        rel.result,
        rel.metadata['entity1'],
        rel.metadata['chunk1'],
        rel.metadata['entity2'],
        rel.metadata['chunk2']
    ))
# Out:
# 1(ADE=fatigue - DRUG=Lipitor)
# 0(ADE=fatigue - DRUG=Zocor)
# 1(ADE=muscle cramps - DRUG=Lipitor)
# 0(ADE=muscle cramps - DRUG=Zocor)
# 1(ADE=anxiety - DRUG=Lipitor)
# 0(ADE=anxiety - DRUG=Zocor)
# 1(ADE=agression - DRUG=Lipitor)
# 0(ADE=agression - DRUG=Zocor)
# 1(ADE=sadness - DRUG=Lipitor)
# 0(ADE=sadness - DRUG=Zocor)

# %% [markdown]
# **Lets show the ADE-DRUG relations by using pandas dataframe.**

# %%
ade_results
# Out:
# [{'sentences': [Annotation(document, 0, 129, I experienced fatigue, muscle cramps, anxiety, agression and sadness after taking Lipitor but no more adverse after passing Zocor., {'sentence': '0'}, [])],
#   'document': [Annotation(document, 0, 129, I experienced fatigue, muscle cramps, anxiety, agression and sadness after taking Lipitor but no more adverse after passing Zocor., {}, [])],
#   'ner_chunks': [Annotation(chunk, 14, 20, fatigue, {'chunk': '0', 'confidence': '0.8692', 'ner_source': 'ner_chunks', 'entity': 'ADE', 'sentence': '0'}, []),
#    Annotation(chunk, 23, 35, muscle cramps, {'chunk': '1', 'confidence': '0.9433', 'ner_source': 'ner_chunks', 'entity': 'ADE', 'sentence': '0'}, []),
#    Annotation(chunk, 38, 44, anxiety, {'chunk': '2', 'confidence': '0.9881', 'ner_source': 'ner_chunks', 'entity': 'ADE', 'sentence': '0'}, []),
#    Annotation(chunk, 47, 55, agression, {'chunk': '3', 'confidence': '0.9664', 'ner_source': 'ner_chunks', 'entity': 'ADE', 'sentence': '0'}, []),
#    Annotation(chunk, 61, 67, sadness, {'chunk': '4', 'confidence': '0.9415', 'ner_source': 'ner_chunks', 'entity': 'ADE', 'sentence': '0'}, []),
#    Annotation(chunk, 82, 88, Lipitor, {'chunk': '5', 'confidence': '0.9945', 'ner_source': 'ner_chunks', 'entity': 'DRUG', 'sentence': '0'}, []),
#    Annotation(chunk, 124, 128, Zocor, {'chunk': '6', 'confidence': '0.9271', 'ner_source': 'ner_chunks', 'entity': 'DRUG', 'sentence': '0'}, [])],
#   'ner_tags': [Annotation(named_entity, 0, 0, O, {'word': 'I', 'confidence': '0.993', 'sentence': '0'}, []),
#    Annotation(named_entity, 2, 12, O, {'word': 'experienced', 'confidence': '0.8684', 'sentence': '0'}, []),
#    Annotation(named_entity, 14, 20, B-ADE, {'word': 'fatigue', 'confidence': '0.8692', 'sentence': '0'}, []),
#    Annotation(named_entity, 21, 21, O, {'word': ',', 'confidence': '0.9995', 'sentence': '0'}, []),
#    Annotation(named_entity, 23, 28, B-ADE, {'word': 'muscle', 'confidence': '0.9381', 'sentence': '0'}, []),
#    Annotation(named_entity, 30, 35, I-ADE, {'word': 'cramps', 'confidence': '0.9485', 'sentence': '0'}, []),
#    Annotation(named_entity, 36, 36, O, {'word': ',', 'confidence': '0.9992', 'sentence': '0'}, []),
#    Annotation(named_entity, 38, 44, B-ADE, {'word': 'anxiety', 'confidence': '0.9881', 'sentence': '0'}, []),
#    Annotation(named_entity, 45, 45, O, {'word': ',', 'confidence': '0.9985', 'sentence': '0'}, []),
#    Annotation(named_entity, 47, 55, B-ADE, {'word': 'agression', 'confidence': '0.9664', 'sentence': '0'}, []),
#    Annotation(named_entity, 57, 59, O, {'word': 'and', 'confidence': '0.9965', 'sentence': '0'}, []),
#    Annotation(named_entity, 61, 67, B-ADE, {'word': 'sadness', 'confidence': '0.9415', 'sentence': '0'}, []),
#    Annotation(named_entity, 69, 73, O, {'word': 'after', 'confidence': '0.9985', 'sentence': '0'}, []),
#    Annotation(named_entity, 75, 80, O, {'word': 'taking', 'confidence': '0.9803', 'sentence': '0'}, []),
#    Annotation(named_entity, 82, 88, B-DRUG, {'word': 'Lipitor', 'confidence': '0.9945', 'sentence': '0'}, []),
#    Annotation(named_entity, 90, 92, O, {'word': 'but', 'confidence': '0.9994', 'sentence': '0'}, []),
#    Annotation(named_entity, 94, 95, O, {'word': 'no', 'confidence': '0.992', 'sentence': '0'}, []),
#    Annotation(named_entity, 97, 100, O, {'word': 'more', 'confidence': '0.9581', 'sentence': '0'}, []),
#    Annotation(named_entity, 102, 108, O, {'word': 'adverse', 'confidence': '0.5069', 'sentence': '0'}, []),
#    Annotation(named_entity, 110, 114, O, {'word': 'after', 'confidence': '0.9992', 'sentence': '0'}, []),
#    Annotation(named_entity, 116, 122, O, {'word': 'passing', 'confidence': '0.9075', 'sentence': '0'}, []),
#    Annotation(named_entity, 124, 128, B-DRUG, {'word': 'Zocor', 'confidence': '0.9271', 'sentence': '0'}, []),
#    Annotation(named_entity, 129, 129, O, {'word': '.', 'confidence': '0.9999', 'sentence': '0'}, [])],
#   'relations': [Annotation(category, 14, 88, 1, {'chunk2': 'Lipitor', 'confidence': '0.9998622', 'entity2_end': '88', 'chunk1': 'fatigue', 'entity1': 'ADE', 'entity2_begin': '82', 'chunk2_confidence': '0.9945', 'entity1_begin': '14', 'sentence': '0', 'direction': 'both', 'entity1_end': '20', 'entity2': 'DRUG', 'chunk1_confidence': '0.8692'}, []),
#    Annotation(category, 14, 128, 0, {'chunk2': 'Zocor', 'confidence': '0.99888533', 'entity2_end': '128', 'chunk1': 'fatigue', 'entity1': 'ADE', 'entity2_begin': '124', 'chunk2_confidence': '0.9271', 'entity1_begin': '14', 'sentence': '0', 'direction': 'both', 'entity1_end': '20', 'entity2': 'DRUG', 'chunk1_confidence': '0.8692'}, []),
#    Annotation(category, 23, 88, 1, {'chunk2': 'Lipitor', 'confidence': '0.99999154', 'entity2_end': '88', 'chunk1': 'muscle cramps', 'entity1': 'ADE', 'entity2_begin': '82', 'chunk2_confidence': '0.9945', 'entity1_begin': '23', 'sentence': '0', 'direction': 'both', 'entity1_end': '35', 'entity2': 'DRUG', 'chunk1_confidence': '0.9433'}, []),
#    Annotation(category, 23, 128, 0, {'chunk2': 'Zocor', 'confidence': '0.9780189', 'entity2_end': '128', 'chunk1': 'muscle cramps', 'entity1': 'ADE', 'entity2_begin': '124', 'chunk2_confidence': '0.9271', 'entity1_begin': '23', 'sentence': '0', 'direction': 'both', 'entity1_end': '35', 'entity2': 'DRUG', 'chunk1_confidence': '0.9433'}, []),
#    Annotation(category, 38, 88, 1, {'chunk2': 'Lipitor', 'confidence': '0.86541504', 'entity2_end': '88', 'chunk1': 'anxiety', 'entity1': 'ADE', 'entity2_begin': '82', 'chunk2_confidence': '0.9945', 'entity1_begin': '38', 'sentence': '0', 'direction': 'both', 'entity1_end': '44', 'entity2': 'DRUG', 'chunk1_confidence': '0.9881'}, []),
#    Annotation(category, 38, 128, 0, {'chunk2': 'Zocor', 'confidence': '0.99998915', 'entity2_end': '128', 'chunk1': 'anxiety', 'entity1': 'ADE', 'entity2_begin': '124', 'chunk2_confidence': '0.9271', 'entity1_begin': '38', 'sentence': '0', 'direction': 'both', 'entity1_end': '44', 'entity2': 'DRUG', 'chunk1_confidence': '0.9881'}, []),
#    Annotation(category, 47, 88, 1, {'chunk2': 'Lipitor', 'confidence': '0.99999785', 'entity2_end': '88', 'chunk1': 'agression', 'entity1': 'ADE', 'entity2_begin': '82', 'chunk2_confidence': '0.9945', 'entity1_begin': '47', 'sentence': '0', 'direction': 'both', 'entity1_end': '55', 'entity2': 'DRUG', 'chunk1_confidence': '0.9664'}, []),
#    Annotation(category, 47, 128, 0, {'chunk2': 'Zocor', 'confidence': '0.999469', 'entity2_end': '128', 'chunk1': 'agression', 'entity1': 'ADE', 'entity2_begin': '124', 'chunk2_confidence': '0.9271', 'entity1_begin': '47', 'sentence': '0', 'direction': 'both', 'entity1_end': '55', 'entity2': 'DRUG', 'chunk1_confidence': '0.9664'}, []),
#    Annotation(category, 61, 88, 1, {'chunk2': 'Lipitor', 'confidence': '1.0', 'entity2_end': '88', 'chunk1': 'sadness', 'entity1': 'ADE', 'entity2_begin': '82', 'chunk2_confidence': '0.9945', 'entity1_begin': '61', 'sentence': '0', 'direction': 'both', 'entity1_end': '67', 'entity2': 'DRUG', 'chunk1_confidence': '0.9415'}, []),
#    Annotation(category, 61, 128, 0, {'chunk2': 'Zocor', 'confidence': '0.99980325', 'entity2_end': '128', 'chunk1': 'sadness', 'entity1': 'ADE', 'entity2_begin': '124', 'chunk2_confidence': '0.9271', 'entity1_begin': '61', 'sentence': '0', 'direction': 'both', 'entity1_end': '67', 'entity2': 'DRUG', 'chunk1_confidence': '0.9415'}, [])],
#   'tokens': [Annotation(token, 0, 0, I, {'sentence': '0'}, []),
#    Annotation(token, 2, 12, experienced, {'sentence': '0'}, []),
#    Annotation(token, 14, 20, fatigue, {'sentence': '0'}, []),
#    Annotation(token, 21, 21, ,, {'sentence': '0'}, []),
#    Annotation(token, 23, 28, muscle, {'sentence': '0'}, []),
#    Annotation(token, 30, 35, cramps, {'sentence': '0'}, []),
#    Annotation(token, 36, 36, ,, {'sentence': '0'}, []),
#    Annotation(token, 38, 44, anxiety, {'sentence': '0'}, []),
#    Annotation(token, 45, 45, ,, {'sentence': '0'}, []),
#    Annotation(token, 47, 55, agression, {'sentence': '0'}, []),
#    Annotation(token, 57, 59, and, {'sentence': '0'}, []),
#    Annotation(token, 61, 67, sadness, {'sentence': '0'}, []),
#    Annotation(token, 69, 73, after, {'sentence': '0'}, []),
#    Annotation(token, 75, 80, taking, {'sentence': '0'}, []),
#    Annotation(token, 82, 88, Lipitor, {'sentence': '0'}, []),
#    Annotation(token, 90, 92, but, {'sentence': '0'}, []),
#    Annotation(token, 94, 95, no, {'sentence': '0'}, []),
#    Annotation(token, 97, 100, more, {'sentence': '0'}, []),
#    Annotation(token, 102, 108, adverse, {'sentence': '0'}, []),
#    Annotation(token, 110, 114, after, {'sentence': '0'}, []),
#    Annotation(token, 116, 122, passing, {'sentence': '0'}, []),
#    Annotation(token, 124, 128, Zocor, {'sentence': '0'}, []),
#    Annotation(token, 129, 129, ., {'sentence': '0'}, [])],
#   'embeddings': [Annotation(word_embeddings, 0, 0, I, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'I', 'sentence': '0'}, []),
#    Annotation(word_embeddings, 2, 12, experienced, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'experienced', 'sentence': '0'}, []),
#    Annotation(word_embeddings, 14, 20, fatigue, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'fatigue', 'sentence': '0'}, []),
#    Annotation(word_embeddings, 21, 21, ,, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': ',', 'sentence': '0'}, []),
#    Annotation(word_embeddings, 23, 28, muscle, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'muscle', 'sentence': '0'}, []),
#    Annotation(word_embeddings, 30, 35, cramps, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'cramps', 'sentence': '0'}, []),
#    Annotation(word_embeddings, 36, 36, ,, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': ',', 'sentence': '0'}, []),
#    Annotation(word_embeddings, 38, 44, anxiety, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'anxiety', 'sentence': '0'}, []),
#    Annotation(word_embeddings, 45, 45, ,, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': ',', 'sentence': '0'}, []),
#    Annotation(word_embeddings, 47, 55, agression, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'agression', 'sentence': '0'}, []),
#    Annotation(word_embeddings, 57, 59, and, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'and', 'sentence': '0'}, []),
#    Annotation(word_embeddings, 61, 67, sadness, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'sadness', 'sentence': '0'}, []),
#    Annotation(word_embeddings, 69, 73, after, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'after', 'sentence': '0'}, []),
#    Annotation(word_embeddings, 75, 80, taking, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'taking', 'sentence': '0'}, []),
#    Annotation(word_embeddings, 82, 88, Lipitor, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'Lipitor', 'sentence': '0'}, []),
#    Annotation(word_embeddings, 90, 92, but, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'but', 'sentence': '0'}, []),
#    Annotation(word_embeddings, 94, 95, no, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'no', 'sentence': '0'}, []),
#    Annotation(word_embeddings, 97, 100, more, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'more', 'sentence': '0'}, []),
#    Annotation(word_embeddings, 102, 108, adverse, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'adverse', 'sentence': '0'}, []),
#    Annotation(word_embeddings, 110, 114, after, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'after', 'sentence': '0'}, []),
#    Annotation(word_embeddings, 116, 122, passing, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'passing', 'sentence': '0'}, []),
#    Annotation(word_embeddings, 124, 128, Zocor, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'Zocor', 'sentence': '0'}, []),
#    Annotation(word_embeddings, 129, 129, ., {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': '.', 'sentence': '0'}, [])],
#   'pos_tags': [Annotation(pos, 0, 0, MC, {'word': 'I', 'sentence': '0'}, []),
#    Annotation(pos, 2, 12, VVNJ, {'word': 'experienced', 'sentence': '0'}, []),
#    Annotation(pos, 14, 20, NN, {'word': 'fatigue', 'sentence': '0'}, []),
#    Annotation(pos, 21, 21, NN, {'word': ',', 'sentence': '0'}, []),
#    Annotation(pos, 23, 28, NN, {'word': 'muscle', 'sentence': '0'}, []),
#    Annotation(pos, 30, 35, NN, {'word': 'cramps', 'sentence': '0'}, []),
#    Annotation(pos, 36, 36, NN, {'word': ',', 'sentence': '0'}, []),
#    Annotation(pos, 38, 44, NN, {'word': 'anxiety', 'sentence': '0'}, []),
#    Annotation(pos, 45, 45, NN, {'word': ',', 'sentence': '0'}, []),
#    Annotation(pos, 47, 55, NN, {'word': 'agression', 'sentence': '0'}, []),
#    Annotation(pos, 57, 59, CC, {'word': 'and', 'sentence': '0'}, []),
#    Annotation(pos, 61, 67, NN, {'word': 'sadness', 'sentence': '0'}, []),
#    Annotation(pos, 69, 73, II, {'word': 'after', 'sentence': '0'}, []),
#    Annotation(pos, 75, 80, VVGN, {'word': 'taking', 'sentence': '0'}, []),
#    Annotation(pos, 82, 88, NN, {'word': 'Lipitor', 'sentence': '0'}, []),
#    Annotation(pos, 90, 92, CC, {'word': 'but', 'sentence': '0'}, []),
#    Annotation(pos, 94, 95, DD, {'word': 'no', 'sentence': '0'}, []),
#    Annotation(pos, 97, 100, RR, {'word': 'more', 'sentence': '0'}, []),
#    Annotation(pos, 102, 108, JJ, {'word': 'adverse', 'sentence': '0'}, []),
#    Annotation(pos, 110, 114, II, {'word': 'after', 'sentence': '0'}, []),
#    Annotation(pos, 116, 122, VVGN, {'word': 'passing', 'sentence': '0'}, []),
#    Annotation(pos, 124, 128, NN, {'word': 'Zocor', 'sentence': '0'}, []),
#    Annotation(pos, 129, 129, NN, {'word': '.', 'sentence': '0'}, [])],
#   'dependencies': [Annotation(dependency, 0, 0, experienced, {'head': '2', 'head.begin': '2', 'head.end': '12', 'sentence': '0'}, []),
#    Annotation(dependency, 2, 12, ROOT, {'head': '0', 'head.begin': '-1', 'head.end': '-1', 'sentence': '0'}, []),
#    Annotation(dependency, 14, 20, experienced, {'head': '2', 'head.begin': '2', 'head.end': '12', 'sentence': '0'}, []),
#    Annotation(dependency, 21, 21, cramps, {'head': '6', 'head.begin': '30', 'head.end': '35', 'sentence': '0'}, []),
#    Annotation(dependency, 23, 28, cramps, {'head': '6', 'head.begin': '30', 'head.end': '35', 'sentence': '0'}, []),
#    Annotation(dependency, 30, 35, fatigue, {'head': '3', 'head.begin': '14', 'head.end': '20', 'sentence': '0'}, []),
#    Annotation(dependency, 36, 36, anxiety, {'head': '8', 'head.begin': '38', 'head.end': '44', 'sentence': '0'}, []),
#    Annotation(dependency, 38, 44, cramps, {'head': '6', 'head.begin': '30', 'head.end': '35', 'sentence': '0'}, []),
#    Annotation(dependency, 45, 45, agression, {'head': '10', 'head.begin': '47', 'head.end': '55', 'sentence': '0'}, []),
#    Annotation(dependency, 47, 55, anxiety, {'head': '8', 'head.begin': '38', 'head.end': '44', 'sentence': '0'}, []),
#    Annotation(dependency, 57, 59, sadness, {'head': '12', 'head.begin': '61', 'head.end': '67', 'sentence': '0'}, []),
#    Annotation(dependency, 61, 67, agression, {'head': '10', 'head.begin': '47', 'head.end': '55', 'sentence': '0'}, []),
#    Annotation(dependency, 69, 73, taking, {'head': '14', 'head.begin': '75', 'head.end': '80', 'sentence': '0'}, []),
#    Annotation(dependency, 75, 80, sadness, {'head': '12', 'head.begin': '61', 'head.end': '67', 'sentence': '0'}, []),
#    Annotation(dependency, 82, 88, taking, {'head': '14', 'head.begin': '75', 'head.end': '80', 'sentence': '0'}, []),
#    Annotation(dependency, 90, 92, adverse, {'head': '19', 'head.begin': '102', 'head.end': '108', 'sentence': '0'}, []),
#    Annotation(dependency, 94, 95, adverse, {'head': '19', 'head.begin': '102', 'head.end': '108', 'sentence': '0'}, []),
#    Annotation(dependency, 97, 100, adverse, {'head': '19', 'head.begin': '102', 'head.end': '108', 'sentence': '0'}, []),
#    Annotation(dependency, 102, 108, Lipitor, {'head': '15', 'head.begin': '82', 'head.end': '88', 'sentence': '0'}, []),
#    Annotation(dependency, 110, 114, Zocor, {'head': '22', 'head.begin': '124', 'head.end': '128', 'sentence': '0'}, []),
#    Annotation(dependency, 116, 122, Zocor, {'head': '22', 'head.begin': '124', 'head.end': '128', 'sentence': '0'}, []),
#    Annotation(dependency, 124, 128, adverse, {'head': '19', 'head.begin': '102', 'head.end': '108', 'sentence': '0'}, []),
#    Annotation(dependency, 129, 129, experienced, {'head': '2', 'head.begin': '2', 'head.end': '12', 'sentence': '0'}, [])]}]

# %%
rel_df = get_relations_df(ade_results)

rel_df
# Out:
#   sentence entity1_begin entity1_end         chunk1 entity1 entity2_begin  \
# 0        0            14          20        fatigue     ADE            82
# 1        0            14          20        fatigue     ADE           124
# 2        0            23          35  muscle cramps     ADE            82
# 3        0            23          35  muscle cramps     ADE           124
# 4        0            38          44        anxiety     ADE            82
# 5        0            38          44        anxiety     ADE           124
# 6        0            47          55      agression     ADE            82
# 7        0            47          55      agression     ADE           124
# 8        0            61          67        sadness     ADE            82
# 9        0            61          67        sadness     ADE           124
#
#   entity2_end   chunk2 entity2 relation  confidence
# 0          88  Lipitor    DRUG        1   0.9998622
# 1         128    Zocor    DRUG        0  0.99888533
# 2          88  Lipitor    DRUG        1  0.99999154
# 3         128    Zocor    DRUG        0   0.9780189
# 4          88  Lipitor    DRUG        1  0.86541504
# 5         128    Zocor    DRUG        0  0.99998915
# 6          88  Lipitor    DRUG        1  0.99999785
# 7         128    Zocor    DRUG        0    0.999469
# 8          88  Lipitor    DRUG        1         1.0
# 9         128    Zocor    DRUG        0  0.99980325

# %% [markdown]
# ### setFeatureScaling
#
# Different feature scaling techniques such as zscore, minmax or empty (no scaling) can be applied. Default is empty.

# %%
reModel = medical.RelationExtractionModel.pretrained("re_ade_clinical", "en", 'clinical/models')\
    .setInputCols(["embeddings", "pos_tags", "ner_chunks", "dependencies"])\
    .setOutputCol("relations")\
    .setMaxSyntacticDistance(10)\
    .setRelationPairs(["drug-ade, ade-drug"])\
    .setFeatureScaling("zscore") # or minmax

ade_pipeline = nlp.Pipeline(stages=[
    documenter,
    sentencer,
    tokenizer,
    words_embedder,
    pos_tagger,
    ner_tagger,
    ner_chunker,
    dependency_parser,
    reModel
])

empty_data = spark.createDataFrame([[""]]).toDF("text")

ade_model = ade_pipeline.fit(empty_data)
# Out:
# re_ade_clinical download started this may take some time.
# [OK!]

# %%
ade_lmodel = nlp.LightPipeline(ade_model)

# %%
text = "I experienced fatigue, muscle cramps, anxiety, agression and sadness after taking Lipitor but no more adverse after passing Zocor."

ade_results = ade_lmodel.fullAnnotate(text)

# %%
rel_df = get_relations_df(ade_results)

rel_df
# Out:
#   sentence entity1_begin entity1_end         chunk1 entity1 entity2_begin  \
# 0        0            14          20        fatigue     ADE            82
# 1        0            14          20        fatigue     ADE           124
# 2        0            23          35  muscle cramps     ADE            82
# 3        0            23          35  muscle cramps     ADE           124
# 4        0            38          44        anxiety     ADE            82
# 5        0            38          44        anxiety     ADE           124
# 6        0            47          55      agression     ADE            82
# 7        0            47          55      agression     ADE           124
# 8        0            61          67        sadness     ADE            82
# 9        0            61          67        sadness     ADE           124
#
#   entity2_end   chunk2 entity2 relation  confidence
# 0          88  Lipitor    DRUG        0   0.9993783
# 1         128    Zocor    DRUG        0  0.98657125
# 2          88  Lipitor    DRUG        0   0.9918811
# 3         128    Zocor    DRUG        0   0.9716513
# 4          88  Lipitor    DRUG        0   0.9890442
# 5         128    Zocor    DRUG        0   0.9999393
# 6          88  Lipitor    DRUG        0  0.85509104
# 7         128    Zocor    DRUG        0   0.9999622
# 8          88  Lipitor    DRUG        1  0.99996483
# 9         128    Zocor    DRUG        1    0.908048

# %% [markdown]
# By changing FeatureScaling, you can observe variations in the confidence scores.

# %% [markdown]
# ### `setRelationPairsCaseSensitive`
# This parameter is set to determine whether relation pairs are case sensitive (Default: False).

# %% [markdown]
# We will use the same `ADE` Relation Extraction pipeline as above with the `setRelationPairsCaseSensitive(True)` and see the difference. <br/>
#
# We have `ADE` and `DRUG` entities coming from the NER model in uppercased. But, we will set `setRelationPairs(["drug-ade, ade-drug"])`lowercased and `setRelationPairsCaseSensitive(True)`. Therefore, we do not expect any relation since case status of the NER entities and the relation pairs do not match.

# %%
ner_tagger = medical.NerModel.pretrained("ner_ade_clinical", "en", "clinical/models")\
    .setInputCols("sentences", "tokens", "embeddings")\
    .setOutputCol("ner_tags")

reModel = medical.RelationExtractionModel()\
    .pretrained("re_ade_clinical", "en", 'clinical/models')\
    .setInputCols(["embeddings", "pos_tags", "ner_chunks", "dependencies"])\
    .setOutputCol("relations")\
    .setMaxSyntacticDistance(10)\
    .setRelationPairs(["drug-ade, ade-drug"])\
    .setRelationPairsCaseSensitive(True)      # it will return only "ade-drug" relationship.
                                              # True, then the pairs of entities in the dataset should match the pairs in setRelationPairs in their specific case (case sensitive).
                                              # False, meaning that the match of those relation names is case insensitive.

ade_pipeline = nlp.Pipeline(stages=[
    documenter,
    sentencer,
    tokenizer,
    words_embedder,
    pos_tagger,
    ner_tagger,
    ner_chunker,
    dependency_parser,
    reModel
])

empty_data = spark.createDataFrame([[""]]).toDF("text")

ade_model = ade_pipeline.fit(empty_data)
# Out:
# ner_ade_clinical download started this may take some time.
# [OK!]
# re_ade_clinical download started this may take some time.
# [OK!]

# %% [markdown]
# Create a LightPipeline for annotation.

# %%
ade_lmodel = nlp.LightPipeline(ade_model)

# %%
text = "I experienced fatigue, muscle cramps, anxiety, agression and sadness after taking Lipitor but no more adverse after passing Zocor."

ade_results = ade_lmodel.fullAnnotate(text)

# %% [markdown]
# Show the ADE-DRUG relations by using pandas dataframe.

# %%
rel_df = get_relations_df(ade_results)

rel_df
# Out:
# Empty DataFrame
# Columns: [sentence, entity1_begin, entity1_end, chunk1, entity1, entity2_begin, entity2_end, chunk2, entity2, relation, confidence]
# Index: []

# %% [markdown]
# As seen above, there is no relation catched because of the mismatch between the relation paris and the NER entities.

# %% [markdown]
# ### `setCustomLabels`
#
# This parameter is used for setting the custom relation labels.

# %% [markdown]
# Lets set custom labels instead of default ones by using .`setCustomLabels` parameter

# %%
reModel = medical.RelationExtractionModel()\
    .pretrained("re_ade_clinical", "en", 'clinical/models')\
    .setInputCols(["embeddings", "pos_tags", "ner_chunks", "dependencies"])\
    .setOutputCol("relations")\
    .setMaxSyntacticDistance(10)\
    .setRelationPairs(["drug-ade, ade-drug"])\
    .setRelationPairsCaseSensitive(False)

# set custom labels
reModel.setCustomLabels({"1": "is_related", "0": "not_related"})

ade_pipeline = nlp.Pipeline(stages=[
    documenter,
    sentencer,
    tokenizer,
    words_embedder,
    pos_tagger,
    ner_tagger,
    ner_chunker,
    dependency_parser,
    reModel
])

empty_data = spark.createDataFrame([[""]]).toDF("text")

ade_model = ade_pipeline.fit(empty_data)
# Out:
# re_ade_clinical download started this may take some time.
# [OK!]

# %% [markdown]
# Create a LightPipeline for annotation.

# %%
ade_lmodel = nlp.LightPipeline(ade_model)

text ="""A 44-year-old man taking naproxen for chronic low back pain and a 20-year-old woman on oxaprozin for rheumatoid arthritis presented with tense bullae and cutaneous fragility on the face and the back of the hands."""

ade_results = ade_lmodel.fullAnnotate(text)

# %% [markdown]
# Showing the results in a pandas dataframe

# %%
print(text)

rel_df = get_relations_df (ade_results)

rel_df
# Out:
# A 44-year-old man taking naproxen for chronic low back pain and a 20-year-old woman on oxaprozin for rheumatoid arthritis presented with tense bullae and cutaneous fragility on the face and the back of the hands.
#   sentence entity1_begin entity1_end     chunk1 entity1 entity2_begin  \
# 0        0            25          32   naproxen    DRUG           137
# 1        0            25          32   naproxen    DRUG           154
# 2        0            87          95  oxaprozin    DRUG           137
# 3        0            87          95  oxaprozin    DRUG           154
#
#   entity2_end                                             chunk2 entity2  \
# 0         148                                       tense bullae     ADE
# 1         210  cutaneous fragility on the face and the back o...     ADE
# 2         148                                       tense bullae     ADE
# 3         210  cutaneous fragility on the face and the back o...     ADE
#
#      relation  confidence
# 0  is_related         1.0
# 1  is_related  0.99999976
# 2  is_related         1.0
# 3  is_related         1.0

# %% [markdown]
# As seen above, we see the labels as we customized; `is_related`, `not_related`.

# %% [markdown]
# ### `setPredictionThreshold`
#
# This parameter is used for setting the minimal activation of the target unit to encode a new relation instance.

# %% [markdown]
# We will set`setPredictionThreshold()` parameter with different values and see its effects on the results. <br/>

# %%
ner_tagger = medical.NerModel.pretrained("ner_ade_clinical", "en", "clinical/models")\
    .setInputCols("sentences", "tokens", "embeddings")\
    .setOutputCol("ner_tags")

reModel = medical.RelationExtractionModel()\
    .pretrained("re_ade_clinical", "en", 'clinical/models')\
    .setInputCols(["embeddings", "pos_tags", "ner_chunks", "dependencies"])\
    .setOutputCol("relations")\
    .setMaxSyntacticDistance(10)\
    .setRelationPairs(["drug-ade, ade-drug"])\
    .setPredictionThreshold(0.9)

ade_pipeline = nlp.Pipeline(stages=[
    documenter,
    sentencer,
    tokenizer,
    words_embedder,
    pos_tagger,
    ner_tagger,
    ner_chunker,
    dependency_parser,
    reModel
])

empty_data = spark.createDataFrame([[""]]).toDF("text")

ade_model = ade_pipeline.fit(empty_data)
# Out:
# ner_ade_clinical download started this may take some time.
# [OK!]
# re_ade_clinical download started this may take some time.
# [OK!]

# %% [markdown]
# Create a LightPipeline for annotation.

# %%
ade_lmodel = nlp.LightPipeline(ade_model)

text = "I experienced fatigue, muscle cramps, anxiety, agression and sadness after taking Lipitor but no more adverse after passing Zocor."

ade_results = ade_lmodel.fullAnnotate(text)

# %% [markdown]
# Checking the results in a pandas dataframe

# %%
rel_df = get_relations_df(ade_results)

rel_df
# Out:
#   sentence entity1_begin entity1_end         chunk1 entity1 entity2_begin  \
# 0        0            14          20        fatigue     ADE            82
# 1        0            14          20        fatigue     ADE           124
# 2        0            23          35  muscle cramps     ADE            82
# 3        0            23          35  muscle cramps     ADE           124
# 4        0            38          44        anxiety     ADE           124
# 5        0            47          55      agression     ADE            82
# 6        0            47          55      agression     ADE           124
# 7        0            61          67        sadness     ADE            82
# 8        0            61          67        sadness     ADE           124
#
#   entity2_end   chunk2 entity2     relation  confidence
# 0          88  Lipitor    DRUG   is_related   0.9998622
# 1         128    Zocor    DRUG  not_related  0.99888533
# 2          88  Lipitor    DRUG   is_related  0.99999154
# 3         128    Zocor    DRUG  not_related   0.9780189
# 4         128    Zocor    DRUG  not_related  0.99998915
# 5          88  Lipitor    DRUG   is_related  0.99999785
# 6         128    Zocor    DRUG  not_related    0.999469
# 7          88  Lipitor    DRUG   is_related         1.0
# 8         128    Zocor    DRUG  not_related  0.99980325

# %% [markdown]
# As seen above, we only have the relations which have a confidence higher than 0.9

# %% [markdown]
# Pipeline with `setPredictionThreshold(0.1)`:

# %%
ner_tagger = medical.NerModel.pretrained("ner_ade_clinical", "en", "clinical/models")\
    .setInputCols("sentences", "tokens", "embeddings")\
    .setOutputCol("ner_tags")

reModel = medical.RelationExtractionModel()\
    .pretrained("re_ade_clinical", "en", 'clinical/models')\
    .setInputCols(["embeddings", "pos_tags", "ner_chunks", "dependencies"])\
    .setOutputCol("relations")\
    .setMaxSyntacticDistance(10)\
    .setRelationPairs(["drug-ade, ade-drug"])\
    .setPredictionThreshold(0.1)

ade_pipeline = nlp.Pipeline(stages=[
    documenter,
    sentencer,
    tokenizer,
    words_embedder,
    pos_tagger,
    ner_tagger,
    ner_chunker,
    dependency_parser,
    reModel
])

empty_data = spark.createDataFrame([[""]]).toDF("text")

ade_model = ade_pipeline.fit(empty_data)
# Out:
# ner_ade_clinical download started this may take some time.
# [OK!]
# re_ade_clinical download started this may take some time.
# [OK!]

# %%
ade_lmodel = nlp.LightPipeline(ade_model)

text = "I experienced fatigue, muscle cramps, anxiety, agression and sadness after taking Lipitor but no more adverse after passing Zocor."

ade_results = ade_lmodel.fullAnnotate(text)

# %%
rel_df = get_relations_df(ade_results)

rel_df
# Out:
#   sentence entity1_begin entity1_end         chunk1 entity1 entity2_begin  \
# 0        0            14          20        fatigue     ADE            82
# 1        0            14          20        fatigue     ADE           124
# 2        0            23          35  muscle cramps     ADE            82
# 3        0            23          35  muscle cramps     ADE           124
# 4        0            38          44        anxiety     ADE            82
# 5        0            38          44        anxiety     ADE           124
# 6        0            47          55      agression     ADE            82
# 7        0            47          55      agression     ADE           124
# 8        0            61          67        sadness     ADE            82
# 9        0            61          67        sadness     ADE           124
#
#   entity2_end   chunk2 entity2     relation  confidence
# 0          88  Lipitor    DRUG   is_related   0.9998622
# 1         128    Zocor    DRUG  not_related  0.99888533
# 2          88  Lipitor    DRUG   is_related  0.99999154
# 3         128    Zocor    DRUG  not_related   0.9780189
# 4          88  Lipitor    DRUG   is_related  0.86541504
# 5         128    Zocor    DRUG  not_related  0.99998915
# 6          88  Lipitor    DRUG   is_related  0.99999785
# 7         128    Zocor    DRUG  not_related    0.999469
# 8          88  Lipitor    DRUG   is_related         1.0
# 9         128    Zocor    DRUG  not_related  0.99980325

# %% [markdown]
# As seen above, since we set the threshold 0.1, we can see all relations higher that 0.1 (see the index 4.)

# %% [markdown]
# ### `setRelationTypePerPair`
#
# List of entity pairs per relations which limit the entities can form a relation. For example, {TrAP: [“PROBLEM”, "TREATMENT"]} which only let “PROBLEM" and "TREATMENT" NER entities in a "TrAP" relation.

# %% [markdown]
# Now, we will define the RE pipeline with `setRelationTypePerPair({"TrAP": ["PROBLEM-TREATMENT"]})` to see only "PROBLEM" and "TREATMENT" entities in "TrAP" relation type.

# %%
ner_tagger = medical.NerModel.pretrained("ner_clinical", "en", "clinical/models")\
    .setInputCols("sentences", "tokens", "embeddings")\
    .setOutputCol("ner_tags")

reModel = medical.RelationExtractionModel()\
    .pretrained("re_clinical", "en", 'clinical/models')\
    .setInputCols(["embeddings", "pos_tags", "ner_chunks", "dependencies"])\
    .setOutputCol("relations")\
    .setMaxSyntacticDistance(10)\
    .setRelationPairsCaseSensitive(False)\
    .setRelationTypePerPair({"TrAP": ["PROBLEM-TREATMENT"]})\

re_pipeline = nlp.Pipeline(stages=[
    documenter,
    sentencer,
    tokenizer,
    words_embedder,
    pos_tagger,
    ner_tagger,
    ner_chunker,
    dependency_parser,
    reModel
])

empty_data = spark.createDataFrame([[""]]).toDF("text")

re_model = re_pipeline.fit(empty_data)
# Out:
# ner_clinical download started this may take some time.
# [OK!]
# re_clinical download started this may take some time.
# [OK!]

# %%
re_lmodel = nlp.LightPipeline(re_model)

text= "A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus ( T2DM ), one prior episode of HTG-induced pancreatitis three years prior to presentation,  associated with an acute hepatitis , and obesity with a body mass index ( BMI ) of 33.5 kg/m2 , presented with a one-week history of polyuria , polydipsia , poor appetite , and vomiting . Two weeks prior to presentation , she was treated with a five-day course of amoxicillin for a respiratory tract infection . She was on metformin , glipizide , and dapagliflozin for T2DM and atorvastatin and gemfibrozil for HTG . She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa ; significantly , her abdominal examination was benign with no tenderness , guarding , or rigidity . Pertinent laboratory findings on admission were : serum glucose 111 mg/dl , bicarbonate 18 mmol/l , anion gap 20 , creatinine 0.4 mg/dL , triglycerides 508 mg/dL , total cholesterol 122 mg/dL , glycated hemoglobin ( HbA1c ) 10% , and venous pH 7.27 . Serum lipase was normal at 43 U/L . Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia . The patient was initially admitted for starvation ketosis , as she reported poor oral intake for three days prior to admission . However , serum chemistry obtained six hours after presentation revealed her glucose was 186 mg/dL , the anion gap was still elevated at 21 , serum bicarbonate was 16 mmol/L , triglyceride level peaked at 2050 mg/dL , and lipase was 52 U/L . The β-hydroxybutyrate level was obtained and found to be elevated at 5.29 mmol/L - the original sample was centrifuged and the chylomicron layer removed prior to analysis due to interference from turbidity caused by lipemia again . The patient was treated with an insulin drip for euDKA and HTG with a reduction in the anion gap to 13 and triglycerides to 1400 mg/dL , within 24 hours . Her euDKA was thought to be precipitated by her respiratory tract infection in the setting of SGLT2 inhibitor use . The patient was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night , 12 units of insulin lispro with meals , and metformin 1000 mg two times a day . It was determined that all SGLT2 inhibitors should be discontinued indefinitely . She had close follow-up with endocrinology post discharge ."

re_results = re_lmodel.fullAnnotate(text)

# %%
rel_df = get_relations_df(re_results)

rel_df[rel_df["relation"]=="TrAP"]
# Out:
#     sentence entity1_begin entity1_end           chunk1    entity1  \
# 46         1           511         521      amoxicillin  TREATMENT
# 47         2           570         578        metformin  TREATMENT
# 48         2           570         578        metformin  TREATMENT
# 49         2           582         590        glipizide  TREATMENT
# 50         2           582         590        glipizide  TREATMENT
# 51         2           598         610    dapagliflozin  TREATMENT
# 52         2           598         610    dapagliflozin  TREATMENT
# 54         2           625         636     atorvastatin  TREATMENT
# 55         2           642         652      gemfibrozil  TREATMENT
# 131       12          1936        1950  an insulin drip  TREATMENT
# 132       12          1936        1950  an insulin drip  TREATMENT
#
#     entity2_begin entity2_end                         chunk2  entity2  \
# 46            527         555  a respiratory tract infection  PROBLEM
# 47            616         619                           T2DM  PROBLEM
# 48            658         660                            HTG  PROBLEM
# 49            616         619                           T2DM  PROBLEM
# 50            658         660                            HTG  PROBLEM
# 51            616         619                           T2DM  PROBLEM
# 52            658         660                            HTG  PROBLEM
# 54            658         660                            HTG  PROBLEM
# 55            658         660                            HTG  PROBLEM
# 131          1956        1960                          euDKA  PROBLEM
# 132          1966        1968                            HTG  PROBLEM
#
#     relation  confidence
# 46      TrAP   0.9999393
# 47      TrAP  0.99999905
# 48      TrAP  0.99999964
# 49      TrAP   0.9999999
# 50      TrAP         1.0
# 51      TrAP  0.99999976
# 52      TrAP   0.9998598
# 54      TrAP  0.99999547
# 55      TrAP         1.0
# 131     TrAP   0.9996302
# 132     TrAP   0.9839804

# %% [markdown]
# As seen above, we only have "TREATMENT" and "PROBLEM" entities in "TrAP" relations.

# %% [markdown]
# This time we will set `setRelationTypePerPair({"TrAP": ["PROBLEM-TEST"]})` to see only "PROBLEM" and "TEST" entities in "TrAP" relations.

# %%
reModel = medical.RelationExtractionModel()\
    .pretrained("re_clinical", "en", 'clinical/models')\
    .setInputCols(["embeddings", "pos_tags", "ner_chunks", "dependencies"])\
    .setOutputCol("relations")\
    .setMaxSyntacticDistance(10)\
    .setRelationPairsCaseSensitive(False)\
    .setRelationTypePerPair({"TrAP": ["PROBLEM-TEST"]})\

re_pipeline = nlp.Pipeline(stages=[
    documenter,
    sentencer,
    tokenizer,
    words_embedder,
    pos_tagger,
    ner_tagger,
    ner_chunker,
    dependency_parser,
    reModel
])

empty_data = spark.createDataFrame([[""]]).toDF("text")

re_model = re_pipeline.fit(empty_data)
# Out:
# re_clinical download started this may take some time.
# [OK!]

# %%
re_lmodel = nlp.LightPipeline(re_model)

re_results = re_lmodel.fullAnnotate(text)

# %%
rel_df = get_relations_df(re_results)
rel_df[rel_df["relation"]=="TrAP"]
# Out:
#    sentence entity1_begin entity1_end chunk1 entity1 entity2_begin  \
# 40        0           321         323    BMI    TEST           424
#
#    entity2_end    chunk2  entity2 relation confidence
# 40         431  vomiting  PROBLEM     TrAP   0.894692

# %% [markdown]
# As seen above, we only see "PROBLEM" and "TEST" entities in "TrAP" relations.

# %% [markdown]
# ### `setMultiClass`
#
# This parameter is set in order to return whether all the labels with corresponding scores (Default: False).

# %%
reModel = medical.RelationExtractionModel()\
    .pretrained("re_clinical", "en", 'clinical/models')\
    .setInputCols(["embeddings", "pos_tags", "ner_chunks", "dependencies"])\
    .setOutputCol("relations")\
    .setMaxSyntacticDistance(10)\
    .setMultiClass(True)


re_pipeline = nlp.Pipeline(stages=[
    documenter,
    sentencer,
    tokenizer,
    words_embedder,
    pos_tagger,
    ner_tagger,
    ner_chunker,
    dependency_parser,
    reModel
])

empty_data = spark.createDataFrame([[""]]).toDF("text")

re_model = re_pipeline.fit(empty_data)
# Out:
# re_clinical download started this may take some time.
# [OK!]

# %%
re_lmodel = nlp.LightPipeline(re_model)

text= "A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus ( T2DM ), one prior episode of HTG-induced pancreatitis three years prior to presentation,  associated with an acute hepatitis , and obesity with a body mass index ( BMI ) of 33.5 kg/m2 , presented with a one-week history of polyuria , polydipsia , poor appetite , and vomiting . Two weeks prior to presentation , she was treated with a five-day course of amoxicillin for a respiratory tract infection . She was on metformin , glipizide , and dapagliflozin for T2DM and atorvastatin and gemfibrozil for HTG . She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa ; significantly , her abdominal examination was benign with no tenderness , guarding , or rigidity . Pertinent laboratory findings on admission were : serum glucose 111 mg/dl , bicarbonate 18 mmol/l , anion gap 20 , creatinine 0.4 mg/dL , triglycerides 508 mg/dL , total cholesterol 122 mg/dL , glycated hemoglobin ( HbA1c ) 10% , and venous pH 7.27 . Serum lipase was normal at 43 U/L . Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia . The patient was initially admitted for starvation ketosis , as she reported poor oral intake for three days prior to admission . However , serum chemistry obtained six hours after presentation revealed her glucose was 186 mg/dL , the anion gap was still elevated at 21 , serum bicarbonate was 16 mmol/L , triglyceride level peaked at 2050 mg/dL , and lipase was 52 U/L . The β-hydroxybutyrate level was obtained and found to be elevated at 5.29 mmol/L - the original sample was centrifuged and the chylomicron layer removed prior to analysis due to interference from turbidity caused by lipemia again . The patient was treated with an insulin drip for euDKA and HTG with a reduction in the anion gap to 13 and triglycerides to 1400 mg/dL , within 24 hours . Her euDKA was thought to be precipitated by her respiratory tract infection in the setting of SGLT2 inhibitor use . The patient was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night , 12 units of insulin lispro with meals , and metformin 1000 mg two times a day . It was determined that all SGLT2 inhibitors should be discontinued indefinitely . She had close follow-up with endocrinology post discharge ."

re_results = re_lmodel.fullAnnotate(text)

# %% [markdown]
# Let's check the metadata of the relations

# %%
re_results[0]["relations"]
# Out:
# [Annotation(category, 39, 153, TeRP, {'TrWP_confidence': '5.49793E-24', 'chunk2': 'subsequent type two diabetes mellitus', 'TrIP_confidence': '0.0', 'TrAP_confidence': '6.382531E-31', 'TrNAP_confidence': '2.8671916E-23', 'confidence': '1.0', 'entity2_end': '153', 'chunk1': 'gestational diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '117', 'TeRP_confidence': '1.0', 'TeCP_confidence': '1.07731E-29', 'O_confidence': '5.097145E-16', 'chunk2_confidence': '0.75560004', 'entity1_begin': '39', 'sentence': '0', 'PIP_confidence': '8.428624E-23', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '67', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9205'}, []),
#  Annotation(category, 39, 160, TeRP, {'TrWP_confidence': '7.218621E-33', 'chunk2': 'T2DM', 'TrIP_confidence': '0.0', 'TrAP_confidence': '5.3768856E-31', 'TrNAP_confidence': '3.5057997E-35', 'confidence': '1.0', 'entity2_end': '160', 'chunk1': 'gestational diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '157', 'TeRP_confidence': '1.0', 'TeCP_confidence': '8.398315E-33', 'O_confidence': '7.091125E-21', 'chunk2_confidence': '0.9928', 'entity1_begin': '39', 'sentence': '0', 'PIP_confidence': '1.677217E-22', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '67', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9205'}, []),
#  Annotation(category, 39, 294, TeRP, {'TrWP_confidence': '0.0', 'chunk2': 'obesity', 'TrIP_confidence': '0.0', 'TrAP_confidence': '0.0', 'TrNAP_confidence': '0.0', 'confidence': '1.0', 'entity2_end': '294', 'chunk1': 'gestational diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '288', 'TeRP_confidence': '1.0', 'TeCP_confidence': '0.0', 'O_confidence': '4.859872E-31', 'chunk2_confidence': '0.997', 'entity1_begin': '39', 'sentence': '0', 'PIP_confidence': '0.0', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '67', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9205'}, []),
#  Annotation(category, 39, 317, TeRP, {'TrWP_confidence': '0.0', 'chunk2': 'a body mass index', 'TrIP_confidence': '0.0', 'TrAP_confidence': '0.0', 'TrNAP_confidence': '0.0', 'confidence': '1.0', 'entity2_end': '317', 'chunk1': 'gestational diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '301', 'TeRP_confidence': '1.0', 'TeCP_confidence': '0.0', 'O_confidence': '1.7967275E-32', 'chunk2_confidence': '0.83052504', 'entity1_begin': '39', 'sentence': '0', 'PIP_confidence': '0.0', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '67', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9205'}, []),
#  Annotation(category, 117, 160, TeRP, {'TrWP_confidence': '8.192508E-26', 'chunk2': 'T2DM', 'TrIP_confidence': '0.0', 'TrAP_confidence': '5.338805E-25', 'TrNAP_confidence': '1.6462486E-26', 'confidence': '1.0', 'entity2_end': '160', 'chunk1': 'subsequent type two diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '157', 'TeRP_confidence': '1.0', 'TeCP_confidence': '8.8749896E-26', 'O_confidence': '5.3090988E-15', 'chunk2_confidence': '0.9928', 'entity1_begin': '117', 'sentence': '0', 'PIP_confidence': '4.3117086E-15', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '153', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.75560004'}, []),
#  Annotation(category, 117, 209, TeRP, {'TrWP_confidence': '1.6270601E-22', 'chunk2': 'HTG-induced pancreatitis', 'TrIP_confidence': '0.0', 'TrAP_confidence': '8.580985E-28', 'TrNAP_confidence': '5.849308E-22', 'confidence': '1.0', 'entity2_end': '209', 'chunk1': 'subsequent type two diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '186', 'TeRP_confidence': '1.0', 'TeCP_confidence': '3.438283E-26', 'O_confidence': '5.7281454E-15', 'chunk2_confidence': '0.97975004', 'entity1_begin': '117', 'sentence': '0', 'PIP_confidence': '4.717952E-18', 'direction': 'both', 'TrCP_confidence': '3.9208913E-35', 'entity1_end': '153', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.75560004'}, []),
#  Annotation(category, 117, 280, TeRP, {'TrWP_confidence': '6.999197E-33', 'chunk2': 'an acute hepatitis', 'TrIP_confidence': '0.0', 'TrAP_confidence': '8.1303163E-38', 'TrNAP_confidence': '0.0', 'confidence': '1.0', 'entity2_end': '280', 'chunk1': 'subsequent type two diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '263', 'TeRP_confidence': '1.0', 'TeCP_confidence': '0.0', 'O_confidence': '1.65407E-22', 'chunk2_confidence': '0.9519333', 'entity1_begin': '117', 'sentence': '0', 'PIP_confidence': '1.4860838E-31', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '153', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.75560004'}, []),
#  Annotation(category, 117, 294, TeRP, {'TrWP_confidence': '0.0', 'chunk2': 'obesity', 'TrIP_confidence': '0.0', 'TrAP_confidence': '0.0', 'TrNAP_confidence': '0.0', 'confidence': '1.0', 'entity2_end': '294', 'chunk1': 'subsequent type two diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '288', 'TeRP_confidence': '1.0', 'TeCP_confidence': '0.0', 'O_confidence': '8.0224783E-25', 'chunk2_confidence': '0.997', 'entity1_begin': '117', 'sentence': '0', 'PIP_confidence': '1.5003309E-37', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '153', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.75560004'}, []),
#  Annotation(category, 117, 317, TeRP, {'TrWP_confidence': '0.0', 'chunk2': 'a body mass index', 'TrIP_confidence': '0.0', 'TrAP_confidence': '0.0', 'TrNAP_confidence': '0.0', 'confidence': '1.0', 'entity2_end': '317', 'chunk1': 'subsequent type two diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '301', 'TeRP_confidence': '1.0', 'TeCP_confidence': '0.0', 'O_confidence': '4.4211118E-26', 'chunk2_confidence': '0.83052504', 'entity1_begin': '117', 'sentence': '0', 'PIP_confidence': '0.0', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '153', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.75560004'}, []),
#  Annotation(category, 117, 323, TeRP, {'TrWP_confidence': '0.0', 'chunk2': 'BMI', 'TrIP_confidence': '0.0', 'TrAP_confidence': '0.0', 'TrNAP_confidence': '0.0', 'confidence': '1.0', 'entity2_end': '323', 'chunk1': 'subsequent type two diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '321', 'TeRP_confidence': '1.0', 'TeCP_confidence': '0.0', 'O_confidence': '3.3683624E-25', 'chunk2_confidence': '0.6775', 'entity1_begin': '117', 'sentence': '0', 'PIP_confidence': '0.0', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '153', 'entity2': 'TEST', 'chunk1_confidence': '0.75560004'}, []),
#  Annotation(category, 117, 387, TeRP, {'TrWP_confidence': '0.0', 'chunk2': 'polyuria', 'TrIP_confidence': '0.0', 'TrAP_confidence': '0.0', 'TrNAP_confidence': '0.0', 'confidence': '1.0', 'entity2_end': '387', 'chunk1': 'subsequent type two diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '380', 'TeRP_confidence': '1.0', 'TeCP_confidence': '0.0', 'O_confidence': '1.5200723E-31', 'chunk2_confidence': '0.9901', 'entity1_begin': '117', 'sentence': '0', 'PIP_confidence': '0.0', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '153', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.75560004'}, []),
#  Annotation(category, 117, 400, TeRP, {'TrWP_confidence': '0.0', 'chunk2': 'polydipsia', 'TrIP_confidence': '0.0', 'TrAP_confidence': '0.0', 'TrNAP_confidence': '0.0', 'confidence': '1.0', 'entity2_end': '400', 'chunk1': 'subsequent type two diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '391', 'TeRP_confidence': '1.0', 'TeCP_confidence': '0.0', 'O_confidence': '7.366709E-30', 'chunk2_confidence': '0.993', 'entity1_begin': '117', 'sentence': '0', 'PIP_confidence': '0.0', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '153', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.75560004'}, []),
#  Annotation(category, 117, 416, TeRP, {'TrWP_confidence': '0.0', 'chunk2': 'poor appetite', 'TrIP_confidence': '0.0', 'TrAP_confidence': '0.0', 'TrNAP_confidence': '0.0', 'confidence': '1.0', 'entity2_end': '416', 'chunk1': 'subsequent type two diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '404', 'TeRP_confidence': '1.0', 'TeCP_confidence': '0.0', 'O_confidence': '2.258945E-33', 'chunk2_confidence': '0.99795', 'entity1_begin': '117', 'sentence': '0', 'PIP_confidence': '0.0', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '153', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.75560004'}, []),
#  Annotation(category, 117, 431, TeRP, {'TrWP_confidence': '0.0', 'chunk2': 'vomiting', 'TrIP_confidence': '0.0', 'TrAP_confidence': '0.0', 'TrNAP_confidence': '0.0', 'confidence': '1.0', 'entity2_end': '431', 'chunk1': 'subsequent type two diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '424', 'TeRP_confidence': '1.0', 'TeCP_confidence': '0.0', 'O_confidence': '4.7378087E-33', 'chunk2_confidence': '0.9931', 'entity1_begin': '117', 'sentence': '0', 'PIP_confidence': '0.0', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '153', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.75560004'}, []),
#  Annotation(category, 157, 209, TeRP, {'TrWP_confidence': '1.6017928E-21', 'chunk2': 'HTG-induced pancreatitis', 'TrIP_confidence': '2.860059E-30', 'TrAP_confidence': '7.247147E-19', 'TrNAP_confidence': '8.716299E-24', 'confidence': '1.0', 'entity2_end': '209', 'chunk1': 'T2DM', 'entity1': 'PROBLEM', 'entity2_begin': '186', 'TeRP_confidence': '1.0', 'TeCP_confidence': '3.3125585E-20', 'O_confidence': '3.239841E-14', 'chunk2_confidence': '0.97975004', 'entity1_begin': '157', 'sentence': '0', 'PIP_confidence': '4.4341374E-17', 'direction': 'both', 'TrCP_confidence': '1.4881552E-30', 'entity1_end': '160', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9928'}, []),
#  Annotation(category, 157, 280, TeRP, {'TrWP_confidence': '3.3178464E-34', 'chunk2': 'an acute hepatitis', 'TrIP_confidence': '1.8891071E-38', 'TrAP_confidence': '1.1261763E-22', 'TrNAP_confidence': '3.0189121E-30', 'confidence': '1.0', 'entity2_end': '280', 'chunk1': 'T2DM', 'entity1': 'PROBLEM', 'entity2_begin': '263', 'TeRP_confidence': '1.0', 'TeCP_confidence': '6.1726616E-21', 'O_confidence': '1.3817679E-16', 'chunk2_confidence': '0.9519333', 'entity1_begin': '157', 'sentence': '0', 'PIP_confidence': '1.0908895E-24', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '160', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9928'}, []),
#  Annotation(category, 157, 294, TeRP, {'TrWP_confidence': '0.0', 'chunk2': 'obesity', 'TrIP_confidence': '0.0', 'TrAP_confidence': '7.225305E-28', 'TrNAP_confidence': '0.0', 'confidence': '0.99999976', 'entity2_end': '294', 'chunk1': 'T2DM', 'entity1': 'PROBLEM', 'entity2_begin': '288', 'TeRP_confidence': '0.99999976', 'TeCP_confidence': '1.2424532E-20', 'O_confidence': '2.1230898E-7', 'chunk2_confidence': '0.997', 'entity1_begin': '157', 'sentence': '0', 'PIP_confidence': '2.6882653E-28', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '160', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9928'}, []),
#  Annotation(category, 157, 317, TeRP, {'TrWP_confidence': '0.0', 'chunk2': 'a body mass index', 'TrIP_confidence': '0.0', 'TrAP_confidence': '4.905016E-25', 'TrNAP_confidence': '7.0066857E-38', 'confidence': '1.0', 'entity2_end': '317', 'chunk1': 'T2DM', 'entity1': 'PROBLEM', 'entity2_begin': '301', 'TeRP_confidence': '1.0', 'TeCP_confidence': '1.8422302E-23', 'O_confidence': '1.5339286E-14', 'chunk2_confidence': '0.83052504', 'entity1_begin': '157', 'sentence': '0', 'PIP_confidence': '1.31779885E-30', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '160', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9928'}, []),
#  Annotation(category, 157, 323, O, {'TrWP_confidence': '0.0', 'chunk2': 'BMI', 'TrIP_confidence': '0.0', 'TrAP_confidence': '0.0', 'TrNAP_confidence': '0.0', 'confidence': '0.99999833', 'entity2_end': '323', 'chunk1': 'T2DM', 'entity1': 'PROBLEM', 'entity2_begin': '321', 'TeRP_confidence': '1.6510612E-6', 'TeCP_confidence': '3.7164812E-29', 'O_confidence': '0.99999833', 'chunk2_confidence': '0.6775', 'entity1_begin': '157', 'sentence': '0', 'PIP_confidence': '0.0', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '160', 'entity2': 'TEST', 'chunk1_confidence': '0.9928'}, []),
#  Annotation(category, 157, 387, TeRP, {'TrWP_confidence': '0.0', 'chunk2': 'polyuria', 'TrIP_confidence': '0.0', 'TrAP_confidence': '5.1039395E-34', 'TrNAP_confidence': '0.0', 'confidence': '0.993796', 'entity2_end': '387', 'chunk1': 'T2DM', 'entity1': 'PROBLEM', 'entity2_begin': '380', 'TeRP_confidence': '0.993796', 'TeCP_confidence': '1.4025113E-27', 'O_confidence': '0.0062040584', 'chunk2_confidence': '0.9901', 'entity1_begin': '157', 'sentence': '0', 'PIP_confidence': '0.0', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '160', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9928'}, []),
#  Annotation(category, 157, 400, TeRP, {'TrWP_confidence': '0.0', 'chunk2': 'polydipsia', 'TrIP_confidence': '0.0', 'TrAP_confidence': '7.202524E-31', 'TrNAP_confidence': '0.0', 'confidence': '0.7955576', 'entity2_end': '400', 'chunk1': 'T2DM', 'entity1': 'PROBLEM', 'entity2_begin': '391', 'TeRP_confidence': '0.7955576', 'TeCP_confidence': '1.8854888E-24', 'O_confidence': '0.2044424', 'chunk2_confidence': '0.993', 'entity1_begin': '157', 'sentence': '0', 'PIP_confidence': '0.0', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '160', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9928'}, []),
#  Annotation(category, 157, 416, TeRP, {'TrWP_confidence': '0.0', 'chunk2': 'poor appetite', 'TrIP_confidence': '0.0', 'TrAP_confidence': '1.1039858E-29', 'TrNAP_confidence': '0.0', 'confidence': '1.0', 'entity2_end': '416', 'chunk1': 'T2DM', 'entity1': 'PROBLEM', 'entity2_begin': '404', 'TeRP_confidence': '1.0', 'TeCP_confidence': '8.8737914E-29', 'O_confidence': '1.1254241E-8', 'chunk2_confidence': '0.99795', 'entity1_begin': '157', 'sentence': '0', 'PIP_confidence': '0.0', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '160', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9928'}, []),
#  Annotation(category, 157, 431, TeRP, {'TrWP_confidence': '0.0', 'chunk2': 'vomiting', 'TrIP_confidence': '0.0', 'TrAP_confidence': '3.447585E-29', 'TrNAP_confidence': '0.0', 'confidence': '0.9993581', 'entity2_end': '431', 'chunk1': 'T2DM', 'entity1': 'PROBLEM', 'entity2_begin': '424', 'TeRP_confidence': '0.9993581', 'TeCP_confidence': '1.1303469E-27', 'O_confidence': '6.4188696E-4', 'chunk2_confidence': '0.9931', 'entity1_begin': '157', 'sentence': '0', 'PIP_confidence': '0.0', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '160', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9928'}, []),
#  Annotation(category, 186, 280, TeRP, {'TrWP_confidence': '8.336535E-22', 'chunk2': 'an acute hepatitis', 'TrIP_confidence': '1.5493168E-35', 'TrAP_confidence': '1.6272445E-24', 'TrNAP_confidence': '7.447007E-23', 'confidence': '1.0', 'entity2_end': '280', 'chunk1': 'HTG-induced pancreatitis', 'entity1': 'PROBLEM', 'entity2_begin': '263', 'TeRP_confidence': '1.0', 'TeCP_confidence': '2.8560898E-23', 'O_confidence': '7.567432E-14', 'chunk2_confidence': '0.9519333', 'entity1_begin': '186', 'sentence': '0', 'PIP_confidence': '2.4521751E-17', 'direction': 'both', 'TrCP_confidence': '7.818029E-34', 'entity1_end': '209', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.97975004'}, []),
#  Annotation(category, 186, 294, TeRP, {'TrWP_confidence': '5.010229E-28', 'chunk2': 'obesity', 'TrIP_confidence': '0.0', 'TrAP_confidence': '9.304702E-27', 'TrNAP_confidence': '3.834432E-29', 'confidence': '1.0', 'entity2_end': '294', 'chunk1': 'HTG-induced pancreatitis', 'entity1': 'PROBLEM', 'entity2_begin': '288', 'TeRP_confidence': '1.0', 'TeCP_confidence': '9.065508E-27', 'O_confidence': '1.7223545E-10', 'chunk2_confidence': '0.997', 'entity1_begin': '186', 'sentence': '0', 'PIP_confidence': '7.7388685E-18', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '209', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.97975004'}, []),
#  Annotation(category, 186, 317, TeRP, {'TrWP_confidence': '9.776211E-32', 'chunk2': 'a body mass index', 'TrIP_confidence': '0.0', 'TrAP_confidence': '1.882827E-30', 'TrNAP_confidence': '3.5449795E-32', 'confidence': '1.0', 'entity2_end': '317', 'chunk1': 'HTG-induced pancreatitis', 'entity1': 'PROBLEM', 'entity2_begin': '301', 'TeRP_confidence': '1.0', 'TeCP_confidence': '7.5131185E-31', 'O_confidence': '6.6093877E-18', 'chunk2_confidence': '0.83052504', 'entity1_begin': '186', 'sentence': '0', 'PIP_confidence': '4.5474695E-25', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '209', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.97975004'}, []),
#  Annotation(category, 186, 323, TeRP, {'TrWP_confidence': '7.24404E-37', 'chunk2': 'BMI', 'TrIP_confidence': '0.0', 'TrAP_confidence': '1.4349794E-34', 'TrNAP_confidence': '0.0', 'confidence': '1.0', 'entity2_end': '323', 'chunk1': 'HTG-induced pancreatitis', 'entity1': 'PROBLEM', 'entity2_begin': '321', 'TeRP_confidence': '1.0', 'TeCP_confidence': '9.327214E-31', 'O_confidence': '5.7883522E-8', 'chunk2_confidence': '0.6775', 'entity1_begin': '186', 'sentence': '0', 'PIP_confidence': '4.569671E-27', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '209', 'entity2': 'TEST', 'chunk1_confidence': '0.97975004'}, []),
#  Annotation(category, 186, 400, TeRP, {'TrWP_confidence': '0.0', 'chunk2': 'polydipsia', 'TrIP_confidence': '0.0', 'TrAP_confidence': '0.0', 'TrNAP_confidence': '0.0', 'confidence': '1.0', 'entity2_end': '400', 'chunk1': 'HTG-induced pancreatitis', 'entity1': 'PROBLEM', 'entity2_begin': '391', 'TeRP_confidence': '1.0', 'TeCP_confidence': '1.6087047E-38', 'O_confidence': '4.273094E-17', 'chunk2_confidence': '0.993', 'entity1_begin': '186', 'sentence': '0', 'PIP_confidence': '0.0', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '209', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.97975004'}, []),
#  Annotation(category, 186, 416, TeRP, {'TrWP_confidence': '0.0', 'chunk2': 'poor appetite', 'TrIP_confidence': '0.0', 'TrAP_confidence': '1.2594829E-38', 'TrNAP_confidence': '0.0', 'confidence': '1.0', 'entity2_end': '416', 'chunk1': 'HTG-induced pancreatitis', 'entity1': 'PROBLEM', 'entity2_begin': '404', 'TeRP_confidence': '1.0', 'TeCP_confidence': '0.0', 'O_confidence': '1.2820771E-23', 'chunk2_confidence': '0.99795', 'entity1_begin': '186', 'sentence': '0', 'PIP_confidence': '0.0', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '209', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.97975004'}, []),
#  Annotation(category, 186, 431, TeRP, {'TrWP_confidence': '0.0', 'chunk2': 'vomiting', 'TrIP_confidence': '0.0', 'TrAP_confidence': '0.0', 'TrNAP_confidence': '0.0', 'confidence': '1.0', 'entity2_end': '431', 'chunk1': 'HTG-induced pancreatitis', 'entity1': 'PROBLEM', 'entity2_begin': '424', 'TeRP_confidence': '1.0', 'TeCP_confidence': '0.0', 'O_confidence': '1.7722666E-20', 'chunk2_confidence': '0.9931', 'entity1_begin': '186', 'sentence': '0', 'PIP_confidence': '0.0', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '209', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.97975004'}, []),
#  Annotation(category, 263, 294, O, {'TrWP_confidence': '1.084676E-21', 'chunk2': 'obesity', 'TrIP_confidence': '4.4918217E-24', 'TrAP_confidence': '3.897432E-23', 'TrNAP_confidence': '1.2824714E-20', 'confidence': '0.99998176', 'entity2_end': '294', 'chunk1': 'an acute hepatitis', 'entity1': 'PROBLEM', 'entity2_begin': '288', 'TeRP_confidence': '1.5742567E-7', 'TeCP_confidence': '4.5235354E-14', 'O_confidence': '0.99998176', 'chunk2_confidence': '0.997', 'entity1_begin': '263', 'sentence': '0', 'PIP_confidence': '1.80688E-5', 'direction': 'both', 'TrCP_confidence': '4.8889757E-24', 'entity1_end': '280', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9519333'}, []),
#  Annotation(category, 288, 317, TeRP, {'TrWP_confidence': '1.24936875E-20', 'chunk2': 'a body mass index', 'TrIP_confidence': '1.0595122E-21', 'TrAP_confidence': '1.2003737E-14', 'TrNAP_confidence': '2.1185064E-19', 'confidence': '1.0', 'entity2_end': '317', 'chunk1': 'obesity', 'entity1': 'PROBLEM', 'entity2_begin': '301', 'TeRP_confidence': '1.0', 'TeCP_confidence': '1.991784E-13', 'O_confidence': '3.0878777E-10', 'chunk2_confidence': '0.83052504', 'entity1_begin': '288', 'sentence': '0', 'PIP_confidence': '1.8298121E-12', 'direction': 'both', 'TrCP_confidence': '1.3334022E-25', 'entity1_end': '294', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.997'}, []),
#  Annotation(category, 288, 323, O, {'TrWP_confidence': '3.7258622E-26', 'chunk2': 'BMI', 'TrIP_confidence': '6.503734E-28', 'TrAP_confidence': '8.4107354E-30', 'TrNAP_confidence': '9.702266E-27', 'confidence': '1.0', 'entity2_end': '323', 'chunk1': 'obesity', 'entity1': 'PROBLEM', 'entity2_begin': '321', 'TeRP_confidence': '3.1191138E-14', 'TeCP_confidence': '2.9928198E-19', 'O_confidence': '1.0', 'chunk2_confidence': '0.6775', 'entity1_begin': '288', 'sentence': '0', 'PIP_confidence': '5.3800535E-13', 'direction': 'both', 'TrCP_confidence': '6.543458E-26', 'entity1_end': '294', 'entity2': 'TEST', 'chunk1_confidence': '0.997'}, []),
#  Annotation(category, 288, 387, TeRP, {'TrWP_confidence': '3.6765146E-28', 'chunk2': 'polyuria', 'TrIP_confidence': '1.8123828E-31', 'TrAP_confidence': '1.2601765E-21', 'TrNAP_confidence': '3.1188299E-25', 'confidence': '0.9999813', 'entity2_end': '387', 'chunk1': 'obesity', 'entity1': 'PROBLEM', 'entity2_begin': '380', 'TeRP_confidence': '0.9999813', 'TeCP_confidence': '7.801607E-14', 'O_confidence': '1.874306E-5', 'chunk2_confidence': '0.9901', 'entity1_begin': '288', 'sentence': '0', 'PIP_confidence': '3.416283E-17', 'direction': 'both', 'TrCP_confidence': '8.440343E-37', 'entity1_end': '294', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.997'}, []),
#  Annotation(category, 288, 400, TeRP, {'TrWP_confidence': '2.1463766E-29', 'chunk2': 'polydipsia', 'TrIP_confidence': '2.1799347E-30', 'TrAP_confidence': '1.8577988E-19', 'TrNAP_confidence': '1.4290674E-25', 'confidence': '0.9997998', 'entity2_end': '400', 'chunk1': 'obesity', 'entity1': 'PROBLEM', 'entity2_begin': '391', 'TeRP_confidence': '0.9997998', 'TeCP_confidence': '4.684755E-11', 'O_confidence': '2.0020237E-4', 'chunk2_confidence': '0.993', 'entity1_begin': '288', 'sentence': '0', 'PIP_confidence': '2.0446246E-18', 'direction': 'both', 'TrCP_confidence': '2.975948E-38', 'entity1_end': '294', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.997'}, []),
#  Annotation(category, 288, 416, TeRP, {'TrWP_confidence': '1.010906E-34', 'chunk2': 'poor appetite', 'TrIP_confidence': '8.6198546E-37', 'TrAP_confidence': '1.35208584E-20', 'TrNAP_confidence': '5.557188E-29', 'confidence': '1.0', 'entity2_end': '416', 'chunk1': 'obesity', 'entity1': 'PROBLEM', 'entity2_begin': '404', 'TeRP_confidence': '1.0', 'TeCP_confidence': '3.929224E-16', 'O_confidence': '1.306389E-12', 'chunk2_confidence': '0.99795', 'entity1_begin': '288', 'sentence': '0', 'PIP_confidence': '1.5492731E-23', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '294', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.997'}, []),
#  Annotation(category, 288, 431, TeRP, {'TrWP_confidence': '6.5784344E-37', 'chunk2': 'vomiting', 'TrIP_confidence': '0.0', 'TrAP_confidence': '5.100947E-20', 'TrNAP_confidence': '4.853663E-32', 'confidence': '0.9999999', 'entity2_end': '431', 'chunk1': 'obesity', 'entity1': 'PROBLEM', 'entity2_begin': '424', 'TeRP_confidence': '0.9999999', 'TeCP_confidence': '2.4403633E-15', 'O_confidence': '6.178427E-8', 'chunk2_confidence': '0.9931', 'entity1_begin': '288', 'sentence': '0', 'PIP_confidence': '3.516816E-24', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '294', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.997'}, []),
#  Annotation(category, 301, 323, O, {'TrWP_confidence': '1.6132903E-29', 'chunk2': 'BMI', 'TrIP_confidence': '5.6669547E-33', 'TrAP_confidence': '6.424147E-33', 'TrNAP_confidence': '5.0372457E-30', 'confidence': '1.0', 'entity2_end': '323', 'chunk1': 'a body mass index', 'entity1': 'PROBLEM', 'entity2_begin': '321', 'TeRP_confidence': '2.9058632E-15', 'TeCP_confidence': '5.462308E-24', 'O_confidence': '1.0', 'chunk2_confidence': '0.6775', 'entity1_begin': '301', 'sentence': '0', 'PIP_confidence': '1.2004168E-11', 'direction': 'both', 'TrCP_confidence': '2.2154339E-30', 'entity1_end': '317', 'entity2': 'TEST', 'chunk1_confidence': '0.83052504'}, []),
#  Annotation(category, 301, 387, TeRP, {'TrWP_confidence': '1.3096501E-22', 'chunk2': 'polyuria', 'TrIP_confidence': '1.3652429E-30', 'TrAP_confidence': '2.9228183E-21', 'TrNAP_confidence': '5.744776E-22', 'confidence': '0.99999964', 'entity2_end': '387', 'chunk1': 'a body mass index', 'entity1': 'PROBLEM', 'entity2_begin': '380', 'TeRP_confidence': '0.99999964', 'TeCP_confidence': '3.3628506E-19', 'O_confidence': '4.0160265E-7', 'chunk2_confidence': '0.9901', 'entity1_begin': '301', 'sentence': '0', 'PIP_confidence': '1.1011648E-11', 'direction': 'both', 'TrCP_confidence': '2.3889647E-31', 'entity1_end': '317', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.83052504'}, []),
#  Annotation(category, 301, 400, TeRP, {'TrWP_confidence': '4.221957E-25', 'chunk2': 'polydipsia', 'TrIP_confidence': '8.2344055E-32', 'TrAP_confidence': '6.859435E-22', 'TrNAP_confidence': '1.8096461E-24', 'confidence': '1.0', 'entity2_end': '400', 'chunk1': 'a body mass index', 'entity1': 'PROBLEM', 'entity2_begin': '391', 'TeRP_confidence': '1.0', 'TeCP_confidence': '1.6867743E-18', 'O_confidence': '1.29810065E-8', 'chunk2_confidence': '0.993', 'entity1_begin': '301', 'sentence': '0', 'PIP_confidence': '1.01329354E-16', 'direction': 'both', 'TrCP_confidence': '2.5700607E-34', 'entity1_end': '317', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.83052504'}, []),
#  Annotation(category, 301, 416, TeRP, {'TrWP_confidence': '2.9476745E-30', 'chunk2': 'poor appetite', 'TrIP_confidence': '0.0', 'TrAP_confidence': '1.2989272E-24', 'TrNAP_confidence': '1.0565016E-28', 'confidence': '1.0', 'entity2_end': '416', 'chunk1': 'a body mass index', 'entity1': 'PROBLEM', 'entity2_begin': '404', 'TeRP_confidence': '1.0', 'TeCP_confidence': '4.6710012E-24', 'O_confidence': '1.8605506E-15', 'chunk2_confidence': '0.99795', 'entity1_begin': '301', 'sentence': '0', 'PIP_confidence': '1.3615511E-22', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '317', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.83052504'}, []),
#  Annotation(category, 301, 431, TeRP, {'TrWP_confidence': '5.5826918E-34', 'chunk2': 'vomiting', 'TrIP_confidence': '0.0', 'TrAP_confidence': '3.8564418E-26', 'TrNAP_confidence': '4.6497378E-32', 'confidence': '1.0', 'entity2_end': '431', 'chunk1': 'a body mass index', 'entity1': 'PROBLEM', 'entity2_begin': '424', 'TeRP_confidence': '1.0', 'TeCP_confidence': '1.0765974E-25', 'O_confidence': '1.1464487E-15', 'chunk2_confidence': '0.9931', 'entity1_begin': '301', 'sentence': '0', 'PIP_confidence': '3.7901865E-25', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '317', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.83052504'}, []),
#  Annotation(category, 321, 387, TeRP, {'TrWP_confidence': '2.1458018E-16', 'chunk2': 'polyuria', 'TrIP_confidence': '1.2189707E-17', 'TrAP_confidence': '1.1973469E-6', 'TrNAP_confidence': '7.490781E-17', 'confidence': '0.99756753', 'entity2_end': '387', 'chunk1': 'BMI', 'entity1': 'TEST', 'entity2_begin': '380', 'TeRP_confidence': '0.99756753', 'TeCP_confidence': '1.7112037E-12', 'O_confidence': '0.002431345', 'chunk2_confidence': '0.9901', 'entity1_begin': '321', 'sentence': '0', 'PIP_confidence': '1.0309234E-15', 'direction': 'both', 'TrCP_confidence': '1.8825471E-19', 'entity1_end': '323', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.6775'}, []),
#  Annotation(category, 321, 400, O, {'TrWP_confidence': '1.3318119E-16', 'chunk2': 'polydipsia', 'TrIP_confidence': '3.3434905E-16', 'TrAP_confidence': '0.016344216', 'TrNAP_confidence': '4.9620967E-17', 'confidence': '0.7831951', 'entity2_end': '400', 'chunk1': 'BMI', 'entity1': 'TEST', 'entity2_begin': '391', 'TeRP_confidence': '0.20046075', 'TeCP_confidence': '2.2511805E-11', 'O_confidence': '0.7831951', 'chunk2_confidence': '0.993', 'entity1_begin': '321', 'sentence': '0', 'PIP_confidence': '9.1875784E-17', 'direction': 'both', 'TrCP_confidence': '9.22659E-19', 'entity1_end': '323', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.6775'}, []),
#  Annotation(category, 321, 416, TeRP, {'TrWP_confidence': '2.4425976E-18', 'chunk2': 'poor appetite', 'TrIP_confidence': '6.392286E-23', 'TrAP_confidence': '0.0019993898', 'TrNAP_confidence': '1.8203158E-18', 'confidence': '0.9980003', 'entity2_end': '416', 'chunk1': 'BMI', 'entity1': 'TEST', 'entity2_begin': '404', 'TeRP_confidence': '0.9980003', 'TeCP_confidence': '6.071187E-14', 'O_confidence': '2.1087091E-7', 'chunk2_confidence': '0.99795', 'entity1_begin': '321', 'sentence': '0', 'PIP_confidence': '4.0952984E-17', 'direction': 'both', 'TrCP_confidence': '2.1207744E-25', 'entity1_end': '323', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.6775'}, []),
#  Annotation(category, 321, 431, TrAP, {'TrWP_confidence': '4.249478E-21', 'chunk2': 'vomiting', 'TrIP_confidence': '2.5057722E-23', 'TrAP_confidence': '0.894692', 'TrNAP_confidence': '7.928209E-20', 'confidence': '0.894692', 'entity2_end': '431', 'chunk1': 'BMI', 'entity1': 'TEST', 'entity2_begin': '424', 'TeRP_confidence': '0.08917765', 'TeCP_confidence': '7.552922E-13', 'O_confidence': '0.016130354', 'chunk2_confidence': '0.9931', 'entity1_begin': '321', 'sentence': '0', 'PIP_confidence': '6.1208884E-19', 'direction': 'both', 'TrCP_confidence': '7.3958275E-27', 'entity1_end': '323', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.6775'}, []),
#  Annotation(category, 380, 400, TeRP, {'TrWP_confidence': '4.7808025E-13', 'chunk2': 'polydipsia', 'TrIP_confidence': '8.326842E-14', 'TrAP_confidence': '2.2993014E-11', 'TrNAP_confidence': '6.37162E-12', 'confidence': '0.8024412', 'entity2_end': '400', 'chunk1': 'polyuria', 'entity1': 'PROBLEM', 'entity2_begin': '391', 'TeRP_confidence': '0.8024412', 'TeCP_confidence': '1.2489945E-5', 'O_confidence': '5.7832483E-4', 'chunk2_confidence': '0.993', 'entity1_begin': '380', 'sentence': '0', 'PIP_confidence': '0.19696799', 'direction': 'both', 'TrCP_confidence': '3.4416982E-16', 'entity1_end': '387', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9901'}, []),
#  Annotation(category, 380, 416, TeRP, {'TrWP_confidence': '6.927186E-14', 'chunk2': 'poor appetite', 'TrIP_confidence': '1.8003609E-16', 'TrAP_confidence': '2.869313E-12', 'TrNAP_confidence': '1.6424554E-12', 'confidence': '0.99934953', 'entity2_end': '416', 'chunk1': 'polyuria', 'entity1': 'PROBLEM', 'entity2_begin': '404', 'TeRP_confidence': '0.99934953', 'TeCP_confidence': '3.2058818E-8', 'O_confidence': '1.1115409E-7', 'chunk2_confidence': '0.99795', 'entity1_begin': '380', 'sentence': '0', 'PIP_confidence': '6.502912E-4', 'direction': 'both', 'TrCP_confidence': '7.610589E-19', 'entity1_end': '387', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9901'}, []),
#  Annotation(category, 380, 431, PIP, {'TrWP_confidence': '1.5195013E-15', 'chunk2': 'vomiting', 'TrIP_confidence': '1.0051138E-17', 'TrAP_confidence': '2.1011426E-14', 'TrNAP_confidence': '1.238613E-12', 'confidence': '0.7593606', 'entity2_end': '431', 'chunk1': 'polyuria', 'entity1': 'PROBLEM', 'entity2_begin': '424', 'TeRP_confidence': '0.2404879', 'TeCP_confidence': '4.6828664E-8', 'O_confidence': '1.5152656E-4', 'chunk2_confidence': '0.9931', 'entity1_begin': '380', 'sentence': '0', 'PIP_confidence': '0.7593606', 'direction': 'both', 'TrCP_confidence': '5.364099E-20', 'entity1_end': '387', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9901'}, []),
#  Annotation(category, 391, 416, TeRP, {'TrWP_confidence': '2.2497486E-14', 'chunk2': 'poor appetite', 'TrIP_confidence': '1.03957545E-16', 'TrAP_confidence': '6.366602E-13', 'TrNAP_confidence': '1.7060862E-13', 'confidence': '0.9879937', 'entity2_end': '416', 'chunk1': 'polydipsia', 'entity1': 'PROBLEM', 'entity2_begin': '404', 'TeRP_confidence': '0.9879937', 'TeCP_confidence': '2.3770056E-7', 'O_confidence': '7.650519E-7', 'chunk2_confidence': '0.99795', 'entity1_begin': '391', 'sentence': '0', 'PIP_confidence': '0.012005177', 'direction': 'both', 'TrCP_confidence': '5.806157E-19', 'entity1_end': '400', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.993'}, []),
#  Annotation(category, 391, 431, PIP, {'TrWP_confidence': '7.3940275E-16', 'chunk2': 'vomiting', 'TrIP_confidence': '1.2521163E-17', 'TrAP_confidence': '1.8243518E-15', 'TrNAP_confidence': '1.904841E-13', 'confidence': '0.999689', 'entity2_end': '431', 'chunk1': 'polydipsia', 'entity1': 'PROBLEM', 'entity2_begin': '424', 'TeRP_confidence': '3.099984E-4', 'TeCP_confidence': '5.3411775E-10', 'O_confidence': '1.070761E-6', 'chunk2_confidence': '0.9931', 'entity1_begin': '391', 'sentence': '0', 'PIP_confidence': '0.999689', 'direction': 'both', 'TrCP_confidence': '5.436946E-20', 'entity1_end': '400', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.993'}, []),
#  Annotation(category, 404, 431, PIP, {'TrWP_confidence': '1.4329012E-18', 'chunk2': 'vomiting', 'TrIP_confidence': '4.044257E-20', 'TrAP_confidence': '5.010461E-19', 'TrNAP_confidence': '1.8281159E-16', 'confidence': '0.99999964', 'entity2_end': '431', 'chunk1': 'poor appetite', 'entity1': 'PROBLEM', 'entity2_begin': '424', 'TeRP_confidence': '2.4440317E-7', 'TeCP_confidence': '5.823498E-12', 'O_confidence': '1.1942699E-7', 'chunk2_confidence': '0.9931', 'entity1_begin': '404', 'sentence': '0', 'PIP_confidence': '0.99999964', 'direction': 'both', 'TrCP_confidence': '2.0323449E-22', 'entity1_end': '416', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.99795'}, []),
#  Annotation(category, 570, 590, O, {'TrWP_confidence': '5.789118E-18', 'chunk2': 'glipizide', 'TrIP_confidence': '4.6499195E-15', 'TrAP_confidence': '5.7578833E-12', 'TrNAP_confidence': '7.741721E-21', 'confidence': '1.0', 'entity2_end': '590', 'chunk1': 'metformin', 'entity1': 'TREATMENT', 'entity2_begin': '582', 'TeRP_confidence': '7.017608E-13', 'TeCP_confidence': '2.7022409E-19', 'O_confidence': '1.0', 'chunk2_confidence': '0.9999', 'entity1_begin': '570', 'sentence': '2', 'PIP_confidence': '1.3319984E-26', 'direction': 'both', 'TrCP_confidence': '8.452901E-12', 'entity1_end': '578', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.9998'}, []),
#  Annotation(category, 570, 610, O, {'TrWP_confidence': '9.3889045E-15', 'chunk2': 'dapagliflozin', 'TrIP_confidence': '1.3459692E-13', 'TrAP_confidence': '2.5112913E-8', 'TrNAP_confidence': '1.3043503E-15', 'confidence': '1.0', 'entity2_end': '610', 'chunk1': 'metformin', 'entity1': 'TREATMENT', 'entity2_begin': '598', 'TeRP_confidence': '4.8874984E-9', 'TeCP_confidence': '1.9191497E-15', 'O_confidence': '1.0', 'chunk2_confidence': '1.0', 'entity1_begin': '570', 'sentence': '2', 'PIP_confidence': '1.06392746E-20', 'direction': 'both', 'TrCP_confidence': '5.1707727E-12', 'entity1_end': '578', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.9998'}, []),
#  Annotation(category, 570, 636, O, {'TrWP_confidence': '5.454336E-23', 'chunk2': 'atorvastatin', 'TrIP_confidence': '1.5782224E-22', 'TrAP_confidence': '1.4018369E-12', 'TrNAP_confidence': '2.6963633E-25', 'confidence': '1.0', 'entity2_end': '636', 'chunk1': 'metformin', 'entity1': 'TREATMENT', 'entity2_begin': '625', 'TeRP_confidence': '2.334003E-13', 'TeCP_confidence': '8.0241615E-25', 'O_confidence': '1.0', 'chunk2_confidence': '0.9999', 'entity1_begin': '570', 'sentence': '2', 'PIP_confidence': '1.9009974E-32', 'direction': 'both', 'TrCP_confidence': '9.7093724E-20', 'entity1_end': '578', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.9998'}, []),
#  Annotation(category, 570, 652, O, {'TrWP_confidence': '1.20154195E-29', 'chunk2': 'gemfibrozil', 'TrIP_confidence': '1.7625171E-28', 'TrAP_confidence': '6.8211993E-17', 'TrNAP_confidence': '5.191156E-32', 'confidence': '1.0', 'entity2_end': '652', 'chunk1': 'metformin', 'entity1': 'TREATMENT', 'entity2_begin': '642', 'TeRP_confidence': '6.504462E-18', 'TeCP_confidence': '1.0065411E-29', 'O_confidence': '1.0', 'chunk2_confidence': '1.0', 'entity1_begin': '570', 'sentence': '2', 'PIP_confidence': '0.0', 'direction': 'both', 'TrCP_confidence': '1.3051302E-25', 'entity1_end': '578', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.9998'}, []),
#  Annotation(category, 582, 610, O, {'TrWP_confidence': '6.2576194E-12', 'chunk2': 'dapagliflozin', 'TrIP_confidence': '1.8650445E-10', 'TrAP_confidence': '1.8589293E-4', 'TrNAP_confidence': '1.8253754E-13', 'confidence': '0.999814', 'entity2_end': '610', 'chunk1': 'glipizide', 'entity1': 'TREATMENT', 'entity2_begin': '598', 'TeRP_confidence': '1.95193E-7', 'TeCP_confidence': '7.1206895E-14', 'O_confidence': '0.999814', 'chunk2_confidence': '1.0', 'entity1_begin': '582', 'sentence': '2', 'PIP_confidence': '1.3581416E-18', 'direction': 'both', 'TrCP_confidence': '3.7655003E-8', 'entity1_end': '590', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.9999'}, []),
#  Annotation(category, 582, 636, O, {'TrWP_confidence': '5.835416E-17', 'chunk2': 'atorvastatin', 'TrIP_confidence': '2.3698491E-17', 'TrAP_confidence': '3.036089E-9', 'TrNAP_confidence': '6.340297E-19', 'confidence': '1.0', 'entity2_end': '636', 'chunk1': 'glipizide', 'entity1': 'TREATMENT', 'entity2_begin': '625', 'TeRP_confidence': '3.1688013E-10', 'TeCP_confidence': '9.756818E-21', 'O_confidence': '1.0', 'chunk2_confidence': '0.9999', 'entity1_begin': '582', 'sentence': '2', 'PIP_confidence': '2.4662826E-26', 'direction': 'both', 'TrCP_confidence': '3.4468264E-14', 'entity1_end': '590', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.9999'}, []),
#  Annotation(category, 582, 652, O, {'TrWP_confidence': '6.881496E-24', 'chunk2': 'gemfibrozil', 'TrIP_confidence': '1.5303125E-23', 'TrAP_confidence': '1.7056009E-13', 'TrNAP_confidence': '5.3986645E-26', 'confidence': '1.0', 'entity2_end': '652', 'chunk1': 'glipizide', 'entity1': 'TREATMENT', 'entity2_begin': '642', 'TeRP_confidence': '5.735667E-15', 'TeCP_confidence': '3.339446E-26', 'O_confidence': '1.0', 'chunk2_confidence': '1.0', 'entity1_begin': '582', 'sentence': '2', 'PIP_confidence': '1.5982429E-33', 'direction': 'both', 'TrCP_confidence': '4.2887156E-20', 'entity1_end': '590', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.9999'}, []),
#  Annotation(category, 598, 636, O, {'TrWP_confidence': '2.3959282E-13', 'chunk2': 'atorvastatin', 'TrIP_confidence': '2.2354807E-12', 'TrAP_confidence': '7.9592236E-11', 'TrNAP_confidence': '1.0564931E-14', 'confidence': '1.0', 'entity2_end': '636', 'chunk1': 'dapagliflozin', 'entity1': 'TREATMENT', 'entity2_begin': '625', 'TeRP_confidence': '5.8282012E-8', 'TeCP_confidence': '5.3283156E-14', 'O_confidence': '1.0', 'chunk2_confidence': '0.9999', 'entity1_begin': '598', 'sentence': '2', 'PIP_confidence': '1.7014043E-19', 'direction': 'both', 'TrCP_confidence': '4.0509646E-10', 'entity1_end': '610', 'entity2': 'TREATMENT', 'chunk1_confidence': '1.0'}, []),
#  Annotation(category, 598, 652, O, {'TrWP_confidence': '3.4801685E-17', 'chunk2': 'gemfibrozil', 'TrIP_confidence': '8.491642E-18', 'TrAP_confidence': '2.2691321E-14', 'TrNAP_confidence': '1.9249673E-19', 'confidence': '1.0', 'entity2_end': '652', 'chunk1': 'dapagliflozin', 'entity1': 'TREATMENT', 'entity2_begin': '642', 'TeRP_confidence': '2.9618148E-11', 'TeCP_confidence': '9.21508E-21', 'O_confidence': '1.0', 'chunk2_confidence': '1.0', 'entity1_begin': '598', 'sentence': '2', 'PIP_confidence': '4.6744723E-26', 'direction': 'both', 'TrCP_confidence': '3.1360734E-14', 'entity1_end': '610', 'entity2': 'TREATMENT', 'chunk1_confidence': '1.0'}, []),
#  Annotation(category, 616, 636, O, {'TrWP_confidence': '1.273928E-27', 'chunk2': 'atorvastatin', 'TrIP_confidence': '2.2899783E-27', 'TrAP_confidence': '1.21245E-28', 'TrNAP_confidence': '2.818948E-26', 'confidence': '1.0', 'entity2_end': '636', 'chunk1': 'T2DM', 'entity1': 'PROBLEM', 'entity2_begin': '625', 'TeRP_confidence': '4.6251285E-14', 'TeCP_confidence': '2.7008715E-18', 'O_confidence': '1.0', 'chunk2_confidence': '0.9999', 'entity1_begin': '616', 'sentence': '2', 'PIP_confidence': '4.1419554E-10', 'direction': 'both', 'TrCP_confidence': '1.3036658E-27', 'entity1_end': '619', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.9995'}, []),
#  Annotation(category, 616, 652, O, {'TrWP_confidence': '4.379748E-27', 'chunk2': 'gemfibrozil', 'TrIP_confidence': '4.9307846E-28', 'TrAP_confidence': '5.1190135E-29', 'TrNAP_confidence': '4.9474453E-26', 'confidence': '1.0', 'entity2_end': '652', 'chunk1': 'T2DM', 'entity1': 'PROBLEM', 'entity2_begin': '642', 'TeRP_confidence': '7.7795495E-15', 'TeCP_confidence': '2.15163E-19', 'O_confidence': '1.0', 'chunk2_confidence': '1.0', 'entity1_begin': '616', 'sentence': '2', 'PIP_confidence': '1.2589693E-11', 'direction': 'both', 'TrCP_confidence': '7.07071E-27', 'entity1_end': '619', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.9995'}, []),
#  Annotation(category, 616, 660, TeRP, {'TrWP_confidence': '1.2082613E-16', 'chunk2': 'HTG', 'TrIP_confidence': '3.7467494E-16', 'TrAP_confidence': '5.5081455E-13', 'TrNAP_confidence': '2.0341274E-14', 'confidence': '0.91954094', 'entity2_end': '660', 'chunk1': 'T2DM', 'entity1': 'PROBLEM', 'entity2_begin': '658', 'TeRP_confidence': '0.91954094', 'TeCP_confidence': '8.69727E-6', 'O_confidence': '0.08040715', 'chunk2_confidence': '0.9994', 'entity1_begin': '616', 'sentence': '2', 'PIP_confidence': '4.3170163E-5', 'direction': 'both', 'TrCP_confidence': '3.7089014E-20', 'entity1_end': '619', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9995'}, []),
#  Annotation(category, 625, 652, O, {'TrWP_confidence': '3.3786324E-17', 'chunk2': 'gemfibrozil', 'TrIP_confidence': '3.158029E-15', 'TrAP_confidence': '6.3408064E-11', 'TrNAP_confidence': '1.7132381E-19', 'confidence': '1.0', 'entity2_end': '652', 'chunk1': 'atorvastatin', 'entity1': 'TREATMENT', 'entity2_begin': '642', 'TeRP_confidence': '1.239422E-8', 'TeCP_confidence': '4.607927E-16', 'O_confidence': '1.0', 'chunk2_confidence': '1.0', 'entity1_begin': '625', 'sentence': '2', 'PIP_confidence': '1.6441423E-23', 'direction': 'both', 'TrCP_confidence': '2.9463958E-13', 'entity1_end': '636', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.9999'}, []),
#  Annotation(category, 738, 809, TeRP, {'TrWP_confidence': '7.1012434E-15', 'chunk2': 'dry oral mucosa', 'TrIP_confidence': '7.98527E-30', 'TrAP_confidence': '3.0467763E-19', 'TrNAP_confidence': '1.7546904E-18', 'confidence': '1.0', 'entity2_end': '809', 'chunk1': 'Physical examination', 'entity1': 'TEST', 'entity2_begin': '795', 'TeRP_confidence': '1.0', 'TeCP_confidence': '1.1281941E-20', 'O_confidence': '3.2530088E-12', 'chunk2_confidence': '0.70489997', 'entity1_begin': '738', 'sentence': '4', 'PIP_confidence': '3.4185013E-15', 'direction': 'both', 'TrCP_confidence': '8.4534365E-26', 'entity1_end': '757', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.95015'}, []),
#  Annotation(category, 829, 883, TeRP, {'TrWP_confidence': '3.037949E-16', 'chunk2': 'tenderness', 'TrIP_confidence': '3.944596E-27', 'TrAP_confidence': '1.7722287E-17', 'TrNAP_confidence': '5.3394524E-19', 'confidence': '1.0', 'entity2_end': '883', 'chunk1': 'her abdominal examination', 'entity1': 'TEST', 'entity2_begin': '874', 'TeRP_confidence': '1.0', 'TeCP_confidence': '6.7528937E-19', 'O_confidence': '1.6721038E-10', 'chunk2_confidence': '0.9996', 'entity1_begin': '829', 'sentence': '5', 'PIP_confidence': '3.3347037E-15', 'direction': 'both', 'TrCP_confidence': '4.655665E-25', 'entity1_end': '853', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9342666'}, []),
#  Annotation(category, 829, 894, TeRP, {'TrWP_confidence': '3.6204445E-14', 'chunk2': 'guarding', 'TrIP_confidence': '5.465033E-26', 'TrAP_confidence': '1.1145252E-16', 'TrNAP_confidence': '3.277293E-18', 'confidence': '1.0', 'entity2_end': '894', 'chunk1': 'her abdominal examination', 'entity1': 'TEST', 'entity2_begin': '887', 'TeRP_confidence': '1.0', 'TeCP_confidence': '7.597259E-20', 'O_confidence': '1.4475559E-8', 'chunk2_confidence': '0.9993', 'entity1_begin': '829', 'sentence': '5', 'PIP_confidence': '1.1409902E-16', 'direction': 'both', 'TrCP_confidence': '3.9888338E-23', 'entity1_end': '853', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9342666'}, []),
#  Annotation(category, 829, 908, TeRP, {'TrWP_confidence': '9.983757E-17', 'chunk2': 'rigidity', 'TrIP_confidence': '1.2980656E-31', 'TrAP_confidence': '5.407402E-19', 'TrNAP_confidence': '1.388586E-21', 'confidence': '1.0', 'entity2_end': '908', 'chunk1': 'her abdominal examination', 'entity1': 'TEST', 'entity2_begin': '901', 'TeRP_confidence': '1.0', 'TeCP_confidence': '6.307476E-23', 'O_confidence': '5.6561414E-12', 'chunk2_confidence': '0.9989', 'entity1_begin': '829', 'sentence': '5', 'PIP_confidence': '5.009474E-17', 'direction': 'both', 'TrCP_confidence': '5.06098E-28', 'entity1_end': '853', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9342666'}, []),
#  Annotation(category, 874, 894, PIP, {'TrWP_confidence': '4.6762886E-24', 'chunk2': 'guarding', 'TrIP_confidence': '3.1539988E-25', 'TrAP_confidence': '6.0090074E-25', 'TrNAP_confidence': '1.804517E-21', 'confidence': '0.99999833', 'entity2_end': '894', 'chunk1': 'tenderness', 'entity1': 'PROBLEM', 'entity2_begin': '887', 'TeRP_confidence': '3.9592255E-13', 'TeCP_confidence': '9.4668455E-18', 'O_confidence': '1.7121425E-6', 'chunk2_confidence': '0.9993', 'entity1_begin': '874', 'sentence': '5', 'PIP_confidence': '0.99999833', 'direction': 'both', 'TrCP_confidence': '5.1354984E-27', 'entity1_end': '883', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9996'}, []),
#  Annotation(category, 874, 908, PIP, {'TrWP_confidence': '7.305676E-22', 'chunk2': 'rigidity', 'TrIP_confidence': '6.762702E-23', 'TrAP_confidence': '1.9695324E-21', 'TrNAP_confidence': '1.2056395E-18', 'confidence': '1.0', 'entity2_end': '908', 'chunk1': 'tenderness', 'entity1': 'PROBLEM', 'entity2_begin': '901', 'TeRP_confidence': '7.3509554E-9', 'TeCP_confidence': '2.1218924E-14', 'O_confidence': '6.8684485E-9', 'chunk2_confidence': '0.9989', 'entity1_begin': '874', 'sentence': '5', 'PIP_confidence': '1.0', 'direction': 'both', 'TrCP_confidence': '2.0226659E-26', 'entity1_end': '883', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9996'}, []),
#  Annotation(category, 887, 908, PIP, {'TrWP_confidence': '2.0781538E-22', 'chunk2': 'rigidity', 'TrIP_confidence': '6.401192E-21', 'TrAP_confidence': '1.4459121E-22', 'TrNAP_confidence': '9.701496E-18', 'confidence': '1.0', 'entity2_end': '908', 'chunk1': 'guarding', 'entity1': 'PROBLEM', 'entity2_begin': '901', 'TeRP_confidence': '2.6897278E-13', 'TeCP_confidence': '7.4186344E-13', 'O_confidence': '3.3297074E-8', 'chunk2_confidence': '0.9989', 'entity1_begin': '887', 'sentence': '5', 'PIP_confidence': '1.0', 'direction': 'both', 'TrCP_confidence': '2.3167898E-24', 'entity1_end': '894', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9993'}, []),
#  Annotation(category, 962, 998, TeRP, {'TrWP_confidence': '5.353517E-12', 'chunk2': 'bicarbonate', 'TrIP_confidence': '2.2905036E-16', 'TrAP_confidence': '2.932709E-11', 'TrNAP_confidence': '4.9501497E-14', 'confidence': '0.99821126', 'entity2_end': '998', 'chunk1': 'serum glucose', 'entity1': 'TEST', 'entity2_begin': '988', 'TeRP_confidence': '0.99821126', 'TeCP_confidence': '1.1831121E-12', 'O_confidence': '0.0017887607', 'chunk2_confidence': '0.9997', 'entity1_begin': '962', 'sentence': '6', 'PIP_confidence': '9.067594E-11', 'direction': 'both', 'TrCP_confidence': '3.1978464E-16', 'entity1_end': '974', 'entity2': 'TEST', 'chunk1_confidence': '0.972'}, []),
# ...
#  Annotation(category, 1675, 1739, TeRP, {'TrWP_confidence': '1.5361809E-13', 'chunk2': 'elevated', 'TrIP_confidence': '2.0444843E-29', 'TrAP_confidence': '2.853312E-16', 'TrNAP_confidence': '4.4313574E-20', 'confidence': '1.0', 'entity2_end': '1739', 'chunk1': 'The β-hydroxybutyrate level', 'entity1': 'TEST', 'entity2_begin': '1732', 'TeRP_confidence': '1.0', 'TeCP_confidence': '1.874744E-21', 'O_confidence': '4.323854E-12', 'chunk2_confidence': '0.8527', 'entity1_begin': '1675', 'sentence': '11', 'PIP_confidence': '6.142825E-15', 'direction': 'both', 'TrCP_confidence': '1.349564E-23', 'entity1_end': '1701', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.8511'}, []),
#  Annotation(category, 1675, 1844, TeRP, {'TrWP_confidence': '3.5994004E-34', 'chunk2': 'analysis', 'TrIP_confidence': '0.0', 'TrAP_confidence': '4.9256498E-29', 'TrNAP_confidence': '2.1575268E-38', 'confidence': '1.0', 'entity2_end': '1844', 'chunk1': 'The β-hydroxybutyrate level', 'entity1': 'TEST', 'entity2_begin': '1837', 'TeRP_confidence': '1.0', 'TeCP_confidence': '3.4085018E-37', 'O_confidence': '1.8370148E-17', 'chunk2_confidence': '0.9949', 'entity1_begin': '1675', 'sentence': '11', 'PIP_confidence': '4.3918265E-35', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '1701', 'entity2': 'TEST', 'chunk1_confidence': '0.8511'}, []),
#  Annotation(category, 1675, 1879, TeRP, {'TrWP_confidence': '3.4943425E-21', 'chunk2': 'interference from turbidity', 'TrIP_confidence': '0.0', 'TrAP_confidence': '1.00538294E-20', 'TrNAP_confidence': '1.2587771E-30', 'confidence': '1.0', 'entity2_end': '1879', 'chunk1': 'The β-hydroxybutyrate level', 'entity1': 'TEST', 'entity2_begin': '1853', 'TeRP_confidence': '1.0', 'TeCP_confidence': '0.0', 'O_confidence': '1.1254797E-16', 'chunk2_confidence': '0.88926667', 'entity1_begin': '1675', 'sentence': '11', 'PIP_confidence': '3.495887E-37', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '1701', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.8511'}, []),
#  Annotation(category, 1675, 1897, TeRP, {'TrWP_confidence': '0.0', 'chunk2': 'lipemia', 'TrIP_confidence': '0.0', 'TrAP_confidence': '3.644272E-28', 'TrNAP_confidence': '0.0', 'confidence': '1.0', 'entity2_end': '1897', 'chunk1': 'The β-hydroxybutyrate level', 'entity1': 'TEST', 'entity2_begin': '1891', 'TeRP_confidence': '1.0', 'TeCP_confidence': '0.0', 'O_confidence': '4.0770818E-20', 'chunk2_confidence': '0.9957', 'entity1_begin': '1675', 'sentence': '11', 'PIP_confidence': '0.0', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '1701', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.8511'}, []),
#  Annotation(category, 1732, 1844, O, {'TrWP_confidence': '6.5456338E-34', 'chunk2': 'analysis', 'TrIP_confidence': '1.2513493E-35', 'TrAP_confidence': '3.688881E-27', 'TrNAP_confidence': '3.117017E-29', 'confidence': '0.9762175', 'entity2_end': '1844', 'chunk1': 'elevated', 'entity1': 'PROBLEM', 'entity2_begin': '1837', 'TeRP_confidence': '0.023782464', 'TeCP_confidence': '1.5188144E-14', 'O_confidence': '0.9762175', 'chunk2_confidence': '0.9949', 'entity1_begin': '1732', 'sentence': '11', 'PIP_confidence': '3.0130848E-13', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '1739', 'entity2': 'TEST', 'chunk1_confidence': '0.8527'}, []),
#  Annotation(category, 1732, 1879, TeRP, {'TrWP_confidence': '0.0', 'chunk2': 'interference from turbidity', 'TrIP_confidence': '0.0', 'TrAP_confidence': '5.566165E-28', 'TrNAP_confidence': '9.851481E-35', 'confidence': '1.0', 'entity2_end': '1879', 'chunk1': 'elevated', 'entity1': 'PROBLEM', 'entity2_begin': '1853', 'TeRP_confidence': '1.0', 'TeCP_confidence': '1.5723773E-27', 'O_confidence': '2.843203E-19', 'chunk2_confidence': '0.88926667', 'entity1_begin': '1732', 'sentence': '11', 'PIP_confidence': '3.9777553E-31', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '1739', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.8527'}, []),
#  Annotation(category, 1732, 1897, TeRP, {'TrWP_confidence': '0.0', 'chunk2': 'lipemia', 'TrIP_confidence': '0.0', 'TrAP_confidence': '3.0169876E-31', 'TrNAP_confidence': '0.0', 'confidence': '0.9999999', 'entity2_end': '1897', 'chunk1': 'elevated', 'entity1': 'PROBLEM', 'entity2_begin': '1891', 'TeRP_confidence': '0.9999999', 'TeCP_confidence': '9.5703564E-23', 'O_confidence': '8.608316E-8', 'chunk2_confidence': '0.9957', 'entity1_begin': '1732', 'sentence': '11', 'PIP_confidence': '3.7781044E-32', 'direction': 'both', 'TrCP_confidence': '0.0', 'entity1_end': '1739', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.8527'}, []),
#  Annotation(category, 1837, 1879, TeRP, {'TrWP_confidence': '4.0079006E-11', 'chunk2': 'interference from turbidity', 'TrIP_confidence': '3.244235E-23', 'TrAP_confidence': '8.046577E-8', 'TrNAP_confidence': '3.418634E-21', 'confidence': '0.9999999', 'entity2_end': '1879', 'chunk1': 'analysis', 'entity1': 'TEST', 'entity2_begin': '1853', 'TeRP_confidence': '0.9999999', 'TeCP_confidence': '2.24559E-21', 'O_confidence': '3.6356407E-10', 'chunk2_confidence': '0.88926667', 'entity1_begin': '1837', 'sentence': '11', 'PIP_confidence': '6.538625E-16', 'direction': 'both', 'TrCP_confidence': '2.8745017E-19', 'entity1_end': '1844', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9949'}, []),
#  Annotation(category, 1837, 1897, TeRP, {'TrWP_confidence': '6.137494E-12', 'chunk2': 'lipemia', 'TrIP_confidence': '1.7003038E-16', 'TrAP_confidence': '3.031577E-8', 'TrNAP_confidence': '1.9500887E-12', 'confidence': '1.0', 'entity2_end': '1897', 'chunk1': 'analysis', 'entity1': 'TEST', 'entity2_begin': '1891', 'TeRP_confidence': '1.0', 'TeCP_confidence': '1.0850734E-8', 'O_confidence': '1.28124595E-8', 'chunk2_confidence': '0.9957', 'entity1_begin': '1837', 'sentence': '11', 'PIP_confidence': '1.6044865E-10', 'direction': 'both', 'TrCP_confidence': '1.6144645E-16', 'entity1_end': '1844', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9949'}, []),
#  Annotation(category, 1853, 1897, TeRP, {'TrWP_confidence': '1.113359E-18', 'chunk2': 'lipemia', 'TrIP_confidence': '1.1791452E-24', 'TrAP_confidence': '9.279359E-18', 'TrNAP_confidence': '4.9573642E-17', 'confidence': '0.9999994', 'entity2_end': '1897', 'chunk1': 'interference from turbidity', 'entity1': 'PROBLEM', 'entity2_begin': '1891', 'TeRP_confidence': '0.9999994', 'TeCP_confidence': '5.527356E-13', 'O_confidence': '1.9269672E-7', 'chunk2_confidence': '0.9957', 'entity1_begin': '1853', 'sentence': '11', 'PIP_confidence': '3.523025E-7', 'direction': 'both', 'TrCP_confidence': '3.4628048E-25', 'entity1_end': '1879', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.88926667'}, []),
#  Annotation(category, 1936, 1985, O, {'TrWP_confidence': '1.8898943E-11', 'chunk2': 'a reduction', 'TrIP_confidence': '1.6584328E-15', 'TrAP_confidence': '8.186833E-13', 'TrNAP_confidence': '1.9675764E-14', 'confidence': '0.99999845', 'entity2_end': '1985', 'chunk1': 'an insulin drip', 'entity1': 'TREATMENT', 'entity2_begin': '1975', 'TeRP_confidence': '1.5000604E-6', 'TeCP_confidence': '2.5406115E-17', 'O_confidence': '0.99999845', 'chunk2_confidence': '0.56735003', 'entity1_begin': '1936', 'sentence': '12', 'PIP_confidence': '9.558495E-21', 'direction': 'both', 'TrCP_confidence': '5.735427E-12', 'entity1_end': '1950', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.97396666'}, []),
#  Annotation(category, 1936, 2002, TeRP, {'TrWP_confidence': '0.11232612', 'chunk2': 'the anion gap', 'TrIP_confidence': '1.0785525E-13', 'TrAP_confidence': '5.873502E-5', 'TrNAP_confidence': '1.2183615E-6', 'confidence': '0.8420974', 'entity2_end': '2002', 'chunk1': 'an insulin drip', 'entity1': 'TREATMENT', 'entity2_begin': '1990', 'TeRP_confidence': '0.8420974', 'TeCP_confidence': '7.870833E-15', 'O_confidence': '0.045516536', 'chunk2_confidence': '0.47016668', 'entity1_begin': '1936', 'sentence': '12', 'PIP_confidence': '1.5600006E-13', 'direction': 'both', 'TrCP_confidence': '9.9136095E-9', 'entity1_end': '1950', 'entity2': 'TEST', 'chunk1_confidence': '0.97396666'}, []),
#  Annotation(category, 1936, 2026, TeRP, {'TrWP_confidence': '2.8567545E-6', 'chunk2': 'triglycerides', 'TrIP_confidence': '2.425856E-21', 'TrAP_confidence': '1.1657226E-4', 'TrNAP_confidence': '3.696949E-14', 'confidence': '0.9854799', 'entity2_end': '2026', 'chunk1': 'an insulin drip', 'entity1': 'TREATMENT', 'entity2_begin': '2014', 'TeRP_confidence': '0.9854799', 'TeCP_confidence': '1.1642721E-20', 'O_confidence': '0.014400713', 'chunk2_confidence': '0.9965', 'entity1_begin': '1936', 'sentence': '12', 'PIP_confidence': '1.6537618E-19', 'direction': 'both', 'TrCP_confidence': '2.158406E-15', 'entity1_end': '1950', 'entity2': 'TEST', 'chunk1_confidence': '0.97396666'}, []),
#  Annotation(category, 1956, 1968, PIP, {'TrWP_confidence': '1.417984E-17', 'chunk2': 'HTG', 'TrIP_confidence': '6.073558E-16', 'TrAP_confidence': '5.394642E-17', 'TrNAP_confidence': '1.5134981E-13', 'confidence': '0.99999774', 'entity2_end': '1968', 'chunk1': 'euDKA', 'entity1': 'PROBLEM', 'entity2_begin': '1966', 'TeRP_confidence': '2.6921139E-9', 'TeCP_confidence': '1.1017653E-8', 'O_confidence': '2.2127786E-6', 'chunk2_confidence': '0.9839', 'entity1_begin': '1956', 'sentence': '12', 'PIP_confidence': '0.99999774', 'direction': 'both', 'TrCP_confidence': '3.3255302E-19', 'entity1_end': '1960', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9847'}, []),
#  Annotation(category, 1956, 1985, O, {'TrWP_confidence': '6.588238E-27', 'chunk2': 'a reduction', 'TrIP_confidence': '6.2842628E-27', 'TrAP_confidence': '2.5590309E-30', 'TrNAP_confidence': '2.1593537E-24', 'confidence': '1.0', 'entity2_end': '1985', 'chunk1': 'euDKA', 'entity1': 'PROBLEM', 'entity2_begin': '1975', 'TeRP_confidence': '1.4667707E-17', 'TeCP_confidence': '2.0181663E-17', 'O_confidence': '1.0', 'chunk2_confidence': '0.56735003', 'entity1_begin': '1956', 'sentence': '12', 'PIP_confidence': '7.102264E-10', 'direction': 'both', 'TrCP_confidence': '1.2941932E-25', 'entity1_end': '1960', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.9847'}, []),
#  Annotation(category, 1956, 2002, PIP, {'TrWP_confidence': '5.6138505E-17', 'chunk2': 'the anion gap', 'TrIP_confidence': '3.447318E-17', 'TrAP_confidence': '3.80193E-16', 'TrNAP_confidence': '2.1946934E-11', 'confidence': '0.9738799', 'entity2_end': '2002', 'chunk1': 'euDKA', 'entity1': 'PROBLEM', 'entity2_begin': '1990', 'TeRP_confidence': '6.156727E-5', 'TeCP_confidence': '3.1098517E-9', 'O_confidence': '0.026058573', 'chunk2_confidence': '0.47016668', 'entity1_begin': '1956', 'sentence': '12', 'PIP_confidence': '0.9738799', 'direction': 'both', 'TrCP_confidence': '1.6701503E-19', 'entity1_end': '1960', 'entity2': 'TEST', 'chunk1_confidence': '0.9847'}, []),
#  Annotation(category, 1956, 2026, O, {'TrWP_confidence': '1.64108E-20', 'chunk2': 'triglycerides', 'TrIP_confidence': '1.6174241E-22', 'TrAP_confidence': '3.054236E-18', 'TrNAP_confidence': '1.5325263E-15', 'confidence': '0.87599975', 'entity2_end': '2026', 'chunk1': 'euDKA', 'entity1': 'PROBLEM', 'entity2_begin': '2014', 'TeRP_confidence': '0.122975715', 'TeCP_confidence': '3.5703578E-9', 'O_confidence': '0.87599975', 'chunk2_confidence': '0.9965', 'entity1_begin': '1956', 'sentence': '12', 'PIP_confidence': '0.0010245122', 'direction': 'both', 'TrCP_confidence': '1.3515044E-25', 'entity1_end': '1960', 'entity2': 'TEST', 'chunk1_confidence': '0.9847'}, []),
#  Annotation(category, 1966, 1985, O, {'TrWP_confidence': '2.2662302E-25', 'chunk2': 'a reduction', 'TrIP_confidence': '1.4629874E-25', 'TrAP_confidence': '1.634709E-26', 'TrNAP_confidence': '1.2781552E-24', 'confidence': '1.0', 'entity2_end': '1985', 'chunk1': 'HTG', 'entity1': 'PROBLEM', 'entity2_begin': '1975', 'TeRP_confidence': '5.2409097E-13', 'TeCP_confidence': '1.5897794E-17', 'O_confidence': '1.0', 'chunk2_confidence': '0.56735003', 'entity1_begin': '1966', 'sentence': '12', 'PIP_confidence': '9.173319E-11', 'direction': 'both', 'TrCP_confidence': '2.7866285E-25', 'entity1_end': '1968', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.9839'}, []),
#  Annotation(category, 1966, 2002, TeRP, {'TrWP_confidence': '2.1144253E-14', 'chunk2': 'the anion gap', 'TrIP_confidence': '6.463459E-15', 'TrAP_confidence': '2.12183E-11', 'TrNAP_confidence': '2.7098365E-12', 'confidence': '0.9764806', 'entity2_end': '2002', 'chunk1': 'HTG', 'entity1': 'PROBLEM', 'entity2_begin': '1990', 'TeRP_confidence': '0.9764806', 'TeCP_confidence': '1.3867471E-8', 'O_confidence': '0.0012301522', 'chunk2_confidence': '0.47016668', 'entity1_begin': '1966', 'sentence': '12', 'PIP_confidence': '0.022289239', 'direction': 'both', 'TrCP_confidence': '1.4823335E-18', 'entity1_end': '1968', 'entity2': 'TEST', 'chunk1_confidence': '0.9839'}, []),
#  Annotation(category, 1966, 2026, TeRP, {'TrWP_confidence': '1.3273827E-21', 'chunk2': 'triglycerides', 'TrIP_confidence': '2.3704693E-23', 'TrAP_confidence': '1.687215E-17', 'TrNAP_confidence': '1.043813E-19', 'confidence': '0.9998374', 'entity2_end': '2026', 'chunk1': 'HTG', 'entity1': 'PROBLEM', 'entity2_begin': '2014', 'TeRP_confidence': '0.9998374', 'TeCP_confidence': '5.373708E-11', 'O_confidence': '1.6253651E-4', 'chunk2_confidence': '0.9965', 'entity1_begin': '1966', 'sentence': '12', 'PIP_confidence': '1.2567669E-10', 'direction': 'both', 'TrCP_confidence': '2.5251178E-27', 'entity1_end': '1968', 'entity2': 'TEST', 'chunk1_confidence': '0.9839'}, []),
#  Annotation(category, 1990, 2026, TeRP, {'TrWP_confidence': '6.195615E-13', 'chunk2': 'triglycerides', 'TrIP_confidence': '3.1966907E-16', 'TrAP_confidence': '1.0982702E-11', 'TrNAP_confidence': '2.7161706E-12', 'confidence': '0.99999964', 'entity2_end': '2026', 'chunk1': 'the anion gap', 'entity1': 'TEST', 'entity2_begin': '2014', 'TeRP_confidence': '0.99999964', 'TeCP_confidence': '7.072596E-8', 'O_confidence': '3.0609831E-7', 'chunk2_confidence': '0.9965', 'entity1_begin': '1990', 'sentence': '12', 'PIP_confidence': '1.981323E-8', 'direction': 'both', 'TrCP_confidence': '3.8716993E-17', 'entity1_end': '2002', 'entity2': 'TEST', 'chunk1_confidence': '0.47016668'}, []),
#  Annotation(category, 2106, 2170, O, {'TrWP_confidence': '1.8017604E-25', 'chunk2': 'SGLT2 inhibitor', 'TrIP_confidence': '2.5723209E-33', 'TrAP_confidence': '4.1581315E-29', 'TrNAP_confidence': '7.207986E-24', 'confidence': '0.9999974', 'entity2_end': '2170', 'chunk1': 'her respiratory tract infection', 'entity1': 'PROBLEM', 'entity2_begin': '2156', 'TeRP_confidence': '9.689912E-7', 'TeCP_confidence': '1.5888203E-21', 'O_confidence': '0.9999974', 'chunk2_confidence': '0.9021', 'entity1_begin': '2106', 'sentence': '13', 'PIP_confidence': '1.645087E-6', 'direction': 'both', 'TrCP_confidence': '4.388073E-31', 'entity1_end': '2136', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.899625'}, []),
#  Annotation(category, 2266, 2319, O, {'TrWP_confidence': '0.005325243', 'chunk2': 'insulin lispro', 'TrIP_confidence': '6.829999E-14', 'TrAP_confidence': '1.4383737E-6', 'TrNAP_confidence': '5.6867755E-9', 'confidence': '0.98402923', 'entity2_end': '2319', 'chunk1': 'insulin glargine', 'entity1': 'TREATMENT', 'entity2_begin': '2306', 'TeRP_confidence': '0.010644013', 'TeCP_confidence': '1.0496726E-17', 'O_confidence': '0.98402923', 'chunk2_confidence': '0.97045004', 'entity1_begin': '2266', 'sentence': '14', 'PIP_confidence': '5.089074E-16', 'direction': 'both', 'TrCP_confidence': '1.0830871E-7', 'entity1_end': '2281', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.98969996'}, [])]

# %% [markdown]
# As you see above, we see all the labels with corresponding scores since we set `setMultiClass(True)`.

# %% [markdown]
# Now, we will set `setMultiClass(False)` and see the difference.

# %%
reModel = medical.RelationExtractionModel()\
    .pretrained("re_clinical", "en", 'clinical/models')\
    .setInputCols(["embeddings", "pos_tags", "ner_chunks", "dependencies"])\
    .setOutputCol("relations")\
    .setMaxSyntacticDistance(10)\
    .setMultiClass(False)


re_pipeline = nlp.Pipeline(stages=[
    documenter,
    sentencer,
    tokenizer,
    words_embedder,
    pos_tagger,
    ner_tagger,
    ner_chunker,
    dependency_parser,
    reModel
])

empty_data = spark.createDataFrame([[""]]).toDF("text")

re_model = re_pipeline.fit(empty_data)
# Out:
# re_clinical download started this may take some time.
# [OK!]

# %%
re_lmodel = nlp.LightPipeline(re_model)

text= "A 28-year-old female with a history of gestational diabetes mellitus diagnosed eight years prior to presentation and subsequent type two diabetes mellitus ( T2DM ), one prior episode of HTG-induced pancreatitis three years prior to presentation,  associated with an acute hepatitis , and obesity with a body mass index ( BMI ) of 33.5 kg/m2 , presented with a one-week history of polyuria , polydipsia , poor appetite , and vomiting . Two weeks prior to presentation , she was treated with a five-day course of amoxicillin for a respiratory tract infection . She was on metformin , glipizide , and dapagliflozin for T2DM and atorvastatin and gemfibrozil for HTG . She had been on dapagliflozin for six months at the time of presentation. Physical examination on presentation was significant for dry oral mucosa ; significantly , her abdominal examination was benign with no tenderness , guarding , or rigidity . Pertinent laboratory findings on admission were : serum glucose 111 mg/dl , bicarbonate 18 mmol/l , anion gap 20 , creatinine 0.4 mg/dL , triglycerides 508 mg/dL , total cholesterol 122 mg/dL , glycated hemoglobin ( HbA1c ) 10% , and venous pH 7.27 . Serum lipase was normal at 43 U/L . Serum acetone levels could not be assessed as blood samples kept hemolyzing due to significant lipemia . The patient was initially admitted for starvation ketosis , as she reported poor oral intake for three days prior to admission . However , serum chemistry obtained six hours after presentation revealed her glucose was 186 mg/dL , the anion gap was still elevated at 21 , serum bicarbonate was 16 mmol/L , triglyceride level peaked at 2050 mg/dL , and lipase was 52 U/L . The β-hydroxybutyrate level was obtained and found to be elevated at 5.29 mmol/L - the original sample was centrifuged and the chylomicron layer removed prior to analysis due to interference from turbidity caused by lipemia again . The patient was treated with an insulin drip for euDKA and HTG with a reduction in the anion gap to 13 and triglycerides to 1400 mg/dL , within 24 hours . Her euDKA was thought to be precipitated by her respiratory tract infection in the setting of SGLT2 inhibitor use . The patient was seen by the endocrinology service and she was discharged on 40 units of insulin glargine at night , 12 units of insulin lispro with meals , and metformin 1000 mg two times a day . It was determined that all SGLT2 inhibitors should be discontinued indefinitely . She had close follow-up with endocrinology post discharge ."

re_results = re_lmodel.fullAnnotate(text)

# %%
re_results[0]["relations"]
# Out:
# [Annotation(category, 39, 153, TeRP, {'chunk2': 'subsequent type two diabetes mellitus', 'confidence': '1.0', 'entity2_end': '153', 'chunk1': 'gestational diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '117', 'chunk2_confidence': '0.75560004', 'entity1_begin': '39', 'sentence': '0', 'direction': 'both', 'entity1_end': '67', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9205'}, []),
#  Annotation(category, 39, 160, TeRP, {'chunk2': 'T2DM', 'confidence': '1.0', 'entity2_end': '160', 'chunk1': 'gestational diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '157', 'chunk2_confidence': '0.9928', 'entity1_begin': '39', 'sentence': '0', 'direction': 'both', 'entity1_end': '67', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9205'}, []),
#  Annotation(category, 39, 294, TeRP, {'chunk2': 'obesity', 'confidence': '1.0', 'entity2_end': '294', 'chunk1': 'gestational diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '288', 'chunk2_confidence': '0.997', 'entity1_begin': '39', 'sentence': '0', 'direction': 'both', 'entity1_end': '67', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9205'}, []),
#  Annotation(category, 39, 317, TeRP, {'chunk2': 'a body mass index', 'confidence': '1.0', 'entity2_end': '317', 'chunk1': 'gestational diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '301', 'chunk2_confidence': '0.83052504', 'entity1_begin': '39', 'sentence': '0', 'direction': 'both', 'entity1_end': '67', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9205'}, []),
#  Annotation(category, 117, 160, TeRP, {'chunk2': 'T2DM', 'confidence': '1.0', 'entity2_end': '160', 'chunk1': 'subsequent type two diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '157', 'chunk2_confidence': '0.9928', 'entity1_begin': '117', 'sentence': '0', 'direction': 'both', 'entity1_end': '153', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.75560004'}, []),
#  Annotation(category, 117, 209, TeRP, {'chunk2': 'HTG-induced pancreatitis', 'confidence': '1.0', 'entity2_end': '209', 'chunk1': 'subsequent type two diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '186', 'chunk2_confidence': '0.97975004', 'entity1_begin': '117', 'sentence': '0', 'direction': 'both', 'entity1_end': '153', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.75560004'}, []),
#  Annotation(category, 117, 280, TeRP, {'chunk2': 'an acute hepatitis', 'confidence': '1.0', 'entity2_end': '280', 'chunk1': 'subsequent type two diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '263', 'chunk2_confidence': '0.9519333', 'entity1_begin': '117', 'sentence': '0', 'direction': 'both', 'entity1_end': '153', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.75560004'}, []),
#  Annotation(category, 117, 294, TeRP, {'chunk2': 'obesity', 'confidence': '1.0', 'entity2_end': '294', 'chunk1': 'subsequent type two diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '288', 'chunk2_confidence': '0.997', 'entity1_begin': '117', 'sentence': '0', 'direction': 'both', 'entity1_end': '153', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.75560004'}, []),
#  Annotation(category, 117, 317, TeRP, {'chunk2': 'a body mass index', 'confidence': '1.0', 'entity2_end': '317', 'chunk1': 'subsequent type two diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '301', 'chunk2_confidence': '0.83052504', 'entity1_begin': '117', 'sentence': '0', 'direction': 'both', 'entity1_end': '153', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.75560004'}, []),
#  Annotation(category, 117, 323, TeRP, {'chunk2': 'BMI', 'confidence': '1.0', 'entity2_end': '323', 'chunk1': 'subsequent type two diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '321', 'chunk2_confidence': '0.6775', 'entity1_begin': '117', 'sentence': '0', 'direction': 'both', 'entity1_end': '153', 'entity2': 'TEST', 'chunk1_confidence': '0.75560004'}, []),
#  Annotation(category, 117, 387, TeRP, {'chunk2': 'polyuria', 'confidence': '1.0', 'entity2_end': '387', 'chunk1': 'subsequent type two diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '380', 'chunk2_confidence': '0.9901', 'entity1_begin': '117', 'sentence': '0', 'direction': 'both', 'entity1_end': '153', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.75560004'}, []),
#  Annotation(category, 117, 400, TeRP, {'chunk2': 'polydipsia', 'confidence': '1.0', 'entity2_end': '400', 'chunk1': 'subsequent type two diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '391', 'chunk2_confidence': '0.993', 'entity1_begin': '117', 'sentence': '0', 'direction': 'both', 'entity1_end': '153', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.75560004'}, []),
#  Annotation(category, 117, 416, TeRP, {'chunk2': 'poor appetite', 'confidence': '1.0', 'entity2_end': '416', 'chunk1': 'subsequent type two diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '404', 'chunk2_confidence': '0.99795', 'entity1_begin': '117', 'sentence': '0', 'direction': 'both', 'entity1_end': '153', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.75560004'}, []),
#  Annotation(category, 117, 431, TeRP, {'chunk2': 'vomiting', 'confidence': '1.0', 'entity2_end': '431', 'chunk1': 'subsequent type two diabetes mellitus', 'entity1': 'PROBLEM', 'entity2_begin': '424', 'chunk2_confidence': '0.9931', 'entity1_begin': '117', 'sentence': '0', 'direction': 'both', 'entity1_end': '153', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.75560004'}, []),
#  Annotation(category, 157, 209, TeRP, {'chunk2': 'HTG-induced pancreatitis', 'confidence': '1.0', 'entity2_end': '209', 'chunk1': 'T2DM', 'entity1': 'PROBLEM', 'entity2_begin': '186', 'chunk2_confidence': '0.97975004', 'entity1_begin': '157', 'sentence': '0', 'direction': 'both', 'entity1_end': '160', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9928'}, []),
#  Annotation(category, 157, 280, TeRP, {'chunk2': 'an acute hepatitis', 'confidence': '1.0', 'entity2_end': '280', 'chunk1': 'T2DM', 'entity1': 'PROBLEM', 'entity2_begin': '263', 'chunk2_confidence': '0.9519333', 'entity1_begin': '157', 'sentence': '0', 'direction': 'both', 'entity1_end': '160', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9928'}, []),
#  Annotation(category, 157, 294, TeRP, {'chunk2': 'obesity', 'confidence': '0.99999976', 'entity2_end': '294', 'chunk1': 'T2DM', 'entity1': 'PROBLEM', 'entity2_begin': '288', 'chunk2_confidence': '0.997', 'entity1_begin': '157', 'sentence': '0', 'direction': 'both', 'entity1_end': '160', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9928'}, []),
#  Annotation(category, 157, 317, TeRP, {'chunk2': 'a body mass index', 'confidence': '1.0', 'entity2_end': '317', 'chunk1': 'T2DM', 'entity1': 'PROBLEM', 'entity2_begin': '301', 'chunk2_confidence': '0.83052504', 'entity1_begin': '157', 'sentence': '0', 'direction': 'both', 'entity1_end': '160', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9928'}, []),
#  Annotation(category, 157, 323, O, {'chunk2': 'BMI', 'confidence': '0.99999833', 'entity2_end': '323', 'chunk1': 'T2DM', 'entity1': 'PROBLEM', 'entity2_begin': '321', 'chunk2_confidence': '0.6775', 'entity1_begin': '157', 'sentence': '0', 'direction': 'both', 'entity1_end': '160', 'entity2': 'TEST', 'chunk1_confidence': '0.9928'}, []),
#  Annotation(category, 157, 387, TeRP, {'chunk2': 'polyuria', 'confidence': '0.993796', 'entity2_end': '387', 'chunk1': 'T2DM', 'entity1': 'PROBLEM', 'entity2_begin': '380', 'chunk2_confidence': '0.9901', 'entity1_begin': '157', 'sentence': '0', 'direction': 'both', 'entity1_end': '160', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9928'}, []),
#  Annotation(category, 157, 400, TeRP, {'chunk2': 'polydipsia', 'confidence': '0.7955576', 'entity2_end': '400', 'chunk1': 'T2DM', 'entity1': 'PROBLEM', 'entity2_begin': '391', 'chunk2_confidence': '0.993', 'entity1_begin': '157', 'sentence': '0', 'direction': 'both', 'entity1_end': '160', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9928'}, []),
#  Annotation(category, 157, 416, TeRP, {'chunk2': 'poor appetite', 'confidence': '1.0', 'entity2_end': '416', 'chunk1': 'T2DM', 'entity1': 'PROBLEM', 'entity2_begin': '404', 'chunk2_confidence': '0.99795', 'entity1_begin': '157', 'sentence': '0', 'direction': 'both', 'entity1_end': '160', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9928'}, []),
#  Annotation(category, 157, 431, TeRP, {'chunk2': 'vomiting', 'confidence': '0.9993581', 'entity2_end': '431', 'chunk1': 'T2DM', 'entity1': 'PROBLEM', 'entity2_begin': '424', 'chunk2_confidence': '0.9931', 'entity1_begin': '157', 'sentence': '0', 'direction': 'both', 'entity1_end': '160', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9928'}, []),
#  Annotation(category, 186, 280, TeRP, {'chunk2': 'an acute hepatitis', 'confidence': '1.0', 'entity2_end': '280', 'chunk1': 'HTG-induced pancreatitis', 'entity1': 'PROBLEM', 'entity2_begin': '263', 'chunk2_confidence': '0.9519333', 'entity1_begin': '186', 'sentence': '0', 'direction': 'both', 'entity1_end': '209', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.97975004'}, []),
#  Annotation(category, 186, 294, TeRP, {'chunk2': 'obesity', 'confidence': '1.0', 'entity2_end': '294', 'chunk1': 'HTG-induced pancreatitis', 'entity1': 'PROBLEM', 'entity2_begin': '288', 'chunk2_confidence': '0.997', 'entity1_begin': '186', 'sentence': '0', 'direction': 'both', 'entity1_end': '209', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.97975004'}, []),
#  Annotation(category, 186, 317, TeRP, {'chunk2': 'a body mass index', 'confidence': '1.0', 'entity2_end': '317', 'chunk1': 'HTG-induced pancreatitis', 'entity1': 'PROBLEM', 'entity2_begin': '301', 'chunk2_confidence': '0.83052504', 'entity1_begin': '186', 'sentence': '0', 'direction': 'both', 'entity1_end': '209', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.97975004'}, []),
#  Annotation(category, 186, 323, TeRP, {'chunk2': 'BMI', 'confidence': '1.0', 'entity2_end': '323', 'chunk1': 'HTG-induced pancreatitis', 'entity1': 'PROBLEM', 'entity2_begin': '321', 'chunk2_confidence': '0.6775', 'entity1_begin': '186', 'sentence': '0', 'direction': 'both', 'entity1_end': '209', 'entity2': 'TEST', 'chunk1_confidence': '0.97975004'}, []),
#  Annotation(category, 186, 400, TeRP, {'chunk2': 'polydipsia', 'confidence': '1.0', 'entity2_end': '400', 'chunk1': 'HTG-induced pancreatitis', 'entity1': 'PROBLEM', 'entity2_begin': '391', 'chunk2_confidence': '0.993', 'entity1_begin': '186', 'sentence': '0', 'direction': 'both', 'entity1_end': '209', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.97975004'}, []),
#  Annotation(category, 186, 416, TeRP, {'chunk2': 'poor appetite', 'confidence': '1.0', 'entity2_end': '416', 'chunk1': 'HTG-induced pancreatitis', 'entity1': 'PROBLEM', 'entity2_begin': '404', 'chunk2_confidence': '0.99795', 'entity1_begin': '186', 'sentence': '0', 'direction': 'both', 'entity1_end': '209', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.97975004'}, []),
#  Annotation(category, 186, 431, TeRP, {'chunk2': 'vomiting', 'confidence': '1.0', 'entity2_end': '431', 'chunk1': 'HTG-induced pancreatitis', 'entity1': 'PROBLEM', 'entity2_begin': '424', 'chunk2_confidence': '0.9931', 'entity1_begin': '186', 'sentence': '0', 'direction': 'both', 'entity1_end': '209', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.97975004'}, []),
#  Annotation(category, 263, 294, O, {'chunk2': 'obesity', 'confidence': '0.99998176', 'entity2_end': '294', 'chunk1': 'an acute hepatitis', 'entity1': 'PROBLEM', 'entity2_begin': '288', 'chunk2_confidence': '0.997', 'entity1_begin': '263', 'sentence': '0', 'direction': 'both', 'entity1_end': '280', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9519333'}, []),
#  Annotation(category, 288, 317, TeRP, {'chunk2': 'a body mass index', 'confidence': '1.0', 'entity2_end': '317', 'chunk1': 'obesity', 'entity1': 'PROBLEM', 'entity2_begin': '301', 'chunk2_confidence': '0.83052504', 'entity1_begin': '288', 'sentence': '0', 'direction': 'both', 'entity1_end': '294', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.997'}, []),
#  Annotation(category, 288, 323, O, {'chunk2': 'BMI', 'confidence': '1.0', 'entity2_end': '323', 'chunk1': 'obesity', 'entity1': 'PROBLEM', 'entity2_begin': '321', 'chunk2_confidence': '0.6775', 'entity1_begin': '288', 'sentence': '0', 'direction': 'both', 'entity1_end': '294', 'entity2': 'TEST', 'chunk1_confidence': '0.997'}, []),
#  Annotation(category, 288, 387, TeRP, {'chunk2': 'polyuria', 'confidence': '0.9999813', 'entity2_end': '387', 'chunk1': 'obesity', 'entity1': 'PROBLEM', 'entity2_begin': '380', 'chunk2_confidence': '0.9901', 'entity1_begin': '288', 'sentence': '0', 'direction': 'both', 'entity1_end': '294', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.997'}, []),
#  Annotation(category, 288, 400, TeRP, {'chunk2': 'polydipsia', 'confidence': '0.9997998', 'entity2_end': '400', 'chunk1': 'obesity', 'entity1': 'PROBLEM', 'entity2_begin': '391', 'chunk2_confidence': '0.993', 'entity1_begin': '288', 'sentence': '0', 'direction': 'both', 'entity1_end': '294', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.997'}, []),
#  Annotation(category, 288, 416, TeRP, {'chunk2': 'poor appetite', 'confidence': '1.0', 'entity2_end': '416', 'chunk1': 'obesity', 'entity1': 'PROBLEM', 'entity2_begin': '404', 'chunk2_confidence': '0.99795', 'entity1_begin': '288', 'sentence': '0', 'direction': 'both', 'entity1_end': '294', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.997'}, []),
#  Annotation(category, 288, 431, TeRP, {'chunk2': 'vomiting', 'confidence': '0.9999999', 'entity2_end': '431', 'chunk1': 'obesity', 'entity1': 'PROBLEM', 'entity2_begin': '424', 'chunk2_confidence': '0.9931', 'entity1_begin': '288', 'sentence': '0', 'direction': 'both', 'entity1_end': '294', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.997'}, []),
#  Annotation(category, 301, 323, O, {'chunk2': 'BMI', 'confidence': '1.0', 'entity2_end': '323', 'chunk1': 'a body mass index', 'entity1': 'PROBLEM', 'entity2_begin': '321', 'chunk2_confidence': '0.6775', 'entity1_begin': '301', 'sentence': '0', 'direction': 'both', 'entity1_end': '317', 'entity2': 'TEST', 'chunk1_confidence': '0.83052504'}, []),
#  Annotation(category, 301, 387, TeRP, {'chunk2': 'polyuria', 'confidence': '0.99999964', 'entity2_end': '387', 'chunk1': 'a body mass index', 'entity1': 'PROBLEM', 'entity2_begin': '380', 'chunk2_confidence': '0.9901', 'entity1_begin': '301', 'sentence': '0', 'direction': 'both', 'entity1_end': '317', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.83052504'}, []),
#  Annotation(category, 301, 400, TeRP, {'chunk2': 'polydipsia', 'confidence': '1.0', 'entity2_end': '400', 'chunk1': 'a body mass index', 'entity1': 'PROBLEM', 'entity2_begin': '391', 'chunk2_confidence': '0.993', 'entity1_begin': '301', 'sentence': '0', 'direction': 'both', 'entity1_end': '317', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.83052504'}, []),
#  Annotation(category, 301, 416, TeRP, {'chunk2': 'poor appetite', 'confidence': '1.0', 'entity2_end': '416', 'chunk1': 'a body mass index', 'entity1': 'PROBLEM', 'entity2_begin': '404', 'chunk2_confidence': '0.99795', 'entity1_begin': '301', 'sentence': '0', 'direction': 'both', 'entity1_end': '317', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.83052504'}, []),
#  Annotation(category, 301, 431, TeRP, {'chunk2': 'vomiting', 'confidence': '1.0', 'entity2_end': '431', 'chunk1': 'a body mass index', 'entity1': 'PROBLEM', 'entity2_begin': '424', 'chunk2_confidence': '0.9931', 'entity1_begin': '301', 'sentence': '0', 'direction': 'both', 'entity1_end': '317', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.83052504'}, []),
#  Annotation(category, 321, 387, TeRP, {'chunk2': 'polyuria', 'confidence': '0.99756753', 'entity2_end': '387', 'chunk1': 'BMI', 'entity1': 'TEST', 'entity2_begin': '380', 'chunk2_confidence': '0.9901', 'entity1_begin': '321', 'sentence': '0', 'direction': 'both', 'entity1_end': '323', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.6775'}, []),
#  Annotation(category, 321, 400, O, {'chunk2': 'polydipsia', 'confidence': '0.7831951', 'entity2_end': '400', 'chunk1': 'BMI', 'entity1': 'TEST', 'entity2_begin': '391', 'chunk2_confidence': '0.993', 'entity1_begin': '321', 'sentence': '0', 'direction': 'both', 'entity1_end': '323', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.6775'}, []),
#  Annotation(category, 321, 416, TeRP, {'chunk2': 'poor appetite', 'confidence': '0.9980003', 'entity2_end': '416', 'chunk1': 'BMI', 'entity1': 'TEST', 'entity2_begin': '404', 'chunk2_confidence': '0.99795', 'entity1_begin': '321', 'sentence': '0', 'direction': 'both', 'entity1_end': '323', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.6775'}, []),
#  Annotation(category, 321, 431, TrAP, {'chunk2': 'vomiting', 'confidence': '0.894692', 'entity2_end': '431', 'chunk1': 'BMI', 'entity1': 'TEST', 'entity2_begin': '424', 'chunk2_confidence': '0.9931', 'entity1_begin': '321', 'sentence': '0', 'direction': 'both', 'entity1_end': '323', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.6775'}, []),
#  Annotation(category, 380, 400, TeRP, {'chunk2': 'polydipsia', 'confidence': '0.8024412', 'entity2_end': '400', 'chunk1': 'polyuria', 'entity1': 'PROBLEM', 'entity2_begin': '391', 'chunk2_confidence': '0.993', 'entity1_begin': '380', 'sentence': '0', 'direction': 'both', 'entity1_end': '387', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9901'}, []),
#  Annotation(category, 380, 416, TeRP, {'chunk2': 'poor appetite', 'confidence': '0.99934953', 'entity2_end': '416', 'chunk1': 'polyuria', 'entity1': 'PROBLEM', 'entity2_begin': '404', 'chunk2_confidence': '0.99795', 'entity1_begin': '380', 'sentence': '0', 'direction': 'both', 'entity1_end': '387', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9901'}, []),
#  Annotation(category, 380, 431, PIP, {'chunk2': 'vomiting', 'confidence': '0.7593606', 'entity2_end': '431', 'chunk1': 'polyuria', 'entity1': 'PROBLEM', 'entity2_begin': '424', 'chunk2_confidence': '0.9931', 'entity1_begin': '380', 'sentence': '0', 'direction': 'both', 'entity1_end': '387', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9901'}, []),
#  Annotation(category, 391, 416, TeRP, {'chunk2': 'poor appetite', 'confidence': '0.9879937', 'entity2_end': '416', 'chunk1': 'polydipsia', 'entity1': 'PROBLEM', 'entity2_begin': '404', 'chunk2_confidence': '0.99795', 'entity1_begin': '391', 'sentence': '0', 'direction': 'both', 'entity1_end': '400', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.993'}, []),
#  Annotation(category, 391, 431, PIP, {'chunk2': 'vomiting', 'confidence': '0.999689', 'entity2_end': '431', 'chunk1': 'polydipsia', 'entity1': 'PROBLEM', 'entity2_begin': '424', 'chunk2_confidence': '0.9931', 'entity1_begin': '391', 'sentence': '0', 'direction': 'both', 'entity1_end': '400', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.993'}, []),
#  Annotation(category, 404, 431, PIP, {'chunk2': 'vomiting', 'confidence': '0.99999964', 'entity2_end': '431', 'chunk1': 'poor appetite', 'entity1': 'PROBLEM', 'entity2_begin': '424', 'chunk2_confidence': '0.9931', 'entity1_begin': '404', 'sentence': '0', 'direction': 'both', 'entity1_end': '416', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.99795'}, []),
#  Annotation(category, 570, 590, O, {'chunk2': 'glipizide', 'confidence': '1.0', 'entity2_end': '590', 'chunk1': 'metformin', 'entity1': 'TREATMENT', 'entity2_begin': '582', 'chunk2_confidence': '0.9999', 'entity1_begin': '570', 'sentence': '2', 'direction': 'both', 'entity1_end': '578', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.9998'}, []),
#  Annotation(category, 570, 610, O, {'chunk2': 'dapagliflozin', 'confidence': '1.0', 'entity2_end': '610', 'chunk1': 'metformin', 'entity1': 'TREATMENT', 'entity2_begin': '598', 'chunk2_confidence': '1.0', 'entity1_begin': '570', 'sentence': '2', 'direction': 'both', 'entity1_end': '578', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.9998'}, []),
#  Annotation(category, 570, 636, O, {'chunk2': 'atorvastatin', 'confidence': '1.0', 'entity2_end': '636', 'chunk1': 'metformin', 'entity1': 'TREATMENT', 'entity2_begin': '625', 'chunk2_confidence': '0.9999', 'entity1_begin': '570', 'sentence': '2', 'direction': 'both', 'entity1_end': '578', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.9998'}, []),
#  Annotation(category, 570, 652, O, {'chunk2': 'gemfibrozil', 'confidence': '1.0', 'entity2_end': '652', 'chunk1': 'metformin', 'entity1': 'TREATMENT', 'entity2_begin': '642', 'chunk2_confidence': '1.0', 'entity1_begin': '570', 'sentence': '2', 'direction': 'both', 'entity1_end': '578', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.9998'}, []),
#  Annotation(category, 582, 610, O, {'chunk2': 'dapagliflozin', 'confidence': '0.999814', 'entity2_end': '610', 'chunk1': 'glipizide', 'entity1': 'TREATMENT', 'entity2_begin': '598', 'chunk2_confidence': '1.0', 'entity1_begin': '582', 'sentence': '2', 'direction': 'both', 'entity1_end': '590', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.9999'}, []),
#  Annotation(category, 582, 636, O, {'chunk2': 'atorvastatin', 'confidence': '1.0', 'entity2_end': '636', 'chunk1': 'glipizide', 'entity1': 'TREATMENT', 'entity2_begin': '625', 'chunk2_confidence': '0.9999', 'entity1_begin': '582', 'sentence': '2', 'direction': 'both', 'entity1_end': '590', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.9999'}, []),
#  Annotation(category, 582, 652, O, {'chunk2': 'gemfibrozil', 'confidence': '1.0', 'entity2_end': '652', 'chunk1': 'glipizide', 'entity1': 'TREATMENT', 'entity2_begin': '642', 'chunk2_confidence': '1.0', 'entity1_begin': '582', 'sentence': '2', 'direction': 'both', 'entity1_end': '590', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.9999'}, []),
#  Annotation(category, 598, 636, O, {'chunk2': 'atorvastatin', 'confidence': '1.0', 'entity2_end': '636', 'chunk1': 'dapagliflozin', 'entity1': 'TREATMENT', 'entity2_begin': '625', 'chunk2_confidence': '0.9999', 'entity1_begin': '598', 'sentence': '2', 'direction': 'both', 'entity1_end': '610', 'entity2': 'TREATMENT', 'chunk1_confidence': '1.0'}, []),
#  Annotation(category, 598, 652, O, {'chunk2': 'gemfibrozil', 'confidence': '1.0', 'entity2_end': '652', 'chunk1': 'dapagliflozin', 'entity1': 'TREATMENT', 'entity2_begin': '642', 'chunk2_confidence': '1.0', 'entity1_begin': '598', 'sentence': '2', 'direction': 'both', 'entity1_end': '610', 'entity2': 'TREATMENT', 'chunk1_confidence': '1.0'}, []),
#  Annotation(category, 616, 636, O, {'chunk2': 'atorvastatin', 'confidence': '1.0', 'entity2_end': '636', 'chunk1': 'T2DM', 'entity1': 'PROBLEM', 'entity2_begin': '625', 'chunk2_confidence': '0.9999', 'entity1_begin': '616', 'sentence': '2', 'direction': 'both', 'entity1_end': '619', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.9995'}, []),
#  Annotation(category, 616, 652, O, {'chunk2': 'gemfibrozil', 'confidence': '1.0', 'entity2_end': '652', 'chunk1': 'T2DM', 'entity1': 'PROBLEM', 'entity2_begin': '642', 'chunk2_confidence': '1.0', 'entity1_begin': '616', 'sentence': '2', 'direction': 'both', 'entity1_end': '619', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.9995'}, []),
#  Annotation(category, 616, 660, TeRP, {'chunk2': 'HTG', 'confidence': '0.91954094', 'entity2_end': '660', 'chunk1': 'T2DM', 'entity1': 'PROBLEM', 'entity2_begin': '658', 'chunk2_confidence': '0.9994', 'entity1_begin': '616', 'sentence': '2', 'direction': 'both', 'entity1_end': '619', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9995'}, []),
#  Annotation(category, 625, 652, O, {'chunk2': 'gemfibrozil', 'confidence': '1.0', 'entity2_end': '652', 'chunk1': 'atorvastatin', 'entity1': 'TREATMENT', 'entity2_begin': '642', 'chunk2_confidence': '1.0', 'entity1_begin': '625', 'sentence': '2', 'direction': 'both', 'entity1_end': '636', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.9999'}, []),
#  Annotation(category, 738, 809, TeRP, {'chunk2': 'dry oral mucosa', 'confidence': '1.0', 'entity2_end': '809', 'chunk1': 'Physical examination', 'entity1': 'TEST', 'entity2_begin': '795', 'chunk2_confidence': '0.70489997', 'entity1_begin': '738', 'sentence': '4', 'direction': 'both', 'entity1_end': '757', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.95015'}, []),
#  Annotation(category, 829, 883, TeRP, {'chunk2': 'tenderness', 'confidence': '1.0', 'entity2_end': '883', 'chunk1': 'her abdominal examination', 'entity1': 'TEST', 'entity2_begin': '874', 'chunk2_confidence': '0.9996', 'entity1_begin': '829', 'sentence': '5', 'direction': 'both', 'entity1_end': '853', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9342666'}, []),
#  Annotation(category, 829, 894, TeRP, {'chunk2': 'guarding', 'confidence': '1.0', 'entity2_end': '894', 'chunk1': 'her abdominal examination', 'entity1': 'TEST', 'entity2_begin': '887', 'chunk2_confidence': '0.9993', 'entity1_begin': '829', 'sentence': '5', 'direction': 'both', 'entity1_end': '853', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9342666'}, []),
#  Annotation(category, 829, 908, TeRP, {'chunk2': 'rigidity', 'confidence': '1.0', 'entity2_end': '908', 'chunk1': 'her abdominal examination', 'entity1': 'TEST', 'entity2_begin': '901', 'chunk2_confidence': '0.9989', 'entity1_begin': '829', 'sentence': '5', 'direction': 'both', 'entity1_end': '853', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9342666'}, []),
#  Annotation(category, 874, 894, PIP, {'chunk2': 'guarding', 'confidence': '0.99999833', 'entity2_end': '894', 'chunk1': 'tenderness', 'entity1': 'PROBLEM', 'entity2_begin': '887', 'chunk2_confidence': '0.9993', 'entity1_begin': '874', 'sentence': '5', 'direction': 'both', 'entity1_end': '883', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9996'}, []),
#  Annotation(category, 874, 908, PIP, {'chunk2': 'rigidity', 'confidence': '1.0', 'entity2_end': '908', 'chunk1': 'tenderness', 'entity1': 'PROBLEM', 'entity2_begin': '901', 'chunk2_confidence': '0.9989', 'entity1_begin': '874', 'sentence': '5', 'direction': 'both', 'entity1_end': '883', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9996'}, []),
#  Annotation(category, 887, 908, PIP, {'chunk2': 'rigidity', 'confidence': '1.0', 'entity2_end': '908', 'chunk1': 'guarding', 'entity1': 'PROBLEM', 'entity2_begin': '901', 'chunk2_confidence': '0.9989', 'entity1_begin': '887', 'sentence': '5', 'direction': 'both', 'entity1_end': '894', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9993'}, []),
#  Annotation(category, 962, 998, TeRP, {'chunk2': 'bicarbonate', 'confidence': '0.99821126', 'entity2_end': '998', 'chunk1': 'serum glucose', 'entity1': 'TEST', 'entity2_begin': '988', 'chunk2_confidence': '0.9997', 'entity1_begin': '962', 'sentence': '6', 'direction': 'both', 'entity1_end': '974', 'entity2': 'TEST', 'chunk1_confidence': '0.972'}, []),
#  Annotation(category, 962, 1020, TeRP, {'chunk2': 'anion gap', 'confidence': '0.94217384', 'entity2_end': '1020', 'chunk1': 'serum glucose', 'entity1': 'TEST', 'entity2_begin': '1012', 'chunk2_confidence': '0.9792', 'entity1_begin': '962', 'sentence': '6', 'direction': 'both', 'entity1_end': '974', 'entity2': 'TEST', 'chunk1_confidence': '0.972'}, []),
#  Annotation(category, 962, 1036, TeRP, {'chunk2': 'creatinine', 'confidence': '0.6737273', 'entity2_end': '1036', 'chunk1': 'serum glucose', 'entity1': 'TEST', 'entity2_begin': '1027', 'chunk2_confidence': '0.9993', 'entity1_begin': '962', 'sentence': '6', 'direction': 'both', 'entity1_end': '974', 'entity2': 'TEST', 'chunk1_confidence': '0.972'}, []),
#  Annotation(category, 962, 1062, TeRP, {'chunk2': 'triglycerides', 'confidence': '0.9994522', 'entity2_end': '1062', 'chunk1': 'serum glucose', 'entity1': 'TEST', 'entity2_begin': '1050', 'chunk2_confidence': '0.9996', 'entity1_begin': '962', 'sentence': '6', 'direction': 'both', 'entity1_end': '974', 'entity2': 'TEST', 'chunk1_confidence': '0.972'}, []),
#  Annotation(category, 962, 1092, TeRP, {'chunk2': 'total cholesterol', 'confidence': '0.999992', 'entity2_end': '1092', 'chunk1': 'serum glucose', 'entity1': 'TEST', 'entity2_begin': '1076', 'chunk2_confidence': '0.9853', 'entity1_begin': '962', 'sentence': '6', 'direction': 'both', 'entity1_end': '974', 'entity2': 'TEST', 'chunk1_confidence': '0.972'}, []),
#  Annotation(category, 988, 1020, O, {'chunk2': 'anion gap', 'confidence': '1.0', 'entity2_end': '1020', 'chunk1': 'bicarbonate', 'entity1': 'TEST', 'entity2_begin': '1012', 'chunk2_confidence': '0.9792', 'entity1_begin': '988', 'sentence': '6', 'direction': 'both', 'entity1_end': '998', 'entity2': 'TEST', 'chunk1_confidence': '0.9997'}, []),
#  Annotation(category, 988, 1036, O, {'chunk2': 'creatinine', 'confidence': '0.9594467', 'entity2_end': '1036', 'chunk1': 'bicarbonate', 'entity1': 'TEST', 'entity2_begin': '1027', 'chunk2_confidence': '0.9993', 'entity1_begin': '988', 'sentence': '6', 'direction': 'both', 'entity1_end': '998', 'entity2': 'TEST', 'chunk1_confidence': '0.9997'}, []),
#  Annotation(category, 988, 1062, TeRP, {'chunk2': 'triglycerides', 'confidence': '0.9548646', 'entity2_end': '1062', 'chunk1': 'bicarbonate', 'entity1': 'TEST', 'entity2_begin': '1050', 'chunk2_confidence': '0.9996', 'entity1_begin': '988', 'sentence': '6', 'direction': 'both', 'entity1_end': '998', 'entity2': 'TEST', 'chunk1_confidence': '0.9997'}, []),
#  Annotation(category, 988, 1092, TeRP, {'chunk2': 'total cholesterol', 'confidence': '0.9999727', 'entity2_end': '1092', 'chunk1': 'bicarbonate', 'entity1': 'TEST', 'entity2_begin': '1076', 'chunk2_confidence': '0.9853', 'entity1_begin': '988', 'sentence': '6', 'direction': 'both', 'entity1_end': '998', 'entity2': 'TEST', 'chunk1_confidence': '0.9997'}, []),
#  Annotation(category, 988, 1124, TeRP, {'chunk2': 'glycated hemoglobin', 'confidence': '0.99999976', 'entity2_end': '1124', 'chunk1': 'bicarbonate', 'entity1': 'TEST', 'entity2_begin': '1106', 'chunk2_confidence': '0.72424996', 'entity1_begin': '988', 'sentence': '6', 'direction': 'both', 'entity1_end': '998', 'entity2': 'TEST', 'chunk1_confidence': '0.9997'}, []),
#  Annotation(category, 988, 1132, TeRP, {'chunk2': 'HbA1c', 'confidence': '0.9999999', 'entity2_end': '1132', 'chunk1': 'bicarbonate', 'entity1': 'TEST', 'entity2_begin': '1128', 'chunk2_confidence': '0.7891', 'entity1_begin': '988', 'sentence': '6', 'direction': 'both', 'entity1_end': '998', 'entity2': 'TEST', 'chunk1_confidence': '0.9997'}, []),
#  Annotation(category, 988, 1154, O, {'chunk2': 'venous pH', 'confidence': '0.9986822', 'entity2_end': '1154', 'chunk1': 'bicarbonate', 'entity1': 'TEST', 'entity2_begin': '1146', 'chunk2_confidence': '0.98714995', 'entity1_begin': '988', 'sentence': '6', 'direction': 'both', 'entity1_end': '998', 'entity2': 'TEST', 'chunk1_confidence': '0.9997'}, []),
#  Annotation(category, 1012, 1036, O, {'chunk2': 'creatinine', 'confidence': '0.9999809', 'entity2_end': '1036', 'chunk1': 'anion gap', 'entity1': 'TEST', 'entity2_begin': '1027', 'chunk2_confidence': '0.9993', 'entity1_begin': '1012', 'sentence': '6', 'direction': 'both', 'entity1_end': '1020', 'entity2': 'TEST', 'chunk1_confidence': '0.9792'}, []),
#  Annotation(category, 1012, 1062, O, {'chunk2': 'triglycerides', 'confidence': '0.58409745', 'entity2_end': '1062', 'chunk1': 'anion gap', 'entity1': 'TEST', 'entity2_begin': '1050', 'chunk2_confidence': '0.9996', 'entity1_begin': '1012', 'sentence': '6', 'direction': 'both', 'entity1_end': '1020', 'entity2': 'TEST', 'chunk1_confidence': '0.9792'}, []),
#  Annotation(category, 1012, 1092, TeRP, {'chunk2': 'total cholesterol', 'confidence': '0.9998777', 'entity2_end': '1092', 'chunk1': 'anion gap', 'entity1': 'TEST', 'entity2_begin': '1076', 'chunk2_confidence': '0.9853', 'entity1_begin': '1012', 'sentence': '6', 'direction': 'both', 'entity1_end': '1020', 'entity2': 'TEST', 'chunk1_confidence': '0.9792'}, []),
#  Annotation(category, 1012, 1124, TeRP, {'chunk2': 'glycated hemoglobin', 'confidence': '1.0', 'entity2_end': '1124', 'chunk1': 'anion gap', 'entity1': 'TEST', 'entity2_begin': '1106', 'chunk2_confidence': '0.72424996', 'entity1_begin': '1012', 'sentence': '6', 'direction': 'both', 'entity1_end': '1020', 'entity2': 'TEST', 'chunk1_confidence': '0.9792'}, []),
#  Annotation(category, 1012, 1132, TeRP, {'chunk2': 'HbA1c', 'confidence': '1.0', 'entity2_end': '1132', 'chunk1': 'anion gap', 'entity1': 'TEST', 'entity2_begin': '1128', 'chunk2_confidence': '0.7891', 'entity1_begin': '1012', 'sentence': '6', 'direction': 'both', 'entity1_end': '1020', 'entity2': 'TEST', 'chunk1_confidence': '0.9792'}, []),
#  Annotation(category, 1012, 1154, TeRP, {'chunk2': 'venous pH', 'confidence': '0.61259484', 'entity2_end': '1154', 'chunk1': 'anion gap', 'entity1': 'TEST', 'entity2_begin': '1146', 'chunk2_confidence': '0.98714995', 'entity1_begin': '1012', 'sentence': '6', 'direction': 'both', 'entity1_end': '1020', 'entity2': 'TEST', 'chunk1_confidence': '0.9792'}, []),
#  Annotation(category, 1027, 1062, O, {'chunk2': 'triglycerides', 'confidence': '0.72227347', 'entity2_end': '1062', 'chunk1': 'creatinine', 'entity1': 'TEST', 'entity2_begin': '1050', 'chunk2_confidence': '0.9996', 'entity1_begin': '1027', 'sentence': '6', 'direction': 'both', 'entity1_end': '1036', 'entity2': 'TEST', 'chunk1_confidence': '0.9993'}, []),
#  Annotation(category, 1027, 1092, TeRP, {'chunk2': 'total cholesterol', 'confidence': '0.9999907', 'entity2_end': '1092', 'chunk1': 'creatinine', 'entity1': 'TEST', 'entity2_begin': '1076', 'chunk2_confidence': '0.9853', 'entity1_begin': '1027', 'sentence': '6', 'direction': 'both', 'entity1_end': '1036', 'entity2': 'TEST', 'chunk1_confidence': '0.9993'}, []),
#  Annotation(category, 1027, 1124, TeRP, {'chunk2': 'glycated hemoglobin', 'confidence': '1.0', 'entity2_end': '1124', 'chunk1': 'creatinine', 'entity1': 'TEST', 'entity2_begin': '1106', 'chunk2_confidence': '0.72424996', 'entity1_begin': '1027', 'sentence': '6', 'direction': 'both', 'entity1_end': '1036', 'entity2': 'TEST', 'chunk1_confidence': '0.9993'}, []),
#  Annotation(category, 1027, 1132, TeRP, {'chunk2': 'HbA1c', 'confidence': '0.9999994', 'entity2_end': '1132', 'chunk1': 'creatinine', 'entity1': 'TEST', 'entity2_begin': '1128', 'chunk2_confidence': '0.7891', 'entity1_begin': '1027', 'sentence': '6', 'direction': 'both', 'entity1_end': '1036', 'entity2': 'TEST', 'chunk1_confidence': '0.9993'}, []),
#  Annotation(category, 1027, 1154, O, {'chunk2': 'venous pH', 'confidence': '0.9565255', 'entity2_end': '1154', 'chunk1': 'creatinine', 'entity1': 'TEST', 'entity2_begin': '1146', 'chunk2_confidence': '0.98714995', 'entity1_begin': '1027', 'sentence': '6', 'direction': 'both', 'entity1_end': '1036', 'entity2': 'TEST', 'chunk1_confidence': '0.9993'}, []),
#  Annotation(category, 1050, 1092, TeRP, {'chunk2': 'total cholesterol', 'confidence': '0.9999999', 'entity2_end': '1092', 'chunk1': 'triglycerides', 'entity1': 'TEST', 'entity2_begin': '1076', 'chunk2_confidence': '0.9853', 'entity1_begin': '1050', 'sentence': '6', 'direction': 'both', 'entity1_end': '1062', 'entity2': 'TEST', 'chunk1_confidence': '0.9996'}, []),
#  Annotation(category, 1050, 1124, TeRP, {'chunk2': 'glycated hemoglobin', 'confidence': '1.0', 'entity2_end': '1124', 'chunk1': 'triglycerides', 'entity1': 'TEST', 'entity2_begin': '1106', 'chunk2_confidence': '0.72424996', 'entity1_begin': '1050', 'sentence': '6', 'direction': 'both', 'entity1_end': '1062', 'entity2': 'TEST', 'chunk1_confidence': '0.9996'}, []),
#  Annotation(category, 1050, 1132, TeRP, {'chunk2': 'HbA1c', 'confidence': '1.0', 'entity2_end': '1132', 'chunk1': 'triglycerides', 'entity1': 'TEST', 'entity2_begin': '1128', 'chunk2_confidence': '0.7891', 'entity1_begin': '1050', 'sentence': '6', 'direction': 'both', 'entity1_end': '1062', 'entity2': 'TEST', 'chunk1_confidence': '0.9996'}, []),
#  Annotation(category, 1050, 1154, TeRP, {'chunk2': 'venous pH', 'confidence': '0.99999964', 'entity2_end': '1154', 'chunk1': 'triglycerides', 'entity1': 'TEST', 'entity2_begin': '1146', 'chunk2_confidence': '0.98714995', 'entity1_begin': '1050', 'sentence': '6', 'direction': 'both', 'entity1_end': '1062', 'entity2': 'TEST', 'chunk1_confidence': '0.9996'}, []),
#  Annotation(category, 1076, 1124, TeRP, {'chunk2': 'glycated hemoglobin', 'confidence': '1.0', 'entity2_end': '1124', 'chunk1': 'total cholesterol', 'entity1': 'TEST', 'entity2_begin': '1106', 'chunk2_confidence': '0.72424996', 'entity1_begin': '1076', 'sentence': '6', 'direction': 'both', 'entity1_end': '1092', 'entity2': 'TEST', 'chunk1_confidence': '0.9853'}, []),
#  Annotation(category, 1076, 1132, TeRP, {'chunk2': 'HbA1c', 'confidence': '1.0', 'entity2_end': '1132', 'chunk1': 'total cholesterol', 'entity1': 'TEST', 'entity2_begin': '1128', 'chunk2_confidence': '0.7891', 'entity1_begin': '1076', 'sentence': '6', 'direction': 'both', 'entity1_end': '1092', 'entity2': 'TEST', 'chunk1_confidence': '0.9853'}, []),
#  Annotation(category, 1076, 1154, TeRP, {'chunk2': 'venous pH', 'confidence': '1.0', 'entity2_end': '1154', 'chunk1': 'total cholesterol', 'entity1': 'TEST', 'entity2_begin': '1146', 'chunk2_confidence': '0.98714995', 'entity1_begin': '1076', 'sentence': '6', 'direction': 'both', 'entity1_end': '1092', 'entity2': 'TEST', 'chunk1_confidence': '0.9853'}, []),
#  Annotation(category, 1106, 1132, TeRP, {'chunk2': 'HbA1c', 'confidence': '0.99999535', 'entity2_end': '1132', 'chunk1': 'glycated hemoglobin', 'entity1': 'TEST', 'entity2_begin': '1128', 'chunk2_confidence': '0.7891', 'entity1_begin': '1106', 'sentence': '6', 'direction': 'both', 'entity1_end': '1124', 'entity2': 'TEST', 'chunk1_confidence': '0.72424996'}, []),
#  Annotation(category, 1106, 1154, TeRP, {'chunk2': 'venous pH', 'confidence': '1.0', 'entity2_end': '1154', 'chunk1': 'glycated hemoglobin', 'entity1': 'TEST', 'entity2_begin': '1146', 'chunk2_confidence': '0.98714995', 'entity1_begin': '1106', 'sentence': '6', 'direction': 'both', 'entity1_end': '1124', 'entity2': 'TEST', 'chunk1_confidence': '0.72424996'}, []),
#  Annotation(category, 1128, 1154, TeRP, {'chunk2': 'venous pH', 'confidence': '0.99997926', 'entity2_end': '1154', 'chunk1': 'HbA1c', 'entity1': 'TEST', 'entity2_begin': '1146', 'chunk2_confidence': '0.98714995', 'entity1_begin': '1128', 'sentence': '6', 'direction': 'both', 'entity1_end': '1132', 'entity2': 'TEST', 'chunk1_confidence': '0.7891'}, []),
#  Annotation(category, 1163, 1195, TeRP, {'chunk2': 'U/L', 'confidence': '0.99999964', 'entity2_end': '1195', 'chunk1': 'Serum lipase', 'entity1': 'TEST', 'entity2_begin': '1193', 'chunk2_confidence': '0.9864', 'entity1_begin': '1163', 'sentence': '7', 'direction': 'both', 'entity1_end': '1174', 'entity2': 'TEST', 'chunk1_confidence': '0.95895'}, []),
#  Annotation(category, 1199, 1257, TeRP, {'chunk2': 'blood samples', 'confidence': '1.0', 'entity2_end': '1257', 'chunk1': 'Serum acetone levels', 'entity1': 'TEST', 'entity2_begin': '1245', 'chunk2_confidence': '0.83655', 'entity1_begin': '1199', 'sentence': '8', 'direction': 'both', 'entity1_end': '1218', 'entity2': 'TEST', 'chunk1_confidence': '0.9502'}, []),
#  Annotation(category, 1199, 1273, TeRP, {'chunk2': 'hemolyzing', 'confidence': '0.99999416', 'entity2_end': '1273', 'chunk1': 'Serum acetone levels', 'entity1': 'TEST', 'entity2_begin': '1264', 'chunk2_confidence': '0.8774', 'entity1_begin': '1199', 'sentence': '8', 'direction': 'both', 'entity1_end': '1218', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9502'}, []),
#  Annotation(category, 1199, 1300, TeRP, {'chunk2': 'significant lipemia', 'confidence': '1.0', 'entity2_end': '1300', 'chunk1': 'Serum acetone levels', 'entity1': 'TEST', 'entity2_begin': '1282', 'chunk2_confidence': '0.94519997', 'entity1_begin': '1199', 'sentence': '8', 'direction': 'both', 'entity1_end': '1218', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9502'}, []),
#  Annotation(category, 1245, 1273, TrWP, {'chunk2': 'hemolyzing', 'confidence': '0.8292767', 'entity2_end': '1273', 'chunk1': 'blood samples', 'entity1': 'TEST', 'entity2_begin': '1264', 'chunk2_confidence': '0.8774', 'entity1_begin': '1245', 'sentence': '8', 'direction': 'both', 'entity1_end': '1257', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.83655'}, []),
#  Annotation(category, 1245, 1300, TeRP, {'chunk2': 'significant lipemia', 'confidence': '0.9995969', 'entity2_end': '1300', 'chunk1': 'blood samples', 'entity1': 'TEST', 'entity2_begin': '1282', 'chunk2_confidence': '0.94519997', 'entity1_begin': '1245', 'sentence': '8', 'direction': 'both', 'entity1_end': '1257', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.83655'}, []),
#  Annotation(category, 1264, 1300, TeRP, {'chunk2': 'significant lipemia', 'confidence': '1.0', 'entity2_end': '1300', 'chunk1': 'hemolyzing', 'entity1': 'PROBLEM', 'entity2_begin': '1282', 'chunk2_confidence': '0.94519997', 'entity1_begin': '1264', 'sentence': '8', 'direction': 'both', 'entity1_end': '1273', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.8774'}, []),
#  Annotation(category, 1443, 1516, TeRP, {'chunk2': 'her glucose', 'confidence': '1.0', 'entity2_end': '1516', 'chunk1': 'serum chemistry', 'entity1': 'TEST', 'entity2_begin': '1506', 'chunk2_confidence': '0.8016', 'entity1_begin': '1443', 'sentence': '10', 'direction': 'both', 'entity1_end': '1457', 'entity2': 'TEST', 'chunk1_confidence': '0.96815'}, []),
#  Annotation(category, 1443, 1546, TeRP, {'chunk2': 'the anion gap', 'confidence': '0.9999999', 'entity2_end': '1546', 'chunk1': 'serum chemistry', 'entity1': 'TEST', 'entity2_begin': '1534', 'chunk2_confidence': '0.9375667', 'entity1_begin': '1443', 'sentence': '10', 'direction': 'both', 'entity1_end': '1457', 'entity2': 'TEST', 'chunk1_confidence': '0.96815'}, []),
#  Annotation(category, 1443, 1565, TeRP, {'chunk2': 'still elevated', 'confidence': '1.0', 'entity2_end': '1565', 'chunk1': 'serum chemistry', 'entity1': 'TEST', 'entity2_begin': '1552', 'chunk2_confidence': '0.70735', 'entity1_begin': '1443', 'sentence': '10', 'direction': 'both', 'entity1_end': '1457', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.96815'}, []),
#  Annotation(category, 1443, 1591, TeRP, {'chunk2': 'serum bicarbonate', 'confidence': '0.9999994', 'entity2_end': '1591', 'chunk1': 'serum chemistry', 'entity1': 'TEST', 'entity2_begin': '1575', 'chunk2_confidence': '0.99055004', 'entity1_begin': '1443', 'sentence': '10', 'direction': 'both', 'entity1_end': '1457', 'entity2': 'TEST', 'chunk1_confidence': '0.96815'}, []),
#  Annotation(category, 1443, 1626, TeRP, {'chunk2': 'triglyceride level', 'confidence': '1.0', 'entity2_end': '1626', 'chunk1': 'serum chemistry', 'entity1': 'TEST', 'entity2_begin': '1609', 'chunk2_confidence': '0.98495', 'entity1_begin': '1443', 'sentence': '10', 'direction': 'both', 'entity1_end': '1457', 'entity2': 'TEST', 'chunk1_confidence': '0.96815'}, []),
#  Annotation(category, 1443, 1660, TeRP, {'chunk2': 'lipase', 'confidence': '0.9998661', 'entity2_end': '1660', 'chunk1': 'serum chemistry', 'entity1': 'TEST', 'entity2_begin': '1655', 'chunk2_confidence': '0.9973', 'entity1_begin': '1443', 'sentence': '10', 'direction': 'both', 'entity1_end': '1457', 'entity2': 'TEST', 'chunk1_confidence': '0.96815'}, []),
#  Annotation(category, 1443, 1671, TeRP, {'chunk2': 'U/L', 'confidence': '0.9985845', 'entity2_end': '1671', 'chunk1': 'serum chemistry', 'entity1': 'TEST', 'entity2_begin': '1669', 'chunk2_confidence': '0.5523', 'entity1_begin': '1443', 'sentence': '10', 'direction': 'both', 'entity1_end': '1457', 'entity2': 'TEST', 'chunk1_confidence': '0.96815'}, []),
#  Annotation(category, 1506, 1546, TeRP, {'chunk2': 'the anion gap', 'confidence': '0.9999949', 'entity2_end': '1546', 'chunk1': 'her glucose', 'entity1': 'TEST', 'entity2_begin': '1534', 'chunk2_confidence': '0.9375667', 'entity1_begin': '1506', 'sentence': '10', 'direction': 'both', 'entity1_end': '1516', 'entity2': 'TEST', 'chunk1_confidence': '0.8016'}, []),
#  Annotation(category, 1506, 1565, TeRP, {'chunk2': 'still elevated', 'confidence': '1.0', 'entity2_end': '1565', 'chunk1': 'her glucose', 'entity1': 'TEST', 'entity2_begin': '1552', 'chunk2_confidence': '0.70735', 'entity1_begin': '1506', 'sentence': '10', 'direction': 'both', 'entity1_end': '1516', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.8016'}, []),
#  Annotation(category, 1506, 1591, TeRP, {'chunk2': 'serum bicarbonate', 'confidence': '0.99999106', 'entity2_end': '1591', 'chunk1': 'her glucose', 'entity1': 'TEST', 'entity2_begin': '1575', 'chunk2_confidence': '0.99055004', 'entity1_begin': '1506', 'sentence': '10', 'direction': 'both', 'entity1_end': '1516', 'entity2': 'TEST', 'chunk1_confidence': '0.8016'}, []),
#  Annotation(category, 1506, 1626, TeRP, {'chunk2': 'triglyceride level', 'confidence': '0.9999927', 'entity2_end': '1626', 'chunk1': 'her glucose', 'entity1': 'TEST', 'entity2_begin': '1609', 'chunk2_confidence': '0.98495', 'entity1_begin': '1506', 'sentence': '10', 'direction': 'both', 'entity1_end': '1516', 'entity2': 'TEST', 'chunk1_confidence': '0.8016'}, []),
#  Annotation(category, 1506, 1660, TeRP, {'chunk2': 'lipase', 'confidence': '0.99460864', 'entity2_end': '1660', 'chunk1': 'her glucose', 'entity1': 'TEST', 'entity2_begin': '1655', 'chunk2_confidence': '0.9973', 'entity1_begin': '1506', 'sentence': '10', 'direction': 'both', 'entity1_end': '1516', 'entity2': 'TEST', 'chunk1_confidence': '0.8016'}, []),
#  Annotation(category, 1506, 1671, O, {'chunk2': 'U/L', 'confidence': '0.6527976', 'entity2_end': '1671', 'chunk1': 'her glucose', 'entity1': 'TEST', 'entity2_begin': '1669', 'chunk2_confidence': '0.5523', 'entity1_begin': '1506', 'sentence': '10', 'direction': 'both', 'entity1_end': '1516', 'entity2': 'TEST', 'chunk1_confidence': '0.8016'}, []),
#  Annotation(category, 1534, 1565, TeRP, {'chunk2': 'still elevated', 'confidence': '1.0', 'entity2_end': '1565', 'chunk1': 'the anion gap', 'entity1': 'TEST', 'entity2_begin': '1552', 'chunk2_confidence': '0.70735', 'entity1_begin': '1534', 'sentence': '10', 'direction': 'both', 'entity1_end': '1546', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9375667'}, []),
#  Annotation(category, 1534, 1591, TeRP, {'chunk2': 'serum bicarbonate', 'confidence': '1.0', 'entity2_end': '1591', 'chunk1': 'the anion gap', 'entity1': 'TEST', 'entity2_begin': '1575', 'chunk2_confidence': '0.99055004', 'entity1_begin': '1534', 'sentence': '10', 'direction': 'both', 'entity1_end': '1546', 'entity2': 'TEST', 'chunk1_confidence': '0.9375667'}, []),
#  Annotation(category, 1534, 1626, TeRP, {'chunk2': 'triglyceride level', 'confidence': '1.0', 'entity2_end': '1626', 'chunk1': 'the anion gap', 'entity1': 'TEST', 'entity2_begin': '1609', 'chunk2_confidence': '0.98495', 'entity1_begin': '1534', 'sentence': '10', 'direction': 'both', 'entity1_end': '1546', 'entity2': 'TEST', 'chunk1_confidence': '0.9375667'}, []),
#  Annotation(category, 1534, 1660, TeRP, {'chunk2': 'lipase', 'confidence': '1.0', 'entity2_end': '1660', 'chunk1': 'the anion gap', 'entity1': 'TEST', 'entity2_begin': '1655', 'chunk2_confidence': '0.9973', 'entity1_begin': '1534', 'sentence': '10', 'direction': 'both', 'entity1_end': '1546', 'entity2': 'TEST', 'chunk1_confidence': '0.9375667'}, []),
#  Annotation(category, 1534, 1671, TeRP, {'chunk2': 'U/L', 'confidence': '1.0', 'entity2_end': '1671', 'chunk1': 'the anion gap', 'entity1': 'TEST', 'entity2_begin': '1669', 'chunk2_confidence': '0.5523', 'entity1_begin': '1534', 'sentence': '10', 'direction': 'both', 'entity1_end': '1546', 'entity2': 'TEST', 'chunk1_confidence': '0.9375667'}, []),
#  Annotation(category, 1552, 1591, O, {'chunk2': 'serum bicarbonate', 'confidence': '0.9820494', 'entity2_end': '1591', 'chunk1': 'still elevated', 'entity1': 'PROBLEM', 'entity2_begin': '1575', 'chunk2_confidence': '0.99055004', 'entity1_begin': '1552', 'sentence': '10', 'direction': 'both', 'entity1_end': '1565', 'entity2': 'TEST', 'chunk1_confidence': '0.70735'}, []),
#  Annotation(category, 1552, 1626, TeRP, {'chunk2': 'triglyceride level', 'confidence': '0.9999958', 'entity2_end': '1626', 'chunk1': 'still elevated', 'entity1': 'PROBLEM', 'entity2_begin': '1609', 'chunk2_confidence': '0.98495', 'entity1_begin': '1552', 'sentence': '10', 'direction': 'both', 'entity1_end': '1565', 'entity2': 'TEST', 'chunk1_confidence': '0.70735'}, []),
#  Annotation(category, 1552, 1660, TeRP, {'chunk2': 'lipase', 'confidence': '0.99998677', 'entity2_end': '1660', 'chunk1': 'still elevated', 'entity1': 'PROBLEM', 'entity2_begin': '1655', 'chunk2_confidence': '0.9973', 'entity1_begin': '1552', 'sentence': '10', 'direction': 'both', 'entity1_end': '1565', 'entity2': 'TEST', 'chunk1_confidence': '0.70735'}, []),
#  Annotation(category, 1552, 1671, TeRP, {'chunk2': 'U/L', 'confidence': '0.9999951', 'entity2_end': '1671', 'chunk1': 'still elevated', 'entity1': 'PROBLEM', 'entity2_begin': '1669', 'chunk2_confidence': '0.5523', 'entity1_begin': '1552', 'sentence': '10', 'direction': 'both', 'entity1_end': '1565', 'entity2': 'TEST', 'chunk1_confidence': '0.70735'}, []),
#  Annotation(category, 1575, 1626, TeRP, {'chunk2': 'triglyceride level', 'confidence': '1.0', 'entity2_end': '1626', 'chunk1': 'serum bicarbonate', 'entity1': 'TEST', 'entity2_begin': '1609', 'chunk2_confidence': '0.98495', 'entity1_begin': '1575', 'sentence': '10', 'direction': 'both', 'entity1_end': '1591', 'entity2': 'TEST', 'chunk1_confidence': '0.99055004'}, []),
#  Annotation(category, 1575, 1660, TeRP, {'chunk2': 'lipase', 'confidence': '1.0', 'entity2_end': '1660', 'chunk1': 'serum bicarbonate', 'entity1': 'TEST', 'entity2_begin': '1655', 'chunk2_confidence': '0.9973', 'entity1_begin': '1575', 'sentence': '10', 'direction': 'both', 'entity1_end': '1591', 'entity2': 'TEST', 'chunk1_confidence': '0.99055004'}, []),
#  Annotation(category, 1575, 1671, TeRP, {'chunk2': 'U/L', 'confidence': '1.0', 'entity2_end': '1671', 'chunk1': 'serum bicarbonate', 'entity1': 'TEST', 'entity2_begin': '1669', 'chunk2_confidence': '0.5523', 'entity1_begin': '1575', 'sentence': '10', 'direction': 'both', 'entity1_end': '1591', 'entity2': 'TEST', 'chunk1_confidence': '0.99055004'}, []),
#  Annotation(category, 1609, 1660, TeRP, {'chunk2': 'lipase', 'confidence': '1.0', 'entity2_end': '1660', 'chunk1': 'triglyceride level', 'entity1': 'TEST', 'entity2_begin': '1655', 'chunk2_confidence': '0.9973', 'entity1_begin': '1609', 'sentence': '10', 'direction': 'both', 'entity1_end': '1626', 'entity2': 'TEST', 'chunk1_confidence': '0.98495'}, []),
#  Annotation(category, 1609, 1671, TeRP, {'chunk2': 'U/L', 'confidence': '1.0', 'entity2_end': '1671', 'chunk1': 'triglyceride level', 'entity1': 'TEST', 'entity2_begin': '1669', 'chunk2_confidence': '0.5523', 'entity1_begin': '1609', 'sentence': '10', 'direction': 'both', 'entity1_end': '1626', 'entity2': 'TEST', 'chunk1_confidence': '0.98495'}, []),
#  Annotation(category, 1655, 1671, TeRP, {'chunk2': 'U/L', 'confidence': '0.99995816', 'entity2_end': '1671', 'chunk1': 'lipase', 'entity1': 'TEST', 'entity2_begin': '1669', 'chunk2_confidence': '0.5523', 'entity1_begin': '1655', 'sentence': '10', 'direction': 'both', 'entity1_end': '1660', 'entity2': 'TEST', 'chunk1_confidence': '0.9973'}, []),
#  Annotation(category, 1675, 1739, TeRP, {'chunk2': 'elevated', 'confidence': '1.0', 'entity2_end': '1739', 'chunk1': 'The β-hydroxybutyrate level', 'entity1': 'TEST', 'entity2_begin': '1732', 'chunk2_confidence': '0.8527', 'entity1_begin': '1675', 'sentence': '11', 'direction': 'both', 'entity1_end': '1701', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.8511'}, []),
#  Annotation(category, 1675, 1844, TeRP, {'chunk2': 'analysis', 'confidence': '1.0', 'entity2_end': '1844', 'chunk1': 'The β-hydroxybutyrate level', 'entity1': 'TEST', 'entity2_begin': '1837', 'chunk2_confidence': '0.9949', 'entity1_begin': '1675', 'sentence': '11', 'direction': 'both', 'entity1_end': '1701', 'entity2': 'TEST', 'chunk1_confidence': '0.8511'}, []),
#  Annotation(category, 1675, 1879, TeRP, {'chunk2': 'interference from turbidity', 'confidence': '1.0', 'entity2_end': '1879', 'chunk1': 'The β-hydroxybutyrate level', 'entity1': 'TEST', 'entity2_begin': '1853', 'chunk2_confidence': '0.88926667', 'entity1_begin': '1675', 'sentence': '11', 'direction': 'both', 'entity1_end': '1701', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.8511'}, []),
#  Annotation(category, 1675, 1897, TeRP, {'chunk2': 'lipemia', 'confidence': '1.0', 'entity2_end': '1897', 'chunk1': 'The β-hydroxybutyrate level', 'entity1': 'TEST', 'entity2_begin': '1891', 'chunk2_confidence': '0.9957', 'entity1_begin': '1675', 'sentence': '11', 'direction': 'both', 'entity1_end': '1701', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.8511'}, []),
#  Annotation(category, 1732, 1844, O, {'chunk2': 'analysis', 'confidence': '0.9762175', 'entity2_end': '1844', 'chunk1': 'elevated', 'entity1': 'PROBLEM', 'entity2_begin': '1837', 'chunk2_confidence': '0.9949', 'entity1_begin': '1732', 'sentence': '11', 'direction': 'both', 'entity1_end': '1739', 'entity2': 'TEST', 'chunk1_confidence': '0.8527'}, []),
#  Annotation(category, 1732, 1879, TeRP, {'chunk2': 'interference from turbidity', 'confidence': '1.0', 'entity2_end': '1879', 'chunk1': 'elevated', 'entity1': 'PROBLEM', 'entity2_begin': '1853', 'chunk2_confidence': '0.88926667', 'entity1_begin': '1732', 'sentence': '11', 'direction': 'both', 'entity1_end': '1739', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.8527'}, []),
#  Annotation(category, 1732, 1897, TeRP, {'chunk2': 'lipemia', 'confidence': '0.9999999', 'entity2_end': '1897', 'chunk1': 'elevated', 'entity1': 'PROBLEM', 'entity2_begin': '1891', 'chunk2_confidence': '0.9957', 'entity1_begin': '1732', 'sentence': '11', 'direction': 'both', 'entity1_end': '1739', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.8527'}, []),
#  Annotation(category, 1837, 1879, TeRP, {'chunk2': 'interference from turbidity', 'confidence': '0.9999999', 'entity2_end': '1879', 'chunk1': 'analysis', 'entity1': 'TEST', 'entity2_begin': '1853', 'chunk2_confidence': '0.88926667', 'entity1_begin': '1837', 'sentence': '11', 'direction': 'both', 'entity1_end': '1844', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9949'}, []),
#  Annotation(category, 1837, 1897, TeRP, {'chunk2': 'lipemia', 'confidence': '1.0', 'entity2_end': '1897', 'chunk1': 'analysis', 'entity1': 'TEST', 'entity2_begin': '1891', 'chunk2_confidence': '0.9957', 'entity1_begin': '1837', 'sentence': '11', 'direction': 'both', 'entity1_end': '1844', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9949'}, []),
#  Annotation(category, 1853, 1897, TeRP, {'chunk2': 'lipemia', 'confidence': '0.9999994', 'entity2_end': '1897', 'chunk1': 'interference from turbidity', 'entity1': 'PROBLEM', 'entity2_begin': '1891', 'chunk2_confidence': '0.9957', 'entity1_begin': '1853', 'sentence': '11', 'direction': 'both', 'entity1_end': '1879', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.88926667'}, []),
#  Annotation(category, 1936, 1985, O, {'chunk2': 'a reduction', 'confidence': '0.99999845', 'entity2_end': '1985', 'chunk1': 'an insulin drip', 'entity1': 'TREATMENT', 'entity2_begin': '1975', 'chunk2_confidence': '0.56735003', 'entity1_begin': '1936', 'sentence': '12', 'direction': 'both', 'entity1_end': '1950', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.97396666'}, []),
#  Annotation(category, 1936, 2002, TeRP, {'chunk2': 'the anion gap', 'confidence': '0.8420974', 'entity2_end': '2002', 'chunk1': 'an insulin drip', 'entity1': 'TREATMENT', 'entity2_begin': '1990', 'chunk2_confidence': '0.47016668', 'entity1_begin': '1936', 'sentence': '12', 'direction': 'both', 'entity1_end': '1950', 'entity2': 'TEST', 'chunk1_confidence': '0.97396666'}, []),
#  Annotation(category, 1936, 2026, TeRP, {'chunk2': 'triglycerides', 'confidence': '0.9854799', 'entity2_end': '2026', 'chunk1': 'an insulin drip', 'entity1': 'TREATMENT', 'entity2_begin': '2014', 'chunk2_confidence': '0.9965', 'entity1_begin': '1936', 'sentence': '12', 'direction': 'both', 'entity1_end': '1950', 'entity2': 'TEST', 'chunk1_confidence': '0.97396666'}, []),
#  Annotation(category, 1956, 1968, PIP, {'chunk2': 'HTG', 'confidence': '0.99999774', 'entity2_end': '1968', 'chunk1': 'euDKA', 'entity1': 'PROBLEM', 'entity2_begin': '1966', 'chunk2_confidence': '0.9839', 'entity1_begin': '1956', 'sentence': '12', 'direction': 'both', 'entity1_end': '1960', 'entity2': 'PROBLEM', 'chunk1_confidence': '0.9847'}, []),
#  Annotation(category, 1956, 1985, O, {'chunk2': 'a reduction', 'confidence': '1.0', 'entity2_end': '1985', 'chunk1': 'euDKA', 'entity1': 'PROBLEM', 'entity2_begin': '1975', 'chunk2_confidence': '0.56735003', 'entity1_begin': '1956', 'sentence': '12', 'direction': 'both', 'entity1_end': '1960', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.9847'}, []),
#  Annotation(category, 1956, 2002, PIP, {'chunk2': 'the anion gap', 'confidence': '0.9738799', 'entity2_end': '2002', 'chunk1': 'euDKA', 'entity1': 'PROBLEM', 'entity2_begin': '1990', 'chunk2_confidence': '0.47016668', 'entity1_begin': '1956', 'sentence': '12', 'direction': 'both', 'entity1_end': '1960', 'entity2': 'TEST', 'chunk1_confidence': '0.9847'}, []),
#  Annotation(category, 1956, 2026, O, {'chunk2': 'triglycerides', 'confidence': '0.87599975', 'entity2_end': '2026', 'chunk1': 'euDKA', 'entity1': 'PROBLEM', 'entity2_begin': '2014', 'chunk2_confidence': '0.9965', 'entity1_begin': '1956', 'sentence': '12', 'direction': 'both', 'entity1_end': '1960', 'entity2': 'TEST', 'chunk1_confidence': '0.9847'}, []),
#  Annotation(category, 1966, 1985, O, {'chunk2': 'a reduction', 'confidence': '1.0', 'entity2_end': '1985', 'chunk1': 'HTG', 'entity1': 'PROBLEM', 'entity2_begin': '1975', 'chunk2_confidence': '0.56735003', 'entity1_begin': '1966', 'sentence': '12', 'direction': 'both', 'entity1_end': '1968', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.9839'}, []),
#  Annotation(category, 1966, 2002, TeRP, {'chunk2': 'the anion gap', 'confidence': '0.9764806', 'entity2_end': '2002', 'chunk1': 'HTG', 'entity1': 'PROBLEM', 'entity2_begin': '1990', 'chunk2_confidence': '0.47016668', 'entity1_begin': '1966', 'sentence': '12', 'direction': 'both', 'entity1_end': '1968', 'entity2': 'TEST', 'chunk1_confidence': '0.9839'}, []),
#  Annotation(category, 1966, 2026, TeRP, {'chunk2': 'triglycerides', 'confidence': '0.9998374', 'entity2_end': '2026', 'chunk1': 'HTG', 'entity1': 'PROBLEM', 'entity2_begin': '2014', 'chunk2_confidence': '0.9965', 'entity1_begin': '1966', 'sentence': '12', 'direction': 'both', 'entity1_end': '1968', 'entity2': 'TEST', 'chunk1_confidence': '0.9839'}, []),
#  Annotation(category, 1990, 2026, TeRP, {'chunk2': 'triglycerides', 'confidence': '0.99999964', 'entity2_end': '2026', 'chunk1': 'the anion gap', 'entity1': 'TEST', 'entity2_begin': '2014', 'chunk2_confidence': '0.9965', 'entity1_begin': '1990', 'sentence': '12', 'direction': 'both', 'entity1_end': '2002', 'entity2': 'TEST', 'chunk1_confidence': '0.47016668'}, []),
#  Annotation(category, 2106, 2170, O, {'chunk2': 'SGLT2 inhibitor', 'confidence': '0.9999974', 'entity2_end': '2170', 'chunk1': 'her respiratory tract infection', 'entity1': 'PROBLEM', 'entity2_begin': '2156', 'chunk2_confidence': '0.9021', 'entity1_begin': '2106', 'sentence': '13', 'direction': 'both', 'entity1_end': '2136', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.899625'}, []),
#  Annotation(category, 2266, 2319, O, {'chunk2': 'insulin lispro', 'confidence': '0.98402923', 'entity2_end': '2319', 'chunk1': 'insulin glargine', 'entity1': 'TREATMENT', 'entity2_begin': '2306', 'chunk2_confidence': '0.97045004', 'entity1_begin': '2266', 'sentence': '14', 'direction': 'both', 'entity1_end': '2281', 'entity2': 'TREATMENT', 'chunk1_confidence': '0.98969996'}, [])]

# %% [markdown]
# ### setScopeWindow

# %% [markdown]
#  By applying the scopeWindow [X, Y], additional X tokens to the left and Y tokens to the right for feature generation, enriching contextual information essential for precise embeddings-based feature extraction.

# %% [markdown]
# Lets set Scope Window instead of default ones by using .`setScopeWindow` parameter

# %%
ner = medical.NerModel.pretrained("ner_oncology", "en", "clinical/models") \
    .setInputCols(["sentences", "tokens", "embeddings"]) \
    .setOutputCol("ner")

ner_converter = medical.NerConverterInternal() \
    .setInputCols(["sentences", "tokens", "ner"]) \
    .setOutputCol("ner_chunk")

pos_tagger = nlp.PerceptronModel.pretrained("pos_clinical", "en", "clinical/models") \
    .setInputCols(["sentences", "tokens"]) \
    .setOutputCol("pos_tags")

dependency_parser = nlp.DependencyParserModel.pretrained("dependency_conllu", "en") \
    .setInputCols(["sentences", "pos_tags", "tokens"]) \
    .setOutputCol("dependencies")

re_model = medical.RelationExtractionModel.pretrained("re_oncology", "en", "clinical/models") \
    .setInputCols(["embeddings", "pos_tags", "ner_chunk", "dependencies"]) \
    .setOutputCol("re_oncology_results") \
    .setScopeWindow([5,5])

pipeline = nlp.Pipeline(
    stages=[
        documenter,
        sentencer,
        tokenizer,
        words_embedder,
        ner,
        ner_converter,
        pos_tagger,
        dependency_parser,
        re_model])

text = """
A mastectomy was performed two months ago, and a 3 cm mass was extracted.
two years ago, she noted a palpable right breast mass, 15 cm in size. Core needle biopsy revealed metaplastic carcinoma.
The patient presented a 2 cm mass in her left breast, and the tumor in her other breast was 3 cm long.
"""
# Out:
# ner_oncology download started this may take some time.
# [OK!]
# pos_clinical download started this may take some time.
# Approximate size to download 1.5 MB
# [OK!]
# dependency_conllu download started this may take some time.
# Approximate size to download 16.7 MB
# [OK!]
# re_oncology download started this may take some time.
# [OK!]

# %%
empty_data = spark.createDataFrame([[""]]).toDF("text")
model = pipeline.fit(empty_data)
lmodel = nlp.LightPipeline(model)
results = lmodel.fullAnnotate(text)

get_relations_df (results, rel_col='re_oncology_results', chunk_col='ner_chunk')
# Out:
#    sentence entity1_begin entity1_end              chunk1            entity1  \
# 0         0             3          12          mastectomy     Cancer_Surgery
# 1         0            28          41      two months ago      Relative_Date
# 2         1           111         115               right          Direction
# 3         1           111         115               right          Direction
# 4         1           117         122              breast        Site_Breast
# 5         1           124         127                mass      Tumor_Finding
# 6         2           145         162  Core needle biopsy     Pathology_Test
# 7         2           173         183         metaplastic  Histological_Type
# 8         3           220         223                2 cm         Tumor_Size
# 9         3           220         223                2 cm         Tumor_Size
# 10        3           220         223                2 cm         Tumor_Size
# 11        3           225         228                mass      Tumor_Finding
# 12        3           233         235                 her             Gender
# 13        3           233         235                 her             Gender
# 14        3           233         235                 her             Gender
# 15        3           233         235                 her             Gender
# 16        3           237         240                left          Direction
# 17        3           237         240                left          Direction
# 18        3           237         240                left          Direction
# 19        3           242         247              breast        Site_Breast
# 20        3           258         262               tumor      Tumor_Finding
# 21        3           258         262               tumor      Tumor_Finding
# 22        3           267         269                 her             Gender
# 23        3           267         269                 her             Gender
# 24        3           277         282              breast        Site_Breast
#
#    entity2_begin entity2_end          chunk2            entity2  \
# 0             28          41  two months ago      Relative_Date
# 1             50          53            3 cm         Tumor_Size
# 2            117         122          breast        Site_Breast
# 3            124         127            mass      Tumor_Finding
# 4            124         127            mass      Tumor_Finding
# 5            130         134           15 cm         Tumor_Size
# 6            173         183     metaplastic  Histological_Type
# 7            185         193       carcinoma          Cancer_Dx
# 8            225         228            mass      Tumor_Finding
# 9            233         235             her             Gender
# 10           258         262           tumor      Tumor_Finding
# 11           233         235             her             Gender
# 12           237         240            left          Direction
# 13           242         247          breast        Site_Breast
# 14           258         262           tumor      Tumor_Finding
# 15           267         269             her             Gender
# 16           242         247          breast        Site_Breast
# 17           258         262           tumor      Tumor_Finding
# 18           267         269             her             Gender
# 19           258         262           tumor      Tumor_Finding
# 20           267         269             her             Gender
# 21           277         282          breast        Site_Breast
# 22           277         282          breast        Site_Breast
# 23           288         291            3 cm         Tumor_Size
# 24           288         291            3 cm         Tumor_Size
#
#          relation  confidence
# 0   is_related_to    0.968594
# 1   is_related_to   0.5710242
# 2   is_related_to  0.92560345
# 3   is_related_to   0.8257168
# 4   is_related_to  0.82079536
# 5   is_related_to   0.7651594
# 6   is_related_to   0.6965841
# 7   is_related_to   0.9588316
# 8   is_related_to  0.97124344
# 9   is_related_to  0.99956256
# 10  is_related_to     0.50454
# 11  is_related_to  0.99869764
# 12  is_related_to  0.94067687
# 13  is_related_to  0.69771653
# 14  is_related_to  0.85589904
# 15  is_related_to  0.70885235
# 16  is_related_to   0.9630643
# 17  is_related_to  0.89724654
# 18  is_related_to   0.7356287
# 19  is_related_to  0.66703117
# 20  is_related_to   0.9366083
# 21  is_related_to   0.5735648
# 22  is_related_to   0.7727899
# 23  is_related_to  0.71926206
# 24  is_related_to  0.79558617

# %%
re_model = medical.RelationExtractionModel.pretrained("re_oncology_wip", "en", "clinical/models") \
    .setInputCols(["embeddings", "pos_tags", "ner_chunk", "dependencies"]) \
    .setOutputCol("re_oncology_results") \
    .setScopeWindow([10,10])

pipeline = nlp.Pipeline(
    stages=[
        documenter,
        sentencer,
        tokenizer,
        words_embedder,
        ner,
        ner_converter,
        pos_tagger,
        dependency_parser,
        re_model])

text = """
A mastectomy was performed two months ago, and a 3 cm mass was extracted.
two years ago, she noted a palpable right breast mass, 15 cm in size. Core needle biopsy revealed metaplastic carcinoma.
The patient presented a 2 cm mass in her left breast, and the tumor in her other breast was 3 cm long.
"""
# Out:
# re_oncology_wip download started this may take some time.
# [OK!]

# %%
empty_data = spark.createDataFrame([[""]]).toDF("text")
model = pipeline.fit(empty_data)
lmodel = nlp.LightPipeline(model)
results = lmodel.fullAnnotate(text)

get_relations_df (results, rel_col='re_oncology_results', chunk_col='ner_chunk')
# Out:
#    sentence entity1_begin entity1_end          chunk1            entity1  \
# 0         0             3          12      mastectomy     Cancer_Surgery
# 1         0             3          12      mastectomy     Cancer_Surgery
# 2         0            28          41  two months ago      Relative_Date
# 3         0            28          41  two months ago      Relative_Date
# 4         0            50          53            3 cm         Tumor_Size
# 5         1           111         115           right          Direction
# 6         1           124         127            mass      Tumor_Finding
# 7         2           173         183     metaplastic  Histological_Type
# 8         3           220         223            2 cm         Tumor_Size
# 9         3           220         223            2 cm         Tumor_Size
# 10        3           220         223            2 cm         Tumor_Size
# 11        3           225         228            mass      Tumor_Finding
# 12        3           225         228            mass      Tumor_Finding
# 13        3           225         228            mass      Tumor_Finding
# 14        3           225         228            mass      Tumor_Finding
# 15        3           225         228            mass      Tumor_Finding
# 16        3           225         228            mass      Tumor_Finding
# 17        3           225         228            mass      Tumor_Finding
# 18        3           233         235             her             Gender
# 19        3           233         235             her             Gender
# 20        3           237         240            left          Direction
# 21        3           237         240            left          Direction
# 22        3           258         262           tumor      Tumor_Finding
# 23        3           258         262           tumor      Tumor_Finding
# 24        3           258         262           tumor      Tumor_Finding
# 25        3           267         269             her             Gender
# 26        3           267         269             her             Gender
# 27        3           277         282          breast        Site_Breast
#
#    entity2_begin entity2_end          chunk2        entity2       relation  \
# 0             28          41  two months ago  Relative_Date  is_related_to
# 1             50          53            3 cm     Tumor_Size  is_related_to
# 2             50          53            3 cm     Tumor_Size  is_related_to
# 3             55          58            mass  Tumor_Finding  is_related_to
# 4             55          58            mass  Tumor_Finding  is_related_to
# 5            117         122          breast    Site_Breast  is_related_to
# 6            130         134           15 cm     Tumor_Size  is_related_to
# 7            185         193       carcinoma      Cancer_Dx  is_related_to
# 8            225         228            mass  Tumor_Finding  is_related_to
# 9            233         235             her         Gender  is_related_to
# 10           237         240            left      Direction  is_related_to
# 11           233         235             her         Gender  is_related_to
# 12           237         240            left      Direction  is_related_to
# 13           242         247          breast    Site_Breast  is_related_to
# 14           258         262           tumor  Tumor_Finding  is_related_to
# 15           267         269             her         Gender  is_related_to
# 16           277         282          breast    Site_Breast  is_related_to
# 17           288         291            3 cm     Tumor_Size  is_related_to
# 18           237         240            left      Direction  is_related_to
# 19           242         247          breast    Site_Breast  is_related_to
# 20           242         247          breast    Site_Breast  is_related_to
# 21           258         262           tumor  Tumor_Finding  is_related_to
# 22           267         269             her         Gender  is_related_to
# 23           277         282          breast    Site_Breast  is_related_to
# 24           288         291            3 cm     Tumor_Size  is_related_to
# 25           277         282          breast    Site_Breast  is_related_to
# 26           288         291            3 cm     Tumor_Size  is_related_to
# 27           288         291            3 cm     Tumor_Size  is_related_to
#
#     confidence
# 0    0.9828268
# 1   0.52637947
# 2    0.6852348
# 3    0.8147535
# 4    0.9886253
# 5    0.9843093
# 6    0.6948512
# 7   0.73977524
# 8    0.8561782
# 9    0.6912351
# 10   0.9257264
# 11  0.99675095
# 12   0.9999062
# 13   0.9585818
# 14    0.594084
# 15  0.75291014
# 16   0.5726365
# 17  0.59602803
# 18   0.9910054
# 19   0.6119752
# 20   0.9860967
# 21   0.5103659
# 22   0.8783879
# 23   0.5581326
# 24    0.545369
# 25   0.8488858
# 26   0.9365484
# 27   0.7211017

# %% [markdown]
# By expanding the scope window, relation extraction is enhanced.
