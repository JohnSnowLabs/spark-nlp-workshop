# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/spark-nlp-workshop/blob/master/Spark_NLP_Udemy_MOOC/Healthcare_NLP/SentenceEntityResolverApproach.ipynb)

# %% [markdown]
# # **SentenceEntityResolverApproach**

# %% [markdown]
# This notebook will cover the different parameters and usages of `SentenceEntityResolverApproach`. This annotator trains a SentenceEntityResolverModel that maps sentence embeddings to entities in a knowledge base.
#
# **📖 Learning Objectives:**
#
# 1. Understand the application and relevance of these models in healthcare data analysis, particularly in coding and classification tasks related to healthcare ontologies like ICD-10, RxNorm, SNOMED, etc.
#
# 2. Become comfortable using the different parameters of the annotator.
#
#
# **🔗 Helpful Links:**
#
# - Documentation : [SentenceEntityResolverApproach](https://nlp.johnsnowlabs.com/docs/en/licensed_annotators#sentenceentityresolver)
#
# - Python Docs : [SentenceEntityResolverApproach](https://nlp.johnsnowlabs.com/licensed/api/python/reference/autosummary/sparknlp_jsl/annotator/resolution/sentence_entity_resolver/index.html)
#
# - Scala Docs : [SentenceEntityResolverApproach](https://nlp.johnsnowlabs.com/licensed/api/com/johnsnowlabs/finance/chunk_classification/resolution/SentenceEntityResolverApproach.html)
#
# - For extended examples of usage, see the [Spark NLP Workshop repository](https://github.com/JohnSnowLabs/spark-nlp-workshop/tree/master/tutorials/Certification_Trainings/Healthcare).

# %% [markdown]
# ## **🎬 Colab Setup**

# %%
# !pip install -q johnsnowlabs

# %%
from google.colab import files
print('Please Upload your John Snow Labs License using the button below')
license_keys = files.upload()

# %%
from johnsnowlabs import nlp, medical

nlp.install()
# Out:
# 👌 Detected license file /content/5.4.0.spark_nlp_for_healthcare.json
# 🚨 Outdated Medical Secrets in license file. Version=5.4.0.PR but should be Version=5.4.0
# 🚨 Outdated OCR Secrets in license file. Version=5.1.2 but should be Version=5.4.0
# 👷 Trying to install compatible secrets. Use nlp.settings.enforce_versions=False if you want to install outdated secrets.
# 📋 Stored John Snow Labs License in /root/.johnsnowlabs/licenses/license_number_0_for_Spark-Healthcare_Spark-OCR.json
# 👷 Setting up  John Snow Labs home in /root/.johnsnowlabs, this might take a few minutes.
# Downloading 🐍+🚀 Python Library spark_nlp-5.4.0-py2.py3-none-any.whl
# Downloading 🐍+💊 Python Library spark_nlp_jsl-5.4.0-py3-none-any.whl
# Downloading 🫘+🚀 Java Library spark-nlp-assembly-5.4.0.jar
# Downloading 🫘+💊 Java Library spark-nlp-jsl-5.4.0.jar
# 🙆 JSL Home setup in /root/.johnsnowlabs
# 👌 Detected license file /content/5.4.0.spark_nlp_for_healthcare.json
# 👷 Trying to install compatible secrets. Use nlp.settings.enforce_versions=False if you want to install outdated secrets.
# Installing /root/.johnsnowlabs/py_installs/spark_nlp_jsl-5.4.0-py3-none-any.whl to /usr/bin/python3
# Installed 1 products:
# 💊 Spark-Healthcare==5.4.0 installed! ✅ Heal the planet with NLP!

# %%
import pandas as pd

spark = nlp.start(hardware_target="gpu")
# Out:
# 👌 Detected license file /content/5.4.0.spark_nlp_for_healthcare.json
# 👷 Trying to install compatible secrets. Use nlp.settings.enforce_versions=False if you want to install outdated secrets.
# 🤓 Looks like you are missing some jars, trying fetching them ...
# 👌 Detected license file /content/5.4.0.spark_nlp_for_healthcare.json
# 👷 Trying to install compatible secrets. Use nlp.settings.enforce_versions=False if you want to install outdated secrets.
# Downloading 🫘+🚀 Java Library spark-nlp-gpu-assembly-5.4.0.jar
# 🙆 JSL Home setup in /root/.johnsnowlabs
# 👌 Detected license file /content/5.4.0.spark_nlp_for_healthcare.json
# 👷 Trying to install compatible secrets. Use nlp.settings.enforce_versions=False if you want to install outdated secrets.
# 👌 Launched gpu optimized session with with: 🚀Spark-NLP==5.4.0, 💊Spark-Healthcare==5.4.0, running on ⚡ PySpark==3.4.0

# %% [markdown]
# ## **🖨️ Input/Output Annotation Types**

# %% [markdown]
# - Input: `SENTENCE_EMBEDDINGS`
#
# - Output: `ENTITY`

# %% [markdown]
# ## **🔎 Parameters**

# %% [markdown]
# General parameters:
#
# - `labelCol` : Column name for the value we are trying to resolve. Usually this contains the entity ID in the knowledge base (e.g., the ICD-10 code).
#
# - `normalizedCol`: Column name for the original, normalized description
#
# - `aux_label_col`: Auxiliary label which maps resolved entities to additional labels
#
# - `useAuxLabel`: Whether to use the auxiliary column or not. Default value is False.
#
# - `distanceFunction`: Determines how the distance between different entities will be calculated.
#
# - `confidenceFunction`: What function to use to calculate confidence: Either ` `INVERSE` or `SOFTMAX`.
#
# - `caseSensitive`: whether to ignore case in tokens for embeddings matching (Default: `False`)
#
# - `threshold`: Threshold value for the last distance calculated (default: 5.0)
#
# - `missAsEmpty`: whether or not to return an empty annotation on unmatched chunks (default: `True`)
#
# - `setDatasetInfo`(info: str): Sets descriptive information about the dataset being used.
#
#
#
# </br>
#
# When finetuning an existing model, there are additional parameters:
#
# - `pretrainedModelPath`: Path to an already trained SentenceEntityResolverModel.This pretrained model will be used as a starting point for training the new one. The path can be a local file path, a distributed file path (HDFS, DBFS), or a cloud storage (S3).
#
# - `overrideExistingCodes`: Whether to override the existing codes with new data while continue the training from a pretrained model. Default value is `False` (keep all the codes).
#
# - `dropCodesList`: A list of codes in a pretrained model that will be omitted when the training process begins with a pretrained model.

# %% [markdown]
# ### **Prepare Data**

# %% [markdown]
# We will use sample data with SNOMED codes.

# %%
# !wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/AskAPatient.fold-0.test.txt
# !wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/AskAPatient.fold-0.train.txt
# !wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/AskAPatient.fold-0.validation.txt

# %%
import pandas as pd


cols = ["snomed_code", "concept_name", "snomed_text"]

aap_tr = pd.read_csv(
    "AskAPatient.fold-0.train.txt",
    sep="\t",
    encoding="ISO-8859-1",
    header=None,
    names=cols
)
aap_tr["snomed_code"] = aap_tr.snomed_code.apply(str)

aap_ts = pd.read_csv(
    "AskAPatient.fold-0.test.txt", sep="\t", header=None, names=cols
)
aap_ts["snomed_code"] = aap_ts.snomed_code.apply(str)

aap_vl = pd.read_csv(
    "AskAPatient.fold-0.validation.txt", sep="\t", header=None, names=cols
)
aap_vl["snomed_code"] = aap_vl.snomed_code.apply(str)

# %%
aap_tr.head()
# Out:
#         snomed_code             concept_name              snomed_text
# 0         108367008     Dislocation of joint     Dislocation of joint
# 1  3384011000036100                Arthrotec                Arthrotec
# 2         166717003  Serum creatinine raised  Serum creatinine raised
# 3  3877011000036101                  Lipitor                  Lipitor
# 4         402234004              Foot eczema              Foot eczema

# %%
# Create spark dataframes

aap_train_sdf = spark.createDataFrame(aap_tr)
aap_test_sdf = spark.createDataFrame(aap_ts)
aap_val_sdf = spark.createDataFrame(aap_vl)

# %%
aap_train_sdf.show()
# Out:
# +----------------+--------------------+--------------------+
# |     snomed_code|        concept_name|         snomed_text|
# +----------------+--------------------+--------------------+
# |       108367008|Dislocation of joint|Dislocation of joint|
# |3384011000036100|           Arthrotec|           Arthrotec|
# |       166717003|Serum creatinine ...|Serum creatinine ...|
# |3877011000036101|             Lipitor|             Lipitor|
# |       402234004|         Foot eczema|         Foot eczema|
# |       404640003|           Dizziness|           Dizziness|
# |       271681002|        Stomach ache|        Stomach ache|
# |        76948002|         Severe pain|         Severe pain|
# |        36031001|        Burning feet|        Burning feet|
# |        76948002|         Severe pain|         Severe pain|
# |        42399005|       Renal failure|       Renal failure|
# |       288227007|Myalgia/myositis ...|Myalgia/myositis ...|
# |       419723007|       Mentally dull|       Mentally dull|
# |       248490000|    Bloating symptom|    Bloating symptom|
# |        22253000|                Pain|                Pain|
# |       162076009|Excessive upper g...|Excessive upper g...|
# |       247592009|Poor short-term m...|Poor short-term m...|
# |        62507009|    Pins and needles|    Pins and needles|
# |3877011000036101|             Lipitor|             Lipitor|
# |        62507009|    Pins and needles|    Pins and needles|
# +----------------+--------------------+--------------------+
# only showing top 20 rows

# %%
documentAssembler = nlp.DocumentAssembler()\
    .setInputCol("snomed_text")\
    .setOutputCol("sentence")

bert_embeddings = nlp.BertSentenceEmbeddings.pretrained("sbiobert_base_cased_mli", "en", "clinical/models")\
    .setInputCols(["sentence"])\
    .setOutputCol("bert_embeddings")
    # .setCaseSensitive(False)

embeddings_pipeline = nlp.Pipeline(stages = [
    documentAssembler,
    bert_embeddings])

embeddings_model = embeddings_pipeline.fit(aap_train_sdf)
snomed_data = embeddings_model.transform(aap_train_sdf)
# Out:
# sbiobert_base_cased_mli download started this may take some time.
# Approximate size to download 384.3 MB
# [OK!]

# %%
snomed_data.show()
# Out:
# +----------------+--------------------+--------------------+--------------------+--------------------+
# |     snomed_code|        concept_name|         snomed_text|            sentence|     bert_embeddings|
# +----------------+--------------------+--------------------+--------------------+--------------------+
# |       108367008|Dislocation of joint|Dislocation of joint|[{document, 0, 19...|[{sentence_embedd...|
# |3384011000036100|           Arthrotec|           Arthrotec|[{document, 0, 8,...|[{sentence_embedd...|
# |       166717003|Serum creatinine ...|Serum creatinine ...|[{document, 0, 22...|[{sentence_embedd...|
# |3877011000036101|             Lipitor|             Lipitor|[{document, 0, 6,...|[{sentence_embedd...|
# |       402234004|         Foot eczema|         Foot eczema|[{document, 0, 10...|[{sentence_embedd...|
# |       404640003|           Dizziness|           Dizziness|[{document, 0, 8,...|[{sentence_embedd...|
# |       271681002|        Stomach ache|        Stomach ache|[{document, 0, 11...|[{sentence_embedd...|
# |        76948002|         Severe pain|         Severe pain|[{document, 0, 10...|[{sentence_embedd...|
# |        36031001|        Burning feet|        Burning feet|[{document, 0, 11...|[{sentence_embedd...|
# |        76948002|         Severe pain|         Severe pain|[{document, 0, 10...|[{sentence_embedd...|
# |        42399005|       Renal failure|       Renal failure|[{document, 0, 12...|[{sentence_embedd...|
# |       288227007|Myalgia/myositis ...|Myalgia/myositis ...|[{document, 0, 27...|[{sentence_embedd...|
# |       419723007|       Mentally dull|       Mentally dull|[{document, 0, 12...|[{sentence_embedd...|
# |       248490000|    Bloating symptom|    Bloating symptom|[{document, 0, 15...|[{sentence_embedd...|
# |        22253000|                Pain|                Pain|[{document, 0, 3,...|[{sentence_embedd...|
# |       162076009|Excessive upper g...|Excessive upper g...|[{document, 0, 35...|[{sentence_embedd...|
# |       247592009|Poor short-term m...|Poor short-term m...|[{document, 0, 21...|[{sentence_embedd...|
# |        62507009|    Pins and needles|    Pins and needles|[{document, 0, 15...|[{sentence_embedd...|
# |3877011000036101|             Lipitor|             Lipitor|[{document, 0, 6,...|[{sentence_embedd...|
# |        62507009|    Pins and needles|    Pins and needles|[{document, 0, 15...|[{sentence_embedd...|
# +----------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ### **Train Model**

# %% [markdown]
# To train the model, we need to indicate the ground truth code (present in the `snomed_code` column) and the ground truth normalized text (present in the `snomed_text` column).
#
# Optional parameters are:
#
# - `distanceFunction`, that can be chosen to be either `EUCLIDEAN` or `COSINE`
# - `caseSensitive`: True or False for casing sensitiveness

# %%
bertExtractor = (
    medical.SentenceEntityResolverApproach()
    .setNeighbours(25)
    .setThreshold(1000)
    .setInputCols("bert_embeddings")
    .setNormalizedCol("snomed_text")
    .setLabelCol("snomed_code")
    .setOutputCol("snomed_pred")
    .setDistanceFunction("EUCLIDIAN") # Or COSINE
    .setCaseSensitive(False)
    .setDatasetInfo("snomed dataset")
)

# %time snomed_model = bertExtractor.fit(snomed_data)
# Out:
# CPU times: user 4.93 s, sys: 658 ms, total: 5.59 s
# Wall time: 16min 59s

# %%
# save if you will need that later
snomed_model.write().overwrite().save("biobertresolve_snomed_askapatient")

# %%
prediction_Model = nlp.PipelineModel(
    stages=[embeddings_model, snomed_model]
)

aap_test_pred = prediction_Model.transform(aap_test_sdf).cache()
aap_val_pred = prediction_Model.transform(aap_val_sdf).cache()

# %%
aap_test_pred.selectExpr(
    "snomed_code",
    "concept_name",
    "snomed_text",
    "snomed_pred[0].result",
    "snomed_pred[0].metadata.resolved_text",
    "snomed_pred[0].metadata.all_k_resolutions",
).show(truncate=50)
# Out:
# +----------------+------------------------------------+--------------------------------+---------------------+--------------------------------------+--------------------------------------------------+
# |     snomed_code|                        concept_name|                     snomed_text|snomed_pred[0].result|snomed_pred[0].metadata[resolved_text]|        snomed_pred[0].metadata[all_k_resolutions]|
# +----------------+------------------------------------+--------------------------------+---------------------+--------------------------------------+--------------------------------------------------+
# |       108367008|                Dislocation of joint|                     dislocating|            387603000|                           balance off|balance off:::Impaired mobility:::Reduced mobil...|
# |3384011000036100|                           Arthrotec|                       Arthrotec|     3384011000036100|                             Arthrotec|                                         Arthrotec|
# |       166717003|             Serum creatinine raised|               elevated creatine|            166717003|                   elevated Creatinine|elevated Creatinine:::Increased creatine kinase...|
# |3877011000036101|                             Lipitor|                         Lipitor|     3877011000036101|                               Lipitor|                                           Lipitor|
# |       402234004|                         Foot eczema|                  Eczema on feet|            402234004|                           Foot eczema|Foot eczema:::Eczema:::Eczema on hands:::foot s...|
# |       404640003|                           Dizziness|                           dizzy|            404640003|                                 dizzy|dizzy:::sleepy:::trembling:::so tired:::sorenes...|
# |       271681002|                        Stomach ache|   pain in the pit of my stomach|             21522001|                    pain in my stomach|pain in my stomach:::pain in my stomach:::gas p...|
# |        76948002|                         Severe pain|extreme muscle pain in shoulders|             76948002|       Severe muscle pain in shoulders|Severe muscle pain in shoulders:::muscle pain i...|
# |        36031001|                        Burning feet|                    Burning feet|             36031001|                          Burning feet|Burning feet:::burning sensations in legs:::bur...|
# |        76948002|                         Severe pain|             imence pain in legs|             10601006|                          pain in legs|                pain in legs:::muscle pain in legs|
# |        42399005|                       Renal failure|              kidney malfunction|             90708001|                       kidney problems|kidney problems:::kidney damage:::kidney failur...|
# |       288227007|        Myalgia/myositis - upper arm|        muscle pain in my biceps|             68962001|   debilitating muscle pain in my arms|debilitating muscle pain in my arms:::muscle pa...|
# |       419723007|                       Mentally dull|                       brain fog|            419723007|                             brain fog|brain fog:::Memory fog:::head hurt:::Extreme we...|
# |       248490000|                    Bloating symptom|                        bloating|            248490000|                              bloating|                                          bloating|
# |        22253000|                                Pain|                            pain|             22253000|                                  pain|                                              pain|
# |       162076009|Excessive upper gastrointestinal gas|                             gas|            162076009|                                   gas|                                               gas|
# |       247592009|              Poor short-term memory|          Short term memory loss|            247592009|                short term memory loss|    short term memory loss:::Transient memory loss|
# |        62507009|                    Pins and needles|             tingling in my feet|             62507009|                      tingling in feet|tingling in feet:::sensations of tingling in my...|
# |3877011000036101|                             Lipitor|                         LIPITOR|     3877011000036101|                               LIPITOR|                                   LIPITOR:::LIPEX|
# |        62507009|                    Pins and needles|   tingling on left side of face|            309557009|         Numbness on left side of face|Numbness on left side of face:::numbness on lef...|
# +----------------+------------------------------------+--------------------------------+---------------------+--------------------------------------+--------------------------------------------------+
# only showing top 20 rows

# %%
aap_val_pred.selectExpr(
    "snomed_code",
    "concept_name",
    "snomed_text",
    "snomed_pred[0].result",
    "snomed_pred[0].metadata.resolved_text",
    "snomed_pred[0].metadata.all_k_resolutions",
).show(truncate=50)
# Out:
# +----------------+---------------------+------------------------------+---------------------+--------------------------------------+--------------------------------------------------+
# |     snomed_code|         concept_name|                   snomed_text|snomed_pred[0].result|snomed_pred[0].metadata[resolved_text]|        snomed_pred[0].metadata[all_k_resolutions]|
# +----------------+---------------------+------------------------------+---------------------+--------------------------------------+--------------------------------------------------+
# |       267032009|   Tired all the time|persisten feeling of tiredness|             84229001|                     extreme tiredness|extreme tiredness:::feeling tired a lot:::feeli...|
# |        22298006|Myocardial infarction|                  HEART ATTACK|             22298006|                          HEART ATTACH|HEART ATTACH:::HEADACHES:::LIGHT HEADED:::HAIR ...|
# |3877011000036101|              Lipitor|                       LIPITOR|     3877011000036101|                               LIPITOR|                                   LIPITOR:::LIPEX|
# |       415690000|             Sweating|                       sweated|            415690000|                              Sweating|                               Sweating:::Swelling|
# |       248491001|         Swollen knee|              swelling at knee|            299322007|                Swelling of knee joint|Swelling of knee joint:::swelling of the legs::...|
# |       248490000|     Bloating symptom|                      bloating|            248490000|                              bloating|                                          bloating|
# |       162059005|        Upset stomach|                 stomach upset|            162059005|                         stomach upset|stomach upset:::gastric upsets:::stomach troubl...|
# |3877011000036101|              Lipitor|                       Lipitor|     3877011000036101|                               Lipitor|                                           Lipitor|
# |        62507009|     Pins and needles|                      tingling|             62507009|                              tingling|                         tingling:::hands tingling|
# |       238131007|           Overweight|                   over weight|            238131007|                           over weight|over weight:::gaining excess weight:::fatiqued:...|
# |        73595000|               Stress|                        stress|             73595000|                                stress|                                 stress:::so tired|
# |3877011000036101|              Lipitor|                       lipitor|     3877011000036101|                               lipitor|                                           lipitor|
# |3877011000036101|              Lipitor|                       Lipitor|     3877011000036101|                               Lipitor|                                           Lipitor|
# |        22253000|                 Pain|                          hurt|             22253000|                              It hurts|It hurts:::feel bad:::confusion:::feel dreadful...|
# |        73211009|    Diabetes mellitus|                      diabetes|             73211009|                              diabetes|                         diabetes:::type2 diabetes|
# |        10601006|   Pain in lower limb|                     sore legs|             10601006|                             sore legs|sore legs:::sore arms:::sore feet:::sore knees:...|
# |        75694006|         Pancreatitis|       acute pancreatic attack|             75694006|                          Pancreatitis|Pancreatitis:::Peritonitis:::abdominal hematoma...|
# |        51197009|       Stomach cramps|     SEVERE abdominal cramping|              9991008|                    abdominal cramping|abdominal cramping:::gassy abdominal cramping::...|
# |         3723001|            Arthritis|                     arthrites|              3723001|                            arthristis|                            arthristis:::arthrotec|
# |       271767006|      Peeling of skin|        skin began to come off|            278040002|          hair has started falling out|hair has started falling out:::vision became bl...|
# +----------------+---------------------+------------------------------+---------------------+--------------------------------------+--------------------------------------------------+
# only showing top 20 rows

# %%
preds_test = aap_test_pred.selectExpr(
    "snomed_code as ytrue", "snomed_pred[0].result as ypred"
).toPandas()
preds_test.head()
# Out:
#               ytrue             ypred
# 0         108367008         387603000
# 1  3384011000036100  3384011000036100
# 2         166717003         166717003
# 3  3877011000036101  3877011000036101
# 4         402234004         402234004

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(preds_test.ytrue, preds_test.ypred)
# Out:
# 0.8016147635524798

# %% [markdown]
# ###  **Train Model with Auxilary Informations**
#
# We can add auxialry information to our model. In here we will add an aux column with the concept names of each code, being more general than the specific occurrence of the code. The auxiliary information will be present in the  `all_k_aux_labels` field of the metadata.

# %%
bertExtractor_aux = (
    medical.SentenceEntityResolverApproach()
    .setNeighbours(25)
    .setThreshold(1000)
    .setInputCols("bert_embeddings")
    .setNormalizedCol("snomed_text")
    .setLabelCol("snomed_code")
    .setOutputCol("snomed_pred")
    .setDistanceFunction("EUCLIDIAN")
    .setCaseSensitive(False)
    .setUseAuxLabel(True)
    .setAuxLabelCol("concept_name")
)

# %time snomed_aux_model = bertExtractor_aux.fit(snomed_data)
# Out:
# CPU times: user 9.86 s, sys: 1.27 s, total: 11.1 s
# Wall time: 34min 32s

# %%
# save if you will need that later
snomed_aux_model.write().overwrite().save(
    "biobertresolve_snomed_askapatient_aux"
)

# %%
aux_prediction_Model = nlp.PipelineModel(
    stages=[embeddings_model, snomed_aux_model]
)

aap_test_pred_aux = aux_prediction_Model.transform(aap_test_sdf).cache()
aap_val_pred_aux = aux_prediction_Model.transform(aap_val_sdf).cache()

# %%
aap_test_pred_aux.selectExpr(
    "snomed_code",
    "concept_name",
    "snomed_text",
    "snomed_pred[0].result",
    "snomed_pred[0].metadata.resolved_text",
    "snomed_pred[0].metadata.all_k_resolutions",
    "snomed_pred[0].metadata.all_k_aux_labels",
).show(truncate=50)
# Out:
# +----------------+------------------------------------+--------------------------------+---------------------+--------------------------------------+--------------------------------------------------+--------------------------------------------------+
# |     snomed_code|                        concept_name|                     snomed_text|snomed_pred[0].result|snomed_pred[0].metadata[resolved_text]|        snomed_pred[0].metadata[all_k_resolutions]|         snomed_pred[0].metadata[all_k_aux_labels]|
# +----------------+------------------------------------+--------------------------------+---------------------+--------------------------------------+--------------------------------------------------+--------------------------------------------------+
# |       108367008|                Dislocation of joint|                     dislocating|            387603000|                           balance off|balance off:::Impaired mobility:::Reduced mobil...|Impairment of balance:::Impaired mobility:::Red...|
# |3384011000036100|                           Arthrotec|                       Arthrotec|     3384011000036100|                             Arthrotec|                                         Arthrotec|                                         Arthrotec|
# |       166717003|             Serum creatinine raised|               elevated creatine|            166717003|                   elevated Creatinine|elevated Creatinine:::Increased creatine kinase...|Serum creatinine raised:::Increased creatine ki...|
# |3877011000036101|                             Lipitor|                         Lipitor|     3877011000036101|                               Lipitor|                                           Lipitor|                                           Lipitor|
# |       402234004|                         Foot eczema|                  Eczema on feet|            402234004|                           Foot eczema|Foot eczema:::Eczema:::Eczema on hands:::foot s...|Foot eczema:::Eczema:::Hand eczema:::Peeling of...|
# |       404640003|                           Dizziness|                           dizzy|            404640003|                                 dizzy|dizzy:::sleepy:::trembling:::so tired:::sorenes...|Dizziness:::Drowsy:::Trembles:::Tired:::Pain:::...|
# |       271681002|                        Stomach ache|   pain in the pit of my stomach|             21522001|                    pain in my stomach|pain in my stomach:::pain in my stomach:::gas p...|Abdominal pain:::Stomach ache:::Flatulence, eru...|
# |        76948002|                         Severe pain|extreme muscle pain in shoulders|             76948002|       Severe muscle pain in shoulders|Severe muscle pain in shoulders:::muscle pain i...|Severe pain:::Myalgia/myositis - shoulder:::Mya...|
# |        36031001|                        Burning feet|                    Burning feet|             36031001|                          Burning feet|Burning feet:::burning sensations in legs:::bur...|   Burning feet:::Burning sensation:::Burning pain|
# |        76948002|                         Severe pain|             imence pain in legs|             10601006|                          pain in legs|                pain in legs:::muscle pain in legs| Pain in lower limb:::Myalgia/myositis - lower leg|
# |        42399005|                       Renal failure|              kidney malfunction|             90708001|                       kidney problems|kidney problems:::kidney damage:::kidney failur...|Kidney disease:::Renal injury:::Renal failure::...|
# |       288227007|        Myalgia/myositis - upper arm|        muscle pain in my biceps|             68962001|   debilitating muscle pain in my arms|debilitating muscle pain in my arms:::muscle pa...|Myalgia:::Myalgia/myositis - shoulder:::Severe ...|
# |       419723007|                       Mentally dull|                       brain fog|            419723007|                             brain fog|brain fog:::Memory fog:::head hurt:::Extreme we...|Mentally dull:::Memory impairment:::Headache:::...|
# |       248490000|                    Bloating symptom|                        bloating|            248490000|                              bloating|                                          bloating|                                  Bloating symptom|
# |        22253000|                                Pain|                            pain|             22253000|                                  pain|                                              pain|                                              Pain|
# |       162076009|Excessive upper gastrointestinal gas|                             gas|            162076009|                                   gas|                                               gas|              Excessive upper gastrointestinal gas|
# |       247592009|              Poor short-term memory|          Short term memory loss|            247592009|                short term memory loss|    short term memory loss:::Transient memory loss|    Poor short-term memory:::Transient memory loss|
# |        62507009|                    Pins and needles|             tingling in my feet|             62507009|                      tingling in feet|tingling in feet:::sensations of tingling in my...|Pins and needles:::Paraesthesia of foot:::Parae...|
# |3877011000036101|                             Lipitor|                         LIPITOR|     3877011000036101|                               LIPITOR|                                   LIPITOR:::LIPEX|                                   Lipitor:::Lipex|
# |        62507009|                    Pins and needles|   tingling on left side of face|            309557009|         Numbness on left side of face|Numbness on left side of face:::numbness on lef...|Numbness of face:::Numbness:::Numbness of upper...|
# +----------------+------------------------------------+--------------------------------+---------------------+--------------------------------------+--------------------------------------------------+--------------------------------------------------+
# only showing top 20 rows

# %%
aap_val_pred_aux.selectExpr(
    "snomed_code",
    "concept_name",
    "snomed_text",
    "snomed_pred[0].result",
    "snomed_pred[0].metadata.resolved_text",
    "snomed_pred[0].metadata.all_k_resolutions",
    "snomed_pred[0].metadata.all_k_aux_labels",
).show(truncate=50)
# Out:
# +----------------+---------------------+------------------------------+---------------------+--------------------------------------+--------------------------------------------------+--------------------------------------------------+
# |     snomed_code|         concept_name|                   snomed_text|snomed_pred[0].result|snomed_pred[0].metadata[resolved_text]|        snomed_pred[0].metadata[all_k_resolutions]|         snomed_pred[0].metadata[all_k_aux_labels]|
# +----------------+---------------------+------------------------------+---------------------+--------------------------------------+--------------------------------------------------+--------------------------------------------------+
# |       267032009|   Tired all the time|persisten feeling of tiredness|             84229001|                     extreme tiredness|extreme tiredness:::feeling tired a lot:::feeli...|Fatigue:::Tired all the time:::Feeling tired:::...|
# |        22298006|Myocardial infarction|                  HEART ATTACK|             22298006|                          HEART ATTACH|HEART ATTACH:::HEADACHES:::LIGHT HEADED:::HAIR ...|Myocardial infarction:::Headache:::Lightheadedn...|
# |3877011000036101|              Lipitor|                       LIPITOR|     3877011000036101|                               LIPITOR|                                   LIPITOR:::LIPEX|                                   Lipitor:::Lipex|
# |       415690000|             Sweating|                       sweated|            415690000|                              Sweating|                               Sweating:::Swelling|                               Sweating:::Swelling|
# |       248491001|         Swollen knee|              swelling at knee|            299322007|                Swelling of knee joint|Swelling of knee joint:::swelling of the legs::...|Swelling of knee joint:::Swollen legs:::Ankle o...|
# |       248490000|     Bloating symptom|                      bloating|            248490000|                              bloating|                                          bloating|                                  Bloating symptom|
# |       162059005|        Upset stomach|                 stomach upset|            162059005|                         stomach upset|stomach upset:::gastric upsets:::stomach troubl...|Upset stomach:::Excessive upper gastrointestina...|
# |3877011000036101|              Lipitor|                       Lipitor|     3877011000036101|                               Lipitor|                                           Lipitor|                                           Lipitor|
# |        62507009|     Pins and needles|                      tingling|             62507009|                              tingling|                         tingling:::hands tingling|           Pins and needles:::Paraesthesia of hand|
# |       238131007|           Overweight|                   over weight|            238131007|                           over weight|over weight:::gaining excess weight:::fatiqued:...|Overweight:::Weight gain:::Fatigue:::Sensation ...|
# |        73595000|               Stress|                        stress|             73595000|                                stress|                                 stress:::so tired|                                    Stress:::Tired|
# |3877011000036101|              Lipitor|                       lipitor|     3877011000036101|                               lipitor|                                           lipitor|                                           Lipitor|
# |3877011000036101|              Lipitor|                       Lipitor|     3877011000036101|                               Lipitor|                                           Lipitor|                                           Lipitor|
# |        22253000|                 Pain|                          hurt|             22253000|                              It hurts|It hurts:::feel bad:::confusion:::feel dreadful...|Pain:::Feeling bad:::Confusion:::Malaise:::Delu...|
# |        73211009|    Diabetes mellitus|                      diabetes|             73211009|                              diabetes|                         diabetes:::type2 diabetes|      Diabetes mellitus:::Type 2 diabetes mellitus|
# |        10601006|   Pain in lower limb|                     sore legs|             10601006|                             sore legs|sore legs:::sore arms:::sore feet:::sore knees:...|Pain in lower limb:::Pain in upper limb:::Foot ...|
# |        75694006|         Pancreatitis|       acute pancreatic attack|             75694006|                          Pancreatitis|Pancreatitis:::Peritonitis:::abdominal hematoma...|Pancreatitis:::Peritonitis:::Intra-abdominal ha...|
# |        51197009|       Stomach cramps|     SEVERE abdominal cramping|              9991008|                    abdominal cramping|abdominal cramping:::gassy abdominal cramping::...|Abdominal colic:::Excessive upper gastrointesti...|
# |         3723001|            Arthritis|                     arthrites|              3723001|                            arthristis|                            arthristis:::arthrotec|                             Arthritis:::Arthrotec|
# |       271767006|      Peeling of skin|        skin began to come off|            278040002|          hair has started falling out|hair has started falling out:::vision became bl...|Loss of hair:::Blurring of visual image:::Tingl...|
# +----------------+---------------------+------------------------------+---------------------+--------------------------------------+--------------------------------------------------+--------------------------------------------------+
# only showing top 20 rows

# %%
preds_test_aux = aap_test_pred_aux.selectExpr(
    "snomed_code as ytrue", "snomed_pred[0].result as ypred"
).toPandas()
accuracy_score(preds_test_aux.ytrue, preds_test_aux.ypred)
# Out:
# 0.7993079584775087

# %% [markdown]
# ## Fine-tune existing models

# %%
bertExtractor_ft = (
    medical.SentenceEntityResolverApproach()
    .setNeighbours(25)
    .setThreshold(1000)
    .setInputCols("bert_embeddings")
    .setNormalizedCol("snomed_text")
    .setLabelCol("snomed_code")
    .setOutputCol("snomed_pred")
    .setPretrainedModelPath("biobertresolve_snomed_askapatient")
    .setOverrideExistingCodes(False) # True to keep intermediate weights only
    .setDropCodesList(["108367008", "3384011000036100"]) # If not set, keep all codes
)

# %%
# %%time
model_ft = bertExtractor_ft.fit(snomed_data)
# Out:
# CPU times: user 4.91 s, sys: 574 ms, total: 5.49 s
# Wall time: 17min 34s
