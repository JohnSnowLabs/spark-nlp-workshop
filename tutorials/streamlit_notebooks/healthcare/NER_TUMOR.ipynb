# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/spark-nlp-workshop/blob/master/tutorials/streamlit_notebooks/healthcare/NER_TUMOR.ipynb)

# %% [markdown]
# # **Detect biological concepts**

# %% [markdown]
# To run this yourself, you will need to upload your license keys to the notebook. Just Run The Cell Below in order to do that. Also You can open the file explorer on the left side of the screen and upload `license_keys.json` to the folder that opens.
# Otherwise, you can look at the example outputs at the bottom of the notebook.

# %% [markdown]
# ## 1. Colab Setup

# %%
import json, os
from google.colab import files

if 'spark_jsl.json' not in os.listdir():
  license_keys = files.upload()
  os.rename(list(license_keys.keys())[0], 'spark_jsl.json')

with open('spark_jsl.json') as f:
    license_keys = json.load(f)

# Defining license key-value pairs as local variables
locals().update(license_keys)
os.environ.update(license_keys)

# %%
# Installing pyspark and spark-nlp
! pip install --upgrade -q pyspark==3.1.2 spark-nlp==$PUBLIC_VERSION

# Installing Spark NLP Healthcare
! pip install --upgrade -q spark-nlp-jsl==$JSL_VERSION  --extra-index-url https://pypi.johnsnowlabs.com/$SECRET

# Installing Spark NLP Display Library for visualization
! pip install -q spark-nlp-display

# %%
import sparknlp
import sparknlp_jsl

from sparknlp.base import *
from sparknlp.annotator import *
from sparknlp_jsl.annotator import *

from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.ml import Pipeline,PipelineModel
from pyspark.sql.types import StringType, IntegerType

import pandas as pd
pd.set_option('display.max_colwidth', 200)

import warnings
warnings.filterwarnings('ignore')

params = {"spark.driver.memory":"16G", 
          "spark.kryoserializer.buffer.max":"2000M", 
          "spark.driver.maxResultSize":"2000M"} 

spark = sparknlp_jsl.start(license_keys['SECRET'],params=params)

print("Spark NLP Version :", sparknlp.version())
print("Spark NLP_JSL Version :", sparknlp_jsl.version())

spark
# Out:
# Spark NLP Version : 4.2.8
# Spark NLP_JSL Version : 4.2.8
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://2e56ebaae10e:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark NLP Licensed</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## 2. Select the NER model and construct the pipeline

# %% [markdown]
# Select the NER model - Tumor model: **ner_bionlp**
#
# For more details: https://github.com/JohnSnowLabs/spark-nlp-models#pretrained-models---spark-nlp-for-healthcare

# %%
# You can change this to the model you want to use and re-run cells below.
# Neoplasm models: ner_bionlp
# Bert embeddings : ner_bionlp_biobert 

MODEL_NAME = "ner_bionlp"
#MODEL_NAME = "ner_bionlp_biobert"

# %% [markdown]
# Create the pipeline

# %%
document_assembler = DocumentAssembler() \
    .setInputCol('text')\
    .setOutputCol('document')

sentence_detector = SentenceDetector() \
    .setInputCols(['document'])\
    .setOutputCol('sentence')

tokenizer = Tokenizer()\
    .setInputCols(['sentence']) \
    .setOutputCol('token')

embeddings_clinical = WordEmbeddingsModel.pretrained('embeddings_clinical', 'en', 'clinical/models') \
    .setInputCols(['sentence', 'token']) \
    .setOutputCol('embeddings')

clinical_ner = MedicalNerModel.pretrained(MODEL_NAME, "en", "clinical/models") \
    .setInputCols(["sentence", "token", "embeddings"])\
    .setOutputCol("ner")

embeddings_clinical_bert = BertEmbeddings.pretrained("biobert_pubmed_base_cased")\
    .setInputCols(["sentence", "token"])\
    .setOutputCol("embeddings")
    
ner_converter = NerConverterInternal()\
    .setInputCols(['sentence', 'token', 'ner']) \
    .setOutputCol('ner_chunk')
# Out:
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ner_bionlp download started this may take some time.
# [OK!]
# biobert_pubmed_base_cased download started this may take some time.
# Approximate size to download 386.4 MB
# [OK!]

# %%
if MODEL_NAME == "ner_bionlp":
    nlp_pipeline = Pipeline(
        stages=[
            document_assembler, 
            sentence_detector,
            tokenizer,
            embeddings_clinical,
            clinical_ner,
            ner_converter
            ])

elif MODEL_NAME == "ner_bionlp_biobert":
    nlp_pipeline = Pipeline(
        stages=[
            document_assembler, 
            sentence_detector,
            tokenizer,
            embeddings_clinical_bert,
            clinical_ner,
            ner_converter
            ])

# %% [markdown]
# ## 3. Create example inputs

# %%
# Enter examples as strings in this array
input_list = [
    """Under loupe magnification, the lesion was excised with 2 mm margins, oriented with sutures and submitted for frozen section pathology. The report was "basal cell carcinoma with all margins free of tumor." Hemostasis was controlled with the Bovie. Excised lesion diameter was 1.2 cm. The defect was closed by elevating a left laterally based rotation flap utilizing the glabellar skin. The flap was elevated with a scalpel and Bovie, rotated into the defect without tension, ***** to the defect with scissors and inset in layer with interrupted 5-0 Vicryl for the dermis and running 5-0 Prolene for the skin. Donor site was closed in V-Y fashion with similar suture technique."""
]

# %% [markdown]
# ## 4. Use the pipeline to create outputs

# %%
df = spark.createDataFrame(input_list, StringType()).toDF("text")
result = nlp_pipeline.fit(df).transform(df)

# %% [markdown]
# ## 5. Visualize results

# %%
from sparknlp_display import NerVisualizer

NerVisualizer().display(
    result = result.collect()[0],
    label_col = 'ner_chunk',
    document_col = 'document'
)
# Out:
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">Under loupe magnification, the </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #C68111"><span class="spark-nlp-display-entity-name">lesion </span><span class="spark-nlp-display-entity-type">Pathological_formation</span></span><span class="spark-nlp-display-others" style="background-color: white"> was excised with 2 mm margins, oriented with sutures and submitted for frozen section pathology. The report was "</span><span class="spark-nlp-display-entity-wrapper" style="background-color: #7B8651"><span class="spark-nlp-display-entity-name">basal cell carcinoma </span><span class="spark-nlp-display-entity-type">Cancer</span></span><span class="spark-nlp-display-others" style="background-color: white"> with all margins free of </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #7B8651"><span class="spark-nlp-display-entity-name">tumor </span><span class="spark-nlp-display-entity-type">Cancer</span></span><span class="spark-nlp-display-others" style="background-color: white">." Hemostasis was controlled with the Bovie. Excised </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #C68111"><span class="spark-nlp-display-entity-name">lesion </span><span class="spark-nlp-display-entity-type">Pathological_formation</span></span><span class="spark-nlp-display-others" style="background-color: white"> diameter was 1.2 cm. The defect was closed by elevating a left laterally based rotation flap utilizing the </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #e6e600"><span class="spark-nlp-display-entity-name">glabellar skin </span><span class="spark-nlp-display-entity-type">Organ</span></span><span class="spark-nlp-display-others" style="background-color: white">. The </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #BEC60B"><span class="spark-nlp-display-entity-name">flap </span><span class="spark-nlp-display-entity-type">Tissue</span></span><span class="spark-nlp-display-others" style="background-color: white"> was elevated with a scalpel and Bovie, rotated into the defect without tension, ***** to the defect with scissors and inset in layer with interrupted 5-0 Vicryl for the </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #BEC60B"><span class="spark-nlp-display-entity-name">dermis </span><span class="spark-nlp-display-entity-type">Tissue</span></span><span class="spark-nlp-display-others" style="background-color: white"> and running 5-0 Prolene for the </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #e6e600"><span class="spark-nlp-display-entity-name">skin </span><span class="spark-nlp-display-entity-type">Organ</span></span><span class="spark-nlp-display-others" style="background-color: white">. Donor site was closed in V-Y fashion with similar suture technique.</span></div>
