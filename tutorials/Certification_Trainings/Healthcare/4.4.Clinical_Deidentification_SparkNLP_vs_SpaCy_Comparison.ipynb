# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/spark-nlp-workshop/blob/master/tutorials/Certification_Trainings/Healthcare/4.4.Clinical_Deidentification_SparkNLP_vs_SpaCy_Comparison.ipynb)

# %% [markdown]
# # Comparison of ScrubaDub + Spacy vs Spark NLP deidentification capabilities
# Out-of-the-box, without customization

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In this notebook we will include a comparison of the deidentification capabilities of different libraries on 100 random clinical notes taken from [n2C2 Deidentification](https://portal.dbmi.hms.harvard.edu/projects/n2c2-nlp/) dataset.
#
# We are just taking into account all the capabilities the libraries offer **without needing to do any further training, finetuning or defining in-house rules.**
#
# The tested libraries are:
# - Spark NLP for Healthcare ([clinical_deidentification](https://https://nlp.johnsnowlabs.com/2021/06/08/clinical_deidentification_glove_en.html) pipeline with Glove Embeddings)
# - [Scrubadub with Spacy Transformers](https://github.com/LeapBeyond/scrubadub_spacy)

# %% [markdown]
# # IMPORTANT NOTES TO CONSIDER BEFORE MOVING FORWARD
# 1. All libraries tested here have different tags. A map of entities is provided.
# 2. All libraries have different annotations guidelines, so we have considered as value *fuzzy matches*, with similarity bigger than the 60% of the annotated by JSL chunk (For some APIs, the chunk "Children Care Clinic" is detected including the word "Clinic", for others only proper names ("Children Care"). Both may be valid, they just depend on the [annotation guidelines](https://https://www.johnsnowlabs.com/inter-annotator-agreement-charts-transfer-learning-training-without-license-custom-training-script-with-annotation-lab/)).
# 3. All libraries have **customization** capabilities, that mean you can get much better results if you use some in-house knowledge, rule-based approach or finetunning. However, the aim of this benchmark is to check **OUT OF THE BOX **capabilities without any customization.
# 4. All libraries have more labels that the ones we included here, we just got a sample of 8 representative labels (`ID, DATE, HOSPITAL, LOCATION, AGE, PATIENT, DOCTOR, PHONE`)

# %% [markdown]
# # Labels available in each API
# Not all the API have the same specificity using labels. Some of them use more high-level tags (for example, `NAME` for both *Doctor* and *Patient* names, or `LOCATION` *City*, *ZIP*, even *Hospital*) but some others go low-level, so you can be able to differentiate between Doctors and Patients, what we should appreaciate.
#
# The more **specificity** - the better, because as a rule of thumb, the more specific the less accurate you usually are: detecting `NAME` is evidently *easier* than *detecting* and *asserting* if that name is a `Doctor`'s name or a `Patient`'s name.
#
# Same happens with LOCATIONS and subentities (Street, City, etc) and many other tasks.

# %% [markdown]
# Our reference is the annotated labels by _JSL in-house medical annotators_. **Their total amount is 8**.
#
# You can see the rest of API labels in the following table:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Which is the most specific library?
# The most specific library is **Spark NLP for Healthcare**, since it's the only one able to distinguish between a Patient and a Doctor Name, a Hospital and other Organizations or Addresses, etc.
#
# This does not say anything about the accuracy of those tags. At the end of the day, you can have just one tag **NAME** or **LOCATION** and be able to detect all patients vs doctors, or organizations vs hospitals.
#
# However, just imagine you want to mas or obfuscate the **Hospital** name. If you detect it as *ORGANIZATION** you may mask it as **ORG** and obfuscate it as "McDonalds". It is much better to be aware it's a Hospital and obfuscate is as **Mt. Sinai** instead.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Which has the best out-of-the-box performance?
# Here is the performance for the 8 annotated tags by in-house JSL medical annotators.
#
# NOTE1: all the API have different specificity. That means that, for Spark NLP, a Hospital will be detected as "**HOSPITAL**" but for Azure it may be an "**Organization**". We need to be **permissive** because different guidelines were applied when training those models in the different providers.
#
# ```
# {
#     'DATE': ['DATE', 'DateTime', 'DATE_OF_BIRTH'],
#     'ID': ['ID', 'MEDICALRECORD', 'SocialNumber', 'IDNUM'],
#     'AGE': ['AGE', 'Quantity'],
#     'PHONE': ['PHONE', 'PHONE_OR_FAX', 'PhoneNumber'],
#     'DOCTOR': ['DOCTOR', 'NAME', 'Person'],
#     'PATIENT': ['PATIENT', 'NAME', 'Person'],
#     'HOSPITAL': ['HOSPITAL', 'ADDRESS', 'Organization', 'Address', 'ORGANIZATION'],
#     'LOCATION': ['LOCATION', 'ADDRESS', 'Address', 'STATE', 'COUNTRY', 'STREET', 'CITY']
# }
# ```

# %% [markdown]
# The results show that, for the *100 clinical notes* of *n2c2 corpus*, the most accurate model is the one from **Spark NLP For Healthcare**, followed very closely by **AWS Comprehend Medical**.
#
# Also, **Spark NLP** is the most specific of them all.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now that we have seen the high-level picture, let's see the advantages and disadvantages of all of them

# %% [markdown]
# ## Spark NLP
# - Best accuracy
# - Best specificity: very granular entities
# - Can be augmented with Spark NLP NER models and rule-based components
# - Can run in air-gapped environments
# - License model: pay a license and use as much as you need
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Scrubadub with Spacy Transformers
# Scrubadub allows you augment the existing annotators and add Spacy Transformers. But, if for the other providers we were able to test something out-of-the-box, with little customization, we found that with Scrubadub we needed to look for the proper annotators and the proper transformers in Spacy.
# - Low number of out-of-the-box tags, you need to look for Spacy Transformers to augment the tags or create your own rule-base annotators
# - For those transformers we used, the accuracy was low
# - Free to use (no license required)
# - Can run in air-gapped environments
# - We could not find proper Spacy Models or Scrubadub out-of-the-box annotators to properly work wit AGE, ID and PHONE.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
#         SPARK NLP    SCRUBADUB
# AGE	      1	   -
# DATE	     1       0.52
# DOCTOR	   0.98    0.79
# HOSPITAL 	0.92    0.89
# ID	       0.93    -
# LOCATION 	0.9     0.93
# PATIENT	  0.96    0.65
# PHONE	    1       -
# ```

# %% [markdown]
# # AGGREGATED METRICS

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # LET US BEGIN !

# %% [markdown]
# # Download some clinical notes from N2C2

# %%
# !wget https://github.com/JohnSnowLabs/spark-nlp-workshop/raw/master/tutorials/Certification_Trainings/Healthcare/data/deid_surrogate_test_all_groundtruth_version2.xml
# Out:
# --2022-03-24 13:07:16--  https://github.com/JohnSnowLabs/spark-nlp-workshop/raw/master/tutorials/Certification_Trainings/Healthcare/data/deid_surrogate_test_all_groundtruth_version2.xml
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/deid_surrogate_test_all_groundtruth_version2.xml [following]
# --2022-03-24 13:07:16--  https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/deid_surrogate_test_all_groundtruth_version2.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1074302 (1.0M) [text/plain]
# Saving to: ‘deid_surrogate_test_all_groundtruth_version2.xml’
#
# deid_surrogate_test 100%[===================>]   1.02M  --.-KB/s    in 0.02s
#
# 2022-03-24 13:07:16 (59.3 MB/s) - ‘deid_surrogate_test_all_groundtruth_version2.xml’ saved [1074302/1074302]

# %% [markdown]
# # Parsing the XML

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('deid_surrogate_test_all_groundtruth_version2.xml')
root = tree.getroot()

# %% [markdown]
# # Retrieving texts and PHI fields

# %%
import re
data = []
for r in root.findall('RECORD'):
    for t in r.findall('TEXT'):
        children = []
        for c in t.getchildren():
            children.append((c.text, c.attrib['TYPE']))
        text = "".join([ t.text ] + [ ET.tostring(e).decode('utf-8') for e in t.getchildren()])
        unmasked_text = re.sub(r"<PHI [^>]*>", "", text)
        unmasked_text = re.sub(r"</PHI>", "", unmasked_text)
        data.append({'unmasked_text': unmasked_text, 'text': text, 'phi': children})
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: This method will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: This method will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.

# %%
len(data)
# Out:
# 220

# %%
# Printing data[0], that contains the information of the first clinical note.
print(data[0]['unmasked_text'])
# Out:
# 113416550
# PRGH
# 13523357
# 630190
# 6/7/1999 12:00:00 AM
# Discharge Summary
# Signed
# DIS
# Admission Date :
# 06/07/1999
# Report Status :
# Signed
# Discharge Date :
# 06/13/1999
# HISTORY OF PRESENT ILLNESS :
# Essentially , Mr. Cornea is a 60 year old male who noted the onset of dark urine during early January .
# He underwent CT and ERCP at the Lisonatemi Faylandsburgnic, Community Hospital with a stent placement and resolution of jaundice .
# He underwent an ECHO and endoscopy at Ingree and Ot of Weamanshy Medical Center on April 28 .
# He was found to have a large , bulging , extrinsic mass in the lesser curvature of his stomach .
# Fine needle aspiration showed atypical cells , positively reactive mesothelial cells .
# Abdominal CT on April 14 , showed a 12 x 8 x 8 cm mass in the region of the left liver , and appeared to be from the lesser curvature of the stomach or left liver .
# He denied any nausea , vomiting , anorexia , or weight loss .
# He states that his color in urine or in stool is now normal .
# PAST MEDICAL HISTORY :
# He has hypertension and nephrolithiasis .
# PAST SURGICAL HISTORY :
# Status post left kidney stones x2 , and he has had a parathyroid surgery .
# ALLERGIES :
# He has no known drug allergies .
# MEDICATIONS PRIOR TO ADMISSION :
# Hydrochlorothiazide 25 mg q.d. , Clonidine 0.1 mg p.o. q.d. , baclofen 5 mg p.o. t.i.d.
# HOSPITAL COURSE :
# Basically , patient underwent a subtotal gastrectomy on the 7th of June by Dr. Kotefooksshuff .
# He had an uncomplicated postoperative course and he was transferred .
# Advanced his diet on postop day # 4 to a transitional diet .
# His PCA was discontinued on postop day # 4 , and essentially he was started on his pre-op medications on the postop day # 5 .
# PHYSICAL EXAMINATION :
# CHEST :
# Clear .
# HEART :
# Regular .
# ABDOMINAL INCISION :
# Clean , dry and intact .
# No drainage .
# VITAL SIGNS :
# He is afebrile and otherwise vital signs are stable .
# He is having good p.o. intake on present diet and he is moving his bowels .
# DISPOSITION :
# He is going to a rehabilitation facility until he is able to live independently .
# DISCHARGE MEDICATIONS :
# Same as pre-op , with the addition of Roxicet elixir .
# Dictated By :
# THAMETO DOYLE , M.D. OS43
# Attending :
# PRO R. KOTEFOOKSSHUFF , M.D. RF6 ZY525/1920
# Batch :
# 69874
# Index No. YFKAJTRZX9
# D :
# 06/13/99
# T :
# 06/13/99 KE9
# [ report_end ]

# %%
print(data[0]['phi'])
# Out:
# [('113416550', 'ID'), ('PRGH', 'HOSPITAL'), ('13523357', 'ID'), ('630190', 'ID'), ('6/7', 'DATE'), ('06/07', 'DATE'), ('06/13', 'DATE'), ('Cornea', 'PATIENT'), ('January', 'DATE'), ('Lisonatemi Faylandsburgnic, Community Hospital', 'HOSPITAL'), ('Ingree and Ot of Weamanshy Medical Center', 'HOSPITAL'), ('April 28', 'DATE'), ('April 14', 'DATE'), ('7th of June', 'DATE'), ('Kotefooksshuff', 'DOCTOR'), ('THAMETO DOYLE', 'DOCTOR'), ('OS43', 'ID'), ('PRO R. KOTEFOOKSSHUFF', 'DOCTOR'), ('RF6 ZY525/1920', 'ID'), ('69874', 'ID'), ('YFKAJTRZX9', 'ID'), ('06/13', 'DATE'), ('06/13', 'DATE'), ('KE9', 'ID')]

# %% [markdown]
# # BENCHMARK PREPARATION

# %%
import random
CLINICAL_NOTES = 100
RANDOM_SEED = 0.1

# %% [markdown]
# ## Shuffling

# %%
f_seed = lambda: RANDOM_SEED
random.shuffle(data, f_seed)
data = data[:100]
len(data)
# Out:
# 100

# %%
data[0]['phi']
# Out:
# [('929334185', 'ID'),
#  ('FIH', 'HOSPITAL'),
#  ('8151167', 'ID'),
#  ('53653/y9m1', 'ID'),
#  ('539442', 'ID'),
#  ('5/13', 'DATE'),
#  ('5/13', 'DATE'),
#  ('5/16', 'DATE'),
#  ('July', 'DATE'),
#  ('July', 'DATE'),
#  ('July', 'DATE'),
#  ('November', 'DATE'),
#  ('September 1', 'DATE'),
#  ('November 5', 'DATE'),
#  ('September', 'DATE'),
#  ('05', 'DATE'),
#  ('May 14', 'DATE'),
#  ('May 15', 'DATE'),
#  ('Douet', 'PATIENT'),
#  ('Wires', 'DOCTOR'),
#  ('Wires', 'DOCTOR'),
#  ('526-6508', 'PHONE'),
#  ('May 16', 'DATE'),
#  ('Wires', 'DOCTOR'),
#  ('Caslighlourdes', 'DOCTOR'),
#  ('STIE FYFE', 'DOCTOR'),
#  ('RIEMIND CASLIGHLOURDES', 'DOCTOR'),
#  ('iv / bmot', 'DOCTOR'),
#  ('5/16', 'DATE'),
#  ('05/17', 'DATE')]

# %%
import json
with open('100n2c2.json', 'w') as f:
  f.write(json.dumps(data))

# %%
# 1 text per line
with open('100n2c2_texts.json', 'w') as f:
  f.write(json.dumps([{'text': x['unmasked_text']} for x in data]))

# %% [markdown]
# # Spark NLP for Healthcare
# Let's use Spark NLP for Healthcare's Pretrained Pipeline for `clinical_deidentification`

# %% [markdown]
# ## License

# %%
import json

from google.colab import files

license_keys = files.upload()

with open(list(license_keys.keys())[0]) as f:
    license_keys = json.load(f)

# Defining license key-value pairs as local variables
locals().update(license_keys)

# Adding license key-value pairs to environment variables
import os
os.environ.update(license_keys)

# %%
# Installing pyspark and spark-nlp
# !pip install --upgrade -q pyspark==3.1.2 spark-nlp==$PUBLIC_VERSION

# Installing Spark NLP Healthcare
# !pip install --upgrade -q spark-nlp-jsl==$JSL_VERSION  --extra-index-url https://pypi.johnsnowlabs.com/$SECRET

# %% [markdown]
# ## Starting a Spark NLP for Healthcare session

# %%
import json
import os

from pyspark.ml import Pipeline,PipelineModel
from pyspark.sql import SparkSession

import sparknlp_jsl
import sparknlp

from sparknlp.annotator import *
from sparknlp_jsl.annotator import *
from sparknlp.base import *

import warnings
import pprint 
warnings.filterwarnings('ignore')

params = {"spark.driver.memory":"16G", 
          "spark.kryoserializer.buffer.max":"2000M", 
          "spark.driver.maxResultSize":"2000M"} 

spark = sparknlp_jsl.start(license_keys['SECRET'],params=params,)

print ("Spark NLP Version :", sparknlp.version())
print ("Spark NLP_JSL Version :", sparknlp_jsl.version())

spark
# Out:
# Spark NLP Version : 3.4.2
# Spark NLP_JSL Version : 3.4.2
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://5c9ee26fe550:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark NLP Licensed</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from sparknlp.pretrained import PretrainedPipeline
deid_pipeline = PretrainedPipeline("clinical_deidentification_glove_augmented", "en", "clinical/models")
# Out:
# clinical_deidentification_glove_augmented download started this may take some time.
# Approx size to download 172.9 MB
# [OK!]

# %% [markdown]
# ## `annotate()` on PretrainedPipelines uses LightPipelines, what means is optimized for speed

# %%
# %%time
res = []
for d in data:
  x = deid_pipeline.annotate(d['unmasked_text'])
  res.append(x)
# Out:
# CPU times: user 2.94 s, sys: 961 ms, total: 3.9 s
# Wall time: 3min 7s

# %%
with open('sparknlp_res_xx.json', 'w') as f:
  f.write(json.dumps(res))

# %% [markdown]
# # ScrubaDub with original and Spacy Transformers (Time: 9.24s)

# %%
# !pip install scrubadub scrubadub_spacy spacy_transformers

# %%
import scrubadub, scrubadub_spacy

detector_list = [
                 scrubadub.detectors.DateOfBirthDetector,
                 scrubadub_spacy.detectors.spacy_name_title.SpacyNameDetector,
                 scrubadub_spacy.detectors.spacy.SpacyEntityDetector(named_entities=['DATE', 'FAC', 'GPE', 'LOC', 'ORG', 'PER', 'PERSON'])
]
scrubber = scrubadub.Scrubber(detector_list=detector_list)
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')

# %%
scrubadub_spacy.detectors.spacy.SpacyEntityDetector.filth_cls_map
# Out:
# {'DATE': scrubadub.filth.date_of_birth.DateOfBirthFilth,
#  'FAC': scrubadub.filth.location.LocationFilth,
#  'GPE': scrubadub.filth.location.LocationFilth,
#  'LOC': scrubadub.filth.location.LocationFilth,
#  'ORG': scrubadub.filth.organization.OrganizationFilth,
#  'PER': scrubadub.filth.name.NameFilth,
#  'PERSON': scrubadub.filth.name.NameFilth}

# %%
# %%time
res = []
for d in data:
  x = scrubber.clean(d['unmasked_text'])
  x = x.replace('+ORGANIZATION', '')
  x = x.replace('+NAME', '')
  res.append({'masked_text': x, 'original_text': d['unmasked_text']})
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# CPU times: user 20min 40s, sys: 20.8 s, total: 21min 1s
# Wall time: 20min 55s

# %%
with open('scruba_res.json', 'w') as f:
  f.write(json.dumps(res))

# %% [markdown]
# # BENCHMARK

# %% [markdown]
# # Load annotated data by JSL and texts

# %%
# !wget https://github.com/JohnSnowLabs/spark-nlp-workshop/raw/master/tutorials/Certification_Trainings/Healthcare/data/annotations.json
# Out:
# --2022-03-24 14:58:03--  https://github.com/JohnSnowLabs/spark-nlp-workshop/raw/master/tutorials/Certification_Trainings/Healthcare/data/annotations.json
# Resolving github.com (github.com)... 13.114.40.48
# Connecting to github.com (github.com)|13.114.40.48|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/annotations.json [following]
# --2022-03-24 14:58:03--  https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/annotations.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1322996 (1.3M) [text/plain]
# Saving to: ‘annotations.json’
#
# annotations.json    100%[===================>]   1.26M  --.-KB/s    in 0.06s
#
# 2022-03-24 14:58:04 (19.7 MB/s) - ‘annotations.json’ saved [1322996/1322996]

# %%
import json
with open('annotations.json', 'r') as f:
  annotations = json.load(f)

# %%
annotations = sorted(annotations, key=lambda x: x['id'])

# %%
import json
with open('100n2c2_texts.json', 'r') as f:
  texts = json.load(f)

# %%
annotations[0]['data']['text']
# Out:
# "\n929334185\nFIH\n8151167\n53653/y9m1\n539442\n5/13/1994 12:00:00 AM\nHYPOPHARYNGEAL CANCER .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n5/13/94\nDISCHARGE DATE :\n5/16/94\nPRINCIPAL DIAGNOSIS :\nHypopharyngeal cancer .\nPRINCIPAL PROCEDURE :\nRemoval of left neck lymph node and esophageal endoscopy and dilation .\nHISTORY AND REASON FOR ADMISSION :\nThis is a 69 year-old white male status post surgery in July of 1993 for a laryngopharyngoesophagogastrectomy with gastric reconstruction and modified right neck dissection for pharyngeal cancer .\nSince that surgery , the patient has had dysphagia off and on , solids worse than liquids .\nSometimes solids get stuck for about 10 minutes .\nAbout two months ago the patient had come to the emergency room because he couldn 't swallow for three days .\nHe required esophageal dilation .\nAlso , since July the patient has noted bilateral lymphadenopathy , especially the large submandibular , which has gotten larger .\nIt is difficult to get an exact history as to the onset of the lymphadenopathy , as the patient cannot vocalize and is intoxicated at the time of admission .\nThe lymphadenopathy is uncomfortable but not painful .\nPAST MEDICAL HISTORY :\nSignificant for radiation therapy after his surgery in July , a tracheoesophageal fistula , which was repaired , exploratory laparotomy in November , 1994 , for small bowel obstruction , hypertension , colitis , neonatal jaundice , and on September 1 , 1993 , drainage of a neck abscess .\nHe underwent closure of pharyngeal cutaneous fistula with muscle interposition on November 5 , 1994 , and a left upper lobectomy in September , 1993 , for lung cancer .\nALLERGIES :\nAspirin .\nMEDICATIONS ON ADMISSION :\nNone .\nSOCIAL HISTORY :\nNotable for heavy alcohol use and history of heavy tobacco use , although he quit two years ago .\nREVIEW OF SYSTEMS :\nNo fevers or chills , no nightsweats .\nPositive weight gain since his last admission , positive diarrhea times two weeks-soft brown stools .\nNegative bright red blood per rectum , negative coughing , negative hemoptysis , negative hematemesis , negative chest pain , positive shortness of breath with exertion .\nThe patient can walk or go up a flight of stairs without any shortness of breath , however .\nPHYSICAL EXAMINATION :\nThe patient was a pleasant , mildly intoxicated male with grossly swollen neck .\nHe was afebrile with stable vital signs .\nHead , eyes , ears , nose , throat :\nnormocephalic , atraumatic , pupils equal , regular and reactive to light and accommodation , extra ocular muscles intact .\nTongue with multiple white-yellow lesions .\nNeck grossly swollen at the midline and right angle with jaw , unable to fully swallow .\nThe lungs were clear to auscultation .\nHeart :\nregular rate and rhythm .\nThe abdomen was soft , nontender , nondistended , positive bowel sounds .\nExtremities without clubbing , cyanosis or edema .\nASSESSMENT AND PLAN :\nThis 69 year-old male status post laryngopharyngo-esophagogastrectomy for cancer in 05/93 now represents with progressive dysphagia and gross lymphadenopathy and neck mass .\nThe patient is mildly intoxicated .\nHOSPITAL COURSE :\nThe patient was given overnight hydration .\nHe was taken to the operating room on May 14 , 1994 , for a bronchoscopy and esophagoscopy , dilatation and biopsy .\nHis left neck mass was excised and preliminarily was said to be squamous cell carcinoma .\nThe patient had esophagoscopy , where a stenosis was noted which was dilated to a # 49 French catheter .\nThere were no complications .\nThe patient was taken to the floor in stable condition .\nPostoperatively , there was no crepitus and X-rays showed no mediastinal air .\nNeck biopsy site was clean .\nOn May 15 , the patient 's diet was advanced to a soft diet and then later in the day to a regular diet .\nRadiation Oncology was consulted and it was determined that Mr. Douet still had room for more palliative radiation therapy of his ne ...

# %%
texts[0]['text']
# Out:
# "\n929334185\nFIH\n8151167\n53653/y9m1\n539442\n5/13/1994 12:00:00 AM\nHYPOPHARYNGEAL CANCER .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n5/13/94\nDISCHARGE DATE :\n5/16/94\nPRINCIPAL DIAGNOSIS :\nHypopharyngeal cancer .\nPRINCIPAL PROCEDURE :\nRemoval of left neck lymph node and esophageal endoscopy and dilation .\nHISTORY AND REASON FOR ADMISSION :\nThis is a 69 year-old white male status post surgery in July of 1993 for a laryngopharyngoesophagogastrectomy with gastric reconstruction and modified right neck dissection for pharyngeal cancer .\nSince that surgery , the patient has had dysphagia off and on , solids worse than liquids .\nSometimes solids get stuck for about 10 minutes .\nAbout two months ago the patient had come to the emergency room because he couldn 't swallow for three days .\nHe required esophageal dilation .\nAlso , since July the patient has noted bilateral lymphadenopathy , especially the large submandibular , which has gotten larger .\nIt is difficult to get an exact history as to the onset of the lymphadenopathy , as the patient cannot vocalize and is intoxicated at the time of admission .\nThe lymphadenopathy is uncomfortable but not painful .\nPAST MEDICAL HISTORY :\nSignificant for radiation therapy after his surgery in July , a tracheoesophageal fistula , which was repaired , exploratory laparotomy in November , 1994 , for small bowel obstruction , hypertension , colitis , neonatal jaundice , and on September 1 , 1993 , drainage of a neck abscess .\nHe underwent closure of pharyngeal cutaneous fistula with muscle interposition on November 5 , 1994 , and a left upper lobectomy in September , 1993 , for lung cancer .\nALLERGIES :\nAspirin .\nMEDICATIONS ON ADMISSION :\nNone .\nSOCIAL HISTORY :\nNotable for heavy alcohol use and history of heavy tobacco use , although he quit two years ago .\nREVIEW OF SYSTEMS :\nNo fevers or chills , no nightsweats .\nPositive weight gain since his last admission , positive diarrhea times two weeks-soft brown stools .\nNegative bright red blood per rectum , negative coughing , negative hemoptysis , negative hematemesis , negative chest pain , positive shortness of breath with exertion .\nThe patient can walk or go up a flight of stairs without any shortness of breath , however .\nPHYSICAL EXAMINATION :\nThe patient was a pleasant , mildly intoxicated male with grossly swollen neck .\nHe was afebrile with stable vital signs .\nHead , eyes , ears , nose , throat :\nnormocephalic , atraumatic , pupils equal , regular and reactive to light and accommodation , extra ocular muscles intact .\nTongue with multiple white-yellow lesions .\nNeck grossly swollen at the midline and right angle with jaw , unable to fully swallow .\nThe lungs were clear to auscultation .\nHeart :\nregular rate and rhythm .\nThe abdomen was soft , nontender , nondistended , positive bowel sounds .\nExtremities without clubbing , cyanosis or edema .\nASSESSMENT AND PLAN :\nThis 69 year-old male status post laryngopharyngo-esophagogastrectomy for cancer in 05/93 now represents with progressive dysphagia and gross lymphadenopathy and neck mass .\nThe patient is mildly intoxicated .\nHOSPITAL COURSE :\nThe patient was given overnight hydration .\nHe was taken to the operating room on May 14 , 1994 , for a bronchoscopy and esophagoscopy , dilatation and biopsy .\nHis left neck mass was excised and preliminarily was said to be squamous cell carcinoma .\nThe patient had esophagoscopy , where a stenosis was noted which was dilated to a # 49 French catheter .\nThere were no complications .\nThe patient was taken to the floor in stable condition .\nPostoperatively , there was no crepitus and X-rays showed no mediastinal air .\nNeck biopsy site was clean .\nOn May 15 , the patient 's diet was advanced to a soft diet and then later in the day to a regular diet .\nRadiation Oncology was consulted and it was determined that Mr. Douet still had room for more palliative radiation therapy of his ne ...

# %% [markdown]
# Check that annotated texts correspond to the original texts

# %%
assert texts[0]['text'] == annotations[0]['data']['text']

# %%
assert texts[99]['text']  == annotations[99]['data']['text']

# %% [markdown]
# # Creating Annotation Named Tuple

# %%
import collections

Annotation = collections.namedtuple('Annotation', 'start end label text')

# %% [markdown]
# # Creating ground truth

# %%
ann_tuples = []
for annotation in annotations:
  for completion in annotation['completions']:
    text_ann = []
    for result in completion['result']:
      tup = Annotation(result['value']['start'], result['value']['end'], result['value']['labels'][0], result['value']['text'])
      text_ann.append(tup)
  ann_tuples.append(text_ann)

# %% [markdown]
# # Creating labels synonyms through different APIs
# Keys: Ground truth labels
# Values: Label names in different APIs

# %%
label_maps = {
    'DATE': ['DATE', 'DateTime', 'DATE_OF_BIRTH'],
    'ID': ['ID', 'MEDICALRECORD', 'IDNUM'],
    'AGE': ['AGE', 'Quantity'],
    'PHONE': ['PHONE', 'PHONE_OR_FAX', 'PhoneNumber', 'PHONE_NUMBER', 'CONTACT'],
    'DOCTOR': ['DOCTOR', 'NAME', 'Person', 'PERSON_NAME', 'PATIENT', 'USERNAME'],
    'PATIENT': ['PATIENT', 'NAME', 'Person', 'PERSON_NAME', 'DOCTOR', 'USERNAME'],
    'HOSPITAL': ['HOSPITAL', 'ADDRESS', 'Organization', 'Address', 'ORGANIZATION', 'LOCATION'],
    'LOCATION': ['LOCATION', 'ADDRESS', 'Address', 'Location', 'Organization', 'STATE', 'COUNTRY', 'STREET', 'CITY', 'HOSPITAL']}

# %%
import math
def is_same_label(api_label, label):
  api_label_mod = api_label.replace("{","")
  api_label_mod = api_label_mod.replace("}","")
  api_label_mod = api_label_mod.replace("[","")
  api_label_mod = api_label_mod.replace("]","")
  api_label_mod = api_label_mod.replace("<","")
  api_label_mod = api_label_mod.replace(">","")
  return api_label_mod in label_maps[label]

def is_sim_pos(pos1, pos2):
  # Different tokenization rules may bring to displacement. I consider a 10% of span
  diff = int(pos1) * 0.1
  return abs(pos1 - pos2) <= diff

def is_sim_text(text1, text2):
  return (text1.strip() in text2.strip()) or (text2.strip() in text1.strip()) or (Levenshtein.ratio(text1.strip(), text2.strip())>0.6)

# %% [markdown]
# # Creating Metrics
# Different libraries have different annotation guidelines, so we won't go for an exact match, but for a fuzzy match

# %%
# !pip install levenshtein
# Out:
# Collecting levenshtein
#   Downloading Levenshtein-0.18.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (258 kB)
#      |████████████████████████████████| 258 kB 29.6 MB/s
# Collecting rapidfuzz<3.0.0,>=2.0.1
#   Downloading rapidfuzz-2.0.7-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 45.3 MB/s
# Collecting jarowinkler<1.1.0,>=1.0.2
#   Downloading jarowinkler-1.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (103 kB)
#      |████████████████████████████████| 103 kB 44.7 MB/s
# Installing collected packages: jarowinkler, rapidfuzz, levenshtein
# Successfully installed jarowinkler-1.0.2 levenshtein-0.18.1 rapidfuzz-2.0.7

# %%
import Levenshtein

# TP: Exact match and label (or equivalent in the map)
# TP (fuzzy match): Partial match and exact label (or equivalent in the map)
# FP: A label annotated by the Medical Annotator was labelled as something else by the model
# FN: A label annotated by the Medical Annotator was not labelled by the model

# NOTE: We are not considering as FP a tag detected by the model and not tagged by the annotator as this is usually done,
# since the models have all many different labels not considered in the Annotator's guidelines

# Calculates TP, FP and FN for 1 document
def get_doc_metrics(ann_tuples, res_tuples, print_fn=False, print_fp=False, verbose=None):
  metrics_dict = dict()
  for key in label_maps.keys():
    metrics_dict[key] = {'tp': 0, 'fp': 0, 'fn': 0}
  
  if res_tuples is None:
    return metrics_dict

  for ann_tuple in ann_tuples:
    checking = False
    if verbose is not None and verbose == ann_tuple.label:
      print("- Checking " + ann_tuple.label + " - " + ann_tuple.text)
      checking = True
    found = False
    if ann_tuple.label not in label_maps:
      continue
    for res_tuple in res_tuples:
      if checking:
        print("-- towards... " + res_tuple.label + " - " + res_tuple.text + "(" + str(is_sim_pos(ann_tuple.start, res_tuple.start)) + " " + str(ann_tuple.start) + "/" + str(res_tuple.start) + "," + str(is_sim_pos(ann_tuple.end, res_tuple.end)) + " " + str(ann_tuple.end) + "/" + str(res_tuple.end) + "," + str(is_same_label(res_tuple.label, ann_tuple.label)) + "," + str(is_sim_text(ann_tuple.text, res_tuple.text)) + ")")
      # Exact match
      if ann_tuple.start == res_tuple.start and ann_tuple.end == res_tuple.end and is_same_label(res_tuple.label, ann_tuple.label) and ann_tuple.text.strip() == res_tuple.text.strip():
        metrics_dict[ann_tuple.label]['tp']+=1
        if checking:
          print ("--- Exact match!")
        found = True
        break
      # Fuzzy match
      elif (is_sim_pos(ann_tuple.start, res_tuple.start) or is_sim_pos(ann_tuple.end, res_tuple.end)) and is_same_label(res_tuple.label, ann_tuple.label) and is_sim_text(ann_tuple.text, res_tuple.text):
        metrics_dict[ann_tuple.label]['tp']+=1
        if checking:
          print ("--- Fuzzy match!")
        found = True
        break
      # False Positives
      elif (is_sim_pos(ann_tuple.start, res_tuple.start) or is_sim_pos(ann_tuple.end, res_tuple.end)) and not is_same_label(res_tuple.label, ann_tuple.label) and is_sim_text(ann_tuple.text, res_tuple.text):
        metrics_dict[ann_tuple.label]['fp']+=1
        found = True
        if checking:
          print ("--- FP!")
        if print_fp:
          print(f"False Positive. Annotated: {ann_tuple.label} --> {ann_tuple.text}\t\tExtracted: {res_tuple.label} --> {res_tuple.text}")
        break
    # Missing annotation
    if not found:
      metrics_dict[ann_tuple.label]['fn']+=1
      if checking:
        print ("--- FN!")
      if print_fn:                 
          print(f"False Negative in {ann_tuple.id}. Annotated: {ann_tuple.label} --> {ann_tuple.text} not found")
  return metrics_dict

# %%
# Calculates TP, FP and FN for all the documents
def get_all_doc_metrics(all_doc_ann, all_doc_res, print_fn=False, print_fp=False, verbose=None):
  if len(all_doc_ann) != len(all_doc_res):
    print("You should have the same number of annotations in ground truth and in API to evaluate")
    return None
  metrics_dict = dict()
  for key in label_maps.keys():
    metrics_dict[key] = {'tp': 0, 'fp': 0, 'fn': 0}

  for i in range(0, len(all_doc_ann)):
    res_dict = get_doc_metrics(all_doc_ann[i], all_doc_res[i], print_fn, print_fp, verbose)
    for k in metrics_dict.keys():
      for k2 in metrics_dict[key].keys():
        metrics_dict[k][k2] += res_dict[k][k2]
  return metrics_dict

# %%
# PREC, REC and F1 calculations
def get_formula_metrics(metrics_dict):
  formula_metrics_dict = dict()
  for key in metrics_dict.keys():
    prec = 0
    if metrics_dict[key]['tp']+metrics_dict[key]['fp'] != 0:
      prec = metrics_dict[key]['tp'] / (metrics_dict[key]['tp']+metrics_dict[key]['fp'])
    rec = 0
    if metrics_dict[key]['tp']+metrics_dict[key]['fn'] != 0:
      rec = metrics_dict[key]['tp'] / (metrics_dict[key]['tp']+metrics_dict[key]['fn'])
    formula_metrics_dict[key] = {
        'prec': prec,
        'rec': rec,
        'f1': (2*rec*prec) / (rec + prec) if (rec + prec) != 0 else 0}
  return formula_metrics_dict

# %% [markdown]
# # SparkNLP

# %%
import json
with open('sparknlp_res_xx.json', 'r') as f:
  sparknlp_res = json.load(f)

# %%
for i in range(0, len(sparknlp_res)):
  sparknlp_res[i]['original_text'] = texts[i]
  text = ""

# %%
import re
sparknlp_tuples = []
for n, r in enumerate(sparknlp_res):
  tuples = []
  found_chunks = []
  masks = re.findall(r"<[A-Z_]+>", "\n".join(r['masked']))
  chunks = r['ner_chunk']
  if len(masks) != len(chunks):
    sparknlp_tuples.append(None)
    continue
  for i in range(0, len(chunks)):
    mask = masks[i]
    chunk = chunks[i]
    possible_spans = [(match.start(), match.end()) for match in re.finditer(f"[\n ]{re.escape(chunk)}[\n ]", r['original_text'])]
    position = found_chunks.count(chunk)
    if position >= len(possible_spans):
      continue
    start = possible_spans[position][0]
    end = possible_spans[position][1]
    found_chunks.append(chunk)
    tuples.append(Annotation(start, end, mask, chunk))
  sparknlp_tuples.append(tuples)

# %%
sparknlp_tuples[0]
# Out:
# [Annotation(start=0, end=11, label='<MEDICALRECORD>', text='929334185'),
#  Annotation(start=10, end=15, label='<HOSPITAL>', text='FIH'),
#  Annotation(start=14, end=34, label='<MEDICALRECORD>', text='8151167\n53653/y9m1'),
#  Annotation(start=33, end=41, label='<MEDICALRECORD>', text='539442'),
#  Annotation(start=40, end=51, label='<DATE>', text='5/13/1994'),
#  Annotation(start=141, end=150, label='<DATE>', text='5/13/94'),
#  Annotation(start=166, end=175, label='<DATE>', text='5/16/94'),
#  Annotation(start=359, end=363, label='<AGE>', text='69'),
#  Annotation(start=405, end=419, label='<DATE>', text='July of 1993'),
#  Annotation(start=405, end=411, label='<DATE>', text='July'),
#  Annotation(start=845, end=851, label='<DATE>', text='July'),
#  Annotation(start=1338, end=1355, label='<DATE>', text='November , 1994'),
#  Annotation(start=1438, end=1458, label='<DATE>', text='September 1 , 1993'),
#  Annotation(start=1570, end=1589, label='<DATE>', text='November 5 , 1994'),
#  Annotation(start=1620, end=1638, label='<DATE>', text='September , 1993'),
#  Annotation(start=2918, end=2922, label='<AGE>', text='69'),
#  Annotation(start=2997, end=3004, label='<DATE>', text='05/93'),
#  Annotation(start=3223, end=3238, label='<DATE>', text='May 14 , 1994'),
#  Annotation(start=3476, end=3480, label='<AGE>', text='49'),
#  Annotation(start=3695, end=3703, label='<DATE>', text='May 15'),
#  Annotation(start=3862, end=3869, label='<PATIENT>', text='Douet'),
#  Annotation(start=3975, end=3982, label='<NAME>', text='Wires'),
#  Annotation(start=3984, end=3993, label='<DATE>', text='Tuesday'),
#  Annotation(start=4018, end=4025, label='<NAME>', text='Wires'),
#  Annotation(start=4047, end=4057, label='<PHONE>', text='526-6508'),
#  Annotation(start=4061, end=4069, label='<DATE>', text='May 16'),
#  Annotation(start=4264, end=4271, label='<NAME>', text='Wires'),
#  Annotation(start=4278, end=4294, label='<DOCTOR>', text='Caslighlourdes'),
#  Annotation(start=4295, end=4306, label='<DOCTOR>', text='STIE FYFE'),
#  Annotation(start=4328, end=4352, label='<DOCTOR>', text='RIEMIND CASLIGHLOURDES'),
#  Annotation(start=4378, end=4387, label='<DATE>', text='5/16/94'),
#  Annotation(start=4391, end=4401, label='<DATE>', text='05/17/94')]

# %%
sparknlp_dict = get_all_doc_metrics(ann_tuples, sparknlp_tuples)
sparknlp_dict
# Out:
# {'AGE': {'fn': 0, 'fp': 0, 'tp': 95},
#  'DATE': {'fn': 5, 'fp': 1, 'tp': 944},
#  'DOCTOR': {'fn': 12, 'fp': 5, 'tp': 381},
#  'HOSPITAL': {'fn': 15, 'fp': 13, 'tp': 154},
#  'ID': {'fn': 39, 'fp': 25, 'tp': 396},
#  'LOCATION': {'fn': 5, 'fp': 4, 'tp': 38},
#  'PATIENT': {'fn': 8, 'fp': 0, 'tp': 107},
#  'PHONE': {'fn': 0, 'fp': 0, 'tp': 15}}

# %%
get_formula_metrics(sparknlp_dict)
# Out:
# {'AGE': {'f1': 1.0, 'prec': 1.0, 'rec': 1.0},
#  'DATE': {'f1': 0.996832101372756,
#   'prec': 0.9989417989417989,
#   'rec': 0.9947312961011591},
#  'DOCTOR': {'f1': 0.9781771501925545,
#   'prec': 0.9870466321243523,
#   'rec': 0.9694656488549618},
#  'HOSPITAL': {'f1': 0.9166666666666667,
#   'prec': 0.9221556886227545,
#   'rec': 0.9112426035502958},
#  'ID': {'f1': 0.9252336448598132,
#   'prec': 0.9406175771971497,
#   'rec': 0.9103448275862069},
#  'LOCATION': {'f1': 0.8941176470588236,
#   'prec': 0.9047619047619048,
#   'rec': 0.8837209302325582},
#  'PATIENT': {'f1': 0.9639639639639639, 'prec': 1.0, 'rec': 0.9304347826086956},
#  'PHONE': {'f1': 1.0, 'prec': 1.0, 'rec': 1.0}}

# %% [markdown]
# # Scrubadub + Spacy Transformers

# %%
import json
with open('scruba_res.json', 'r') as f:
  scruba_res = json.load(f)

# %%
scruba_res[0]
# Out:
# {'masked_text': "\n929334185\nFIH\n8151167\n53653/y9m1\n539442\n5/13/1994 12:00:00 AM\nHYPOPHARYNGEAL CANCER .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n5/13/94\nDISCHARGE DATE :\n{{DATE_OF_BIRTH}}\nPRINCIPAL DIAGNOSIS :\nHypopharyngeal cancer .\nPRINCIPAL PROCEDURE :\nRemoval of left neck lymph node and esophageal endoscopy and dilation .\nHISTORY AND REASON FOR ADMISSION :\nThis is a 69 year-old white male status post surgery in {{DATE_OF_BIRTH}} for a laryngopharyngoesophagogastrectomy with gastric reconstruction and modified right neck dissection for pharyngeal cancer .\nSince that surgery , the patient has had dysphagia off and on , solids worse than liquids .\nSometimes solids get stuck for about 10 minutes .\nAbout two months ago the patient had come to the emergency room because he couldn 't swallow for three days .\nHe required esophageal dilation .\nAlso , since July the patient has noted bilateral lymphadenopathy , especially the large submandibular , which has gotten larger .\nIt is difficult to get an exact history as to the onset of the lymphadenopathy , as the patient cannot vocalize and is intoxicated at the time of admission .\nThe lymphadenopathy is uncomfortable but not painful .\nPAST MEDICAL HISTORY :\nSignificant for radiation therapy after his surgery in July , a tracheoesophageal fistula , which was repaired , exploratory laparotomy in {{DATE_OF_BIRTH}} , for small bowel obstruction , hypertension , colitis , neonatal jaundice , and on {{DATE_OF_BIRTH}} , drainage of a neck abscess .\nHe underwent closure of pharyngeal cutaneous fistula with muscle interposition on {{DATE_OF_BIRTH}} , and a left upper lobectomy in {{DATE_OF_BIRTH}} , for lung cancer .\nALLERGIES :\nAspirin .\nMEDICATIONS ON ADMISSION :\nNone .\nSOCIAL HISTORY :\nNotable for heavy alcohol use and history of heavy tobacco use , although he quit two years ago .\nREVIEW OF SYSTEMS :\nNo fevers or chills , no nightsweats .\nPositive weight gain since his last admission , positive diarrhea times two weeks-soft brown stools .\nNegative bright red blood per rectum , negative coughing , negative hemoptysis , negative hematemesis , negative chest pain , positive shortness of breath with exertion .\nThe patient can walk or go up a flight of stairs without any shortness of breath , however .\nPHYSICAL EXAMINATION :\nThe patient was a pleasant , mildly intoxicated male with grossly swollen neck .\nHe was afebrile with stable vital signs .\nHead , eyes , ears , nose , throat :\nnormocephalic , atraumatic , pupils equal , regular and reactive to light and accommodation , extra ocular muscles intact .\nTongue with multiple white-yellow lesions .\nNeck grossly swollen at the midline and right angle with jaw , unable to fully swallow .\nThe lungs were clear to auscultation .\nHeart :\nregular rate and rhythm .\nThe abdomen was soft , nontender , nondistended , positive bowel sounds .\nExtremities without clubbing , cyanosis or edema .\nASSESSMENT AND PLAN :\nThis 69 year-old male status post laryngopharyngo-esophagogastrectomy for cancer in {{DATE_OF_BIRTH}} now represents with progressive dysphagia and gross lymphadenopathy and neck mass .\nThe patient is mildly intoxicated .\nHOSPITAL COURSE :\nThe patient was given overnight hydration .\nHe was taken to the operating room on {{DATE_OF_BIRTH}} , for a bronchoscopy and esophagoscopy , dilatation and biopsy .\nHis left neck mass was excised and preliminarily was said to be squamous cell carcinoma .\nThe patient had esophagoscopy , where a stenosis was noted which was dilated to a # 49 French catheter .\nThere were no complications .\nThe patient was taken to the floor in stable condition .\nPostoperatively , there was no crepitus and X-rays showed no mediastinal air .\nNeck biopsy site was clean .\nOn May 15 , the patient 's diet was advanced to a soft diet and then later in the day to a regular diet .\nRadiation Oncology was consulted and it was determined that {{NAME}} still had room ...
#  'original_text': "\n929334185\nFIH\n8151167\n53653/y9m1\n539442\n5/13/1994 12:00:00 AM\nHYPOPHARYNGEAL CANCER .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n5/13/94\nDISCHARGE DATE :\n5/16/94\nPRINCIPAL DIAGNOSIS :\nHypopharyngeal cancer .\nPRINCIPAL PROCEDURE :\nRemoval of left neck lymph node and esophageal endoscopy and dilation .\nHISTORY AND REASON FOR ADMISSION :\nThis is a 69 year-old white male status post surgery in July of 1993 for a laryngopharyngoesophagogastrectomy with gastric reconstruction and modified right neck dissection for pharyngeal cancer .\nSince that surgery , the patient has had dysphagia off and on , solids worse than liquids .\nSometimes solids get stuck for about 10 minutes .\nAbout two months ago the patient had come to the emergency room because he couldn 't swallow for three days .\nHe required esophageal dilation .\nAlso , since July the patient has noted bilateral lymphadenopathy , especially the large submandibular , which has gotten larger .\nIt is difficult to get an exact history as to the onset of the lymphadenopathy , as the patient cannot vocalize and is intoxicated at the time of admission .\nThe lymphadenopathy is uncomfortable but not painful .\nPAST MEDICAL HISTORY :\nSignificant for radiation therapy after his surgery in July , a tracheoesophageal fistula , which was repaired , exploratory laparotomy in November , 1994 , for small bowel obstruction , hypertension , colitis , neonatal jaundice , and on September 1 , 1993 , drainage of a neck abscess .\nHe underwent closure of pharyngeal cutaneous fistula with muscle interposition on November 5 , 1994 , and a left upper lobectomy in September , 1993 , for lung cancer .\nALLERGIES :\nAspirin .\nMEDICATIONS ON ADMISSION :\nNone .\nSOCIAL HISTORY :\nNotable for heavy alcohol use and history of heavy tobacco use , although he quit two years ago .\nREVIEW OF SYSTEMS :\nNo fevers or chills , no nightsweats .\nPositive weight gain since his last admission , positive diarrhea times two weeks-soft brown stools .\nNegative bright red blood per rectum , negative coughing , negative hemoptysis , negative hematemesis , negative chest pain , positive shortness of breath with exertion .\nThe patient can walk or go up a flight of stairs without any shortness of breath , however .\nPHYSICAL EXAMINATION :\nThe patient was a pleasant , mildly intoxicated male with grossly swollen neck .\nHe was afebrile with stable vital signs .\nHead , eyes , ears , nose , throat :\nnormocephalic , atraumatic , pupils equal , regular and reactive to light and accommodation , extra ocular muscles intact .\nTongue with multiple white-yellow lesions .\nNeck grossly swollen at the midline and right angle with jaw , unable to fully swallow .\nThe lungs were clear to auscultation .\nHeart :\nregular rate and rhythm .\nThe abdomen was soft , nontender , nondistended , positive bowel sounds .\nExtremities without clubbing , cyanosis or edema .\nASSESSMENT AND PLAN :\nThis 69 year-old male status post laryngopharyngo-esophagogastrectomy for cancer in 05/93 now represents with progressive dysphagia and gross lymphadenopathy and neck mass .\nThe patient is mildly intoxicated .\nHOSPITAL COURSE :\nThe patient was given overnight hydration .\nHe was taken to the operating room on May 14 , 1994 , for a bronchoscopy and esophagoscopy , dilatation and biopsy .\nHis left neck mass was excised and preliminarily was said to be squamous cell carcinoma .\nThe patient had esophagoscopy , where a stenosis was noted which was dilated to a # 49 French catheter .\nThere were no complications .\nThe patient was taken to the floor in stable condition .\nPostoperatively , there was no crepitus and X-rays showed no mediastinal air .\nNeck biopsy site was clean .\nOn May 15 , the patient 's diet was advanced to a soft diet and then later in the day to a regular diet .\nRadiation Oncology was consulted and it was determined that Mr. Douet still had room for more palliative radiation ...

# %%
import re
def get_chunks_scruba(masked, original):    
  masked_rep = re.sub(r"{{[A-Z_]+}}", "", masked)
  masked_rep = re.sub(r"\n", " ", masked_rep)  
  masked_split = [x for x in masked_rep.split(' ') if x != '']

  orig_rep = re.sub(r"\n", " ", original)
  orig_split = [x for x in orig_rep.split(' ') if x != '']
  
  chunks = []
  i=0
  j=0
  while True:
    if i == len(masked_split):
      break
    # print(f"Comparing {masked_split[i]} to {orig_split[j]}")
    if masked_split[i] == orig_split[j]:
      i+=1
      j+=1
    else:
      end = False
      chunk = []
      while not end:
        chunk.append(orig_split[j])
        # print(f"- Adding to chunk: {chunk}")      
        j+=1
        if j == len(orig_split):
          return chunks
        # print(f"- Checking next word: {masked_split[i]} to {orig_split[j]}")      
        if masked_split[i] == orig_split[j]:
          # print(f"-- Finishing chunk: {chunk}")
          end = True
          chunks.append(" ".join(chunk))
  return chunks

# %%
get_chunks_scruba(scruba_res[0]['masked_text'], scruba_res[0]['original_text'])
# Out:
# ['5/16/94',
#  'July of 1993',
#  'November',
#  '1994 ,',
#  'September 1',
#  '1993 ,',
#  'November 5',
#  '1994 ,',
#  'September',
#  '1993 ,',
#  '05/93',
#  'May 14',
#  '1994 ,',
#  'Mr. Douet',
#  'Dr. Wires',
#  'Dr. Wires',
#  'Dr. Wires',
#  'Dr. Caslighlourdes',
#  'STIE FYFE',
#  'RIEMIND CASLIGHLOURDES',
#  '5/16/94',
#  '05/17/94']

# %%
re.findall(r"{{[A-Z_]+}}", scruba_res[0]['masked_text'])
# Out:
# ['{{DATE_OF_BIRTH}}',
#  '{{DATE_OF_BIRTH}}',
#  '{{DATE_OF_BIRTH}}',
#  '{{DATE_OF_BIRTH}}',
#  '{{DATE_OF_BIRTH}}',
#  '{{DATE_OF_BIRTH}}',
#  '{{DATE_OF_BIRTH}}',
#  '{{DATE_OF_BIRTH}}',
#  '{{NAME}}',
#  '{{NAME}}',
#  '{{NAME}}',
#  '{{NAME}}',
#  '{{NAME}}',
#  '{{NAME}}',
#  '{{NAME}}',
#  '{{DATE_OF_BIRTH}}',
#  '{{DATE_OF_BIRTH}}']

# %%
import re
scruba_tuples = []
for res in scruba_res:
  tuples = []
  found_chunks = []
  masks = re.findall(r"{{[A-Z_]+}}", res['masked_text'])
  chunks = get_chunks_scruba(res['masked_text'], res['original_text'])
  if len(masks) != len(chunks):
    scruba_tuples.append(None)
    continue
  for i in range(0, len(chunks)):
    mask = masks[i]
    chunk = chunks[i]
    possible_spans = [(match.start(), match.end()) for match in re.finditer(re.escape(chunk), res['original_text'])]
    position = found_chunks.count(chunk)
    if position >= len(possible_spans):
      continue
    start = possible_spans[position][0]
    end = possible_spans[position][1]
    found_chunks.append(chunk)
    tuples.append(Annotation(start, end, mask, chunk))
  scruba_tuples.append(tuples)

# %%
scruba_tuples
# Out:
# [None,
#  None,
#  [Annotation(start=163, end=170, label='{{DATE_OF_BIRTH}}', text='11/6/92'),
#   Annotation(start=320, end=327, label='{{DATE_OF_BIRTH}}', text='71 year'),
#   Annotation(start=1883, end=1891, label='{{DATE_OF_BIRTH}}', text='10/28/92'),
#   Annotation(start=3488, end=3495, label='{{DATE_OF_BIRTH}}', text='11/3/92'),
#   Annotation(start=3529, end=3553, label='{{ORGANIZATION}}', text='the GYN Oncology Service'),
#   Annotation(start=3669, end=3676, label='{{DATE_OF_BIRTH}}', text='11/4/92'),
#   Annotation(start=3881, end=3888, label='{{DATE_OF_BIRTH}}', text='11/5/92'),
#   Annotation(start=4191, end=4199, label='{{NAME}}', text='Dr. Wood'),
#   Annotation(start=4245, end=4259, label='{{NAME}}', text='Dr. Chabechird'),
#   Annotation(start=4425, end=4449, label='{{NAME}}', text='BRENDNIUNGAND ASILBEKOTE'),
#   Annotation(start=4511, end=4518, label='{{DATE_OF_BIRTH}}', text='11/6/92'),
#   Annotation(start=4538, end=4562, label='{{NAME}}', text='Dr. Slaineaee Chabechird')],
#  None,
#  None,
#  [Annotation(start=209, end=228, label='{{DATE_OF_BIRTH}}', text='12/19/2000 02:48 PM'),
#   Annotation(start=245, end=253, label='{{NAME}}', text='Vengloan'),
#   Annotation(start=739, end=761, label='{{NAME}}', text='Dr. Linketerf tomorrow'),
#   Annotation(start=873, end=881, label='{{NAME}}', text='Vengloan')],
#  None,
#  None,
#  [Annotation(start=99, end=109, label='{{DATE_OF_BIRTH}}', text='06/07/1999'),
#   Annotation(start=150, end=160, label='{{DATE_OF_BIRTH}}', text='06/13/1999'),
#   Annotation(start=204, end=214, label='{{NAME}}', text='Mr. Cornea'),
#   Annotation(start=322, end=372, label='{{ORGANIZATION}}', text='the Lisonatemi Faylandsburgnic, Community Hospital'),
#   Annotation(start=463, end=504, label='{{ORGANIZATION}}', text='Ingree and Ot of Weamanshy Medical Center'),
#   Annotation(start=1415, end=1433, label='{{NAME}}', text='Dr. Kotefooksshuff')],
#  None,
#  None,
#  [Annotation(start=145, end=155, label='{{DATE_OF_BIRTH}}', text='06/15/2004'),
#   Annotation(start=375, end=379, label='{{DATE_OF_BIRTH}}', text='1997'),
#   Annotation(start=507, end=556, label='{{ORGANIZATION}}', text="the New Wishwarm Medical Center 's Emergency Room"),
#   Annotation(start=961, end=969, label='{{DATE_OF_BIRTH}}', text='06/14/04')],
#  None,
#  [Annotation(start=183, end=198, label='{{NAME}}', text='JESCWIERST , MA'),
#   Annotation(start=1134, end=1142, label='{{NAME}}', text='Dr Floor'),
#   Annotation(start=2480, end=2488, label='{{NAME}}', text='Dr Floor')],
#  None,
#  [Annotation(start=742, end=750, label='{{NAME}}', text='override'),
#   Annotation(start=771, end=779, label='{{NAME}}', text='override'),
#   Annotation(start=3210, end=3229, label='{{NAME}}', text='Dr. Koteskismanhout')],
#  None,
#  [Annotation(start=348, end=368, label='{{ORGANIZATION}}', text='Ro Woodma Healthcare')],
#  [Annotation(start=193, end=200, label='{{DATE_OF_BIRTH}}', text='75 year'),
#   Annotation(start=233, end=253, label='{{ORGANIZATION}}', text='Iming Medical Center'),
#   Annotation(start=478, end=485, label='{{DATE_OF_BIRTH}}', text='75 year'),
#   Annotation(start=528, end=541, label='{{DATE_OF_BIRTH}}', text='November 1993'),
#   Annotation(start=1206, end=1232, label='{{ORGANIZATION}}', text='Xas Tupalmsmodral Hospital'),
#   Annotation(start=1236, end=1244, label='{{DATE_OF_BIRTH}}', text='11-11-93'),
#   Annotation(start=3184, end=3206, label='{{ORGANIZATION}}', text='Cardiac Rehabilitation'),
#   Annotation(start=3284, end=3288, label='{{ORGANIZATION}}', text='Cean'),
#   Annotation(start=3291, end=3312, label='{{NAME}}', text='Dr. Dieseld Pollejesc'),
#   Annotation(start=3667, end=3687, label='{{NAME}}', text='Dr. Telshey Study a9')],
#  [Annotation(start=609, end=611, label='{{NAME}}', text='MD'),
#   Annotation(start=959, end=973, label='{{NAME}}', text='Dr. Oghagneuph'),
#   Annotation(start=1526, end=1540, label='{{NAME}}', text='Ms Wierstprehe'),
#   Annotation(start=1546, end=1553, label='{{DATE_OF_BIRTH}}', text='62 year')],
#  [Annotation(start=1155, end=1173, label='{{NAME}}', text='Dr. Sharp , stroke'),
#   Annotation(start=1155, end=1164, label='{{NAME}}', text='Dr. Sharp'),
#   Annotation(start=1159, end=1164, label='{{NAME}}', text='Sharp'),
#   Annotation(start=1831, end=1835, label='{{DATE_OF_BIRTH}}', text='1993')],
#  None,
#  None,
#  [Annotation(start=460, end=467, label='{{DATE_OF_BIRTH}}', text='71 year'),
#   Annotation(start=880, end=897, label='{{DATE_OF_BIRTH}}', text='February 3 , 1992'),
#   Annotation(start=1227, end=1242, label='{{DATE_OF_BIRTH}}', text='January of 1992'),
#   Annotation(start=2978, end=2987, label='{{NAME}}', text='Dr. Large'),
#   Annotation(start=3111, end=3121, label='{{NAME}}', text='KITRI CURB'),
#   Annotation(start=3145, end=3163, label='{{NAME}}', text='SLAINEAEE S. LARGE'),
#   Annotation(start=3230, end=3239, label='{{NAME}}', text='Dr. Large')],
#  [Annotation(start=196, end=204, label='{{DATE_OF_BIRTH}}', text='09/24/92'),
#   Annotation(start=325, end=349, label='{{LOCATION}}', text='the GYN Oncology SErvice'),
#   Annotation(start=353, end=357, label='{{DATE_OF_BIRTH}}', text='1980'),
#   Annotation(start=361, end=379, label='{{NAME}}', text='Dr. Slaineaee Ganz'),
#   Annotation(start=827, end=836, label='{{DATE_OF_BIRTH}}', text='June 1992'),
#   Annotation(start=1320, end=1329, label='{{DATE_OF_BIRTH}}', text='June 1992'),
#   Annotation(start=3027, end=3049, label='{{ORGANIZATION}}', text='Anticoagulation Clinic'),
#   Annotation(start=3624, end=3642, label='{{NAME}}', text='Dr. Slaineaee Ganz'),
#   Annotation(start=3687, end=3708, label='{{NAME}}', text='TOMEDANKELL FLOWAYLES'),
#   Annotation(start=3732, end=3746, label='{{NAME}}', text='SLAINEAEE GANZ'),
#   Annotation(start=3774, end=3782, label='{{DATE_OF_BIRTH}}', text='09/24/92')],
#  [Annotation(start=395, end=402, label='{{DATE_OF_BIRTH}}', text='71 year'),
#   Annotation(start=657, end=684, label='{{ORGANIZATION}}', text='the General Surgery Service'),
#   Annotation(start=878, end=911, label='{{ORGANIZATION}}', text='the Gynecology / Oncology Service'),
#   Annotation(start=1040, end=1058, label='{{DATE_OF_BIRTH}}', text='November 28 , 1992'),
#   Annotation(start=1385, end=1402, label='{{DATE_OF_BIRTH}}', text='December 8 , 1992'),
#   Annotation(start=1971, end=1984, label='{{DATE_OF_BIRTH}}', text='November 1992'),
#   Annotation(start=4433, end=4466, label='{{ORGANIZATION}}', text='the Gynecology / Oncology Service'),
#   Annotation(start=5402, end=5418, label='{{DATE_OF_BIRTH}}', text='January 8 , 1992'),
#   Annotation(start=5872, end=5886, label='{{NAME}}', text='Dr. Chabechird'),
#   Annotation(start=5899, end=5913, label='{{NAME}}', text='RAHZACK INNELL'),
#   Annotation(start=6013, end=6044, label='{{NAME}}', text='Dr. Slaineaee Chabechird Palmda')],
#  None,
#  [Annotation(start=136, end=143, label='{{DATE_OF_BIRTH}}', text='5/14/92'),
#   Annotation(start=161, end=168, label='{{DATE_OF_BIRTH}}', text='5/19/92'),
#   Annotation(start=251, end=258, label='{{DATE_OF_BIRTH}}', text='71 year'),
#   Annotation(start=371, end=387, label='{{NAME}}', text='Dr. Korcblinknud'),
#   Annotation(start=681, end=691, label='{{NAME}}', text='Dr. Median'),
#   Annotation(start=923, end=941, label='{{LOCATION}}', text='Sephsandpot Center'),
#   Annotation(start=1071, end=1105, label='{{ORGANIZATION}}', text='the Fairm of Ijordcompmac Hospital'),
#   Annotation(start=1236, end=1240, label='{{DATE_OF_BIRTH}}', text='1988'),
#   Annotation(start=1616, end=1623, label='{{DATE_OF_BIRTH}}', text='71 year'),
#   Annotation(start=2141, end=2148, label='{{DATE_OF_BIRTH}}', text='5/14/92'),
#   Annotation(start=3156, end=3158, label='{{NAME}}', text='MA'),
#   Annotation(start=3203, end=3212, label='{{NAME}}', text='COR TLAND'),
#   Annotation(start=3240, end=3248, label='{{DATE_OF_BIRTH}}', text='07/02/92'),
#   Annotation(start=3254, end=3262, label='{{DATE_OF_BIRTH}}', text='07/07/92')],
#  [Annotation(start=135, end=141, label='{{DATE_OF_BIRTH}}', text='3-1-94'),
#   Annotation(start=159, end=166, label='{{DATE_OF_BIRTH}}', text='3-14-94'),
#   Annotation(start=196, end=199, label='{{NAME}}', text='Mr.'),
#   Annotation(start=208, end=215, label='{{DATE_OF_BIRTH}}', text='77 year'),
#   Annotation(start=1004, end=1008, label='{{DATE_OF_BIRTH}}', text='1991'),
#   Annotation(start=1060, end=1063, label='{{NAME}}', text='Mr.'),
#   Annotation(start=1447, end=1457, label='{{NAME}}', text='Dr. Reg He'),
#   Annotation(start=1876, end=1899, label='{{NAME}}', text='Dr. Lenchermoi Fyfesaul'),
#   Annotation(start=1903, end=1923, label='{{ORGANIZATION}}', text='the Oncology Service'),
#   Annotation(start=1994, end=1997, label='{{NAME}}', text='Mr.'),
#   Annotation(start=2086, end=2098, label='{{NAME}}', text='LENNI E. CEA'),
#   Annotation(start=2139, end=2147, label='{{DATE_OF_BIRTH}}', text='03/13/94')],
#  [Annotation(start=311, end=318, label='{{DATE_OF_BIRTH}}', text='1/12/92'),
#   Annotation(start=536, end=548, label='{{NAME}}', text='Ms. Tikrhalt'),
#   Annotation(start=555, end=562, label='{{DATE_OF_BIRTH}}', text='86 year'),
#   Annotation(start=963, end=969, label='{{NAME}}', text='Dr. Ko'),
#   Annotation(start=2703, end=2710, label='{{DATE_OF_BIRTH}}', text='86 year'),
#   Annotation(start=2860, end=2880, label='{{NAME}}', text='Dr. Fede A. Duhenile'),
#   Annotation(start=2886, end=2893, label='{{DATE_OF_BIRTH}}', text='1/12/92'),
#   Annotation(start=5819, end=5825, label='{{NAME}}', text='Dr. Ko'),
#   Annotation(start=5925, end=5932, label='{{DATE_OF_BIRTH}}', text='8/27/92'),
#   Annotation(start=6052, end=6079, label='{{ORGANIZATION}}', text='Visiting Nurses Association'),
#   Annotation(start=6193, end=6214, label='{{NAME}}', text='TOMEDANKELL FLOWAYLES'),
#   Annotation(start=6271, end=6277, label='{{NAME}}', text='Dr. Ko')],
#  [Annotation(start=218, end=225, label='{{DATE_OF_BIRTH}}', text='68 year'),
#   Annotation(start=312, end=339, label='{{ORGANIZATION}}', text='Cla Lip Operinlafo Hospital'),
#   Annotation(start=1042, end=1076, label='{{ORGANIZATION}}', text='the Fairm of Ijordcompmac Hospital'),
#   Annotation(start=1221, end=1255, label='{{ORGANIZATION}}', text='the Fairm of Ijordcompmac Hospital'),
#   Annotation(start=1631, end=1635, label='{{DATE_OF_BIRTH}}', text='1979'),
#   Annotation(start=3992, end=4039, label='{{ORGANIZATION}}', text='the Valtawnprinceel Community Memorial Hospital'),
#   Annotation(start=4077, end=4087, label='{{NAME}}', text='TOYA NIQUE')],
#  [Annotation(start=177, end=185, label='{{DATE_OF_BIRTH}}', text='03/08/92'),
#   Annotation(start=575, end=585, label='{{DATE_OF_BIRTH}}', text='03/03/92 -'),
#   Annotation(start=797, end=805, label='{{DATE_OF_BIRTH}}', text='02/23/92'),
#   Annotation(start=1165, end=1197, label='{{ORGANIZATION}}', text='the Per Naplesspecrycet Hospital'),
#   Annotation(start=1987, end=2012, label='{{ORGANIZATION}}', text='the Tau Memorial Hospital'),
#   Annotation(start=2031, end=2051, label='{{NAME}}', text='Dr. Freiermthalskush'),
#   Annotation(start=2681, end=2687, label='{{DATE_OF_BIRTH}}', text='3/3/92'),
#   Annotation(start=3005, end=3013, label='{{DATE_OF_BIRTH}}', text='03/07/92'),
#   Annotation(start=3283, end=3300, label='{{NAME}}', text='SHERMENE JESCSELC'),
#   Annotation(start=3324, end=3339, label='{{NAME}}', text='LENNI BREUTZOLN'),
#   Annotation(start=3369, end=3377, label='{{DATE_OF_BIRTH}}', text='03/08/92'),
#   Annotation(start=3383, end=3391, label='{{DATE_OF_BIRTH}}', text='03/10/92'),
#   Annotation(start=3397, end=3407, label='{{NAME}}', text='Dr. Person')],
#  None,
#  [Annotation(start=902, end=914, label='{{NAME}}', text='Dr. Duhenile'),
#   Annotation(start=1246, end=1250, label='{{DATE_OF_BIRTH}}', text='1983'),
#   Annotation(start=3065, end=3084, label='{{NAME}}', text='Dr. Besti Kotebreun'),
#   Annotation(start=3088, end=3109, label='{{ORGANIZATION}}', text='the Radiology Service')],
#  [Annotation(start=152, end=160, label='{{DATE_OF_BIRTH}}', text='09/18/93'),
#   Annotation(start=178, end=186, label='{{DATE_OF_BIRTH}}', text='09/29/93'),
#   Annotation(start=464, end=472, label='{{DATE_OF_BIRTH}}', text='09/22/93'),
#   Annotation(start=509, end=516, label='{{DATE_OF_BIRTH}}', text='75 year'),
#   Annotation(start=791, end=796, label='{{DATE_OF_BIRTH}}', text='06/93'),
#   Annotation(start=1032, end=1062, label='{{ORGANIZATION}}', text='Fairm of Ijordcompmac Hospital'),
#   Annotation(start=1565, end=1581, label='{{ORGANIZATION}}', text='Vascular Surgery'),
#   Annotation(start=1626, end=1634, label='{{DATE_OF_BIRTH}}', text='09/18/93'),
#   Annotation(start=1808, end=1812, label='{{DATE_OF_BIRTH}}', text='1987'),
#   Annotation(start=1875, end=1880, label='{{DATE_OF_BIRTH}}', text='06/93'),
#   Annotation(start=3551, end=3566, label='{{DATE_OF_BIRTH}}', text='August 7 , 1993'),
#   Annotation(start=3605, end=3613, label='{{NAME}}', text='Mr. Iron'),
#   Annotation(start=3630, end=3681, label='{{ORGANIZATION}}', text='the Ossontonville Milt Ywestmeadtl Marlenc Hospital'),
#   Annotation(start=3855, end=3863, label='{{DATE_OF_BIRTH}}', text='09/21/93'),
#   Annotation(start=4501, end=4509, label='{{DATE_OF_BIRTH}}', text='09/22/93'),
#   Annotation(start=4922, end=4941, label='{{ORGANIZATION}}', text='the Medical Service'),
#   Annotation(start=5304, end=5312, label='{{DATE_OF_BIRTH}}', text='09/29/93'),
#   Annotation(start=5446, end=5465, label='{{NAME}}', text='Dr. Tiffill Sapnins'),
#   Annotation(start=5469, end=5510, label='{{ORGANIZATION}}', text='Dingclearf Alllirefaith Memorial Hospital'),
#   Annotation(start=5515, end=5540, label='{{NAME}}', text='Dr. Dwainco Rallsversgach'),
#   Annotation(start=3609, end=3613, label='{{NAME}}', text='Iron'),
#   Annotation(start=5807, end=5818, label='{{NAME}}', text='MARGNA IRON'),
#   Annotation(start=5846, end=5854, label='{{DATE_OF_BIRTH}}', text='01/09/94'),
#   Annotation(start=5874, end=5919, label='{{NAME}}', text='Dr. Tiffill Sapnins Dr. Dwainco Rallsversgach')],
#  [Annotation(start=200, end=207, label='{{DATE_OF_BIRTH}}', text='12/6/93'),
#   Annotation(start=403, end=410, label='{{DATE_OF_BIRTH}}', text='70 year'),
#   Annotation(start=618, end=652, label='{{ORGANIZATION}}', text='the Fairm of Ijordcompmac Hospital'),
#   Annotation(start=656, end=664, label='{{DATE_OF_BIRTH}}', text='11/06/93'),
#   Annotation(start=1857, end=1891, label='{{ORGANIZATION}}', text='the Fairm of Ijordcompmac Hospital'),
#   Annotation(start=2517, end=2525, label='{{LOCATION}}', text='Kentucky'),
#   Annotation(start=622, end=652, label='{{ORGANIZATION}}', text='Fairm of Ijordcompmac Hospital'),
#   Annotation(start=3459, end=3472, label='{{DATE_OF_BIRTH}}', text='Friday , 1963'),
#   Annotation(start=5456, end=5470, label='{{ORGANIZATION}}', text='Surgery Clinic'),
#   Annotation(start=5790, end=5809, label='{{ORGANIZATION}}', text='the Coumadin Clinic'),
#   Annotation(start=5813, end=5820, label='{{DATE_OF_BIRTH}}', text='12/7/93'),
#   Annotation(start=5853, end=5861, label='{{DATE_OF_BIRTH}}', text='12/21/93'),
#   Annotation(start=5893, end=5900, label='{{DATE_OF_BIRTH}}', text='1/24/94'),
#   Annotation(start=6105, end=6120, label='{{ORGANIZATION}}', text='Social Security'),
#   Annotation(start=6123, end=6140, label='{{LOCATION}}', text='SANDSHAEARL AREAS'),
#   Annotation(start=6168, end=6175, label='{{DATE_OF_BIRTH}}', text='12/6/93'),
#   Annotation(start=6181, end=6189, label='{{DATE_OF_BIRTH}}', text='12/07/93')],
#  [Annotation(start=137, end=145, label='{{DATE_OF_BIRTH}}', text='08-27-92'),
#   Annotation(start=218, end=225, label='{{DATE_OF_BIRTH}}', text='75 year'),
#   Annotation(start=503, end=509, label='{{NAME}}', text='doctor'),
#   Annotation(start=513, end=520, label='{{LOCATION}}', text='Arizona'),
#   Annotation(start=760, end=790, label='{{ORGANIZATION}}', text='Fairm of Ijordcompmac Hospital'),
#   Annotation(start=2620, end=2628, label='{{DATE_OF_BIRTH}}', text='08-27-92')],
#  [Annotation(start=413, end=418, label='{{NAME}}', text='Birch'),
#   Annotation(start=517, end=524, label='{{DATE_OF_BIRTH}}', text='52 year'),
#   Annotation(start=853, end=863, label='{{DATE_OF_BIRTH}}', text='April 1992'),
#   Annotation(start=982, end=996, label='{{DATE_OF_BIRTH}}', text='June 22 , 1993'),
#   Annotation(start=1208, end=1212, label='{{DATE_OF_BIRTH}}', text='1970'),
#   Annotation(start=1259, end=1263, label='{{DATE_OF_BIRTH}}', text='1980'),
#   Annotation(start=1760, end=1773, label='{{DATE_OF_BIRTH}}', text='February 1989'),
#   Annotation(start=1873, end=1882, label='{{DATE_OF_BIRTH}}', text='June 1993'),
#   Annotation(start=1943, end=1957, label='{{DATE_OF_BIRTH}}', text='September 1992'),
#   Annotation(start=3092, end=3097, label='{{NAME}}', text='Birch'),
#   Annotation(start=3154, end=3173, label='{{LOCATION}}', text='Jackson-Pratt drain'),
#   Annotation(start=3442, end=3461, label='{{LOCATION}}', text='Jackson-Pratt drain'),
#   Annotation(start=4661, end=4671, label='{{NAME}}', text='Dr. Cancer'),
#   Annotation(start=4685, end=4697, label='{{NAME}}', text='Dr. Kotefold'),
#   Annotation(start=4702, end=4712, label='{{NAME}}', text='Dr. Cancer'),
#   Annotation(start=4715, end=4725, label='{{NAME}}', text='KITRI CURB'),
#   Annotation(start=4818, end=4834, label='{{NAME}}', text='Dr. Ertca Cancer'),
#   Annotation(start=4837, end=4849, label='{{NAME}}', text='Dr. Kotefold')],
#  None,
#  None,
#  [Annotation(start=358, end=362, label='{{DATE_OF_BIRTH}}', text='1984'),
#   Annotation(start=666, end=686, label='{{ORGANIZATION}}', text='Mongcana Ster Staarv'),
#   Annotation(start=1175, end=1179, label='{{DATE_OF_BIRTH}}', text='1940'),
#   Annotation(start=1220, end=1224, label='{{DATE_OF_BIRTH}}', text='1986'),
#   Annotation(start=1455, end=1470, label='{{LOCATION}}', text='Forda Minsas Ve'),
#   Annotation(start=1473, end=1480, label='{{LOCATION}}', text='Wyoming'),
#   Annotation(start=1686, end=1690, label='{{DATE_OF_BIRTH}}', text='1987'),
#   Annotation(start=2932, end=2936, label='{{LOCATION}}', text='Cesa'),
#   Annotation(start=2939, end=2947, label='{{LOCATION}}', text='New York')],
#  [Annotation(start=136, end=144, label='{{NAME}}', text='NERTLAND'),
#   Annotation(start=193, end=203, label='{{DATE_OF_BIRTH}}', text='02/02/2002'),
#   Annotation(start=221, end=231, label='{{DATE_OF_BIRTH}}', text='02/14/2002'),
#   Annotation(start=693, end=705, label='{{NAME}}', text='Mr. Nertland'),
#   Annotation(start=969, end=1003, label='{{ORGANIZATION}}', text='the Fairm of Ijordcompmac Hospital'),
#   Annotation(start=1081, end=1085, label='{{NAME}}', text='Sieh'),
#   Annotation(start=1090, end=1099, label='{{NAME}}', text='Shufffyfe'),
#   Annotation(start=3194, end=3216, label='{{LOCATION}}', text='the Coronary Care Unit'),
#   Annotation(start=5411, end=5419, label='{{NAME}}', text='Dr. Sieh'),
#   Annotation(start=5424, end=5437, label='{{NAME}}', text='Mizy Flomhemp'),
#   Annotation(start=5441, end=5497, label='{{ORGANIZATION}}', text='the Fairm of Ijordcompmac Hospital Heart Failure Program'),
#   Annotation(start=5541, end=5557, label='{{NAME}}', text='Dr. Ri Tlandmaul'),
#   Annotation(start=5561, end=5614, label='{{ORGANIZATION}}', text='the Fairm of Ijordcompmac Hospital Psychiatry Service'),
#   Annotation(start=5622, end=5635, label='{{NAME}}', text='MIZY FLOMHEMP')],
#  [],
#  [],
#  None,
#  [],
#  [],
#  [Annotation(start=143, end=151, label='{{NAME}}', text='NERTLAND'),
#   Annotation(start=284, end=292, label='{{NAME}}', text='NERTLAND')],
#  None,
#  None,
#  [Annotation(start=619, end=648, label='{{ORGANIZATION}}', text='Tonland County Medical Center'),
#   Annotation(start=770, end=804, label='{{ORGANIZATION}}', text='the Fairm of Ijordcompmac Hospital'),
#   Annotation(start=1060, end=1065, label='{{DATE_OF_BIRTH}}', text='07/93'),
#   Annotation(start=2101, end=2135, label='{{ORGANIZATION}}', text='the Fairm of Ijordcompmac Hospital'),
#   Annotation(start=2585, end=2619, label='{{ORGANIZATION}}', text='the Fairm of Ijordcompmac Hospital'),
#   Annotation(start=2781, end=2799, label='{{LOCATION}}', text='the Operating Room'),
#   Annotation(start=2943, end=2959, label='{{ORGANIZATION}}', text='the Ona Hospital'),
#   Annotation(start=4950, end=4964, label='{{ORGANIZATION}}', text='Villrow Health'),
#   Annotation(start=5567, end=5581, label='{{ORGANIZATION}}', text='Villrow Health'),
#   Annotation(start=5610, end=5630, label='{{ORGANIZATION}}', text='Neurosurgery Service'),
#   Annotation(start=5867, end=5881, label='{{ORGANIZATION}}', text='Villrow Health'),
#   Annotation(start=5884, end=5900, label='{{NAME}}', text='DALYWOO DROREITE'),
#   Annotation(start=5941, end=5949, label='{{DATE_OF_BIRTH}}', text='11/04/93')],
#  [],
#  None,
#  [],
#  [],
#  [],
#  [Annotation(start=215, end=225, label='{{DATE_OF_BIRTH}}', text='05/20/2000'),
#   Annotation(start=599, end=619, label='{{ORGANIZATION}}', text='the Oncology Service'),
#   Annotation(start=836, end=843, label='{{DATE_OF_BIRTH}}', text='5/20/00'),
#   Annotation(start=917, end=938, label='{{NAME}}', text='MAREN STEA TLANDFLENT'),
#   Annotation(start=1016, end=1037, label='{{NAME}}', text='MAREN STEA TLANDFLENT')],
#  None,
#  [Annotation(start=624, end=658, label='{{ORGANIZATION}}', text='the Fairm of Ijordcompmac Hospital'),
#   Annotation(start=3652, end=3708, label='{{ORGANIZATION}}', text='the Nilame Hospital Cardiac Surgical Intensive Care Unit'),
#   Annotation(start=4359, end=4380, label='{{NAME}}', text='Dr. Len Fyfejescdoyle'),
#   Annotation(start=4401, end=4407, label='{{NAME}}', text='doctor'),
#   Annotation(start=4415, end=4419, label='{{ORGANIZATION}}', text='ASDH'),
#   Annotation(start=4422, end=4436, label='{{NAME}}', text='Dr. Lenni Vera'),
#   Annotation(start=4443, end=4457, label='{{NAME}}', text='Dr. Kotebeathe'),
#   Annotation(start=4461, end=4486, label='{{ORGANIZATION}}', text='the Endocrinology Service'),
#   Annotation(start=4489, end=4505, label='{{NAME}}', text='KOLO TITCHETLAND'),
#   Annotation(start=4529, end=4539, label='{{NAME}}', text='LENNI VERA'),
#   Annotation(start=4547, end=4564, label='{{NAME}}', text='LEN FYFEJESCDOYLE')],
#  [Annotation(start=162, end=169, label='{{DATE_OF_BIRTH}}', text='12/6/92'),
#   Annotation(start=577, end=611, label='{{ORGANIZATION}}', text='the Fairm of Ijordcompmac Hospital'),
#   Annotation(start=788, end=796, label='{{DATE_OF_BIRTH}}', text='20 years'),
#   Annotation(start=1341, end=1382, label='{{ORGANIZATION}}', text='the Storm Mor Hospital And Medical Center'),
#   Annotation(start=3750, end=3773, label='{{LOCATION}}', text='the Intensive Care Unit'),
#   Annotation(start=5038, end=5052, label='{{ORGANIZATION}}', text='Speech Therapy'),
#   Annotation(start=11199, end=11210, label='{{NAME}}', text='JOASSCCHIRD'),
#   Annotation(start=11234, end=11247, label='{{NAME}}', text='NAREA SWALLOW'),
#   Annotation(start=11275, end=11282, label='{{DATE_OF_BIRTH}}', text='12/6/92'),
#   Annotation(start=11288, end=11296, label='{{DATE_OF_BIRTH}}', text='12/06/92'),
#   Annotation(start=11302, end=11313, label='{{NAME}}', text='Dr. Namarce')],
#  None,
#  [Annotation(start=154, end=162, label='{{DATE_OF_BIRTH}}', text='10-24-93'),
#   Annotation(start=777, end=785, label='{{DATE_OF_BIRTH}}', text='May 1993'),
#   Annotation(start=882, end=890, label='{{DATE_OF_BIRTH}}', text='10-24-93'),
#   Annotation(start=991, end=999, label='{{DATE_OF_BIRTH}}', text='May 1993'),
#   Annotation(start=1156, end=1166, label='{{LOCATION}}', text='Pre Health'),
#   Annotation(start=1200, end=1230, label='{{ORGANIZATION}}', text='Fairm of Ijordcompmac Hospital'),
#   Annotation(start=1989, end=2010, label='{{LOCATION}}', text='the Cardiac Care Unit'),
#   Annotation(start=2830, end=2844, label='{{NAME}}', text='Dr. Shuffburle'),
#   Annotation(start=2946, end=2956, label='{{NAME}}', text='Dr. Amesin'),
#   Annotation(start=2975, end=2988, label='{{NAME}}', text='Dr. Shuffpasc'),
#   Annotation(start=2992, end=3033, label='{{ORGANIZATION}}', text='Dingclearf Alllirefaith Memorial Hospital'),
#   Annotation(start=3219, end=3227, label='{{DATE_OF_BIRTH}}', text='10-24-93'),
#   Annotation(start=3320, end=3369, label='{{LOCATION}}', text='the Fairm of Ijordcompmac Hospital Emergency Ward'),
#   Annotation(start=6021, end=6039, label='{{LOCATION}}', text='the Step Down Unit'),
#   Annotation(start=7646, end=7651, label='{{NAME}}', text='Bruce'),
#   Annotation(start=8313, end=8321, label='{{DATE_OF_BIRTH}}', text='May 1993'),
#   Annotation(start=8368, end=8378, label='{{NAME}}', text='Dr. Amesin'),
#   Annotation(start=8385, end=8395, label='{{NAME}}', text='Dr. Scgach'),
#   Annotation(start=8600, end=8610, label='{{NAME}}', text='Dr. Amesin'),
#   Annotation(start=9109, end=9119, label='{{NAME}}', text='Dr. Amesin'),
#   Annotation(start=9131, end=9143, label='{{NAME}}', text='Dr. Lfsquarc'),
#   Annotation(start=9501, end=9517, label='{{NAME}}', text='CAGHALA UINTEELE'),
#   Annotation(start=9572, end=9613, label='{{NAME}}', text='Dr. Telshey Swatlleebtik Dr. Eri Lfsquarc')],
#  None,
#  [Annotation(start=375, end=396, label='{{ORGANIZATION}}', text='Ijordcompmac Hospital'),
#   Annotation(start=411, end=425, label='{{NAME}}', text='Taroby Patient'),
#   Annotation(start=901, end=935, label='{{ORGANIZATION}}', text='the Fairm of Ijordcompmac Hospital'),
#   Annotation(start=1122, end=1133, label='{{NAME}}', text='Mr. Patient'),
#   Annotation(start=1147, end=1158, label='{{NAME}}', text='Dr. Patient'),
#   Annotation(start=2827, end=2838, label='{{NAME}}', text='Mr. Patient'),
#   Annotation(start=2901, end=2919, label='{{DATE_OF_BIRTH}}', text='February 23 , 1993'),
#   Annotation(start=2952, end=2986, label='{{ORGANIZATION}}', text='the Fairm of Ijordcompmac Hospital'),
#   Annotation(start=3410, end=3421, label='{{NAME}}', text='Mr. Patient'),
#   Annotation(start=3854, end=3865, label='{{NAME}}', text='Mr. Patient'),
#   Annotation(start=3932, end=3956, label='{{NAME}}', text='Dr. Guabenfranda Patient')],
#  None,
#  [Annotation(start=138, end=146, label='{{DATE_OF_BIRTH}}', text='05-03-94'),
#   Annotation(start=405, end=413, label='{{DATE_OF_BIRTH}}', text='05/03/94'),
#   Annotation(start=497, end=505, label='{{NAME}}', text='Dr. Post'),
#   Annotation(start=554, end=561, label='{{DATE_OF_BIRTH}}', text='76 year'),
#   Annotation(start=678, end=683, label='{{DATE_OF_BIRTH}}', text='12/92'),
#   Annotation(start=1533, end=1541, label='{{NAME}}', text='Afebrile'),
#   Annotation(start=1732, end=1735, label='{{NAME}}', text='mry')],
#  [Annotation(start=136, end=143, label='{{DATE_OF_BIRTH}}', text='8-15-93'),
#   Annotation(start=215, end=222, label='{{DATE_OF_BIRTH}}', text='78 year'),
#   Annotation(start=3366, end=3373, label='{{DATE_OF_BIRTH}}', text='8-19-93'),
#   Annotation(start=3382, end=3389, label='{{DATE_OF_BIRTH}}', text='8-21-93'),
#   Annotation(start=4222, end=4231, label='{{NAME}}', text='MS Contin'),
#   Annotation(start=4345, end=4354, label='{{NAME}}', text='Dr. Signs'),
#   Annotation(start=7129, end=7150, label='{{NAME}}', text='GUABENFRANDA D. FOLEY')],
#  [Annotation(start=208, end=215, label='{{DATE_OF_BIRTH}}', text='75 year'),
#   Annotation(start=473, end=485, label='{{DATE_OF_BIRTH}}', text='January 1992'),
#   Annotation(start=1202, end=1242, label='{{LOCATION}}', text="Tah Erri Dearenorow Todblora Hospital 's"),
#   Annotation(start=1578, end=1608, label='{{ORGANIZATION}}', text='Fairm of Ijordcompmac Hospital'),
#   Annotation(start=2975, end=2982, label='{{DATE_OF_BIRTH}}', text='9/24/93'),
#   Annotation(start=3361, end=3368, label='{{DATE_OF_BIRTH}}', text='9/24/93'),
#   Annotation(start=3411, end=3418, label='{{DATE_OF_BIRTH}}', text='9/24/93'),
#   Annotation(start=3555, end=3571, label='{{ORGANIZATION}}', text='Vascular Surgery'),
#   Annotation(start=3724, end=3731, label='{{DATE_OF_BIRTH}}', text='9/29/93'),
#   Annotation(start=3781, end=3813, label='{{LOCATION}}', text='the Surgical Intensive Care Unit'),
#   Annotation(start=4835, end=4842, label='{{DATE_OF_BIRTH}}', text='10/7/93'),
#   Annotation(start=4961, end=4968, label='{{DATE_OF_BIRTH}}', text='9/29/93'),
#   Annotation(start=5071, end=5078, label='{{DATE_OF_BIRTH}}', text='9/24/93'),
#   Annotation(start=5439, end=5457, label='{{NAME}}', text='Dr. Bodlkotesmitre'),
#   Annotation(start=5474, end=5490, label='{{NAME}}', text='Dr. Shuff p.r.n.')],
#  [Annotation(start=399, end=406, label='{{DATE_OF_BIRTH}}', text='52 year'),
#   Annotation(start=495, end=500, label='{{DATE_OF_BIRTH}}', text='03/92'),
#   Annotation(start=3562, end=3580, label='{{LOCATION}}', text='the Brook Hospital'),
#   Annotation(start=4105, end=4111, label='{{NAME}}', text='Dr. Ma'),
#   Annotation(start=4218, end=4227, label='{{NAME}}', text='MS Contin'),
#   Annotation(start=4424, end=4455, label='{{ORGANIZATION}}', text='Santea Gehawhi General Hospital'),
#   Annotation(start=4490, end=4501, label='{{NAME}}', text='ONGNIQUE MA')],
#  [Annotation(start=246, end=254, label='{{NAME}}', text='GETZSIEH'),
#   Annotation(start=302, end=304, label='{{NAME}}', text='MD'),
#   Annotation(start=749, end=792, label='{{NAME}}', text='Dr. Ala Aixknoleskaysneighslemteelenortkote'),
#   Annotation(start=1030, end=1035, label='{{NAME}}', text='NIQUE')],
#  None,
#  [Annotation(start=1552, end=1561, label='{{ORGANIZATION}}', text='Medtronic'),
#   Annotation(start=2582, end=2594, label='{{NAME}}', text='Dr. Jescdrig'),
#   Annotation(start=2668, end=2678, label='{{ORGANIZATION}}', text='ICD Clinic'),
#   Annotation(start=2681, end=2689, label='{{NAME}}', text='CA SHUFF')],
#  [Annotation(start=367, end=376, label='{{NAME}}', text='Mr. Stain'),
#   Annotation(start=398, end=469, label='{{ORGANIZATION}}', text='the Oreiewlefell Merkane I Penaltbridgesgreat University Medical Center'),
#   Annotation(start=1670, end=1678, label='{{NAME}}', text='Dr. Wire'),
#   Annotation(start=2927, end=2935, label='{{DATE_OF_BIRTH}}', text='06/05/93')],
#  [Annotation(start=377, end=384, label='{{DATE_OF_BIRTH}}', text='82 year'),
#   Annotation(start=458, end=470, label='{{DATE_OF_BIRTH}}', text='January 1993'),
#   Annotation(start=474, end=478, label='{{LOCATION}}', text='Iowa'),
#   Annotation(start=562, end=573, label='{{NAME}}', text='Dr. Bolmshi'),
#   Annotation(start=577, end=589, label='{{DATE_OF_BIRTH}}', text='January 1993'),
#   Annotation(start=2887, end=2898, label='{{NAME}}', text='Dr. Bolmshi'),
#   Annotation(start=3524, end=3543, label='{{ORGANIZATION}}', text='Cancer Pain Service'),
#   Annotation(start=3572, end=3588, label='{{ORGANIZATION}}', text='The Pain Service'),
#   Annotation(start=3852, end=3864, label='{{NAME}}', text='Dr. Fyfekote'),
#   Annotation(start=4004, end=4016, label='{{NAME}}', text='Dr. Fyfekote'),
#   Annotation(start=4066, end=4080, label='{{NAME}}', text='SIE FLYTHEGACH'),
#   Annotation(start=4104, end=4116, label='{{NAME}}', text='DOJE BOLMSHI')],
#  None,
#  [Annotation(start=495, end=525, label='{{ORGANIZATION}}', text='Fairm of Ijordcompmac Hospital'),
#   Annotation(start=994, end=1004, label='{{DATE_OF_BIRTH}}', text='April 1989'),
#   Annotation(start=1044, end=1058, label='{{DATE_OF_BIRTH}}', text='September 1992'),
#   Annotation(start=1112, end=1116, label='{{DATE_OF_BIRTH}}', text='1984'),
#   Annotation(start=1119, end=1128, label='{{ORGANIZATION}}', text='Medtronic'),
#   Annotation(start=1877, end=1917, label='{{LOCATION}}', text='the Cardiac Electrophysiology Laboratory'),
#   Annotation(start=2855, end=2913, label='{{LOCATION}}', text='the Scst.ontdrain University Medical Center Step Down Unit'),
#   Annotation(start=3301, end=3310, label='{{ORGANIZATION}}', text='Medtronic'),
#   Annotation(start=4034, end=4050, label='{{ORGANIZATION}}', text='Da Valley Health'),
#   Annotation(start=4053, end=4071, label='{{NAME}}', text='Dr. Ri Roleubbreun'),
#   Annotation(start=4093, end=4102, label='{{NAME}}', text='Dr. Shuff')],
#  [Annotation(start=218, end=225, label='{{DATE_OF_BIRTH}}', text='68 year')],
#  [Annotation(start=468, end=475, label='{{DATE_OF_BIRTH}}', text='63 year'),
#   Annotation(start=776, end=786, label='{{DATE_OF_BIRTH}}', text='April 1993'),
#   Annotation(start=2302, end=2322, label='{{ORGANIZATION}}', text='the Oncology Service'),
#   Annotation(start=3170, end=3190, label='{{NAME}}', text='Dr. Guabenfranda Day'),
#   Annotation(start=3207, end=3215, label='{{NAME}}', text='CA SHUFF'),
#   Annotation(start=3269, end=3285, label='{{NAME}}', text='GUABENFRANDA DAY')],
#  None,
#  None,
#  None,
#  None,
#  None,
#  [Annotation(start=11, end=14, label='{{ORGANIZATION}}', text='FIH'),
#   Annotation(start=137, end=145, label='{{DATE_OF_BIRTH}}', text='06-30-93'),
#   Annotation(start=363, end=370, label='{{DATE_OF_BIRTH}}', text='67 year'),
#   Annotation(start=892, end=900, label='{{DATE_OF_BIRTH}}', text='05/05/93'),
#   Annotation(start=904, end=907, label='{{ORGANIZATION}}', text='FIH'),
#   Annotation(start=2376, end=2384, label='{{DATE_OF_BIRTH}}', text='06/30/93'),
#   Annotation(start=3635, end=3656, label='{{NAME}}', text='Dr. Iechalette Cancer'),
#   Annotation(start=3777, end=3791, label='{{NAME}}', text='Dr. Na Dussmum')],
#  None,
#  [Annotation(start=497, end=507, label='{{NAME}}', text='Mr. Breath'),
#   Annotation(start=839, end=865, label='{{ORGANIZATION}}', text='Giles Min General Hospital'),
#   Annotation(start=1053, end=1087, label='{{LOCATION}}', text='the Fairm of Ijordcompmac Hospital'),
#   Annotation(start=2149, end=2155, label='{{NAME}}', text='Mattox'),
#   Annotation(start=2885, end=2920, label='{{LOCATION}}', text='the Respiratory Intensive Care Unit'),
#   Annotation(start=3152, end=3172, label='{{ORGANIZATION}}', text='Neurosurgery Service'),
#   Annotation(start=4147, end=4165, label='{{LOCATION}}', text='Roux-en-Y drainage'),
#   Annotation(start=4197, end=4210, label='{{LOCATION}}', text='Jackson-Pratt'),
#   Annotation(start=4322, end=4329, label='{{ORGANIZATION}}', text='Quinton'),
#   Annotation(start=5509, end=5522, label='{{LOCATION}}', text='Jackson-Pratt'),
#   Annotation(start=6727, end=6741, label='{{DATE_OF_BIRTH}}', text='July 30 , 1993'),
#   Annotation(start=7333, end=7340, label='{{ORGANIZATION}}', text='Quinton')],
#  [Annotation(start=189, end=197, label='{{DATE_OF_BIRTH}}', text='01/22/93'),
#   Annotation(start=227, end=243, label='{{NAME}}', text='Mr. Louplardkote'),
#   Annotation(start=249, end=256, label='{{DATE_OF_BIRTH}}', text='70 year'),
#   Annotation(start=447, end=452, label='{{DATE_OF_BIRTH}}', text='02/92'),
#   Annotation(start=458, end=470, label='{{DATE_OF_BIRTH}}', text='March , 1993'),
#   Annotation(start=606, end=620, label='{{DATE_OF_BIRTH}}', text='October , 1993'),
#   Annotation(start=2603, end=2611, label='{{DATE_OF_BIRTH}}', text='01/15/93'),
#   Annotation(start=2932, end=2949, label='{{NAME}}', text='Dr. Chitllik Kote'),
#   Annotation(start=3749, end=3781, label='{{ORGANIZATION}}', text='the Surgical Intensive Care Unit'),
#   Annotation(start=4219, end=4232, label='{{LOCATION}}', text='the Pacer Lab'),
#   Annotation(start=5061, end=5078, label='{{ORGANIZATION}}', text='the Pacer Service'),
#   Annotation(start=6048, end=6056, label='{{DATE_OF_BIRTH}}', text='01/22/93'),
#   Annotation(start=6347, end=6355, label='{{DATE_OF_BIRTH}}', text='01/17/93'),
#   Annotation(start=6359, end=6376, label='{{NAME}}', text='Dr. Chitllik Kote'),
#   Annotation(start=6654, end=6671, label='{{NAME}}', text='Dr. Chitllik Kote'),
#   Annotation(start=6704, end=6717, label='{{NAME}}', text='Dr. Naka Jesc'),
#   Annotation(start=6743, end=6768, label='{{NAME}}', text='Dr. Tomedankell Flowayles'),
#   Annotation(start=6772, end=6790, label='{{ORGANIZATION}}', text='Sephsandpot Center'),
#   Annotation(start=6794, end=6802, label='{{LOCATION}}', text='Chandbay'),
#   Annotation(start=6805, end=6819, label='{{NAME}}', text='LEEN PAUGBREUN'),
#   Annotation(start=6843, end=6856, label='{{NAME}}', text='CHITLLIK KOTE'),
#   Annotation(start=6884, end=6892, label='{{DATE_OF_BIRTH}}', text='01/24/93'),
#   Annotation(start=6898, end=6906, label='{{DATE_OF_BIRTH}}', text='01/26/93'),
#   Annotation(start=2936, end=2949, label='{{NAME}}', text='Chitllik Kote'),
#   Annotation(start=6708, end=6717, label='{{NAME}}', text='Naka Jesc'),
#   Annotation(start=6747, end=6768, label='{{NAME}}', text='Tomedankell Flowayles'),
#   Annotation(start=6974, end=6996, label='{{ORGANIZATION}}', text='M.D. T. Medical Center'),
#   Annotation(start=6999, end=7007, label='{{LOCATION}}', text='Carsterl'),
#   Annotation(start=7010, end=7019, label='{{LOCATION}}', text='Minnesota')],
#  None,
#  [Annotation(start=304, end=308, label='{{NAME}}', text='Down'),
#   Annotation(start=387, end=391, label='{{NAME}}', text='Down'),
#   Annotation(start=556, end=560, label='{{NAME}}', text='Down'),
#   Annotation(start=770, end=774, label='{{DATE_OF_BIRTH}}', text='1998'),
#   Annotation(start=1037, end=1041, label='{{NAME}}', text='Down'),
#   Annotation(start=1091, end=1095, label='{{NAME}}', text='Down'),
#   Annotation(start=1121, end=1125, label='{{DATE_OF_BIRTH}}', text='1998'),
#   Annotation(start=1681, end=1685, label='{{NAME}}', text='Down'),
#   Annotation(start=2944, end=2964, label='{{ORGANIZATION}}', text='the Arkzie- Memorial'),
#   Annotation(start=4867, end=4881, label='{{NAME}}', text='Dr. Flythegach'),
#   Annotation(start=5051, end=5066, label='{{NAME}}', text='LATO TIKFREIERM'),
#   Annotation(start=5120, end=5135, label='{{NAME}}', text='LATO TIKFREIERM'),
#   Annotation(start=5268, end=5283, label='{{NAME}}', text='LATO TIKFREIERM')],
#  [Annotation(start=679, end=688, label='{{NAME}}', text='ZETLLILLE'),
#   Annotation(start=901, end=908, label='{{NAME}}', text='LASHARG')],
#  [Annotation(start=128, end=136, label='{{DATE_OF_BIRTH}}', text='03-28-94'),
#   Annotation(start=154, end=162, label='{{DATE_OF_BIRTH}}', text='03-31-94'),
#   Annotation(start=398, end=411, label='{{LOCATION}}', text='a Fayran Wara'),
#   Annotation(start=620, end=650, label='{{ORGANIZATION}}', text='Fairm of Ijordcompmac Hospital'),
#   Annotation(start=728, end=736, label='{{LOCATION}}', text='Ingloard'),
#   Annotation(start=1337, end=1341, label='{{DATE_OF_BIRTH}}', text='1991'),
#   Annotation(start=1353, end=1371, label='{{ORGANIZATION}}', text='Sephsandpot Center'),
#   Annotation(start=1447, end=1458, label='{{DATE_OF_BIRTH}}', text='July , 1993'),
#   Annotation(start=4656, end=4674, label='{{LOCATION}}', text='the Bless Hospital'),
#   Annotation(start=4753, end=4763, label='{{NAME}}', text='Dr. Breath'),
#   Annotation(start=4767, end=4785, label='{{LOCATION}}', text='the Bless Hospital'),
#   Annotation(start=4809, end=4823, label='{{NAME}}', text='TIFFILL BREATH'),
#   Annotation(start=4851, end=4859, label='{{DATE_OF_BIRTH}}', text='03-31-94')],
#  None,
#  None,
#  None,
#  [Annotation(start=223, end=233, label='{{DATE_OF_BIRTH}}', text='12/26/2002'),
#   Annotation(start=1881, end=1889, label='{{NAME}}', text='evidence'),
#   Annotation(start=1953, end=1961, label='{{NAME}}', text='evidence'),
#   Annotation(start=1965, end=1975, label='{{NAME}}', text='Wenckebach'),
#   Annotation(start=1998, end=2006, label='{{NAME}}', text='evidence'),
#   Annotation(start=2032, end=2040, label='{{NAME}}', text='evidence'),
#   Annotation(start=2213, end=2221, label='{{NAME}}', text='evidence'),
#   Annotation(start=2662, end=2672, label='{{DATE_OF_BIRTH}}', text='12/23/2002'),
#   Annotation(start=2704, end=2712, label='{{NAME}}', text='evidence'),
#   Annotation(start=2740, end=2750, label='{{NAME}}', text='Wenckebach'),
#   Annotation(start=2769, end=2777, label='{{NAME}}', text='evidence'),
#   Annotation(start=3131, end=3141, label='{{DATE_OF_BIRTH}}', text='12/26/2002'),
#   Annotation(start=3218, end=3227, label='{{ORGANIZATION}}', text='Medtronic'),
#   Annotation(start=3420, end=3428, label='{{NAME}}', text='evidence'),
#   Annotation(start=3704, end=3714, label='{{DATE_OF_BIRTH}}', text='12/26/2002'),
#   Annotation(start=4902, end=4918, label='{{NAME}}', text='ILL KIHDAIZ , MD'),
#   Annotation(start=4981, end=4997, label='{{DATE_OF_BIRTH}}', text='01/10/2003 22:16'),
#   Annotation(start=5066, end=5076, label='{{DATE_OF_BIRTH}}', text='12/26/2002'),
#   Annotation(start=5082, end=5097, label='{{DATE_OF_BIRTH}}', text='12/27/2002 6:24'),
#   Annotation(start=4902, end=4913, label='{{NAME}}', text='ILL KIHDAIZ')],
#  None,
#  None,
#  [Annotation(start=239, end=249, label='{{DATE_OF_BIRTH}}', text='08/04/1998'),
#   Annotation(start=452, end=456, label='{{DATE_OF_BIRTH}}', text='1992'),
#   Annotation(start=737, end=757, label='{{ORGANIZATION}}', text='the Bridges Hospital'),
#   Annotation(start=999, end=1003, label='{{DATE_OF_BIRTH}}', text='1992'),
#   Annotation(start=1392, end=1441, label='{{LOCATION}}', text='the Fairm of Ijordcompmac Hospital Emergency Ward'),
#   Annotation(start=1447, end=1496, label='{{LOCATION}}', text='the Fairm of Ijordcompmac Hospital Emergency Ward'),
#   Annotation(start=2617, end=2621, label='{{DATE_OF_BIRTH}}', text='1992'),
#   Annotation(start=2747, end=2767, label='{{ORGANIZATION}}', text='the Bridges Hospital'),
#   Annotation(start=2958, end=2965, label='{{LOCATION}}', text='Sonhunt'),
#   Annotation(start=3910, end=3959, label='{{LOCATION}}', text='the Fairm of Ijordcompmac Hospital Emergency Ward'),
#   Annotation(start=6031, end=6038, label='{{DATE_OF_BIRTH}}', text='81 year'),
#   Annotation(start=1396, end=1426, label='{{ORGANIZATION}}', text='Fairm of Ijordcompmac Hospital'),
#   Annotation(start=6351, end=6390, label='{{ORGANIZATION}}', text='Lyjoneshutchepawalt Cleod Exre Hospital'),
#   Annotation(start=1392, end=1426, label='{{ORGANIZATION}}', text='the Fairm of Ijordcompmac Hospital'),
#   Annotation(start=6667, end=6687, label='{{ORGANIZATION}}', text='the Bridges Hospital'),
#   Annotation(start=1451, end=1481, label='{{ORGANIZATION}}', text='Fairm of Ijordcompmac Hospital'),
#   Annotation(start=7062, end=7069, label='{{LOCATION}}', text='Valemin'),
#   Annotation(start=7210, end=7259, label='{{LOCATION}}', text='the Fairm of Ijordcompmac Hospital Emergency Ward'),
#   Annotation(start=8210, end=8230, label='{{ORGANIZATION}}', text='the Bridges Hospital'),
#   Annotation(start=8686, end=8706, label='{{ORGANIZATION}}', text='the Bridges Hospital'),
#   Annotation(start=8710, end=8716, label='{{DATE_OF_BIRTH}}', text='8/6/98'),
#   Annotation(start=8740, end=8754, label='{{NAME}}', text='Dr. Chpo Night'),
#   Annotation(start=8758, end=8778, label='{{ORGANIZATION}}', text='the Bridges Hospital')],
#  [],
#  [Annotation(start=141, end=145, label='{{NAME}}', text='KOTE'),
#   Annotation(start=512, end=519, label='{{DATE_OF_BIRTH}}', text='65 year'),
#   Annotation(start=524, end=528, label='{{NAME}}', text='lady'),
#   Annotation(start=691, end=705, label='{{LOCATION}}', text='Hercent Avenue'),
#   Annotation(start=825, end=841, label='{{LOCATION}}', text='Ton-balt airport'),
#   Annotation(start=1326, end=1331, label='{{LOCATION}}', text='Maine'),
#   Annotation(start=2001, end=2009, label='{{LOCATION}}', text='Nebraska'),
#   Annotation(start=2048, end=2082, label='{{ORGANIZATION}}', text='the Fairm of Ijordcompmac Hospital'),
#   Annotation(start=6525, end=6542, label='{{ORGANIZATION}}', text='Pulmonary Service'),
#   Annotation(start=6658, end=6666, label='{{LOCATION}}', text='Missouri'),
#   Annotation(start=6727, end=6742, label='{{ORGANIZATION}}', text="Atrovent MDI 's"),
#   Annotation(start=6879, end=6884, label='{{LOCATION}}', text='Balau'),
#   Annotation(start=7135, end=7137, label='{{NAME}}', text='Lo'),
#   Annotation(start=7367, end=7378, label='{{LOCATION}}', text='Reveverburg'),
#   Annotation(start=7381, end=7390, label='{{NAME}}', text='LENNI CAN'),
#   Annotation(start=7411, end=7421, label='{{DATE_OF_BIRTH}}', text='08/04/1999'),
#   Annotation(start=7427, end=7437, label='{{DATE_OF_BIRTH}}', text='08/09/1999'),
#   Annotation(start=7505, end=7517, label='{{ORGANIZATION}}', text='Thesa Health')]]

# %%
scruba_dict = get_all_doc_metrics(ann_tuples, scruba_tuples)
scruba_dict
# Out:
# {'AGE': {'fn': 27, 'fp': 27, 'tp': 0},
#  'DATE': {'fn': 303, 'fp': 0, 'tp': 167},
#  'DOCTOR': {'fn': 68, 'fp': 1, 'tp': 133},
#  'HOSPITAL': {'fn': 19, 'fp': 0, 'tp': 78},
#  'ID': {'fn': 277, 'fp': 0, 'tp': 0},
#  'LOCATION': {'fn': 1, 'fp': 1, 'tp': 14},
#  'PATIENT': {'fn': 19, 'fp': 0, 'tp': 18},
#  'PHONE': {'fn': 10, 'fp': 0, 'tp': 0}}

# %%
get_formula_metrics(scruba_dict)
# Out:
# {'AGE': {'f1': 0, 'prec': 0.0, 'rec': 0.0},
#  'DATE': {'f1': 0.5243328100470958, 'prec': 1.0, 'rec': 0.3553191489361702},
#  'DOCTOR': {'f1': 0.7940298507462685,
#   'prec': 0.9925373134328358,
#   'rec': 0.6616915422885572},
#  'HOSPITAL': {'f1': 0.8914285714285715,
#   'prec': 1.0,
#   'rec': 0.8041237113402062},
#  'ID': {'f1': 0, 'prec': 0, 'rec': 0.0},
#  'LOCATION': {'f1': 0.9333333333333333,
#   'prec': 0.9333333333333333,
#   'rec': 0.9333333333333333},
#  'PATIENT': {'f1': 0.6545454545454547, 'prec': 1.0, 'rec': 0.4864864864864865},
#  'PHONE': {'f1': 0, 'prec': 0, 'rec': 0.0}}

# %% [markdown]
# # THAT'S A WRAP!
