# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/spark-nlp-workshop/blob/master/tutorials/Certification_Trainings/Healthcare/30.4.Text_Classification_with_LargeFewShotClassifier.ipynb)

# %% [markdown]
# # Large FewShot Classifier Model

# %% [markdown]
# In this notebook, we’ll explore how SetFit can efficiently deliver strong performance even with a limited amount of data. SetFit leverages contrastive learning to expand a small set of labeled examples into thousands of training instances, making the most of what’s available. While it may not match the performance of Bert For Sequence Classifcation (BFSC) models trained on full datasets, it offers a balance of efficiency and effectiveness.

# %% [markdown]
# ## **Colab Setup**

# %%
import json
import os

from google.colab import files

if 'spark_jsl.json' not in os.listdir():
  license_keys = files.upload()
  os.rename(list(license_keys.keys())[0], 'spark_jsl.json')

with open('spark_jsl.json') as f:
    license_keys = json.load(f)

# Defining license key-value pairs as local variables
locals().update(license_keys)
os.environ.update(license_keys)

# %%
# Installing setfit transformers onnx-tf skl2onnx (>=1.19.1 for onnx>=1.16)
! pip install -q setfit "transformers>=4.41,<5.0" onnx-tf "skl2onnx>=1.19.1" "onnxruntime>=1.19.2" onnxscript
! pip install -q optimum
! pip install -q sentence_transformers
! pip install -q "transformers>=4.41,<5.0" "skl2onnx>=1.19.1" "onnxruntime>=1.19.2"  # re-pin after optimum

# %%
# Installing pyspark and spark-nlp
! pip install --upgrade -q pyspark==3.4.1 spark-nlp==$PUBLIC_VERSION

# Installing Spark NLP Healthcare
! pip install --upgrade -q spark-nlp-jsl==$JSL_VERSION  --extra-index-url https://pypi.johnsnowlabs.com/$SECRET

# Installing Spark NLP Display Library for visualization
! pip install -q spark-nlp-display

# %%
import setfit
import onnx
import tensorflow as tf
import shutil
import copy
import sentence_transformers
import torch
import torch.onnx
import transformers
# import onnx_tf

from transformers import pipeline, set_seed, BioGptTokenizer, BioGptForCausalLM, AutoTokenizer, AutoModel
from sentence_transformers import SentenceTransformer
from setfit import Trainer, SetFitModel, TrainingArguments, sample_dataset
from skl2onnx import convert_sklearn
from datasets import Dataset
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
#skl2onnx is needed to convert sklearn LogisticRegression to ONNX
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
import json
import os

import numpy as np
import pandas as pd

import sparknlp
import sparknlp_jsl

from pyspark.ml import Pipeline
from pyspark.sql import SparkSession
from pyspark.sql.functions import col

from sparknlp.base import *
from sparknlp.annotator import *
from sparknlp_jsl.annotator import *

import warnings
warnings.filterwarnings('ignore')

params = {"spark.driver.memory":"16G",
          "spark.kryoserializer.buffer.max":"2000M",
          "spark.driver.maxResultSize":"2000M"}

spark = sparknlp_jsl.start(license_keys['SECRET'],params=params)

print("Spark NLP Version :", sparknlp.version())
print("Spark NLP_JSL Version :", sparknlp_jsl.version())

spark
# Out:
# Spark NLP Version : 6.4.0
# Spark NLP_JSL Version : 6.4.0
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://689bfa6fc2a7:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark NLP Licensed</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
#disable gpu
import os
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %% [markdown]
# ## Healthcare NLP for Data Scientists Course
#
# If you are not familiar with the components in this notebook, you can check [Healthcare NLP for Data Scientists Udemy Course](https://www.udemy.com/course/healthcare-nlp-for-data-scientists/) and the [MOOC Notebooks](https://github.com/JohnSnowLabs/spark-nlp-workshop/tree/master/Spark_NLP_Udemy_MOOC/Healthcare_NLP) for each components.

# %% [markdown]
# # Pretrained Models

# %% [markdown]
# | Model Name              | Description |
# |-------------------------|-------------|
# |[large_fewshot_classifier_age_group](https://nlp.johnsnowlabs.com/2024/08/15/large_fewshot_classifier_age_group_en)      | This few-shot classification model identifies and classifies tweets reporting Adverse Drug Events (ADEs).
# |[large_fewshot_classifier_ade](https://nlp.johnsnowlabs.com/2024/08/12/large_fewshot_classifier_ade_en)      | This few-shot classification model identifies and classifies the age group of a person mentioned in health documents.

# %%
#Pipeline for pretrained `large_fewshot_classifier_ade` model

documentAssembler = DocumentAssembler() \
    .setInputCol("text") \
    .setOutputCol("document")

large_few_shot_classifier = LargeFewShotClassifierModel()\
    .pretrained("large_fewshot_classifier_ade", "en", "clinical/models")\
    .setInputCols("document")\
    .setOutputCol("prediction")

pipeline = Pipeline().setStages([
    documentAssembler,
    large_few_shot_classifier
])
# Out:
# large_fewshot_classifier_ade download started this may take some time.
# Approximate size to download 388 MB
# [OK!]

# %%
large_few_shot_classifier.getClasses()
# Out:
# ['noADE', 'ADE']

# %%
data = spark.createDataFrame([
    ["The patient developed severe liver toxicity after taking the medication for three weeks"],
    ["He experienced no complications during the treatment and reported feeling much better."],
    ["She experienced a sudden drop in blood pressure after the administration of the new drug."],
    ["The doctor recommended a daily dosage of the vitamin supplement to improve her health."]
]).toDF("text")

result = pipeline.fit(data).transform(data)

result.selectExpr("text", "prediction.result[0] as prediction").show(truncate=False)
# Out:
# +-----------------------------------------------------------------------------------------+----------+
# |text                                                                                     |prediction|
# +-----------------------------------------------------------------------------------------+----------+
# |The patient developed severe liver toxicity after taking the medication for three weeks  |ADE       |
# |He experienced no complications during the treatment and reported feeling much better.   |noADE     |
# |She experienced a sudden drop in blood pressure after the administration of the new drug.|ADE       |
# |The doctor recommended a daily dosage of the vitamin supplement to improve her health.   |noADE     |
# +-----------------------------------------------------------------------------------------+----------+

# %% [markdown]
# # Training

# %% [markdown]
# ## Dataset

# %%
# !wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/mtsamples_classifier.csv

# %%
df = pd.read_csv("./mtsamples_classifier.csv").dropna().reset_index(drop=True)
df.rename(columns={'category': 'label'}, inplace=True)
df['label']=df['label'].astype(str)
df["text"] = df["text"].astype(str)
df["length"] = df["text"].apply(lambda x: len(x))
#df = df[df["length"] <= 512].reset_index(drop=True)
df
# Out:
#                 label                                               text  \
# 0    Gastroenterology   PROCEDURES PERFORMED: Colonoscopy. INDICATION...
# 1    Gastroenterology   OPERATION 1. Ivor-Lewis esophagogastrectomy. ...
# 2    Gastroenterology   PREOPERATIVE DIAGNOSES: 1. Gastroesophageal r...
# 3    Gastroenterology   PROCEDURE: Colonoscopy. PREOPERATIVE DIAGNOSE...
# 4    Gastroenterology   PREOPERATIVE DIAGNOSIS: Right colon tumor. PO...
# ..                ...                                                ...
# 625           Urology   PREOPERATIVE DIAGNOSIS: Bilateral vesicourete...
# 626           Urology   HISTORY OF PRESENT ILLNESS: The patient prese...
# 627           Urology   Thank you for allowing me to help in the eval...
# 628           Urology   PREOPERATIVE DIAGNOSIS: Bilateral undescended...
# 629           Urology   REASON FOR VISIT: Overactive bladder with mic...
#
#      length
# 0      3058
# 1      5937
# 2      2422
# 3      1886
# 4      3999
# ..      ...
# 625    2871
# 626    2008
# 627    3213
# 628    3766
# 629    1193
#
# [630 rows x 3 columns]

# %%
df["label"].value_counts()
# Out:
# label
# Orthopedic          222
# Gastroenterology    157
# Neurology           141
# Urology             110
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
train_data_df, test_data_df = train_test_split(df, test_size=0.2, random_state=55, stratify= df['label'])

# %%
train_data_df.label.value_counts()
# Out:
# label
# Orthopedic          178
# Gastroenterology    125
# Neurology           113
# Urology              88
# Name: count, dtype: int64

# %%
test_data_df.label.value_counts()
# Out:
# label
# Orthopedic          44
# Gastroenterology    32
# Neurology           28
# Urology             22
# Name: count, dtype: int64

# %% [markdown]
# ## Preprocess

# %%
#base sentence embeddings model to use
MODEL_NAME = "sentence-transformers/all-mpnet-base-v2"

# !mkdir -p  ./models
#location to save the trained model
EXPORT_PATH = "./models/mtsamples_classifier/"
#Use differentiable head or not. If not differentiable, SetFit will use sklearn LogisticRegression for the classifier
#Otherwise a custom Pytorch model will be used. A differentiable head makes a more powerful/sensitive classifier but
#requires more data. If only a few examples per class are available, then resort to a non-differentiable classifier
USE_DIFFERENTIABLE_HEAD = False
USE_NUMERIC_LABELS = True

# %%
#preprocess data
#NOTE: a SetFIT model with differentiable head only accepts numeric(integer) labels. In such a case you need to
#convert the labels to ints and save the original labels in a separate text file called labels.txt (see below)
def preprocessing_data(df, labels = None):
    if not labels:
        labels = list(df.label.unique())

    if USE_DIFFERENTIABLE_HEAD or USE_NUMERIC_LABELS:
        df["label_classes"] =  df["label"]
        df["label"] = df.apply(lambda x: labels.index(x["label"]), axis=1)
    #df["length"] = df["text"].apply(lambda x: len(x))
    #df = df[df["length"] <= 512]
    return df, labels

# %%
#create training/test datasets

#Number of samples per class to use in the training set. The larger, the better, but slower
N_SAMPLES_PER_CLASS = {
    "Orthopedic": 1,
    "Gastroenterology": 1,
    "Neurology" : 1,
    "Urology": 1
}

train_data_df_p, labels = preprocessing_data(train_data_df)
test_data_df_p, _ = preprocessing_data(test_data_df, labels)

#add numeric labels, if needed
for k in list(N_SAMPLES_PER_CLASS.keys()):
    N_SAMPLES_PER_CLASS[labels.index(k)] = N_SAMPLES_PER_CLASS[k]

# train_data_df_p = train_data_df_p.groupby("label").apply(lambda x: x.sample(N_SAMPLES_PER_CLASS[x["label"].iloc[0]]))
# train_data_df_p = train_data_df_p.reset_index(drop=True)


train_dataset = Dataset.from_pandas(train_data_df_p)
test_dataset = Dataset.from_pandas(test_data_df_p)

# train_dataset = sample_dataset(train_dataset, label_column="label", num_samples=N_SAMPLES)

# %%
labels
# Out:
# ['Gastroenterology', 'Orthopedic', 'Neurology', 'Urology']

# %%
train_dataset
# Out:
# Dataset({
#     features: ['label', 'text', 'length', 'label_classes', '__index_level_0__'],
#     num_rows: 504
# })

# %%
test_dataset
# Out:
# Dataset({
#     features: ['label', 'text', 'length', 'label_classes', '__index_level_0__'],
#     num_rows: 126
# })

# %% [markdown]
# ## Training

# %%
#Create the model
if USE_DIFFERENTIABLE_HEAD:
    model = SetFitModel.from_pretrained(MODEL_NAME,
                                        use_differentiable_head = True,
                                        head_params={"out_features": len(labels)})
    model.labels = list(range(0, len(labels)))
else:
    model = SetFitModel.from_pretrained(MODEL_NAME)
    model.labels = labels
# Out:
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# model_head.pkl not found on HuggingFace Hub, initialising classification head with random weights. You should TRAIN this model on a downstream task to use it for predictions and inference.

# %%
model.labels
# Out:
# ['Gastroenterology', 'Orthopedic', 'Neurology', 'Urology']

# %%
args = TrainingArguments(
    # loss=sentence_transformers.losses.OnlineContrastiveLoss,
    max_steps = 10,
    batch_size=1,
    num_epochs=1
)
args.eval_strategy = args.evaluation_strategy
trainer = Trainer(
    model=model,
    args=args,
    train_dataset=train_dataset
)
# Out:
# Map:   0%|          | 0/504 [00:00<?, ? examples/s]

# %%
trainer.train()
# Out:
# ***** Running training *****
#   Num unique pairs = 10
#   Batch size = 1
#   Num epochs = 1
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 3
# wandb: You chose "Don't visualize my results"
# wandb: Using W&B in offline mode.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.27.2
# W&B syncing is set to <code>`offline`<code> in this directory. Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.<br>Run data is saved locally in <code>/content/wandb/offline-run-20260619_231427-inc6lbxf</code>
#     <div>
#
#       <progress value='10' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10/10 00:44, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>

# %%
# SetFit >=1.x: log_history on st_trainer.state (not trainer.state)
_state = getattr(getattr(trainer, "st_trainer", None), "state", None) or getattr(trainer, "state", None)
_state.log_history[-5:] if _state else "Training finished — see trainer.train() output above."
# Out:
# [{'embedding_loss': 0.1246,
#   'grad_norm': 3.382701873779297,
#   'learning_rate': 0.0,
#   'epoch': 0.1,
#   'step': 1},
#  {'train_runtime': 63.2284,
#   'train_samples_per_second': 0.158,
#   'train_steps_per_second': 0.158,
#   'total_flos': 0.0,
#   'train_loss': 0.22792476713657378,
#   'epoch': 1.0,
#   'step': 10}]

# %%
USE_DIFFERENTIABLE_HEAD
# Out:
# False

# %%
#convert numeric label ids to 32 bit ints
if USE_DIFFERENTIABLE_HEAD:
    model.labels = [int(l_i) for l_i in model.labels]

# %%
model.save_pretrained(EXPORT_PATH)

# %%
EXPORT_PATH
# Out:
# './models/mtsamples_classifier/'

# %%
labels
# Out:
# ['Gastroenterology', 'Orthopedic', 'Neurology', 'Urology']

# %%
#Save the original labels. Not necessary if using a non-differentiable head, but doing it in all cases for consistency
with open(f"{EXPORT_PATH}/labels.txt", "wt") as F:
    for label in labels:
        F.write(label + "\n")

# %% [markdown]
# ## Evaluation

# %%
trainer.evaluate(test_dataset)
# Out:
# ***** Running evaluation *****
# Downloading builder script: 0.00B [00:00, ?B/s]
# {'accuracy': 0.9444444444444444}

# %%
test_predictions = []
test_labels = []
batch_i = 0
batch_size = 16
while batch_i * batch_size < len(test_dataset):
    batch = test_dataset[batch_i * batch_size: (batch_i + 1)* batch_size]
    # print(batch)
    predicted_labels = model.predict(batch["text"])
    test_predictions.extend([predicted_label if type(predicted_label) == str else  labels[int(predicted_label)] for predicted_label in predicted_labels])
    test_labels.extend([ex_label if type(ex_label) == str else labels[int(ex_label)] for ex_label in batch["label"]])
    batch_i += 1

# %%
report = classification_report(test_labels, test_predictions)
print(report)
# Out:
#                   precision    recall  f1-score   support
#
# Gastroenterology       0.94      1.00      0.97        32
#        Neurology       0.90      0.93      0.91        28
#       Orthopedic       0.98      0.98      0.98        44
#          Urology       0.95      0.82      0.88        22
#
#         accuracy                           0.94       126
#        macro avg       0.94      0.93      0.93       126
#     weighted avg       0.94      0.94      0.94       126

# %% [markdown]
# # Export into LargeFewShotClassifier

# %%
#location of set fit model
SETFIT_MODEL_PATH = "./models/mtsamples_classifier"

#location of the exported ONNX version of the model
OUTPUT_PATH = "./models/mtsamples_classifier_onnx"

#location of the exported SparkNLP model
SPARKNLP_OUTPUT_PATH = "./models/sparknlp/mtsamples_classifier"



# !test -d $OUTPUT_PATH || mkdir $OUTPUT_PATH
# !test -d $SETFIT_MODEL_PATH || mkdir $SETFIT_MODEL_PATH

# !ls -l $OUTPUT_PATH
# Out:
# total 0

# %%
#load the underlying senternce embeddings model
ssent_emb = SentenceTransformer(SETFIT_MODEL_PATH)

#load set fit model
set_fit_model = setfit.SetFitModel.from_pretrained(SETFIT_MODEL_PATH)

#check if the classifier(head) is differentiable
set_fit_model.has_differentiable_head
# Out:
# False

# %%
#customized sentence embeddings model
class JSLSetFitEmbeddings(torch.nn.Module):
    def forward(self, input_ids, attention_mask):

        return self.sent_emb(input={"input_ids": input_ids, "attention_mask": attention_mask})["sentence_embedding"]

    def __init__(self, sent_emb):
        super().__init__()
        self.sent_emb = sent_emb

#customized classifier model
class JSLSetFitDifferentiableClassifier(torch.nn.Module):
    def forward(self, embeddings):
        return self.diff_classifier({"sentence_embedding": embeddings})["probs"]

    def __init__(self, diff_classifier):
        super().__init__()
        self.diff_classifier = diff_classifier

# %%
#load the underlying sentence embeddings model
ssent_emb = SentenceTransformer(SETFIT_MODEL_PATH)

#load tokeznier
tokenizer = transformers.AutoTokenizer.from_pretrained(SETFIT_MODEL_PATH)

#load customized sentence embeddings model
jsl_set_fit_embeddings = JSLSetFitEmbeddings(ssent_emb)

# %%
#dummy inputs for the embeddings model
dummy_input_ids = torch.ones(1, 5, requires_grad=False).int().to("cpu")
dummy_attention_mask = torch.ones(1, 5, requires_grad=False).int().to("cpu")
dummy_args = tuple([dummy_input_ids, dummy_attention_mask])

dynamic_axes = {
    'input_ids': {0: 'batch', 1: 'max_seq'},
    'attention_mask': {0: 'batch', 1: 'max_seq'}
}

# %%
#get the shape of the embeddings
sample_output_shape = jsl_set_fit_embeddings(input_ids = dummy_input_ids, attention_mask=dummy_attention_mask).shape

# %%
# Export the embeddings model to ONNX format
torch.onnx.export (
    jsl_set_fit_embeddings,
    (dummy_input_ids, dummy_attention_mask),
    f"{OUTPUT_PATH}/embeddings.onnx",
    input_names=['input_ids', 'attention_mask'],
    output_names=['embeddings'],
    opset_version=12,
    do_constant_folding=True,
    dynamic_axes=dynamic_axes,
    export_params=True,
    verbose=False
)
# Out:
# W0619 23:20:55.904000 7173 torch/onnx/_internal/exporter/_compat.py:133] Setting ONNX exporter to use operator set version 18 because the requested opset_version 12 is a lower version than we have implementations for. Automatic version conversion will be performed, which may not be successful at converting to the requested version. If version conversion is unsuccessful, the opset version of the exported model will be kept at 18. Please consider setting opset_version >=18 to leverage latest ONNX features
# WARNING:onnxscript.version_converter:The model version conversion is not supported by the onnxscript version converter and fallback is enabled. The model will be converted using the onnx C API (target version: 12).
# WARNING:onnxscript.version_converter:Failed to convert the model to the target version 12 using the ONNX C API. The model was not modified
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/onnxscript/version_converter/__init__.py", line 137, in call
#     converted_proto = _c_api_utils.call_onnx_api(
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/onnxscript/version_converter/_c_api_utils.py", line 65, in call_onnx_api
#     result = func(proto)
#              ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/onnxscript/version_converter/__init__.py", line 132, in _partial_convert_version
#     return onnx.version_converter.convert_version(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/onnx/version_converter.py", line 39, in convert_version
#     converted_model_str = C.convert_version(model_str, target_version)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: /project/onnx/version_converter/adapters/axes_input_to_attribute.h:56: adapt: Assertion `node->hasAttribute(kaxes)` failed: No initializer or constant input to node found
# ONNXProgram(
#     model=
#         <
#             ir_version=10,
#             opset_imports={'': 18},
#             producer_name='pytorch',
#             producer_version='2.11.0+cpu',
#             domain=None,
#             model_version=None,
#         >
#         graph(
#             name=main_graph,
#             inputs=(
#                 %"input_ids"<INT32,[batch,max_seq]>,
#                 %"attention_mask"<INT32,[batch,max_seq]>
#             ),
#             outputs=(
#                 %"embeddings"<FLOAT,[batch,768]>
#             ),
#             initializers=(
#                 %"sent_emb.0.model.embeddings.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.embeddings.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.0.attention.attn.q.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.0.attention.attn.k.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.0.attention.attn.v.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.0.attention.attn.o.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.0.attention.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.0.attention.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.0.output.dense.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.0.output.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.0.output.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.1.attention.attn.q.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.1.attention.attn.k.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.1.attention.attn.v.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.1.attention.attn.o.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.1.attention.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.1.attention.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.1.output.dense.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.1.output.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.1.output.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.2.attention.attn.q.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.2.attention.attn.k.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.2.attention.attn.v.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.2.attention.attn.o.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.2.attention.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.2.attention.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.2.output.dense.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.2.output.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.2.output.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.3.attention.attn.q.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.3.attention.attn.k.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.3.attention.attn.v.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.3.attention.attn.o.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.3.attention.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.3.attention.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.3.output.dense.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.3.output.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.3.output.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.4.attention.attn.q.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.4.attention.attn.k.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.4.attention.attn.v.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.4.attention.attn.o.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.4.attention.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.4.attention.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.4.output.dense.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.4.output.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.4.output.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.5.attention.attn.q.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.5.attention.attn.k.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.5.attention.attn.v.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.5.attention.attn.o.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.5.attention.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.5.attention.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.5.output.dense.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.5.output.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.5.output.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.6.attention.attn.q.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.6.attention.attn.k.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.6.attention.attn.v.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.6.attention.attn.o.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.6.attention.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.6.attention.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.6.output.dense.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.6.output.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.6.output.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.7.attention.attn.q.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.7.attention.attn.k.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.7.attention.attn.v.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.7.attention.attn.o.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.7.attention.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.7.attention.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.7.output.dense.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.7.output.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.7.output.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.8.attention.attn.q.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.8.attention.attn.k.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.8.attention.attn.v.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.8.attention.attn.o.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.8.attention.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.8.attention.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.8.output.dense.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.8.output.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.8.output.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.9.attention.attn.q.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.9.attention.attn.k.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.9.attention.attn.v.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.9.attention.attn.o.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.9.attention.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.9.attention.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.9.output.dense.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.9.output.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.9.output.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.10.attention.attn.q.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.10.attention.attn.k.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.10.attention.attn.v.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.10.attention.attn.o.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.10.attention.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.10.attention.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.10.output.dense.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.10.output.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.10.output.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.11.attention.attn.q.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.11.attention.attn.k.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.11.attention.attn.v.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.11.attention.attn.o.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.11.attention.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.11.attention.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.11.output.dense.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.11.output.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.11.output.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.relative_attention_bias.weight"<FLOAT,[32,12]>{TorchTensor(...)},
#                 %"sent_emb.0.model.embeddings.word_embeddings.weight"<FLOAT,[30527,768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.embeddings.position_embeddings.weight"<FLOAT,[514,768]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.0.intermediate.dense.bias"<FLOAT,[3072]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.1.intermediate.dense.bias"<FLOAT,[3072]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.2.intermediate.dense.bias"<FLOAT,[3072]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.3.intermediate.dense.bias"<FLOAT,[3072]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.4.intermediate.dense.bias"<FLOAT,[3072]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.5.intermediate.dense.bias"<FLOAT,[3072]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.6.intermediate.dense.bias"<FLOAT,[3072]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.7.intermediate.dense.bias"<FLOAT,[3072]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.8.intermediate.dense.bias"<FLOAT,[3072]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.9.intermediate.dense.bias"<FLOAT,[3072]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.10.intermediate.dense.bias"<FLOAT,[3072]>{TorchTensor(...)},
#                 %"sent_emb.0.model.encoder.layer.11.intermediate.dense.bias"<FLOAT,[3072]>{TorchTensor(...)},
#                 %"scalar_tensor_default"<INT32,[]>{Tensor<INT32,[]>(array(1, dtype=int32), name='scalar_tensor_default')},
#                 %"val_36"<INT64,[]>{Tensor<INT64,[]>(array(0), name='val_36')},
#                 %"val_37"<INT64,[]>{Tensor<INT64,[]>(array(1), name='val_37')},
#                 %"scalar_tensor_default_1"<FLOAT,[]>{Tensor<FLOAT,[]>(array(8., dtype=float32), name='scalar_tensor_default_1')},
#                 %"val_66"<INT64,[]>{Tensor<INT64,[]>(array(15), name='val_66')},
#                 %"val_74"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_82"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_90"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_104"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_108"<FLOAT,[768,3072]>{Tensor(...)},
#                 %"val_117"<FLOAT,[3072,768]>{Tensor(...)},
#                 %"val_121"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_129"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_137"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_150"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_154"<FLOAT,[768,3072]>{Tensor(...)},
#                 %"val_163"<FLOAT,[3072,768]>{Tensor(...)},
#                 %"val_167"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_175"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_183"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_196"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_200"<FLOAT,[768,3072]>{Tensor(...)},
#                 %"val_209"<FLOAT,[3072,768]>{Tensor(...)},
#                 %"val_213"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_221"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_229"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_242"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_246"<FLOAT,[768,3072]>{Tensor(...)},
#                 %"val_255"<FLOAT,[3072,768]>{Tensor(...)},
#                 %"val_259"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_267"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_275"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_288"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_292"<FLOAT,[768,3072]>{Tensor(...)},
#                 %"val_301"<FLOAT,[3072,768]>{Tensor(...)},
#                 %"val_305"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_313"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_321"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_334"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_338"<FLOAT,[768,3072]>{Tensor(...)},
#                 %"val_347"<FLOAT,[3072,768]>{Tensor(...)},
#                 %"val_351"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_359"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_367"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_380"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_384"<FLOAT,[768,3072]>{Tensor(...)},
#                 %"val_393"<FLOAT,[3072,768]>{Tensor(...)},
#                 %"val_397"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_405"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_413"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_426"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_430"<FLOAT,[768,3072]>{Tensor(...)},
#                 %"val_439"<FLOAT,[3072,768]>{Tensor(...)},
#                 %"val_443"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_451"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_459"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_472"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_476"<FLOAT,[768,3072]>{Tensor(...)},
#                 %"val_485"<FLOAT,[3072,768]>{Tensor(...)},
#                 %"val_489"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_497"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_505"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_518"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_522"<FLOAT,[768,3072]>{Tensor(...)},
#                 %"val_531"<FLOAT,[3072,768]>{Tensor(...)},
#                 %"val_535"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_543"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_551"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_564"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_568"<FLOAT,[768,3072]>{Tensor(...)},
#                 %"val_577"<FLOAT,[3072,768]>{Tensor(...)},
#                 %"val_581"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_589"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_597"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_610"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_614"<FLOAT,[768,3072]>{Tensor(...)},
#                 %"val_623"<FLOAT,[3072,768]>{Tensor(...)},
#                 %"val_636"<FLOAT,[]>{Tensor<FLOAT,[]>(array(1.e-09, dtype=float32), name='val_636')},
#                 %"val_638"<INT64,[1]>{Tensor<INT64,[1]>(array([1]), name='val_638')},
#                 %"val_640"<FLOAT,[]>{Tensor<FLOAT,[]>(array(1.e-12, dtype=float32), name='val_640')},
#                 %"val_645"<INT64,[2]>{Tensor<INT64,[2]>(array([1, 2]), name='val_645')},
#                 %"val_30"<FLOAT,[]>{Tensor<FLOAT,[]>(array(1., dtype=float32), name='val_30')},
#                 %"val_31"<FLOAT,[]>{Tensor<FLOAT,[]>(array(-3.4028235e+38, dtype=float32), name='val_31')},
#                 %"val_51"<INT64,[1]>{Tensor<INT64,[1]>(array([0]), name='val_51')},
#                 %"val_62"<INT64,[]>{Tensor<INT64,[]>(array(16), name='val_62')},
#                 %"val_63"<INT64,[]>{Tensor<INT64,[]>(array(8), name='val_63')},
#                 %"val_64"<FLOAT,[]>{Tensor<FLOAT,[]>(array(2.7725887, dtype=float32), name='val_64')},
#                 %"val_78"<INT64,[1]>{Tensor<INT64,[1]>(array([-1]), name='val_78')},
#                 %"val_79"<INT64,[1]>{Tensor<INT64,[1]>(array([12]), name='val_79')},
#                 %"val_80"<INT64,[1]>{Tensor<INT64,[1]>(array([64]), name='val_80')},
#                 %"val_102"<INT64,[1]>{Tensor<INT64,[1]>(array([768]), name='val_102')},
#                 %"val_110"<FLOAT,[]>{Tensor<FLOAT,[]>(array(1.4142135, dtype=float32), name='val_110')},
#                 %"val_115"<FLOAT,[]>{Tensor<FLOAT,[]>(array(0.5, dtype=float32), name='val_115')}
#             ),
#         ) {
#               0 |  # node_Shape_2
#                    %"val_2"<INT64,[1]> ⬅️ ::Shape(%"attention_mask") {end=1, start=0}
#               1 |  # node_Shape_3
#                    %"val_3"<INT64,[1]> ⬅️ ::Shape(%"attention_mask") {end=2, start=1}
#               2 |  # node_sym_size_int_51
#                    %"sym_size_int_51"<INT64,[]> ⬅️ ::Squeeze(%"val_3")
#               3 |  # node_Unsqueeze_618
#                    %"unsqueeze_1"<INT32,[batch,1,1,max_seq]> ⬅️ ::Unsqueeze(%"attention_mask", %"val_645"{[1, 2]})
#               4 |  # node__to_copy
#                    %"_to_copy"<FLOAT,[batch,1,1,max_seq]> ⬅️ ::Cast(%"unsqueeze_1") {to=1}
#               5 |  # node_sub_10
#                    %"sub_10"<FLOAT,[batch,1,1,max_seq]> ⬅️ ::Sub(%"val_30"{1.0}, %"_to_copy")
#               6 |  # node_mul_21
#                    %"mul_21"<FLOAT,[batch,1,1,max_seq]> ⬅️ ::Mul(%"sub_10", %"val_31"{-3.4028234663852886e+38})
#               7 |  # node_Equal_32
#                    %"val_32"<BOOL,[batch,max_seq]> ⬅️ ::Equal(%"input_ids", %"scalar_tensor_default"{1})
#               8 |  # node_ne
#                    %"ne"<BOOL,[batch,max_seq]> ⬅️ ::Not(%"val_32")
#               9 |  # node__to_copy_1
#                    %"_to_copy_1"<INT32,[batch,max_seq]> ⬅️ ::Cast(%"ne") {to=6}
#              10 |  # node_convert_element_type_default
#                    %"convert_element_type_default"<INT64,[batch,max_seq]> ⬅️ ::Cast(%"_to_copy_1") {to=7}
#              11 |  # node_cumsum
#                    %"cumsum"<INT64,[batch,max_seq]> ⬅️ ::CumSum(%"convert_element_type_default", %"val_37"{1}) {reverse=0, exclusive=0}
#              12 |  # node_type_as
#                    %"type_as"<INT32,[batch,max_seq]> ⬅️ ::Cast(%"cumsum") {to=6}
#              13 |  # node_mul_33
#                    %"mul_33"<INT32,[batch,max_seq]> ⬅️ ::Mul(%"type_as", %"_to_copy_1")
#              14 |  # node__to_copy_2
#                    %"_to_copy_2"<INT64,[batch,max_seq]> ⬅️ ::Cast(%"mul_33") {to=7}
#              15 |  # node_add_50
#                    %"add_50"<INT64,[batch,max_seq]> ⬅️ ::Add(%"_to_copy_2", %"val_37"{1})
#              16 |  # node_embedding
#                    %"embedding"<FLOAT,[batch,max_seq,768]> ⬅️ ::Gather(%"sent_emb.0.model.embeddings.word_embeddings.weight"{...}, %"input_ids") {axis=0}
#              17 |  # node_embedding_1
#                    %"embedding_1"<FLOAT,[batch,max_seq,768]> ⬅️ ::Gather(%"sent_emb.0.model.embeddings.position_embeddings.weight"{...}, %"add_50") {axis=0}
#              18 |  # node_add_62
#                    %"add_62"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"embedding", %"embedding_1")
#              19 |  # node_layer_norm
#                    %"layer_norm"<FLOAT,[batch,max_seq,768]> ⬅️ ::LayerNormalization(%"add_62", %"sent_emb.0.model.embeddings.LayerNorm.weight"{...}, %"sent_emb.0.model.embeddings.LayerNorm.bias"{...}) {stash_type=1, epsilon=1e-05, axis=-1}
#              20 |  # node_arange
#                    %"arange"<INT64,[max_seq]> ⬅️ ::Range(%"val_36"{0}, %"sym_size_int_51", %"val_37"{1})
#              21 |  # node_unsqueeze_2
#                    %"unsqueeze_2"<INT64,[max_seq,1]> ⬅️ ::Unsqueeze(%"arange", %"val_638"{[1]})
#              22 |  # node_unsqueeze_3
#                    %"unsqueeze_3"<INT64,[1,max_seq]> ⬅️ ::Unsqueeze(%"arange", %"val_51"{[0]})
#              23 |  # node_sub_45
#                    %"sub_45"<INT64,[max_seq,max_seq]> ⬅️ ::Sub(%"unsqueeze_3", %"unsqueeze_2")
#              24 |  # node_neg
#                    %"neg"<INT64,[max_seq,max_seq]> ⬅️ ::Neg(%"sub_45")
#              25 |  # node_lt
#                    %"lt"<BOOL,[max_seq,max_seq]> ⬅️ ::Less(%"neg", %"val_36"{0})
#              26 |  # node__to_copy_3
#                    %"_to_copy_3"<INT64,[max_seq,max_seq]> ⬅️ ::Cast(%"lt") {to=7}
#              27 |  # node_mul_70
#                    %"mul_70"<INT64,[max_seq,max_seq]> ⬅️ ::Mul(%"_to_copy_3", %"val_62"{16})
#              28 |  # node_abs_1
#                    %"abs_1"<INT64,[max_seq,max_seq]> ⬅️ ::Abs(%"neg")
#              29 |  # node_lt_1
#                    %"lt_1"<BOOL,[max_seq,max_seq]> ⬅️ ::Less(%"abs_1", %"val_63"{8})
#              30 |  # node__to_copy_4
#                    %"_to_copy_4"<FLOAT,[max_seq,max_seq]> ⬅️ ::Cast(%"abs_1") {to=1}
#              31 |  # node_div
#                    %"div"<FLOAT,[max_seq,max_seq]> ⬅️ ::Div(%"_to_copy_4", %"scalar_tensor_default_1"{8.0})
#              32 |  # node_log
#                    %"log"<FLOAT,[max_seq,max_seq]> ⬅️ ::Log(%"div")
#              33 |  # node_div_1
#                    %"div_1"<FLOAT,[max_seq,max_seq]> ⬅️ ::Div(%"log", %"val_64"{2.7725887298583984})
#              34 |  # node_mul_86
#                    %"mul_86"<FLOAT,[max_seq,max_seq]> ⬅️ ::Mul(%"div_1", %"scalar_tensor_default_1"{8.0})
#              35 |  # node__to_copy_5
#                    %"_to_copy_5"<INT64,[max_seq,max_seq]> ⬅️ ::Cast(%"mul_86") {to=7}
#              36 |  # node_add_131
#                    %"add_131"<INT64,[max_seq,max_seq]> ⬅️ ::Add(%"_to_copy_5", %"val_63"{8})
#              37 |  # node_Shape_65
#                    %"val_67"<INT64,[2]> ⬅️ ::Shape(%"add_131") {start=0}
#              38 |  # node_full_like
#                    %"full_like"<INT64,[max_seq,max_seq]> ⬅️ ::Expand(%"val_66"{15}, %"val_67")
#              39 |  # node_minimum
#                    %"minimum"<INT64,[max_seq,max_seq]> ⬅️ ::Min(%"add_131", %"full_like")
#              40 |  # node_where
#                    %"where"<INT64,[max_seq,max_seq]> ⬅️ ::Where(%"lt_1", %"abs_1", %"minimum")
#              41 |  # node_add_150
#                    %"add_150"<INT64,[max_seq,max_seq]> ⬅️ ::Add(%"mul_70", %"where")
#              42 |  # node_embedding_2
#                    %"embedding_2"<FLOAT,[max_seq,max_seq,12]> ⬅️ ::Gather(%"sent_emb.0.model.encoder.relative_attention_bias.weight"{...}, %"add_150") {axis=0}
#              43 |  # node_permute
#                    %"permute"<FLOAT,[12,max_seq,max_seq]> ⬅️ ::Transpose(%"embedding_2") {perm=(2, 0, 1)}
#              44 |  # node_unsqueeze_4
#                    %"unsqueeze_4"<FLOAT,[1,12,max_seq,max_seq]> ⬅️ ::Unsqueeze(%"permute", %"val_51"{[0]})
#              45 |  # node_Concat_71
#                    %"val_73"<INT64,[4]> ⬅️ ::Concat(%"val_2", %"val_638"{[1]}, %"val_3", %"val_3") {axis=0}
#              46 |  # node_expand
#                    %"expand"<FLOAT,[batch,12,max_seq,max_seq]> ⬅️ ::Expand(%"unsqueeze_4", %"val_73")
#              47 |  # node_MatMul_73
#                    %"val_75"<FLOAT,[batch,max_seq,768]> ⬅️ ::MatMul(%"layer_norm", %"val_74"{...})
#              48 |  # node_linear
#                    %"linear"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"val_75", %"sent_emb.0.model.encoder.layer.0.attention.attn.q.bias"{...})
#              49 |  # node_Concat_79
#                    %"val_81"<INT64,[4]> ⬅️ ::Concat(%"val_2", %"val_78"{[-1]}, %"val_79"{[12]}, %"val_80"{[64]}) {axis=0}
#              50 |  # node_view
#                    %"view"<FLOAT,[batch,max_seq,12,64]> ⬅️ ::Reshape(%"linear", %"val_81") {allowzero=1}
#              51 |  # node_transpose
#                    %"transpose"<FLOAT,[batch,12,max_seq,64]> ⬅️ ::Transpose(%"view") {perm=(0, 2, 1, 3)}
#              52 |  # node_MatMul_81
#                    %"val_83"<FLOAT,[batch,max_seq,768]> ⬅️ ::MatMul(%"layer_norm", %"val_82"{...})
#              53 |  # node_linear_1
#                    %"linear_1"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"val_83", %"sent_emb.0.model.encoder.layer.0.attention.attn.k.bias"{...})
#              54 |  # node_view_1
#                    %"view_1"<FLOAT,[batch,max_seq,12,64]> ⬅️ ::Reshape(%"linear_1", %"val_81") {allowzero=1}
#              55 |  # node_MatMul_89
#                    %"val_91"<FLOAT,[batch,max_seq,768]> ⬅️ ::MatMul(%"layer_norm", %"val_90"{...})
#              56 |  # node_linear_2
#                    %"linear_2"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"val_91", %"sent_emb.0.model.encoder.layer.0.attention.attn.v.bias"{...})
#              57 |  # node_view_2
#                    %"view_2"<FLOAT,[batch,max_seq,12,64]> ⬅️ ::Reshape(%"linear_2", %"val_81") {allowzero=1}
#              58 |  # node_transpose_2
#                    %"transpose_2"<FLOAT,[batch,12,max_seq,64]> ⬅️ ::Transpose(%"view_2") {perm=(0, 2, 1, 3)}
#              59 |  # node_Transpose_629
#                    %"transpose_3"<FLOAT,[batch,12,64,max_seq]> ⬅️ ::Transpose(%"view_1") {perm=(0, 2, 3, 1)}
#              60 |  # node_matmul
#                    %"matmul"<FLOAT,[batch,12,max_seq,max_seq]> ⬅️ ::MatMul(%"transpose", %"transpose_3")
#              61 |  # node_div_2
#                    %"div_2"<FLOAT,[batch,12,max_seq,max_seq]> ⬅️ ::Div(%"matmul", %"scalar_tensor_default_1"{8.0})
#              62 |  # node_add_239
#                    %"add_239"<FLOAT,[batch,12,max_seq,max_seq]> ⬅️ ::Add(%"div_2", %"expand")
#              63 |  # node_add_245
#                    %"add_245"<FLOAT,[batch,12,max_seq,max_seq]> ⬅️ ::Add(%"add_239", %"mul_21")
#              64 |  # node_softmax
#                    %"softmax"<FLOAT,[batch,12,max_seq,max_seq]> ⬅️ ::Softmax(%"add_245") {axis=-1}
#              65 |  # node_matmul_1
#                    %"matmul_1"<FLOAT,[batch,12,max_seq,64]> ⬅️ ::MatMul(%"softmax", %"transpose_2")
#              66 |  # node_permute_1
#                    %"permute_1"<FLOAT,[batch,max_seq,12,64]> ⬅️ ::Transpose(%"matmul_1") {perm=(0, 2, 1, 3)}
#              67 |  # node_Concat_101
#                    %"val_103"<INT64,[3]> ⬅️ ::Concat(%"val_2", %"val_3", %"val_102"{[768]}) {axis=0}
#              68 |  # node_view_3
#                    %"view_3"<FLOAT,[batch,max_seq,768]> ⬅️ ::Reshape(%"permute_1", %"val_103") {allowzero=1}
#              69 |  # node_MatMul_103
#                    %"val_105"<FLOAT,[batch,max_seq,768]> ⬅️ ::MatMul(%"view_3", %"val_104"{...})
#              70 |  # node_linear_3
#                    %"linear_3"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"val_105", %"sent_emb.0.model.encoder.layer.0.attention.attn.o.bias"{...})
#              71 |  # node_add_288
#                    %"add_288"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"linear_3", %"layer_norm")
#              72 |  # node_layer_norm_1
#                    %"layer_norm_1"<FLOAT,[batch,max_seq,768]> ⬅️ ::LayerNormalization(%"add_288", %"sent_emb.0.model.encoder.layer.0.attention.LayerNorm.weight"{...}, %"sent_emb.0.model.encoder.layer.0.attention.LayerNorm.bias"{...}) {stash_type=1, epsilon=1e-05, axis=-1}
#              73 |  # node_MatMul_105
#                    %"val_109"<FLOAT,[batch,max_seq,3072]> ⬅️ ::MatMul(%"layer_norm_1", %"val_108"{...})
#              74 |  # node_linear_4
#                    %"linear_4"<FLOAT,[batch,max_seq,3072]> ⬅️ ::Add(%"val_109", %"sent_emb.0.model.encoder.layer.0.intermediate.dense.bias"{...})
#              75 |  # node_Div_107
#                    %"val_111"<FLOAT,[batch,max_seq,3072]> ⬅️ ::Div(%"linear_4", %"val_110"{1.4142135381698608})
#              76 |  # node_Erf_108
#                    %"val_112"<FLOAT,[batch,max_seq,3072]> ⬅️ ::Erf(%"val_111")
#              77 |  # node_Add_110
#                    %"val_114"<FLOAT,[batch,max_seq,3072]> ⬅️ ::Add(%"val_112", %"val_30"{1.0})
#              78 |  # node_Mul_112
#                    %"val_116"<FLOAT,[batch,max_seq,3072]> ⬅️ ::Mul(%"val_115"{0.5}, %"val_114")
#              79 |  # node_gelu
#                    %"gelu"<FLOAT,[batch,max_seq,3072]> ⬅️ ::Mul(%"linear_4", %"val_116")
#              80 |  # node_MatMul_114
#                    %"val_118"<FLOAT,[batch,max_seq,768]> ⬅️ ::MatMul(%"gelu", %"val_117"{...})
#              81 |  # node_linear_5
#                    %"linear_5"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"val_118", %"sent_emb.0.model.encoder.layer.0.output.dense.bias"{...})
#              82 |  # node_add_313
#                    %"add_313"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"linear_5", %"layer_norm_1")
#              83 |  # node_layer_norm_2
#                    %"layer_norm_2"<FLOAT,[batch,max_seq,768]> ⬅️ ::LayerNormalization(%"add_313", %"sent_emb.0.model.encoder.layer.0.output.LayerNorm.weight"{...}, %"sent_emb.0.model.encoder.layer.0.output.LayerNorm.bias"{...}) {stash_type=1, epsilon=1e-05, axis=-1}
#              84 |  # node_MatMul_116
#                    %"val_122"<FLOAT,[batch,max_seq,768]> ⬅️ ::MatMul(%"layer_norm_2", %"val_121"{...})
#              85 |  # node_linear_6
#                    %"linear_6"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"val_122", %"sent_emb.0.model.encoder.layer.1.attention.attn.q.bias"{...})
#              86 |  # node_view_4
#                    %"view_4"<FLOAT,[batch,max_seq,12,64]> ⬅️ ::Reshape(%"linear_6", %"val_81") {allowzero=1}
#              87 |  # node_transpose_4
#                    %"transpose_4"<FLOAT,[batch,12,max_seq,64]> ⬅️ ::Transpose(%"view_4") {perm=(0, 2, 1, 3)}
#              88 |  # node_MatMul_124
#                    %"val_130"<FLOAT,[batch,max_seq,768]> ⬅️ ::MatMul(%"layer_norm_2", %"val_129"{...})
#              89 |  # node_linear_7
#                    %"linear_7"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"val_130", %"sent_emb.0.model.encoder.layer.1.attention.attn.k.bias"{...})
#              90 |  # node_view_5
#                    %"view_5"<FLOAT,[batch,max_seq,12,64]> ⬅️ ::Reshape(%"linear_7", %"val_81") {allowzero=1}
#              91 |  # node_MatMul_132
#                    %"val_138"<FLOAT,[batch,max_seq,768]> ⬅️ ::MatMul(%"layer_norm_2", %"val_137"{...})
#              92 |  # node_linear_8
#                    %"linear_8"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"val_138", %"sent_emb.0.model.encoder.layer.1.attention.attn.v.bias"{...})
#              93 |  # node_view_6
#                    %"view_6"<FLOAT,[batch,max_seq,12,64]> ⬅️ ::Reshape(%"linear_8", %"val_81") {allowzero=1}
#              94 |  # node_transpose_6
#                    %"transpose_6"<FLOAT,[batch,12,max_seq,64]> ⬅️ ::Transpose(%"view_6") {perm=(0, 2, 1, 3)}
#              95 |  # node_Transpose_635
#                    %"transpose_7"<FLOAT,[batch,12,64,max_seq]> ⬅️ ::Transpose(%"view_5") {perm=(0, 2, 3, 1)}
#              96 |  # node_matmul_2
#                    %"matmul_2"<FLOAT,[batch,12,max_seq,max_seq]> ⬅️ ::MatMul(%"transpose_4", %"transpose_7")
#              97 |  # node_div_3
#                    %"div_3"<FLOAT,[batch,12,max_seq,max_seq]> ⬅️ ::Div(%"matmul_2", %"scalar_tensor_default_1"{8.0})
#              98 |  # node_add_389
#                    %"add_389"<FLOAT,[batch,12,max_seq,max_seq]> ⬅️ ::Add(%"div_3", %"expand")
#              99 |  # node_add_395
#                    %"add_395"<FLOAT,[batch,12,max_seq,max_seq]> ⬅️ ::Add(%"add_389", %"mul_21")
#             100 |  # node_softmax_1
#                    %"softmax_1"<FLOAT,[batch,12,max_seq,max_seq]> ⬅️ ::Softmax(%"add_395") {axis=-1}
#             101 |  # node_matmul_3
#                    %"matmul_3"<FLOAT,[batch,12,max_seq,64]> ⬅️ ::MatMul(%"softmax_1", %"transpose_6")
#             102 |  # node_permute_2
#                    %"permute_2"<FLOAT,[batch,max_seq,12,64]> ⬅️ ::Transpose(%"matmul_3") {perm=(0, 2, 1, 3)}
#             103 |  # node_view_7
#                    %"view_7"<FLOAT,[batch,max_seq,768]> ⬅️ ::Reshape(%"permute_2", %"val_103") {allowzero=1}
#             104 |  # node_MatMul_145
#                    %"val_151"<FLOAT,[batch,max_seq,768]> ⬅️ ::MatMul(%"view_7", %"val_150"{...})
#             105 |  # node_linear_9
#                    %"linear_9"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"val_151", %"sent_emb.0.model.encoder.layer.1.attention.attn.o.bias"{...})
#             106 |  # node_add_438
#                    %"add_438"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"linear_9", %"layer_norm_2")
#             107 |  # node_layer_norm_3
#                    %"layer_norm_3"<FLOAT,[batch,max_seq,768]> ⬅️ ::LayerNormalization(%"add_438", %"sent_emb.0.model.encoder.layer.1.attention.LayerNorm.weight"{...}, %"sent_emb.0.model.encoder.layer.1.attention.LayerNorm.bias"{...}) {stash_type=1, epsilon=1e-05, axis=-1}
#             108 |  # node_MatMul_147
#                    %"val_155"<FLOAT,[batch,max_seq,3072]> ⬅️ ::MatMul(%"layer_norm_3", %"val_154"{...})
#             109 |  # node_linear_10
#                    %"linear_10"<FLOAT,[batch,max_seq,3072]> ⬅️ ::Add(%"val_155", %"sent_emb.0.model.encoder.layer.1.intermediate.dense.bias"{...})
#             110 |  # node_Div_149
#                    %"val_157"<FLOAT,[batch,max_seq,3072]> ⬅️ ::Div(%"linear_10", %"val_110"{1.4142135381698608})
#             111 |  # node_Erf_150
#                    %"val_158"<FLOAT,[batch,max_seq,3072]> ⬅️ ::Erf(%"val_157")
#             112 |  # node_Add_152
#                    %"val_160"<FLOAT,[batch,max_seq,3072]> ⬅️ ::Add(%"val_158", %"val_30"{1.0})
#             113 |  # node_Mul_154
#                    %"val_162"<FLOAT,[batch,max_seq,3072]> ⬅️ ::Mul(%"val_115"{0.5}, %"val_160")
#             114 |  # node_gelu_1
#                    %"gelu_1"<FLOAT,[batch,max_seq,3072]> ⬅️ ::Mul(%"linear_10", %"val_162")
#             115 |  # node_MatMul_156
#                    %"val_164"<FLOAT,[batch,max_seq,768]> ⬅️ ::MatMul(%"gelu_1", %"val_163"{...})
#             116 |  # node_linear_11
#                    %"linear_11"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"val_164", %"sent_emb.0.model.encoder.layer.1.output.dense.bias"{...})
#             117 |  # node_add_463
#                    %"add_463"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"linear_11", %"layer_norm_3")
#             118 |  # node_layer_norm_4
#                    %"layer_norm_4"<FLOAT,[batch,max_seq,768]> ⬅️ ::LayerNormalization(%"add_463", %"sent_emb.0.model.encoder.layer.1.output.LayerNorm.weight"{...}, %"sent_emb.0.model.encoder.layer.1.output.LayerNorm.bias"{...}) {stash_type=1, epsilon=1e-05, axis=-1}
#             119 |  # node_MatMul_158
#                    %"val_168"<FLOAT,[batch,max_seq,768]> ⬅️ ::MatMul(%"layer_norm_4", %"val_167"{...})
#             120 |  # node_linear_12
#                    %"linear_12"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"val_168", %"sent_emb.0.model.encoder.layer.2.attention.attn.q.bias"{...})
#             121 |  # node_view_8
#                    %"view_8"<FLOAT,[batch,max_seq,12,64]> ⬅️ ::Reshape(%"linear_12", %"val_81") {allowzero=1}
#             122 |  # node_transpose_8
#                    %"transpose_8"<FLOAT,[batch,12,max_seq,64]> ⬅️ ::Transpose(%"view_8") {perm=(0, 2, 1, 3)}
#             123 |  # node_MatMul_166
#                    %"val_176"<FLOAT,[batch,max_seq,768]> ⬅️ ::MatMul(%"layer_norm_4", %"val_175"{...})
#             124 |  # node_linear_13
#                    %"linear_13"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"val_176", %"sent_emb.0.model.encoder.layer.2.attention.attn.k.bias"{...})
#             125 |  # node_view_9
#                    %"view_9"<FLOAT,[batch,max_seq,12,64]> ⬅️ ::Reshape(%"linear_13", %"val_81") {allowzero=1}
#             126 |  # node_MatMul_174
#                    %"val_184"<FLOAT,[batch,max_seq,768]> ⬅️ ::MatMul(%"layer_norm_4", %"val_183"{...})
#             127 |  # node_linear_14
#                    %"linear_14"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"val_184", %"sent_emb.0.model.encoder.layer.2.attention.attn.v.bias"{...})
#             128 |  # node_view_10
#                    %"view_10"<FLOAT,[batch,max_seq,12,64]> ⬅️ ::Reshape(%"linear_14", %"val_81") {allowzero=1}
#             129 |  # node_transpose_10
#                    %"transpose_10"<FLOAT,[batch,12,max_seq,64]> ⬅️ ::Transpose(%"view_10") {perm=(0, 2, 1, 3)}
#             130 |  # node_Transpose_641
#                    %"transpose_11"<FLOAT,[batch,12,64,max_seq]> ⬅️ ::Transpose(%"view_9") {perm=(0, 2, 3, 1)}
#             131 |  # node_matmul_4
#                    %"matmul_4"<FLOAT,[batch,12,max_seq,max_seq]> ⬅️ ::MatMul(%"transpose_8", %"transpose_11")
#             132 |  # node_div_4
#                    %"div_4"<FLOAT,[batch,12,max_seq,max_seq]> ⬅️ ::Div(%"matmul_4", %"scalar_tensor_default_1"{8.0})
#             133 |  # node_add_539
#                    %"add_539"<FLOAT,[batch,12,max_seq,max_seq]> ⬅️ ::Add(%"div_4", %"expand")
#             134 |  # node_add_545
#                    %"add_545"<FLOAT,[batch,12,max_seq,max_seq]> ⬅️ ::Add(%"add_539", %"mul_21")
#             135 |  # node_softmax_2
#                    %"softmax_2"<FLOAT,[batch,12,max_seq,max_seq]> ⬅️ ::Softmax(%"add_545") {axis=-1}
#             136 |  # node_matmul_5
#                    %"matmul_5"<FLOAT,[batch,12,max_seq,64]> ⬅️ ::MatMul(%"softmax_2", %"transpose_10")
#             137 |  # node_permute_3
#                    %"permute_3"<FLOAT,[batch,max_seq,12,64]> ⬅️ ::Transpose(%"matmul_5") {perm=(0, 2, 1, 3)}
#             138 |  # node_view_11
#                    %"view_11"<FLOAT,[batch,max_seq,768]> ⬅️ ::Reshape(%"permute_3", %"val_103") {allowzero=1}
#             139 |  # node_MatMul_187
#                    %"val_197"<FLOAT,[batch,max_seq,768]> ⬅️ ::MatMul(%"view_11", %"val_196"{...})
#             140 |  # node_linear_15
#                    %"linear_15"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"val_197", %"sent_emb.0.model.encoder.layer.2.attention.attn.o.bias"{...})
#             141 |  # node_add_588
#                    %"add_588"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"linear_15", %"layer_norm_4")
#             142 |  # node_layer_norm_5
#                    %"layer_norm_5"<FLOAT,[batch,max_seq,768]> ⬅️ ::LayerNormalization(%"add_588", %"sent_emb.0.model.encoder.layer.2.attention.LayerNorm.weight"{...}, %"sent_emb.0.model.encoder.layer.2.attention.LayerNorm.bias"{...}) {stash_type=1, epsilon=1e-05, axis=-1}
#             143 |  # node_MatMul_189
#                    %"val_201"<FLOAT,[batch,max_seq,3072]> ⬅️ ::MatMul(%"layer_norm_5", %"val_200"{...})
#             144 |  # node_linear_16
#                    %"linear_16"<FLOAT,[batch,max_seq,3072]> ⬅️ ::Add(%"val_201", %"sent_emb.0.model.encoder.layer.2.intermediate.dense.bias"{...})
#             145 |  # node_Div_191
#                    %"val_203"<FLOAT,[batch,max_seq,3072]> ⬅️ ::Div(%"linear_16", %"val_110"{1.4142135381698608})
#             146 |  # node_Erf_192
#                    %"val_204"<FLOAT,[batch,max_seq,3072]> ⬅️ ::Erf(%"val_203")
#             147 |  # node_Add_194
#                    %"val_206"<FLOAT,[batch,max_seq,3072]> ⬅️ ::Add(%"val_204", %"val_30"{1.0})
#             148 |  # node_Mul_196
#                    %"val_208"<FLOAT,[batch,max_seq,3072]> ⬅️ ::Mul(%"val_115"{0.5}, %"val_206")
#             149 |  # node_gelu_2
#                    %"gelu_2"<FLOAT,[batch,max_seq,3072]> ⬅️ ::Mul(%"linear_16", %"val_208")
#             150 |  # node_MatMul_198
#                    %"val_210"<FLOAT,[batch,max_seq,768]> ⬅️ ::MatMul(%"gelu_2", %"val_209"{...})
#             151 |  # node_linear_17
#                    %"linear_17"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"val_210", %"sent_emb.0.model.encoder.layer.2.output.dense.bias"{...})
#             152 |  # node_add_613
#                    %"add_613"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"linear_17", %"layer_norm_5")
#             153 |  # node_layer_norm_6
#                    %"layer_norm_6"<FLOAT,[batch,max_seq,768]> ⬅️ ::LayerNormalization(%"add_613", %"sent_emb.0.model.encoder.layer.2.output.LayerNorm.weight"{...}, %"sent_emb.0.model.encoder.layer.2.output.LayerNorm.bias"{...}) {stash_type=1, epsilon=1e-05, axis=-1}
#             154 |  # node_MatMul_200
#                    %"val_214"<FLOAT,[batch,max_seq,768]> ⬅️ ::MatMul(%"layer_norm_6", %"val_213"{...})
#             155 |  # node_linear_18
#                    %"linear_18"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"val_214", %"sent_emb.0.model.encoder.layer.3.attention.attn.q.bias"{...})
#             156 |  # node_view_12
#                    %"view_12"<FLOAT,[batch,max_seq,12,64]> ⬅️ ::Reshape(%"linear_18", %"val_81") {allowzero=1}
#             157 |  # node_transpose_12
#                    %"transpose_12"<FLOAT,[batch,12,max_seq,64]> ⬅️ ::Transpose(%"view_12") {perm=(0, 2, 1, 3)}
#             158 |  # node_MatMul_208
#                    %"val_222"<FLOAT,[batch,max_seq,768]> ⬅️ ::MatMul(%"layer_norm_6", %"val_221"{...})
#             159 |  # node_linear_19
#                    %"linear_19"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"val_222", %"sent_emb.0.model.encoder.layer.3.attention.attn.k.bias"{...})
#             160 |  # node_view_13
#                    %"view_13"<FLOAT,[batch,max_seq,12,64]> ⬅️ ::Reshape(%"linear_19", %"val_81") {allowzero=1}
#             161 |  # node_MatMul_216
#                    %"val_230"<FLOAT,[batch,max_seq,768]> ⬅️ ::MatMul(%"layer_norm_6", %"val_229"{...})
#             162 |  # node_linear_20
#                    %"linear_20"<FLOAT,[batch,max_seq,768]> ⬅️ ::Add(%"val_230", %"sent_emb.0.model.encoder.layer.3.attention.attn.v.bias"{...})
#             163 |  # node_view_14
#                    %"view_14"<FLOAT,[batch,max_seq,12,64]> ⬅️ ::Reshape(%"linear_20", %"val_81") {allowzero=1}
#             164 |  # node_transpose_14
#                    %"transpose_14"<FLOAT,[batch,12,max_seq,64]> ⬅️ ::Transpose(%"view_14") {perm=(0, 2, 1, 3)}
#             165 |  # node_Transpose_647
#                    %"transpose_15"<FLOAT,[batch,12,64,max_seq]> ⬅️ ::Transpose(%"view_13") {perm=(0, 2, 3, 1)}
#             166 |  # node_matmul_6
#                    %"matmul_6"<FLOAT,[batch,12,max_seq,max_seq]> ⬅️ ::MatMul(%"transpose_12", %"transpose_15")
#             167 |  # node_div_5
#                    %"div_5"<FLOAT,[batch,12,max_seq,max_seq]> ⬅️ ::Div(%"matmul_6", %"scalar_tensor_default_1"{8.0})
#             168 |  # node_add_689
#                    %"add_689"<FLOAT,[batch,12,max_seq,max_seq]> ⬅️ ::Add(%"div_5", %"expand")
#             169 |  # node_add_695
#                    %"add_695"<FLOAT,[batch,12,max_seq,max_seq]> ⬅️ ::Add(%"add_689", %"mul_21")
#             170 |  # node_softmax_3
#                    %"softmax_3"<FLOAT,[batch,12,max_seq,max_seq]> ⬅️ ::Softmax(%"add_695") {axis=-1}
#             171 |  # node_matmul_7
#                    %"matmul_7"<FLOAT,[batch,12,max_seq,64]> ⬅️ ::MatMul(%"softmax_3", %"transpose_14")
#             172 |  # node_permute_4
#                    %"permute_4"<FLOAT,[batch,max_seq,12,64]> ⬅️ ::Transpose(%"matmul_7") {perm=(0, 2, 1, 3)}
#             173 |  # node_view_15
#                    %"view_15"<FLOAT,[batch,max_seq,768]> ⬅️ ::Reshape(%"permute_4", %"val_103") {allowzero=1}
#             174 |  # node_MatMul_229
#                    %"val_243"<FLOAT,[batch,max_seq,768]> ⬅️ ::MatMul(%"view_15", %"val_242"{...})
#             175 |  # node_linear_21
# ...
#             p_sent_emb_0_model_encoder_layer_5_attention_layernorm_weight: PARAMETER target='sent_emb.0.model.encoder.layer.5.attention.LayerNorm.weight'
#             p_sent_emb_0_model_encoder_layer_5_attention_layernorm_bias: PARAMETER target='sent_emb.0.model.encoder.layer.5.attention.LayerNorm.bias'
#             p_sent_emb_0_model_encoder_layer_5_intermediate_dense_weight: PARAMETER target='sent_emb.0.model.encoder.layer.5.intermediate.dense.weight'
#             p_sent_emb_0_model_encoder_layer_5_intermediate_dense_bias: PARAMETER target='sent_emb.0.model.encoder.layer.5.intermediate.dense.bias'
#             p_sent_emb_0_model_encoder_layer_5_output_dense_weight: PARAMETER target='sent_emb.0.model.encoder.layer.5.output.dense.weight'
#             p_sent_emb_0_model_encoder_layer_5_output_dense_bias: PARAMETER target='sent_emb.0.model.encoder.layer.5.output.dense.bias'
#             p_sent_emb_0_model_encoder_layer_5_output_layernorm_weight: PARAMETER target='sent_emb.0.model.encoder.layer.5.output.LayerNorm.weight'
#             p_sent_emb_0_model_encoder_layer_5_output_layernorm_bias: PARAMETER target='sent_emb.0.model.encoder.layer.5.output.LayerNorm.bias'
#             p_sent_emb_0_model_encoder_layer_6_attention_attn_q_weight: PARAMETER target='sent_emb.0.model.encoder.layer.6.attention.attn.q.weight'
#             p_sent_emb_0_model_encoder_layer_6_attention_attn_q_bias: PARAMETER target='sent_emb.0.model.encoder.layer.6.attention.attn.q.bias'
#             p_sent_emb_0_model_encoder_layer_6_attention_attn_k_weight: PARAMETER target='sent_emb.0.model.encoder.layer.6.attention.attn.k.weight'
#             p_sent_emb_0_model_encoder_layer_6_attention_attn_k_bias: PARAMETER target='sent_emb.0.model.encoder.layer.6.attention.attn.k.bias'
#             p_sent_emb_0_model_encoder_layer_6_attention_attn_v_weight: PARAMETER target='sent_emb.0.model.encoder.layer.6.attention.attn.v.weight'
#             p_sent_emb_0_model_encoder_layer_6_attention_attn_v_bias: PARAMETER target='sent_emb.0.model.encoder.layer.6.attention.attn.v.bias'
#             p_sent_emb_0_model_encoder_layer_6_attention_attn_o_weight: PARAMETER target='sent_emb.0.model.encoder.layer.6.attention.attn.o.weight'
#             p_sent_emb_0_model_encoder_layer_6_attention_attn_o_bias: PARAMETER target='sent_emb.0.model.encoder.layer.6.attention.attn.o.bias'
#             p_sent_emb_0_model_encoder_layer_6_attention_layernorm_weight: PARAMETER target='sent_emb.0.model.encoder.layer.6.attention.LayerNorm.weight'
#             p_sent_emb_0_model_encoder_layer_6_attention_layernorm_bias: PARAMETER target='sent_emb.0.model.encoder.layer.6.attention.LayerNorm.bias'
#             p_sent_emb_0_model_encoder_layer_6_intermediate_dense_weight: PARAMETER target='sent_emb.0.model.encoder.layer.6.intermediate.dense.weight'
#             p_sent_emb_0_model_encoder_layer_6_intermediate_dense_bias: PARAMETER target='sent_emb.0.model.encoder.layer.6.intermediate.dense.bias'
#             p_sent_emb_0_model_encoder_layer_6_output_dense_weight: PARAMETER target='sent_emb.0.model.encoder.layer.6.output.dense.weight'
#             p_sent_emb_0_model_encoder_layer_6_output_dense_bias: PARAMETER target='sent_emb.0.model.encoder.layer.6.output.dense.bias'
#             p_sent_emb_0_model_encoder_layer_6_output_layernorm_weight: PARAMETER target='sent_emb.0.model.encoder.layer.6.output.LayerNorm.weight'
#             p_sent_emb_0_model_encoder_layer_6_output_layernorm_bias: PARAMETER target='sent_emb.0.model.encoder.layer.6.output.LayerNorm.bias'
#             p_sent_emb_0_model_encoder_layer_7_attention_attn_q_weight: PARAMETER target='sent_emb.0.model.encoder.layer.7.attention.attn.q.weight'
#             p_sent_emb_0_model_encoder_layer_7_attention_attn_q_bias: PARAMETER target='sent_emb.0.model.encoder.layer.7.attention.attn.q.bias'
#             p_sent_emb_0_model_encoder_layer_7_attention_attn_k_weight: PARAMETER target='sent_emb.0.model.encoder.layer.7.attention.attn.k.weight'
#             p_sent_emb_0_model_encoder_layer_7_attention_attn_k_bias: PARAMETER target='sent_emb.0.model.encoder.layer.7.attention.attn.k.bias'
#             p_sent_emb_0_model_encoder_layer_7_attention_attn_v_weight: PARAMETER target='sent_emb.0.model.encoder.layer.7.attention.attn.v.weight'
#             p_sent_emb_0_model_encoder_layer_7_attention_attn_v_bias: PARAMETER target='sent_emb.0.model.encoder.layer.7.attention.attn.v.bias'
#             p_sent_emb_0_model_encoder_layer_7_attention_attn_o_weight: PARAMETER target='sent_emb.0.model.encoder.layer.7.attention.attn.o.weight'
#             p_sent_emb_0_model_encoder_layer_7_attention_attn_o_bias: PARAMETER target='sent_emb.0.model.encoder.layer.7.attention.attn.o.bias'
#             p_sent_emb_0_model_encoder_layer_7_attention_layernorm_weight: PARAMETER target='sent_emb.0.model.encoder.layer.7.attention.LayerNorm.weight'
#             p_sent_emb_0_model_encoder_layer_7_attention_layernorm_bias: PARAMETER target='sent_emb.0.model.encoder.layer.7.attention.LayerNorm.bias'
#             p_sent_emb_0_model_encoder_layer_7_intermediate_dense_weight: PARAMETER target='sent_emb.0.model.encoder.layer.7.intermediate.dense.weight'
#             p_sent_emb_0_model_encoder_layer_7_intermediate_dense_bias: PARAMETER target='sent_emb.0.model.encoder.layer.7.intermediate.dense.bias'
#             p_sent_emb_0_model_encoder_layer_7_output_dense_weight: PARAMETER target='sent_emb.0.model.encoder.layer.7.output.dense.weight'
#             p_sent_emb_0_model_encoder_layer_7_output_dense_bias: PARAMETER target='sent_emb.0.model.encoder.layer.7.output.dense.bias'
#             p_sent_emb_0_model_encoder_layer_7_output_layernorm_weight: PARAMETER target='sent_emb.0.model.encoder.layer.7.output.LayerNorm.weight'
#             p_sent_emb_0_model_encoder_layer_7_output_layernorm_bias: PARAMETER target='sent_emb.0.model.encoder.layer.7.output.LayerNorm.bias'
#             p_sent_emb_0_model_encoder_layer_8_attention_attn_q_weight: PARAMETER target='sent_emb.0.model.encoder.layer.8.attention.attn.q.weight'
#             p_sent_emb_0_model_encoder_layer_8_attention_attn_q_bias: PARAMETER target='sent_emb.0.model.encoder.layer.8.attention.attn.q.bias'
#             p_sent_emb_0_model_encoder_layer_8_attention_attn_k_weight: PARAMETER target='sent_emb.0.model.encoder.layer.8.attention.attn.k.weight'
#             p_sent_emb_0_model_encoder_layer_8_attention_attn_k_bias: PARAMETER target='sent_emb.0.model.encoder.layer.8.attention.attn.k.bias'
#             p_sent_emb_0_model_encoder_layer_8_attention_attn_v_weight: PARAMETER target='sent_emb.0.model.encoder.layer.8.attention.attn.v.weight'
#             p_sent_emb_0_model_encoder_layer_8_attention_attn_v_bias: PARAMETER target='sent_emb.0.model.encoder.layer.8.attention.attn.v.bias'
#             p_sent_emb_0_model_encoder_layer_8_attention_attn_o_weight: PARAMETER target='sent_emb.0.model.encoder.layer.8.attention.attn.o.weight'
#             p_sent_emb_0_model_encoder_layer_8_attention_attn_o_bias: PARAMETER target='sent_emb.0.model.encoder.layer.8.attention.attn.o.bias'
#             p_sent_emb_0_model_encoder_layer_8_attention_layernorm_weight: PARAMETER target='sent_emb.0.model.encoder.layer.8.attention.LayerNorm.weight'
#             p_sent_emb_0_model_encoder_layer_8_attention_layernorm_bias: PARAMETER target='sent_emb.0.model.encoder.layer.8.attention.LayerNorm.bias'
#             p_sent_emb_0_model_encoder_layer_8_intermediate_dense_weight: PARAMETER target='sent_emb.0.model.encoder.layer.8.intermediate.dense.weight'
#             p_sent_emb_0_model_encoder_layer_8_intermediate_dense_bias: PARAMETER target='sent_emb.0.model.encoder.layer.8.intermediate.dense.bias'
#             p_sent_emb_0_model_encoder_layer_8_output_dense_weight: PARAMETER target='sent_emb.0.model.encoder.layer.8.output.dense.weight'
#             p_sent_emb_0_model_encoder_layer_8_output_dense_bias: PARAMETER target='sent_emb.0.model.encoder.layer.8.output.dense.bias'
#             p_sent_emb_0_model_encoder_layer_8_output_layernorm_weight: PARAMETER target='sent_emb.0.model.encoder.layer.8.output.LayerNorm.weight'
#             p_sent_emb_0_model_encoder_layer_8_output_layernorm_bias: PARAMETER target='sent_emb.0.model.encoder.layer.8.output.LayerNorm.bias'
#             p_sent_emb_0_model_encoder_layer_9_attention_attn_q_weight: PARAMETER target='sent_emb.0.model.encoder.layer.9.attention.attn.q.weight'
#             p_sent_emb_0_model_encoder_layer_9_attention_attn_q_bias: PARAMETER target='sent_emb.0.model.encoder.layer.9.attention.attn.q.bias'
#             p_sent_emb_0_model_encoder_layer_9_attention_attn_k_weight: PARAMETER target='sent_emb.0.model.encoder.layer.9.attention.attn.k.weight'
#             p_sent_emb_0_model_encoder_layer_9_attention_attn_k_bias: PARAMETER target='sent_emb.0.model.encoder.layer.9.attention.attn.k.bias'
#             p_sent_emb_0_model_encoder_layer_9_attention_attn_v_weight: PARAMETER target='sent_emb.0.model.encoder.layer.9.attention.attn.v.weight'
#             p_sent_emb_0_model_encoder_layer_9_attention_attn_v_bias: PARAMETER target='sent_emb.0.model.encoder.layer.9.attention.attn.v.bias'
#             p_sent_emb_0_model_encoder_layer_9_attention_attn_o_weight: PARAMETER target='sent_emb.0.model.encoder.layer.9.attention.attn.o.weight'
#             p_sent_emb_0_model_encoder_layer_9_attention_attn_o_bias: PARAMETER target='sent_emb.0.model.encoder.layer.9.attention.attn.o.bias'
#             p_sent_emb_0_model_encoder_layer_9_attention_layernorm_weight: PARAMETER target='sent_emb.0.model.encoder.layer.9.attention.LayerNorm.weight'
#             p_sent_emb_0_model_encoder_layer_9_attention_layernorm_bias: PARAMETER target='sent_emb.0.model.encoder.layer.9.attention.LayerNorm.bias'
#             p_sent_emb_0_model_encoder_layer_9_intermediate_dense_weight: PARAMETER target='sent_emb.0.model.encoder.layer.9.intermediate.dense.weight'
#             p_sent_emb_0_model_encoder_layer_9_intermediate_dense_bias: PARAMETER target='sent_emb.0.model.encoder.layer.9.intermediate.dense.bias'
#             p_sent_emb_0_model_encoder_layer_9_output_dense_weight: PARAMETER target='sent_emb.0.model.encoder.layer.9.output.dense.weight'
#             p_sent_emb_0_model_encoder_layer_9_output_dense_bias: PARAMETER target='sent_emb.0.model.encoder.layer.9.output.dense.bias'
#             p_sent_emb_0_model_encoder_layer_9_output_layernorm_weight: PARAMETER target='sent_emb.0.model.encoder.layer.9.output.LayerNorm.weight'
#             p_sent_emb_0_model_encoder_layer_9_output_layernorm_bias: PARAMETER target='sent_emb.0.model.encoder.layer.9.output.LayerNorm.bias'
#             p_sent_emb_0_model_encoder_layer_10_attention_attn_q_weight: PARAMETER target='sent_emb.0.model.encoder.layer.10.attention.attn.q.weight'
#             p_sent_emb_0_model_encoder_layer_10_attention_attn_q_bias: PARAMETER target='sent_emb.0.model.encoder.layer.10.attention.attn.q.bias'
#             p_sent_emb_0_model_encoder_layer_10_attention_attn_k_weight: PARAMETER target='sent_emb.0.model.encoder.layer.10.attention.attn.k.weight'
#             p_sent_emb_0_model_encoder_layer_10_attention_attn_k_bias: PARAMETER target='sent_emb.0.model.encoder.layer.10.attention.attn.k.bias'
#             p_sent_emb_0_model_encoder_layer_10_attention_attn_v_weight: PARAMETER target='sent_emb.0.model.encoder.layer.10.attention.attn.v.weight'
#             p_sent_emb_0_model_encoder_layer_10_attention_attn_v_bias: PARAMETER target='sent_emb.0.model.encoder.layer.10.attention.attn.v.bias'
#             p_sent_emb_0_model_encoder_layer_10_attention_attn_o_weight: PARAMETER target='sent_emb.0.model.encoder.layer.10.attention.attn.o.weight'
#             p_sent_emb_0_model_encoder_layer_10_attention_attn_o_bias: PARAMETER target='sent_emb.0.model.encoder.layer.10.attention.attn.o.bias'
#             p_sent_emb_0_model_encoder_layer_10_attention_layernorm_weight: PARAMETER target='sent_emb.0.model.encoder.layer.10.attention.LayerNorm.weight'
#             p_sent_emb_0_model_encoder_layer_10_attention_layernorm_bias: PARAMETER target='sent_emb.0.model.encoder.layer.10.attention.LayerNorm.bias'
#             p_sent_emb_0_model_encoder_layer_10_intermediate_dense_weight: PARAMETER target='sent_emb.0.model.encoder.layer.10.intermediate.dense.weight'
#             p_sent_emb_0_model_encoder_layer_10_intermediate_dense_bias: PARAMETER target='sent_emb.0.model.encoder.layer.10.intermediate.dense.bias'
#             p_sent_emb_0_model_encoder_layer_10_output_dense_weight: PARAMETER target='sent_emb.0.model.encoder.layer.10.output.dense.weight'
#             p_sent_emb_0_model_encoder_layer_10_output_dense_bias: PARAMETER target='sent_emb.0.model.encoder.layer.10.output.dense.bias'
#             p_sent_emb_0_model_encoder_layer_10_output_layernorm_weight: PARAMETER target='sent_emb.0.model.encoder.layer.10.output.LayerNorm.weight'
#             p_sent_emb_0_model_encoder_layer_10_output_layernorm_bias: PARAMETER target='sent_emb.0.model.encoder.layer.10.output.LayerNorm.bias'
#             p_sent_emb_0_model_encoder_layer_11_attention_attn_q_weight: PARAMETER target='sent_emb.0.model.encoder.layer.11.attention.attn.q.weight'
#             p_sent_emb_0_model_encoder_layer_11_attention_attn_q_bias: PARAMETER target='sent_emb.0.model.encoder.layer.11.attention.attn.q.bias'
#             p_sent_emb_0_model_encoder_layer_11_attention_attn_k_weight: PARAMETER target='sent_emb.0.model.encoder.layer.11.attention.attn.k.weight'
#             p_sent_emb_0_model_encoder_layer_11_attention_attn_k_bias: PARAMETER target='sent_emb.0.model.encoder.layer.11.attention.attn.k.bias'
#             p_sent_emb_0_model_encoder_layer_11_attention_attn_v_weight: PARAMETER target='sent_emb.0.model.encoder.layer.11.attention.attn.v.weight'
#             p_sent_emb_0_model_encoder_layer_11_attention_attn_v_bias: PARAMETER target='sent_emb.0.model.encoder.layer.11.attention.attn.v.bias'
#             p_sent_emb_0_model_encoder_layer_11_attention_attn_o_weight: PARAMETER target='sent_emb.0.model.encoder.layer.11.attention.attn.o.weight'
#             p_sent_emb_0_model_encoder_layer_11_attention_attn_o_bias: PARAMETER target='sent_emb.0.model.encoder.layer.11.attention.attn.o.bias'
#             p_sent_emb_0_model_encoder_layer_11_attention_layernorm_weight: PARAMETER target='sent_emb.0.model.encoder.layer.11.attention.LayerNorm.weight'
#             p_sent_emb_0_model_encoder_layer_11_attention_layernorm_bias: PARAMETER target='sent_emb.0.model.encoder.layer.11.attention.LayerNorm.bias'
#             p_sent_emb_0_model_encoder_layer_11_intermediate_dense_weight: PARAMETER target='sent_emb.0.model.encoder.layer.11.intermediate.dense.weight'
#             p_sent_emb_0_model_encoder_layer_11_intermediate_dense_bias: PARAMETER target='sent_emb.0.model.encoder.layer.11.intermediate.dense.bias'
#             p_sent_emb_0_model_encoder_layer_11_output_dense_weight: PARAMETER target='sent_emb.0.model.encoder.layer.11.output.dense.weight'
#             p_sent_emb_0_model_encoder_layer_11_output_dense_bias: PARAMETER target='sent_emb.0.model.encoder.layer.11.output.dense.bias'
#             p_sent_emb_0_model_encoder_layer_11_output_layernorm_weight: PARAMETER target='sent_emb.0.model.encoder.layer.11.output.LayerNorm.weight'
#             p_sent_emb_0_model_encoder_layer_11_output_layernorm_bias: PARAMETER target='sent_emb.0.model.encoder.layer.11.output.LayerNorm.bias'
#             p_sent_emb_0_model_encoder_relative_attention_bias_weight: PARAMETER target='sent_emb.0.model.encoder.relative_attention_bias.weight'
#             p_sent_emb_0_model_pooler_dense_weight: PARAMETER target='sent_emb.0.model.pooler.dense.weight'
#             p_sent_emb_0_model_pooler_dense_bias: PARAMETER target='sent_emb.0.model.pooler.dense.bias'
#             b_sent_emb_0_model_embeddings_position_ids: BUFFER target='sent_emb.0.model.embeddings.position_ids' persistent=False
#             input_ids: USER_INPUT
#             attention_mask: USER_INPUT
#
#             # outputs
#             div_15: USER_OUTPUT
#
#         Range constraints: {s43: VR[0, int_oo], s53: VR[0, int_oo]}
#
# )

# %%
set_fit_model.model_head.class_weight

# %%
#Export the classifier. We export different models, depending on whether the head is differentiable or not

if not set_fit_model.has_differentiable_head:
    #Head not differentiable, e.g. using sklearn
    print("Exporting non differentiable classifier")
    from skl2onnx.common.data_types import FloatTensorType
    initial_type = [('embeddings', FloatTensorType([None, sample_output_shape[1]]))]
    set_fit_model.model_head.classes_ = np.array(set_fit_model.labels)
    classifier_onnx = convert_sklearn(set_fit_model.model_head, initial_types=initial_type)

    with open(f"{OUTPUT_PATH}/classifier.onnx", "wb") as F:
        F.write(classifier_onnx.SerializeToString())
else:
    #Head differentiable, use standart Pytorch to ONNX export
    print("Exporting differentiable classifier")
    dummy_embeddings = torch.ones(sample_output_shape).to("cpu")
    set_fit_model.model_head.classes_ = np.array(set_fit_model.labels)  # added
    jsl_set_fit_head = JSLSetFitDifferentiableClassifier(set_fit_model.model_head)
    # # # Export to ONNX format
    torch.onnx.export (
        jsl_set_fit_head,
        (dummy_embeddings),
        f"{OUTPUT_PATH}/classifier.onnx",
        input_names=['embeddings'],
        output_names=['output_probability'],
        opset_version=12,
        do_constant_folding=True,
        dynamic_axes={"embeddings": {0: 'batch', 1: 'max_seq'}},
        export_params=True,
        verbose=False
    )
# Out:
# Exporting non differentiable classifier

# %%
set_fit_model.model_head.classes_
# Out:
# array(['Gastroenterology', 'Orthopedic', 'Neurology', 'Urology'],
#       dtype='<U16')

# %%
#Create the assets folder
# !test -d $OUTPUT_PATH/assets || mkdir $OUTPUT_PATH/assets

#save vocabulary
tokenizer.save_vocabulary(f"{OUTPUT_PATH}/assets")
# Out:
# ('./models/mtsamples_classifier_onnx/assets/vocab.txt',)

# %%
#if the labels are already specified in a separate file, load them, otherwise get them from the model
#Mind that the labels MUST be specified in a separate file when using a differentiable head
if os.path.isfile(f"{SETFIT_MODEL_PATH}/labels.txt"):
    shutil.copy(f"{SETFIT_MODEL_PATH}/labels.txt", f"{OUTPUT_PATH}/assets/labels.txt")
else:
    with open(f"{OUTPUT_PATH}/assets/labels.txt", "wt") as F:
        for label in set_fit_model.labels:
            F.write(label + "\n")

# %% [markdown]
# ## Test Base Model

# %%
#Sample texts
texts = [
    "The patient was diagnosed with early-onset Parkinson's disease, and the neurologist recommended starting dopamine therapy immediately.",
    "The orthopedic surgeon performed a successful knee replacement surgery, allowing the patient to regain mobility.",
    "The patient presented with symptoms of Crohn's disease, and a colonoscopy was scheduled for further evaluation.",
    "PSA levels were elevated, prompting further tests to rule out prostate cancer."
]
inputs = tokenizer.batch_encode_plus(texts, padding=True)

# %%
#Load the models in ONNX
import onnxruntime as ort

session_options = ort.SessionOptions()
session_options.log_severity_level = 3

onnx_embds = ort.InferenceSession(f"{OUTPUT_PATH}/embeddings.onnx", sess_options=session_options)
onnx_head = ort.InferenceSession(f"{OUTPUT_PATH}/classifier.onnx", sess_options=session_options)

# %%
#Do ONNX inference. The output differs depending on the type of head
embeddings = onnx_embds.run(["embeddings"], {"input_ids": inputs["input_ids"], "attention_mask": inputs["attention_mask"]})[0]
if set_fit_model.has_differentiable_head:
    with open(f"{SETFIT_MODEL_PATH}/labels.txt", "rt") as F:
        labels = list(map(lambda x: x.strip(), F.readlines()))
        print(labels)
    probs = onnx_head.run(["output_probability"], {"embeddings": embeddings})[0]
    for ex in probs:
        print(labels[np.argmax(ex)], np.max(ex), ex)
else:
    print(onnx_head.run(["output_label", "output_probability"], {"embeddings": embeddings}))
# Out:
# [array(['Neurology', 'Orthopedic', 'Gastroenterology', 'Urology'],
#       dtype=object), [{'Gastroenterology': 0.08220913261175156, 'Neurology': 0.7695624232292175, 'Orthopedic': 0.09834089130163193, 'Urology': 0.04988756775856018}, {'Gastroenterology': 0.033971574157476425, 'Neurology': 0.09799709171056747, 'Orthopedic': 0.7882588505744934, 'Urology': 0.07977255433797836}, {'Gastroenterology': 0.9042631387710571, 'Neurology': 0.04206877574324608, 'Orthopedic': 0.02549692615866661, 'Urology': 0.028171204030513763}, {'Gastroenterology': 0.09859948605298996, 'Neurology': 0.27392449975013733, 'Orthopedic': 0.09362111985683441, 'Urology': 0.5338549613952637}]]

# %% [markdown]
# ## Load and Save into SparkNLP

# %%
#Set the model architecture. Currently we only suport MPNet.
#Supporting other architectures requires implementing the corresponding tokenizer, the rest should work out of the box.

model_architecture = None
if "MPNetModel" in ssent_emb[0].auto_model.config.architectures: # Access the config from the underlying Transformer model
    model_architecture = "mpnet"

# %%
# Spark addFile ships only .onnx; embed external weights before loadSavedModel
from pathlib import Path

def consolidate_onnx_model(onnx_path):
    path = Path(onnx_path)
    data_path = path.with_suffix(".onnx.data")
    if not data_path.exists():
        return f"{path.name} (already inline)"
    # Avoid onnx.load(load_external_data=True): Colab hard-linked .data triggers onnx>=1.21 check
    model = onnx.load(str(path), load_external_data=False)
    tensor_data = data_path.read_bytes()
    for initializer in model.graph.initializer:
        if initializer.data_location != onnx.TensorProto.EXTERNAL:
            continue
        offset = length = 0
        for ext in initializer.external_data:
            if ext.key == "offset":
                offset = int(ext.value)
            elif ext.key == "length":
                length = int(ext.value)
        initializer.raw_data = tensor_data[offset:offset + length]
        del initializer.external_data[:]
        initializer.ClearField("data_location")
    onnx.save(model, str(path))
    data_path.unlink()
    return f"{path.name} (embedded weights)"

for _onnx_file in ("embeddings.onnx", "classifier.onnx"):
    print(consolidate_onnx_model(f"{OUTPUT_PATH}/{_onnx_file}"))

# !ls -lh $OUTPUT_PATH
# Out:
# embeddings.onnx (embedded weights)
# classifier.onnx (already inline)
# total 417M
# drwxr-xr-x 2 root root 4.0K Jun 19 23:21 assets
# -rw-r--r-- 1 root root  16K Jun 19 23:21 classifier.onnx
# -rw-r--r-- 1 root root 417M Jun 19 23:21 embeddings.onnx

# %%
#export model to SparkNLP
sparknlp_jsl.annotator.LargeFewShotClassifierModel\
    .loadSavedModel(OUTPUT_PATH,
                    spark,
                    model_architecture=model_architecture,
                    has_differentiable_head=set_fit_model.has_differentiable_head)\
    .setCaseSensitive(not tokenizer.do_lower_case)\
    .write().overwrite().save(SPARKNLP_OUTPUT_PATH)

# %% [markdown]
# ## Pipeline

# %%
#define pipeline
document_assembler = DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")

large_few_shot_classifier = LargeFewShotClassifierModel()\
    .load(SPARKNLP_OUTPUT_PATH)\
    .setInputCols("document")\
    .setOutputCol("prediction")

pipeline = Pipeline().setStages([
    document_assembler,
    large_few_shot_classifier
])

# %%
large_few_shot_classifier.getClasses()
# Out:
# ['Urology', 'Gastroenterology', 'Neurology', 'Orthopedic']

# %%
#Sample texts were defined above
#sample Spark data
spark_df = spark.createDataFrame([[texts[0]],
                                  [texts[1]],
                                  [texts[2]],
                                  [texts[3]]]).toDF("text")

spark_df.show(truncate = 100)
# Out:
# +----------------------------------------------------------------------------------------------------+
# |                                                                                                text|
# +----------------------------------------------------------------------------------------------------+
# |The patient was diagnosed with early-onset Parkinson's disease, and the neurologist recommended s...|
# |The orthopedic surgeon performed a successful knee replacement surgery, allowing the patient to r...|
# |The patient presented with symptoms of Crohn's disease, and a colonoscopy was scheduled for furth...|
# |                      PSA levels were elevated, prompting further tests to rule out prostate cancer.|
# +----------------------------------------------------------------------------------------------------+

# %%
results = pipeline.fit(spark_df).transform(spark_df)

#show results
results.selectExpr("text","prediction.result[0] as prediction").show(truncate=100)
# Out:
# +----------------------------------------------------------------------------------------------------+----------------+
# |                                                                                                text|      prediction|
# +----------------------------------------------------------------------------------------------------+----------------+
# |The patient was diagnosed with early-onset Parkinson's disease, and the neurologist recommended s...|       Neurology|
# |The orthopedic surgeon performed a successful knee replacement surgery, allowing the patient to r...|      Orthopedic|
# |The patient presented with symptoms of Crohn's disease, and a colonoscopy was scheduled for furth...|Gastroenterology|
# |                      PSA levels were elevated, prompting further tests to rule out prostate cancer.|         Urology|
# +----------------------------------------------------------------------------------------------------+----------------+

# %% [markdown]
# ## Evaluation in SparkNLP

# %%
test_data_df
# Out:
#      label                                               text  length  \
# 429      1   HISTORY OF PRESENT ILLNESS: The patient is a ...    7258
# 576      3   CHIEF COMPLAINT: This 61-year-old male presen...    4335
# 29       0   HISTORY OF PRESENT ILLNESS: Ms. Connor is a 5...    3560
# 166      2   PREOPERATIVE DIAGNOSIS: Brain tumor left temp...    2749
# 579      3   CHIEF COMPLAINT: Left flank pain and unable t...    1270
# ..     ...                                                ...     ...
# 509      1   PREOPERATIVE DIAGNOSIS: Left carpal tunnel sy...    2428
# 413      1   PREOPERATIVE DIAGNOSES: 1. Left carpal tunnel...    7669
# 186      2   CC: Progressive memory and cognitive decline....    5233
# 273      2   REASON FOR REFERRAL: The patient is a 58-year...   31031
# 534      3   PREOPERATIVE DIAGNOSES: 1. Radiation cystitis...    8826
#
#         label_classes
# 429        Orthopedic
# 576           Urology
# 29   Gastroenterology
# 166         Neurology
# 579           Urology
# ..                ...
# 509        Orthopedic
# 413        Orthopedic
# 186         Neurology
# 273         Neurology
# 534           Urology
#
# [126 rows x 4 columns]

# %%
test_spark_df = spark.createDataFrame(test_data_df)

test_results = pipeline.fit(test_spark_df).transform(test_spark_df)

# %%
test_results.selectExpr("text", "label","label_classes" ,"prediction.result[0] as prediction").show(5, truncate=100)
# Out:
# +----------------------------------------------------------------------------------------------------+-----+----------------+----------------+
# |                                                                                                text|label|   label_classes|      prediction|
# +----------------------------------------------------------------------------------------------------+-----+----------------+----------------+
# | HISTORY OF PRESENT ILLNESS: The patient is a 26-year-old female, referred to Physical Therapy fo...|    1|      Orthopedic|      Orthopedic|
# | CHIEF COMPLAINT: This 61-year-old male presents today with recent finding of abnormal serum PSA ...|    3|         Urology|Gastroenterology|
# | HISTORY OF PRESENT ILLNESS: Ms. Connor is a 50-year-old female who returns to clinic for a wound...|    0|Gastroenterology|Gastroenterology|
# | PREOPERATIVE DIAGNOSIS: Brain tumor left temporal lobe. POSTOPERATIVE DIAGNOSIS: Brain tumor lef...|    2|       Neurology|       Neurology|
# | CHIEF COMPLAINT: Left flank pain and unable to urinate. HISTORY: The patient is a 46-year-old fe...|    3|         Urology|Gastroenterology|
# +----------------------------------------------------------------------------------------------------+-----+----------------+----------------+
# only showing top 5 rows

# %%
res_df = test_results.selectExpr("text","label_classes", "prediction.result[0] as prediction").toPandas()
res_df
# Out:
#                                                   text     label_classes  \
# 0     HISTORY OF PRESENT ILLNESS: The patient is a ...        Orthopedic
# 1     CHIEF COMPLAINT: This 61-year-old male presen...           Urology
# 2     HISTORY OF PRESENT ILLNESS: Ms. Connor is a 5...  Gastroenterology
# 3     PREOPERATIVE DIAGNOSIS: Brain tumor left temp...         Neurology
# 4     CHIEF COMPLAINT: Left flank pain and unable t...           Urology
# ..                                                 ...               ...
# 121   PREOPERATIVE DIAGNOSIS: Left carpal tunnel sy...        Orthopedic
# 122   PREOPERATIVE DIAGNOSES: 1. Left carpal tunnel...        Orthopedic
# 123   CC: Progressive memory and cognitive decline....         Neurology
# 124   REASON FOR REFERRAL: The patient is a 58-year...         Neurology
# 125   PREOPERATIVE DIAGNOSES: 1. Radiation cystitis...           Urology
#
#            prediction
# 0          Orthopedic
# 1    Gastroenterology
# 2    Gastroenterology
# 3           Neurology
# 4    Gastroenterology
# ..                ...
# 121        Orthopedic
# 122        Orthopedic
# 123         Neurology
# 124         Neurology
# 125           Urology
#
# [126 rows x 3 columns]

# %%
report = classification_report(res_df["label_classes"], res_df["prediction"], digits=4)
print(report)
# Out:
#                   precision    recall  f1-score   support
#
# Gastroenterology     0.9118    0.9688    0.9394        32
#        Neurology     0.8966    0.9286    0.9123        28
#       Orthopedic     0.9773    0.9773    0.9773        44
#          Urology     0.9474    0.8182    0.8780        22
#
#         accuracy                         0.9365       126
#        macro avg     0.9332    0.9232    0.9267       126
#     weighted avg     0.9375    0.9365    0.9359       126
