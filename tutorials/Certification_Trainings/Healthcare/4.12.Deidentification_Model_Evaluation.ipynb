# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/spark-nlp-workshop/blob/master/tutorials/Certification_Trainings/Healthcare/4.12.Deidentification_Model_Evaluation.ipynb)

# %% [markdown]
# If you are using the `johnsnowlabs` library, please use this  [04.13.Deidentification_Model_Evaluation](https://github.com/JohnSnowLabs/spark-nlp-workshop/blob/master/healthcare-nlp/04.13.Deidentification_Model_Evaluation.ipynb) notebook.

# %% [markdown]
# # 📌 Benchmarking De‑Identification Models
#
# In this notebook we assess all available de‑identification models on the **deidentification_benchmark_ground_truth_10_doc** dataset.
#
# Using the profiling pipeline, we gather predictions, align them with ground‑truth labels, tidy up tag formats, and produce standard evaluation metrics. The results for each model are summarised along the way for quick comparison.

# %% [markdown]
# # 🛠 **Set Up**

# %%
# !pip -q install azure-health-deidentification azure-identity openai anthropic boto3

# %% [markdown]
# 📍 Restart session may required.

# %%
import json
import os

from google.colab import files

if 'spark_jsl.json' not in os.listdir():
  license_keys = files.upload()
  os.rename(list(license_keys.keys())[0], 'spark_jsl.json')

with open('spark_jsl.json') as f:
    license_keys = json.load(f)

# Defining license key-value pairs as local variables
locals().update(license_keys)
os.environ.update(license_keys)

# %%
# Installing pyspark and spark-nlp
! pip install --upgrade -q pyspark==3.5.1 spark-nlp==$PUBLIC_VERSION

# Installing Spark NLP Healthcare
! pip install --upgrade -q spark-nlp-jsl==$JSL_VERSION  --extra-index-url https://pypi.johnsnowlabs.com/$SECRET

# %%
import json
import os

import sparknlp
import sparknlp_jsl

from sparknlp.base import *
from sparknlp.annotator import *
from sparknlp_jsl.annotator import *
from sparknlp_jsl.pipeline_tracer import PipelineTracer
from sparknlp_jsl.pipeline_output_parser import PipelineOutputParser

from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.ml import Pipeline,PipelineModel

import pandas as pd
pd.set_option('display.max_colwidth', 200)

import warnings
warnings.filterwarnings('ignore')

params = {"spark.driver.memory":"16G",
          "spark.kryoserializer.buffer.max":"2000M",
          "spark.driver.maxResultSize":"2000M"}

print("Spark NLP Version :", sparknlp.version())
print("Spark NLP_JSL Version :", sparknlp_jsl.version())

spark = sparknlp_jsl.start(license_keys['SECRET'],params=params)

spark
# Out:
# Spark NLP Version : 6.4.0
# Spark NLP_JSL Version : 6.4.0
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://3232c342c661:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark NLP Licensed</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# # 📝 **Dataset**
#
# For the benchmark, we will use 48 open-source documents annotated by domain experts working at John Snow Labs. These annotations include the entities `IDNUM`, `LOCATION`, `DATE`, `AGE`, `NAME` and `CONTACT` Therefore, the benchmark will be conducted based on these labels.
#
# **NOTE:** In this notebook, the results were prepared using the whole dataset, but a small part of it was shared. If you are interested in using the dataset, please contact us by sending email to **support@johnsnowlabs.com**

# %%
# !wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/academic/DeIdentification_Benchmarks_Text2Story2025/deidentification_benchmark_ground_truth_10_doc.csv

# %%
ground_truth_df = pd.read_csv("deidentification_benchmark_ground_truth_10_doc.csv")
ground_truth_df
# Out:
#      doc_id  \
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 271      38
# 272      38
# 273      38
# 274      38
# 275      38
#
#                                                                                                                                                                                                         text  \
# 0    \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1    \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2    \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3    \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4    \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ..                                                                                                                                                                                                       ...
# 271  Pasco Bond DOB : 24/09/1974 Page 1 of 7\n\nOffice Visit Pasco Bond ( 24/9/1974 )\n\nPasco Bond Description : 52 year old\n\n1/10/2018 9:00 AM Office Visit male\n\nProvider : Delvin , Dept Phone : ...
# 272  Pasco Bond DOB : 24/09/1974 Page 1 of 7\n\nOffice Visit Pasco Bond ( 24/9/1974 )\n\nPasco Bond Description : 52 year old\n\n1/10/2018 9:00 AM Office Visit male\n\nProvider : Delvin , Dept Phone : ...
# 273  Pasco Bond DOB : 24/09/1974 Page 1 of 7\n\nOffice Visit Pasco Bond ( 24/9/1974 )\n\nPasco Bond Description : 52 year old\n\n1/10/2018 9:00 AM Office Visit male\n\nProvider : Delvin , Dept Phone : ...
# 274  Pasco Bond DOB : 24/09/1974 Page 1 of 7\n\nOffice Visit Pasco Bond ( 24/9/1974 )\n\nPasco Bond Description : 52 year old\n\n1/10/2018 9:00 AM Office Visit male\n\nProvider : Delvin , Dept Phone : ...
# 275  Pasco Bond DOB : 24/09/1974 Page 1 of 7\n\nOffice Visit Pasco Bond ( 24/9/1974 )\n\nPasco Bond Description : 52 year old\n\n1/10/2018 9:00 AM Office Visit male\n\nProvider : Delvin , Dept Phone : ...
#
#      begin    end         chunk chunk_label
# 0        1     10     957770228       IDNUM
# 1       11     14           FIH    LOCATION
# 2       15     22       0408267       IDNUM
# 3       23     33    46769/5v7d       IDNUM
# 4       34     40        237890       IDNUM
# ..     ...    ...           ...         ...
# 271  10233  10245  Cheree Cords        NAME
# 272  10300  10311   Pauline Bos        NAME
# 273  10328  10337     1/10/2018        DATE
# 274  10554  10564    Pasco Bond        NAME
# 275  10571  10581    24/09/1974        DATE
#
# [276 rows x 6 columns]

# %%
ground_truth_df.chunk_label.value_counts()
# Out:
# chunk_label
# DATE        123
# NAME         70
# IDNUM        37
# LOCATION     35
# AGE           8
# CONTACT       3
# Name: count, dtype: int64

# %% [markdown]
# # 🧩 **Getting Token-Level Information**
#
# Obtaining token, start, end, and label information for each text to be used as ground truth for future predictions.

# %%
from sparknlp.pretrained import PretrainedPipeline

deid_pipeline = PretrainedPipeline("ner_profiling_deidentification", "en", "clinical/models")
# Out:
# ner_profiling_deidentification download started this may take some time.
# Approx size to download 2.5 GB
# [OK!]

# %%
text_df = ground_truth_df[["doc_id", "text"]].drop_duplicates()
spark_df = spark.createDataFrame(text_df).repartition(32)
spark_df.show()
# Out:
# +------+--------------------+
# |doc_id|                text|
# +------+--------------------+
# |     1|\n957770228\nFIH\...|
# |     4|\n229937784\nFIH\...|
# |    38|Pasco Bond DOB : ...|
# |    20|\n263283549 ELMVH...|
# |    10|\n305265793\nFIH\...|
# |    29|\n417344403 RWH\n...|
# |    25|\n649953363\nFIH\...|
# |     9|\n333145593\nFIH\...|
# +------+--------------------+

# %%
documentAssembler = DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")

# Tokenizer splits words in a relevant format for NLP
tokenizer = Tokenizer()\
    .setInputCols(["document"])\
    .setOutputCol("token")

nlpPipeline = Pipeline(
    stages=[
        documentAssembler,
        tokenizer
        ])

empty_data = spark.createDataFrame([[""]]).toDF("text")

model = nlpPipeline.fit(empty_data)

# %%
sdf_result = model.transform(spark_df)

token_pred_df = sdf_result.select("doc_id", "text", F.explode(F.arrays_zip(sdf_result.token.begin,
                                                                           sdf_result.token.end,
                                                                           sdf_result.token.result,
                                                                          )).alias("cols"))\
                          .select("doc_id", "text", F.expr("cols['0']").alias("token_begin"),
                                                    F.expr("cols['1']").alias("token_end"),
                                                    F.expr("cols['2']").alias("token")).toPandas()

token_pred_df
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       token_begin  token_end       token
# 0               1          9   957770228
# 1              11         13         FIH
# 2              15         21     0408267
# 3              23         32  46769/5v7d
# 4              34         39      237890
# ...           ...        ...         ...
# 8627         7602       7604         M.D
# 8628         7605       7605           .
# 8629         7607       7607           [
# 8630         7609       7618  report_end
# 8631         7620       7620           ]
#
# [8632 rows x 5 columns]

# %%
# %%time
from tqdm import tqdm

gt_token_labels = []
docs = token_pred_df.text.unique()

for doc in tqdm(docs):
    gt_slice_df = ground_truth_df[ground_truth_df.text==doc].copy()
    token_slice_df = token_pred_df[token_pred_df.text==doc].copy()

    for token_ind, token_row in token_slice_df.iterrows():
        # gt
        token_label="O"
        for gt_ind, gt_row in gt_slice_df.iterrows():
            if (gt_row.begin <=token_row.token_begin < gt_row.end):
                token_label = gt_row.chunk_label
                break
            else:
                pass
        gt_token_labels.append(token_label)
# Out:
# 100%|██████████| 8/8 [00:13<00:00,  1.63s/it]
# CPU times: user 14.1 s, sys: 123 ms, total: 14.2 s
# Wall time: 14.2 s

# %%
token_pred_df["token_label"] = gt_token_labels
token_pred_df
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       token_begin  token_end       token token_label
# 0               1          9   957770228       IDNUM
# 1              11         13         FIH    LOCATION
# 2              15         21     0408267       IDNUM
# 3              23         32  46769/5v7d       IDNUM
# 4              34         39      237890       IDNUM
# ...           ...        ...         ...         ...
# 8627         7602       7604         M.D           O
# 8628         7605       7605           .           O
# 8629         7607       7607           [           O
# 8630         7609       7618  report_end           O
# 8631         7620       7620           ]           O
#
# [8632 rows x 6 columns]

# %%
token_pred_df.to_csv("token_pred_df.csv", index=False)

# %%
import pandas as pd
token_pred_df = pd.read_csv("token_pred_df.csv")

token_pred_df = token_pred_df.rename(columns={
    'token_begin': 'begin',
    'token_end': 'end'
})

token_pred_df
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label
# 0         1     9   957770228       IDNUM
# 1        11    13         FIH    LOCATION
# 2        15    21     0408267       IDNUM
# 3        23    32  46769/5v7d       IDNUM
# 4        34    39      237890       IDNUM
# ...     ...   ...         ...         ...
# 8627   7602  7604         M.D           O
# 8628   7605  7605           .           O
# 8629   7607  7607           [           O
# 8630   7609  7618  report_end           O
# 8631   7620  7620           ]           O
#
# [8632 rows x 6 columns]

# %% [markdown]
# # 🧨 **Getting Predictions from Each Model in the Pipeline**

# %%
import pandas as pd
import plotly.graph_objects as go
from typing import List, Dict, Optional

class NERResultViewer:
    """
    A utility class to visualize NER (Named Entity Recognition) model outputs
    in different formats: chunks, token-level predictions, tuple results, and label distribution plots.
    """

    def __init__(self, light_result=None):
        """
        Initialize the class with the light_result dictionary from Spark NLP or similar output.
        """
        self.light_result = light_result


    def build_chunk_dataframe(self, results):
        """
        Helper function that builds a DataFrame from chunk results.
        """
        data = {
            'sentence': [r.metadata.get('sentence', '') for r in results],
            'begin': [r.begin for r in results],
            'end': [r.end for r in results],
            'chunks': [r.result for r in results],
            'entity': [r.metadata.get('entity') if r.metadata.get('entity') else r.metadata.get('field', '') for r in results],
            'confidence': [r.metadata.get('confidence', '') for r in results]
        }
        return pd.DataFrame(data)

    def show_chunk_results(self):
        """
        Prints chunk-level NER results as DataFrames for each model.
        """
        if self.light_result is None:
            print("light_result is None.")
            return

        for key in self.light_result.keys():
            if key in ['sentence', 'token'] or "_chunks" not in key:
                continue

            model_name = "_".join(key.split("_")[:-1])
            results = self.light_result[key]

            print(f"\n{'*' * 20} {model_name} Model Results {'*' * 20}")

            if len(results) == 0:
                print("No Result For This Model")
                continue

            df = self.build_chunk_dataframe(results)
            try:
                from IPython.display import display  # noqa
                display(df)
            except Exception:
                print(df.to_string(index=False))

    def get_token_results(self):
        """
        Generate a DataFrame showing token-level predictions for all models.
        """
        if self.light_result is None:
            return pd.DataFrame()

        # Extract base token data
        token_data = self.light_result["token"]
        df = pd.DataFrame({
            'sentence': [t.metadata["sentence"] for t in token_data],
            'begin': [t.begin for t in token_data],
            'end': [t.end for t in token_data],
            'token': [t.result for t in token_data]
        })

        # Add neural NER model predictions
        for key, model_output in self.light_result.items():
            if key in ["sentence", "token"] or "_chunks" in key or "ner" not in key:
                continue
            labels = [entry.result for entry in model_output]
            df[key] = labels

        # Add rule-based chunk predictions (e.g., *_chunks)
        for key, chunk_annotations in self.light_result.items():
            if key in ["sentence", "token"] or "ner" in key:
                continue

            chunk_df = self.build_chunk_dataframe(chunk_annotations)

            # Build an index-efficient token -> label mapping
            labels = []
            for _, token_row in df.iterrows():
                matched_entity = "O"
                for _, chunk_row in chunk_df.iterrows():
                    if (chunk_row.begin <= token_row.begin < chunk_row.end) or (token_row.begin <= chunk_row.begin < token_row.end):
                        matched_entity = chunk_row.entity
                        break
                labels.append(matched_entity)

            column_name = "_".join(key.split("_")[:-1])
            df[column_name] = labels

        return df

    def show_results_as_tuples(self):
        """
        Print the NER token predictions as (token, label) tuples for each model.
        """
        if self.light_result is None:
            print("light_result is None.")
            return

        tokens = [j.result for j in self.light_result["token"]]

        for key in self.light_result.keys():
            if key == 'sentence' or "_chunks" in key:
                continue

            results = self.light_result[key]

            print(f"\n{'*'*20} {key} Model Results {'*'*20}")

            if len(results) == 0:
                print("No Result For This Model")
                continue

            labels = [r.result for r in results]
            paired = list(zip(tokens, labels))
            print(paired)

    def plot_entity_counts(self):
        """
        Plot a horizontal bar chart of entity counts (excluding "O") per model using Plotly.
        """
        result_df = self.get_token_results()
        if result_df.empty:
            print("No token results to plot.")
            return

        # Extract only label columns (excluding token info)
        label_result_df = result_df[result_df.columns[4:]].copy()

        # Count how many non-'O' labels exist for each model
        label_count_list = [label_result_df[label_result_df[col] != "O"].shape[0] for col in label_result_df.columns]

        # Create bar plot
        fig = go.Figure(go.Bar(
            x=label_count_list,
            y=label_result_df.columns,
            orientation='h'
        ))

        fig.update_layout(
            autosize=False,
            width=1500,
            height=1500,
            margin=dict(l=50, r=50, b=100, t=100, pad=4),
            paper_bgcolor="LightSteelBlue",
            title={'text': "Counts of Labelled Entities", 'y':0.98, 'x':0.5, 'xanchor': 'center', 'yanchor': 'top'},
            titlefont=dict(size=30),
            yaxis=dict(title_text="Clinical NER Models", titlefont=dict(size=30)),
        )

        fig.show()


    @staticmethod
    def build_docs(token_pred_df: pd.DataFrame) -> pd.DataFrame:
        return (
            token_pred_df[['doc_id', 'text']]
            .drop_duplicates(subset='doc_id')
            .sort_values('doc_id')
            .reset_index(drop=True)
        )

    @staticmethod
    def run_light_pipeline_on_docs(docs_df: pd.DataFrame, pipeline) -> pd.DataFrame:
        """
        Runs a Spark NLP LightPipeline on a docs dataframe (doc_id, text)
        and returns concatenated token-level predictions for all documents.
        """
        results = []
        for doc_id, text in zip(docs_df['doc_id'].tolist(), docs_df['text'].tolist()):
            annotated = pipeline.fullAnnotate(text)[0]
            viewer = NERResultViewer(annotated)
            token_df = viewer.get_token_results()
            token_df.insert(0, 'doc_id', doc_id)
            results.append(token_df)

        prediction_df = pd.concat(results, ignore_index=True) if results else pd.DataFrame()
        return prediction_df

    @staticmethod
    def infer_model_columns(prediction_df: pd.DataFrame) -> List[str]:
        base = {'doc_id', 'sentence', 'begin', 'end', 'token'}
        return [c for c in prediction_df.columns if c not in base]

    @staticmethod
    def get_model_df(pred_df: pd.DataFrame, model_name: str, strip_prefix: bool = True) -> pd.DataFrame:
        df = pred_df[['doc_id', 'sentence', 'begin', 'end', 'token', model_name]].copy()
        if strip_prefix and df[model_name].dtype == 'object':
            df[model_name] = df[model_name].str.replace(r'^[BI]-', '', regex=True)
        return df

    @staticmethod
    def merge_all_models(
        gold_token_df: pd.DataFrame,
        pred_df: pd.DataFrame,
        model_cols: Optional[List[str]] = None,
        strip_prefix: bool = True
    ) -> Dict[str, pd.DataFrame]:

        if model_cols is None:
            model_cols = NERResultViewer.infer_model_columns(pred_df)

        results: Dict[str, pd.DataFrame] = {}

        gold = gold_token_df.copy()
        if 'token_label' not in gold.columns and 'label' in gold.columns:
            gold = gold.rename(columns={'label': 'token_label'})

        for model in model_cols:
            if model not in pred_df.columns:
                continue

            df_pred = NERResultViewer.get_model_df(pred_df, model, strip_prefix)

            merged = gold.merge(
                df_pred[['doc_id', 'begin', 'end', model]],
                on=['doc_id', 'begin', 'end'],
                how='inner',
                validate='one_to_one'
            )

            merged = merged.rename(columns={model: 'pred_label'})

            ordered_cols = [c for c in ['doc_id', 'text', 'begin', 'end', 'token', 'token_label', 'pred_label'] if c in merged.columns]
            results[model] = merged[ordered_cols].copy()

        return results

# %%
token_pred_df[['doc_id','text']].head()
# Out:
#    doc_id  \
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#
#                                                                                                                                                                                                       text
# 0  \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1  \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2  \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3  \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4  \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...

# %%
docs = NERResultViewer.build_docs(token_pred_df)

# %%
prediction_df = NERResultViewer.run_light_pipeline_on_docs(docs, deid_pipeline)
prediction_df.head()
# Out:
#    doc_id sentence  begin  end       token ner_deid_augmented  \
# 0       1        0      1    9   957770228               B-ID
# 1       1        1     11   13         FIH         B-LOCATION
# 2       1        1     15   21     0408267               B-ID
# 3       1        1     23   32  46769/5v7d                  O
# 4       1        1     34   39      237890               B-ID
#
#   ner_deid_subentity_augmented_i2b2 ner_deidentify_dl  \
# 0                           B-IDNUM   I-MEDICALRECORD
# 1                        B-HOSPITAL        I-HOSPITAL
# 2                           B-IDNUM   I-MEDICALRECORD
# 3                   B-MEDICALRECORD   I-MEDICALRECORD
# 4                           B-IDNUM   I-MEDICALRECORD
#
#   ner_deid_subentity_augmented_langtest ner_deid_synthetic  ... email_matcher  \
# 0                       B-MEDICALRECORD               B-ID  ...             O
# 1                            B-HOSPITAL         B-LOCATION  ...             O
# 2                       B-MEDICALRECORD               B-ID  ...             O
# 3                                     O                  O  ...             O
# 4                                     O               B-ID  ...             O
#
#   zip_parser license_parser phone_matcher dln_parser vin_parser age_parser  \
# 0          O              O             O          O          O          O
# 1          O              O             O          O          O          O
# 2          O              O             O          O          O          O
# 3          O              O             O          O          O          O
# 4          O              O             O          O          O          O
#
#   country_matcher date_matcher date_of_birth_parser
# 0               O            O                    O
# 1               O            O                    O
# 2               O            O                    O
# 3               O            O                    O
# 4               O            O                    O
#
# [5 rows x 46 columns]

# %%
all_merged = NERResultViewer.merge_all_models(token_pred_df, prediction_df)

# %% [markdown]
# ### 🎈 **ner_deid_augmented**

# %%
df_aug = all_merged['ner_deid_augmented']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM         ID
# 1        11    13         FIH    LOCATION   LOCATION
# 2        15    21     0408267       IDNUM         ID
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM         ID
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'ID': 'IDNUM'})

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in labels if l != 'O']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#        IDNUM       0.97      0.78      0.87        37
#     LOCATION       0.73      0.84      0.78        81
#         DATE       0.98      1.00      0.99       213
#          AGE       1.00      0.30      0.46        20
#         NAME       0.89      0.58      0.70       165
#      CONTACT       0.50      1.00      0.67         3
#
#    micro avg       0.90      0.80      0.85       519
#    macro avg       0.84      0.75      0.74       519
# weighted avg       0.91      0.80      0.83       519

# %% [markdown]
# ### 🎈 **ner_deid_subentity_augmented_i2b2**

# %%
df_aug = all_merged['ner_deid_subentity_augmented_i2b2']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label     pred_label
# 0         1     9   957770228       IDNUM          IDNUM
# 1        11    13         FIH    LOCATION       HOSPITAL
# 2        15    21     0408267       IDNUM          IDNUM
# 3        23    32  46769/5v7d       IDNUM  MEDICALRECORD
# 4        34    39      237890       IDNUM          IDNUM
# ...     ...   ...         ...         ...            ...
# 8627   7602  7604         M.D           O              O
# 8628   7605  7605           .           O              O
# 8629   7607  7607           [           O              O
# 8630   7609  7618  report_end           O              O
# 8631   7620  7620           ]           O              O
#
# [8632 rows x 7 columns]

# %%
df_aug['token_label'].value_counts()
# Out:
# token_label
# O           8113
# DATE         213
# NAME         165
# LOCATION      81
# IDNUM         37
# AGE           20
# CONTACT        3
# Name: count, dtype: int64

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O                8171
# DATE              218
# DOCTOR             99
# HOSPITAL           49
# IDNUM              17
# MEDICALRECORD      14
# STATE              14
# PHONE              13
# PATIENT            13
# STREET              9
# AGE                 8
# ORGANIZATION        2
# CITY                2
# COUNTRY             1
# DEVICE              1
# ZIP                 1
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'MEDICALRECORD': 'IDNUM', 'ZIP':'LOCATION', 'CITY':'LOCATION',
                                                     'STREET':'LOCATION', 'COUNTRY':'LOCATION', 'STATE':'LOCATION',
                                                     'PHONE':'CONTACT', 'DOCTOR':'NAME', 'HOSPITAL':'LOCATION', 'PATIENT':'NAME',
                                                     'ORGANIZATION':'O', 'DEVICE':'O'})

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O           8174
# DATE         218
# NAME         112
# LOCATION      76
# IDNUM         31
# CONTACT       13
# AGE            8
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in labels if l != 'O']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#        IDNUM       1.00      0.84      0.91        37
#     LOCATION       0.70      0.65      0.68        81
#         DATE       0.97      0.99      0.98       213
#          AGE       0.88      0.35      0.50        20
#         NAME       0.91      0.62      0.74       165
#      CONTACT       0.23      1.00      0.38         3
#
#    micro avg       0.89      0.78      0.83       519
#    macro avg       0.78      0.74      0.70       519
# weighted avg       0.90      0.78      0.83       519

# %% [markdown]
# ### 🎈 **ner_deidentify_dl**

# %%
df_aug = all_merged['ner_deidentify_dl']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label     pred_label
# 0         1     9   957770228       IDNUM  MEDICALRECORD
# 1        11    13         FIH    LOCATION       HOSPITAL
# 2        15    21     0408267       IDNUM  MEDICALRECORD
# 3        23    32  46769/5v7d       IDNUM  MEDICALRECORD
# 4        34    39      237890       IDNUM  MEDICALRECORD
# ...     ...   ...         ...         ...            ...
# 8627   7602  7604         M.D           O              O
# 8628   7605  7605           .           O              O
# 8629   7607  7607           [           O              O
# 8630   7609  7618  report_end           O              O
# 8631   7620  7620           ]           O              O
#
# [8632 rows x 7 columns]

# %%
df_aug['token_label'].value_counts()
# Out:
# token_label
# O           8113
# DATE         213
# NAME         165
# LOCATION      81
# IDNUM         37
# AGE           20
# CONTACT        3
# Name: count, dtype: int64

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O                8199
# DATE              206
# DOCTOR             91
# HOSPITAL           55
# MEDICALRECORD      27
# PATIENT            22
# STREET             13
# PHONE               7
# AGE                 6
# EMAIL               1
# ZIP                 1
# IDNUM               1
# USERNAME            1
# CITY                1
# STATE               1
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'MEDICALRECORD': 'IDNUM', 'ZIP':'LOCATION', 'CITY':'LOCATION',
                                                     'STREET':'LOCATION', 'STATE':'LOCATION', 'PHONE':'CONTACT', 'EMAIL':'CONTACT',
                                                     'DOCTOR':'NAME', 'HOSPITAL':'LOCATION', 'PATIENT':'NAME', 'USERNAME':'O'})

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O           8200
# DATE         206
# NAME         113
# LOCATION      71
# IDNUM         28
# CONTACT        8
# AGE            6
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in labels if l != 'O']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#        IDNUM       0.96      0.73      0.83        37
#     LOCATION       0.77      0.68      0.72        81
#         DATE       0.99      0.95      0.97       213
#          AGE       1.00      0.30      0.46        20
#         NAME       0.88      0.61      0.72       165
#      CONTACT       0.38      1.00      0.55         3
#
#    micro avg       0.91      0.76      0.83       519
#    macro avg       0.83      0.71      0.71       519
# weighted avg       0.92      0.76      0.82       519

# %% [markdown]
# ### 🎈 **ner_deid_subentity_augmented_langtest**

# %%
df_aug = all_merged['ner_deid_subentity_augmented_langtest']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label     pred_label
# 0         1     9   957770228       IDNUM  MEDICALRECORD
# 1        11    13         FIH    LOCATION       HOSPITAL
# 2        15    21     0408267       IDNUM  MEDICALRECORD
# 3        23    32  46769/5v7d       IDNUM              O
# 4        34    39      237890       IDNUM              O
# ...     ...   ...         ...         ...            ...
# 8627   7602  7604         M.D           O              O
# 8628   7605  7605           .           O              O
# 8629   7607  7607           [           O              O
# 8630   7609  7618  report_end           O              O
# 8631   7620  7620           ]           O              O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O                8170
# DATE              210
# DOCTOR            116
# HOSPITAL           42
# MEDICALRECORD      27
# PATIENT            16
# STREET             13
# AGE                 8
# CITY                8
# IDNUM               5
# USERNAME            4
# COUNTRY             4
# PHONE               2
# STATE               2
# ZIP                 2
# PROFESSION          2
# ORGANIZATION        1
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'MEDICALRECORD': 'IDNUM', 'ZIP':'LOCATION', 'CITY':'LOCATION',
                                                     'STREET':'LOCATION', 'STATE':'LOCATION', 'COUNTRY':'LOCATION',
                                                     'PHONE':'CONTACT', 'DOCTOR':'NAME', 'HOSPITAL':'LOCATION', 'PATIENT':'NAME',
                                                     'USERNAME':'O', 'PROFESSION':'O', 'ORGANIZATION':'O'})

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O           8177
# DATE         210
# NAME         132
# LOCATION      71
# IDNUM         32
# AGE            8
# CONTACT        2
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in labels if l != 'O']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#        IDNUM       0.91      0.78      0.84        37
#     LOCATION       0.85      0.74      0.79        81
#         DATE       0.99      0.97      0.98       213
#          AGE       1.00      0.40      0.57        20
#         NAME       0.85      0.68      0.75       165
#      CONTACT       1.00      0.67      0.80         3
#
#    micro avg       0.92      0.81      0.86       519
#    macro avg       0.93      0.71      0.79       519
# weighted avg       0.92      0.81      0.85       519

# %% [markdown]
# ### 🎈 **ner_deid_synthetic**

# %%
df_aug = all_merged['ner_deid_synthetic']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM         ID
# 1        11    13         FIH    LOCATION   LOCATION
# 2        15    21     0408267       IDNUM         ID
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM         ID
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O           8198
# DATE         207
# NAME         111
# LOCATION      73
# ID            31
# AGE            9
# CONTACT        3
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'ID': 'IDNUM'})

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in labels if l != 'O']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#        IDNUM       1.00      0.84      0.91        37
#     LOCATION       0.85      0.77      0.81        81
#         DATE       1.00      0.97      0.98       213
#          AGE       0.67      0.30      0.41        20
#         NAME       0.89      0.60      0.72       165
#      CONTACT       1.00      1.00      1.00         3
#
#    micro avg       0.94      0.78      0.85       519
#    macro avg       0.90      0.75      0.80       519
# weighted avg       0.93      0.78      0.84       519

# %% [markdown]
# ### 🎈 **ner_deid_aipii**

# %%
df_aug = all_merged['ner_deid_aipii']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM          O
# 1        11    13         FIH    LOCATION          O
# 2        15    21     0408267       IDNUM          O
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM          O
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O          8468
# NAME         69
# DATE         25
# CITY         23
# STREET       23
# LICENSE       8
# ZIP           7
# IDNUM         5
# SSN           4
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'SSN': 'IDNUM', 'ZIP':'LOCATION', 'CITY':'LOCATION',
                                                     'STREET':'LOCATION', 'LICENSE':'O'})

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O           8476
# NAME          69
# LOCATION      53
# DATE          25
# IDNUM          9
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
exclude = ['O', 'CONTACT', 'AGE']
labels = [l for l in labels if l not in exclude]

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#        IDNUM       0.22      0.05      0.09        37
#     LOCATION       0.53      0.35      0.42        81
#         DATE       1.00      0.12      0.21       213
#         NAME       0.48      0.20      0.28       165
#
#    micro avg       0.56      0.18      0.27       496
#    macro avg       0.56      0.18      0.25       496
# weighted avg       0.69      0.18      0.26       496

# %% [markdown]
# ### 🎈 **ner_deid_large_langtest**

# %%
df_aug = all_merged['ner_deid_large_langtest']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM         ID
# 1        11    13         FIH    LOCATION   LOCATION
# 2        15    21     0408267       IDNUM          O
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM          O
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O             8035
# DATE           250
# NAME           155
# LOCATION       120
# ID              24
# PROFESSION      24
# AGE             18
# CONTACT          6
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'ID': 'IDNUM', 'PROFESSION':'O'})

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O           8059
# DATE         250
# NAME         155
# LOCATION     120
# IDNUM         24
# AGE           18
# CONTACT        6
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in labels if l != 'O']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#        IDNUM       0.83      0.54      0.66        37
#     LOCATION       0.47      0.69      0.56        81
#         DATE       0.85      1.00      0.92       213
#          AGE       0.33      0.30      0.32        20
#         NAME       0.63      0.59      0.61       165
#      CONTACT       0.50      1.00      0.67         3
#
#    micro avg       0.69      0.76      0.72       519
#    macro avg       0.60      0.69      0.62       519
# weighted avg       0.70      0.76      0.72       519

# %% [markdown]
# ### 🎈 **ner_deid_large**

# %%
df_aug = all_merged['ner_deid_large']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM         ID
# 1        11    13         FIH    LOCATION   LOCATION
# 2        15    21     0408267       IDNUM         ID
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM         ID
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O           8172
# DATE         206
# NAME         139
# LOCATION      73
# ID            32
# AGE            7
# CONTACT        3
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'ID': 'IDNUM'})

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in labels if l != 'O']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#        IDNUM       1.00      0.86      0.93        37
#     LOCATION       0.90      0.81      0.86        81
#         DATE       0.99      0.96      0.97       213
#          AGE       0.86      0.30      0.44        20
#         NAME       0.96      0.81      0.88       165
#      CONTACT       1.00      1.00      1.00         3
#
#    micro avg       0.97      0.86      0.91       519
#    macro avg       0.95      0.79      0.85       519
# weighted avg       0.96      0.86      0.90       519

# %% [markdown]
# ### 🎈 **ner_deid_subentity_docwise**

# %%
df_aug = all_merged['ner_deid_subentity_docwise']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label     pred_label
# 0         1     9   957770228       IDNUM  MEDICALRECORD
# 1        11    13         FIH    LOCATION       HOSPITAL
# 2        15    21     0408267       IDNUM  MEDICALRECORD
# 3        23    32  46769/5v7d       IDNUM  MEDICALRECORD
# 4        34    39      237890       IDNUM  MEDICALRECORD
# ...     ...   ...         ...         ...            ...
# 8627   7602  7604         M.D           O              O
# 8628   7605  7605           .           O              O
# 8629   7607  7607           [           O              O
# 8630   7609  7618  report_end           O              O
# 8631   7620  7620           ]           O              O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O                8206
# DATE              205
# DOCTOR             99
# HOSPITAL           42
# MEDICALRECORD      29
# CITY               11
# PATIENT            10
# AGE                 8
# PHONE               7
# IDNUM               5
# STREET              3
# ZIP                 2
# USERNAME            2
# STATE               2
# PROFESSION          1
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'MEDICALRECORD': 'IDNUM', 'ZIP':'LOCATION', 'CITY':'LOCATION',
                                                     'STREET':'LOCATION', 'STATE':'LOCATION', 'USERNAME':'O',
                                                     'PHONE':'CONTACT', 'DOCTOR':'NAME', 'HOSPITAL':'LOCATION', 'PATIENT':'NAME',
                                                     'PROFESSION':'O'})

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O           8209
# DATE         205
# NAME         109
# LOCATION      60
# IDNUM         34
# AGE            8
# CONTACT        7
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in labels if l != 'O']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#        IDNUM       0.91      0.84      0.87        37
#     LOCATION       0.93      0.69      0.79        81
#         DATE       1.00      0.96      0.98       213
#          AGE       1.00      0.40      0.57        20
#         NAME       0.92      0.61      0.73       165
#      CONTACT       0.29      0.67      0.40         3
#
#    micro avg       0.95      0.77      0.85       519
#    macro avg       0.84      0.69      0.72       519
# weighted avg       0.95      0.77      0.84       519

# %% [markdown]
# ### 🎈 **ner_deid_subentity_augmented_v2**

# %%
df_aug = all_merged['ner_deid_subentity_augmented_v2']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label     pred_label
# 0         1     9   957770228       IDNUM  MEDICALRECORD
# 1        11    13         FIH    LOCATION       HOSPITAL
# 2        15    21     0408267       IDNUM  MEDICALRECORD
# 3        23    32  46769/5v7d       IDNUM              O
# 4        34    39      237890       IDNUM          IDNUM
# ...     ...   ...         ...         ...            ...
# 8627   7602  7604         M.D           O              O
# 8628   7605  7605           .           O              O
# 8629   7607  7607           [           O              O
# 8630   7609  7618  report_end           O       USERNAME
# 8631   7620  7620           ]           O              O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O                8097
# DATE              216
# DOCTOR            115
# HOSPITAL           64
# PATIENT            49
# MEDICALRECORD      20
# STREET             15
# PHONE              11
# AGE                 9
# ORGANIZATION        8
# USERNAME            8
# IDNUM               6
# CITY                6
# STATE               3
# ZIP                 2
# PROFESSION          2
# DEVICE              1
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'MEDICALRECORD': 'IDNUM', 'ZIP':'LOCATION', 'CITY':'LOCATION',
                                                     'STREET':'LOCATION', 'STATE':'LOCATION', 'USERNAME':'O',
                                                     'PHONE':'CONTACT', 'DOCTOR':'NAME', 'HOSPITAL':'LOCATION', 'PATIENT':'NAME',
                                                     'PROFESSION':'O', 'ORGANIZATION':'O', 'DEVICE':'O'})

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O           8116
# DATE         216
# NAME         164
# LOCATION      90
# IDNUM         26
# CONTACT       11
# AGE            9
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in labels if l != 'O']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#        IDNUM       1.00      0.70      0.83        37
#     LOCATION       0.80      0.89      0.84        81
#         DATE       0.98      0.99      0.98       213
#          AGE       0.89      0.40      0.55        20
#         NAME       0.89      0.88      0.89       165
#      CONTACT       0.27      1.00      0.43         3
#
#    micro avg       0.90      0.90      0.90       519
#    macro avg       0.80      0.81      0.75       519
# weighted avg       0.92      0.90      0.90       519

# %% [markdown]
# ### 🎈 **ner_deid_subentity_augmented_docwise**

# %%
df_aug = all_merged['ner_deid_subentity_augmented_docwise']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label     pred_label
# 0         1     9   957770228       IDNUM  MEDICALRECORD
# 1        11    13         FIH    LOCATION       HOSPITAL
# 2        15    21     0408267       IDNUM  MEDICALRECORD
# 3        23    32  46769/5v7d       IDNUM              O
# 4        34    39      237890       IDNUM  MEDICALRECORD
# ...     ...   ...         ...         ...            ...
# 8627   7602  7604         M.D           O              O
# 8628   7605  7605           .           O              O
# 8629   7607  7607           [           O              O
# 8630   7609  7618  report_end           O              O
# 8631   7620  7620           ]           O              O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O                8121
# DATE              214
# DOCTOR            133
# PATIENT            44
# HOSPITAL           43
# MEDICALRECORD      29
# LOCATION           10
# AGE                 8
# STREET              8
# USERNAME            6
# ORGANIZATION        4
# PHONE               3
# STATE               3
# IDNUM               2
# CITY                2
# ZIP                 2
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'MEDICALRECORD': 'IDNUM', 'ZIP':'LOCATION', 'CITY':'LOCATION',
                                                     'STREET':'LOCATION', 'STATE':'LOCATION', 'USERNAME':'O',
                                                     'PHONE':'CONTACT', 'DOCTOR':'NAME', 'HOSPITAL':'LOCATION', 'PATIENT':'NAME',
                                                     'ORGANIZATION':'O'})

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O           8131
# DATE         214
# NAME         177
# LOCATION      68
# IDNUM         31
# AGE            8
# CONTACT        3
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in labels if l != 'O']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#        IDNUM       1.00      0.84      0.91        37
#     LOCATION       0.91      0.77      0.83        81
#         DATE       0.99      0.99      0.99       213
#          AGE       1.00      0.40      0.57        20
#         NAME       0.82      0.88      0.85       165
#      CONTACT       1.00      1.00      1.00         3
#
#    micro avg       0.92      0.89      0.90       519
#    macro avg       0.95      0.81      0.86       519
# weighted avg       0.92      0.89      0.90       519

# %% [markdown]
# ### 🎈 **zeroshot_ner_deid_subentity_merged_medium**

# %%
df_aug = all_merged['zeroshot_ner_deid_subentity_merged_medium']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM          O
# 1        11    13         FIH    LOCATION          O
# 2        15    21     0408267       IDNUM          O
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM          O
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O   USERNAME
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O               8066
# DATE             217
# DOCTOR           103
# HOSPITAL          72
# PATIENT           55
# AGE               24
# STREET            17
# CITY              16
# USERNAME          15
# ORGANIZATION      13
# IDNUM             12
# PROFESSION        12
# STATE              4
# PHONE              3
# ZIP                2
# COUNTRY            1
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'ZIP':'LOCATION', 'CITY':'LOCATION', 'COUNTRY':'LOCATION',
                                                     'STREET':'LOCATION', 'STATE':'LOCATION', 'USERNAME':'O',
                                                     'PHONE':'CONTACT', 'DOCTOR':'NAME', 'HOSPITAL':'LOCATION', 'PATIENT':'NAME',
                                                     'ORGANIZATION':'O', 'PROFESSION':'O'})

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O           8106
# DATE         217
# NAME         158
# LOCATION     112
# AGE           24
# IDNUM         12
# CONTACT        3
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in labels if l != 'O']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#        IDNUM       1.00      0.32      0.49        37
#     LOCATION       0.68      0.94      0.79        81
#         DATE       0.98      1.00      0.99       213
#          AGE       0.33      0.40      0.36        20
#         NAME       0.96      0.92      0.93       165
#      CONTACT       0.67      0.67      0.67         3
#
#    micro avg       0.88      0.89      0.88       519
#    macro avg       0.77      0.71      0.71       519
# weighted avg       0.90      0.89      0.88       519

# %% [markdown]
# ### 🎈 **ner_deid_sd_large**

# %%
df_aug = all_merged['ner_deid_sd_large']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM         ID
# 1        11    13         FIH    LOCATION   LOCATION
# 2        15    21     0408267       IDNUM         ID
# 3        23    32  46769/5v7d       IDNUM         ID
# 4        34    39      237890       IDNUM         ID
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O           8149
# DATE         215
# NAME         149
# LOCATION      78
# ID            31
# AGE            6
# CONTACT        4
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'ID': 'IDNUM'})

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in labels if l != 'O']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#        IDNUM       0.94      0.78      0.85        37
#     LOCATION       0.82      0.79      0.81        81
#         DATE       0.96      0.97      0.97       213
#          AGE       1.00      0.30      0.46        20
#         NAME       0.92      0.83      0.87       165
#      CONTACT       0.50      0.67      0.57         3
#
#    micro avg       0.92      0.86      0.89       519
#    macro avg       0.86      0.72      0.76       519
# weighted avg       0.92      0.86      0.88       519

# %% [markdown]
# ### 🎈 **ner_deid_generic_augmented**

# %%
df_aug = all_merged['ner_deid_generic_augmented']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM         ID
# 1        11    13         FIH    LOCATION   LOCATION
# 2        15    21     0408267       IDNUM         ID
# 3        23    32  46769/5v7d       IDNUM         ID
# 4        34    39      237890       IDNUM         ID
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O           8147
# DATE         214
# NAME         136
# LOCATION      85
# ID            36
# AGE            8
# CONTACT        6
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'ID': 'IDNUM'})

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in labels if l != 'O']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#        IDNUM       0.97      0.95      0.96        37
#     LOCATION       0.80      0.84      0.82        81
#         DATE       0.98      0.99      0.98       213
#          AGE       1.00      0.40      0.57        20
#         NAME       0.79      0.65      0.72       165
#      CONTACT       0.50      1.00      0.67         3
#
#    micro avg       0.89      0.83      0.86       519
#    macro avg       0.84      0.80      0.79       519
# weighted avg       0.89      0.83      0.85       519

# %% [markdown]
# ### 🎈 **ner_deid_enriched**

# %%
df_aug = all_merged['ner_deid_enriched']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label     pred_label
# 0         1     9   957770228       IDNUM  MEDICALRECORD
# 1        11    13         FIH    LOCATION       HOSPITAL
# 2        15    21     0408267       IDNUM  MEDICALRECORD
# 3        23    32  46769/5v7d       IDNUM  MEDICALRECORD
# 4        34    39      237890       IDNUM  MEDICALRECORD
# ...     ...   ...         ...         ...            ...
# 8627   7602  7604         M.D           O              O
# 8628   7605  7605           .           O              O
# 8629   7607  7607           [           O              O
# 8630   7609  7618  report_end           O              O
# 8631   7620  7620           ]           O              O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O                8145
# DATE              215
# DOCTOR            101
# HOSPITAL           49
# PATIENT            47
# MEDICALRECORD      30
# STREET             15
# CITY                8
# AGE                 7
# PHONE               4
# USERNAME            4
# IDNUM               2
# STATE               2
# ZIP                 2
# COUNTRY             1
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'MEDICALRECORD':'IDNUM', 'ZIP':'LOCATION', 'CITY':'LOCATION', 'COUNTRY':'LOCATION',
                                                     'STREET':'LOCATION', 'STATE':'LOCATION', 'USERNAME':'O',
                                                     'PHONE':'CONTACT', 'DOCTOR':'NAME', 'HOSPITAL':'LOCATION', 'PATIENT':'NAME'})

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O           8149
# DATE         215
# NAME         148
# LOCATION      77
# IDNUM         32
# AGE            7
# CONTACT        4
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in labels if l != 'O']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#        IDNUM       0.97      0.84      0.90        37
#     LOCATION       0.82      0.78      0.80        81
#         DATE       0.99      1.00      0.99       213
#          AGE       1.00      0.35      0.52        20
#         NAME       0.94      0.84      0.89       165
#      CONTACT       0.50      0.67      0.57         3
#
#    micro avg       0.94      0.87      0.91       519
#    macro avg       0.87      0.75      0.78       519
# weighted avg       0.94      0.87      0.90       519

# %% [markdown]
# ### 🎈 **ner_deid_generic_augmented_langtest**

# %%
df_aug = all_merged['ner_deid_generic_augmented_langtest']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM         ID
# 1        11    13         FIH    LOCATION   LOCATION
# 2        15    21     0408267       IDNUM         ID
# 3        23    32  46769/5v7d       IDNUM   LOCATION
# 4        34    39      237890       IDNUM         ID
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O       NAME
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O             8135
# DATE           197
# NAME           152
# LOCATION        94
# ID              37
# AGE              8
# PROFESSION       6
# CONTACT          3
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'ID':'IDNUM', 'PROFESSION':'O'})

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O           8141
# DATE         197
# NAME         152
# LOCATION      94
# IDNUM         37
# AGE            8
# CONTACT        3
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in labels if l != 'O']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#        IDNUM       0.76      0.76      0.76        37
#     LOCATION       0.73      0.85      0.79        81
#         DATE       0.98      0.91      0.94       213
#          AGE       1.00      0.40      0.57        20
#         NAME       0.76      0.70      0.73       165
#      CONTACT       0.67      0.67      0.67         3
#
#    micro avg       0.85      0.80      0.82       519
#    macro avg       0.82      0.71      0.74       519
# weighted avg       0.85      0.80      0.82       519

# %% [markdown]
# ### 🎈 **ner_deid_subentity_augmented**

# %%
df_aug = all_merged['ner_deid_subentity_augmented']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label     pred_label
# 0         1     9   957770228       IDNUM  MEDICALRECORD
# 1        11    13         FIH    LOCATION       HOSPITAL
# 2        15    21     0408267       IDNUM  MEDICALRECORD
# 3        23    32  46769/5v7d       IDNUM              O
# 4        34    39      237890       IDNUM  MEDICALRECORD
# ...     ...   ...         ...         ...            ...
# 8627   7602  7604         M.D           O              O
# 8628   7605  7605           .           O              O
# 8629   7607  7607           [           O              O
# 8630   7609  7618  report_end           O              O
# 8631   7620  7620           ]           O              O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O                8186
# DATE              198
# DOCTOR            101
# HOSPITAL           41
# MEDICALRECORD      24
# PATIENT            22
# IDNUM              16
# STREET             10
# AGE                 9
# PHONE               7
# CITY                5
# STATE               4
# USERNAME            4
# ZIP                 3
# ORGANIZATION        2
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'MEDICALRECORD':'IDNUM', 'ZIP':'LOCATION', 'CITY':'LOCATION', 'ORGANIZATION':'O',
                                                     'STREET':'LOCATION', 'STATE':'LOCATION', 'USERNAME':'O',
                                                     'PHONE':'CONTACT', 'DOCTOR':'NAME', 'HOSPITAL':'LOCATION', 'PATIENT':'NAME'})

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O           8192
# DATE         198
# NAME         123
# LOCATION      63
# IDNUM         40
# AGE            9
# CONTACT        7
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in labels if l != 'O']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#        IDNUM       0.68      0.73      0.70        37
#     LOCATION       0.86      0.67      0.75        81
#         DATE       0.98      0.91      0.94       213
#          AGE       0.89      0.40      0.55        20
#         NAME       0.84      0.62      0.72       165
#      CONTACT       0.29      0.67      0.40         3
#
#    micro avg       0.88      0.75      0.81       519
#    macro avg       0.75      0.67      0.68       519
# weighted avg       0.89      0.75      0.81       519

# %% [markdown]
# ### 🎈 **ner_deid_generic_docwise**

# %%
df_aug = all_merged['ner_deid_generic_docwise']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM         ID
# 1        11    13         FIH    LOCATION   LOCATION
# 2        15    21     0408267       IDNUM         ID
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM          O
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O             8156
# DATE           216
# NAME           129
# LOCATION        75
# ID              38
# AGE              8
# PROFESSION       6
# CONTACT          4
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'ID':'IDNUM', 'PROFESSION':'O'})

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O           8162
# DATE         216
# NAME         129
# LOCATION      75
# IDNUM         38
# AGE            8
# CONTACT        4
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in labels if l != 'O']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#        IDNUM       0.74      0.76      0.75        37
#     LOCATION       0.71      0.65      0.68        81
#         DATE       0.96      0.97      0.97       213
#          AGE       1.00      0.40      0.57        20
#         NAME       0.82      0.64      0.72       165
#      CONTACT       0.50      0.67      0.57         3
#
#    micro avg       0.86      0.78      0.82       519
#    macro avg       0.79      0.68      0.71       519
# weighted avg       0.86      0.78      0.81       519

# %% [markdown]
# ### 🎈 **ner_deid_generic_augmented_allUpperCased_langtest**

# %%
df_aug = all_merged['ner_deid_generic_augmented_allUpperCased_langtest']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM         ID
# 1        11    13         FIH    LOCATION   LOCATION
# 2        15    21     0408267       IDNUM         ID
# 3        23    32  46769/5v7d       IDNUM         ID
# 4        34    39      237890       IDNUM         ID
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O             8165
# DATE           193
# NAME           132
# LOCATION        89
# ID              40
# AGE              9
# CONTACT          2
# PROFESSION       2
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'ID':'IDNUM', 'PROFESSION':'O'})

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O           8167
# DATE         193
# NAME         132
# LOCATION      89
# IDNUM         40
# AGE            9
# CONTACT        2
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in labels if l != 'O']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#        IDNUM       0.82      0.89      0.86        37
#     LOCATION       0.67      0.74      0.71        81
#         DATE       0.96      0.87      0.92       213
#          AGE       0.89      0.40      0.55        20
#         NAME       0.79      0.63      0.70       165
#      CONTACT       1.00      0.67      0.80         3
#
#    micro avg       0.85      0.76      0.80       519
#    macro avg       0.86      0.70      0.76       519
# weighted avg       0.85      0.76      0.80       519

# %% [markdown]
# ### 🎈 **state_matcher**

# %%
df_aug = all_merged['state_matcher']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM          O
# 1        11    13         FIH    LOCATION          O
# 2        15    21     0408267       IDNUM          O
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM          O
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O        8628
# STATE       4
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'STATE':'LOCATION'})

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O           8628
# LOCATION       4
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in df_aug['token_label'].unique() if l == 'LOCATION']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#     LOCATION       1.00      0.05      0.09        81
#
#    micro avg       1.00      0.05      0.09        81
#    macro avg       1.00      0.05      0.09        81
# weighted avg       1.00      0.05      0.09        81

# %% [markdown]
# ### 🎈 **ssn_parser**

# %%
df_aug = all_merged['ssn_parser']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM          O
# 1        11    13         FIH    LOCATION          O
# 2        15    21     0408267       IDNUM          O
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM          O
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O    8632
# Name: count, dtype: int64

# %% [markdown]
# **This model did not detect any entities in the current dataset.**

# %% [markdown]
# ### 🎈 **phone_parser**

# %%
df_aug = all_merged['phone_parser']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM          O
# 1        11    13         FIH    LOCATION          O
# 2        15    21     0408267       IDNUM          O
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM          O
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O        8630
# PHONE       2
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'PHONE':'CONTACT'})

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O          8630
# CONTACT       2
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in df_aug['token_label'].unique() if l == 'CONTACT']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#      CONTACT       1.00      0.67      0.80         3
#
#    micro avg       1.00      0.67      0.80         3
#    macro avg       1.00      0.67      0.80         3
# weighted avg       1.00      0.67      0.80         3

# %% [markdown]
# ### 🎈 **zip_matcher**

# %%
df_aug = all_merged['zip_matcher']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM          O
# 1        11    13         FIH    LOCATION          O
# 2        15    21     0408267       IDNUM          O
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM          O
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O      8630
# ZIP       2
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'ZIP':'LOCATION'})

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O           8630
# LOCATION       2
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in df_aug['token_label'].unique() if l == 'LOCATION']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#     LOCATION       1.00      0.02      0.05        81
#
#    micro avg       1.00      0.02      0.05        81
#    macro avg       1.00      0.02      0.05        81
# weighted avg       1.00      0.02      0.05        81

# %% [markdown]
# ### 🎈 **ip_matcher**

# %%
df_aug = all_merged['ip_matcher']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM          O
# 1        11    13         FIH    LOCATION          O
# 2        15    21     0408267       IDNUM          O
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM          O
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O    8632
# Name: count, dtype: int64

# %% [markdown]
# **This model did not detect any entities in the current dataset.**

# %% [markdown]
# ### 🎈 **medical_record_parser**

# %%
df_aug = all_merged['medical_record_parser']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM          O
# 1        11    13         FIH    LOCATION          O
# 2        15    21     0408267       IDNUM          O
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM          O
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O                8631
# MEDICALRECORD       1
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'MEDICALRECORD':'IDNUM'})

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O        8631
# IDNUM       1
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in df_aug['token_label'].unique() if l == 'IDNUM']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#        IDNUM       1.00      0.03      0.05        37
#
#    micro avg       1.00      0.03      0.05        37
#    macro avg       1.00      0.03      0.05        37
# weighted avg       1.00      0.03      0.05        37

# %% [markdown]
# ### 🎈 **date_of_death_parser**

# %%
df_aug = all_merged['date_of_death_parser']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM          O
# 1        11    13         FIH    LOCATION          O
# 2        15    21     0408267       IDNUM          O
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM          O
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O    8632
# Name: count, dtype: int64

# %% [markdown]
# **This model did not detect any entities in the current dataset.**

# %% [markdown]
# ### 🎈 **account_parser**

# %%
df_aug = all_merged['account_parser']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM          O
# 1        11    13         FIH    LOCATION          O
# 2        15    21     0408267       IDNUM          O
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM          O
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O    8632
# Name: count, dtype: int64

# %% [markdown]
# **This model did not detect any entities in the current dataset.**

# %% [markdown]
# ### 🎈 **plate_parser**

# %%
df_aug = all_merged['plate_parser']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM          O
# 1        11    13         FIH    LOCATION          O
# 2        15    21     0408267       IDNUM          O
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM          O
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O    8632
# Name: count, dtype: int64

# %% [markdown]
# **This model did not detect any entities in the current dataset.**

# %% [markdown]
# ### 🎈 **url_matcher**

# %%
df_aug = all_merged['url_matcher']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM          O
# 1        11    13         FIH    LOCATION          O
# 2        15    21     0408267       IDNUM          O
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM          O
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O    8632
# Name: count, dtype: int64

# %% [markdown]
# **This model did not detect any entities in the current dataset.**

# %% [markdown]
# ### 🎈 **email_matcher**

# %%
df_aug = all_merged['email_matcher']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM          O
# 1        11    13         FIH    LOCATION          O
# 2        15    21     0408267       IDNUM          O
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM          O
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O    8632
# Name: count, dtype: int64

# %% [markdown]
# **This model did not detect any entities in the current dataset.**

# %% [markdown]
# ### 🎈 **zip_parser**

# %%
df_aug = all_merged['zip_parser']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM          O
# 1        11    13         FIH    LOCATION          O
# 2        15    21     0408267       IDNUM          O
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM          O
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O      8630
# ZIP       2
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'ZIP':'LOCATION'})

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O           8630
# LOCATION       2
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in df_aug['token_label'].unique() if l == 'LOCATION']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#     LOCATION       1.00      0.02      0.05        81
#
#    micro avg       1.00      0.02      0.05        81
#    macro avg       1.00      0.02      0.05        81
# weighted avg       1.00      0.02      0.05        81

# %% [markdown]
# ### 🎈 **license_parser**

# %%
df_aug = all_merged['license_parser']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM          O
# 1        11    13         FIH    LOCATION          O
# 2        15    21     0408267       IDNUM          O
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM          O
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O    8632
# Name: count, dtype: int64

# %% [markdown]
# **This model did not detect any entities in the current dataset.**

# %% [markdown]
# ### 🎈 **phone_matcher**

# %%
df_aug = all_merged['phone_matcher']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM          O
# 1        11    13         FIH    LOCATION          O
# 2        15    21     0408267       IDNUM          O
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM          O
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O        8631
# PHONE       1
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'PHONE':'CONTACT'})

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O          8631
# CONTACT       1
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in df_aug['token_label'].unique() if l == 'CONTACT']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#      CONTACT       1.00      0.33      0.50         3
#
#    micro avg       1.00      0.33      0.50         3
#    macro avg       1.00      0.33      0.50         3
# weighted avg       1.00      0.33      0.50         3

# %% [markdown]
# ### 🎈 **dln_parser**

# %%
df_aug = all_merged['dln_parser']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM          O
# 1        11    13         FIH    LOCATION          O
# 2        15    21     0408267       IDNUM          O
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM          O
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O    8632
# Name: count, dtype: int64

# %% [markdown]
# **This model did not detect any entities in the current dataset.**

# %% [markdown]
# ### 🎈 **vin_parser**

# %%
df_aug = all_merged['vin_parser']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM          O
# 1        11    13         FIH    LOCATION          O
# 2        15    21     0408267       IDNUM          O
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM          O
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O    8632
# Name: count, dtype: int64

# %% [markdown]
# **This model did not detect any entities in the current dataset.**

# %% [markdown]
# ### 🎈 **age_parser**

# %%
df_aug = all_merged['age_parser']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM          O
# 1        11    13         FIH    LOCATION          O
# 2        15    21     0408267       IDNUM          O
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM          O
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O      8624
# AGE       8
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in df_aug['token_label'].unique() if l == 'AGE']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#          AGE       1.00      0.40      0.57        20
#
#    micro avg       1.00      0.40      0.57        20
#    macro avg       1.00      0.40      0.57        20
# weighted avg       1.00      0.40      0.57        20

# %% [markdown]
# ### 🎈 **country_matcher**

# %%
df_aug = all_merged['country_matcher']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM          O
# 1        11    13         FIH    LOCATION          O
# 2        15    21     0408267       IDNUM          O
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM          O
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O          8630
# COUNTRY       2
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'COUNTRY':'LOCATION'})

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O           8630
# LOCATION       2
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in df_aug['token_label'].unique() if l == 'LOCATION']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#     LOCATION       0.50      0.01      0.02        81
#
#    micro avg       0.50      0.01      0.02        81
#    macro avg       0.50      0.01      0.02        81
# weighted avg       0.50      0.01      0.02        81

# %% [markdown]
# ### 🎈 **date_matcher**

# %%
df_aug = all_merged['date_matcher']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM          O
# 1        11    13         FIH    LOCATION          O
# 2        15    21     0408267       IDNUM          O
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM          O
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O       8496
# DATE     136
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in df_aug['token_label'].unique() if l == 'DATE']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#         DATE       0.99      0.63      0.77       213
#
#    micro avg       0.99      0.63      0.77       213
#    macro avg       0.99      0.63      0.77       213
# weighted avg       0.99      0.63      0.77       213

# %% [markdown]
# ### 🎈 **date_of_birth_parser**

# %%
df_aug = all_merged['date_of_birth_parser']
df_aug
# Out:
#       doc_id  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 8627       9
# 8628       9
# 8629       9
# 8630       9
# 8631       9
#
#                                                                                                                                                                                                          text  \
# 0     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 1     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 2     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 3     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# 4     \n957770228\nFIH\n0408267\n46769/5v7d\n237890\n2/5/1994 12:00:00 AM\nTRACHEOESOPHAGEAL FISTULA .\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n2-5-94\nDISCHARGE DATE :\n4-2-94\nPRIN...
# ...                                                                                                                                                                                                       ...
# 8627  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8628  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8629  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8630  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
# 8631  \n333145593\nFIH\n9229891\n50096/c65m\n571634\n12/5/1993 12:00:00 AM\nDischarge Summary\nUnsigned\nDIS\nReport Status :\nUnsigned\nADMISSION DATE :\n12/05/93\nDISCHARGE DATE :\n12/17/93\nCAUSE OF ...
#
#       begin   end       token token_label pred_label
# 0         1     9   957770228       IDNUM          O
# 1        11    13         FIH    LOCATION          O
# 2        15    21     0408267       IDNUM          O
# 3        23    32  46769/5v7d       IDNUM          O
# 4        34    39      237890       IDNUM          O
# ...     ...   ...         ...         ...        ...
# 8627   7602  7604         M.D           O          O
# 8628   7605  7605           .           O          O
# 8629   7607  7607           [           O          O
# 8630   7609  7618  report_end           O          O
# 8631   7620  7620           ]           O          O
#
# [8632 rows x 7 columns]

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O      8618
# DOB      14
# Name: count, dtype: int64

# %%
df_aug['pred_label'] = df_aug['pred_label'].replace({'DOB':'DATE'})

# %%
df_aug['pred_label'].value_counts()
# Out:
# pred_label
# O       8618
# DATE      14
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

y_true = df_aug['token_label']
y_pred = df_aug['pred_label']

labels = df_aug['token_label'].unique()
labels = [l for l in df_aug['token_label'].unique() if l == 'DATE']

print(classification_report(y_true, y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#         DATE       1.00      0.07      0.12       213
#
#    micro avg       1.00      0.07      0.12       213
#    macro avg       1.00      0.07      0.12       213
# weighted avg       1.00      0.07      0.12       213
