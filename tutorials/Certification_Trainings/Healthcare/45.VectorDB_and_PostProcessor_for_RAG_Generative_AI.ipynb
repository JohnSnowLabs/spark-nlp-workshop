# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/spark-nlp-workshop/blob/master/tutorials/Certification_Trainings/Healthcare/45.VectorDB_and_PostProcessor_for_RAG_Generative_AI.ipynb)

# %% [markdown]
# # VectorDB, VectorDBPostProcessor and ContextSplitAssembler

# %% [markdown]
# # Setup

# %%
import json
import os

from google.colab import files

if 'spark_jsl.json' not in os.listdir():
  license_keys = files.upload()
  os.rename(list(license_keys.keys())[0], 'spark_jsl.json')

with open('spark_jsl.json') as f:
    license_keys = json.load(f)

# Defining license key-value pairs as local variables
locals().update(license_keys)
os.environ.update(license_keys)

# %%
# Installing pyspark and spark-nlp
! pip install --upgrade -q pyspark==3.4.0  spark-nlp==$PUBLIC_VERSION

# Installing Spark NLP Healthcare
#! pip install --upgrade -q spark-nlp-jsl==$JSL_VERSION  --extra-index-url https://pypi.johnsnowlabs.com/$SECRET
! pip install --upgrade -q spark-nlp-jsl==5.4.0  --extra-index-url https://pypi.johnsnowlabs.com/5.4.0-db9b4c2dee65db7fa6100bcc05a0f609a2e1c396

# Installing Spark NLP Display Library for visualization
! pip install -q spark-nlp-display

# %%
import sparknlp
import sparknlp_jsl

from sparknlp.base import *
from sparknlp.util import *
from sparknlp.common import *
from sparknlp.annotator import *
from sparknlp_jsl.base import *
from sparknlp_jsl.annotator import *

import pyspark.sql.types as T
import pyspark.sql.functions as F
from pyspark.sql import SparkSession
from pyspark.ml import Pipeline, PipelineModel

spark = sparknlp_jsl.start(secret = "5.4.0-db9b4c2dee65db7fa6100bcc05a0f609a2e1c396", use_vectordb=True)

print("Spark NLP Version :", sparknlp.version())
print("Spark NLP_JSL Version :", sparknlp_jsl.version())

spark
# Out:
# Spark NLP Version : 5.4.0
# Spark NLP_JSL Version : 5.4.0
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://3ed86bd2098c:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark NLP Licensed</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# # DATAFRAME

# %%
! wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/healthcare-nlp/data/pubmed_diabetes_1000_meta.csv

# %%
from pyspark.sql.types import IntegerType, StringType, StructType, StructField

schema = StructType(
    [
        StructField("row_id", StringType(), nullable = True),
        StructField("pubmed_id", StringType(), nullable = True),
        StructField("abstract", StringType(), nullable = True),
        StructField("pubdate", StringType(), nullable = True),
        StructField("title", StringType(), nullable = True),
        StructField("fulljournalname", StringType(), nullable = True),
    ]
)

# %%
df = spark.read.option("header", "true")\
               .option("multiLine", "true")\
               .schema(schema)\
               .csv(path = "./pubmed_diabetes_1000_meta.csv")\
               .withColumnRenamed("abstract", "text")\
               .limit(100)

print(f"count: {df.count()}")
print(f"columns: {df.columns}")
# Out:
# count: 100
# columns: ['row_id', 'pubmed_id', 'text', 'pubdate', 'title', 'fulljournalname']

# %%
df.schema
# Out:
# StructType([StructField('row_id', StringType(), True), StructField('pubmed_id', StringType(), True), StructField('text', StringType(), True), StructField('pubdate', StringType(), True), StructField('title', StringType(), True), StructField('fulljournalname', StringType(), True)])

# %%
df.show(20,truncate=100)
# Out:
# +------+----------+----------------------------------------------------------------------------------------------------+-----------+----------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+
# |row_id| pubmed_id|                                                                                                text|    pubdate|                                                                                               title|                                                                      fulljournalname|
# +------+----------+----------------------------------------------------------------------------------------------------+-----------+----------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+
# |     0|PMC3312572|The pituitary gland and infundibulum can be involved in a variety of medical conditions, includin...|2012 Mar 18|                            Metastatic Prostate Adenocarcinoma Presenting Central Diabetes Insipidus|                                                             Case Reports in Medicine|
# |     1|PMC7730786|Current evidence suggests that the information needs of people with diabetes mellitus differ acro...|2020 Dec 10|  Different information needs in subgroups of people with diabetes mellitus: a latent class analysis|                                                                    BMC Public Health|
# |     2|PMC6913526|Ethnic minority populations exhibit disproportionately high rates of type 2 diabetes mellitus (T2...|2019 Oct 16|Development and Efficacy of an Electronic, Culturally Adapted Lifestyle Counseling Tool for Impro...|                                                 Journal of Medical Internet Research|
# |     3|PMC4653349|Recently, imbalance in the vasopressin (AVP) system, measured as elevated levels of copeptin (the...|   2016 Jan|                        Genetic vasopressin 1b receptor variance in overweight and diabetes mellitus|                                                    European Journal of Endocrinology|
# |     4|PMC8606862|Deterioration in glucose homeostasis has been associated with intestinal dysbiosis, but it is not...|2021 Nov 21|Progression of diabetes is associated with changes in the ileal transcriptome and ileal‐colon mor...|                                                                Physiological Reports|
# |     5|PMC8756324|We aimed to determine the hospital‐based prevalence and clinical features of fulminant type 1 dia...|2021 Aug 31|Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A...|                                                    Journal of Diabetes Investigation|
# |     6|PMC7245830|Although important advances in treatment strategies have been developed in type 2 diabetes mellit...|2020 May 24|Role of social and other determinants of health in the effect of a multicomponent integrated care...|                                           International Journal for Equity in Health|
# |     7|PMC7146037|Background: Diabetes is referred to a group of diseases characterized by high glucose levels in b...|2020 Mar 30|     Prevalence and incidence of type 1 diabetes in the world: a systematic review and meta-analysis|                                                        Health Promotion Perspectives|
# |     8|PMC4783042|Different studies have produced conflicting results regarding the association between smoking and...| 2016 Mar 8|Cigarette Smoking Is Associated with a Lower Prevalence of Newly Diagnosed Diabetes Screened by O...|                                                                             PLoS ONE|
# |     9|PMC5471766|The prevalence of diabetes in children and adolescents is increasing worldwide, with profound imp...|2016 Nov 10|                                     Challenges in diagnosis and management of diabetes in the young|                                                  Clinical Diabetes and Endocrinology|
# |    10|PMC6364380|The alteration of water balance and related disorders has emerged as being strictly linked to the...| 2019 Feb 4|           Vasopressin–aquaporin-2 pathway: recent advances in understanding water balance disorders|                                                                        F1000Research|
# |    11|PMC7404253|Gestational diabetes mellitus (GDM), characterized by a transitory form of diabetes induced by in...|2020 Jul 15|                         Gestational Diabetes Mellitus: A Harbinger of the Vicious Cycle of Diabetes|                                          International Journal of Molecular Sciences|
# |    12|PMC4975132|In Colombia, diabetes mellitus is a public health program for those responsible for creating and ...|2016 Jun 30|Clinical practice guideline for the prevention, early detection, diagnosis, management and follow...|                                                                 Colombia Médica : CM|
# |    13|PMC6826500|Type 2 diabetes mellitus (T2DM) and late-onset Alzheimer’s disease–dementia (LOAD) are increasing...|2019 Sep 29|Type 2 Diabetes Mellitus Increases the Risk of Late-Onset Alzheimer’s Disease: Ultrastructural Re...|                                                                       Brain Sciences|
# |    14|PMC5415486|Adipose tissue‐derived hormones are associated with metabolic disorders including type 2 diabetes...|2016 Oct 30|Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabe...|                                                    Journal of Diabetes Investigation|
# |    15|PMC5019196|Hypernatremia is a frequent cause of intensive care unit admission. The patient presented in this...| 2016 Sep 9|               Unusual Presentation of Central Diabetes Insipidus in a Patient With Neurosarcoidosis|                           Journal of Investigative Medicine High Impact Case Reports|
# |    16|PMC5800826|Immune checkpoint inhibitors, including anti–programmed cell death protein 1 (PD-1), anti–program...| 2017 Dec 6|                                             Anti–PD-L1 Treatment Induced Central Diabetes Insipidus|                                 The Journal of Clinical Endocrinology and Metabolism|
# |    17|PMC7045001|The emergence of tuberculosis (TB) and diabetes mellitus (DM) coepidemic threatens the gains made...|2020 Jan 21|Mapping evidence on the implementation of the WHO’s collaborative framework for the management of...|                                                                             BMJ Open|
# |    18|PMC6599074|Excessive glucocorticoid secretion has been associated with type 2 diabetes mellitus (T2DM) and o...| 2019 Jun 6|    Salivary cortisol is not associated with incident insulin resistance or type 2 diabetes mellitus|                                                                Endocrine Connections|
# |    19|PMC7955447|It is unclear whether reversion from pre–diabetes mellitus to normoglycemia reduces cardiovascula...|2021 Jan 26|Reversion From Pre–Diabetes Mellitus to Normoglycemia and Risk of Cardiovascular Disease and All‐...|Journal of the American Heart Association: Cardiovascular and Cerebrovascular Disease|
# +------+----------+----------------------------------------------------------------------------------------------------+-----------+----------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# # Pipeline Stages

# %%
document = DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")

splitter = InternalDocumentSplitter()\
    .setInputCols("document")\
    .setOutputCol("split")\
    .setSplitMode("regex")\
    .setSplitPatterns(["\n", "\r\n", "\n\n"])\
    .setExplodeSplits(True)\
    .setEnableSentenceIncrement(True)

embeddings = BertSentenceEmbeddings\
    .pretrained("sbiobert_base_cased_mli_onnx", "en", "clinical/models") \
    .setInputCols(["split"]) \
    .setOutputCol("embeddings")

embedding_pipeline = Pipeline().setStages([
    document,
    splitter,
    embeddings
])
# Out:
# sbiobert_base_cased_mli_onnx download started this may take some time.
# Approximate size to download 384.4 MB
# [OK!]

# %% [markdown]
# # Save Base DF

# %%
# %%time
embedding_pipeline.fit(df).transform(df)\
    .write.mode("overwrite")\
    .parquet("./pubmed_df.parquet")
# Out:
# CPU times: user 794 ms, sys: 89.2 ms, total: 884 ms
# Wall time: 2min 33s

# %%
baseDF = spark.read.load("./pubmed_df.parquet")

# %% [markdown]
# InternalDocumentSplitter has split documents by line split chars.
# DocumentSplitter has increased the length of df

# %%
baseDF.show(20,truncate=100)
baseDF.count()
# Out:
# +------+----------+----------------------------------------------------------------------------------------------------+-----------+----------------------------------------------------------------------------------------------------+------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+
# |row_id| pubmed_id|                                                                                                text|    pubdate|                                                                                               title|                     fulljournalname|                                                                                            document|                                                                                               split|                                                                                          embeddings|
# +------+----------+----------------------------------------------------------------------------------------------------+-----------+----------------------------------------------------------------------------------------------------+------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+
# |     0|PMC3312572|The pituitary gland and infundibulum can be involved in a variety of medical conditions, includin...|2012 Mar 18|                            Metastatic Prostate Adenocarcinoma Presenting Central Diabetes Insipidus|            Case Reports in Medicine|[{document, 0, 1206, The pituitary gland and infundibulum can be involved in a variety of medical...|[{document, 0, 1207, The pituitary gland and infundibulum can be involved in a variety of medical...|[{sentence_embeddings, 0, 1207, The pituitary gland and infundibulum can be involved in a variety...|
# |     1|PMC7730786|Current evidence suggests that the information needs of people with diabetes mellitus differ acro...|2020 Dec 10|  Different information needs in subgroups of people with diabetes mellitus: a latent class analysis|                   BMC Public Health|[{document, 0, 2050, Current evidence suggests that the information needs of people with diabetes...|[{document, 0, 509, Current evidence suggests that the information needs of people with diabetes ...|[{sentence_embeddings, 0, 509, Current evidence suggests that the information needs of people wit...|
# |     1|PMC7730786|Current evidence suggests that the information needs of people with diabetes mellitus differ acro...|2020 Dec 10|  Different information needs in subgroups of people with diabetes mellitus: a latent class analysis|                   BMC Public Health|[{document, 0, 2050, Current evidence suggests that the information needs of people with diabetes...|[{document, 510, 1151, This cross-sectional study was based on data from 837 respondents with dia...|[{sentence_embeddings, 510, 1151, This cross-sectional study was based on data from 837 responden...|
# |     1|PMC7730786|Current evidence suggests that the information needs of people with diabetes mellitus differ acro...|2020 Dec 10|  Different information needs in subgroups of people with diabetes mellitus: a latent class analysis|                   BMC Public Health|[{document, 0, 2050, Current evidence suggests that the information needs of people with diabetes...|[{document, 1152, 1676, We identified the following four classes of people with different informa...|[{sentence_embeddings, 1152, 1676, We identified the following four classes of people with differ...|
# |     1|PMC7730786|Current evidence suggests that the information needs of people with diabetes mellitus differ acro...|2020 Dec 10|  Different information needs in subgroups of people with diabetes mellitus: a latent class analysis|                   BMC Public Health|[{document, 0, 2050, Current evidence suggests that the information needs of people with diabetes...|[{document, 1677, 1971, Knowledge about different patient subgroups can be useful for tailored in...|[{sentence_embeddings, 1677, 1971, Knowledge about different patient subgroups can be useful for ...|
# |     1|PMC7730786|Current evidence suggests that the information needs of people with diabetes mellitus differ acro...|2020 Dec 10|  Different information needs in subgroups of people with diabetes mellitus: a latent class analysis|                   BMC Public Health|[{document, 0, 2050, Current evidence suggests that the information needs of people with diabetes...|[{document, 1972, 2051, Supplementary information accompanies this paper at 10.1186/s12889-020-09...|[{sentence_embeddings, 1972, 2051, Supplementary information accompanies this paper at 10.1186/s1...|
# |     2|PMC6913526|Ethnic minority populations exhibit disproportionately high rates of type 2 diabetes mellitus (T2...|2019 Oct 16|Development and Efficacy of an Electronic, Culturally Adapted Lifestyle Counseling Tool for Impro...|Journal of Medical Internet Research|[{document, 0, 3142, Ethnic minority populations exhibit disproportionately high rates of type 2 ...|[{document, 0, 281, Ethnic minority populations exhibit disproportionately high rates of type 2 d...|[{sentence_embeddings, 0, 281, Ethnic minority populations exhibit disproportionately high rates ...|
# |     2|PMC6913526|Ethnic minority populations exhibit disproportionately high rates of type 2 diabetes mellitus (T2...|2019 Oct 16|Development and Efficacy of an Electronic, Culturally Adapted Lifestyle Counseling Tool for Impro...|Journal of Medical Internet Research|[{document, 0, 3142, Ethnic minority populations exhibit disproportionately high rates of type 2 ...|[{document, 282, 691, This study aimed (1) to develop an adaptable Interactive Lifestyle Assessme...|[{sentence_embeddings, 282, 691, This study aimed (1) to develop an adaptable Interactive Lifesty...|
# |     2|PMC6913526|Ethnic minority populations exhibit disproportionately high rates of type 2 diabetes mellitus (T2...|2019 Oct 16|Development and Efficacy of an Electronic, Culturally Adapted Lifestyle Counseling Tool for Impro...|Journal of Medical Internet Research|[{document, 0, 3142, Ethnic minority populations exhibit disproportionately high rates of type 2 ...|[{document, 692, 1852, The I-ACE software, developed in consultation with clinical dieticians, in...|[{sentence_embeddings, 692, 1852, The I-ACE software, developed in consultation with clinical die...|
# |     2|PMC6913526|Ethnic minority populations exhibit disproportionately high rates of type 2 diabetes mellitus (T2...|2019 Oct 16|Development and Efficacy of an Electronic, Culturally Adapted Lifestyle Counseling Tool for Impro...|Journal of Medical Internet Research|[{document, 0, 3142, Ethnic minority populations exhibit disproportionately high rates of type 2 ...|[{document, 1853, 2650, A total of 25 participants were enrolled in each arm, of whom 24 and 21 c...|[{sentence_embeddings, 1853, 2650, A total of 25 participants were enrolled in each arm, of whom ...|
# |     2|PMC6913526|Ethnic minority populations exhibit disproportionately high rates of type 2 diabetes mellitus (T2...|2019 Oct 16|Development and Efficacy of an Electronic, Culturally Adapted Lifestyle Counseling Tool for Impro...|Journal of Medical Internet Research|[{document, 0, 3142, Ethnic minority populations exhibit disproportionately high rates of type 2 ...|[{document, 2651, 3062, The use of the I-ACE software in a 6-month, 4-session dietician-delivered...|[{sentence_embeddings, 2651, 3062, The use of the I-ACE software in a 6-month, 4-session dieticia...|
# |     2|PMC6913526|Ethnic minority populations exhibit disproportionately high rates of type 2 diabetes mellitus (T2...|2019 Oct 16|Development and Efficacy of an Electronic, Culturally Adapted Lifestyle Counseling Tool for Impro...|Journal of Medical Internet Research|[{document, 0, 3142, Ethnic minority populations exhibit disproportionately high rates of type 2 ...|[{document, 3063, 3143, ClinicalTrials.gov NCT01858506; https://clinicaltrials.gov/ct2/show/NCT01...|[{sentence_embeddings, 3063, 3143, ClinicalTrials.gov NCT01858506; https://clinicaltrials.gov/ct2...|
# |     3|PMC4653349|Recently, imbalance in the vasopressin (AVP) system, measured as elevated levels of copeptin (the...|   2016 Jan|                        Genetic vasopressin 1b receptor variance in overweight and diabetes mellitus|   European Journal of Endocrinology|[{document, 0, 1588, Recently, imbalance in the vasopressin (AVP) system, measured as elevated le...|[{document, 0, 370, Recently, imbalance in the vasopressin (AVP) system, measured as elevated lev...|[{sentence_embeddings, 0, 370, Recently, imbalance in the vasopressin (AVP) system, measured as e...|
# |     3|PMC4653349|Recently, imbalance in the vasopressin (AVP) system, measured as elevated levels of copeptin (the...|   2016 Jan|                        Genetic vasopressin 1b receptor variance in overweight and diabetes mellitus|   European Journal of Endocrinology|[{document, 0, 1588, Recently, imbalance in the vasopressin (AVP) system, measured as elevated le...|[{document, 371, 465, Malmö Diet and Cancer study (MDC) is a population-based prospective cohort ...|[{sentence_embeddings, 371, 465, Malmö Diet and Cancer study (MDC) is a population-based prospect...|
# |     3|PMC4653349|Recently, imbalance in the vasopressin (AVP) system, measured as elevated levels of copeptin (the...|   2016 Jan|                        Genetic vasopressin 1b receptor variance in overweight and diabetes mellitus|   European Journal of Endocrinology|[{document, 0, 1588, Recently, imbalance in the vasopressin (AVP) system, measured as elevated le...|[{document, 466, 781, Four tag single nucleotide polymorphisms (SNPs: rs35810727, rs28373064, rs3...|[{sentence_embeddings, 466, 781, Four tag single nucleotide polymorphisms (SNPs: rs35810727, rs28...|
# |     3|PMC4653349|Recently, imbalance in the vasopressin (AVP) system, measured as elevated levels of copeptin (the...|   2016 Jan|                        Genetic vasopressin 1b receptor variance in overweight and diabetes mellitus|   European Journal of Endocrinology|[{document, 0, 1588, Recently, imbalance in the vasopressin (AVP) system, measured as elevated le...|[{document, 782, 1317, In MDC-CC, the major allele of rs35810727 was associated with elevated BMI...|[{sentence_embeddings, 782, 1317, In MDC-CC, the major allele of rs35810727 was associated with e...|
# |     3|PMC4653349|Recently, imbalance in the vasopressin (AVP) system, measured as elevated levels of copeptin (the...|   2016 Jan|                        Genetic vasopressin 1b receptor variance in overweight and diabetes mellitus|   European Journal of Endocrinology|[{document, 0, 1588, Recently, imbalance in the vasopressin (AVP) system, measured as elevated le...|[{document, 1318, 1589, Genetic variance of AVPR1B contributes to overweight. Furthermore, our da...|[{sentence_embeddings, 1318, 1589, Genetic variance of AVPR1B contributes to overweight. Furtherm...|
# |     4|PMC8606862|Deterioration in glucose homeostasis has been associated with intestinal dysbiosis, but it is not...|2021 Nov 21|Progression of diabetes is associated with changes in the ileal transcriptome and ileal‐colon mor...|               Physiological Reports|[{document, 0, 2124, Deterioration in glucose homeostasis has been associated with intestinal dys...|[{document, 0, 1702, Deterioration in glucose homeostasis has been associated with intestinal dys...|[{sentence_embeddings, 0, 1702, Deterioration in glucose homeostasis has been associated with int...|
# |     4|PMC8606862|Deterioration in glucose homeostasis has been associated with intestinal dysbiosis, but it is not...|2021 Nov 21|Progression of diabetes is associated with changes in the ileal transcriptome and ileal‐colon mor...|               Physiological Reports|[{document, 0, 2124, Deterioration in glucose homeostasis has been associated with intestinal dys...|[{document, 1703, 2125, The advancement of diabetes in the UC Davis Type 2 Diabetes Mellitus (UCD...|[{sentence_embeddings, 1703, 2125, The advancement of diabetes in the UC Davis Type 2 Diabetes Me...|
# |     5|PMC8756324|We aimed to determine the hospital‐based prevalence and clinical features of fulminant type 1 dia...|2021 Aug 31|Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A...|   Journal of Diabetes Investigation|[{document, 0, 1871, We aimed to determine the hospital‐based prevalence and clinical features of...|[{document, 0, 121, We aimed to determine the hospital‐based prevalence and clinical features of ...|[{sentence_embeddings, 0, 121, We aimed to determine the hospital‐based prevalence and clinical f...|
# +------+----------+----------------------------------------------------------------------------------------------------+-----------+----------------------------------------------------------------------------------------------------+------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+
# only showing top 20 rows
# 243

# %% [markdown]
# # VectorDB Stage

# %% [markdown]
# ## Train a new VectorDB model

# %%
vector_db = VectorDBApproach()\
    .setInputCols("embeddings", "split")\
    .setOutputCol("vector_db")\
    .setMetaDataFields(["fulljournalname", "title", "pubdate"])\
    .setTopK(40)\
    .setIdentifierCol("pubmed_id")\
    .fit(baseDF)

# %% [markdown]
# Functions:
# - setMetadataFields: Columns in the dataframe from which to create partitions
# - setExcludeSelf: whether to include the row identifier as a candidate neighbor
# - setSimilarityThreshold: do not return neighbors further away than this distance
# - setNumReplicas: number of index replicas to create when querying
# - setIdentifierCol: column name for the row identifier
# - setDistanceFunction: distance function to use
# - setTopK: number of neighbors to find

# %% [markdown]
# ## Save a new VectorDB model

# %%
vector_db.write().overwrite().save("./models/new_vector_db_model")

# %% [markdown]
# ## Load a saved model

# %%
document = DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")

embeddings = BertSentenceEmbeddings\
    .pretrained("sbiobert_base_cased_mli_onnx", "en", "clinical/models") \
    .setInputCols(["document"]) \
    .setOutputCol("embeddings")

vector_db_loaded = VectorDBModel.load("./models/new_vector_db_model")\
    .setInputCols("embeddings", "document")\
    .setOutputCol("vector_db")\
    .setTopK(10)\

pipeline = Pipeline().setStages([
    document,


    embeddings.setInputCols("document"),
    vector_db_loaded
])

pipeline_model = pipeline.fit(spark.createDataFrame([[""]]))
# Out:
# sbiobert_base_cased_mli_onnx download started this may take some time.
# Approximate size to download 384.4 MB
# [OK!]

# %% [markdown]
# ## QUERY

# %%
query_1 = """What are the causes of diabetes?"""
query_2 = """relationship between diabetes and obesity"""

queries = [
    [query_1],
    [query_2]
]

query_df = spark.createDataFrame(queries).toDF("text")
query_df.show(truncate=False)
# Out:
# +-----------------------------------------+
# |text                                     |
# +-----------------------------------------+
# |What are the causes of diabetes?         |
# |relationship between diabetes and obesity|
# +-----------------------------------------+

# %%
result_df = pipeline_model.transform(query_df)
result_df.selectExpr("text","vector_db").show(truncate=False)
# Out:
# +-----------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |text                                     |vector_db                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# +-----------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |What are the causes of diabetes?         |[{vector_similarity_rankings, 0, 31, Current evidence suggests that the information needs of people with diabetes mellitus differ across patient groups. With a view to being able to provide individualized information, this study aims to identify (i) the diabetes-related information needs of people with diabetes mellitus; (ii) different subgroups of people with specific information needs; and (iii) associated characteristics of the identified subgroups, such as sociodemographic characteristics, diabetes-related comorbidities, and well-being., {fulljournalname -> BMC Public Health, document -> 0, uuid -> fbb7b54c-471e-47ec-9d12-b56b32f861d3, pieceId -> -1, score -> 0.74267092, target_text -> What are the causes of diabetes?, code -> PMC7730786-fbb7b54c-471e-47ec-9d12-b56b32f861d3, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> Current evidence suggests that the information needs of people with diabetes mellitus differ across patient groups. With a view to being able to provide individualized information, this study aims to identify (i) the diabetes-related information needs of people with diabetes mellitus; (ii) different subgroups of people with specific information needs; and (iii) associated characteristics of the identified subgroups, such as sociodemographic characteristics, diabetes-related comorbidities, and well-being., title -> Different information needs in subgroups of people with diabetes mellitus: a latent class analysis, pubdate -> 2020 Dec 10, distance -> 0.25732908, sentence -> 0}, []}, {vector_similarity_rankings, 0, 31, Background: Diabetes is referred to a group of diseases characterized by high glucose levels in blood. It is caused by a deficiency in the production or function of insulin or both, which can occur because of different reasons, resulting in protein and lipid metabolic disorders. The aim of this study was to systematically review the prevalence and incidence of type 1 diabetes in the world., {fulljournalname -> Health Promotion Perspectives, document -> 0, uuid -> 53f2c7c8-6bdb-48dc-b59a-b505b4623df2, pieceId -> -1, score -> 0.67687259, target_text -> What are the causes of diabetes?, code -> PMC7146037-53f2c7c8-6bdb-48dc-b59a-b505b4623df2, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> Background: Diabetes is referred to a group of diseases characterized by high glucose levels in blood. It is caused by a deficiency in the production or function of insulin or both, which can occur because of different reasons, resulting in protein and lipid metabolic disorders. The aim of this study was to systematically review the prevalence and incidence of type 1 diabetes in the world., title -> Prevalence and incidence of type 1 diabetes in the world: a systematic review and meta-analysis, pubdate -> 2020 Mar 30, distance -> 0.32312741, sentence -> 0}, []}, {vector_similarity_rankings, 0, 31, Adiponectin and pro‐inflammatory cytokines are associated with type 2 diabetes mellitus, and might serve as a prognostic marker and a therapeutic intervention for overweight‐related type 2 diabetes mellitus., {fulljournalname -> Journal of Diabetes Investigation, document -> 3, uuid -> 5ea2f001-9b35-45f0-90ba-633d2a004a65, pieceId -> -1, score -> 0.66904215, target_text -> What are the causes of diabetes?, code -> PMC5415486-5ea2f001-9b35-45f0-90ba-633d2a004a65, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> Adiponectin and pro‐inflammatory cytokines are associated with type 2 diabetes mellitus, and might serve as a prognostic marker and a therapeutic intervention for overweight‐related type 2 diabetes mellitus., title -> Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus, pubdate -> 2016 Oct 30, distance -> 0.33095785, sentence -> 3}, []}, {vector_similarity_rankings, 0, 31, Excessive glucocorticoid secretion has been a ...
# |relationship between diabetes and obesity|[{vector_similarity_rankings, 0, 40, Adiponectin and pro‐inflammatory cytokines are associated with type 2 diabetes mellitus, and might serve as a prognostic marker and a therapeutic intervention for overweight‐related type 2 diabetes mellitus., {fulljournalname -> Journal of Diabetes Investigation, document -> 3, uuid -> 5ea2f001-9b35-45f0-90ba-633d2a004a65, pieceId -> -1, score -> 0.81705717, target_text -> relationship between diabetes and obesity, code -> PMC5415486-5ea2f001-9b35-45f0-90ba-633d2a004a65, isWordStart -> true, token -> relationship between diabetes and obesity, resolved_text -> Adiponectin and pro‐inflammatory cytokines are associated with type 2 diabetes mellitus, and might serve as a prognostic marker and a therapeutic intervention for overweight‐related type 2 diabetes mellitus., title -> Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus, pubdate -> 2016 Oct 30, distance -> 0.18294283, sentence -> 3}, []}, {vector_similarity_rankings, 0, 40, MVD is associated with an excess HF risk in individuals with type 2 diabetes mellitus after adjusting for other known risk factors. Our findings underscore the contribution of MVD to the development of diabetes mellitus–related HF., {fulljournalname -> Journal of the American Heart Association: Cardiovascular and Cerebrovascular Disease, document -> 2, uuid -> 4e4ccec7-44c7-4aa7-995b-d32430803767, pieceId -> -1, score -> 0.78443956, target_text -> relationship between diabetes and obesity, code -> PMC8477890-4e4ccec7-44c7-4aa7-995b-d32430803767, isWordStart -> true, token -> relationship between diabetes and obesity, resolved_text -> MVD is associated with an excess HF risk in individuals with type 2 diabetes mellitus after adjusting for other known risk factors. Our findings underscore the contribution of MVD to the development of diabetes mellitus–related HF., title -> Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus, pubdate -> 2021 Jun 10, distance -> 0.21556044, sentence -> 2}, []}, {vector_similarity_rankings, 0, 40, Adipose tissue‐derived hormones are associated with metabolic disorders including type 2 diabetes mellitus. The present study investigated the levels of adiponectin and pro‐inflammatory cytokines including tumor necrosis factor‐α (TNF‐α), interleukin‐1 beta (IL‐1β) and IL‐10 in Vietnamese patients with type 2 diabetes mellitus, and their correlations with clinical parameters of overweight and type 2 diabetes mellitus., {fulljournalname -> Journal of Diabetes Investigation, document -> 0, uuid -> 6f8898ea-43c1-48f4-94e3-1b737b00aa6c, pieceId -> -1, score -> 0.77110173, target_text -> relationship between diabetes and obesity, code -> PMC5415486-6f8898ea-43c1-48f4-94e3-1b737b00aa6c, isWordStart -> true, token -> relationship between diabetes and obesity, resolved_text -> Adipose tissue‐derived hormones are associated with metabolic disorders including type 2 diabetes mellitus. The present study investigated the levels of adiponectin and pro‐inflammatory cytokines including tumor necrosis factor‐α (TNF‐α), interleukin‐1 beta (IL‐1β) and IL‐10 in Vietnamese patients with type 2 diabetes mellitus, and their correlations with clinical parameters of overweight and type 2 diabetes mellitus., title -> Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus, pubdate -> 2016 Oct 30, distance -> 0.22889827, sentence -> 0}, []}, {vector_similarity_rankings, 0, 40, Genetic variance of AVPR1B contributes to overweight. Furthermore, our data indicate a link between AVPR1B variance and DM development. Our data point at a relationship between the disturbance of the pharmacologically modifiable AVP system and the body weight regulation., {fulljournalname -> European Journal of Endocrinology, document -> 4, uuid -> 9bba9908-aba8-4e0e-a936-267a7c021c26, pieceId -> -1, s ...
# +-----------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...

# %%
result_df.selectExpr("text","explode(vector_db) as vector_db_annotations").show(truncate=False)
# Out:
# +-----------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |text                                     |vector_db_annotations                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# +-----------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |What are the causes of diabetes?         |{vector_similarity_rankings, 0, 31, Current evidence suggests that the information needs of people with diabetes mellitus differ across patient groups. With a view to being able to provide individualized information, this study aims to identify (i) the diabetes-related information needs of people with diabetes mellitus; (ii) different subgroups of people with specific information needs; and (iii) associated characteristics of the identified subgroups, such as sociodemographic characteristics, diabetes-related comorbidities, and well-being., {fulljournalname -> BMC Public Health, document -> 0, uuid -> fbb7b54c-471e-47ec-9d12-b56b32f861d3, pieceId -> -1, score -> 0.74267092, target_text -> What are the causes of diabetes?, code -> PMC7730786-fbb7b54c-471e-47ec-9d12-b56b32f861d3, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> Current evidence suggests that the information needs of people with diabetes mellitus differ across patient groups. With a view to being able to provide individualized information, this study aims to identify (i) the diabetes-related information needs of people with diabetes mellitus; (ii) different subgroups of people with specific information needs; and (iii) associated characteristics of the identified subgroups, such as sociodemographic characteristics, diabetes-related comorbidities, and well-being., title -> Different information needs in subgroups of people with diabetes mellitus: a latent class analysis, pubdate -> 2020 Dec 10, distance -> 0.25732908, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# |What are the causes of diabetes?         |{vector_similarity_rankings, 0, 31, Background: Diabetes is referred to a group of diseases characterized by high glucose levels in blood. It is caused by a deficiency in the production or function of insulin or both, which can occur because of different reasons, resulting in protein and lipid metabolic disorders. The aim of this study was to systematically review the prevalence and incidence of type 1 diabetes in the world., {fulljournalname -> Health Promotion Perspectives, document -> 0, uuid -> 53f2c7c8-6bdb-48dc-b59a-b505b4623df2, pieceId -> -1, score -> 0.67687259, target_text -> What are the causes of diabetes?, code -> PMC7146037-53f2c7c8-6bdb-48dc-b59a-b505b4623df2, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> Background: Diabetes is referred to a group of diseases characterized by high glucose levels in blood. It is caused by a deficiency in the production or function of insulin or both, which can occur because of different reasons, resulting in protein and lipid metabolic disorders. The aim of this study was to systematically review the prevalence and incidence of type 1 diabetes in the world., title -> Prevalence and incidence of type 1 diabetes in the world: a systematic review and meta-analysis, pubdate -> 2020 Mar 30, distance -> 0.32312741, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |What are the causes of diabetes?         |{vector_similarity_rankings, 0, 31, Adiponectin and pro‐inflammatory cytokines are associated with type 2 diabetes mellitus, and might serve as a prognostic marker and a therapeutic intervention for overweight‐related type 2 diabetes mellitus., {fulljournalname -> Journal of Diabetes Investigation, document -> 3, uuid -> 5ea2f001-9b35-45f0-90ba-633d2a004a65, pieceId -> -1, score -> 0.66904215, target_text -> What are the causes of diabetes?, code -> PMC5415486-5ea2f001-9b35-45f0-90ba-633d2a004a65, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> Adiponectin and pro‐inflammatory cytokines are associated with type 2 diabetes mellitus, and might serve as a prognostic marker and a therapeutic intervention for overweight‐related type 2 diabetes mellitus., title -> Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus, pubdate -> 2016 Oct 30, distance -> 0.33095785, sentence -> 3}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |What are the causes of diabetes?         |{vector_similarity_rankings, 0, 31, Excessive glucocorticoid secretion has been associated with type 2 diabetes mellitus (T2DM) and other features of the metabolic syndrome. We aimed to evaluate whether basal or evening salivary cortisol may predict the occurrence of incident insulin resistance (IR) or T2DM., {fulljournalname -> Endocrine Connections, document -> 0, uuid -> ca9bf9b6-9f94-401d-9134-5687b29a8662, pieceId -> -1, score -> 0.65421363, target_text -> What are the causes of diabetes?, code -> PMC6599074-ca9bf9b6-9f94-401d-9134-5687b29a8662, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> Excessive glucocorticoid secretion has been associated with type 2 diabetes mellitus (T2DM) and other features of the metabolic syndrome. We aimed to evaluate whether basal or evening salivary cortisol may predict the occurrence of incident insulin resistance (IR) or T2DM., title -> Salivary cortisol is not associated with incident insulin resistance or type 2 diabetes mellitus, pubdate -> 2019 Jun 6, distance -> 0.34578637, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |What are the causes of diabetes?         |{vector_similarity_rankings, 0, 31, These findings suggest a possible role for SERPINA3 in the development of the early stages of type 2 diabetes mellitus, although further replication studies and functional investigations regarding their role are required., {fulljournalname -> Journal of Diabetes Investigation, document -> 3, uuid -> 2bc3e8d1-3160-4c61-a442-3c52984cc69d, pieceId -> -1, score -> 0.64962672, target_text -> What are the causes of diabetes?, code -> PMC5583949-2bc3e8d1-3160-4c61-a442-3c52984cc69d, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> These findings suggest a possible role for SERPINA3 in the development of the early stages of type 2 diabetes mellitus, although further replication studies and functional investigations regarding their role are required., title -> Proteomic analysis of serum biomarkers for prediabetes using the Long‐Evans Agouti rat, a spontaneous animal model of type 2 diabetes mellitus, pubdate -> 2017 Mar 27, distance -> 0.35037328, sentence -> 3}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |What are the causes of diabetes?         |{vector_similarity_rankings, 0, 31, We provide novel information on the prevalence and clinical features of fulminant type 1 diabetes mellitus in Korea., {fulljournalname -> Journal of Diabetes Investigation, document -> 4, uuid -> b3b39bc4-9f02-400f-b1e5-8ae313765533, pieceId -> -1, score -> 0.63333490, target_text -> What are the causes of diabetes?, code -> PMC8756324-b3b39bc4-9f02-400f-b1e5-8ae313765533, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> We provide novel information on the prevalence and clinical features of fulminant type 1 diabetes mellitus in Korea., title -> Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research, pubdate -> 2021 Aug 31, distance -> 0.36666510, sentence -> 4}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# |What are the causes of diabetes?         |{vector_similarity_rankings, 0, 31, Adipose tissue‐derived hormones are associated with metabolic disorders including type 2 diabetes mellitus. The present study investigated the levels of adiponectin and pro‐inflammatory cytokines including tumor necrosis factor‐α (TNF‐α), interleukin‐1 beta (IL‐1β) and IL‐10 in Vietnamese patients with type 2 diabetes mellitus, and their correlations with clinical parameters of overweight and type 2 diabetes mellitus., {fulljournalname -> Journal of Diabetes Investigation, document -> 0, uuid -> 6f8898ea-43c1-48f4-94e3-1b737b00aa6c, pieceId -> -1, score -> 0.62630709, target_text -> What are the causes of diabetes?, code -> PMC5415486-6f8898ea-43c1-48f4-94e3-1b737b00aa6c, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> Adipose tissue‐derived hormones are associated with metabolic disorders including type 2 diabetes mellitus. The present study investigated the levels of adiponectin and pro‐inflammatory cytokines including tumor necrosis factor‐α (TNF‐α), interleukin‐1 beta (IL‐1β) and IL‐10 in Vietnamese patients with type 2 diabetes mellitus, and their correlations with clinical parameters of overweight and type 2 diabetes mellitus., title -> Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus, pubdate -> 2016 Oct 30, distance -> 0.37369291, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# |What are the causes of diabetes?         |{vector_similarity_rankings, 0, 31, MVD is associated with an excess HF risk in individuals with type 2 diabetes mellitus after adjusting for other known risk factors. Our findings underscore the contribution of MVD to the development of diabetes mellitus–related HF., {fulljournalname -> Journal of the American Heart Association: Cardiovascular and Cerebrovascular Disease, document -> 2, uuid -> 4e4ccec7-44c7-4aa7-995b-d32430803767, pieceId -> -1, score -> 0.61528191, target_text -> What are the causes of diabetes?, code -> PMC8477890-4e4ccec7-44c7-4aa7-995b-d32430803767, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> MVD is associated with an excess HF risk in individuals with type 2 diabetes mellitus after adjusting for other known risk factors. Our findings underscore the contribution of MVD to the development of diabetes mellitus–related HF., title -> Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus, pubdate -> 2021 Jun 10, distance -> 0.38471809, sentence -> 2}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |What are the causes of diabetes?         |{vector_similarity_rankings, 0, 31, The present meta‐analysis was carried out to assess the association between exposure to the level of atmospheric particulate matter 2.5 (PM2.5; fine particulate matter with aerodynamic diameter less than 2.5 μm) and type 2 diabetes mellitus or gestational diabetes mellitus (GDM)., {fulljournalname -> Journal of Diabetes Investigation, document -> 0, uuid -> f7588513-39c0-4f9b-b3c0-46bfb1c315aa, pieceId -> -1, score -> 0.60167503, target_text -> What are the causes of diabetes?, code -> PMC5583950-f7588513-39c0-4f9b-b3c0-46bfb1c315aa, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> The present meta‐analysis was carried out to assess the association between exposure to the level of atmospheric particulate matter 2.5 (PM2.5; fine particulate matter with aerodynamic diameter less than 2.5 μm) and type 2 diabetes mellitus or gestational diabetes mellitus (GDM)., title -> Association between particulate matter 2.5 and diabetes mellitus: A meta‐analysis of cohort studies, pubdate -> 2017 May 3, distance -> 0.39832497, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |What are the causes of diabetes?         |{vector_similarity_rankings, 0, 31, We aimed to determine the hospital‐based prevalence and clinical features of fulminant type 1 diabetes mellitus in Korea., {fulljournalname -> Journal of Diabetes Investigation, document -> 0, uuid -> 43adc9b2-d974-4b18-b732-ca8afa133082, pieceId -> -1, score -> 0.59917990, target_text -> What are the causes of diabetes?, code -> PMC8756324-43adc9b2-d974-4b18-b732-ca8afa133082, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> We aimed to determine the hospital‐based prevalence and clinical features of fulminant type 1 diabetes mellitus in Korea., title -> Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research, pubdate -> 2021 Aug 31, distance -> 0.40082010, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# ...
# |relationship between diabetes and obesity|{vector_similarity_rankings, 0, 40, Ethnic minority populations exhibit disproportionately high rates of type 2 diabetes mellitus (T2DM). Electronic health tools have the potential to facilitate the cultural adaptation and tailoring of T2DM education to improve the knowledge and management of diabetes mellitus (DM)., {fulljournalname -> Journal of Medical Internet Research, document -> 0, uuid -> 3405ecb9-ddfb-4064-9eee-874e26fd49ce, pieceId -> -1, score -> 0.70460826, target_text -> relationship between diabetes and obesity, code -> PMC6913526-3405ecb9-ddfb-4064-9eee-874e26fd49ce, isWordStart -> true, token -> relationship between diabetes and obesity, resolved_text -> Ethnic minority populations exhibit disproportionately high rates of type 2 diabetes mellitus (T2DM). Electronic health tools have the potential to facilitate the cultural adaptation and tailoring of T2DM education to improve the knowledge and management of diabetes mellitus (DM)., title -> Development and Efficacy of an Electronic, Culturally Adapted Lifestyle Counseling Tool for Improving Diabetes-Related Dietary Knowledge: Randomized Controlled Trial Among Ethnic Minority Adults With Type 2 Diabetes Mellitus, pubdate -> 2019 Oct 16, distance -> 0.29539174, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# |relationship between diabetes and obesity|{vector_similarity_rankings, 0, 40, Background: Diabetes is referred to a group of diseases characterized by high glucose levels in blood. It is caused by a deficiency in the production or function of insulin or both, which can occur because of different reasons, resulting in protein and lipid metabolic disorders. The aim of this study was to systematically review the prevalence and incidence of type 1 diabetes in the world., {fulljournalname -> Health Promotion Perspectives, document -> 0, uuid -> 53f2c7c8-6bdb-48dc-b59a-b505b4623df2, pieceId -> -1, score -> 0.70399022, target_text -> relationship between diabetes and obesity, code -> PMC7146037-53f2c7c8-6bdb-48dc-b59a-b505b4623df2, isWordStart -> true, token -> relationship between diabetes and obesity, resolved_text -> Background: Diabetes is referred to a group of diseases characterized by high glucose levels in blood. It is caused by a deficiency in the production or function of insulin or both, which can occur because of different reasons, resulting in protein and lipid metabolic disorders. The aim of this study was to systematically review the prevalence and incidence of type 1 diabetes in the world., title -> Prevalence and incidence of type 1 diabetes in the world: a systematic review and meta-analysis, pubdate -> 2020 Mar 30, distance -> 0.29600978, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# |relationship between diabetes and obesity|{vector_similarity_rankings, 0, 40, The increasing prevalence of older adults with diabetes has become a major social burden. Diabetes, frailty, and cognitive dysfunction are closely related to the mechanisms of aging. Insulin resistance, arteriosclerosis, chronic inflammation, oxidative stress, and mitochondrial dysfunction may be common mechanisms shared by frailty and cognitive impairment. Hyperglycemia, hypoglycemia, obesity, vascular factors, physical inactivity, and malnutrition are important risk factors for cognitive impairment and frailty in older adults with diabetes. The impact of nutrients on health outcomes varies with age; thus, shifting diet therapy strategies from the treatment of obesity/metabolic syndrome to frailty prevention may be necessary in patients with diabetes who are over 75 years of age, have frailty or sarcopenia, and experience malnutrition. For the prevention of frailty, optimal energy intake, sufficient protein and vitamin intake, and healthy dietary patterns should be recommended. The treatment of diabetes after middle age should include the awareness of proper glycemic control aimed at extending healthy life expectancy with proper nutrition, exercise, and social connectivity. Nutritional therapy in combination with exercise, optimal glycemic and metabolic control, and social participation/support for frailty prevention can extend healthy life expectancy and maintain quality of life in older adults with diabetes mellitus., {fulljournalname -> Nutrients, document -> 0, uuid -> 25bc2579-14a2-46d6-bb92-506819e37d26, pieceId -> -1, score -> 0.67858838, target_text -> relationship between diabetes and obesity, code -> PMC7693664-25bc2579-14a2-46d6-bb92-506819e37d26, isWordStart -> true, token -> relationship between diabetes and obesity, resolved_text -> The increasing prevalence of older adults with diabetes has become a major social burden. Diabetes, frailty, and cognitive dysfunction are closely related to the mechanisms of aging. Insulin resistance, arteriosclerosis, chronic inflammation, oxidative stress, and mitochondrial dysfunction may be common mechanisms shared by frailty and cognitive impairment. Hyperglycemia, hypoglycemia, obesity, vascular factors, physical inactivity, and malnutrition are important risk factors for cognitive impairment and frailty in older adults with diabetes. The impact of nutrients on health outcomes varies with age; thus, shifting diet therapy strategies from the treatment of obesity/metabolic syndrome to frailty prevention may be necessary in patients with diabetes who are over 75 years of age, have frailty or sarcopenia, and experience malnutrition. For the prevention of frailty, optimal energy intake, sufficient protein and vitamin intake, and healthy dietary patterns should be recommended. The treatment of diabetes after middle age should include the awareness of proper glycemic control aimed at extending healthy life expectancy with proper nutrition, exercise, and social connectivity. Nutritional therapy in combination with exercise, optimal glycemic and metabolic control, and social participation/support for frailty prevention can extend healthy life expectancy and maintain quality of life in older adults with diabetes mellitus., title -> Nutrition Management in Older Adults with Diabetes: A Review on the Importance of Shifting Prevention Strategies from Metabolic Syndrome to Frailty, pubdate -> 2020 Nov 1, distance -> 0.32141162, sentence -> 0}, []}|
# +-----------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# ## Check the metadata

# %%
result_df.selectExpr("explode(vector_db.metadata) as vector_db_annotation_metadata").show(truncate=False)
# Out:
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |vector_db_annotation_metadata                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{fulljournalname -> BMC Public Health, document -> 0, uuid -> fbb7b54c-471e-47ec-9d12-b56b32f861d3, pieceId -> -1, score -> 0.74267092, target_text -> What are the causes of diabetes?, code -> PMC7730786-fbb7b54c-471e-47ec-9d12-b56b32f861d3, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> Current evidence suggests that the information needs of people with diabetes mellitus differ across patient groups. With a view to being able to provide individualized information, this study aims to identify (i) the diabetes-related information needs of people with diabetes mellitus; (ii) different subgroups of people with specific information needs; and (iii) associated characteristics of the identified subgroups, such as sociodemographic characteristics, diabetes-related comorbidities, and well-being., title -> Different information needs in subgroups of people with diabetes mellitus: a latent class analysis, pubdate -> 2020 Dec 10, distance -> 0.25732908, sentence -> 0}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |{fulljournalname -> Health Promotion Perspectives, document -> 0, uuid -> 53f2c7c8-6bdb-48dc-b59a-b505b4623df2, pieceId -> -1, score -> 0.67687259, target_text -> What are the causes of diabetes?, code -> PMC7146037-53f2c7c8-6bdb-48dc-b59a-b505b4623df2, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> Background: Diabetes is referred to a group of diseases characterized by high glucose levels in blood. It is caused by a deficiency in the production or function of insulin or both, which can occur because of different reasons, resulting in protein and lipid metabolic disorders. The aim of this study was to systematically review the prevalence and incidence of type 1 diabetes in the world., title -> Prevalence and incidence of type 1 diabetes in the world: a systematic review and meta-analysis, pubdate -> 2020 Mar 30, distance -> 0.32312741, sentence -> 0}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |{fulljournalname -> Journal of Diabetes Investigation, document -> 3, uuid -> 5ea2f001-9b35-45f0-90ba-633d2a004a65, pieceId -> -1, score -> 0.66904215, target_text -> What are the causes of diabetes?, code -> PMC5415486-5ea2f001-9b35-45f0-90ba-633d2a004a65, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> Adiponectin and pro‐inflammatory cytokines are associated with type 2 diabetes mellitus, and might serve as a prognostic marker and a therapeutic intervention for overweight‐related type 2 diabetes mellitus., title -> Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus, pubdate -> 2016 Oct 30, distance -> 0.33095785, sentence -> 3}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |{fulljournalname -> Endocrine Connections, document -> 0, uuid -> ca9bf9b6-9f94-401d-9134-5687b29a8662, pieceId -> -1, score -> 0.65421363, target_text -> What are the causes of diabetes?, code -> PMC6599074-ca9bf9b6-9f94-401d-9134-5687b29a8662, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> Excessive glucocorticoid secretion has been associated with type 2 diabetes mellitus (T2DM) and other features of the metabolic syndrome. We aimed to evaluate whether basal or evening salivary cortisol may predict the occurrence of incident insulin resistance (IR) or T2DM., title -> Salivary cortisol is not associated with incident insulin resistance or type 2 diabetes mellitus, pubdate -> 2019 Jun 6, distance -> 0.34578637, sentence -> 0}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# |{fulljournalname -> Journal of Diabetes Investigation, document -> 3, uuid -> 2bc3e8d1-3160-4c61-a442-3c52984cc69d, pieceId -> -1, score -> 0.64962672, target_text -> What are the causes of diabetes?, code -> PMC5583949-2bc3e8d1-3160-4c61-a442-3c52984cc69d, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> These findings suggest a possible role for SERPINA3 in the development of the early stages of type 2 diabetes mellitus, although further replication studies and functional investigations regarding their role are required., title -> Proteomic analysis of serum biomarkers for prediabetes using the Long‐Evans Agouti rat, a spontaneous animal model of type 2 diabetes mellitus, pubdate -> 2017 Mar 27, distance -> 0.35037328, sentence -> 3}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |{fulljournalname -> Journal of Diabetes Investigation, document -> 4, uuid -> b3b39bc4-9f02-400f-b1e5-8ae313765533, pieceId -> -1, score -> 0.63333490, target_text -> What are the causes of diabetes?, code -> PMC8756324-b3b39bc4-9f02-400f-b1e5-8ae313765533, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> We provide novel information on the prevalence and clinical features of fulminant type 1 diabetes mellitus in Korea., title -> Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research, pubdate -> 2021 Aug 31, distance -> 0.36666510, sentence -> 4}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |{fulljournalname -> Journal of Diabetes Investigation, document -> 0, uuid -> 6f8898ea-43c1-48f4-94e3-1b737b00aa6c, pieceId -> -1, score -> 0.62630709, target_text -> What are the causes of diabetes?, code -> PMC5415486-6f8898ea-43c1-48f4-94e3-1b737b00aa6c, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> Adipose tissue‐derived hormones are associated with metabolic disorders including type 2 diabetes mellitus. The present study investigated the levels of adiponectin and pro‐inflammatory cytokines including tumor necrosis factor‐α (TNF‐α), interleukin‐1 beta (IL‐1β) and IL‐10 in Vietnamese patients with type 2 diabetes mellitus, and their correlations with clinical parameters of overweight and type 2 diabetes mellitus., title -> Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus, pubdate -> 2016 Oct 30, distance -> 0.37369291, sentence -> 0}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |{fulljournalname -> Journal of the American Heart Association: Cardiovascular and Cerebrovascular Disease, document -> 2, uuid -> 4e4ccec7-44c7-4aa7-995b-d32430803767, pieceId -> -1, score -> 0.61528191, target_text -> What are the causes of diabetes?, code -> PMC8477890-4e4ccec7-44c7-4aa7-995b-d32430803767, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> MVD is associated with an excess HF risk in individuals with type 2 diabetes mellitus after adjusting for other known risk factors. Our findings underscore the contribution of MVD to the development of diabetes mellitus–related HF., title -> Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus, pubdate -> 2021 Jun 10, distance -> 0.38471809, sentence -> 2}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |{fulljournalname -> Journal of Diabetes Investigation, document -> 0, uuid -> f7588513-39c0-4f9b-b3c0-46bfb1c315aa, pieceId -> -1, score -> 0.60167503, target_text -> What are the causes of diabetes?, code -> PMC5583950-f7588513-39c0-4f9b-b3c0-46bfb1c315aa, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> The present meta‐analysis was carried out to assess the association between exposure to the level of atmospheric particulate matter 2.5 (PM2.5; fine particulate matter with aerodynamic diameter less than 2.5 μm) and type 2 diabetes mellitus or gestational diabetes mellitus (GDM)., title -> Association between particulate matter 2.5 and diabetes mellitus: A meta‐analysis of cohort studies, pubdate -> 2017 May 3, distance -> 0.39832497, sentence -> 0}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# |{fulljournalname -> Journal of Diabetes Investigation, document -> 0, uuid -> 43adc9b2-d974-4b18-b732-ca8afa133082, pieceId -> -1, score -> 0.59917990, target_text -> What are the causes of diabetes?, code -> PMC8756324-43adc9b2-d974-4b18-b732-ca8afa133082, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> We aimed to determine the hospital‐based prevalence and clinical features of fulminant type 1 diabetes mellitus in Korea., title -> Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research, pubdate -> 2021 Aug 31, distance -> 0.40082010, sentence -> 0}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# |{fulljournalname -> Journal of Diabetes Investigation, document -> 3, uuid -> 5ea2f001-9b35-45f0-90ba-633d2a004a65, pieceId -> -1, score -> 0.81705717, target_text -> relationship between diabetes and obesity, code -> PMC5415486-5ea2f001-9b35-45f0-90ba-633d2a004a65, isWordStart -> true, token -> relationship between diabetes and obesity, resolved_text -> Adiponectin and pro‐inflammatory cytokines are associated with type 2 diabetes mellitus, and might serve as a prognostic marker and a therapeutic intervention for overweight‐related type 2 diabetes mellitus., title -> Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus, pubdate -> 2016 Oct 30, distance -> 0.18294283, sentence -> 3}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# |{fulljournalname -> Journal of the American Heart Association: Cardiovascular and Cerebrovascular Disease, document -> 2, uuid -> 4e4ccec7-44c7-4aa7-995b-d32430803767, pieceId -> -1, score -> 0.78443956, target_text -> relationship between diabetes and obesity, code -> PMC8477890-4e4ccec7-44c7-4aa7-995b-d32430803767, isWordStart -> true, token -> relationship between diabetes and obesity, resolved_text -> MVD is associated with an excess HF risk in individuals with type 2 diabetes mellitus after adjusting for other known risk factors. Our findings underscore the contribution of MVD to the development of diabetes mellitus–related HF., title -> Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus, pubdate -> 2021 Jun 10, distance -> 0.21556044, sentence -> 2}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# |{fulljournalname -> Journal of Diabetes Investigation, document -> 0, uuid -> 6f8898ea-43c1-48f4-94e3-1b737b00aa6c, pieceId -> -1, score -> 0.77110173, target_text -> relationship between diabetes and obesity, code -> PMC5415486-6f8898ea-43c1-48f4-94e3-1b737b00aa6c, isWordStart -> true, token -> relationship between diabetes and obesity, resolved_text -> Adipose tissue‐derived hormones are associated with metabolic disorders including type 2 diabetes mellitus. The present study investigated the levels of adiponectin and pro‐inflammatory cytokines including tumor necrosis factor‐α (TNF‐α), interleukin‐1 beta (IL‐1β) and IL‐10 in Vietnamese patients with type 2 diabetes mellitus, and their correlations with clinical parameters of overweight and type 2 diabetes mellitus., title -> Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus, pubdate -> 2016 Oct 30, distance -> 0.22889827, sentence -> 0}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# |{fulljournalname -> European Journal of Endocrinology, document -> 4, uuid -> 9bba9908-aba8-4e0e-a936-267a7c021c26, pieceId -> -1, score -> 0.76566081, target_text -> relationship between diabetes and obesity, code -> PMC4653349-9bba9908-aba8-4e0e-a936-267a7c021c26, isWordStart -> true, token -> relationship between diabetes and obesity, resolved_text -> Genetic variance of AVPR1B contributes to overweight. Furthermore, our data indicate a link between AVPR1B variance and DM development. Our data point at a relationship between the disturbance of the pharmacologically modifiable AVP system and the body weight regulation., title -> Genetic vasopressin 1b receptor variance in overweight and diabetes mellitus, pubdate -> 2016 Jan, distance -> 0.23433919, sentence -> 4}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# |{fulljournalname -> Endocrine Connections, document -> 0, uuid -> ca9bf9b6-9f94-401d-9134-5687b29a8662, pieceId -> -1, score -> 0.75506246, target_text -> relationship between diabetes and obesity, code -> PMC6599074-ca9bf9b6-9f94-401d-9134-5687b29a8662, isWordStart -> true, token -> relationship between diabetes and obesity, resolved_text -> Excessive glucocorticoid secretion has been associated with type 2 diabetes mellitus (T2DM) and other features of the metabolic syndrome. We aimed to evaluate whether basal or evening salivary cortisol may predict the occurrence of incident insulin resistance (IR) or T2DM., title -> Salivary cortisol is not associated with incident insulin resistance or type 2 diabetes mellitus, pubdate -> 2019 Jun 6, distance -> 0.24493754, sentence -> 0}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# |{fulljournalname -> European Journal of Endocrinology, document -> 0, uuid -> 64398a66-eddf-45d8-9082-7a7d28ff3bfd, pieceId -> -1, score -> 0.72744142, target_text -> relationship between diabetes and obesity, code -> PMC4653349-64398a66-eddf-45d8-9082-7a7d28ff3bfd, isWordStart -> true, token -> relationship between diabetes and obesity, resolved_text -> Recently, imbalance in the vasopressin (AVP) system, measured as elevated levels of copeptin (the C-terminal part of the AVP pro-hormone) in plasma, was linked to the development of abdominal obesity and diabetes mellitus (DM). Here, we aim to investigate if the genetic variation of the human AVP receptor 1b gene (AVPR1B) is associated with measures of obesity and DM., title -> Genetic vasopressin 1b receptor variance in overweight and diabetes mellitus, pubdate -> 2016 Jan, distance -> 0.27255858, sentence -> 0}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# |{fulljournalname -> American Journal of Obstetrics and Gynecology, document -> 0, uuid -> eccc0fe9-51c5-46e2-af51-8133d8403ea7, pieceId -> -1, score -> 0.72434327, target_text -> relationship between diabetes and obesity, code -> PMC8686449-eccc0fe9-51c5-46e2-af51-8133d8403ea7, isWordStart -> true, token -> relationship between diabetes and obesity, resolved_text -> Among nonpregnant individuals, diabetes mellitus and high body mass index increase the risk of COVID-19 and its severity., title -> Diabetes mellitus, maternal adiposity, and insulin-dependent gestational diabetes are associated with COVID-19 in pregnancy: the INTERCOVID study, pubdate -> 2021 Dec 20, distance -> 0.27565673, sentence -> 0}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |{fulljournalname -> Journal of Medical Internet Research, document -> 0, uuid -> 3405ecb9-ddfb-4064-9eee-874e26fd49ce, pieceId -> -1, score -> 0.70460826, target_text -> relationship between diabetes and obesity, code -> PMC6913526-3405ecb9-ddfb-4064-9eee-874e26fd49ce, isWordStart -> true, token -> relationship between diabetes and obesity, resolved_text -> Ethnic minority populations exhibit disproportionately high rates of type 2 diabetes mellitus (T2DM). Electronic health tools have the potential to facilitate the cultural adaptation and tailoring of T2DM education to improve the knowledge and management of diabetes mellitus (DM)., title -> Development and Efficacy of an Electronic, Culturally Adapted Lifestyle Counseling Tool for Improving Diabetes-Related Dietary Knowledge: Randomized Controlled Trial Among Ethnic Minority Adults With Type 2 Diabetes Mellitus, pubdate -> 2019 Oct 16, distance -> 0.29539174, sentence -> 0}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# |{fulljournalname -> Health Promotion Perspectives, document -> 0, uuid -> 53f2c7c8-6bdb-48dc-b59a-b505b4623df2, pieceId -> -1, score -> 0.70399022, target_text -> relationship between diabetes and obesity, code -> PMC7146037-53f2c7c8-6bdb-48dc-b59a-b505b4623df2, isWordStart -> true, token -> relationship between diabetes and obesity, resolved_text -> Background: Diabetes is referred to a group of diseases characterized by high glucose levels in blood. It is caused by a deficiency in the production or function of insulin or both, which can occur because of different reasons, resulting in protein and lipid metabolic disorders. The aim of this study was to systematically review the prevalence and incidence of type 1 diabetes in the world., title -> Prevalence and incidence of type 1 diabetes in the world: a systematic review and meta-analysis, pubdate -> 2020 Mar 30, distance -> 0.29600978, sentence -> 0}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |{fulljournalname -> Nutrients, document -> 0, uuid -> 25bc2579-14a2-46d6-bb92-506819e37d26, pieceId -> -1, score -> 0.67858838, target_text -> relationship between diabetes and obesity, code -> PMC7693664-25bc2579-14a2-46d6-bb92-506819e37d26, isWordStart -> true, token -> relationship between diabetes and obesity, resolved_text -> The increasing prevalence of older adults with diabetes has become a major social burden. Diabetes, frailty, and cognitive dysfunction are closely related to the mechanisms of aging. Insulin resistance, arteriosclerosis, chronic inflammation, oxidative stress, and mitochondrial dysfunction may be common mechanisms shared by frailty and cognitive impairment. Hyperglycemia, hypoglycemia, obesity, vascular factors, physical inactivity, and malnutrition are important risk factors for cognitive impairment and frailty in older adults with diabetes. The impact of nutrients on health outcomes varies with age; thus, shifting diet therapy strategies from the treatment of obesity/metabolic syndrome to frailty prevention may be necessary in patients with diabetes who are over 75 years of age, have frailty or sarcopenia, and experience malnutrition. For the prevention of frailty, optimal energy intake, sufficient protein and vitamin intake, and healthy dietary patterns should be recommended. The treatment of diabetes after middle age should include the awareness of proper glycemic control aimed at extending healthy life expectancy with proper nutrition, exercise, and social connectivity. Nutritional therapy in combination with exercise, optimal glycemic and metabolic control, and social participation/support for frailty prevention can extend healthy life expectancy and maintain quality of life in older adults with diabetes mellitus., title -> Nutrition Management in Older Adults with Diabetes: A Review on the Importance of Shifting Prevention Strategies from Metabolic Syndrome to Frailty, pubdate -> 2020 Nov 1, distance -> 0.32141162, sentence -> 0}|
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# ## Check the similarity

# %%
baseDF.select("pubmed_id", "split.result").where("""pubmed_id == 'PMC7730786'""").show(truncate=False)
# Out:
# +----------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |pubmed_id |result                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# +----------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |PMC7730786|[Current evidence suggests that the information needs of people with diabetes mellitus differ across patient groups. With a view to being able to provide individualized information, this study aims to identify (i) the diabetes-related information needs of people with diabetes mellitus; (ii) different subgroups of people with specific information needs; and (iii) associated characteristics of the identified subgroups, such as sociodemographic characteristics, diabetes-related comorbidities, and well-being.]                                                                                                                                    |
# |PMC7730786|[This cross-sectional study was based on data from 837 respondents with diabetes mellitus who participated in the population-based KORA (Cooperative Health Research in the Augsburg Region) Health Survey 2016 in Southern Germany (KORA GEFU 4 study) (45.6% female, mean age 71.1 years, 92.8% Type 2 diabetes). Diabetes-related information needs were assessed with a questionnaire asking about patients’ information needs concerning 11 diabetes-related topics, e.g. ‘long-term complications’ and ‘treatment/therapy’. Subgroups of people with different information needs and associated characteristics were identified using latent class analysis.]|
# |PMC7730786|[We identified the following four classes of people with different information needs: ‘high needs on all topics’, ‘low needs on all topics’, ‘moderate needs with a focus on complications and diabetes in everyday life’, and ‘advanced needs with a focus on social and legal aspects and diabetes research’. The classes differed significantly in age, years of education, type of diabetes, diabetes duration, diabetes-related comorbidities, smoking behaviour, diabetes education, current level of information, and time preference.]                                                                                                                     |
# |PMC7730786|[Knowledge about different patient subgroups can be useful for tailored information campaigns or physician-patient interactions. Further research is needed to analyse health care needs in these groups, changes in information needs over the course of the disease, and prospective health outcomes.]                                                                                                                                                                                                                                                                                                                                                           |
# |PMC7730786|[Supplementary information accompanies this paper at 10.1186/s12889-020-09968-9.]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# +----------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
spark_df = spark.createDataFrame([[query_1, "Italian Journal of Pediatrics"]]).toDF("text", "fulljournalname")

pipeline_model.transform(spark_df)\
    .selectExpr("explode(vector_db.metadata) as vector_db_annotation_metadata").show(truncate=False)
# Out:
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |vector_db_annotation_metadata                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{fulljournalname -> Italian Journal of Pediatrics, document -> 0, uuid -> 85caa88d-4cd2-4cc4-9e8a-3684aa145608, pieceId -> -1, score -> 0.58362472, target_text -> What are the causes of diabetes?, code -> PMC4422421-85caa88d-4cd2-4cc4-9e8a-3684aa145608, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> Wolfram syndrome (WS) is an autosomal recessive neurodegenerative disorder characterized by diabetes mellitus (DM), optic atrophy (OA), central diabetes insipidus (CDI) and deafness (D)., title -> Congenital central diabetes insipidus and optic atrophy in a Wolfram newborn: is there a role for WFS1 gene in neurodevelopment?, pubdate -> 2014 Sep 26, distance -> 0.41637528, sentence -> 0}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |{fulljournalname -> Italian Journal of Pediatrics, document -> 8, uuid -> 02cf0380-d2dc-4006-8aed-c272d1b16dd7, pieceId -> -1, score -> 0.50509220, target_text -> What are the causes of diabetes?, code -> PMC4422421-02cf0380-d2dc-4006-8aed-c272d1b16dd7, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> Wolfram syndrome should be considered in the differential diagnosis of the rare cases of congenital central diabetes insipidus developed in the neonatal period., title -> Congenital central diabetes insipidus and optic atrophy in a Wolfram newborn: is there a role for WFS1 gene in neurodevelopment?, pubdate -> 2014 Sep 26, distance -> 0.49490780, sentence -> 8}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |{fulljournalname -> Italian Journal of Pediatrics, document -> 7, uuid -> 239610c7-a2ef-4ecb-a7d6-4ae90a19b858, pieceId -> -1, score -> 0.42660752, target_text -> What are the causes of diabetes?, code -> PMC4422421-239610c7-a2ef-4ecb-a7d6-4ae90a19b858, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> The analysis of our case, in the light of the most recent literature, suggests a possible role for WFS1 gene in the development of certain brain structures during the fetal period., title -> Congenital central diabetes insipidus and optic atrophy in a Wolfram newborn: is there a role for WFS1 gene in neurodevelopment?, pubdate -> 2014 Sep 26, distance -> 0.57339248, sentence -> 7}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# |{fulljournalname -> Italian Journal of Pediatrics, document -> 3, uuid -> 0c53083e-6850-4b11-bf2e-105017667d89, pieceId -> -1, score -> 0.40909364, target_text -> What are the causes of diabetes?, code -> PMC4422421-0c53083e-6850-4b11-bf2e-105017667d89, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> Here we review and discuss the pathophysiological mechanisms that we believe responsible for the perinatal onset of Wolfram syndrome as these data strongly suggest a role for WFS1 gene in foetal and neonatal neurodevelopment., title -> Congenital central diabetes insipidus and optic atrophy in a Wolfram newborn: is there a role for WFS1 gene in neurodevelopment?, pubdate -> 2014 Sep 26, distance -> 0.59090636, sentence -> 3}                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# |{fulljournalname -> Italian Journal of Pediatrics, document -> 6, uuid -> cefcdd7b-9dfe-4a6f-83a1-0bb732645741, pieceId -> -1, score -> 0.33468976, target_text -> What are the causes of diabetes?, code -> PMC4422421-cefcdd7b-9dfe-4a6f-83a1-0bb732645741, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> During the five years follow-up the patient did not developed glucose intolerance or diabetes mellitus. By the end of the second year of life, primary non-autoimmune central hypothyroidism and mild neurodevelopment retardation were diagnosed., title -> Congenital central diabetes insipidus and optic atrophy in a Wolfram newborn: is there a role for WFS1 gene in neurodevelopment?, pubdate -> 2014 Sep 26, distance -> 0.66531024, sentence -> 6}                                                                                                                                                                                                                                                                                                                                                                                                                        |
# |{fulljournalname -> Italian Journal of Pediatrics, document -> 4, uuid -> 7a4c18c9-0d6f-402a-b478-d482871aa4c7, pieceId -> -1, score -> 0.32001674, target_text -> What are the causes of diabetes?, code -> PMC4422421-7a4c18c9-0d6f-402a-b478-d482871aa4c7, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> We described a male patient of 30 weeks’ gestation with intrauterine growth restriction and poly-hydramnios., title -> Congenital central diabetes insipidus and optic atrophy in a Wolfram newborn: is there a role for WFS1 gene in neurodevelopment?, pubdate -> 2014 Sep 26, distance -> 0.67998326, sentence -> 4}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# |{fulljournalname -> Italian Journal of Pediatrics, document -> 1, uuid -> da33fb9b-aad1-47a5-b23d-7dc35ef7da42, pieceId -> -1, score -> 0.31655383, target_text -> What are the causes of diabetes?, code -> PMC4422421-da33fb9b-aad1-47a5-b23d-7dc35ef7da42, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> The phenotype of the disease has been associated with several mutations in the WFS1 gene, a nuclear gene localized on chromosome 4. Since the discovery of the association between WFS1 gene and Wolfram syndrome, more than 150 mutations have been identified in WS patients., title -> Congenital central diabetes insipidus and optic atrophy in a Wolfram newborn: is there a role for WFS1 gene in neurodevelopment?, pubdate -> 2014 Sep 26, distance -> 0.68344617, sentence -> 1}                                                                                                                                                                                                                                                                                                                                                                                           |
# |{fulljournalname -> Italian Journal of Pediatrics, document -> 2, uuid -> 07850c04-69c1-46d9-b542-7facad5bba2d, pieceId -> -1, score -> 0.31603203, target_text -> What are the causes of diabetes?, code -> PMC4422421-07850c04-69c1-46d9-b542-7facad5bba2d, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> We previously described the first case of perinatal onset of Wolfram syndrome newborn carrying a segmental uniparental heterodysomy affecting the short arm of chromosome 4 responsible for a significant reduction in wolframin expression., title -> Congenital central diabetes insipidus and optic atrophy in a Wolfram newborn: is there a role for WFS1 gene in neurodevelopment?, pubdate -> 2014 Sep 26, distance -> 0.68396797, sentence -> 2}                                                                                                                                                                                                                                                                                                                                                                                                                              |
# |{fulljournalname -> Italian Journal of Pediatrics, document -> 5, uuid -> 3f9def7a-1a67-4ffe-a2bb-2fe68db27049, pieceId -> -1, score -> 0.21854428, target_text -> What are the causes of diabetes?, code -> PMC4422421-3f9def7a-1a67-4ffe-a2bb-2fe68db27049, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> During the first days of life, the patient showed a 19% weight loss associated with polyuria and hypernatremia. The presence of persistent hypernatremia (serum sodium 150 mEq/L), high plasma osmolarity (322 mOsm/L) and low urine osmolarity (190 mOsm/l) with a Uosm/Posm ratio < 1 were consistent with CDI. The diagnosis of CDI was confirmed by the desmopressin test and the brain magnetic resonance imaging (MRI) at 34 weeks of age, that showed the lack of posterior pituitary hyperintense signal. In addition, a bilateral asymmetrical optic nerve hypoplasia associated with right orbital bone hypoplasia was observed, suggesting the diagnosis of WF., title -> Congenital central diabetes insipidus and optic atrophy in a Wolfram newborn: is there a role for WFS1 gene in neurodevelopment?, pubdate -> 2014 Sep 26, distance -> 0.78145572, sentence -> 5}|
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
spark_df = spark.createDataFrame([[query_1, "XXXXXXX"]]).toDF("text", "fulljournalname")

pipeline_model.transform(spark_df)\
    .selectExpr("explode(vector_db.metadata) as vector_db_annotation_metadata").show(truncate=False)
# Out:
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |vector_db_annotation_metadata                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{fulljournalname -> BMC Public Health, document -> 0, uuid -> fbb7b54c-471e-47ec-9d12-b56b32f861d3, pieceId -> -1, score -> 0.74267092, target_text -> What are the causes of diabetes?, code -> PMC7730786-fbb7b54c-471e-47ec-9d12-b56b32f861d3, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> Current evidence suggests that the information needs of people with diabetes mellitus differ across patient groups. With a view to being able to provide individualized information, this study aims to identify (i) the diabetes-related information needs of people with diabetes mellitus; (ii) different subgroups of people with specific information needs; and (iii) associated characteristics of the identified subgroups, such as sociodemographic characteristics, diabetes-related comorbidities, and well-being., title -> Different information needs in subgroups of people with diabetes mellitus: a latent class analysis, pubdate -> 2020 Dec 10, distance -> 0.25732908, sentence -> 0}|
# |{fulljournalname -> Health Promotion Perspectives, document -> 0, uuid -> 53f2c7c8-6bdb-48dc-b59a-b505b4623df2, pieceId -> -1, score -> 0.67687259, target_text -> What are the causes of diabetes?, code -> PMC7146037-53f2c7c8-6bdb-48dc-b59a-b505b4623df2, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> Background: Diabetes is referred to a group of diseases characterized by high glucose levels in blood. It is caused by a deficiency in the production or function of insulin or both, which can occur because of different reasons, resulting in protein and lipid metabolic disorders. The aim of this study was to systematically review the prevalence and incidence of type 1 diabetes in the world., title -> Prevalence and incidence of type 1 diabetes in the world: a systematic review and meta-analysis, pubdate -> 2020 Mar 30, distance -> 0.32312741, sentence -> 0}                                                                                                            |
# |{fulljournalname -> Journal of Diabetes Investigation, document -> 3, uuid -> 5ea2f001-9b35-45f0-90ba-633d2a004a65, pieceId -> -1, score -> 0.66904215, target_text -> What are the causes of diabetes?, code -> PMC5415486-5ea2f001-9b35-45f0-90ba-633d2a004a65, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> Adiponectin and pro‐inflammatory cytokines are associated with type 2 diabetes mellitus, and might serve as a prognostic marker and a therapeutic intervention for overweight‐related type 2 diabetes mellitus., title -> Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus, pubdate -> 2016 Oct 30, distance -> 0.33095785, sentence -> 3}                                                                                                                                                                                                                                                                                   |
# |{fulljournalname -> Endocrine Connections, document -> 0, uuid -> ca9bf9b6-9f94-401d-9134-5687b29a8662, pieceId -> -1, score -> 0.65421363, target_text -> What are the causes of diabetes?, code -> PMC6599074-ca9bf9b6-9f94-401d-9134-5687b29a8662, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> Excessive glucocorticoid secretion has been associated with type 2 diabetes mellitus (T2DM) and other features of the metabolic syndrome. We aimed to evaluate whether basal or evening salivary cortisol may predict the occurrence of incident insulin resistance (IR) or T2DM., title -> Salivary cortisol is not associated with incident insulin resistance or type 2 diabetes mellitus, pubdate -> 2019 Jun 6, distance -> 0.34578637, sentence -> 0}                                                                                                                                                                                                                                           |
# |{fulljournalname -> Journal of Diabetes Investigation, document -> 3, uuid -> 2bc3e8d1-3160-4c61-a442-3c52984cc69d, pieceId -> -1, score -> 0.64962672, target_text -> What are the causes of diabetes?, code -> PMC5583949-2bc3e8d1-3160-4c61-a442-3c52984cc69d, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> These findings suggest a possible role for SERPINA3 in the development of the early stages of type 2 diabetes mellitus, although further replication studies and functional investigations regarding their role are required., title -> Proteomic analysis of serum biomarkers for prediabetes using the Long‐Evans Agouti rat, a spontaneous animal model of type 2 diabetes mellitus, pubdate -> 2017 Mar 27, distance -> 0.35037328, sentence -> 3}                                                                                                                                                                                                                                    |
# |{fulljournalname -> Journal of Diabetes Investigation, document -> 4, uuid -> b3b39bc4-9f02-400f-b1e5-8ae313765533, pieceId -> -1, score -> 0.63333490, target_text -> What are the causes of diabetes?, code -> PMC8756324-b3b39bc4-9f02-400f-b1e5-8ae313765533, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> We provide novel information on the prevalence and clinical features of fulminant type 1 diabetes mellitus in Korea., title -> Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research, pubdate -> 2021 Aug 31, distance -> 0.36666510, sentence -> 4}                                                                                                                                                                                                                                                                                                                                                       |
# |{fulljournalname -> Journal of Diabetes Investigation, document -> 0, uuid -> 6f8898ea-43c1-48f4-94e3-1b737b00aa6c, pieceId -> -1, score -> 0.62630709, target_text -> What are the causes of diabetes?, code -> PMC5415486-6f8898ea-43c1-48f4-94e3-1b737b00aa6c, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> Adipose tissue‐derived hormones are associated with metabolic disorders including type 2 diabetes mellitus. The present study investigated the levels of adiponectin and pro‐inflammatory cytokines including tumor necrosis factor‐α (TNF‐α), interleukin‐1 beta (IL‐1β) and IL‐10 in Vietnamese patients with type 2 diabetes mellitus, and their correlations with clinical parameters of overweight and type 2 diabetes mellitus., title -> Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus, pubdate -> 2016 Oct 30, distance -> 0.37369291, sentence -> 0}                                                             |
# |{fulljournalname -> Journal of the American Heart Association: Cardiovascular and Cerebrovascular Disease, document -> 2, uuid -> 4e4ccec7-44c7-4aa7-995b-d32430803767, pieceId -> -1, score -> 0.61528191, target_text -> What are the causes of diabetes?, code -> PMC8477890-4e4ccec7-44c7-4aa7-995b-d32430803767, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> MVD is associated with an excess HF risk in individuals with type 2 diabetes mellitus after adjusting for other known risk factors. Our findings underscore the contribution of MVD to the development of diabetes mellitus–related HF., title -> Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus, pubdate -> 2021 Jun 10, distance -> 0.38471809, sentence -> 2}                                                                                                                                                                                                                    |
# |{fulljournalname -> Journal of Diabetes Investigation, document -> 0, uuid -> f7588513-39c0-4f9b-b3c0-46bfb1c315aa, pieceId -> -1, score -> 0.60167503, target_text -> What are the causes of diabetes?, code -> PMC5583950-f7588513-39c0-4f9b-b3c0-46bfb1c315aa, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> The present meta‐analysis was carried out to assess the association between exposure to the level of atmospheric particulate matter 2.5 (PM2.5; fine particulate matter with aerodynamic diameter less than 2.5 μm) and type 2 diabetes mellitus or gestational diabetes mellitus (GDM)., title -> Association between particulate matter 2.5 and diabetes mellitus: A meta‐analysis of cohort studies, pubdate -> 2017 May 3, distance -> 0.39832497, sentence -> 0}                                                                                                                                                                                                                     |
# |{fulljournalname -> Journal of Diabetes Investigation, document -> 0, uuid -> 43adc9b2-d974-4b18-b732-ca8afa133082, pieceId -> -1, score -> 0.59917990, target_text -> What are the causes of diabetes?, code -> PMC8756324-43adc9b2-d974-4b18-b732-ca8afa133082, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> We aimed to determine the hospital‐based prevalence and clinical features of fulminant type 1 diabetes mellitus in Korea., title -> Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research, pubdate -> 2021 Aug 31, distance -> 0.40082010, sentence -> 0}                                                                                                                                                                                                                                                                                                                                                  |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# ## Check the setTopK()

# %%
pipeline_model.stages[-1].setTopK(5)

spark_df = spark.createDataFrame([[query_1, "Italian Journal of Pediatrics"]]).toDF("text", "fulljournalname")

pipeline_model.transform(spark_df).selectExpr("explode(vector_db.metadata) as vector_db_annotation_metadata").show(truncate=False)
# Out:
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |vector_db_annotation_metadata                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{fulljournalname -> Italian Journal of Pediatrics, document -> 0, uuid -> 85caa88d-4cd2-4cc4-9e8a-3684aa145608, pieceId -> -1, score -> 0.58362472, target_text -> What are the causes of diabetes?, code -> PMC4422421-85caa88d-4cd2-4cc4-9e8a-3684aa145608, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> Wolfram syndrome (WS) is an autosomal recessive neurodegenerative disorder characterized by diabetes mellitus (DM), optic atrophy (OA), central diabetes insipidus (CDI) and deafness (D)., title -> Congenital central diabetes insipidus and optic atrophy in a Wolfram newborn: is there a role for WFS1 gene in neurodevelopment?, pubdate -> 2014 Sep 26, distance -> 0.41637528, sentence -> 0}                                                        |
# |{fulljournalname -> Italian Journal of Pediatrics, document -> 8, uuid -> 02cf0380-d2dc-4006-8aed-c272d1b16dd7, pieceId -> -1, score -> 0.50509220, target_text -> What are the causes of diabetes?, code -> PMC4422421-02cf0380-d2dc-4006-8aed-c272d1b16dd7, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> Wolfram syndrome should be considered in the differential diagnosis of the rare cases of congenital central diabetes insipidus developed in the neonatal period., title -> Congenital central diabetes insipidus and optic atrophy in a Wolfram newborn: is there a role for WFS1 gene in neurodevelopment?, pubdate -> 2014 Sep 26, distance -> 0.49490780, sentence -> 8}                                                                                  |
# |{fulljournalname -> Italian Journal of Pediatrics, document -> 7, uuid -> 239610c7-a2ef-4ecb-a7d6-4ae90a19b858, pieceId -> -1, score -> 0.42660752, target_text -> What are the causes of diabetes?, code -> PMC4422421-239610c7-a2ef-4ecb-a7d6-4ae90a19b858, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> The analysis of our case, in the light of the most recent literature, suggests a possible role for WFS1 gene in the development of certain brain structures during the fetal period., title -> Congenital central diabetes insipidus and optic atrophy in a Wolfram newborn: is there a role for WFS1 gene in neurodevelopment?, pubdate -> 2014 Sep 26, distance -> 0.57339248, sentence -> 7}                                                              |
# |{fulljournalname -> Italian Journal of Pediatrics, document -> 3, uuid -> 0c53083e-6850-4b11-bf2e-105017667d89, pieceId -> -1, score -> 0.40909364, target_text -> What are the causes of diabetes?, code -> PMC4422421-0c53083e-6850-4b11-bf2e-105017667d89, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> Here we review and discuss the pathophysiological mechanisms that we believe responsible for the perinatal onset of Wolfram syndrome as these data strongly suggest a role for WFS1 gene in foetal and neonatal neurodevelopment., title -> Congenital central diabetes insipidus and optic atrophy in a Wolfram newborn: is there a role for WFS1 gene in neurodevelopment?, pubdate -> 2014 Sep 26, distance -> 0.59090636, sentence -> 3}                 |
# |{fulljournalname -> Italian Journal of Pediatrics, document -> 6, uuid -> cefcdd7b-9dfe-4a6f-83a1-0bb732645741, pieceId -> -1, score -> 0.33468976, target_text -> What are the causes of diabetes?, code -> PMC4422421-cefcdd7b-9dfe-4a6f-83a1-0bb732645741, isWordStart -> true, token -> What are the causes of diabetes?, resolved_text -> During the five years follow-up the patient did not developed glucose intolerance or diabetes mellitus. By the end of the second year of life, primary non-autoimmune central hypothyroidism and mild neurodevelopment retardation were diagnosed., title -> Congenital central diabetes insipidus and optic atrophy in a Wolfram newborn: is there a role for WFS1 gene in neurodevelopment?, pubdate -> 2014 Sep 26, distance -> 0.66531024, sentence -> 6}|
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
result_df.selectExpr("text", "explode(vector_db.result) as results").show(truncate=100)
# Out:
# +-----------------------------------------+----------------------------------------------------------------------------------------------------+
# |                                     text|                                                                                             results|
# +-----------------------------------------+----------------------------------------------------------------------------------------------------+
# |         What are the causes of diabetes?|Current evidence suggests that the information needs of people with diabetes mellitus differ acro...|
# |         What are the causes of diabetes?|Background: Diabetes is referred to a group of diseases characterized by high glucose levels in b...|
# |         What are the causes of diabetes?|Adiponectin and pro‐inflammatory cytokines are associated with type 2 diabetes mellitus, and migh...|
# |         What are the causes of diabetes?|Excessive glucocorticoid secretion has been associated with type 2 diabetes mellitus (T2DM) and o...|
# |         What are the causes of diabetes?|These findings suggest a possible role for SERPINA3 in the development of the early stages of typ...|
# |relationship between diabetes and obesity|Adiponectin and pro‐inflammatory cytokines are associated with type 2 diabetes mellitus, and migh...|
# |relationship between diabetes and obesity|MVD is associated with an excess HF risk in individuals with type 2 diabetes mellitus after adjus...|
# |relationship between diabetes and obesity|Adipose tissue‐derived hormones are associated with metabolic disorders including type 2 diabetes...|
# |relationship between diabetes and obesity|Genetic variance of AVPR1B contributes to overweight. Furthermore, our data indicate a link betwe...|
# |relationship between diabetes and obesity|Excessive glucocorticoid secretion has been associated with type 2 diabetes mellitus (T2DM) and o...|
# +-----------------------------------------+----------------------------------------------------------------------------------------------------+

# %%
flattener = Flattener()\
    .setInputCols("vector_db")\
    .setExplodeSelectedFields({"vector_db": ["metadata.target_text as Questions",
                                             "result as Text",
                                             "metadata.distance as Distance",
                                             "metadata.pubdate as Date",
                                             "metadata.code as ID",
                                             "metadata.title as Title"]})

flattener.transform(result_df).show(truncate=100)
# Out:
# +-----------------------------------------+----------------------------------------------------------------------------------------------------+----------+-----------+-----------------------------------------------+----------------------------------------------------------------------------------------------------+
# |                                Questions|                                                                                                Text|  Distance|       Date|                                             ID|                                                                                               Title|
# +-----------------------------------------+----------------------------------------------------------------------------------------------------+----------+-----------+-----------------------------------------------+----------------------------------------------------------------------------------------------------+
# |         What are the causes of diabetes?|Current evidence suggests that the information needs of people with diabetes mellitus differ acro...|0.25732908|2020 Dec 10|PMC7730786-fbb7b54c-471e-47ec-9d12-b56b32f861d3|  Different information needs in subgroups of people with diabetes mellitus: a latent class analysis|
# |         What are the causes of diabetes?|Background: Diabetes is referred to a group of diseases characterized by high glucose levels in b...|0.32312741|2020 Mar 30|PMC7146037-53f2c7c8-6bdb-48dc-b59a-b505b4623df2|     Prevalence and incidence of type 1 diabetes in the world: a systematic review and meta-analysis|
# |         What are the causes of diabetes?|Adiponectin and pro‐inflammatory cytokines are associated with type 2 diabetes mellitus, and migh...|0.33095785|2016 Oct 30|PMC5415486-5ea2f001-9b35-45f0-90ba-633d2a004a65|Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabe...|
# |         What are the causes of diabetes?|Excessive glucocorticoid secretion has been associated with type 2 diabetes mellitus (T2DM) and o...|0.34578637| 2019 Jun 6|PMC6599074-ca9bf9b6-9f94-401d-9134-5687b29a8662|    Salivary cortisol is not associated with incident insulin resistance or type 2 diabetes mellitus|
# |         What are the causes of diabetes?|These findings suggest a possible role for SERPINA3 in the development of the early stages of typ...|0.35037328|2017 Mar 27|PMC5583949-2bc3e8d1-3160-4c61-a442-3c52984cc69d|Proteomic analysis of serum biomarkers for prediabetes using the Long‐Evans Agouti rat, a spontan...|
# |relationship between diabetes and obesity|Adiponectin and pro‐inflammatory cytokines are associated with type 2 diabetes mellitus, and migh...|0.18294283|2016 Oct 30|PMC5415486-5ea2f001-9b35-45f0-90ba-633d2a004a65|Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabe...|
# |relationship between diabetes and obesity|MVD is associated with an excess HF risk in individuals with type 2 diabetes mellitus after adjus...|0.21556044|2021 Jun 10|PMC8477890-4e4ccec7-44c7-4aa7-995b-d32430803767|    Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus|
# |relationship between diabetes and obesity|Adipose tissue‐derived hormones are associated with metabolic disorders including type 2 diabetes...|0.22889827|2016 Oct 30|PMC5415486-6f8898ea-43c1-48f4-94e3-1b737b00aa6c|Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabe...|
# |relationship between diabetes and obesity|Genetic variance of AVPR1B contributes to overweight. Furthermore, our data indicate a link betwe...|0.23433919|   2016 Jan|PMC4653349-9bba9908-aba8-4e0e-a936-267a7c021c26|                        Genetic vasopressin 1b receptor variance in overweight and diabetes mellitus|
# |relationship between diabetes and obesity|Excessive glucocorticoid secretion has been associated with type 2 diabetes mellitus (T2DM) and o...|0.24493754| 2019 Jun 6|PMC6599074-ca9bf9b6-9f94-401d-9134-5687b29a8662|    Salivary cortisol is not associated with incident insulin resistance or type 2 diabetes mellitus|
# +-----------------------------------------+----------------------------------------------------------------------------------------------------+----------+-----------+-----------------------------------------------+----------------------------------------------------------------------------------------------------+

# %%
flattener = Flattener()\
    .setInputCols("vector_db")\
    .setExplodeSelectedFields({"vector_db": ["metadata.token",
                                             "metadata.distance",
                                             "metadata.pubdate",
                                             "metadata.code",
                                             "metadata.title"]})

flattener.transform(result_df).show(truncate=False)
# Out:
# +-----------------------------------------+---------------------------+--------------------------+-----------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------+
# |vector_db_metadata_token                 |vector_db_metadata_distance|vector_db_metadata_pubdate|vector_db_metadata_code                        |vector_db_metadata_title                                                                                                                      |
# +-----------------------------------------+---------------------------+--------------------------+-----------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------+
# |What are the causes of diabetes?         |0.25732908                 |2020 Dec 10               |PMC7730786-fbb7b54c-471e-47ec-9d12-b56b32f861d3|Different information needs in subgroups of people with diabetes mellitus: a latent class analysis                                            |
# |What are the causes of diabetes?         |0.32312741                 |2020 Mar 30               |PMC7146037-53f2c7c8-6bdb-48dc-b59a-b505b4623df2|Prevalence and incidence of type 1 diabetes in the world: a systematic review and meta-analysis                                               |
# |What are the causes of diabetes?         |0.33095785                 |2016 Oct 30               |PMC5415486-5ea2f001-9b35-45f0-90ba-633d2a004a65|Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus                                 |
# |What are the causes of diabetes?         |0.34578637                 |2019 Jun 6                |PMC6599074-ca9bf9b6-9f94-401d-9134-5687b29a8662|Salivary cortisol is not associated with incident insulin resistance or type 2 diabetes mellitus                                              |
# |What are the causes of diabetes?         |0.35037328                 |2017 Mar 27               |PMC5583949-2bc3e8d1-3160-4c61-a442-3c52984cc69d|Proteomic analysis of serum biomarkers for prediabetes using the Long‐Evans Agouti rat, a spontaneous animal model of type 2 diabetes mellitus|
# |relationship between diabetes and obesity|0.18294283                 |2016 Oct 30               |PMC5415486-5ea2f001-9b35-45f0-90ba-633d2a004a65|Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus                                 |
# |relationship between diabetes and obesity|0.21556044                 |2021 Jun 10               |PMC8477890-4e4ccec7-44c7-4aa7-995b-d32430803767|Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus                                              |
# |relationship between diabetes and obesity|0.22889827                 |2016 Oct 30               |PMC5415486-6f8898ea-43c1-48f4-94e3-1b737b00aa6c|Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus                                 |
# |relationship between diabetes and obesity|0.23433919                 |2016 Jan                  |PMC4653349-9bba9908-aba8-4e0e-a936-267a7c021c26|Genetic vasopressin 1b receptor variance in overweight and diabetes mellitus                                                                  |
# |relationship between diabetes and obesity|0.24493754                 |2019 Jun 6                |PMC6599074-ca9bf9b6-9f94-401d-9134-5687b29a8662|Salivary cortisol is not associated with incident insulin resistance or type 2 diabetes mellitus                                              |
# +-----------------------------------------+---------------------------+--------------------------+-----------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# ## Check setSimilarityThreshold

# %%
pipeline_model.stages[-1].setSimilarityThreshold(0.30)

flattener = Flattener()\
    .setInputCols("vector_db")\
    .setExplodeSelectedFields({"vector_db": ["metadata.token",
                                             "metadata.distance",
                                             "metadata.code",
                                             "metadata.title"]})

result_df = pipeline_model.transform(query_df)

flattener.transform(result_df).show(truncate=False)
# Out:
# +-----------------------------------------+---------------------------+-----------------------------------------------+-------------------------------------------------------------------------------------------------------------+
# |vector_db_metadata_token                 |vector_db_metadata_distance|vector_db_metadata_code                        |vector_db_metadata_title                                                                                     |
# +-----------------------------------------+---------------------------+-----------------------------------------------+-------------------------------------------------------------------------------------------------------------+
# |What are the causes of diabetes?         |0.25732908                 |PMC7730786-fbb7b54c-471e-47ec-9d12-b56b32f861d3|Different information needs in subgroups of people with diabetes mellitus: a latent class analysis           |
# |relationship between diabetes and obesity|0.18294283                 |PMC5415486-5ea2f001-9b35-45f0-90ba-633d2a004a65|Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus|
# |relationship between diabetes and obesity|0.21556044                 |PMC8477890-4e4ccec7-44c7-4aa7-995b-d32430803767|Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus             |
# |relationship between diabetes and obesity|0.22889827                 |PMC5415486-6f8898ea-43c1-48f4-94e3-1b737b00aa6c|Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus|
# |relationship between diabetes and obesity|0.23433919                 |PMC4653349-9bba9908-aba8-4e0e-a936-267a7c021c26|Genetic vasopressin 1b receptor variance in overweight and diabetes mellitus                                 |
# |relationship between diabetes and obesity|0.24493754                 |PMC6599074-ca9bf9b6-9f94-401d-9134-5687b29a8662|Salivary cortisol is not associated with incident insulin resistance or type 2 diabetes mellitus             |
# +-----------------------------------------+---------------------------+-----------------------------------------------+-------------------------------------------------------------------------------------------------------------+

# %%
pipeline_model.stages[-1].setSimilarityThreshold(0.35)

flattener = Flattener()\
    .setInputCols("vector_db")\
    .setExplodeSelectedFields({"vector_db": ["metadata.token",
                                             "metadata.distance",
                                             "metadata.code",
                                             "metadata.title"]})

result_df = pipeline_model.transform(query_df)

flattener.transform(result_df).show(truncate=False)
# Out:
# +-----------------------------------------+---------------------------+-----------------------------------------------+-------------------------------------------------------------------------------------------------------------+
# |vector_db_metadata_token                 |vector_db_metadata_distance|vector_db_metadata_code                        |vector_db_metadata_title                                                                                     |
# +-----------------------------------------+---------------------------+-----------------------------------------------+-------------------------------------------------------------------------------------------------------------+
# |What are the causes of diabetes?         |0.25732908                 |PMC7730786-fbb7b54c-471e-47ec-9d12-b56b32f861d3|Different information needs in subgroups of people with diabetes mellitus: a latent class analysis           |
# |What are the causes of diabetes?         |0.32312741                 |PMC7146037-53f2c7c8-6bdb-48dc-b59a-b505b4623df2|Prevalence and incidence of type 1 diabetes in the world: a systematic review and meta-analysis              |
# |What are the causes of diabetes?         |0.33095785                 |PMC5415486-5ea2f001-9b35-45f0-90ba-633d2a004a65|Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus|
# |What are the causes of diabetes?         |0.34578637                 |PMC6599074-ca9bf9b6-9f94-401d-9134-5687b29a8662|Salivary cortisol is not associated with incident insulin resistance or type 2 diabetes mellitus             |
# |relationship between diabetes and obesity|0.18294283                 |PMC5415486-5ea2f001-9b35-45f0-90ba-633d2a004a65|Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus|
# |relationship between diabetes and obesity|0.21556044                 |PMC8477890-4e4ccec7-44c7-4aa7-995b-d32430803767|Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus             |
# |relationship between diabetes and obesity|0.22889827                 |PMC5415486-6f8898ea-43c1-48f4-94e3-1b737b00aa6c|Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus|
# |relationship between diabetes and obesity|0.23433919                 |PMC4653349-9bba9908-aba8-4e0e-a936-267a7c021c26|Genetic vasopressin 1b receptor variance in overweight and diabetes mellitus                                 |
# |relationship between diabetes and obesity|0.24493754                 |PMC6599074-ca9bf9b6-9f94-401d-9134-5687b29a8662|Salivary cortisol is not associated with incident insulin resistance or type 2 diabetes mellitus             |
# +-----------------------------------------+---------------------------+-----------------------------------------------+-------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# # VectorDBPostProcessor

# %% [markdown]
# ## Save VectorDB DF

# %%
query2 = """What are the effects of diabetes on the body?"""

# %%
pipeline_model.stages[-1].setSimilarityThreshold(0.99).setTopK(20)
pipeline_model.transform(spark.createDataFrame([[query2]]).toDF("text")).select("vector_db").write.mode("overwrite").parquet("/content/models/vector_df")

# %% [markdown]
# ## Read Vector DF

# %%
vector_df = spark.read.load("/content/models/vector_df")

# %%
vector_df.selectExpr("explode(vector_db) as vector_db").show(truncate=False)
# Out:
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |vector_db                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{vector_similarity_rankings, 0, 44, Current evidence suggests that the information needs of people with diabetes mellitus differ across patient groups. With a view to being able to provide individualized information, this study aims to identify (i) the diabetes-related information needs of people with diabetes mellitus; (ii) different subgroups of people with specific information needs; and (iii) associated characteristics of the identified subgroups, such as sociodemographic characteristics, diabetes-related comorbidities, and well-being., {fulljournalname -> BMC Public Health, document -> 0, uuid -> fbb7b54c-471e-47ec-9d12-b56b32f861d3, pieceId -> -1, score -> 0.79923863, target_text -> What are the effects of diabetes on the body?, code -> PMC7730786-fbb7b54c-471e-47ec-9d12-b56b32f861d3, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Current evidence suggests that the information needs of people with diabetes mellitus differ across patient groups. With a view to being able to provide individualized information, this study aims to identify (i) the diabetes-related information needs of people with diabetes mellitus; (ii) different subgroups of people with specific information needs; and (iii) associated characteristics of the identified subgroups, such as sociodemographic characteristics, diabetes-related comorbidities, and well-being., title -> Different information needs in subgroups of people with diabetes mellitus: a latent class analysis, pubdate -> 2020 Dec 10, distance -> 0.20076137, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# |{vector_similarity_rankings, 0, 44, Adiponectin and pro‐inflammatory cytokines are associated with type 2 diabetes mellitus, and might serve as a prognostic marker and a therapeutic intervention for overweight‐related type 2 diabetes mellitus., {fulljournalname -> Journal of Diabetes Investigation, document -> 3, uuid -> 5ea2f001-9b35-45f0-90ba-633d2a004a65, pieceId -> -1, score -> 0.73810669, target_text -> What are the effects of diabetes on the body?, code -> PMC5415486-5ea2f001-9b35-45f0-90ba-633d2a004a65, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Adiponectin and pro‐inflammatory cytokines are associated with type 2 diabetes mellitus, and might serve as a prognostic marker and a therapeutic intervention for overweight‐related type 2 diabetes mellitus., title -> Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus, pubdate -> 2016 Oct 30, distance -> 0.26189331, sentence -> 3}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# |{vector_similarity_rankings, 0, 44, Background: Diabetes is referred to a group of diseases characterized by high glucose levels in blood. It is caused by a deficiency in the production or function of insulin or both, which can occur because of different reasons, resulting in protein and lipid metabolic disorders. The aim of this study was to systematically review the prevalence and incidence of type 1 diabetes in the world., {fulljournalname -> Health Promotion Perspectives, document -> 0, uuid -> 53f2c7c8-6bdb-48dc-b59a-b505b4623df2, pieceId -> -1, score -> 0.72076187, target_text -> What are the effects of diabetes on the body?, code -> PMC7146037-53f2c7c8-6bdb-48dc-b59a-b505b4623df2, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Background: Diabetes is referred to a group of diseases characterized by high glucose levels in blood. It is caused by a deficiency in the production or function of insulin or both, which can occur because of different reasons, resulting in protein and lipid metabolic disorders. The aim of this study was to systematically review the prevalence and incidence of type 1 diabetes in the world., title -> Prevalence and incidence of type 1 diabetes in the world: a systematic review and meta-analysis, pubdate -> 2020 Mar 30, distance -> 0.27923813, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# |{vector_similarity_rankings, 0, 44, Excessive glucocorticoid secretion has been associated with type 2 diabetes mellitus (T2DM) and other features of the metabolic syndrome. We aimed to evaluate whether basal or evening salivary cortisol may predict the occurrence of incident insulin resistance (IR) or T2DM., {fulljournalname -> Endocrine Connections, document -> 0, uuid -> ca9bf9b6-9f94-401d-9134-5687b29a8662, pieceId -> -1, score -> 0.69687414, target_text -> What are the effects of diabetes on the body?, code -> PMC6599074-ca9bf9b6-9f94-401d-9134-5687b29a8662, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Excessive glucocorticoid secretion has been associated with type 2 diabetes mellitus (T2DM) and other features of the metabolic syndrome. We aimed to evaluate whether basal or evening salivary cortisol may predict the occurrence of incident insulin resistance (IR) or T2DM., title -> Salivary cortisol is not associated with incident insulin resistance or type 2 diabetes mellitus, pubdate -> 2019 Jun 6, distance -> 0.30312586, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# |{vector_similarity_rankings, 0, 44, Adipose tissue‐derived hormones are associated with metabolic disorders including type 2 diabetes mellitus. The present study investigated the levels of adiponectin and pro‐inflammatory cytokines including tumor necrosis factor‐α (TNF‐α), interleukin‐1 beta (IL‐1β) and IL‐10 in Vietnamese patients with type 2 diabetes mellitus, and their correlations with clinical parameters of overweight and type 2 diabetes mellitus., {fulljournalname -> Journal of Diabetes Investigation, document -> 0, uuid -> 6f8898ea-43c1-48f4-94e3-1b737b00aa6c, pieceId -> -1, score -> 0.69644116, target_text -> What are the effects of diabetes on the body?, code -> PMC5415486-6f8898ea-43c1-48f4-94e3-1b737b00aa6c, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Adipose tissue‐derived hormones are associated with metabolic disorders including type 2 diabetes mellitus. The present study investigated the levels of adiponectin and pro‐inflammatory cytokines including tumor necrosis factor‐α (TNF‐α), interleukin‐1 beta (IL‐1β) and IL‐10 in Vietnamese patients with type 2 diabetes mellitus, and their correlations with clinical parameters of overweight and type 2 diabetes mellitus., title -> Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus, pubdate -> 2016 Oct 30, distance -> 0.30355884, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |{vector_similarity_rankings, 0, 44, These findings suggest a possible role for SERPINA3 in the development of the early stages of type 2 diabetes mellitus, although further replication studies and functional investigations regarding their role are required., {fulljournalname -> Journal of Diabetes Investigation, document -> 3, uuid -> 2bc3e8d1-3160-4c61-a442-3c52984cc69d, pieceId -> -1, score -> 0.68466444, target_text -> What are the effects of diabetes on the body?, code -> PMC5583949-2bc3e8d1-3160-4c61-a442-3c52984cc69d, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> These findings suggest a possible role for SERPINA3 in the development of the early stages of type 2 diabetes mellitus, although further replication studies and functional investigations regarding their role are required., title -> Proteomic analysis of serum biomarkers for prediabetes using the Long‐Evans Agouti rat, a spontaneous animal model of type 2 diabetes mellitus, pubdate -> 2017 Mar 27, distance -> 0.31533556, sentence -> 3}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# |{vector_similarity_rankings, 0, 44, Type 2 diabetes mellitus is a progressive disease that is characterized by the appearance of insulin resistance. The term insulin resistance is very wide and could affect different proteins involved in insulin signaling, as well as other mechanisms. In this review, we have analyzed the main molecular mechanisms that could be involved in the connection between type 2 diabetes and neurodegeneration, in general, and more specifically with the appearance of Alzheimer’s disease. We have studied, in more detail, the different processes involved, such as inflammation, endoplasmic reticulum stress, autophagy, and mitochondrial dysfunction., {fulljournalname -> Cells, document -> 0, uuid -> 13a2bd0c-5e85-4085-b8a9-e9215061323c, pieceId -> -1, score -> 0.65106501, target_text -> What are the effects of diabetes on the body?, code -> PMC8157600-13a2bd0c-5e85-4085-b8a9-e9215061323c, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Type 2 diabetes mellitus is a progressive disease that is characterized by the appearance of insulin resistance. The term insulin resistance is very wide and could affect different proteins involved in insulin signaling, as well as other mechanisms. In this review, we have analyzed the main molecular mechanisms that could be involved in the connection between type 2 diabetes and neurodegeneration, in general, and more specifically with the appearance of Alzheimer’s disease. We have studied, in more detail, the different processes involved, such as inflammation, endoplasmic reticulum stress, autophagy, and mitochondrial dysfunction., title -> Insulin Resistance and Diabetes Mellitus in Alzheimer’s Disease, pubdate -> 2021 May 18, distance -> 0.34893499, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# |{vector_similarity_rankings, 0, 44, MVD is associated with an excess HF risk in individuals with type 2 diabetes mellitus after adjusting for other known risk factors. Our findings underscore the contribution of MVD to the development of diabetes mellitus–related HF., {fulljournalname -> Journal of the American Heart Association: Cardiovascular and Cerebrovascular Disease, document -> 2, uuid -> 4e4ccec7-44c7-4aa7-995b-d32430803767, pieceId -> -1, score -> 0.64457040, target_text -> What are the effects of diabetes on the body?, code -> PMC8477890-4e4ccec7-44c7-4aa7-995b-d32430803767, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> MVD is associated with an excess HF risk in individuals with type 2 diabetes mellitus after adjusting for other known risk factors. Our findings underscore the contribution of MVD to the development of diabetes mellitus–related HF., title -> Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus, pubdate -> 2021 Jun 10, distance -> 0.35542960, sentence -> 2}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# |{vector_similarity_rankings, 0, 44, Gestational Diabetes Mellitus (GDM) is a transitory metabolic condition caused by dysregulation triggered by intolerance to carbohydrates, dysfunction of beta-pancreatic and endothelial cells, and insulin resistance during pregnancy. However, this disease includes not only changes related to metabolic distress but also placental immunoendocrine adaptations, resulting in harmful effects to the mother and fetus. In this review, we focus on the placenta as an immuno-endocrine organ that can recognize and respond to the hyperglycemic environment. It synthesizes diverse chemicals that play a role in inflammation, innate defense, endocrine response, oxidative stress, and angiogenesis, all associated with different perinatal outcomes., {fulljournalname -> International Journal of Molecular Sciences, document -> 0, uuid -> 916047ee-b184-4873-9372-d5ac15aaee96, pieceId -> -1, score -> 0.63952809, target_text -> What are the effects of diabetes on the body?, code -> PMC8348825-916047ee-b184-4873-9372-d5ac15aaee96, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Gestational Diabetes Mellitus (GDM) is a transitory metabolic condition caused by dysregulation triggered by intolerance to carbohydrates, dysfunction of beta-pancreatic and endothelial cells, and insulin resistance during pregnancy. However, this disease includes not only changes related to metabolic distress but also placental immunoendocrine adaptations, resulting in harmful effects to the mother and fetus. In this review, we focus on the placenta as an immuno-endocrine organ that can recognize and respond to the hyperglycemic environment. It synthesizes diverse chemicals that play a role in inflammation, innate defense, endocrine response, oxidative stress, and angiogenesis, all associated with different perinatal outcomes., title -> Immunoendocrine Dysregulation during Gestational Diabetes Mellitus: The Central Role of the Placenta, pubdate -> 2021 Jul 28, distance -> 0.36047191, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                          |
# |{vector_similarity_rankings, 0, 44, We provide novel information on the prevalence and clinical features of fulminant type 1 diabetes mellitus in Korea., {fulljournalname -> Journal of Diabetes Investigation, document -> 4, uuid -> b3b39bc4-9f02-400f-b1e5-8ae313765533, pieceId -> -1, score -> 0.63645101, target_text -> What are the effects of diabetes on the body?, code -> PMC8756324-b3b39bc4-9f02-400f-b1e5-8ae313765533, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> We provide novel information on the prevalence and clinical features of fulminant type 1 diabetes mellitus in Korea., title -> Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research, pubdate -> 2021 Aug 31, distance -> 0.36354899, sentence -> 4}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# |{vector_similarity_rankings, 0, 44, Immunotherapy is now a recognized treatment option for several types of cancer. However, some cancer patients treated with immune checkpoint inhibitors (ICIs) are subject to immune-related adverse events, including induced diabetes mellitus. The exact role and molecular/genetic action of ICIs in diabetes are still not well understood. Elucidating the underlying mechanisms in a proper fashion would allow better refining of biomarkers that would help diagnose patients at risk of altered immune system homeostasis, but would also hold the potential of new therapeutic options for diabetes. In the present narrative review, we propose to discuss the case of autoimmune diabetes following treatment with ICIs and the role of ICIs in the pathophysiology of diabetes. We also present some scarce available data on interesting potential immune therapies for diabetes., {fulljournalname -> International Journal of Molecular Sciences, document -> 0, uuid -> 814194af-7d54-4587-9939-e2dd25ae49d7, pieceId -> -1, score -> 0.62932451, target_text -> What are the effects of diabetes on the body?, code -> PMC7923776-814194af-7d54-4587-9939-e2dd25ae49d7, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Immunotherapy is now a recognized treatment option for several types of cancer. However, some cancer patients treated with immune checkpoint inhibitors (ICIs) are subject to immune-related adverse events, including induced diabetes mellitus. The exact role and molecular/genetic action of ICIs in diabetes are still not well understood. Elucidating the underlying mechanisms in a proper fashion would allow better refining of biomarkers that would help diagnose patients at risk of altered immune system homeostasis, but would also hold the potential of new therapeutic options for diabetes. In the present narrative review, we propose to discuss the case of autoimmune diabetes following treatment with ICIs and the role of ICIs in the pathophysiology of diabetes. We also present some scarce available data on interesting potential immune therapies for diabetes., title -> Immune Checkpoint Inhibitor-Induced Diabetes Mellitus: Potential Role of T Cells in the Underlying Mechanism, pubdate -> 2021 Feb 20, distance -> 0.37067549, sentence -> 0}, []}                                                                                                                                    |
# |{vector_similarity_rankings, 0, 44, Microvascular disease (MVD) is a potential contributor to the pathogenesis of diabetes mellitus–related cardiac dysfunction. However, there is a paucity of data on the link between MVD and incident heart failure (HF) in type 2 diabetes mellitus. We examined the association of MVD with incident HF in adults with type 2 diabetes mellitus., {fulljournalname -> Journal of the American Heart Association: Cardiovascular and Cerebrovascular Disease, document -> 0, uuid -> c21d0cee-ea14-42c6-9503-db792a2056a4, pieceId -> -1, score -> 0.62841475, target_text -> What are the effects of diabetes on the body?, code -> PMC8477890-c21d0cee-ea14-42c6-9503-db792a2056a4, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Microvascular disease (MVD) is a potential contributor to the pathogenesis of diabetes mellitus–related cardiac dysfunction. However, there is a paucity of data on the link between MVD and incident heart failure (HF) in type 2 diabetes mellitus. We examined the association of MVD with incident HF in adults with type 2 diabetes mellitus., title -> Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus, pubdate -> 2021 Jun 10, distance -> 0.37158525, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# |{vector_similarity_rankings, 0, 44, Type 1 diabetes mellitus (T1DM) is associated with premature cardiovascular disease (CVD), but the underlying mechanisms remain poorly understood. The American Diabetes Association and the European Association for the Study of Diabetes recently updated their position statement on the management of type 2 diabetes mellitus (T2DM) to include additional focus on cardiovascular risk; improved management of risk factors in T1DM is also needed. There are important differences in the pathophysiology of CVD in T1DM and T2DM. Hyperglycaemia appears to have a more profound effect on cardiovascular risk in T1DM than T2DM, and other risk factors appear to cause a synergistic rather than additive effect, so achievement of treatment targets for all recognized risk factors is crucial to reducing cardiovascular risk. Here we discuss the evidence for addressing established cardiovascular risk factors, candidate biomarkers and surrogate measurements, and possible interventions., {fulljournalname -> Diabetes Therapy, document -> 0, uuid -> 6e0c9411-b3a6-402d-852c-23c835d82313, pieceId -> -1, score -> 0.61824764, target_text -> What are the effects of diabetes on the body?, code -> PMC6531592-6e0c9411-b3a6-402d-852c-23c835d82313, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Type 1 diabetes mellitus (T1DM) is associated with premature cardiovascular disease (CVD), but the underlying mechanisms remain poorly understood. The American Diabetes Association and the European Association for the Study of Diabetes recently updated their position statement on the management of type 2 diabetes mellitus (T2DM) to include additional focus on cardiovascular risk; improved management of risk factors in T1DM is also needed. There are important differences in the pathophysiology of CVD in T1DM and T2DM. Hyperglycaemia appears to have a more profound effect on cardiovascular risk in T1DM than T2DM, and other risk factors appear to cause a synergistic rather than additive effect, so achievement of treatment targets for all recognized risk factors is crucial to reducing cardiovascular risk. Here we discuss the evidence for addressing established cardiovascular risk factors, candidate biomarkers and surrogate measurements, and possible interventions., title -> Cardiovascular Risk in Type 1 Diabetes Mellitus, pubdate -> 2019 Apr 19, distance -> 0.38175236, sentence -> 0}, []}|
# |{vector_similarity_rankings, 0, 44, Smoking is a strong risk factor for albuminuria in people with type 2 diabetes mellitus (T2DM). However, it is unclear whether this sequela of smoking is brought about by its action on cardiometabolic parameters or the relationship is independent. The aim of this systematic review is to explore this relationship., {fulljournalname -> Acta Diabetologica, document -> 0, uuid -> 5ddb9db3-53a5-4b5a-8ef1-c630d60ce1f4, pieceId -> -1, score -> 0.61680575, target_text -> What are the effects of diabetes on the body?, code -> PMC6597612-5ddb9db3-53a5-4b5a-8ef1-c630d60ce1f4, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Smoking is a strong risk factor for albuminuria in people with type 2 diabetes mellitus (T2DM). However, it is unclear whether this sequela of smoking is brought about by its action on cardiometabolic parameters or the relationship is independent. The aim of this systematic review is to explore this relationship., title -> Association of smoking and cardiometabolic parameters with albuminuria in people with type 2 diabetes mellitus: a systematic review and meta-analysis, pubdate -> 2019 Feb 24, distance -> 0.38319425, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |{vector_similarity_rankings, 0, 44, Determining risk factors for diabetes insipidus (DI) after pituitary surgery is important in improving patient care. Our objective is to determine the factors associated with DI after pituitary surgery., {fulljournalname -> Endocrinology and Metabolism, document -> 0, uuid -> 428e1ecb-36e0-4657-9c25-3a12e6210cd2, pieceId -> -1, score -> 0.61419606, target_text -> What are the effects of diabetes on the body?, code -> PMC5744728-428e1ecb-36e0-4657-9c25-3a12e6210cd2, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Determining risk factors for diabetes insipidus (DI) after pituitary surgery is important in improving patient care. Our objective is to determine the factors associated with DI after pituitary surgery., title -> Factors Associated with Postoperative Diabetes Insipidus after Pituitary Surgery, pubdate -> 2017 Nov 21, distance -> 0.38580394, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# |{vector_similarity_rankings, 0, 44, This study aimed to determine whether diabetes mellitus and high body mass index are risk factors for COVID-19 in pregnancy and whether gestational diabetes mellitus is associated with COVID-19 diagnosis., {fulljournalname -> American Journal of Obstetrics and Gynecology, document -> 1, uuid -> 02028a97-c4c4-46f9-b88a-bb476f60205c, pieceId -> -1, score -> 0.61013022, target_text -> What are the effects of diabetes on the body?, code -> PMC8686449-02028a97-c4c4-46f9-b88a-bb476f60205c, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> This study aimed to determine whether diabetes mellitus and high body mass index are risk factors for COVID-19 in pregnancy and whether gestational diabetes mellitus is associated with COVID-19 diagnosis., title -> Diabetes mellitus, maternal adiposity, and insulin-dependent gestational diabetes are associated with COVID-19 in pregnancy: the INTERCOVID study, pubdate -> 2021 Dec 20, distance -> 0.38986978, sentence -> 1}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# |{vector_similarity_rankings, 0, 44, Genetic variance of AVPR1B contributes to overweight. Furthermore, our data indicate a link between AVPR1B variance and DM development. Our data point at a relationship between the disturbance of the pharmacologically modifiable AVP system and the body weight regulation., {fulljournalname -> European Journal of Endocrinology, document -> 4, uuid -> 9bba9908-aba8-4e0e-a936-267a7c021c26, pieceId -> -1, score -> 0.60795502, target_text -> What are the effects of diabetes on the body?, code -> PMC4653349-9bba9908-aba8-4e0e-a936-267a7c021c26, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Genetic variance of AVPR1B contributes to overweight. Furthermore, our data indicate a link between AVPR1B variance and DM development. Our data point at a relationship between the disturbance of the pharmacologically modifiable AVP system and the body weight regulation., title -> Genetic vasopressin 1b receptor variance in overweight and diabetes mellitus, pubdate -> 2016 Jan, distance -> 0.39204498, sentence -> 4}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |{vector_similarity_rankings, 0, 44, We aimed to determine the hospital‐based prevalence and clinical features of fulminant type 1 diabetes mellitus in Korea., {fulljournalname -> Journal of Diabetes Investigation, document -> 0, uuid -> 43adc9b2-d974-4b18-b732-ca8afa133082, pieceId -> -1, score -> 0.60589224, target_text -> What are the effects of diabetes on the body?, code -> PMC8756324-43adc9b2-d974-4b18-b732-ca8afa133082, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> We aimed to determine the hospital‐based prevalence and clinical features of fulminant type 1 diabetes mellitus in Korea., title -> Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research, pubdate -> 2021 Aug 31, distance -> 0.39410776, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |{vector_similarity_rankings, 0, 44, The present meta‐analysis was carried out to assess the association between exposure to the level of atmospheric particulate matter 2.5 (PM2.5; fine particulate matter with aerodynamic diameter less than 2.5 μm) and type 2 diabetes mellitus or gestational diabetes mellitus (GDM)., {fulljournalname -> Journal of Diabetes Investigation, document -> 0, uuid -> f7588513-39c0-4f9b-b3c0-46bfb1c315aa, pieceId -> -1, score -> 0.60588633, target_text -> What are the effects of diabetes on the body?, code -> PMC5583950-f7588513-39c0-4f9b-b3c0-46bfb1c315aa, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> The present meta‐analysis was carried out to assess the association between exposure to the level of atmospheric particulate matter 2.5 (PM2.5; fine particulate matter with aerodynamic diameter less than 2.5 μm) and type 2 diabetes mellitus or gestational diabetes mellitus (GDM)., title -> Association between particulate matter 2.5 and diabetes mellitus: A meta‐analysis of cohort studies, pubdate -> 2017 May 3, distance -> 0.39411367, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# |{vector_similarity_rankings, 0, 44, Wolfram syndrome (WS) is an autosomal recessive neurodegenerative disorder characterized by diabetes mellitus (DM), optic atrophy (OA), central diabetes insipidus (CDI) and deafness (D)., {fulljournalname -> Italian Journal of Pediatrics, document -> 0, uuid -> 85caa88d-4cd2-4cc4-9e8a-3684aa145608, pieceId -> -1, score -> 0.60134703, target_text -> What are the effects of diabetes on the body?, code -> PMC4422421-85caa88d-4cd2-4cc4-9e8a-3684aa145608, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Wolfram syndrome (WS) is an autosomal recessive neurodegenerative disorder characterized by diabetes mellitus (DM), optic atrophy (OA), central diabetes insipidus (CDI) and deafness (D)., title -> Congenital central diabetes insipidus and optic atrophy in a Wolfram newborn: is there a role for WFS1 gene in neurodevelopment?, pubdate -> 2014 Sep 26, distance -> 0.39865297, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
Flattener().setInputCols("vector_db").setExplodeSelectedFields({"vector_db": ["metadata.distance", "metadata.pubdate", "metadata.title", "metadata.fulljournalname"]}).transform(vector_df).show(truncate=False)
# Out:
# +---------------------------+--------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+
# |vector_db_metadata_distance|vector_db_metadata_pubdate|vector_db_metadata_title                                                                                                                             |vector_db_metadata_fulljournalname                                                   |
# +---------------------------+--------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+
# |0.20076137                 |2020 Dec 10               |Different information needs in subgroups of people with diabetes mellitus: a latent class analysis                                                   |BMC Public Health                                                                    |
# |0.26189331                 |2016 Oct 30               |Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus                                        |Journal of Diabetes Investigation                                                    |
# |0.27923813                 |2020 Mar 30               |Prevalence and incidence of type 1 diabetes in the world: a systematic review and meta-analysis                                                      |Health Promotion Perspectives                                                        |
# |0.30312586                 |2019 Jun 6                |Salivary cortisol is not associated with incident insulin resistance or type 2 diabetes mellitus                                                     |Endocrine Connections                                                                |
# |0.30355884                 |2016 Oct 30               |Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus                                        |Journal of Diabetes Investigation                                                    |
# |0.31533556                 |2017 Mar 27               |Proteomic analysis of serum biomarkers for prediabetes using the Long‐Evans Agouti rat, a spontaneous animal model of type 2 diabetes mellitus       |Journal of Diabetes Investigation                                                    |
# |0.34893499                 |2021 May 18               |Insulin Resistance and Diabetes Mellitus in Alzheimer’s Disease                                                                                      |Cells                                                                                |
# |0.35542960                 |2021 Jun 10               |Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus                                                     |Journal of the American Heart Association: Cardiovascular and Cerebrovascular Disease|
# |0.36047191                 |2021 Jul 28               |Immunoendocrine Dysregulation during Gestational Diabetes Mellitus: The Central Role of the Placenta                                                 |International Journal of Molecular Sciences                                          |
# |0.36354899                 |2021 Aug 31               |Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research                 |Journal of Diabetes Investigation                                                    |
# |0.37067549                 |2021 Feb 20               |Immune Checkpoint Inhibitor-Induced Diabetes Mellitus: Potential Role of T Cells in the Underlying Mechanism                                         |International Journal of Molecular Sciences                                          |
# |0.37158525                 |2021 Jun 10               |Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus                                                     |Journal of the American Heart Association: Cardiovascular and Cerebrovascular Disease|
# |0.38175236                 |2019 Apr 19               |Cardiovascular Risk in Type 1 Diabetes Mellitus                                                                                                      |Diabetes Therapy                                                                     |
# |0.38319425                 |2019 Feb 24               |Association of smoking and cardiometabolic parameters with albuminuria in people with type 2 diabetes mellitus: a systematic review and meta-analysis|Acta Diabetologica                                                                   |
# |0.38580394                 |2017 Nov 21               |Factors Associated with Postoperative Diabetes Insipidus after Pituitary Surgery                                                                     |Endocrinology and Metabolism                                                         |
# |0.38986978                 |2021 Dec 20               |Diabetes mellitus, maternal adiposity, and insulin-dependent gestational diabetes are associated with COVID-19 in pregnancy: the INTERCOVID study    |American Journal of Obstetrics and Gynecology                                        |
# |0.39204498                 |2016 Jan                  |Genetic vasopressin 1b receptor variance in overweight and diabetes mellitus                                                                         |European Journal of Endocrinology                                                    |
# |0.39410776                 |2021 Aug 31               |Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research                 |Journal of Diabetes Investigation                                                    |
# |0.39411367                 |2017 May 3                |Association between particulate matter 2.5 and diabetes mellitus: A meta‐analysis of cohort studies                                                  |Journal of Diabetes Investigation                                                    |
# |0.39865297                 |2014 Sep 26               |Congenital central diabetes insipidus and optic atrophy in a Wolfram newborn: is there a role for WFS1 gene in neurodevelopment?                     |Italian Journal of Pediatrics                                                        |
# +---------------------------+--------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+

# %% [markdown]
# ## VectorDBPostProcessor Initialize

# %% [markdown]
# VectorDBPostProcessor
# ````
# Parameters
# ----------
# filterBy: str
#     The filterBy parameter is used to select and prioritize filter options.
#     Options: `metadata`, and `diversity_by_threshold`.
#     Options can be given as a comma separated string like "metadata, diversityByThreshold". The order of the options will be used to filter the annotations.
#     - `metadata`: Filter by metadata fields. The `metadataCriteria` parameter should be set.
#     - `diversity_by_threshold`: Filter by diversity threshold. Filter by the distance between the sorted annotations.
#     When `diversity_by_threshold` option is set, `diversityThreshold` parameter should be used to set the threshold.
#     Default: `metadata`
# sortBy: str
#     The sortBy parameter is used to select sorting option.
#     Options: `ascending`, `descending`, `lost_in_the_middle`, `diversity`.
#     - `ascending`: Sort by ascending order of distance.
#     - `descending`: Sort by descending order of distance.
#     - `lost_in_the_middle`: Sort by lost in the middle ranker. Let's say we have 5 annotations with distances [1, 2, 3, 4, 5]. The lost in the middle ranker will sort them as [1, 3, 5, 4, 2].
#     - `diversity`:  Sort by diversity ranker. The annotations are sorted by distance and the first annotation select, and then the next annotation is selected by the maximum average distance from the selected annotations.
#     Default: `ascending`
# caseSensitive: bool
#     Whether the criteria of the string operators are case sensitive or not.
#     For example, if set to False, the operator "equals" will match "John" with "john".
#     Default: False
# diversityThreshold: float
#     The diversityThreshold parameter is used to set the threshold for the diversityByThreshold filter.
#     The diversityByThreshold filter selects the annotations by the distance between the sorted annotations.
#     Default: 0.01
# maxTopKAfterFiltering: int
#     The maxTopKAfterFiltering parameter is used to set the maximum number of annotations to return after filtering.
#     If the number of annotations after filtering is greater than maxTopKAfterFiltering, the top maxTopKAfterFiltering annotations are selected.
#     Default: 20
# allowZeroContentAfterFiltering: bool
#     Whether to allow zero annotation after filtering.
#     If set to True, the output may contain zero annotation if all annotations are filtered out.
#     If set to False, The output is tried to contain at least one annotation.
#     Default: False
# metadataCriteria: list[dict]
#     The metadataCriteria parameter is used to filter the annotations by metadata fields.
#     The metadataCriteria param is a list of dictionaries.
#     A dictionary should contain the following keys:
#
#     - `field`: The field of the metadata to filter.
#     - `fieldType`: The type of the field to filter. Options: string, int, float, date.
#     - `operator`: The operator to apply to the filter. Options: equals, not_equals, greater_than, greater_than_or_equals, less_than, less_than_or_equals, contains, not_contains, regex.
#     - `value`: The value to filter.
#     - `matchMode`: The match mode to apply to the filter. Options: any, all, none.
#     - `matchValues`: The values to filter.
#     - `dateFormats`: The date formats to parse the date metadata field.
#     - `converterFallback`: The converter fallback when hitting cast exception. Options: filter, not_filter, error.
#
#     Notes:
#     ------
#     - `field`, `fieldType`, and `operator` are required. Other keys are optional.
#     - `fieldType` is set to `string`, supported operators are: equals, not_equals, contains, not_contains, regex.
#     - `fieldType` is set to `int` or `float` or `date`, supported operators are: equals, not_equals, greater_than, greater_than_or_equals, less_than, less_than_or_equals.
#     - If `matchMode` and `matchValues` are not set, `value` must be set.
#     - If `value` is set, `matchMode` and `matchValues` are ignored.
#     - If `fieldType` is set to `date`, `dateFormats` must be set.
#     - `matchMode` and `matchValues` must be set together.
#     - If `converterFallback` is set to `error`, the filter will throw an error when hitting cast exception. Default 'error'.
# ````

# %%
post_processor = VectorDBPostProcessor() \
    .setInputCols("vector_db") \
    .setOutputCol("post") \
    .setFilterBy("metadata") \
    .setMetadataCriteria([
        {"field": "pubdate", "fieldType": "date", "operator": "greater_than", "value": "2017 May 11", "dateFormats": ["yyyy MMM dd", "yyyy MMM d"], "converterFallback": "filter"},
        {"field": "distance", "fieldType": "float", "operator": "less_than", "value": "0.5470"},
        {"field": "title", "fieldType": "string", "operator": "contains", "matchMode": "any", "matchValues": ["diabetes", "immune system"]}
      ])

flattener = Flattener() \
  .setInputCols("post") \
  .setExplodeSelectedFields({"post": ["metadata.distance", "metadata.score", "metadata.pubdate", "metadata.title", "metadata.fulljournalname"]})

# %%
flattener.transform(post_processor.transform(vector_df)) \
  .show(truncate=False)
# Out:
# +----------------------+-------------------+---------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+
# |post_metadata_distance|post_metadata_score|post_metadata_pubdate|post_metadata_title                                                                                                                                  |post_metadata_fulljournalname                                                        |
# +----------------------+-------------------+---------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+
# |0.20076137            |0.79923863         |2020 Dec 10          |Different information needs in subgroups of people with diabetes mellitus: a latent class analysis                                                   |BMC Public Health                                                                    |
# |0.27923813            |0.72076187         |2020 Mar 30          |Prevalence and incidence of type 1 diabetes in the world: a systematic review and meta-analysis                                                      |Health Promotion Perspectives                                                        |
# |0.30312586            |0.69687414         |2019 Jun 6           |Salivary cortisol is not associated with incident insulin resistance or type 2 diabetes mellitus                                                     |Endocrine Connections                                                                |
# |0.34893499            |0.65106501         |2021 May 18          |Insulin Resistance and Diabetes Mellitus in Alzheimer’s Disease                                                                                      |Cells                                                                                |
# |0.35542960            |0.64457040         |2021 Jun 10          |Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus                                                     |Journal of the American Heart Association: Cardiovascular and Cerebrovascular Disease|
# |0.36047191            |0.63952809         |2021 Jul 28          |Immunoendocrine Dysregulation during Gestational Diabetes Mellitus: The Central Role of the Placenta                                                 |International Journal of Molecular Sciences                                          |
# |0.36354899            |0.63645101         |2021 Aug 31          |Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research                 |Journal of Diabetes Investigation                                                    |
# |0.37067549            |0.62932451         |2021 Feb 20          |Immune Checkpoint Inhibitor-Induced Diabetes Mellitus: Potential Role of T Cells in the Underlying Mechanism                                         |International Journal of Molecular Sciences                                          |
# |0.37158525            |0.62841475         |2021 Jun 10          |Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus                                                     |Journal of the American Heart Association: Cardiovascular and Cerebrovascular Disease|
# |0.38175236            |0.61824764         |2019 Apr 19          |Cardiovascular Risk in Type 1 Diabetes Mellitus                                                                                                      |Diabetes Therapy                                                                     |
# |0.38319425            |0.61680575         |2019 Feb 24          |Association of smoking and cardiometabolic parameters with albuminuria in people with type 2 diabetes mellitus: a systematic review and meta-analysis|Acta Diabetologica                                                                   |
# |0.38580394            |0.61419606         |2017 Nov 21          |Factors Associated with Postoperative Diabetes Insipidus after Pituitary Surgery                                                                     |Endocrinology and Metabolism                                                         |
# |0.38986978            |0.61013022         |2021 Dec 20          |Diabetes mellitus, maternal adiposity, and insulin-dependent gestational diabetes are associated with COVID-19 in pregnancy: the INTERCOVID study    |American Journal of Obstetrics and Gynecology                                        |
# |0.39410776            |0.60589224         |2021 Aug 31          |Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research                 |Journal of Diabetes Investigation                                                    |
# +----------------------+-------------------+---------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+

# %% [markdown]
# ## Check sortBy lost_in_the_middle

# %%
flattener.transform(post_processor.setSortBy("lost_in_the_middle").transform(vector_df)) \
  .show(truncate=False)
# Out:
# +----------------------+-------------------+---------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+
# |post_metadata_distance|post_metadata_score|post_metadata_pubdate|post_metadata_title                                                                                                                                  |post_metadata_fulljournalname                                                        |
# +----------------------+-------------------+---------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+
# |0.20076137            |0.79923863         |2020 Dec 10          |Different information needs in subgroups of people with diabetes mellitus: a latent class analysis                                                   |BMC Public Health                                                                    |
# |0.30312586            |0.69687414         |2019 Jun 6           |Salivary cortisol is not associated with incident insulin resistance or type 2 diabetes mellitus                                                     |Endocrine Connections                                                                |
# |0.35542960            |0.64457040         |2021 Jun 10          |Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus                                                     |Journal of the American Heart Association: Cardiovascular and Cerebrovascular Disease|
# |0.36354899            |0.63645101         |2021 Aug 31          |Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research                 |Journal of Diabetes Investigation                                                    |
# |0.37158525            |0.62841475         |2021 Jun 10          |Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus                                                     |Journal of the American Heart Association: Cardiovascular and Cerebrovascular Disease|
# |0.38319425            |0.61680575         |2019 Feb 24          |Association of smoking and cardiometabolic parameters with albuminuria in people with type 2 diabetes mellitus: a systematic review and meta-analysis|Acta Diabetologica                                                                   |
# |0.38986978            |0.61013022         |2021 Dec 20          |Diabetes mellitus, maternal adiposity, and insulin-dependent gestational diabetes are associated with COVID-19 in pregnancy: the INTERCOVID study    |American Journal of Obstetrics and Gynecology                                        |
# |0.39410776            |0.60589224         |2021 Aug 31          |Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research                 |Journal of Diabetes Investigation                                                    |
# |0.38580394            |0.61419606         |2017 Nov 21          |Factors Associated with Postoperative Diabetes Insipidus after Pituitary Surgery                                                                     |Endocrinology and Metabolism                                                         |
# |0.38175236            |0.61824764         |2019 Apr 19          |Cardiovascular Risk in Type 1 Diabetes Mellitus                                                                                                      |Diabetes Therapy                                                                     |
# |0.37067549            |0.62932451         |2021 Feb 20          |Immune Checkpoint Inhibitor-Induced Diabetes Mellitus: Potential Role of T Cells in the Underlying Mechanism                                         |International Journal of Molecular Sciences                                          |
# |0.36047191            |0.63952809         |2021 Jul 28          |Immunoendocrine Dysregulation during Gestational Diabetes Mellitus: The Central Role of the Placenta                                                 |International Journal of Molecular Sciences                                          |
# |0.34893499            |0.65106501         |2021 May 18          |Insulin Resistance and Diabetes Mellitus in Alzheimer’s Disease                                                                                      |Cells                                                                                |
# |0.27923813            |0.72076187         |2020 Mar 30          |Prevalence and incidence of type 1 diabetes in the world: a systematic review and meta-analysis                                                      |Health Promotion Perspectives                                                        |
# +----------------------+-------------------+---------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+

# %% [markdown]
# ## check sortBy diversity

# %%
flattener.transform(post_processor.setSortBy("diversity").transform(vector_df)) \
  .show(truncate=False)
# Out:
# +----------------------+-------------------+---------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+
# |post_metadata_distance|post_metadata_score|post_metadata_pubdate|post_metadata_title                                                                                                                                  |post_metadata_fulljournalname                                                        |
# +----------------------+-------------------+---------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+
# |0.20076137            |0.79923863         |2020 Dec 10          |Different information needs in subgroups of people with diabetes mellitus: a latent class analysis                                                   |BMC Public Health                                                                    |
# |0.39410776            |0.60589224         |2021 Aug 31          |Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research                 |Journal of Diabetes Investigation                                                    |
# |0.27923813            |0.72076187         |2020 Mar 30          |Prevalence and incidence of type 1 diabetes in the world: a systematic review and meta-analysis                                                      |Health Promotion Perspectives                                                        |
# |0.38986978            |0.61013022         |2021 Dec 20          |Diabetes mellitus, maternal adiposity, and insulin-dependent gestational diabetes are associated with COVID-19 in pregnancy: the INTERCOVID study    |American Journal of Obstetrics and Gynecology                                        |
# |0.35542960            |0.64457040         |2021 Jun 10          |Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus                                                     |Journal of the American Heart Association: Cardiovascular and Cerebrovascular Disease|
# |0.30312586            |0.69687414         |2019 Jun 6           |Salivary cortisol is not associated with incident insulin resistance or type 2 diabetes mellitus                                                     |Endocrine Connections                                                                |
# |0.38580394            |0.61419606         |2017 Nov 21          |Factors Associated with Postoperative Diabetes Insipidus after Pituitary Surgery                                                                     |Endocrinology and Metabolism                                                         |
# |0.38319425            |0.61680575         |2019 Feb 24          |Association of smoking and cardiometabolic parameters with albuminuria in people with type 2 diabetes mellitus: a systematic review and meta-analysis|Acta Diabetologica                                                                   |
# |0.34893499            |0.65106501         |2021 May 18          |Insulin Resistance and Diabetes Mellitus in Alzheimer’s Disease                                                                                      |Cells                                                                                |
# |0.38175236            |0.61824764         |2019 Apr 19          |Cardiovascular Risk in Type 1 Diabetes Mellitus                                                                                                      |Diabetes Therapy                                                                     |
# |0.36047191            |0.63952809         |2021 Jul 28          |Immunoendocrine Dysregulation during Gestational Diabetes Mellitus: The Central Role of the Placenta                                                 |International Journal of Molecular Sciences                                          |
# |0.37158525            |0.62841475         |2021 Jun 10          |Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus                                                     |Journal of the American Heart Association: Cardiovascular and Cerebrovascular Disease|
# |0.36354899            |0.63645101         |2021 Aug 31          |Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research                 |Journal of Diabetes Investigation                                                    |
# |0.37067549            |0.62932451         |2021 Feb 20          |Immune Checkpoint Inhibitor-Induced Diabetes Mellitus: Potential Role of T Cells in the Underlying Mechanism                                         |International Journal of Molecular Sciences                                          |
# +----------------------+-------------------+---------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+

# %% [markdown]
# ## Check sortBy ascending

# %%
flattener.transform(post_processor.setSortBy("ascending").transform(vector_df)) \
  .show(truncate=False)
# Out:
# +----------------------+-------------------+---------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+
# |post_metadata_distance|post_metadata_score|post_metadata_pubdate|post_metadata_title                                                                                                                                  |post_metadata_fulljournalname                                                        |
# +----------------------+-------------------+---------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+
# |0.20076137            |0.79923863         |2020 Dec 10          |Different information needs in subgroups of people with diabetes mellitus: a latent class analysis                                                   |BMC Public Health                                                                    |
# |0.27923813            |0.72076187         |2020 Mar 30          |Prevalence and incidence of type 1 diabetes in the world: a systematic review and meta-analysis                                                      |Health Promotion Perspectives                                                        |
# |0.30312586            |0.69687414         |2019 Jun 6           |Salivary cortisol is not associated with incident insulin resistance or type 2 diabetes mellitus                                                     |Endocrine Connections                                                                |
# |0.34893499            |0.65106501         |2021 May 18          |Insulin Resistance and Diabetes Mellitus in Alzheimer’s Disease                                                                                      |Cells                                                                                |
# |0.35542960            |0.64457040         |2021 Jun 10          |Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus                                                     |Journal of the American Heart Association: Cardiovascular and Cerebrovascular Disease|
# |0.36047191            |0.63952809         |2021 Jul 28          |Immunoendocrine Dysregulation during Gestational Diabetes Mellitus: The Central Role of the Placenta                                                 |International Journal of Molecular Sciences                                          |
# |0.36354899            |0.63645101         |2021 Aug 31          |Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research                 |Journal of Diabetes Investigation                                                    |
# |0.37067549            |0.62932451         |2021 Feb 20          |Immune Checkpoint Inhibitor-Induced Diabetes Mellitus: Potential Role of T Cells in the Underlying Mechanism                                         |International Journal of Molecular Sciences                                          |
# |0.37158525            |0.62841475         |2021 Jun 10          |Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus                                                     |Journal of the American Heart Association: Cardiovascular and Cerebrovascular Disease|
# |0.38175236            |0.61824764         |2019 Apr 19          |Cardiovascular Risk in Type 1 Diabetes Mellitus                                                                                                      |Diabetes Therapy                                                                     |
# |0.38319425            |0.61680575         |2019 Feb 24          |Association of smoking and cardiometabolic parameters with albuminuria in people with type 2 diabetes mellitus: a systematic review and meta-analysis|Acta Diabetologica                                                                   |
# |0.38580394            |0.61419606         |2017 Nov 21          |Factors Associated with Postoperative Diabetes Insipidus after Pituitary Surgery                                                                     |Endocrinology and Metabolism                                                         |
# |0.38986978            |0.61013022         |2021 Dec 20          |Diabetes mellitus, maternal adiposity, and insulin-dependent gestational diabetes are associated with COVID-19 in pregnancy: the INTERCOVID study    |American Journal of Obstetrics and Gynecology                                        |
# |0.39410776            |0.60589224         |2021 Aug 31          |Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research                 |Journal of Diabetes Investigation                                                    |
# +----------------------+-------------------+---------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+

# %% [markdown]
# ## check filterBy diversityByThreshold

# %%
flattener.transform(post_processor.setFilterBy("metadata, diversity_by_threshold").setDiversityThreshold(0.05).transform(vector_df)) \
  .show(truncate=False)
# Out:
# +----------------------+-------------------+---------------------+--------------------------------------------------------------------------------------------------+-----------------------------+
# |post_metadata_distance|post_metadata_score|post_metadata_pubdate|post_metadata_title                                                                               |post_metadata_fulljournalname|
# +----------------------+-------------------+---------------------+--------------------------------------------------------------------------------------------------+-----------------------------+
# |0.20076137            |0.79923863         |2020 Dec 10          |Different information needs in subgroups of people with diabetes mellitus: a latent class analysis|BMC Public Health            |
# |0.27923813            |0.72076187         |2020 Mar 30          |Prevalence and incidence of type 1 diabetes in the world: a systematic review and meta-analysis   |Health Promotion Perspectives|
# |0.34893499            |0.65106501         |2021 May 18          |Insulin Resistance and Diabetes Mellitus in Alzheimer’s Disease                                   |Cells                        |
# +----------------------+-------------------+---------------------+--------------------------------------------------------------------------------------------------+-----------------------------+

# %% [markdown]
# ## check metadataCriteria

# %%
flattener.transform((
    post_processor
    .setSortBy("ascending")
    .setFilterBy("metadata")
    .setMetadataCriteria([{"field": "fulljournalname", "fieldType": "string", "operator": "equals", "matchMode": "any", "matchValues": ["Journal of Diabetes Investigation", "BMC Public Health"] }])).transform(vector_df)) \
  .show(truncate=False)
# Out:
# +----------------------+-------------------+---------------------+----------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------+
# |post_metadata_distance|post_metadata_score|post_metadata_pubdate|post_metadata_title                                                                                                                           |post_metadata_fulljournalname    |
# +----------------------+-------------------+---------------------+----------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------+
# |0.20076137            |0.79923863         |2020 Dec 10          |Different information needs in subgroups of people with diabetes mellitus: a latent class analysis                                            |BMC Public Health                |
# |0.26189331            |0.73810669         |2016 Oct 30          |Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus                                 |Journal of Diabetes Investigation|
# |0.30355884            |0.69644116         |2016 Oct 30          |Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus                                 |Journal of Diabetes Investigation|
# |0.31533556            |0.68466444         |2017 Mar 27          |Proteomic analysis of serum biomarkers for prediabetes using the Long‐Evans Agouti rat, a spontaneous animal model of type 2 diabetes mellitus|Journal of Diabetes Investigation|
# |0.36354899            |0.63645101         |2021 Aug 31          |Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research          |Journal of Diabetes Investigation|
# |0.39410776            |0.60589224         |2021 Aug 31          |Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research          |Journal of Diabetes Investigation|
# |0.39411367            |0.60588633         |2017 May 3           |Association between particulate matter 2.5 and diabetes mellitus: A meta‐analysis of cohort studies                                           |Journal of Diabetes Investigation|
# +----------------------+-------------------+---------------------+----------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------+

# %%
flattener.transform((
    post_processor
    .setSortBy("ascending")
    .setFilterBy("metadata")
    .setMetadataCriteria(
        [{"field": "fulljournalname", "fieldType": "string", "operator": "equals", "matchMode": "any", "matchValues": ["Journal of Diabetes Investigation", "BMC Public Health"] },
         {"field": "pubdate", "fieldType": "date", "operator": "not_equals", "matchMode": "all", "matchValues": ["2017Mar27", "2017May03"], "dateFormats": ["yyyy MMM dd", "yyyy MMM d", "yyyy MMM", "yyyyMMMdd"] }
         ])).transform(vector_df)) \
  .show(truncate=False)
# Out:
# +----------------------+-------------------+---------------------+------------------------------------------------------------------------------------------------------------------------------------+---------------------------------+
# |post_metadata_distance|post_metadata_score|post_metadata_pubdate|post_metadata_title                                                                                                                 |post_metadata_fulljournalname    |
# +----------------------+-------------------+---------------------+------------------------------------------------------------------------------------------------------------------------------------+---------------------------------+
# |0.20076137            |0.79923863         |2020 Dec 10          |Different information needs in subgroups of people with diabetes mellitus: a latent class analysis                                  |BMC Public Health                |
# |0.26189331            |0.73810669         |2016 Oct 30          |Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus                       |Journal of Diabetes Investigation|
# |0.30355884            |0.69644116         |2016 Oct 30          |Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus                       |Journal of Diabetes Investigation|
# |0.36354899            |0.63645101         |2021 Aug 31          |Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research|Journal of Diabetes Investigation|
# |0.39410776            |0.60589224         |2021 Aug 31          |Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research|Journal of Diabetes Investigation|
# +----------------------+-------------------+---------------------+------------------------------------------------------------------------------------------------------------------------------------+---------------------------------+

# %% [markdown]
# ## check between

# %%
flattener.transform((
    post_processor
    .setSortBy("ascending")
    .setFilterBy("metadata")
    .setMetadataCriteria(
        [{"field": "distance", "fieldType": "float", "operator": "greater_than", "value": "0.30"},
         {"field": "distance", "fieldType": "float", "operator": "less_than", "value": "0.39"}
         ])).transform(vector_df)) \
  .show(truncate=False)
# Out:
# +----------------------+-------------------+---------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+
# |post_metadata_distance|post_metadata_score|post_metadata_pubdate|post_metadata_title                                                                                                                                  |post_metadata_fulljournalname                                                        |
# +----------------------+-------------------+---------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+
# |0.30312586            |0.69687414         |2019 Jun 6           |Salivary cortisol is not associated with incident insulin resistance or type 2 diabetes mellitus                                                     |Endocrine Connections                                                                |
# |0.30355884            |0.69644116         |2016 Oct 30          |Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus                                        |Journal of Diabetes Investigation                                                    |
# |0.31533556            |0.68466444         |2017 Mar 27          |Proteomic analysis of serum biomarkers for prediabetes using the Long‐Evans Agouti rat, a spontaneous animal model of type 2 diabetes mellitus       |Journal of Diabetes Investigation                                                    |
# |0.34893499            |0.65106501         |2021 May 18          |Insulin Resistance and Diabetes Mellitus in Alzheimer’s Disease                                                                                      |Cells                                                                                |
# |0.35542960            |0.64457040         |2021 Jun 10          |Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus                                                     |Journal of the American Heart Association: Cardiovascular and Cerebrovascular Disease|
# |0.36047191            |0.63952809         |2021 Jul 28          |Immunoendocrine Dysregulation during Gestational Diabetes Mellitus: The Central Role of the Placenta                                                 |International Journal of Molecular Sciences                                          |
# |0.36354899            |0.63645101         |2021 Aug 31          |Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research                 |Journal of Diabetes Investigation                                                    |
# |0.37067549            |0.62932451         |2021 Feb 20          |Immune Checkpoint Inhibitor-Induced Diabetes Mellitus: Potential Role of T Cells in the Underlying Mechanism                                         |International Journal of Molecular Sciences                                          |
# |0.37158525            |0.62841475         |2021 Jun 10          |Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus                                                     |Journal of the American Heart Association: Cardiovascular and Cerebrovascular Disease|
# |0.38175236            |0.61824764         |2019 Apr 19          |Cardiovascular Risk in Type 1 Diabetes Mellitus                                                                                                      |Diabetes Therapy                                                                     |
# |0.38319425            |0.61680575         |2019 Feb 24          |Association of smoking and cardiometabolic parameters with albuminuria in people with type 2 diabetes mellitus: a systematic review and meta-analysis|Acta Diabetologica                                                                   |
# |0.38580394            |0.61419606         |2017 Nov 21          |Factors Associated with Postoperative Diabetes Insipidus after Pituitary Surgery                                                                     |Endocrinology and Metabolism                                                         |
# |0.38986978            |0.61013022         |2021 Dec 20          |Diabetes mellitus, maternal adiposity, and insulin-dependent gestational diabetes are associated with COVID-19 in pregnancy: the INTERCOVID study    |American Journal of Obstetrics and Gynecology                                        |
# +----------------------+-------------------+---------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+

# %% [markdown]
# ## check maxTopKAfterFiltering

# %%
flattener.transform((
    post_processor
    .setSortBy("ascending")
    .setFilterBy("metadata")
    .setMaxTopKAfterFiltering(5)
    .setMetadataCriteria(
        [{"field": "distance", "fieldType": "float", "operator": "greater_than", "value": "0.30"},
         {"field": "distance", "fieldType": "float", "operator": "less_than", "value": "0.39"}
         ])).transform(vector_df)) \
  .show(truncate=False)
# Out:
# +----------------------+-------------------+---------------------+----------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+
# |post_metadata_distance|post_metadata_score|post_metadata_pubdate|post_metadata_title                                                                                                                           |post_metadata_fulljournalname                                                        |
# +----------------------+-------------------+---------------------+----------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+
# |0.30312586            |0.69687414         |2019 Jun 6           |Salivary cortisol is not associated with incident insulin resistance or type 2 diabetes mellitus                                              |Endocrine Connections                                                                |
# |0.30355884            |0.69644116         |2016 Oct 30          |Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus                                 |Journal of Diabetes Investigation                                                    |
# |0.31533556            |0.68466444         |2017 Mar 27          |Proteomic analysis of serum biomarkers for prediabetes using the Long‐Evans Agouti rat, a spontaneous animal model of type 2 diabetes mellitus|Journal of Diabetes Investigation                                                    |
# |0.34893499            |0.65106501         |2021 May 18          |Insulin Resistance and Diabetes Mellitus in Alzheimer’s Disease                                                                               |Cells                                                                                |
# |0.35542960            |0.64457040         |2021 Jun 10          |Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus                                              |Journal of the American Heart Association: Cardiovascular and Cerebrovascular Disease|
# +----------------------+-------------------+---------------------+----------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+

# %% [markdown]
# ## check allowZeroContentAfterFiltering

# %%
flattener.transform((
    post_processor
    .setSortBy("ascending")
    .setFilterBy("metadata")
    .setAllowZeroContentAfterFiltering(False)  # Default: False
    .setMetadataCriteria(
        [{"field": "distance", "fieldType": "float", "operator": "equals", "value": "1.0"},
         ])).transform(vector_df)) \
  .show(truncate=False)
# Out:
# +----------------------+-------------------+---------------------+--------------------------------------------------------------------------------------------------+-----------------------------+
# |post_metadata_distance|post_metadata_score|post_metadata_pubdate|post_metadata_title                                                                               |post_metadata_fulljournalname|
# +----------------------+-------------------+---------------------+--------------------------------------------------------------------------------------------------+-----------------------------+
# |0.20076137            |0.79923863         |2020 Dec 10          |Different information needs in subgroups of people with diabetes mellitus: a latent class analysis|BMC Public Health            |
# +----------------------+-------------------+---------------------+--------------------------------------------------------------------------------------------------+-----------------------------+

# %% [markdown]
# # ContextSplitAssembler

# %% [markdown]
# ContextSplitAssembler is compatible with VectorDB and VectorDBPostProcessor
# ```python
# Parameters
#     ----------
#     joinString : str
#         This parameter specifies the string that will be inserted between results of annotations when combining them into a single result.
#         It acts as a delimiter, ensuring that the elements are properly separated and organized in the final result of annotation.
#         Default: " ".
#     explodeSplits : bool
#         Whether to explode the splits into separate annotations or not.
#         Default: False.
#   ```

# %%
context_split_assembler = ( ContextSplitAssembler()
  .setInputCols("vector_db")
  .setOutputCol("document")
  .setJoinString("\n")
  .setExplodeSplits(False))

# %%
vector_df.selectExpr("explode(vector_db) as vector_db").show(truncate=False)
# Out:
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |vector_db                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{vector_similarity_rankings, 0, 44, Current evidence suggests that the information needs of people with diabetes mellitus differ across patient groups. With a view to being able to provide individualized information, this study aims to identify (i) the diabetes-related information needs of people with diabetes mellitus; (ii) different subgroups of people with specific information needs; and (iii) associated characteristics of the identified subgroups, such as sociodemographic characteristics, diabetes-related comorbidities, and well-being., {fulljournalname -> BMC Public Health, document -> 0, uuid -> fbb7b54c-471e-47ec-9d12-b56b32f861d3, pieceId -> -1, score -> 0.79923863, target_text -> What are the effects of diabetes on the body?, code -> PMC7730786-fbb7b54c-471e-47ec-9d12-b56b32f861d3, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Current evidence suggests that the information needs of people with diabetes mellitus differ across patient groups. With a view to being able to provide individualized information, this study aims to identify (i) the diabetes-related information needs of people with diabetes mellitus; (ii) different subgroups of people with specific information needs; and (iii) associated characteristics of the identified subgroups, such as sociodemographic characteristics, diabetes-related comorbidities, and well-being., title -> Different information needs in subgroups of people with diabetes mellitus: a latent class analysis, pubdate -> 2020 Dec 10, distance -> 0.20076137, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# |{vector_similarity_rankings, 0, 44, Adiponectin and pro‐inflammatory cytokines are associated with type 2 diabetes mellitus, and might serve as a prognostic marker and a therapeutic intervention for overweight‐related type 2 diabetes mellitus., {fulljournalname -> Journal of Diabetes Investigation, document -> 3, uuid -> 5ea2f001-9b35-45f0-90ba-633d2a004a65, pieceId -> -1, score -> 0.73810669, target_text -> What are the effects of diabetes on the body?, code -> PMC5415486-5ea2f001-9b35-45f0-90ba-633d2a004a65, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Adiponectin and pro‐inflammatory cytokines are associated with type 2 diabetes mellitus, and might serve as a prognostic marker and a therapeutic intervention for overweight‐related type 2 diabetes mellitus., title -> Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus, pubdate -> 2016 Oct 30, distance -> 0.26189331, sentence -> 3}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# |{vector_similarity_rankings, 0, 44, Background: Diabetes is referred to a group of diseases characterized by high glucose levels in blood. It is caused by a deficiency in the production or function of insulin or both, which can occur because of different reasons, resulting in protein and lipid metabolic disorders. The aim of this study was to systematically review the prevalence and incidence of type 1 diabetes in the world., {fulljournalname -> Health Promotion Perspectives, document -> 0, uuid -> 53f2c7c8-6bdb-48dc-b59a-b505b4623df2, pieceId -> -1, score -> 0.72076187, target_text -> What are the effects of diabetes on the body?, code -> PMC7146037-53f2c7c8-6bdb-48dc-b59a-b505b4623df2, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Background: Diabetes is referred to a group of diseases characterized by high glucose levels in blood. It is caused by a deficiency in the production or function of insulin or both, which can occur because of different reasons, resulting in protein and lipid metabolic disorders. The aim of this study was to systematically review the prevalence and incidence of type 1 diabetes in the world., title -> Prevalence and incidence of type 1 diabetes in the world: a systematic review and meta-analysis, pubdate -> 2020 Mar 30, distance -> 0.27923813, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# |{vector_similarity_rankings, 0, 44, Excessive glucocorticoid secretion has been associated with type 2 diabetes mellitus (T2DM) and other features of the metabolic syndrome. We aimed to evaluate whether basal or evening salivary cortisol may predict the occurrence of incident insulin resistance (IR) or T2DM., {fulljournalname -> Endocrine Connections, document -> 0, uuid -> ca9bf9b6-9f94-401d-9134-5687b29a8662, pieceId -> -1, score -> 0.69687414, target_text -> What are the effects of diabetes on the body?, code -> PMC6599074-ca9bf9b6-9f94-401d-9134-5687b29a8662, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Excessive glucocorticoid secretion has been associated with type 2 diabetes mellitus (T2DM) and other features of the metabolic syndrome. We aimed to evaluate whether basal or evening salivary cortisol may predict the occurrence of incident insulin resistance (IR) or T2DM., title -> Salivary cortisol is not associated with incident insulin resistance or type 2 diabetes mellitus, pubdate -> 2019 Jun 6, distance -> 0.30312586, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# |{vector_similarity_rankings, 0, 44, Adipose tissue‐derived hormones are associated with metabolic disorders including type 2 diabetes mellitus. The present study investigated the levels of adiponectin and pro‐inflammatory cytokines including tumor necrosis factor‐α (TNF‐α), interleukin‐1 beta (IL‐1β) and IL‐10 in Vietnamese patients with type 2 diabetes mellitus, and their correlations with clinical parameters of overweight and type 2 diabetes mellitus., {fulljournalname -> Journal of Diabetes Investigation, document -> 0, uuid -> 6f8898ea-43c1-48f4-94e3-1b737b00aa6c, pieceId -> -1, score -> 0.69644116, target_text -> What are the effects of diabetes on the body?, code -> PMC5415486-6f8898ea-43c1-48f4-94e3-1b737b00aa6c, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Adipose tissue‐derived hormones are associated with metabolic disorders including type 2 diabetes mellitus. The present study investigated the levels of adiponectin and pro‐inflammatory cytokines including tumor necrosis factor‐α (TNF‐α), interleukin‐1 beta (IL‐1β) and IL‐10 in Vietnamese patients with type 2 diabetes mellitus, and their correlations with clinical parameters of overweight and type 2 diabetes mellitus., title -> Adiponectin and pro‐inflammatory cytokines are modulated in Vietnamese patients with type 2 diabetes mellitus, pubdate -> 2016 Oct 30, distance -> 0.30355884, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |{vector_similarity_rankings, 0, 44, These findings suggest a possible role for SERPINA3 in the development of the early stages of type 2 diabetes mellitus, although further replication studies and functional investigations regarding their role are required., {fulljournalname -> Journal of Diabetes Investigation, document -> 3, uuid -> 2bc3e8d1-3160-4c61-a442-3c52984cc69d, pieceId -> -1, score -> 0.68466444, target_text -> What are the effects of diabetes on the body?, code -> PMC5583949-2bc3e8d1-3160-4c61-a442-3c52984cc69d, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> These findings suggest a possible role for SERPINA3 in the development of the early stages of type 2 diabetes mellitus, although further replication studies and functional investigations regarding their role are required., title -> Proteomic analysis of serum biomarkers for prediabetes using the Long‐Evans Agouti rat, a spontaneous animal model of type 2 diabetes mellitus, pubdate -> 2017 Mar 27, distance -> 0.31533556, sentence -> 3}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# |{vector_similarity_rankings, 0, 44, Type 2 diabetes mellitus is a progressive disease that is characterized by the appearance of insulin resistance. The term insulin resistance is very wide and could affect different proteins involved in insulin signaling, as well as other mechanisms. In this review, we have analyzed the main molecular mechanisms that could be involved in the connection between type 2 diabetes and neurodegeneration, in general, and more specifically with the appearance of Alzheimer’s disease. We have studied, in more detail, the different processes involved, such as inflammation, endoplasmic reticulum stress, autophagy, and mitochondrial dysfunction., {fulljournalname -> Cells, document -> 0, uuid -> 13a2bd0c-5e85-4085-b8a9-e9215061323c, pieceId -> -1, score -> 0.65106501, target_text -> What are the effects of diabetes on the body?, code -> PMC8157600-13a2bd0c-5e85-4085-b8a9-e9215061323c, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Type 2 diabetes mellitus is a progressive disease that is characterized by the appearance of insulin resistance. The term insulin resistance is very wide and could affect different proteins involved in insulin signaling, as well as other mechanisms. In this review, we have analyzed the main molecular mechanisms that could be involved in the connection between type 2 diabetes and neurodegeneration, in general, and more specifically with the appearance of Alzheimer’s disease. We have studied, in more detail, the different processes involved, such as inflammation, endoplasmic reticulum stress, autophagy, and mitochondrial dysfunction., title -> Insulin Resistance and Diabetes Mellitus in Alzheimer’s Disease, pubdate -> 2021 May 18, distance -> 0.34893499, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# |{vector_similarity_rankings, 0, 44, MVD is associated with an excess HF risk in individuals with type 2 diabetes mellitus after adjusting for other known risk factors. Our findings underscore the contribution of MVD to the development of diabetes mellitus–related HF., {fulljournalname -> Journal of the American Heart Association: Cardiovascular and Cerebrovascular Disease, document -> 2, uuid -> 4e4ccec7-44c7-4aa7-995b-d32430803767, pieceId -> -1, score -> 0.64457040, target_text -> What are the effects of diabetes on the body?, code -> PMC8477890-4e4ccec7-44c7-4aa7-995b-d32430803767, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> MVD is associated with an excess HF risk in individuals with type 2 diabetes mellitus after adjusting for other known risk factors. Our findings underscore the contribution of MVD to the development of diabetes mellitus–related HF., title -> Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus, pubdate -> 2021 Jun 10, distance -> 0.35542960, sentence -> 2}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# |{vector_similarity_rankings, 0, 44, Gestational Diabetes Mellitus (GDM) is a transitory metabolic condition caused by dysregulation triggered by intolerance to carbohydrates, dysfunction of beta-pancreatic and endothelial cells, and insulin resistance during pregnancy. However, this disease includes not only changes related to metabolic distress but also placental immunoendocrine adaptations, resulting in harmful effects to the mother and fetus. In this review, we focus on the placenta as an immuno-endocrine organ that can recognize and respond to the hyperglycemic environment. It synthesizes diverse chemicals that play a role in inflammation, innate defense, endocrine response, oxidative stress, and angiogenesis, all associated with different perinatal outcomes., {fulljournalname -> International Journal of Molecular Sciences, document -> 0, uuid -> 916047ee-b184-4873-9372-d5ac15aaee96, pieceId -> -1, score -> 0.63952809, target_text -> What are the effects of diabetes on the body?, code -> PMC8348825-916047ee-b184-4873-9372-d5ac15aaee96, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Gestational Diabetes Mellitus (GDM) is a transitory metabolic condition caused by dysregulation triggered by intolerance to carbohydrates, dysfunction of beta-pancreatic and endothelial cells, and insulin resistance during pregnancy. However, this disease includes not only changes related to metabolic distress but also placental immunoendocrine adaptations, resulting in harmful effects to the mother and fetus. In this review, we focus on the placenta as an immuno-endocrine organ that can recognize and respond to the hyperglycemic environment. It synthesizes diverse chemicals that play a role in inflammation, innate defense, endocrine response, oxidative stress, and angiogenesis, all associated with different perinatal outcomes., title -> Immunoendocrine Dysregulation during Gestational Diabetes Mellitus: The Central Role of the Placenta, pubdate -> 2021 Jul 28, distance -> 0.36047191, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                          |
# |{vector_similarity_rankings, 0, 44, We provide novel information on the prevalence and clinical features of fulminant type 1 diabetes mellitus in Korea., {fulljournalname -> Journal of Diabetes Investigation, document -> 4, uuid -> b3b39bc4-9f02-400f-b1e5-8ae313765533, pieceId -> -1, score -> 0.63645101, target_text -> What are the effects of diabetes on the body?, code -> PMC8756324-b3b39bc4-9f02-400f-b1e5-8ae313765533, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> We provide novel information on the prevalence and clinical features of fulminant type 1 diabetes mellitus in Korea., title -> Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research, pubdate -> 2021 Aug 31, distance -> 0.36354899, sentence -> 4}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# |{vector_similarity_rankings, 0, 44, Immunotherapy is now a recognized treatment option for several types of cancer. However, some cancer patients treated with immune checkpoint inhibitors (ICIs) are subject to immune-related adverse events, including induced diabetes mellitus. The exact role and molecular/genetic action of ICIs in diabetes are still not well understood. Elucidating the underlying mechanisms in a proper fashion would allow better refining of biomarkers that would help diagnose patients at risk of altered immune system homeostasis, but would also hold the potential of new therapeutic options for diabetes. In the present narrative review, we propose to discuss the case of autoimmune diabetes following treatment with ICIs and the role of ICIs in the pathophysiology of diabetes. We also present some scarce available data on interesting potential immune therapies for diabetes., {fulljournalname -> International Journal of Molecular Sciences, document -> 0, uuid -> 814194af-7d54-4587-9939-e2dd25ae49d7, pieceId -> -1, score -> 0.62932451, target_text -> What are the effects of diabetes on the body?, code -> PMC7923776-814194af-7d54-4587-9939-e2dd25ae49d7, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Immunotherapy is now a recognized treatment option for several types of cancer. However, some cancer patients treated with immune checkpoint inhibitors (ICIs) are subject to immune-related adverse events, including induced diabetes mellitus. The exact role and molecular/genetic action of ICIs in diabetes are still not well understood. Elucidating the underlying mechanisms in a proper fashion would allow better refining of biomarkers that would help diagnose patients at risk of altered immune system homeostasis, but would also hold the potential of new therapeutic options for diabetes. In the present narrative review, we propose to discuss the case of autoimmune diabetes following treatment with ICIs and the role of ICIs in the pathophysiology of diabetes. We also present some scarce available data on interesting potential immune therapies for diabetes., title -> Immune Checkpoint Inhibitor-Induced Diabetes Mellitus: Potential Role of T Cells in the Underlying Mechanism, pubdate -> 2021 Feb 20, distance -> 0.37067549, sentence -> 0}, []}                                                                                                                                    |
# |{vector_similarity_rankings, 0, 44, Microvascular disease (MVD) is a potential contributor to the pathogenesis of diabetes mellitus–related cardiac dysfunction. However, there is a paucity of data on the link between MVD and incident heart failure (HF) in type 2 diabetes mellitus. We examined the association of MVD with incident HF in adults with type 2 diabetes mellitus., {fulljournalname -> Journal of the American Heart Association: Cardiovascular and Cerebrovascular Disease, document -> 0, uuid -> c21d0cee-ea14-42c6-9503-db792a2056a4, pieceId -> -1, score -> 0.62841475, target_text -> What are the effects of diabetes on the body?, code -> PMC8477890-c21d0cee-ea14-42c6-9503-db792a2056a4, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Microvascular disease (MVD) is a potential contributor to the pathogenesis of diabetes mellitus–related cardiac dysfunction. However, there is a paucity of data on the link between MVD and incident heart failure (HF) in type 2 diabetes mellitus. We examined the association of MVD with incident HF in adults with type 2 diabetes mellitus., title -> Microvascular Disease and Incident Heart Failure Among Individuals With Type 2 Diabetes Mellitus, pubdate -> 2021 Jun 10, distance -> 0.37158525, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# |{vector_similarity_rankings, 0, 44, Type 1 diabetes mellitus (T1DM) is associated with premature cardiovascular disease (CVD), but the underlying mechanisms remain poorly understood. The American Diabetes Association and the European Association for the Study of Diabetes recently updated their position statement on the management of type 2 diabetes mellitus (T2DM) to include additional focus on cardiovascular risk; improved management of risk factors in T1DM is also needed. There are important differences in the pathophysiology of CVD in T1DM and T2DM. Hyperglycaemia appears to have a more profound effect on cardiovascular risk in T1DM than T2DM, and other risk factors appear to cause a synergistic rather than additive effect, so achievement of treatment targets for all recognized risk factors is crucial to reducing cardiovascular risk. Here we discuss the evidence for addressing established cardiovascular risk factors, candidate biomarkers and surrogate measurements, and possible interventions., {fulljournalname -> Diabetes Therapy, document -> 0, uuid -> 6e0c9411-b3a6-402d-852c-23c835d82313, pieceId -> -1, score -> 0.61824764, target_text -> What are the effects of diabetes on the body?, code -> PMC6531592-6e0c9411-b3a6-402d-852c-23c835d82313, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Type 1 diabetes mellitus (T1DM) is associated with premature cardiovascular disease (CVD), but the underlying mechanisms remain poorly understood. The American Diabetes Association and the European Association for the Study of Diabetes recently updated their position statement on the management of type 2 diabetes mellitus (T2DM) to include additional focus on cardiovascular risk; improved management of risk factors in T1DM is also needed. There are important differences in the pathophysiology of CVD in T1DM and T2DM. Hyperglycaemia appears to have a more profound effect on cardiovascular risk in T1DM than T2DM, and other risk factors appear to cause a synergistic rather than additive effect, so achievement of treatment targets for all recognized risk factors is crucial to reducing cardiovascular risk. Here we discuss the evidence for addressing established cardiovascular risk factors, candidate biomarkers and surrogate measurements, and possible interventions., title -> Cardiovascular Risk in Type 1 Diabetes Mellitus, pubdate -> 2019 Apr 19, distance -> 0.38175236, sentence -> 0}, []}|
# |{vector_similarity_rankings, 0, 44, Smoking is a strong risk factor for albuminuria in people with type 2 diabetes mellitus (T2DM). However, it is unclear whether this sequela of smoking is brought about by its action on cardiometabolic parameters or the relationship is independent. The aim of this systematic review is to explore this relationship., {fulljournalname -> Acta Diabetologica, document -> 0, uuid -> 5ddb9db3-53a5-4b5a-8ef1-c630d60ce1f4, pieceId -> -1, score -> 0.61680575, target_text -> What are the effects of diabetes on the body?, code -> PMC6597612-5ddb9db3-53a5-4b5a-8ef1-c630d60ce1f4, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Smoking is a strong risk factor for albuminuria in people with type 2 diabetes mellitus (T2DM). However, it is unclear whether this sequela of smoking is brought about by its action on cardiometabolic parameters or the relationship is independent. The aim of this systematic review is to explore this relationship., title -> Association of smoking and cardiometabolic parameters with albuminuria in people with type 2 diabetes mellitus: a systematic review and meta-analysis, pubdate -> 2019 Feb 24, distance -> 0.38319425, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |{vector_similarity_rankings, 0, 44, Determining risk factors for diabetes insipidus (DI) after pituitary surgery is important in improving patient care. Our objective is to determine the factors associated with DI after pituitary surgery., {fulljournalname -> Endocrinology and Metabolism, document -> 0, uuid -> 428e1ecb-36e0-4657-9c25-3a12e6210cd2, pieceId -> -1, score -> 0.61419606, target_text -> What are the effects of diabetes on the body?, code -> PMC5744728-428e1ecb-36e0-4657-9c25-3a12e6210cd2, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Determining risk factors for diabetes insipidus (DI) after pituitary surgery is important in improving patient care. Our objective is to determine the factors associated with DI after pituitary surgery., title -> Factors Associated with Postoperative Diabetes Insipidus after Pituitary Surgery, pubdate -> 2017 Nov 21, distance -> 0.38580394, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# |{vector_similarity_rankings, 0, 44, This study aimed to determine whether diabetes mellitus and high body mass index are risk factors for COVID-19 in pregnancy and whether gestational diabetes mellitus is associated with COVID-19 diagnosis., {fulljournalname -> American Journal of Obstetrics and Gynecology, document -> 1, uuid -> 02028a97-c4c4-46f9-b88a-bb476f60205c, pieceId -> -1, score -> 0.61013022, target_text -> What are the effects of diabetes on the body?, code -> PMC8686449-02028a97-c4c4-46f9-b88a-bb476f60205c, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> This study aimed to determine whether diabetes mellitus and high body mass index are risk factors for COVID-19 in pregnancy and whether gestational diabetes mellitus is associated with COVID-19 diagnosis., title -> Diabetes mellitus, maternal adiposity, and insulin-dependent gestational diabetes are associated with COVID-19 in pregnancy: the INTERCOVID study, pubdate -> 2021 Dec 20, distance -> 0.38986978, sentence -> 1}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# |{vector_similarity_rankings, 0, 44, Genetic variance of AVPR1B contributes to overweight. Furthermore, our data indicate a link between AVPR1B variance and DM development. Our data point at a relationship between the disturbance of the pharmacologically modifiable AVP system and the body weight regulation., {fulljournalname -> European Journal of Endocrinology, document -> 4, uuid -> 9bba9908-aba8-4e0e-a936-267a7c021c26, pieceId -> -1, score -> 0.60795502, target_text -> What are the effects of diabetes on the body?, code -> PMC4653349-9bba9908-aba8-4e0e-a936-267a7c021c26, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Genetic variance of AVPR1B contributes to overweight. Furthermore, our data indicate a link between AVPR1B variance and DM development. Our data point at a relationship between the disturbance of the pharmacologically modifiable AVP system and the body weight regulation., title -> Genetic vasopressin 1b receptor variance in overweight and diabetes mellitus, pubdate -> 2016 Jan, distance -> 0.39204498, sentence -> 4}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |{vector_similarity_rankings, 0, 44, We aimed to determine the hospital‐based prevalence and clinical features of fulminant type 1 diabetes mellitus in Korea., {fulljournalname -> Journal of Diabetes Investigation, document -> 0, uuid -> 43adc9b2-d974-4b18-b732-ca8afa133082, pieceId -> -1, score -> 0.60589224, target_text -> What are the effects of diabetes on the body?, code -> PMC8756324-43adc9b2-d974-4b18-b732-ca8afa133082, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> We aimed to determine the hospital‐based prevalence and clinical features of fulminant type 1 diabetes mellitus in Korea., title -> Prevalence and clinical characteristics of fulminant type 1 diabetes mellitus in Korean adults: A multi‐institutional joint research, pubdate -> 2021 Aug 31, distance -> 0.39410776, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |{vector_similarity_rankings, 0, 44, The present meta‐analysis was carried out to assess the association between exposure to the level of atmospheric particulate matter 2.5 (PM2.5; fine particulate matter with aerodynamic diameter less than 2.5 μm) and type 2 diabetes mellitus or gestational diabetes mellitus (GDM)., {fulljournalname -> Journal of Diabetes Investigation, document -> 0, uuid -> f7588513-39c0-4f9b-b3c0-46bfb1c315aa, pieceId -> -1, score -> 0.60588633, target_text -> What are the effects of diabetes on the body?, code -> PMC5583950-f7588513-39c0-4f9b-b3c0-46bfb1c315aa, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> The present meta‐analysis was carried out to assess the association between exposure to the level of atmospheric particulate matter 2.5 (PM2.5; fine particulate matter with aerodynamic diameter less than 2.5 μm) and type 2 diabetes mellitus or gestational diabetes mellitus (GDM)., title -> Association between particulate matter 2.5 and diabetes mellitus: A meta‐analysis of cohort studies, pubdate -> 2017 May 3, distance -> 0.39411367, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# |{vector_similarity_rankings, 0, 44, Wolfram syndrome (WS) is an autosomal recessive neurodegenerative disorder characterized by diabetes mellitus (DM), optic atrophy (OA), central diabetes insipidus (CDI) and deafness (D)., {fulljournalname -> Italian Journal of Pediatrics, document -> 0, uuid -> 85caa88d-4cd2-4cc4-9e8a-3684aa145608, pieceId -> -1, score -> 0.60134703, target_text -> What are the effects of diabetes on the body?, code -> PMC4422421-85caa88d-4cd2-4cc4-9e8a-3684aa145608, isWordStart -> true, token -> What are the effects of diabetes on the body?, resolved_text -> Wolfram syndrome (WS) is an autosomal recessive neurodegenerative disorder characterized by diabetes mellitus (DM), optic atrophy (OA), central diabetes insipidus (CDI) and deafness (D)., title -> Congenital central diabetes insipidus and optic atrophy in a Wolfram newborn: is there a role for WFS1 gene in neurodevelopment?, pubdate -> 2014 Sep 26, distance -> 0.39865297, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
context_split_assembler.transform(
    post_processor.transform(
        vector_df
    )
  ).selectExpr("explode(document) as document").show(truncate=False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |document                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |{document, 0, 7518, Current evidence suggests that the information needs of people with diabetes mellitus differ across patient groups. With a view to being able to provide individualized information, this study aims to identify (i) the diabetes-related information needs of people with diabetes mellitus; (ii) different subgroups of people with specific information needs; and (iii) associated characteristics of the identified subgroups, such as sociodemographic characteristics, diabetes-related comorbidities, and well-being.\nAdiponectin and pro‐inflammatory cytokines are associated with type 2 diabetes mellitus, and might serve as a prognostic marker and a therapeutic intervention for overweight‐related type 2 diabetes mellitus.\nBackground: Diabetes is referred to a group of diseases characterized by high glucose levels in blood. It is caused by a deficiency in the production or function of insulin or both, which can occur because of different reasons, resulting in protein and lipid metabolic disorders. The aim of this study was to systematically review the prevalence and incidence of type 1 diabetes in the world.\nExcessive glucocorticoid secretion has been associated with type 2 diabetes mellitus (T2DM) and other features of the metabolic syndrome. We aimed to evaluate whether basal or evening salivary cortisol may predict the occurrence of incident insulin resistance (IR) or T2DM.\nAdipose tissue‐derived hormones are associated with metabolic disorders including type 2 diabetes mellitus. The present study investigated the levels of adiponectin and pro‐inflammatory cytokines including tumor necrosis factor‐α (TNF‐α), interleukin‐1 beta (IL‐1β) and IL‐10 in Vietnamese patients with type 2 diabetes mellitus, and their correlations with clinical parameters of overweight and type 2 diabetes mellitus.\nThese findings suggest a possible role for SERPINA3 in the development of the early stages of type 2 diabetes mellitus, although further replication studies and functional investigations regarding their role are required.\nType 2 diabetes mellitus is a progressive disease that is characterized by the appearance of insulin resistance. The term insulin resistance is very wide and could affect different proteins involved in insulin signaling, as well as other mechanisms. In this review, we have analyzed the main molecular mechanisms that could be involved in the connection between type 2 diabetes and neurodegeneration, in general, and more specifically with the appearance of Alzheimer’s disease. We have studied, in more detail, the different processes involved, such as inflammation, endoplasmic reticulum stress, autophagy, and mitochondrial dysfunction.\nMVD is associated with an excess HF risk in individuals with type 2 diabetes mellitus after adjusting for other known risk factors. Our findings underscore the contribution of MVD to the development of diabetes mellitus–related HF.\nGestational Diabetes Mellitus (GDM) is a transitory metabolic condition caused by dysregulation triggered by intolerance to carbohydrates, dysfunction of beta-pancreatic and endothelial cells, and insulin resistance during pregnancy. However, this disease includes not only changes related to metabolic distress but also placental immunoendocrine adaptations, resulting in harmful effects to the mother and fetus. In this review, we focus on the placenta as an immuno-endocrine organ that can recognize and respond to the hyperglycemic environment. It synthesizes diverse chemicals that play a role in inflammation, innate defense, endocrine response, oxidative stress, and angiogenesis, all associated with different perinatal outcomes.\nWe provide novel information on the prevalence and clinical features of fulminant type 1 diabetes mellitus in Korea.\nImmunotherapy is now a recognized treatment option for several types of cancer. However, some cancer patients treated with immune checkpoint inhibitors (ICIs) are subject to immune-related adverse events, includin ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...

# %%
doc = Annotation.fromRow(
    context_split_assembler.transform(
        post_processor.transform(vector_df)
    ).selectExpr("document").collect()[0]["document"][0]
  )

# %%
print(doc.result)
# Out:
# Current evidence suggests that the information needs of people with diabetes mellitus differ across patient groups. With a view to being able to provide individualized information, this study aims to identify (i) the diabetes-related information needs of people with diabetes mellitus; (ii) different subgroups of people with specific information needs; and (iii) associated characteristics of the identified subgroups, such as sociodemographic characteristics, diabetes-related comorbidities, and well-being.
# Adiponectin and pro‐inflammatory cytokines are associated with type 2 diabetes mellitus, and might serve as a prognostic marker and a therapeutic intervention for overweight‐related type 2 diabetes mellitus.
# Background: Diabetes is referred to a group of diseases characterized by high glucose levels in blood. It is caused by a deficiency in the production or function of insulin or both, which can occur because of different reasons, resulting in protein and lipid metabolic disorders. The aim of this study was to systematically review the prevalence and incidence of type 1 diabetes in the world.
# Excessive glucocorticoid secretion has been associated with type 2 diabetes mellitus (T2DM) and other features of the metabolic syndrome. We aimed to evaluate whether basal or evening salivary cortisol may predict the occurrence of incident insulin resistance (IR) or T2DM.
# Adipose tissue‐derived hormones are associated with metabolic disorders including type 2 diabetes mellitus. The present study investigated the levels of adiponectin and pro‐inflammatory cytokines including tumor necrosis factor‐α (TNF‐α), interleukin‐1 beta (IL‐1β) and IL‐10 in Vietnamese patients with type 2 diabetes mellitus, and their correlations with clinical parameters of overweight and type 2 diabetes mellitus.
# These findings suggest a possible role for SERPINA3 in the development of the early stages of type 2 diabetes mellitus, although further replication studies and functional investigations regarding their role are required.
# Type 2 diabetes mellitus is a progressive disease that is characterized by the appearance of insulin resistance. The term insulin resistance is very wide and could affect different proteins involved in insulin signaling, as well as other mechanisms. In this review, we have analyzed the main molecular mechanisms that could be involved in the connection between type 2 diabetes and neurodegeneration, in general, and more specifically with the appearance of Alzheimer’s disease. We have studied, in more detail, the different processes involved, such as inflammation, endoplasmic reticulum stress, autophagy, and mitochondrial dysfunction.
# MVD is associated with an excess HF risk in individuals with type 2 diabetes mellitus after adjusting for other known risk factors. Our findings underscore the contribution of MVD to the development of diabetes mellitus–related HF.
# Gestational Diabetes Mellitus (GDM) is a transitory metabolic condition caused by dysregulation triggered by intolerance to carbohydrates, dysfunction of beta-pancreatic and endothelial cells, and insulin resistance during pregnancy. However, this disease includes not only changes related to metabolic distress but also placental immunoendocrine adaptations, resulting in harmful effects to the mother and fetus. In this review, we focus on the placenta as an immuno-endocrine organ that can recognize and respond to the hyperglycemic environment. It synthesizes diverse chemicals that play a role in inflammation, innate defense, endocrine response, oxidative stress, and angiogenesis, all associated with different perinatal outcomes.
# We provide novel information on the prevalence and clinical features of fulminant type 1 diabetes mellitus in Korea.
# Immunotherapy is now a recognized treatment option for several types of cancer. However, some cancer patients treated with immune checkpoint inhibitors (ICIs) are subject to immune-related adverse events, including induced diabetes mellitus. The exact role and molecular/genetic action of ICIs in diabetes are still not well understood. Elucidating the underlying mechanisms in a proper fashion would allow better refining of biomarkers that would help diagnose patients at risk of altered immune system homeostasis, but would also hold the potential of new therapeutic options for diabetes. In the present narrative review, we propose to discuss the case of autoimmune diabetes following treatment with ICIs and the role of ICIs in the pathophysiology of diabetes. We also present some scarce available data on interesting potential immune therapies for diabetes.
# Microvascular disease (MVD) is a potential contributor to the pathogenesis of diabetes mellitus–related cardiac dysfunction. However, there is a paucity of data on the link between MVD and incident heart failure (HF) in type 2 diabetes mellitus. We examined the association of MVD with incident HF in adults with type 2 diabetes mellitus.
# Type 1 diabetes mellitus (T1DM) is associated with premature cardiovascular disease (CVD), but the underlying mechanisms remain poorly understood. The American Diabetes Association and the European Association for the Study of Diabetes recently updated their position statement on the management of type 2 diabetes mellitus (T2DM) to include additional focus on cardiovascular risk; improved management of risk factors in T1DM is also needed. There are important differences in the pathophysiology of CVD in T1DM and T2DM. Hyperglycaemia appears to have a more profound effect on cardiovascular risk in T1DM than T2DM, and other risk factors appear to cause a synergistic rather than additive effect, so achievement of treatment targets for all recognized risk factors is crucial to reducing cardiovascular risk. Here we discuss the evidence for addressing established cardiovascular risk factors, candidate biomarkers and surrogate measurements, and possible interventions.
# Smoking is a strong risk factor for albuminuria in people with type 2 diabetes mellitus (T2DM). However, it is unclear whether this sequela of smoking is brought about by its action on cardiometabolic parameters or the relationship is independent. The aim of this systematic review is to explore this relationship.
# Determining risk factors for diabetes insipidus (DI) after pituitary surgery is important in improving patient care. Our objective is to determine the factors associated with DI after pituitary surgery.
# This study aimed to determine whether diabetes mellitus and high body mass index are risk factors for COVID-19 in pregnancy and whether gestational diabetes mellitus is associated with COVID-19 diagnosis.
# Genetic variance of AVPR1B contributes to overweight. Furthermore, our data indicate a link between AVPR1B variance and DM development. Our data point at a relationship between the disturbance of the pharmacologically modifiable AVP system and the body weight regulation.
# We aimed to determine the hospital‐based prevalence and clinical features of fulminant type 1 diabetes mellitus in Korea.
# The present meta‐analysis was carried out to assess the association between exposure to the level of atmospheric particulate matter 2.5 (PM2.5; fine particulate matter with aerodynamic diameter less than 2.5 μm) and type 2 diabetes mellitus or gestational diabetes mellitus (GDM).
# Wolfram syndrome (WS) is an autosomal recessive neurodegenerative disorder characterized by diabetes mellitus (DM), optic atrophy (OA), central diabetes insipidus (CDI) and deafness (D).

# %% [markdown]
# !!!!!  Lost metadata values

# %%
print(doc.end)
print(doc.annotatorType)
print(doc.metadata)
# Out:
# 7518
# document
# {'sentence': '0', 'document': '0'}

# %% [markdown]
# ## check setExplodeSplits(True)

# %%
context_split_assembler.setExplodeSplits(True).transform(
    post_processor.transform(
        vector_df
    )
  ).selectExpr("explode(document) as document").show(truncate=False)
# Out:
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |document                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{document, 0, 508, Current evidence suggests that the information needs of people with diabetes mellitus differ across patient groups. With a view to being able to provide individualized information, this study aims to identify (i) the diabetes-related information needs of people with diabetes mellitus; (ii) different subgroups of people with specific information needs; and (iii) associated characteristics of the identified subgroups, such as sociodemographic characteristics, diabetes-related comorbidities, and well-being., {document -> 0, sentence -> 0}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |{document, 509, 715, Adiponectin and pro‐inflammatory cytokines are associated with type 2 diabetes mellitus, and might serve as a prognostic marker and a therapeutic intervention for overweight‐related type 2 diabetes mellitus., {document -> 1, sentence -> 1}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |{document, 716, 1107, Background: Diabetes is referred to a group of diseases characterized by high glucose levels in blood. It is caused by a deficiency in the production or function of insulin or both, which can occur because of different reasons, resulting in protein and lipid metabolic disorders. The aim of this study was to systematically review the prevalence and incidence of type 1 diabetes in the world., {document -> 2, sentence -> 2}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# |{document, 1108, 1380, Excessive glucocorticoid secretion has been associated with type 2 diabetes mellitus (T2DM) and other features of the metabolic syndrome. We aimed to evaluate whether basal or evening salivary cortisol may predict the occurrence of incident insulin resistance (IR) or T2DM., {document -> 3, sentence -> 3}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# |{document, 1381, 1801, Adipose tissue‐derived hormones are associated with metabolic disorders including type 2 diabetes mellitus. The present study investigated the levels of adiponectin and pro‐inflammatory cytokines including tumor necrosis factor‐α (TNF‐α), interleukin‐1 beta (IL‐1β) and IL‐10 in Vietnamese patients with type 2 diabetes mellitus, and their correlations with clinical parameters of overweight and type 2 diabetes mellitus., {document -> 4, sentence -> 4}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# |{document, 1802, 2022, These findings suggest a possible role for SERPINA3 in the development of the early stages of type 2 diabetes mellitus, although further replication studies and functional investigations regarding their role are required., {document -> 5, sentence -> 5}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |{document, 2023, 2661, Type 2 diabetes mellitus is a progressive disease that is characterized by the appearance of insulin resistance. The term insulin resistance is very wide and could affect different proteins involved in insulin signaling, as well as other mechanisms. In this review, we have analyzed the main molecular mechanisms that could be involved in the connection between type 2 diabetes and neurodegeneration, in general, and more specifically with the appearance of Alzheimer’s disease. We have studied, in more detail, the different processes involved, such as inflammation, endoplasmic reticulum stress, autophagy, and mitochondrial dysfunction., {document -> 6, sentence -> 6}, []}                                                                                                                                                                                                                                                                                                                                                 |
# |{document, 2662, 2892, MVD is associated with an excess HF risk in individuals with type 2 diabetes mellitus after adjusting for other known risk factors. Our findings underscore the contribution of MVD to the development of diabetes mellitus–related HF., {document -> 7, sentence -> 7}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# |{document, 2893, 3629, Gestational Diabetes Mellitus (GDM) is a transitory metabolic condition caused by dysregulation triggered by intolerance to carbohydrates, dysfunction of beta-pancreatic and endothelial cells, and insulin resistance during pregnancy. However, this disease includes not only changes related to metabolic distress but also placental immunoendocrine adaptations, resulting in harmful effects to the mother and fetus. In this review, we focus on the placenta as an immuno-endocrine organ that can recognize and respond to the hyperglycemic environment. It synthesizes diverse chemicals that play a role in inflammation, innate defense, endocrine response, oxidative stress, and angiogenesis, all associated with different perinatal outcomes., {document -> 8, sentence -> 8}, []}                                                                                                                                                                                                                                               |
# |{document, 3630, 3745, We provide novel information on the prevalence and clinical features of fulminant type 1 diabetes mellitus in Korea., {document -> 9, sentence -> 9}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |{document, 3746, 4609, Immunotherapy is now a recognized treatment option for several types of cancer. However, some cancer patients treated with immune checkpoint inhibitors (ICIs) are subject to immune-related adverse events, including induced diabetes mellitus. The exact role and molecular/genetic action of ICIs in diabetes are still not well understood. Elucidating the underlying mechanisms in a proper fashion would allow better refining of biomarkers that would help diagnose patients at risk of altered immune system homeostasis, but would also hold the potential of new therapeutic options for diabetes. In the present narrative review, we propose to discuss the case of autoimmune diabetes following treatment with ICIs and the role of ICIs in the pathophysiology of diabetes. We also present some scarce available data on interesting potential immune therapies for diabetes., {document -> 10, sentence -> 10}, []}                                                                                                              |
# |{document, 4610, 4947, Microvascular disease (MVD) is a potential contributor to the pathogenesis of diabetes mellitus–related cardiac dysfunction. However, there is a paucity of data on the link between MVD and incident heart failure (HF) in type 2 diabetes mellitus. We examined the association of MVD with incident HF in adults with type 2 diabetes mellitus., {document -> 11, sentence -> 11}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |{document, 4948, 5921, Type 1 diabetes mellitus (T1DM) is associated with premature cardiovascular disease (CVD), but the underlying mechanisms remain poorly understood. The American Diabetes Association and the European Association for the Study of Diabetes recently updated their position statement on the management of type 2 diabetes mellitus (T2DM) to include additional focus on cardiovascular risk; improved management of risk factors in T1DM is also needed. There are important differences in the pathophysiology of CVD in T1DM and T2DM. Hyperglycaemia appears to have a more profound effect on cardiovascular risk in T1DM than T2DM, and other risk factors appear to cause a synergistic rather than additive effect, so achievement of treatment targets for all recognized risk factors is crucial to reducing cardiovascular risk. Here we discuss the evidence for addressing established cardiovascular risk factors, candidate biomarkers and surrogate measurements, and possible interventions., {document -> 12, sentence -> 12}, []}|
# |{document, 5922, 6235, Smoking is a strong risk factor for albuminuria in people with type 2 diabetes mellitus (T2DM). However, it is unclear whether this sequela of smoking is brought about by its action on cardiometabolic parameters or the relationship is independent. The aim of this systematic review is to explore this relationship., {document -> 13, sentence -> 13}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |{document, 6236, 6437, Determining risk factors for diabetes insipidus (DI) after pituitary surgery is important in improving patient care. Our objective is to determine the factors associated with DI after pituitary surgery., {document -> 14, sentence -> 14}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |{document, 6438, 6641, This study aimed to determine whether diabetes mellitus and high body mass index are risk factors for COVID-19 in pregnancy and whether gestational diabetes mellitus is associated with COVID-19 diagnosis., {document -> 15, sentence -> 15}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# |{document, 6642, 6912, Genetic variance of AVPR1B contributes to overweight. Furthermore, our data indicate a link between AVPR1B variance and DM development. Our data point at a relationship between the disturbance of the pharmacologically modifiable AVP system and the body weight regulation., {document -> 16, sentence -> 16}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# |{document, 6913, 7033, We aimed to determine the hospital‐based prevalence and clinical features of fulminant type 1 diabetes mellitus in Korea., {document -> 17, sentence -> 17}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# |{document, 7034, 7313, The present meta‐analysis was carried out to assess the association between exposure to the level of atmospheric particulate matter 2.5 (PM2.5; fine particulate matter with aerodynamic diameter less than 2.5 μm) and type 2 diabetes mellitus or gestational diabetes mellitus (GDM)., {document -> 18, sentence -> 18}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# |{document, 7314, 7499, Wolfram syndrome (WS) is an autosomal recessive neurodegenerative disorder characterized by diabetes mellitus (DM), optic atrophy (OA), central diabetes insipidus (CDI) and deafness (D)., {document -> 19, sentence -> 19}, []}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
collected = context_split_assembler.setExplodeSplits(True).transform(
    post_processor.transform(
        vector_df
    )
  ).selectExpr("document").collect()[0]["document"]

for row in collected:
  anno = Annotation.fromRow(row)
  print(f"Begin: {anno.begin}, End: {anno.end}, metadata: {anno.metadata}")
# Out:
# Begin: 0, End: 508, metadata: {'sentence': '0', 'document': '0'}
# Begin: 509, End: 715, metadata: {'sentence': '1', 'document': '1'}
# Begin: 716, End: 1107, metadata: {'sentence': '2', 'document': '2'}
# Begin: 1108, End: 1380, metadata: {'sentence': '3', 'document': '3'}
# Begin: 1381, End: 1801, metadata: {'sentence': '4', 'document': '4'}
# Begin: 1802, End: 2022, metadata: {'sentence': '5', 'document': '5'}
# Begin: 2023, End: 2661, metadata: {'sentence': '6', 'document': '6'}
# Begin: 2662, End: 2892, metadata: {'sentence': '7', 'document': '7'}
# Begin: 2893, End: 3629, metadata: {'sentence': '8', 'document': '8'}
# Begin: 3630, End: 3745, metadata: {'sentence': '9', 'document': '9'}
# Begin: 3746, End: 4609, metadata: {'sentence': '10', 'document': '10'}
# Begin: 4610, End: 4947, metadata: {'sentence': '11', 'document': '11'}
# Begin: 4948, End: 5921, metadata: {'sentence': '12', 'document': '12'}
# Begin: 5922, End: 6235, metadata: {'sentence': '13', 'document': '13'}
# Begin: 6236, End: 6437, metadata: {'sentence': '14', 'document': '14'}
# Begin: 6438, End: 6641, metadata: {'sentence': '15', 'document': '15'}
# Begin: 6642, End: 6912, metadata: {'sentence': '16', 'document': '16'}
# Begin: 6913, End: 7033, metadata: {'sentence': '17', 'document': '17'}
# Begin: 7034, End: 7313, metadata: {'sentence': '18', 'document': '18'}
# Begin: 7314, End: 7499, metadata: {'sentence': '19', 'document': '19'}
