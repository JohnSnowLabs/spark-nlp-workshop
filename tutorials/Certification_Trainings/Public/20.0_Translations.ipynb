# %% [markdown]
# ![JohnSnowLabs](https://sparknlp.org/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/spark-nlp-workshop/blob/master/tutorials/Certification_Trainings/Public/20.0_Translations.ipynb)

# %% [markdown]
# # **Multilingual Translation**

# %% [markdown]
# This notebook will cover the different parameters and usages of `Translator Annotators`.
#
# **📖 Learning Objectives:**
#
# 1. Background: Understand the `Translator` such as `MarianTransformer` and M2M100Transformer .
#
# 2. Colab setup.
#
# 3. Become comfortable with using the different parameters of the annotator.
#
# **🔗 Helpful Links:**
#
# - For Translation models: : [Model Hub](https://sparknlp.org/models?tag=translation)
# - For extended examples of usage, see [Spark NLP Workshop repository](https://github.com/JohnSnowLabs/spark-nlp-workshop/tree/master).

# %% [markdown]
# ## **🎬 Colab Setup**

# %%
# Installing pyspark and spark-nlp
# !wget -q http://setup.johnsnowlabs.com/colab.sh -O - | bash

# %%
import sparknlp
from sparknlp.base import *
from sparknlp.annotator import *

from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.ml import Pipeline,PipelineModel

import pandas as pd

import warnings
warnings.filterwarnings('ignore')

params = {"spark.driver.memory":"16G",
          "spark.kryoserializer.buffer.max":"2000M",
          "spark.driver.maxResultSize":"2000M"}

spark = sparknlp.start(params=params)

print("Spark NLP Version :", sparknlp.version())

spark
# Out:
# Spark NLP Version : 5.3.3
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://4a70bac72f69:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark NLP</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# # MarianTransformer

# %% [markdown]
# ## **📜 Background**
#
# MarianTransformer: Fast Neural Machine Translation
#
# MarianTransformer: Fast Neural Machine Translation
#
# Marian is an efficient, free Neural Machine Translation framework written in pure C++ with minimal dependencies. It is mainly being developed by the Microsoft Translator team. Many academic (most notably the University of Edinburgh and in the past the Adam Mickiewicz University in Poznań) and commercial contributors help with its development. MarianTransformer uses the models trained by MarianNMT.
#
# It is currently the engine behind the Microsoft Translator Neural Machine Translation services and being deployed by many companies, organizations and research projects.
#
# Note that this model only supports inputs up to 512 tokens. If you are working with longer inputs, consider splitting them first. For example, you can use the SentenceDetectorDL annotator to split longer texts into sentences.
#
#
# The default model is `"opus_mt_en_fr"`, default language is `"xx"` (meaning multi-lingual), if no values are provided.
# For available pretrained models please see the [Models Hub](https://nlp.johnsnowlabs.com/models?annotator=MarianTransformer).
#
#
# **🔗 Helpful Links:**
#
# - Python API: [MarianTransformer](https://sparknlp.org/api/python/reference/autosummary/sparknlp/annotator/seq2seq/marian_transformer/index.html#sparknlp.annotator.seq2seq.marian_transformer.MarianTransformer)
# - Scala API: [MarianTransformer](https://sparknlp.org/api/com/johnsnowlabs/nlp/annotators/seq2seq/MarianTransformer)
# - Source: [MarianTransformer](https://github.com/JohnSnowLabs/spark-nlp/tree/master/src/main/scala/com/johnsnowlabs/nlp/annotators/seq2seq/MarianTransformer.scala)
# - [MarianNMT at GitHub](https://marian-nmt.github.io/)
# - [Marian: Fast Neural Machine Translation in C++ ](https://www.aclweb.org/anthology/P18-4020/)

# %% [markdown]
# ## **🖨️ Input/Output Annotation Types**
#
# - Input: `DOCUMENT`
#
# - Output: `DOCUMENT`

# %% [markdown]
# ## **🔎 Parameters**
#
# `maxInputLength`: Controls the maximum length for encoder inputs (source language texts), by default 40
#
# `maxOutputLength`: Controls the maximum length for decoder outputs (target language texts), by default 40

# %% [markdown]
# **Model List**:

# %% [markdown]
# |index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|index|model|lang|
# |-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|-----:|:-----|----|
# | 1| [opus_mt_aav_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_aav_en_xx.html)  |aav => en| 28| [opus_mt_ase_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ase_de_xx.html)  |ase => de| 55| [opus_mt_bg_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bg_es_xx.html)  |bg => es| 82| [opus_mt_cau_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_cau_en_xx.html)  |cau => en| 109| [opus_mt_cs_uk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_cs_uk_xx.html)  |cs => uk| 136| [opus_mt_de_el](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_el_xx.html)  |de => el| 163| [opus_mt_de_lt](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_lt_xx.html)  |de => lt| 190| [opus_mt_efi_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_efi_fr_xx.html)  |efi => fr| 217| [opus_mt_en_crs](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_crs_xx.html)  |en => crs| 244| [opus_mt_en_guw](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_guw_xx.html)  |en => guw| 271| [opus_mt_en_ln](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_ln_xx.html)  |en => ln| 298| [opus_mt_en_pag](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_pag_xx.html)  |en => pag| 325| [opus_mt_en_sw](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_en_sw_xx.html)  |en => sw| 352| [opus_mt_eo_af](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_eo_af_xx.html)  |eo => af| 379| [opus_mt_es_bi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_bi_xx.html)  |es => bi| 406| [opus_mt_es_hil](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_hil_xx.html)  |es => hil| 433| [opus_mt_es_pl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_pl_xx.html)  |es => pl| 460| [opus_mt_es_wls](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_wls_xx.html)  |es => wls| 487| [opus_mt_fi_efi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_efi_xx.html)  |fi => efi| 514| [opus_mt_fi_kqn](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_kqn_xx.html)  |fi => kqn| 541| [opus_mt_fi_sg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_sg_xx.html)  |fi => sg| 568| [opus_mt_fi_yap](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_yap_xx.html)  |fi => yap| 595| [opus_mt_fr_gaa](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_gaa_xx.html)  |fr => gaa| 622| [opus_mt_fr_ms](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_ms_xx.html)  |fr => ms| 649| [opus_mt_fr_tll](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_tll_xx.html)  |fr => tll| 676| [opus_mt_gem_gem](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_gem_gem_xx.html)  |gem => gem| 703| [opus_mt_he_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_he_de_xx.html)  |he => de| 730| [opus_mt_hu_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_hu_fr_xx.html)  |hu => fr| 757| [opus_mt_is_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_is_de_xx.html)  |is => de| 784| [opus_mt_itc_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_itc_en_xx.html)  |itc => en| 811| [opus_mt_kg_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_kg_es_xx.html)  |kg => es| 838| [opus_mt_ln_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ln_en_xx.html)  |ln => en| 865| [opus_mt_lua_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lua_sv_xx.html)  |lua => sv| 892| [opus_mt_mk_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_mk_en_xx.html)  |mk => en| 919| [opus_mt_nl_ca](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_nl_ca_xx.html)  |nl => ca| 946| [opus_mt_ny_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ny_en_xx.html)  |ny => en| 973| [opus_mt_pl_lt](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pl_lt_xx.html)  |pl => lt| 1000| [opus_mt_ro_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ro_sv_xx.html)  |ro => sv| 1027| [opus_mt_rw_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_rw_fr_xx.html)  |rw => fr| 1054| [opus_mt_sm_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sm_fr_xx.html)  |sm => fr| 1081| [opus_mt_sv_chk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_chk_xx.html)  |sv => chk| 1108| [opus_mt_sv_iso](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_iso_xx.html)  |sv => iso| 1135| [opus_mt_sv_run](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_run_xx.html)  |sv => run| 1162| [opus_mt_sv_war](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_war_xx.html)  |sv => war| 1189| [opus_mt_tn_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tn_en_xx.html)  |tn => en| 1216| [opus_mt_ts_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ts_fi_xx.html)  |ts => fi| 1243| [opus_mt_uk_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_uk_fi_xx.html)  |uk => fi| 1270| [opus_mt_vsl_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_vsl_es_xx.html)  |vsl => es| 1297| [opus_mt_zh_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_zh_fi_xx.html)  |zh => fi| 1324| []()|
# | 2| [opus_mt_aed_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_aed_es_xx.html)  |aed => es| 29| [opus_mt_ase_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ase_en_xx.html)  |ase => en| 56| [opus_mt_bg_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bg_fi_xx.html)  |bg => fi| 83| [opus_mt_ccs_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ccs_en_xx.html)  |ccs => en| 110| [opus_mt_csg_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_csg_es_xx.html)  |csg => es| 137| [opus_mt_de_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_en_xx.html)  |de => en| 164| [opus_mt_de_lua](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_lua_xx.html)  |de => lua| 191| [opus_mt_efi_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_efi_sv_xx.html)  |efi => sv| 218| [opus_mt_en_cs](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_cs_xx.html)  |en => cs| 245| [opus_mt_en_gv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_gv_xx.html)  |en => gv| 272| [opus_mt_en_loz](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_loz_xx.html)  |en => loz| 299| [opus_mt_en_pap](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_pap_xx.html)  |en => pap| 326| [opus_mt_en_swc](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_swc_xx.html)  |en => swc| 353| [opus_mt_eo_bg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_eo_bg_xx.html)  |eo => bg| 380| [opus_mt_es_bzs](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_bzs_xx.html)  |es => bzs| 407| [opus_mt_es_ho](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_ho_xx.html)  |es => ho| 434| [opus_mt_es_pon](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_pon_xx.html)  |es => pon| 461| [opus_mt_es_xh](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_xh_xx.html)  |es => xh| 488| [opus_mt_fi_el](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_el_xx.html)  |fi => el| 515| [opus_mt_fi_lg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_lg_xx.html)  |fi => lg| 542| [opus_mt_fi_sk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_sk_xx.html)  |fi => sk| 569| [opus_mt_fi_yo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_yo_xx.html)  |fi => yo| 596| [opus_mt_fr_gil](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_gil_xx.html)  |fr => gil| 623| [opus_mt_fr_mt](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_mt_xx.html)  |fr => mt| 650| [opus_mt_fr_tn](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_fr_tn_xx.html)  |fr => tn| 677| [opus_mt_gil_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_gil_en_xx.html)  |gil => en| 704| [opus_mt_he_eo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_he_eo_xx.html)  |he => eo| 731| [opus_mt_hu_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_hu_sv_xx.html)  |hu => sv| 758| [opus_mt_is_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_is_en_xx.html)  |is => en| 785| [opus_mt_itc_itc](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_itc_itc_xx.html)  |itc => itc| 812| [opus_mt_kg_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_kg_fr_xx.html)  |kg => fr| 839| [opus_mt_ln_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ln_es_xx.html)  |ln => es| 866| [opus_mt_lue_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lue_en_xx.html)  |lue => en| 893| [opus_mt_mk_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_mk_es_xx.html)  |mk => es| 920| [opus_mt_nl_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_nl_en_xx.html)  |nl => en| 947| [opus_mt_ny_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ny_es_xx.html)  |ny => es| 974| [opus_mt_pl_no](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pl_no_xx.html)  |pl => no| 1001| [opus_mt_roa_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_roa_en_xx.html)  |roa => en| 1028| [opus_mt_rw_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_rw_sv_xx.html)  |rw => sv| 1055| [opus_mt_sn_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sn_en_xx.html)  |sn => en| 1082| [opus_mt_sv_crs](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_crs_xx.html)  |sv => crs| 1109| [opus_mt_sv_kg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_kg_xx.html)  |sv => kg| 1136| [opus_mt_sv_rw](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_rw_xx.html)  |sv => rw| 1163| [opus_mt_sv_wls](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_wls_xx.html)  |sv => wls| 1190| [opus_mt_tn_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tn_es_xx.html)  |tn => es| 1217| [opus_mt_ts_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ts_fr_xx.html)  |ts => fr| 1244| [opus_mt_uk_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_uk_fr_xx.html)  |uk => fr| 1271| [opus_mt_wa_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_wa_en_xx.html)  |wa => en| 1298| [opus_mt_zh_he](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_zh_he_xx.html)  |zh => he| 1325| []()|
# | 3| [opus_mt_af_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_af_de_xx.html)  |af => de| 30| [opus_mt_ase_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ase_es_xx.html)  |ase => es| 57| [opus_mt_bg_fr](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_bg_fr_xx.html)  |bg => fr| 84| [opus_mt_ceb_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ceb_en_xx.html)  |ceb => en| 111| [opus_mt_csn_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_csn_es_xx.html)  |csn => es| 138| [opus_mt_de_eo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_eo_xx.html)  |de => eo| 165| [opus_mt_de_ms](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_ms_xx.html)  |de => ms| 192| [opus_mt_el_ar](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_el_ar_xx.html)  |el => ar| 219| [opus_mt_en_cus](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_cus_xx.html)  |en => cus| 246| [opus_mt_en_ha](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_ha_xx.html)  |en => ha| 273| [opus_mt_en_lu](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_en_lu_xx.html)  |en => lu| 300| [opus_mt_en_phi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_phi_xx.html)  |en => phi| 327| [opus_mt_en_tdt](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_tdt_xx.html)  |en => tdt| 354| [opus_mt_eo_cs](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_eo_cs_xx.html)  |eo => cs| 381| [opus_mt_es_ca](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_ca_xx.html)  |es => ca| 408| [opus_mt_es_hr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_hr_xx.html)  |es => hr| 435| [opus_mt_es_prl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_prl_xx.html)  |es => prl| 462| [opus_mt_es_yo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_yo_xx.html)  |es => yo| 489| [opus_mt_fi_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_en_xx.html)  |fi => en| 516| [opus_mt_fi_ln](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_ln_xx.html)  |fi => ln| 543| [opus_mt_fi_sl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_sl_xx.html)  |fi => sl| 570| [opus_mt_fi_zne](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_zne_xx.html)  |fi => zne| 597| [opus_mt_fr_guw](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_guw_xx.html)  |fr => guw| 624| [opus_mt_fr_niu](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_niu_xx.html)  |fr => niu| 651| [opus_mt_fr_to](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_to_xx.html)  |fr => to| 678| [opus_mt_gil_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_gil_es_xx.html)  |gil => es| 705| [opus_mt_he_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_he_es_xx.html)  |he => es| 732| [opus_mt_hu_uk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_hu_uk_xx.html)  |hu => uk| 759| [opus_mt_is_eo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_is_eo_xx.html)  |is => eo| 786| [opus_mt_ja_ar](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ja_ar_xx.html)  |ja => ar| 813| [opus_mt_kg_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_kg_sv_xx.html)  |kg => sv| 840| [opus_mt_ln_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ln_fr_xx.html)  |ln => fr| 867| [opus_mt_lue_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lue_es_xx.html)  |lue => es| 894| [opus_mt_mk_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_mk_fi_xx.html)  |mk => fi| 921| [opus_mt_nl_eo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_nl_eo_xx.html)  |nl => eo| 948| [opus_mt_nyk_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_nyk_en_xx.html)  |nyk => en| 975| [opus_mt_pl_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pl_sv_xx.html)  |pl => sv| 1002| [opus_mt_ru_af](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ru_af_xx.html)  |ru => af| 1029| [opus_mt_sal_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sal_en_xx.html)  |sal => en| 1056| [opus_mt_sn_es](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_sn_es_xx.html)  |sn => es| 1083| [opus_mt_sv_cs](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_cs_xx.html)  |sv => cs| 1110| [opus_mt_sv_kqn](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_kqn_xx.html)  |sv => kqn| 1137| [opus_mt_sv_sg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_sg_xx.html)  |sv => sg| 1164| [opus_mt_sv_xh](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_xh_xx.html)  |sv => xh| 1191| [opus_mt_tn_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tn_fr_xx.html)  |tn => fr| 1218| [opus_mt_ts_sv](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_ts_sv_xx.html)  |ts => sv| 1245| [opus_mt_uk_he](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_uk_he_xx.html)  |uk => he| 1272| [opus_mt_wal_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_wal_en_xx.html)  |wal => en| 1299| [opus_mt_zh_it](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_zh_it_xx.html)  |zh => it| 1326| []()|
# | 4| [opus_mt_af_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_af_en_xx.html)  |af => en| 31| [opus_mt_ase_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ase_fr_xx.html)  |ase => fr| 58| [opus_mt_bg_it](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bg_it_xx.html)  |bg => it| 85| [opus_mt_ceb_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ceb_es_xx.html)  |ceb => es| 112| [opus_mt_cus_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_cus_en_xx.html)  |cus => en| 139| [opus_mt_de_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_es_xx.html)  |de => es| 166| [opus_mt_de_mt](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_mt_xx.html)  |de => mt| 193| [opus_mt_el_eo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_el_eo_xx.html)  |el => eo| 220| [opus_mt_en_cy](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_cy_xx.html)  |en => cy| 247| [opus_mt_en_he](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_he_xx.html)  |en => he| 274| [opus_mt_en_lua](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_lua_xx.html)  |en => lua| 301| [opus_mt_en_pis](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_pis_xx.html)  |en => pis| 328| [opus_mt_en_ti](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_en_ti_xx.html)  |en => ti| 355| [opus_mt_eo_da](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_eo_da_xx.html)  |eo => da| 382| [opus_mt_es_ceb](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_ceb_xx.html)  |es => ceb| 409| [opus_mt_es_ht](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_ht_xx.html)  |es => ht| 436| [opus_mt_es_rn](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_rn_xx.html)  |es => rn| 463| [opus_mt_es_yua](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_yua_xx.html)  |es => yua| 490| [opus_mt_fi_eo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_eo_xx.html)  |fi => eo| 517| [opus_mt_fi_lu](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_lu_xx.html)  |fi => lu| 544| [opus_mt_fi_sm](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_sm_xx.html)  |fi => sm| 571| [opus_mt_fiu_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fiu_en_xx.html)  |fiu => en| 598| [opus_mt_fr_ha](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_ha_xx.html)  |fr => ha| 625| [opus_mt_fr_no](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_no_xx.html)  |fr => no| 652| [opus_mt_fr_tpi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_tpi_xx.html)  |fr => tpi| 679| [opus_mt_gil_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_gil_fi_xx.html)  |gil => fi| 706| [opus_mt_he_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_he_fi_xx.html)  |he => fi| 733| [opus_mt_hy_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_hy_en_xx.html)  |hy => en| 760| [opus_mt_is_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_is_es_xx.html)  |is => es| 787| [opus_mt_ja_bg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ja_bg_xx.html)  |ja => bg| 814| [opus_mt_kj_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_kj_en_xx.html)  |kj => en| 841| [opus_mt_loz_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_loz_de_xx.html)  |loz => de| 868| [opus_mt_lue_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lue_fi_xx.html)  |lue => fi| 895| [opus_mt_mk_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_mk_fr_xx.html)  |mk => fr| 922| [opus_mt_nl_es](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_nl_es_xx.html)  |nl => es| 949| [opus_mt_om_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_om_en_xx.html)  |om => en| 976| [opus_mt_pl_uk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pl_uk_xx.html)  |pl => uk| 1003| [opus_mt_ru_ar](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ru_ar_xx.html)  |ru => ar| 1030| [opus_mt_sem_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sem_en_xx.html)  |sem => en| 1057| [opus_mt_sn_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sn_fr_xx.html)  |sn => fr| 1084| [opus_mt_sv_ee](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_ee_xx.html)  |sv => ee| 1111| [opus_mt_sv_kwy](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_kwy_xx.html)  |sv => kwy| 1138| [opus_mt_sv_sk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_sk_xx.html)  |sv => sk| 1165| [opus_mt_sv_yap](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_yap_xx.html)  |sv => yap| 1192| [opus_mt_tn_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tn_sv_xx.html)  |tn => sv| 1219| [opus_mt_tum_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tum_en_xx.html)  |tum => en| 1246| [opus_mt_uk_hu](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_uk_hu_xx.html)  |uk => hu| 1273| [opus_mt_war_en](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_war_en_xx.html)  |war => en| 1300| [opus_mt_zh_ms](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_zh_ms_xx.html)  |zh => ms| 1327| []()|
# | 5| [opus_mt_af_eo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_af_eo_xx.html)  |af => eo| 32| [opus_mt_ase_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ase_sv_xx.html)  |ase => sv| 59| [opus_mt_bg_ru](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bg_ru_xx.html)  |bg => ru| 86| [opus_mt_ceb_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ceb_fi_xx.html)  |ceb => fi| 113| [opus_mt_cy_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_cy_en_xx.html)  |cy => en| 140| [opus_mt_de_et](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_et_xx.html)  |de => et| 167| [opus_mt_de_niu](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_de_niu_xx.html)  |de => niu| 194| [opus_mt_el_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_el_fi_xx.html)  |el => fi| 221| [opus_mt_en_da](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_da_xx.html)  |en => da| 248| [opus_mt_en_hi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_hi_xx.html)  |en => hi| 275| [opus_mt_en_lue](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_lue_xx.html)  |en => lue| 302| [opus_mt_en_pon](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_pon_xx.html)  |en => pon| 329| [opus_mt_en_tiv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_tiv_xx.html)  |en => tiv| 356| [opus_mt_eo_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_eo_de_xx.html)  |eo => de| 383| [opus_mt_es_crs](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_crs_xx.html)  |es => crs| 410| [opus_mt_es_id](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_id_xx.html)  |es => id| 437| [opus_mt_es_ro](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_ro_xx.html)  |es => ro| 464| [opus_mt_es_zai](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_zai_xx.html)  |es => zai| 491| [opus_mt_fi_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_es_xx.html)  |fi => es| 518| [opus_mt_fi_lua](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_lua_xx.html)  |fi => lua| 545| [opus_mt_fi_sn](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_sn_xx.html)  |fi => sn| 572| [opus_mt_fiu_fiu](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fiu_fiu_xx.html)  |fiu => fiu| 599| [opus_mt_fr_he](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_he_xx.html)  |fr => he| 626| [opus_mt_fr_nso](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_nso_xx.html)  |fr => nso| 653| [opus_mt_fr_ts](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_ts_xx.html)  |fr => ts| 680| [opus_mt_gil_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_gil_fr_xx.html)  |gil => fr| 707| [opus_mt_he_it](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_he_it_xx.html)  |he => it| 734| [opus_mt_hy_ru](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_hy_ru_xx.html)  |hy => ru| 761| [opus_mt_is_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_is_fi_xx.html)  |is => fi| 788| [opus_mt_ja_da](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ja_da_xx.html)  |ja => da| 815| [opus_mt_kl_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_kl_en_xx.html)  |kl => en| 842| [opus_mt_loz_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_loz_en_xx.html)  |loz => en| 869| [opus_mt_lue_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lue_fr_xx.html)  |lue => fr| 896| [opus_mt_mkh_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_mkh_en_xx.html)  |mkh => en| 923| [opus_mt_nl_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_nl_fi_xx.html)  |nl => fi| 950| [opus_mt_pa_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pa_en_xx.html)  |pa => en| 977| [opus_mt_pon_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pon_en_xx.html)  |pon => en| 1004| [opus_mt_ru_bg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ru_bg_xx.html)  |ru => bg| 1031| [opus_mt_sem_sem](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sem_sem_xx.html)  |sem => sem| 1058| [opus_mt_sn_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sn_sv_xx.html)  |sn => sv| 1085| [opus_mt_sv_efi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_efi_xx.html)  |sv => efi| 1112| [opus_mt_sv_lg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_lg_xx.html)  |sv => lg| 1139| [opus_mt_sv_sl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_sl_xx.html)  |sv => sl| 1166| [opus_mt_sv_yo](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_sv_yo_xx.html)  |sv => yo| 1193| [opus_mt_to_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_to_en_xx.html)  |to => en| 1220| [opus_mt_tum_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tum_es_xx.html)  |tum => es| 1247| [opus_mt_uk_it](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_uk_it_xx.html)  |uk => it| 1274| [opus_mt_war_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_war_es_xx.html)  |war => es| 1301| [opus_mt_zh_nl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_zh_nl_xx.html)  |zh => nl| 1328| []()|
# | 6| [opus_mt_af_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_af_es_xx.html)  |af => es| 33| [opus_mt_az_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_az_en_xx.html)  |az => en| 60| [opus_mt_bg_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bg_sv_xx.html)  |bg => sv| 87| [opus_mt_ceb_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ceb_fr_xx.html)  |ceb => fr| 114| [opus_mt_da_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_da_de_xx.html)  |da => de| 141| [opus_mt_de_eu](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_eu_xx.html)  |de => eu| 168| [opus_mt_de_nl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_nl_xx.html)  |de => nl| 195| [opus_mt_el_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_el_fr_xx.html)  |el => fr| 222| [opus_mt_en_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_de_xx.html)  |en => de| 249| [opus_mt_en_hil](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_hil_xx.html)  |en => hil| 276| [opus_mt_en_lun](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_lun_xx.html)  |en => lun| 303| [opus_mt_en_poz](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_poz_xx.html)  |en => poz| 330| [opus_mt_en_tl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_tl_xx.html)  |en => tl| 357| [opus_mt_eo_el](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_eo_el_xx.html)  |eo => el| 384| [opus_mt_es_cs](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_cs_xx.html)  |es => cs| 411| [opus_mt_es_ig](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_ig_xx.html)  |es => ig| 438| [opus_mt_es_ru](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_ru_xx.html)  |es => ru| 465| [opus_mt_et_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_et_de_xx.html)  |et => de| 492| [opus_mt_fi_et](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_et_xx.html)  |fi => et| 519| [opus_mt_fi_lue](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_lue_xx.html)  |fi => lue| 546| [opus_mt_fi_sq](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_sq_xx.html)  |fi => sq| 573| [opus_mt_fj_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fj_en_xx.html)  |fj => en| 600| [opus_mt_fr_hil](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_hil_xx.html)  |fr => hil| 627| [opus_mt_fr_ny](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_ny_xx.html)  |fr => ny| 654| [opus_mt_fr_tum](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_tum_xx.html)  |fr => tum| 681| [opus_mt_gil_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_gil_sv_xx.html)  |gil => sv| 708| [opus_mt_he_ru](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_he_ru_xx.html)  |he => ru| 735| [opus_mt_id_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_id_en_xx.html)  |id => en| 762| [opus_mt_is_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_is_fr_xx.html)  |is => fr| 789| [opus_mt_ja_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ja_de_xx.html)  |ja => de| 816| [opus_mt_ko_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ko_de_xx.html)  |ko => de| 843| [opus_mt_loz_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_loz_es_xx.html)  |loz => es| 870| [opus_mt_lue_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lue_sv_xx.html)  |lue => sv| 897| [opus_mt_ml_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ml_en_xx.html)  |ml => en| 924| [opus_mt_nl_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_nl_fr_xx.html)  |nl => fr| 951| [opus_mt_pag_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pag_de_xx.html)  |pag => de| 978| [opus_mt_pon_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pon_es_xx.html)  |pon => es| 1005| [opus_mt_ru_da](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ru_da_xx.html)  |ru => da| 1032| [opus_mt_sg_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sg_en_xx.html)  |sg => en| 1059| [opus_mt_sq_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sq_en_xx.html)  |sq => en| 1086| [opus_mt_sv_el](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_el_xx.html)  |sv => el| 1113| [opus_mt_sv_ln](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_ln_xx.html)  |sv => ln| 1140| [opus_mt_sv_sm](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_sm_xx.html)  |sv => sm| 1167| [opus_mt_sv_zne](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_zne_xx.html)  |sv => zne| 1194| [opus_mt_to_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_to_es_xx.html)  |to => es| 1221| [opus_mt_tum_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tum_fr_xx.html)  |tum => fr| 1248| [opus_mt_uk_nl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_uk_nl_xx.html)  |uk => nl| 1275| [opus_mt_war_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_war_fi_xx.html)  |war => fi| 1302| [opus_mt_zh_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_zh_sv_xx.html)  |zh => sv| 1329| []()|
# | 7| [opus_mt_af_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_af_fi_xx.html)  |af => fi| 34| [opus_mt_az_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_az_es_xx.html)  |az => es| 61| [opus_mt_bg_tr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bg_tr_xx.html)  |bg => tr| 88| [opus_mt_ceb_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ceb_sv_xx.html)  |ceb => sv| 115| [opus_mt_da_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_da_en_xx.html)  |da => en| 142| [opus_mt_de_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_fi_xx.html)  |de => fi| 169| [opus_mt_de_no](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_no_xx.html)  |de => no| 196| [opus_mt_el_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_el_sv_xx.html)  |el => sv| 223| [opus_mt_en_dra](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_dra_xx.html)  |en => dra| 250| [opus_mt_en_ho](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_ho_xx.html)  |en => ho| 277| [opus_mt_en_luo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_luo_xx.html)  |en => luo| 304| [opus_mt_en_pqe](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_pqe_xx.html)  |en => pqe| 331| [opus_mt_en_tll](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_tll_xx.html)  |en => tll| 358| [opus_mt_eo_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_eo_en_xx.html)  |eo => en| 385| [opus_mt_es_csg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_csg_xx.html)  |es => csg| 412| [opus_mt_es_ilo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_ilo_xx.html)  |es => ilo| 439| [opus_mt_es_rw](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_rw_xx.html)  |es => rw| 466| [opus_mt_et_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_et_en_xx.html)  |et => en| 493| [opus_mt_fi_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_fi_xx.html)  |fi => fi| 520| [opus_mt_fi_lus](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_lus_xx.html)  |fi => lus| 547| [opus_mt_fi_srn](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_srn_xx.html)  |fi => srn| 574| [opus_mt_fj_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fj_fr_xx.html)  |fj => fr| 601| [opus_mt_fr_ho](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_ho_xx.html)  |fr => ho| 628| [opus_mt_fr_pag](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_pag_xx.html)  |fr => pag| 655| [opus_mt_fr_tvl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_tvl_xx.html)  |fr => tvl| 682| [opus_mt_gl_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_gl_en_xx.html)  |gl => en| 709| [opus_mt_he_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_he_sv_xx.html)  |he => sv| 736| [opus_mt_id_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_id_es_xx.html)  |id => es| 763| [opus_mt_is_it](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_is_it_xx.html)  |is => it| 790| [opus_mt_ja_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ja_en_xx.html)  |ja => en| 817| [opus_mt_ko_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ko_en_xx.html)  |ko => en| 844| [opus_mt_loz_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_loz_fi_xx.html)  |loz => fi| 871| [opus_mt_lun_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lun_en_xx.html)  |lun => en| 898| [opus_mt_mos_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_mos_en_xx.html)  |mos => en| 925| [opus_mt_nl_no](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_nl_no_xx.html)  |nl => no| 952| [opus_mt_pag_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pag_en_xx.html)  |pag => en| 979| [opus_mt_pon_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pon_fi_xx.html)  |pon => fi| 1006| [opus_mt_ru_en](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_ru_en_xx.html)  |ru => en| 1033| [opus_mt_sg_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sg_es_xx.html)  |sg => es| 1060| [opus_mt_sq_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sq_es_xx.html)  |sq => es| 1087| [opus_mt_sv_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_en_xx.html)  |sv => en| 1114| [opus_mt_sv_lu](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_lu_xx.html)  |sv => lu| 1141| [opus_mt_sv_sn](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_sn_xx.html)  |sv => sn| 1168| [opus_mt_swc_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_swc_en_xx.html)  |swc => en| 1195| [opus_mt_to_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_to_fr_xx.html)  |to => fr| 1222| [opus_mt_tum_sv](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_tum_sv_xx.html)  |tum => sv| 1249| [opus_mt_uk_no](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_uk_no_xx.html)  |uk => no| 1276| [opus_mt_war_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_war_fr_xx.html)  |war => fr| 1303| [opus_mt_zh_uk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_zh_uk_xx.html)  |zh => uk| 1330| []()|
# | 8| [opus_mt_af_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_af_fr_xx.html)  |af => fr| 35| [opus_mt_az_tr](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_az_tr_xx.html)  |az => tr| 62| [opus_mt_bg_uk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bg_uk_xx.html)  |bg => uk| 89| [opus_mt_cel_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_cel_en_xx.html)  |cel => en| 116| [opus_mt_da_eo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_da_eo_xx.html)  |da => eo| 143| [opus_mt_de_fj](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_fj_xx.html)  |de => fj| 170| [opus_mt_de_nso](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_nso_xx.html)  |de => nso| 197| [opus_mt_en_aav](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_aav_xx.html)  |en => aav| 224| [opus_mt_en_ee](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_ee_xx.html)  |en => ee| 251| [opus_mt_en_ht](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_ht_xx.html)  |en => ht| 278| [opus_mt_en_lus](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_lus_xx.html)  |en => lus| 305| [opus_mt_en_pqw](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_pqw_xx.html)  |en => pqw| 332| [opus_mt_en_tn](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_tn_xx.html)  |en => tn| 359| [opus_mt_eo_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_eo_es_xx.html)  |eo => es| 386| [opus_mt_es_csn](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_csn_xx.html)  |es => csn| 413| [opus_mt_es_is](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_is_xx.html)  |es => is| 440| [opus_mt_es_sg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_sg_xx.html)  |es => sg| 467| [opus_mt_et_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_et_es_xx.html)  |et => es| 494| [opus_mt_fi_fj](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_fj_xx.html)  |fi => fj| 521| [opus_mt_fi_lv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_lv_xx.html)  |fi => lv| 548| [opus_mt_fi_st](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_st_xx.html)  |fi => st| 575| [opus_mt_fr_af](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_af_xx.html)  |fr => af| 602| [opus_mt_fr_hr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_hr_xx.html)  |fr => hr| 629| [opus_mt_fr_pap](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_pap_xx.html)  |fr => pap| 656| [opus_mt_fr_tw](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_tw_xx.html)  |fr => tw| 683| [opus_mt_gl_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_gl_es_xx.html)  |gl => es| 710| [opus_mt_he_uk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_he_uk_xx.html)  |he => uk| 737| [opus_mt_id_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_id_fi_xx.html)  |id => fi| 764| [opus_mt_is_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_is_sv_xx.html)  |is => sv| 791| [opus_mt_ja_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ja_es_xx.html)  |ja => es| 818| [opus_mt_ko_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ko_es_xx.html)  |ko => es| 845| [opus_mt_loz_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_loz_fr_xx.html)  |loz => fr| 872| [opus_mt_luo_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_luo_en_xx.html)  |luo => en| 899| [opus_mt_mr_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_mr_en_xx.html)  |mr => en| 926| [opus_mt_nl_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_nl_sv_xx.html)  |nl => sv| 953| [opus_mt_pag_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pag_es_xx.html)  |pag => es| 980| [opus_mt_pon_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pon_fr_xx.html)  |pon => fr| 1007| [opus_mt_ru_eo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ru_eo_xx.html)  |ru => eo| 1034| [opus_mt_sg_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sg_fi_xx.html)  |sg => fi| 1061| [opus_mt_sq_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sq_sv_xx.html)  |sq => sv| 1088| [opus_mt_sv_eo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_eo_xx.html)  |sv => eo| 1115| [opus_mt_sv_lua](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_lua_xx.html)  |sv => lua| 1142| [opus_mt_sv_sq](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_sq_xx.html)  |sv => sq| 1169| [opus_mt_swc_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_swc_es_xx.html)  |swc => es| 1196| [opus_mt_to_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_to_sv_xx.html)  |to => sv| 1223| [opus_mt_tvl_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tvl_en_xx.html)  |tvl => en| 1250| [opus_mt_uk_pl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_uk_pl_xx.html)  |uk => pl| 1277| [opus_mt_war_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_war_sv_xx.html)  |war => sv| 1304| [opus_mt_zh_vi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_zh_vi_xx.html)  |zh => vi| 1331| []()|
# | 9| [opus_mt_af_nl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_af_nl_xx.html)  |af => nl| 36| [opus_mt_bat_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bat_en_xx.html)  |bat => en| 63| [opus_mt_bi_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bi_en_xx.html)  |bi => en| 90| [opus_mt_chk_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_chk_en_xx.html)  |chk => en| 117| [opus_mt_da_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_da_es_xx.html)  |da => es| 144| [opus_mt_de_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_fr_xx.html)  |de => fr| 171| [opus_mt_de_ny](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_ny_xx.html)  |de => ny| 198| [opus_mt_en_af](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_af_xx.html)  |en => af| 225| [opus_mt_en_efi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_efi_xx.html)  |en => efi| 252| [opus_mt_en_hu](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_en_hu_xx.html)  |en => hu| 279| [opus_mt_en_map](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_map_xx.html)  |en => map| 306| [opus_mt_en_rn](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_rn_xx.html)  |en => rn| 333| [opus_mt_en_to](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_to_xx.html)  |en => to| 360| [opus_mt_eo_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_eo_fi_xx.html)  |eo => fi| 387| [opus_mt_es_da](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_da_xx.html)  |es => da| 414| [opus_mt_es_iso](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_iso_xx.html)  |es => iso| 441| [opus_mt_es_sl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_sl_xx.html)  |es => sl| 468| [opus_mt_et_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_et_fi_xx.html)  |et => fi| 495| [opus_mt_fi_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_fr_xx.html)  |fi => fr| 522| [opus_mt_fi_mfe](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_mfe_xx.html)  |fi => mfe| 549| [opus_mt_fi_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_sv_xx.html)  |fi => sv| 576| [opus_mt_fr_ar](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_ar_xx.html)  |fr => ar| 603| [opus_mt_fr_ht](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_ht_xx.html)  |fr => ht| 630| [opus_mt_fr_pis](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_pis_xx.html)  |fr => pis| 657| [opus_mt_fr_ty](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_ty_xx.html)  |fr => ty| 684| [opus_mt_gl_pt](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_gl_pt_xx.html)  |gl => pt| 711| [opus_mt_hi_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_hi_en_xx.html)  |hi => en| 738| [opus_mt_id_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_id_fr_xx.html)  |id => fr| 765| [opus_mt_iso_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_iso_en_xx.html)  |iso => en| 792| [opus_mt_ja_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ja_fi_xx.html)  |ja => fi| 819| [opus_mt_ko_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ko_fi_xx.html)  |ko => fi| 846| [opus_mt_loz_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_loz_sv_xx.html)  |loz => sv| 873| [opus_mt_lus_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lus_en_xx.html)  |lus => en| 900| [opus_mt_ms_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ms_de_xx.html)  |ms => de| 927| [opus_mt_nl_uk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_nl_uk_xx.html)  |nl => uk| 954| [opus_mt_pag_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pag_fi_xx.html)  |pag => fi| 981| [opus_mt_pon_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pon_sv_xx.html)  |pon => sv| 1008| [opus_mt_ru_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ru_es_xx.html)  |ru => es| 1035| [opus_mt_sg_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sg_fr_xx.html)  |sg => fr| 1062| [opus_mt_srn_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_srn_en_xx.html)  |srn => en| 1089| [opus_mt_sv_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_es_xx.html)  |sv => es| 1116| [opus_mt_sv_lue](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_lue_xx.html)  |sv => lue| 1143| [opus_mt_sv_srn](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_srn_xx.html)  |sv => srn| 1170| [opus_mt_swc_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_swc_fi_xx.html)  |swc => fi| 1197| [opus_mt_toi_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_toi_en_xx.html)  |toi => en| 1224| [opus_mt_tvl_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tvl_es_xx.html)  |tvl => es| 1251| [opus_mt_uk_pt](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_uk_pt_xx.html)  |uk => pt| 1278| [opus_mt_wls_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_wls_en_xx.html)  |wls => en| 1305| [opus_mt_zle_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_zle_en_xx.html)  |zle => en| 1332| []()|
# | 10| [opus_mt_af_ru](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_af_ru_xx.html)  |af => ru| 37| [opus_mt_bcl_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bcl_de_xx.html)  |bcl => de| 64| [opus_mt_bi_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bi_es_xx.html)  |bi => es| 91| [opus_mt_chk_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_chk_es_xx.html)  |chk => es| 118| [opus_mt_da_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_da_fi_xx.html)  |da => fi| 145| [opus_mt_de_gaa](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_gaa_xx.html)  |de => gaa| 172| [opus_mt_de_pag](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_pag_xx.html)  |de => pag| 199| [opus_mt_en_afa](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_afa_xx.html)  |en => afa| 226| [opus_mt_en_el](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_el_xx.html)  |en => el| 253| [opus_mt_en_hy](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_hy_xx.html)  |en => hy| 280| [opus_mt_en_mfe](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_mfe_xx.html)  |en => mfe| 307| [opus_mt_en_rnd](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_rnd_xx.html)  |en => rnd| 334| [opus_mt_en_toi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_toi_xx.html)  |en => toi| 361| [opus_mt_eo_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_eo_fr_xx.html)  |eo => fr| 388| [opus_mt_es_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_de_xx.html)  |es => de| 415| [opus_mt_es_it](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_it_xx.html)  |es => it| 442| [opus_mt_es_sm](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_sm_xx.html)  |es => sm| 469| [opus_mt_et_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_et_fr_xx.html)  |et => fr| 496| [opus_mt_fi_fse](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_fse_xx.html)  |fi => fse| 523| [opus_mt_fi_mg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_mg_xx.html)  |fi => mg| 550| [opus_mt_fi_sw](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_sw_xx.html)  |fi => sw| 577| [opus_mt_fr_ase](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_ase_xx.html)  |fr => ase| 604| [opus_mt_fr_hu](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_hu_xx.html)  |fr => hu| 631| [opus_mt_fr_pl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_pl_xx.html)  |fr => pl| 658| [opus_mt_fr_uk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_uk_xx.html)  |fr => uk| 685| [opus_mt_gmq_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_gmq_en_xx.html)  |gmq => en| 712| [opus_mt_hi_ur](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_hi_ur_xx.html)  |hi => ur| 739| [opus_mt_id_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_id_sv_xx.html)  |id => sv| 766| [opus_mt_iso_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_iso_es_xx.html)  |iso => es| 793| [opus_mt_ja_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ja_fr_xx.html)  |ja => fr| 820| [opus_mt_ko_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ko_fr_xx.html)  |ko => fr| 847| [opus_mt_lt_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lt_de_xx.html)  |lt => de| 874| [opus_mt_lus_es](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_lus_es_xx.html)  |lus => es| 901| [opus_mt_ms_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ms_fr_xx.html)  |ms => fr| 928| [opus_mt_no_da](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_no_da_xx.html)  |no => da| 955| [opus_mt_pag_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pag_sv_xx.html)  |pag => sv| 982| [opus_mt_pqe_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pqe_en_xx.html)  |pqe => en| 1009| [opus_mt_ru_et](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ru_et_xx.html)  |ru => et| 1036| [opus_mt_sg_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sg_sv_xx.html)  |sg => sv| 1063| [opus_mt_srn_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_srn_es_xx.html)  |srn => es| 1090| [opus_mt_sv_et](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_et_xx.html)  |sv => et| 1117| [opus_mt_sv_lus](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_lus_xx.html)  |sv => lus| 1144| [opus_mt_sv_st](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_st_xx.html)  |sv => st| 1171| [opus_mt_swc_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_swc_fr_xx.html)  |swc => fr| 1198| [opus_mt_toi_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_toi_es_xx.html)  |toi => es| 1225| [opus_mt_tvl_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tvl_fi_xx.html)  |tvl => fi| 1252| [opus_mt_uk_ru](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_uk_ru_xx.html)  |uk => ru| 1279| [opus_mt_wls_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_wls_fr_xx.html)  |wls => fr| 1306| [opus_mt_zle_zle](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_zle_zle_xx.html)  |zle => zle| 1333| []()|
# | 11| [opus_mt_af_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_af_sv_xx.html)  |af => sv| 38| [opus_mt_bcl_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bcl_en_xx.html)  |bcl => en| 65| [opus_mt_bi_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bi_fr_xx.html)  |bi => fr| 92| [opus_mt_chk_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_chk_fr_xx.html)  |chk => fr| 119| [opus_mt_da_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_da_fr_xx.html)  |da => fr| 146| [opus_mt_de_gil](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_gil_xx.html)  |de => gil| 173| [opus_mt_de_pap](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_pap_xx.html)  |de => pap| 200| [opus_mt_en_alv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_alv_xx.html)  |en => alv| 227| [opus_mt_en_eo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_eo_xx.html)  |en => eo| 254| [opus_mt_en_id](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_id_xx.html)  |en => id| 281| [opus_mt_en_mg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_mg_xx.html)  |en => mg| 308| [opus_mt_en_ro](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_ro_xx.html)  |en => ro| 335| [opus_mt_en_tpi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_tpi_xx.html)  |en => tpi| 362| [opus_mt_eo_he](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_eo_he_xx.html)  |eo => he| 389| [opus_mt_es_ee](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_ee_xx.html)  |es => ee| 416| [opus_mt_es_kg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_kg_xx.html)  |es => kg| 443| [opus_mt_es_sn](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_es_sn_xx.html)  |es => sn| 470| [opus_mt_et_ru](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_et_ru_xx.html)  |et => ru| 497| [opus_mt_fi_gaa](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_gaa_xx.html)  |fi => gaa| 524| [opus_mt_fi_mh](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_mh_xx.html)  |fi => mh| 551| [opus_mt_fi_swc](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_swc_xx.html)  |fi => swc| 578| [opus_mt_fr_bcl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_bcl_xx.html)  |fr => bcl| 605| [opus_mt_fr_id](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_fr_id_xx.html)  |fr => id| 632| [opus_mt_fr_pon](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_pon_xx.html)  |fr => pon| 659| [opus_mt_fr_ve](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_ve_xx.html)  |fr => ve| 686| [opus_mt_gmq_gmq](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_gmq_gmq_xx.html)  |gmq => gmq| 713| [opus_mt_hil_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_hil_de_xx.html)  |hil => de| 740| [opus_mt_ig_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ig_de_xx.html)  |ig => de| 767| [opus_mt_iso_fi](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_iso_fi_xx.html)  |iso => fi| 794| [opus_mt_ja_he](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ja_he_xx.html)  |ja => he| 821| [opus_mt_ko_hu](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ko_hu_xx.html)  |ko => hu| 848| [opus_mt_lt_eo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lt_eo_xx.html)  |lt => eo| 875| [opus_mt_lus_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lus_fi_xx.html)  |lus => fi| 902| [opus_mt_ms_it](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ms_it_xx.html)  |ms => it| 929| [opus_mt_no_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_no_de_xx.html)  |no => de| 956| [opus_mt_pap_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pap_de_xx.html)  |pap => de| 983| [opus_mt_prl_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_prl_es_xx.html)  |prl => es| 1010| [opus_mt_ru_eu](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ru_eu_xx.html)  |ru => eu| 1037| [opus_mt_sh_eo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sh_eo_xx.html)  |sh => eo| 1064| [opus_mt_srn_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_srn_fr_xx.html)  |srn => fr| 1091| [opus_mt_sv_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_fi_xx.html)  |sv => fi| 1118| [opus_mt_sv_lv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_lv_xx.html)  |sv => lv| 1145| [opus_mt_sv_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_sv_xx.html)  |sv => sv| 1172| [opus_mt_swc_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_swc_sv_xx.html)  |swc => sv| 1199| [opus_mt_toi_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_toi_fi_xx.html)  |toi => fi| 1226| [opus_mt_tvl_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tvl_fr_xx.html)  |tvl => fr| 1253| [opus_mt_uk_sh](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_uk_sh_xx.html)  |uk => sh| 1280| [opus_mt_wls_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_wls_sv_xx.html)  |wls => sv| 1307| [opus_mt_zls_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_zls_en_xx.html)  |zls => en| 1334| []()|
# | 12| [opus_mt_afa_afa](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_afa_afa_xx.html)  |afa => afa| 39| [opus_mt_bcl_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bcl_es_xx.html)  |bcl => es| 66| [opus_mt_bi_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bi_sv_xx.html)  |bi => sv| 93| [opus_mt_chk_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_chk_sv_xx.html)  |chk => sv| 120| [opus_mt_da_no](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_da_no_xx.html)  |da => no| 147| [opus_mt_de_guw](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_guw_xx.html)  |de => guw| 174| [opus_mt_de_pis](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_pis_xx.html)  |de => pis| 201| [opus_mt_en_ar](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_ar_xx.html)  |en => ar| 228| [opus_mt_en_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_es_xx.html)  |en => es| 255| [opus_mt_en_ig](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_ig_xx.html)  |en => ig| 282| [opus_mt_en_mh](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_mh_xx.html)  |en => mh| 309| [opus_mt_en_roa](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_roa_xx.html)  |en => roa| 336| [opus_mt_en_trk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_trk_xx.html)  |en => trk| 363| [opus_mt_eo_hu](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_eo_hu_xx.html)  |eo => hu| 390| [opus_mt_es_efi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_efi_xx.html)  |es => efi| 417| [opus_mt_es_ln](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_ln_xx.html)  |es => ln| 444| [opus_mt_es_srn](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_srn_xx.html)  |es => srn| 471| [opus_mt_et_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_et_sv_xx.html)  |et => sv| 498| [opus_mt_fi_gil](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_gil_xx.html)  |fi => gil| 525| [opus_mt_fi_mk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_mk_xx.html)  |fi => mk| 552| [opus_mt_fi_tiv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_tiv_xx.html)  |fi => tiv| 579| [opus_mt_fr_bem](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_bem_xx.html)  |fr => bem| 606| [opus_mt_fr_ig](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_ig_xx.html)  |fr => ig| 633| [opus_mt_fr_rnd](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_rnd_xx.html)  |fr => rnd| 660| [opus_mt_fr_vi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_vi_xx.html)  |fr => vi| 687| [opus_mt_gmw_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_gmw_en_xx.html)  |gmw => en| 714| [opus_mt_hil_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_hil_en_xx.html)  |hil => en| 741| [opus_mt_ig_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ig_en_xx.html)  |ig => en| 768| [opus_mt_iso_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_iso_fr_xx.html)  |iso => fr| 795| [opus_mt_ja_hu](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ja_hu_xx.html)  |ja => hu| 822| [opus_mt_ko_ru](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ko_ru_xx.html)  |ko => ru| 849| [opus_mt_lt_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lt_es_xx.html)  |lt => es| 876| [opus_mt_lus_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lus_fr_xx.html)  |lus => fr| 903| [opus_mt_ms_ms](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ms_ms_xx.html)  |ms => ms| 930| [opus_mt_no_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_no_es_xx.html)  |no => es| 957| [opus_mt_pap_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pap_en_xx.html)  |pap => en| 984| [opus_mt_pt_ca](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pt_ca_xx.html)  |pt => ca| 1011| [opus_mt_ru_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ru_fi_xx.html)  |ru => fi| 1038| [opus_mt_sh_uk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sh_uk_xx.html)  |sh => uk| 1065| [opus_mt_srn_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_srn_sv_xx.html)  |srn => sv| 1092| [opus_mt_sv_fj](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_fj_xx.html)  |sv => fj| 1119| [opus_mt_sv_mfe](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_mfe_xx.html)  |sv => mfe| 1146| [opus_mt_sv_swc](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_swc_xx.html)  |sv => swc| 1173| [opus_mt_taw_en](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_taw_en_xx.html)  |taw => en| 1200| [opus_mt_toi_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_toi_fr_xx.html)  |toi => fr| 1227| [opus_mt_tvl_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tvl_sv_xx.html)  |tvl => sv| 1254| [opus_mt_uk_sl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_uk_sl_xx.html)  |uk => sl| 1281| [opus_mt_xh_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_xh_en_xx.html)  |xh => en| 1308| [opus_mt_zls_zls](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_zls_zls_xx.html)  |zls => zls| 1335| []()|
# | 13| [opus_mt_afa_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_afa_en_xx.html)  |afa => en| 40| [opus_mt_bcl_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bcl_fi_xx.html)  |bcl => fi| 67| [opus_mt_bn_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bn_en_xx.html)  |bn => en| 94| [opus_mt_cpf_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_cpf_en_xx.html)  |cpf => en| 121| [opus_mt_da_ru](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_da_ru_xx.html)  |da => ru| 148| [opus_mt_de_ha](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_ha_xx.html)  |de => ha| 175| [opus_mt_de_pl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_pl_xx.html)  |de => pl| 202| [opus_mt_en_az](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_az_xx.html)  |en => az| 229| [opus_mt_en_et](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_et_xx.html)  |en => et| 256| [opus_mt_en_iir](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_iir_xx.html)  |en => iir| 283| [opus_mt_en_mk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_mk_xx.html)  |en => mk| 310| [opus_mt_en_ru](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_ru_xx.html)  |en => ru| 337| [opus_mt_en_ts](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_ts_xx.html)  |en => ts| 364| [opus_mt_eo_it](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_eo_it_xx.html)  |eo => it| 391| [opus_mt_es_el](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_el_xx.html)  |es => el| 418| [opus_mt_es_loz](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_loz_xx.html)  |es => loz| 445| [opus_mt_es_st](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_st_xx.html)  |es => st| 472| [opus_mt_eu_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_eu_de_xx.html)  |eu => de| 499| [opus_mt_fi_guw](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_guw_xx.html)  |fi => guw| 526| [opus_mt_fi_mos](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_mos_xx.html)  |fi => mos| 553| [opus_mt_fi_tll](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_tll_xx.html)  |fi => tll| 580| [opus_mt_fr_ber](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_ber_xx.html)  |fr => ber| 607| [opus_mt_fr_ilo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_ilo_xx.html)  |fr => ilo| 634| [opus_mt_fr_ro](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_ro_xx.html)  |fr => ro| 661| [opus_mt_fr_war](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_war_xx.html)  |fr => war| 688| [opus_mt_gmw_gmw](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_gmw_gmw_xx.html)  |gmw => gmw| 715| [opus_mt_hil_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_hil_fi_xx.html)  |hil => fi| 742| [opus_mt_ig_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ig_es_xx.html)  |ig => es| 769| [opus_mt_iso_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_iso_sv_xx.html)  |iso => sv| 796| [opus_mt_ja_it](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_ja_it_xx.html)  |ja => it| 823| [opus_mt_ko_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ko_sv_xx.html)  |ko => sv| 850| [opus_mt_lt_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lt_fr_xx.html)  |lt => fr| 877| [opus_mt_lus_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lus_sv_xx.html)  |lus => sv| 904| [opus_mt_mt_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_mt_en_xx.html)  |mt => en| 931| [opus_mt_no_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_no_fi_xx.html)  |no => fi| 958| [opus_mt_pap_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pap_es_xx.html)  |pap => es| 985| [opus_mt_pt_eo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pt_eo_xx.html)  |pt => eo| 1012| [opus_mt_ru_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ru_fr_xx.html)  |ru => fr| 1039| [opus_mt_sk_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sk_en_xx.html)  |sk => en| 1066| [opus_mt_ss_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ss_en_xx.html)  |ss => en| 1093| [opus_mt_sv_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_fr_xx.html)  |sv => fr| 1120| [opus_mt_sv_mh](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_mh_xx.html)  |sv => mh| 1147| [opus_mt_sv_th](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_th_xx.html)  |sv => th| 1174| [opus_mt_th_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_th_en_xx.html)  |th => en| 1201| [opus_mt_toi_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_toi_sv_xx.html)  |toi => sv| 1228| [opus_mt_tw_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tw_es_xx.html)  |tw => es| 1255| [opus_mt_uk_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_uk_sv_xx.html)  |uk => sv| 1282| [opus_mt_xh_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_xh_es_xx.html)  |xh => es| 1309| [opus_mt_zlw_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_zlw_en_xx.html)  |zlw => en| 1336| []()|
# | 14| [opus_mt_alv_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_alv_en_xx.html)  |alv => en| 41| [opus_mt_bcl_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bcl_fr_xx.html)  |bcl => fr| 68| [opus_mt_bnt_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bnt_en_xx.html)  |bnt => en| 95| [opus_mt_cpp_cpp](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_cpp_cpp_xx.html)  |cpp => cpp| 122| [opus_mt_de_af](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_af_xx.html)  |de => af| 149| [opus_mt_de_he](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_he_xx.html)  |de => he| 176| [opus_mt_de_pon](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_pon_xx.html)  |de => pon| 203| [opus_mt_en_bat](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_bat_xx.html)  |en => bat| 230| [opus_mt_en_eu](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_eu_xx.html)  |en => eu| 257| [opus_mt_en_ilo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_ilo_xx.html)  |en => ilo| 284| [opus_mt_en_mkh](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_mkh_xx.html)  |en => mkh| 311| [opus_mt_en_run](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_run_xx.html)  |en => run| 338| [opus_mt_en_tut](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_tut_xx.html)  |en => tut| 365| [opus_mt_eo_nl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_eo_nl_xx.html)  |eo => nl| 392| [opus_mt_es_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_en_xx.html)  |es => en| 419| [opus_mt_es_lt](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_lt_xx.html)  |es => lt| 446| [opus_mt_es_swc](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_swc_xx.html)  |es => swc| 473| [opus_mt_eu_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_eu_en_xx.html)  |eu => en| 500| [opus_mt_fi_ha](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_ha_xx.html)  |fi => ha| 527| [opus_mt_fi_mt](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_mt_xx.html)  |fi => mt| 554| [opus_mt_fi_tn](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_tn_xx.html)  |fi => tn| 581| [opus_mt_fr_bg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_bg_xx.html)  |fr => bg| 608| [opus_mt_fr_iso](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_iso_xx.html)  |fr => iso| 635| [opus_mt_fr_ru](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_ru_xx.html)  |fr => ru| 662| [opus_mt_fr_wls](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_wls_xx.html)  |fr => wls| 689| [opus_mt_grk_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_grk_en_xx.html)  |grk => en| 716| [opus_mt_ho_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ho_en_xx.html)  |ho => en| 743| [opus_mt_ig_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ig_fi_xx.html)  |ig => fi| 770| [opus_mt_it_ar](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_it_ar_xx.html)  |it => ar| 797| [opus_mt_ja_ms](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ja_ms_xx.html)  |ja => ms| 824| [opus_mt_kqn_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_kqn_en_xx.html)  |kqn => en| 851| [opus_mt_lt_it](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lt_it_xx.html)  |lt => it| 878| [opus_mt_lv_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lv_en_xx.html)  |lv => en| 905| [opus_mt_mt_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_mt_es_xx.html)  |mt => es| 932| [opus_mt_no_fr](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_no_fr_xx.html)  |no => fr| 959| [opus_mt_pap_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pap_fi_xx.html)  |pap => fi| 986| [opus_mt_pt_gl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pt_gl_xx.html)  |pt => gl| 1013| [opus_mt_ru_he](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ru_he_xx.html)  |ru => he| 1040| [opus_mt_sk_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sk_es_xx.html)  |sk => es| 1067| [opus_mt_ssp_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ssp_es_xx.html)  |ssp => es| 1094| [opus_mt_sv_gaa](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_gaa_xx.html)  |sv => gaa| 1121| [opus_mt_sv_mos](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_mos_xx.html)  |sv => mos| 1148| [opus_mt_sv_tiv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_tiv_xx.html)  |sv => tiv| 1175| [opus_mt_th_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_th_fr_xx.html)  |th => fr| 1202| [opus_mt_tpi_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tpi_en_xx.html)  |tpi => en| 1229| [opus_mt_tw_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tw_fi_xx.html)  |tw => fi| 1256| [opus_mt_uk_tr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_uk_tr_xx.html)  |uk => tr| 1283| [opus_mt_xh_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_xh_fr_xx.html)  |xh => fr| 1310| [opus_mt_zlw_zlw](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_zlw_zlw_xx.html)  |zlw => zlw| 1337| []()|
# | 15| [opus_mt_am_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_am_sv_xx.html)  |am => sv| 42| [opus_mt_bcl_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bcl_sv_xx.html)  |bcl => sv| 69| [opus_mt_bzs_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bzs_en_xx.html)  |bzs => en| 96| [opus_mt_cpp_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_cpp_en_xx.html)  |cpp => en| 123| [opus_mt_de_ar](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_ar_xx.html)  |de => ar| 150| [opus_mt_de_hil](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_hil_xx.html)  |de => hil| 177| [opus_mt_de_tl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_tl_xx.html)  |de => tl| 204| [opus_mt_en_bcl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_bcl_xx.html)  |en => bcl| 231| [opus_mt_en_euq](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_euq_xx.html)  |en => euq| 258| [opus_mt_en_inc](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_inc_xx.html)  |en => inc| 285| [opus_mt_en_ml](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_ml_xx.html)  |en => ml| 312| [opus_mt_en_rw](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_rw_xx.html)  |en => rw| 339| [opus_mt_en_tvl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_tvl_xx.html)  |en => tvl| 366| [opus_mt_eo_pl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_eo_pl_xx.html)  |eo => pl| 393| [opus_mt_es_eo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_eo_xx.html)  |es => eo| 420| [opus_mt_es_lua](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_lua_xx.html)  |es => lua| 447| [opus_mt_es_tl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_tl_xx.html)  |es => tl| 474| [opus_mt_eu_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_eu_es_xx.html)  |eu => es| 501| [opus_mt_fi_he](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_he_xx.html)  |fi => he| 528| [opus_mt_fi_niu](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_niu_xx.html)  |fi => niu| 555| [opus_mt_fi_to](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_to_xx.html)  |fi => to| 582| [opus_mt_fr_bi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_bi_xx.html)  |fr => bi| 609| [opus_mt_fr_kg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_kg_xx.html)  |fr => kg| 636| [opus_mt_fr_run](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_fr_run_xx.html)  |fr => run| 663| [opus_mt_fr_xh](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_xh_xx.html)  |fr => xh| 690| [opus_mt_guw_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_guw_de_xx.html)  |guw => de| 717| [opus_mt_hr_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_hr_es_xx.html)  |hr => es| 744| [opus_mt_ig_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ig_fr_xx.html)  |ig => fr| 771| [opus_mt_it_bg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_it_bg_xx.html)  |it => bg| 798| [opus_mt_ja_nl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ja_nl_xx.html)  |ja => nl| 825| [opus_mt_kqn_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_kqn_es_xx.html)  |kqn => es| 852| [opus_mt_lt_pl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lt_pl_xx.html)  |lt => pl| 879| [opus_mt_lv_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lv_es_xx.html)  |lv => es| 906| [opus_mt_mt_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_mt_fi_xx.html)  |mt => fi| 933| [opus_mt_no_nl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_no_nl_xx.html)  |no => nl| 960| [opus_mt_pap_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pap_fr_xx.html)  |pap => fr| 987| [opus_mt_pt_tl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pt_tl_xx.html)  |pt => tl| 1014| [opus_mt_ru_hy](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ru_hy_xx.html)  |ru => hy| 1041| [opus_mt_sk_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sk_fi_xx.html)  |sk => fi| 1068| [opus_mt_st_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_st_en_xx.html)  |st => en| 1095| [opus_mt_sv_gil](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_gil_xx.html)  |sv => gil| 1122| [opus_mt_sv_mt](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_mt_xx.html)  |sv => mt| 1149| [opus_mt_sv_tll](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_tll_xx.html)  |sv => tll| 1176| [opus_mt_ti_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ti_en_xx.html)  |ti => en| 1203| [opus_mt_tpi_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tpi_sv_xx.html)  |tpi => sv| 1230| [opus_mt_tw_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tw_fr_xx.html)  |tw => fr| 1257| [opus_mt_umb_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_umb_en_xx.html)  |umb => en| 1284| [opus_mt_xh_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_xh_sv_xx.html)  |xh => sv| 1311| [opus_mt_zne_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_zne_es_xx.html)  |zne => es| 1338| []()|
# | 16| [opus_mt_ar_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ar_de_xx.html)  |ar => de| 43| [opus_mt_be_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_be_es_xx.html)  |be => es| 70| [opus_mt_bzs_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bzs_es_xx.html)  |bzs => es| 97| [opus_mt_crs_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_crs_de_xx.html)  |crs => de| 124| [opus_mt_de_ase](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_ase_xx.html)  |de => ase| 151| [opus_mt_de_ho](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_ho_xx.html)  |de => ho| 178| [opus_mt_de_uk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_uk_xx.html)  |de => uk| 205| [opus_mt_en_bem](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_en_bem_xx.html)  |en => bem| 232| [opus_mt_en_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_fi_xx.html)  |en => fi| 259| [opus_mt_en_ine](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_ine_xx.html)  |en => ine| 286| [opus_mt_en_mos](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_mos_xx.html)  |en => mos| 313| [opus_mt_en_sal](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_sal_xx.html)  |en => sal| 340| [opus_mt_en_tw](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_tw_xx.html)  |en => tw| 367| [opus_mt_eo_pt](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_eo_pt_xx.html)  |eo => pt| 394| [opus_mt_es_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_es_xx.html)  |es => es| 421| [opus_mt_es_lus](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_lus_xx.html)  |es => lus| 448| [opus_mt_es_tll](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_es_tll_xx.html)  |es => tll| 475| [opus_mt_eu_ru](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_eu_ru_xx.html)  |eu => ru| 502| [opus_mt_fi_hil](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_hil_xx.html)  |fi => hil| 529| [opus_mt_fi_nl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_nl_xx.html)  |fi => nl| 556| [opus_mt_fi_toi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_toi_xx.html)  |fi => toi| 583| [opus_mt_fr_bzs](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_bzs_xx.html)  |fr => bzs| 610| [opus_mt_fr_kqn](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_kqn_xx.html)  |fr => kqn| 637| [opus_mt_fr_rw](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_rw_xx.html)  |fr => rw| 664| [opus_mt_fr_yap](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_yap_xx.html)  |fr => yap| 691| [opus_mt_guw_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_guw_en_xx.html)  |guw => en| 718| [opus_mt_hr_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_hr_fi_xx.html)  |hr => fi| 745| [opus_mt_ig_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ig_sv_xx.html)  |ig => sv| 772| [opus_mt_it_ca](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_it_ca_xx.html)  |it => ca| 799| [opus_mt_ja_pl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ja_pl_xx.html)  |ja => pl| 826| [opus_mt_kqn_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_kqn_fr_xx.html)  |kqn => fr| 853| [opus_mt_lt_ru](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lt_ru_xx.html)  |lt => ru| 880| [opus_mt_lv_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lv_fi_xx.html)  |lv => fi| 907| [opus_mt_mt_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_mt_fr_xx.html)  |mt => fr| 934| [opus_mt_no_no](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_no_no_xx.html)  |no => no| 961| [opus_mt_phi_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_phi_en_xx.html)  |phi => en| 988| [opus_mt_pt_uk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pt_uk_xx.html)  |pt => uk| 1015| [opus_mt_ru_lt](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ru_lt_xx.html)  |ru => lt| 1042| [opus_mt_sk_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sk_fr_xx.html)  |sk => fr| 1069| [opus_mt_st_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_st_es_xx.html)  |st => es| 1096| [opus_mt_sv_guw](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_guw_xx.html)  |sv => guw| 1123| [opus_mt_sv_niu](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_niu_xx.html)  |sv => niu| 1150| [opus_mt_sv_tn](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_tn_xx.html)  |sv => tn| 1177| [opus_mt_tiv_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tiv_en_xx.html)  |tiv => en| 1204| [opus_mt_tr_ar](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tr_ar_xx.html)  |tr => ar| 1231| [opus_mt_tw_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tw_sv_xx.html)  |tw => sv| 1258| [opus_mt_ur_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ur_en_xx.html)  |ur => en| 1285| [opus_mt_yap_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_yap_en_xx.html)  |yap => en| 1312| [opus_mt_zne_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_zne_fi_xx.html)  |zne => fi| 1339| []()|
# | 17| [opus_mt_ar_el](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ar_el_xx.html)  |ar => el| 44| [opus_mt_bem_en](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_bem_en_xx.html)  |bem => en| 71| [opus_mt_bzs_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bzs_fi_xx.html)  |bzs => fi| 98| [opus_mt_crs_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_crs_en_xx.html)  |crs => en| 125| [opus_mt_de_bcl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_bcl_xx.html)  |de => bcl| 152| [opus_mt_de_hr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_hr_xx.html)  |de => hr| 179| [opus_mt_de_vi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_vi_xx.html)  |de => vi| 206| [opus_mt_en_ber](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_ber_xx.html)  |en => ber| 233| [opus_mt_en_fiu](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_fiu_xx.html)  |en => fiu| 260| [opus_mt_en_is](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_is_xx.html)  |en => is| 287| [opus_mt_en_mr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_mr_xx.html)  |en => mr| 314| [opus_mt_en_sem](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_sem_xx.html)  |en => sem| 341| [opus_mt_en_ty](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_ty_xx.html)  |en => ty| 368| [opus_mt_eo_ro](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_eo_ro_xx.html)  |eo => ro| 395| [opus_mt_es_et](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_et_xx.html)  |es => et| 422| [opus_mt_es_mfs](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_mfs_xx.html)  |es => mfs| 449| [opus_mt_es_tn](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_tn_xx.html)  |es => tn| 476| [opus_mt_euq_en](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_euq_en_xx.html)  |euq => en| 503| [opus_mt_fi_ho](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_ho_xx.html)  |fi => ho| 530| [opus_mt_fi_no](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_no_xx.html)  |fi => no| 557| [opus_mt_fi_tpi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_tpi_xx.html)  |fi => tpi| 584| [opus_mt_fr_ca](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_ca_xx.html)  |fr => ca| 611| [opus_mt_fr_kwy](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_kwy_xx.html)  |fr => kwy| 638| [opus_mt_fr_sg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_sg_xx.html)  |fr => sg| 665| [opus_mt_fr_yo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_yo_xx.html)  |fr => yo| 692| [opus_mt_guw_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_guw_es_xx.html)  |guw => es| 719| [opus_mt_hr_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_hr_fr_xx.html)  |hr => fr| 746| [opus_mt_iir_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_iir_en_xx.html)  |iir => en| 773| [opus_mt_it_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_it_de_xx.html)  |it => de| 800| [opus_mt_ja_pt](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ja_pt_xx.html)  |ja => pt| 827| [opus_mt_kqn_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_kqn_sv_xx.html)  |kqn => sv| 854| [opus_mt_lt_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lt_sv_xx.html)  |lt => sv| 881| [opus_mt_lv_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lv_fr_xx.html)  |lv => fr| 908| [opus_mt_mt_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_mt_sv_xx.html)  |mt => sv| 935| [opus_mt_no_pl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_no_pl_xx.html)  |no => pl| 962| [opus_mt_pis_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pis_en_xx.html)  |pis => en| 989| [opus_mt_rn_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_rn_de_xx.html)  |rn => de| 1016| [opus_mt_ru_lv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ru_lv_xx.html)  |ru => lv| 1043| [opus_mt_sk_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sk_sv_xx.html)  |sk => sv| 1070| [opus_mt_st_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_st_fi_xx.html)  |st => fi| 1097| [opus_mt_sv_ha](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_ha_xx.html)  |sv => ha| 1124| [opus_mt_sv_nl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_nl_xx.html)  |sv => nl| 1151| [opus_mt_sv_to](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_to_xx.html)  |sv => to| 1178| [opus_mt_tiv_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tiv_fr_xx.html)  |tiv => fr| 1205| [opus_mt_tr_az](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tr_az_xx.html)  |tr => az| 1232| [opus_mt_ty_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ty_es_xx.html)  |ty => es| 1259| [opus_mt_urj_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_urj_en_xx.html)  |urj => en| 1286| [opus_mt_yap_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_yap_fr_xx.html)  |yap => fr| 1313| [opus_mt_zne_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_zne_fr_xx.html)  |zne => fr| 1340| []()|
# | 18| [opus_mt_ar_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ar_en_xx.html)  |ar => en| 45| [opus_mt_bem_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bem_es_xx.html)  |bem => es| 72| [opus_mt_bzs_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bzs_fr_xx.html)  |bzs => fr| 99| [opus_mt_crs_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_crs_es_xx.html)  |crs => es| 126| [opus_mt_de_bg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_bg_xx.html)  |de => bg| 153| [opus_mt_de_ht](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_ht_xx.html)  |de => ht| 180| [opus_mt_dra_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_dra_en_xx.html)  |dra => en| 207| [opus_mt_en_bg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_bg_xx.html)  |en => bg| 234| [opus_mt_en_fj](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_fj_xx.html)  |en => fj| 261| [opus_mt_en_iso](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_iso_xx.html)  |en => iso| 288| [opus_mt_en_mt](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_mt_xx.html)  |en => mt| 315| [opus_mt_en_sg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_sg_xx.html)  |en => sg| 342| [opus_mt_en_uk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_uk_xx.html)  |en => uk| 369| [opus_mt_eo_ru](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_eo_ru_xx.html)  |eo => ru| 396| [opus_mt_es_eu](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_eu_xx.html)  |es => eu| 423| [opus_mt_es_mk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_mk_xx.html)  |es => mk| 450| [opus_mt_es_to](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_es_to_xx.html)  |es => to| 477| [opus_mt_fi_af](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_af_xx.html)  |fi => af| 504| [opus_mt_fi_hr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_hr_xx.html)  |fi => hr| 531| [opus_mt_fi_nso](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_nso_xx.html)  |fi => nso| 558| [opus_mt_fi_tr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_tr_xx.html)  |fi => tr| 585| [opus_mt_fr_ceb](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_ceb_xx.html)  |fr => ceb| 612| [opus_mt_fr_lg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_lg_xx.html)  |fr => lg| 639| [opus_mt_fr_sk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_sk_xx.html)  |fr => sk| 666| [opus_mt_fr_zne](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_zne_xx.html)  |fr => zne| 693| [opus_mt_guw_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_guw_fi_xx.html)  |guw => fi| 720| [opus_mt_hr_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_hr_sv_xx.html)  |hr => sv| 747| [opus_mt_iir_iir](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_iir_iir_xx.html)  |iir => iir| 774| [opus_mt_it_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_it_en_xx.html)  |it => en| 801| [opus_mt_ja_ru](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ja_ru_xx.html)  |ja => ru| 828| [opus_mt_kwn_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_kwn_en_xx.html)  |kwn => en| 855| [opus_mt_lt_tr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lt_tr_xx.html)  |lt => tr| 882| [opus_mt_lv_ru](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lv_ru_xx.html)  |lv => ru| 909| [opus_mt_mul_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_mul_en_xx.html)  |mul => en| 936| [opus_mt_no_ru](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_no_ru_xx.html)  |no => ru| 963| [opus_mt_pis_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pis_es_xx.html)  |pis => es| 990| [opus_mt_rn_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_rn_en_xx.html)  |rn => en| 1017| [opus_mt_ru_no](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ru_no_xx.html)  |ru => no| 1044| [opus_mt_sl_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sl_es_xx.html)  |sl => es| 1071| [opus_mt_st_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_st_fr_xx.html)  |st => fr| 1098| [opus_mt_sv_he](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_he_xx.html)  |sv => he| 1125| [opus_mt_sv_no](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_no_xx.html)  |sv => no| 1152| [opus_mt_sv_toi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_toi_xx.html)  |sv => toi| 1179| [opus_mt_tiv_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tiv_sv_xx.html)  |tiv => sv| 1206| [opus_mt_tr_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tr_en_xx.html)  |tr => en| 1233| [opus_mt_ty_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ty_fi_xx.html)  |ty => fi| 1260| [opus_mt_urj_urj](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_urj_urj_xx.html)  |urj => urj| 1287| [opus_mt_yap_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_yap_sv_xx.html)  |yap => sv| 1314| [opus_mt_zne_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_zne_sv_xx.html)  |zne => sv| 1341| []()|
# | 19| [opus_mt_ar_eo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ar_eo_xx.html)  |ar => eo| 46| [opus_mt_bem_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bem_fi_xx.html)  |bem => fi| 73| [opus_mt_bzs_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bzs_sv_xx.html)  |bzs => sv| 100| [opus_mt_crs_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_crs_fi_xx.html)  |crs => fi| 127| [opus_mt_de_bi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_bi_xx.html)  |de => bi| 154| [opus_mt_de_hu](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_hu_xx.html)  |de => hu| 181| [opus_mt_ee_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ee_de_xx.html)  |ee => de| 208| [opus_mt_en_bi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_bi_xx.html)  |en => bi| 235| [opus_mt_en_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_fr_xx.html)  |en => fr| 262| [opus_mt_en_it](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_it_xx.html)  |en => it| 289| [opus_mt_en_mul](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_mul_xx.html)  |en => mul| 316| [opus_mt_en_sit](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_sit_xx.html)  |en => sit| 343| [opus_mt_en_umb](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_umb_xx.html)  |en => umb| 370| [opus_mt_eo_sh](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_eo_sh_xx.html)  |eo => sh| 397| [opus_mt_es_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_fi_xx.html)  |es => fi| 424| [opus_mt_es_mt](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_mt_xx.html)  |es => mt| 451| [opus_mt_es_tpi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_tpi_xx.html)  |es => tpi| 478| [opus_mt_fi_bcl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_bcl_xx.html)  |fi => bcl| 505| [opus_mt_fi_ht](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_ht_xx.html)  |fi => ht| 532| [opus_mt_fi_ny](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_ny_xx.html)  |fi => ny| 559| [opus_mt_fi_ts](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_ts_xx.html)  |fi => ts| 586| [opus_mt_fr_crs](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_crs_xx.html)  |fr => crs| 613| [opus_mt_fr_ln](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_ln_xx.html)  |fr => ln| 640| [opus_mt_fr_sl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_sl_xx.html)  |fr => sl| 667| [opus_mt_fse_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fse_fi_xx.html)  |fse => fi| 694| [opus_mt_guw_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_guw_fr_xx.html)  |guw => fr| 721| [opus_mt_ht_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ht_en_xx.html)  |ht => en| 748| [opus_mt_ilo_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ilo_de_xx.html)  |ilo => de| 775| [opus_mt_it_eo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_it_eo_xx.html)  |it => eo| 802| [opus_mt_ja_sh](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ja_sh_xx.html)  |ja => sh| 829| [opus_mt_kwy_en](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_kwy_en_xx.html)  |kwy => en| 856| [opus_mt_lu_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lu_en_xx.html)  |lu => en| 883| [opus_mt_lv_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lv_sv_xx.html)  |lv => sv| 910| [opus_mt_ng_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ng_en_xx.html)  |ng => en| 937| [opus_mt_no_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_no_sv_xx.html)  |no => sv| 964| [opus_mt_pis_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pis_fi_xx.html)  |pis => fi| 991| [opus_mt_rn_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_rn_es_xx.html)  |rn => es| 1018| [opus_mt_ru_sl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ru_sl_xx.html)  |ru => sl| 1045| [opus_mt_sl_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sl_fi_xx.html)  |sl => fi| 1072| [opus_mt_st_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_st_sv_xx.html)  |st => sv| 1099| [opus_mt_sv_hil](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_hil_xx.html)  |sv => hil| 1126| [opus_mt_sv_nso](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_nso_xx.html)  |sv => nso| 1153| [opus_mt_sv_tpi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_tpi_xx.html)  |sv => tpi| 1180| [opus_mt_tl_de](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_tl_de_xx.html)  |tl => de| 1207| [opus_mt_tr_eo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tr_eo_xx.html)  |tr => eo| 1234| [opus_mt_ty_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ty_fr_xx.html)  |ty => fr| 1261| [opus_mt_ve_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ve_en_xx.html)  |ve => en| 1288| [opus_mt_yo_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_yo_en_xx.html)  |yo => en| 1315| []()| 1342| []()|
# | 20| [opus_mt_ar_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ar_es_xx.html)  |ar => es| 47| [opus_mt_bem_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bem_fr_xx.html)  |bem => fr| 74| [opus_mt_ca_de](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_ca_de_xx.html)  |ca => de| 101| [opus_mt_crs_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_crs_fr_xx.html)  |crs => fr| 128| [opus_mt_de_bzs](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_bzs_xx.html)  |de => bzs| 155| [opus_mt_de_ig](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_ig_xx.html)  |de => ig| 182| [opus_mt_ee_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ee_en_xx.html)  |ee => en| 209| [opus_mt_en_bnt](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_bnt_xx.html)  |en => bnt| 236| [opus_mt_en_ga](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_en_ga_xx.html)  |en => ga| 263| [opus_mt_en_itc](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_itc_xx.html)  |en => itc| 290| [opus_mt_en_ng](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_ng_xx.html)  |en => ng| 317| [opus_mt_en_sk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_sk_xx.html)  |en => sk| 344| [opus_mt_en_ur](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_ur_xx.html)  |en => ur| 371| [opus_mt_eo_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_eo_sv_xx.html)  |eo => sv| 398| [opus_mt_es_fj](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_fj_xx.html)  |es => fj| 425| [opus_mt_es_niu](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_niu_xx.html)  |es => niu| 452| [opus_mt_es_tvl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_tvl_xx.html)  |es => tvl| 479| [opus_mt_fi_bem](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_bem_xx.html)  |fi => bem| 506| [opus_mt_fi_hu](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_hu_xx.html)  |fi => hu| 533| [opus_mt_fi_pag](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_pag_xx.html)  |fi => pag| 560| [opus_mt_fi_tvl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_tvl_xx.html)  |fi => tvl| 587| [opus_mt_fr_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_de_xx.html)  |fr => de| 614| [opus_mt_fr_loz](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_loz_xx.html)  |fr => loz| 641| [opus_mt_fr_sm](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_sm_xx.html)  |fr => sm| 668| [opus_mt_ga_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ga_en_xx.html)  |ga => en| 695| [opus_mt_guw_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_guw_sv_xx.html)  |guw => sv| 722| [opus_mt_ht_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ht_es_xx.html)  |ht => es| 749| [opus_mt_ilo_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ilo_en_xx.html)  |ilo => en| 776| [opus_mt_it_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_it_es_xx.html)  |it => es| 803| [opus_mt_ja_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ja_sv_xx.html)  |ja => sv| 830| [opus_mt_kwy_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_kwy_fr_xx.html)  |kwy => fr| 857| [opus_mt_lu_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lu_es_xx.html)  |lu => es| 884| [opus_mt_mfe_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_mfe_en_xx.html)  |mfe => en| 911| [opus_mt_nic_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_nic_en_xx.html)  |nic => en| 938| [opus_mt_no_uk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_no_uk_xx.html)  |no => uk| 965| [opus_mt_pis_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pis_fr_xx.html)  |pis => fr| 992| [opus_mt_rn_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_rn_fr_xx.html)  |rn => fr| 1019| [opus_mt_ru_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ru_sv_xx.html)  |ru => sv| 1046| [opus_mt_sl_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sl_fr_xx.html)  |sl => fr| 1073| [opus_mt_sv_af](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_af_xx.html)  |sv => af| 1100| [opus_mt_sv_ho](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_ho_xx.html)  |sv => ho| 1127| [opus_mt_sv_ny](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_ny_xx.html)  |sv => ny| 1154| [opus_mt_sv_ts](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_ts_xx.html)  |sv => ts| 1181| [opus_mt_tl_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tl_en_xx.html)  |tl => en| 1208| [opus_mt_tr_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tr_es_xx.html)  |tr => es| 1235| [opus_mt_ty_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ty_sv_xx.html)  |ty => sv| 1262| [opus_mt_ve_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ve_es_xx.html)  |ve => es| 1289| [opus_mt_yo_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_yo_es_xx.html)  |yo => es| 1316| []()| 1343| []()|
# | 21| [opus_mt_ar_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ar_fr_xx.html)  |ar => fr| 48| [opus_mt_bem_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bem_sv_xx.html)  |bem => sv| 75| [opus_mt_ca_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ca_en_xx.html)  |ca => en| 102| [opus_mt_crs_sv](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_crs_sv_xx.html)  |crs => sv| 129| [opus_mt_de_ca](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_ca_xx.html)  |de => ca| 156| [opus_mt_de_ilo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_ilo_xx.html)  |de => ilo| 183| [opus_mt_ee_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ee_es_xx.html)  |ee => es| 210| [opus_mt_en_bzs](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_bzs_xx.html)  |en => bzs| 237| [opus_mt_en_gaa](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_gaa_xx.html)  |en => gaa| 264| [opus_mt_en_jap](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_jap_xx.html)  |en => jap| 291| [opus_mt_en_nic](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_nic_xx.html)  |en => nic| 318| [opus_mt_en_sla](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_sla_xx.html)  |en => sla| 345| [opus_mt_en_urj](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_urj_xx.html)  |en => urj| 372| [opus_mt_es_aed](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_aed_xx.html)  |es => aed| 399| [opus_mt_es_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_fr_xx.html)  |es => fr| 426| [opus_mt_es_nl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_nl_xx.html)  |es => nl| 453| [opus_mt_es_tw](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_tw_xx.html)  |es => tw| 480| [opus_mt_fi_bg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_bg_xx.html)  |fi => bg| 507| [opus_mt_fi_id](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_id_xx.html)  |fi => id| 534| [opus_mt_fi_pap](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_pap_xx.html)  |fi => pap| 561| [opus_mt_fi_tw](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_tw_xx.html)  |fi => tw| 588| [opus_mt_fr_ee](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_ee_xx.html)  |fr => ee| 615| [opus_mt_fr_lu](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_lu_xx.html)  |fr => lu| 642| [opus_mt_fr_sn](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_sn_xx.html)  |fr => sn| 669| [opus_mt_gaa_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_gaa_de_xx.html)  |gaa => de| 696| [opus_mt_gv_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_gv_en_xx.html)  |gv => en| 723| [opus_mt_ht_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ht_fi_xx.html)  |ht => fi| 750| [opus_mt_ilo_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ilo_es_xx.html)  |ilo => es| 777| [opus_mt_it_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_it_fr_xx.html)  |it => fr| 804| [opus_mt_ja_tr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ja_tr_xx.html)  |ja => tr| 831| [opus_mt_kwy_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_kwy_sv_xx.html)  |kwy => sv| 858| [opus_mt_lu_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lu_fi_xx.html)  |lu => fi| 885| [opus_mt_mfe_es](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_mfe_es_xx.html)  |mfe => es| 912| [opus_mt_niu_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_niu_de_xx.html)  |niu => de| 939| [opus_mt_nso_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_nso_de_xx.html)  |nso => de| 966| [opus_mt_pis_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pis_sv_xx.html)  |pis => sv| 993| [opus_mt_rn_ru](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_rn_ru_xx.html)  |rn => ru| 1020| [opus_mt_ru_uk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ru_uk_xx.html)  |ru => uk| 1047| [opus_mt_sl_ru](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sl_ru_xx.html)  |sl => ru| 1074| [opus_mt_sv_ase](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_ase_xx.html)  |sv => ase| 1101| [opus_mt_sv_hr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_hr_xx.html)  |sv => hr| 1128| [opus_mt_sv_pag](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_pag_xx.html)  |sv => pag| 1155| [opus_mt_sv_tum](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_tum_xx.html)  |sv => tum| 1182| [opus_mt_tl_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tl_es_xx.html)  |tl => es| 1209| [opus_mt_tr_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tr_fr_xx.html)  |tr => fr| 1236| [opus_mt_tzo_es](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_tzo_es_xx.html)  |tzo => es| 1263| [opus_mt_vi_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_vi_de_xx.html)  |vi => de| 1290| [opus_mt_yo_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_yo_fi_xx.html)  |yo => fi| 1317| []()| 1344| []()|
# | 22| [opus_mt_ar_he](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ar_he_xx.html)  |ar => he| 49| [opus_mt_ber_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ber_en_xx.html)  |ber => en| 76| [opus_mt_ca_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ca_es_xx.html)  |ca => es| 103| [opus_mt_cs_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_cs_de_xx.html)  |cs => de| 130| [opus_mt_de_crs](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_crs_xx.html)  |de => crs| 157| [opus_mt_de_is](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_is_xx.html)  |de => is| 184| [opus_mt_ee_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ee_fi_xx.html)  |ee => fi| 211| [opus_mt_en_ca](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_ca_xx.html)  |en => ca| 238| [opus_mt_en_gem](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_gem_xx.html)  |en => gem| 265| [opus_mt_en_kg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_kg_xx.html)  |en => kg| 292| [opus_mt_en_niu](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_niu_xx.html)  |en => niu| 319| [opus_mt_en_sm](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_sm_xx.html)  |en => sm| 346| [opus_mt_en_vi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_vi_xx.html)  |en => vi| 373| [opus_mt_es_af](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_af_xx.html)  |es => af| 400| [opus_mt_es_gaa](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_gaa_xx.html)  |es => gaa| 427| [opus_mt_es_no](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_no_xx.html)  |es => no| 454| [opus_mt_es_ty](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_ty_xx.html)  |es => ty| 481| [opus_mt_fi_bzs](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_bzs_xx.html)  |fi => bzs| 508| [opus_mt_fi_ig](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_ig_xx.html)  |fi => ig| 535| [opus_mt_fi_pis](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_pis_xx.html)  |fi => pis| 562| [opus_mt_fi_ty](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_ty_xx.html)  |fi => ty| 589| [opus_mt_fr_efi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_efi_xx.html)  |fr => efi| 616| [opus_mt_fr_lua](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_lua_xx.html)  |fr => lua| 643| [opus_mt_fr_srn](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_srn_xx.html)  |fr => srn| 670| [opus_mt_gaa_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_gaa_en_xx.html)  |gaa => en| 697| [opus_mt_ha_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ha_en_xx.html)  |ha => en| 724| [opus_mt_ht_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ht_fr_xx.html)  |ht => fr| 751| [opus_mt_ilo_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ilo_fi_xx.html)  |ilo => fi| 778| [opus_mt_it_is](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_it_is_xx.html)  |it => is| 805| [opus_mt_ja_vi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ja_vi_xx.html)  |ja => vi| 832| [opus_mt_lg_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lg_en_xx.html)  |lg => en| 859| [opus_mt_lu_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lu_fr_xx.html)  |lu => fr| 886| [opus_mt_mfs_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_mfs_es_xx.html)  |mfs => es| 913| [opus_mt_niu_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_niu_en_xx.html)  |niu => en| 940| [opus_mt_nso_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_nso_en_xx.html)  |nso => en| 967| [opus_mt_pl_ar](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pl_ar_xx.html)  |pl => ar| 994| [opus_mt_rnd_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_rnd_en_xx.html)  |rnd => en| 1021| [opus_mt_ru_vi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ru_vi_xx.html)  |ru => vi| 1048| [opus_mt_sl_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sl_sv_xx.html)  |sl => sv| 1075| [opus_mt_sv_bcl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_bcl_xx.html)  |sv => bcl| 1102| [opus_mt_sv_ht](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_ht_xx.html)  |sv => ht| 1129| [opus_mt_sv_pap](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_pap_xx.html)  |sv => pap| 1156| [opus_mt_sv_tvl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_tvl_xx.html)  |sv => tvl| 1183| [opus_mt_tl_pt](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tl_pt_xx.html)  |tl => pt| 1210| [opus_mt_tr_lt](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tr_lt_xx.html)  |tr => lt| 1237| [opus_mt_uk_bg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_uk_bg_xx.html)  |uk => bg| 1264| [opus_mt_vi_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_vi_en_xx.html)  |vi => en| 1291| [opus_mt_yo_fr](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_yo_fr_xx.html)  |yo => fr| 1318| []()| 1345| []()|
# | 23| [opus_mt_ar_it](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ar_it_xx.html)  |ar => it| 50| [opus_mt_ber_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ber_es_xx.html)  |ber => es| 77| [opus_mt_ca_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ca_fr_xx.html)  |ca => fr| 104| [opus_mt_cs_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_cs_en_xx.html)  |cs => en| 131| [opus_mt_de_cs](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_cs_xx.html)  |de => cs| 158| [opus_mt_de_iso](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_iso_xx.html)  |de => iso| 185| [opus_mt_ee_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ee_fr_xx.html)  |ee => fr| 212| [opus_mt_en_ceb](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_ceb_xx.html)  |en => ceb| 239| [opus_mt_en_gil](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_gil_xx.html)  |en => gil| 266| [opus_mt_en_kj](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_kj_xx.html)  |en => kj| 293| [opus_mt_en_nl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_nl_xx.html)  |en => nl| 320| [opus_mt_en_sn](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_sn_xx.html)  |en => sn| 347| [opus_mt_en_xh](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_xh_xx.html)  |en => xh| 374| [opus_mt_es_ar](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_ar_xx.html)  |es => ar| 401| [opus_mt_es_gil](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_gil_xx.html)  |es => gil| 428| [opus_mt_es_nso](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_nso_xx.html)  |es => nso| 455| [opus_mt_es_tzo](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_es_tzo_xx.html)  |es => tzo| 482| [opus_mt_fi_ceb](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_fi_ceb_xx.html)  |fi => ceb| 509| [opus_mt_fi_ilo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_ilo_xx.html)  |fi => ilo| 536| [opus_mt_fi_pon](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_pon_xx.html)  |fi => pon| 563| [opus_mt_fi_uk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_uk_xx.html)  |fi => uk| 590| [opus_mt_fr_el](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_el_xx.html)  |fr => el| 617| [opus_mt_fr_lue](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_lue_xx.html)  |fr => lue| 644| [opus_mt_fr_st](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_st_xx.html)  |fr => st| 671| [opus_mt_gaa_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_gaa_es_xx.html)  |gaa => es| 698| [opus_mt_ha_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ha_es_xx.html)  |ha => es| 725| [opus_mt_ht_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ht_sv_xx.html)  |ht => sv| 752| [opus_mt_ilo_sv](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_ilo_sv_xx.html)  |ilo => sv| 779| [opus_mt_it_lt](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_it_lt_xx.html)  |it => lt| 806| [opus_mt_jap_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_jap_en_xx.html)  |jap => en| 833| [opus_mt_lg_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lg_es_xx.html)  |lg => es| 860| [opus_mt_lu_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lu_sv_xx.html)  |lu => sv| 887| [opus_mt_mg_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_mg_en_xx.html)  |mg => en| 914| [opus_mt_niu_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_niu_es_xx.html)  |niu => es| 941| [opus_mt_nso_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_nso_es_xx.html)  |nso => es| 968| [opus_mt_pl_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pl_de_xx.html)  |pl => de| 995| [opus_mt_rnd_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_rnd_fr_xx.html)  |rnd => fr| 1022| [opus_mt_run_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_run_en_xx.html)  |run => en| 1049| [opus_mt_sl_uk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sl_uk_xx.html)  |sl => uk| 1076| [opus_mt_sv_bem](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_bem_xx.html)  |sv => bem| 1103| [opus_mt_sv_hu](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_hu_xx.html)  |sv => hu| 1130| [opus_mt_sv_pis](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_pis_xx.html)  |sv => pis| 1157| [opus_mt_sv_tw](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_tw_xx.html)  |sv => tw| 1184| [opus_mt_tll_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tll_en_xx.html)  |tll => en| 1211| [opus_mt_tr_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tr_sv_xx.html)  |tr => sv| 1238| [opus_mt_uk_ca](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_uk_ca_xx.html)  |uk => ca| 1265| [opus_mt_vi_eo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_vi_eo_xx.html)  |vi => eo| 1292| [opus_mt_yo_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_yo_sv_xx.html)  |yo => sv| 1319| []()| 1346| []()|
# | 24| [opus_mt_ar_pl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ar_pl_xx.html)  |ar => pl| 51| [opus_mt_ber_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ber_fr_xx.html)  |ber => fr| 78| [opus_mt_ca_it](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ca_it_xx.html)  |ca => it| 105| [opus_mt_cs_eo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_cs_eo_xx.html)  |cs => eo| 132| [opus_mt_de_da](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_da_xx.html)  |de => da| 159| [opus_mt_de_it](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_it_xx.html)  |de => it| 186| [opus_mt_ee_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ee_sv_xx.html)  |ee => sv| 213| [opus_mt_en_cel](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_cel_xx.html)  |en => cel| 240| [opus_mt_en_gl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_gl_xx.html)  |en => gl| 267| [opus_mt_en_kqn](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_kqn_xx.html)  |en => kqn| 294| [opus_mt_en_nso](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_nso_xx.html)  |en => nso| 321| [opus_mt_en_sq](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_sq_xx.html)  |en => sq| 348| [opus_mt_en_zh](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_zh_xx.html)  |en => zh| 375| [opus_mt_es_ase](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_ase_xx.html)  |es => ase| 402| [opus_mt_es_gl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_gl_xx.html)  |es => gl| 429| [opus_mt_es_ny](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_ny_xx.html)  |es => ny| 456| [opus_mt_es_uk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_uk_xx.html)  |es => uk| 483| [opus_mt_fi_crs](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_crs_xx.html)  |fi => crs| 510| [opus_mt_fi_is](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_is_xx.html)  |fi => is| 537| [opus_mt_fi_ro](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_ro_xx.html)  |fi => ro| 564| [opus_mt_fi_ve](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_ve_xx.html)  |fi => ve| 591| [opus_mt_fr_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_en_xx.html)  |fr => en| 618| [opus_mt_fr_lus](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_lus_xx.html)  |fr => lus| 645| [opus_mt_fr_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_sv_xx.html)  |fr => sv| 672| [opus_mt_gaa_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_gaa_fi_xx.html)  |gaa => fi| 699| [opus_mt_ha_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ha_fi_xx.html)  |ha => fi| 726| [opus_mt_hu_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_hu_de_xx.html)  |hu => de| 753| [opus_mt_inc_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_inc_en_xx.html)  |inc => en| 780| [opus_mt_it_ms](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_it_ms_xx.html)  |it => ms| 807| [opus_mt_ka_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ka_en_xx.html)  |ka => en| 834| [opus_mt_lg_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lg_fi_xx.html)  |lg => fi| 861| [opus_mt_lua_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lua_en_xx.html)  |lua => en| 888| [opus_mt_mg_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_mg_es_xx.html)  |mg => es| 915| [opus_mt_niu_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_niu_fi_xx.html)  |niu => fi| 942| [opus_mt_nso_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_nso_fi_xx.html)  |nso => fi| 969| [opus_mt_pl_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pl_en_xx.html)  |pl => en| 996| [opus_mt_rnd_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_rnd_sv_xx.html)  |rnd => sv| 1023| [opus_mt_run_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_run_es_xx.html)  |run => es| 1050| [opus_mt_sla_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sla_en_xx.html)  |sla => en| 1077| [opus_mt_sv_bg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_bg_xx.html)  |sv => bg| 1104| [opus_mt_sv_id](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_id_xx.html)  |sv => id| 1131| [opus_mt_sv_pon](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_pon_xx.html)  |sv => pon| 1158| [opus_mt_sv_ty](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_ty_xx.html)  |sv => ty| 1185| [opus_mt_tll_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tll_es_xx.html)  |tll => es| 1212| [opus_mt_tr_uk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tr_uk_xx.html)  |tr => uk| 1239| [opus_mt_uk_cs](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_uk_cs_xx.html)  |uk => cs| 1266| [opus_mt_vi_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_vi_es_xx.html)  |vi => es| 1293| [opus_mt_zai_es](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_zai_es_xx.html)  |zai => es| 1320| []()| 1347| []()|
# | 25| [opus_mt_ar_ru](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ar_ru_xx.html)  |ar => ru| 52| [opus_mt_bg_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bg_de_xx.html)  |bg => de| 79| [opus_mt_ca_nl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ca_nl_xx.html)  |ca => nl| 106| [opus_mt_cs_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_cs_fi_xx.html)  |cs => fi| 133| [opus_mt_de_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_de_xx.html)  |de => de| 160| [opus_mt_de_kg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_kg_xx.html)  |de => kg| 187| [opus_mt_efi_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_efi_de_xx.html)  |efi => de| 214| [opus_mt_en_chk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_chk_xx.html)  |en => chk| 241| [opus_mt_en_gmq](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_gmq_xx.html)  |en => gmq| 268| [opus_mt_en_kwn](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_kwn_xx.html)  |en => kwn| 295| [opus_mt_en_ny](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_ny_xx.html)  |en => ny| 322| [opus_mt_en_ss](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_ss_xx.html)  |en => ss| 349| [opus_mt_en_zle](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_zle_xx.html)  |en => zle| 376| [opus_mt_es_bcl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_bcl_xx.html)  |es => bcl| 403| [opus_mt_es_guw](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_guw_xx.html)  |es => guw| 430| [opus_mt_es_pag](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_pag_xx.html)  |es => pag| 457| [opus_mt_es_ve](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_ve_xx.html)  |es => ve| 484| [opus_mt_fi_cs](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_cs_xx.html)  |fi => cs| 511| [opus_mt_fi_iso](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_iso_xx.html)  |fi => iso| 538| [opus_mt_fi_ru](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_ru_xx.html)  |fi => ru| 565| [opus_mt_fi_war](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_war_xx.html)  |fi => war| 592| [opus_mt_fr_eo](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_fr_eo_xx.html)  |fr => eo| 619| [opus_mt_fr_mfe](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_mfe_xx.html)  |fr => mfe| 646| [opus_mt_fr_swc](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_swc_xx.html)  |fr => swc| 673| [opus_mt_gaa_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_gaa_fr_xx.html)  |gaa => fr| 700| [opus_mt_ha_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ha_fr_xx.html)  |ha => fr| 727| [opus_mt_hu_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_hu_en_xx.html)  |hu => en| 754| [opus_mt_inc_inc](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_inc_inc_xx.html)  |inc => inc| 781| [opus_mt_it_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_it_sv_xx.html)  |it => sv| 808| [opus_mt_ka_ru](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ka_ru_xx.html)  |ka => ru| 835| [opus_mt_lg_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lg_fr_xx.html)  |lg => fr| 862| [opus_mt_lua_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lua_es_xx.html)  |lua => es| 889| [opus_mt_mh_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_mh_en_xx.html)  |mh => en| 916| [opus_mt_niu_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_niu_fr_xx.html)  |niu => fr| 943| [opus_mt_nso_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_nso_fr_xx.html)  |nso => fr| 970| [opus_mt_pl_eo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pl_eo_xx.html)  |pl => eo| 997| [opus_mt_ro_eo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ro_eo_xx.html)  |ro => eo| 1024| [opus_mt_run_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_run_sv_xx.html)  |run => sv| 1051| [opus_mt_sla_sla](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sla_sla_xx.html)  |sla => sla| 1078| [opus_mt_sv_bi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_bi_xx.html)  |sv => bi| 1105| [opus_mt_sv_ig](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_ig_xx.html)  |sv => ig| 1132| [opus_mt_sv_rnd](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_rnd_xx.html)  |sv => rnd| 1159| [opus_mt_sv_uk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_uk_xx.html)  |sv => uk| 1186| [opus_mt_tll_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tll_fi_xx.html)  |tll => fi| 1213| [opus_mt_trk_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_trk_en_xx.html)  |trk => en| 1240| [opus_mt_uk_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_uk_de_xx.html)  |uk => de| 1267| [opus_mt_vi_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_vi_fr_xx.html)  |vi => fr| 1294| [opus_mt_zh_bg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_zh_bg_xx.html)  |zh => bg| 1321| []()| 1348| []()|
# | 26| [opus_mt_ar_tr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ar_tr_xx.html)  |ar => tr| 53| [opus_mt_bg_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bg_en_xx.html)  |bg => en| 80| [opus_mt_ca_pt](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ca_pt_xx.html)  |ca => pt| 107| [opus_mt_cs_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_cs_fr_xx.html)  |cs => fr| 134| [opus_mt_de_ee](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_ee_xx.html)  |de => ee| 161| [opus_mt_de_ln](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_ln_xx.html)  |de => ln| 188| [opus_mt_efi_en](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_efi_en_xx.html)  |efi => en| 215| [opus_mt_en_cpf](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_cpf_xx.html)  |en => cpf| 242| [opus_mt_en_gmw](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_gmw_xx.html)  |en => gmw| 269| [opus_mt_en_kwy](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_kwy_xx.html)  |en => kwy| 296| [opus_mt_en_nyk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_nyk_xx.html)  |en => nyk| 323| [opus_mt_en_st](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_st_xx.html)  |en => st| 350| [opus_mt_en_zls](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_zls_xx.html)  |en => zls| 377| [opus_mt_es_ber](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_ber_xx.html)  |es => ber| 404| [opus_mt_es_ha](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_ha_xx.html)  |es => ha| 431| [opus_mt_es_pap](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_pap_xx.html)  |es => pap| 458| [opus_mt_es_vi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_vi_xx.html)  |es => vi| 485| [opus_mt_fi_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_de_xx.html)  |fi => de| 512| [opus_mt_fi_it](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_it_xx.html)  |fi => it| 539| [opus_mt_fi_run](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_run_xx.html)  |fi => run| 566| [opus_mt_fi_wls](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_wls_xx.html)  |fi => wls| 593| [opus_mt_fr_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_es_xx.html)  |fr => es| 620| [opus_mt_fr_mh](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_mh_xx.html)  |fr => mh| 647| [opus_mt_fr_tiv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_tiv_xx.html)  |fr => tiv| 674| [opus_mt_gaa_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_gaa_sv_xx.html)  |gaa => sv| 701| [opus_mt_ha_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ha_sv_xx.html)  |ha => sv| 728| [opus_mt_hu_eo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_hu_eo_xx.html)  |hu => eo| 755| [opus_mt_ine_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ine_en_xx.html)  |ine => en| 782| [opus_mt_it_uk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_it_uk_xx.html)  |it => uk| 809| [opus_mt_kab_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_kab_en_xx.html)  |kab => en| 836| [opus_mt_lg_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lg_sv_xx.html)  |lg => sv| 863| [opus_mt_lua_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lua_fi_xx.html)  |lua => fi| 890| [opus_mt_mh_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_mh_es_xx.html)  |mh => es| 917| [opus_mt_niu_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_niu_sv_xx.html)  |niu => sv| 944| [opus_mt_nso_sv](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_nso_sv_xx.html)  |nso => sv| 971| [opus_mt_pl_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pl_es_xx.html)  |pl => es| 998| [opus_mt_ro_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ro_fi_xx.html)  |ro => fi| 1025| [opus_mt_rw_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_rw_en_xx.html)  |rw => en| 1052| [opus_mt_sm_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sm_en_xx.html)  |sm => en| 1079| [opus_mt_sv_bzs](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_bzs_xx.html)  |sv => bzs| 1106| [opus_mt_sv_ilo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_ilo_xx.html)  |sv => ilo| 1133| [opus_mt_sv_ro](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_ro_xx.html)  |sv => ro| 1160| [opus_mt_sv_umb](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_umb_xx.html)  |sv => umb| 1187| [opus_mt_tll_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tll_fr_xx.html)  |tll => fr| 1214| [opus_mt_ts_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ts_en_xx.html)  |ts => en| 1241| [opus_mt_uk_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_uk_en_xx.html)  |uk => en| 1268| [opus_mt_vi_it](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_vi_it_xx.html)  |vi => it| 1295| [opus_mt_zh_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_zh_de_xx.html)  |zh => de| 1322| []()| 1349| []()|
# | 27| [opus_mt_art_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_art_en_xx.html)  |art => en| 54| [opus_mt_bg_eo](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_bg_eo_xx.html)  |bg => eo| 81| [opus_mt_ca_uk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ca_uk_xx.html)  |ca => uk| 108| [opus_mt_cs_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_cs_sv_xx.html)  |cs => sv| 135| [opus_mt_de_efi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_efi_xx.html)  |de => efi| 162| [opus_mt_de_loz](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_de_loz_xx.html)  |de => loz| 189| [opus_mt_efi_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_efi_fi_xx.html)  |efi => fi| 216| [opus_mt_en_cpp](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_cpp_xx.html)  |en => cpp| 243| [opus_mt_en_grk](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_grk_xx.html)  |en => grk| 270| [opus_mt_en_lg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_lg_xx.html)  |en => lg| 297| [opus_mt_en_om](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_om_xx.html)  |en => om| 324| [opus_mt_en_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_sv_xx.html)  |en => sv| 351| [opus_mt_en_zlw](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_en_zlw_xx.html)  |en => zlw| 378| [opus_mt_es_bg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_bg_xx.html)  |es => bg| 405| [opus_mt_es_he](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_he_xx.html)  |es => he| 432| [opus_mt_es_pis](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_pis_xx.html)  |es => pis| 459| [opus_mt_es_war](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_es_war_xx.html)  |es => war| 486| [opus_mt_fi_ee](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_ee_xx.html)  |fi => ee| 513| [opus_mt_fi_kg](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_kg_xx.html)  |fi => kg| 540| [opus_mt_fi_rw](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_rw_xx.html)  |fi => rw| 567| [opus_mt_fi_xh](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fi_xh_xx.html)  |fi => xh| 594| [opus_mt_fr_fj](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_fj_xx.html)  |fr => fj| 621| [opus_mt_fr_mos](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_mos_xx.html)  |fr => mos| 648| [opus_mt_fr_tl](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_fr_tl_xx.html)  |fr => tl| 675| [opus_mt_gem_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_gem_en_xx.html)  |gem => en| 702| [opus_mt_he_ar](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_he_ar_xx.html)  |he => ar| 729| [opus_mt_hu_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_hu_fi_xx.html)  |hu => fi| 756| [opus_mt_ine_ine](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ine_ine_xx.html)  |ine => ine| 783| [opus_mt_it_vi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_it_vi_xx.html)  |it => vi| 810| [opus_mt_kg_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_kg_en_xx.html)  |kg => en| 837| [opus_mt_ln_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ln_de_xx.html)  |ln => de| 864| [opus_mt_lua_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_lua_fr_xx.html)  |lua => fr| 891| [opus_mt_mh_fi](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_mh_fi_xx.html)  |mh => fi| 918| [opus_mt_nl_af](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_nl_af_xx.html)  |nl => af| 945| [opus_mt_ny_de](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ny_de_xx.html)  |ny => de| 972| [opus_mt_pl_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_pl_fr_xx.html)  |pl => fr| 999| [opus_mt_ro_fr](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_ro_fr_xx.html)  |ro => fr| 1026| [opus_mt_rw_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_rw_es_xx.html)  |rw => es| 1053| [opus_mt_sm_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sm_es_xx.html)  |sm => es| 1080| [opus_mt_sv_ceb](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_ceb_xx.html)  |sv => ceb| 1107| [opus_mt_sv_is](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_is_xx.html)  |sv => is| 1134| [opus_mt_sv_ru](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_ru_xx.html)  |sv => ru| 1161| [opus_mt_sv_ve](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_sv_ve_xx.html)  |sv => ve| 1188| [opus_mt_tll_sv](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_tll_sv_xx.html)  |tll => sv| 1215| [opus_mt_ts_es](https://nlp.johnsnowlabs.com/2021/06/02/opus_mt_ts_es_xx.html)  |ts => es| 1242| [opus_mt_uk_es](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_uk_es_xx.html)  |uk => es| 1269| [opus_mt_vi_ru](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_vi_ru_xx.html)  |vi => ru| 1296| [opus_mt_zh_en](https://nlp.johnsnowlabs.com/2021/06/01/opus_mt_zh_en_xx.html)  |zh => en| 1323| []()| 1350| []()|

# %% [markdown]
# ## Define Spark NLP pipeline

# %%
documentAssembler = DocumentAssembler() \
    .setInputCol("text") \
    .setOutputCol("document")

sentence = SentenceDetectorDLModel.pretrained("sentence_detector_dl", "xx") \
    .setInputCols("document") \
    .setOutputCol("sentence")

marian = MarianTransformer.pretrained("opus_mt_en_fr","xx") \
    .setInputCols("sentence") \
    .setOutputCol("translation") \
    .setMaxInputLength(128)

pipeline = Pipeline() \
    .setStages([
        documentAssembler,
        sentence,
        marian
    ])
# Out:
# sentence_detector_dl download started this may take some time.
# Approximate size to download 514.9 KB
# [OK!]
# opus_mt_en_fr download started this may take some time.
# Approximate size to download 378.7 MB
# [OK!]

# %%
text = "What is the capital of France? We should know this in french."

data = spark.createDataFrame([[text]]).toDF("text")
result = pipeline.fit(data).transform(data)

result.selectExpr("sentence.result as sentence", "translation.result as translation").show(truncate=False)
# Out:
# +----------------------------------------------------------------+--------------------------------------------------------------------------+
# |sentence                                                        |translation                                                               |
# +----------------------------------------------------------------+--------------------------------------------------------------------------+
# |[What is the capital of France?, We should know this in french.]|[Quelle est la capitale de la France ?, On devrait le savoir en français.]|
# +----------------------------------------------------------------+--------------------------------------------------------------------------+

# %% [markdown]
# ## Light Pipeline version

# %%
pipeline_model = pipeline.fit(spark.createDataFrame([[""]]).toDF('text'))
ligth_model = LightPipeline(pipeline_model)

ligth_result = ligth_model.fullAnnotate(text)
ligth_result[0]["translation"]
# Out:
# [Annotation(document, 0, 36, Quelle est la capitale de la France ?, {'sentence': '0'}, []),
#  Annotation(document, 37, 68, On devrait le savoir en français., {'sentence': '1'}, [])]

# %% [markdown]
# visualize the results

# %%
original_text=[]
translated_text=[]

for i in range(len(ligth_result)):
   sentences = ligth_result[i]['sentence']
   translations = ligth_result[i]['translation']

   for sentence, translation in zip(sentences, translations):
      original_text.append(sentence.result)
      translated_text.append(translation.result)

pd.DataFrame({
    "original_text":original_text,
    "translated_text":translated_text
})
# Out:
#                     original_text                        translated_text
# 0  What is the capital of France?  Quelle est la capitale de la France ?
# 1  We should know this in french.      On devrait le savoir en français.

# %% [markdown]
# # M2M100Transformer

# %% [markdown]
# ## **📜 Background**
#
# `M2M100Transformer`     M2M100 is a multilingual encoder-decoder (seq-to-seq) model trained for Many-to-Many multilingual translation.
#
# The model can directly translate between the 9,900 directions of 100 languages.
#
#
# Languages Covered:
# -----
# Afrikaans (af), Amharic (am), Arabic (ar), Asturian (ast), Azerbaijani (az), Bashkir (ba),
# Belarusian (be), Bulgarian (bg), Bengali (bn), Breton (br), Bosnian (bs), Catalan; Valencian
# (ca), Cebuano (ceb), Czech (cs), Welsh (cy), Danish (da), German (de), Greeek (el), English
# (en), Spanish (es), Estonian (et), Persian (fa), Fulah (ff), Finnish (fi), French (fr),
# Western Frisian (fy), Irish (ga), Gaelic; Scottish Gaelic (gd), Galician (gl), Gujarati (gu),
# Hausa (ha), Hebrew (he), Hindi (hi), Croatian (hr), Haitian; Haitian Creole (ht), Hungarian
# (hu), Armenian (hy), Indonesian (id), Igbo (ig), Iloko (ilo), Icelandic (is), Italian (it),
# Japanese (ja), Javanese (jv), Georgian (ka), Kazakh (kk), Central Khmer (km), Kannada (kn),
# Korean (ko), Luxembourgish; Letzeburgesch (lb), Ganda (lg), Lingala (ln), Lao (lo), Lithuanian
# (lt), Latvian (lv), Malagasy (mg), Macedonian (mk), Malayalam (ml), Mongolian (mn), Marathi
# (mr), Malay (ms), Burmese (my), Nepali (ne), Dutch; Flemish (nl), Norwegian (no), Northern
# Sotho (ns), Occitan (post 1500) (oc), Oriya (or), Panjabi; Punjabi (pa), Polish (pl), Pushto;
# Pashto (ps), Portuguese (pt), Romanian; Moldavian; Moldovan (ro), Russian (ru), Sindhi (sd),
# Sinhala; Sinhalese (si), Slovak (sk), Slovenian (sl), Somali (so), Albanian (sq), Serbian
# (sr), Swati (ss), Sundanese (su), Swedish (sv), Swahili (sw), Tamil (ta), Thai (th), Tagalog
# (tl), Tswana (tn), Turkish (tr), Ukrainian (uk), Urdu (ur), Uzbek (uz), Vietnamese (vi), Wolof
# (wo), Xhosa (xh), Yiddish (yi), Yoruba (yo), Chinese (zh), Zulu (zu)
#
# References
# ----------
# - `Beyond English-Centric Multilingual Machine Translation
#   <https://arxiv.org/pdf/2010.11125.pdf>`__
# - https://github.com/pytorch/fairseq/tree/master/examples/m2m_100
#
# **Paper Abstract:**
#
# * Existing work in translation demonstrated the potential of massively multilingual machine translation by training
# a single model able to translate between any pair of languages. However, much of this work is English-Centric by
# training only on data which was translated from or to English. While this is supported by large sources of
# training data, it does not reflect translation needs worldwide. In this work, we create a true Many-to-Many
# multilingual translation model that can translate directly between any pair of 100 languages. We build and open
# source a training dataset that covers thousands of language directions with supervised data, created through
# large-scale mining. Then, we explore how to effectively increase model capacity through a combination of dense
# scaling and language-specific sparse parameters to create high quality models. Our focus on non-English-Centric
# models brings gains of more than 10 BLEU when directly translating between non-English directions while performing
# competitively to the best single systems of WMT. We open-source our scripts so that others may reproduce the data,
# evaluation, and final M2M-100 model.*

# %% [markdown]
# ## **🖨️ Input/Output Annotation Types**
#
# - Input: `DOCUMENT`
#
# - Output: `DOCUMENT`

# %% [markdown]
# ## **🔎 Parameters**
#
# - `minOutputLength`: Minimum length of the sequence to be generated, by default 0
# - `maxOutputLength`: Maximum length of output text, by default 20
# - `srcLang`: Source Language (Default: `en`)
# - `tgtLang`: Target Language (Default: `fr`)
# - `doSample`: Whether or not to use sampling; use greedy decoding otherwise, by default False
# - `temperature`: The value used to module the next token probabilities, by default 1.0
# - `topP`: he number of highest probability vocabulary tokens to keep for top-k-filtering, by default 50
# - `topP`: Top cumulative probability for vocabulary tokens, by default 1.0, If set to float < 1, only the most probable tokens with probabilities that add up to ``topP`` or higher are kept for generation.
# - `repetitionPenalty`: The parameter for repetition penalty, 1.0 means no Penalty. , by default 1.0
# - `noRepeatNgramSize`: If set to int > 0, all ngrams of that size can only occur once by default 0

# %% [markdown]
# ## Define Spark NLP pipeline

# %% [markdown]
# **A sample text in Chinese - we'll translate it to English**

# %%
document_assembler = DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")

sentence_detector = SentenceDetectorDLModel.pretrained("sentence_detector_dl","xx") \
    .setInputCols(['document'])\
    .setOutputCol('sentence')
# Out:
# sentence_detector_dl download started this may take some time.
# Approximate size to download 514.9 KB
# [OK!]

# %%
source_language = "zh"
target_language = "en"

m2m100_transformer = M2M100Transformer.pretrained() \
    .setInputCols(["sentence"]) \
    .setMaxOutputLength(128) \
    .setOutputCol("generation") \
    .setSrcLang(source_language) \
    .setTgtLang(target_language)

pipeline = Pipeline(
    stages=[
        document_assembler,
        sentence_detector,
        m2m100_transformer
])
# Out:
# m2m100_418M download started this may take some time.
# Approximate size to download 2.8 GB
# [OK!]

# %%
transcripts = [
    ["""除了是北方之王之外，约翰·斯诺还是一位英国医生，也是麻醉和医疗卫生发展的领导者。 他被认为是第一个利用数据治愈 1854 年霍乱爆发的人。"""],
]

df = spark.createDataFrame(transcripts).toDF('text')
df.show(truncate=100)
# Out:
# +----------------------------------------------------------------------------------------------------------------------------------+
# |                                                                                                                              text|
# +----------------------------------------------------------------------------------------------------------------------------------+
# |除了是北方之王之外，约翰·斯诺还是一位英国医生，也是麻醉和医疗卫生发展的领导者。 他被认为是第一个利用数据治愈 1854 年霍乱爆发的人。|
# +----------------------------------------------------------------------------------------------------------------------------------+

# %%
result = pipeline.fit(df).transform(df)
result.select('text',"generation.result").show()
# Out:
# +------------------------------------+--------------------+
# |                                text|              result|
# +------------------------------------+--------------------+
# |除了是北方之王之外，约翰·斯诺还是...|[In addition to b...|
# +------------------------------------+--------------------+

# %% [markdown]
# ## Light Pipeline version

# %% [markdown]
# Let's create the light Pipiline

# %%
pipeline_model = pipeline.fit(spark.createDataFrame([[""]]).toDF('text'))
ligth_model = LightPipeline(pipeline_model)

# %%
text = """除了是北方之王之外，约翰·斯诺还是一位英国医生，也是麻醉和医疗卫生发展的领导者。 他被认为是第一个利用数据治愈 1854 年霍乱爆发的人。"""


res = ligth_model.fullAnnotate(text)

# %% [markdown]
# visualize the results

# %%
print ('Original:', text, '\n\n')

print ('Translated:\n')
for sentence in res[0]['generation']:
  print (sentence.result)
# Out:
# Original: 除了是北方之王之外，约翰·斯诺还是一位英国医生，也是麻醉和医疗卫生发展的领导者。 他被认为是第一个利用数据治愈 1854 年霍乱爆发的人。
#
#
# Translated:
#
# In addition to being the King of the North, John Snow was also a British doctor and a leader in the development of anesthesia and health care. he was considered the first person to use data to cure the 1854 cholera outbreak.

# %%
res
# Out:
# [{'document': [Annotation(document, 0, 68, 除了是北方之王之外，约翰·斯诺还是一位英国医生，也是麻醉和医疗卫生发展的领导者。 他被认为是第一个利用数据治愈 1854 年霍乱爆发的人。, {}, [])],
#   'sentence': [Annotation(document, 0, 68, 除了是北方之王之外，约翰·斯诺还是一位英国医生，也是麻醉和医疗卫生发展的领导者。 他被认为是第一个利用数据治愈 1854 年霍乱爆发的人。, {'sentence': '0'}, [])],
#   'generation': [Annotation(document, 0, 223, In addition to being the King of the North, John Snow was also a British doctor and a leader in the development of anesthesia and health care. he was considered the first person to use data to cure the 1854 cholera outbreak., {'sentence': '0'}, [])]}]
