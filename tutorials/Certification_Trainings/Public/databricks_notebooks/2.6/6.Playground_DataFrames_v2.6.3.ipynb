# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)

# %% [markdown]
# # 6. Spark DataFrames Playground v.2.6.3

# %%
import sparknlp

from sparknlp.base import *
from sparknlp.annotator import *

from pyspark.ml import Pipeline

print("Spark NLP version", sparknlp.version())

spark = sparknlp.start()

print("Apache Spark version:", spark.version)

spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.164.246.233:44266">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.5</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://10.164.246.233:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
document = DocumentAssembler().setInputCol('text').setOutputCol('document')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
tokenizer = Tokenizer().setInputCols('document').setOutputCol('token')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pos = PerceptronModel.pretrained().setInputCols('document', 'token').setOutputCol('pos')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">pos_anc download started this may take some time.
# Approximate size to download 4.3 MB
# [OK!]
# </div>

# %%
pipeline = Pipeline().setStages([document, tokenizer, pos])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# !wget https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/jupyter/annotation/english/spark-nlp-basics/sample-sentences-en.txt
  
dbutils.fs.cp("file:/databricks/driver/sample-sentences-en.txt", "dbfs:/")

# %%
# %fs ls "file:/databricks/driver"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>file:/databricks/driver/conf/</td><td>conf/</td><td>4096</td></tr><tr><td>file:/databricks/driver/logs/</td><td>logs/</td><td>4096</td></tr><tr><td>file:/databricks/driver/__pycache__/</td><td>__pycache__/</td><td>4096</td></tr><tr><td>file:/databricks/driver/aclimdb_test.csv</td><td>aclimdb_test.csv</td><td>32715164</td></tr><tr><td>file:/databricks/driver/news_category_train.csv</td><td>news_category_train.csv</td><td>24032125</td></tr><tr><td>file:/databricks/driver/spam_ham_dataset.csv</td><td>spam_ham_dataset.csv</td><td>5502589</td></tr><tr><td>file:/databricks/driver/dataset_encoder.py</td><td>dataset_encoder.py</td><td>2543</td></tr><tr><td>file:/databricks/driver/sentence_grouper.py</td><td>sentence_grouper.py</td><td>953</td></tr><tr><td>file:/databricks/driver/aclimdb_train.csv</td><td>aclimdb_train.csv</td><td>33497180</td></tr><tr><td>file:/databricks/driver/toxic_train.snappy.parquet</td><td>toxic_train.snappy.parquet</td><td>2767307</td></tr><tr><td>file:/databricks/driver/aclimdb_train.csv.1</td><td>aclimdb_train.csv.1</td><td>33497180</td></tr><tr><td>file:/databricks/driver/ner_model_saver.py</td><td>ner_model_saver.py</td><td>2484</td></tr><tr><td>file:/databricks/driver/title_conference.csv</td><td>title_conference.csv</td><td>188402</td></tr><tr><td>file:/databricks/driver/eng.testa</td><td>eng.testa</td><td>827443</td></tr><tr><td>file:/databricks/driver/ner_logs/</td><td>ner_logs/</td><td>4096</td></tr><tr><td>file:/databricks/driver/ner_model.py</td><td>ner_model.py</td><td>21853</td></tr><tr><td>file:/databricks/driver/ganglia/</td><td>ganglia/</td><td>4096</td></tr><tr><td>file:/databricks/driver/ner_highlighter.py</td><td>ner_highlighter.py</td><td>2000</td></tr><tr><td>file:/databricks/driver/derby.log</td><td>derby.log</td><td>717</td></tr><tr><td>file:/databricks/driver/eng.train</td><td>eng.train</td><td>3283420</td></tr><tr><td>file:/databricks/driver/eventlogs/</td><td>eventlogs/</td><td>4096</td></tr><tr><td>file:/databricks/driver/ner_log_parser.py</td><td>ner_log_parser.py</td><td>3311</td></tr><tr><td>file:/databricks/driver/spam_ham_dataset.csv.1</td><td>spam_ham_dataset.csv.1</td><td>5502589</td></tr><tr><td>file:/databricks/driver/models/</td><td>models/</td><td>4096</td></tr><tr><td>file:/databricks/driver/toxic_test.snappy.parquet</td><td>toxic_test.snappy.parquet</td><td>296833</td></tr><tr><td>file:/databricks/driver/create_graph.py</td><td>create_graph.py</td><td>1542</td></tr><tr><td>file:/databricks/driver/aclimdb_test.csv.1</td><td>aclimdb_test.csv.1</td><td>32715164</td></tr><tr><td>file:/databricks/driver/conll_eval.py</td><td>conll_eval.py</td><td>7431</td></tr><tr><td>file:/databricks/driver/news_category_test.csv</td><td>news_category_test.csv</td><td>1504408</td></tr></tbody></table></div>

# %%
data = spark.read.text('./sample-sentences-en.txt').toDF('text')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+
#                 text|
# +--------------------+
# Peter is a very g...|
# My life in Russia...|
# John and Peter ar...|
# Lucas Nogal Dunbe...|
# Europe is very cu...|
# +--------------------+
#
# </div>

# %%
model = pipeline.fit(data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
result = model.transform(data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
result.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+--------------------+--------------------+
#                 text|            document|               token|                 pos|
# +--------------------+--------------------+--------------------+--------------------+
# Peter is a very g...|[[document, 0, 27...|[[token, 0, 4, Pe...|[[pos, 0, 4, NNP,...|
# My life in Russia...|[[document, 0, 37...|[[token, 0, 1, My...|[[pos, 0, 1, PRP$...|
# John and Peter ar...|[[document, 0, 76...|[[token, 0, 3, Jo...|[[pos, 0, 3, NNP,...|
# Lucas Nogal Dunbe...|[[document, 0, 67...|[[token, 0, 4, Lu...|[[pos, 0, 4, NNP,...|
# Europe is very cu...|[[document, 0, 68...|[[token, 0, 5, Eu...|[[pos, 0, 5, NNP,...|
# +--------------------+--------------------+--------------------+--------------------+
#
# </div>

# %%
stored = result\
  .select('text', 'pos.begin', 'pos.end', 'pos.result', 'pos.metadata')\
  .toDF('text', 'pos_begin', 'pos_end', 'pos_result', 'pos_meta')\
  .cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
stored.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- text: string (nullable = true)
# -- pos_begin: array (nullable = true)
#     |-- element: integer (containsNull = true)
# -- pos_end: array (nullable = true)
#     |-- element: integer (containsNull = true)
# -- pos_result: array (nullable = true)
#     |-- element: string (containsNull = true)
# -- pos_meta: array (nullable = true)
#     |-- element: map (containsNull = true)
#     |    |-- key: string
#     |    |-- value: string (valueContainsNull = true)
#
# </div>

# %%
stored.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+--------------------+--------------------+--------------------+
#                 text|           pos_begin|             pos_end|          pos_result|            pos_meta|
# +--------------------+--------------------+--------------------+--------------------+--------------------+
# Peter is a very g...|[0, 6, 9, 11, 16,...|[4, 7, 9, 14, 19,...|[NNP, VBZ, DT, RB...|[[word -&gt; Peter],...|
# My life in Russia...|[0, 3, 8, 11, 18,...|[1, 6, 9, 16, 19,...|[PRP$, NN, IN, NN...|[[word -&gt; My], [w...|
# John and Peter ar...|[0, 5, 9, 15, 19,...|[3, 7, 13, 17, 26...|[NNP, CC, NNP, VB...|[[word -&gt; John], ...|
# Lucas Nogal Dunbe...|[0, 6, 12, 23, 26...|[4, 10, 21, 24, 2...|[NNP, NNP, NNP, V...|[[word -&gt; Lucas],...|
# Europe is very cu...|[0, 7, 10, 15, 23...|[5, 8, 13, 21, 26...|[NNP, VBZ, RB, RB...|[[word -&gt; Europe]...|
# +--------------------+--------------------+--------------------+--------------------+--------------------+
#
# </div>

# %% [markdown]
# ---------
# ## Spark SQL Functions

# %%
from pyspark.sql.functions import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
stored.filter(array_contains('pos_result', 'VBD')).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+---------+-------+----------+--------+
# text|pos_begin|pos_end|pos_result|pos_meta|
# +----+---------+-------+----------+--------+
# +----+---------+-------+----------+--------+
#
# </div>

# %%
stored.withColumn('token_count', size('pos_result')).select('pos_result', 'token_count').show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-----------+
#           pos_result|token_count|
# +--------------------+-----------+
# [NNP, VBZ, DT, RB...|          7|
# [PRP$, NN, IN, NN...|          8|
# [NNP, CC, NNP, VB...|         15|
# [NNP, NNP, NNP, V...|         15|
# [NNP, VBZ, RB, RB...|         15|
# +--------------------+-----------+
#
# </div>

# %%
stored.select('text', array_max('pos_end')).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+------------------+
#                 text|array_max(pos_end)|
# +--------------------+------------------+
# Peter is a very g...|                27|
# My life in Russia...|                37|
# John and Peter ar...|                76|
# Lucas Nogal Dunbe...|                67|
# Europe is very cu...|                68|
# +--------------------+------------------+
#
# </div>

# %%
stored.withColumn('unique_pos', array_distinct('pos_result')).select('pos_result', 'unique_pos').show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+
#           pos_result|          unique_pos|
# +--------------------+--------------------+
# [NNP, VBZ, DT, RB...|[NNP, VBZ, DT, RB...|
# [PRP$, NN, IN, NN...|[PRP$, NN, IN, NN...|
# [NNP, CC, NNP, VB...|[NNP, CC, VBP, NN...|
# [NNP, NNP, NNP, V...|[NNP, VBZ, DT, RB...|
# [NNP, VBZ, RB, RB...|[NNP, VBZ, RB, JJ...|
# +--------------------+--------------------+
#
# </div>

# %%
stored.groupBy(array_sort(array_distinct('pos_result'))).count().show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------------------------+-----+
# array_sort(array_distinct(pos_result))|count|
# +--------------------------------------+-----+
#                   [., CC, EX, JJ, N...|    1|
#                   [., IN, JJ, NN, N...|    1|
#                   [., CC, DT, IN, J...|    1|
#                   [., DT, IN, JJ, N...|    1|
#                   [., DT, JJ, NN, N...|    1|
# +--------------------------------------+-----+
#
# </div>

# %% [markdown]
# ----------------
# ### SQL Functions with `col`

# %%
from pyspark.sql.functions import col
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
stored.select(col('pos_meta').getItem(0).getItem('word')).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+
# pos_meta[0][word]|
# +-----------------+
#             Peter|
#                My|
#              John|
#             Lucas|
#            Europe|
# +-----------------+
#
# </div>

# %% [markdown]
# -------------
# ### Spark NLP Annotation UDFs

# %%
result.select('pos').show(1, truncate=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# pos                                                                                                                                                                                                                                                                    |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# [[pos, 0, 4, NNP, [word -&gt; Peter], []], [pos, 6, 7, VBZ, [word -&gt; is], []], [pos, 9, 9, DT, [word -&gt; a], []], [pos, 11, 14, RB, [word -&gt; very], []], [pos, 16, 19, JJ, [word -&gt; good], []], [pos, 21, 26, NN, [word -&gt; person], []], [pos, 27, 27, ., [word -&gt; .], []]]|
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 1 row
#
# </div>

# %%
def nn_tokens(annotations):
    nn_annotations = list(
        filter(lambda annotation: annotation.result == 'NN', annotations)
    )
    return list(
        map(lambda nn_annotation: nn_annotation.metadata['word'], nn_annotations)
    )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from sparknlp.functions import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.types import ArrayType, StringType
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
result.select(map_annotations(nn_tokens, ArrayType(StringType()))('pos').alias('nn_tokens')).show(truncate=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+
# nn_tokens|
# +---------+
# [person] |
# [life]   |
# []       |
# [car]    |
# []       |
# +---------+
#
# </div>

# %% [markdown]
# End of Notebook # 6
