# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/spark-nlp-workshop/blob/master/tutorials/Certification_Trainings/Public/14.BertForTokenClassification_In_Spark_NLP.ipynb)

# %% [markdown]
# # BertForTokenClassification

# %% [markdown]
# **BertForTokenClassification** can load Bert Models with a token classification head on top (a linear layer on top of the hidden-states output) e.g. for Named-Entity-Recognition (NER) tasks.
#
# Pretrained models can be loaded with `pretrained` of the companion object. The default model is `"bert_base_token_classifier_conll03"`, if no name is provided. <br/>
#
# Models from the HuggingFace 🤗 Transformers library are also compatible with Spark NLP 🚀.

# %% [markdown]
# ## Colab Setup

# %%
! pip install -q pyspark==3.2.0 spark-nlp

# %%
import sparknlp

spark = sparknlp.start(spark32=True)

from sparknlp.base import *
from sparknlp.annotator import *
from pyspark.ml import Pipeline,PipelineModel
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
import pandas as pd


print("Spark NLP version", sparknlp.version())
print("Apache Spark version:", spark.version)

spark
# Out:
# Spark NLP version 3.4.0
# Apache Spark version: 3.2.0
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://59d865998543:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark NLP</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# **BertForTokenClassification Models**
#
#
# *   `bert_base_token_classifier_conll03`
# *   `bert_large_token_classifier_conll03`
# *   `bert_base_token_classifier_ontonote`
# *   `bert_large_token_classifier_ontonote`
# *   `bert_token_classifier_ner_ud_gsd`
# *   `bert_token_classifier_scandi_ner`
# *   `bert_token_classifier_chinese_ner`
# *   `bert_token_classifier_dutch_udlassy_ner`
#
# **AlbertForTokenClassification Models**
#
#
#
# *   `albert_base_token_classifier_conll03`
# *   `albert_large_token_classifier_conll03`
# *   `albert_xlarge_token_classifier_conll03`
#
# **DistilBertForTokenClassification Models**
#
#
# *   `distilbert_base_token_classifier_conll03`
# *   `distilbert_base_token_classifier_ontonotes`
#
#
# **RoBertaForTokenClassification Models**
#
#
# *   `roberta_token_classifier_ticker`
# *   `roberta_token_classifier_icelandic_ner`
# *   `roberta_base_token_classifier_conll03`
# *   `roberta_large_token_classifier_conll03`
# *   `roberta_token_classifier_timex_semeval`
# *   `distilroberta_base_token_classifier_ontonotes`
# *   `roberta_base_token_classifier_ontonotes`
# *   `roberta_large_token_classifier_ontonotes`
#
#
#
# **XlmRoBertaForTokenClassification Models**
#
#
# *   `xlm_roberta_large_token_classifier_conll03`
# *   `xlm_roberta_large_token_classifier_hrl`
# *   `xlm_roberta_base_token_classifier_conll03`
#
#
#
# **XlnetForTokenClassification Models**
#
#
#
# *   `xlnet_base_token_classifier_conll03`
# *   `xlnet_large_token_classifier_conll03`
#
#
#
#
#
#
# You can find all these models and more here in [Spark NLP Models Hub](https://nlp.johnsnowlabs.com/models?edition=Spark+NLP&task=Named+Entity+Recognition)

# %% [markdown]
# ## BertForTokenClassification Pipeline

# %% [markdown]
# Now, let's create a Spark NLP Pipeline with `bert_base_token_classifier_conll03` model and check the results. <br/>

# %%
document_assembler = DocumentAssembler() \
    .setInputCol('text') \
    .setOutputCol('document')

tokenizer = Tokenizer() \
    .setInputCols(['document']) \
    .setOutputCol('token')

tokenClassifier = BertForTokenClassification \
      .pretrained('bert_base_token_classifier_conll03', 'en') \
      .setInputCols(['token', 'document']) \
      .setOutputCol('ner') \
      .setCaseSensitive(True) \
      .setMaxSentenceLength(512)

# since output column is IOB/IOB2 style, NerConverter can extract entities
ner_converter = NerConverter() \
    .setInputCols(['document', 'token', 'ner']) \
    .setOutputCol('entities')

pipeline = Pipeline(stages=[
    document_assembler, 
    tokenizer,
    tokenClassifier,
    ner_converter
])

example = spark.createDataFrame([['My name is John Parker! I live in New York and I am a member of the New York Road Runners.']]).toDF("text")
model = pipeline.fit(example)
result= model.transform(example)
# Out:
# bert_base_token_classifier_conll03 download started this may take some time.
# Approximate size to download 385.4 MB
# [OK!]

# %%
model.stages
# Out:
# [DocumentAssembler_31f857e963aa,
#  REGEX_TOKENIZER_e4e9b3ddd4a1,
#  BERT_FOR_TOKEN_CLASSIFICATION_675a6a750b89,
#  NerConverter_1c3a0c474945]

# %% [markdown]
# We can check the classes of `bert_base_token_classifier_conll03` model by using `getClasses()` function

# %%
tokenClassifier.getClasses()
# Out:
# ['B-LOC', 'I-ORG', 'I-MISC', 'I-LOC', 'I-PER', 'B-MISC', 'B-ORG', 'O', 'B-PER']

# %%
result.columns
# Out:
# ['text', 'document', 'token', 'ner', 'entities']

# %%
result.printSchema()
# Out:
# root
#  |-- text: string (nullable = true)
#  |-- document: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- annotatorType: string (nullable = true)
#  |    |    |-- begin: integer (nullable = false)
#  |    |    |-- end: integer (nullable = false)
#  |    |    |-- result: string (nullable = true)
#  |    |    |-- metadata: map (nullable = true)
#  |    |    |    |-- key: string
#  |    |    |    |-- value: string (valueContainsNull = true)
#  |    |    |-- embeddings: array (nullable = true)
#  |    |    |    |-- element: float (containsNull = false)
#  |-- token: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- annotatorType: string (nullable = true)
#  |    |    |-- begin: integer (nullable = false)
#  |    |    |-- end: integer (nullable = false)
#  |    |    |-- result: string (nullable = true)
#  |    |    |-- metadata: map (nullable = true)
#  |    |    |    |-- key: string
#  |    |    |    |-- value: string (valueContainsNull = true)
#  |    |    |-- embeddings: array (nullable = true)
#  |    |    |    |-- element: float (containsNull = false)
#  |-- ner: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- annotatorType: string (nullable = true)
#  |    |    |-- begin: integer (nullable = false)
#  |    |    |-- end: integer (nullable = false)
#  |    |    |-- result: string (nullable = true)
#  |    |    |-- metadata: map (nullable = true)
#  |    |    |    |-- key: string
#  |    |    |    |-- value: string (valueContainsNull = true)
#  |    |    |-- embeddings: array (nullable = true)
#  |    |    |    |-- element: float (containsNull = false)
#  |-- entities: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- annotatorType: string (nullable = true)
#  |    |    |-- begin: integer (nullable = false)
#  |    |    |-- end: integer (nullable = false)
#  |    |    |-- result: string (nullable = true)
#  |    |    |-- metadata: map (nullable = true)
#  |    |    |    |-- key: string
#  |    |    |    |-- value: string (valueContainsNull = true)
#  |    |    |-- embeddings: array (nullable = true)
#  |    |    |    |-- element: float (containsNull = false)

# %% [markdown]
# Checking the ner labels of each token

# %%
result_df = result.select(F.explode(F.arrays_zip(result.token.result, result.ner.result, result.entities.result)).alias("cols"))\
                  .select(F.expr("cols['0']").alias("token"),
                          F.expr("cols['1']").alias("ner_label"))

result_df.show(50, truncate=100)
# Out:
# +-------+---------+
# |  token|ner_label|
# +-------+---------+
# |     My|        O|
# |   name|        O|
# |     is|        O|
# |   John|    B-PER|
# | Parker|    I-PER|
# |      !|        O|
# |      I|        O|
# |   live|        O|
# |     in|        O|
# |    New|    B-LOC|
# |   York|    I-LOC|
# |    and|        O|
# |      I|        O|
# |     am|        O|
# |      a|        O|
# | member|        O|
# |     of|        O|
# |    the|        O|
# |    New|    B-ORG|
# |   York|    I-ORG|
# |   Road|    I-ORG|
# |Runners|    I-ORG|
# |      .|        O|
# +-------+---------+

# %% [markdown]
# Inspecting the chunks

# %%
result_df_1= result.select(F.explode(F.arrays_zip(result.entities.result, result.entities.begin, result.entities.end, result.entities.metadata)).alias("col"))\
                   .select(F.expr("col['0']").alias("entities"),
                            F.expr("col['1']").alias("begin"),
                            F.expr("col['2']").alias("end"),
                            F.expr("col['3']['entity']").alias("ner_label"))
result_df_1.show(50, truncate=False)
# Out:
# +---------------------+-----+---+---------+
# |entities             |begin|end|ner_label|
# +---------------------+-----+---+---------+
# |John Parker          |11   |21 |PER      |
# |New York             |34   |41 |LOC      |
# |New York Road Runners|68   |88 |ORG      |
# +---------------------+-----+---+---------+

# %% [markdown]
# ##  BertForTokenClassification By Using LightPipeline

# %% [markdown]
# Now,  we will use our model with LightPipeline.

# %%
from sparknlp.base import LightPipeline

# %%
document_assembler = DocumentAssembler() \
    .setInputCol('text') \
    .setOutputCol('document')

tokenizer = Tokenizer() \
    .setInputCols(['document']) \
    .setOutputCol('token')

tokenClassifier = BertForTokenClassification \
    .pretrained('bert_base_token_classifier_conll03', 'en') \
    .setInputCols(['token', 'document']) \
    .setOutputCol('ner') \
    .setCaseSensitive(True) \
    .setMaxSentenceLength(512)

# since output column is IOB/IOB2 style, NerConverter can extract entities
ner_converter = NerConverter() \
    .setInputCols(['document', 'token', 'ner']) \
    .setOutputCol('entities')

pipeline = Pipeline(stages=[
    document_assembler, 
    tokenizer,
    tokenClassifier,
    ner_converter
])

empty_df = spark.createDataFrame([['']]).toDF("text")
model = pipeline.fit(example)
# Out:
# bert_base_token_classifier_conll03 download started this may take some time.
# Approximate size to download 385.4 MB
# [OK!]

# %% [markdown]
# We've built our model, let's use LightPipeline and fullAnnotate it with sample data.

# %%
light_model= LightPipeline(model)
light_result= light_model.fullAnnotate("Steven Rothery is the original guitarist and the longest continuous member of the British rock band Marillion.")[0]

# %%
light_result
# Out:
# {'document': [Annotation(document, 0, 109, Steven Rothery is the original guitarist and the longest continuous member of the British rock band Marillion., {})],
#  'entities': [Annotation(chunk, 0, 13, Steven Rothery, {'entity': 'PER', 'sentence': '0', 'chunk': '0'}),
#   Annotation(chunk, 82, 88, British, {'entity': 'MISC', 'sentence': '0', 'chunk': '1'}),
#   Annotation(chunk, 100, 108, Marillion, {'entity': 'ORG', 'sentence': '0', 'chunk': '2'})],
#  'ner': [Annotation(named_entity, 0, 5, B-PER, {'Some(I-LOC)': '1.87171E-5', 'Some(B-PER)': '0.9990536', 'Some(B-ORG)': '2.6759852E-4', 'Some(O)': '1.4683903E-4', 'Some(I-ORG)': '3.1453208E-5', 'Some(B-LOC)': '2.1402798E-4', 'Some(I-MISC)': '2.0058473E-5', 'Some(B-MISC)': '1.285331E-4', 'Some(I-PER)': '1.19188604E-4', 'word': 'Steven', 'sentence': '0'}),
#   Annotation(named_entity, 7, 13, I-PER, {'Some(I-LOC)': '1.2193699E-4', 'Some(B-PER)': '4.6251802E-4', 'Some(B-ORG)': '4.08042E-5', 'Some(O)': '1.7726915E-4', 'Some(I-ORG)': '2.6501116E-4', 'Some(B-LOC)': '1.2717307E-4', 'Some(I-MISC)': '8.0047335E-5', 'Some(B-MISC)': '7.485434E-5', 'Some(I-PER)': '0.9986504', 'word': 'Rothery', 'sentence': '0'}),
#   Annotation(named_entity, 15, 16, O, {'Some(I-LOC)': '7.0970564E-6', 'Some(B-PER)': '1.5951451E-5', 'Some(B-ORG)': '9.4083125E-6', 'Some(O)': '0.9999192', 'Some(I-ORG)': '1.2611858E-5', 'Some(B-LOC)': '8.522506E-6', 'Some(I-MISC)': '8.404317E-6', 'Some(B-MISC)': '9.95261E-6', 'Some(I-PER)': '8.878273E-6', 'word': 'is', 'sentence': '0'}),
#   Annotation(named_entity, 18, 20, O, {'Some(I-LOC)': '7.0020487E-6', 'Some(B-PER)': '1.7104549E-5', 'Some(B-ORG)': '1.1457226E-5', 'Some(O)': '0.9999184', 'Some(I-ORG)': '9.653539E-6', 'Some(B-LOC)': '9.431452E-6', 'Some(I-MISC)': '8.598613E-6', 'Some(B-MISC)': '1.0746982E-5', 'Some(I-PER)': '7.58612E-6', 'word': 'the', 'sentence': '0'}),
#   Annotation(named_entity, 22, 29, O, {'Some(I-LOC)': '5.6530307E-6', 'Some(B-PER)': '1.6510745E-5', 'Some(B-ORG)': '1.3623318E-5', 'Some(O)': '0.9999151', 'Some(I-ORG)': '8.778305E-6', 'Some(B-LOC)': '1.0594588E-5', 'Some(I-MISC)': '7.062782E-6', 'Some(B-MISC)': '1.7166585E-5', 'Some(I-PER)': '5.4972656E-6', 'word': 'original', 'sentence': '0'}),
#   Annotation(named_entity, 31, 39, O, {'Some(I-LOC)': '6.236092E-6', 'Some(B-PER)': '1.597651E-5', 'Some(B-ORG)': '7.969847E-6', 'Some(O)': '0.9999119', 'Some(I-ORG)': '9.979645E-6', 'Some(B-LOC)': '8.603074E-6', 'Some(I-MISC)': '1.0297553E-5', 'Some(B-MISC)': '2.1998481E-5', 'Some(I-PER)': '7.0217698E-6', 'word': 'guitarist', 'sentence': '0'}),
#   Annotation(named_entity, 41, 43, O, {'Some(I-LOC)': '1.0938309E-5', 'Some(B-PER)': '1.6311966E-5', 'Some(B-ORG)': '1.3506976E-5', 'Some(O)': '0.9998985', 'Some(I-ORG)': '1.3256691E-5', 'Some(B-LOC)': '8.235153E-6', 'Some(I-MISC)': '1.3898123E-5', 'Some(B-MISC)': '1.2500437E-5', 'Some(I-PER)': '1.2869877E-5', 'word': 'and', 'sentence': '0'}),
#   Annotation(named_entity, 45, 47, O, {'Some(I-LOC)': '6.749585E-6', 'Some(B-PER)': '1.7218212E-5', 'Some(B-ORG)': '1.1001696E-5', 'Some(O)': '0.9999208', 'Some(I-ORG)': '8.69294E-6', 'Some(B-LOC)': '9.270207E-6', 'Some(I-MISC)': '8.01283E-6', 'Some(B-MISC)': '1.08513095E-5', 'Some(I-PER)': '7.422858E-6', 'word': 'the', 'sentence': '0'}),
#   Annotation(named_entity, 49, 55, O, {'Some(I-LOC)': '7.5452367E-6', 'Some(B-PER)': '1.6423392E-5', 'Some(B-ORG)': '1.21675685E-5', 'Some(O)': '0.9999061', 'Some(I-ORG)': '8.784308E-6', 'Some(B-LOC)': '1.3661981E-5', 'Some(I-MISC)': '9.443413E-6', 'Some(B-MISC)': '1.9093975E-5', 'Some(I-PER)': '6.73475E-6', 'word': 'longest', 'sentence': '0'}),
#   Annotation(named_entity, 57, 66, O, {'Some(I-LOC)': '6.635626E-6', 'Some(B-PER)': '1.6831016E-5', 'Some(B-ORG)': '1.197905E-5', 'Some(O)': '0.999909', 'Some(I-ORG)': '1.0508197E-5', 'Some(B-LOC)': '1.1209551E-5', 'Some(I-MISC)': '9.635688E-6', 'Some(B-MISC)': '1.6946535E-5', 'Some(I-PER)': '7.290957E-6', 'word': 'continuous', 'sentence': '0'}),
#   Annotation(named_entity, 68, 73, O, {'Some(I-LOC)': '7.70956E-6', 'Some(B-PER)': '1.398974E-5', 'Some(B-ORG)': '9.241327E-6', 'Some(O)': '0.99992186', 'Some(I-ORG)': '9.299618E-6', 'Some(B-LOC)': '8.017117E-6', 'Some(I-MISC)': '9.168493E-6', 'Some(B-MISC)': '1.341681E-5', 'Some(I-PER)': '7.2742187E-6', 'word': 'member', 'sentence': '0'}),
#   Annotation(named_entity, 75, 76, O, {'Some(I-LOC)': '9.101425E-6', 'Some(B-PER)': '1.1982197E-5', 'Some(B-ORG)': '9.971172E-6', 'Some(O)': '0.99992204', 'Some(I-ORG)': '1.2063836E-5', 'Some(B-LOC)': '7.47211E-6', 'Some(I-MISC)': '9.032177E-6', 'Some(B-MISC)': '1.0725794E-5', 'Some(I-PER)': '7.6112924E-6', 'word': 'of', 'sentence': '0'}),
#   Annotation(named_entity, 78, 80, O, {'Some(I-LOC)': '8.50036E-6', 'Some(B-PER)': '1.3354042E-5', 'Some(B-ORG)': '1.1609487E-5', 'Some(O)': '0.99991685', 'Some(I-ORG)': '1.127247E-5', 'Some(B-LOC)': '8.679634E-6', 'Some(I-MISC)': '9.082433E-6', 'Some(B-MISC)': '1.3504056E-5', 'Some(I-PER)': '7.136142E-6', 'word': 'the', 'sentence': '0'}),
#   Annotation(named_entity, 82, 88, B-MISC, {'Some(I-LOC)': '1.0380786E-4', 'Some(B-PER)': '2.2445244E-4', 'Some(B-ORG)': '5.621188E-4', 'Some(O)': '0.002675554', 'Some(I-ORG)': '9.4253584E-5', 'Some(B-LOC)': '4.447668E-4', 'Some(I-MISC)': '7.1315357E-4', 'Some(B-MISC)': '0.9950795', 'Some(I-PER)': '1.02352154E-4', 'word': 'British', 'sentence': '0'}),
#   Annotation(named_entity, 90, 93, O, {'Some(I-LOC)': '1.7629221E-5', 'Some(B-PER)': '2.3965E-5', 'Some(B-ORG)': '1.3998538E-5', 'Some(O)': '0.9998183', 'Some(I-ORG)': '2.5810736E-5', 'Some(B-LOC)': '1.28703205E-5', 'Some(I-MISC)': '4.035269E-5', 'Some(B-MISC)': '3.4313503E-5', 'Some(I-PER)': '1.27367675E-5', 'word': 'rock', 'sentence': '0'}),
#   Annotation(named_entity, 95, 98, O, {'Some(I-LOC)': '1.2107544E-5', 'Some(B-PER)': '2.0496012E-5', 'Some(B-ORG)': '2.1695778E-5', 'Some(O)': '0.99983704', 'Some(I-ORG)': '3.5584188E-5', 'Some(B-LOC)': '1.0330032E-5', 'Some(I-MISC)': '2.6352038E-5', 'Some(B-MISC)': '2.4700039E-5', 'Some(I-PER)': '1.1698666E-5', 'word': 'band', 'sentence': '0'}),
#   Annotation(named_entity, 100, 108, B-ORG, {'Some(I-LOC)': '0.0012121431', 'Some(B-PER)': '0.028681798', 'Some(B-ORG)': '0.863167', 'Some(O)': '0.013275852', 'Some(I-ORG)': '0.0038415', 'Some(B-LOC)': '0.013800029', 'Some(I-MISC)': '0.009413758', 'Some(B-MISC)': '0.065442495', 'Some(I-PER)': '0.0011654396', 'word': 'Marillion', 'sentence': '0'}),
#   Annotation(named_entity, 109, 109, O, {'Some(I-LOC)': '1.6327564E-5', 'Some(B-PER)': '1.4526597E-5', 'Some(B-ORG)': '1.183711E-5', 'Some(O)': '0.99987996', 'Some(I-ORG)': '2.5750984E-5', 'Some(B-LOC)': '9.7642405E-6', 'Some(I-MISC)': '1.745137E-5', 'Some(B-MISC)': '1.24756825E-5', 'Some(I-PER)': '1.1880677E-5', 'word': '.', 'sentence': '0'})],
#  'token': [Annotation(token, 0, 5, Steven, {'sentence': '0'}),
#   Annotation(token, 7, 13, Rothery, {'sentence': '0'}),
#   Annotation(token, 15, 16, is, {'sentence': '0'}),
#   Annotation(token, 18, 20, the, {'sentence': '0'}),
#   Annotation(token, 22, 29, original, {'sentence': '0'}),
#   Annotation(token, 31, 39, guitarist, {'sentence': '0'}),
#   Annotation(token, 41, 43, and, {'sentence': '0'}),
#   Annotation(token, 45, 47, the, {'sentence': '0'}),
#   Annotation(token, 49, 55, longest, {'sentence': '0'}),
#   Annotation(token, 57, 66, continuous, {'sentence': '0'}),
#   Annotation(token, 68, 73, member, {'sentence': '0'}),
#   Annotation(token, 75, 76, of, {'sentence': '0'}),
#   Annotation(token, 78, 80, the, {'sentence': '0'}),
#   Annotation(token, 82, 88, British, {'sentence': '0'}),
#   Annotation(token, 90, 93, rock, {'sentence': '0'}),
#   Annotation(token, 95, 98, band, {'sentence': '0'}),
#   Annotation(token, 100, 108, Marillion, {'sentence': '0'}),
#   Annotation(token, 109, 109, ., {'sentence': '0'})]}

# %%
light_result.keys()
# Out:
# dict_keys(['document', 'token', 'ner', 'entities'])

# %% [markdown]
# Checking the ner labels of each token

# %%
tokens= []
ner_labels= []

for i, k in list(zip(light_result["token"], light_result["ner"])):
  tokens.append(i.result)
  ner_labels.append(k.result)

result_df= pd.DataFrame({"tokens": tokens, "ner_labels": ner_labels})
result_df.head(20)
# Out:
#         tokens ner_labels
# 0       Steven      B-PER
# 1      Rothery      I-PER
# 2           is          O
# 3          the          O
# 4     original          O
# 5    guitarist          O
# 6          and          O
# 7          the          O
# 8      longest          O
# 9   continuous          O
# 10      member          O
# 11          of          O
# 12         the          O
# 13     British     B-MISC
# 14        rock          O
# 15        band          O
# 16   Marillion      B-ORG
# 17           .          O

# %% [markdown]
# Let's check the chunk results

# %%
chunks= []
begin= []
end= []
ner_label= []

for i in light_result["entities"]:
  chunks.append(i.result)
  begin.append(i.begin)
  end.append(i.end)
  ner_label.append(i.metadata["entity"])

result_df= pd.DataFrame({"chunks": chunks, "begin": begin, "end": end, "ner_label": ner_label})
result_df.head(20)
# Out:
#            chunks  begin  end ner_label
# 0  Steven Rothery      0   13       PER
# 1         British     82   88      MISC
# 2       Marillion    100  108       ORG
