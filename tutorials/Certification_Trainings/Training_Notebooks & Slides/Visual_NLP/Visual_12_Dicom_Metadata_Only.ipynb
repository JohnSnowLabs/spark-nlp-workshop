# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/spark-nlp-workshop/blob/master/tutorials/Certification_Trainings/Medical_Language_Models/April_2025/Notebooks/Dicom_Metadata_Only.ipynb)

# %% [markdown]
# <!-- ========================================================= -->
# <!--        John Snow Labs - Package Installation Guide         -->
# <!--        JupyterLab Single Markdown Cell (HTML Content)      -->
# <!-- ========================================================= -->
#
# <h1>Package Installation</h1>
#
# <!-- Link to official GitHub repository -->
# <p>
#   Official Repository:
#   <a href="https://github.com/JohnSnowLabs/johnsnowlabs" target="_blank">
#     https://github.com/JohnSnowLabs/johnsnowlabs
#   </a>
# </p>
#
# <!-- License setup instructions -->
# <p>
#   Keep your <strong>license keys</strong> in a JSON file and point to it using the
#   <code>json_license_path</code> argument when starting the Spark session.
# </p>
#
# <!-- Visual NLP configuration note -->
# <p>
#   Set <code>visual=True</code> while starting the Spark session to install and make
#   <strong>Visual NLP libraries</strong> available.
# </p>
#
# <!-- Restart note -->
# <p>
#   ⚠️ <strong>Important:</strong> After installing the library, make sure to
#   <strong>RESTART your session</strong> before running Spark again.
# </p>
#
# <!-- End of notebook cell -->

# %%
# !pip install -q johnsnowlabs

# %%
from johnsnowlabs import nlp, visual, medical

nlp.install(refresh_install=True, visual=True, json_license_path="./spark_nlp_for_healthcare_spark_ocr_10538.json")

# %%
# RESTART SESSION!!!

# %%
from johnsnowlabs import visual, nlp

spark = nlp.start(visual=True, hardware_target="gpu", json_license_path="./spark_nlp_for_healthcare_spark_ocr_10538.json")

spark
# Out:
# 👌 License info detected in file ./spark_nlp_for_healthcare_spark_ocr_10538.json
# 25/10/21 09:51:50 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/10/21 09:51:50 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 👌 Launched gpu optimized session with with: 🚀Spark-NLP==6.1.3, 💊Spark-Healthcare==6.1.1, 🕶Spark-OCR==6.1.0, running on ⚡ PySpark==3.4.0
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://071af2228ca5:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>John-Snow-Labs-Spark-Session 🚀 with Jars for: 🚀Spark-NLP==6.1.3, 💊Spark-Healthcare==6.1.1, 🕶Spark-OCR==6.1.0, running on ⚡ PySpark==3.4.0</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# <h1>Dicom Metadata DeIdentification</h1>
#
# <!-- Notebook purpose -->
# <p>
#   This notebook focuses on the <strong>DICOM Metadata De-Identification</strong> process — the anonymization of
#   Protected Health Information (PHI) stored within DICOM headers and nested tag structures.
#   It demonstrates how <strong>Visual NLP</strong> transformers can be applied
#   to sanitize sensitive metadata fields across large DICOM datasets while maintaining UID consistency
#   and referential integrity.
# </p>
#
# <!-- Stages list -->
# <h2>Concepts and Components Covered in this Notebook</h2>
# <ul>
#   <li>DicomToMetadata</li>
#   <li>DicomMetadataDeidentifier</li>
# </ul>

# %%
# 📦 Spark OCR Imports
from sparkocr.transformers import *
from sparkocr.enums import *
from sparkocr.utils import *
from sparkocr.schemas import BinarySchema

# ⚡ Spark NLP Core
from sparknlp.base import *
from sparknlp.annotator import *
from sparknlp.pretrained import PretrainedPipeline

# 🔗 Spark ML
from pyspark.ml import Pipeline, PipelineModel
import pyspark.sql.functions as F

# 🧩 Spark NLP for Healthcare (JSL)
import sparknlp_jsl
from sparknlp_jsl.annotator import *
from sparkocr.base import LightPipeline

from pyspark.sql.functions import *
from pyspark.sql.types import *
from urllib.parse import urlparse
from IPython.display import display, Markdown
from PIL import Image, ImageDraw, ImageFont
import pkg_resources
import pandas as pd
import time

# %%
def compare_dicom_metadata(dicom_original_metadata, dicom_redacted_metadata):
    """
    Compare Original and Redacted Metadata
    Add a new column denoting if value has changed
    Returns pandas dataframe
    """
    metadata_mapping = []

    for key in dicom_original_metadata.keys():
        changed = dicom_original_metadata[key] != dicom_redacted_metadata[key]
        metadata_mapping.append([key,dicom_original_metadata[key],dicom_redacted_metadata[key], changed])

    metadata_mapping_df = pd.DataFrame(metadata_mapping, columns=["Key", "Original Value", "Redacted Value", "Value Changed"])

    return metadata_mapping_df

# %% [markdown]
# <h2>Extract Metadata from Dicom Object</h2>

# %%
dicom_to_metadata = DicomToMetadata() \
    .setInputCol("content") \
    .setOutputCol("metadata")

# %%
df = spark.read.format("binaryFile").load("./data/visual/dicom/TCIA-MIDI-B-Synthetic-Test_20250502___1.1.582.0.3.8604111.4.040.1865311550435039158___1-1.dcm")

result = dicom_to_metadata.transform(df).select("metadata").collect()[0].asDict()["metadata"]

json_result = json.loads(result)

json_result

# %% [markdown]
# <h2>Run Deidentify Dicom Metadata and Extract Results</h2>

# %%
csv_path = pkg_resources.resource_filename('sparkocr', "resources/ocr/dicom/default_dicom_strategy.csv")

strategy_csv = pd.read_csv(csv_path)

strategy_csv.head(10)
# Out:
#           Tags  VR                             Name Status  \
# 0  (0002,0100)  UI  Private Information Creator UID    NaN
# 1  (0002,0102)  OB              Private Information    NaN
# 2  (0004,1130)  CS                      File-set ID    NaN
# 3  (0004,1141)  CS      File-set Descriptor File ID    NaN
# 4  (0004,1432)  UI               Private Record UID    NaN
# 5  (0004,1500)  CS               Referenced File ID    NaN
# 6  (0008,0012)  DA           Instance Creation Date    NaN
# 7  (0008,0014)  UI             Instance Creator UID    NaN
# 8  (0008,0020)  DA                       Study Date    NaN
# 9  (0008,0021)  DA                      Series Date    NaN
#
#                       Action Repeatable
# 0                     hashId        NaN
# 1                     hashId        NaN
# 2                     hashId        NaN
# 3                     hashId        NaN
# 4                     hashId        NaN
# 5                     hashId        NaN
# 6  shiftDateByRandomNbOfDays        NaN
# 7                     hashId        NaN
# 8   shiftDateByFixedNbOfDays        112
# 9  shiftDateByRandomNbOfDays        NaN

# %%
dicom_deidentifier = DicomMetadataDeidentifier() \
    .setInputCols(["content"]) \
    .setOutputCol("dicom_metadata_cleaned") \
    .setRemovePrivateTags(False) \
    .setPlaceholderText("<hidden>") \
    .setStrategyFile(csv_path)

# %%
df = spark.read.format("binaryFile").load("./data/visual/dicom/TCIA-MIDI-B-Synthetic-Test_20250502___1.1.582.0.3.8604111.4.040.1865311550435039158___1-1.dcm")

result = dicom_deidentifier.transform(df).write \
  .format("binaryFormat") \
  .option("type", "dicom") \
  .option("field", "dicom_metadata_cleaned") \
  .option("nameField", "fileName") \
  .option("extension", "dcm") \
  .option("prefix", "de-id-") \
  .mode("overwrite") \
  .save("./data/result_metadata/")
# Out:
# 25/10/21 10:40:37 WARN SparkContext: The path /usr/local/lib/python3.12/dist-packages/sparkocr/resources/ocr/dicom/first_names.all.txt has been added already. Overwriting of added paths is not supported in the current version.
# 25/10/21 10:40:37 WARN SparkContext: The path /usr/local/lib/python3.12/dist-packages/sparkocr/resources/ocr/dicom/last_names.all.txt has been added already. Overwriting of added paths is not supported in the current version.
# /usr/local/lib/python3.12/dist-packages/sparkocr/transformers/dicom/dicom_metadata_deidentifier.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# 10:40:40, INFO Run DicomMetadataDeidentifier
# 10:40:41, INFO DEBUG: tag:(2, 256), vr:UI, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(2, 258), vr:OB, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(4, 4400), vr:CS, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(4, 4417), vr:CS, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(4, 5170), vr:UI, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(4, 5376), vr:CS, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(8, 18), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 10:40:41, INFO DEBUG: tag:(8, 20), vr:UI, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(8, 32), vr:DA, action:shiftDateByFixedNbOfDays, option:112
# 10:40:41, INFO Run DicomMetadataDeidentifier:vr:DA, action:shiftDateByFixedNbOfDays
# 10:40:41, INFO DEBUG: tag:(8, 33), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 10:40:41, INFO DEBUG: tag:(8, 34), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 10:40:41, INFO DEBUG: tag:(8, 35), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 10:40:41, INFO Run DicomMetadataDeidentifier:vr:DA, action:shiftDateByRandomNbOfDays
# 10:40:41, INFO DEBUG: tag:(8, 36), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 10:40:41, INFO DEBUG: tag:(8, 37), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 10:40:41, INFO DEBUG: tag:(8, 42), vr:DT, action:shiftDateByRandomNbOfDays, option:None
# 10:40:41, INFO DEBUG: tag:(8, 80), vr:SH, action:hashId, option:None
# 10:40:41, INFO Run DicomMetadataDeidentifier:vr:SH, action:hashId
# /usr/local/lib/python3.12/dist-packages/pydicom/valuerep.py:440: UserWarning: The value length (44) exceeds the maximum length of 16 allowed for VR SH.
#   warn_and_log(msg)
# 10:40:41, INFO DEBUG: tag:(8, 88), vr:UI, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(8, 128), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(8, 129), vr:ST, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(8, 130), vr:SQ, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(8, 144), vr:PN, action:remove, option:None
# 10:40:41, INFO Run DicomMetadataDeidentifier:vr:PN, action:remove
# 10:40:41, INFO DEBUG: tag:(8, 146), vr:ST, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(8, 148), vr:SH, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(8, 156), vr:PN, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(8, 269), vr:UI, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(8, 513), vr:SH, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(8, 4112), vr:SH, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(8, 4160), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(8, 4168), vr:PN, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(8, 4176), vr:PN, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(8, 4192), vr:PN, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(8, 4208), vr:PN, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(8, 4501), vr:UI, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(8, 12304), vr:UI, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(16, 16), vr:PN, action:remove, option:None
# 10:40:41, INFO Run DicomMetadataDeidentifier:vr:PN, action:remove
# 10:40:41, INFO DEBUG: tag:(16, 32), vr:LO, action:hashId, option:None
# 10:40:41, INFO Run DicomMetadataDeidentifier:vr:LO, action:hashId
# 10:40:41, INFO DEBUG: tag:(16, 33), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(16, 48), vr:DA, action:shiftDateByRandomNbOfDays, option:True
# 10:40:41, INFO Run DicomMetadataDeidentifier:vr:DA, action:shiftDateByRandomNbOfDays
# 10:40:41, INFO DEBUG: tag:(16, 51), vr:LO, action:shiftDateByRandomNbOfDays, option:True
# 10:40:41, INFO DEBUG: tag:(16, 52), vr:LO, action:shiftDateByRandomNbOfDays, option:True
# 10:40:41, INFO DEBUG: tag:(16, 4096), vr:LO, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(16, 4097), vr:PN, action:replaceWithRandomName, option:None
# 10:40:41, INFO DEBUG: tag:(16, 4098), vr:SQ, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(16, 4101), vr:PN, action:replaceWithRandomName, option:coherent
# 10:40:41, INFO DEBUG: tag:(16, 4112), vr:AS, action:shiftDateByRandomNbOfDays, option:None
# 10:40:41, INFO Run DicomMetadataDeidentifier:vr:AS, action:shiftDateByRandomNbOfDays
# 10:40:41, INFO DEBUG: tag:(16, 4160), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(16, 4176), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(16, 4192), vr:PN, action:replaceWithRandomName, option:None
# 10:40:41, INFO DEBUG: tag:(16, 4224), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(16, 4225), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(16, 4240), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(16, 8528), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(16, 8530), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(16, 8532), vr:SH, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(16, 8533), vr:LT, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(16, 8656), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 10:40:41, INFO DEBUG: tag:(16, 8688), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(16, 8855), vr:PN, action:replaceWithRandomName, option:None
# 10:40:41, INFO DEBUG: tag:(16, 8857), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(18, 16), vr:LO, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(18, 32), vr:LO, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(18, 48), vr:LO, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(18, 49), vr:LO, action:replaceWithRandomName, option:None
# 10:40:41, INFO DEBUG: tag:(18, 64), vr:LO, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(18, 66), vr:LO, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(18, 80), vr:LO, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(18, 96), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(18, 98), vr:CS, action:replaceWithLiteral, option:YES
# 10:40:41, INFO DEBUG: tag:(18, 113), vr:LO, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(18, 129), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(18, 130), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(20, 260), vr:PN, action:replaceWithRandomName, option:None
# 10:40:41, INFO DEBUG: tag:(20, 8198), vr:PN, action:replaceWithRandomName, option:None
# 10:40:41, INFO DEBUG: tag:(24, 21), vr:CS, action:replaceWithLiteral, option:Chest
# 10:40:41, INFO Run DicomMetadataDeidentifier:vr:CS, action:replaceWithLiteral
# /usr/local/lib/python3.12/dist-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR CS: 'Chest'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# 10:40:41, INFO DEBUG: tag:(24, 4114), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 10:40:41, INFO DEBUG: tag:(24, 4608), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 10:40:41, INFO DEBUG: tag:(24, 28684), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 10:40:41, INFO DEBUG: tag:(32, 13), vr:UI, action:hashId, option:None
# 10:40:41, INFO Run DicomMetadataDeidentifier:vr:UI, action:hashId
# /usr/local/lib/python3.12/dist-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.1.582.0.3.8604111.4.040.2461550950283810514'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# 10:40:41, INFO DEBUG: tag:(32, 14), vr:UI, action:hashId, option:None
# 10:40:41, INFO Run DicomMetadataDeidentifier:vr:UI, action:hashId
# /usr/local/lib/python3.12/dist-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.1.582.0.3.8604111.4.040.1865311550435039158'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# 10:40:41, INFO DEBUG: tag:(32, 16), vr:SH, action:hashId, option:None
# 10:40:41, INFO Run DicomMetadataDeidentifier:vr:SH, action:hashId
# 10:40:41, INFO DEBUG: tag:(32, 82), vr:UI, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(32, 512), vr:UI, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(32, 13313), vr:CS, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(32, 13316), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(32, 13318), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(32, 37217), vr:UI, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(32, 37220), vr:UI, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(40, 771), vr:CS, action:replaceWithLiteral, option:MODIFIED
# 10:40:41, INFO DEBUG: tag:(40, 16384), vr:LT, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(50, 18), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(50, 4096), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 10:40:41, INFO DEBUG: tag:(50, 4146), vr:PN, action:replaceWithRandomName, option:None
# 10:40:41, INFO DEBUG: tag:(50, 4147), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(50, 4160), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 10:40:41, INFO DEBUG: tag:(50, 4176), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 10:40:41, INFO DEBUG: tag:(56, 16), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(56, 17), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(56, 30), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(56, 32), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 10:40:41, INFO DEBUG: tag:(56, 96), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(56, 97), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(56, 768), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(64, 6), vr:PN, action:replaceWithRandomName, option:None
# 10:40:41, INFO DEBUG: tag:(64, 579), vr:SH, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(64, 4097), vr:SH, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(64, 4100), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(64, 4101), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(64, 4112), vr:PN, action:replaceWithRandomName, option:None
# 10:40:41, INFO DEBUG: tag:(64, 4354), vr:ST, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(64, 4355), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(64, 8200), vr:PN, action:replaceWithRandomName, option:None
# 10:40:41, INFO DEBUG: tag:(64, 8208), vr:SH, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(64, 16437), vr:SQ, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(64, 16439), vr:PN, action:replaceWithRandomName, option:None
# 10:40:41, INFO DEBUG: tag:(64, 40999), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(64, 41075), vr:SQ, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(64, 41077), vr:PN, action:replaceWithRandomName, option:None
# 10:40:41, INFO Run DicomMetadataDeidentifier:vr:PN, action:replaceWithRandomName
# 10:40:41, INFO DEBUG: tag:(64, 41080), vr:SQ, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(64, 41082), vr:SQ, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(64, 41251), vr:PN, action:replaceWithRandomName, option:coherent
# 10:40:41, INFO DEBUG: tag:(64, 41252), vr:UI, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(64, 41812), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(64, 56076), vr:UI, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(64, 56077), vr:UI, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(112, 1), vr:SQ, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(112, 132), vr:PN, action:replaceWithRandomName, option:None
# 10:40:41, INFO DEBUG: tag:(112, 794), vr:UI, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(136, 512), vr:SQ, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(136, 2308), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(136, 2310), vr:ST, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(136, 2320), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(136, 2322), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(1024, 256), vr:UI, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(1024, 1028), vr:OB, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(1024, 1360), vr:SQ, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(1024, 1377), vr:SQ, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(8240, 32), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(12294, 8), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 10:40:41, INFO DEBUG: tag:(12294, 36), vr:UI, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(12294, 166), vr:PN, action:replaceWithRandomName, option:None
# 10:40:41, INFO DEBUG: tag:(12294, 194), vr:UI, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(12298, 19), vr:UI, action:hashId, option:None
# 10:40:41, INFO DEBUG: tag:(12302, 8), vr:PN, action:replaceWithRandomName, option:None
# 10:40:41, INFO DEBUG: tag:(16384, 16), vr:LT, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(16384, 16384), vr:LT, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(16392, 66), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(16392, 258), vr:PN, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(16392, 266), vr:PN, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(16392, 268), vr:PN, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(16392, 273), vr:SQ, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(16392, 276), vr:PN, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(16392, 281), vr:PN, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(16392, 282), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(16392, 514), vr:LO, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(65532, 65532), vr:OB, action:remove, option:None
# 10:40:41, INFO DEBUG: tag:(-1025, 1), vr:SH, action:remove, option:None
# /usr/local/lib/python3.12/dist-packages/pydicom/dataset.py:589: UserWarning: Invalid value '(-1025, 1)' used with the 'in' operator: must be an element tag as a 2-tuple or int, or an element keyword
#   warn_and_log(msg)
# 25/10/21 10:40:41 WARN BasicWriteTaskStatsTracker: Expected 1 files, but only saw 0. This could be due to the output format not writing empty files, or files being not immediately visible in the filesystem.

# %% [markdown]
# <h2>Run DicomToMetadata and Extract Results</h2>

# %%
df = spark.read.format("binaryFile").load("./data/result_metadata/*.dcm")

deid_result = dicom_to_metadata.transform(df).select("metadata").collect()[0].asDict()["metadata"]

json_deid_result = json.loads(deid_result)

json_deid_result
# Out:
# /usr/local/lib/python3.12/dist-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.1.582.0.3.8604111.4.040.1906345282118337300'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# {'SpecificCharacterSet': 'ISO_IR 100',
#  'SOPClassUID': '1.2.840.10008.5.1.4.1.1.7',
#  'SOPInstanceUID': '1.1.582.0.3.8604111.4.040.1906345282118337300',
#  'StudyDate': '20131109',
#  'ContentDate': '20130905',
#  'StudyTime': '110007',
#  'ContentTime': '110007',
#  'AccessionNumber': '2.25.104661169016722362372224050231930259815',
#  'Modality': 'MG',
#  'ConversionType': 'WSD',
#  "ReferringPhysician'sName": '<hidden>',
#  'AdmittingDiagnosesDescription': 'Suspected breast cancer; Ordered by Dr. Burke',
#  "Patient'sName": '<hidden>',
#  'PatientID': '2.25.104661169016722362372224050231930259815',
#  "Patient'sBirthDate": '19410504',
#  "Patient'sSex": 'U',
#  "Patient'sAge": '056M',
#  'PrivateCreator': 'CTP',
#  'Privatetagdata': '29059656',
#  'BodyPartExamined': 'Chest',
#  'SecondaryCaptureDeviceManufacturer': 'MathWorks',
#  "SecondaryCaptureDeviceManufacturer'sModelName": 'MATLAB',
#  'ProtocolName': 'Performed 20130720',
#  'StudyInstanceUID': '2.25.104661169016722362372224050231930259815',
#  'SeriesInstanceUID': '2.25.104661169016722362372224050231930259815',
#  'StudyID': '2.25.104661169016722362372224050231930259815',
#  'SeriesNumber': '1',
#  'InstanceNumber': '1',
#  'PatientOrientation': 'CC',
#  'SamplesperPixel': '1',
#  'PhotometricInterpretation': 'MONOCHROME2',
#  'Rows': '4624',
#  'Columns': '2800',
#  'BitsAllocated': '16',
#  'BitsStored': '16',
#  'HighBit': '15',
#  'PixelRepresentation': '0',
#  'SmallestImagePixelValue': '0',
#  'LargestImagePixelValue': '65535',
#  'RequestedProcedureDescription': 'Ordered for Bruce Mendoza by Dr. Burke',
#  'StudyComments': 'Ordered for 250-65-7242 by Dr. Burke',
#  'VerifyingObserverName': 'karai longchamps'}

# %% [markdown]
# <h3>Compare the Tags with Changes</h3>

# %%
pd_df = compare_dicom_metadata(json_result, json_deid_result)
pd_df[pd_df["Value Changed"] == True].head(50)
# Out:
#                          Key                                 Original Value  \
# 3                  StudyDate                                       20130720
# 4                ContentDate                                       20130720
# 7            AccessionNumber                                20130720E771698
# 10  ReferringPhysician'sName                                    BURKE^KAYLA
# 12             Patient'sName                                  MENDOZA^BRUCE
# 13                 PatientID                                      930219598
# 14        Patient'sBirthDate                                       19410527
# 16              Patient'sAge                                           072Y
# 19          BodyPartExamined                                    Left Breast
# 23          StudyInstanceUID  1.1.582.0.3.8604111.4.040.2461550950283810514
# 24         SeriesInstanceUID  1.1.582.0.3.8604111.4.040.1865311550435039158
# 25                   StudyID                                           DDSM
# 41     VerifyingObserverName                               PERKINS^JENNIFER
#
#                                   Redacted Value  Value Changed
# 3                                       20131109           True
# 4                                       20130905           True
# 7   2.25.104661169016722362372224050231930259815           True
# 10                                      <hidden>           True
# 12                                      <hidden>           True
# 13  2.25.104661169016722362372224050231930259815           True
# 14                                      19410504           True
# 16                                          056M           True
# 19                                         Chest           True
# 23  2.25.104661169016722362372224050231930259815           True
# 24  2.25.104661169016722362372224050231930259815           True
# 25  2.25.104661169016722362372224050231930259815           True
# 41                              karai longchamps           True

# %%
import shutil
shutil.rmtree("./data/result_metadata/")
