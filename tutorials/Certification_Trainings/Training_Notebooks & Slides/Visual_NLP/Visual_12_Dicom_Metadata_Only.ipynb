# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/spark-nlp-workshop/blob/master/tutorials/Certification_Trainings/Medical_Language_Models/April_2025/Notebooks/Dicom_Metadata_Only.ipynb)

# %% [markdown]
# <!-- ========================================================= -->
# <!--        John Snow Labs - Package Installation Guide         -->
# <!--        JupyterLab Single Markdown Cell (HTML Content)      -->
# <!-- ========================================================= -->
#
# <h1>Package Installation</h1>
#
# <!-- Link to official GitHub repository -->
# <p>
#   Official Repository:
#   <a href="https://github.com/JohnSnowLabs/johnsnowlabs" target="_blank">
#     https://github.com/JohnSnowLabs/johnsnowlabs
#   </a>
# </p>
#
# <!-- License setup instructions -->
# <p>
#   Keep your <strong>license keys</strong> in a JSON file and point to it using the
#   <code>json_license_path</code> argument when starting the Spark session.
# </p>
#
# <!-- Visual NLP configuration note -->
# <p>
#   Set <code>visual=True</code> while starting the Spark session to install and make
#   <strong>Visual NLP libraries</strong> available.
# </p>
#
# <!-- Restart note -->
# <p>
#   ⚠️ <strong>Important:</strong> After installing the library, make sure to
#   <strong>RESTART your session</strong> before running Spark again.
# </p>
#
# <!-- End of notebook cell -->

# %%
# !pip install -q johnsnowlabs

# %%
from johnsnowlabs import nlp, visual, medical

nlp.install(refresh_install=True, visual=True, json_license_path="./spark_nlp_for_healthcare_spark_ocr_10538.json")

# %%
# RESTART SESSION!!!

# %%
from johnsnowlabs import visual, nlp

spark = nlp.start(visual=True, hardware_target="gpu", json_license_path="./spark_nlp_for_healthcare_spark_ocr_10538.json")

spark
# Out:
# 👌 License info detected in file ./spark_nlp_for_healthcare_spark_ocr_10538.json
# 25/10/22 20:25:28 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 👌 Launched gpu optimized session with with: 🚀Spark-NLP==6.1.3, 💊Spark-Healthcare==6.1.1, 🕶Spark-OCR==6.1.0, running on ⚡ PySpark==3.4.0
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://f94dde53c389:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>John-Snow-Labs-Spark-Session 🚀 with Jars for: 🚀Spark-NLP==6.1.3, 💊Spark-Healthcare==6.1.1, 🕶Spark-OCR==6.1.0, running on ⚡ PySpark==3.4.0</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# <h1>Dicom Metadata DeIdentification</h1>
#
# <!-- Notebook purpose -->
# <p>
#   This notebook focuses on the <strong>DICOM Metadata De-Identification</strong> process — the anonymization of
#   Protected Health Information (PHI) stored within DICOM headers and nested tag structures.
#   It demonstrates how <strong>Visual NLP</strong> transformers can be applied
#   to sanitize sensitive metadata fields across large DICOM datasets while maintaining UID consistency
#   and referential integrity.
# </p>
#
# <!-- Stages list -->
# <h2>Concepts and Components Covered in this Notebook</h2>
# <ul>
#   <li>DicomToMetadata</li>
#   <li>DicomMetadataDeidentifier</li>
# </ul>

# %%
# 📦 Spark OCR Imports
from sparkocr.transformers import *
from sparkocr.enums import *
from sparkocr.utils import *
from sparkocr.schemas import BinarySchema

# ⚡ Spark NLP Core
from sparknlp.base import *
from sparknlp.annotator import *
from sparknlp.pretrained import PretrainedPipeline

# 🔗 Spark ML
from pyspark.ml import Pipeline, PipelineModel
import pyspark.sql.functions as F

# 🧩 Spark NLP for Healthcare (JSL)
import sparknlp_jsl
from sparknlp_jsl.annotator import *
from sparkocr.base import LightPipeline

from pyspark.sql.functions import *
from pyspark.sql.types import *
from urllib.parse import urlparse
from IPython.display import display, Markdown
from PIL import Image, ImageDraw, ImageFont
import pkg_resources
import pandas as pd
import time

# %%
def compare_dicom_metadata(dicom_original_metadata, dicom_redacted_metadata):
    """
    Compare Original and Redacted Metadata
    Add a new column denoting if value has changed
    Returns pandas dataframe
    """
    metadata_mapping = []

    for key in dicom_original_metadata.keys():
        changed = dicom_original_metadata[key] != dicom_redacted_metadata[key]
        metadata_mapping.append([key,dicom_original_metadata[key],dicom_redacted_metadata[key], changed])

    metadata_mapping_df = pd.DataFrame(metadata_mapping, columns=["Key", "Original Value", "Redacted Value", "Value Changed"])

    return metadata_mapping_df

# %% [markdown]
# <h2>Extract Metadata from Dicom Object</h2>

# %%
dicom_to_metadata = DicomToMetadata() \
    .setInputCol("content") \
    .setOutputCol("metadata")

# %%
df = spark.read.format("binaryFile").load("./data/visual/dicom/David_Douglas.dcm")

result = dicom_to_metadata.transform(df).select("metadata").collect()[0].asDict()["metadata"]

json_result = json.loads(result)

json_result
# Out:
# /usr/local/lib/python3.12/dist-packages/sparkocr/transformers/dicom/dicom_metadata_deidentifier.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# {'ImageType': "['DERIVED', 'PRIMARY', 'POST_PROCESSED', 'RT', '', '', '', '', '100000']",
#  'SOPClassUID': '1.2.840.10008.5.1.4.1.1.1',
#  'SOPInstanceUID': '2.25.112784503178059210578740147414000844278',
#  'StudyDate': '20130713',
#  'SeriesDate': '20130713',
#  'AcquisitionDate': '20130713',
#  'ContentDate': '20130713',
#  'StudyTime': '085957',
#  'SeriesTime': '090020.000',
#  'AcquisitionTime': '090020.408',
#  'ContentTime': '090143.249',
#  'AccessionNumber': '20130714E864535',
#  'Modality': 'CR',
#  'Manufacturer': 'FUJIFILM Corporation',
#  'InstitutionName': 'Scott Community Hospital',
#  'InstitutionAddress': '334 Michael Manor Sarahview, PA 56560',
#  "ReferringPhysician'sName": 'HUGHES^KATHLEEN',
#  "ReferringPhysician'sAddress": '0544 Green Inlet Jeffreyland, HI 66060',
#  'StudyDescription': 'XR CHEST AP PORTABLE for Douglas Davidson',
#  'ProcedureCodeSequence': [{'CodeValue': 'CHESTAPPAP',
#    'CodingSchemeDesignator': 'SECTRA',
#    'CodeMeaning': 'XR CHEST AP PORTABLE'}],
#  "PerformingPhysician'sName": 'BROWN^PETER',
#  'DerivationDescription': 'G1.0e#1.60+0.20,MDR0.2AM0.6',
#  'PrivateCreator': 'FDMS 1.0',
#  "Patient'sName": 'DAVIDSON^DOUGLAS',
#  'PatientID': '292821506',
#  "Patient'sBirthDate": '19760616',
#  "Patient'sSex": 'M',
#  "Patient'sAge": '037Y',
#  'ClinicalTrialTimePointID': '',
#  'Privatetagdata': "b'87009668'",
#  'Contrast/BolusAgent': '',
#  'BodyPartExamined': 'CHEST',
#  'SoftwareVersions': 'DR-ID 300CL APL Software V7.4.0017',
#  'ImagerPixelSpacing': '[0.20, 0.20]',
#  'AcquisitionDeviceProcessingDescription': 'CHEST AP PORT X-WISE GRID',
#  'AcquisitionDeviceProcessingCode': '0200',
#  'ExposureIndex': '319',
#  'TargetExposureIndex': '876',
#  'DeviationIndex': '-4.4',
#  'PositionerType': 'NONE',
#  'ViewPosition': '',
#  'Sensitivity': '318',
#  'DetectorDescription': 'Fcr',
#  'DetectorID': '',
#  'ContributingEquipmentSequence': [{'Manufacturer': 'SECTRA',
#    'ContributionDateTime': '20120224142721',
#    'PurposeofReferenceCodeSequence': [{'CodeValue': '109103',
#      'CodingSchemeDesignator': 'DCM',
#      'CodeMeaning': 'Modifying Equipment'}]}],
#  'StudyInstanceUID': '2.25.106461954783291641048254423668956446198',
#  'SeriesInstanceUID': '2.25.22373700284337223907674770690654453238',
#  'StudyID': '',
#  'SeriesNumber': '1002',
#  'AcquisitionNumber': '003',
#  'InstanceNumber': '1002',
#  'PatientOrientation': '',
#  'Laterality': '',
#  'SamplesperPixel': '1',
#  'PhotometricInterpretation': 'MONOCHROME1',
#  'Rows': '1760',
#  'Columns': '2140',
#  'PixelSpacing': '[0.20, 0.20]',
#  'BitsAllocated': '16',
#  'BitsStored': '10',
#  'HighBit': '9',
#  'PixelRepresentation': '0',
#  'LongitudinalTemporalInformationModified': 'MODIFIED',
#  'WindowCenter': '511',
#  'WindowWidth': '1023',
#  'RescaleIntercept': '0',
#  'RescaleSlope': '1',
#  'RescaleType': 'US',
#  'LossyImageCompression': '00',
#  'PerformedProtocolCodeSequence': [{'CodeValue': 'FCR0200-0011',
#    'CodingSchemeDesignator': 'Fuji Standard',
#    'CodeMeaning': 'CHEST AP PORT X-WISE GRID'}],
#  'ImageDisplayFormat': 'STANDARD\\1,1',
#  'AnnotationDisplayFormatID': 'CR00',
#  'FilmOrientation': 'LANDSCAPE',
#  'BorderDensity': 'BLACK',
#  'Trim': 'NO'}

# %% [markdown]
# <h2>Run Deidentify Dicom Metadata and Extract Results</h2>

# %%
csv_path = pkg_resources.resource_filename('sparkocr', "resources/ocr/dicom/default_dicom_strategy.csv")

strategy_csv = pd.read_csv(csv_path)

strategy_csv.head(10)
# Out:
#           Tags  VR                             Name Status  \
# 0  (0002,0100)  UI  Private Information Creator UID    NaN
# 1  (0002,0102)  OB              Private Information    NaN
# 2  (0004,1130)  CS                      File-set ID    NaN
# 3  (0004,1141)  CS      File-set Descriptor File ID    NaN
# 4  (0004,1432)  UI               Private Record UID    NaN
# 5  (0004,1500)  CS               Referenced File ID    NaN
# 6  (0008,0012)  DA           Instance Creation Date    NaN
# 7  (0008,0014)  UI             Instance Creator UID    NaN
# 8  (0008,0020)  DA                       Study Date    NaN
# 9  (0008,0021)  DA                      Series Date    NaN
#
#                       Action Repeatable
# 0                     hashId        NaN
# 1                     hashId        NaN
# 2                     hashId        NaN
# 3                     hashId        NaN
# 4                     hashId        NaN
# 5                     hashId        NaN
# 6  shiftDateByRandomNbOfDays        NaN
# 7                     hashId        NaN
# 8   shiftDateByFixedNbOfDays        112
# 9  shiftDateByRandomNbOfDays        NaN

# %%
dicom_deidentifier = DicomMetadataDeidentifier() \
    .setInputCols(["content"]) \
    .setOutputCol("dicom_metadata_cleaned") \
    .setRemovePrivateTags(False) \
    .setPlaceholderText("<hidden>") \
    .setStrategyFile(csv_path)

# %%
df = spark.read.format("binaryFile").load("./data/visual/dicom/David_Douglas.dcm")

result = dicom_deidentifier.transform(df).write \
  .format("binaryFormat") \
  .option("type", "dicom") \
  .option("field", "dicom_metadata_cleaned") \
  .option("nameField", "fileName") \
  .option("extension", "dcm") \
  .option("prefix", "de-id-") \
  .mode("overwrite") \
  .save("./data/result_metadata/")
# Out:
# 20:25:53, INFO Run DicomMetadataDeidentifier
# 20:25:53, INFO DEBUG: tag:(2, 256), vr:UI, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(2, 258), vr:OB, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(4, 4400), vr:CS, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(4, 4417), vr:CS, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(4, 5170), vr:UI, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(4, 5376), vr:CS, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(8, 18), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 20:25:53, INFO DEBUG: tag:(8, 20), vr:UI, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(8, 32), vr:DA, action:shiftDateByFixedNbOfDays, option:112
# 20:25:53, INFO Run DicomMetadataDeidentifier:vr:DA, action:shiftDateByFixedNbOfDays
# 20:25:53, INFO DEBUG: tag:(8, 33), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 20:25:53, INFO Run DicomMetadataDeidentifier:vr:DA, action:shiftDateByRandomNbOfDays
# 20:25:53, INFO DEBUG: tag:(8, 34), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 20:25:53, INFO Run DicomMetadataDeidentifier:vr:DA, action:shiftDateByRandomNbOfDays
# 20:25:53, INFO DEBUG: tag:(8, 35), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 20:25:53, INFO Run DicomMetadataDeidentifier:vr:DA, action:shiftDateByRandomNbOfDays
# 20:25:53, INFO DEBUG: tag:(8, 36), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 20:25:53, INFO DEBUG: tag:(8, 37), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 20:25:53, INFO DEBUG: tag:(8, 42), vr:DT, action:shiftDateByRandomNbOfDays, option:None
# 20:25:53, INFO DEBUG: tag:(8, 80), vr:SH, action:hashId, option:None
# 20:25:53, INFO Run DicomMetadataDeidentifier:vr:SH, action:hashId
# /usr/local/lib/python3.12/dist-packages/pydicom/valuerep.py:440: UserWarning: The value length (44) exceeds the maximum length of 16 allowed for VR SH.
#   warn_and_log(msg)
# 20:25:53, INFO DEBUG: tag:(8, 88), vr:UI, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(8, 128), vr:LO, action:remove, option:None
# 20:25:53, INFO Run DicomMetadataDeidentifier:vr:LO, action:remove
# 20:25:53, INFO DEBUG: tag:(8, 129), vr:ST, action:remove, option:None
# 20:25:53, INFO Run DicomMetadataDeidentifier:vr:ST, action:remove
# 20:25:53, INFO DEBUG: tag:(8, 130), vr:SQ, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(8, 144), vr:PN, action:remove, option:None
# 20:25:53, INFO Run DicomMetadataDeidentifier:vr:PN, action:remove
# 20:25:53, INFO DEBUG: tag:(8, 146), vr:ST, action:remove, option:None
# 20:25:53, INFO Run DicomMetadataDeidentifier:vr:ST, action:remove
# 20:25:53, INFO DEBUG: tag:(8, 148), vr:SH, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(8, 156), vr:PN, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(8, 269), vr:UI, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(8, 513), vr:SH, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(8, 4112), vr:SH, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(8, 4160), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(8, 4168), vr:PN, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(8, 4176), vr:PN, action:remove, option:None
# 20:25:53, INFO Run DicomMetadataDeidentifier:vr:PN, action:remove
# 20:25:53, INFO DEBUG: tag:(8, 4192), vr:PN, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(8, 4208), vr:PN, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(8, 4501), vr:UI, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(8, 12304), vr:UI, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(16, 16), vr:PN, action:remove, option:None
# 20:25:53, INFO Run DicomMetadataDeidentifier:vr:PN, action:remove
# 20:25:53, INFO DEBUG: tag:(16, 32), vr:LO, action:hashId, option:None
# 20:25:53, INFO Run DicomMetadataDeidentifier:vr:LO, action:hashId
# 20:25:53, INFO DEBUG: tag:(16, 33), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(16, 48), vr:DA, action:shiftDateByRandomNbOfDays, option:True
# 20:25:53, INFO Run DicomMetadataDeidentifier:vr:DA, action:shiftDateByRandomNbOfDays
# 20:25:53, INFO DEBUG: tag:(16, 51), vr:LO, action:shiftDateByRandomNbOfDays, option:True
# 20:25:53, INFO DEBUG: tag:(16, 52), vr:LO, action:shiftDateByRandomNbOfDays, option:True
# 20:25:53, INFO DEBUG: tag:(16, 4096), vr:LO, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(16, 4097), vr:PN, action:replaceWithRandomName, option:None
# 20:25:53, INFO DEBUG: tag:(16, 4098), vr:SQ, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(16, 4101), vr:PN, action:replaceWithRandomName, option:coherent
# 20:25:53, INFO DEBUG: tag:(16, 4112), vr:AS, action:shiftDateByRandomNbOfDays, option:None
# 20:25:53, INFO Run DicomMetadataDeidentifier:vr:AS, action:shiftDateByRandomNbOfDays
# 20:25:53, INFO DEBUG: tag:(16, 4160), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(16, 4176), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(16, 4192), vr:PN, action:replaceWithRandomName, option:None
# 20:25:53, INFO DEBUG: tag:(16, 4224), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(16, 4225), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(16, 4240), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(16, 8528), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(16, 8530), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(16, 8532), vr:SH, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(16, 8533), vr:LT, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(16, 8656), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 20:25:53, INFO DEBUG: tag:(16, 8688), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(16, 8855), vr:PN, action:replaceWithRandomName, option:None
# 20:25:53, INFO DEBUG: tag:(16, 8857), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(18, 16), vr:LO, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(18, 32), vr:LO, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(18, 48), vr:LO, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(18, 49), vr:LO, action:replaceWithRandomName, option:None
# 20:25:53, INFO DEBUG: tag:(18, 64), vr:LO, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(18, 66), vr:LO, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(18, 80), vr:LO, action:hashId, option:None
# 20:25:53, INFO Run DicomMetadataDeidentifier:vr:LO, action:hashId
# 20:25:53, INFO DEBUG: tag:(18, 96), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(18, 98), vr:CS, action:replaceWithLiteral, option:YES
# 20:25:53, INFO DEBUG: tag:(18, 113), vr:LO, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(18, 129), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(18, 130), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(20, 260), vr:PN, action:replaceWithRandomName, option:None
# 20:25:53, INFO DEBUG: tag:(20, 8198), vr:PN, action:replaceWithRandomName, option:None
# 20:25:53, INFO DEBUG: tag:(24, 21), vr:CS, action:replaceWithLiteral, option:Chest
# 20:25:53, INFO Run DicomMetadataDeidentifier:vr:CS, action:replaceWithLiteral
# /usr/local/lib/python3.12/dist-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR CS: 'Chest'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# 20:25:53, INFO DEBUG: tag:(24, 4114), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 20:25:53, INFO DEBUG: tag:(24, 4608), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 20:25:53, INFO DEBUG: tag:(24, 28684), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 20:25:53, INFO DEBUG: tag:(32, 13), vr:UI, action:hashId, option:None
# 20:25:53, INFO Run DicomMetadataDeidentifier:vr:UI, action:hashId
# 20:25:53, INFO DEBUG: tag:(32, 14), vr:UI, action:hashId, option:None
# 20:25:53, INFO Run DicomMetadataDeidentifier:vr:UI, action:hashId
# 20:25:53, INFO DEBUG: tag:(32, 16), vr:SH, action:hashId, option:None
# 20:25:53, INFO Run DicomMetadataDeidentifier:vr:SH, action:hashId
# 20:25:53, INFO DEBUG: tag:(32, 82), vr:UI, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(32, 512), vr:UI, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(32, 13313), vr:CS, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(32, 13316), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(32, 13318), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(32, 37217), vr:UI, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(32, 37220), vr:UI, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(40, 771), vr:CS, action:replaceWithLiteral, option:MODIFIED
# 20:25:53, INFO Run DicomMetadataDeidentifier:vr:CS, action:replaceWithLiteral
# 20:25:53, INFO DEBUG: tag:(40, 16384), vr:LT, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(50, 18), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(50, 4096), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 20:25:53, INFO DEBUG: tag:(50, 4146), vr:PN, action:replaceWithRandomName, option:None
# 20:25:53, INFO DEBUG: tag:(50, 4147), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(50, 4160), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 20:25:53, INFO DEBUG: tag:(50, 4176), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 20:25:53, INFO DEBUG: tag:(56, 16), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(56, 17), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(56, 30), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(56, 32), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 20:25:53, INFO DEBUG: tag:(56, 96), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(56, 97), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(56, 768), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(64, 6), vr:PN, action:replaceWithRandomName, option:None
# 20:25:53, INFO DEBUG: tag:(64, 579), vr:SH, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(64, 4097), vr:SH, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(64, 4100), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(64, 4101), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(64, 4112), vr:PN, action:replaceWithRandomName, option:None
# 20:25:53, INFO DEBUG: tag:(64, 4354), vr:ST, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(64, 4355), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(64, 8200), vr:PN, action:replaceWithRandomName, option:None
# 20:25:53, INFO DEBUG: tag:(64, 8208), vr:SH, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(64, 16437), vr:SQ, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(64, 16439), vr:PN, action:replaceWithRandomName, option:None
# 20:25:53, INFO DEBUG: tag:(64, 40999), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(64, 41075), vr:SQ, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(64, 41077), vr:PN, action:replaceWithRandomName, option:None
# 20:25:53, INFO DEBUG: tag:(64, 41080), vr:SQ, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(64, 41082), vr:SQ, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(64, 41251), vr:PN, action:replaceWithRandomName, option:coherent
# 20:25:53, INFO DEBUG: tag:(64, 41252), vr:UI, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(64, 41812), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(64, 56076), vr:UI, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(64, 56077), vr:UI, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(112, 1), vr:SQ, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(112, 132), vr:PN, action:replaceWithRandomName, option:None
# 20:25:53, INFO DEBUG: tag:(112, 794), vr:UI, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(136, 512), vr:SQ, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(136, 2308), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(136, 2310), vr:ST, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(136, 2320), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(136, 2322), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(1024, 256), vr:UI, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(1024, 1028), vr:OB, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(1024, 1360), vr:SQ, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(1024, 1377), vr:SQ, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(8240, 32), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(12294, 8), vr:DA, action:shiftDateByRandomNbOfDays, option:None
# 20:25:53, INFO DEBUG: tag:(12294, 36), vr:UI, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(12294, 166), vr:PN, action:replaceWithRandomName, option:None
# 20:25:53, INFO DEBUG: tag:(12294, 194), vr:UI, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(12298, 19), vr:UI, action:hashId, option:None
# 20:25:53, INFO DEBUG: tag:(12302, 8), vr:PN, action:replaceWithRandomName, option:None
# 20:25:53, INFO DEBUG: tag:(16384, 16), vr:LT, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(16384, 16384), vr:LT, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(16392, 66), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(16392, 258), vr:PN, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(16392, 266), vr:PN, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(16392, 268), vr:PN, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(16392, 273), vr:SQ, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(16392, 276), vr:PN, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(16392, 281), vr:PN, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(16392, 282), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(16392, 514), vr:LO, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(65532, 65532), vr:OB, action:remove, option:None
# 20:25:53, INFO DEBUG: tag:(-1025, 1), vr:SH, action:remove, option:None
# /usr/local/lib/python3.12/dist-packages/pydicom/dataset.py:589: UserWarning: Invalid value '(-1025, 1)' used with the 'in' operator: must be an element tag as a 2-tuple or int, or an element keyword
#   warn_and_log(msg)
# 25/10/22 20:25:53 WARN BasicWriteTaskStatsTracker: Expected 1 files, but only saw 0. This could be due to the output format not writing empty files, or files being not immediately visible in the filesystem.

# %% [markdown]
# <h2>Run DicomToMetadata and Extract Results</h2>

# %%
df = spark.read.format("binaryFile").load("./data/result_metadata/*.dcm")

deid_result = dicom_to_metadata.transform(df).select("metadata").collect()[0].asDict()["metadata"]

json_deid_result = json.loads(deid_result)

json_deid_result
# Out:
# {'ImageType': "['DERIVED', 'PRIMARY', 'POST_PROCESSED', 'RT', '', '', '', '', '100000']",
#  'SOPClassUID': '1.2.840.10008.5.1.4.1.1.1',
#  'SOPInstanceUID': '2.25.112784503178059210578740147414000844278',
#  'StudyDate': '20131102',
#  'SeriesDate': '20130819',
#  'AcquisitionDate': '20130616',
#  'ContentDate': '20130519',
#  'StudyTime': '085957',
#  'SeriesTime': '090020.000',
#  'AcquisitionTime': '090020.408',
#  'ContentTime': '090143.249',
#  'AccessionNumber': '2.25.104661169016722362372224050231930259815',
#  'Modality': 'CR',
#  'Manufacturer': 'FUJIFILM Corporation',
#  'InstitutionName': '<hidden>',
#  'InstitutionAddress': '<hidden>',
#  "ReferringPhysician'sName": '<hidden>',
#  "ReferringPhysician'sAddress": '<hidden>',
#  'StudyDescription': 'XR CHEST AP PORTABLE for Douglas Davidson',
#  'ProcedureCodeSequence': [{'CodeValue': 'CHESTAPPAP',
#    'CodingSchemeDesignator': 'SECTRA',
#    'CodeMeaning': 'XR CHEST AP PORTABLE'}],
#  "PerformingPhysician'sName": '<hidden>',
#  'DerivationDescription': 'G1.0e#1.60+0.20,MDR0.2AM0.6',
#  'PrivateCreator': 'FDMS 1.0',
#  "Patient'sName": '<hidden>',
#  'PatientID': '2.25.104661169016722362372224050231930259815',
#  "Patient'sBirthDate": '19760522',
#  "Patient'sSex": 'M',
#  "Patient'sAge": '059D',
#  'ClinicalTrialTimePointID': '2.25.104661169016722362372224050231930259815',
#  'Privatetagdata': "b'87009668'",
#  'Contrast/BolusAgent': '',
#  'BodyPartExamined': 'Chest',
#  'SoftwareVersions': 'DR-ID 300CL APL Software V7.4.0017',
#  'ImagerPixelSpacing': '[0.20, 0.20]',
#  'AcquisitionDeviceProcessingDescription': 'CHEST AP PORT X-WISE GRID',
#  'AcquisitionDeviceProcessingCode': '0200',
#  'ExposureIndex': '319',
#  'TargetExposureIndex': '876',
#  'DeviationIndex': '-4.4',
#  'PositionerType': 'NONE',
#  'ViewPosition': '',
#  'Sensitivity': '318',
#  'DetectorDescription': 'Fcr',
#  'DetectorID': '',
#  'ContributingEquipmentSequence': [{'Manufacturer': 'SECTRA',
#    'ContributionDateTime': '20120224142721',
#    'PurposeofReferenceCodeSequence': [{'CodeValue': '109103',
#      'CodingSchemeDesignator': 'DCM',
#      'CodeMeaning': 'Modifying Equipment'}]}],
#  'StudyInstanceUID': '2.25.104661169016722362372224050231930259815',
#  'SeriesInstanceUID': '2.25.104661169016722362372224050231930259815',
#  'StudyID': '2.25.104661169016722362372224050231930259815',
#  'SeriesNumber': '1002',
#  'AcquisitionNumber': '003',
#  'InstanceNumber': '1002',
#  'PatientOrientation': '',
#  'Laterality': '',
#  'SamplesperPixel': '1',
#  'PhotometricInterpretation': 'MONOCHROME1',
#  'Rows': '1760',
#  'Columns': '2140',
#  'PixelSpacing': '[0.20, 0.20]',
#  'BitsAllocated': '16',
#  'BitsStored': '10',
#  'HighBit': '9',
#  'PixelRepresentation': '0',
#  'LongitudinalTemporalInformationModified': 'MODIFIED',
#  'WindowCenter': '511',
#  'WindowWidth': '1023',
#  'RescaleIntercept': '0',
#  'RescaleSlope': '1',
#  'RescaleType': 'US',
#  'LossyImageCompression': '00',
#  'PerformedProtocolCodeSequence': [{'CodeValue': 'FCR0200-0011',
#    'CodingSchemeDesignator': 'Fuji Standard',
#    'CodeMeaning': 'CHEST AP PORT X-WISE GRID'}],
#  'ImageDisplayFormat': 'STANDARD\\1,1',
#  'AnnotationDisplayFormatID': 'CR00',
#  'FilmOrientation': 'LANDSCAPE',
#  'BorderDensity': 'BLACK',
#  'Trim': 'NO'}

# %% [markdown]
# <h3>Compare the Tags with Changes</h3>

# %%
pd_df = compare_dicom_metadata(json_result, json_deid_result)
pd_df[pd_df["Value Changed"] == True].head(50)
# Out:
#                             Key                                Original Value  \
# 3                     StudyDate                                      20130713
# 4                    SeriesDate                                      20130713
# 5               AcquisitionDate                                      20130713
# 6                   ContentDate                                      20130713
# 11              AccessionNumber                               20130714E864535
# 14              InstitutionName                      Scott Community Hospital
# 15           InstitutionAddress         334 Michael Manor Sarahview, PA 56560
# 16     ReferringPhysician'sName                               HUGHES^KATHLEEN
# 17  ReferringPhysician'sAddress        0544 Green Inlet Jeffreyland, HI 66060
# 20    PerformingPhysician'sName                                   BROWN^PETER
# 23                Patient'sName                              DAVIDSON^DOUGLAS
# 24                    PatientID                                     292821506
# 25           Patient'sBirthDate                                      19760616
# 27                 Patient'sAge                                          037Y
# 28     ClinicalTrialTimePointID
# 31             BodyPartExamined                                         CHEST
# 45             StudyInstanceUID  2.25.106461954783291641048254423668956446198
# 46            SeriesInstanceUID   2.25.22373700284337223907674770690654453238
# 47                      StudyID
#
#                                   Redacted Value  Value Changed
# 3                                       20131102           True
# 4                                       20130819           True
# 5                                       20130616           True
# 6                                       20130519           True
# 11  2.25.104661169016722362372224050231930259815           True
# 14                                      <hidden>           True
# 15                                      <hidden>           True
# 16                                      <hidden>           True
# 17                                      <hidden>           True
# 20                                      <hidden>           True
# 23                                      <hidden>           True
# 24  2.25.104661169016722362372224050231930259815           True
# 25                                      19760522           True
# 27                                          059D           True
# 28  2.25.104661169016722362372224050231930259815           True
# 31                                         Chest           True
# 45  2.25.104661169016722362372224050231930259815           True
# 46  2.25.104661169016722362372224050231930259815           True
# 47  2.25.104661169016722362372224050231930259815           True

# %%
import shutil
shutil.rmtree("./data/result_metadata/")
