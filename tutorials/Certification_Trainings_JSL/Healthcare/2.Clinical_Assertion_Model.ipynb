# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/spark-nlp-workshop/blob/master/tutorials/Certification_Trainings_JSL/Healthcare/2.Clinical_Assertion_Model.ipynb)

# %% [markdown]
# # Clinical Assertion Status Model
#
#
# The deep neural network architecture for assertion status detection in Spark NLP is based on a Bi-LSTM framework, and is a modified version of the architecture proposed by Federico Fancellu, Adam Lopez and Bonnie Webber ([Neural Networks For Negation Scope Detection](https://aclanthology.org/P16-1047.pdf)). Its goal is to classify the assertions made on given medical concepts as being present, absent, or possible in the patient, conditionally present in the patient under certain circumstances,
# hypothetically present in the patient at some future point, and
# mentioned in the patient report but associated with someoneelse.
# In the proposed implementation, input units depend on the
# target tokens (a named entity) and the neighboring words that
# are explicitly encoded as a sequence using word embeddings.
# Similar to paper mentioned above,  it is observed that that 95% of the scope tokens (neighboring words) fall in a window of 9 tokens to the left and 15
# to the right of the target tokens in the same dataset. Therefore, the same window size was implemented and it following parameters were used: learning
# rate 0.0012, dropout 0.05, batch size 64 and a maximum sentence length 250. The model has been implemented within
# Spark NLP as an annotator called AssertionDLModel. After
# training 20 epoch and measuring accuracy on the official test
# set, this implementation exceeds the latest state-of-the-art
# accuracy benchmarks as summarized as following table:
#
# |Assertion Label|Spark NLP|Latest Best|
# |-|-|-|
# |Absent       |0.944 |0.937|
# |Someone-else |0.904|0.869|
# |Conditional  |0.441|0.422|
# |Hypothetical |0.862|0.890|
# |Possible     |0.680|0.630|
# |Present      |0.953|0.957|
# |micro F1     |0.939|0.934|

# %% [markdown]
# **Colab Setup**

# %%
# Install the johnsnowlabs library to access Spark-OCR and Spark-NLP for Healthcare, Finance, and Legal.
! pip install -q johnsnowlabs

# %%
from google.colab import files
print('Please Upload your John Snow Labs License using the button below')
license_keys = files.upload()

# %%
import johnsnowlabs as jsl
from johnsnowlabs import * 

# After uploading your license run this to install all licensed Python Wheels and pre-download Jars the Spark Session JVM
jsl.install()

# %%
import johnsnowlabs as jsl
from johnsnowlabs import * 
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# Automatically load license data and start a session with all jars user has access to
spark = jsl.start(exclude_ocr = True)

# %% [markdown]
# # Clinical Assertion Models (with pretrained models)

# %% [markdown]
# |    | model_name              |Predicted Entities|
# |---:|:------------------------|-|
# |  1 | [assertion_dl](https://nlp.johnsnowlabs.com/2021/01/26/assertion_dl_en.html)            |Present, Absent, Possible, conditional, hypothetical, associated_with_someone_else|
# |  2 | [assertion_dl_biobert](https://nlp.johnsnowlabs.com/2021/01/26/assertion_dl_biobert_en.html)    |Present, Absent, Possible, conditional, hypothetical, associated_with_someone_else|
# |  3 | [assertion_dl_healthcare](https://nlp.johnsnowlabs.com/2020/09/23/assertion_dl_healthcare_en.html) |Present, Absent, Possible, conditional, hypothetical, associated_with_someone_else|
# |  4 | [assertion_dl_large](https://nlp.johnsnowlabs.com/2020/05/21/assertion_dl_large_en.html)      |Present, Absent, Possible, conditional, hypothetical, associated_with_someone_else|
# |  5 | [assertion_dl_radiology](https://nlp.johnsnowlabs.com/2021/03/18/assertion_dl_radiology_en.html)   |Confirmed, Suspected, Negative|
# |  6 | [assertion_jsl](https://nlp.johnsnowlabs.com/2021/07/24/assertion_jsl_en.html)           |Present, Absent, Possible, Planned, Someoneelse, Past, Family, Hypotetical|
# |  7 | [assertion_jsl_large](https://nlp.johnsnowlabs.com/2021/07/24/assertion_jsl_large_en.html)     |present, absent, possible, planned, someoneelse, past, hypothetical|
# |  8 |  [assertion_ml](https://nlp.johnsnowlabs.com/2020/01/30/assertion_ml_en.html) |Hypothetical, Present, Absent, Possible, Conditional, Associated_with_someone_else|
# |  9 | [assertion_dl_scope_L10R10](https://nlp.johnsnowlabs.com/2022/03/17/assertion_dl_scope_L10R10_en_3_0.html)| hypothetical, associated_with_someone_else, conditional, possible, absent, present|
# | 10 | [assertion_dl_biobert_scope_L10R10](https://nlp.johnsnowlabs.com/2022/03/24/assertion_dl_biobert_scope_L10R10_en_2_4.html)| hypothetical, associated_with_someone_else, conditional, possible, absent, present|
# | 11 | [assertion_jsl_augmented](https://nlp.johnsnowlabs.com/2022/09/15/assertion_jsl_augmented_en.html)| Present, Absent, Possible, Planned, Past, Family, Hypotetical, SomeoneElse|

# %% [markdown]
# ### Pretrained `assertion_jsl_augmented` model

# %%
# Annotator that transforms a text column from dataframe into an Annotation ready for NLP

documentAssembler = nlp.DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")

# Sentence Detector annotator, processes various sentences per line
sentenceDetector = nlp.SentenceDetector()\
    .setInputCols(["document"])\
    .setOutputCol("sentence")

# Tokenizer splits words in a relevant format for NLP
tokenizer = nlp.Tokenizer()\
    .setInputCols(["sentence"])\
    .setOutputCol("token")

# Clinical word embeddings trained on PubMED dataset
word_embeddings = nlp.WordEmbeddingsModel.pretrained("embeddings_clinical", "en", "clinical/models")\
    .setInputCols(["sentence", "token"])\
    .setOutputCol("embeddings")

# NER model trained on i2b2 (sampled from MIMIC) dataset
clinical_ner = medical.NerModel.pretrained("ner_jsl", "en", "clinical/models") \
    .setInputCols(["sentence", "token", "embeddings"]) \
    .setOutputCol("ner")\
    #.setIncludeAllConfidenceScores(False)

ner_converter = medical.NerConverterInternal() \
    .setInputCols(["sentence", "token", "ner"]) \
    .setOutputCol("ner_chunk")\
    .setWhiteList(["SYMPTOM","VS_FINDING","DISEASE_SYNDROME_DISORDER","ADMISSION_DISCHARGE","PROCEDURE"])

# Assertion model trained on i2b2 (sampled from MIMIC) dataset
clinical_assertion = medical.AssertionDLModel.pretrained("assertion_jsl_augmented", "en", "clinical/models") \
    .setInputCols(["sentence", "ner_chunk", "embeddings"]) \
    .setOutputCol("assertion")
    
nlpPipeline = Pipeline(stages=[
    documentAssembler, 
    sentenceDetector,
    tokenizer,
    word_embeddings,
    clinical_ner,
    ner_converter,
    clinical_assertion
    ])

empty_data = spark.createDataFrame([[""]]).toDF("text")

model = nlpPipeline.fit(empty_data)
# Out:
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ner_jsl download started this may take some time.
# [OK!]
# assertion_jsl_augmented download started this may take some time.
# [OK!]

# %%
medical.AssertionDLApproach().extractParamMap()
# Out:
# {Param(parent='AssertionDLApproach_2e0edd22511f', name='lazyAnnotator', doc='Whether this AnnotatorModel acts as lazy in RecursivePipelines'): False,
#  Param(parent='AssertionDLApproach_2e0edd22511f', name='label', doc='Column with one label per document'): 'label',
#  Param(parent='AssertionDLApproach_2e0edd22511f', name='batchSize', doc='Size for each batch in the optimization process'): 64,
#  Param(parent='AssertionDLApproach_2e0edd22511f', name='epochs', doc='Number of epochs for the optimization process'): 5,
#  Param(parent='AssertionDLApproach_2e0edd22511f', name='learningRate', doc='Learning rate for the optimization process'): 0.0012,
#  Param(parent='AssertionDLApproach_2e0edd22511f', name='dropout', doc='Dropout at the output of each layer'): 0.05,
#  Param(parent='AssertionDLApproach_2e0edd22511f', name='maxSentLen', doc='Max length for an input sentence.'): 250,
#  Param(parent='AssertionDLApproach_2e0edd22511f', name='includeConfidence', doc='whether to include confidence scores in annotation metadata'): False,
#  Param(parent='AssertionDLApproach_2e0edd22511f', name='scopeWindow', doc='The scope window of the assertion expression'): [-1,
#   -1]}

# %%
# we also have a LogReg based Assertion Model.
'''
clinical_assertion_ml = AssertionLogRegModel.pretrained("assertion_ml", "en", "clinical/models") \
    .setInputCols(["sentence", "ner_chunk", "embeddings"]) \
    .setOutputCol("assertion")
'''

# %%
text = """
GENERAL: He is an elderly gentleman in no acute distress. He is sitting up in bed eating his breakfast. He is alert and oriented and answering questions appropriately.
HEENT: Sclerae show mild arcus senilis in the right. Left is clear. Pupils are equally round and reactive to light. Extraocular movements are intact. Oropharynx is clear.
NECK: Supple. Trachea is midline. No jugular venous pressure distention is noted. No adenopathy in the cervical, supraclavicular, or axillary areas.
ABDOMEN: Soft and nontender. There may be some fullness in the left upper quadrant, although I do not appreciate a true spleen with inspiration.
EXTREMITIES: There is some edema, but no cyanosis and clubbing .
IMPRESSION: At this time is refractory anemia, which is transfusion dependent. He is on B12, iron, folic acid, and Procrit. There are no sign or symptom of blood loss and a recent esophagogastroduodenoscopy, which was negative. His creatinine was 1. 
  My impression at this time is that he probably has an underlying myelodysplastic syndrome or bone marrow failure. His creatinine on this hospitalization was up slightly to 1.6 and this may contribute to his anemia.
  At this time, my recommendation for the patient is that he undergoes further serologic evaluation with reticulocyte count, serum protein, and electrophoresis, LDH, B12, folate, erythropoietin level, and he should undergo a bone marrow aspiration and biopsy. 
  I have discussed the procedure in detail which the patient. I have discussed the risks, benefits, and successes of that treatment and usefulness of the bone marrow and predicting his cause of refractory anemia and further therapeutic interventions, which might be beneficial to him. 
  He is willing to proceed with the studies I have described to him. We will order an ultrasound of his abdomen because of the possible fullness of the spleen, and I will probably see him in follow up after this hospitalization.
  As always, we greatly appreciate being able to participate in the care of your patient. We appreciate the consultation of the patient. 
"""

# %%
light_model = LightPipeline(model)

light_result = light_model.fullAnnotate(text)[0]

chunks=[]
entities=[]
status=[]
confidence=[]

for n,m in zip(light_result['ner_chunk'],light_result['assertion']):
    
    chunks.append(n.result)
    entities.append(n.metadata['entity']) 
    status.append(m.result)
    confidence.append(m.metadata['confidence'])
        
df = pd.DataFrame({'chunks':chunks, 'entities':entities, 'assertion':status, 'confidence':confidence})

df
# Out:
#                                 chunks                   entities  \
# 0                             distress                    Symptom
# 1                        arcus senilis                    Symptom
# 2   jugular venous pressure distention                    Symptom
# 3                           adenopathy                    Symptom
# 4                            nontender                    Symptom
# 5                             fullness                    Symptom
# 6                                edema                    Symptom
# 7                             cyanosis                 VS_Finding
# 8                             clubbing                    Symptom
# 9                               anemia  Disease_Syndrome_Disorder
# 10                          blood loss                    Symptom
# 11          esophagogastroduodenoscopy                  Procedure
# 12            myelodysplastic syndrome  Disease_Syndrome_Disorder
# 13                 bone marrow failure  Disease_Syndrome_Disorder
# 14                     hospitalization        Admission_Discharge
# 15                              anemia  Disease_Syndrome_Disorder
# 16              bone marrow aspiration                  Procedure
# 17                              biopsy                  Procedure
# 18                              anemia  Disease_Syndrome_Disorder
# 19              fullness of the spleen                    Symptom
# 20                     hospitalization        Admission_Discharge
#
#        assertion confidence
# 0         Absent        1.0
# 1           Past        1.0
# 2         Absent        1.0
# 3         Absent        1.0
# 4         Absent        1.0
# 5       Possible     0.9999
# 6        Present        1.0
# 7         Absent        1.0
# 8         Absent        1.0
# 9   Hypothetical     0.9758
# 10        Absent        1.0
# 11        Absent        1.0
# 12      Possible        1.0
# 13      Possible        1.0
# 14          Past     0.9999
# 15       Present        1.0
# 16       Planned        1.0
# 17       Planned        1.0
# 18  Hypothetical      0.999
# 19      Possible        1.0
# 20       Planned        1.0

# %%
light_model = LightPipeline(model)

light_result = light_model.fullAnnotate(text)[0]

vis = viz.AssertionVisualizer()

vis.display(light_result, 'ner_chunk', 'assertion')
# Out:
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white"><br>GENERAL: He is an elderly gentleman in no acute </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #AF967EB3"><span class="spark-nlp-display-entity-name">distress </span><span class="spark-nlp-display-entity-type">Symptom</span><span class="spark-nlp-display-entity-resolution" style="background-color: #AF967EFF">Absent </span></span><span class="spark-nlp-display-others" style="background-color: white">. He is sitting up in bed eating his breakfast. He is alert and oriented and answering questions appropriately.<br>HEENT: Sclerae show mild </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #AF967EB3"><span class="spark-nlp-display-entity-name">arcus senilis </span><span class="spark-nlp-display-entity-type">Symptom</span><span class="spark-nlp-display-entity-resolution" style="background-color: #AF967EFF">Past </span></span><span class="spark-nlp-display-others" style="background-color: white"> in the right. Left is clear. Pupils are equally round and reactive to light. Extraocular movements are intact. Oropharynx is clear.<br>NECK: Supple. Trachea is midline. No </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #AF967EB3"><span class="spark-nlp-display-entity-name">jugular venous pressure distention </span><span class="spark-nlp-display-entity-type">Symptom</span><span class="spark-nlp-display-entity-resolution" style="background-color: #AF967EFF">Absent </span></span><span class="spark-nlp-display-others" style="background-color: white"> is noted. No </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #AF967EB3"><span class="spark-nlp-display-entity-name">adenopathy </span><span class="spark-nlp-display-entity-type">Symptom</span><span class="spark-nlp-display-entity-resolution" style="background-color: #AF967EFF">Absent </span></span><span class="spark-nlp-display-others" style="background-color: white"> in the cervical, supraclavicular, or axillary areas.<br>ABDOMEN: Soft and </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #AF967EB3"><span class="spark-nlp-display-entity-name">nontender </span><span class="spark-nlp-display-entity-type">Symptom</span><span class="spark-nlp-display-entity-resolution" style="background-color: #AF967EFF">Absent </span></span><span class="spark-nlp-display-others" style="background-color: white">. There may be some </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #AF967EB3"><span class="spark-nlp-display-entity-name">fullness </span><span class="spark-nlp-display-entity-type">Symptom</span><span class="spark-nlp-display-entity-resolution" style="background-color: #AF967EFF">Possible </span></span><span class="spark-nlp-display-others" style="background-color: white"> in the left upper quadrant, although I do not appreciate a true spleen with inspiration.<br>EXTREMITIES: There is some </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #AF967EB3"><span class="spark-nlp-display-entity-name">edema </span><span class="spark-nlp-display-entity-type">Symptom</span><span class="spark-nlp-display-entity-resolution" style="background-color: #AF967EFF">Present </span></span><span class="spark-nlp-display-others" style="background-color: white">, but no </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #9432B9B3"><span class="spark-nlp-display-entity-name">cyanosis </span><span class="spark-nlp-display-entity-type">VS_Finding</span><span class="spark-nlp-display-entity-resolution" style="background-color: #9432B9FF">Absent </span></span><span class="spark-nlp-display-others" style="background-color: white"> and </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #AF967EB3"><span class="spark-nlp-display-entity-name">clubbing </span><span class="spark-nlp-display-entity-type">Sym ...

# %%
nlu.to_pretty_df(model,text,output_level='chunk').columns
# Out:
# Index(['assertion', 'assertion_confidence', 'document', 'entities_ner_chunk',
#        'entities_ner_chunk_class', 'entities_ner_chunk_confidence',
#        'entities_ner_chunk_origin_chunk', 'entities_ner_chunk_origin_sentence',
#        'sentence_pragmatic', 'word_embedding_embeddings'],
#       dtype='object')

# %%
cols = [
     'entities_ner_chunk',
     'entities_ner_chunk_class', 
     'assertion',
     'assertion_confidence']
     
df = nlu.to_pretty_df(model,text,output_level='chunk')[cols].reset_index(drop=True)
df
# Out:
#                     entities_ner_chunk   entities_ner_chunk_class  \
# 0                             distress                    Symptom
# 1                        arcus senilis                    Symptom
# 2   jugular venous pressure distention                    Symptom
# 3                           adenopathy                    Symptom
# 4                            nontender                    Symptom
# 5                             fullness                    Symptom
# 6                                edema                    Symptom
# 7                             cyanosis                 VS_Finding
# 8                             clubbing                    Symptom
# 9                               anemia  Disease_Syndrome_Disorder
# 10                          blood loss                    Symptom
# 11          esophagogastroduodenoscopy                  Procedure
# 12            myelodysplastic syndrome  Disease_Syndrome_Disorder
# 13                 bone marrow failure  Disease_Syndrome_Disorder
# 14                     hospitalization        Admission_Discharge
# 15                              anemia  Disease_Syndrome_Disorder
# 16              bone marrow aspiration                  Procedure
# 17                              biopsy                  Procedure
# 18                              anemia  Disease_Syndrome_Disorder
# 19              fullness of the spleen                    Symptom
# 20                     hospitalization        Admission_Discharge
#
#        assertion assertion_confidence
# 0         Absent                  1.0
# 1           Past                  1.0
# 2         Absent                  1.0
# 3         Absent                  1.0
# 4         Absent                  1.0
# 5       Possible               0.9999
# 6        Present                  1.0
# 7         Absent                  1.0
# 8         Absent                  1.0
# 9   Hypothetical               0.9758
# 10        Absent                  1.0
# 11        Absent                  1.0
# 12      Possible                  1.0
# 13      Possible                  1.0
# 14          Past               0.9999
# 15       Present                  1.0
# 16       Planned                  1.0
# 17       Planned                  1.0
# 18  Hypothetical                0.999
# 19      Possible                  1.0
# 20       Planned                  1.0

# %%
# Downloading sample datasets.
! wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/mt_samples_10.csv

# %%
mt_samples_df = spark.createDataFrame(pd.read_csv("/content/mt_samples_10.csv", sep=',', index_col=["index"]).reset_index())
                
mt_samples_df.printSchema()
# Out:
# root
#  |-- index: long (nullable = true)
#  |-- text: string (nullable = true)

# %%
mt_samples_df.show()
# Out:
# +-----+--------------------+
# |index|                text|
# +-----+--------------------+
# |    0|Sample Type / Med...|
# |    1|Sample Type / Med...|
# |    2|Sample Type / Med...|
# |    3|Sample Type / Med...|
# |    4|Sample Type / Med...|
# |    5|Sample Type / Med...|
# |    6|Sample Type / Med...|
# |    7|Sample Type / Med...|
# |    8|Sample Type / Med...|
# |    9|Sample Type / Med...|
# +-----+--------------------+

# %%
result = model.transform(mt_samples_df)

# %%
result.show()
# Out:
# +-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |index|                text|            document|            sentence|               token|          embeddings|                 ner|           ner_chunk|           assertion|
# +-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |    0|Sample Type / Med...|[{document, 0, 54...|[{document, 0, 24...|[{token, 0, 5, Sa...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 68, 76, ...|[{assertion, 68, ...|
# |    1|Sample Type / Med...|[{document, 0, 32...|[{document, 0, 26...|[{token, 0, 5, Sa...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 68, 80, ...|[{assertion, 68, ...|
# |    2|Sample Type / Med...|[{document, 0, 42...|[{document, 0, 14...|[{token, 0, 5, Sa...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 68, 73, ...|[{assertion, 68, ...|
# |    3|Sample Type / Med...|[{document, 0, 20...|[{document, 0, 29...|[{token, 0, 5, Sa...|[{word_embeddings...|[{named_entity, 0...|                  []|                  []|
# |    4|Sample Type / Med...|[{document, 0, 34...|[{document, 0, 11...|[{token, 0, 5, Sa...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 102, 116...|[{assertion, 102,...|
# |    5|Sample Type / Med...|[{document, 0, 15...|[{document, 0, 28...|[{token, 0, 5, Sa...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 1399, 14...|[{assertion, 1399...|
# |    6|Sample Type / Med...|[{document, 0, 25...|[{document, 0, 15...|[{token, 0, 5, Sa...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 68, 73, ...|[{assertion, 68, ...|
# |    7|Sample Type / Med...|[{document, 0, 93...|[{document, 0, 19...|[{token, 0, 5, Sa...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 1063, 10...|[{assertion, 1063...|
# |    8|Sample Type / Med...|[{document, 0, 20...|[{document, 0, 15...|[{token, 0, 5, Sa...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 1019, 10...|[{assertion, 1019...|
# |    9|Sample Type / Med...|[{document, 0, 19...|[{document, 0, 15...|[{token, 0, 5, Sa...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 68, 95, ...|[{assertion, 68, ...|
# +-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+

# %%
result.select('sentence.result').take(1)
# Out:
# [Row(result=['Sample Type / Medical Specialty:\nHematology - Oncology\nSample Name:\nDischarge Summary - Mesothelioma - 1\nDescription:\nMesothelioma, pleural effusion, atrial fibrillation, anemia, ascites, esophageal reflux, and history of deep venous thrombosis.', '(Medical Transcription Sample Report)\nPRINCIPAL DIAGNOSIS:\nMesothelioma.', 'SECONDARY DIAGNOSES:\nPleural effusion, atrial fibrillation, anemia, ascites, esophageal reflux, and history of deep venous thrombosis.', 'PROCEDURES', '1. On August 24, 2007, decortication of the lung with pleural biopsy and transpleural fluoroscopy.', '2. On August 20, 2007, thoracentesis.', '3. On August 31, 2007, Port-A-Cath placement.', 'HISTORY AND PHYSICAL:\nThe patient is a 41-year-old Vietnamese female with a nonproductive cough that started last week.', 'She has had right-sided chest pain radiating to her back with fever starting yesterday.', 'She has a history of pericarditis and pericardectomy in May 2006 and developed cough with right-sided chest pain, and went to an urgent care center.', 'Chest x-ray revealed right-sided pleural effusion.', 'PAST MEDICAL HISTORY', '1. Pericardectomy.', '2. Pericarditis.', '2. Atrial fibrillation.', '4. RNCA with intracranial thrombolytic treatment.', '5 PTA of MCA.', '6. Mesenteric venous thrombosis.', '7. Pericardial window.', '8. Cholecystectomy.', '9. Left thoracentesis.', 'FAMILY HISTORY:\nNo family history of coronary artery disease, CVA, diabetes, CHF or MI.', 'The patient has one family member, a sister, with history of cancer.', 'SOCIAL HISTORY:\nShe is married.', 'Employed with the US Post Office.', 'She is a mother of three.', 'Denies tobacco, alcohol or illicit drug use.', 'MEDICATIONS', '1. Coumadin 1 mg daily.', 'Last INR was on Tuesday, August 14, 2007, and her INR was 2.3.', '2. Amiodarone 100 mg p.o. daily.', 'REVIEW OF SYSTEMS:\nComplete review of systems negative except as in pulmonary as noted above.', 'The patient also reports occasional numbness and tingling of her left arm.', 'PHYSICAL EXAMINATION\nVITAL SIGNS: Blood pressure 123/95, heart rate 83, respirations 20, temperature 97, and oxygen saturation 97%.', 'GENERAL: Positive nonproductive cough and pain with coughing.', 'HEENT: Pupils are equal and reactive to light and accommodation.', 'Tympanic membranes are clear.', 'NECK: Supple.', 'No lymphadenopathy.', 'No masses.', 'RESPIRATORY: Pleural friction rub is noted.', 'GI: Soft, nondistended, and nontender.', 'Positive bowel sounds.', 'No organomegaly.', 'EXTREMITIES: No edema, no clubbing, no cyanosis, no tenderness.', 'Full range of motion.', 'Normal pulses in all extremities.', 'SKIN: No breakdown or lesions.', 'No ulcers.', 'NEUROLOGIC: Grossly intact.', 'No focal deficits.', 'Awake, alert, and oriented to person, place, and time.', 'LABORATORY DATA:\nLabs are pending.', 'HOSPITAL COURSE:\nThe patient was admitted for a right-sided pleural effusion for thoracentesis on Monday by Dr. X. Her Coumadin was placed on hold.', 'A repeat echocardiogram was checked.', 'She was started on prophylaxis for DVT with Lovenox 40 mg subcutaneously.', 'Her history dated back to March 2005 when she first sought medical attention for evidence of pericarditis, which was treated with pericardial window in an outside hospital, at that time she was also found to have mesenteric pain and thrombosis, is now anticoagulated.', 'Her pericardial fluid was accumulated and she was seen by Dr. Y. At that time, she was recommended for pericardectomy, which was performed by Dr. Z. Review of her CT scan from March 2006 prior to her pericardectomy, already shows bilateral plural effusions.', 'The patient improved clinically after the pericardectomy with resolution of her symptoms.', 'Recently, she was readmitted to the hospital with chest pain and found to have bilateral pleural effusion, the right greater than the left.', 'CT of the chest also revealed a large mediastinal lymph node.', 'We reviewed the pathology obtained from the pericardectomy i ...

# %%
result.select(F.explode(F.arrays_zip(result.ner_chunk.result,  
                                     result.ner_chunk.begin, 
                                     result.ner_chunk.end, 
                                     result.ner_chunk.metadata, 
                                     result.assertion.result,
                                     result.assertion.metadata)).alias("cols")) \
      .select(F.expr("cols['0']").alias("chunk"),
              F.expr("cols['1']").alias("begin"),
              F.expr("cols['2']").alias("end"),
              F.expr("cols['3']['entity']").alias("ner_label"),
              F.expr("cols['3']['sentence']").alias("sent_id"),
              F.expr("cols['4']").alias("assertion"),
              F.expr("cols['5']['confidence']").alias("confidence") ).show(truncate=False)
# Out:
# +-------------------------+-----+---+-------------------------+-------+---------+----------+
# |chunk                    |begin|end|ner_label                |sent_id|assertion|confidence|
# +-------------------------+-----+---+-------------------------+-------+---------+----------+
# |Discharge                |68   |76 |Admission_Discharge      |0      |Past     |1.0       |
# |pleural effusion         |132  |147|Disease_Syndrome_Disorder|0      |Present  |0.9904    |
# |anemia                   |171  |176|Disease_Syndrome_Disorder|0      |Present  |0.8993    |
# |ascites                  |179  |185|Disease_Syndrome_Disorder|0      |Present  |0.9992    |
# |esophageal reflux        |188  |204|Disease_Syndrome_Disorder|0      |Present  |1.0       |
# |deep venous thrombosis   |222  |243|Disease_Syndrome_Disorder|0      |Past     |1.0       |
# |Pleural effusion         |340  |355|Disease_Syndrome_Disorder|2      |Present  |1.0       |
# |anemia                   |379  |384|Disease_Syndrome_Disorder|2      |Present  |1.0       |
# |ascites                  |387  |393|Disease_Syndrome_Disorder|2      |Present  |1.0       |
# |esophageal reflux        |396  |412|Disease_Syndrome_Disorder|2      |Present  |1.0       |
# |deep venous thrombosis   |430  |451|Disease_Syndrome_Disorder|2      |Past     |1.0       |
# |decortication of the lung|488  |512|Procedure                |4      |Past     |1.0       |
# |pleural biopsy           |519  |532|Procedure                |4      |Past     |1.0       |
# |transpleural fluoroscopy |538  |561|Procedure                |4      |Past     |1.0       |
# |thoracentesis            |587  |599|Procedure                |5      |Past     |1.0       |
# |Port-A-Cath placement    |625  |645|Procedure                |6      |Past     |1.0       |
# |cough                    |738  |742|Symptom                  |7      |Past     |1.0       |
# |chest pain               |792  |801|Symptom                  |8      |Past     |1.0       |
# |fever                    |830  |834|VS_Finding               |8      |Present  |1.0       |
# |pericarditis             |877  |888|Disease_Syndrome_Disorder|9      |Present  |0.9999    |
# +-------------------------+-----+---+-------------------------+-------+---------+----------+
# only showing top 20 rows

# %% [markdown]
# ### Pretrained `assertion_dl_radiology` model

# %%
documentAssembler = nlp.DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")

# Sentence Detector annotator, processes various sentences per line
sentenceDetector = nlp.SentenceDetectorDLModel\
    .pretrained("sentence_detector_dl_healthcare","en","clinical/models") \
    .setInputCols(["document"]) \
    .setOutputCol("sentence")

# Tokenizer splits words in a relevant format for NLP
tokenizer = nlp.Tokenizer()\
    .setInputCols(["sentence"])\
    .setOutputCol("token")

# Clinical word embeddings trained on PubMED dataset
word_embeddings = nlp.WordEmbeddingsModel.pretrained("embeddings_clinical", "en", "clinical/models")\
    .setInputCols(["sentence", "token"])\
    .setOutputCol("embeddings")

# NER model for radiology
radiology_ner = medical.NerModel.pretrained("ner_radiology", "en", "clinical/models") \
    .setInputCols(["sentence", "token", "embeddings"]) \
    .setOutputCol("ner")\
    #.setIncludeAllConfidenceScores(False)

ner_converter = nlp.NerConverter() \
    .setInputCols(["sentence", "token", "ner"]) \
    .setOutputCol("ner_chunk")\
    .setWhiteList(["ImagingFindings"])

# Assertion model trained on radiology dataset
radiology_assertion = medical.AssertionDLModel.pretrained("assertion_dl_radiology", "en", "clinical/models") \
    .setInputCols(["sentence", "ner_chunk", "embeddings"]) \
    .setOutputCol("assertion")

nlpPipeline = Pipeline(stages=[
    documentAssembler, 
    sentenceDetector,
    tokenizer,
    word_embeddings,
    radiology_ner,
    ner_converter,
    radiology_assertion
    ])

empty_data = spark.createDataFrame([[""]]).toDF("text")
radiologyAssertion_model = nlpPipeline.fit(empty_data)
# Out:
# sentence_detector_dl_healthcare download started this may take some time.
# Approximate size to download 367.3 KB
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ner_radiology download started this may take some time.
# [OK!]
# assertion_dl_radiology download started this may take some time.
# [OK!]

# %%
# A sample text from a radiology report

text = """No right-sided pleural effusion or pneumothorax is definitively seen and there are mildly displaced fractures of the left lateral 8th and likely 9th ribs."""

# %%
data = spark.createDataFrame([[text]]).toDF("text")

# %%
result = radiologyAssertion_model.transform(data)

# %%
result.select(F.explode(F.arrays_zip(result.ner_chunk.result, 
                                     result.ner_chunk.metadata, 
                                     result.assertion.result)).alias("cols")) \
      .select(F.expr("cols['0']").alias("chunk"),
              F.expr("cols['1']['entity']").alias("ner_label"),
              F.expr("cols['1']['sentence']").alias("sent_id"),
              F.expr("cols['2']").alias("assertion")).show(truncate=False)
# Out:
# +-------------------+---------------+-------+---------+
# |chunk              |ner_label      |sent_id|assertion|
# +-------------------+---------------+-------+---------+
# |effusion           |ImagingFindings|0      |Negative |
# |pneumothorax       |ImagingFindings|0      |Negative |
# |displaced fractures|ImagingFindings|0      |Confirmed|
# +-------------------+---------------+-------+---------+

# %% [markdown]
# ## Writing a generic Assertion + NER function

# %%
def get_base_pipeline (embeddings = 'embeddings_clinical'):

    documentAssembler = nlp.DocumentAssembler()\
        .setInputCol("text")\
        .setOutputCol("document")

  # Sentence Detector annotator, processes various sentences per line
    sentenceDetector = nlp.SentenceDetector()\
        .setInputCols(["document"])\
        .setOutputCol("sentence")

  # Tokenizer splits words in a relevant format for NLP
    tokenizer = nlp.Tokenizer()\
        .setInputCols(["sentence"])\
        .setOutputCol("token")

  # Clinical word embeddings trained on PubMED dataset
    word_embeddings = nlp.WordEmbeddingsModel.pretrained(embeddings, "en", "clinical/models")\
        .setInputCols(["sentence", "token"])\
        .setOutputCol("embeddings")

    base_pipeline = Pipeline(stages=[
                        documentAssembler,
                        sentenceDetector,
                        tokenizer,
                        word_embeddings])

    return base_pipeline



def get_clinical_assertion (embeddings, spark_df, nrows = 100, ner_model_name = 'ner_clinical', assertion_model_name="assertion_dl"):

  # NER model trained on i2b2 (sampled from MIMIC) dataset
    loaded_ner_model = medical.NerModel.pretrained(ner_model_name, "en", "clinical/models") \
        .setInputCols(["sentence", "token", "embeddings"]) \
        .setOutputCol("ner")

    ner_converter = nlp.NerConverter() \
        .setInputCols(["sentence", "token", "ner"]) \
        .setOutputCol("ner_chunk")

  # Assertion model trained on i2b2 (sampled from MIMIC) dataset
  # coming from sparknlp_jsl.annotator !!
    clinical_assertion = medical.AssertionDLModel.pretrained(assertion_model_name, "en", "clinical/models") \
        .setInputCols(["sentence", "ner_chunk", "embeddings"]) \
        .setOutputCol("assertion")
      

    base_model = get_base_pipeline (embeddings)

    nlpPipeline = Pipeline(stages=[
        base_model,
        loaded_ner_model,
        ner_converter,
        clinical_assertion])

    empty_data = spark.createDataFrame([[""]]).toDF("text")

    model = nlpPipeline.fit(empty_data)

    result = model.transform(spark_df.limit(nrows))

    result = result.withColumn("id", F.monotonically_increasing_id())

    result_df = result.select(F.explode(F.arrays_zip(result.ner_chunk.result, 
                                                     result.ner_chunk.metadata, 
                                                     result.assertion.result,
                                                     result.assertion.metadata)).alias("cols")) \
                      .select(F.expr("cols['0']").alias("chunk"),
                              F.expr("cols['1']['entity']").alias("ner_label"),
                              F.expr("cols['2']").alias("assertion"),
                              F.expr("cols['3']['confidence']").alias("confidence"))\
                      .filter("ner_label!='O'")

    return result_df

# %%
embeddings = 'embeddings_clinical'

ner_model_name = 'ner_clinical_large'

nrows = 100

ner_df = get_clinical_assertion (embeddings, mt_samples_df, nrows, ner_model_name)

ner_df.show(30,truncate=50)
# Out:
# ner_clinical_large download started this may take some time.
# [OK!]
# assertion_dl download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# +----------------------------+---------+---------+----------+
# |                       chunk|ner_label|assertion|confidence|
# +----------------------------+---------+---------+----------+
# |                Mesothelioma|  PROBLEM|  present|    0.9996|
# |                Mesothelioma|  PROBLEM|  present|    0.9996|
# |            pleural effusion|  PROBLEM|  present|    0.9997|
# |         atrial fibrillation|  PROBLEM|  present|    0.9998|
# |                      anemia|  PROBLEM|  present|    0.9997|
# |                     ascites|  PROBLEM|  present|    0.9997|
# |           esophageal reflux|  PROBLEM|  present|    0.9998|
# |      deep venous thrombosis|  PROBLEM|  present|    0.9998|
# |                Mesothelioma|  PROBLEM|  present|    0.9992|
# |            Pleural effusion|  PROBLEM|  present|    0.9999|
# |         atrial fibrillation|  PROBLEM|  present|       1.0|
# |                      anemia|  PROBLEM|  present|    0.9999|
# |                     ascites|  PROBLEM|  present|    0.9999|
# |           esophageal reflux|  PROBLEM|  present|    0.9999|
# |      deep venous thrombosis|  PROBLEM|  present|    0.9993|
# |   decortication of the lung|TREATMENT|  present|       1.0|
# |              pleural biopsy|     TEST|  present|    0.9999|
# |    transpleural fluoroscopy|     TEST|  present|    0.9997|
# |               thoracentesis|TREATMENT|  present|    0.9998|
# |       Port-A-Cath placement|TREATMENT|  present|       1.0|
# |       a nonproductive cough|  PROBLEM|  present|    0.9972|
# |      right-sided chest pain|  PROBLEM|  present|    0.9998|
# |                       fever|  PROBLEM|  present|    0.9998|
# |                pericarditis|  PROBLEM|  present|    0.9998|
# |              pericardectomy|TREATMENT|  present|    0.9999|
# |                       cough|  PROBLEM|  present|    0.9996|
# |      right-sided chest pain|  PROBLEM|  present|    0.9998|
# |                 Chest x-ray|     TEST|  present|    0.9999|
# |right-sided pleural effusion|  PROBLEM|  present|    0.9999|
# |              Pericardectomy|TREATMENT|  present|    0.9985|
# +----------------------------+---------+---------+----------+
# only showing top 30 rows

# %%
embeddings = 'embeddings_clinical'

ner_model_name = 'ner_posology'

nrows = 100

ner_df = get_clinical_assertion (embeddings, mt_samples_df, nrows, ner_model_name)

ner_df.show()
# Out:
# ner_posology download started this may take some time.
# [OK!]
# assertion_dl download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# +----------------+---------+------------+----------+
# |           chunk|ner_label|   assertion|confidence|
# +----------------+---------+------------+----------+
# |        Coumadin|     DRUG|hypothetical|    0.8709|
# |            1 mg| STRENGTH| conditional|    0.7772|
# |           daily|FREQUENCY| conditional|    0.5086|
# |      Amiodarone|     DRUG|hypothetical|    0.8589|
# |          100 mg| STRENGTH|hypothetical|    0.6143|
# |             p.o|    ROUTE|hypothetical|    0.7991|
# |           daily|FREQUENCY|     present|    0.9074|
# |        Coumadin|     DRUG|     present|    0.9997|
# |         Lovenox|     DRUG|     present|    0.9994|
# |           40 mg| STRENGTH|     present|    0.9982|
# |  subcutaneously|    ROUTE|     present|    0.9871|
# |    chemotherapy|     DRUG|     present|    0.9999|
# |       cisplatin|     DRUG|     present|    0.9999|
# |75 mg/centimeter| STRENGTH|     present|    0.9998|
# |          109 mg| STRENGTH|     present|    0.9999|
# |              IV|    ROUTE|     present|    0.9999|
# |       piggyback|     DRUG|     present|    0.9999|
# |    over 2 hours| DURATION|     present|    0.9999|
# |       September|     DRUG|     present|       1.0|
# |          Alimta|     DRUG|     present|       1.0|
# +----------------+---------+------------+----------+
# only showing top 20 rows

# %%
embeddings = 'embeddings_clinical'

ner_model_name = 'ner_posology_greedy'

entry_data = spark.createDataFrame([["The patient did not take a capsule of Advil."]]).toDF("text")

ner_df = get_clinical_assertion (embeddings, entry_data, nrows, ner_model_name)

ner_df.show()
# Out:
# ner_posology_greedy download started this may take some time.
# [OK!]
# assertion_dl download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# +----------------+---------+---------+----------+
# |           chunk|ner_label|assertion|confidence|
# +----------------+---------+---------+----------+
# |capsule of Advil|     DRUG|   absent|    0.9855|
# +----------------+---------+---------+----------+

# %%
embeddings = 'embeddings_clinical'

ner_model_name = 'ner_clinical'

entry_data = spark.createDataFrame([["The patient has no fever"]]).toDF("text")

ner_df = get_clinical_assertion (embeddings, entry_data, nrows, ner_model_name)

ner_df.show()
# Out:
# ner_clinical download started this may take some time.
# [OK!]
# assertion_dl download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# +-----+---------+---------+----------+
# |chunk|ner_label|assertion|confidence|
# +-----+---------+---------+----------+
# |fever|  PROBLEM|   absent|     0.998|
# +-----+---------+---------+----------+

# %%
def get_clinical_assertion_light (light_model, text):

  light_result = light_model.fullAnnotate(text)[0]

  chunks=[]
  entities=[]
  status=[]
  confidence=[]

  for n,m in zip(light_result['ner_chunk'],light_result['assertion']):
      
      chunks.append(n.result)
      entities.append(n.metadata['entity']) 
      status.append(m.result)
      confidence.append(m.metadata['confidence'])
          
  df = pd.DataFrame({'chunks':chunks, 'entities':entities, 'assertion':status,'confidence':confidence})

  return df

# %%
clinical_text = """
Patient with severe fever and sore throat. 
He shows no stomach pain and he maintained on an epidural and PCA for pain control.
He also became short of breath with climbing a flight of stairs.
After CT, lung tumor located at the right lower lobe. Father with Alzheimer.
"""

light_model = LightPipeline(model)

# get_clinical_assertion_light (light_model, clinical_text)

cols = [
     'entities_ner_chunk',
     'entities_ner_chunk_class', 
     'assertion',
     'assertion_confidence']
     
df = nlu.to_pretty_df(light_model,clinical_text, output_level='chunk')[cols]
df
# Out:
#                                  entities_ner_chunk  \
# 0                                             fever
# 0                                       sore throat
# 0                                      stomach pain
# 0                                              pain
# 0  short of breath with climbing a flight of stairs
# 0                                         Alzheimer
#
#     entities_ner_chunk_class     assertion assertion_confidence
# 0                 VS_Finding       Present                  1.0
# 0                    Symptom       Present                  1.0
# 0                    Symptom        Absent                  1.0
# 0                    Symptom  Hypothetical               0.9973
# 0                    Symptom       Present                  1.0
# 0  Disease_Syndrome_Disorder        Family               0.8136

# %% [markdown]
# # Oncological Assertion Models

# %% [markdown]
# Oncology Assertion Models
#
# |    | model_name              |Predicted Entities|
# |---:|:------------------------|-|
# | 1 | [assertion_oncology_wip](https://nlp.johnsnowlabs.com/2022/10/11/assertion_oncology_wip_en.html) | Medical_History, Family_History, Possible, Hypothetical_Or_Absent|
# | 2 | [assertion_oncology_problem_wip](https://nlp.johnsnowlabs.com/2022/10/11/assertion_oncology_problem_wip_en.html) |Present, Possible, Hypothetical, Absent, Family|
# | 3 | [assertion_oncology_treatment_wip](https://nlp.johnsnowlabs.com/2022/10/11/assertion_oncology_treatment_binary_wip_en.html) |Present, Planned, Past, Hypothetical, Absent|
# | 3 | [assertion_oncology_treatment_wip]() |Present, Planned, Past, Hypothetical, Absent|
# | 4 | [assertion_oncology_response_to_treatment_wip](https://nlp.johnsnowlabs.com/2022/10/11/assertion_oncology_response_to_treatment_wip_en.html) |Present_Or_Past, Hypothetical_Or_Absent|
# | 5 | [assertion_oncology_test_binary_wip](https://nlp.johnsnowlabs.com/2022/10/01/assertion_oncology_test_binary_wip_en.html) |Present_Or_Past, Hypothetical_Or_Absent|
# | 6 | [assertion_oncology_smoking_status_wip](https://nlp.johnsnowlabs.com/2022/10/11/assertion_oncology_smoking_status_wip_en.html) |Absent, Past, Present|
# | 7 | [assertion_oncology_family_history_wip](https://nlp.johnsnowlabs.com/2022/10/11/assertion_oncology_family_history_wip_en.html) |Family_History, Other|
# | 8 | [assertion_oncology_demographic_binary_wip](https://nlp.johnsnowlabs.com/2022/10/11/assertion_oncology_demographic_binary_wip_en.html) |Patient, Someone_Else|

# %%
embeddings = 'embeddings_clinical'

ner_model_name = 'ner_oncology_wip'

assertion_model_name='assertion_oncology_wip'

nrows = 100

ner_df = get_clinical_assertion (embeddings, mt_samples_df, nrows, ner_model_name,assertion_model_name )

ner_df.show(truncate = False)
# Out:
# ner_oncology_wip download started this may take some time.
# [OK!]
# assertion_oncology_wip download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# +------------------------+--------------------+------------+----------+
# |chunk                   |ner_label           |assertion   |confidence|
# +------------------------+--------------------+------------+----------+
# |Mesothelioma            |Cancer_Dx           |Present     |0.9885    |
# |Mesothelioma            |Cancer_Dx           |Hypothetical|0.981     |
# |August 24, 2007         |Date                |Past        |0.9726    |
# |decortication           |Cancer_Surgery      |Past        |0.994     |
# |lung                    |Site_Lung           |Past        |0.9453    |
# |pleural                 |Site_Other_Body_Part|Past        |0.9624    |
# |biopsy                  |Pathology_Test      |Past        |0.9979    |
# |transpleural fluoroscopy|Imaging_Test        |Past        |0.9979    |
# |August 20, 2007         |Date                |Past        |0.956     |
# |August 31, 2007         |Date                |Past        |0.9925    |
# |41-year-old             |Gender              |Present     |0.9986    |
# |Vietnamese              |Race_Ethnicity      |Present     |0.8024    |
# |female                  |Gender              |Present     |0.9772    |
# |started last week       |Relative_Date       |Present     |0.9831    |
# |She                     |Gender              |Present     |0.9992    |
# |her                     |Gender              |Present     |0.9944    |
# |She                     |Gender              |Present     |0.9993    |
# |pericardectomy          |Cancer_Surgery      |Past        |0.997     |
# |May 2006                |Date                |Past        |0.9971    |
# |Chest x-ray             |Imaging_Test        |Past        |0.9984    |
# +------------------------+--------------------+------------+----------+
# only showing top 20 rows

# %% [markdown]
# # Assertion Filterer
# AssertionFilterer will allow you to filter out the named entities by the list of acceptable assertion statuses. This annotator would be quite handy if you want to set a white list for the acceptable assertion statuses like present or conditional; and do not want absent conditions get out of your pipeline.

# %%
clinical_ner = medical.NerModel.pretrained("ner_clinical", "en", "clinical/models") \
    .setInputCols(["sentence", "token", "embeddings"]) \
    .setOutputCol("ner")\
    #.setIncludeAllConfidenceScores(False)

ner_converter = nlp.NerConverter() \
    .setInputCols(["sentence", "token", "ner"]) \
    .setOutputCol("ner_chunk")

clinical_assertion = medical.AssertionDLModel.pretrained("assertion_dl", "en", "clinical/models") \
    .setInputCols(["sentence", "ner_chunk", "embeddings"]) \
    .setOutputCol("assertion")

assertion_filterer = medical.AssertionFilterer()\
    .setInputCols("sentence","ner_chunk","assertion")\
    .setOutputCol("assertion_filtered")\
    .setWhiteList(["present"])

nlpPipeline = Pipeline(stages=[
      documentAssembler, 
      sentenceDetector,
      tokenizer,
      word_embeddings,
      clinical_ner,
      ner_converter,
      clinical_assertion,
      assertion_filterer
    ])

empty_data = spark.createDataFrame([[""]]).toDF("text")
assertionFilter_model = nlpPipeline.fit(empty_data)
# Out:
# ner_clinical download started this may take some time.
# [OK!]
# assertion_dl download started this may take some time.
# [OK!]

# %%
text = 'Patient has a headache for the last 2 weeks, needs to get a head CT, and appears anxious when she walks fast. Alopecia noted. She denies pain.'

light_model = LightPipeline(assertionFilter_model)
light_result = light_model.annotate(text)

light_result.keys()
# Out:
# dict_keys(['assertion_filtered', 'document', 'ner_chunk', 'assertion', 'token', 'ner', 'embeddings', 'sentence'])

# %%
list(zip(light_result['ner_chunk'], light_result['assertion']))
# Out:
# [('a headache', 'present'),
#  ('a head CT', 'present'),
#  ('anxious', 'present'),
#  ('Alopecia', 'present'),
#  ('pain', 'absent')]

# %%
assertion_filterer.getWhiteList()
# Out:
# ['present']

# %%
light_result['assertion_filtered']
# Out:
# ['a headache', 'a head CT', 'anxious', 'Alopecia']

# %% [markdown]
# # Train a custom Assertion Model

# %%
# !wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/i2b2_assertion_sample_short.csv

# %%
assertion_df = spark.read.option("header", True).option("inferSchema", "True").csv("i2b2_assertion_sample_short.csv")

# %%
assertion_df.show(3, truncate=100)
# Out:
# +-------------------------------------------------+-------------------+-------+-----+---+
# |                                             text|             target|  label|start|end|
# +-------------------------------------------------+-------------------+-------+-----+---+
# |She has no history of liver disease , hepatitis .|      liver disease| absent|    5|  6|
# |                         1. Undesired fertility .|undesired fertility|present|    1|  2|
# |                            3) STATUS POST FALL .|               fall|present|    3|  3|
# +-------------------------------------------------+-------------------+-------+-----+---+
# only showing top 3 rows

# %%
(training_data, test_data) = assertion_df.randomSplit([0.8, 0.2], seed = 100)
print("Training Dataset Count: " + str(training_data.count()))
print("Test Dataset Count: " + str(test_data.count()))
# Out:
# Training Dataset Count: 721
# Test Dataset Count: 170

# %%
training_data.groupBy('label').count().orderBy('count', ascending=False).show(truncate=False)
# Out:
# +-------+-----+
# |label  |count|
# +-------+-----+
# |present|546  |
# |absent |175  |
# +-------+-----+

# %%
document = nlp.DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")

chunk = nlp.Doc2Chunk()\
    .setInputCols("document")\
    .setOutputCol("chunk")\
    .setChunkCol("target")\
    .setStartCol("start")\
    .setStartColByTokenIndex(True)\
    .setFailOnMissing(False)\
    .setLowerCase(True)

token = nlp.Tokenizer()\
    .setInputCols(['document'])\
    .setOutputCol('token')

embeddings = nlp.WordEmbeddingsModel.pretrained("embeddings_clinical", "en", "clinical/models")\
    .setInputCols(["document", "token"])\
    .setOutputCol("embeddings")
# Out:
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]

# %% [markdown]
# We will transform our test data with a pipeline consisting of same steps with the pipeline which contains AssertionDLApproach.
# By doing this, we enable that test data will have same columns with training data in AssertionDLApproach. <br/>
# The goal of this implementation is enabling the usage of `setTestDataset()` parameter in AssertionDLApproach.

# %%
clinical_assertion_pipeline = Pipeline(
    stages = [
    document,
    chunk,
    token,
    embeddings])

assertion_test_data = clinical_assertion_pipeline.fit(test_data).transform(test_data)

# %%
assertion_test_data.columns
# Out:
# ['text',
#  'target',
#  'label',
#  'start',
#  'end',
#  'document',
#  'chunk',
#  'token',
#  'embeddings']

# %% [markdown]
# We save the test data in parquet format to use in `AssertionDLApproach()`.

# %%
assertion_test_data.write.parquet('i2b2_assertion_sample_test_data.parquet')

# %% [markdown]
# ## Graph setup and training

# %%
# !pip install -q tensorflow==2.7.0
# !pip install -q tensorflow-addons

# %% [markdown]
# We will use TFGraphBuilder annotator which can be used to create graphs in the model training pipeline.
#
# TFGraphBuilder inspects the data and creates the proper graph if a suitable version of TensorFlow (<= 2.7 ) is available. The graph is stored in the defined folder and loaded by the approach.

# %%
graph_folder= "./tf_graphs"

# %%
assertion_graph_builder = medical.TFGraphBuilder()\
    .setModelName("assertion_dl")\
    .setInputCols(["sentence", "token", "embeddings"]) \
    .setLabelColumn("label")\
    .setGraphFolder(graph_folder)\
    .setGraphFile("assertion_graph.pb")\
    .setMaxSequenceLength(250)\
    .setHiddenUnitsNumber(25)

# %%
'''
# ready to use tf_graph

# !mkdir training_logs
# !mkdir assertion_tf_graph

# !wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/tf_graphs/blstm_34_32_30_200_2.pb -P /content/assertion_tf_graph
'''

# %%
'''
# create custom graph

medical.tf_graph.print_model_params("assertion_dl")

feat_size = 200
n_classes = 6

medical.tf_graph.build("assertion_dl",
                        build_params={"n_classes": n_classes},
                        model_location= "./tf_graphs", 
                        model_filename="blstm_34_32_30_{}_{}.pb".format(feat_size, n_classes))
'''

# %% [markdown]
# **Setting the Scope Window (Target Area) Dynamically in Assertion Status Detection Models**
#
#
# This parameter allows you to train the Assertion Status Models to focus on specific context windows when resolving the status of a NER chunk. The window is in format `[X,Y]` being `X` the number of tokens to consider on the left of the chunk, and `Y` the max number of tokens to consider on the right. Let’s take a look at what different windows mean:
#
#
# *   By default, the window is `[-1,-1]` which means that the Assertion Status will look at all of the tokens in the sentence/document (up to a maximum of tokens set in `setMaxSentLen()` ).
# *   `[0,0]` means “don’t pay attention to any token except the ner_chunk”, what basically is not considering any context for the Assertion resolution.
# *   `[9,15]` is what empirically seems to be the best baseline, meaning that we look up to 9 tokens on the left and 15 on the right of the ner chunk to understand the context and resolve the status.
#
#
# Check this [Scope Window Tuning Assertion Status Detection notebook](https://github.com/JohnSnowLabs/spark-nlp-workshop/blob/master/tutorials/Certification_Trainings_JSL/Healthcare/2.1.Scope_window_tuning_assertion_status_detection.ipynb)  that illustrates the effect of the different windows and how to properly fine-tune your AssertionDLModels to get the best of them.
#
# In our case, the best Scope Window is around [10,10]

# %%
scope_window = [10,10]

assertionStatus = medical.AssertionDLApproach()\
    .setLabelCol("label")\
    .setInputCols("document", "chunk", "embeddings")\
    .setOutputCol("assertion")\
    .setBatchSize(128)\
    .setDropout(0.1)\
    .setLearningRate(0.001)\
    .setEpochs(50)\
    .setValidationSplit(0.2)\
    .setStartCol("start")\
    .setEndCol("end")\
    .setMaxSentLen(250)\
    .setIncludeConfidence(True)\
    .setEnableOutputLogs(True)\
    .setOutputLogsPath('training_logs/')\
    .setGraphFolder(graph_folder)\
    .setGraphFile(f"{graph_folder}/assertion_graph.pb")\
    .setTestDataset(path="/content/i2b2_assertion_sample_test_data.parquet")\
    .setScopeWindow(scope_window)

'''
If .setTestDataset parameter is employed, raw test data cannot be fitted. .setTestDataset only works for dataframes which are correctly transformed
by a pipeline consisting of document, chunk, embeddings stages.
'''

# %%
'''
assertionStatus = medical.AssertionLogRegApproach()\
    .setLabelCol("label")\
    .setInputCols("document", "chunk", "embeddings")\
    .setOutputCol("assertion")\
    .setMaxIter(100) # default: 26
'''

# %%
clinical_assertion_pipeline = Pipeline(
    stages = [
    document,
    chunk,
    token,
    embeddings,
    assertion_graph_builder,
    assertionStatus])

# %%
# %%time

assertion_model = clinical_assertion_pipeline.fit(training_data)
# Out:
# TF Graph Builder configuration:
# Model name: assertion_dl
# Graph folder: ./tf_graphs
# Graph file name: assertion_graph.pb
# Build params: {'n_classes': 2, 'feat_size': 200, 'max_seq_len': 250, 'n_hidden': 25}
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Device mapping: no known devices.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/sparknlp_jsl/_tf_graph_builders/tf2contrib/rnn.py:239: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/rnn.py:450: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/layers/legacy_rnn/rnn_cell_impl.py:766: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Device mapping: no known devices.
# assertion_dl graph exported to ./tf_graphs/assertion_graph.pb
# CPU times: user 13.5 s, sys: 751 ms, total: 14.2 s
# Wall time: 4min 50s

# %% [markdown]
# ## Checking the results

# %% [markdown]
# Checking the results saved in the log file

# %%
import os
log_files = os.listdir("./training_logs")
log_files
# Out:
# ['AssertionDLApproach_d932b8ea12a1.log']

# %%
with open("./training_logs/"+log_files[0]) as log_file:
    print(log_file.read())
# Out:
# Name of the selected graph: ./tf_graphs/assertion_graph.pb
# Training started, trainExamples: 721
#
#
# Epoch: 0 started, learning rate: 0.001, dataset size: 577
# Done, 6.853388778 total training loss: 5.0451503, avg training loss: 1.0090301, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.99s
# Total validation loss: 1.5567	Avg validation loss: 0.7783
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 52	 10	 65	 0.83870965	 0.44444445	 0.5810056
# absent	 17	 65	 10	 0.20731707	 0.6296296	 0.3119266
# tp: 69 fp: 75 fn: 75 labels: 2
# Macro-average	 prec: 0.52301335, rec: 0.537037, f1: 0.52993244
# Micro-average	 prec: 0.47916666, rec: 0.47916666, f1: 0.47916666
#
#
# Quality on test dataset:
# time to finish evaluation: 0.78s
# Total test loss: 1.4393	Avg test loss: 0.7196
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 54	 21	 63	 0.72	 0.46153846	 0.5625
# absent	 32	 63	 21	 0.33684212	 0.6037736	 0.43243247
# tp: 86 fp: 84 fn: 84 labels: 2
# Macro-average	 prec: 0.52842104, rec: 0.532656, f1: 0.53053004
# Micro-average	 prec: 0.5058824, rec: 0.5058824, f1: 0.5058824
#
#
# Epoch: 1 started, learning rate: 9.5E-4, dataset size: 577
# Done, 3.952157281 total training loss: 3.2176623, avg training loss: 0.64353245, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.64s
# Total validation loss: 1.0438	Avg validation loss: 0.5219
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 102	 22	 15	 0.82258064	 0.8717949	 0.84647304
# absent	 5	 15	 22	 0.25	 0.18518518	 0.21276595
# tp: 107 fp: 37 fn: 37 labels: 2
# Macro-average	 prec: 0.5362903, rec: 0.52849, f1: 0.53236157
# Micro-average	 prec: 0.7430556, rec: 0.7430556, f1: 0.7430556
#
#
# Quality on test dataset:
# time to finish evaluation: 0.78s
# Total test loss: 1.4215	Avg test loss: 0.7107
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 103	 46	 14	 0.6912752	 0.8803419	 0.77443606
# absent	 7	 14	 46	 0.33333334	 0.13207547	 0.18918921
# tp: 110 fp: 60 fn: 60 labels: 2
# Macro-average	 prec: 0.51230425, rec: 0.50620866, f1: 0.5092382
# Micro-average	 prec: 0.64705884, rec: 0.64705884, f1: 0.64705884
#
#
# Epoch: 2 started, learning rate: 9.025E-4, dataset size: 577
# Done, 4.129508965 total training loss: 3.3448772, avg training loss: 0.6689755, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.65s
# Total validation loss: 1.0113	Avg validation loss: 0.5057
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 102	 22	 15	 0.82258064	 0.8717949	 0.84647304
# absent	 5	 15	 22	 0.25	 0.18518518	 0.21276595
# tp: 107 fp: 37 fn: 37 labels: 2
# Macro-average	 prec: 0.5362903, rec: 0.52849, f1: 0.53236157
# Micro-average	 prec: 0.7430556, rec: 0.7430556, f1: 0.7430556
#
#
# Quality on test dataset:
# time to finish evaluation: 0.77s
# Total test loss: 1.4089	Avg test loss: 0.7044
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 104	 46	 13	 0.6933333	 0.8888889	 0.7790262
# absent	 7	 13	 46	 0.35	 0.13207547	 0.19178084
# tp: 111 fp: 59 fn: 59 labels: 2
# Macro-average	 prec: 0.52166665, rec: 0.5104822, f1: 0.51601386
# Micro-average	 prec: 0.65294117, rec: 0.65294117, f1: 0.65294117
#
#
# Epoch: 3 started, learning rate: 8.57375E-4, dataset size: 577
# Done, 3.691796244 total training loss: 3.0976717, avg training loss: 0.6195344, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.62s
# Total validation loss: 1.0237	Avg validation loss: 0.5118
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 101	 20	 16	 0.8347107	 0.8632479	 0.8487395
# absent	 7	 16	 20	 0.3043478	 0.25925925	 0.27999997
# tp: 108 fp: 36 fn: 36 labels: 2
# Macro-average	 prec: 0.5695293, rec: 0.56125355, f1: 0.56536114
# Micro-average	 prec: 0.75, rec: 0.75, f1: 0.75
#
#
# Quality on test dataset:
# time to finish evaluation: 0.75s
# Total test loss: 1.2164	Avg test loss: 0.6082
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 101	 42	 16	 0.7062937	 0.8632479	 0.77692306
# absent	 11	 16	 42	 0.4074074	 0.20754717	 0.27499998
# tp: 112 fp: 58 fn: 58 labels: 2
# Macro-average	 prec: 0.55685055, rec: 0.5353975, f1: 0.54591334
# Micro-average	 prec: 0.65882355, rec: 0.65882355, f1: 0.65882355
#
#
# Epoch: 4 started, learning rate: 8.145062E-4, dataset size: 577
# Done, 3.891098038 total training loss: 2.9695978, avg training loss: 0.5939196, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.64s
# Total validation loss: 1.1109	Avg validation loss: 0.5554
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 99	 17	 18	 0.8534483	 0.84615386	 0.8497854
# absent	 10	 18	 17	 0.35714287	 0.37037036	 0.36363637
# tp: 109 fp: 35 fn: 35 labels: 2
# Macro-average	 prec: 0.60529554, rec: 0.6082621, f1: 0.60677516
# Micro-average	 prec: 0.7569444, rec: 0.7569444, f1: 0.7569444
#
#
# Quality on test dataset:
# time to finish evaluation: 0.75s
# Total test loss: 1.1989	Avg test loss: 0.5994
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 96	 39	 21	 0.7111111	 0.82051283	 0.76190484
# absent	 14	 21	 39	 0.4	 0.26415095	 0.3181818
# tp: 110 fp: 60 fn: 60 labels: 2
# Macro-average	 prec: 0.5555556, rec: 0.5423319, f1: 0.54886407
# Micro-average	 prec: 0.64705884, rec: 0.64705884, f1: 0.64705884
#
#
# Epoch: 5 started, learning rate: 7.7378086E-4, dataset size: 577
# Done, 4.069269654 total training loss: 2.9269886, avg training loss: 0.5853977, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.62s
# Total validation loss: 1.0595	Avg validation loss: 0.5298
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 100	 17	 17	 0.85470086	 0.85470086	 0.85470086
# absent	 10	 17	 17	 0.37037036	 0.37037036	 0.37037036
# tp: 110 fp: 34 fn: 34 labels: 2
# Macro-average	 prec: 0.6125356, rec: 0.6125356, f1: 0.6125356
# Micro-average	 prec: 0.7638889, rec: 0.7638889, f1: 0.7638889
#
#
# Quality on test dataset:
# time to finish evaluation: 0.76s
# Total test loss: 1.1747	Avg test loss: 0.5873
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 98	 40	 19	 0.71014494	 0.83760685	 0.76862746
# absent	 13	 19	 40	 0.40625	 0.24528302	 0.30588236
# tp: 111 fp: 59 fn: 59 labels: 2
# Macro-average	 prec: 0.5581975, rec: 0.54144496, f1: 0.5496936
# Micro-average	 prec: 0.65294117, rec: 0.65294117, f1: 0.65294117
#
#
# Epoch: 6 started, learning rate: 7.350918E-4, dataset size: 577
# Done, 5.806348889 total training loss: 2.8350546, avg training loss: 0.56701094, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.84s
# Total validation loss: 0.9535	Avg validation loss: 0.4768
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 102	 20	 15	 0.8360656	 0.8717949	 0.8535565
# absent	 7	 15	 20	 0.3181818	 0.25925925	 0.28571427
# tp: 109 fp: 35 fn: 35 labels: 2
# Macro-average	 prec: 0.5771237, rec: 0.5655271, f1: 0.57126653
# Micro-average	 prec: 0.7569444, rec: 0.7569444, f1: 0.7569444
#
#
# Quality on test dataset:
# time to finish evaluation: 0.92s
# Total test loss: 1.1651	Avg test loss: 0.5825
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 103	 41	 14	 0.7152778	 0.8803419	 0.789272
# absent	 12	 14	 41	 0.46153846	 0.2264151	 0.30379745
# tp: 115 fp: 55 fn: 55 labels: 2
# Macro-average	 prec: 0.5884081, rec: 0.55337846, f1: 0.5703559
# Micro-average	 prec: 0.6764706, rec: 0.6764706, f1: 0.6764706
#
#
# Epoch: 7 started, learning rate: 6.983372E-4, dataset size: 577
# Done, 4.939950777 total training loss: 2.767033, avg training loss: 0.5534066, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.62s
# Total validation loss: 0.9124	Avg validation loss: 0.4562
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 102	 20	 15	 0.8360656	 0.8717949	 0.8535565
# absent	 7	 15	 20	 0.3181818	 0.25925925	 0.28571427
# tp: 109 fp: 35 fn: 35 labels: 2
# Macro-average	 prec: 0.5771237, rec: 0.5655271, f1: 0.57126653
# Micro-average	 prec: 0.7569444, rec: 0.7569444, f1: 0.7569444
#
#
# Quality on test dataset:
# time to finish evaluation: 0.75s
# Total test loss: 1.1666	Avg test loss: 0.5833
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 103	 41	 14	 0.7152778	 0.8803419	 0.789272
# absent	 12	 14	 41	 0.46153846	 0.2264151	 0.30379745
# tp: 115 fp: 55 fn: 55 labels: 2
# Macro-average	 prec: 0.5884081, rec: 0.55337846, f1: 0.5703559
# Micro-average	 prec: 0.6764706, rec: 0.6764706, f1: 0.6764706
#
#
# Epoch: 8 started, learning rate: 6.6342036E-4, dataset size: 577
# Done, 4.009276236 total training loss: 2.7615447, avg training loss: 0.5523089, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.63s
# Total validation loss: 0.9005	Avg validation loss: 0.4503
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 102	 20	 15	 0.8360656	 0.8717949	 0.8535565
# absent	 7	 15	 20	 0.3181818	 0.25925925	 0.28571427
# tp: 109 fp: 35 fn: 35 labels: 2
# Macro-average	 prec: 0.5771237, rec: 0.5655271, f1: 0.57126653
# Micro-average	 prec: 0.7569444, rec: 0.7569444, f1: 0.7569444
#
#
# Quality on test dataset:
# time to finish evaluation: 0.77s
# Total test loss: 1.1260	Avg test loss: 0.5630
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 103	 41	 14	 0.7152778	 0.8803419	 0.789272
# absent	 12	 14	 41	 0.46153846	 0.2264151	 0.30379745
# tp: 115 fp: 55 fn: 55 labels: 2
# Macro-average	 prec: 0.5884081, rec: 0.55337846, f1: 0.5703559
# Micro-average	 prec: 0.6764706, rec: 0.6764706, f1: 0.6764706
#
#
# Epoch: 9 started, learning rate: 6.302493E-4, dataset size: 577
# Done, 3.903641261 total training loss: 2.6797915, avg training loss: 0.5359583, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.62s
# Total validation loss: 0.9065	Avg validation loss: 0.4533
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 101	 18	 16	 0.8487395	 0.8632479	 0.85593224
# absent	 9	 16	 18	 0.36	 0.33333334	 0.34615383
# tp: 110 fp: 34 fn: 34 labels: 2
# Macro-average	 prec: 0.60436976, rec: 0.5982906, f1: 0.60131484
# Micro-average	 prec: 0.7638889, rec: 0.7638889, f1: 0.7638889
#
#
# Quality on test dataset:
# time to finish evaluation: 0.76s
# Total test loss: 1.0747	Avg test loss: 0.5374
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 103	 39	 14	 0.7253521	 0.8803419	 0.79536676
# absent	 14	 14	 39	 0.5	 0.26415095	 0.34567901
# tp: 117 fp: 53 fn: 53 labels: 2
# Macro-average	 prec: 0.612676, rec: 0.57224643, f1: 0.5917715
# Micro-average	 prec: 0.6882353, rec: 0.6882353, f1: 0.6882353
#
#
# Epoch: 10 started, learning rate: 5.9873686E-4, dataset size: 577
# Done, 3.830385666 total training loss: 2.61028, avg training loss: 0.522056, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.62s
# Total validation loss: 0.8824	Avg validation loss: 0.4412
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 102	 18	 15	 0.85	 0.8717949	 0.86075956
# absent	 9	 15	 18	 0.375	 0.33333334	 0.35294116
# tp: 111 fp: 33 fn: 33 labels: 2
# Macro-average	 prec: 0.6125, rec: 0.6025641, f1: 0.6074915
# Micro-average	 prec: 0.7708333, rec: 0.7708333, f1: 0.7708333
#
#
# Quality on test dataset:
# time to finish evaluation: 0.73s
# Total test loss: 1.0316	Avg test loss: 0.5158
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 103	 36	 14	 0.7410072	 0.8803419	 0.8046875
# absent	 17	 14	 36	 0.5483871	 0.3207547	 0.4047619
# tp: 120 fp: 50 fn: 50 labels: 2
# Macro-average	 prec: 0.6446972, rec: 0.60054827, f1: 0.6218401
# Micro-average	 prec: 0.7058824, rec: 0.7058824, f1: 0.7058824
#
#
# Epoch: 11 started, learning rate: 5.688E-4, dataset size: 577
# Done, 4.069237847 total training loss: 2.4905725, avg training loss: 0.4981145, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.79s
# Total validation loss: 0.8262	Avg validation loss: 0.4131
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 102	 16	 15	 0.86440676	 0.8717949	 0.8680851
# absent	 11	 15	 16	 0.42307693	 0.4074074	 0.41509432
# tp: 113 fp: 31 fn: 31 labels: 2
# Macro-average	 prec: 0.64374185, rec: 0.6396011, f1: 0.6416648
# Micro-average	 prec: 0.7847222, rec: 0.7847222, f1: 0.7847222
#
#
# Quality on test dataset:
# time to finish evaluation: 0.97s
# Total test loss: 0.9819	Avg test loss: 0.4909
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 105	 35	 12	 0.75	 0.8974359	 0.8171206
# absent	 18	 12	 35	 0.6	 0.33962265	 0.43373498
# tp: 123 fp: 47 fn: 47 labels: 2
# Macro-average	 prec: 0.675, rec: 0.61852926, f1: 0.645532
# Micro-average	 prec: 0.7235294, rec: 0.7235294, f1: 0.7235294
#
#
# Epoch: 12 started, learning rate: 5.4036E-4, dataset size: 577
# Done, 3.692789868 total training loss: 2.3633218, avg training loss: 0.47266436, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.63s
# Total validation loss: 0.7570	Avg validation loss: 0.3785
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 105	 14	 12	 0.88235295	 0.8974359	 0.8898305
# absent	 13	 12	 14	 0.52	 0.4814815	 0.49999994
# tp: 118 fp: 26 fn: 26 labels: 2
# Macro-average	 prec: 0.70117646, rec: 0.6894587, f1: 0.6952682
# Micro-average	 prec: 0.8194444, rec: 0.8194444, f1: 0.8194445
#
#
# Quality on test dataset:
# time to finish evaluation: 0.76s
# Total test loss: 0.9262	Avg test loss: 0.4631
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 105	 35	 12	 0.75	 0.8974359	 0.8171206
# absent	 18	 12	 35	 0.6	 0.33962265	 0.43373498
# tp: 123 fp: 47 fn: 47 labels: 2
# Macro-average	 prec: 0.675, rec: 0.61852926, f1: 0.645532
# Micro-average	 prec: 0.7235294, rec: 0.7235294, f1: 0.7235294
#
#
# Epoch: 13 started, learning rate: 5.13342E-4, dataset size: 577
# Done, 3.911090681 total training loss: 2.2593145, avg training loss: 0.4518629, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.62s
# Total validation loss: 0.7054	Avg validation loss: 0.3527
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 105	 12	 12	 0.8974359	 0.8974359	 0.8974359
# absent	 15	 12	 12	 0.5555556	 0.5555556	 0.5555556
# tp: 120 fp: 24 fn: 24 labels: 2
# Macro-average	 prec: 0.72649574, rec: 0.72649574, f1: 0.7264958
# Micro-average	 prec: 0.8333333, rec: 0.8333333, f1: 0.8333333
#
#
# Quality on test dataset:
# time to finish evaluation: 0.75s
# Total test loss: 0.8487	Avg test loss: 0.4243
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 106	 28	 11	 0.7910448	 0.9059829	 0.8446215
# absent	 25	 11	 28	 0.6944444	 0.4716981	 0.56179774
# tp: 131 fp: 39 fn: 39 labels: 2
# Macro-average	 prec: 0.74274457, rec: 0.6888405, f1: 0.7147777
# Micro-average	 prec: 0.7705882, rec: 0.7705882, f1: 0.7705882
#
#
# Epoch: 14 started, learning rate: 4.8767487E-4, dataset size: 577
# Done, 3.86247586 total training loss: 2.0916984, avg training loss: 0.41833967, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.64s
# Total validation loss: 0.6318	Avg validation loss: 0.3159
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 11	 8	 0.90833336	 0.93162394	 0.9198313
# absent	 16	 8	 11	 0.6666667	 0.5925926	 0.627451
# tp: 125 fp: 19 fn: 19 labels: 2
# Macro-average	 prec: 0.7875, rec: 0.76210827, f1: 0.77459615
# Micro-average	 prec: 0.8680556, rec: 0.8680556, f1: 0.8680556
#
#
# Quality on test dataset:
# time to finish evaluation: 0.73s
# Total test loss: 0.7797	Avg test loss: 0.3899
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 107	 21	 10	 0.8359375	 0.9145299	 0.87346935
# absent	 32	 10	 21	 0.7619048	 0.6037736	 0.67368424
# tp: 139 fp: 31 fn: 31 labels: 2
# Macro-average	 prec: 0.7989211, rec: 0.75915176, f1: 0.7785289
# Micro-average	 prec: 0.81764704, rec: 0.81764704, f1: 0.81764704
#
#
# Epoch: 15 started, learning rate: 4.6329113E-4, dataset size: 577
# Done, 3.785627764 total training loss: 1.8800986, avg training loss: 0.37601972, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.63s
# Total validation loss: 0.5902	Avg validation loss: 0.2951
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 103	 5	 14	 0.9537037	 0.8803419	 0.91555554
# absent	 22	 14	 5	 0.6111111	 0.8148148	 0.69841266
# tp: 125 fp: 19 fn: 19 labels: 2
# Macro-average	 prec: 0.7824074, rec: 0.84757835, f1: 0.81369
# Micro-average	 prec: 0.8680556, rec: 0.8680556, f1: 0.8680556
#
#
# Quality on test dataset:
# time to finish evaluation: 0.74s
# Total test loss: 0.7198	Avg test loss: 0.3599
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 106	 16	 11	 0.86885244	 0.9059829	 0.8870293
# absent	 37	 11	 16	 0.7708333	 0.6981132	 0.7326733
# tp: 143 fp: 27 fn: 27 labels: 2
# Macro-average	 prec: 0.8198429, rec: 0.8020481, f1: 0.8108479
# Micro-average	 prec: 0.84117645, rec: 0.84117645, f1: 0.84117645
#
#
# Epoch: 16 started, learning rate: 4.4012658E-4, dataset size: 577
# Done, 3.702743757 total training loss: 1.7547574, avg training loss: 0.3509515, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.61s
# Total validation loss: 0.4904	Avg validation loss: 0.2452
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 106	 6	 11	 0.9464286	 0.9059829	 0.92576426
# absent	 21	 11	 6	 0.65625	 0.7777778	 0.7118644
# tp: 127 fp: 17 fn: 17 labels: 2
# Macro-average	 prec: 0.80133927, rec: 0.8418803, f1: 0.8211097
# Micro-average	 prec: 0.8819444, rec: 0.8819444, f1: 0.8819444
#
#
# Quality on test dataset:
# time to finish evaluation: 0.73s
# Total test loss: 0.6778	Avg test loss: 0.3389
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 107	 19	 10	 0.8492063	 0.9145299	 0.88065845
# absent	 34	 10	 19	 0.77272725	 0.6415094	 0.7010309
# tp: 141 fp: 29 fn: 29 labels: 2
# Macro-average	 prec: 0.8109668, rec: 0.77801967, f1: 0.7941517
# Micro-average	 prec: 0.82941175, rec: 0.82941175, f1: 0.82941175
#
#
# Epoch: 17 started, learning rate: 4.1812024E-4, dataset size: 577
# Done, 3.730211395 total training loss: 1.6237758, avg training loss: 0.32475516, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.60s
# Total validation loss: 0.5063	Avg validation loss: 0.2531
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 104	 3	 13	 0.97196263	 0.8888889	 0.9285714
# absent	 24	 13	 3	 0.6486486	 0.8888889	 0.74999994
# tp: 128 fp: 16 fn: 16 labels: 2
# Macro-average	 prec: 0.8103056, rec: 0.8888889, f1: 0.84778017
# Micro-average	 prec: 0.8888889, rec: 0.8888889, f1: 0.8888889
#
#
# Quality on test dataset:
# time to finish evaluation: 0.74s
# Total test loss: 0.6447	Avg test loss: 0.3223
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 104	 13	 13	 0.8888889	 0.8888889	 0.8888889
# absent	 40	 13	 13	 0.754717	 0.754717	 0.754717
# tp: 144 fp: 26 fn: 26 labels: 2
# Macro-average	 prec: 0.821803, rec: 0.821803, f1: 0.821803
# Micro-average	 prec: 0.84705883, rec: 0.84705883, f1: 0.84705883
#
#
# Epoch: 18 started, learning rate: 3.9721423E-4, dataset size: 577
# Done, 3.556179982 total training loss: 1.5538023, avg training loss: 0.31076044, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.62s
# Total validation loss: 0.4251	Avg validation loss: 0.2126
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 110	 6	 7	 0.94827586	 0.94017094	 0.944206
# absent	 21	 7	 6	 0.75	 0.7777778	 0.7636364
# tp: 131 fp: 13 fn: 13 labels: 2
# Macro-average	 prec: 0.8491379, rec: 0.85897434, f1: 0.85402775
# Micro-average	 prec: 0.9097222, rec: 0.9097222, f1: 0.9097222
#
#
# Quality on test dataset:
# time to finish evaluation: 0.77s
# Total test loss: 0.6519	Avg test loss: 0.3260
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 20	 8	 0.8449612	 0.93162394	 0.88617885
# absent	 33	 8	 20	 0.80487806	 0.6226415	 0.7021277
# tp: 142 fp: 28 fn: 28 labels: 2
# Macro-average	 prec: 0.82491964, rec: 0.77713275, f1: 0.8003135
# Micro-average	 prec: 0.8352941, rec: 0.8352941, f1: 0.8352941
#
#
# Epoch: 19 started, learning rate: 3.773535E-4, dataset size: 577
# Done, 3.512802734 total training loss: 1.4196299, avg training loss: 0.28392598, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.61s
# Total validation loss: 0.4519	Avg validation loss: 0.2260
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 104	 4	 13	 0.962963	 0.8888889	 0.92444444
# absent	 23	 13	 4	 0.6388889	 0.8518519	 0.73015875
# tp: 127 fp: 17 fn: 17 labels: 2
# Macro-average	 prec: 0.80092597, rec: 0.8703704, f1: 0.83420545
# Micro-average	 prec: 0.8819444, rec: 0.8819444, f1: 0.8819444
#
#
# Quality on test dataset:
# time to finish evaluation: 0.74s
# Total test loss: 0.6067	Avg test loss: 0.3034
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 13	 8	 0.89344263	 0.93162394	 0.9121339
# absent	 40	 8	 13	 0.8333333	 0.754717	 0.79207915
# tp: 149 fp: 21 fn: 21 labels: 2
# Macro-average	 prec: 0.86338794, rec: 0.84317046, f1: 0.8531594
# Micro-average	 prec: 0.87647057, rec: 0.87647057, f1: 0.87647057
#
#
# Epoch: 20 started, learning rate: 3.5848582E-4, dataset size: 577
# Done, 3.578359871 total training loss: 1.4147947, avg training loss: 0.28295892, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.62s
# Total validation loss: 0.4165	Avg validation loss: 0.2082
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 110	 7	 7	 0.94017094	 0.94017094	 0.94017094
# absent	 20	 7	 7	 0.7407407	 0.7407407	 0.7407407
# tp: 130 fp: 14 fn: 14 labels: 2
# Macro-average	 prec: 0.84045583, rec: 0.84045583, f1: 0.84045583
# Micro-average	 prec: 0.9027778, rec: 0.9027778, f1: 0.9027778
#
#
# Quality on test dataset:
# time to finish evaluation: 0.73s
# Total test loss: 0.6304	Avg test loss: 0.3152
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 18	 8	 0.8582677	 0.93162394	 0.89344263
# absent	 35	 8	 18	 0.81395346	 0.6603774	 0.7291667
# tp: 144 fp: 26 fn: 26 labels: 2
# Macro-average	 prec: 0.8361106, rec: 0.79600066, f1: 0.8155627
# Micro-average	 prec: 0.84705883, rec: 0.84705883, f1: 0.84705883
#
#
# Epoch: 21 started, learning rate: 3.4056153E-4, dataset size: 577
# Done, 3.662579823 total training loss: 1.354706, avg training loss: 0.2709412, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.62s
# Total validation loss: 0.4226	Avg validation loss: 0.2113
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 108	 5	 9	 0.9557522	 0.9230769	 0.9391304
# absent	 22	 9	 5	 0.7096774	 0.8148148	 0.7586206
# tp: 130 fp: 14 fn: 14 labels: 2
# Macro-average	 prec: 0.8327148, rec: 0.86894584, f1: 0.8504446
# Micro-average	 prec: 0.9027778, rec: 0.9027778, f1: 0.9027778
#
#
# Quality on test dataset:
# time to finish evaluation: 0.75s
# Total test loss: 0.5888	Avg test loss: 0.2944
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 15	 8	 0.87903225	 0.93162394	 0.9045643
# absent	 38	 8	 15	 0.82608694	 0.7169811	 0.7676768
# tp: 147 fp: 23 fn: 23 labels: 2
# Macro-average	 prec: 0.85255957, rec: 0.82430255, f1: 0.83819294
# Micro-average	 prec: 0.86470586, rec: 0.86470586, f1: 0.86470586
#
#
# Epoch: 22 started, learning rate: 3.2353346E-4, dataset size: 577
# Done, 3.731007153 total training loss: 1.2998207, avg training loss: 0.25996414, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.62s
# Total validation loss: 0.4141	Avg validation loss: 0.2071
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 6	 8	 0.9478261	 0.93162394	 0.9396552
# absent	 21	 8	 6	 0.7241379	 0.7777778	 0.74999994
# tp: 130 fp: 14 fn: 14 labels: 2
# Macro-average	 prec: 0.83598197, rec: 0.85470086, f1: 0.84523773
# Micro-average	 prec: 0.9027778, rec: 0.9027778, f1: 0.9027778
#
#
# Quality on test dataset:
# time to finish evaluation: 0.75s
# Total test loss: 0.5867	Avg test loss: 0.2933
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 15	 8	 0.87903225	 0.93162394	 0.9045643
# absent	 38	 8	 15	 0.82608694	 0.7169811	 0.7676768
# tp: 147 fp: 23 fn: 23 labels: 2
# Macro-average	 prec: 0.85255957, rec: 0.82430255, f1: 0.83819294
# Micro-average	 prec: 0.86470586, rec: 0.86470586, f1: 0.86470586
#
#
# Epoch: 23 started, learning rate: 3.073568E-4, dataset size: 577
# Done, 3.790850169 total training loss: 1.2855551, avg training loss: 0.257111, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.63s
# Total validation loss: 0.4203	Avg validation loss: 0.2102
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 108	 5	 9	 0.9557522	 0.9230769	 0.9391304
# absent	 22	 9	 5	 0.7096774	 0.8148148	 0.7586206
# tp: 130 fp: 14 fn: 14 labels: 2
# Macro-average	 prec: 0.8327148, rec: 0.86894584, f1: 0.8504446
# Micro-average	 prec: 0.9027778, rec: 0.9027778, f1: 0.9027778
#
#
# Quality on test dataset:
# time to finish evaluation: 0.77s
# Total test loss: 0.5746	Avg test loss: 0.2873
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 108	 14	 9	 0.8852459	 0.9230769	 0.9037656
# absent	 39	 9	 14	 0.8125	 0.7358491	 0.77227724
# tp: 147 fp: 23 fn: 23 labels: 2
# Macro-average	 prec: 0.84887296, rec: 0.829463, f1: 0.8390558
# Micro-average	 prec: 0.86470586, rec: 0.86470586, f1: 0.86470586
#
#
# Epoch: 24 started, learning rate: 2.9198895E-4, dataset size: 577
# Done, 3.846950602 total training loss: 1.2871486, avg training loss: 0.25742972, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.62s
# Total validation loss: 0.4151	Avg validation loss: 0.2075
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 108	 6	 9	 0.94736844	 0.9230769	 0.935065
# absent	 21	 9	 6	 0.7	 0.7777778	 0.73684216
# tp: 129 fp: 15 fn: 15 labels: 2
# Macro-average	 prec: 0.8236842, rec: 0.8504274, f1: 0.8368422
# Micro-average	 prec: 0.8958333, rec: 0.8958333, f1: 0.8958334
#
#
# Quality on test dataset:
# time to finish evaluation: 0.76s
# Total test loss: 0.5721	Avg test loss: 0.2860
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 14	 8	 0.88617885	 0.93162394	 0.9083333
# absent	 39	 8	 14	 0.82978725	 0.7358491	 0.78000003
# tp: 148 fp: 22 fn: 22 labels: 2
# Macro-average	 prec: 0.85798305, rec: 0.83373654, f1: 0.845686
# Micro-average	 prec: 0.87058824, rec: 0.87058824, f1: 0.87058824
#
#
# Epoch: 25 started, learning rate: 2.773895E-4, dataset size: 577
# Done, 3.939152439 total training loss: 1.1908422, avg training loss: 0.23816843, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.62s
# Total validation loss: 0.4142	Avg validation loss: 0.2071
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 8	 8	 0.93162394	 0.93162394	 0.93162394
# absent	 19	 8	 8	 0.7037037	 0.7037037	 0.7037037
# tp: 128 fp: 16 fn: 16 labels: 2
# Macro-average	 prec: 0.8176638, rec: 0.8176638, f1: 0.8176638
# Micro-average	 prec: 0.8888889, rec: 0.8888889, f1: 0.8888889
#
#
# Quality on test dataset:
# time to finish evaluation: 0.73s
# Total test loss: 0.5778	Avg test loss: 0.2889
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 14	 8	 0.88617885	 0.93162394	 0.9083333
# absent	 39	 8	 14	 0.82978725	 0.7358491	 0.78000003
# tp: 148 fp: 22 fn: 22 labels: 2
# Macro-average	 prec: 0.85798305, rec: 0.83373654, f1: 0.845686
# Micro-average	 prec: 0.87058824, rec: 0.87058824, f1: 0.87058824
#
#
# Epoch: 26 started, learning rate: 2.6352002E-4, dataset size: 577
# Done, 3.715420372 total training loss: 1.1395122, avg training loss: 0.22790244, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.65s
# Total validation loss: 0.4205	Avg validation loss: 0.2103
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 111	 9	 6	 0.925	 0.94871795	 0.93670887
# absent	 18	 6	 9	 0.75	 0.6666667	 0.7058823
# tp: 129 fp: 15 fn: 15 labels: 2
# Macro-average	 prec: 0.8375, rec: 0.8076923, f1: 0.8223261
# Micro-average	 prec: 0.8958333, rec: 0.8958333, f1: 0.8958334
#
#
# Quality on test dataset:
# time to finish evaluation: 0.74s
# Total test loss: 0.5908	Avg test loss: 0.2954
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 16	 8	 0.872	 0.93162394	 0.90082645
# absent	 37	 8	 16	 0.82222223	 0.6981132	 0.75510204
# tp: 146 fp: 24 fn: 24 labels: 2
# Macro-average	 prec: 0.8471111, rec: 0.81486857, f1: 0.83067703
# Micro-average	 prec: 0.85882354, rec: 0.85882354, f1: 0.85882354
#
#
# Epoch: 27 started, learning rate: 2.5034402E-4, dataset size: 577
# Done, 3.780559861 total training loss: 1.1829197, avg training loss: 0.23658395, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.63s
# Total validation loss: 0.4489	Avg validation loss: 0.2245
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 106	 5	 11	 0.954955	 0.9059829	 0.92982465
# absent	 22	 11	 5	 0.6666667	 0.8148148	 0.73333335
# tp: 128 fp: 16 fn: 16 labels: 2
# Macro-average	 prec: 0.8108108, rec: 0.8603989, f1: 0.83486915
# Micro-average	 prec: 0.8888889, rec: 0.8888889, f1: 0.8888889
#
#
# Quality on test dataset:
# time to finish evaluation: 0.74s
# Total test loss: 0.5558	Avg test loss: 0.2779
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 108	 12	 9	 0.9	 0.9230769	 0.9113924
# absent	 41	 9	 12	 0.82	 0.7735849	 0.79611653
# tp: 149 fp: 21 fn: 21 labels: 2
# Macro-average	 prec: 0.86, rec: 0.8483309, f1: 0.8541257
# Micro-average	 prec: 0.87647057, rec: 0.87647057, f1: 0.87647057
#
#
# Epoch: 28 started, learning rate: 2.3782681E-4, dataset size: 577
# Done, 3.770723284 total training loss: 1.0854203, avg training loss: 0.21708405, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.62s
# Total validation loss: 0.4338	Avg validation loss: 0.2169
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 111	 9	 6	 0.925	 0.94871795	 0.93670887
# absent	 18	 6	 9	 0.75	 0.6666667	 0.7058823
# tp: 129 fp: 15 fn: 15 labels: 2
# Macro-average	 prec: 0.8375, rec: 0.8076923, f1: 0.8223261
# Micro-average	 prec: 0.8958333, rec: 0.8958333, f1: 0.8958334
#
#
# Quality on test dataset:
# time to finish evaluation: 0.75s
# Total test loss: 0.5969	Avg test loss: 0.2985
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 16	 8	 0.872	 0.93162394	 0.90082645
# absent	 37	 8	 16	 0.82222223	 0.6981132	 0.75510204
# tp: 146 fp: 24 fn: 24 labels: 2
# Macro-average	 prec: 0.8471111, rec: 0.81486857, f1: 0.83067703
# Micro-average	 prec: 0.85882354, rec: 0.85882354, f1: 0.85882354
#
#
# Epoch: 29 started, learning rate: 2.2593547E-4, dataset size: 577
# Done, 3.816085898 total training loss: 1.1687254, avg training loss: 0.23374507, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.62s
# Total validation loss: 0.4427	Avg validation loss: 0.2214
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 107	 7	 10	 0.9385965	 0.9145299	 0.926407
# absent	 20	 10	 7	 0.6666667	 0.7407407	 0.7017544
# tp: 127 fp: 17 fn: 17 labels: 2
# Macro-average	 prec: 0.8026316, rec: 0.8276353, f1: 0.8149417
# Micro-average	 prec: 0.8819444, rec: 0.8819444, f1: 0.8819444
#
#
# Quality on test dataset:
# time to finish evaluation: 0.75s
# Total test loss: 0.5502	Avg test loss: 0.2751
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 108	 14	 9	 0.8852459	 0.9230769	 0.9037656
# absent	 39	 9	 14	 0.8125	 0.7358491	 0.77227724
# tp: 147 fp: 23 fn: 23 labels: 2
# Macro-average	 prec: 0.84887296, rec: 0.829463, f1: 0.8390558
# Micro-average	 prec: 0.86470586, rec: 0.86470586, f1: 0.86470586
#
#
# Epoch: 30 started, learning rate: 2.1463868E-4, dataset size: 577
# Done, 3.883920475 total training loss: 1.0700395, avg training loss: 0.2140079, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.62s
# Total validation loss: 0.4397	Avg validation loss: 0.2199
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 108	 8	 9	 0.9310345	 0.9230769	 0.92703867
# absent	 19	 9	 8	 0.6785714	 0.7037037	 0.690909
# tp: 127 fp: 17 fn: 17 labels: 2
# Macro-average	 prec: 0.80480295, rec: 0.8133903, f1: 0.80907387
# Micro-average	 prec: 0.8819444, rec: 0.8819444, f1: 0.8819444
#
#
# Quality on test dataset:
# time to finish evaluation: 0.73s
# Total test loss: 0.5563	Avg test loss: 0.2782
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 108	 15	 9	 0.8780488	 0.9230769	 0.9
# absent	 38	 9	 15	 0.80851066	 0.7169811	 0.76000005
# tp: 146 fp: 24 fn: 24 labels: 2
# Macro-average	 prec: 0.8432797, rec: 0.820029, f1: 0.8314918
# Micro-average	 prec: 0.85882354, rec: 0.85882354, f1: 0.85882354
#
#
# Epoch: 31 started, learning rate: 2.0390675E-4, dataset size: 577
# Done, 3.74563013 total training loss: 1.1112843, avg training loss: 0.22225685, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.61s
# Total validation loss: 0.4399	Avg validation loss: 0.2200
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 110	 9	 7	 0.92436975	 0.94017094	 0.9322034
# absent	 18	 7	 9	 0.72	 0.6666667	 0.69230765
# tp: 128 fp: 16 fn: 16 labels: 2
# Macro-average	 prec: 0.8221849, rec: 0.8034188, f1: 0.81269354
# Micro-average	 prec: 0.8888889, rec: 0.8888889, f1: 0.8888889
#
#
# Quality on test dataset:
# time to finish evaluation: 0.72s
# Total test loss: 0.5842	Avg test loss: 0.2921
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 15	 8	 0.87903225	 0.93162394	 0.9045643
# absent	 38	 8	 15	 0.82608694	 0.7169811	 0.7676768
# tp: 147 fp: 23 fn: 23 labels: 2
# Macro-average	 prec: 0.85255957, rec: 0.82430255, f1: 0.83819294
# Micro-average	 prec: 0.86470586, rec: 0.86470586, f1: 0.86470586
#
#
# Epoch: 32 started, learning rate: 1.9371141E-4, dataset size: 577
# Done, 3.708392354 total training loss: 1.0742954, avg training loss: 0.21485908, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.63s
# Total validation loss: 0.4533	Avg validation loss: 0.2266
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 106	 5	 11	 0.954955	 0.9059829	 0.92982465
# absent	 22	 11	 5	 0.6666667	 0.8148148	 0.73333335
# tp: 128 fp: 16 fn: 16 labels: 2
# Macro-average	 prec: 0.8108108, rec: 0.8603989, f1: 0.83486915
# Micro-average	 prec: 0.8888889, rec: 0.8888889, f1: 0.8888889
#
#
# Quality on test dataset:
# time to finish evaluation: 0.75s
# Total test loss: 0.5637	Avg test loss: 0.2818
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 108	 13	 9	 0.892562	 0.9230769	 0.90756303
# absent	 40	 9	 13	 0.81632656	 0.754717	 0.7843138
# tp: 148 fp: 22 fn: 22 labels: 2
# Macro-average	 prec: 0.85444427, rec: 0.838897, f1: 0.8465993
# Micro-average	 prec: 0.87058824, rec: 0.87058824, f1: 0.87058824
#
#
# Epoch: 33 started, learning rate: 1.8402583E-4, dataset size: 577
# Done, 3.700960581 total training loss: 1.1127344, avg training loss: 0.22254689, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.63s
# Total validation loss: 0.4464	Avg validation loss: 0.2232
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 9	 8	 0.9237288	 0.93162394	 0.9276596
# absent	 18	 8	 9	 0.6923077	 0.6666667	 0.6792453
# tp: 127 fp: 17 fn: 17 labels: 2
# Macro-average	 prec: 0.80801827, rec: 0.79914534, f1: 0.80355734
# Micro-average	 prec: 0.8819444, rec: 0.8819444, f1: 0.8819444
#
#
# Quality on test dataset:
# time to finish evaluation: 0.75s
# Total test loss: 0.5886	Avg test loss: 0.2943
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 108	 15	 9	 0.8780488	 0.9230769	 0.9
# absent	 38	 9	 15	 0.80851066	 0.7169811	 0.76000005
# tp: 146 fp: 24 fn: 24 labels: 2
# Macro-average	 prec: 0.8432797, rec: 0.820029, f1: 0.8314918
# Micro-average	 prec: 0.85882354, rec: 0.85882354, f1: 0.85882354
#
#
# Epoch: 34 started, learning rate: 1.7482454E-4, dataset size: 577
# Done, 3.708530403 total training loss: 1.123118, avg training loss: 0.2246236, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.63s
# Total validation loss: 0.4641	Avg validation loss: 0.2320
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 110	 9	 7	 0.92436975	 0.94017094	 0.9322034
# absent	 18	 7	 9	 0.72	 0.6666667	 0.69230765
# tp: 128 fp: 16 fn: 16 labels: 2
# Macro-average	 prec: 0.8221849, rec: 0.8034188, f1: 0.81269354
# Micro-average	 prec: 0.8888889, rec: 0.8888889, f1: 0.8888889
#
#
# Quality on test dataset:
# time to finish evaluation: 0.73s
# Total test loss: 0.6113	Avg test loss: 0.3056
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 110	 15	 7	 0.88	 0.94017094	 0.90909094
# absent	 38	 7	 15	 0.84444445	 0.7169811	 0.77551025
# tp: 148 fp: 22 fn: 22 labels: 2
# Macro-average	 prec: 0.8622222, rec: 0.828576, f1: 0.8450643
# Micro-average	 prec: 0.87058824, rec: 0.87058824, f1: 0.87058824
#
#
# Epoch: 35 started, learning rate: 1.6608331E-4, dataset size: 577
# Done, 3.751109968 total training loss: 0.9947616, avg training loss: 0.19895232, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.76s
# Total validation loss: 0.4924	Avg validation loss: 0.2462
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 105	 5	 12	 0.95454544	 0.8974359	 0.92511004
# absent	 22	 12	 5	 0.64705884	 0.8148148	 0.7213115
# tp: 127 fp: 17 fn: 17 labels: 2
# Macro-average	 prec: 0.8008021, rec: 0.85612535, f1: 0.82754016
# Micro-average	 prec: 0.8819444, rec: 0.8819444, f1: 0.8819444
#
#
# Quality on test dataset:
# time to finish evaluation: 0.88s
# Total test loss: 0.5602	Avg test loss: 0.2801
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 10	 8	 0.9159664	 0.93162394	 0.9237288
# absent	 43	 8	 10	 0.84313726	 0.8113208	 0.82692313
# tp: 152 fp: 18 fn: 18 labels: 2
# Macro-average	 prec: 0.8795518, rec: 0.87147236, f1: 0.87549347
# Micro-average	 prec: 0.89411765, rec: 0.89411765, f1: 0.89411765
#
#
# Epoch: 36 started, learning rate: 1.5777914E-4, dataset size: 577
# Done, 3.867323939 total training loss: 1.0031947, avg training loss: 0.20063893, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.62s
# Total validation loss: 0.4612	Avg validation loss: 0.2306
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 110	 9	 7	 0.92436975	 0.94017094	 0.9322034
# absent	 18	 7	 9	 0.72	 0.6666667	 0.69230765
# tp: 128 fp: 16 fn: 16 labels: 2
# Macro-average	 prec: 0.8221849, rec: 0.8034188, f1: 0.81269354
# Micro-average	 prec: 0.8888889, rec: 0.8888889, f1: 0.8888889
#
#
# Quality on test dataset:
# time to finish evaluation: 0.73s
# Total test loss: 0.6014	Avg test loss: 0.3007
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 110	 15	 7	 0.88	 0.94017094	 0.90909094
# absent	 38	 7	 15	 0.84444445	 0.7169811	 0.77551025
# tp: 148 fp: 22 fn: 22 labels: 2
# Macro-average	 prec: 0.8622222, rec: 0.828576, f1: 0.8450643
# Micro-average	 prec: 0.87058824, rec: 0.87058824, f1: 0.87058824
#
#
# Epoch: 37 started, learning rate: 1.4989018E-4, dataset size: 577
# Done, 3.643157611 total training loss: 1.0213134, avg training loss: 0.20426269, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.62s
# Total validation loss: 0.4627	Avg validation loss: 0.2314
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 9	 8	 0.9237288	 0.93162394	 0.9276596
# absent	 18	 8	 9	 0.6923077	 0.6666667	 0.6792453
# tp: 127 fp: 17 fn: 17 labels: 2
# Macro-average	 prec: 0.80801827, rec: 0.79914534, f1: 0.80355734
# Micro-average	 prec: 0.8819444, rec: 0.8819444, f1: 0.8819444
#
#
# Quality on test dataset:
# time to finish evaluation: 0.77s
# Total test loss: 0.5926	Avg test loss: 0.2963
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 15	 8	 0.87903225	 0.93162394	 0.9045643
# absent	 38	 8	 15	 0.82608694	 0.7169811	 0.7676768
# tp: 147 fp: 23 fn: 23 labels: 2
# Macro-average	 prec: 0.85255957, rec: 0.82430255, f1: 0.83819294
# Micro-average	 prec: 0.86470586, rec: 0.86470586, f1: 0.86470586
#
#
# Epoch: 38 started, learning rate: 1.4239567E-4, dataset size: 577
# Done, 3.888732905 total training loss: 0.98817545, avg training loss: 0.19763508, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.62s
# Total validation loss: 0.4823	Avg validation loss: 0.2411
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 107	 6	 10	 0.94690263	 0.9145299	 0.93043476
# absent	 21	 10	 6	 0.67741936	 0.7777778	 0.724138
# tp: 128 fp: 16 fn: 16 labels: 2
# Macro-average	 prec: 0.81216097, rec: 0.84615386, f1: 0.828809
# Micro-average	 prec: 0.8888889, rec: 0.8888889, f1: 0.8888889
#
#
# Quality on test dataset:
# time to finish evaluation: 0.74s
# Total test loss: 0.5630	Avg test loss: 0.2815
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 12	 8	 0.90082645	 0.93162394	 0.9159664
# absent	 41	 8	 12	 0.8367347	 0.7735849	 0.8039216
# tp: 150 fp: 20 fn: 20 labels: 2
# Macro-average	 prec: 0.8687806, rec: 0.8526044, f1: 0.8606165
# Micro-average	 prec: 0.88235295, rec: 0.88235295, f1: 0.88235295
#
#
# Epoch: 39 started, learning rate: 1.3527588E-4, dataset size: 577
# Done, 3.847999505 total training loss: 1.0361348, avg training loss: 0.20722696, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.63s
# Total validation loss: 0.4720	Avg validation loss: 0.2360
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 108	 9	 9	 0.9230769	 0.9230769	 0.9230769
# absent	 18	 9	 9	 0.6666667	 0.6666667	 0.6666667
# tp: 126 fp: 18 fn: 18 labels: 2
# Macro-average	 prec: 0.7948718, rec: 0.7948718, f1: 0.79487187
# Micro-average	 prec: 0.875, rec: 0.875, f1: 0.875
#
#
# Quality on test dataset:
# time to finish evaluation: 0.76s
# Total test loss: 0.5818	Avg test loss: 0.2909
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 15	 8	 0.87903225	 0.93162394	 0.9045643
# absent	 38	 8	 15	 0.82608694	 0.7169811	 0.7676768
# tp: 147 fp: 23 fn: 23 labels: 2
# Macro-average	 prec: 0.85255957, rec: 0.82430255, f1: 0.83819294
# Micro-average	 prec: 0.86470586, rec: 0.86470586, f1: 0.86470586
#
#
# Epoch: 40 started, learning rate: 1.2851208E-4, dataset size: 577
# Done, 3.992028232 total training loss: 0.9843068, avg training loss: 0.19686136, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.64s
# Total validation loss: 0.4831	Avg validation loss: 0.2415
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 110	 9	 7	 0.92436975	 0.94017094	 0.9322034
# absent	 18	 7	 9	 0.72	 0.6666667	 0.69230765
# tp: 128 fp: 16 fn: 16 labels: 2
# Macro-average	 prec: 0.8221849, rec: 0.8034188, f1: 0.81269354
# Micro-average	 prec: 0.8888889, rec: 0.8888889, f1: 0.8888889
#
#
# Quality on test dataset:
# time to finish evaluation: 0.75s
# Total test loss: 0.6017	Avg test loss: 0.3008
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 110	 15	 7	 0.88	 0.94017094	 0.90909094
# absent	 38	 7	 15	 0.84444445	 0.7169811	 0.77551025
# tp: 148 fp: 22 fn: 22 labels: 2
# Macro-average	 prec: 0.8622222, rec: 0.828576, f1: 0.8450643
# Micro-average	 prec: 0.87058824, rec: 0.87058824, f1: 0.87058824
#
#
# Epoch: 41 started, learning rate: 1.2208648E-4, dataset size: 577
# Done, 3.728688325 total training loss: 0.97542155, avg training loss: 0.1950843, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.64s
# Total validation loss: 0.4834	Avg validation loss: 0.2417
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 108	 8	 9	 0.9310345	 0.9230769	 0.92703867
# absent	 19	 9	 8	 0.6785714	 0.7037037	 0.690909
# tp: 127 fp: 17 fn: 17 labels: 2
# Macro-average	 prec: 0.80480295, rec: 0.8133903, f1: 0.80907387
# Micro-average	 prec: 0.8819444, rec: 0.8819444, f1: 0.8819444
#
#
# Quality on test dataset:
# time to finish evaluation: 0.74s
# Total test loss: 0.5800	Avg test loss: 0.2900
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 15	 8	 0.87903225	 0.93162394	 0.9045643
# absent	 38	 8	 15	 0.82608694	 0.7169811	 0.7676768
# tp: 147 fp: 23 fn: 23 labels: 2
# Macro-average	 prec: 0.85255957, rec: 0.82430255, f1: 0.83819294
# Micro-average	 prec: 0.86470586, rec: 0.86470586, f1: 0.86470586
#
#
# Epoch: 42 started, learning rate: 1.15982155E-4, dataset size: 577
# Done, 3.911078851 total training loss: 0.9030424, avg training loss: 0.18060848, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.63s
# Total validation loss: 0.5104	Avg validation loss: 0.2552
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 106	 6	 11	 0.9464286	 0.9059829	 0.92576426
# absent	 21	 11	 6	 0.65625	 0.7777778	 0.7118644
# tp: 127 fp: 17 fn: 17 labels: 2
# Macro-average	 prec: 0.80133927, rec: 0.8418803, f1: 0.8211097
# Micro-average	 prec: 0.8819444, rec: 0.8819444, f1: 0.8819444
#
#
# Quality on test dataset:
# time to finish evaluation: 0.76s
# Total test loss: 0.5609	Avg test loss: 0.2804
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 12	 8	 0.90082645	 0.93162394	 0.9159664
# absent	 41	 8	 12	 0.8367347	 0.7735849	 0.8039216
# tp: 150 fp: 20 fn: 20 labels: 2
# Macro-average	 prec: 0.8687806, rec: 0.8526044, f1: 0.8606165
# Micro-average	 prec: 0.88235295, rec: 0.88235295, f1: 0.88235295
#
#
# Epoch: 43 started, learning rate: 1.1018305E-4, dataset size: 577
# Done, 3.762413828 total training loss: 0.96100485, avg training loss: 0.19220097, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.65s
# Total validation loss: 0.4962	Avg validation loss: 0.2481
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 108	 8	 9	 0.9310345	 0.9230769	 0.92703867
# absent	 19	 9	 8	 0.6785714	 0.7037037	 0.690909
# tp: 127 fp: 17 fn: 17 labels: 2
# Macro-average	 prec: 0.80480295, rec: 0.8133903, f1: 0.80907387
# Micro-average	 prec: 0.8819444, rec: 0.8819444, f1: 0.8819444
#
#
# Quality on test dataset:
# time to finish evaluation: 0.76s
# Total test loss: 0.5831	Avg test loss: 0.2915
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 15	 8	 0.87903225	 0.93162394	 0.9045643
# absent	 38	 8	 15	 0.82608694	 0.7169811	 0.7676768
# tp: 147 fp: 23 fn: 23 labels: 2
# Macro-average	 prec: 0.85255957, rec: 0.82430255, f1: 0.83819294
# Micro-average	 prec: 0.86470586, rec: 0.86470586, f1: 0.86470586
#
#
# Epoch: 44 started, learning rate: 1.046739E-4, dataset size: 577
# Done, 4.765603512 total training loss: 0.9104979, avg training loss: 0.18209958, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.68s
# Total validation loss: 0.5109	Avg validation loss: 0.2555
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 110	 9	 7	 0.92436975	 0.94017094	 0.9322034
# absent	 18	 7	 9	 0.72	 0.6666667	 0.69230765
# tp: 128 fp: 16 fn: 16 labels: 2
# Macro-average	 prec: 0.8221849, rec: 0.8034188, f1: 0.81269354
# Micro-average	 prec: 0.8888889, rec: 0.8888889, f1: 0.8888889
#
#
# Quality on test dataset:
# time to finish evaluation: 0.76s
# Total test loss: 0.6088	Avg test loss: 0.3044
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 110	 15	 7	 0.88	 0.94017094	 0.90909094
# absent	 38	 7	 15	 0.84444445	 0.7169811	 0.77551025
# tp: 148 fp: 22 fn: 22 labels: 2
# Macro-average	 prec: 0.8622222, rec: 0.828576, f1: 0.8450643
# Micro-average	 prec: 0.87058824, rec: 0.87058824, f1: 0.87058824
#
#
# Epoch: 45 started, learning rate: 9.94402E-5, dataset size: 577
# Done, 3.692347665 total training loss: 0.9236671, avg training loss: 0.18473342, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.70s
# Total validation loss: 0.5057	Avg validation loss: 0.2528
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 108	 9	 9	 0.9230769	 0.9230769	 0.9230769
# absent	 18	 9	 9	 0.6666667	 0.6666667	 0.6666667
# tp: 126 fp: 18 fn: 18 labels: 2
# Macro-average	 prec: 0.7948718, rec: 0.7948718, f1: 0.79487187
# Micro-average	 prec: 0.875, rec: 0.875, f1: 0.875
#
#
# Quality on test dataset:
# time to finish evaluation: 1.00s
# Total test loss: 0.5921	Avg test loss: 0.2960
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 15	 8	 0.87903225	 0.93162394	 0.9045643
# absent	 38	 8	 15	 0.82608694	 0.7169811	 0.7676768
# tp: 147 fp: 23 fn: 23 labels: 2
# Macro-average	 prec: 0.85255957, rec: 0.82430255, f1: 0.83819294
# Micro-average	 prec: 0.86470586, rec: 0.86470586, f1: 0.86470586
#
#
# Epoch: 46 started, learning rate: 9.446819E-5, dataset size: 577
# Done, 5.376386068 total training loss: 0.8882773, avg training loss: 0.17765546, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.90s
# Total validation loss: 0.5159	Avg validation loss: 0.2580
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 107	 8	 10	 0.93043476	 0.9145299	 0.92241377
# absent	 19	 10	 8	 0.6551724	 0.7037037	 0.67857146
# tp: 126 fp: 18 fn: 18 labels: 2
# Macro-average	 prec: 0.7928036, rec: 0.80911684, f1: 0.80087715
# Micro-average	 prec: 0.875, rec: 0.875, f1: 0.875
#
#
# Quality on test dataset:
# time to finish evaluation: 0.94s
# Total test loss: 0.5748	Avg test loss: 0.2874
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 13	 8	 0.89344263	 0.93162394	 0.9121339
# absent	 40	 8	 13	 0.8333333	 0.754717	 0.79207915
# tp: 149 fp: 21 fn: 21 labels: 2
# Macro-average	 prec: 0.86338794, rec: 0.84317046, f1: 0.8531594
# Micro-average	 prec: 0.87647057, rec: 0.87647057, f1: 0.87647057
#
#
# Epoch: 47 started, learning rate: 8.9744775E-5, dataset size: 577
# Done, 4.27659462 total training loss: 0.87426704, avg training loss: 0.17485341, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.62s
# Total validation loss: 0.5163	Avg validation loss: 0.2581
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 107	 8	 10	 0.93043476	 0.9145299	 0.92241377
# absent	 19	 10	 8	 0.6551724	 0.7037037	 0.67857146
# tp: 126 fp: 18 fn: 18 labels: 2
# Macro-average	 prec: 0.7928036, rec: 0.80911684, f1: 0.80087715
# Micro-average	 prec: 0.875, rec: 0.875, f1: 0.875
#
#
# Quality on test dataset:
# time to finish evaluation: 0.74s
# Total test loss: 0.5827	Avg test loss: 0.2914
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 15	 8	 0.87903225	 0.93162394	 0.9045643
# absent	 38	 8	 15	 0.82608694	 0.7169811	 0.7676768
# tp: 147 fp: 23 fn: 23 labels: 2
# Macro-average	 prec: 0.85255957, rec: 0.82430255, f1: 0.83819294
# Micro-average	 prec: 0.86470586, rec: 0.86470586, f1: 0.86470586
#
#
# Epoch: 48 started, learning rate: 8.525753E-5, dataset size: 577
# Done, 3.757914745 total training loss: 0.9233907, avg training loss: 0.18467814, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.63s
# Total validation loss: 0.5204	Avg validation loss: 0.2602
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 8	 8	 0.93162394	 0.93162394	 0.93162394
# absent	 19	 8	 8	 0.7037037	 0.7037037	 0.7037037
# tp: 128 fp: 16 fn: 16 labels: 2
# Macro-average	 prec: 0.8176638, rec: 0.8176638, f1: 0.8176638
# Micro-average	 prec: 0.8888889, rec: 0.8888889, f1: 0.8888889
#
#
# Quality on test dataset:
# time to finish evaluation: 0.73s
# Total test loss: 0.5967	Avg test loss: 0.2983
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 15	 8	 0.87903225	 0.93162394	 0.9045643
# absent	 38	 8	 15	 0.82608694	 0.7169811	 0.7676768
# tp: 147 fp: 23 fn: 23 labels: 2
# Macro-average	 prec: 0.85255957, rec: 0.82430255, f1: 0.83819294
# Micro-average	 prec: 0.86470586, rec: 0.86470586, f1: 0.86470586
#
#
# Epoch: 49 started, learning rate: 8.099466E-5, dataset size: 577
# Done, 3.828811155 total training loss: 0.8752636, avg training loss: 0.17505272, batches: 5
# Quality on validation dataset (20.0%), validation examples = 144
# time to finish evaluation: 0.62s
# Total validation loss: 0.5227	Avg validation loss: 0.2613
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 8	 8	 0.93162394	 0.93162394	 0.93162394
# absent	 19	 8	 8	 0.7037037	 0.7037037	 0.7037037
# tp: 128 fp: 16 fn: 16 labels: 2
# Macro-average	 prec: 0.8176638, rec: 0.8176638, f1: 0.8176638
# Micro-average	 prec: 0.8888889, rec: 0.8888889, f1: 0.8888889
#
#
# Quality on test dataset:
# time to finish evaluation: 0.77s
# Total test loss: 0.5948	Avg test loss: 0.2974
# label	 tp	 fp	 fn	 prec	 rec	 f1
# present	 109	 15	 8	 0.87903225	 0.93162394	 0.9045643
# absent	 38	 8	 15	 0.82608694	 0.7169811	 0.7676768
# tp: 147 fp: 23 fn: 23 labels: 2
# Macro-average	 prec: 0.85255957, rec: 0.82430255, f1: 0.83819294
# Micro-average	 prec: 0.86470586, rec: 0.86470586, f1: 0.86470586

# %%
preds = assertion_model.transform(test_data).select('label','assertion.result')

preds.show()
# Out:
# +-------+---------+
# |  label|   result|
# +-------+---------+
# |present|[present]|
# | absent|[present]|
# |present|[present]|
# |present|[present]|
# |present|[present]|
# |present|[present]|
# |present|[present]|
# |present|[present]|
# |present|[present]|
# |present|[present]|
# |present|[present]|
# |present|[present]|
# |present|[present]|
# |present|[present]|
# |present|[present]|
# |present|[present]|
# |present|[present]|
# |present|[present]|
# |present|[present]|
# |present|[present]|
# +-------+---------+
# only showing top 20 rows

# %%
preds_df = preds.toPandas()

# %%
preds_df['result'] = preds_df['result'].apply(lambda x : x[0])
preds_df
# Out:
#        label   result
# 0    present  present
# 1     absent  present
# 2    present  present
# 3    present  present
# 4    present  present
# ..       ...      ...
# 165  present  present
# 166   absent   absent
# 167   absent   absent
# 168   absent   absent
# 169  present  present
#
# [170 rows x 2 columns]

# %%
# We are going to use sklearn to evalute the results on test dataset
from sklearn.metrics import classification_report

print (classification_report( preds_df['label'], preds_df['result']))
# Out:
#               precision    recall  f1-score   support
#
#       absent       0.83      0.72      0.77        53
#      present       0.88      0.93      0.90       117
#
#     accuracy                           0.86       170
#    macro avg       0.85      0.82      0.84       170
# weighted avg       0.86      0.86      0.86       170

# %%
# save model
assertion_model.stages[-1].write().overwrite().save('assertion_custom_model')

# %% [markdown]
# ## Load saved model

# %%
clinical_ner = medical.NerModel.pretrained("ner_clinical", "en", "clinical/models") \
    .setInputCols(["sentence", "token", "embeddings"]) \
    .setOutputCol("ner")

ner_converter = nlp.NerConverter() \
    .setInputCols(["sentence", "token", "ner"]) \
    .setOutputCol("ner_chunk")

clinical_assertion = medical.AssertionDLModel.load("assertion_custom_model") \
    .setInputCols(["sentence", "ner_chunk", "embeddings"]) \
    .setOutputCol("assertion")
    
nlpPipeline = Pipeline(stages=[
    documentAssembler, 
    sentenceDetector,
    tokenizer,
    word_embeddings,
    clinical_ner,
    ner_converter,
    clinical_assertion
    ])

empty_data = spark.createDataFrame([[""]]).toDF("text")

model = nlpPipeline.fit(empty_data)
# Out:
# ner_clinical download started this may take some time.
# [OK!]

# %%
text = 'Patient has a headache for the last 2 weeks, needs to get a head CT, and appears anxious when she walks fast. No alopecia noted. She denies pain'

light_model = LightPipeline(model)

light_result = light_model.fullAnnotate(text)[0]

print(text)

chunks=[]
entities=[]
status=[]
confidence=[]
for n,m in zip(light_result['ner_chunk'],light_result['assertion']):
    
    chunks.append(n.result)
    entities.append(n.metadata['entity']) 
    status.append(m.result)
    confidence.append(m.metadata['confidence'])
        
df = pd.DataFrame({'chunks':chunks, 'entities':entities, 'assertion':status, 'confidence':confidence})

df
# Out:
# Patient has a headache for the last 2 weeks, needs to get a head CT, and appears anxious when she walks fast. No alopecia noted. She denies pain
#        chunks entities assertion confidence
# 0  a headache  PROBLEM   present     0.9866
# 1   a head CT     TEST   present     0.9978
# 2     anxious  PROBLEM    absent      0.912
# 3    alopecia  PROBLEM    absent     0.9588
# 4        pain  PROBLEM    absent     0.6638
