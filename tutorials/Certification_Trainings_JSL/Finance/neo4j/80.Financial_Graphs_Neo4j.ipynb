# %% [markdown]
# # Financial Graphs with Spark NLP and Neo4J

# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/spark-nlp-workshop/blob/master/tutorials/Certification_Trainings_JSL/Finance/neo4j/80.Financial_Graphs_Neo4j.ipynb)

# %% [markdown]
# # Colab Setup

# %%
# Install the johnsnowlabs library to access Spark-OCR and Spark-NLP for Healthcare, Finance, and Legal.
! pip install johnsnowlabs
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting johnsnowlabs
#   Downloading johnsnowlabs-4.2.5-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.2/74.2 KB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from johnsnowlabs) (2.25.1)
# Collecting nlu==4.0.1rc4
#   Downloading nlu-4.0.1rc4-py3-none-any.whl (570 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.6/570.6 KB 19.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from johnsnowlabs) (1.21.6)
# Collecting spark-nlp-display==4.1
#   Downloading spark_nlp_display-4.1-py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.4/95.4 KB 5.9 MB/s eta 0:00:00
# Collecting databricks-api
#   Downloading databricks_api-0.8.0-py3-none-any.whl (7.2 kB)
# Collecting pyspark==3.1.2
#   Downloading pyspark-3.1.2.tar.gz (212.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.4/212.4 MB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting spark-nlp==4.2.4
#   Downloading spark_nlp-4.2.4-py2.py3-none-any.whl (448 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 448.4/448.4 KB 27.5 MB/s eta 0:00:00
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.8/dist-packages (from johnsnowlabs) (1.10.4)
# Requirement already satisfied: pandas>=1.3.5 in /usr/local/lib/python3.8/dist-packages (from nlu==4.0.1rc4->johnsnowlabs) (1.3.5)
# Requirement already satisfied: pyarrow>=0.16.0 in /usr/local/lib/python3.8/dist-packages (from nlu==4.0.1rc4->johnsnowlabs) (9.0.0)
# Collecting py4j==0.10.9
#   Downloading py4j-0.10.9-py2.py3-none-any.whl (198 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.6/198.6 KB 25.0 MB/s eta 0:00:00
# Collecting svgwrite==1.4
#   Downloading svgwrite-1.4-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 KB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: ipython in /usr/local/lib/python3.8/dist-packages (from spark-nlp-display==4.1->johnsnowlabs) (7.9.0)
# Collecting databricks-cli
#   Downloading databricks-cli-0.17.4.tar.gz (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.3/82.3 KB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic->johnsnowlabs) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->johnsnowlabs) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->johnsnowlabs) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->johnsnowlabs) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->johnsnowlabs) (4.0.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.3.5->nlu==4.0.1rc4->johnsnowlabs) (2022.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.3.5->nlu==4.0.1rc4->johnsnowlabs) (2.8.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.8/dist-packages (from databricks-cli->databricks-api->johnsnowlabs) (7.1.2)
# Collecting pyjwt>=1.7.0
#   Downloading PyJWT-2.6.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: oauthlib>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from databricks-cli->databricks-api->johnsnowlabs) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.8/dist-packages (from databricks-cli->databricks-api->johnsnowlabs) (0.8.10)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.8/dist-packages (from databricks-cli->databricks-api->johnsnowlabs) (1.15.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython->spark-nlp-display==4.1->johnsnowlabs) (4.4.2)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipython->spark-nlp-display==4.1->johnsnowlabs) (5.7.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython->spark-nlp-display==4.1->johnsnowlabs) (2.6.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython->spark-nlp-display==4.1->johnsnowlabs) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython->spark-nlp-display==4.1->johnsnowlabs) (57.4.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 72.2 MB/s eta 0:00:00
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython->spark-nlp-display==4.1->johnsnowlabs) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython->spark-nlp-display==4.1->johnsnowlabs) (2.0.10)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython->spark-nlp-display==4.1->johnsnowlabs) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython->spark-nlp-display==4.1->johnsnowlabs) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->spark-nlp-display==4.1->johnsnowlabs) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython->spark-nlp-display==4.1->johnsnowlabs) (0.7.0)
# Building wheels for collected packages: pyspark, databricks-cli
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.1.2-py2.py3-none-any.whl size=212880769 sha256=0b43e3e635a7e8b1f0c6d47e59fb98241413e4f4b7594765a3091e12dd82605a
#   Stored in directory: /root/.cache/pip/wheels/df/88/9e/58ef1f74892fef590330ca0830b5b6d995ba29b44f977b3926
#   Building wheel for databricks-cli (setup.py) ... done
#   Created wheel for databricks-cli: filename=databricks_cli-0.17.4-py3-none-any.whl size=142894 sha256=21dbdb4c215ae0e432382091de7910864b2dcb3c60bf7063b136b383bd3f94fd
#   Stored in directory: /root/.cache/pip/wheels/48/7c/6e/4bf2c1748c7ecf994ca951591de81674ed6bf633e1e337d873
# Successfully built pyspark databricks-cli
# Installing collected packages: spark-nlp, py4j, dataclasses, svgwrite, pyspark, pyjwt, jedi, colorama, databricks-cli, spark-nlp-display, nlu, databricks-api, johnsnowlabs
# Successfully installed colorama-0.4.6 databricks-api-0.8.0 databricks-cli-0.17.4 dataclasses-0.6 jedi-0.18.2 johnsnowlabs-4.2.5 nlu-4.0.1rc4 py4j-0.10.9 pyjwt-2.6.0 pyspark-3.1.2 spark-nlp-4.2.4 spark-nlp-display-4.1 svgwrite-1.4

# %%
from johnsnowlabs import nlp, finance
# After uploading your license run this to install all licensed Python Wheels and pre-download Jars the Spark Session JVM
# Make sure to restart your notebook afterwards for changes to take effect
nlp.install(force_browser=True)
# Out:
# 127.0.0.1 - - [13/Jan/2023 13:04:53] "GET /login?code=02JfyrvqbPTxPlTvoUNHRnyN9eBUkg HTTP/1.1" 200 -
# Downloading license...
# Licenses extracted successfully
# 📋 Stored John Snow Labs License in /root/.johnsnowlabs/licenses/license_number_0_for_Spark-Healthcare_Spark-OCR.json
# 👷 Setting up  John Snow Labs home in /root/.johnsnowlabs, this might take a few minutes.
# Downloading 🐍+🚀 Python Library spark_nlp-4.2.4-py2.py3-none-any.whl
# Downloading 🐍+💊 Python Library spark_nlp_jsl-4.2.4-py3-none-any.whl
# Downloading 🫘+🚀 Java Library spark-nlp-assembly-4.2.4.jar
# Downloading 🫘+💊 Java Library spark-nlp-jsl-4.2.4.jar
# 🙆 JSL Home setup in /root/.johnsnowlabs
# Installing /root/.johnsnowlabs/py_installs/spark_nlp_jsl-4.2.4-py3-none-any.whl to /usr/bin/python3
# Running: /usr/bin/python3 -m pip install /root/.johnsnowlabs/py_installs/spark_nlp_jsl-4.2.4-py3-none-any.whl
# Installed 1 products:
# 💊 Spark-Healthcare==4.2.4 installed! ✅ Heal the planet with NLP!

# %%
# Restart your runtime after running this cell.
# !pip install -q neo4j
# !pip install -q tqdm
# !pip install -q --user graphistry[all]
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.5/162.5 KB 17.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#   WARNING: Generating metadata for package neo4j produced metadata for project name unknown. Fix your #egg=neo4j fragments.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.8/157.8 KB 18.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#   WARNING: Generating metadata for package neo4j produced metadata for project name unknown. Fix your #egg=neo4j fragments.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.2/174.2 KB 18.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for neo4j (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.8/212.8 KB 19.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.1/155.1 KB 19.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 87.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 KB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 KB 12.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 648.0/648.0 KB 53.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.3/73.3 KB 10.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.2/280.2 KB 30.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 KB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.5/131.5 KB 17.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 84.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 106.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 75.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 22.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 71.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 98.0 MB/s eta 0:00:00
#   Building wheel for annoy (setup.py) ... done
#   Building wheel for neotime (setup.py) ... done
#   Building wheel for python-igraph (setup.py) ... done
#   Building wheel for sentence-transformers (setup.py) ... done
#   Building wheel for umap-learn (setup.py) ... done
#   Building wheel for pynndescent (setup.py) ... done
#   WARNING: The script huggingface-cli is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script transformers-cli is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %% [markdown]
# <b><h1><font color='darkred'>!!! ATTENTION !!! </font><h1><b>
#
# <b>After running previous cell, <font color='darkred'>RESTART the COLAB RUNTIME </font> and go ahead.<b>

# %%
from johnsnowlabs import nlp, finance
# Automatically load license data and start a session with all jars user has access to
spark = nlp.start()
# Out:
# 👌 Launched cpu optimized session with with: 🚀Spark-NLP==4.2.4, 💊Spark-Healthcare==4.2.4, running on ⚡ PySpark==3.1.2

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
# if you want to start the session with custom params as in start function above
def start(SECRET):
    builder = SparkSession.builder \
        .appName("Spark NLP Licensed") \
        .master("local[*]") \
        .config("spark.driver.memory", "16G") \
        .config("spark.serializer", "org.apache.spark.serializer.KryoSerializer") \
        .config("spark.kryoserializer.buffer.max", "2000M") \
        .config("spark.jars.packages", "com.johnsnowlabs.nlp:spark-nlp_2.12:"+PUBLIC_VERSION) \
        .config("spark.jars", "https://pypi.johnsnowlabs.com/"+SECRET+"/spark-nlp-jsl-"+JSL_VERSION+".jar")
      
    return builder.getOrCreate()

#spark = start(SECRET)

# %%
import os
import sys
import time
import json
import neo4j
import functools 
import graphistry
import numpy as np
import pandas as pd
from tqdm import tqdm
from scipy import spatial
from neo4j import GraphDatabase
from neo4j import GraphDatabase, Driver

print('neo4j', neo4j.__version__)
print('graphistry', graphistry.__version__)
# Out:
# neo4j 5.2.1
# graphistry 0.28.7

# %% [markdown]
# ### Establishing a connection with Neo4j Sandbox and pygraphistry

# %%
class Neo4jConnection:
    
    def __init__(self, uri, user, pwd):
        
        self.__uri = uri
        self.__user = user
        self.__pwd = pwd
        self.__driver = None
        
        try:
            self.__driver = GraphDatabase.driver(self.__uri, auth=(self.__user, self.__pwd))
        except Exception as e:
            print("Failed to create the driver:", e)
        
    def close(self):
        
        if self.__driver is not None:
            self.__driver.close()
        
    def query(self, query, parameters=None, db=None):
        
        assert self.__driver is not None, "Driver not initialized!"
        session = None
        response = None
        
        try: 
            session = self.__driver.session(database=db) if db is not None else self.__driver.session() 
            response = list(session.run(query, parameters))
        except Exception as e:
            print("Query failed:", e)
        finally: 
            if session is not None:
                session.close()
        return response

# %%
import neo4j
from neo4j import GraphDatabase
from neo4j import GraphDatabase, Driver


uri = 'bolt://3.93.153.8:7687'
pwd = 'thanks-pails-adherences'
user= 'neo4j'

#Create a Neo4J sandbox connection (https://neo4j.com/sandbox/)
conn = Neo4jConnection(uri=uri, user=user , pwd=pwd)

NEO4J = {
    'uri': uri, 
    'auth': ("neo4j", pwd)
}

# user,MY_PASSWORD = '',''

# create an account in graphistry for visualization and use the username and password here. (https://www.graphistry.com/)
graphistry.register(api=3,bolt=NEO4J,username=user, password=MY_PASSWORD)

# %% [markdown]
# ![Screenshot 2023-01-13 184905.png](data:image/png;base64,...)

# %% [markdown]
# # Available graphs in ChunkMappers

# %%
sec_results = [
    """Fig Publishing, Inc.""",
    """AWA Group LP""",
    """DatChat, Inc.""",
    """iConsumer Corp."""]

# %%
documentAssembler = nlp.DocumentAssembler()\
        .setInputCol("text")\
        .setOutputCol("document")

chunkAssembler = nlp.Doc2Chunk() \
    .setInputCols("document") \
    .setOutputCol("chunk") \
    .setIsArray(False)
#to change
CM = finance.ChunkMapperModel()\
      .pretrained("finmapper_edgar_companyname", "en", "finance/models")\
      .setInputCols(["chunk"])\
      .setOutputCol("mappings")

cm_pipeline = nlp.Pipeline(stages=[documentAssembler, chunkAssembler, CM])
# Out:
# finmapper_edgar_companyname download started this may take some time.
# [OK!]

# %%
text = [""]
test_data = spark.createDataFrame([text]).toDF("text")
fit_cm_pipeline = cm_pipeline.fit(test_data)

# %%
from collections import defaultdict
# import pandas as pd

dicti = defaultdict(list)

for i in sec_results:
    kk = fit_cm_pipeline.transform(spark.createDataFrame([[i]]).toDF("text"))
    cm_res = []
    cm_res.append(kk.collect())
    for r in cm_res:
        json_dict = dict()
        json_dict['mappings'] = []
        for n in r[0]['mappings']:
            json_dict['mappings'].append([str(n.annotatorType), n.begin, n.end, str(n.result), {k:v for k,v in n.metadata.items()}])
    for i in json_dict['mappings']:
        dicti[i[4]['relation']].append(i[3])
    #     print(i[3],'--->',i[4]['relation'])  
    # print('-------------------------------')

df = pd.DataFrame(dicti)

# %%
df
# Out:
#                    name                                              sic  \
# 0  Fig Publishing, Inc.             SERVICES-PREPACKAGED SOFTWARE [7372]
# 1          AWA Group LP                         INVESTMENT ADVICE [6282]
# 2         DatChat, Inc.  TELEGRAPH & OTHER MESSAGE COMMUNICATIONS [4822]
# 3       iConsumer Corp.                SERVICES-PERSONAL SERVICES [7200]
#
#   sic_code irs_number fiscal_year_end state_location state_incorporation  \
# 0     7372  475336565             931             CA                  DE
# 1     6282  371785232             630             NC                  DE
# 2     4822  472502264            1231             NJ                  NV
# 3     7200  274286597            1231             FL                  DE
#
#               business_street  business_city business_state business_zip  \
# 0            599 THIRD STREET  SAN FRANCISCO             CA        94107
# 1   116 SOUTH FRANKLIN STREET    ROCKY MOUNT             NC        27804
# 2            65 CHURCH STREET  NEW BRUNSWICK             NJ        08901
# 3  19821 NW 2ND AVE SUITE 351  MIAMI GARDENS             FL        33169
#
#    business_phone    former_name former_name_date        date company_id
# 0  (415) 689-5789                                  2017-01-23    1658966
# 1    952-446-6678                                  2017-01-23    1645148
# 2      7323544768  Dat Chat, Inc         20150722  2017-01-12    1648960
# 3      8003726095                                  2017-01-18    1652350

# %% [markdown]
# ### Generate csv for Neo4j

# %%
df.to_csv('graphs.csv',index=False)

# %% [markdown]
# To use the CSV in Neo4j there are a couple of ways mentioned [here](https://neo4j.com/developer/kb/import-csv-locations/). I have used the one where we upload it to google sheets and then publish it to web and then use the link that is generated in here.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Visualization using Neo4j and graphistry

# %%
query = '''
    // create an array of maps, using the keys() function
    LOAD CSV WITH HEADERS FROM 'https://docs.google.com/spreadsheets/d/e/2PACX-1vSSFwFkyFQgMwb_WyW8LYC0mN-7tFgt3jsiO3uq6D1atKG05w8gxSxQUytqpl1BUTbOs3ErjdO1eeWY/pub?gid=419410490&single=true&output=csv' as row
    with row.name AS company,
        [key IN keys(row) WHERE key<>'name' | {relType:key,location:row[key]}] as relTypeLocs

    WHERE row.name = 'DatChat, Inc.'

    unwind relTypeLocs AS relTypeLoc



    merge (l:locations {name:COALESCE(relTypeLoc.location,'Unknown')})



    merge (t:tokens {name:company})



    WITH l,t,



        relTypeLoc.relType AS relType



    // use apoc to create the rels



    CALL apoc.create.relationship(t,relType,{}, l) YIELD rel



    RETURN *
    '''

# %%
result = conn.query(query)

result
# Out:
# [<Record l=<Node element_id='0' labels=frozenset({'locations'}) properties={'name': '1648960'}> rel=<Relationship element_id='33' nodes=(<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>, <Node element_id='0' labels=frozenset({'locations'}) properties={'name': '1648960'}>) type='company_id' properties={}> relType='company_id' t=<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>>,
#  <Record l=<Node element_id='2' labels=frozenset({'locations'}) properties={'name': 'NJ'}> rel=<Relationship element_id='34' nodes=(<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>, <Node element_id='2' labels=frozenset({'locations'}) properties={'name': 'NJ'}>) type='state_location' properties={}> relType='state_location' t=<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>>,
#  <Record l=<Node element_id='3' labels=frozenset({'locations'}) properties={'name': '472502264'}> rel=<Relationship element_id='35' nodes=(<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>, <Node element_id='3' labels=frozenset({'locations'}) properties={'name': '472502264'}>) type='irs_number' properties={}> relType='irs_number' t=<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>>,
#  <Record l=<Node element_id='4' labels=frozenset({'locations'}) properties={'name': 'NEW BRUNSWICK'}> rel=<Relationship element_id='36' nodes=(<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>, <Node element_id='4' labels=frozenset({'locations'}) properties={'name': 'NEW BRUNSWICK'}>) type='business_city' properties={}> relType='business_city' t=<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>>,
#  <Record l=<Node element_id='5' labels=frozenset({'locations'}) properties={'name': '2017-01-12'}> rel=<Relationship element_id='37' nodes=(<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>, <Node element_id='5' labels=frozenset({'locations'}) properties={'name': '2017-01-12'}>) type='date' properties={}> relType='date' t=<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>>,
#  <Record l=<Node element_id='6' labels=frozenset({'locations'}) properties={'name': 'Dat Chat, Inc'}> rel=<Relationship element_id='38' nodes=(<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>, <Node element_id='6' labels=frozenset({'locations'}) properties={'name': 'Dat Chat, Inc'}>) type='former_name' properties={}> relType='former_name' t=<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>>,
#  <Record l=<Node element_id='7' labels=frozenset({'locations'}) properties={'name': '20150722'}> rel=<Relationship element_id='39' nodes=(<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>, <Node element_id='7' labels=frozenset({'locations'}) properties={'name': '20150722'}>) type='former_name_date' properties={}> relType='former_name_date' t=<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>>,
#  <Record l=<Node element_id='2' labels=frozenset({'locations'}) properties={'name': 'NJ'}> rel=<Relationship element_id='40' nodes=(<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>, <Node element_id='2' labels=frozenset({'locations'}) properties={'name': 'NJ'}>) type='business_state' properties={}> relType='business_state' t=<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>>,
#  <Record l=<Node element_id='8' labels=frozenset({'locations'}) properties={'name': '1231'}> rel=<Relationship element_id='41' nodes=(<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>, <Node element_id='8' labels=frozenset({'locations'}) properties={'name': '1231'}>) type='fiscal_year_end' properties={}> relType='fiscal_year_end' t=<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>>,
#  <Record l=<Node element_id='9' labels=frozenset({'locations'}) properties={'name': '65 CHURCH STREET'}> rel=<Relationship element_id='42' nodes=(<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>, <Node element_id='9' labels=frozenset({'locations'}) properties={'name': '65 CHURCH STREET'}>) type='business_street' properties={}> relType='business_street' t=<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>>,
#  <Record l=<Node element_id='10' labels=frozenset({'locations'}) properties={'name': '4822'}> rel=<Relationship element_id='43' nodes=(<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>, <Node element_id='10' labels=frozenset({'locations'}) properties={'name': '4822'}>) type='sic_code' properties={}> relType='sic_code' t=<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>>,
#  <Record l=<Node element_id='11' labels=frozenset({'locations'}) properties={'name': 'TELEGRAPH & OTHER MESSAGE COMMUNICATIONS [4822]'}> rel=<Relationship element_id='44' nodes=(<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>, <Node element_id='11' labels=frozenset({'locations'}) properties={'name': 'TELEGRAPH & OTHER MESSAGE COMMUNICATIONS [4822]'}>) type='sic' properties={}> relType='sic' t=<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>>,
#  <Record l=<Node element_id='12' labels=frozenset({'locations'}) properties={'name': '7323544768'}> rel=<Relationship element_id='45' nodes=(<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>, <Node element_id='12' labels=frozenset({'locations'}) properties={'name': '7323544768'}>) type='business_phone' properties={}> relType='business_phone' t=<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>>,
#  <Record l=<Node element_id='13' labels=frozenset({'locations'}) properties={'name': 'NV'}> rel=<Relationship element_id='46' nodes=(<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>, <Node element_id='13' labels=frozenset({'locations'}) properties={'name': 'NV'}>) type='state_incorporation' properties={}> relType='state_incorporation' t=<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>>,
#  <Record l=<Node element_id='14' labels=frozenset({'locations'}) properties={'name': '8901'}> rel=<Relationship element_id='47' nodes=(<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>, <Node element_id='14' labels=frozenset({'locations'}) properties={'name': '8901'}>) type='business_zip' properties={}> relType='business_zip' t=<Node element_id='1' labels=frozenset({'tokens'}) properties={'name': 'DatChat, Inc.'}>>]

# %%
g = graphistry.cypher(query)
print(g._edges.columns)
# g.plot()

g.plot()
# Out:
# Index(['_bolt_relationship_id', 'type', '_bolt_start_node_id_key',
#        '_bolt_end_node_id_key'],
#       dtype='object')
#             <iframe id="988ad8a9-2114-4dee-9ed7-033449d6fb79" src="https://hub.graphistry.com/graph/graph.html?dataset=1959900a8920408abb4b44f341202a8c&type=arrow&viztoken=9c4457e3-ad93-4429-a208-433678302a63&usertag=8938914a-pygraphistry-0.28.7&splashAfter=1673615394&info=true"
#                     allowfullscreen="true" webkitallowfullscreen="true" mozallowfullscreen="true"
#                     oallowfullscreen="true" msallowfullscreen="true"
#                     style="width:100%; height:500px; border: 1px solid #DDD; overflow: hidden"
#
#             >
#             </iframe>
#
#             <script>
#                 try {
#                   $("#988ad8a9-2114-4dee-9ed7-033449d6fb79").bind('mousewheel', function(e) { e.preventDefault(); });
#                 } catch (e) { console.error('exn catching scroll', e); }
#             </script>

# %% [markdown]
# ![graph.png](data:image/png;base64,...)

# %% [markdown]
# # Graph without Relation Extraction

# %%
document_assembler = nlp.DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")

sentence_detector = nlp.SentenceDetector() \
    .setInputCols(["document"]) \
    .setOutputCol("sentence") \
    .setCustomBounds(["\n\n"])

tokenizer = nlp.Tokenizer()\
    .setInputCols(["sentence"])\
    .setOutputCol("token")

embeddings = nlp.BertEmbeddings.pretrained("bert_embeddings_finbert_pretrain_yiyanghkust","en")\
    .setInputCols(["sentence", "token"])\
    .setOutputCol("embeddings")\
    .setCaseSensitive(True)\
    .setMaxSentenceLength(512)
#to change
ner_model = finance.NerModel.pretrained("finner_10k_summary","en","finance/models")\
    .setInputCols(["sentence", "token", "embeddings"])\
    .setOutputCol("ner")\

ner_converter = finance.NerConverterInternal()\
    .setInputCols(["sentence", "token", "ner"])\
    .setOutputCol("ner_chunk")

pipeline = nlp.Pipeline(stages=[
    document_assembler,
    sentence_detector,
    tokenizer,
    embeddings,
    ner_model,
    ner_converter   
    ])

model = pipeline.fit(spark.createDataFrame([[""]]).toDF("text"))
# Out:
# bert_embeddings_finbert_pretrain_yiyanghkust download started this may take some time.
# Approximate size to download 393.2 MB
# [OK!]
# finner_10k_summary download started this may take some time.
# [OK!]

# %%
data = spark.createDataFrame([["""ANNUAL REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES AND EXCHANGE ACT OF 1934
For the annual period ended January 31, 2021
or
TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934
For the transition period from________to_______
Commission File Number: 001-38856
PAGERDUTY, INC.
(Exact name of registrant as specified in its charter)
Delaware
27-2793871
(State or other jurisdiction of
incorporation or organization)
(I.R.S. Employer
Identification Number)
600 Townsend St., Suite 200, San Francisco, CA 94103
(844) 800-3889
(Address, including zip code, and telephone number, including area code, of registrant’s principal executive offices)
Securities registered pursuant to Section 12(b) of the Act:
Title of each class
Trading symbol(s)
Name of each exchange on which registered
Common Stock, $0.000005 par value,
PD
New York Stock Exchange"""]]).toDF("text")

result = model.transform(data)

# %%
import pyspark.sql.functions as F

result.select(F.explode(F.arrays_zip('ner_chunk.result', 'ner_chunk.metadata')).alias("cols")) \
               .select(F.expr("cols['0']").alias("ticker"),
                       F.expr("cols['1']['entity']").alias("label")).show(50, truncate = False)
# Out:
# +----------------------------------------------+-----------------+
# |ticker                                        |label            |
# +----------------------------------------------+-----------------+
# |January 31, 2021                              |FISCAL_YEAR      |
# |001-38856                                     |CFN              |
# |PAGERDUTY, INC                                |ORG              |
# |Delaware                                      |STATE            |
# |27-2793871                                    |IRS              |
# |600 Townsend St., Suite 200, San Francisco, CA|ADDRESS          |
# |(844) 800-3889                                |PHONE            |
# |Common Stock                                  |TITLE_CLASS      |
# |$0.000005                                     |TITLE_CLASS_VALUE|
# |PD                                            |TICKER           |
# |New York Stock Exchange                       |STOCK_EXCHANGE   |
# +----------------------------------------------+-----------------+

# %%
# from sparknlp_display import NerVisualizer

visualiser = nlp.viz.NerVisualizer()

visualiser.display(result = result.collect()[0] ,label_col = 'ner_chunk', document_col = 'document')
# Out:
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
#         border-width: medium;
#         text-align: center;
#
#         font-weight: 400;
#
#         border-radius: 5px;
#         padding: 2px 5px;
#         display: block;
#         margin: 3px 2px;
#
#     }
#     .spark-nlp-display-entity-type{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Montserrat', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-entity-resolution{
#         font-size: 14px;
#         line-height: 24px;
#         color: #ffffff;
#         font-family: 'Vistol Regular', sans-serif !important;
#
#         text-transform: uppercase;
#
#         font-weight: 500;
#
#         display: block;
#         padding: 3px 5px;
#     }
#
#     .spark-nlp-display-others{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         font-weight: 400;
#     }
#
# </style>
#  <span class="spark-nlp-display-others" style="background-color: white">ANNUAL REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES AND EXCHANGE ACT OF 1934<br>For the annual period ended </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #0B4F4B"><span class="spark-nlp-display-entity-name">January 31, 2021 </span><span class="spark-nlp-display-entity-type">FISCAL_YEAR</span></span><span class="spark-nlp-display-others" style="background-color: white"><br>or<br>TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934<br>For the transition period from________to_______<br>Commission File Number: </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #A168B1"><span class="spark-nlp-display-entity-name">001-38856 </span><span class="spark-nlp-display-entity-type">CFN</span></span><span class="spark-nlp-display-others" style="background-color: white"><br></span><span class="spark-nlp-display-entity-wrapper" style="background-color: #038F50"><span class="spark-nlp-display-entity-name">PAGERDUTY, INC </span><span class="spark-nlp-display-entity-type">ORG</span></span><span class="spark-nlp-display-others" style="background-color: white">.<br>(Exact name of registrant as specified in its charter)<br></span><span class="spark-nlp-display-entity-wrapper" style="background-color: #66567B"><span class="spark-nlp-display-entity-name">Delaware </span><span class="spark-nlp-display-entity-type">STATE</span></span><span class="spark-nlp-display-others" style="background-color: white"><br></span><span class="spark-nlp-display-entity-wrapper" style="background-color: #8DC618"><span class="spark-nlp-display-entity-name">27-2793871 </span><span class="spark-nlp-display-entity-type">IRS</span></span><span class="spark-nlp-display-others" style="background-color: white"><br>(State or other jurisdiction of<br>incorporation or organization)<br>(I.R.S. Employer<br>Identification Number)<br></span><span class="spark-nlp-display-entity-wrapper" style="background-color: #51526C"><span class="spark-nlp-display-entity-name">600 Townsend St., Suite 200, San Francisco, CA </span><span class="spark-nlp-display-entity-type">ADDRESS</span></span><span class="spark-nlp-display-others" style="background-color: white"> 94103<br></span><span class="spark-nlp-display-entity-wrapper" style="background-color: #B6BA77"><span class="spark-nlp-display-entity-name">(844) 800-3889 </span><span class="spark-nlp-display-entity-type">PHONE</span></span><span class="spark-nlp-display-others" style="background-color: white"><br>(Address, including zip code, and telephone number, including area code, of registrant’s principal executive offices)<br>Securities registered pursuant to Section 12(b) of the Act:<br>Title of each class<br>Trading symbol(s)<br>Name of each exchange on which registered<br></span><span class="spark-nlp-display-entity-wrapper" style="background-color: #68B052"><span class="spark-nlp-display-entity-name">Common Stock </span><span class="spark-nlp-display-entity-type">TITLE_CLASS</span></span><span class="spark-nlp-display-others" style="background-color: white">, </span><span class="spark-nlp-display-entity-wrapper" style="background-color: #12782C"><span class="spark-nlp-display-entity-name">$0.000005 </span><span class="spark-nlp-display-entity-type">TITLE_CLASS_VALUE</span></span><span class="spark-nlp-display-others" style="background-color: white"> par value,<br></span><span class="spark-nlp-display-entity-wrapper" style="background-color: #7D003C"><span class="spark-nlp-display-entity-name">PD </span><span class="spark-nlp-display-entity-type">TICKER</span></span><span class="spark-nlp-display-others" style="background-color: white"><br></span><span class="spark-nlp-display-entity-wrapper" style="background-color: #B6B54B"><span class="spark-nlp-display-entity-name">New York Stock Exchange </span><span class="spark-nlp-display-entity-type">STOCK_EXCHANGE</span></sp ...

# %% [markdown]
# ### Visualizing using Neo4j and graphistry

# %% [markdown]
# ### Generate csv for Neo4j

# %%
df = result.select(F.explode(F.arrays_zip('ner_chunk.result', 'ner_chunk.metadata')).alias("cols")) \
               .select(F.expr("cols['0']").alias("ticker"),
                       F.expr("cols['1']['entity']").alias("label")).toPandas()

# %%
df.to_csv('graphs.csv',index=False)

# %% [markdown]
# TO use the CSV in Neo4j there are a couple of ways mentioned [here](https://neo4j.com/developer/kb/import-csv-locations/). I have used the one where we upload it to google sheets and then publish it to web and then use the link that is generated in here.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Visualizing the Nodes and Edges

# %%
(graphistry
  .edges(df, 'label','ticker')
  .nodes(df,'label')
).plot()
# Out:
#             <iframe id="1cd44035-65b3-4770-abd7-4cfdb199ce54" src="https://hub.graphistry.com/graph/graph.html?dataset=f80ee9ae7dcd4ccc9ce14bf6b0f595bc&type=arrow&viztoken=acb20143-5b1d-4fbc-9d14-003c930c4407&usertag=8938914a-pygraphistry-0.28.7&splashAfter=1673615478&info=true"
#                     allowfullscreen="true" webkitallowfullscreen="true" mozallowfullscreen="true"
#                     oallowfullscreen="true" msallowfullscreen="true"
#                     style="width:100%; height:500px; border: 1px solid #DDD; overflow: hidden"
#
#             >
#             </iframe>
#
#             <script>
#                 try {
#                   $("#1cd44035-65b3-4770-abd7-4cfdb199ce54").bind('mousewheel', function(e) { e.preventDefault(); });
#                 } catch (e) { console.error('exn catching scroll', e); }
#             </script>

# %% [markdown]
# ![graph.png](data:image/png;base64,...)

# %% [markdown]
# # Graphs with NER and Relation Extraction

# %%
documentAssembler = nlp.DocumentAssembler()\
  .setInputCol("text")\
  .setOutputCol("document")

"""sentenceDetector = SentenceDetectorDLModel.pretrained("sentence_detector_dl","xx")\
        .setInputCols(["document"])\
        .setOutputCol("sentence")"""

tokenizer = nlp.Tokenizer()\
  .setInputCols("document")\
  .setOutputCol("token")

embeddings = nlp.BertEmbeddings.pretrained("bert_embeddings_sec_bert_base", "en") \
        .setInputCols("document", "token") \
        .setOutputCol("embeddings")\
        .setMaxSentenceLength(512)

ner_model = finance.NerModel.pretrained("finner_orgs_prods_alias","en","finance/models")\
        .setInputCols(["document", "token", "embeddings"])\
        .setOutputCol("ner")

ner_converter = finance.NerConverterInternal()\
        .setInputCols(["document","token","ner"])\
        .setOutputCol("ner_chunk")

"""
ONLY NEEDED IF YOU WANT TO FILTER RELATION PAIRS OR SYNTACTIC DISTANCE
pos_tagger = PerceptronModel()\
    .pretrained("pos_clinical", "en", "clinical/models") \
    .setInputCols(["document", "tokens"])\
    .setOutputCol("pos_tags")

dependency_parser = DependencyParserModel() \
    .pretrained("dependency_conllu", "en") \
    .setInputCols(["document", "pos_tags", "tokens"]) \
    .setOutputCol("dependencies")

# Set a filter on pairs of named entities which will be treated as relation candidates
re_filter = RENerChunksFilter()\
    .setInputCols(["ner_chunks", "dependencies"])\
    .setOutputCol("re_ner_chunks")\
#    .setMaxSyntacticDistance(7)\
#    .setRelationPairs(['PARTY-ALIAS', 'DOC-PARTY', 'DOC-EFFDATE'])
"""
reDL = finance.RelationExtractionDLModel.pretrained("finre_acquisitions_subsidiaries_md", "en", "finance/models")\
    .setPredictionThreshold(0.5)\
    .setInputCols(["ner_chunk", "document"])\
    .setOutputCol("relations")
# Out:
# bert_embeddings_sec_bert_base download started this may take some time.
# Approximate size to download 390.4 MB
# [OK!]
# finner_orgs_prods_alias download started this may take some time.
# [OK!]
# finre_acquisitions_subsidiaries_md download started this may take some time.
# [OK!]

# %%
pipeline = nlp.Pipeline(stages=[
    documentAssembler,
    tokenizer,
    embeddings,
    ner_model,
    ner_converter,
    reDL
])
"""sentenceDetector,
pos_tagger,
    dependency_parser,
    re_filter,
"""
# Out:
# 'sentenceDetector,\npos_tagger,\n    dependency_parser,\n    re_filter,\n'

# %%
text=['''
On January 25, 2019, the Company acquired all outstanding stock of SignifAI, Inc. ("SignifAI"), an event intelligence company specializing in artificial intelligence and machine learning.
''']

data = spark.createDataFrame([text]).toDF("text")
model = pipeline.fit(data)
lmodel = nlp.LightPipeline(model)

# %%
import pandas as pd

def get_relations_df (results, col='relations'):
  """Shows a Dataframe with the relations extracted by Spark NLP"""
  rel_pairs=[]
  for rel in results[0][col]:
      rel_pairs.append((
        rel.result, 
        rel.metadata['entity1'], 
        rel.metadata['entity1_begin'],
        rel.metadata['entity1_end'],
        rel.metadata['chunk1'], 
        rel.metadata['entity2'],
        rel.metadata['entity2_begin'],
        rel.metadata['entity2_end'],
        rel.metadata['chunk2'], 
        rel.metadata['confidence']
    ))

  rel_df = pd.DataFrame(rel_pairs, columns=['relation','entity1','entity1_begin','entity1_end','chunk1','entity2','entity2_begin','entity2_end','chunk2', 'confidence'])

  return rel_df

# %%
for i in range(len(text)):
    results = lmodel.fullAnnotate(text)
    rel_df = get_relations_df (results)
    rel_df = rel_df[rel_df['relation']!='no_rel']
    print(rel_df.to_string(index=False))
    print()
# Out:
#        relation entity1 entity1_begin entity1_end         chunk1 entity2 entity2_begin entity2_end   chunk2 confidence
# was_acquired_by     ORG            68          81 SignifAI, Inc.     ORG            26          32  Company  0.9929484
#           other     ORG            26          32        Company   ALIAS            85          92 SignifAI 0.97278804
#           other     ORG            68          81 SignifAI, Inc.   ALIAS            85          92 SignifAI  0.9998134

# %% [markdown]
# ### Visualization using Neo4j and graphistry

# %%
def update_data(query, rows, batch_size = 10000):
    # Function to handle the updating the Neo4j database in batch mode.
    # Especially for large datasets.
    total = 0
    batch = 0
    start = time.time()
    result = None

    while batch * batch_size < len(rows):

        res = conn.query(query, parameters={'rows': rows[batch*batch_size:(batch+1)*batch_size].to_dict('records')})
        total += res[0]['total']
        batch += 1
        result = {"total":total, "batches":batch, "time":time.time()-start}
        print(result)

    return result

# %%
def add_ners_rels(rows, batch_size=10000):
    # Adds NER nodes to the Neo4j graph as a batch job.
    query = '''
    //chunk1 NERs
    UNWIND $rows as row
    MERGE(n1:NER{name:row.chunk1}) ON CREATE SET n1.type=row.entity1

    //chunk2 NERs
    MERGE(n2:NER{name:row.chunk2}) ON CREATE SET n2.type=row.entity2

    //connect NERs
    WITH row, n1, n2
    MERGE (n1)-[:LINKS{relation:row.relation}]->(n2)
    RETURN count(*) as total  
    '''

    return update_data(query, rows, batch_size)

# %%
add_ners_rels(rel_df)
# Out:
# {'total': 3, 'batches': 1, 'time': 0.23645687103271484}
# {'total': 3, 'batches': 1, 'time': 0.23645687103271484}

# %% [markdown]
# ![graph.png](data:image/png;base64,...)

# %%
rel_df.to_csv('relations.csv',index=False)

# %%
# import pandas as pd
matches_df = pd.read_csv('/content/relations.csv')
matches_df.columns
# Out:
# Index(['relation', 'entity1', 'entity1_begin', 'entity1_end', 'chunk1',
#        'entity2', 'entity2_begin', 'entity2_end', 'chunk2', 'confidence'],
#       dtype='object')

# %%
(graphistry
  .edges(matches_df, 'chunk1',
        'chunk2')
  .nodes(matches_df, 'relation','entity1','entity2')
).plot()
# Out:
#             <iframe id="44870821-94fa-4bbe-a324-bc5753a0f989" src="https://hub.graphistry.com/graph/graph.html?dataset=d03b1fa07fd446b6b1bb0619db045933&type=arrow&viztoken=64730db8-f54a-4d74-9b2e-bdc51f687539&usertag=8938914a-pygraphistry-0.28.7&splashAfter=1673615588&info=true"
#                     allowfullscreen="true" webkitallowfullscreen="true" mozallowfullscreen="true"
#                     oallowfullscreen="true" msallowfullscreen="true"
#                     style="width:100%; height:500px; border: 1px solid #DDD; overflow: hidden"
#
#             >
#             </iframe>
#
#             <script>
#                 try {
#                   $("#44870821-94fa-4bbe-a324-bc5753a0f989").bind('mousewheel', function(e) { e.preventDefault(); });
#                 } catch (e) { console.error('exn catching scroll', e); }
#             </script>
